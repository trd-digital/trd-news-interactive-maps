# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 6th Apr. 13th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE     SOLD DATE PROPERTY TYPE              ADDRESS  \
# 1  PAST SALE  April-8-2025   Condo/Co-op  860 SE 6th Ave #302
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Deerfield Beach                FL             33441.0  195000.0   2.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Deerfield-Beach/860-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11033358         N          Y  26.306261 -80.095111
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward County

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-08    33
# 2025-04-11    33
# 2025-04-10    28
# 2025-04-07    26
# 2025-04-09    18
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 91   PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 76   PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 75   PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 55   PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 99   PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 95   PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 32   PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 139  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 93   PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 106  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 91          Hollywood                FL             33019.0  2499000.0   2.0
# 76    Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 75    Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 55          Hollywood                FL             33019.0  1390000.0   3.0
# 99    Fort Lauderdale                FL             33301.0   860000.0   2.0
# 95    Fort Lauderdale                FL             33316.0   830000.0   2.0
# 32    Fort Lauderdale                FL             33301.0   830000.0   3.0
# 139   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 93    Fort Lauderdale                FL             33316.0   725000.0   1.0
# 106  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 91     2.0  ...   Sold                         NaN                       NaN
# 76     3.5  ...   Sold                         NaN                       NaN
# 75     3.5  ...   Sold                         NaN                       NaN
# 55     3.0  ...   Sold                         NaN                       NaN
# 99     2.0  ...   Sold                         NaN                       NaN
# 95     2.0  ...   Sold                         NaN                       NaN
# 32     2.0  ...   Sold                         NaN                       NaN
# 139    2.0  ...   Sold                         NaN                       NaN
# 93     1.5  ...   Sold                         NaN                       NaN
# 106    3.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 91   https://www.redfin.com/FL/Hollywood/1400-S-Oce...       MARMLS
# 76   https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS
# 75   https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS
# 55   https://www.redfin.com/FL/Hollywood/4011-S-Oce...       MARMLS
# 99   https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS
# 95   https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 32   https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS
# 139  https://www.redfin.com/FL/Fort-Lauderdale/3850...  Beaches MLS
# 93   https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS
# 106  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 91   A11712814         N          Y  26.002892 -80.118439
# 76   F10479219         N          Y  26.126606 -80.120888
# 75   F10476528         N          Y  26.126606 -80.120888
# 55   A11728478         N          Y  25.986784 -80.118718
# 99   F10465832         N          Y  26.117655 -80.139463
# 95   F10475137         N          Y  26.118136 -80.107099
# 32   F10488785         N          Y  26.117655 -80.139463
# 139  F10426229         N          Y  26.175091 -80.097701
# 93   A11690817         N          Y  26.096516 -80.106815
# 106  A11682394         N          Y  25.982872 -80.119329
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 1  PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 2  PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 3  PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 4  PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 5  PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 6  PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 7  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 8  PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 9  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2499000.0   2.0
# 1   Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 3         Hollywood                FL             33019.0  1390000.0   3.0
# 4   Fort Lauderdale                FL             33301.0   860000.0   2.0
# 5   Fort Lauderdale                FL             33316.0   830000.0   2.0
# 6   Fort Lauderdale                FL             33301.0   830000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 8   Fort Lauderdale                FL             33316.0   725000.0   1.0
# 9  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    2.0  ... -80.118439  https://www.redfin.com/FL/Hollywood/1400-S-Oce...
# 1    3.5  ... -80.120888  https://www.redfin.com/FL/Fort-Lauderdale/161-...
# 2    3.5  ... -80.120888  https://www.redfin.com/FL/Fort-Lauderdale/161-...
# 3    3.0  ... -80.118718  https://www.redfin.com/FL/Hollywood/4011-S-Oce...
# 4    2.0  ... -80.139463  https://www.redfin.com/FL/Fort-Lauderdale/347-...
# 5    2.0  ... -80.107099  https://www.redfin.com/FL/Fort-Lauderdale/1-La...
# 6    2.0  ... -80.139463  https://www.redfin.com/FL/Fort-Lauderdale/347-...
# 7    2.0  ... -80.097701  https://www.redfin.com/FL/Fort-Lauderdale/3850...
# 8    1.5  ... -80.106815  https://www.redfin.com/FL/Fort-Lauderdale/2100...
# 9    3.0  ... -80.119329  https://www.redfin.com/FL/Hallandale-Beach/188...
#
#      list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0          Kamie Manzi              e-Wing Realty, Inc               None
# 1  Matthew Bertanzetti    Florida Luxurious Properties               None
# 2        Andrew Ziffer            Compass Florida, LLC               None
# 3      Gabriel Miranda                   Piquet Realty               None
# 4         Rachel Buemi       D'Angelo Realty Group LLC               None
# 5  Gilmar Scantamburlo         United Realty Group Inc               None
# 6     Debra Steinhardt       D'Angelo Realty Group LLC               None
# 7   Justin Bartholomew                    S & B Realty      Nancy Seltzer
# 8           Brian Hero      One Sotheby's Int'l Realty               None
# 9     Olga Zaurova, PA  Big International Realty, Inc.               None
#
#    list_broker_name_2      buy_agent_name_1               buy_broker_name_1  \
# 0                None       Micheline Nohra        Options Realty Team, LLC
# 1                None         Kelly Charles          The Agency Florida LLC
# 2                None    Elizabeth Caldwell            Compass Florida, LLC
# 3                None        Jonathan Perez    Fortune Christie's Intl R.E.
# 4                None           Oscar Manes  Keller Williams Capital Realty
# 5                None  Santiago Lopez White        United Realty Group, Inc
# 6                None       Tatiana Asailov        Tatiana Real Estate, Inc
# 7        S & B Realty    Justin Bartholomew                    S & B Realty
# 8                None            Brian Hero      One Sotheby's Int'l Realty
# 9                None             Esya Hart     Winston Towers Realty, Inc.
#
#    buy_agent_name_2  buy_broker_name_2
# 0              None               None
# 1              None               None
# 2              None               None
# 3              None               None
# 4              None               None
# 5              None               None
# 6              None               None
# 7     Nancy Seltzer       S & B Realty
# 8              None               None
# 9              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 138

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $311,070

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $271

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $42,927,599

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          138              311070          271                     42927599.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 201
# -----------
# Input Previous Week Condo Average Sales Price:
# 368669
# -----------
# Input Previous Week Condo Average PSF:
# 303
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 74102478.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE               ADDRESS       CITY  \
# 0  PAST SALE 2025-04-11   Condo/Co-op  1400 S Ocean Dr #506  Hollywood
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33019.0  2499000.0   2.0    2.0
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...  MARMLS  A11712814
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       Kamie Manzi
#
#    list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  e-Wing Realty, Inc              None               None  Micheline Nohra
#
#           buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Options Realty Team, LLC             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 1  PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 2  PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 3  PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 4  PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 5  PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 6  PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 7  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 8  PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 9  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2499000.0   2.0
# 1   Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 3         Hollywood                FL             33019.0  1390000.0   3.0
# 4   Fort Lauderdale                FL             33301.0   860000.0   2.0
# 5   Fort Lauderdale                FL             33316.0   830000.0   2.0
# 6   Fort Lauderdale                FL             33301.0   830000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 8   Fort Lauderdale                FL             33316.0   725000.0   1.0
# 9  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    2.0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
# 1    3.5            Palms On Venice       2128.0       NaN      2016.0
# 2    3.5            Palms On Venice       2128.0       NaN      2016.0
# 3    3.0                 HYDE BEACH       1740.0       NaN      2017.0
# 4    2.0                Watergarden       1204.0       NaN      2004.0
# 5    2.0       Venetian Condominium       1500.0       NaN      1971.0
# 6    2.0                Watergarden       1469.0       NaN      2004.0
# 7    2.0              Regency Tower       1650.0       NaN      1969.0
# 8    1.5    POINT OF AMERICAS CONDO       1109.0       NaN      1969.0
# 9    3.0  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
# 1             NaN          804.0     2009.0   Sold
# 2             NaN          775.0     2009.0   Sold
# 3             NaN          799.0     2384.0   Sold
# 4             NaN          714.0     1232.0   Sold
# 5             NaN          553.0     1286.0   Sold
# 6             NaN          565.0     1632.0   Sold
# 7             NaN          473.0     1609.0   Sold
# 8             NaN          654.0     1145.0   Sold
# 9             NaN          345.0     1731.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       MARMLS  A11712814
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10479219
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10476528
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...       MARMLS  A11728478
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10465832
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS  F10475137
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10488785
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...  Beaches MLS  F10426229
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11690817
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS  A11682394
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
# 1        N          Y  26.126606 -80.120888
# 2        N          Y  26.126606 -80.120888
# 3        N          Y  25.986784 -80.118718
# 4        N          Y  26.117655 -80.139463
# 5        N          Y  26.118136 -80.107099
# 6        N          Y  26.117655 -80.139463
# 7        N          Y  26.175091 -80.097701
# 8        N          Y  26.096516 -80.106815
# 9        N          Y  25.982872 -80.119329
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...          Kamie Manzi
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Matthew Bertanzetti
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...        Andrew Ziffer
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...      Gabriel Miranda
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...         Rachel Buemi
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Gilmar Scantamburlo
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...     Debra Steinhardt
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...   Justin Bartholomew
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...           Brian Hero
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...     Olga Zaurova, PA
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0              e-Wing Realty, Inc              None               None
# 1    Florida Luxurious Properties              None               None
# 2            Compass Florida, LLC              None               None
# 3                   Piquet Realty              None               None
# 4       D'Angelo Realty Group LLC              None               None
# 5         United Realty Group Inc              None               None
# 6       D'Angelo Realty Group LLC              None               None
# 7                    S & B Realty     Nancy Seltzer       S & B Realty
# 8      One Sotheby's Int'l Realty              None               None
# 9  Big International Realty, Inc.              None               None
#
#        buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Micheline Nohra        Options Realty Team, LLC             None
# 1         Kelly Charles          The Agency Florida LLC             None
# 2    Elizabeth Caldwell            Compass Florida, LLC             None
# 3        Jonathan Perez    Fortune Christie's Intl R.E.             None
# 4           Oscar Manes  Keller Williams Capital Realty             None
# 5  Santiago Lopez White        United Realty Group, Inc             None
# 6       Tatiana Asailov        Tatiana Real Estate, Inc             None
# 7    Justin Bartholomew                    S & B Realty    Nancy Seltzer
# 8            Brian Hero      One Sotheby's Int'l Realty             None
# 9             Esya Hart     Winston Towers Realty, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7      S & B Realty     8    blue
# 8              None     9    blue
# 9              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78c026a75c546a2a6448d1c26fe5ba8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 6th — Apr. 13th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78c026a75c546a2a6448d1c26fe5ba8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_78c026a75c546a2a6448d1c26fe5ba8e = L.map(
#                 &quot;map_78c026a75c546a2a6448d1c26fe5ba8e&quot;,
#                 {
#                     center: [26.14911168714286, -80.17437720000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_b0c2bd2a010bc4ccfe7091602edc0a2a = L.featureGroup(
#                 {}
#             ).addTo(map_78c026a75c546a2a6448d1c26fe5ba8e);
#
#
#             var marker_10399d45f65c4073a57b247df4941a04 = L.marker(
#                 [26.0028915, -80.1184386],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_b0c2bd2a010bc4ccfe7091602edc0a2a);
#
#
#             var icon_5aea645f93c5d452c1209ec60471854d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10399d45f65c4073a57b247df4941a04.setIcon(icon_5aea645f93c5d452c1209ec60471854d);
#
#
#         var popup_445ce897c345cbdd05340beacf0569f6 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_fa045ef429332ec6627386cc92612a3f = $(`&lt;div id=&quot;html_fa045ef429332ec6627386cc92612a3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1400 S Ocean Dr #506&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,499,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,996.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;1,252.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1969.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_445ce897c345cbdd05340beacf0569f6.setContent(html_fa045ef429332ec6627386cc92612a3f);
#
#
#
#         marker_10399d45f65c4073a57b247df4941a04.bindPopup(popup_445ce897c345cbdd05340beacf0569f6)
#         ;
#
#
#
#
#             var feature_group_2bfd097bcdad689a1b269028985fc83d = L.featureGroup(
#                 {}
#             ).addTo(map_78c026a75c546a2a6448d1c26fe5ba8e);
#
#
#             var marker_4437123b73df1937da438a9d55a7e986 = L.marker(
#                 [26.1266064, -80.1208877],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_2bfd097bcdad689a1b269028985fc83d);
#
#
#             var icon_a3f86773163aa5648e288fcb2017a394 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4437123b73df1937da438a9d55a7e986.setIcon(icon_a3f86773163aa5648e288fcb2017a394);
#
#
#         var popup_bf09ca90a0eb996ee998820243ff5384 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_454df3846db5df549e56ca58e549ca49 = $(`&lt;div id=&quot;html_454df3846db5df549e56ca58e549ca49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;161 Isle Of Venice Dr #301&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,710,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$804.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,128.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2016.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_bf09ca90a0eb996ee998820243ff5384.setContent(html_454df3846db5df549e56ca58e549ca49);
#
#
#
#         marker_4437123b73df1937da438a9d55a7e986.bindPopup(popup_bf09ca90a0eb996ee998820243ff5384)
#         ;
#
#
#
#
#             var marker_537cbee7c134e20cd106d9b295028ef4 = L.marker(
#                 [26.1266064, -80.1208877],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_2bfd097bcdad689a1b269028985fc83d);
#
#
#             var icon_8053da0554bfd318d15e243102bfd5d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_537cbee7c134e20cd106d9b295028ef4.setIcon(icon_8053da0554bfd318d15e243102bfd5d7);
#
#
#         var popup_278153c26b61f51ac3afb4213c4ac667 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a1b74bca228a6c20f0d8c82d1dde46e

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE               ADDRESS       CITY  \
# 0  PAST SALE 2025-04-11   Condo/Co-op  1400 S Ocean Dr #506  Hollywood
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33019.0  2499000.0   2.0    2.0
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...  MARMLS  A11712814
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       Kamie Manzi
#
#    list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  e-Wing Realty, Inc              None               None  Micheline Nohra
#
#           buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Options Realty Team, LLC             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04142025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #506 in Hollywood'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 1  PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 2  PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 3  PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 4  PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 5  PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 6  PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 7  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 8  PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 9  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2499000.0   2.0
# 1   Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 3         Hollywood                FL             33019.0  1390000.0   3.0
# 4   Fort Lauderdale                FL             33301.0   860000.0   2.0
# 5   Fort Lauderdale                FL             33316.0   830000.0   2.0
# 6   Fort Lauderdale                FL             33301.0   830000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 8   Fort Lauderdale                FL             33316.0   725000.0   1.0
# 9  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    2.0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
# 1    3.5            Palms On Venice       2128.0       NaN      2016.0
# 2    3.5            Palms On Venice       2128.0       NaN      2016.0
# 3    3.0                 HYDE BEACH       1740.0       NaN      2017.0
# 4    2.0                Watergarden       1204.0       NaN      2004.0
# 5    2.0       Venetian Condominium       1500.0       NaN      1971.0
# 6    2.0                Watergarden       1469.0       NaN      2004.0
# 7    2.0              Regency Tower       1650.0       NaN      1969.0
# 8    1.5    POINT OF AMERICAS CONDO       1109.0       NaN      1969.0
# 9    3.0  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
# 1             NaN          804.0     2009.0   Sold
# 2             NaN          775.0     2009.0   Sold
# 3             NaN          799.0     2384.0   Sold
# 4             NaN          714.0     1232.0   Sold
# 5             NaN          553.0     1286.0   Sold
# 6             NaN          565.0     1632.0   Sold
# 7             NaN          473.0     1609.0   Sold
# 8             NaN          654.0     1145.0   Sold
# 9             NaN          345.0     1731.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       MARMLS  A11712814
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10479219
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10476528
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...       MARMLS  A11728478
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10465832
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS  F10475137
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10488785
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...  Beaches MLS  F10426229
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11690817
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS  A11682394
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
# 1        N          Y  26.126606 -80.120888
# 2        N          Y  26.126606 -80.120888
# 3        N          Y  25.986784 -80.118718
# 4        N          Y  26.117655 -80.139463
# 5        N          Y  26.118136 -80.107099
# 6        N          Y  26.117655 -80.139463
# 7        N          Y  26.175091 -80.097701
# 8        N          Y  26.096516 -80.106815
# 9        N          Y  25.982872 -80.119329
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...          Kamie Manzi
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Matthew Bertanzetti
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...        Andrew Ziffer
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...      Gabriel Miranda
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...         Rachel Buemi
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Gilmar Scantamburlo
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...     Debra Steinhardt
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...   Justin Bartholomew
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...           Brian Hero
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...     Olga Zaurova, PA
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0              e-Wing Realty, Inc              None               None
# 1    Florida Luxurious Properties              None               None
# 2            Compass Florida, LLC              None               None
# 3                   Piquet Realty              None               None
# 4       D'Angelo Realty Group LLC              None               None
# 5         United Realty Group Inc              None               None
# 6       D'Angelo Realty Group LLC              None               None
# 7                    S & B Realty     Nancy Seltzer       S & B Realty
# 8      One Sotheby's Int'l Realty              None               None
# 9  Big International Realty, Inc.              None               None
#
#        buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Micheline Nohra        Options Realty Team, LLC             None
# 1         Kelly Charles          The Agency Florida LLC             None
# 2    Elizabeth Caldwell            Compass Florida, LLC             None
# 3        Jonathan Perez    Fortune Christie's Intl R.E.             None
# 4           Oscar Manes  Keller Williams Capital Realty             None
# 5  Santiago Lopez White        United Realty Group, Inc             None
# 6       Tatiana Asailov        Tatiana Real Estate, Inc             None
# 7    Justin Bartholomew                    S & B Realty    Nancy Seltzer
# 8            Brian Hero      One Sotheby's Int'l Realty             None
# 9             Esya Hart     Winston Towers Realty, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7      S & B Realty     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #...
# 1  Palms On Venice at 161 Isle Of Venice Dr #301 ...
# 2  Palms On Venice at 161 Isle Of Venice Dr #204 ...
# 3   HYDE BEACH at 4011 S Ocean Dr #3679 in Hollywood
# 4  Watergarden at 347 N New River Dr #1003 in For...
# 5  Venetian Condominium at 1 Las Olas Cir #1204 i...
# 6  Watergarden at 347 N New River Dr E #2504 in F...
# 7  Regency Tower at 3850 Galt Ocean Dr #1701 in F...
# 8  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #70...
# 9  LA MER ESTATES WEST CONDO at 1880 S Ocean Dr U...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: TRAFALGAR TOWERS CONDOMIN closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $670,000 to $2,499,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Hollywood, Fort Lauderdale, Hallandale Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 138 condo sales totaling $42,927,599 million from Apr. 6th to Apr. 13th. The previous week, brokers closed 201 condo sales totaling $74,102,478.
#
# Last week’s units sold for an average of $311,070, lower than the $368,669 average price from the previous week. The average price per square foot fell to $271 from $303, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $670,000.0 million to $2,499,000.0 million.
#
# TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #506 in Hollywood took the top spot with a $2,499,000.0 million closing. The sale closed at $1,996.0 per square foot.
#
# Kamie Manzi with e-Wing Realty, Inc, and None with None had the listing.
# Micheline Nohra with Options Realty Team, LLC, and None with None represented the buyer.
#
# Palms On Venice at 161 Isle Of Venice Dr #301 in Fort Lauderdale, closed for the second highest amount, $1,710,000.0, or $804.0 per square foot.
#
# Matthew Bertanzetti with Florida Luxurious Properties, and None with None had the listing.
# Kelly Charles with The Agency Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04142025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 6th to Apr. 13th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 1  PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 2  PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 3  PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 4  PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 5  PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 6  PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 7  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 8  PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 9  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2499000.0   2.0
# 1   Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 3         Hollywood                FL             33019.0  1390000.0   3.0
# 4   Fort Lauderdale                FL             33301.0   860000.0   2.0
# 5   Fort Lauderdale                FL             33316.0   830000.0   2.0
# 6   Fort Lauderdale                FL             33301.0   830000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 8   Fort Lauderdale                FL             33316.0   725000.0   1.0
# 9  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    2.0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
# 1    3.5            Palms On Venice       2128.0       NaN      2016.0
# 2    3.5            Palms On Venice       2128.0       NaN      2016.0
# 3    3.0                 HYDE BEACH       1740.0       NaN      2017.0
# 4    2.0                Watergarden       1204.0       NaN      2004.0
# 5    2.0       Venetian Condominium       1500.0       NaN      1971.0
# 6    2.0                Watergarden       1469.0       NaN      2004.0
# 7    2.0              Regency Tower       1650.0       NaN      1969.0
# 8    1.5    POINT OF AMERICAS CONDO       1109.0       NaN      1969.0
# 9    3.0  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
# 1             NaN          804.0     2009.0   Sold
# 2             NaN          775.0     2009.0   Sold
# 3             NaN          799.0     2384.0   Sold
# 4             NaN          714.0     1232.0   Sold
# 5             NaN          553.0     1286.0   Sold
# 6             NaN          565.0     1632.0   Sold
# 7             NaN          473.0     1609.0   Sold
# 8             NaN          654.0     1145.0   Sold
# 9             NaN          345.0     1731.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       MARMLS  A11712814
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10479219
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10476528
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...       MARMLS  A11728478
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10465832
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS  F10475137
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10488785
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...  Beaches MLS  F10426229
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11690817
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS  A11682394
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
# 1        N          Y  26.126606 -80.120888
# 2        N          Y  26.126606 -80.120888
# 3        N          Y  25.986784 -80.118718
# 4        N          Y  26.117655 -80.139463
# 5        N          Y  26.118136 -80.107099
# 6        N          Y  26.117655 -80.139463
# 7        N          Y  26.175091 -80.097701
# 8        N          Y  26.096516 -80.106815
# 9        N          Y  25.982872 -80.119329
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...          Kamie Manzi
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Matthew Bertanzetti
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...        Andrew Ziffer
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...      Gabriel Miranda
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...         Rachel Buemi
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Gilmar Scantamburlo
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...     Debra Steinhardt
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...   Justin Bartholomew
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...           Brian Hero
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...     Olga Zaurova, PA
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0              e-Wing Realty, Inc              None               None
# 1    Florida Luxurious Properties              None               None
# 2            Compass Florida, LLC              None               None
# 3                   Piquet Realty              None               None
# 4       D'Angelo Realty Group LLC              None               None
# 5         United Realty Group Inc              None               None
# 6       D'Angelo Realty Group LLC              None               None
# 7                    S & B Realty     Nancy Seltzer       S & B Realty
# 8      One Sotheby's Int'l Realty              None               None
# 9  Big International Realty, Inc.              None               None
#
#        buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Micheline Nohra        Options Realty Team, LLC             None
# 1         Kelly Charles          The Agency Florida LLC             None
# 2    Elizabeth Caldwell            Compass Florida, LLC             None
# 3        Jonathan Perez    Fortune Christie's Intl R.E.             None
# 4           Oscar Manes  Keller Williams Capital Realty             None
# 5  Santiago Lopez White        United Realty Group, Inc             None
# 6       Tatiana Asailov        Tatiana Real Estate, Inc             None
# 7    Justin Bartholomew                    S & B Realty    Nancy Seltzer
# 8            Brian Hero      One Sotheby's Int'l Realty             None
# 9             Esya Hart     Winston Towers Realty, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7      S & B Realty     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #...
# 1  Palms On Venice at 161 Isle Of Venice Dr #301 ...
# 2  Palms On Venice at 161 Isle Of Venice Dr #204 ...
# 3   HYDE BEACH at 4011 S Ocean Dr #3679 in Hollywood
# 4  Watergarden at 347 N New River Dr #1003 in For...
# 5  Venetian Condominium at 1 Las Olas Cir #1204 i...
# 6  Watergarden at 347 N New River Dr E #2504 in F...
# 7  Regency Tower at 3850 Galt Ocean Dr #1701 in F...
# 8  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #70...
# 9  LA MER ESTATES WEST CONDO at 1880 S Ocean Dr U...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: TRAFALGAR TOWERS CONDOMIN closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $670,000 to $2,499,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Hollywood, Fort Lauderdale, Hallandale Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 138 condo sales totaling $42,927,599 million from Apr. 6th to Apr. 13th. The previous week, brokers closed 201 condo sales totaling $74,102,478.
#
# Last week’s units sold for an average of $311,070, lower than the $368,669 average price from the previous week. The average price per square foot fell to $271 from $303, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $670,000.0 million to $2,499,000.0 million.
#
# TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #506 in Hollywood took the top spot with a $2,499,000.0 million closing. The sale closed at $1,996.0 per square foot.
#
# Kamie Manzi with e-Wing Realty, Inc, and None with None had the listing.
# Micheline Nohra with Options Realty Team, LLC, and None with None represented the buyer.
#
# Palms On Venice at 161 Isle Of Venice Dr #301 in Fort Lauderdale, closed for the second highest amount, $1,710,000.0, or $804.0 per square foot.
#
# Matthew Bertanzetti with Florida Luxurious Properties, and None with None had the listing.
# Kelly Charles with The Agency Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04142025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 6th to Apr. 13th:
#
# Most Expensive
# TRAFALGAR TOWERS CONDOMIN, 1400 S Ocean Dr #506, in Hollywood | Price: $2,499,000 | $1,996 psf | Listing agents: Kamie Manzi with e-Wing Realty, Inc and None with None | Buyer's agents: Micheline Nohra with Options Realty Team, LLC and None with None
#
# Least Expensive
# LA MER ESTATES WEST CONDO, 1880 S Ocean Dr Unit TS503, in Hallandale Beach | Price: $670,000 | $345 psf | Listing agents: Olga Zaurova, PA with Big International Realty, Inc. and None with None | Buyer's agents: Esya Hart with Winston Towers Realty, Inc. and None with None
#
# Highest Price Per Square Foot
# TRAFALGAR TOWERS CONDOMIN, 1400 S Ocean Dr #506, in Hollywood | Price: $2,499,000 | $1,996 psf | Listing agents: Kamie Manzi with e-Wing Realty, Inc and None with None | Buyer's agents: Micheline Nohra with Options Realty Team, LLC and None with None
#
# Lowest Price Per Square Foot
# LA MER ESTATES WEST CONDO, 1880 S Ocean Dr Unit TS503, in Hallandale Beach | Price: $670,000 | $345 psf | Listing agents: Olga Zaurova, PA with Big International Realty, Inc. and None with None | Buyer's agents: Esya Hart with Winston Towers Realty, Inc. and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Hollywood/1400-S-Ocean-Dr-33019/unit-506/home/41954381
# Second priciest sale:  https://www.redfin.com/FL/Fort-Lauderdale/161-Isle-of-Venice-Dr-33301/unit-301/home/58576778
# Cheapest top ten sale:  https://www.redfin.com/FL/Hallandale-Beach/1880-N-Ocean-Dr-33009/unit-TS503/home/41965096
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/2100-S-Ocean-Ln-33316/unit-704/home/41806408
# Highest top ten psf:  https://www.redfin.com/FL/Hollywood/1400-S-Ocean-Dr-33019/unit-506/home/41954381
# Lowest top ten psf:  https://www.redfin.com/FL/Hallandale-Beach/1880-N-Ocean-Dr-33009/unit-TS503/home/41965096

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Hollywood/1400-S-Ocean-Dr-33019/unit-506/home/41954381

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/161-Isle-of-Venice-Dr-33301/unit-301/home/58576778

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/1880-N-Ocean-Dr-33009/unit-TS503/home/41965096

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2100-S-Ocean-Ln-33316/unit-704/home/41806408

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Hollywood/1400-S-Ocean-Dr-33019/unit-506/home/41954381

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/1880-N-Ocean-Dr-33009/unit-TS503/home/41965096

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-04-11   Condo/Co-op        1400 S Ocean Dr #506
# 1  PAST SALE 2025-04-07   Condo/Co-op  161 Isle Of Venice Dr #301
# 2  PAST SALE 2025-04-10   Condo/Co-op  161 Isle Of Venice Dr #204
# 3  PAST SALE 2025-04-10   Condo/Co-op       4011 S Ocean Dr #3679
# 4  PAST SALE 2025-04-10   Condo/Co-op    347 N New River Dr #1003
# 5  PAST SALE 2025-04-10   Condo/Co-op        1 Las Olas Cir #1204
# 6  PAST SALE 2025-04-10   Condo/Co-op  347 N New River Dr E #2504
# 7  PAST SALE 2025-04-08   Condo/Co-op    3850 Galt Ocean Dr #1701
# 8  PAST SALE 2025-04-11   Condo/Co-op        2100 S Ocean Ln #704
# 9  PAST SALE 2025-04-10   Condo/Co-op  1880 S Ocean Dr Unit TS503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2499000.0   2.0
# 1   Fort Lauderdale                FL             33301.0  1710000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1650000.0   3.0
# 3         Hollywood                FL             33019.0  1390000.0   3.0
# 4   Fort Lauderdale                FL             33301.0   860000.0   2.0
# 5   Fort Lauderdale                FL             33316.0   830000.0   2.0
# 6   Fort Lauderdale                FL             33301.0   830000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   780000.0   2.0
# 8   Fort Lauderdale                FL             33316.0   725000.0   1.0
# 9  Hallandale Beach                FL             33009.0   670000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    2.0  TRAFALGAR TOWERS CONDOMIN       1252.0       NaN      1969.0
# 1    3.5            Palms On Venice       2128.0       NaN      2016.0
# 2    3.5            Palms On Venice       2128.0       NaN      2016.0
# 3    3.0                 HYDE BEACH       1740.0       NaN      2017.0
# 4    2.0                Watergarden       1204.0       NaN      2004.0
# 5    2.0       Venetian Condominium       1500.0       NaN      1971.0
# 6    2.0                Watergarden       1469.0       NaN      2004.0
# 7    2.0              Regency Tower       1650.0       NaN      1969.0
# 8    1.5    POINT OF AMERICAS CONDO       1109.0       NaN      1969.0
# 9    3.0  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1996.0     1572.0   Sold
# 1             NaN          804.0     2009.0   Sold
# 2             NaN          775.0     2009.0   Sold
# 3             NaN          799.0     2384.0   Sold
# 4             NaN          714.0     1232.0   Sold
# 5             NaN          553.0     1286.0   Sold
# 6             NaN          565.0     1632.0   Sold
# 7             NaN          473.0     1609.0   Sold
# 8             NaN          654.0     1145.0   Sold
# 9             NaN          345.0     1731.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...       MARMLS  A11712814
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10479219
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Beaches MLS  F10476528
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...       MARMLS  A11728478
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10465832
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS  F10475137
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...  Beaches MLS  F10488785
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...  Beaches MLS  F10426229
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11690817
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS  A11682394
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.002892 -80.118439
# 1        N          Y  26.126606 -80.120888
# 2        N          Y  26.126606 -80.120888
# 3        N          Y  25.986784 -80.118718
# 4        N          Y  26.117655 -80.139463
# 5        N          Y  26.118136 -80.107099
# 6        N          Y  26.117655 -80.139463
# 7        N          Y  26.175091 -80.097701
# 8        N          Y  26.096516 -80.106815
# 9        N          Y  25.982872 -80.119329
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/1400-S-Oce...          Kamie Manzi
# 1  https://www.redfin.com/FL/Fort-Lauderdale/161-...  Matthew Bertanzetti
# 2  https://www.redfin.com/FL/Fort-Lauderdale/161-...        Andrew Ziffer
# 3  https://www.redfin.com/FL/Hollywood/4011-S-Oce...      Gabriel Miranda
# 4  https://www.redfin.com/FL/Fort-Lauderdale/347-...         Rachel Buemi
# 5  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Gilmar Scantamburlo
# 6  https://www.redfin.com/FL/Fort-Lauderdale/347-...     Debra Steinhardt
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3850...   Justin Bartholomew
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2100...           Brian Hero
# 9  https://www.redfin.com/FL/Hallandale-Beach/188...     Olga Zaurova, PA
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0              e-Wing Realty, Inc              None               None
# 1    Florida Luxurious Properties              None               None
# 2            Compass Florida, LLC              None               None
# 3                   Piquet Realty              None               None
# 4       D'Angelo Realty Group LLC              None               None
# 5         United Realty Group Inc              None               None
# 6       D'Angelo Realty Group LLC              None               None
# 7                    S & B Realty     Nancy Seltzer       S & B Realty
# 8      One Sotheby's Int'l Realty              None               None
# 9  Big International Realty, Inc.              None               None
#
#        buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Micheline Nohra        Options Realty Team, LLC             None
# 1         Kelly Charles          The Agency Florida LLC             None
# 2    Elizabeth Caldwell            Compass Florida, LLC             None
# 3        Jonathan Perez    Fortune Christie's Intl R.E.             None
# 4           Oscar Manes  Keller Williams Capital Realty             None
# 5  Santiago Lopez White        United Realty Group, Inc             None
# 6       Tatiana Asailov        Tatiana Real Estate, Inc             None
# 7    Justin Bartholomew                    S & B Realty    Nancy Seltzer
# 8            Brian Hero      One Sotheby's Int'l Realty             None
# 9             Esya Hart     Winston Towers Realty, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7      S & B Realty     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  TRAFALGAR TOWERS CONDOMIN at 1400 S Ocean Dr #...
# 1  Palms On Venice at 161 Isle Of Venice Dr #301 ...
# 2  Palms On Venice at 161 Isle Of Venice Dr #204 ...
# 3   HYDE BEACH at 4011 S Ocean Dr #3679 in Hollywood
# 4  Watergarden at 347 N New River Dr #1003 in For...
# 5  Venetian Condominium at 1 Las Olas Cir #1204 i...
# 6  Watergarden at 347 N New River Dr E #2504 in F...
# 7  Regency Tower at 3850 Galt Ocean Dr #1701 in F...
# 8  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #70...
# 9  LA MER ESTATES WEST CONDO at 1880 S Ocean Dr U...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 1, 13) ## List (Earlier) date
date2 = datetime(2025, 4, 7) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 84

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1996.0
# 1     804.0
# 2     775.0
# 3     799.0
# 4     714.0
# 5     553.0
# 6     565.0
# 7     473.0
# 8     654.0
# 9     345.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                         ADDRESS       PRICE BEDS  \
# 0 2025-04-11               1400 S Ocean Dr #506 in Hollywood  $2,499,000    2
# 1 2025-04-07   161 Isle Of Venice Dr #301 in Fort Lauderdale  $1,710,000    3
# 2 2025-04-10   161 Isle Of Venice Dr #204 in Fort Lauderdale  $1,650,000    3
# 3 2025-04-10              4011 S Ocean Dr #3679 in Hollywood  $1,390,000    3
# 4 2025-04-10     347 N New River Dr #1003 in Fort Lauderdale    $860,000    2
# 5 2025-04-10         1 Las Olas Cir #1204 in Fort Lauderdale    $830,000    2
# 6 2025-04-10   347 N New River Dr E #2504 in Fort Lauderdale    $830,000    3
# 7 2025-04-08     3850 Galt Ocean Dr #1701 in Fort Lauderdale    $780,000    2
# 8 2025-04-11         2100 S Ocean Ln #704 in Fort Lauderdale    $725,000    1
# 9 2025-04-10  1880 S Ocean Dr Unit TS503 in Hallandale Beach    $670,000    3
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    2.0       1,252       1969        $1,996       MARMLS  A11712814
# 1    3.5       2,128       2016          $804  Beaches MLS  F10479219
# 2    3.5       2,128       2016          $775  Beaches MLS  F10476528
# 3    3.0       1,740       2017          $799       MARMLS  A11728478
# 4    2.0       1,204       2004          $714  Beaches MLS  F10465832
# 5    2.0       1,500       1971          $553  Beaches MLS  F10475137
# 6    2.0       1,469       2004          $565  Beaches MLS  F10488785
# 7    2.0       1,650       1969          $473  Beaches MLS  F10426229
# 8    1.5       1,109       1969          $654       MARMLS  A11690817
# 9    3.0       1,940       1974          $345       MARMLS  A11682394
#
#                                         LISTING INFO  \
# 0                 Kamie Manzi e-Wing Realty, Inc
# 1  Matthew Bertanzetti Florida Luxurious Properti...
# 2             Andrew Ziffer Compass Florida, LLC
# 3                  Gabriel Miranda Piquet Realty
# 4         Rachel Buemi D'Angelo Realty Group LLC
# 5    Gilmar Scantamburlo United Realty Group Inc
# 6     Debra Steinhardt D'Angelo Realty Group LLC
# 7  Justin Bartholomew S & B Realty Nancy Seltzer ...
# 8          Brian Hero One Sotheby's Int'l Realty
# 9  Olga Zaurova, PA Big International Realty, Inc...
#
#                                          BUYING INFO
# 0       Micheline Nohra Options Realty Team, LLC
# 1           Kelly Charles The Agency Florida LLC
# 2        Elizabeth Caldwell Compass Florida, LLC
# 3    Jonathan Perez Fortune Christie's Intl R.E.
# 4     Oscar Manes Keller Williams Capital Realty
# 5  Santiago Lopez White United Realty Group, Inc
# 6       Tatiana Asailov Tatiana Real Estate, Inc
# 7  Justin Bartholomew S & B Realty Nancy Seltzer ...
# 8          Brian Hero One Sotheby's Int'l Realty
# 9          Esya Hart Winston Towers Realty, Inc.
