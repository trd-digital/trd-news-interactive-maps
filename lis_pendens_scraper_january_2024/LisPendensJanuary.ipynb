# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_Jan_2024.csv',dtype='str')

# %%
# Make sure to update this
first_month = 1
current_month = 'January'

# %%
len(df)
# Out:
# 673

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'], format='mixed')

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 573

# %% [markdown]
# ## Data Stuff

# %%
# # Count number of earliest month dates
# sep_dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

# print(f'Number of September dates: {sep_dates_count}')

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
# create new column and assign colors based on month
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'red' if x.month == first_month else '')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_74538/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 376

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{current_month}')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_red = folium.FeatureGroup(name=f'{current_month}') ## 

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'red':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    else:
        continue

# Add the FeatureGroups to the map
fg_red.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d68a29a536f0fab1d83376222f725439 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;January&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d68a29a536f0fab1d83376222f725439&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d68a29a536f0fab1d83376222f725439 = L.map(
#                 &quot;map_d68a29a536f0fab1d83376222f725439&quot;,
#                 {
#                     center: [41.797766555585106, -87.72441754175532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_39ac21a78c5150926b798a866063a0a6 = L.featureGroup(
#                 {}
#             ).addTo(map_d68a29a536f0fab1d83376222f725439);
#
#
#             var circle_marker_f584af0c3ac2168a3b4de79bd8df9242 = L.circleMarker(
#                 [41.763738, -87.637926],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_39ac21a78c5150926b798a866063a0a6);
#
#
#         var popup_d9728eafb9460dd71ad03faa6bbe93cb = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_1aee6aead3380783c9a8662cec3c7f21 = $(`&lt;div id=&quot;html_1aee6aead3380783c9a8662cec3c7f21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;ALLIANCE BLDR &amp; CONSTRUCTION&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;7151 PARNELL AVE LLC&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;20-28-105-008-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;7153 S PARNELL AVE, CHICAGO&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$152,065.80&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_d9728eafb9460dd71ad03faa6bbe93cb.setContent(html_1aee6aead3380783c9a8662cec3c7f21);
#
#
#
#         circle_marker_f584af0c3ac2168a3b4de79bd8df9242.bindPopup(popup_d9728eafb9460dd71ad03faa6bbe93cb)
#         ;
#
#
#
#
#             var circle_marker_575603191f36f48ace4701e3b07f71be = L.circleMarker(
#                 [41.575652, -87.8997071],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_39ac21a78c5150926b798a866063a0a6);
#
#
#         var popup_3d5cd44748d63ad2a3ce6de80de220b1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9edd588e34afc8f4a2dec40fda8fc659 = $(`&lt;div id=&quot;html_9edd588e34afc8f4a2dec40fda8fc659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;CITIBANK NA TR&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;ALDWORTH PAUL&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;27-30-407-001-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;11573 BROOK HILL DR, ORLAND PARK&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$298,700.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_3d5cd44748d63ad2a3ce6de80de220b1.setContent(html_9edd588e34afc8f4a2dec40fda8fc659);
#
#
#
#         circle_marker_575603191f36f48ace4701e3b07f71be.bindPopup(popup_3d5cd44748d63ad2a3ce6de80de220b1)
#         ;
#
#
#
#
#             var circle_marker_434b1b484e85d86ba27a422fbbaff305 = L.circleMarker(
#                 [41.8785359, -87.7138446],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_39ac21a78c5150926b798a866063a0a6);
#
#
#         var popup_a38adf9d065f506189a037dabe16f4bc = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9a3b79672b7662e622e9a3be559f80d9 = $(`&lt;div id=&quot;html_9a3b79672b7662e622e9a3be559f80d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;US BANK NATIONAL ASSN TR

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_january_2024

# %% [markdown]
# ## Stats for story

# %%
df['mortgage_amount_int'] = df['mortgage_amount'].str.replace('$','')
df['mortgage_amount_int'] = df['mortgage_amount_int'].str.replace(',','')
df = df.loc[df['mortgage_amount_int'] != 'NA']
df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)

# %%
# Count number of first month dates
dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

print(f'Number of {current_month} dates: {dates_count}')
# Out:
# Number of January dates: 320

# %%
df['Doc Recorded'].dt.month.value_counts()
# Out:
# Doc Recorded
# 1    320
# Name: count, dtype: int64

# %%
# df.loc[df['Doc Recorded'].dt.month == first_month]

# %%
x = df.loc[df['Doc Recorded'].dt.month == first_month]

# %%
x.reset_index(inplace=True, drop=True)

# %%
# x.at[123,'mortgage_amount_int']=33130000
# x.at[123,'mortgage_amount']='$33,130,000'

# x.at[16,'mortgage_amount_int']=173600
# x.at[16,'mortgage_amount']='$173,600'

# %%
x.sort_values(by='mortgage_amount_int',ascending=False).iloc[0:1]
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 125     View  2403015015   2024-01-30          NaN  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.        1st Grantor          1st Grantee   Assoc. Doc#  \
# 125         NaN  AREEIF LENDER LLC  1411 S MICHIGAN LLC  1935317082.0
#
#                                              deed_urls                 PIN  \
# 125  https://crs.cookcountyclerkil.gov/Document/Det...  17-22-108-097-0000
#
#               Address COLOR  \
# 125  UNKNOWN, UNKNOWN   red
#
#                                          mortgage_urls mortgage_amount  \
# 125  https://crs.cookcountyclerkil.gov/Document/Det...  $76,250,000.00
#
#                           geo_address                  geocoded        lat  \
# 125  UNKNOWN, UNKNOWN Cook County, IL  (41.7376587, -87.697554)  41.737659
#
#            lon  mortgage_amount_int
# 125 -87.697554             76250000

# %%
print(x['mortgage_urls'].iloc[125])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=MzA3MDA5NjM1&hId=YTY0OWUxM2E4M2E3N2MwODkwM2JhZDliNGVmMGExOTYxYTllOThlODY1YTE3ZmVlZTljZTg3ZjRhNWE4NjdmYQ2

# %%
print(f'{current_month}: ${x.mortgage_amount_int.sum():,}')
# Out:
# January: $173,976,614

# %%
# October
16 + 12 + 5
# Out:
# 33

# %%
print(x[x['1st Grantor'] == 'NEWREZ LLC']['deed_urls'].iloc[1])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=NDQ2Nzc5Mjg1&hId=M2UwNDkyZjI2MmYxODQ1MGExOTJiOWJkZjJjYzRkMTcwZGUyNzZjYWMyOWFhMWMwODgxNzE0ZTU2ZTgyNzhkMg2

# %%
x['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# NEWREZ LLC                                           46
# WILMINGTON SAV FUND SOCIETY FSB TR                   24
# US BANK NATIONAL ASSN TR                             22
# US BANK TRUST NATIONAL ASSN TR                       22
# WELLS FARGO BK NA                                    15
# ROCKET MTG LLC                                        8
# BANK OF NEW YORK MELLON TR                            6
# FEDERAL HOME LOAN MORTGAGE CORP TR                    6
# HUNTINGTON NATL BANK                                  6
# PNC BK NATIONAL ASSOCIATION                           5
# LOANDEPOTCOM LLC                                      5
# CARRINGTON MTG SERVICES LLC                           5
# COMMUNITY LOAN SERVICING LLC                          5
# LAKEVIEW LOAN SERVICING LLC                           4
# CITIBANK NA TR                                        4
# BANK OF NEW YORK MELLON TRUST CO NA TR                4
# US BK TRUST NATIONAL ASSOCIATION                      4
# JP MORGAN MORTGAGE ACQ CORP                           4
# MORTGAGE ASSETS MGMT LLC                              4
# DEUTSCHE BK NATIONAL TRUST COMPANY TR                 4
# OLD NATL BANK                                         3
# FIFTH THIRD BK NATIONAL ASSOCIATION                   3
# CIVIC REAL ESTATE HOLDINGS III LLC                    3
# UMB BANK NATIONAL ASSN TR                             3
# WELLS FARGO BANK NATIONAL ASSN TR                     3
# ALLIANT CREDIT UNION                                  3
# SERVIS ONE INC                                        2
# NWL CO LLC                                            2
# ARVEST BANK                                           2
# MARQUETTE BANK                                        2
# GROVE FUNDG II TRUST                                  2
# F ST INVESTMENTS LLC                                  2
# FORETHOUGHT LIFE INST COMPANY                         2
# FIRST AMER BANK                                       2
# WINTRUST MORTGAGE                                     2
# PHH MTG CORPORATION                                   2
# METROPOLITAN LIFE INST COMPANY                        2
# SELENE FIN LP                                         2
# NEXBANK                                               2
# NATIONSTAR MTG LLC                                    2
# WILMINGTON TRUST NATIONAL ASSN TR                     2
# CREDIT UNION 1                                        2
# PENNYMAC LOAN SERVICES LLC                            1
# AB 27 INVESTMENTS LLC                                 1
# COASTAL COMM BANK                                     1
# WILMINGTON SAV FUND SOCIETY FSB                       1
# HOF GRANTOR TRUST 3                                   1
# US BANK TRUST COMPANY NATIONAL ASSN TR                1
# RESIDENTIAL CAP PARTNERS SECURES LOAN FUND XI LLC     1
# PLAZA HOME MTG INC                                    1
# SECRETARY OF VETERANS AFFAIRS                         1
# HOF GRANTOR TRUST 1                                   1
# RFLF 2B LLC                                           1
# GREEN STREET FUNDG TRUST II                           1
# RFLF 2 LLC                                            1
# NATIONS DIRECT MTG LLC                                1
# WELLS FARGO USA HOLDINGS INC                          1
# REPUBLIC BK OF CHICAGO                                1
# BANK OF AMER NA                                       1
# ILLINOIS HOUSING DEV AUTHORITY                        1
# Name: count, dtype: int64

# %%
x['1st Grantee'].value_counts()
# Out:
# 1st Grantee
# CHICAGO TITLE LAND TRUST CO TR           4
# MBBI CLASSIC BLDR LLC                    2
# DORSETT RESTORATION AND RECOVERY CORP    2
# MILOVAC WENDY M                          2
# KLUJIAN PETER                            2
#                                         ..
# 213 48 LLC                               1
# CARTER ADAM E                            1
# BRASILE JOAN MARIE                       1
# GURTZ ADAM                               1
# TNT PROP USA LLC                         1
# Name: count, Length: 310, dtype: int64

# %%
df.to_csv(f'{current_month}_2024_foreclosures.csv')

# %%
# apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
print(f"{current_month} median mortgage foreclosure amount: ${x['mortgage_amount_int'].median():,}")
# Out:
# January median mortgage foreclosure amount: $192,250.0

# %% [markdown]
# ## Boundary Analysis

# %%
boundaries = gpd.read_file('Boundaries - Neighborhoods.geojson')

# %%
# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(x['lon'], x['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_x = gpd.GeoDataFrame(x, geometry=geometry)

gdf_filings_x.crs = 'EPSG:4326'
gdf_filings_x = gdf_filings_x.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_x = gpd.sjoin(gdf_filings_x, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# %%
counts_x['count'].sum()
