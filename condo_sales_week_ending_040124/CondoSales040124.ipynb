# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Mar. 25th Apr. 1st

# %%
filename = glob.glob('redfin*.csv')
filename = filename[0]

# %%
df = pd.read_csv(filename)
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]
df = df.sort_values(by='PRICE',ascending=False)
df_top_ten = df.head(10)

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 172

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $754,193

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $562

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $129,721,118

# %% [markdown]
# ## Previous Week's Values

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 137
# Input Previous Week Condo Average Sales Price:
# 793404
# Input Previous Week Condo Average PSF:
# 599
# Input Previous Week Condo Sales total (ex: $XX million)
# $109 million

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#      SALE TYPE      SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 151  PAST SALE  March-26-2024   Condo/Co-op  5224 Fisher Island Dr #5224
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 151  Miami Beach                FL             33109.0  8875000.0   4.0
#
#      BATHS                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 151    4.5  BAYVIEW FISHER ISL CONDO       3550.0       NaN      1992.0
#
#      DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 151             NaN         2500.0     8584.0   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 151                         NaN                       NaN
#
#                                                    URL  SOURCE       MLS#  \
# 151  https://www.redfin.com/FL/Miami-Beach/5224-Fis...  MARMLS  A11462393
#
#     FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 151        N          Y  25.762695 -80.148393     1  orange

# %%
def popup_html(row):
    building_name = row['LOCATION']
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14625168f99152f66cd4bc027d4d10b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Mar. 25th - Apr. 1st&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14625168f99152f66cd4bc027d4d10b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d14625168f99152f66cd4bc027d4d10b = L.map(
#                 &quot;map_d14625168f99152f66cd4bc027d4d10b&quot;,
#                 {
#                     center: [25.819175245930236, -80.20342510755815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_51332c8ca3ce4c960c9591b13aa92e4f = L.featureGroup(
#                 {}
#             ).addTo(map_d14625168f99152f66cd4bc027d4d10b);
#
#
#             var marker_5caa8aadcd2f007737bad30175c133a6 = L.marker(
#                 [25.762695, -80.148393],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_51332c8ca3ce4c960c9591b13aa92e4f);
#
#
#             var icon_2730688bc76a26d61952a689af5deb99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5caa8aadcd2f007737bad30175c133a6.setIcon(icon_2730688bc76a26d61952a689af5deb99);
#
#
#         var popup_7050620b3201f5e807f2d7b69ff2c0ce = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_86b2999c4287dd39dd5ea6a4d63f58e7 = $(`&lt;div id=&quot;html_86b2999c4287dd39dd5ea6a4d63f58e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;BAYVIEW FISHER ISL CONDO&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$8,875,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,500.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,550.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1992.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_7050620b3201f5e807f2d7b69ff2c0ce.setContent(html_86b2999c4287dd39dd5ea6a4d63f58e7);
#
#
#
#         marker_5caa8aadcd2f007737bad30175c133a6.bindPopup(popup_7050620b3201f5e807f2d7b69ff2c0ce)
#         ;
#
#
#
#
#             var feature_group_0f96f980a6bc0894c165f95484844ba2 = L.featureGroup(
#                 {}
#             ).addTo(map_d14625168f99152f66cd4bc027d4d10b);
#
#
#             var marker_dae4f2aff4e3a308068b19e7485faee4 = L.marker(
#                 [25.769375, -80.133358],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_0f96f980a6bc0894c165f95484844ba2);
#
#
#             var icon_a0548b709d237f08161b84927e0e4561 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dae4f2aff4e3a308068b19e7485faee4.setIcon(icon_a0548b709d237f08161b84927e0e4561);
#
#
#         var popup_bce320adb368c18f98d442f3ea9b24bf = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3ff62a308d99457075eaabe314a0c934 = $(`&lt;div id=&quot;html_3ff62a308d99457075eaabe314a0c934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;ONE OCEAN CONDO&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,925,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,291.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,041.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2016.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_bce320adb368c18f98d442f3ea9b24bf.setContent(html_3ff62a308d99457075eaabe314a0c934);
#
#
#
#         marker_dae4f2aff4e3a308068b19e7485faee4.bindPopup(popup_bce320adb368c18f98d442f3ea9b24bf)
#         ;
#
#
#
#
#             var marker_f7f45d873bd348958e3b0cfa4359d32d = L.marker(
#                 [25.7061176, -80.253344],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_0f96f980a6bc0894c165f95484844ba2);
#
#
#             var icon_776adcbd0a17e8156c63629c3aaad3c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f7f45d873bd348958e3b0cfa4359d32d.setIcon(icon_776adcbd0a17e8156c63629c3aaad3c3);
#
#
#         var popup_0e0d8bd596c7d331d7817de3c6fd7f7f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6e7262a403524bf82ffc74c5d815ccc9 = $(`&lt;div id=&q

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#      SALE TYPE      SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 151  PAST SALE  March-26-2024   Condo/Co-op  5224 Fisher Island Dr #5224
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 151  Miami Beach                FL             33109.0  8875000.0   4.0
#
#      BATHS                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 151    4.5  BAYVIEW FISHER ISL CONDO       3550.0       NaN      1992.0
#
#      DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 151             NaN         2500.0     8584.0   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 151                         NaN                       NaN
#
#                                                    URL  SOURCE       MLS#  \
# 151  https://www.redfin.com/FL/Miami-Beach/5224-Fis...  MARMLS  A11462393
#
#     FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 151        N          Y  25.762695 -80.148393     1  orange

# %%
# , {df_top_ten[df_top_ten['PRICE'].idxmax()]['ADDRESS']} | Price ${df_top_ten[df_top_ten['PRICE'].idxmax()]['PRICE']:,.0f}

# %%
df_top_ten['PRICE'].iloc[0]
# Out:
# 8875000.0

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_040124

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'BAYVIEW FISHER ISL CONDO at 5224 Fisher Island Dr #5224 in Miami Beach'

# %%
previous_week_condo_sales_total = 109_000_000

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
# df_top_ten

# %% [markdown]
# ## RESUME HERE

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} tops Miami-Dade weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m Miami-Dade County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m Miami-Dade County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #MiamiDade condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, Miami-Dade County, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

Miami-Dade County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} sales average from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: BAYVIEW FISHER ISL CONDO tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,912,500M to $8,875,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Aventura, Coral Gables, Bal Harbour, Sunny Isles Beach, Miami Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 172 condo sales totaling $129,721,118 million from Mar. 25th to Apr. 1st. The previous week, brokers closed 137 condo sales totaling $109,000,000.
#
# Last week’s units sold for an average of $754,193, lower than the $793,404 sales average from the previous week. The average price per square foot fell to $562 from $599, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,912,500.0 million to $8,875,000.0 million.
#
# BAYVIEW FISHER ISL CONDO at 5224 Fisher Island Dr #5224 in Miami Beach took the top spot with a $8,875,000.0 million closing. The sale closed at $2,500.0 per square foot.
#
# ONE OCEAN CONDO at 1 Collins Ave #308 in Miami Beach, closed for the second highest amount, $3,925,000.0, or $1,291.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_040124" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 25th to Apr. 1st:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf")

print(story_checklist)
# Out:
# HED: BAYVIEW FISHER ISL CONDO tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,912,500M to $8,875,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Aventura, Coral Gables, Bal Harbour, Sunny Isles Beach, Miami Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 172 condo sales totaling $129,721,118 million from Mar. 25th to Apr. 1st. The previous week, brokers closed 137 condo sales totaling $109,000,000.
#
# Last week’s units sold for an average of $754,193, lower than the $793,404 sales average from the previous week. The average price per square foot fell to $562 from $599, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,912,500.0 million to $8,875,000.0 million.
#
# BAYVIEW FISHER ISL CONDO at 5224 Fisher Island Dr #5224 in Miami Beach took the top spot with a $8,875,000.0 million closing. The sale closed at $2,500.0 per square foot.
#
# ONE OCEAN CONDO at 1 Collins Ave #308 in Miami Beach, closed for the second highest amount, $3,925,000.0, or $1,291.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_040124" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 25th to Apr. 1st:
#
# Most Expensive
# BAYVIEW FISHER ISL CONDO, 5224 Fisher Island Dr #5224 in Miami Beach | Price: $8,875,000 | $2,500 psf
# Least Expensive
# THE GRAND VENETIAN CONDO, 10 Venetian Way #1702 in Miami Beach | Price: $1,912,500 | $1,307 psf
# Highest Price Per Square Foot
# BAYVIEW FISHER ISL CONDO, 5224 Fisher Island Dr #5224 in Miami Beach | Price: $8,875,000 | $2,500 psf
# Lowest Price Per Square Foot
# Trump Tower I, 16001 Collins Ave #3004 in Sunny Isles Beach | Price: $2,000,000 | $859 psf
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Miami-Beach/5224-Fisher-Island-Dr-33109/unit-5224/home/43103369

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Miami-Beach/10-Venetian-Way-33139/unit-1702/home/43259824

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/5224-Fisher-Island-Dr-33109/unit-5224/home/43103369

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/16001-Collins-Ave-33160/unit-3004/home/43387030

# %%
df_top_ten
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE  March-26-2024   Condo/Co-op  5224 Fisher Island Dr #5224
# 1  PAST SALE  March-25-2024   Condo/Co-op           1 Collins Ave #308
# 2  PAST SALE  March-25-2024   Condo/Co-op     10 Edgewater Dr Unit PHD
# 3  PAST SALE  March-28-2024   Condo/Co-op  5500 Island Estates Dr #502
# 4  PAST SALE  March-25-2024   Condo/Co-op  5000 Island Estates Dr #507
# 5  PAST SALE  March-29-2024   Condo/Co-op       10295 Collins Ave #806
# 6  PAST SALE  March-25-2024   Condo/Co-op       6000 Island Blvd #2806
# 7  PAST SALE  March-27-2024   Condo/Co-op      15811 Collins Ave #3904
# 8  PAST SALE  March-26-2024   Condo/Co-op      16001 Collins Ave #3004
# 9  PAST SALE  March-27-2024   Condo/Co-op        10 Venetian Way #1702
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0        Miami Beach                FL             33109.0  8875000.0   4.0
# 1        Miami Beach                FL             33139.0  3925000.0   4.0
# 2       Coral Gables                FL             33133.0  3675000.0   2.0
# 3           Aventura                FL             33160.0  3418018.0   3.0
# 4           Aventura                FL             33160.0  3320000.0   3.0
# 5        Bal Harbour                FL             33154.0  2900000.0   2.0
# 6           Aventura                FL             33160.0  2830000.0   4.0
# 7  Sunny Isles Beach                FL             33160.0  2400000.0   3.0
# 8  Sunny Isles Beach                FL             33160.0  2000000.0   3.0
# 9        Miami Beach                FL             33139.0  1912500.0   2.0
#
#    BATHS                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5      BAYVIEW FISHER ISL CONDO       3550.0       NaN      1992.0
# 1    4.5               ONE OCEAN CONDO       3041.0       NaN      2016.0
# 2    3.5              THE GABLES CONDO       2950.0       NaN      1997.0
# 3    4.5                   PRIVE CONDO       2628.0       NaN      2017.0
# 4    4.5                   PRIVE CONDO       2626.0       NaN      2018.0
# 5    2.5     10295 COLLINS AVE RESDNTA       2009.0       NaN      2007.0
# 6    3.5  Bellamare AT Williams Island       3222.0       NaN      2005.0
# 7    3.5           TDR TOWER III CONDO       2558.0       NaN      2010.0
# 8    3.5                 Trump Tower I       2327.0       NaN      2008.0
# 9    2.0      THE GRAND VENETIAN CONDO       1463.0       NaN      2001.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2500.0     8584.0   Sold
# 1             NaN         1291.0     7405.0   Sold
# 2             NaN         1246.0     8914.0   Sold
# 3             NaN         1301.0     5792.0   Sold
# 4             NaN         1264.0     5785.0   Sold
# 5             NaN         1444.0     2452.0   Sold
# 6             NaN          878.0     3354.0   Sold
# 7             NaN          938.0     2373.0   Sold
# 8             NaN          859.0     2837.0   Sold
# 9             NaN         1307.0     2066.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Miami-Beach/5224-Fis...       MARMLS
# 1  https://www.redfin.com/FL/Miami-Beach/1-Collin...       MARMLS
# 2  https://www.redfin.com/FL/Coral-Gables/10-Edge...       MARMLS
# 3  https://www.redfin.com/FL/Aventura/5500-Island...       MARMLS
# 4  https://www.redfin.com/FL/Aventura/5000-Island...       MARMLS
# 5  https://www.redfin.com/FL/Bal-Harbour/10295-Co...       MARMLS
# 6  https://www.redfin.com/FL/Aventura/6000-Island...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Miami-Beach/15...       MARMLS
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  Beaches MLS
# 9  https://www.redfin.com/FL/Miami-Beach/10-Venet...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR  \
# 0    A11462393        N          Y  25.762695 -80.148393     1  orange
# 1    A11441923        N          Y  25.769375 -80.133358     2    blue
# 2    A11520369        N          Y  25.706118 -80.253344     3    blue
# 3    A11523202        N          Y  25.946664 -80.130515     4    blue
# 4    A11492074        N          Y  25.946283 -80.130806     5    blue
# 5    A11425129        N          Y  25.898952 -80.123405     6    blue
# 6  RX-10933840        N          Y  25.942792 -80.135400     7    blue
# 7    A11521285        N          Y  25.922834 -80.121864     8    blue
# 8    F10422168        N          Y  25.924069 -80.121660     9    blue
# 9    A11450525        N          Y  25.791132 -80.146640    10    blue
#
#                                            FULL_NAME
# 0  BAYVIEW FISHER ISL CONDO at 5224 Fisher Island...
# 1  ONE OCEAN CONDO at 1 Collins Ave #308 in Miami...
# 2  THE GABLES CONDO at 10 Edgewater Dr Unit PHD i...
# 3  PRIVE CONDO at 5500 Island Estates Dr #502 in ...
# 4  PRIVE CONDO at 5000 Island Estates Dr #507 in ...
# 5  10295 COLLINS AVE RESDNTA at 10295 Collins Ave...
# 6  Bellamare AT Williams Island at 6000 Island Bl...
# 7  TDR TOWER III CONDO at 15811 Collins Ave #3904...
# 8  Trump Tower I at 16001 Collins Ave #3004 in Su...
# 9  THE GRAND VENETIAN CONDO at 10 Venetian Way #1...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 2, 14) ## List (Earlier) date
date2 = datetime(2024, 3, 26) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 41
