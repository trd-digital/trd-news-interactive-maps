# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now() - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=6)

def format_date(date):
    day = date.day
    # Months 3-7 (March–July) should be full; all others abbreviated with a period
    if date.month in (3, 4, 5, 6, 7):
        month_str = date.strftime("%B")      # e.g. "March", "April", ...
    else:
        month_str = date.strftime("%b") + "."  # e.g. "Jan.", "Feb.", "Aug.", ...

    return f"{month_str} {day}"


# Format both dates
week_ending = format_date(today)
week_starting = format_date(one_week_ago)

print(week_starting, week_ending)
# Out:
# July 31 Aug. 6

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE             ADDRESS  \
# 1  PAST SALE  August-1-2025   Condo/Co-op  632 Brackenwood Cv
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Palm Beach Gardens                FL             33418.0  400000.0   2.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Palm-Beach-Gardens/6...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11084132         N          Y  26.831208 -80.147182
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
#  Palm Beach County

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] >= one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-07-31    32
# 2025-07-30    28
# 2025-08-01    22
# 2025-07-29    11
# 2025-08-03     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(11)

# %%
df_top_ten = df_top_ten.reset_index()

# %%
df_top_ten = df_top_ten.drop(index=8)

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"
        querystring = {"url": url}
        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }
        response = requests.get(base_url, headers=headers, params=querystring)
        response.raise_for_status()
        data = response.json()

        # Safely drill down, falling back to {} if any level is None or missing
        info = data.get('data') or {}
        panel = info.get('mainHouseInfoPanelInfo') or {}
        house = panel.get('mainHouseInfo') or {}

        # Extract listing agents
        listing_agents = house.get('listingAgents') or []
        list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName') if len(listing_agents) > 0 else None
        list_broker_name_1 = listing_agents[0].get('brokerName')           if len(listing_agents) > 0 else None
        list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName') if len(listing_agents) > 1 else None
        list_broker_name_2 = listing_agents[1].get('brokerName')           if len(listing_agents) > 1 else None

        # Extract buying agents
        buying_agents = house.get('buyingAgents') or []
        buy_agent_name_1  = buying_agents[0].get('agentInfo', {}).get('agentName') if len(buying_agents) > 0 else None
        buy_broker_name_1 = buying_agents[0].get('brokerName')             if len(buying_agents) > 0 else None
        buy_agent_name_2  = buying_agents[1].get('agentInfo', {}).get('agentName') if len(buying_agents) > 1 else None
        buy_broker_name_2 = buying_agents[1].get('brokerName')             if len(buying_agents) > 1 else None

        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return { key: None for key in [
            'url', 'list_agent_name_1','list_broker_name_1',
            'list_agent_name_2','list_broker_name_2',
            'buy_agent_name_1','buy_broker_name_1',
            'buy_agent_name_2','buy_broker_name_2'
        ] }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    index  SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0    116  PAST SALE 2025-07-30   Condo/Co-op
# 1     44  PAST SALE 2025-07-30   Condo/Co-op
# 2     18  PAST SALE 2025-07-31   Condo/Co-op
# 3      8  PAST SALE 2025-07-31   Condo/Co-op
# 4     91  PAST SALE 2025-07-29   Condo/Co-op
# 5     49  PAST SALE 2025-07-31   Condo/Co-op
# 6     21  PAST SALE 2025-08-01   Condo/Co-op
# 7     15  PAST SALE 2025-07-30   Condo/Co-op
# 8    110  PAST SALE 2025-07-31   Condo/Co-op
# 9     13  PAST SALE 2025-07-31   Condo/Co-op
#
#                                ADDRESS              CITY STATE OR PROVINCE  \
# 0          2770 S Ocean Blvd Unit 201n        Palm Beach                FL
# 1       2600 S Ocean Blvd Unit 9C & 9D        Boca Raton                FL
# 2                701 Captains Way #701           Jupiter                FL
# 3             19630 Sawgrass Cir #2901        Boca Raton                FL
# 4              3115 S Ocean Blvd #1004    Highland Beach                FL
# 5                155 Tresana Blvd #107           Jupiter                FL
# 6              4740 S Ocean Blvd #1403    Highland Beach                FL
# 7                   11282 Glen Oaks Ct  North Palm Beach                FL
# 8                 701 S Olive Ave #202   West Palm Beach                FL
# 9  3579 Quail Ridge Dr Unit Bobwhite A     Boynton Beach                FL
#
#    ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0             33480.0  4000000.0   4.0    5.5
# 1             33432.0  3100000.0   4.0    4.5
# 2             33477.0  2100000.0   3.0    2.0
# 3             33434.0  1300000.0   3.0    3.0
# 4             33487.0  1250000.0   3.0    2.5
# 5             33478.0  1250000.0   3.0    2.5
# 6             33487.0   812000.0   2.0    2.0
# 7             33408.0   755000.0   2.0    2.5
# 8             33401.0   700000.0   2.0    2.0
# 9             33436.0   630000.0   2.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0                                 2770       4370.0       NaN      1991.0
# 1                          OCEANS EDGE       4202.0       NaN      1974.0
# 2  Captains Way AT Admirals Cove Condo       2033.0       NaN      1988.0
# 3                           Peppertree       2080.0       NaN      1979.0
# 4            Ocean Terrace North Condo       1852.0       NaN      1981.0
# 5        Jupiter Country Club Condo II       3042.0       NaN      2017.0
# 6                   Braemar Isle Condo       2050.0       NaN      1982.0
# 7                     North Palm Beach       2300.0       NaN      1983.0
# 8                 Two City Plaza Condo       1208.0       NaN      2008.0
# 9                          Quail Ridge       1737.0       NaN      1978.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          915.0     5750.0   Sold
# 1             NaN          738.0     3926.0   Sold
# 2             NaN         1033.0     2357.0   Sold
# 3             NaN          625.0     1460.0   Sold
# 4             NaN          675.0     2500.0   Sold
# 5             NaN          411.0     1295.0   Sold
# 6             NaN          396.0     2597.0   Sold
# 7             NaN          328.0        NaN   Sold
# 8             NaN          579.0     1182.0   Sold
# 9             NaN          363.0     1598.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...       MARMLS
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...  Beaches MLS
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...        PBBOR
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...  Beaches MLS
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
# 1    A11778186        N          Y  26.325422 -80.074701
# 2  RX-11096443        N          Y  26.907510 -80.085826
# 3  RX-11098622        N          Y  26.390498 -80.155550
# 4  RX-11061970        N          Y  26.418745 -80.063926
# 5  RX-11074044        N          Y  26.928057 -80.155226
# 6  RX-11097738        N          Y  26.393265 -80.069030
# 7      24-1802        N          Y  26.841592 -80.060273
# 8  RX-11025422        N          Y  26.706646 -80.052576
# 9  RX-11085859        N          Y  26.508482 -80.101142
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...    Carole Koeppel
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Devin Kay
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...      Lisa Fishman
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...    Judith Romanow
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...   Colleen Newland
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...       Gray Welton
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...      Ryan Coleman
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...  LILLIAN PULITZER
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...     Rhys Hollyman
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...          Ann Jara
#
#                         list_broker_name_1 list_agent_name_2  \
# 0             Sotheby's Intl. Realty, Inc.              None
# 1                          Douglas Elliman              None
# 2                     NV Realty Group, LLC              None
# 3                     Boca West Realty LLC       Ina Tuchman
# 4                          Douglas Elliman              None
# 5                     NV Realty Group, LLC              None
# 6                      Compass Florida LLC       Scott Gerow
# 7  Brown Harris Stevens of Palm Beach 5225              None
# 8                         Logan Realty Inc              None
# 9       The Club at Quail Ridge Realty Inc              None
#
#      list_broker_name_2   buy_agent_name_1  \
# 0                  None          Dana Koch
# 1                  None               None
# 2                  None    Jessica Kaufman
# 3  Boca West Realty LLC        Ina Tuchman
# 4                  None     Scott Correale
# 5                  None  Jennifer Friedman
# 6   Compass Florida LLC  Mary Ann Phillips
# 7                  None   LILLIAN PULITZER
# 8                  None      Lori Cronican
# 9                  None           Ann Jara
#
#                          buy_broker_name_1      buy_agent_name_2  \
# 0                       The Corcoran Group                  None
# 1                                     None                  None
# 2                    Beachfront Realty Inc                  None
# 3                     Boca West Realty LLC                  None
# 4       One Sotheby's International Realty                  None
# 5       Fine Living Realty of Palm Beaches                  None
# 6                      RE/MAX Select Group                  None
# 7  Brown Harris Stevens of Palm Beach 5225                  None
# 8                          Douglas Elliman  Christopher Cronican
# 9       The Club at Quail Ridge Realty Inc                  None
#
#   buy_broker_name_2
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8   Douglas Elliman
# 9              None

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 94

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $395,110

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $267

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $37,140,300

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           94              395110          267                     37140300.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 57
# -----------
# Input Previous Week Condo Average Sales Price:
# 411834
# -----------
# Input Previous Week Condo Average PSF:
# 288
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
#
0       NaN      1978.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          915.0     5750.0   Sold
# 1             NaN          738.0     3926.0   Sold
# 2             NaN         1033.0     2357.0   Sold
# 3             NaN          625.0     1460.0   Sold
# 4             NaN          675.0     2500.0   Sold
# 5             NaN          411.0     1295.0   Sold
# 6             NaN          396.0     2597.0   Sold
# 7             NaN          328.0        NaN   Sold
# 8             NaN          579.0     1182.0   Sold
# 9             NaN          363.0     1598.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...       MARMLS
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...  Beaches MLS
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...        PBBOR
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...  Beaches MLS
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
# 1    A11778186        N          Y  26.325422 -80.074701
# 2  RX-11096443        N          Y  26.907510 -80.085826
# 3  RX-11098622        N          Y  26.390498 -80.155550
# 4  RX-11061970        N          Y  26.418745 -80.063926
# 5  RX-11074044        N          Y  26.928057 -80.155226
# 6  RX-11097738        N          Y  26.393265 -80.069030
# 7      24-1802        N          Y  26.841592 -80.060273
# 8  RX-11025422        N          Y  26.706646 -80.052576
# 9  RX-11085859        N          Y  26.508482 -80.101142
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...    Carole Koeppel
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Devin Kay
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...      Lisa Fishman
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...    Judith Romanow
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...   Colleen Newland
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...       Gray Welton
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...      Ryan Coleman
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...  LILLIAN PULITZER
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...     Rhys Hollyman
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...          Ann Jara
#
#                         list_broker_name_1 list_agent_name_2  \
# 0             Sotheby's Intl. Realty, Inc.              None
# 1                          Douglas Elliman              None
# 2                     NV Realty Group, LLC              None
# 3                     Boca West Realty LLC       Ina Tuchman
# 4                          Douglas Elliman              None
# 5                     NV Realty Group, LLC              None
# 6                      Compass Florida LLC       Scott Gerow
# 7  Brown Harris Stevens of Palm Beach 5225              None
# 8                         Logan Realty Inc              None
# 9       The Club at Quail Ridge Realty Inc              None
#
#      list_broker_name_2   buy_agent_name_1  \
# 0                  None          Dana Koch
# 1                  None               None
# 2                  None    Jessica Kaufman
# 3  Boca West Realty LLC        Ina Tuchman
# 4                  None     Scott Correale
# 5                  None  Jennifer Friedman
# 6   Compass Florida LLC  Mary Ann Phillips
# 7                  None   LILLIAN PULITZER
# 8                  None      Lori Cronican
# 9                  None           Ann Jara
#
#                          buy_broker_name_1      buy_agent_name_2  \
# 0                       The Corcoran Group                  None
# 1                                     None                  None
# 2                    Beachfront Realty Inc                  None
# 3                     Boca West Realty LLC                  None
# 4       One Sotheby's International Realty                  None
# 5       Fine Living Realty of Palm Beaches                  None
# 6                      RE/MAX Select Group                  None
# 7  Brown Harris Stevens of Palm Beach 5225                  None
# 8                          Douglas Elliman  Christopher Cronican
# 9       The Club at Quail Ridge Realty Inc                  None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8   Douglas Elliman     9    blue
# 9              None    10    blue

# %%
# %store -r map_box_api_key

# %%
import folium
from branca.element import Template, MacroElement

# ——— Your title & caption HTML ———
title_html = f'''
  <h3 align="center" style="font-size:16px"><b>Recent {county} County Condo Sales</b></h3>
'''
caption_html = f'''
  <p align="center" style="font-size:13px"><i>{week_starting} — {week_ending}</i></p>
'''

# ——— Base map ———
m = folium.Map(
    location=df[['LATITUDE','LONGITUDE']].mean().to_list(),
    zoom_start=9,
    tiles=None
)

# ——— Tile layers ———
folium.TileLayer('OpenStreetMap', name='OSM', control=False).add_to(m)
folium.TileLayer(
    tiles=(
        "https://api.mapbox.com/styles/v1/"
        "mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x"
        f"?access_token={map_box_api_key}"
    ),
    attr="Mapbox", name="Streets", control=False
).add_to(m)

# ——— Add your markers ———
for _, row in df_top_ten.iterrows():
    lat, lon = row['LATITUDE'], row['LONGITUDE']
    popup = folium.Popup(popup_html(row), max_width=400)

    if row['COLOR'] == 'blue':
        # Regular sale: blue circle
        folium.CircleMarker(
            location=(lat, lon),
            radius=7,
            fill=True,
            fill_color='blue',
            fill_opacity=0.5,
            color=None,
            popup=popup
        ).add_to(m)
    else:
        # Top sale: gold star
        folium.Marker(
            location=(lat, lon),
            popup=popup,
            icon=folium.DivIcon(
                html="""
                <div style="font-size:24px; line-height:24px; color:gold;">
                  &#9733;
                </div>
                """
            )
        ).add_to(m)

# ——— Layer control, title & caption ———
folium.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))

# ——— Optional legend via branca ———
legend_html = """
{% macro html(this, kwargs) %}
  <div style="
      position: fixed;
      bottom: 50px; left: 50px;
      background: white; padding: 8px;
      border: 2px solid grey;
      font-size: 12px;
      z-index: 9999;
  ">
    <div style="display:inline-block; font-size:18px; color:gold; margin-right:6px;">&#9733;</div> Top Sale<br>
    <i style="background: blue; width: 10px; height: 10px;
       display: inline-block; margin-right: 6px;"></i> All other sales
  </div>
{% endmacro %}
"""
legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)

# ——— Display ———
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c2b504f03626e4d421edb0a85d8d28a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County County Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#   &lt;p align=&quot;center&quot; style=&quot;font-size:13px&quot;&gt;&lt;i&gt;July 28 — Aug. 3&lt;/i&gt;&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c2b504f03626e4d421edb0a85d8d28a&quot; &gt;&lt;/div&gt;
#
#
#   &lt;div style=&quot;
#       position: fixed;
#       bottom: 50px; left: 50px;
#       background: white; padding: 8px;
#       border: 2px solid grey;
#       font-size: 12px;
#       z-index: 9999;
#   &quot;&gt;
#     &lt;div style=&quot;display:inline-block; font-size:18px; color:gold; margin-right:6px;&quot;&gt;&amp;#9733;&lt;/div&gt; Top Sale&lt;br&gt;
#     &lt;i style=&quot;background: blue; width: 10px; height: 10px;
#        display: inline-block; margin-right: 6px;&quot;&gt;&lt;/i&gt; All other sales
#   &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c2b504f03626e4d421edb0a85d8d28a = L.map(
#                 &quot;map_1c2b504f03626e4d421edb0a85d8d28a&quot;,
#                 {
#                     center: [26.55745898534483, -80.11438997586207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b3579167a0c846af3a97d7adc2d46f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c2b504f03626e4d421edb0a85d8d28a);
#
#
#             var tile_layer_931f171876dbc3725e15c74d23130171 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoidHJkZGF0YSIsImEiOiJjamc2bTc2YmUxY2F3MnZxZGh2amR2MTY5In0.QlOWqB-yQNrNlXD0KQ9IvQ&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c2b504f03626e4d421edb0a85d8d28a);
#
#
#             var marker_e655bb42ee574bd225ecd26b50211887 = L.marker(
#                 [26.6223163, -80.037453],
#                 {}
#             ).addTo(map_1c2b504f03626e4d421edb0a85d8d28a);
#
#
#             var div_icon_fb7a0c74f92c6bf426f4e592e2154e90 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size:24px; line-height:24px; color:gold;\&quot;\u003e\n                  \u0026#9733;\n                \u003c/div\u003e\n                &quot;});
#             marker_e655bb42ee574bd225ecd26b50211887.setIcon(div_icon_fb7a0c74f92c6bf426f4e592e2154e90);
#
#
#         var popup_c39a3e79979eeef0c8947ad9d56cac21 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_5c3e02b8aaee6c47a855a77e7d1d18c3 = $(`&lt;div id=&quot;html_5c3e02b8aaee6c47a855a77e7d1d18c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2770 S Ocean Blvd Unit 201n&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,000,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$915.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,370.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1991.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_c39a3e79979eeef0c8947ad9d56cac21.setContent(html_5c3e02b8aaee6c47a855a77e7d1d18c3);
#
#
#
#         marker_e655bb42ee574bd225ecd26b50211887.bindPopup(popup_c39a3e79979eeef0c8947ad9d56cac21)
#         ;
#
#
#
#
#             var circle_marker_b97eef298c3b11e3e64c6896763dd3d9 = L.circleMarker(
#                 [26.3254221, -80.0747009],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c2b504f03626e4d421edb0a85d8d28a);
#
#
#         var popup_4b85ef6f0be432cb27e33e73e823cad9 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_ac83fdc398b87713ec43ae8a314a2e50 = $(`&lt;div id=&quot;html_ac83fdc398b87713ec43ae8a314a2e50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2600 S Ocean Blvd Unit 9C &amp; 9D&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,100,000.0&lt;br&gt;

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    index  SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0    116  PAST SALE 2025-07-30   Condo/Co-op  2770 S Ocean Blvd Unit 201n
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Palm Beach                FL             33480.0  4000000.0   4.0    5.5
#
#   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# 0     2770       4370.0       NaN      1991.0             NaN          915.0
#
#    HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0     5750.0   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...    Carole Koeppel
#
#              list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Sotheby's Intl. Realty, Inc.              None               None
#
#   buy_agent_name_1   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0        Dana Koch  The Corcoran Group             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
'https://trd-digital.github.io/trd-news-interactive-maps/' == 'https://trd-digital.github.io/trd-news-interactive-maps/'
# Out:
# True

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_08042025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '2770 at 2770 S Ocean Blvd Unit 201n in Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['index', 'SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    index  SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0    116  PAST SALE 2025-07-30   Condo/Co-op
# 1     44  PAST SALE 2025-07-30   Condo/Co-op
# 2     18  PAST SALE 2025-07-31   Condo/Co-op
# 3      8  PAST SALE 2025-07-31   Condo/Co-op
# 4     91  PAST SALE 2025-07-29   Condo/Co-op
# 5     49  PAST SALE 2025-07-31   Condo/Co-op
# 6     21  PAST SALE 2025-08-01   Condo/Co-op
# 7     15  PAST SALE 2025-07-30   Condo/Co-op
# 8    110  PAST SALE 2025-07-31   Condo/Co-op
# 9     13  PAST SALE 2025-07-31   Condo/Co-op
#
#                                ADDRESS              CITY STATE OR PROVINCE  \
# 0          2770 S Ocean Blvd Unit 201n        Palm Beach                FL
# 1       2600 S Ocean Blvd Unit 9C & 9D        Boca Raton                FL
# 2                701 Captains Way #701           Jupiter                FL
# 3             19630 Sawgrass Cir #2901        Boca Raton                FL
# 4              3115 S Ocean Blvd #1004    Highland Beach                FL
# 5                155 Tresana Blvd #107           Jupiter                FL
# 6              4740 S Ocean Blvd #1403    Highland Beach                FL
# 7                   11282 Glen Oaks Ct  North Palm Beach                FL
# 8                 701 S Olive Ave #202   West Palm Beach                FL
# 9  3579 Quail Ridge Dr Unit Bobwhite A     Boynton Beach                FL
#
#    ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0             33480.0  4000000.0   4.0    5.5
# 1             33432.0  3100000.0   4.0    4.5
# 2             33477.0  2100000.0   3.0    2.0
# 3             33434.0  1300000.0   3.0    3.0
# 4             33487.0  1250000.0   3.0    2.5
# 5             33478.0  1250000.0   3.0    2.5
# 6             33487.0   812000.0   2.0    2.0
# 7             33408.0   755000.0   2.0    2.5
# 8             33401.0   700000.0   2.0    2.0
# 9             33436.0   630000.0   2.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0                                 2770       4370.0       NaN      1991.0
# 1                          OCEANS EDGE       4202.0       NaN      1974.0
# 2  Captains Way AT Admirals Cove Condo       2033.0       NaN      1988.0
# 3                           Peppertree       2080.0       NaN      1979.0
# 4            Ocean Terrace North Condo       1852.0       NaN      1981.0
# 5        Jupiter Country Club Condo II       3042.0       NaN      2017.0
# 6                   Braemar Isle Condo       2050.0       NaN      1982.0
# 7                     North Palm Beach       2300.0       NaN      1983.0
# 8                 Two City Plaza Condo       1208.0       NaN      2008.0
# 9                          Quail Ridge       1737.0       NaN      1978.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          915.0     5750.0   Sold
# 1             NaN          738.0     3926.0   Sold
# 2             NaN         1033.0     2357.0   Sold
# 3             NaN          625.0     1460.0   Sold
# 4             NaN          675.0     2500.0   Sold
# 5             NaN          411.0     1295.0   Sold
# 6             NaN          396.0     2597.0   Sold
# 7             NaN          328.0        NaN   Sold
# 8             NaN          579.0     1182.0   Sold
# 9             NaN          363.0     1598.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...       MARMLS
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...  Beaches MLS
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...        PBBOR
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...  Beaches MLS
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
# 1    A11778186        N          Y  26.325422 -80.074701
# 2  RX-11096443        N          Y  26.907510 -80.085826
# 3  RX-11098622        N          Y  26.390498 -80.155550
# 4  RX-11061970        N          Y  26.418745 -80.063926
# 5  RX-11074044        N          Y  26.928057 -80.155226
# 6  RX-11097738        N          Y  26.393265 -80.069030
# 7      24-1802        N          Y  26.841592 -80.060273
# 8  RX-11025422        N          Y  26.706646 -80.052576
# 9  RX-11085859        N          Y  26.508482 -80.101142
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...    Carole Koeppel
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Devin Kay
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...      Lisa Fishman
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...    Judith Romanow
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...   Colleen Newland
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...       Gray Welton
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...      Ryan Coleman
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...  LILLIAN PULITZER
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...     Rhys Hollyman
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...          Ann Jara
#
#                         list_broker_name_1 list_agent_name_2  \
# 0             Sotheby's Intl. Realty, Inc.              None
# 1                          Douglas Elliman              None
# 2                     NV Realty Group, LLC              None
# 3                     Boca West Realty LLC       Ina Tuchman
# 4                          Douglas Elliman              None
# 5                     NV Realty Group, LLC              None
# 6                      Compass Florida LLC       Scott Gerow
# 7  Brown Harris Stevens of Palm Beach 5225              None
# 8                         Logan Realty Inc              None
ALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-07-30   Condo/Co-op     2770 S Ocean Blvd Unit 201n
# 1  PAST SALE 2025-07-30   Condo/Co-op  2600 S Ocean Blvd Unit 9C & 9D
# 2  PAST SALE 2025-07-31   Condo/Co-op           701 Captains Way #701
# 3  PAST SALE 2025-07-31   Condo/Co-op        19630 Sawgrass Cir #2901
# 4  PAST SALE 2025-07-29   Condo/Co-op         3115 S Ocean Blvd #1004
# 5  PAST SALE 2025-07-31   Condo/Co-op           155 Tresana Blvd #107
# 6  PAST SALE 2025-08-01   Condo/Co-op         4740 S Ocean Blvd #1403
# 7  PAST SALE 2025-07-30   Condo/Co-op              11282 Glen Oaks Ct
# 8  PAST SALE 2025-07-30   Condo/Co-op    11282 Glen Oaks Ct Unit 31-C
# 9  PAST SALE 2025-07-31   Condo/Co-op            701 S Olive Ave #202
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0        Palm Beach                FL             33480.0  4000000.0   4.0
# 1        Boca Raton                FL             33432.0  3100000.0   4.0
# 2           Jupiter                FL             33477.0  2100000.0   3.0
# 3        Boca Raton                FL             33434.0  1300000.0   3.0
# 4    Highland Beach                FL             33487.0  1250000.0   3.0
# 5           Jupiter                FL             33478.0  1250000.0   3.0
# 6    Highland Beach                FL             33487.0   812000.0   2.0
# 7  North Palm Beach                FL             33408.0   755000.0   2.0
# 8  North Palm Beach                FL             33408.0   755000.0   2.0
# 9   West Palm Beach                FL             33401.0   700000.0   2.0
#
#    BATHS                             LOCATION  SQUARE FEET  LOT SIZE  \
# 0    5.5                                 2770       4370.0       NaN
# 1    4.5                          OCEANS EDGE       4202.0       NaN
# 2    2.0  Captains Way AT Admirals Cove Condo       2033.0       NaN
# 3    3.0                           Peppertree       2080.0       NaN
# 4    2.5            Ocean Terrace North Condo       1852.0       NaN
# 5    2.5        Jupiter Country Club Condo II       3042.0       NaN
# 6    2.0                   Braemar Isle Condo       2050.0       NaN
# 7    2.5                     North Palm Beach       2300.0       NaN
# 8    2.5                    Twelve Oaks Condo       2300.0       NaN
# 9    2.0                 Two City Plaza Condo       1208.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1991.0             NaN          915.0     5750.0   Sold
# 1      1974.0             NaN          738.0     3926.0   Sold
# 2      1988.0             NaN         1033.0     2357.0   Sold
# 3      1979.0             NaN          625.0     1460.0   Sold
# 4      1981.0             NaN          675.0     2500.0   Sold
# 5      2017.0             NaN          411.0     1295.0   Sold
# 6      1982.0             NaN          396.0     2597.0   Sold
# 7      1983.0             NaN          328.0        NaN   Sold
# 8      1983.0             NaN          328.0     1600.0   Sold
# 9      2008.0             NaN          579.0     1182.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...       MARMLS
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...  Beaches MLS
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...        PBBOR
# 8  https://www.redfin.com/FL/North-Palm-Beach/112...  Beaches MLS
# 9  https://www.redfin.com/FL/West-Palm-Beach/701-...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
# 1    A11778186        N          Y  26.325422 -80.074701
# 2  RX-11096443        N          Y  26.907510 -80.085826
# 3  RX-11098622        N          Y  26.390498 -80.155550
# 4  RX-11061970        N          Y  26.418745 -80.063926
# 5  RX-11074044        N          Y  26.928057 -80.155226
# 6  RX-11097738        N          Y  26.393265 -80.069030
# 7      24-1802        N          Y  26.841592 -80.060273
# 8  RX-11040465        N          Y  26.841592 -80.060273
# 9  RX-11025422        N          Y  26.706646 -80.052576
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc
ALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0    116  PAST SALE 2025-07-30   Condo/Co-op
# 1     44  PAST SALE 2025-07-30   Condo/Co-op
# 2     18  PAST SALE 2025-07-31   Condo/Co-op
# 3      8  PAST SALE 2025-07-31   Condo/Co-op
# 4     91  PAST SALE 2025-07-29   Condo/Co-op
# 5     49  PAST SALE 2025-07-31   Condo/Co-op
# 6     21  PAST SALE 2025-08-01   Condo/Co-op
# 7     15  PAST SALE 2025-07-30   Condo/Co-op
# 8    110  PAST SALE 2025-07-31   Condo/Co-op
# 9     13  PAST SALE 2025-07-31   Condo/Co-op
#
#                                ADDRESS              CITY STATE OR PROVINCE  \
# 0          2770 S Ocean Blvd Unit 201n        Palm Beach                FL
# 1       2600 S Ocean Blvd Unit 9C & 9D        Boca Raton                FL
# 2                701 Captains Way #701           Jupiter                FL
# 3             19630 Sawgrass Cir #2901        Boca Raton                FL
# 4              3115 S Ocean Blvd #1004    Highland Beach                FL
# 5                155 Tresana Blvd #107           Jupiter                FL
# 6              4740 S Ocean Blvd #1403    Highland Beach                FL
# 7                   11282 Glen Oaks Ct  North Palm Beach                FL
# 8                 701 S Olive Ave #202   West Palm Beach                FL
# 9  3579 Quail Ridge Dr Unit Bobwhite A     Boynton Beach                FL
#
#    ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0             33480.0  4000000.0   4.0    5.5
# 1             33432.0  3100000.0   4.0    4.5
# 2             33477.0  2100000.0   3.0    2.0
# 3             33434.0  1300000.0   3.0    3.0
# 4             33487.0  1250000.0   3.0    2.5
# 5             33478.0  1250000.0   3.0    2.5
# 6             33487.0   812000.0   2.0    2.0
# 7             33408.0   755000.0   2.0    2.5
# 8             33401.0   700000.0   2.0    2.0
# 9             33436.0   630000.0   2.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0                                 2770       4370.0       NaN      1991.0
# 1                          OCEANS EDGE       4202.0       NaN      1974.0
# 2  Captains Way AT Admirals Cove Condo       2033.0       NaN      1988.0
# 3                           Peppertree       2080.0       NaN      1979.0
# 4            Ocean Terrace North Condo       1852.0       NaN      1981.0
# 5        Jupiter Country Club Condo II       3042.0       NaN      2017.0
# 6                   Braemar Isle Condo       2050.0       NaN      1982.0
# 7                     North Palm Beach       2300.0       NaN      1983.0
# 8                 Two City Plaza Condo       1208.0       NaN      2008.0
# 9                          Quail Ridge       1737.0       NaN      1978.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          915.0     5750.0   Sold
# 1             NaN          738.0     3926.0   Sold
# 2             NaN         1033.0     2357.0   Sold
# 3             NaN          625.0     1460.0   Sold
# 4             NaN          675.0     2500.0   Sold
# 5             NaN          411.0     1295.0   Sold
# 6             NaN          396.0     2597.0   Sold
# 7             NaN          328.0        NaN   Sold
# 8             NaN          579.0     1182.0   Sold
# 9             NaN          363.0     1598.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...       MARMLS
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...  Beaches MLS
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...        PBBOR
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...  Beaches MLS
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10936399        N          Y  26.622316 -80.037453
# 1    A11778186        N          Y  26.325422 -80.074701
# 2  RX-11096443        N          Y  26.907510 -80.085826
# 3  RX-11098622        N          Y  26.390498 -80.155550
# 4  RX-11061970        N          Y  26.418745 -80.063926
# 5  RX-11074044        N          Y  26.928057 -80.155226
# 6  RX-11097738        N          Y  26.393265 -80.069030
# 7      24-1802        N          Y  26.841592 -80.060273
# 8  RX-11025422        N          Y  26.706646 -80.052576
# 9  RX-11085859        N          Y  26.508482 -80.101142
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...    Carole Koeppel
# 1  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Devin Kay
# 2  https://www.redfin.com/FL/Jupiter/701-Captains...      Lisa Fishman
# 3  https://www.redfin.com/FL/Boca-Raton/19630-Saw...    Judith Romanow
# 4  https://www.redfin.com/FL/Highland-Beach/3115-...   Colleen Newland
# 5  https://www.redfin.com/FL/Jupiter/155-Tresana-...       Gray Welton
# 6  https://www.redfin.com/FL/Highland-Beach/4740-...      Ryan Coleman
# 7  https://www.redfin.com/FL/North-Palm-Beach/112...  LILLIAN PULITZER
# 8  https://www.redfin.com/FL/West-Palm-Beach/701-...     Rhys Hollyman
# 9  https://www.redfin.com/FL/Boynton-Beach/3579-S...          Ann Jara
#
#                         list_broker_name_1 list_agent_name_2  \
# 0             Sotheby's Intl. Realty, Inc.              None
# 1                          Douglas Elliman              None
# 2                     NV Realty Group, LLC              None
# 3                     Boca West Realty LLC       Ina Tuchman
# 4                          Douglas Elliman              None
# 5                     NV Realty Group, LLC              None
# 6                      Compass Florida LLC       Scott Gerow
# 7  Brown Harris Stevens of Palm Beach 5225              None
# 8                         Logan Realty Inc              None
# 9       The Club at Quail Ridge Realty Inc              None
#
#      list_broker_name_2   buy_agent_name_1  \
# 0                  None          Dana Koch
# 1                  None               None
# 2                  None    Jessica Kaufman
# 3  Boca West Realty LLC        Ina Tuchman
# 4                  None     Scott Correale
# 5                  None  Jennifer Friedman
# 6   Compass Florida LLC  Mary Ann Phillips
# 7                  None   LILLIAN PULITZER
# 8                  None      Lori Cronican
# 9                  None           Ann Jara
#
#                          buy_broker_name_1      buy_agent_name_2  \
# 0                       The Corcoran Group                  None
# 1                                     None                  None
# 2                    Beachfront Realty Inc                  None
# 3                     Boca West Realty LLC                  None
# 4       One Sotheby's International Realty                  None
# 5       Fine Living Realty of Palm Beaches                  None
# 6                      RE/MAX Select Group                  None
# 7  Brown Harris Stevens of Palm Beach 5225                  None
# 8                          Douglas Elliman  Christopher Cronican
# 9       The Club at Quail Ridge Realty Inc                  None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8   Douglas Elliman     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  2770 at 2770 S Ocean Blvd Unit 201n in Palm Beach
# 1  OCEANS EDGE at 2600 S Ocean Blvd Unit 9C & 9D ...
# 2  Captains Way AT Admirals Cove Condo at 701 Cap...
# 3  Peppertree at 19630 Sawgrass Cir #2901 in Boca...
# 4  Ocean Terrace North Condo at 3115 S Ocean Blvd...
# 5  Jupiter Country Club Condo II at 155 Tresana B...
# 6  Braemar Isle Condo at 4740 S Ocean Blvd #1403 ...
# 7  North Palm Beach at 11282 Glen Oaks Ct in Nort...
# 8  Two City Plaza Condo at 701 S Olive Ave #202 i...
# 9  Quail Ridge at 3579 Quail Ridge Dr Unit Bobwhi...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 11, 1) ## List (Earlier) date
date2 = datetime(2025, 7, 30) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 271

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING AGENTS'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING AGENTS'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "BEDS", 
    "BATHS",
    "SOURCE", 
    "MLS#"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df = chart_df.rename(columns={'$/SQUARE FEET':'PPSF'})

# %%
chart_df['PPSF'].astype(float)
# Out:
# 0     915.0
# 1     738.0
# 2    1033.0
# 3     625.0
# 4     675.0
# 5     411.0
# 6     396.0
# 7     328.0
# 8     579.0
# 9     363.0
# Name: PPSF, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['PPSF'] = chart_df['PPSF'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))

# %%
desired_order = [
    'SOLD DATE',
    'LOCATION',
    'ADDRESS',
    'PRICE',
    'SQUARE FEET',
    'PPSF',
    'YEAR BUILT',
    'LISTING AGENTS',
    'BUYING AGENTS'
]

chart_df = chart_df[desired_order]

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                             LOCATION  \
# 0 2025-07-30                                 2770
# 1 2025-07-30                          OCEANS EDGE
# 2 2025-07-31  Captains Way AT Admirals Cove Condo
# 3 2025-07-31                           Peppertree
# 4 2025-07-29            Ocean Terrace North Condo
# 5 2025-07-31        Jupiter Country Club Condo II
# 6 2025-08-01                   Braemar Isle Condo
# 7 2025-07-30                     North Palm Beach
# 8 2025-07-31                 Two City Plaza Condo
# 9 2025-07-31                          Quail Ridge
#
#                                              ADDRESS       PRICE SQUARE FEET  \
# 0          2770 S Ocean Blvd Unit 201n in Palm Beach  $4,000,000       4,370
# 1       2600 S Ocean Blvd Unit 9C & 9D in Boca Raton  $3,100,000       4,202
# 2                   701 Captains Way #701 in Jupiter  $2,100,000       2,033
# 3             19630 Sawgrass Cir #2901 in Boca Raton  $1,300,000       2,080
# 4          3115 S Ocean Blvd #1004 in Highland Beach  $1,250,000       1,852
# 5                   155 Tresana Blvd #107 in Jupiter  $1,250,000       3,042
# 6          4740 S Ocean Blvd #1403 in Highland Beach    $812,000       2,050
# 7             11282 Glen Oaks Ct in North Palm Beach    $755,000       2,300
# 8            701 S Olive Ave #202 in West Palm Beach    $700,000       1,208
# 9  3579 Quail Ridge Dr Unit Bobwhite A in Boynton...    $630,000       1,737
#
#      PPSF YEAR BUILT                                     LISTING AGENTS  \
# 0    $915       1991    Carole Koeppel Sotheby's Intl. Realty, Inc.
# 1    $738       1974                      Devin Kay Douglas Elliman
# 2  $1,033       1988              Lisa Fishman NV Realty Group, LLC
# 3    $625       1979  Judith Romanow Boca West Realty LLC Ina Tuchma...
# 4    $675       1981                Colleen Newland Douglas Elliman
# 5    $411       2017               Gray Welton NV Realty Group, LLC
# 6    $396       1982  Ryan Coleman Compass Florida LLC Scott Gerow C...
# 7    $328       1983  LILLIAN PULITZER Brown Harris Stevens of Palm ...
# 8    $579       2008                 Rhys Hollyman Logan Realty Inc
# 9    $363       1978    Ann Jara The Club at Quail Ridge Realty Inc
#
#                                        BUYING AGENTS
# 0                   Dana Koch The Corcoran Group
# 1
# 2          Jessica Kaufman Beachfront Realty Inc
# 3               Ina Tuchman Boca West Realty LLC
# 4  Scott Correale One Sotheby's International Rea...
# 5  Jennifer Friedman Fine Living Realty of Palm B...
# 6          Mary Ann Phillips RE/MAX Select Group
# 7  LILLIAN PULITZER Brown Harris Stevens of Palm ...
# 8  Lori Cronican Douglas Elliman Christopher Cron...
# 9    Ann Jara The Club at Quail Ridge Realty Inc
