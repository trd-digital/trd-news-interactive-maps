# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import urllib3
import re
import os
import folium

# %%
df = pd.read_csv("Untitled spreadsheet - Sheet1.csv")

# %%
df.columns
# Out:
# Index(['Developer', 'Status', 'Number of buildings ', 'Number of stories',
#        'Condos', 'Apartments', 'Offices', 'Retail ', 'medical offics', 'hotel',
#        'Expected complation ', 'Restaurants', 'Address', 'Unnamed: 13',
#        'CRE space', 'Long/Lant'],
#       dtype='object')

# %% [markdown]
# ## Map Maker

# %%
df = df.drop(columns=['Unnamed: 13'])

# %%
df[['lon','lat']] = df['Long/Lant'].str.split(',',expand=True).astype(float)

# %%
def popup_html(row_index):
    # Define the HTML content with a <style> tag to change the font
    html_content = '''
    <style>
        .popup-content {
            font-family: Arial, sans-serif; /* Change the font family as needed */
            font-size: 14px;
        }
    </style>
    <div class="popup-content">
    '''

    # Dynamically add data for each column that has a value
    for column in df.columns:
        if column not in ['lat', 'lon', 'image_links', 'Long/Lant']:
            value = df.at[row_index, column]
            value_str = str(value).strip()
            if pd.notnull(value) and value_str != "":
                html_content += f'<strong>{column}:</strong> {value_str}<br>'

    # Close the div tag
    html_content += '</div>'

    return html_content

# Define your map 'm' here as needed
m = folium.Map(location=df[["lon", "lat"]].mean().to_list(), zoom_start=15.5)

# Example of how to use the popup_html function within the loop for adding markers
for i in range(len(df)):
    popup_content = popup_html(i)
    iframe = folium.IFrame(html=popup_content, width=300, height=200)  # Adjust width and height as needed
    popup = folium.Popup(iframe, max_width=350)  # Adjust max_width as needed
    folium.Marker(
        location=[df.iloc[i]['lon'], df.iloc[i]['lat']],
        popup=popup
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_746749daf46ba8bc8683b690fe0a3d43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_746749daf46ba8bc8683b690fe0a3d43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_746749daf46ba8bc8683b690fe0a3d43 = L.map(
#                 &quot;map_746749daf46ba8bc8683b690fe0a3d43&quot;,
#                 {
#                     center: [25.78232505328107, -80.1927422966995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d436eedcc7d5ff0173e7ab97d6a2959 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#             var marker_eaa4acafcd78358a3ea113bec1b92d51 = L.marker(
#                 [25.783181749080377, -80.19258158823348],
#                 {}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#         var popup_7a87c6e79a8500b8cfa01650415d6110 = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var i_frame_34c7229dd8ca3f7294b228280b4c243d = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7a87c6e79a8500b8cfa01650415d6110.setContent(i_frame_34c7229dd8ca3f7294b228280b4c243d);
#
#
#
#         marker_eaa4acafcd78358a3ea113bec1b92d51.bindPopup(popup_7a87c6e79a8500b8cfa01650415d6110)
#         ;
#
#
#
#
#             var marker_04accbb27b7ef034b896291d67567f9a = L.marker(
#                 [25.783562579544732, -80.19117739738849],
#                 {}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#         var popup_f01b3b7000912d9381d2c1a769373dd8 = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var i_frame_4637bdd846229b22cc2219d5d46308f4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_f01b3b7000912d9381d2c1a769373dd8.setContent(i_frame_4637bdd846229b22cc2219d5d46308f4);
#
#
#
#         marker_04accbb27b7ef034b896291d67567f9a.bindPopup(popup_f01b3b7000912d9381d2c1a769373dd8)
#         ;
#
#
#
#
#             var marker_341aa02834c2b0f686ef01e3a2fd39ab = L.marker(
#                 [25.781480120338802, -80.1935240462881],
#                 {}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#         var popup_1e739c107976c8dc15d53089b5684507 = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var i_frame_5a23df6d66c35d44da76dc19e1bad884 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_1e739c107976c8dc15d53089b5684507.setContent(i_frame_5a23df6d66c35d44da76dc19e1bad884);
#
#
#
#         marker_341aa02834c2b0f686ef01e3a2fd39ab.bindPopup(popup_1e739c107976c8dc15d53089b5684507)
#         ;
#
#
#
#
#             var marker_a368665b0f39aae1b1912055592945ca = L.marker(
#                 [25.781591189985807, -80.19266072963225],
#                 {}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#         var popup_c43772f2a33ecc4814d570ac4f3306cd = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var i_frame_e5cde670b8810b2c8ecaf1c943f5b008 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_c43772f2a33ecc4814d570ac4f3306cd.setContent(i_frame_e5cde670b8810b2c8ecaf1c943f5b008);
#
#
#
#         marker_a368665b0f39aae1b1912055592945ca.bindPopup(popup_c43772f2a33ecc4814d570ac4f3306cd)
#         ;
#
#
#
#
#             var marker_2aede90fdd82f02efcbfedcc64d9e7e6 = L.marker(
#                 [25.784484867987615, -80.19201451615663],
#                 {}
#             ).addTo(map_746749daf46ba8bc8683b690fe0a3d43);
#
#
#         var popup_ba8dc97ac01235dd3d592d1a5015dc28 = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var i_frame_d12b1210591bb6be62d6d71548e338b2 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_ba8dc97ac01235dd3d592d1a5015dc28.setContent(i_frame_d12b1210591bb6be62d6d71548e338b2);
#
#
#
#         marker_2aede90fdd82f02efcbfedcc64d9e7e6.bindPopup(popup_ba8dc97ac01235dd3d592d1a5015dc28)
#         ;
#
#
#
#
#             var mark

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL grabber
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Miami_WorldCenter_03_28_24
