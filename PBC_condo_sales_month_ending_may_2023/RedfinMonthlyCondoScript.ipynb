# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import folium

# %% [markdown]
# ## Data Read-in

# %%
df = pd.read_csv('redfin_2023-06-06-10-58-53.csv')

# %% [markdown]
# ## Data Clean

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
df = df.dropna(subset=['SOLD DATE'])

# %%
# Define list of desired months (excluding current month)
desired_months = ['May']

# Filter DataFrame to include only entries from desired months
df_filtered = df[df['SOLD DATE'].str.split('-', expand=True)[0].isin(desired_months)]

# Reset the index
df_filtered = df_filtered.reset_index(drop=True)

# %%
# Data checks
print(df_filtered['PRICE'].isna().value_counts())
print('-------')
print(df_filtered['$/SQUARE FEET'].isna().value_counts())
print('-------')
print(df_filtered['YEAR BUILT'].isna().value_counts())
print('-------')
# Out:
# PRICE
# False    943
# Name: count, dtype: int64
# -------
# $/SQUARE FEET
# False    940
# True       3
# Name: count, dtype: int64
# -------
# YEAR BUILT
# False    943
# Name: count, dtype: int64
# -------

# %%
df_filtered.loc[df_filtered['PRICE'] == '0']
# Out:
# Empty DataFrame
# Columns: [SALE TYPE, SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, STATUS, NEXT OPEN HOUSE START TIME, NEXT OPEN HOUSE END TIME, URL, SOURCE, MLS#, FAVORITE, INTERESTED, LATITUDE, LONGITUDE]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_filtered['PRICE'] = pd.to_numeric(df_filtered['PRICE'])
df_filtered['$/SQUARE FEET'] = pd.to_numeric(df_filtered['$/SQUARE FEET'])
df_filtered['YEAR BUILT'] = pd.to_numeric(df_filtered['YEAR BUILT'])
df_filtered['LATITUDE'] = pd.to_numeric(df_filtered['LATITUDE'])
df_filtered['LONGITUDE'] = pd.to_numeric(df_filtered['LONGITUDE'])

# %%
df_filtered.sort_values(by='PRICE',ascending=True).head(20)
# Out:
#      SALE TYPE    SOLD DATE PROPERTY TYPE                      ADDRESS
# 621  PAST SALE   May-1-2023   Condo/Co-op  7844 Willow Spring Dr #1713  \
# 63   PAST SALE  May-22-2023   Condo/Co-op       1721 Village Blvd #305
# 23   PAST SALE  May-20-2023   Condo/Co-op                 81 Waltham D
# 15   PAST SALE  May-12-2023   Condo/Co-op                244 Windsor K
# 54   PAST SALE  May-26-2023   Condo/Co-op             41 Norwich B #41
# 503  PAST SALE  May-29-2023   Condo/Co-op         2400 NE 1st Ln #4110
# 480  PAST SALE  May-15-2023   Condo/Co-op   150 Salisbury G Unit 150 G
# 144  PAST SALE  May-25-2023   Condo/Co-op       285 285 Windsor M #285
# 695  PAST SALE  May-26-2023   Condo/Co-op                 156 Sussex H
# 657  PAST SALE  May-18-2023   Condo/Co-op                  95 Saxony B
# 93   PAST SALE  May-31-2023   Condo/Co-op            242 Northampton M
# 49   PAST SALE  May-17-2023   Condo/Co-op          149 Coventry G #149
# 121  PAST SALE  May-12-2023   Condo/Co-op                  17 Sussex A
# 782  PAST SALE   May-5-2023   Condo/Co-op              43 Dorchester B
# 5    PAST SALE  May-12-2023   Condo/Co-op              150 Berkshire G
# 21   PAST SALE  May-12-2023   Condo/Co-op           287 Norwich L #287
# 18   PAST SALE  May-12-2023   Condo/Co-op                 215 Sussex K
# 617  PAST SALE  May-22-2023   Condo/Co-op        2616 N Garden Dr #105
# 16   PAST SALE  May-12-2023   Condo/Co-op            371 Northampton S
# 723  PAST SALE  May-24-2023   Condo/Co-op    3400 Springdale Blvd #315
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS
# 621       Lake Worth                FL             33467.0    200.0   2.0  \
# 63   West Palm Beach                FL             33409.0    220.0   2.0
# 23   West Palm Beach                FL             33417.0  40000.0   1.0
# 15   West Palm Beach                FL             33417.0  56400.0   1.0
# 54   West Palm Beach                FL             33417.0  63401.0   1.0
# 503    Boynton Beach                FL             33435.0  70000.0   1.0
# 480  West Palm Beach                FL             33417.0  70000.0   1.0
# 144  West Palm Beach                FL             33417.0  70000.0   1.0
# 695  West Palm Beach                FL             33417.0  70000.0   1.0
# 657     Delray Beach                FL             33446.0  72500.0   1.0
# 93   West Palm Beach                FL             33417.0  76000.0   1.0
# 49   West Palm Beach                FL             33417.0  78000.0   1.0
# 121  West Palm Beach                FL             33417.0  78500.0   1.0
# 782  West Palm Beach                FL             33417.0  79000.0   1.0
# 5    West Palm Beach                FL             33417.0  80000.0   1.0
# 21   West Palm Beach                FL             33417.0  80000.0   2.0
# 18   West Palm Beach                FL             33417.0  80000.0   1.0
# 617       Lake Worth                FL             33461.0  80000.0   1.0
# 16   West Palm Beach                FL             33417.0  80000.0   1.0
# 723     Palm Springs                FL             33461.0  80000.0   1.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME
# 621    2.0  ...   Sold                         NaN                       NaN  \
# 63     2.0  ...   Sold                         NaN                       NaN
# 23     1.5  ...   Sold                         NaN                       NaN
# 15     1.0  ...   Sold                         NaN                       NaN
# 54     1.5  ...   Sold                         NaN                       NaN
# 503    1.5  ...   Sold                         NaN                       NaN
# 480    1.0  ...   Sold                         NaN                       NaN
# 144    1.5  ...   Sold                         NaN                       NaN
# 695    1.0  ...   Sold                         NaN                       NaN
# 657    1.0  ...   Sold                         NaN                       NaN
# 93     1.0  ...   Sold                         NaN                       NaN
# 49     1.5  ...   Sold                         NaN                       NaN
# 121    1.0  ...   Sold                         NaN                       NaN
# 782    1.5  ...   Sold                         NaN                       NaN
# 5      1.0  ...   Sold                         NaN                       NaN
# 21     1.5  ...   Sold                         NaN                       NaN
# 18     1.0  ...   Sold                         NaN                       NaN
# 617    1.0  ...   Sold                         NaN                       NaN
# 16     1.5  ...   Sold                         NaN                       NaN
# 723    1.5  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE
# 621  https://www.redfin.com/FL/Lake-Worth/7844-Will...  Beaches MLS  \
# 63   https://www.redfin.com/FL/West-Palm-Beach/1721...  Beaches MLS
# 23   https://www.redfin.com/FL/West-Palm-Beach/81-W...  Beaches MLS
# 15   https://www.redfin.com/FL/West-Palm-Beach/244-...  Beaches MLS
# 54   https://www.redfin.com/FL/West-Palm-Beach/41-N...       MARMLS
# 503  https://www.redfin.com/FL/Boynton-Beach/2400-N...  Beaches MLS
# 480  https://www.redfin.com/FL/West-Palm-Beach/150-...  Beaches MLS
# 144  https://www.redfin.com/FL/West-Palm-Beach/285-...       MARMLS
# 695  https://www.redfin.com/FL/West-Palm-Beach/156-...  Beaches MLS
# 657  https://www.redfin.com/FL/Delray-Beach/95-Saxo...  Beaches MLS
# 93   https://www.redfin.com/FL/West-Palm-Beach/242-...  Beaches MLS
# 49   https://www.redfin.com/FL/West-Palm-Beach/149-...       MARMLS
# 121  https://www.redfin.com/FL/West-Palm-Beach/17-S...  Beaches MLS
# 782  https://www.redfin.com/FL/West-Palm-Beach/43-D...  Beaches MLS
# 5    https://www.redfin.com/FL/West-Palm-Beach/150-...  Beaches MLS
# 21   https://www.redfin.com/FL/West-Palm-Beach/287-...  Beaches MLS
# 18   https://www.redfin.com/FL/West-Palm-Beach/215-...  Beaches MLS
# 617  https://www.redfin.com/FL/Lake-Worth/2616-Gard...  Beaches MLS
# 16   https://www.redfin.com/FL/West-Palm-Beach/371-...  Beaches MLS
# 723  https://www.redfin.com/FL/Palm-Springs/3400-Sp...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 621  RX-10865771         N          Y  26.623884 -80.171637
# 63   RX-10878498         N          Y  26.728345 -80.101391
# 23   RX-10891372         N          Y  26.716811 -80.122574
# 15   RX-10889288         N          Y  26.710774 -80.134635
# 54     A11248852         N          Y  26.718523 -80.121254
# 503  RX-10875661         N          Y  26.551620 -80.066109
# 480  RX-10861851         N          Y  26.716733 -80.121228
# 144    A11365611         N          Y  26.711200 -80.135707
# 695  RX-10867569         N          Y  26.720161 -80.134195
# 657  RX-10857533         N          Y  26.440922 -80.148274
# 93   RX-10878101         N          Y  26.717573 -80.134890
# 49     A11375490         N          Y  26.719274 -80.122286
# 121  RX-10879760         N          Y  26.720161 -80.134195
# 782  RX-10856659         N          Y  26.720629 -80.128772
# 5    RX-10889458         N          Y  26.714279 -80.132480
# 21   RX-10889445         N          Y  26.720040 -80.120173
# 18   RX-10889305         N          Y  26.720161 -80.134195
# 617  RX-10871776         N          Y  26.634259 -80.082171
# 16   RX-10889441         N          Y  26.716578 -80.133892
# 723  RX-10866215         N          Y  26.647291 -80.102943
#
# [20 rows x 27 columns]

# %%
print(df_filtered['URL'].iloc[63])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/1721-Village-Blvd-33409/unit-305/home/42595071

# %%
# Correct the prices, if needed
df_filtered.at[621,'PRICE']=(200000)
df_filtered.at[63,'PRICE']=(220000)

# %%
# Find problem psf by searching for a '0' value
df_filtered.loc[df_filtered['$/SQUARE FEET'] == '0'][['SOLD DATE','ADDRESS','CITY','$/SQUARE FEET','PRICE','SQUARE FEET']]
# Out:
# Empty DataFrame
# Columns: [SOLD DATE, ADDRESS, CITY, $/SQUARE FEET, PRICE, SQUARE FEET]
# Index: []

# %%
# Corrections, if needed
df_filtered.at[621,'$/SQUARE FEET']=(200000/1360)
df_filtered.at[63,'$/SQUARE FEET']=(220000/1075)

df_filtered.at[220,'$/SQUARE FEET']=(225000/1050)

# %%
# Find problem psf by searching for low values
df_filtered.sort_values(by='$/SQUARE FEET',ascending=True).head(20)[['PRICE','ADDRESS','CITY','$/SQUARE FEET']]
# Out:
#         PRICE                     ADDRESS             CITY  $/SQUARE FEET
# 23    40000.0                81 Waltham D  West Palm Beach           58.0
# 449   85000.0         2300 NE 1st Ln #201    Boynton Beach           74.0
# 34   135000.0        1 Westgate Ln Unit A    Boynton Beach           75.0
# 503   70000.0        2400 NE 1st Ln #4110    Boynton Beach           92.0
# 54    63401.0            41 Norwich B #41  West Palm Beach           93.0
# 657   72500.0                 95 Saxony B     Delray Beach           95.0
# 15    56400.0               244 Windsor K  West Palm Beach           96.0
# 348  100000.0         505 Spencer Dr #101  West Palm Beach           97.0
# 21    80000.0          287 Norwich L #287  West Palm Beach           98.0
# 249  100000.0     291 Cape Cod Cir Unit A       Lake Worth           98.0
# 144   70000.0      285 285 Windsor M #285  West Palm Beach          100.0
# 723   80000.0   3400 Springdale Blvd #315     Palm Springs          103.0
# 102  120000.0   6805 Willow Wood Dr #5073       Boca Raton          106.0
# 589   80000.0        2515 NE 1st Ct #3180    Boynton Beach          106.0
# 617   80000.0       2616 N Garden Dr #105       Lake Worth          108.0
# 480   70000.0  150 Salisbury G Unit 150 G  West Palm Beach          108.0
# 134  120000.0     3186 Via Poinciana #107       Lake Worth          111.0
# 627   99000.0       2615 S Garden Dr #204       Lake Worth          111.0
# 385   85000.0      447 Saxony J Dr Unit J     Delray Beach          112.0
# 791  205000.0       28 Westgate Ln Unit A    Boynton Beach          113.0

# %%
print(df_filtered.URL.iloc[23])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/81-Waltham-D-33417/home/42141590

# %%
# # Drop sales that aren't condos but labeled as such
# df_filtered = df_filtered.drop(1320)

# %% [markdown]
# ## Make Maps

# %%
### Create a price column formatted as currency ###
df_filtered['PRICE_AS_CURRENCY'] = df_filtered['PRICE'].apply(lambda x: "${:,.0f}".format(x))
### Set formatting for Beds, Baths ###
df_filtered['YEAR BUILT DISPLAY'] = df_filtered['YEAR BUILT'].apply(lambda x: '{:.0f}'.format(x))
df_filtered['PRICE_SQUARE_FEET_AS_CURRENCY'] = df_filtered['$/SQUARE FEET'].apply(lambda x: '${:,.0f}'.format(x))

# %%
df_filtered = df_filtered.sort_values(by=['PRICE'], ascending=False)
### Insert different colors for top 10 sales vs. the rest ###
df_filtered['COLOR'] = ''
### Create RANK column ###
df_filtered['RANK'] = 0
### Insert RANK values ###
df_filtered['RANK'] = range(1, len(df_filtered) + 1)
# use numpy to assign values to the 'COLOR' column
df_filtered['COLOR'] = np.where(df_filtered['RANK'] <= 10, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
### Define list of columns to drop from DF ###
columns_drop = ['SALE TYPE','PROPERTY TYPE','STATE OR PROVINCE','ZIP OR POSTAL CODE','HOA/MONTH','STATUS','NEXT OPEN HOUSE START TIME','NEXT OPEN HOUSE END TIME','SOURCE','MLS#','FAVORITE','INTERESTED','SQUARE FEET','LOT SIZE']

# %%
### Drop the columns ###
df_filtered = df_filtered.drop(columns=columns_drop)

# %%
def popup_html(row):
    Price = row['PRICE_AS_CURRENCY']
    Address = row['ADDRESS']
    City = row['CITY']
    sold_date = row['SOLD DATE']
    beds = row['BEDS']
    baths = row['BATHS']
    psf = row['PRICE_SQUARE_FEET_AS_CURRENCY']
    year_built = row['YEAR BUILT DISPLAY']
    rank = row['RANK']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Price: </strong>{}'''.format(Price) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>City: </strong>{}'''.format(City) + '''<br>
    <strong>Sold: </strong>{}'''.format(sold_date) + '''<br>
    <strong>Beds: </strong>{}'''.format(beds) + '''<br>
    <strong>Baths: </strong>{}'''.format(baths) + '''<br>
    <strong>Price per sf: </strong>{}'''.format(psf) + '''<br>
    <strong>Year Built: </strong>{}'''.format(year_built) + '''<br>
    <strong>Price Rank: </strong>{}'''.format(rank) + '''
    </html>
    '''
    return html

# %%
### Create map container ###
m = folium.Map(location=df_filtered[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=10,tiles=None)

### Create title ###
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f"May 2023 Condo Sales")

m.get_root().html.add_child(folium.Element(title_html))

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top 10 Sales')

for index, row in df_filtered.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)

# Display map

# %%
m.save('index.html')

# %% [markdown]
# ## Summary Info

# %%
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

Newest = '\033[1m' + 'Newest' + '\033[0m'
Oldest = '\033[1m' + 'Oldest' + '\033[0m'

# %%
df_filtered.columns
# Out:
# Index(['SOLD DATE', 'ADDRESS', 'CITY', 'PRICE', 'BEDS', 'BATHS', 'LOCATION',
#        'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'URL', 'LATITUDE',
#        'LONGITUDE', 'PRICE_AS_CURRENCY', 'YEAR BUILT DISPLAY',
#        'PRICE_SQUARE_FEET_AS_CURRENCY', 'COLOR', 'RANK'],
#       dtype='object')

# %%
df_filtered['FULL_ADDRESS'] = df_filtered['ADDRESS'] + ' ' + df_filtered['CITY']

# %%
print(df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['URL'])
# Out:
# https://www.redfin.com/FL/Palm-Beach/235-Sunrise-Ave-33480/unit-1102/home/104341979

# %%
print(f"{ME}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{LE}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{MAX_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{MIN_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{Newest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{Oldest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['YEAR BUILT']:.0f}")
# Out:
# Most Expensive
# Seaglass Condo, 1500 Beach Rd #501 Tequesta | Price $9,410,000 | $2,619 psf | Year built: 2022
# Least Expensive
# Century Village, 81 Waltham D West Palm Beach | Price $40,000 | $58 psf | Year built: 1969
# Highest Price Per Square Foot
# Lowell House Condo Lts 53 And 54 Blk H Royal Park A, 340 S Ocean Blvd Unit 5f Palm Beach | Price $5,500,000 | $3,012 psf | Year built: 1967
# Lowest Price Per Square Foot
# Century Village, 81 Waltham D West Palm Beach | Price $40,000 | $58 psf | Year built: 1969
# Newest
# Seaglass Condo, 1500 Beach Rd #501 Tequesta | Price $9,410,000 | $2,619 psf | Year built: 2022
# Oldest
# Palm Beach Hotel Condo, 235 Sunrise Ave #1102 Palm Beach | Price $700,000 | $648 psf | Year built: 1925

# %% [markdown]
# ## Time on Market Calculator

# %%
# print(df_Current.loc[df_Current['YEAR BUILT'].idxmin()])

# %%
from datetime import datetime, timedelta

date1 = datetime(2023, 4, 10) ## List (Earlier) date
date2 = datetime(2023, 5, 17) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 37

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PBC_condo_sales_month_ending_may_2023

# %% [markdown]
# ## Get Summary Data

# %%
print('SALES INFO')
print(f'Number of sales: {len(df_filtered)}')
print('--------')
print(f'Total sale price: ${df_filtered["PRICE"].sum():,.0f}')
print('--------')
print(f'Median sale price: ${df_filtered["PRICE"].median():,.0f}')
print('--------')
print(f'Max sale price: ${df_filtered["PRICE"].max():,.0f}')
print('--------')
print(f'Min sale price: ${df_filtered["PRICE"].min():,.0f}')
print('------------------------------------------------')
print('PSF INFO')
print(f'Max price per square foot: ${df_filtered["$/SQUARE FEET"].max():,.0f}')
print('--------')
print(f'Min price per square foot: ${df_filtered["$/SQUARE FEET"].min():,.0f}')
print('--------')
print(f'Median price per square foot: ${df_filtered["$/SQUARE FEET"].median():,.0f}')
print('------------------------------------------------')
print('CONDO AGES')
print(f'Newest building: {df_filtered["YEAR BUILT"].max()}')
print('----------')
print(f'Oldest building: {df_filtered["YEAR BUILT"].min()}')
print('----------')
print(f'Average building age: {df_filtered["YEAR BUILT"].mean()}')
# Out:
# SALES INFO
# Number of sales: 985
# --------
# Total sale price: $742,492,761
# --------
# Median sale price: $415,000
# --------
# Max sale price: $22,000,000
# --------
# Min sale price: $65,000
# ------------------------------------------------
# PSF INFO
# Max price per square foot: $4,245
# --------
# Min price per square foot: $90
# --------
# Median price per square foot: $450
# ------------------------------------------------
# CONDO AGES
# Newest building: 2023.0
# ----------
# Oldest building: 1925.0
# ----------
# Average building age: 1988.0314720812182
