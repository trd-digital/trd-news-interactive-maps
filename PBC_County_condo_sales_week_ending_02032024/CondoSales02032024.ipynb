# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Jan. 26th Feb. 2nd

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE       ADDRESS        CITY  \
# 1  PAST SALE  January-28-2025   Condo/Co-op  634 Marlboro  Lake Worth
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33467.0  120000.0   2.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Lake-Worth/634-Marlb...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11045099         N          Y  26.624011   -80.1622
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# df2 = df[(df['SOLD DATE'] > '2024-12-29') & (df['SOLD DATE'] < '2025-01-07')]

# %%
df2 = df

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-01-31    28
# 2025-01-30    21
# 2025-01-27    15
# 2025-01-29    14
# 2025-01-28    11
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 4   PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 16  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 27  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 50  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 10  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 65  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 32  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 81  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 74  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 6   PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  \
# 4           Palm Beach                FL             33480.0  14900000.0
# 16          Boca Raton                FL             33432.0   4425000.0
# 27  Palm Beach Gardens                FL             33410.0   3400000.0
# 50          Palm Beach                FL             33480.0   2887500.0
# 10          Boca Raton                FL             33432.0   2700000.0
# 65             Jupiter                FL             33469.0   2500000.0
# 32          Palm Beach                FL             33480.0   1585025.0
# 81          Palm Beach                FL             33480.0   1350000.0
# 74          Boca Raton                FL             33432.0   1320000.0
# 6           Boca Raton                FL             33432.0   1100000.0
#
#     BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 4    5.0    6.5  ...   Sold                         NaN
# 16   3.0    4.5  ...   Sold                         NaN
# 27   3.0    3.0  ...   Sold                         NaN
# 50   2.0    2.0  ...   Sold                         NaN
# 10   3.0    2.5  ...   Sold                         NaN
# 65   3.0    3.5  ...   Sold                         NaN
# 32   2.0    2.0  ...   Sold                         NaN
# 81   2.0    2.0  ...   Sold                         NaN
# 74   2.0    2.0  ...   Sold                         NaN
# 6    2.0    2.0  ...   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 4                        NaN
# 16                       NaN
# 27                       NaN
# 50                       NaN
# 10                       NaN
# 65                       NaN
# 32                       NaN
# 81                       NaN
# 74                       NaN
# 6                        NaN
#
#                                                   URL       SOURCE  \
# 4   https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
# 16  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...  Beaches MLS
# 27  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 50  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 10  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...  Beaches MLS
# 65  https://www.redfin.com/FL/Jupiter/19750-Beach-...  Beaches MLS
# 32  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...  Beaches MLS
# 81  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...  Beaches MLS
# 74  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 6   https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 4   RX-11047415         N          Y  26.646645 -80.037547
# 16  RX-11041231         N          Y  26.344996 -80.076846
# 27  RX-11032639         N          Y  26.881072 -80.073865
# 50  RX-11014811         N          Y  26.720485 -80.041578
# 10  RX-11042990         N          Y  26.325405 -80.074687
# 65  RX-11013690         N          Y  26.967565 -80.080179
# 32  RX-11025737         N          Y  26.625982 -80.037408
# 81  RX-10968735         N          Y  26.619676 -80.037645
# 74  RX-11001639         N          Y  26.348269 -80.076619
# 6     F10466020         N          Y  26.323489 -80.075035
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 0  PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 1  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 2  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 3  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 4  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 5  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 6  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 7  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 8  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 9  PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  14900000.0   5.0
# 1          Boca Raton                FL             33432.0   4425000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0   3400000.0   3.0
# 3          Palm Beach                FL             33480.0   2887500.0   2.0
# 4          Boca Raton                FL             33432.0   2700000.0   3.0
# 5             Jupiter                FL             33469.0   2500000.0   3.0
# 6          Palm Beach                FL             33480.0   1585025.0   2.0
# 7          Palm Beach                FL             33480.0   1350000.0   2.0
# 8          Boca Raton                FL             33432.0   1320000.0   2.0
# 9          Boca Raton                FL             33432.0   1100000.0   2.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    6.5  ... -80.037547  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...
# 1    4.5  ... -80.076846  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...
# 2    3.0  ... -80.073865  https://www.redfin.com/FL/Palm-Beach-Gardens/2...
# 3    2.0  ... -80.041578  https://www.redfin.com/FL/Palm-Beach/150-Bradl...
# 4    2.5  ... -80.074687  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...
# 5    3.5  ... -80.080179  https://www.redfin.com/FL/Jupiter/19750-Beach-...
# 6    2.0  ... -80.037408  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...
# 7    2.0  ... -80.037645  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...
# 8    2.0  ... -80.076619  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...
# 9    2.0  ... -80.075035  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...
#
#      list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0     Spencer Schlager                 Douglas Elliman               None
# 1           David Hall             Compass Florida LLC         Sonia Hall
# 2           Laura Pope    Sotheby's Intl. Realty, Inc.               None
# 3  Christopher Leavitt                 Douglas Elliman               None
# 4         Jill Glanzer    Signature Real Estate Finder   Matthew Maschler
# 5       Fanning Hearon           K2 Realty, Inc. (NPB)               None
# 6      Victoria Brewer                 Douglas Elliman        Howard Vine
# 7       Benjamin Stein    Sotheby's Intl. Realty, Inc.               None
# 8     Alexander Golden            Compass Florida, LLC               None
# 9       Denise Stewart  Keller Williams Realty Profess     Dennis Stewart
#
#                list_broker_name_2    buy_agent_name_1  \
# 0                            None        Fern Fodiman
# 1             Compass Florida LLC  Todd David Lipsich
# 2                            None       Kelly Schmidt
# 3                            None       Shirley Wyner
# 4    Signature Real Estate Finder        Gregory Lynn
# 5                            None     Annette Kravick
# 6                 Douglas Elliman        Mia Morrison
# 7                            None   Geoffrey Aldridge
# 8                            None        Alexa Downie
# 9  Keller Williams Realty Profess      Andrew Pietrak
#
#                 buy_broker_name_1  buy_agent_name_2   buy_broker_name_2
# 0    Sotheby's Intl. Realty, Inc.              None                None
# 1          Luxury Partners Realty              None                None
# 2          Illustrated Properties              None                None
# 3   William Raveis Palm Beach LLC              None                None
# 4               Lynn Realty Group              None                None
# 5    The Keyes Company (Tequesta)              None                None
# 6              The Corcoran Group    Laura Johnston  The Corcoran Group
# 7                 Douglas Elliman              None                None
# 8  Champagne & Parisi Real Estate              None                None
# 9    Luxury Real Estate Group LLC              None                None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 89

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $688,181

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $377

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $61,248,125

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Palm Beach County
# Input Previous Week Condo Sales Total (number units sold):
# 64
# Input Previous Week Condo Average Sales Price:
# 403182
# Input Previous Week Condo Average PSF:
# 299
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 25_800_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE            ADDRESS        CITY  \
# 0  PAST SALE 2025-01-31   Condo/Co-op  1 Sloans Curve Dr  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33480.0  14900000.0   5.0    6.5
#
#                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Residences AT Sloans Curve       5308.0   16405.0      1981.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Spencer Schlager
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None     Fern Fodiman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0  Sotheby's Intl. Realty, Inc.             None              None     1
#
#     COLOR
# 0  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 0  PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 1  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 2  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 3  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 4  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 5  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 6  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 7  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 8  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 9  PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  14900000.0   5.0
# 1          Boca Raton                FL             33432.0   4425000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0   3400000.0   3.0
# 3          Palm Beach                FL             33480.0   2887500.0   2.0
# 4          Boca Raton                FL             33432.0   2700000.0   3.0
# 5             Jupiter                FL             33469.0   2500000.0   3.0
# 6          Palm Beach                FL             33480.0   1585025.0   2.0
# 7          Palm Beach                FL             33480.0   1350000.0   2.0
# 8          Boca Raton                FL             33432.0   1320000.0   2.0
# 9          Boca Raton                FL             33432.0   1100000.0   2.0
#
#    BATHS                          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5        Residences AT Sloans Curve       5308.0   16405.0      1981.0
# 1    4.5                Mizner Grand Condo       4168.0       NaN      2000.0
# 2    3.0                             Azure       2759.0       NaN      2018.0
# 3    2.0         Palm Beach Biltmore Condo       1610.0       NaN      1926.0
# 4    2.5                 Oceans Edge Condo       2105.0       NaN      1975.0
# 5    3.5  Passages OF Jupiter Island Condo       2979.0       NaN      1982.0
# 6    2.0          Twenty Six Hundred Condo       1661.0       NaN      1977.0
# 7    2.0                Ambassador II Corp       1294.0  180559.0      1968.0
# 8    2.0                      Mizner Court       1706.0       NaN      1989.0
# 9    2.0                      Ocean Towers       1425.0       NaN      1973.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
# 1             NaN         1062.0     5028.0   Sold
# 2             NaN         1232.0     2903.0   Sold
# 3             NaN         1793.0     2616.0   Sold
# 4             NaN         1283.0     2617.0   Sold
# 5             NaN          839.0     2933.0   Sold
# 6             NaN          954.0     2138.0   Sold
# 7             NaN         1043.0     2188.0   Sold
# 8             NaN          774.0     2957.0   Sold
# 9             NaN          772.0     1262.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...  Beaches MLS
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...  Beaches MLS
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
# 1  RX-11041231        N          Y  26.344996 -80.076846
# 2  RX-11032639        N          Y  26.881072 -80.073865
# 3  RX-11014811        N          Y  26.720485 -80.041578
# 4  RX-11042990        N          Y  26.325405 -80.074687
# 5  RX-11013690        N          Y  26.967565 -80.080179
# 6  RX-11025737        N          Y  26.625982 -80.037408
# 7  RX-10968735        N          Y  26.619676 -80.037645
# 8  RX-11001639        N          Y  26.348269 -80.076619
# 9    F10466020        N          Y  26.323489 -80.075035
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...     Spencer Schlager
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...           David Hall
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...           Laura Pope
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Christopher Leavitt
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Jill Glanzer
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...       Fanning Hearon
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...      Victoria Brewer
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...       Benjamin Stein
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...     Alexander Golden
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...       Denise Stewart
#
#                list_broker_name_1 list_agent_name_2  \
# 0                 Douglas Elliman              None
# 1             Compass Florida LLC        Sonia Hall
# 2    Sotheby's Intl. Realty, Inc.              None
# 3                 Douglas Elliman              None
# 4    Signature Real Estate Finder  Matthew Maschler
# 5           K2 Realty, Inc. (NPB)              None
# 6                 Douglas Elliman       Howard Vine
# 7    Sotheby's Intl. Realty, Inc.              None
# 8            Compass Florida, LLC              None
# 9  Keller Williams Realty Profess    Dennis Stewart
#
#                list_broker_name_2    buy_agent_name_1  \
# 0                            None        Fern Fodiman
# 1             Compass Florida LLC  Todd David Lipsich
# 2                            None       Kelly Schmidt
# 3                            None       Shirley Wyner
# 4    Signature Real Estate Finder        Gregory Lynn
# 5                            None     Annette Kravick
# 6                 Douglas Elliman        Mia Morrison
# 7                            None   Geoffrey Aldridge
# 8                            None        Alexa Downie
# 9  Keller Williams Realty Profess      Andrew Pietrak
#
#                 buy_broker_name_1 buy_agent_name_2   buy_broker_name_2  RANK  \
# 0    Sotheby's Intl. Realty, Inc.             None                None     1
# 1          Luxury Partners Realty             None                None     2
# 2          Illustrated Properties             None                None     3
# 3   William Raveis Palm Beach LLC             None                None     4
# 4               Lynn Realty Group             None                None     5
# 5    The Keyes Company (Tequesta)             None                None     6
# 6              The Corcoran Group   Laura Johnston  The Corcoran Group     7
# 7                 Douglas Elliman             None                None     8
# 8  Champagne & Parisi Real Estate             None                None     9
# 9    Luxury Real Estate Group LLC             None                None    10
#
#     COLOR
# 0  orange
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# 5    blue
# 6    blue
# 7    blue
# 8    blue
# 9    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45cf016d866444a075c1ae6db0c48519 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Jan. 26th — Feb. 2nd&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45cf016d866444a075c1ae6db0c48519&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_45cf016d866444a075c1ae6db0c48519 = L.map(
#                 &quot;map_45cf016d866444a075c1ae6db0c48519&quot;,
#                 {
#                     center: [26.601100451685397, -80.10721669662921],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_45f83346394c4bb2b857a3f96a2fb6a7 = L.featureGroup(
#                 {}
#             ).addTo(map_45cf016d866444a075c1ae6db0c48519);
#
#
#             var marker_ea796635e6935954a590f74c8e1441d3 = L.marker(
#                 [26.6466449, -80.0375472],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_45f83346394c4bb2b857a3f96a2fb6a7);
#
#
#             var icon_d01c1b10ebc4dabb387d6e1b652f0af0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea796635e6935954a590f74c8e1441d3.setIcon(icon_d01c1b10ebc4dabb387d6e1b652f0af0);
#
#
#         var popup_e428454c0937439a75ea4d2b2d92dab3 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9685216f4e2002d8b0540b2a311d3b3e = $(`&lt;div id=&quot;html_9685216f4e2002d8b0540b2a311d3b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1 Sloans Curve Dr&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$14,900,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,807.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;5,308.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1981.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_e428454c0937439a75ea4d2b2d92dab3.setContent(html_9685216f4e2002d8b0540b2a311d3b3e);
#
#
#
#         marker_ea796635e6935954a590f74c8e1441d3.bindPopup(popup_e428454c0937439a75ea4d2b2d92dab3)
#         ;
#
#
#
#
#             var feature_group_339991871ddf41c475b7e87581983350 = L.featureGroup(
#                 {}
#             ).addTo(map_45cf016d866444a075c1ae6db0c48519);
#
#
#             var marker_aed77bbd520dc383dbb2b1f98bd1016f = L.marker(
#                 [26.3449963, -80.0768464],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_339991871ddf41c475b7e87581983350);
#
#
#             var icon_b20876a4ccfc3705a29573ea2f60834e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aed77bbd520dc383dbb2b1f98bd1016f.setIcon(icon_b20876a4ccfc3705a29573ea2f60834e);
#
#
#         var popup_55935a31a2ca004ccfeaa074c6d4c939 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_22cb7c07968ed30b3ef1bba2df464914 = $(`&lt;div id=&quot;html_22cb7c07968ed30b3ef1bba2df464914&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;400 SE 5th Ave #605&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,425,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,062.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,168.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2000.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_55935a31a2ca004ccfeaa074c6d4c939.setContent(html_22cb7c07968ed30b3ef1bba2df464914);
#
#
#
#         marker_aed77bbd520dc383dbb2b1f98bd1016f.bindPopup(popup_55935a31a2ca004ccfeaa074c6d4c939)
#         ;
#
#
#
#
#             var marker_36bd6af648a1633a46d24022610b87f5 = L.marker(
#                 [26.8810721, -80.0738652],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_339991871ddf41c475b7e87581983350);
#
#
#             var icon_bfda63f62cfe3ea99d572657f2889f47 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36bd6af648a1633a46d24022610b87f5.setIcon(icon_bfda63f62cfe3ea99d572657f2889f47);
#
#
#         var popup_43877b5e174e099fdd3c9dac03697b83 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_59c9f662e6359d0fd406561e4c4381b9 =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE            ADDRESS        CITY  \
# 0  PAST SALE 2025-01-31   Condo/Co-op  1 Sloans Curve Dr  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33480.0  14900000.0   5.0    6.5
#
#                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Residences AT Sloans Curve       5308.0   16405.0      1981.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Spencer Schlager
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None     Fern Fodiman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0  Sotheby's Intl. Realty, Inc.             None              None     1
#
#     COLOR
# 0  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_02032024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Residences AT Sloans Curve at 1 Sloans Curve Dr in Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 0  PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 1  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 2  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 3  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 4  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 5  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 6  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 7  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 8  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 9  PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  14900000.0   5.0
# 1          Boca Raton                FL             33432.0   4425000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0   3400000.0   3.0
# 3          Palm Beach                FL             33480.0   2887500.0   2.0
# 4          Boca Raton                FL             33432.0   2700000.0   3.0
# 5             Jupiter                FL             33469.0   2500000.0   3.0
# 6          Palm Beach                FL             33480.0   1585025.0   2.0
# 7          Palm Beach                FL             33480.0   1350000.0   2.0
# 8          Boca Raton                FL             33432.0   1320000.0   2.0
# 9          Boca Raton                FL             33432.0   1100000.0   2.0
#
#    BATHS                          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5        Residences AT Sloans Curve       5308.0   16405.0      1981.0
# 1    4.5                Mizner Grand Condo       4168.0       NaN      2000.0
# 2    3.0                             Azure       2759.0       NaN      2018.0
# 3    2.0         Palm Beach Biltmore Condo       1610.0       NaN      1926.0
# 4    2.5                 Oceans Edge Condo       2105.0       NaN      1975.0
# 5    3.5  Passages OF Jupiter Island Condo       2979.0       NaN      1982.0
# 6    2.0          Twenty Six Hundred Condo       1661.0       NaN      1977.0
# 7    2.0                Ambassador II Corp       1294.0  180559.0      1968.0
# 8    2.0                      Mizner Court       1706.0       NaN      1989.0
# 9    2.0                      Ocean Towers       1425.0       NaN      1973.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
# 1             NaN         1062.0     5028.0   Sold
# 2             NaN         1232.0     2903.0   Sold
# 3             NaN         1793.0     2616.0   Sold
# 4             NaN         1283.0     2617.0   Sold
# 5             NaN          839.0     2933.0   Sold
# 6             NaN          954.0     2138.0   Sold
# 7             NaN         1043.0     2188.0   Sold
# 8             NaN          774.0     2957.0   Sold
# 9             NaN          772.0     1262.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...  Beaches MLS
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...  Beaches MLS
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
# 1  RX-11041231        N          Y  26.344996 -80.076846
# 2  RX-11032639        N          Y  26.881072 -80.073865
# 3  RX-11014811        N          Y  26.720485 -80.041578
# 4  RX-11042990        N          Y  26.325405 -80.074687
# 5  RX-11013690        N          Y  26.967565 -80.080179
# 6  RX-11025737        N          Y  26.625982 -80.037408
# 7  RX-10968735        N          Y  26.619676 -80.037645
# 8  RX-11001639        N          Y  26.348269 -80.076619
# 9    F10466020        N          Y  26.323489 -80.075035
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...     Spencer Schlager
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...           David Hall
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...           Laura Pope
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Christopher Leavitt
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Jill Glanzer
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...       Fanning Hearon
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...      Victoria Brewer
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...       Benjamin Stein
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...     Alexander Golden
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...       Denise Stewart
#
#                list_broker_name_1 list_agent_name_2  \
# 0                 Douglas Elliman              None
# 1             Compass Florida LLC        Sonia Hall
# 2    Sotheby's Intl. Realty, Inc.              None
# 3                 Douglas Elliman              None
# 4    Signature Real Estate Finder  Matthew Maschler
# 5           K2 Realty, Inc. (NPB)              None
# 6                 Douglas Elliman       Howard Vine
# 7    Sotheby's Intl. Realty, Inc.              None
# 8            Compass Florida, LLC              None
# 9  Keller Williams Realty Profess    Dennis Stewart
#
#                list_broker_name_2    buy_agent_name_1  \
# 0                            None        Fern Fodiman
# 1             Compass Florida LLC  Todd David Lipsich
# 2                            None       Kelly Schmidt
# 3                            None       Shirley Wyner
# 4    Signature Real Estate Finder        Gregory Lynn
# 5                            None     Annette Kravick
# 6                 Douglas Elliman        Mia Morrison
# 7                            None   Geoffrey Aldridge
# 8                            None        Alexa Downie
# 9  Keller Williams Realty Profess      Andrew Pietrak
#
#                 buy_broker_name_1 buy_agent_name_2   buy_broker_name_2  RANK  \
# 0    Sotheby's Intl. Realty, Inc.             None                None     1
# 1          Luxury Partners Realty             None                None     2
# 2          Illustrated Properties             None                None     3
# 3   William Raveis Palm Beach LLC             None                None     4
# 4               Lynn Realty Group             None                None     5
# 5    The Keyes Company (Tequesta)             None                None     6
# 6              The Corcoran Group   Laura Johnston  The Corcoran Group     7
# 7                 Douglas Elliman             None                None     8
# 8  Champagne & Parisi Real Estate             None                None     9
# 9    Luxury Real Estate Group LLC             None                None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Residences AT Sloans Curve at 1 Sloans Curve D...
# 1    blue  Mizner Grand Condo at 400 SE 5th Ave #605 in B...
# 2    blue  Azure at 2720 Donald Ross Rd #510 in Palm Beac...
# 3    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #1...
# 4    blue  Oceans Edge Condo at 2600 S Ocean Blvd Unit 11...
# 5    blue  Passages OF Jupiter Island Condo at 19750 Beac...
# 6    blue  Twenty Six Hundred Condo at 2600 S Ocean 503 B...
# 7    blue  Ambassador II Corp at 2780 S Ocean Blvd #110 i...
# 8    blue  Mizner Court at 140 SE 5th Ave Ph 45 in Boca R...
# 9    blue  Ocean Towers at 2800 S Ocean Blvd Ph -C in Boc...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Residences AT Sloans Curve closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,100,000 to $14,900,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Palm Beach Gardens, Palm Beach, Boca Raton, Jupiter
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 89 condo sales totaling $61,248,125 million from Jan. 26th to Feb. 2nd. The previous week, brokers closed 64 condo sales totaling $25,800,000.
#
# Last week’s units sold for an average of $688,181, higher than the $403,182 average price from the previous week. The average price per square foot rose to $377 from $299, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,100,000.0 million to $14,900,000.0 million.
#
# Residences AT Sloans Curve at 1 Sloans Curve Dr in Palm Beach took the top spot with a $14,900,000.0 million closing. The sale closed at $2,807.0 per square foot.
#
# Spencer Schlager with Douglas Elliman, and None with None had the listing.
# Fern Fodiman with Sotheby's Intl. Realty, Inc., and None with None represented the buyer.
#
# Mizner Grand Condo at 400 SE 5th Ave #605 in Boca Raton, closed for the second highest amount, $4,425,000.0, or $1,062.0 per square foot.
#
# David Hall with Compass Florida LLC, and Sonia Hall with Compass Florida LLC had the listing.
# Todd David Lipsich with Luxury Partners Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_02032024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 26th to Feb. 2nd:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 0  PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 1  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 2  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 3  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 4  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 5  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 6  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 7  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 8  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 9  PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  14900000.0   5.0
# 1          Boca Raton                FL             33432.0   4425000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0   3400000.0   3.0
# 3          Palm Beach                FL             33480.0   2887500.0   2.0
# 4          Boca Raton                FL             33432.0   2700000.0   3.0
# 5             Jupiter                FL             33469.0   2500000.0   3.0
# 6          Palm Beach                FL             33480.0   1585025.0   2.0
# 7          Palm Beach                FL             33480.0   1350000.0   2.0
# 8          Boca Raton                FL             33432.0   1320000.0   2.0
# 9          Boca Raton                FL             33432.0   1100000.0   2.0
#
#    BATHS                          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5        Residences AT Sloans Curve       5308.0   16405.0      1981.0
# 1    4.5                Mizner Grand Condo       4168.0       NaN      2000.0
# 2    3.0                             Azure       2759.0       NaN      2018.0
# 3    2.0         Palm Beach Biltmore Condo       1610.0       NaN      1926.0
# 4    2.5                 Oceans Edge Condo       2105.0       NaN      1975.0
# 5    3.5  Passages OF Jupiter Island Condo       2979.0       NaN      1982.0
# 6    2.0          Twenty Six Hundred Condo       1661.0       NaN      1977.0
# 7    2.0                Ambassador II Corp       1294.0  180559.0      1968.0
# 8    2.0                      Mizner Court       1706.0       NaN      1989.0
# 9    2.0                      Ocean Towers       1425.0       NaN      1973.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
# 1             NaN         1062.0     5028.0   Sold
# 2             NaN         1232.0     2903.0   Sold
# 3             NaN         1793.0     2616.0   Sold
# 4             NaN         1283.0     2617.0   Sold
# 5             NaN          839.0     2933.0   Sold
# 6             NaN          954.0     2138.0   Sold
# 7             NaN         1043.0     2188.0   Sold
# 8             NaN          774.0     2957.0   Sold
# 9             NaN          772.0     1262.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...  Beaches MLS
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...  Beaches MLS
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
# 1  RX-11041231        N          Y  26.344996 -80.076846
# 2  RX-11032639        N          Y  26.881072 -80.073865
# 3  RX-11014811        N          Y  26.720485 -80.041578
# 4  RX-11042990        N          Y  26.325405 -80.074687
# 5  RX-11013690        N          Y  26.967565 -80.080179
# 6  RX-11025737        N          Y  26.625982 -80.037408
# 7  RX-10968735        N          Y  26.619676 -80.037645
# 8  RX-11001639        N          Y  26.348269 -80.076619
# 9    F10466020        N          Y  26.323489 -80.075035
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...     Spencer Schlager
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...           David Hall
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...           Laura Pope
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Christopher Leavitt
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Jill Glanzer
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...       Fanning Hearon
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...      Victoria Brewer
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...       Benjamin Stein
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...     Alexander Golden
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...       Denise Stewart
#
#                list_broker_name_1 list_agent_name_2  \
# 0                 Douglas Elliman              None
# 1             Compass Florida LLC        Sonia Hall
# 2    Sotheby's Intl. Realty, Inc.              None
# 3                 Douglas Elliman              None
# 4    Signature Real Estate Finder  Matthew Maschler
# 5           K2 Realty, Inc. (NPB)              None
# 6                 Douglas Elliman       Howard Vine
# 7    Sotheby's Intl. Realty, Inc.              None
# 8            Compass Florida, LLC              None
# 9  Keller Williams Realty Profess    Dennis Stewart
#
#                list_broker_name_2    buy_agent_name_1  \
# 0                            None        Fern Fodiman
# 1             Compass Florida LLC  Todd David Lipsich
# 2                            None       Kelly Schmidt
# 3                            None       Shirley Wyner
# 4    Signature Real Estate Finder        Gregory Lynn
# 5                            None     Annette Kravick
# 6                 Douglas Elliman        Mia Morrison
# 7                            None   Geoffrey Aldridge
# 8                            None        Alexa Downie
# 9  Keller Williams Realty Profess      Andrew Pietrak
#
#                 buy_broker_name_1 buy_agent_name_2   buy_broker_name_2  RANK  \
# 0    Sotheby's Intl. Realty, Inc.             None                None     1
# 1          Luxury Partners Realty             None                None     2
# 2          Illustrated Properties             None                None     3
# 3   William Raveis Palm Beach LLC             None                None     4
# 4               Lynn Realty Group             None                None     5
# 5    The Keyes Company (Tequesta)             None                None     6
# 6              The Corcoran Group   Laura Johnston  The Corcoran Group     7
# 7                 Douglas Elliman             None                None     8
# 8  Champagne & Parisi Real Estate             None                None     9
# 9    Luxury Real Estate Group LLC             None                None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Residences AT Sloans Curve at 1 Sloans Curve D...
# 1    blue  Mizner Grand Condo at 400 SE 5th Ave #605 in B...
# 2    blue  Azure at 2720 Donald Ross Rd #510 in Palm Beac...
# 3    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #1...
# 4    blue  Oceans Edge Condo at 2600 S Ocean Blvd Unit 11...
# 5    blue  Passages OF Jupiter Island Condo at 19750 Beac...
# 6    blue  Twenty Six Hundred Condo at 2600 S Ocean 503 B...
# 7    blue  Ambassador II Corp at 2780 S Ocean Blvd #110 i...
# 8    blue  Mizner Court at 140 SE 5th Ave Ph 45 in Boca R...
# 9    blue  Ocean Towers at 2800 S Ocean Blvd Ph -C in Boc...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Residences AT Sloans Curve closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,100,000 to $14,900,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Palm Beach Gardens, Palm Beach, Boca Raton, Jupiter
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 89 condo sales totaling $61,248,125 million from Jan. 26th to Feb. 2nd. The previous week, brokers closed 64 condo sales totaling $25,800,000.
#
# Last week’s units sold for an average of $688,181, higher than the $403,182 average price from the previous week. The average price per square foot rose to $377 from $299, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,100,000.0 million to $14,900,000.0 million.
#
# Residences AT Sloans Curve at 1 Sloans Curve Dr in Palm Beach took the top spot with a $14,900,000.0 million closing. The sale closed at $2,807.0 per square foot.
#
# Spencer Schlager with Douglas Elliman, and None with None had the listing.
# Fern Fodiman with Sotheby's Intl. Realty, Inc., and None with None represented the buyer.
#
# Mizner Grand Condo at 400 SE 5th Ave #605 in Boca Raton, closed for the second highest amount, $4,425,000.0, or $1,062.0 per square foot.
#
# David Hall with Compass Florida LLC, and Sonia Hall with Compass Florida LLC had the listing.
# Todd David Lipsich with Luxury Partners Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_02032024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 26th to Feb. 2nd:
#
# Most Expensive
# Residences AT Sloans Curve, 1 Sloans Curve Dr, in Palm Beach | Price: $14,900,000 | $2,807 psf | Listing agents: Spencer Schlager with Douglas Elliman and None with None | Buyer's agents: Fern Fodiman with Sotheby's Intl. Realty, Inc. and None with None
#
# Least Expensive
# Ocean Towers, 2800 S Ocean Blvd Ph -C, in Boca Raton | Price: $1,100,000 | $772 psf | Listing agents: Denise Stewart with Keller Williams Realty Profess and Dennis Stewart with Keller Williams Realty Profess | Buyer's agents: Andrew Pietrak with Luxury Real Estate Group LLC and None with None
#
# Highest Price Per Square Foot
# Residences AT Sloans Curve, 1 Sloans Curve Dr, in Palm Beach | Price: $14,900,000 | $2,807 psf | Listing agents: Spencer Schlager with Douglas Elliman and None with None | Buyer's agents: Fern Fodiman with Sotheby's Intl. Realty, Inc. and None with None
#
# Lowest Price Per Square Foot
# Ocean Towers, 2800 S Ocean Blvd Ph -C, in Boca Raton | Price: $1,100,000 | $772 psf | Listing agents: Denise Stewart with Keller Williams Realty Profess and Dennis Stewart with Keller Williams Realty Profess | Buyer's agents: Andrew Pietrak with Luxury Real Estate Group LLC and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Palm-Beach/1-Sloans-Curve-Dr-33480/home/42435967
# Second priciest sale:  https://www.redfin.com/FL/Boca-Raton/400-SE-5th-Ave-33432/unit-605/home/42549878
# Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/2800-S-Ocean-Blvd-33432/unit-C/home/45428024
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/140-SE-5th-Ave-33432/unit-45/home/42322612
# Highest top ten psf:  https://www.redfin.com/FL/Palm-Beach/1-Sloans-Curve-Dr-33480/home/42435967
# Lowest top ten psf:  https://www.redfin.com/FL/Boca-Raton/2800-S-Ocean-Blvd-33432/unit-C/home/45428024

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Palm-Beach/1-Sloans-Curve-Dr-33480/home/42435967

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/400-SE-5th-Ave-33432/unit-605/home/42549878

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/2800-S-Ocean-Blvd-33432/unit-C/home/45428024

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/140-SE-5th-Ave-33432/unit-45/home/42322612

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Palm-Beach/1-Sloans-Curve-Dr-33480/home/42435967

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/2800-S-Ocean-Blvd-33432/unit-C/home/45428024

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 0  PAST SALE 2025-01-31   Condo/Co-op                  1 Sloans Curve Dr
# 1  PAST SALE 2025-01-30   Condo/Co-op                400 SE 5th Ave #605
# 2  PAST SALE 2025-01-28   Condo/Co-op           2720 Donald Ross Rd #510
# 3  PAST SALE 2025-01-29   Condo/Co-op                150 Bradley Pl #107
# 4  PAST SALE 2025-01-31   Condo/Co-op         2600 S Ocean Blvd Unit 11c
# 5  PAST SALE 2025-01-31   Condo/Co-op               19750 Beach Rd #5040
# 6  PAST SALE 2025-01-27   Condo/Co-op  2600 S Ocean 503 Blvd S Unit 503s
# 7  PAST SALE 2025-01-29   Condo/Co-op             2780 S Ocean Blvd #110
# 8  PAST SALE 2025-01-31   Condo/Co-op               140 SE 5th Ave Ph 45
# 9  PAST SALE 2025-01-31   Condo/Co-op            2800 S Ocean Blvd Ph -C
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  14900000.0   5.0
# 1          Boca Raton                FL             33432.0   4425000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0   3400000.0   3.0
# 3          Palm Beach                FL             33480.0   2887500.0   2.0
# 4          Boca Raton                FL             33432.0   2700000.0   3.0
# 5             Jupiter                FL             33469.0   2500000.0   3.0
# 6          Palm Beach                FL             33480.0   1585025.0   2.0
# 7          Palm Beach                FL             33480.0   1350000.0   2.0
# 8          Boca Raton                FL             33432.0   1320000.0   2.0
# 9          Boca Raton                FL             33432.0   1100000.0   2.0
#
#    BATHS                          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5        Residences AT Sloans Curve       5308.0   16405.0      1981.0
# 1    4.5                Mizner Grand Condo       4168.0       NaN      2000.0
# 2    3.0                             Azure       2759.0       NaN      2018.0
# 3    2.0         Palm Beach Biltmore Condo       1610.0       NaN      1926.0
# 4    2.5                 Oceans Edge Condo       2105.0       NaN      1975.0
# 5    3.5  Passages OF Jupiter Island Condo       2979.0       NaN      1982.0
# 6    2.0          Twenty Six Hundred Condo       1661.0       NaN      1977.0
# 7    2.0                Ambassador II Corp       1294.0  180559.0      1968.0
# 8    2.0                      Mizner Court       1706.0       NaN      1989.0
# 9    2.0                      Ocean Towers       1425.0       NaN      1973.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2807.0     3237.0   Sold
# 1             NaN         1062.0     5028.0   Sold
# 2             NaN         1232.0     2903.0   Sold
# 3             NaN         1793.0     2616.0   Sold
# 4             NaN         1283.0     2617.0   Sold
# 5             NaN          839.0     2933.0   Sold
# 6             NaN          954.0     2138.0   Sold
# 7             NaN         1043.0     2188.0   Sold
# 8             NaN          774.0     2957.0   Sold
# 9             NaN          772.0     1262.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...  Beaches MLS
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...  Beaches MLS
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11047415        N          Y  26.646645 -80.037547
# 1  RX-11041231        N          Y  26.344996 -80.076846
# 2  RX-11032639        N          Y  26.881072 -80.073865
# 3  RX-11014811        N          Y  26.720485 -80.041578
# 4  RX-11042990        N          Y  26.325405 -80.074687
# 5  RX-11013690        N          Y  26.967565 -80.080179
# 6  RX-11025737        N          Y  26.625982 -80.037408
# 7  RX-10968735        N          Y  26.619676 -80.037645
# 8  RX-11001639        N          Y  26.348269 -80.076619
# 9    F10466020        N          Y  26.323489 -80.075035
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/1-Sloans-...     Spencer Schlager
# 1  https://www.redfin.com/FL/Boca-Raton/400-SE-5t...           David Hall
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...           Laura Pope
# 3  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Christopher Leavitt
# 4  https://www.redfin.com/FL/Boca-Raton/2600-S-Oc...         Jill Glanzer
# 5  https://www.redfin.com/FL/Jupiter/19750-Beach-...       Fanning Hearon
# 6  https://www.redfin.com/FL/Palm-Beach/2600-S-Oc...      Victoria Brewer
# 7  https://www.redfin.com/FL/Palm-Beach/2780-S-Oc...       Benjamin Stein
# 8  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...     Alexander Golden
# 9  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...       Denise Stewart
#
#                list_broker_name_1 list_agent_name_2  \
# 0                 Douglas Elliman              None
# 1             Compass Florida LLC        Sonia Hall
# 2    Sotheby's Intl. Realty, Inc.              None
# 3                 Douglas Elliman              None
# 4    Signature Real Estate Finder  Matthew Maschler
# 5           K2 Realty, Inc. (NPB)              None
# 6                 Douglas Elliman       Howard Vine
# 7    Sotheby's Intl. Realty, Inc.              None
# 8            Compass Florida, LLC              None
# 9  Keller Williams Realty Profess    Dennis Stewart
#
#                list_broker_name_2    buy_agent_name_1  \
# 0                            None        Fern Fodiman
# 1             Compass Florida LLC  Todd David Lipsich
# 2                            None       Kelly Schmidt
# 3                            None       Shirley Wyner
# 4    Signature Real Estate Finder        Gregory Lynn
# 5                            None     Annette Kravick
# 6                 Douglas Elliman        Mia Morrison
# 7                            None   Geoffrey Aldridge
# 8                            None        Alexa Downie
# 9  Keller Williams Realty Profess      Andrew Pietrak
#
#                 buy_broker_name_1 buy_agent_name_2   buy_broker_name_2  RANK  \
# 0    Sotheby's Intl. Realty, Inc.             None                None     1
# 1          Luxury Partners Realty             None                None     2
# 2          Illustrated Properties             None                None     3
# 3   William Raveis Palm Beach LLC             None                None     4
# 4               Lynn Realty Group             None                None     5
# 5    The Keyes Company (Tequesta)             None                None     6
# 6              The Corcoran Group   Laura Johnston  The Corcoran Group     7
# 7                 Douglas Elliman             None                None     8
# 8  Champagne & Parisi Real Estate             None                None     9
# 9    Luxury Real Estate Group LLC             None                None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Residences AT Sloans Curve at 1 Sloans Curve D...
# 1    blue  Mizner Grand Condo at 400 SE 5th Ave #605 in B...
# 2    blue  Azure at 2720 Donald Ross Rd #510 in Palm Beac...
# 3    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #1...
# 4    blue  Oceans Edge Condo at 2600 S Ocean Blvd Unit 11...
# 5    blue  Passages OF Jupiter Island Condo at 19750 Beac...
# 6    blue  Twenty Six Hundred Condo at 2600 S Ocean 503 B...
# 7    blue  Ambassador II Corp at 2780 S Ocean Blvd #110 i...
# 8    blue  Mizner Court at 140 SE 5th Ave Ph 45 in Boca R...
# 9    blue  Ocean Towers at 2800 S Ocean Blvd Ph -C in Boc...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 12, 1) ## List (Earlier) date
date2 = datetime(2025, 1, 30) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 60

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    2807.0
# 1    1062.0
# 2    1232.0
# 3    1793.0
# 4    1283.0
# 5     839.0
# 6     954.0
# 7    1043.0
# 8     774.0
# 9     772.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                          ADDRESS        PRICE  \
# 0 2025-01-31                  1 Sloans Curve Dr in Palm Beach  $14,900,000
# 1 2025-01-30                400 SE 5th Ave #605 in Boca Raton   $4,425,000
# 2 2025-01-28   2720 Donald Ross Rd #510 in Palm Beach Gardens   $3,400,000
# 3 2025-01-29                150 Bradley Pl #107 in Palm Beach   $2,887,500
# 4 2025-01-31         2600 S Ocean Blvd Unit 11c in Boca Raton   $2,700,000
# 5 2025-01-31                  19750 Beach Rd #5040 in Jupiter   $2,500,000
# 6 2025-01-27  2600 S Ocean 503 Blvd S Unit 503s in Palm Beach   $1,585,025
# 7 2025-01-29             2780 S Ocean Blvd #110 in Palm Beach   $1,350,000
# 8 2025-01-31               140 SE 5th Ave Ph 45 in Boca Raton   $1,320,000
# 9 2025-01-31            2800 S Ocean Blvd Ph -C in Boca Raton   $1,100,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    5    6.5       5,308       1981        $2,807  Beaches MLS  RX-11047415
# 1    3    4.5       4,168       2000        $1,062  Beaches MLS  RX-11041231
# 2    3    3.0       2,759       2018        $1,232  Beaches MLS  RX-11032639
# 3    2    2.0       1,610       1926        $1,793  Beaches MLS  RX-11014811
# 4    3    2.5       2,105       1975        $1,283  Beaches MLS  RX-11042990
# 5    3    3.5       2,979       1982          $839  Beaches MLS  RX-11013690
# 6    2    2.0       1,661       1977          $954  Beaches MLS  RX-11025737
# 7    2    2.0       1,294       1968        $1,043  Beaches MLS  RX-10968735
# 8    2    2.0       1,706       1989          $774  Beaches MLS  RX-11001639
# 9    2    2.0       1,425       1973          $772  Beaches MLS    F10466020
#
#                                         LISTING INFO  \
# 0               Spencer Schlager Douglas Elliman
# 1  David Hall Compass Florida LLC Sonia Hall Comp...
# 2        Laura Pope Sotheby's Intl. Realty, Inc.
# 3            Christopher Leavitt Douglas Elliman
# 4  Jill Glanzer Signature Real Estate Finder Matt...
# 5           Fanning Hearon K2 Realty, Inc. (NPB)
# 6  Victoria Brewer Douglas Elliman Howard Vine Do...
# 7    Benjamin Stein Sotheby's Intl. Realty, Inc.
# 8          Alexander Golden Compass Florida, LLC
# 9  Denise Stewart Keller Williams Realty Profess ...
#
#                                          BUYING INFO
# 0      Fern Fodiman Sotheby's Intl. Realty, Inc.
# 1      Todd David Lipsich Luxury Partners Realty
# 2           Kelly Schmidt Illustrated Properties
# 3    Shirley Wyner William Raveis Palm Beach LLC
# 4                 Gregory Lynn Lynn Realty Group
# 5   Annette Kravick The Keyes Company (Tequesta)
# 6  Mia Morrison The Corcoran Group Laura Johnston...
# 7              Geoffrey Aldridge Douglas Elliman
# 8    Alexa Downie Champagne & Parisi Real Estate
# 9    Andrew Pietrak Luxury Real Estate Group LLC
