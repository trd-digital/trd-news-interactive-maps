# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Jan. 12th Jan. 19th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 1  PAST SALE  January-14-2025   Condo/Co-op  15710 E Waterside Cir #106
#
#       CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ...  \
# 1  Sunrise                FL             33326.0  320000.0   3.0    2.5  ...
#
#   STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Sunrise/15710-E-Wate...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED  LATITUDE  LONGITUDE
# 1  RX-11042199         N          Y  26.11999 -80.358689
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# df2 = df[(df['SOLD DATE'] > '2024-12-29') & (df['SOLD DATE'] < '2025-01-07')]

# %%
df2 = df

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-01-15    28
# 2025-01-14    27
# 2025-01-17    24
# 2025-01-16    20
# 2025-01-13    19
# 2025-01-20     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 47  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 41  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 66  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 59  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 61  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 97  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 17  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 15  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 37  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 14  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                      CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 47        Fort Lauderdale                FL             33305.0  2875000.0
# 41  Lauderdale By The Sea                FL             33062.0  2550000.0
# 66       Hallandale Beach                FL             33009.0  1999999.0
# 59              Hollywood                FL             33019.0  1345000.0
# 61          Pompano Beach                FL             33062.0  1175000.0
# 97        Fort Lauderdale                FL             33301.0  1030000.0
# 17        Fort Lauderdale                FL             33308.0   955000.0
# 15        Fort Lauderdale                FL             33301.0   950000.0
# 37          Pompano Beach                FL             33062.0   900000.0
# 14  Lauderdale By The Sea                FL             33308.0   850000.0
#
#     BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 47   2.0    3.0  ...   Sold                         NaN
# 41   3.0    4.5  ...   Sold                         NaN
# 66   3.0    3.0  ...   Sold                         NaN
# 59   3.0    3.5  ...   Sold                         NaN
# 61   2.0    2.5  ...   Sold                         NaN
# 97   2.0    2.5  ...   Sold                         NaN
# 17   3.0    2.5  ...   Sold                         NaN
# 15   3.0    2.0  ...   Sold                         NaN
# 37   2.0    2.5  ...   Sold                         NaN
# 14   2.0    2.0  ...   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 47                       NaN
# 41                       NaN
# 66                       NaN
# 59                       NaN
# 61                       NaN
# 97                       NaN
# 17                       NaN
# 15                       NaN
# 37                       NaN
# 14                       NaN
#
#                                                   URL       SOURCE  \
# 47  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 41  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Beaches MLS
# 66  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 59  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 61  https://www.redfin.com/FL/Pompano-Beach/812-N-...  Beaches MLS
# 97  https://www.redfin.com/FL/Fort-Lauderdale/400-...       MARMLS
# 17  https://www.redfin.com/FL/Fort-Lauderdale/3750...       MARMLS
# 15  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS
# 37  https://www.redfin.com/FL/Pompano-Beach/3419-S...  Beaches MLS
# 14  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 47    F10471227         N          Y  26.157113 -80.100623
# 41    F10468069         N          Y  26.210753 -80.092365
# 66    A11647949         N          Y  25.984911 -80.118344
# 59    A11683701         N          Y  25.993975 -80.117768
# 61  RX-11030685         N          Y  26.245355 -80.086922
# 97    A11611644         N          Y  26.126738 -80.121826
# 17    A11705869         N          Y  26.174073 -80.098173
# 15    F10472447         N          Y  26.120405 -80.139762
# 37    F10473434         N          Y  26.226554 -80.090419
# 14    F10469042         N          Y  26.199954 -80.094697
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 1  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 2  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 3  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 4  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 5  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 6  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 7  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 8  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 9  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33305.0  2875000.0
# 1  Lauderdale By The Sea                FL             33062.0  2550000.0
# 2       Hallandale Beach                FL             33009.0  1999999.0
# 3              Hollywood                FL             33019.0  1345000.0
# 4          Pompano Beach                FL             33062.0  1175000.0
# 5        Fort Lauderdale                FL             33301.0  1030000.0
# 6        Fort Lauderdale                FL             33308.0   955000.0
# 7        Fort Lauderdale                FL             33301.0   950000.0
# 8          Pompano Beach                FL             33062.0   900000.0
# 9  Lauderdale By The Sea                FL             33308.0   850000.0
#
#    BEDS  BATHS  ...  LONGITUDE  \
# 0   2.0    3.0  ... -80.100623
# 1   3.0    4.5  ... -80.092365
# 2   3.0    3.0  ... -80.118344
# 3   3.0    3.5  ... -80.117768
# 4   2.0    2.5  ... -80.086922
# 5   2.0    2.5  ... -80.121826
# 6   3.0    2.5  ... -80.098173
# 7   3.0    2.0  ... -80.139762
# 8   2.0    2.5  ... -80.090419
# 9   2.0    2.0  ... -80.094697
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Maritza Meza Giusti
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Thomas Michael LaPuma
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...              Mary Mass
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...           Silvana Sosa
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...       Peter Pellegrini
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...      Jennifer Ginsburg
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...        Mauro Rodriguez
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...           Rachel Buemi
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...         Evelyn Bateman
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...         Lori El Sanadi
#
#              list_broker_name_1  list_agent_name_2  \
# 0        Coldwell Banker Realty               None
# 1  Florida Luxurious Properties     Maritza Gaitan
# 2      Related ISG Realty, LLC.               None
# 3               Florida.Doc Inc               None
# 4       Pickle Ball Real Estate               None
# 5          Freebird Real Estate               None
# 6       Partnership Realty Inc.               None
# 7     D'Angelo Realty Group LLC               None
# 8                EXP Realty LLC               None
# 9        Coldwell Banker Realty               None
#
#            list_broker_name_2  buy_agent_name_1  \
# 0                        None        Adam Elmer
# 1  Las Olas R E Professionals     Dany Flanders
# 2                        None    Leslie Sanchez
# 3                        None      David Koster
# 4                        None      Taylar Shinn
# 5                        None       glen Primak
# 6                        None   Mauro Rodriguez
# 7                        None       Bobbi Ocean
# 8                        None    Evelyn Bateman
# 9                        None      Fernando Rey
#
#                     buy_broker_name_1  buy_agent_name_2  buy_broker_name_2
# 0      Fortune International Realty B              None               None
# 1         RE/MAX Consultants Realty 1              None               None
# 2  One Sotheby's International Realty              None               None
# 3  One Sotheby's International Realty              None               None
# 4       Charles Rutenberg Realty Fort              None               None
# 5              The Agency Florida LLC              None               None
# 6             Partnership Realty Inc.              None               None
# 7       Galleria International Realty              None               None
# 8                      EXP Realty LLC              None               None
# 9                 Post and Post, Inc.              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 119

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $357,750

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $279

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $42,572,247

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Broward
# Input Previous Week Condo Sales Total (number units sold):
# 76
# Input Previous Week Condo Average Sales Price:
# 326342
# Input Previous Week Condo Average PSF:
# 281
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 34_500_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33305.0  2875000.0   2.0
#
#    BATHS                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.0  Auberge Beach Residences       1895.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10471227
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100623
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Maritza Meza Giusti
#
#        list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Coldwell Banker Realty              None               None
#
#   buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer  Fortune International Realty B             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 1  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 2  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 3  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 4  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 5  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 6  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 7  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 8  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 9  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33305.0  2875000.0
# 1  Lauderdale By The Sea                FL             33062.0  2550000.0
# 2       Hallandale Beach                FL             33009.0  1999999.0
# 3              Hollywood                FL             33019.0  1345000.0
# 4          Pompano Beach                FL             33062.0  1175000.0
# 5        Fort Lauderdale                FL             33301.0  1030000.0
# 6        Fort Lauderdale                FL             33308.0   955000.0
# 7        Fort Lauderdale                FL             33301.0   950000.0
# 8          Pompano Beach                FL             33062.0   900000.0
# 9  Lauderdale By The Sea                FL             33308.0   850000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   2.0    3.0   Auberge Beach Residences       1895.0       NaN      2018.0
# 1   3.0    4.5              Aquazul Condo       3029.0       NaN      2005.0
# 2   3.0    3.0       BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   2.0    2.5       Seapointe OF Pompano       2320.0       NaN      1983.0
# 5   2.0    2.5       LANDINGS AT LAS OLAS       1797.0       NaN      2006.0
# 6   3.0    2.5  REGENCY TOWER SOUTH CONDO       2080.0       NaN      1970.0
# 7   3.0    2.0         350 Las Olas Place       1650.0       NaN      2005.0
# 8   2.0    2.5                Beach Haven       1360.0       NaN      1985.0
# 9   2.0    2.0     Sea Ranch Club A Condo       1950.0       NaN      1976.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
# 1             NaN          842.0     3197.0   Sold
# 2             NaN          969.0     2417.0   Sold
# 3             NaN          636.0     2162.0   Sold
# 4             NaN          506.0     1466.0   Sold
# 5             NaN          573.0     1330.0   Sold
# 6             NaN          459.0     2027.0   Sold
# 7             NaN          576.0     1826.0   Sold
# 8             NaN          662.0      700.0   Sold
# 9             NaN          436.0     1630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Beaches MLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...       MARMLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...  Beaches MLS
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10471227        N          Y  26.157113 -80.100623
# 1    F10468069        N          Y  26.210753 -80.092365
# 2    A11647949        N          Y  25.984911 -80.118344
# 3    A11683701        N          Y  25.993975 -80.117768
# 4  RX-11030685        N          Y  26.245355 -80.086922
# 5    A11611644        N          Y  26.126738 -80.121826
# 6    A11705869        N          Y  26.174073 -80.098173
# 7    F10472447        N          Y  26.120405 -80.139762
# 8    F10473434        N          Y  26.226554 -80.090419
# 9    F10469042        N          Y  26.199954 -80.094697
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Maritza Meza Giusti
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Thomas Michael LaPuma
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...              Mary Mass
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...           Silvana Sosa
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...       Peter Pellegrini
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...      Jennifer Ginsburg
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...        Mauro Rodriguez
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...           Rachel Buemi
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...         Evelyn Bateman
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...         Lori El Sanadi
#
#              list_broker_name_1 list_agent_name_2          list_broker_name_2  \
# 0        Coldwell Banker Realty              None                        None
# 1  Florida Luxurious Properties    Maritza Gaitan  Las Olas R E Professionals
# 2      Related ISG Realty, LLC.              None                        None
# 3               Florida.Doc Inc              None                        None
# 4       Pickle Ball Real Estate              None                        None
# 5          Freebird Real Estate              None                        None
# 6       Partnership Realty Inc.              None                        None
# 7     D'Angelo Realty Group LLC              None                        None
# 8                EXP Realty LLC              None                        None
# 9        Coldwell Banker Realty              None                        None
#
#   buy_agent_name_1                   buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer      Fortune International Realty B             None
# 1    Dany Flanders         RE/MAX Consultants Realty 1             None
# 2   Leslie Sanchez  One Sotheby's International Realty             None
# 3     David Koster  One Sotheby's International Realty             None
# 4     Taylar Shinn       Charles Rutenberg Realty Fort             None
# 5      glen Primak              The Agency Florida LLC             None
# 6  Mauro Rodriguez             Partnership Realty Inc.             None
# 7      Bobbi Ocean       Galleria International Realty             None
# 8   Evelyn Bateman                      EXP Realty LLC             None
# 9     Fernando Rey                 Post and Post, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ca965b97935f413eae5bf52e7dd2397 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Jan. 12th — Jan. 19th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ca965b97935f413eae5bf52e7dd2397&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4ca965b97935f413eae5bf52e7dd2397 = L.map(
#                 &quot;map_4ca965b97935f413eae5bf52e7dd2397&quot;,
#                 {
#                     center: [26.14874738739496, -80.18421564789917],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_69ae491ffbb3caa1542d638c17b66340 = L.featureGroup(
#                 {}
#             ).addTo(map_4ca965b97935f413eae5bf52e7dd2397);
#
#
#             var marker_bc4670027684e156b765a16bb7714e7b = L.marker(
#                 [26.1571129, -80.1006235],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_69ae491ffbb3caa1542d638c17b66340);
#
#
#             var icon_4a661807083dbbf4d53318d6af707c10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bc4670027684e156b765a16bb7714e7b.setIcon(icon_4a661807083dbbf4d53318d6af707c10);
#
#
#         var popup_4fdd6e43f0212190701d2708ce28edbd = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b3ae005e107334e95595b8282fecd25f = $(`&lt;div id=&quot;html_b3ae005e107334e95595b8282fecd25f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2200 N Ocean Blvd Unit N704&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,875,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,517.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;1,895.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_4fdd6e43f0212190701d2708ce28edbd.setContent(html_b3ae005e107334e95595b8282fecd25f);
#
#
#
#         marker_bc4670027684e156b765a16bb7714e7b.bindPopup(popup_4fdd6e43f0212190701d2708ce28edbd)
#         ;
#
#
#
#
#             var feature_group_297fd0b1bbb398d881c8ff1ec3cd2eda = L.featureGroup(
#                 {}
#             ).addTo(map_4ca965b97935f413eae5bf52e7dd2397);
#
#
#             var marker_437a53b1d905c4062cc5e612b00422cd = L.marker(
#                 [26.210753, -80.0923649],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_297fd0b1bbb398d881c8ff1ec3cd2eda);
#
#
#             var icon_abe7c7bbc72566f63a9bd82394032a8a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_437a53b1d905c4062cc5e612b00422cd.setIcon(icon_abe7c7bbc72566f63a9bd82394032a8a);
#
#
#         var popup_2fbe4ab14c15992abfe7d65267edfaf1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_185d6dc66e8b754759c1c0cfa3ec46fc = $(`&lt;div id=&quot;html_185d6dc66e8b754759c1c0cfa3ec46fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1600 S Ocean Blvd #401&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,550,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$842.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,029.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2005.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_2fbe4ab14c15992abfe7d65267edfaf1.setContent(html_185d6dc66e8b754759c1c0cfa3ec46fc);
#
#
#
#         marker_437a53b1d905c4062cc5e612b00422cd.bindPopup(popup_2fbe4ab14c15992abfe7d65267edfaf1)
#         ;
#
#
#
#
#             var marker_cdb2a10b29be8243a0a3de7580a23a1f = L.marker(
#                 [25.9849114, -80.1183443],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_297fd0b1bbb398d881c8ff1ec3cd2eda);
#
#
#             var icon_41f80f1ad110707075d743655fc98698 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cdb2a10b29be8243a0a3de7580a23a1f.setIcon(icon_41f80f1ad110707075d743655fc98698);
#
#
#         var popup_b487ebd51d4642781654b87bcd48ae26 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_fc2c81659a0966b00356ee1572bc98ca =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33305.0  2875000.0   2.0
#
#    BATHS                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.0  Auberge Beach Residences       1895.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10471227
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100623
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Maritza Meza Giusti
#
#        list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Coldwell Banker Realty              None               None
#
#   buy_agent_name_1               buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer  Fortune International Realty B             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_01202024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Auberge Beach Residences at 2200 N Ocean Blvd Unit N704 in Fort Lauderdale'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 1  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 2  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 3  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 4  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 5  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 6  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 7  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 8  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 9  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33305.0  2875000.0
# 1  Lauderdale By The Sea                FL             33062.0  2550000.0
# 2       Hallandale Beach                FL             33009.0  1999999.0
# 3              Hollywood                FL             33019.0  1345000.0
# 4          Pompano Beach                FL             33062.0  1175000.0
# 5        Fort Lauderdale                FL             33301.0  1030000.0
# 6        Fort Lauderdale                FL             33308.0   955000.0
# 7        Fort Lauderdale                FL             33301.0   950000.0
# 8          Pompano Beach                FL             33062.0   900000.0
# 9  Lauderdale By The Sea                FL             33308.0   850000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   2.0    3.0   Auberge Beach Residences       1895.0       NaN      2018.0
# 1   3.0    4.5              Aquazul Condo       3029.0       NaN      2005.0
# 2   3.0    3.0       BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   2.0    2.5       Seapointe OF Pompano       2320.0       NaN      1983.0
# 5   2.0    2.5       LANDINGS AT LAS OLAS       1797.0       NaN      2006.0
# 6   3.0    2.5  REGENCY TOWER SOUTH CONDO       2080.0       NaN      1970.0
# 7   3.0    2.0         350 Las Olas Place       1650.0       NaN      2005.0
# 8   2.0    2.5                Beach Haven       1360.0       NaN      1985.0
# 9   2.0    2.0     Sea Ranch Club A Condo       1950.0       NaN      1976.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
# 1             NaN          842.0     3197.0   Sold
# 2             NaN          969.0     2417.0   Sold
# 3             NaN          636.0     2162.0   Sold
# 4             NaN          506.0     1466.0   Sold
# 5             NaN          573.0     1330.0   Sold
# 6             NaN          459.0     2027.0   Sold
# 7             NaN          576.0     1826.0   Sold
# 8             NaN          662.0      700.0   Sold
# 9             NaN          436.0     1630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Beaches MLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...       MARMLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...  Beaches MLS
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10471227        N          Y  26.157113 -80.100623
# 1    F10468069        N          Y  26.210753 -80.092365
# 2    A11647949        N          Y  25.984911 -80.118344
# 3    A11683701        N          Y  25.993975 -80.117768
# 4  RX-11030685        N          Y  26.245355 -80.086922
# 5    A11611644        N          Y  26.126738 -80.121826
# 6    A11705869        N          Y  26.174073 -80.098173
# 7    F10472447        N          Y  26.120405 -80.139762
# 8    F10473434        N          Y  26.226554 -80.090419
# 9    F10469042        N          Y  26.199954 -80.094697
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Maritza Meza Giusti
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Thomas Michael LaPuma
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...              Mary Mass
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...           Silvana Sosa
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...       Peter Pellegrini
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...      Jennifer Ginsburg
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...        Mauro Rodriguez
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...           Rachel Buemi
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...         Evelyn Bateman
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...         Lori El Sanadi
#
#              list_broker_name_1 list_agent_name_2          list_broker_name_2  \
# 0        Coldwell Banker Realty              None                        None
# 1  Florida Luxurious Properties    Maritza Gaitan  Las Olas R E Professionals
# 2      Related ISG Realty, LLC.              None                        None
# 3               Florida.Doc Inc              None                        None
# 4       Pickle Ball Real Estate              None                        None
# 5          Freebird Real Estate              None                        None
# 6       Partnership Realty Inc.              None                        None
# 7     D'Angelo Realty Group LLC              None                        None
# 8                EXP Realty LLC              None                        None
# 9        Coldwell Banker Realty              None                        None
#
#   buy_agent_name_1                   buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer      Fortune International Realty B             None
# 1    Dany Flanders         RE/MAX Consultants Realty 1             None
# 2   Leslie Sanchez  One Sotheby's International Realty             None
# 3     David Koster  One Sotheby's International Realty             None
# 4     Taylar Shinn       Charles Rutenberg Realty Fort             None
# 5      glen Primak              The Agency Florida LLC             None
# 6  Mauro Rodriguez             Partnership Realty Inc.             None
# 7      Bobbi Ocean       Galleria International Realty             None
# 8   Evelyn Bateman                      EXP Realty LLC             None
# 9     Fernando Rey                 Post and Post, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  Auberge Beach Residences at 2200 N Ocean Blvd ...
# 1  Aquazul Condo at 1600 S Ocean Blvd #401 in Lau...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #1101 ...
# 3  OCEAN PALMS CONDO at 3101 S Ocean Dr #1005 in ...
# 4  Seapointe OF Pompano at 812 N North Ocean Blvd...
# 5  LANDINGS AT LAS OLAS at 400 Hendricks Isle #40...
# 6  REGENCY TOWER SOUTH CONDO at 3750 Galt Ocean D...
# 7  350 Las Olas Place at 350 SE 2nd St #2670 in F...
# 8  Beach Haven at 3419 SE 8th St #10 in Pompano B...
# 9  Sea Ranch Club A Condo at 5100 N Ocean Blvd #1...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Auberge Beach Residences closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $850,000 to $2,875,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hallandale Beach, Pompano Beach, Fort Lauderdale, Hollywood, Lauderdale By The Sea
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 119 condo sales totaling $42,572,247 million from Jan. 12th to Jan. 19th. The previous week, brokers closed 76 condo sales totaling $34,500,000.
#
# Last week’s units sold for an average of $357,750, higher than the $326,342 average price from the previous week. The average price per square foot fell to $279 from $281, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $850,000.0 million to $2,875,000.0 million.
#
# Auberge Beach Residences at 2200 N Ocean Blvd Unit N704 in Fort Lauderdale took the top spot with a $2,875,000.0 million closing. The sale closed at $1,517.0 per square foot.
#
# Maritza Meza Giusti with Coldwell Banker Realty, and None with None had the listing.
# Adam Elmer with Fortune International Realty B, and None with None represented the buyer.
#
# Aquazul Condo at 1600 S Ocean Blvd #401 in Lauderdale By The Sea, closed for the second highest amount, $2,550,000.0, or $842.0 per square foot.
#
# Thomas Michael LaPuma with Florida Luxurious Properties, and Maritza Gaitan with Las Olas R E Professionals had the listing.
# Dany Flanders with RE/MAX Consultants Realty 1, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_01202024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 12th to Jan. 19th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 1  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 2  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 3  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 4  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 5  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 6  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 7  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 8  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 9  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33305.0  2875000.0
# 1  Lauderdale By The Sea                FL             33062.0  2550000.0
# 2       Hallandale Beach                FL             33009.0  1999999.0
# 3              Hollywood                FL             33019.0  1345000.0
# 4          Pompano Beach                FL             33062.0  1175000.0
# 5        Fort Lauderdale                FL             33301.0  1030000.0
# 6        Fort Lauderdale                FL             33308.0   955000.0
# 7        Fort Lauderdale                FL             33301.0   950000.0
# 8          Pompano Beach                FL             33062.0   900000.0
# 9  Lauderdale By The Sea                FL             33308.0   850000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   2.0    3.0   Auberge Beach Residences       1895.0       NaN      2018.0
# 1   3.0    4.5              Aquazul Condo       3029.0       NaN      2005.0
# 2   3.0    3.0       BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   2.0    2.5       Seapointe OF Pompano       2320.0       NaN      1983.0
# 5   2.0    2.5       LANDINGS AT LAS OLAS       1797.0       NaN      2006.0
# 6   3.0    2.5  REGENCY TOWER SOUTH CONDO       2080.0       NaN      1970.0
# 7   3.0    2.0         350 Las Olas Place       1650.0       NaN      2005.0
# 8   2.0    2.5                Beach Haven       1360.0       NaN      1985.0
# 9   2.0    2.0     Sea Ranch Club A Condo       1950.0       NaN      1976.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
# 1             NaN          842.0     3197.0   Sold
# 2             NaN          969.0     2417.0   Sold
# 3             NaN          636.0     2162.0   Sold
# 4             NaN          506.0     1466.0   Sold
# 5             NaN          573.0     1330.0   Sold
# 6             NaN          459.0     2027.0   Sold
# 7             NaN          576.0     1826.0   Sold
# 8             NaN          662.0      700.0   Sold
# 9             NaN          436.0     1630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Beaches MLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...       MARMLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...  Beaches MLS
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10471227        N          Y  26.157113 -80.100623
# 1    F10468069        N          Y  26.210753 -80.092365
# 2    A11647949        N          Y  25.984911 -80.118344
# 3    A11683701        N          Y  25.993975 -80.117768
# 4  RX-11030685        N          Y  26.245355 -80.086922
# 5    A11611644        N          Y  26.126738 -80.121826
# 6    A11705869        N          Y  26.174073 -80.098173
# 7    F10472447        N          Y  26.120405 -80.139762
# 8    F10473434        N          Y  26.226554 -80.090419
# 9    F10469042        N          Y  26.199954 -80.094697
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Maritza Meza Giusti
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Thomas Michael LaPuma
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...              Mary Mass
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...           Silvana Sosa
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...       Peter Pellegrini
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...      Jennifer Ginsburg
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...        Mauro Rodriguez
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...           Rachel Buemi
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...         Evelyn Bateman
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...         Lori El Sanadi
#
#              list_broker_name_1 list_agent_name_2          list_broker_name_2  \
# 0        Coldwell Banker Realty              None                        None
# 1  Florida Luxurious Properties    Maritza Gaitan  Las Olas R E Professionals
# 2      Related ISG Realty, LLC.              None                        None
# 3               Florida.Doc Inc              None                        None
# 4       Pickle Ball Real Estate              None                        None
# 5          Freebird Real Estate              None                        None
# 6       Partnership Realty Inc.              None                        None
# 7     D'Angelo Realty Group LLC              None                        None
# 8                EXP Realty LLC              None                        None
# 9        Coldwell Banker Realty              None                        None
#
#   buy_agent_name_1                   buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer      Fortune International Realty B             None
# 1    Dany Flanders         RE/MAX Consultants Realty 1             None
# 2   Leslie Sanchez  One Sotheby's International Realty             None
# 3     David Koster  One Sotheby's International Realty             None
# 4     Taylar Shinn       Charles Rutenberg Realty Fort             None
# 5      glen Primak              The Agency Florida LLC             None
# 6  Mauro Rodriguez             Partnership Realty Inc.             None
# 7      Bobbi Ocean       Galleria International Realty             None
# 8   Evelyn Bateman                      EXP Realty LLC             None
# 9     Fernando Rey                 Post and Post, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  Auberge Beach Residences at 2200 N Ocean Blvd ...
# 1  Aquazul Condo at 1600 S Ocean Blvd #401 in Lau...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #1101 ...
# 3  OCEAN PALMS CONDO at 3101 S Ocean Dr #1005 in ...
# 4  Seapointe OF Pompano at 812 N North Ocean Blvd...
# 5  LANDINGS AT LAS OLAS at 400 Hendricks Isle #40...
# 6  REGENCY TOWER SOUTH CONDO at 3750 Galt Ocean D...
# 7  350 Las Olas Place at 350 SE 2nd St #2670 in F...
# 8  Beach Haven at 3419 SE 8th St #10 in Pompano B...
# 9  Sea Ranch Club A Condo at 5100 N Ocean Blvd #1...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Auberge Beach Residences closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $850,000 to $2,875,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hallandale Beach, Pompano Beach, Fort Lauderdale, Hollywood, Lauderdale By The Sea
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 119 condo sales totaling $42,572,247 million from Jan. 12th to Jan. 19th. The previous week, brokers closed 76 condo sales totaling $34,500,000.
#
# Last week’s units sold for an average of $357,750, higher than the $326,342 average price from the previous week. The average price per square foot fell to $279 from $281, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $850,000.0 million to $2,875,000.0 million.
#
# Auberge Beach Residences at 2200 N Ocean Blvd Unit N704 in Fort Lauderdale took the top spot with a $2,875,000.0 million closing. The sale closed at $1,517.0 per square foot.
#
# Maritza Meza Giusti with Coldwell Banker Realty, and None with None had the listing.
# Adam Elmer with Fortune International Realty B, and None with None represented the buyer.
#
# Aquazul Condo at 1600 S Ocean Blvd #401 in Lauderdale By The Sea, closed for the second highest amount, $2,550,000.0, or $842.0 per square foot.
#
# Thomas Michael LaPuma with Florida Luxurious Properties, and Maritza Gaitan with Las Olas R E Professionals had the listing.
# Dany Flanders with RE/MAX Consultants Realty 1, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_01202024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 12th to Jan. 19th:
#
# Most Expensive
# Auberge Beach Residences, 2200 N Ocean Blvd Unit N704, in Fort Lauderdale | Price: $2,875,000 | $1,517 psf | Listing agents: Maritza Meza Giusti with Coldwell Banker Realty and None with None | Buyer's agents: Adam Elmer with Fortune International Realty B and None with None
#
# Least Expensive
# Sea Ranch Club A Condo, 5100 N Ocean Blvd #1118, in Lauderdale By The Sea | Price: $850,000 | $436 psf | Listing agents: Lori El Sanadi with Coldwell Banker Realty and None with None | Buyer's agents: Fernando Rey with Post and Post, Inc. and None with None
#
# Highest Price Per Square Foot
# Auberge Beach Residences, 2200 N Ocean Blvd Unit N704, in Fort Lauderdale | Price: $2,875,000 | $1,517 psf | Listing agents: Maritza Meza Giusti with Coldwell Banker Realty and None with None | Buyer's agents: Adam Elmer with Fortune International Realty B and None with None
#
# Lowest Price Per Square Foot
# Sea Ranch Club A Condo, 5100 N Ocean Blvd #1118, in Lauderdale By The Sea | Price: $850,000 | $436 psf | Listing agents: Lori El Sanadi with Coldwell Banker Realty and None with None | Buyer's agents: Fernando Rey with Post and Post, Inc. and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N704/home/148713443
# Second priciest sale:  https://www.redfin.com/FL/Pompano-Beach/1600-S-Ocean-Blvd-33062/unit-401/home/42036986
# Cheapest top ten sale:  https://www.redfin.com/FL/Lauderdale-by-the-Sea/5100-N-Ocean-Blvd-33308/unit-1118/home/41702906
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Pompano-Beach/3419-SE-8th-St-33062/unit-10/home/41698265
# Highest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N704/home/148713443
# Lowest top ten psf:  https://www.redfin.com/FL/Lauderdale-by-the-Sea/5100-N-Ocean-Blvd-33308/unit-1118/home/41702906

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N704/home/148713443

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Pompano-Beach/1600-S-Ocean-Blvd-33062/unit-401/home/42036986

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Lauderdale-by-the-Sea/5100-N-Ocean-Blvd-33308/unit-1118/home/41702906

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Pompano-Beach/3419-SE-8th-St-33062/unit-10/home/41698265

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N704/home/148713443

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Lauderdale-by-the-Sea/5100-N-Ocean-Blvd-33308/unit-1118/home/41702906

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-16   Condo/Co-op  2200 N Ocean Blvd Unit N704
# 1  PAST SALE 2025-01-14   Condo/Co-op       1600 S Ocean Blvd #401
# 2  PAST SALE 2025-01-13   Condo/Co-op        1830 S Ocean Dr #1101
# 3  PAST SALE 2025-01-15   Condo/Co-op        3101 S Ocean Dr #1005
# 4  PAST SALE 2025-01-15   Condo/Co-op  812 N North Ocean Blvd #405
# 5  PAST SALE 2025-01-15   Condo/Co-op      400 Hendricks Isle #402
# 6  PAST SALE 2025-01-14   Condo/Co-op      3750 Galt Ocean Dr #711
# 7  PAST SALE 2025-01-16   Condo/Co-op          350 SE 2nd St #2670
# 8  PAST SALE 2025-01-17   Condo/Co-op           3419 SE 8th St #10
# 9  PAST SALE 2025-01-14   Condo/Co-op      5100 N Ocean Blvd #1118
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33305.0  2875000.0
# 1  Lauderdale By The Sea                FL             33062.0  2550000.0
# 2       Hallandale Beach                FL             33009.0  1999999.0
# 3              Hollywood                FL             33019.0  1345000.0
# 4          Pompano Beach                FL             33062.0  1175000.0
# 5        Fort Lauderdale                FL             33301.0  1030000.0
# 6        Fort Lauderdale                FL             33308.0   955000.0
# 7        Fort Lauderdale                FL             33301.0   950000.0
# 8          Pompano Beach                FL             33062.0   900000.0
# 9  Lauderdale By The Sea                FL             33308.0   850000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   2.0    3.0   Auberge Beach Residences       1895.0       NaN      2018.0
# 1   3.0    4.5              Aquazul Condo       3029.0       NaN      2005.0
# 2   3.0    3.0       BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   2.0    2.5       Seapointe OF Pompano       2320.0       NaN      1983.0
# 5   2.0    2.5       LANDINGS AT LAS OLAS       1797.0       NaN      2006.0
# 6   3.0    2.5  REGENCY TOWER SOUTH CONDO       2080.0       NaN      1970.0
# 7   3.0    2.0         350 Las Olas Place       1650.0       NaN      2005.0
# 8   2.0    2.5                Beach Haven       1360.0       NaN      1985.0
# 9   2.0    2.0     Sea Ranch Club A Condo       1950.0       NaN      1976.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1517.0     4074.0   Sold
# 1             NaN          842.0     3197.0   Sold
# 2             NaN          969.0     2417.0   Sold
# 3             NaN          636.0     2162.0   Sold
# 4             NaN          506.0     1466.0   Sold
# 5             NaN          573.0     1330.0   Sold
# 6             NaN          459.0     2027.0   Sold
# 7             NaN          576.0     1826.0   Sold
# 8             NaN          662.0      700.0   Sold
# 9             NaN          436.0     1630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Beaches MLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...       MARMLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...  Beaches MLS
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10471227        N          Y  26.157113 -80.100623
# 1    F10468069        N          Y  26.210753 -80.092365
# 2    A11647949        N          Y  25.984911 -80.118344
# 3    A11683701        N          Y  25.993975 -80.117768
# 4  RX-11030685        N          Y  26.245355 -80.086922
# 5    A11611644        N          Y  26.126738 -80.121826
# 6    A11705869        N          Y  26.174073 -80.098173
# 7    F10472447        N          Y  26.120405 -80.139762
# 8    F10473434        N          Y  26.226554 -80.090419
# 9    F10469042        N          Y  26.199954 -80.094697
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Maritza Meza Giusti
# 1  https://www.redfin.com/FL/Pompano-Beach/1600-S...  Thomas Michael LaPuma
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...              Mary Mass
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...           Silvana Sosa
# 4  https://www.redfin.com/FL/Pompano-Beach/812-N-...       Peter Pellegrini
# 5  https://www.redfin.com/FL/Fort-Lauderdale/400-...      Jennifer Ginsburg
# 6  https://www.redfin.com/FL/Fort-Lauderdale/3750...        Mauro Rodriguez
# 7  https://www.redfin.com/FL/Fort-Lauderdale/350-...           Rachel Buemi
# 8  https://www.redfin.com/FL/Pompano-Beach/3419-S...         Evelyn Bateman
# 9  https://www.redfin.com/FL/Lauderdale-by-the-Se...         Lori El Sanadi
#
#              list_broker_name_1 list_agent_name_2          list_broker_name_2  \
# 0        Coldwell Banker Realty              None                        None
# 1  Florida Luxurious Properties    Maritza Gaitan  Las Olas R E Professionals
# 2      Related ISG Realty, LLC.              None                        None
# 3               Florida.Doc Inc              None                        None
# 4       Pickle Ball Real Estate              None                        None
# 5          Freebird Real Estate              None                        None
# 6       Partnership Realty Inc.              None                        None
# 7     D'Angelo Realty Group LLC              None                        None
# 8                EXP Realty LLC              None                        None
# 9        Coldwell Banker Realty              None                        None
#
#   buy_agent_name_1                   buy_broker_name_1 buy_agent_name_2  \
# 0       Adam Elmer      Fortune International Realty B             None
# 1    Dany Flanders         RE/MAX Consultants Realty 1             None
# 2   Leslie Sanchez  One Sotheby's International Realty             None
# 3     David Koster  One Sotheby's International Realty             None
# 4     Taylar Shinn       Charles Rutenberg Realty Fort             None
# 5      glen Primak              The Agency Florida LLC             None
# 6  Mauro Rodriguez             Partnership Realty Inc.             None
# 7      Bobbi Ocean       Galleria International Realty             None
# 8   Evelyn Bateman                      EXP Realty LLC             None
# 9     Fernando Rey                 Post and Post, Inc.             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  Auberge Beach Residences at 2200 N Ocean Blvd ...
# 1  Aquazul Condo at 1600 S Ocean Blvd #401 in Lau...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #1101 ...
# 3  OCEAN PALMS CONDO at 3101 S Ocean Dr #1005 in ...
# 4  Seapointe OF Pompano at 812 N North Ocean Blvd...
# 5  LANDINGS AT LAS OLAS at 400 Hendricks Isle #40...
# 6  REGENCY TOWER SOUTH CONDO at 3750 Galt Ocean D...
# 7  350 Las Olas Place at 350 SE 2nd St #2670 in F...
# 8  Beach Haven at 3419 SE 8th St #10 in Pompano B...
# 9  Sea Ranch Club A Condo at 5100 N Ocean Blvd #1...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 10, 29) ## List (Earlier) date
date2 = datetime(2025, 1, 14) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 77

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1517.0
# 1     842.0
# 2     969.0
# 3     636.0
# 4     506.0
# 5     573.0
# 6     459.0
# 7     576.0
# 8     662.0
# 9     436.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                           ADDRESS       PRICE  \
# 0 2025-01-16    2200 N Ocean Blvd Unit N704 in Fort Lauderdale  $2,875,000
# 1 2025-01-14   1600 S Ocean Blvd #401 in Lauderdale By The Sea  $2,550,000
# 2 2025-01-13         1830 S Ocean Dr #1101 in Hallandale Beach  $1,999,999
# 3 2025-01-15                3101 S Ocean Dr #1005 in Hollywood  $1,345,000
# 4 2025-01-15      812 N North Ocean Blvd #405 in Pompano Beach  $1,175,000
# 5 2025-01-15        400 Hendricks Isle #402 in Fort Lauderdale  $1,030,000
# 6 2025-01-14        3750 Galt Ocean Dr #711 in Fort Lauderdale    $955,000
# 7 2025-01-16            350 SE 2nd St #2670 in Fort Lauderdale    $950,000
# 8 2025-01-17               3419 SE 8th St #10 in Pompano Beach    $900,000
# 9 2025-01-14  5100 N Ocean Blvd #1118 in Lauderdale By The Sea    $850,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    2    3.0       1,895       2018        $1,517  Beaches MLS    F10471227
# 1    3    4.5       3,029       2005          $842  Beaches MLS    F10468069
# 2    3    3.0       2,065       2006          $969       MARMLS    A11647949
# 3    3    3.5       2,115       2005          $636       MARMLS    A11683701
# 4    2    2.5       2,320       1983          $506  Beaches MLS  RX-11030685
# 5    2    2.5       1,797       2006          $573       MARMLS    A11611644
# 6    3    2.5       2,080       1970          $459       MARMLS    A11705869
# 7    3    2.0       1,650       2005          $576  Beaches MLS    F10472447
# 8    2    2.5       1,360       1985          $662  Beaches MLS    F10473434
# 9    2    2.0       1,950       1976          $436  Beaches MLS    F10469042
#
#                                         LISTING INFO  \
# 0     Maritza Meza Giusti Coldwell Banker Realty
# 1  Thomas Michael LaPuma Florida Luxurious Proper...
# 2             Mary Mass Related ISG Realty, LLC.
# 3                   Silvana Sosa Florida.Doc Inc
# 4       Peter Pellegrini Pickle Ball Real Estate
# 5         Jennifer Ginsburg Freebird Real Estate
# 6        Mauro Rodriguez Partnership Realty Inc.
# 7         Rachel Buemi D'Angelo Realty Group LLC
# 8                  Evelyn Bateman EXP Realty LLC
# 9          Lori El Sanadi Coldwell Banker Realty
#
#                                          BUYING INFO
# 0      Adam Elmer Fortune International Realty B
# 1      Dany Flanders RE/MAX Consultants Realty 1
# 2  Leslie Sanchez One Sotheby's International Rea...
# 3  David Koster One Sotheby's International Realt...
# 4     Taylar Shinn Charles Rutenberg Realty Fort
# 5             glen Primak The Agency Florida LLC
# 6        Mauro Rodriguez Partnership Realty Inc.
# 7      Bobbi Ocean Galleria International Realty
# 8                  Evelyn Bateman EXP Realty LLC
# 9               Fernando Rey Post and Post, Inc.
