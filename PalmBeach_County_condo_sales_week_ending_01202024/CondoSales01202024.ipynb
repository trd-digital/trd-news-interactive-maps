# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Jan. 12th Jan. 19th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 1  PAST SALE  January-15-2025   Condo/Co-op  17613 Ashbourne Way Unit B
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 1  Boca Raton                FL             33496.0  1270000.0   3.0    2.5
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Boca-Raton/17613-Ash...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11052898         N          Y  26.415307 -80.128518
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# df2 = df[(df['SOLD DATE'] > '2024-12-29') & (df['SOLD DATE'] < '2025-01-07')]

# %%
df2 = df

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-01-15    36
# 2025-01-17    22
# 2025-01-14     9
# 2025-01-16     7
# 2025-01-13     7
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 13  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 8   PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 37  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 9   PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4   PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 16  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 3   PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 63  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 17  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 2   PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 13      Palm Beach                FL             33480.0  7820000.0   3.0
# 8       Palm Beach                FL             33480.0  7600000.0   3.0
# 37   Singer Island                FL             33404.0  6750000.0   3.0
# 9       Boca Raton                FL             33432.0  3050000.0   4.0
# 4    Singer Island                FL             33404.0  2900000.0   3.0
# 16  Highland Beach                FL             33487.0  2250000.0   2.0
# 3          Jupiter                FL             33477.0  2022000.0   3.0
# 63   Riviera Beach                FL             33404.0  2000000.0   2.0
# 17         Jupiter                FL             33477.0  1865000.0   3.0
# 2          Jupiter                FL             33477.0  1825000.0   2.0
#
#     BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 13    3.5  ...   Sold                         NaN                       NaN
# 8     3.5  ...   Sold                         NaN                       NaN
# 37    4.5  ...   Sold                         NaN                       NaN
# 9     3.0  ...   Sold                         NaN                       NaN
# 4     3.5  ...   Sold                         NaN                       NaN
# 16    2.5  ...   Sold                         NaN                       NaN
# 3     3.0  ...   Sold                         NaN                       NaN
# 63    2.5  ...   Sold                         NaN                       NaN
# 17    2.5  ...   Sold                         NaN                       NaN
# 2     2.5  ...   Sold                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 13  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
# 8   https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 37  https://www.redfin.com/FL/Riviera-Beach/5000-N...  Beaches MLS
# 9   https://www.redfin.com/FL/Boca-Raton/701-E-Cam...  Beaches MLS
# 4   https://www.redfin.com/FL/Riviera-Beach/5150-N...  Beaches MLS
# 16  https://www.redfin.com/FL/Highland-Beach/3505-...  Beaches MLS
# 3   https://www.redfin.com/FL/Jupiter/600-S-US-Hig...  Beaches MLS
# 63  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 17  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
# 2   https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 13  RX-11032155         N          Y  26.642292 -80.038181
# 8   RX-11040760         N          Y  26.622316 -80.037453
# 37  RX-11020046         N          Y  26.798832 -80.032417
# 9   RX-11039973         N          Y  26.339459 -80.076301
# 4   RX-11041920         N          Y  26.803026 -80.033425
# 16  RX-11042375         N          Y  26.412583 -80.064295
# 3   RX-11031504         N          Y  26.927761 -80.078329
# 63  RX-10995255         N          Y  26.785112 -80.033355
# 17  RX-11038407         N          Y  26.918751 -80.066110
# 2   RX-11052859         N          Y  26.918751 -80.066110
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 1  PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 2  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 3  PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4  PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 5  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 6  PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 7  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 8  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 9  PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Palm Beach                FL             33480.0  7820000.0   3.0
# 1      Palm Beach                FL             33480.0  7600000.0   3.0
# 2   Singer Island                FL             33404.0  6750000.0   3.0
# 3      Boca Raton                FL             33432.0  3050000.0   4.0
# 4   Singer Island                FL             33404.0  2900000.0   3.0
# 5  Highland Beach                FL             33487.0  2250000.0   2.0
# 6         Jupiter                FL             33477.0  2022000.0   3.0
# 7   Riviera Beach                FL             33404.0  2000000.0   2.0
# 8         Jupiter                FL             33477.0  1865000.0   3.0
# 9         Jupiter                FL             33477.0  1825000.0   2.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    3.5  ... -80.038181  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...
# 1    3.5  ... -80.037453  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...
# 2    4.5  ... -80.032417  https://www.redfin.com/FL/Riviera-Beach/5000-N...
# 3    3.0  ... -80.076301  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...
# 4    3.5  ... -80.033425  https://www.redfin.com/FL/Riviera-Beach/5150-N...
# 5    2.5  ... -80.064295  https://www.redfin.com/FL/Highland-Beach/3505-...
# 6    3.0  ... -80.078329  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...
# 7    2.5  ... -80.033355  https://www.redfin.com/FL/Riviera-Beach/2700-N...
# 8    2.5  ... -80.066110  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...
# 9    2.5  ... -80.066110  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...
#
#     list_agent_name_1              list_broker_name_1  \
# 0        Scott Gordon                 Douglas Elliman
# 1  J. Hasozbek-Garcia  Premier Estate Properties, Inc
# 2       Angela Voland  Waterfront Properties & Club C
# 3     Jonathan Postma              Coldwell Banker/BR
# 4         Andrea Roth            Echo Fine Properties
# 5           Ahuva New          Boca Expert Realty LLC
# 6         Andrea Roth            Echo Fine Properties
# 7  Patrick Letourneau  One Sotheby's International Re
# 8       Paul Stockall             Compass Florida LLC
# 9   Susan Dephouse PA   Platinum Properties/The Keyes
#
#           list_agent_name_2              list_broker_name_2  buy_agent_name_1  \
# 0              Mindy Gordon                 Douglas Elliman      Fern Fodiman
# 1  Jennifer Hasozbek-Garcia  Premier Estate Properties, Inc         Guy Clark
# 2                      None                            None     Denice Sexton
# 3                      None                            None        David Hall
# 4                      None                            None       Andrea Roth
# 5                      None                            None   Matthew Bachrad
# 6                      None                            None       Andrea Roth
# 7                      None                            None         Non Agent
# 8          Diane Hutchinson             Compass Florida LLC   Megan McSweeney
# 9                      None                            None     Michael Fagan
#
#               buy_broker_name_1  buy_agent_name_2           buy_broker_name_2
# 0  Sotheby's Intl. Realty, Inc.              None                        None
# 1               Douglas Elliman              None                        None
# 2              Lost Tree Realty              None                        None
# 3           Compass Florida LLC        Sonia Hall         Compass Florida LLC
# 4          Echo Fine Properties              None                        None
# 5    William Raveis Real Estate    Danielle Stern  William Raveis Real Estate
# 6          Echo Fine Properties              None                        None
# 7     Non-Member Selling Office              None                        None
# 8           Mangrove Realty Inc              None                        None
# 9                KW Innovations              None                        None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 81

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $811,490

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $397

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $65,730,700

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Palm Beach
# Input Previous Week Condo Sales Total (number units sold):
# 99
# Input Previous Week Condo Average Sales Price:
# 619637
# Input Previous Week Condo Average PSF:
# 348
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 61_300_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op  2100 S Ocean Blvd Unit 508s
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Palm Beach                FL             33480.0  7820000.0   3.0    3.5
#
#                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Twenty One Hundred Condo       3107.0       NaN      1980.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2517.0     3998.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...      Scott Gordon
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman      Mindy Gordon    Douglas Elliman     Fern Fodiman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0  Sotheby's Intl. Realty, Inc.             None              None     1
#
#     COLOR
# 0  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 1  PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 2  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 3  PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4  PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 5  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 6  PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 7  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 8  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 9  PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Palm Beach                FL             33480.0  7820000.0   3.0
# 1      Palm Beach                FL             33480.0  7600000.0   3.0
# 2   Singer Island                FL             33404.0  6750000.0   3.0
# 3      Boca Raton                FL             33432.0  3050000.0   4.0
# 4   Singer Island                FL             33404.0  2900000.0   3.0
# 5  Highland Beach                FL             33487.0  2250000.0   2.0
# 6         Jupiter                FL             33477.0  2022000.0   3.0
# 7   Riviera Beach                FL             33404.0  2000000.0   2.0
# 8         Jupiter                FL             33477.0  1865000.0   3.0
# 9         Jupiter                FL             33477.0  1825000.0   2.0
#
#    BATHS                               LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Twenty One Hundred Condo       3107.0       NaN
# 1    3.5  Twenty Seven Seventy South Ocean Blvd       4178.0       NaN
# 2    4.5                       5000 North Ocean       3753.0       NaN
# 3    3.0                       Boca Inlet Condo       2647.0       NaN
# 4    3.5                            Via Delfino       3483.0       NaN
# 5    2.5                       Villa Nova Condo       2659.0       NaN
# 6    3.0                     Jupiter Yacht Club       2855.0       NaN
# 7    2.5                 2700 North Ocean Condo       2115.0       NaN
# 8    2.5           Jupiter Ocean Grande 2 Condo       2064.0       NaN
# 9    2.5                   Jupiter Ocean Grande       2064.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1980.0             NaN         2517.0     3998.0   Sold
# 1      1990.0             NaN         1819.0     6583.0   Sold
# 2      2020.0             NaN         1799.0     3697.0   Sold
# 3      1965.0             NaN         1152.0     3670.0   Sold
# 4      2003.0             NaN          833.0     2768.0   Sold
# 5      1987.0             NaN          846.0     2879.0   Sold
# 6      2005.0             NaN          708.0     3213.0   Sold
# 7      2008.0             NaN          946.0     2131.0   Sold
# 8      2002.0             NaN          904.0     2233.0   Sold
# 9      2002.0             NaN          884.0     2466.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...  Beaches MLS
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...  Beaches MLS
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...  Beaches MLS
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
# 1  RX-11040760        N          Y  26.622316 -80.037453
# 2  RX-11020046        N          Y  26.798832 -80.032417
# 3  RX-11039973        N          Y  26.339459 -80.076301
# 4  RX-11041920        N          Y  26.803026 -80.033425
# 5  RX-11042375        N          Y  26.412583 -80.064295
# 6  RX-11031504        N          Y  26.927761 -80.078329
# 7  RX-10995255        N          Y  26.785112 -80.033355
# 8  RX-11038407        N          Y  26.918751 -80.066110
# 9  RX-11052859        N          Y  26.918751 -80.066110
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...        Scott Gordon
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  J. Hasozbek-Garcia
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...       Angela Voland
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...     Jonathan Postma
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...         Andrea Roth
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...           Ahuva New
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...         Andrea Roth
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Patrick Letourneau
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...       Paul Stockall
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...   Susan Dephouse PA
#
#                list_broker_name_1         list_agent_name_2  \
# 0                 Douglas Elliman              Mindy Gordon
# 1  Premier Estate Properties, Inc  Jennifer Hasozbek-Garcia
# 2  Waterfront Properties & Club C                      None
# 3              Coldwell Banker/BR                      None
# 4            Echo Fine Properties                      None
# 5          Boca Expert Realty LLC                      None
# 6            Echo Fine Properties                      None
# 7  One Sotheby's International Re                      None
# 8             Compass Florida LLC          Diane Hutchinson
# 9   Platinum Properties/The Keyes                      None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                 Douglas Elliman     Fern Fodiman
# 1  Premier Estate Properties, Inc        Guy Clark
# 2                            None    Denice Sexton
# 3                            None       David Hall
# 4                            None      Andrea Roth
# 5                            None  Matthew Bachrad
# 6                            None      Andrea Roth
# 7                            None        Non Agent
# 8             Compass Florida LLC  Megan McSweeney
# 9                            None    Michael Fagan
#
#               buy_broker_name_1 buy_agent_name_2           buy_broker_name_2  \
# 0  Sotheby's Intl. Realty, Inc.             None                        None
# 1               Douglas Elliman             None                        None
# 2              Lost Tree Realty             None                        None
# 3           Compass Florida LLC       Sonia Hall         Compass Florida LLC
# 4          Echo Fine Properties             None                        None
# 5    William Raveis Real Estate   Danielle Stern  William Raveis Real Estate
# 6          Echo Fine Properties             None                        None
# 7     Non-Member Selling Office             None                        None
# 8           Mangrove Realty Inc             None                        None
# 9                KW Innovations             None                        None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c30e086460a5700286fb12d7de82b0b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Jan. 12th — Jan. 19th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c30e086460a5700286fb12d7de82b0b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c30e086460a5700286fb12d7de82b0b5 = L.map(
#                 &quot;map_c30e086460a5700286fb12d7de82b0b5&quot;,
#                 {
#                     center: [26.601855969135805, -80.10864069506172],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_28e9f58b849b2c9729f3f2adc33d3032 = L.featureGroup(
#                 {}
#             ).addTo(map_c30e086460a5700286fb12d7de82b0b5);
#
#
#             var marker_7662420f314e665284e72b8a3b1b65b7 = L.marker(
#                 [26.6422925, -80.038181],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_28e9f58b849b2c9729f3f2adc33d3032);
#
#
#             var icon_40debb3753a5ebac4d8565f2d472e78f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7662420f314e665284e72b8a3b1b65b7.setIcon(icon_40debb3753a5ebac4d8565f2d472e78f);
#
#
#         var popup_4c79489078f93f6f3f6a4ea9dad5d5e6 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_4a28b2a4fb4b0691cd8c029423c480ae = $(`&lt;div id=&quot;html_4a28b2a4fb4b0691cd8c029423c480ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2100 S Ocean Blvd Unit 508s&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,820,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,517.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,107.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1980.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_4c79489078f93f6f3f6a4ea9dad5d5e6.setContent(html_4a28b2a4fb4b0691cd8c029423c480ae);
#
#
#
#         marker_7662420f314e665284e72b8a3b1b65b7.bindPopup(popup_4c79489078f93f6f3f6a4ea9dad5d5e6)
#         ;
#
#
#
#
#             var feature_group_53d1c3f04a0898e8886727490ec9aacb = L.featureGroup(
#                 {}
#             ).addTo(map_c30e086460a5700286fb12d7de82b0b5);
#
#
#             var marker_0678022687c171f2a3cf0f5cd05727d7 = L.marker(
#                 [26.6223163, -80.037453],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_53d1c3f04a0898e8886727490ec9aacb);
#
#
#             var icon_4a6858f887b64804927df267a02f0bd9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0678022687c171f2a3cf0f5cd05727d7.setIcon(icon_4a6858f887b64804927df267a02f0bd9);
#
#
#         var popup_27b6d801610d56311da25110cc411b1a = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f0c57cbb13ae31f49f35dfd024f5b0ce = $(`&lt;div id=&quot;html_f0c57cbb13ae31f49f35dfd024f5b0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2770 S Ocean Blvd Unit S302&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,600,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,819.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,178.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1990.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_27b6d801610d56311da25110cc411b1a.setContent(html_f0c57cbb13ae31f49f35dfd024f5b0ce);
#
#
#
#         marker_0678022687c171f2a3cf0f5cd05727d7.bindPopup(popup_27b6d801610d56311da25110cc411b1a)
#         ;
#
#
#
#
#             var marker_52caacd5c73d225cd8908202da5da766 = L.marker(
#                 [26.7988319, -80.0324172],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_53d1c3f04a0898e8886727490ec9aacb);
#
#
#             var icon_2cf42027b1639ec144d56b1b9b1e9316 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52caacd5c73d225cd8908202da5da766.setIcon(icon_2cf42027b1639ec144d56b1b9b1e9316);
#
#
#         var popup_a6ba282c4e24bb3e97cd8bac913ad987 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2f58449a7b9743731ef341651

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op  2100 S Ocean Blvd Unit 508s
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Palm Beach                FL             33480.0  7820000.0   3.0    3.5
#
#                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Twenty One Hundred Condo       3107.0       NaN      1980.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2517.0     3998.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...      Scott Gordon
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman      Mindy Gordon    Douglas Elliman     Fern Fodiman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0  Sotheby's Intl. Realty, Inc.             None              None     1
#
#     COLOR
# 0  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01202024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Twenty One Hundred Condo at 2100 S Ocean Blvd Unit 508s in Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 1  PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 2  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 3  PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4  PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 5  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 6  PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 7  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 8  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 9  PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Palm Beach                FL             33480.0  7820000.0   3.0
# 1      Palm Beach                FL             33480.0  7600000.0   3.0
# 2   Singer Island                FL             33404.0  6750000.0   3.0
# 3      Boca Raton                FL             33432.0  3050000.0   4.0
# 4   Singer Island                FL             33404.0  2900000.0   3.0
# 5  Highland Beach                FL             33487.0  2250000.0   2.0
# 6         Jupiter                FL             33477.0  2022000.0   3.0
# 7   Riviera Beach                FL             33404.0  2000000.0   2.0
# 8         Jupiter                FL             33477.0  1865000.0   3.0
# 9         Jupiter                FL             33477.0  1825000.0   2.0
#
#    BATHS                               LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Twenty One Hundred Condo       3107.0       NaN
# 1    3.5  Twenty Seven Seventy South Ocean Blvd       4178.0       NaN
# 2    4.5                       5000 North Ocean       3753.0       NaN
# 3    3.0                       Boca Inlet Condo       2647.0       NaN
# 4    3.5                            Via Delfino       3483.0       NaN
# 5    2.5                       Villa Nova Condo       2659.0       NaN
# 6    3.0                     Jupiter Yacht Club       2855.0       NaN
# 7    2.5                 2700 North Ocean Condo       2115.0       NaN
# 8    2.5           Jupiter Ocean Grande 2 Condo       2064.0       NaN
# 9    2.5                   Jupiter Ocean Grande       2064.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1980.0             NaN         2517.0     3998.0   Sold
# 1      1990.0             NaN         1819.0     6583.0   Sold
# 2      2020.0             NaN         1799.0     3697.0   Sold
# 3      1965.0             NaN         1152.0     3670.0   Sold
# 4      2003.0             NaN          833.0     2768.0   Sold
# 5      1987.0             NaN          846.0     2879.0   Sold
# 6      2005.0             NaN          708.0     3213.0   Sold
# 7      2008.0             NaN          946.0     2131.0   Sold
# 8      2002.0             NaN          904.0     2233.0   Sold
# 9      2002.0             NaN          884.0     2466.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...  Beaches MLS
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...  Beaches MLS
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...  Beaches MLS
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
# 1  RX-11040760        N          Y  26.622316 -80.037453
# 2  RX-11020046        N          Y  26.798832 -80.032417
# 3  RX-11039973        N          Y  26.339459 -80.076301
# 4  RX-11041920        N          Y  26.803026 -80.033425
# 5  RX-11042375        N          Y  26.412583 -80.064295
# 6  RX-11031504        N          Y  26.927761 -80.078329
# 7  RX-10995255        N          Y  26.785112 -80.033355
# 8  RX-11038407        N          Y  26.918751 -80.066110
# 9  RX-11052859        N          Y  26.918751 -80.066110
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...        Scott Gordon
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  J. Hasozbek-Garcia
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...       Angela Voland
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...     Jonathan Postma
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...         Andrea Roth
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...           Ahuva New
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...         Andrea Roth
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Patrick Letourneau
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...       Paul Stockall
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...   Susan Dephouse PA
#
#                list_broker_name_1         list_agent_name_2  \
# 0                 Douglas Elliman              Mindy Gordon
# 1  Premier Estate Properties, Inc  Jennifer Hasozbek-Garcia
# 2  Waterfront Properties & Club C                      None
# 3              Coldwell Banker/BR                      None
# 4            Echo Fine Properties                      None
# 5          Boca Expert Realty LLC                      None
# 6            Echo Fine Properties                      None
# 7  One Sotheby's International Re                      None
# 8             Compass Florida LLC          Diane Hutchinson
# 9   Platinum Properties/The Keyes                      None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                 Douglas Elliman     Fern Fodiman
# 1  Premier Estate Properties, Inc        Guy Clark
# 2                            None    Denice Sexton
# 3                            None       David Hall
# 4                            None      Andrea Roth
# 5                            None  Matthew Bachrad
# 6                            None      Andrea Roth
# 7                            None        Non Agent
# 8             Compass Florida LLC  Megan McSweeney
# 9                            None    Michael Fagan
#
#               buy_broker_name_1 buy_agent_name_2           buy_broker_name_2  \
# 0  Sotheby's Intl. Realty, Inc.             None                        None
# 1               Douglas Elliman             None                        None
# 2              Lost Tree Realty             None                        None
# 3           Compass Florida LLC       Sonia Hall         Compass Florida LLC
# 4          Echo Fine Properties             None                        None
# 5    William Raveis Real Estate   Danielle Stern  William Raveis Real Estate
# 6          Echo Fine Properties             None                        None
# 7     Non-Member Selling Office             None                        None
# 8           Mangrove Realty Inc             None                        None
# 9                KW Innovations             None                        None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Twenty One Hundred Condo at 2100 S Ocean Blvd ...
# 1     2    blue  Twenty Seven Seventy South Ocean Blvd at 2770 ...
# 2     3    blue  5000 North Ocean at 5000 N Ocean Dr #1601 in S...
# 3     4    blue  Boca Inlet Condo at 701 E Camino Real Unit 12a...
# 4     5    blue  Via Delfino at 5150 N Ocean Dr #2001 in Singer...
# 5     6    blue  Villa Nova Condo at 3505 S Ocean 6s Blvd Unit ...
# 6     7    blue  Jupiter Yacht Club at 600 S Us Highway 1 #307 ...
# 7     8    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 8     9    blue  Jupiter Ocean Grande 2 Condo at 221 Ocean Gran...
# 9    10    blue  Jupiter Ocean Grande at 221 Ocean Grande Blvd ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Twenty One Hundred Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,825,000 to $7,820,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Riviera Beach, Boca Raton, Singer Island, Palm Beach, Jupiter, Highland Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 81 condo sales totaling $65,730,700 million from Jan. 12th to Jan. 19th. The previous week, brokers closed 99 condo sales totaling $61,300,000.
#
# Last week’s units sold for an average of $811,490, higher than the $619,637 average price from the previous week. The average price per square foot rose to $397 from $348, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,825,000.0 million to $7,820,000.0 million.
#
# Twenty One Hundred Condo at 2100 S Ocean Blvd Unit 508s in Palm Beach took the top spot with a $7,820,000.0 million closing. The sale closed at $2,517.0 per square foot.
#
# Scott Gordon with Douglas Elliman, and Mindy Gordon with Douglas Elliman had the listing.
# Fern Fodiman with Sotheby's Intl. Realty, Inc., and None with None represented the buyer.
#
# Twenty Seven Seventy South Ocean Blvd at 2770 S Ocean Blvd Unit S302 in Palm Beach, closed for the second highest amount, $7,600,000.0, or $1,819.0 per square foot.
#
# J. Hasozbek-Garcia with Premier Estate Properties, Inc, and Jennifer Hasozbek-Garcia with Premier Estate Properties, Inc had the listing.
# Guy Clark with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01202024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 12th to Jan. 19th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 1  PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 2  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 3  PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4  PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 5  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 6  PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 7  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 8  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 9  PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Palm Beach                FL             33480.0  7820000.0   3.0
# 1      Palm Beach                FL             33480.0  7600000.0   3.0
# 2   Singer Island                FL             33404.0  6750000.0   3.0
# 3      Boca Raton                FL             33432.0  3050000.0   4.0
# 4   Singer Island                FL             33404.0  2900000.0   3.0
# 5  Highland Beach                FL             33487.0  2250000.0   2.0
# 6         Jupiter                FL             33477.0  2022000.0   3.0
# 7   Riviera Beach                FL             33404.0  2000000.0   2.0
# 8         Jupiter                FL             33477.0  1865000.0   3.0
# 9         Jupiter                FL             33477.0  1825000.0   2.0
#
#    BATHS                               LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Twenty One Hundred Condo       3107.0       NaN
# 1    3.5  Twenty Seven Seventy South Ocean Blvd       4178.0       NaN
# 2    4.5                       5000 North Ocean       3753.0       NaN
# 3    3.0                       Boca Inlet Condo       2647.0       NaN
# 4    3.5                            Via Delfino       3483.0       NaN
# 5    2.5                       Villa Nova Condo       2659.0       NaN
# 6    3.0                     Jupiter Yacht Club       2855.0       NaN
# 7    2.5                 2700 North Ocean Condo       2115.0       NaN
# 8    2.5           Jupiter Ocean Grande 2 Condo       2064.0       NaN
# 9    2.5                   Jupiter Ocean Grande       2064.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1980.0             NaN         2517.0     3998.0   Sold
# 1      1990.0             NaN         1819.0     6583.0   Sold
# 2      2020.0             NaN         1799.0     3697.0   Sold
# 3      1965.0             NaN         1152.0     3670.0   Sold
# 4      2003.0             NaN          833.0     2768.0   Sold
# 5      1987.0             NaN          846.0     2879.0   Sold
# 6      2005.0             NaN          708.0     3213.0   Sold
# 7      2008.0             NaN          946.0     2131.0   Sold
# 8      2002.0             NaN          904.0     2233.0   Sold
# 9      2002.0             NaN          884.0     2466.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...  Beaches MLS
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...  Beaches MLS
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...  Beaches MLS
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
# 1  RX-11040760        N          Y  26.622316 -80.037453
# 2  RX-11020046        N          Y  26.798832 -80.032417
# 3  RX-11039973        N          Y  26.339459 -80.076301
# 4  RX-11041920        N          Y  26.803026 -80.033425
# 5  RX-11042375        N          Y  26.412583 -80.064295
# 6  RX-11031504        N          Y  26.927761 -80.078329
# 7  RX-10995255        N          Y  26.785112 -80.033355
# 8  RX-11038407        N          Y  26.918751 -80.066110
# 9  RX-11052859        N          Y  26.918751 -80.066110
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...        Scott Gordon
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  J. Hasozbek-Garcia
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...       Angela Voland
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...     Jonathan Postma
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...         Andrea Roth
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...           Ahuva New
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...         Andrea Roth
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Patrick Letourneau
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...       Paul Stockall
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...   Susan Dephouse PA
#
#                list_broker_name_1         list_agent_name_2  \
# 0                 Douglas Elliman              Mindy Gordon
# 1  Premier Estate Properties, Inc  Jennifer Hasozbek-Garcia
# 2  Waterfront Properties & Club C                      None
# 3              Coldwell Banker/BR                      None
# 4            Echo Fine Properties                      None
# 5          Boca Expert Realty LLC                      None
# 6            Echo Fine Properties                      None
# 7  One Sotheby's International Re                      None
# 8             Compass Florida LLC          Diane Hutchinson
# 9   Platinum Properties/The Keyes                      None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                 Douglas Elliman     Fern Fodiman
# 1  Premier Estate Properties, Inc        Guy Clark
# 2                            None    Denice Sexton
# 3                            None       David Hall
# 4                            None      Andrea Roth
# 5                            None  Matthew Bachrad
# 6                            None      Andrea Roth
# 7                            None        Non Agent
# 8             Compass Florida LLC  Megan McSweeney
# 9                            None    Michael Fagan
#
#               buy_broker_name_1 buy_agent_name_2           buy_broker_name_2  \
# 0  Sotheby's Intl. Realty, Inc.             None                        None
# 1               Douglas Elliman             None                        None
# 2              Lost Tree Realty             None                        None
# 3           Compass Florida LLC       Sonia Hall         Compass Florida LLC
# 4          Echo Fine Properties             None                        None
# 5    William Raveis Real Estate   Danielle Stern  William Raveis Real Estate
# 6          Echo Fine Properties             None                        None
# 7     Non-Member Selling Office             None                        None
# 8           Mangrove Realty Inc             None                        None
# 9                KW Innovations             None                        None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Twenty One Hundred Condo at 2100 S Ocean Blvd ...
# 1     2    blue  Twenty Seven Seventy South Ocean Blvd at 2770 ...
# 2     3    blue  5000 North Ocean at 5000 N Ocean Dr #1601 in S...
# 3     4    blue  Boca Inlet Condo at 701 E Camino Real Unit 12a...
# 4     5    blue  Via Delfino at 5150 N Ocean Dr #2001 in Singer...
# 5     6    blue  Villa Nova Condo at 3505 S Ocean 6s Blvd Unit ...
# 6     7    blue  Jupiter Yacht Club at 600 S Us Highway 1 #307 ...
# 7     8    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 8     9    blue  Jupiter Ocean Grande 2 Condo at 221 Ocean Gran...
# 9    10    blue  Jupiter Ocean Grande at 221 Ocean Grande Blvd ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Twenty One Hundred Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,825,000 to $7,820,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Riviera Beach, Boca Raton, Singer Island, Palm Beach, Jupiter, Highland Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 81 condo sales totaling $65,730,700 million from Jan. 12th to Jan. 19th. The previous week, brokers closed 99 condo sales totaling $61,300,000.
#
# Last week’s units sold for an average of $811,490, higher than the $619,637 average price from the previous week. The average price per square foot rose to $397 from $348, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,825,000.0 million to $7,820,000.0 million.
#
# Twenty One Hundred Condo at 2100 S Ocean Blvd Unit 508s in Palm Beach took the top spot with a $7,820,000.0 million closing. The sale closed at $2,517.0 per square foot.
#
# Scott Gordon with Douglas Elliman, and Mindy Gordon with Douglas Elliman had the listing.
# Fern Fodiman with Sotheby's Intl. Realty, Inc., and None with None represented the buyer.
#
# Twenty Seven Seventy South Ocean Blvd at 2770 S Ocean Blvd Unit S302 in Palm Beach, closed for the second highest amount, $7,600,000.0, or $1,819.0 per square foot.
#
# J. Hasozbek-Garcia with Premier Estate Properties, Inc, and Jennifer Hasozbek-Garcia with Premier Estate Properties, Inc had the listing.
# Guy Clark with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01202024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 12th to Jan. 19th:
#
# Most Expensive
# Twenty One Hundred Condo, 2100 S Ocean Blvd Unit 508s, in Palm Beach | Price: $7,820,000 | $2,517 psf | Listing agents: Scott Gordon with Douglas Elliman and Mindy Gordon with Douglas Elliman | Buyer's agents: Fern Fodiman with Sotheby's Intl. Realty, Inc. and None with None
#
# Least Expensive
# Jupiter Ocean Grande, 221 Ocean Grande Blvd #508, in Jupiter | Price: $1,825,000 | $884 psf | Listing agents: Susan Dephouse PA with Platinum Properties/The Keyes and None with None | Buyer's agents: Michael Fagan with KW Innovations and None with None
#
# Highest Price Per Square Foot
# Twenty One Hundred Condo, 2100 S Ocean Blvd Unit 508s, in Palm Beach | Price: $7,820,000 | $2,517 psf | Listing agents: Scott Gordon with Douglas Elliman and Mindy Gordon with Douglas Elliman | Buyer's agents: Fern Fodiman with Sotheby's Intl. Realty, Inc. and None with None
#
# Lowest Price Per Square Foot
# Jupiter Yacht Club, 600 S Us Highway 1 #307, in Jupiter | Price: $2,022,000 | $708 psf | Listing agents: Andrea Roth with Echo Fine Properties and None with None | Buyer's agents: Andrea Roth with Echo Fine Properties and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Palm-Beach/2100-S-Ocean-Blvd-33480/unit-508S/home/42436210
# Second priciest sale:  https://www.redfin.com/FL/Palm-Beach/2770-S-Ocean-Blvd-33480/unit-S302/home/193730991
# Cheapest top ten sale:  https://www.redfin.com/FL/Jupiter/221-Ocean-Grande-Blvd-33477/unit-508/home/42565900
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Jupiter/221-Ocean-Grande-Blvd-33477/unit-608/home/42565887
# Highest top ten psf:  https://www.redfin.com/FL/Palm-Beach/2100-S-Ocean-Blvd-33480/unit-508S/home/42436210
# Lowest top ten psf:  https://www.redfin.com/FL/Jupiter/600-S-US-Highway-1-33477/unit-307/home/42613152

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Palm-Beach/2100-S-Ocean-Blvd-33480/unit-508S/home/42436210

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Palm-Beach/2770-S-Ocean-Blvd-33480/unit-S302/home/193730991

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Jupiter/221-Ocean-Grande-Blvd-33477/unit-508/home/42565900

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Jupiter/221-Ocean-Grande-Blvd-33477/unit-608/home/42565887

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Palm-Beach/2100-S-Ocean-Blvd-33480/unit-508S/home/42436210

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Jupiter/600-S-US-Highway-1-33477/unit-307/home/42613152

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2025-01-15   Condo/Co-op   2100 S Ocean Blvd Unit 508s
# 1  PAST SALE 2025-01-15   Condo/Co-op   2770 S Ocean Blvd Unit S302
# 2  PAST SALE 2025-01-14   Condo/Co-op         5000 N Ocean Dr #1601
# 3  PAST SALE 2025-01-17   Condo/Co-op    701 E Camino Real Unit 12a
# 4  PAST SALE 2025-01-14   Condo/Co-op         5150 N Ocean Dr #2001
# 5  PAST SALE 2025-01-17   Condo/Co-op  3505 S Ocean 6s Blvd Unit 6s
# 6  PAST SALE 2025-01-15   Condo/Co-op       600 S Us Highway 1 #307
# 7  PAST SALE 2025-01-15   Condo/Co-op     2700 N Ocean Dr Unit 805b
# 8  PAST SALE 2025-01-15   Condo/Co-op    221 Ocean Grande Blvd #608
# 9  PAST SALE 2025-01-16   Condo/Co-op    221 Ocean Grande Blvd #508
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Palm Beach                FL             33480.0  7820000.0   3.0
# 1      Palm Beach                FL             33480.0  7600000.0   3.0
# 2   Singer Island                FL             33404.0  6750000.0   3.0
# 3      Boca Raton                FL             33432.0  3050000.0   4.0
# 4   Singer Island                FL             33404.0  2900000.0   3.0
# 5  Highland Beach                FL             33487.0  2250000.0   2.0
# 6         Jupiter                FL             33477.0  2022000.0   3.0
# 7   Riviera Beach                FL             33404.0  2000000.0   2.0
# 8         Jupiter                FL             33477.0  1865000.0   3.0
# 9         Jupiter                FL             33477.0  1825000.0   2.0
#
#    BATHS                               LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Twenty One Hundred Condo       3107.0       NaN
# 1    3.5  Twenty Seven Seventy South Ocean Blvd       4178.0       NaN
# 2    4.5                       5000 North Ocean       3753.0       NaN
# 3    3.0                       Boca Inlet Condo       2647.0       NaN
# 4    3.5                            Via Delfino       3483.0       NaN
# 5    2.5                       Villa Nova Condo       2659.0       NaN
# 6    3.0                     Jupiter Yacht Club       2855.0       NaN
# 7    2.5                 2700 North Ocean Condo       2115.0       NaN
# 8    2.5           Jupiter Ocean Grande 2 Condo       2064.0       NaN
# 9    2.5                   Jupiter Ocean Grande       2064.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1980.0             NaN         2517.0     3998.0   Sold
# 1      1990.0             NaN         1819.0     6583.0   Sold
# 2      2020.0             NaN         1799.0     3697.0   Sold
# 3      1965.0             NaN         1152.0     3670.0   Sold
# 4      2003.0             NaN          833.0     2768.0   Sold
# 5      1987.0             NaN          846.0     2879.0   Sold
# 6      2005.0             NaN          708.0     3213.0   Sold
# 7      2008.0             NaN          946.0     2131.0   Sold
# 8      2002.0             NaN          904.0     2233.0   Sold
# 9      2002.0             NaN          884.0     2466.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...  Beaches MLS
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...  Beaches MLS
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...  Beaches MLS
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11032155        N          Y  26.642292 -80.038181
# 1  RX-11040760        N          Y  26.622316 -80.037453
# 2  RX-11020046        N          Y  26.798832 -80.032417
# 3  RX-11039973        N          Y  26.339459 -80.076301
# 4  RX-11041920        N          Y  26.803026 -80.033425
# 5  RX-11042375        N          Y  26.412583 -80.064295
# 6  RX-11031504        N          Y  26.927761 -80.078329
# 7  RX-10995255        N          Y  26.785112 -80.033355
# 8  RX-11038407        N          Y  26.918751 -80.066110
# 9  RX-11052859        N          Y  26.918751 -80.066110
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2100-S-Oc...        Scott Gordon
# 1  https://www.redfin.com/FL/Palm-Beach/2770-S-Oc...  J. Hasozbek-Garcia
# 2  https://www.redfin.com/FL/Riviera-Beach/5000-N...       Angela Voland
# 3  https://www.redfin.com/FL/Boca-Raton/701-E-Cam...     Jonathan Postma
# 4  https://www.redfin.com/FL/Riviera-Beach/5150-N...         Andrea Roth
# 5  https://www.redfin.com/FL/Highland-Beach/3505-...           Ahuva New
# 6  https://www.redfin.com/FL/Jupiter/600-S-US-Hig...         Andrea Roth
# 7  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Patrick Letourneau
# 8  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...       Paul Stockall
# 9  https://www.redfin.com/FL/Jupiter/221-Ocean-Gr...   Susan Dephouse PA
#
#                list_broker_name_1         list_agent_name_2  \
# 0                 Douglas Elliman              Mindy Gordon
# 1  Premier Estate Properties, Inc  Jennifer Hasozbek-Garcia
# 2  Waterfront Properties & Club C                      None
# 3              Coldwell Banker/BR                      None
# 4            Echo Fine Properties                      None
# 5          Boca Expert Realty LLC                      None
# 6            Echo Fine Properties                      None
# 7  One Sotheby's International Re                      None
# 8             Compass Florida LLC          Diane Hutchinson
# 9   Platinum Properties/The Keyes                      None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                 Douglas Elliman     Fern Fodiman
# 1  Premier Estate Properties, Inc        Guy Clark
# 2                            None    Denice Sexton
# 3                            None       David Hall
# 4                            None      Andrea Roth
# 5                            None  Matthew Bachrad
# 6                            None      Andrea Roth
# 7                            None        Non Agent
# 8             Compass Florida LLC  Megan McSweeney
# 9                            None    Michael Fagan
#
#               buy_broker_name_1 buy_agent_name_2           buy_broker_name_2  \
# 0  Sotheby's Intl. Realty, Inc.             None                        None
# 1               Douglas Elliman             None                        None
# 2              Lost Tree Realty             None                        None
# 3           Compass Florida LLC       Sonia Hall         Compass Florida LLC
# 4          Echo Fine Properties             None                        None
# 5    William Raveis Real Estate   Danielle Stern  William Raveis Real Estate
# 6          Echo Fine Properties             None                        None
# 7     Non-Member Selling Office             None                        None
# 8           Mangrove Realty Inc             None                        None
# 9                KW Innovations             None                        None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Twenty One Hundred Condo at 2100 S Ocean Blvd ...
# 1     2    blue  Twenty Seven Seventy South Ocean Blvd at 2770 ...
# 2     3    blue  5000 North Ocean at 5000 N Ocean Dr #1601 in S...
# 3     4    blue  Boca Inlet Condo at 701 E Camino Real Unit 12a...
# 4     5    blue  Via Delfino at 5150 N Ocean Dr #2001 in Singer...
# 5     6    blue  Villa Nova Condo at 3505 S Ocean 6s Blvd Unit ...
# 6     7    blue  Jupiter Yacht Club at 600 S Us Highway 1 #307 ...
# 7     8    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 8     9    blue  Jupiter Ocean Grande 2 Condo at 221 Ocean Gran...
# 9    10    blue  Jupiter Ocean Grande at 221 Ocean Grande Blvd ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 11, 27) ## List (Earlier) date
date2 = datetime(2025, 1, 15) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 49

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    2517.0
# 1    1819.0
# 2    1799.0
# 3    1152.0
# 4     833.0
# 5     846.0
# 6     708.0
# 7     946.0
# 8     904.0
# 9     884.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                         ADDRESS       PRICE BEDS  \
# 0 2025-01-15       2100 S Ocean Blvd Unit 508s in Palm Beach  $7,820,000    3
# 1 2025-01-15       2770 S Ocean Blvd Unit S302 in Palm Beach  $7,600,000    3
# 2 2025-01-14          5000 N Ocean Dr #1601 in Singer Island  $6,750,000    3
# 3 2025-01-17        701 E Camino Real Unit 12a in Boca Raton  $3,050,000    4
# 4 2025-01-14          5150 N Ocean Dr #2001 in Singer Island  $2,900,000    3
# 5 2025-01-17  3505 S Ocean 6s Blvd Unit 6s in Highland Beach  $2,250,000    2
# 6 2025-01-15              600 S Us Highway 1 #307 in Jupiter  $2,022,000    3
# 7 2025-01-15      2700 N Ocean Dr Unit 805b in Riviera Beach  $2,000,000    2
# 8 2025-01-15           221 Ocean Grande Blvd #608 in Jupiter  $1,865,000    3
# 9 2025-01-16           221 Ocean Grande Blvd #508 in Jupiter  $1,825,000    2
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3.5       3,107       1980        $2,517  Beaches MLS  RX-11032155
# 1    3.5       4,178       1990        $1,819  Beaches MLS  RX-11040760
# 2    4.5       3,753       2020        $1,799  Beaches MLS  RX-11020046
# 3    3.0       2,647       1965        $1,152  Beaches MLS  RX-11039973
# 4    3.5       3,483       2003          $833  Beaches MLS  RX-11041920
# 5    2.5       2,659       1987          $846  Beaches MLS  RX-11042375
# 6    3.0       2,855       2005          $708  Beaches MLS  RX-11031504
# 7    2.5       2,115       2008          $946  Beaches MLS  RX-10995255
# 8    2.5       2,064       2002          $904  Beaches MLS  RX-11038407
# 9    2.5       2,064       2002          $884  Beaches MLS  RX-11052859
#
#                                         LISTING INFO  \
# 0  Scott Gordon Douglas Elliman Mindy Gordon Doug...
# 1  J. Hasozbek-Garcia Premier Estate Properties, ...
# 2   Angela Voland Waterfront Properties & Club C
# 3             Jonathan Postma Coldwell Banker/BR
# 4               Andrea Roth Echo Fine Properties
# 5               Ahuva New Boca Expert Realty LLC
# 6               Andrea Roth Echo Fine Properties
# 7  Patrick Letourneau One Sotheby's International...
# 8  Paul Stockall Compass Florida LLC Diane Hutchi...
# 9  Susan Dephouse PA Platinum Properties/The Keye...
#
#                                          BUYING INFO
# 0      Fern Fodiman Sotheby's Intl. Realty, Inc.
# 1                      Guy Clark Douglas Elliman
# 2                 Denice Sexton Lost Tree Realty
# 3  David Hall Compass Florida LLC Sonia Hall Comp...
# 4               Andrea Roth Echo Fine Properties
# 5  Matthew Bachrad William Raveis Real Estate Dan...
# 6               Andrea Roth Echo Fine Properties
# 7            Non Agent Non-Member Selling Office
# 8            Megan McSweeney Mangrove Realty Inc
# 9                   Michael Fagan KW Innovations
