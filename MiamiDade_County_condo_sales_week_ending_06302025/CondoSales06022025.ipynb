# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now() - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=6)

def format_date(date):
    day = date.day
    # Months 3-7 (March–July) should be full; all others abbreviated with a period
    if date.month in (3, 4, 5, 6, 7):
        month_str = date.strftime("%B")      # e.g. "March", "April", ...
    else:
        month_str = date.strftime("%b") + "."  # e.g. "Jan.", "Feb.", "Aug.", ...

    return f"{month_str} {day}"


# Format both dates
week_ending = format_date(today)
week_starting = format_date(one_week_ago)

print(week_starting, week_ending)
# Out:
# June 23 June 29

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE     SOLD DATE PROPERTY TYPE            ADDRESS     CITY  \
# 1  PAST SALE  June-25-2025   Condo/Co-op  6566 W 2nd Ct #18  Hialeah
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33012.0  310000.0   3.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Hialeah/6566-W-2nd-C...  MARMLS  A11766707
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.882108 -80.289443
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] >= one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-06-27    36
# 2025-06-25    18
# 2025-06-26    16
# 2025-06-24    14
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 60   PAST SALE 2025-06-24   Condo/Co-op           1455 Ocean Dr #809
# 34   PAST SALE 2025-06-27   Condo/Co-op         788 NE 23rd St #3502
# 11   PAST SALE 2025-06-27   Condo/Co-op            102 24th St #1045
# 27   PAST SALE 2025-06-24   Condo/Co-op     2627 S Bayshore Dr #2605
# 86   PAST SALE 2025-06-27   Condo/Co-op  1121 Crandon Blvd Unit F602
# 32   PAST SALE 2025-06-27   Condo/Co-op        700 NE 26th Ter #2302
# 99   PAST SALE 2025-06-27   Condo/Co-op       5875 Collins Ave #1507
# 102  PAST SALE 2025-06-24   Condo/Co-op  300 Biscayne Blvd Way #2306
# 119  PAST SALE 2025-06-27   Condo/Co-op     2020 N Bayshore Dr #2402
# 87   PAST SALE 2025-06-24   Condo/Co-op      2020 N Bayshore Dr #903
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 60     Miami Beach                FL             33139.0  4300000.0   3.0
# 34           Miami                FL             33137.0  3000000.0   4.0
# 11     Miami Beach                FL             33139.0  2900000.0   2.0
# 27   Coconut Grove                FL             33133.0  2600000.0   2.0
# 86    Key Biscayne                FL             33149.0  1950000.0   3.0
# 32           Miami                FL             33137.0  1950000.0   2.0
# 99     Miami Beach                FL             33140.0  1775000.0   2.0
# 102          Miami                FL             33131.0  1750000.0   2.0
# 119          Miami                FL             33137.0  1700000.0   3.0
# 87           Miami                FL             33137.0  1470000.0   3.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 60     3.5  ...   Sold                         NaN                       NaN
# 34     4.5  ...   Sold                         NaN                       NaN
# 11     2.0  ...   Sold                         NaN                       NaN
# 27     2.5  ...   Sold                         NaN                       NaN
# 86     3.0  ...   Sold                         NaN                       NaN
# 32     3.5  ...   Sold                         NaN                       NaN
# 99     2.5  ...   Sold                         NaN                       NaN
# 102    2.5  ...   Sold                         NaN                       NaN
# 119    3.5  ...   Sold                         NaN                       NaN
# 87     3.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 60   https://www.redfin.com/FL/Miami-Beach/1455-Oce...       MARMLS
# 34   https://www.redfin.com/FL/Miami/788-NE-23rd-St...       MARMLS
# 11   https://www.redfin.com/FL/Miami-Beach/102-24th...       MARMLS
# 27   https://www.redfin.com/FL/Miami/2627-S-Bayshor...       MARMLS
# 86   https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       MARMLS
# 32   https://www.redfin.com/FL/Miami/700-NE-26th-Te...       MARMLS
# 99   https://www.redfin.com/FL/Miami-Beach/5875-Col...       MARMLS
# 102  https://www.redfin.com/FL/Miami/300-Biscayne-B...  Beaches MLS
# 119  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS
# 87   https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 60   A11774776         N          Y  25.787317 -80.129357
# 34   A11792281         N          Y  25.799065 -80.185542
# 11   A11792330         N          Y  25.799770 -80.126865
# 27   A11786394         N          Y  25.732272 -80.234921
# 86   A11734384         N          Y  25.683541 -80.157137
# 32   A11793470         N          Y  25.802006 -80.185769
# 99   A11713614         N          Y  25.840891 -80.120220
# 102  F10467425         N          Y  25.770777 -80.187521
# 119  A11588531         N          Y  25.796683 -80.187669
# 87   A11744723         N          Y  25.796683 -80.187669
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"
        querystring = {"url": url}
        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)
        time.sleep(0.2)
        response.raise_for_status()

        # If .json() returns None, fall back on empty dict
        data = response.json() or {}

        # Drill down with or {} at each step to avoid None.get errors
        panel_info = (data.get('data') or {}) \
            .get('mainHouseInfoPanelInfo') or {}
        main_info = panel_info.get('mainHouseInfo') or {}

        # Now safe to pull lists
        listing_agents = main_info.get('listingAgents') or []
        buying_agents  = main_info.get('buyingAgents')  or []

        # Defaults
        list_agent_name_1 = list_broker_name_1 = None
        list_agent_name_2 = list_broker_name_2 = None
        buy_agent_name_1  = buy_broker_name_1  = None
        buy_agent_name_2  = buy_broker_name_2  = None

        # Extract up to two listing agents
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}) \
                                             .get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}) \
                                             .get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')

        # Extract up to two buying agents
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}) \
                                            .get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}) \
                                            .get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')

        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 84

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $715,219

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $547

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $60,078,400

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input county name:
#  Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 135
# -----------
# Input Previous Week Condo Average Sales Price:
# 903964
# -----------
# Input Previous Week Condo Average PSF:
# 580
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 122035163.0

# %%
last_week
# Out:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          135              903964          580                    122035163.0

# %%
last_week['Last Week Total Dollar Volume'].iloc[0]
# Out:
# 122035163.0

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           84              715219          547                     60078400.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE             ADDRESS         CITY  \
# 0  PAST SALE 2025-06-24   Condo/Co-op  1455 Ocean Dr #809  Miami Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33139.0  4300000.0   3.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  MARMLS  A11774776
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None  Adriana Briceno
#
#        buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Compass Florida, LLC.             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-06-24   Condo/Co-op           1455 Ocean Dr #809
# 1  PAST SALE 2025-06-27   Condo/Co-op         788 NE 23rd St #3502
# 2  PAST SALE 2025-06-27   Condo/Co-op            102 24th St #1045
# 3  PAST SALE 2025-06-24   Condo/Co-op     2627 S Bayshore Dr #2605
# 4  PAST SALE 2025-06-27   Condo/Co-op  1121 Crandon Blvd Unit F602
# 5  PAST SALE 2025-06-27   Condo/Co-op        700 NE 26th Ter #2302
# 6  PAST SALE 2025-06-27   Condo/Co-op       5875 Collins Ave #1507
# 7  PAST SALE 2025-06-24   Condo/Co-op  300 Biscayne Blvd Way #2306
# 8  PAST SALE 2025-06-27   Condo/Co-op     2020 N Bayshore Dr #2402
# 9  PAST SALE 2025-06-24   Condo/Co-op      2020 N Bayshore Dr #903
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0    Miami Beach                FL             33139.0  4300000.0   3.0
# 1          Miami                FL             33137.0  3000000.0   4.0
# 2    Miami Beach                FL             33139.0  2900000.0   2.0
# 3  Coconut Grove                FL             33133.0  2600000.0   2.0
# 4   Key Biscayne                FL             33149.0  1950000.0   3.0
# 5          Miami                FL             33137.0  1950000.0   2.0
# 6    Miami Beach                FL             33140.0  1775000.0   2.0
# 7          Miami                FL             33131.0  1750000.0   2.0
# 8          Miami                FL             33137.0  1700000.0   3.0
# 9          Miami                FL             33137.0  1470000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
# 1    4.5              NANCY TERRACE       3326.0       NaN      2021.0
# 2    2.0        2399 COLLINS AVENUE       1123.0       NaN      2015.0
# 3    2.5       GROVENOR HOUSE CONDO       1756.0       NaN      2006.0
# 4    3.0  TOWERS OF KEY BISCAYNE CO       2402.0       NaN      1971.0
# 5    3.5               MISSONI BAIA       2348.0       NaN      2023.0
# 6    2.5                  MEI CONDO       1323.0       NaN      2008.0
# 7    2.5    Aston Martin Residences       1317.0       NaN      2024.0
# 8    3.5        PARAMOUNT BAY CONDO       2201.0       NaN      2010.0
# 9    3.0        PARAMOUNT BAY CONDO       1708.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
# 1             NaN          902.0     4973.0   Sold
# 2             NaN         2582.0     6952.0   Sold
# 3             NaN         1481.0     5430.0   Sold
# 4             NaN          812.0     2876.0   Sold
# 5             NaN          830.0     3631.0   Sold
# 6             NaN         1342.0     3307.0   Sold
# 7             NaN         1329.0     2243.0   Sold
# 8             NaN          772.0     3587.0   Sold
# 9             NaN          861.0     2802.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...       MARMLS  A11774776
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...       MARMLS  A11792281
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...       MARMLS  A11792330
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...       MARMLS  A11786394
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       MARMLS  A11734384
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...       MARMLS  A11793470
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...       MARMLS  A11713614
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...  Beaches MLS  F10467425
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11588531
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11744723
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
# 1        N          Y  25.799065 -80.185542
# 2        N          Y  25.799770 -80.126865
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.683541 -80.157137
# 5        N          Y  25.802006 -80.185769
# 6        N          Y  25.840891 -80.120220
# 7        N          Y  25.770777 -80.187521
# 8        N          Y  25.796683 -80.187669
# 9        N          Y  25.796683 -80.187669
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...            Liz Hogan
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...          Tracy Galya
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...        Michael Light
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       Mario Gallardo
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...        Stefan Segall
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...  Yackeline Leiderman
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...         Nur Ela Mast
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...      Elizabeth James
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...           Sep Niakan
#
#                    list_broker_name_1    list_agent_name_2  \
# 0                     Douglas Elliman                 None
# 1               Compass Florida, LLC.                 None
# 2                     Douglas Elliman                 None
# 3                     Douglas Elliman         Jaimee Light
# 4  One Sotheby's International Realty  Jacqueline Gallardo
# 5                Compass Florida, LLC        Rana Tilllawi
# 6        Fortune Christie's Intl R.E.                 None
# 7        Florida Luxurious Properties                 None
# 8               Star Bay Realty Corp.                 None
# 9                Blackbook Properties  Stephanie Bienstock
#
#                    list_broker_name_2   buy_agent_name_1  \
# 0                                None    Adriana Briceno
# 1                                None          Liz Hogan
# 2                                None     Joseph Brikman
# 3                     Douglas Elliman         Eric Davis
# 4  One Sotheby's International Realty     Thelma Vanolli
# 5               Compass Florida, LLC.    Jonathan Gutman
# 6                                None        Betsy Magde
# 7                                None       Nur Ela Mast
# 8                                None  Christopher Pessy
# 9                Blackbook Properties     Andrew Becerra
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0               Compass Florida, LLC.             None              None
# 1               Compass Florida, LLC.             None              None
# 2                     Real Broker LLC  Rebecca Fischer   Real Broker LLC
# 3  One Sotheby's International Realty             None              None
# 4             United Realty Group Inc             None              None
# 5             United Realty Group Inc             None              None
# 6               Compass Florida, LLC.             None              None
# 7        Florida Luxurious Properties             None              None
# 8                Compass Florida, LLC             None              None
# 9                      EXP Realty LLC             None              None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
# %store -r map_box_api_key

# %%
import folium
from branca.element import Template, MacroElement

# ——— Your title & caption HTML ———
title_html = f'''
  <h3 align="center" style="font-size:16px"><b>Recent {county} County Condo Sales</b></h3>
'''
caption_html = f'''
  <p align="center" style="font-size:13px"><i>{week_starting} — {week_ending}</i></p>
'''

# ——— Base map ———
m = folium.Map(
    location=df[['LATITUDE','LONGITUDE']].mean().to_list(),
    zoom_start=10.5,
    tiles=None
)

# ——— Tile layers ———
folium.TileLayer('OpenStreetMap', name='OSM', control=False).add_to(m)
folium.TileLayer(
    tiles=(
        "https://api.mapbox.com/styles/v1/"
        "mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x"
        f"?access_token={map_box_api_key}"
    ),
    attr="Mapbox", name="Streets", control=False
).add_to(m)

# ——— Add your markers ———
for _, row in df_top_ten.iterrows():
    lat, lon = row['LATITUDE'], row['LONGITUDE']
    popup = folium.Popup(popup_html(row), max_width=400)

    if row['COLOR'] == 'blue':
        # Regular sale: blue circle
        folium.CircleMarker(
            location=(lat, lon),
            radius=7,
            fill=True,
            fill_color='blue',
            fill_opacity=0.5,
            color=None,
            popup=popup
        ).add_to(m)
    else:
        # Top sale: gold star
        folium.Marker(
            location=(lat, lon),
            popup=popup,
            icon=folium.DivIcon(
                html="""
                <div style="font-size:24px; line-height:24px; color:gold;">
                  &#9733;
                </div>
                """
            )
        ).add_to(m)

# ——— Layer control, title & caption ———
folium.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))

# ——— Optional legend via branca ———
legend_html = """
{% macro html(this, kwargs) %}
  <div style="
      position: fixed;
      bottom: 50px; left: 50px;
      background: white; padding: 8px;
      border: 2px solid grey;
      font-size: 12px;
      z-index: 9999;
  ">
    <div style="display:inline-block; font-size:18px; color:gold; margin-right:6px;">&#9733;</div> Top Sale<br>
    <i style="background: blue; width: 10px; height: 10px;
       display: inline-block; margin-right: 6px;"></i> All other sales
  </div>
{% endmacro %}
"""
legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)

# ——— Display ———
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc99cdd80625443e557bbc9e6a30c3ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade County Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#   &lt;p align=&quot;center&quot; style=&quot;font-size:13px&quot;&gt;&lt;i&gt;June 23 — June 29&lt;/i&gt;&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc99cdd80625443e557bbc9e6a30c3ab&quot; &gt;&lt;/div&gt;
#
#
#   &lt;div style=&quot;
#       position: fixed;
#       bottom: 50px; left: 50px;
#       background: white; padding: 8px;
#       border: 2px solid grey;
#       font-size: 12px;
#       z-index: 9999;
#   &quot;&gt;
#     &lt;div style=&quot;display:inline-block; font-size:18px; color:gold; margin-right:6px;&quot;&gt;&amp;#9733;&lt;/div&gt; Top Sale&lt;br&gt;
#     &lt;i style=&quot;background: blue; width: 10px; height: 10px;
#        display: inline-block; margin-right: 6px;&quot;&gt;&lt;/i&gt; All other sales
#   &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_dc99cdd80625443e557bbc9e6a30c3ab = L.map(
#                 &quot;map_dc99cdd80625443e557bbc9e6a30c3ab&quot;,
#                 {
#                     center: [25.813812602419357, -80.22029945725805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3d0e6118a4a0d2a70164f8e9dcbb4ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc99cdd80625443e557bbc9e6a30c3ab);
#
#
#             var tile_layer_0f9c5334eb23da38acfdd6dd375ee5af = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoidHJkZGF0YSIsImEiOiJjamc2bTc2YmUxY2F3MnZxZGh2amR2MTY5In0.QlOWqB-yQNrNlXD0KQ9IvQ&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc99cdd80625443e557bbc9e6a30c3ab);
#
#
#             var marker_5e62b387f76ee580cf95fba82c1165ba = L.marker(
#                 [25.7873169, -80.1293566],
#                 {}
#             ).addTo(map_dc99cdd80625443e557bbc9e6a30c3ab);
#
#
#             var div_icon_034ea7afa02390522f6cf798b2f09c41 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size:24px; line-height:24px; color:gold;\&quot;\u003e\n                  \u0026#9733;\n                \u003c/div\u003e\n                &quot;});
#             marker_5e62b387f76ee580cf95fba82c1165ba.setIcon(div_icon_034ea7afa02390522f6cf798b2f09c41);
#
#
#         var popup_cdf9ca9013106e45a8062878a5424435 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_d428c7ae3d7d0217a976678c43329f45 = $(`&lt;div id=&quot;html_d428c7ae3d7d0217a976678c43329f45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1455 Ocean Dr #809&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,300,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,911.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,250.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1998.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_cdf9ca9013106e45a8062878a5424435.setContent(html_d428c7ae3d7d0217a976678c43329f45);
#
#
#
#         marker_5e62b387f76ee580cf95fba82c1165ba.bindPopup(popup_cdf9ca9013106e45a8062878a5424435)
#         ;
#
#
#
#
#             var circle_marker_c7259b0c63effb66770eef89535b3a33 = L.circleMarker(
#                 [25.7990651, -80.1855416],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dc99cdd80625443e557bbc9e6a30c3ab);
#
#
#         var popup_36e13316c67c9ecbb8eeb052b3580c0f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_7331d2d40e27fffe45ddc9aa8e402263 = $(`&lt;div id=&quot;html_7331d2d40e27fffe45ddc9aa8e402263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;788 NE 23rd St #3502&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,000,000.0&lt;br&gt;     &lt;strong&gt;Price

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE             ADDRESS         CITY  \
# 0  PAST SALE 2025-06-24   Condo/Co-op  1455 Ocean Dr #809  Miami Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33139.0  4300000.0   3.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  MARMLS  A11774776
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None  Adriana Briceno
#
#        buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Compass Florida, LLC.             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06302025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #809 in Miami Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-06-24   Condo/Co-op           1455 Ocean Dr #809
# 1  PAST SALE 2025-06-27   Condo/Co-op         788 NE 23rd St #3502
# 2  PAST SALE 2025-06-27   Condo/Co-op            102 24th St #1045
# 3  PAST SALE 2025-06-24   Condo/Co-op     2627 S Bayshore Dr #2605
# 4  PAST SALE 2025-06-27   Condo/Co-op  1121 Crandon Blvd Unit F602
# 5  PAST SALE 2025-06-27   Condo/Co-op        700 NE 26th Ter #2302
# 6  PAST SALE 2025-06-27   Condo/Co-op       5875 Collins Ave #1507
# 7  PAST SALE 2025-06-24   Condo/Co-op  300 Biscayne Blvd Way #2306
# 8  PAST SALE 2025-06-27   Condo/Co-op     2020 N Bayshore Dr #2402
# 9  PAST SALE 2025-06-24   Condo/Co-op      2020 N Bayshore Dr #903
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0    Miami Beach                FL             33139.0  4300000.0   3.0
# 1          Miami                FL             33137.0  3000000.0   4.0
# 2    Miami Beach                FL             33139.0  2900000.0   2.0
# 3  Coconut Grove                FL             33133.0  2600000.0   2.0
# 4   Key Biscayne                FL             33149.0  1950000.0   3.0
# 5          Miami                FL             33137.0  1950000.0   2.0
# 6    Miami Beach                FL             33140.0  1775000.0   2.0
# 7          Miami                FL             33131.0  1750000.0   2.0
# 8          Miami                FL             33137.0  1700000.0   3.0
# 9          Miami                FL             33137.0  1470000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
# 1    4.5              NANCY TERRACE       3326.0       NaN      2021.0
# 2    2.0        2399 COLLINS AVENUE       1123.0       NaN      2015.0
# 3    2.5       GROVENOR HOUSE CONDO       1756.0       NaN      2006.0
# 4    3.0  TOWERS OF KEY BISCAYNE CO       2402.0       NaN      1971.0
# 5    3.5               MISSONI BAIA       2348.0       NaN      2023.0
# 6    2.5                  MEI CONDO       1323.0       NaN      2008.0
# 7    2.5    Aston Martin Residences       1317.0       NaN      2024.0
# 8    3.5        PARAMOUNT BAY CONDO       2201.0       NaN      2010.0
# 9    3.0        PARAMOUNT BAY CONDO       1708.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
# 1             NaN          902.0     4973.0   Sold
# 2             NaN         2582.0     6952.0   Sold
# 3             NaN         1481.0     5430.0   Sold
# 4             NaN          812.0     2876.0   Sold
# 5             NaN          830.0     3631.0   Sold
# 6             NaN         1342.0     3307.0   Sold
# 7             NaN         1329.0     2243.0   Sold
# 8             NaN          772.0     3587.0   Sold
# 9             NaN          861.0     2802.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...       MARMLS  A11774776
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...       MARMLS  A11792281
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...       MARMLS  A11792330
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...       MARMLS  A11786394
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       MARMLS  A11734384
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...       MARMLS  A11793470
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...       MARMLS  A11713614
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...  Beaches MLS  F10467425
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11588531
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11744723
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
# 1        N          Y  25.799065 -80.185542
# 2        N          Y  25.799770 -80.126865
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.683541 -80.157137
# 5        N          Y  25.802006 -80.185769
# 6        N          Y  25.840891 -80.120220
# 7        N          Y  25.770777 -80.187521
# 8        N          Y  25.796683 -80.187669
# 9        N          Y  25.796683 -80.187669
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...            Liz Hogan
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...          Tracy Galya
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...        Michael Light
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       Mario Gallardo
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...        Stefan Segall
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...  Yackeline Leiderman
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...         Nur Ela Mast
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...      Elizabeth James
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...           Sep Niakan
#
#                    list_broker_name_1    list_agent_name_2  \
# 0                     Douglas Elliman                 None
# 1               Compass Florida, LLC.                 None
# 2                     Douglas Elliman                 None
# 3                     Douglas Elliman         Jaimee Light
# 4  One Sotheby's International Realty  Jacqueline Gallardo
# 5                Compass Florida, LLC        Rana Tilllawi
# 6        Fortune Christie's Intl R.E.                 None
# 7        Florida Luxurious Properties                 None
# 8               Star Bay Realty Corp.                 None
# 9                Blackbook Properties  Stephanie Bienstock
#
#                    list_broker_name_2   buy_agent_name_1  \
# 0                                None    Adriana Briceno
# 1                                None          Liz Hogan
# 2                                None     Joseph Brikman
# 3                     Douglas Elliman         Eric Davis
# 4  One Sotheby's International Realty     Thelma Vanolli
# 5               Compass Florida, LLC.    Jonathan Gutman
# 6                                None        Betsy Magde
# 7                                None       Nur Ela Mast
# 8                                None  Christopher Pessy
# 9                Blackbook Properties     Andrew Becerra
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0               Compass Florida, LLC.             None              None
# 1               Compass Florida, LLC.             None              None
# 2                     Real Broker LLC  Rebecca Fischer   Real Broker LLC
# 3  One Sotheby's International Realty             None              None
# 4             United Realty Group Inc             None              None
# 5             United Realty Group Inc             None              None
# 6               Compass Florida, LLC.             None              None
# 7        Florida Luxurious Properties             None              None
# 8                Compass Florida, LLC             None              None
# 9                      EXP Realty LLC             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #80...
# 1     2    blue     NANCY TERRACE at 788 NE 23rd St #3502 in Miami
# 2     3    blue  2399 COLLINS AVENUE at 102 24th St #1045 in Mi...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #26...
# 4     5    blue  TOWERS OF KEY BISCAYNE CO at 1121 Crandon Blvd...
# 5     6    blue     MISSONI BAIA at 700 NE 26th Ter #2302 in Miami
# 6     7    blue  MEI CONDO at 5875 Collins Ave #1507 in Miami B...
# 7     8    blue  Aston Martin Residences at 300 Biscayne Blvd W...
# 8     9    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #240...
# 9    10    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #903...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: IL VILLAGGIO ON SOUTH BEA closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,470,000 to $4,300,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Miami Beach, Miami, Key Biscayne, Coconut Grove, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 84 condo sales totaling $60,078,400 million from June 23 to June 29. The previous week, brokers closed 135 condo sales totaling $122,035,163.
#
# Last week’s units sold for an average of $715,219, lower than the $903,964 average price from the previous week. The average price per square foot fell to $547 from $580, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,470,000.0 million to $4,300,000.0 million.
#
# IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #809 in Miami Beach took the top spot with a $4,300,000.0 million closing. The sale closed at $1,911.0 per square foot.
#
# T Kimberly Rodstein with Douglas Elliman, and None with None had the listing.
# Adriana Briceno with Compass Florida, LLC., and None with None represented the buyer.
#
# NANCY TERRACE at 788 NE 23rd St #3502 in Miami, closed for the second highest amount, $3,000,000.0, or $902.0 per square foot.
#
# Liz Hogan with Compass Florida, LLC., and None with None had the listing.
# Liz Hogan with Compass Florida, LLC., and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06302025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from June 23 to June 29:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-06-24   Condo/Co-op           1455 Ocean Dr #809
# 1  PAST SALE 2025-06-27   Condo/Co-op         788 NE 23rd St #3502
# 2  PAST SALE 2025-06-27   Condo/Co-op            102 24th St #1045
# 3  PAST SALE 2025-06-24   Condo/Co-op     2627 S Bayshore Dr #2605
# 4  PAST SALE 2025-06-27   Condo/Co-op  1121 Crandon Blvd Unit F602
# 5  PAST SALE 2025-06-27   Condo/Co-op        700 NE 26th Ter #2302
# 6  PAST SALE 2025-06-27   Condo/Co-op       5875 Collins Ave #1507
# 7  PAST SALE 2025-06-24   Condo/Co-op  300 Biscayne Blvd Way #2306
# 8  PAST SALE 2025-06-27   Condo/Co-op     2020 N Bayshore Dr #2402
# 9  PAST SALE 2025-06-24   Condo/Co-op      2020 N Bayshore Dr #903
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0    Miami Beach                FL             33139.0  4300000.0   3.0
# 1          Miami                FL             33137.0  3000000.0   4.0
# 2    Miami Beach                FL             33139.0  2900000.0   2.0
# 3  Coconut Grove                FL             33133.0  2600000.0   2.0
# 4   Key Biscayne                FL             33149.0  1950000.0   3.0
# 5          Miami                FL             33137.0  1950000.0   2.0
# 6    Miami Beach                FL             33140.0  1775000.0   2.0
# 7          Miami                FL             33131.0  1750000.0   2.0
# 8          Miami                FL             33137.0  1700000.0   3.0
# 9          Miami                FL             33137.0  1470000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
# 1    4.5              NANCY TERRACE       3326.0       NaN      2021.0
# 2    2.0        2399 COLLINS AVENUE       1123.0       NaN      2015.0
# 3    2.5       GROVENOR HOUSE CONDO       1756.0       NaN      2006.0
# 4    3.0  TOWERS OF KEY BISCAYNE CO       2402.0       NaN      1971.0
# 5    3.5               MISSONI BAIA       2348.0       NaN      2023.0
# 6    2.5                  MEI CONDO       1323.0       NaN      2008.0
# 7    2.5    Aston Martin Residences       1317.0       NaN      2024.0
# 8    3.5        PARAMOUNT BAY CONDO       2201.0       NaN      2010.0
# 9    3.0        PARAMOUNT BAY CONDO       1708.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
# 1             NaN          902.0     4973.0   Sold
# 2             NaN         2582.0     6952.0   Sold
# 3             NaN         1481.0     5430.0   Sold
# 4             NaN          812.0     2876.0   Sold
# 5             NaN          830.0     3631.0   Sold
# 6             NaN         1342.0     3307.0   Sold
# 7             NaN         1329.0     2243.0   Sold
# 8             NaN          772.0     3587.0   Sold
# 9             NaN          861.0     2802.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...       MARMLS  A11774776
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...       MARMLS  A11792281
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...       MARMLS  A11792330
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...       MARMLS  A11786394
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       MARMLS  A11734384
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...       MARMLS  A11793470
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...       MARMLS  A11713614
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...  Beaches MLS  F10467425
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11588531
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11744723
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
# 1        N          Y  25.799065 -80.185542
# 2        N          Y  25.799770 -80.126865
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.683541 -80.157137
# 5        N          Y  25.802006 -80.185769
# 6        N          Y  25.840891 -80.120220
# 7        N          Y  25.770777 -80.187521
# 8        N          Y  25.796683 -80.187669
# 9        N          Y  25.796683 -80.187669
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...            Liz Hogan
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...          Tracy Galya
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...        Michael Light
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       Mario Gallardo
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...        Stefan Segall
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...  Yackeline Leiderman
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...         Nur Ela Mast
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...      Elizabeth James
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...           Sep Niakan
#
#                    list_broker_name_1    list_agent_name_2  \
# 0                     Douglas Elliman                 None
# 1               Compass Florida, LLC.                 None
# 2                     Douglas Elliman                 None
# 3                     Douglas Elliman         Jaimee Light
# 4  One Sotheby's International Realty  Jacqueline Gallardo
# 5                Compass Florida, LLC        Rana Tilllawi
# 6        Fortune Christie's Intl R.E.                 None
# 7        Florida Luxurious Properties                 None
# 8               Star Bay Realty Corp.                 None
# 9                Blackbook Properties  Stephanie Bienstock
#
#                    list_broker_name_2   buy_agent_name_1  \
# 0                                None    Adriana Briceno
# 1                                None          Liz Hogan
# 2                                None     Joseph Brikman
# 3                     Douglas Elliman         Eric Davis
# 4  One Sotheby's International Realty     Thelma Vanolli
# 5               Compass Florida, LLC.    Jonathan Gutman
# 6                                None        Betsy Magde
# 7                                None       Nur Ela Mast
# 8                                None  Christopher Pessy
# 9                Blackbook Properties     Andrew Becerra
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0               Compass Florida, LLC.             None              None
# 1               Compass Florida, LLC.             None              None
# 2                     Real Broker LLC  Rebecca Fischer   Real Broker LLC
# 3  One Sotheby's International Realty             None              None
# 4             United Realty Group Inc             None              None
# 5             United Realty Group Inc             None              None
# 6               Compass Florida, LLC.             None              None
# 7        Florida Luxurious Properties             None              None
# 8                Compass Florida, LLC             None              None
# 9                      EXP Realty LLC             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #80...
# 1     2    blue     NANCY TERRACE at 788 NE 23rd St #3502 in Miami
# 2     3    blue  2399 COLLINS AVENUE at 102 24th St #1045 in Mi...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #26...
# 4     5    blue  TOWERS OF KEY BISCAYNE CO at 1121 Crandon Blvd...
# 5     6    blue     MISSONI BAIA at 700 NE 26th Ter #2302 in Miami
# 6     7    blue  MEI CONDO at 5875 Collins Ave #1507 in Miami B...
# 7     8    blue  Aston Martin Residences at 300 Biscayne Blvd W...
# 8     9    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #240...
# 9    10    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #903...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: IL VILLAGGIO ON SOUTH BEA closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,470,000 to $4,300,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Miami Beach, Miami, Key Biscayne, Coconut Grove, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 84 condo sales totaling $60,078,400 million from June 23 to June 29. The previous week, brokers closed 135 condo sales totaling $122,035,163.
#
# Last week’s units sold for an average of $715,219, lower than the $903,964 average price from the previous week. The average price per square foot fell to $547 from $580, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,470,000.0 million to $4,300,000.0 million.
#
# IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #809 in Miami Beach took the top spot with a $4,300,000.0 million closing. The sale closed at $1,911.0 per square foot.
#
# T Kimberly Rodstein with Douglas Elliman, and None with None had the listing.
# Adriana Briceno with Compass Florida, LLC., and None with None represented the buyer.
#
# NANCY TERRACE at 788 NE 23rd St #3502 in Miami, closed for the second highest amount, $3,000,000.0, or $902.0 per square foot.
#
# Liz Hogan with Compass Florida, LLC., and None with None had the listing.
# Liz Hogan with Compass Florida, LLC., and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06302025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from June 23 to June 29:
#
# Most Expensive
# IL VILLAGGIO ON SOUTH BEA, 1455 Ocean Dr #809, in Miami Beach | Price: $4,300,000 | $1,911 psf | Listing agents: T Kimberly Rodstein with Douglas Elliman and None with None | Buyer's agents: Adriana Briceno with Compass Florida, LLC. and None with None
#
# Least Expensive
# PARAMOUNT BAY CONDO, 2020 N Bayshore Dr #903, in Miami | Price: $1,470,000 | $861 psf | Listing agents: Sep Niakan with Blackbook Properties and Stephanie Bienstock with Blackbook Properties | Buyer's agents: Andrew Becerra with EXP Realty LLC and None with None
#
# Highest Price Per Square Foot
# 2399 COLLINS AVENUE, 102 24th St #1045, in Miami Beach | Price: $2,900,000 | $2,582 psf | Listing agents: Tracy Galya with Douglas Elliman and None with None | Buyer's agents: Joseph Brikman with Real Broker LLC and Rebecca Fischer with Real Broker LLC
#
# Lowest Price Per Square Foot
# PARAMOUNT BAY CONDO, 2020 N Bayshore Dr #2402, in Miami | Price: $1,700,000 | $772 psf | Listing agents: Elizabeth James with Star Bay Realty Corp. and None with None | Buyer's agents: Christopher Pessy with Compass Florida, LLC and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Miami-Beach/1455-Ocean-Dr-33139/unit-809/home/42797369
# Second priciest sale:  https://www.redfin.com/FL/Miami/788-NE-23rd-St-33137/unit-3502/home/174545653
# Cheapest top ten sale:  https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-903/home/50122015
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-2402/home/50121322
# Highest top ten psf:  https://www.redfin.com/FL/Miami-Beach/102-24th-St-33139/unit-1045/home/79136359
# Lowest top ten psf:  https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-2402/home/50121322

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Miami-Beach/1455-Ocean-Dr-33139/unit-809/home/42797369

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Miami/788-NE-23rd-St-33137/unit-3502/home/174545653

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-903/home/50122015

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-2402/home/50121322

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/102-24th-St-33139/unit-1045/home/79136359

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Miami/2020-N-Bayshore-Dr-33137/unit-2402/home/50121322

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-06-24   Condo/Co-op           1455 Ocean Dr #809
# 1  PAST SALE 2025-06-27   Condo/Co-op         788 NE 23rd St #3502
# 2  PAST SALE 2025-06-27   Condo/Co-op            102 24th St #1045
# 3  PAST SALE 2025-06-24   Condo/Co-op     2627 S Bayshore Dr #2605
# 4  PAST SALE 2025-06-27   Condo/Co-op  1121 Crandon Blvd Unit F602
# 5  PAST SALE 2025-06-27   Condo/Co-op        700 NE 26th Ter #2302
# 6  PAST SALE 2025-06-27   Condo/Co-op       5875 Collins Ave #1507
# 7  PAST SALE 2025-06-24   Condo/Co-op  300 Biscayne Blvd Way #2306
# 8  PAST SALE 2025-06-27   Condo/Co-op     2020 N Bayshore Dr #2402
# 9  PAST SALE 2025-06-24   Condo/Co-op      2020 N Bayshore Dr #903
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0    Miami Beach                FL             33139.0  4300000.0   3.0
# 1          Miami                FL             33137.0  3000000.0   4.0
# 2    Miami Beach                FL             33139.0  2900000.0   2.0
# 3  Coconut Grove                FL             33133.0  2600000.0   2.0
# 4   Key Biscayne                FL             33149.0  1950000.0   3.0
# 5          Miami                FL             33137.0  1950000.0   2.0
# 6    Miami Beach                FL             33140.0  1775000.0   2.0
# 7          Miami                FL             33131.0  1750000.0   2.0
# 8          Miami                FL             33137.0  1700000.0   3.0
# 9          Miami                FL             33137.0  1470000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  IL VILLAGGIO ON SOUTH BEA       2250.0       NaN      1998.0
# 1    4.5              NANCY TERRACE       3326.0       NaN      2021.0
# 2    2.0        2399 COLLINS AVENUE       1123.0       NaN      2015.0
# 3    2.5       GROVENOR HOUSE CONDO       1756.0       NaN      2006.0
# 4    3.0  TOWERS OF KEY BISCAYNE CO       2402.0       NaN      1971.0
# 5    3.5               MISSONI BAIA       2348.0       NaN      2023.0
# 6    2.5                  MEI CONDO       1323.0       NaN      2008.0
# 7    2.5    Aston Martin Residences       1317.0       NaN      2024.0
# 8    3.5        PARAMOUNT BAY CONDO       2201.0       NaN      2010.0
# 9    3.0        PARAMOUNT BAY CONDO       1708.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1911.0     4456.0   Sold
# 1             NaN          902.0     4973.0   Sold
# 2             NaN         2582.0     6952.0   Sold
# 3             NaN         1481.0     5430.0   Sold
# 4             NaN          812.0     2876.0   Sold
# 5             NaN          830.0     3631.0   Sold
# 6             NaN         1342.0     3307.0   Sold
# 7             NaN         1329.0     2243.0   Sold
# 8             NaN          772.0     3587.0   Sold
# 9             NaN          861.0     2802.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...       MARMLS  A11774776
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...       MARMLS  A11792281
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...       MARMLS  A11792330
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...       MARMLS  A11786394
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       MARMLS  A11734384
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...       MARMLS  A11793470
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...       MARMLS  A11713614
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...  Beaches MLS  F10467425
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11588531
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...       MARMLS  A11744723
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.787317 -80.129357
# 1        N          Y  25.799065 -80.185542
# 2        N          Y  25.799770 -80.126865
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.683541 -80.157137
# 5        N          Y  25.802006 -80.185769
# 6        N          Y  25.840891 -80.120220
# 7        N          Y  25.770777 -80.187521
# 8        N          Y  25.796683 -80.187669
# 9        N          Y  25.796683 -80.187669
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/1455-Oce...  T Kimberly Rodstein
# 1  https://www.redfin.com/FL/Miami/788-NE-23rd-St...            Liz Hogan
# 2  https://www.redfin.com/FL/Miami-Beach/102-24th...          Tracy Galya
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...        Michael Light
# 4  https://www.redfin.com/FL/Key-Biscayne/1121-Cr...       Mario Gallardo
# 5  https://www.redfin.com/FL/Miami/700-NE-26th-Te...        Stefan Segall
# 6  https://www.redfin.com/FL/Miami-Beach/5875-Col...  Yackeline Leiderman
# 7  https://www.redfin.com/FL/Miami/300-Biscayne-B...         Nur Ela Mast
# 8  https://www.redfin.com/FL/Miami/2020-N-Bayshor...      Elizabeth James
# 9  https://www.redfin.com/FL/Miami/2020-N-Bayshor...           Sep Niakan
#
#                    list_broker_name_1    list_agent_name_2  \
# 0                     Douglas Elliman                 None
# 1               Compass Florida, LLC.                 None
# 2                     Douglas Elliman                 None
# 3                     Douglas Elliman         Jaimee Light
# 4  One Sotheby's International Realty  Jacqueline Gallardo
# 5                Compass Florida, LLC        Rana Tilllawi
# 6        Fortune Christie's Intl R.E.                 None
# 7        Florida Luxurious Properties                 None
# 8               Star Bay Realty Corp.                 None
# 9                Blackbook Properties  Stephanie Bienstock
#
#                    list_broker_name_2   buy_agent_name_1  \
# 0                                None    Adriana Briceno
# 1                                None          Liz Hogan
# 2                                None     Joseph Brikman
# 3                     Douglas Elliman         Eric Davis
# 4  One Sotheby's International Realty     Thelma Vanolli
# 5               Compass Florida, LLC.    Jonathan Gutman
# 6                                None        Betsy Magde
# 7                                None       Nur Ela Mast
# 8                                None  Christopher Pessy
# 9                Blackbook Properties     Andrew Becerra
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0               Compass Florida, LLC.             None              None
# 1               Compass Florida, LLC.             None              None
# 2                     Real Broker LLC  Rebecca Fischer   Real Broker LLC
# 3  One Sotheby's International Realty             None              None
# 4             United Realty Group Inc             None              None
# 5             United Realty Group Inc             None              None
# 6               Compass Florida, LLC.             None              None
# 7        Florida Luxurious Properties             None              None
# 8                Compass Florida, LLC             None              None
# 9                      EXP Realty LLC             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  IL VILLAGGIO ON SOUTH BEA at 1455 Ocean Dr #80...
# 1     2    blue     NANCY TERRACE at 788 NE 23rd St #3502 in Miami
# 2     3    blue  2399 COLLINS AVENUE at 102 24th St #1045 in Mi...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #26...
# 4     5    blue  TOWERS OF KEY BISCAYNE CO at 1121 Crandon Blvd...
# 5     6    blue     MISSONI BAIA at 700 NE 26th Ter #2302 in Miami
# 6     7    blue  MEI CONDO at 5875 Collins Ave #1507 in Miami B...
# 7     8    blue  Aston Martin Residences at 300 Biscayne Blvd W...
# 8     9    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #240...
# 9    10    blue  PARAMOUNT BAY CONDO at 2020 N Bayshore Dr #903...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 5, 1) ## List (Earlier) date
date2 = datetime(2025, 6, 27) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 57

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING AGENTS'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING AGENTS'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
chart_df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME', 'LISTING AGENTS',
#        'BUYING AGENTS'],
#       dtype='object')

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "BEDS", 
    "BATHS",
    "SOURCE", 
    "MLS#"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df = chart_df.rename(columns={'$/SQUARE FEET':'PPSF'})

# %%
chart_df['PPSF'].astype(float)
# Out:
# 0    1911.0
# 1     902.0
# 2    2582.0
# 3    1481.0
# 4     812.0
# 5     830.0
# 6    1342.0
# 7    1329.0
# 8     772.0
# 9     861.0
# Name: PPSF, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['PPSF'] = chart_df['PPSF'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))

# %%
desired_order = [
    'SOLD DATE',
    'LOCATION',
    'ADDRESS',
    'PRICE',
    'SQUARE FEET',
    'PPSF',
    'YEAR BUILT',
    'LISTING AGENTS',
    'BUYING AGENTS'
]

chart_df = chart_df[desired_order]

# %%
chart_df
# Out:
#    SOLD DATE                   LOCATION  \
# 0 2025-06-24  IL VILLAGGIO ON SOUTH BEA
# 1 2025-06-27              NANCY TERRACE
# 2 2025-06-27        2399 COLLINS AVENUE
# 3 2025-06-24       GROVENOR HOUSE CONDO
# 4 2025-06-27  TOWERS OF KEY BISCAYNE CO
# 5 2025-06-27               MISSONI BAIA
# 6 2025-06-27                  MEI CONDO
# 7 2025-06-24    Aston Martin Residences
# 8 2025-06-27        PARAMOUNT BAY CONDO
# 9 2025-06-24        PARAMOUNT BAY CONDO
#
#                                        ADDRESS       PRICE SQUARE FEET  \
# 0            1455 Ocean Dr #809 in Miami Beach  $4,300,000       2,250
# 1                788 NE 23rd St #3502 in Miami  $3,000,000       3,326
# 2             102 24th St #1045 in Miami Beach  $2,900,000       1,123
# 3    2627 S Bayshore Dr #2605 in Coconut Grove  $2,600,000       1,756
# 4  1121 Crandon Blvd Unit F602 in Key Biscayne  $1,950,000       2,402
# 5               700 NE 26th Ter #2302 in Miami  $1,950,000       2,348
# 6        5875 Collins Ave #1507 in Miami Beach  $1,775,000       1,323
# 7         300 Biscayne Blvd Way #2306 in Miami  $1,750,000       1,317
# 8            2020 N Bayshore Dr #2402 in Miami  $1,700,000       2,201
# 9             2020 N Bayshore Dr #903 in Miami  $1,470,000       1,708
#
#      PPSF YEAR BUILT                                     LISTING AGENTS  \
# 0  $1,911       1998            T Kimberly Rodstein Douglas Elliman
# 1    $902       2021                Liz Hogan Compass Florida, LLC.
# 2  $2,582       2015                    Tracy Galya Douglas Elliman
# 3  $1,481       2006  Michael Light Douglas Elliman Jaimee Light Dou...
# 4    $812       1971  Mario Gallardo One Sotheby's International Rea...
# 5    $830       2023  Stefan Segall Compass Florida, LLC Rana Tillla...
# 6  $1,342       2008  Yackeline Leiderman Fortune Christie's Intl R....
# 7  $1,329       2024      Nur Ela Mast Florida Luxurious Properties
# 8    $772       2010          Elizabeth James Star Bay Realty Corp.
# 9    $861       2010  Sep Niakan Blackbook Properties Stephanie Bien...
#
#                                        BUYING AGENTS
# 0          Adriana Briceno Compass Florida, LLC.
# 1                Liz Hogan Compass Florida, LLC.
# 2  Joseph Brikman Real Broker LLC Rebecca Fischer...
# 3  Eric Davis One Sotheby's International Realty
# 4         Thelma Vanolli United Realty Group Inc
# 5        Jonathan Gutman United Realty Group Inc
# 6              Betsy Magde Compass Florida, LLC.
# 7      Nur Ela Mast Florida Luxurious Properties
# 8         Christopher Pessy Compass Florida, LLC
# 9                  Andrew Becerra EXP Realty LLC

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df.columns
# Out:
# Index(['SOLD DATE', 'LOCATION', 'ADDRESS', 'PRICE', 'SQUARE FEET', 'PPSF',
#        'YEAR BUILT', 'LISTING AGENTS', 'BUYING AGENTS'],
#       dtype='object')
