# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import folium
import geopandas as gpd
import glob
from datetime import datetime, timedelta

# %% [markdown]
# ## Data Read-in

# %%
df = pd.read_csv('2023 eviction notices.xlsx - Sheet1.csv')

# %%
df['File Date'] = pd.to_datetime(df['File Date'])

# %%
df_filtered = df[df['File Date'] > '5.31.23']

# %%
df_filtered = df_filtered.drop_duplicates(subset='Eviction ID')

# %%
columns_to_check = ['Non Payment', 'Breach',
       'Nuisance', 'Illegal Use', 'Failure to Sign Renewal', 'Access Denial',
       'Unapproved Subtenant', 'Owner Move In', 'Demolition',
       'Capital Improvement', 'Substantial Rehab', 'Ellis Act WithDrawal',
       'Condo Conversion', 'Roommate Same Unit', 'Other Cause',
       'Late Payments', 'Lead Remediation', 'Development',
       'Good Samaritan Ends']

# %%
df_filtered['Eviction_Reason'] = df_filtered[columns_to_check].idxmax(axis=1)

# %%
df_filtered['Eviction_Reason'].value_counts()
# Out:
# Eviction_Reason
# Nuisance                158
# Non Payment              43
# Capital Improvement      36
# Breach                   35
# Owner Move In            30
# Ellis Act WithDrawal     24
# Other Cause              11
# Roommate Same Unit        8
# Unapproved Subtenant      7
# Illegal Use               1
# Access Denial             1
# Late Payments             1
# Name: count, dtype: int64

# %% [markdown]
# ## HTML Popup Formatter

# %%
def popup_html(row):
    Eviction_ID = row['Eviction ID']
    Address = row['Address']
    Neighborhood = row['Neighborhoods - Analysis Boundaries']
    Eviction_Reason = row['Eviction_Reason']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Eviction ID: </strong>{}'''.format(Eviction_ID) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Neighborhood: </strong>{}'''.format(Neighborhood) + '''<br>
    <strong>Eviction Reason: </strong>{}'''.format(Eviction_Reason) + '''<br>
    </html>
    '''
    return html

# %%
df_filtered.columns
# Out:
# Index(['Eviction ID', 'Address', 'City', 'State',
#        'Eviction Notice Source Zipcode', 'File Date', 'Non Payment', 'Breach',
#        'Nuisance', 'Illegal Use', 'Failure to Sign Renewal', 'Access Denial',
#        'Unapproved Subtenant', 'Owner Move In', 'Demolition',
#        'Capital Improvement', 'Substantial Rehab', 'Ellis Act WithDrawal',
#        'Condo Conversion', 'Roommate Same Unit', 'Other Cause',
#        'Late Payments', 'Lead Remediation', 'Development',
#        'Good Samaritan Ends', 'Constraints Date', 'Supervisor District',
#        'Neighborhoods - Analysis Boundaries', 'Location', 'Shape',
#        'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'DELETE - Neighborhoods', 'DELETE - Police Districts',
#        'DELETE - Supervisor Districts', 'DELETE - Fire Prevention Districts',
#        'DELETE - Zip Codes', 'CBD, BID and GBD Boundaries as of 2017',
#        'Central Market/Tenderloin Boundary', 'Areas of Vulnerability, 2016',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Fix It Zones as of 2018-02-07', 'Neighborhoods', 'Eviction_Reason'],
#       dtype='object')

# %%
# Remove parentheses and split the 'Location' column
df_filtered[['LATITUDE', 'LONGITUDE']] = df_filtered['Location'].str.replace('[()]', '', regex=True).str.split(', ', expand=True)

# Convert 'LATITUDE' and 'LONGITUDE' to numeric types
df_filtered['LATITUDE'] = pd.to_numeric(df_filtered['LATITUDE'], errors='coerce')
df_filtered['LONGITUDE'] = pd.to_numeric(df_filtered['LONGITUDE'], errors='coerce')

# %%
len(df_filtered)
# Out:
# 355

# %%
df_filtered = df_filtered.dropna(subset=['LATITUDE','LONGITUDE'])

# %%
### Create map container ###
m = folium.Map(location=df_filtered[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=11,tiles=None)

### Create title ###
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f"San Francisco eviction notices for the second half of 2023")

m.get_root().html.add_child(folium.Element(title_html))

for index, row in df_filtered.iterrows():
    marker = folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        radius=5,
        fill=True,
        popup=folium.Popup(popup_html(row), max_width=400))
    marker.add_to(m)

# Add the FeatureGroups to the map

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4724712686d0abdfeb0ed5a73525dd00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;San Francisco eviction notices for the second half of 2023&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4724712686d0abdfeb0ed5a73525dd00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4724712686d0abdfeb0ed5a73525dd00 = L.map(
#                 &quot;map_4724712686d0abdfeb0ed5a73525dd00&quot;,
#                 {
#                     center: [37.76296138709477, -122.42918501733895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var marker_4b731f197facb29812f4799203fec9c4 = L.marker(
#                 [37.74231153578174, -122.47129138540214],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_4724712686d0abdfeb0ed5a73525dd00);
#
#
#         var popup_fcb8b45ad38944995aa36ef502ea91f6 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f8ccb56b46ac457f6136f1d06cb9547f = $(`&lt;div id=&quot;html_f8ccb56b46ac457f6136f1d06cb9547f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231384&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;2400 Block Of 15th  Avenue&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;West of Twin Peaks&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_fcb8b45ad38944995aa36ef502ea91f6.setContent(html_f8ccb56b46ac457f6136f1d06cb9547f);
#
#
#
#         marker_4b731f197facb29812f4799203fec9c4.bindPopup(popup_fcb8b45ad38944995aa36ef502ea91f6)
#         ;
#
#
#
#
#             var marker_825cbb8ce084067c2762a7724b899092 = L.marker(
#                 [37.71327845826784, -122.47292413080852],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_4724712686d0abdfeb0ed5a73525dd00);
#
#
#         var popup_8d084905e3b2d2b9085bd25b171698aa = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_d43d902e0b347c2602e544a67dde0e8a = $(`&lt;div id=&quot;html_d43d902e0b347c2602e544a67dde0e8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231386&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;0 Block Of Chumasero  Drive&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Lakeshore&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_8d084905e3b2d2b9085bd25b171698aa.setContent(html_d43d902e0b347c2602e544a67dde0e8a);
#
#
#
#         marker_825cbb8ce084067c2762a7724b899092.bindPopup(popup_8d084905e3b2d2b9085bd25b171698aa)
#         ;
#
#
#
#
#             var marker_02f37b9930c0126ad2aeee538a9ecf5f = L.marker(
#                 [37.720253860588926, -122.43438503237964],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_4724712686d0abdfeb0ed5a73525dd00);
#
#
#         var popup_bf0d9f680cdd16bd28248ffb5dce14cd = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_eb43dc5e15a3b7815bbe65c918c67c7b = $(`&lt;div id=&quot;html_eb43dc5e15a3b7815bbe65c918c67c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231474&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;300 Block Of Russia  Avenue&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Excelsior&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Ellis Act WithDrawal&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_bf0d9f680cdd16bd28248ffb5dce14cd.setContent(html_eb43dc5e15a3b7815bbe65c918c67c7b);
#
#
#
#         marker_02f37b9930c0126ad2aeee538a9ecf5f.bindPopup(popup_bf0d9f680cdd16bd28248ffb5dce14cd)
#         ;
#
#
#
#
#             var marker_5d6a05e1f1c096fe7c715a33730324cc = L.marker(
#                 [37.75856482463206, -122.42017407474351],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_4724712686d0abdfeb0ed5a73525dd00);
#
#
#         var popup_7ffca09c083ac44c37b141d297db3c45 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_68c6d5a9e1b175e0f2efb0720c144d8f = $(`&lt;div id=&quot;html_68c6d5a9e1b175e0f2efb0720c144d8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231385&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;3500 Block Of 20th  Street&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Mission&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_7ffca09c083ac44c37b141d297db3c45.setContent(html_68c6d5a9e1b175e0f2efb0720c144d8f);
#
#
#
#         marker_5d6a05e1f1c096fe7c715a33730324cc.bindPopup(popup_7ffca09c083ac44c37b141d297db3c45)
#         ;
#
#
#
#
#             var marker_ea74af4d

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/SF_2023_eviction_notices_July_onwards
