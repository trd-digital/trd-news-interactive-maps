# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import folium
import geopandas as gpd
import glob
from datetime import datetime, timedelta

# %% [markdown]
# ## Data Read-in

# %%
df = pd.read_csv('2023 eviction notices.xlsx - Sheet1.csv')

# %%
df['File Date'] = pd.to_datetime(df['File Date'])

# %%
df_filtered = df[df['File Date'] > '5.31.23']

# %%
df_filtered.columns
# Out:
# Index(['Eviction ID', 'Address', 'City', 'State',
#        'Eviction Notice Source Zipcode', 'File Date', 'Non Payment', 'Breach',
#        'Nuisance', 'Illegal Use', 'Failure to Sign Renewal', 'Access Denial',
#        'Unapproved Subtenant', 'Owner Move In', 'Demolition',
#        'Capital Improvement', 'Substantial Rehab', 'Ellis Act WithDrawal',
#        'Condo Conversion', 'Roommate Same Unit', 'Other Cause',
#        'Late Payments', 'Lead Remediation', 'Development',
#        'Good Samaritan Ends', 'Constraints Date', 'Supervisor District',
#        'Neighborhoods - Analysis Boundaries', 'Location', 'Shape',
#        'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'DELETE - Neighborhoods', 'DELETE - Police Districts',
#        'DELETE - Supervisor Districts', 'DELETE - Fire Prevention Districts',
#        'DELETE - Zip Codes', 'CBD, BID and GBD Boundaries as of 2017',
#        'Central Market/Tenderloin Boundary', 'Areas of Vulnerability, 2016',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Fix It Zones as of 2018-02-07', 'Neighborhoods'],
#       dtype='object')

# %%
columns_to_check = ['Non Payment', 'Breach',
       'Nuisance', 'Illegal Use', 'Failure to Sign Renewal', 'Access Denial',
       'Unapproved Subtenant', 'Owner Move In', 'Demolition',
       'Capital Improvement', 'Substantial Rehab', 'Ellis Act WithDrawal',
       'Condo Conversion', 'Roommate Same Unit', 'Other Cause',
       'Late Payments', 'Lead Remediation', 'Development',
       'Good Samaritan Ends']

# %%
df_filtered['Eviction_Reason'] = df_filtered[columns_to_check].idxmax(axis=1)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_73573/1230607948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Eviction_Reason'] = df_filtered[columns_to_check].idxmax(axis=1)

# %%
df_filtered['Eviction_Reason'].value_counts()
# Out:
# Eviction_Reason
# Nuisance                641
# Capital Improvement     190
# Non Payment             175
# Owner Move In           138
# Breach                  129
# Ellis Act WithDrawal     76
# Other Cause              46
# Roommate Same Unit       31
# Unapproved Subtenant     27
# Access Denial             6
# Late Payments             6
# Illegal Use               1
# Name: count, dtype: int64

# %% [markdown]
# ## HTML Popup Formatter

# %%
df

# %%
def popup_html(row):
    Eviction_ID = row['Eviction ID']
    Address = row['Address']
    Neighborhood = row['Neighborhoods - Analysis Boundaries']
    Eviction_Reason = row['Eviction_Reason']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Eviction ID: </strong>{}'''.format(Eviction_ID) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Neighborhood: </strong>{}'''.format(Neighborhood) + '''<br>
    <strong>Eviction Reason: </strong>{}'''.format(Eviction_Reason) + '''<br>
    </html>
    '''
    return html

# %%
df_filtered.columns
# Out:
# Index(['Eviction ID', 'Address', 'City', 'State',
#        'Eviction Notice Source Zipcode', 'File Date', 'Non Payment', 'Breach',
#        'Nuisance', 'Illegal Use', 'Failure to Sign Renewal', 'Access Denial',
#        'Unapproved Subtenant', 'Owner Move In', 'Demolition',
#        'Capital Improvement', 'Substantial Rehab', 'Ellis Act WithDrawal',
#        'Condo Conversion', 'Roommate Same Unit', 'Other Cause',
#        'Late Payments', 'Lead Remediation', 'Development',
#        'Good Samaritan Ends', 'Constraints Date', 'Supervisor District',
#        'Neighborhoods - Analysis Boundaries', 'Location', 'Shape',
#        'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'DELETE - Neighborhoods', 'DELETE - Police Districts',
#        'DELETE - Supervisor Districts', 'DELETE - Fire Prevention Districts',
#        'DELETE - Zip Codes', 'CBD, BID and GBD Boundaries as of 2017',
#        'Central Market/Tenderloin Boundary', 'Areas of Vulnerability, 2016',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Fix It Zones as of 2018-02-07', 'Neighborhoods', 'Eviction_Reason',
#        'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
# Remove parentheses and split the 'Location' column
df_filtered[['LATITUDE', 'LONGITUDE']] = df_filtered['Location'].str.replace('[()]', '', regex=True).str.split(', ', expand=True)

# Convert 'LATITUDE' and 'LONGITUDE' to numeric types
df_filtered['LATITUDE'] = pd.to_numeric(df_filtered['LATITUDE'], errors='coerce')
df_filtered['LONGITUDE'] = pd.to_numeric(df_filtered['LONGITUDE'], errors='coerce')

# %%
len(df_filtered)
# Out:
# 1182

# %%
df_filtered = df_filtered.dropna(subset=['LATITUDE','LONGITUDE'])

# %%
### Create map container ###
m = folium.Map(location=df_filtered[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=11,tiles=None)

### Create title ###
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f"San Francisco Eviction Notices - July 1st to Dec. 31st")

m.get_root().html.add_child(folium.Element(title_html))

for index, row in df_filtered.iterrows():
    marker = folium.Marker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        radius=5,
        fill=True,
        popup=folium.Popup(popup_html(row), max_width=400))
    marker.add_to(m)

# Add the FeatureGroups to the map

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2df81c0122ab62cf634da0e54d4e5a8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;San Francisco Eviction Notices - July 1st to Dec. 31st&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2df81c0122ab62cf634da0e54d4e5a8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2df81c0122ab62cf634da0e54d4e5a8d = L.map(
#                 &quot;map_2df81c0122ab62cf634da0e54d4e5a8d&quot;,
#                 {
#                     center: [37.76711524785881, -122.42431343666925],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var marker_489e7d91661ce821604fc7daffc0e76d = L.marker(
#                 [37.74231153578174, -122.47129138540214],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_2df81c0122ab62cf634da0e54d4e5a8d);
#
#
#         var popup_034682a67456025741ff73db536c840c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b5e774acb202191e4a833bf26610a308 = $(`&lt;div id=&quot;html_b5e774acb202191e4a833bf26610a308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231384&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;2400 Block Of 15th  Avenue&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;West of Twin Peaks&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_034682a67456025741ff73db536c840c.setContent(html_b5e774acb202191e4a833bf26610a308);
#
#
#
#         marker_489e7d91661ce821604fc7daffc0e76d.bindPopup(popup_034682a67456025741ff73db536c840c)
#         ;
#
#
#
#
#             var marker_587824670d57ac6745248bce8b9a237c = L.marker(
#                 [37.71327845826784, -122.47292413080852],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_2df81c0122ab62cf634da0e54d4e5a8d);
#
#
#         var popup_969ce6ebcb401f789fd0594c8acd91ed = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_dfaa7c885f1163546da2c35bd8f96571 = $(`&lt;div id=&quot;html_dfaa7c885f1163546da2c35bd8f96571&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231386&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;0 Block Of Chumasero  Drive&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Lakeshore&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_969ce6ebcb401f789fd0594c8acd91ed.setContent(html_dfaa7c885f1163546da2c35bd8f96571);
#
#
#
#         marker_587824670d57ac6745248bce8b9a237c.bindPopup(popup_969ce6ebcb401f789fd0594c8acd91ed)
#         ;
#
#
#
#
#             var marker_df7f8507a5131503734d9b1c0f133798 = L.marker(
#                 [37.720253860588926, -122.43438503237964],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_2df81c0122ab62cf634da0e54d4e5a8d);
#
#
#         var popup_0a703681f56353a403210aaf81fa3d70 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b1d3275140f3d1e5bf089701161b31c0 = $(`&lt;div id=&quot;html_b1d3275140f3d1e5bf089701161b31c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231474&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;300 Block Of Russia  Avenue&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Excelsior&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Ellis Act WithDrawal&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_0a703681f56353a403210aaf81fa3d70.setContent(html_b1d3275140f3d1e5bf089701161b31c0);
#
#
#
#         marker_df7f8507a5131503734d9b1c0f133798.bindPopup(popup_0a703681f56353a403210aaf81fa3d70)
#         ;
#
#
#
#
#             var marker_1be3ece897db07530c789e482813822a = L.marker(
#                 [37.75856482463206, -122.42017407474351],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_2df81c0122ab62cf634da0e54d4e5a8d);
#
#
#         var popup_6fa43b17f56690cb6d7d372902be6e56 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6208141f13c461e0b7e24f06d5f0755c = $(`&lt;div id=&quot;html_6208141f13c461e0b7e24f06d5f0755c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Eviction ID: &lt;/strong&gt;M231385&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;3500 Block Of 20th  Street&lt;br&gt;     &lt;strong&gt;Neighborhood: &lt;/strong&gt;Mission&lt;br&gt;     &lt;strong&gt;Eviction Reason: &lt;/strong&gt;Nuisance&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_6fa43b17f56690cb6d7d372902be6e56.setContent(html_6208141f13c461e0b7e24f06d5f0755c);
#
#
#
#         marker_1be3ece897db07530c789e482813822a.bindPopup(popup_6fa43b17f56690cb6d7d372902be6e56)
#         ;
#
#
#
#
#             var marker_ad994fb4807d

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/SF_2023_eviction_notices_July_onwards
