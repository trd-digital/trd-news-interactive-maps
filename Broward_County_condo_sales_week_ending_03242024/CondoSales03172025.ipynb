# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Mar. 16th Mar. 23rd

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE               ADDRESS  \
# 1  PAST SALE  March-19-2025   Condo/Co-op  1100 NE 9th Ave #303
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Fort Lauderdale                FL             33304.0  140000.0   1.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    1.0  ...   Sold                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1100...  MARMLS  A11766968
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  26.139207 -80.134176
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward County

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-03-18    26
# 2025-03-20    26
# 2025-03-17    22
# 2025-03-21    22
# 2025-03-19    19
# 2025-03-22     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 91  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 5   PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 80  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 79  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 54  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 50  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 25  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 65  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 35  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 7   PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                      CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 91        Fort Lauderdale                FL             33304.0  1950000.0
# 5         Deerfield Beach                FL             33441.0  1789000.0
# 80        Fort Lauderdale                FL             33316.0  1250000.0
# 79              Hollywood                FL             33019.0  1225000.0
# 54        Fort Lauderdale                FL             33308.0  1180000.0
# 50        Fort Lauderdale                FL             33301.0  1150000.0
# 25        Fort Lauderdale                FL             33316.0   975000.0
# 65          Pompano Beach                FL             33068.0   920000.0
# 35  Lauderdale By The Sea                FL             33308.0   875000.0
# 7         Fort Lauderdale                FL             33301.0   745000.0
#
#     BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 91   3.0    3.5  ...   Sold                         NaN
# 5    3.0    3.0  ...   Sold                         NaN
# 80   4.0    2.0  ...   Sold                         NaN
# 79   3.0    2.0  ...   Sold                         NaN
# 54   3.0    2.5  ...   Sold                         NaN
# 50   2.0    2.5  ...   Sold                         NaN
# 25   2.0    2.0  ...   Sold                         NaN
# 65   1.0    1.0  ...   Sold                         NaN
# 35   3.0    2.0  ...   Sold                         NaN
# 7    2.0    2.0  ...   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 91                       NaN
# 5                        NaN
# 80                       NaN
# 79                       NaN
# 54                       NaN
# 50                       NaN
# 25                       NaN
# 65                       NaN
# 35                       NaN
# 7                        NaN
#
#                                                   URL       SOURCE       MLS#  \
# 91  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
# 5   https://www.redfin.com/FL/Deerfield-Beach/701-...  Beaches MLS  F10486204
# 80  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10464891
# 79  https://www.redfin.com/FL/Hollywood/2751-S-Oce...       MARMLS  A11658942
# 54  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10476667
# 50  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11708273
# 25  https://www.redfin.com/FL/Fort-Lauderdale/1645...  Beaches MLS  F10483777
# 65  https://www.redfin.com/FL/Pompano-Beach/431-S-...  Beaches MLS  F10477577
# 35  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10479493
# 7   https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10484349
#
#     FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 91         N          Y  26.135735 -80.109605
# 5          N          Y  26.308137 -80.077107
# 80         N          Y  26.095913 -80.106280
# 79         N          Y  25.995586 -80.117479
# 54         N          Y  26.168258 -80.099279
# 50         N          Y  26.118354 -80.141518
# 25         N          Y  26.102067 -80.106957
# 65         N          Y  26.225843 -80.200536
# 35         N          Y  26.201000 -80.094629
# 7          N          Y  26.118764 -80.114177
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 1  PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 2  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 3  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 4  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 5  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 6  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 7  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 8  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 9  PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33304.0  1950000.0
# 1        Deerfield Beach                FL             33441.0  1789000.0
# 2        Fort Lauderdale                FL             33316.0  1250000.0
# 3              Hollywood                FL             33019.0  1225000.0
# 4        Fort Lauderdale                FL             33308.0  1180000.0
# 5        Fort Lauderdale                FL             33301.0  1150000.0
# 6        Fort Lauderdale                FL             33316.0   975000.0
# 7          Pompano Beach                FL             33068.0   920000.0
# 8  Lauderdale By The Sea                FL             33308.0   875000.0
# 9        Fort Lauderdale                FL             33301.0   745000.0
#
#    BEDS  BATHS  ...  LONGITUDE  \
# 0   3.0    3.5  ... -80.109605
# 1   3.0    3.0  ... -80.077107
# 2   4.0    2.0  ... -80.106280
# 3   3.0    2.0  ... -80.117479
# 4   3.0    2.5  ... -80.099279
# 5   2.0    2.5  ... -80.141518
# 6   2.0    2.0  ... -80.106957
# 7   1.0    1.0  ... -80.200536
# 8   3.0    2.0  ... -80.094629
# 9   2.0    2.0  ... -80.114177
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...      Deborah Ruffino
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...        Michael Rizzo
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...        Melanie Dayan
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...          Ross Guedry
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...          Bobbi Ocean
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...      Barry Zimmerman
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...     Sylvie Jolicoeur
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...     Ana Maria Becker
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Peter Orenchuk
#
#                list_broker_name_1  list_agent_name_2  \
# 0    Florida Luxurious Properties               None
# 1          The Cove Guspav Realty               None
# 2          Coldwell Banker Realty         Ely Benaim
# 3        Sunny Isles Realty, Inc.               None
# 4    Winchester Group Real Estate               None
# 5   Galleria International Realty               None
# 6  Better Homes & Gdns RE Fla 1st         Noam Manor
# 7      Balistreri Real Estate Inc               None
# 8          Coldwell Banker Realty               None
# 9     Team Effort Real Estate Inc               None
#
#                list_broker_name_2         buy_agent_name_1  \
# 0                            None      Matthew Bertanzetti
# 1                            None                     None
# 2          Coldwell Banker Realty            Michael Rizzo
# 3                            None             Millana Ford
# 4                            None            Victor Attias
# 5                            None                     None
# 6  Better Homes & Gdns RE Fla 1st  Christine Hansen Vargas
# 7                            None             Jacobus Louw
# 8                            None           Susan Gauthier
# 9                            None          Christian Widen
#
#                     buy_broker_name_1     buy_agent_name_2  \
# 0        Florida Luxurious Properties  Matthew Bertanzetti
# 1  One Sotheby's International Realty                 None
# 2              Coldwell Banker Realty                 None
# 3                     Vera Realty LLC       Michael Platon
# 4               Galt Ocean Realty Inc                 None
# 5                                None                 None
# 6            South Florida Home Sales                 None
# 7                     BHHS EWM Realty                 None
# 8             By The Sea Realty, Inc.                 None
# 9                   The Keyes Company                 None
#
#               buy_broker_name_2
# 0  Florida Luxurious Properties
# 1                          None
# 2                          None
# 3               Vera Realty LLC
# 4                          None
# 5                          None
# 6                          None
# 7                          None
# 8                          None
# 9                          None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 116

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $329,636

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $273

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $38,237,750

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          116              329636          273                     38237750.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 132
# -----------
# Input Previous Week Condo Average Sales Price:
# 323436
# -----------
# Input Previous Week Condo Average PSF:
# 283
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 42693500.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op  920 Intracoastal Dr #603
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33304.0  1950000.0   3.0
#
#    BATHS LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  Aquablu       3258.0       NaN      2018.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          599.0     4161.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
#
#              list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Florida Luxurious Properties              None               None
#
#       buy_agent_name_1             buy_broker_name_1     buy_agent_name_2  \
# 0  Matthew Bertanzetti  Florida Luxurious Properties  Matthew Bertanzetti
#
#               buy_broker_name_2  RANK   COLOR
# 0  Florida Luxurious Properties     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 1  PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 2  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 3  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 4  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 5  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 6  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 7  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 8  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 9  PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33304.0  1950000.0
# 1        Deerfield Beach                FL             33441.0  1789000.0
# 2        Fort Lauderdale                FL             33316.0  1250000.0
# 3              Hollywood                FL             33019.0  1225000.0
# 4        Fort Lauderdale                FL             33308.0  1180000.0
# 5        Fort Lauderdale                FL             33301.0  1150000.0
# 6        Fort Lauderdale                FL             33316.0   975000.0
# 7          Pompano Beach                FL             33068.0   920000.0
# 8  Lauderdale By The Sea                FL             33308.0   875000.0
# 9        Fort Lauderdale                FL             33301.0   745000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5                    Aquablu       3258.0       NaN      2018.0
# 1   3.0    3.0               Orchid Beach       2380.0       NaN      2006.0
# 2   4.0    2.0           Point Of America       2011.0       NaN      1971.0
# 3   3.0    2.0             AQUARIUS CONDO       1768.0       NaN      1973.0
# 4   3.0    2.5              L'hermitage I       1977.0       NaN      1997.0
# 5   2.0    2.5  LAS OLAS RIVER HOUSE COND       1869.0       NaN      2004.0
# 6   2.0    2.0                   Oceanage       1273.0       NaN      1973.0
# 7   1.0    1.0            Aztec Rv Resort       1188.0       NaN      2010.0
# 8   3.0    2.0  Sea Ranch Lakes North Con       1708.0       NaN      1971.0
# 9   2.0    2.0               Four Seasons       1770.0       NaN      1959.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          599.0     4161.0   Sold
# 1             NaN          752.0     1603.0   Sold
# 2             NaN          622.0     1974.0   Sold
# 3             NaN          693.0     2980.0   Sold
# 4             NaN          597.0     2765.0   Sold
# 5             NaN          615.0     2420.0   Sold
# 6             NaN          766.0     1275.0   Sold
# 7             NaN          774.0      428.0   Sold
# 8             NaN          512.0     1083.0   Sold
# 9             NaN          421.0     2339.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...  Beaches MLS  F10486204
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10464891
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...       MARMLS  A11658942
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10476667
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11708273
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...  Beaches MLS  F10483777
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...  Beaches MLS  F10477577
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10479493
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10484349
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
# 1        N          Y  26.308137 -80.077107
# 2        N          Y  26.095913 -80.106280
# 3        N          Y  25.995586 -80.117479
# 4        N          Y  26.168258 -80.099279
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.102067 -80.106957
# 7        N          Y  26.225843 -80.200536
# 8        N          Y  26.201000 -80.094629
# 9        N          Y  26.118764 -80.114177
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...      Deborah Ruffino
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...        Michael Rizzo
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...        Melanie Dayan
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...          Ross Guedry
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...          Bobbi Ocean
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...      Barry Zimmerman
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...     Sylvie Jolicoeur
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...     Ana Maria Becker
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Peter Orenchuk
#
#                list_broker_name_1 list_agent_name_2  \
# 0    Florida Luxurious Properties              None
# 1          The Cove Guspav Realty              None
# 2          Coldwell Banker Realty        Ely Benaim
# 3        Sunny Isles Realty, Inc.              None
# 4    Winchester Group Real Estate              None
# 5   Galleria International Realty              None
# 6  Better Homes & Gdns RE Fla 1st        Noam Manor
# 7      Balistreri Real Estate Inc              None
# 8          Coldwell Banker Realty              None
# 9     Team Effort Real Estate Inc              None
#
#                list_broker_name_2         buy_agent_name_1  \
# 0                            None      Matthew Bertanzetti
# 1                            None                     None
# 2          Coldwell Banker Realty            Michael Rizzo
# 3                            None             Millana Ford
# 4                            None            Victor Attias
# 5                            None                     None
# 6  Better Homes & Gdns RE Fla 1st  Christine Hansen Vargas
# 7                            None             Jacobus Louw
# 8                            None           Susan Gauthier
# 9                            None          Christian Widen
#
#                     buy_broker_name_1     buy_agent_name_2  \
# 0        Florida Luxurious Properties  Matthew Bertanzetti
# 1  One Sotheby's International Realty                 None
# 2              Coldwell Banker Realty                 None
# 3                     Vera Realty LLC       Michael Platon
# 4               Galt Ocean Realty Inc                 None
# 5                                None                 None
# 6            South Florida Home Sales                 None
# 7                     BHHS EWM Realty                 None
# 8             By The Sea Realty, Inc.                 None
# 9                   The Keyes Company                 None
#
#               buy_broker_name_2  RANK   COLOR
# 0  Florida Luxurious Properties     1  orange
# 1                          None     2    blue
# 2                          None     3    blue
# 3               Vera Realty LLC     4    blue
# 4                          None     5    blue
# 5                          None     6    blue
# 6                          None     7    blue
# 7                          None     8    blue
# 8                          None     9    blue
# 9                          None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a75c5f5353415206645557ac077d3b35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Mar. 16th — Mar. 23rd&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a75c5f5353415206645557ac077d3b35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a75c5f5353415206645557ac077d3b35 = L.map(
#                 &quot;map_a75c5f5353415206645557ac077d3b35&quot;,
#                 {
#                     center: [26.16320267155173, -80.18359454224138],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_80648a614e00250dfbf929b471a079c7 = L.featureGroup(
#                 {}
#             ).addTo(map_a75c5f5353415206645557ac077d3b35);
#
#
#             var marker_3f62bb9d1fa6cb481f23cd47d5e1e4df = L.marker(
#                 [26.1357345, -80.1096046],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_80648a614e00250dfbf929b471a079c7);
#
#
#             var icon_4db669aad2a1c6c935ec2669e748a801 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3f62bb9d1fa6cb481f23cd47d5e1e4df.setIcon(icon_4db669aad2a1c6c935ec2669e748a801);
#
#
#         var popup_ddad279bce20e85f2df12158cc3dd535 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b91e9270e716d462d09efe53bbd750b0 = $(`&lt;div id=&quot;html_b91e9270e716d462d09efe53bbd750b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;920 Intracoastal Dr #603&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,950,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$599.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,258.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ddad279bce20e85f2df12158cc3dd535.setContent(html_b91e9270e716d462d09efe53bbd750b0);
#
#
#
#         marker_3f62bb9d1fa6cb481f23cd47d5e1e4df.bindPopup(popup_ddad279bce20e85f2df12158cc3dd535)
#         ;
#
#
#
#
#             var feature_group_cf189b24a992da220a7cf4c2e716cd5d = L.featureGroup(
#                 {}
#             ).addTo(map_a75c5f5353415206645557ac077d3b35);
#
#
#             var marker_47f47e42f321efb7f3abe5969985e962 = L.marker(
#                 [26.3081369, -80.0771074],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_cf189b24a992da220a7cf4c2e716cd5d);
#
#
#             var icon_4332be20c1784d75899acf4dbdb25caf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47f47e42f321efb7f3abe5969985e962.setIcon(icon_4332be20c1784d75899acf4dbdb25caf);
#
#
#         var popup_94085bdd5eb627bc26d00de773df0a17 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3d0950e5c0ee56eacdbf8f401cdc5656 = $(`&lt;div id=&quot;html_3d0950e5c0ee56eacdbf8f401cdc5656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;701 SE 21st Ave #407&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,789,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$752.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,380.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2006.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_94085bdd5eb627bc26d00de773df0a17.setContent(html_3d0950e5c0ee56eacdbf8f401cdc5656);
#
#
#
#         marker_47f47e42f321efb7f3abe5969985e962.bindPopup(popup_94085bdd5eb627bc26d00de773df0a17)
#         ;
#
#
#
#
#             var marker_547d1120c456f934721f87d05cff9300 = L.marker(
#                 [26.0959126, -80.1062796],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_cf189b24a992da220a7cf4c2e716cd5d);
#
#
#             var icon_79348a7fd2aa5f577a537cf961d753c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_547d1120c456f934721f87d05cff9300.setIcon(icon_79348a7fd2aa5f577a537cf961d753c2);
#
#
#         var popup_1fd0af254d311098bda7437cb1a0b51f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_cdc5ce1f20e475f07e85a41f077c996f =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op  920 Intracoastal Dr #603
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33304.0  1950000.0   3.0
#
#    BATHS LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  Aquablu       3258.0       NaN      2018.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          599.0     4161.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
#
#              list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Florida Luxurious Properties              None               None
#
#       buy_agent_name_1             buy_broker_name_1     buy_agent_name_2  \
# 0  Matthew Bertanzetti  Florida Luxurious Properties  Matthew Bertanzetti
#
#               buy_broker_name_2  RANK   COLOR
# 0  Florida Luxurious Properties     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_03242024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Aquablu at 920 Intracoastal Dr #603 in Fort Lauderdale'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 1  PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 2  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 3  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 4  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 5  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 6  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 7  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 8  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 9  PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33304.0  1950000.0
# 1        Deerfield Beach                FL             33441.0  1789000.0
# 2        Fort Lauderdale                FL             33316.0  1250000.0
# 3              Hollywood                FL             33019.0  1225000.0
# 4        Fort Lauderdale                FL             33308.0  1180000.0
# 5        Fort Lauderdale                FL             33301.0  1150000.0
# 6        Fort Lauderdale                FL             33316.0   975000.0
# 7          Pompano Beach                FL             33068.0   920000.0
# 8  Lauderdale By The Sea                FL             33308.0   875000.0
# 9        Fort Lauderdale                FL             33301.0   745000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5                    Aquablu       3258.0       NaN      2018.0
# 1   3.0    3.0               Orchid Beach       2380.0       NaN      2006.0
# 2   4.0    2.0           Point Of America       2011.0       NaN      1971.0
# 3   3.0    2.0             AQUARIUS CONDO       1768.0       NaN      1973.0
# 4   3.0    2.5              L'hermitage I       1977.0       NaN      1997.0
# 5   2.0    2.5  LAS OLAS RIVER HOUSE COND       1869.0       NaN      2004.0
# 6   2.0    2.0                   Oceanage       1273.0       NaN      1973.0
# 7   1.0    1.0            Aztec Rv Resort       1188.0       NaN      2010.0
# 8   3.0    2.0  Sea Ranch Lakes North Con       1708.0       NaN      1971.0
# 9   2.0    2.0               Four Seasons       1770.0       NaN      1959.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          599.0     4161.0   Sold
# 1             NaN          752.0     1603.0   Sold
# 2             NaN          622.0     1974.0   Sold
# 3             NaN          693.0     2980.0   Sold
# 4             NaN          597.0     2765.0   Sold
# 5             NaN          615.0     2420.0   Sold
# 6             NaN          766.0     1275.0   Sold
# 7             NaN          774.0      428.0   Sold
# 8             NaN          512.0     1083.0   Sold
# 9             NaN          421.0     2339.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...  Beaches MLS  F10486204
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10464891
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...       MARMLS  A11658942
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10476667
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11708273
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...  Beaches MLS  F10483777
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...  Beaches MLS  F10477577
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10479493
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10484349
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
# 1        N          Y  26.308137 -80.077107
# 2        N          Y  26.095913 -80.106280
# 3        N          Y  25.995586 -80.117479
# 4        N          Y  26.168258 -80.099279
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.102067 -80.106957
# 7        N          Y  26.225843 -80.200536
# 8        N          Y  26.201000 -80.094629
# 9        N          Y  26.118764 -80.114177
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...      Deborah Ruffino
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...        Michael Rizzo
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...        Melanie Dayan
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...          Ross Guedry
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...          Bobbi Ocean
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...      Barry Zimmerman
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...     Sylvie Jolicoeur
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...     Ana Maria Becker
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Peter Orenchuk
#
#                list_broker_name_1 list_agent_name_2  \
# 0    Florida Luxurious Properties              None
# 1          The Cove Guspav Realty              None
# 2          Coldwell Banker Realty        Ely Benaim
# 3        Sunny Isles Realty, Inc.              None
# 4    Winchester Group Real Estate              None
# 5   Galleria International Realty              None
# 6  Better Homes & Gdns RE Fla 1st        Noam Manor
# 7      Balistreri Real Estate Inc              None
# 8          Coldwell Banker Realty              None
# 9     Team Effort Real Estate Inc              None
#
#                list_broker_name_2         buy_agent_name_1  \
# 0                            None      Matthew Bertanzetti
# 1                            None                     None
# 2          Coldwell Banker Realty            Michael Rizzo
# 3                            None             Millana Ford
# 4                            None            Victor Attias
# 5                            None                     None
# 6  Better Homes & Gdns RE Fla 1st  Christine Hansen Vargas
# 7                            None             Jacobus Louw
# 8                            None           Susan Gauthier
# 9                            None          Christian Widen
#
#                     buy_broker_name_1     buy_agent_name_2  \
# 0        Florida Luxurious Properties  Matthew Bertanzetti
# 1  One Sotheby's International Realty                 None
# 2              Coldwell Banker Realty                 None
# 3                     Vera Realty LLC       Michael Platon
# 4               Galt Ocean Realty Inc                 None
# 5                                None                 None
# 6            South Florida Home Sales                 None
# 7                     BHHS EWM Realty                 None
# 8             By The Sea Realty, Inc.                 None
# 9                   The Keyes Company                 None
#
#               buy_broker_name_2  RANK   COLOR  \
# 0  Florida Luxurious Properties     1  orange
# 1                          None     2    blue
# 2                          None     3    blue
# 3               Vera Realty LLC     4    blue
# 4                          None     5    blue
# 5                          None     6    blue
# 6                          None     7    blue
# 7                          None     8    blue
# 8                          None     9    blue
# 9                          None    10    blue
#
#                                            FULL_NAME
# 0  Aquablu at 920 Intracoastal Dr #603 in Fort La...
# 1  Orchid Beach at 701 SE 21st Ave #407 in Deerfi...
# 2  Point Of America at 2200 S Ocean Ln #308 in Fo...
# 3  AQUARIUS CONDO at 2751 S Ocean Dr Unit 1701S i...
# 4  L'hermitage I at 3100 N Ocean Blvd #704 in For...
# 5  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6  Oceanage at 1645 S Ocean Ln #188 in Fort Laude...
# 7  Aztec Rv Resort at 431 S Cortez Dr #431 in Pom...
# 8  Sea Ranch Lakes North Con at 5200 N Ocean Blvd...
# 9  Four Seasons at 333 Sunset Dr #808 in Fort Lau...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Aquablu closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $745,000 to $1,950,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Deerfield Beach, Fort Lauderdale, Pompano Beach, Hollywood, Lauderdale By The Sea, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 116 condo sales totaling $38,237,750 million from Mar. 16th to Mar. 23rd. The previous week, brokers closed 132 condo sales totaling $42,693,500.
#
# Last week’s units sold for an average of $329,636, higher than the $323,436 average price from the previous week. The average price per square foot fell to $273 from $283, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $745,000.0 million to $1,950,000.0 million.
#
# Aquablu at 920 Intracoastal Dr #603 in Fort Lauderdale took the top spot with a $1,950,000.0 million closing. The sale closed at $599.0 per square foot.
#
# Matthew Bertanzetti with Florida Luxurious Properties, and None with None had the listing.
# Matthew Bertanzetti with Florida Luxurious Properties, and Matthew Bertanzetti with Florida Luxurious Properties represented the buyer.
#
# Orchid Beach at 701 SE 21st Ave #407 in Deerfield Beach, closed for the second highest amount, $1,789,000.0, or $752.0 per square foot.
#
# Deborah Ruffino with The Cove Guspav Realty, and None with None had the listing.
# None with One Sotheby's International Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_03242024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 16th to Mar. 23rd:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 1  PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 2  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 3  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 4  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 5  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 6  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 7  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 8  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 9  PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33304.0  1950000.0
# 1        Deerfield Beach                FL             33441.0  1789000.0
# 2        Fort Lauderdale                FL             33316.0  1250000.0
# 3              Hollywood                FL             33019.0  1225000.0
# 4        Fort Lauderdale                FL             33308.0  1180000.0
# 5        Fort Lauderdale                FL             33301.0  1150000.0
# 6        Fort Lauderdale                FL             33316.0   975000.0
# 7          Pompano Beach                FL             33068.0   920000.0
# 8  Lauderdale By The Sea                FL             33308.0   875000.0
# 9        Fort Lauderdale                FL             33301.0   745000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5                    Aquablu       3258.0       NaN      2018.0
# 1   3.0    3.0               Orchid Beach       2380.0       NaN      2006.0
# 2   4.0    2.0           Point Of America       2011.0       NaN      1971.0
# 3   3.0    2.0             AQUARIUS CONDO       1768.0       NaN      1973.0
# 4   3.0    2.5              L'hermitage I       1977.0       NaN      1997.0
# 5   2.0    2.5  LAS OLAS RIVER HOUSE COND       1869.0       NaN      2004.0
# 6   2.0    2.0                   Oceanage       1273.0       NaN      1973.0
# 7   1.0    1.0            Aztec Rv Resort       1188.0       NaN      2010.0
# 8   3.0    2.0  Sea Ranch Lakes North Con       1708.0       NaN      1971.0
# 9   2.0    2.0               Four Seasons       1770.0       NaN      1959.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          599.0     4161.0   Sold
# 1             NaN          752.0     1603.0   Sold
# 2             NaN          622.0     1974.0   Sold
# 3             NaN          693.0     2980.0   Sold
# 4             NaN          597.0     2765.0   Sold
# 5             NaN          615.0     2420.0   Sold
# 6             NaN          766.0     1275.0   Sold
# 7             NaN          774.0      428.0   Sold
# 8             NaN          512.0     1083.0   Sold
# 9             NaN          421.0     2339.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...  Beaches MLS  F10486204
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10464891
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...       MARMLS  A11658942
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10476667
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11708273
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...  Beaches MLS  F10483777
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...  Beaches MLS  F10477577
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10479493
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10484349
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
# 1        N          Y  26.308137 -80.077107
# 2        N          Y  26.095913 -80.106280
# 3        N          Y  25.995586 -80.117479
# 4        N          Y  26.168258 -80.099279
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.102067 -80.106957
# 7        N          Y  26.225843 -80.200536
# 8        N          Y  26.201000 -80.094629
# 9        N          Y  26.118764 -80.114177
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...      Deborah Ruffino
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...        Michael Rizzo
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...        Melanie Dayan
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...          Ross Guedry
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...          Bobbi Ocean
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...      Barry Zimmerman
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...     Sylvie Jolicoeur
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...     Ana Maria Becker
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Peter Orenchuk
#
#                list_broker_name_1 list_agent_name_2  \
# 0    Florida Luxurious Properties              None
# 1          The Cove Guspav Realty              None
# 2          Coldwell Banker Realty        Ely Benaim
# 3        Sunny Isles Realty, Inc.              None
# 4    Winchester Group Real Estate              None
# 5   Galleria International Realty              None
# 6  Better Homes & Gdns RE Fla 1st        Noam Manor
# 7      Balistreri Real Estate Inc              None
# 8          Coldwell Banker Realty              None
# 9     Team Effort Real Estate Inc              None
#
#                list_broker_name_2         buy_agent_name_1  \
# 0                            None      Matthew Bertanzetti
# 1                            None                     None
# 2          Coldwell Banker Realty            Michael Rizzo
# 3                            None             Millana Ford
# 4                            None            Victor Attias
# 5                            None                     None
# 6  Better Homes & Gdns RE Fla 1st  Christine Hansen Vargas
# 7                            None             Jacobus Louw
# 8                            None           Susan Gauthier
# 9                            None          Christian Widen
#
#                     buy_broker_name_1     buy_agent_name_2  \
# 0        Florida Luxurious Properties  Matthew Bertanzetti
# 1  One Sotheby's International Realty                 None
# 2              Coldwell Banker Realty                 None
# 3                     Vera Realty LLC       Michael Platon
# 4               Galt Ocean Realty Inc                 None
# 5                                None                 None
# 6            South Florida Home Sales                 None
# 7                     BHHS EWM Realty                 None
# 8             By The Sea Realty, Inc.                 None
# 9                   The Keyes Company                 None
#
#               buy_broker_name_2  RANK   COLOR  \
# 0  Florida Luxurious Properties     1  orange
# 1                          None     2    blue
# 2                          None     3    blue
# 3               Vera Realty LLC     4    blue
# 4                          None     5    blue
# 5                          None     6    blue
# 6                          None     7    blue
# 7                          None     8    blue
# 8                          None     9    blue
# 9                          None    10    blue
#
#                                            FULL_NAME
# 0  Aquablu at 920 Intracoastal Dr #603 in Fort La...
# 1  Orchid Beach at 701 SE 21st Ave #407 in Deerfi...
# 2  Point Of America at 2200 S Ocean Ln #308 in Fo...
# 3  AQUARIUS CONDO at 2751 S Ocean Dr Unit 1701S i...
# 4  L'hermitage I at 3100 N Ocean Blvd #704 in For...
# 5  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6  Oceanage at 1645 S Ocean Ln #188 in Fort Laude...
# 7  Aztec Rv Resort at 431 S Cortez Dr #431 in Pom...
# 8  Sea Ranch Lakes North Con at 5200 N Ocean Blvd...
# 9  Four Seasons at 333 Sunset Dr #808 in Fort Lau...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Aquablu closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $745,000 to $1,950,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Deerfield Beach, Fort Lauderdale, Pompano Beach, Hollywood, Lauderdale By The Sea, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 116 condo sales totaling $38,237,750 million from Mar. 16th to Mar. 23rd. The previous week, brokers closed 132 condo sales totaling $42,693,500.
#
# Last week’s units sold for an average of $329,636, higher than the $323,436 average price from the previous week. The average price per square foot fell to $273 from $283, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $745,000.0 million to $1,950,000.0 million.
#
# Aquablu at 920 Intracoastal Dr #603 in Fort Lauderdale took the top spot with a $1,950,000.0 million closing. The sale closed at $599.0 per square foot.
#
# Matthew Bertanzetti with Florida Luxurious Properties, and None with None had the listing.
# Matthew Bertanzetti with Florida Luxurious Properties, and Matthew Bertanzetti with Florida Luxurious Properties represented the buyer.
#
# Orchid Beach at 701 SE 21st Ave #407 in Deerfield Beach, closed for the second highest amount, $1,789,000.0, or $752.0 per square foot.
#
# Deborah Ruffino with The Cove Guspav Realty, and None with None had the listing.
# None with One Sotheby's International Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_03242024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 16th to Mar. 23rd:
#
# Most Expensive
# Aquablu, 920 Intracoastal Dr #603, in Fort Lauderdale | Price: $1,950,000 | $599 psf | Listing agents: Matthew Bertanzetti with Florida Luxurious Properties and None with None | Buyer's agents: Matthew Bertanzetti with Florida Luxurious Properties and Matthew Bertanzetti with Florida Luxurious Properties
#
# Least Expensive
# Four Seasons, 333 Sunset Dr #808, in Fort Lauderdale | Price: $745,000 | $421 psf | Listing agents: Peter Orenchuk with Team Effort Real Estate Inc and None with None | Buyer's agents: Christian Widen with The Keyes Company and None with None
#
# Highest Price Per Square Foot
# Aztec Rv Resort, 431 S Cortez Dr #431, in Pompano Beach | Price: $920,000 | $774 psf | Listing agents: Sylvie Jolicoeur with Balistreri Real Estate Inc and None with None | Buyer's agents: Jacobus Louw with BHHS EWM Realty and None with None
#
# Lowest Price Per Square Foot
# Four Seasons, 333 Sunset Dr #808, in Fort Lauderdale | Price: $745,000 | $421 psf | Listing agents: Peter Orenchuk with Team Effort Real Estate Inc and None with None | Buyer's agents: Christian Widen with The Keyes Company and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Fort-Lauderdale/920-Intracoastal-Dr-33304/unit-603/home/144474020
# Second priciest sale:  https://www.redfin.com/FL/Deerfield-Beach/701-SE-21st-Ave-33441/unit-407/home/42055068
# Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/333-Sunset-Dr-33301/unit-808/home/41801115
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Lauderdale-by-the-Sea/5200-N-Ocean-Blvd-33308/unit-909D/home/41704515
# Highest top ten psf:  https://www.redfin.com/FL/Pompano-Beach/431-S-Cortez-Dr-33068/unit-431/home/42082012
# Lowest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/333-Sunset-Dr-33301/unit-808/home/41801115

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Fort-Lauderdale/920-Intracoastal-Dr-33304/unit-603/home/144474020

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Deerfield-Beach/701-SE-21st-Ave-33441/unit-407/home/42055068

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/333-Sunset-Dr-33301/unit-808/home/41801115

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Lauderdale-by-the-Sea/5200-N-Ocean-Blvd-33308/unit-909D/home/41704515

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Pompano-Beach/431-S-Cortez-Dr-33068/unit-431/home/42082012

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/333-Sunset-Dr-33301/unit-808/home/41801115

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-19   Condo/Co-op     920 Intracoastal Dr #603
# 1  PAST SALE 2025-03-20   Condo/Co-op         701 SE 21st Ave #407
# 2  PAST SALE 2025-03-21   Condo/Co-op         2200 S Ocean Ln #308
# 3  PAST SALE 2025-03-19   Condo/Co-op   2751 S Ocean Dr Unit 1701S
# 4  PAST SALE 2025-03-18   Condo/Co-op       3100 N Ocean Blvd #704
# 5  PAST SALE 2025-03-20   Condo/Co-op       333 Las Olas Way #3203
# 6  PAST SALE 2025-03-18   Condo/Co-op         1645 S Ocean Ln #188
# 7  PAST SALE 2025-03-20   Condo/Co-op         431 S Cortez Dr #431
# 8  PAST SALE 2025-03-17   Condo/Co-op  5200 N Ocean Blvd Unit 909D
# 9  PAST SALE 2025-03-20   Condo/Co-op           333 Sunset Dr #808
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33304.0  1950000.0
# 1        Deerfield Beach                FL             33441.0  1789000.0
# 2        Fort Lauderdale                FL             33316.0  1250000.0
# 3              Hollywood                FL             33019.0  1225000.0
# 4        Fort Lauderdale                FL             33308.0  1180000.0
# 5        Fort Lauderdale                FL             33301.0  1150000.0
# 6        Fort Lauderdale                FL             33316.0   975000.0
# 7          Pompano Beach                FL             33068.0   920000.0
# 8  Lauderdale By The Sea                FL             33308.0   875000.0
# 9        Fort Lauderdale                FL             33301.0   745000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5                    Aquablu       3258.0       NaN      2018.0
# 1   3.0    3.0               Orchid Beach       2380.0       NaN      2006.0
# 2   4.0    2.0           Point Of America       2011.0       NaN      1971.0
# 3   3.0    2.0             AQUARIUS CONDO       1768.0       NaN      1973.0
# 4   3.0    2.5              L'hermitage I       1977.0       NaN      1997.0
# 5   2.0    2.5  LAS OLAS RIVER HOUSE COND       1869.0       NaN      2004.0
# 6   2.0    2.0                   Oceanage       1273.0       NaN      1973.0
# 7   1.0    1.0            Aztec Rv Resort       1188.0       NaN      2010.0
# 8   3.0    2.0  Sea Ranch Lakes North Con       1708.0       NaN      1971.0
# 9   2.0    2.0               Four Seasons       1770.0       NaN      1959.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          599.0     4161.0   Sold
# 1             NaN          752.0     1603.0   Sold
# 2             NaN          622.0     1974.0   Sold
# 3             NaN          693.0     2980.0   Sold
# 4             NaN          597.0     2765.0   Sold
# 5             NaN          615.0     2420.0   Sold
# 6             NaN          766.0     1275.0   Sold
# 7             NaN          774.0      428.0   Sold
# 8             NaN          512.0     1083.0   Sold
# 9             NaN          421.0     2339.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Beaches MLS  F10468111
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...  Beaches MLS  F10486204
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10464891
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...       MARMLS  A11658942
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10476667
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11708273
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...  Beaches MLS  F10483777
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...  Beaches MLS  F10477577
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10479493
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10484349
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.135735 -80.109605
# 1        N          Y  26.308137 -80.077107
# 2        N          Y  26.095913 -80.106280
# 3        N          Y  25.995586 -80.117479
# 4        N          Y  26.168258 -80.099279
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.102067 -80.106957
# 7        N          Y  26.225843 -80.200536
# 8        N          Y  26.201000 -80.094629
# 9        N          Y  26.118764 -80.114177
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Matthew Bertanzetti
# 1  https://www.redfin.com/FL/Deerfield-Beach/701-...      Deborah Ruffino
# 2  https://www.redfin.com/FL/Fort-Lauderdale/2200...        Michael Rizzo
# 3  https://www.redfin.com/FL/Hollywood/2751-S-Oce...        Melanie Dayan
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3100...          Ross Guedry
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...          Bobbi Ocean
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1645...      Barry Zimmerman
# 7  https://www.redfin.com/FL/Pompano-Beach/431-S-...     Sylvie Jolicoeur
# 8  https://www.redfin.com/FL/Lauderdale-by-the-Se...     Ana Maria Becker
# 9  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Peter Orenchuk
#
#                list_broker_name_1 list_agent_name_2  \
# 0    Florida Luxurious Properties              None
# 1          The Cove Guspav Realty              None
# 2          Coldwell Banker Realty        Ely Benaim
# 3        Sunny Isles Realty, Inc.              None
# 4    Winchester Group Real Estate              None
# 5   Galleria International Realty              None
# 6  Better Homes & Gdns RE Fla 1st        Noam Manor
# 7      Balistreri Real Estate Inc              None
# 8          Coldwell Banker Realty              None
# 9     Team Effort Real Estate Inc              None
#
#                list_broker_name_2         buy_agent_name_1  \
# 0                            None      Matthew Bertanzetti
# 1                            None                     None
# 2          Coldwell Banker Realty            Michael Rizzo
# 3                            None             Millana Ford
# 4                            None            Victor Attias
# 5                            None                     None
# 6  Better Homes & Gdns RE Fla 1st  Christine Hansen Vargas
# 7                            None             Jacobus Louw
# 8                            None           Susan Gauthier
# 9                            None          Christian Widen
#
#                     buy_broker_name_1     buy_agent_name_2  \
# 0        Florida Luxurious Properties  Matthew Bertanzetti
# 1  One Sotheby's International Realty                 None
# 2              Coldwell Banker Realty                 None
# 3                     Vera Realty LLC       Michael Platon
# 4               Galt Ocean Realty Inc                 None
# 5                                None                 None
# 6            South Florida Home Sales                 None
# 7                     BHHS EWM Realty                 None
# 8             By The Sea Realty, Inc.                 None
# 9                   The Keyes Company                 None
#
#               buy_broker_name_2  RANK   COLOR  \
# 0  Florida Luxurious Properties     1  orange
# 1                          None     2    blue
# 2                          None     3    blue
# 3               Vera Realty LLC     4    blue
# 4                          None     5    blue
# 5                          None     6    blue
# 6                          None     7    blue
# 7                          None     8    blue
# 8                          None     9    blue
# 9                          None    10    blue
#
#                                            FULL_NAME
# 0  Aquablu at 920 Intracoastal Dr #603 in Fort La...
# 1  Orchid Beach at 701 SE 21st Ave #407 in Deerfi...
# 2  Point Of America at 2200 S Ocean Ln #308 in Fo...
# 3  AQUARIUS CONDO at 2751 S Ocean Dr Unit 1701S i...
# 4  L'hermitage I at 3100 N Ocean Blvd #704 in For...
# 5  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6  Oceanage at 1645 S Ocean Ln #188 in Fort Laude...
# 7  Aztec Rv Resort at 431 S Cortez Dr #431 in Pom...
# 8  Sea Ranch Lakes North Con at 5200 N Ocean Blvd...
# 9  Four Seasons at 333 Sunset Dr #808 in Fort Lau...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 2, 11) ## List (Earlier) date
date2 = datetime(2025, 3, 20) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 37

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    599.0
# 1    752.0
# 2    622.0
# 3    693.0
# 4    597.0
# 5    615.0
# 6    766.0
# 7    774.0
# 8    512.0
# 9    421.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2025-03-19        920 Intracoastal Dr #603 in Fort Lauderdale  $1,950,000
# 1 2025-03-20            701 SE 21st Ave #407 in Deerfield Beach  $1,789,000
# 2 2025-03-21            2200 S Ocean Ln #308 in Fort Lauderdale  $1,250,000
# 3 2025-03-19            2751 S Ocean Dr Unit 1701S in Hollywood  $1,225,000
# 4 2025-03-18          3100 N Ocean Blvd #704 in Fort Lauderdale  $1,180,000
# 5 2025-03-20          333 Las Olas Way #3203 in Fort Lauderdale  $1,150,000
# 6 2025-03-18            1645 S Ocean Ln #188 in Fort Lauderdale    $975,000
# 7 2025-03-20              431 S Cortez Dr #431 in Pompano Beach    $920,000
# 8 2025-03-17  5200 N Ocean Blvd Unit 909D in Lauderdale By T...    $875,000
# 9 2025-03-20              333 Sunset Dr #808 in Fort Lauderdale    $745,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    3    3.5       3,258       2018          $599  Beaches MLS  F10468111
# 1    3    3.0       2,380       2006          $752  Beaches MLS  F10486204
# 2    4    2.0       2,011       1971          $622  Beaches MLS  F10464891
# 3    3    2.0       1,768       1973          $693       MARMLS  A11658942
# 4    3    2.5       1,977       1997          $597  Beaches MLS  F10476667
# 5    2    2.5       1,869       2004          $615       MARMLS  A11708273
# 6    2    2.0       1,273       1973          $766  Beaches MLS  F10483777
# 7    1    1.0       1,188       2010          $774  Beaches MLS  F10477577
# 8    3    2.0       1,708       1971          $512  Beaches MLS  F10479493
# 9    2    2.0       1,770       1959          $421  Beaches MLS  F10484349
#
#                                         LISTING INFO  \
# 0  Matthew Bertanzetti Florida Luxurious Properti...
# 1         Deborah Ruffino The Cove Guspav Realty
# 2  Michael Rizzo Coldwell Banker Realty Ely Benai...
# 3         Melanie Dayan Sunny Isles Realty, Inc.
# 4       Ross Guedry Winchester Group Real Estate
# 5      Bobbi Ocean Galleria International Realty
# 6  Barry Zimmerman Better Homes & Gdns RE Fla 1st...
# 7    Sylvie Jolicoeur Balistreri Real Estate Inc
# 8        Ana Maria Becker Coldwell Banker Realty
# 9     Peter Orenchuk Team Effort Real Estate Inc
#
#                                          BUYING INFO
# 0  Matthew Bertanzetti Florida Luxurious Properti...
# 1             One Sotheby's International Realty
# 2           Michael Rizzo Coldwell Banker Realty
# 3  Millana Ford Vera Realty LLC Michael Platon Ve...
# 4            Victor Attias Galt Ocean Realty Inc
# 5
# 6  Christine Hansen Vargas South Florida Home Sal...
# 7                   Jacobus Louw BHHS EWM Realty
# 8         Susan Gauthier By The Sea Realty, Inc.
# 9              Christian Widen The Keyes Company
