# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now() - timedelta(days=2)

# Get the date one week ago
one_week_ago = today - timedelta(days=8)

def format_date(date):
    day = date.day
    # Months 3-7 (March–July) should be full; all others abbreviated with a period
    if date.month in (3, 4, 5, 6, 7):
        month_str = date.strftime("%B")      # e.g. "March", "April", ...
    else:
        month_str = date.strftime("%b") + "."  # e.g. "Jan.", "Feb.", "Aug.", ...

    return f"{month_str} {day}"


# Format both dates
week_ending = format_date(today)
week_starting = format_date(one_week_ago)

print(week_starting, week_ending)
# Out:
# June 6 June 14

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE             ADDRESS        CITY  \
# 1  PAST SALE  June-9-2025   Condo/Co-op  4242 Deste Ct #305  Lake Worth
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33467.0  134999.0   2.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE    MLS#  \
# 1  https://www.redfin.com/FL/Greenacres/4242-Dest...   PBBOR  25-821
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  26.612095 -80.149542
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
#  Palm Beach

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-06-09    27
# 2025-06-12    22
# 2025-06-13    16
# 2025-06-11    14
# 2025-06-10    13
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 72  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 3   PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 17  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 2   PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 86  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 88  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 75  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 77  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 12  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 25  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 72    West Palm Beach                FL             33401.0  12543000.0   3.0
# 3          Boca Raton                FL             33432.0   2753000.0   2.0
# 17  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 2          Boca Raton                FL             33432.0   2039000.0   2.0
# 86         Boca Raton                FL             33432.0   1875000.0   2.0
# 88         Palm Beach                FL             33480.0   1690800.0   2.0
# 75      Singer Island                FL             33404.0   1650000.0   2.0
# 77         Boca Raton                FL             33432.0   1635700.0   2.0
# 12         Boca Raton                FL             33431.0   1387500.0   3.0
# 25         Boca Raton                FL             33434.0   1200000.0   3.0
#
#     BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 72    4.5  ...   Sold                         NaN                       NaN
# 3     3.0  ...   Sold                         NaN                       NaN
# 17    3.0  ...   Sold                         NaN                       NaN
# 2     2.5  ...   Sold                         NaN                       NaN
# 86    2.5  ...   Sold                         NaN                       NaN
# 88    2.0  ...   Sold                         NaN                       NaN
# 75    3.5  ...   Sold                         NaN                       NaN
# 77    2.0  ...   Sold                         NaN                       NaN
# 12    3.0  ...   Sold                         NaN                       NaN
# 25    2.0  ...   Sold                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 72  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
# 3   https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 17  https://www.redfin.com/FL/Palm-Beach-Shores/18...  Beaches MLS
# 2   https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 86  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...  Beaches MLS
# 88  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Beaches MLS
# 75  https://www.redfin.com/FL/Riviera-Beach/4000-N...  Beaches MLS
# 77  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
# 12  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...  Beaches MLS
# 25  https://www.redfin.com/FL/Boca-Raton/19980-Saw...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 72  RX-11029308         N          Y  26.703917 -80.049385
# 3   RX-11091056         N          Y  26.347042 -80.083200
# 17  RX-11076265         N          Y  26.781054 -80.039562
# 2   RX-11090640         N          Y  26.347042 -80.083200
# 86  RX-11030421         N          Y  26.350338 -80.082988
# 88  RX-11013110         N          Y  26.721061 -80.035205
# 75  RX-11053747         N          Y  26.795862 -80.032351
# 77  RX-11045437         N          Y  26.323476 -80.075019
# 12  RX-11069723         N          Y  26.389260 -80.067914
# 25  RX-11068508         N          Y  26.385217 -80.155402
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 1  PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 2  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 3  PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 4  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 5  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 6  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 7  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 8  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 9  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0    West Palm Beach                FL             33401.0  12543000.0   3.0
# 1         Boca Raton                FL             33432.0   2753000.0   2.0
# 2  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 3         Boca Raton                FL             33432.0   2039000.0   2.0
# 4         Boca Raton                FL             33432.0   1875000.0   2.0
# 5         Palm Beach                FL             33480.0   1690800.0   2.0
# 6      Singer Island                FL             33404.0   1650000.0   2.0
# 7         Boca Raton                FL             33432.0   1635700.0   2.0
# 8         Boca Raton                FL             33431.0   1387500.0   3.0
# 9         Boca Raton                FL             33434.0   1200000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    4.5  ... -80.049385  https://www.redfin.com/FL/West-Palm-Beach/1100...
# 1    3.0  ... -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 2    3.0  ... -80.039562  https://www.redfin.com/FL/Palm-Beach-Shores/18...
# 3    2.5  ... -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 4    2.5  ... -80.082988  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...
# 5    2.0  ... -80.035205  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...
# 6    3.5  ... -80.032351  https://www.redfin.com/FL/Riviera-Beach/4000-N...
# 7    2.0  ... -80.075019  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...
# 8    3.0  ... -80.067914  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...
# 9    2.0  ... -80.155402  https://www.redfin.com/FL/Boca-Raton/19980-Saw...
#
#        list_agent_name_1              list_broker_name_1    list_agent_name_2  \
# 0        Christian Angle     Christian Angle Real Estate                 None
# 1    Rochelle LeCavalier                 Douglas Elliman    Alejandro Salazar
# 2          Thomas Murray        Compass Florida LLC (PB)                 None
# 3    Rochelle LeCavalier                 Douglas Elliman    Alejandro Salazar
# 4          Michael Wells   Premier Estate Properties Inc            Scot Karp
# 5  Karen Lehrman Prayias    Sotheby's Intl. Realty, Inc.                 None
# 6           Emmy Buckman  Illustrated Properties LLC (Co         Owen Buckman
# 7         Andrew Pietrak    Luxury Real Estate Group LLC                 None
# 8            Lisa Nanfra             Compass Florida LLC  Beth Aronson Fisher
# 9         Abigail Wapner           Abigail Wapner Realty    Barbara Orenstein
#
#                list_broker_name_2       buy_agent_name_1  \
# 0                            None       Julien Taylor IV
# 1                 Douglas Elliman         Non Non-Member
# 2                            None          Thomas Murray
# 3                 Douglas Elliman              Non Agent
# 4   Premier Estate Properties Inc           Scott Eckert
# 5                            None  Karen Lehrman Prayias
# 6  Illustrated Properties LLC (Co        Meike MacGregor
# 7                            None         Robert Goodman
# 8             Compass Florida LLC           Sian Matthew
# 9           Abigail Wapner Realty            Ina Tuchman
#
#               buy_broker_name_1  buy_agent_name_2  buy_broker_name_2
# 0    William Raveis Real Estate              None               None
# 1     Non-Member Selling Office              None               None
# 2      Compass Florida LLC (PB)              None               None
# 3     Non-Member Selling Office              None               None
# 4                    RPE Realty              None               None
# 5  Sotheby's Intl. Realty, Inc.              None               None
# 6           Compass Florida LLC              None               None
# 7                      LoKation              None               None
# 8               Coldwell Banker              None               None
# 9          Boca West Realty LLC              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 92

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $598,087

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $353

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $55,024,048

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           92              598087          353                     55024048.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 91
# -----------
# Input Previous Week Condo Average Sales Price:
# 592601
# -----------
# Input Previous Week Condo Average PSF:
# 341
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 53926699.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op  1100 S Flagler Dr #1502
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0  West Palm Beach                FL             33401.0  12543000.0   3.0
#
#    BATHS       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.5  Bristol Condo       3815.0       NaN      2019.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         3288.0     8327.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...   Christian Angle
#
#             list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Christian Angle Real Estate              None               None
#
#    buy_agent_name_1           buy_broker_name_1 buy_agent_name_2  \
# 0  Julien Taylor IV  William Raveis Real Estate             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 1  PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 2  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 3  PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 4  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 5  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 6  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 7  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 8  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 9  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0    West Palm Beach                FL             33401.0  12543000.0   3.0
# 1         Boca Raton                FL             33432.0   2753000.0   2.0
# 2  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 3         Boca Raton                FL             33432.0   2039000.0   2.0
# 4         Boca Raton                FL             33432.0   1875000.0   2.0
# 5         Palm Beach                FL             33480.0   1690800.0   2.0
# 6      Singer Island                FL             33404.0   1650000.0   2.0
# 7         Boca Raton                FL             33432.0   1635700.0   2.0
# 8         Boca Raton                FL             33431.0   1387500.0   3.0
# 9         Boca Raton                FL             33434.0   1200000.0   3.0
#
#    BATHS                        LOCATION  SQUARE FEET   LOT SIZE  YEAR BUILT  \
# 0    4.5                   Bristol Condo       3815.0        NaN      2019.0
# 1    3.0                Alina Residences       2701.0      180.0      2024.0
# 2    3.0    Havn Yacht Club & Residences       2662.0        NaN      2008.0
# 3    2.5                Alina Residences       1937.0      180.0      2024.0
# 4    2.5    200 East Palmetto Park Condo       2018.0     2018.0      2009.0
# 5    2.0        Ocean Towers North Condo       1395.0        NaN      1968.0
# 6    3.5                      Martinique       2011.0        NaN      1986.0
# 7    2.0              Ocean Towers Condo       1425.0        NaN      1973.0
# 8    3.0  Sea Ranch Club OF Boca I Condo       2660.0        NaN      1981.0
# 9    2.0     Village OF Peppertree Condo       1779.0  1519994.0      1979.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3288.0     8327.0   Sold
# 1             NaN         1019.0     2283.0   Sold
# 2             NaN          939.0     3993.0   Sold
# 3             NaN         1053.0     1625.0   Sold
# 4             NaN          929.0     2292.0   Sold
# 5             NaN         1212.0     2138.0   Sold
# 6             NaN          820.0     1901.0   Sold
# 7             NaN         1148.0     1262.0   Sold
# 8             NaN          522.0     2494.0   Sold
# 9             NaN          675.0     1219.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
# 1  RX-11091056        N          Y  26.347042 -80.083200
# 2  RX-11076265        N          Y  26.781054 -80.039562
# 3  RX-11090640        N          Y  26.347042 -80.083200
# 4  RX-11030421        N          Y  26.350338 -80.082988
# 5  RX-11013110        N          Y  26.721061 -80.035205
# 6  RX-11053747        N          Y  26.795862 -80.032351
# 7  RX-11045437        N          Y  26.323476 -80.075019
# 8  RX-11069723        N          Y  26.389260 -80.067914
# 9  RX-11068508        N          Y  26.385217 -80.155402
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...        Christian Angle
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...          Thomas Murray
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...          Michael Wells
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Karen Lehrman Prayias
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...           Emmy Buckman
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...         Andrew Pietrak
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...            Lisa Nanfra
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...         Abigail Wapner
#
#                list_broker_name_1    list_agent_name_2  \
# 0     Christian Angle Real Estate                 None
# 1                 Douglas Elliman    Alejandro Salazar
# 2        Compass Florida LLC (PB)                 None
# 3                 Douglas Elliman    Alejandro Salazar
# 4   Premier Estate Properties Inc            Scot Karp
# 5    Sotheby's Intl. Realty, Inc.                 None
# 6  Illustrated Properties LLC (Co         Owen Buckman
# 7    Luxury Real Estate Group LLC                 None
# 8             Compass Florida LLC  Beth Aronson Fisher
# 9           Abigail Wapner Realty    Barbara Orenstein
#
#                list_broker_name_2       buy_agent_name_1  \
# 0                            None       Julien Taylor IV
# 1                 Douglas Elliman         Non Non-Member
# 2                            None          Thomas Murray
# 3                 Douglas Elliman              Non Agent
# 4   Premier Estate Properties Inc           Scott Eckert
# 5                            None  Karen Lehrman Prayias
# 6  Illustrated Properties LLC (Co        Meike MacGregor
# 7                            None         Robert Goodman
# 8             Compass Florida LLC           Sian Matthew
# 9           Abigail Wapner Realty            Ina Tuchman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0    William Raveis Real Estate             None              None     1
# 1     Non-Member Selling Office             None              None     2
# 2      Compass Florida LLC (PB)             None              None     3
# 3     Non-Member Selling Office             None              None     4
# 4                    RPE Realty             None              None     5
# 5  Sotheby's Intl. Realty, Inc.             None              None     6
# 6           Compass Florida LLC             None              None     7
# 7                      LoKation             None              None     8
# 8               Coldwell Banker             None              None     9
# 9          Boca West Realty LLC             None              None    10
#
#     COLOR
# 0  orange
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# 5    blue
# 6    blue
# 7    blue
# 8    blue
# 9    blue

# %%
# %store -r map_box_api_key

# %%
import folium
from branca.element import Template, MacroElement

# ——— Your title & caption HTML ———
title_html = f'''
  <h3 align="center" style="font-size:16px"><b>Recent {county} County Condo Sales</b></h3>
'''
caption_html = f'''
  <p align="center" style="font-size:13px"><i>{week_starting} — {week_ending}</i></p>
'''

# ——— Base map ———
m = folium.Map(
    location=df[['LATITUDE','LONGITUDE']].mean().to_list(),
    zoom_start=9,
    tiles=None
)

# ——— Tile layers ———
folium.TileLayer('OpenStreetMap', name='OSM', control=False).add_to(m)
folium.TileLayer(
    tiles=(
        "https://api.mapbox.com/styles/v1/"
        "mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x"
        f"?access_token={map_box_api_key}"
    ),
    attr="Mapbox", name="Streets", control=False
).add_to(m)

# ——— Add your markers ———
for _, row in df_top_ten.iterrows():
    lat, lon = row['LATITUDE'], row['LONGITUDE']
    popup = folium.Popup(popup_html(row), max_width=400)

    if row['COLOR'] == 'blue':
        # Regular sale: blue circle
        folium.CircleMarker(
            location=(lat, lon),
            radius=7,
            fill=True,
            fill_color='blue',
            fill_opacity=0.5,
            color=None,
            popup=popup
        ).add_to(m)
    else:
        # Top sale: gold star
        folium.Marker(
            location=(lat, lon),
            popup=popup,
            icon=folium.DivIcon(
                html="""
                <div style="font-size:24px; line-height:24px; color:gold;">
                  &#9733;
                </div>
                """
            )
        ).add_to(m)

# ——— Layer control, title & caption ———
folium.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))

# ——— Optional legend via branca ———
legend_html = """
{% macro html(this, kwargs) %}
  <div style="
      position: fixed;
      bottom: 50px; left: 50px;
      background: white; padding: 8px;
      border: 2px solid grey;
      font-size: 12px;
      z-index: 9999;
  ">
    <div style="display:inline-block; font-size:18px; color:gold; margin-right:6px;">&#9733;</div> Top Sale<br>
    <i style="background: blue; width: 10px; height: 10px;
       display: inline-block; margin-right: 6px;"></i> All other sales
  </div>
{% endmacro %}
"""
legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)

# ——— Display ———
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6520719ee1f88896744c37f0e7a4b217 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#   &lt;p align=&quot;center&quot; style=&quot;font-size:13px&quot;&gt;&lt;i&gt;June 6 — June 14&lt;/i&gt;&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6520719ee1f88896744c37f0e7a4b217&quot; &gt;&lt;/div&gt;
#
#
#   &lt;div style=&quot;
#       position: fixed;
#       bottom: 50px; left: 50px;
#       background: white; padding: 8px;
#       border: 2px solid grey;
#       font-size: 12px;
#       z-index: 9999;
#   &quot;&gt;
#     &lt;div style=&quot;display:inline-block; font-size:18px; color:gold; margin-right:6px;&quot;&gt;&amp;#9733;&lt;/div&gt; Top Sale&lt;br&gt;
#     &lt;i style=&quot;background: blue; width: 10px; height: 10px;
#        display: inline-block; margin-right: 6px;&quot;&gt;&lt;/i&gt; All other sales
#   &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6520719ee1f88896744c37f0e7a4b217 = L.map(
#                 &quot;map_6520719ee1f88896744c37f0e7a4b217&quot;,
#                 {
#                     center: [26.58754141304348, -80.10535278152174],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb21854f34521eb46d95f91c453e9616 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6520719ee1f88896744c37f0e7a4b217);
#
#
#             var tile_layer_04b5f21350a61bd55598be80b7bfa108 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoidHJkZGF0YSIsImEiOiJjamc2bTc2YmUxY2F3MnZxZGh2amR2MTY5In0.QlOWqB-yQNrNlXD0KQ9IvQ&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6520719ee1f88896744c37f0e7a4b217);
#
#
#             var marker_eb20d865f7887ae1f7abaa8939c695af = L.marker(
#                 [26.7039174, -80.0493848],
#                 {}
#             ).addTo(map_6520719ee1f88896744c37f0e7a4b217);
#
#
#             var div_icon_a590a0732bc871852bec816e067154c1 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size:24px; line-height:24px; color:gold;\&quot;\u003e\n                  \u0026#9733;\n                \u003c/div\u003e\n                &quot;});
#             marker_eb20d865f7887ae1f7abaa8939c695af.setIcon(div_icon_a590a0732bc871852bec816e067154c1);
#
#
#         var popup_3ebbbfefc87829d1177e7031f7acecdf = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9c1c52cdd8d50c0a50eed7d36587d46e = $(`&lt;div id=&quot;html_9c1c52cdd8d50c0a50eed7d36587d46e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1100 S Flagler Dr #1502&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$12,543,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3,288.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,815.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2019.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_3ebbbfefc87829d1177e7031f7acecdf.setContent(html_9c1c52cdd8d50c0a50eed7d36587d46e);
#
#
#
#         marker_eb20d865f7887ae1f7abaa8939c695af.bindPopup(popup_3ebbbfefc87829d1177e7031f7acecdf)
#         ;
#
#
#
#
#             var circle_marker_d03d1ede6b1aad1db9b9aace1fa065a1 = L.circleMarker(
#                 [26.3470419, -80.0832],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6520719ee1f88896744c37f0e7a4b217);
#
#
#         var popup_1ea3c8c0cb76ef895b304250b7978263 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9f00d6365cd6da5b31af40fa5eac4790 = $(`&lt;div id=&quot;html_9f00d6365cd6da5b31af40fa5eac4790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;220 SE Mizner Blvd #303&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,753,000.0&lt;br&gt;     &lt;strong&gt;Price

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op  1100 S Flagler Dr #1502
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0  West Palm Beach                FL             33401.0  12543000.0   3.0
#
#    BATHS       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.5  Bristol Condo       3815.0       NaN      2019.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         3288.0     8327.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...   Christian Angle
#
#             list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Christian Angle Real Estate              None               None
#
#    buy_agent_name_1           buy_broker_name_1 buy_agent_name_2  \
# 0  Julien Taylor IV  William Raveis Real Estate             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_06162025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Bristol Condo at 1100 S Flagler Dr #1502 in West Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 1  PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 2  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 3  PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 4  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 5  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 6  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 7  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 8  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 9  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0    West Palm Beach                FL             33401.0  12543000.0   3.0
# 1         Boca Raton                FL             33432.0   2753000.0   2.0
# 2  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 3         Boca Raton                FL             33432.0   2039000.0   2.0
# 4         Boca Raton                FL             33432.0   1875000.0   2.0
# 5         Palm Beach                FL             33480.0   1690800.0   2.0
# 6      Singer Island                FL             33404.0   1650000.0   2.0
# 7         Boca Raton                FL             33432.0   1635700.0   2.0
# 8         Boca Raton                FL             33431.0   1387500.0   3.0
# 9         Boca Raton                FL             33434.0   1200000.0   3.0
#
#    BATHS                        LOCATION  SQUARE FEET   LOT SIZE  YEAR BUILT  \
# 0    4.5                   Bristol Condo       3815.0        NaN      2019.0
# 1    3.0                Alina Residences       2701.0      180.0      2024.0
# 2    3.0    Havn Yacht Club & Residences       2662.0        NaN      2008.0
# 3    2.5                Alina Residences       1937.0      180.0      2024.0
# 4    2.5    200 East Palmetto Park Condo       2018.0     2018.0      2009.0
# 5    2.0        Ocean Towers North Condo       1395.0        NaN      1968.0
# 6    3.5                      Martinique       2011.0        NaN      1986.0
# 7    2.0              Ocean Towers Condo       1425.0        NaN      1973.0
# 8    3.0  Sea Ranch Club OF Boca I Condo       2660.0        NaN      1981.0
# 9    2.0     Village OF Peppertree Condo       1779.0  1519994.0      1979.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3288.0     8327.0   Sold
# 1             NaN         1019.0     2283.0   Sold
# 2             NaN          939.0     3993.0   Sold
# 3             NaN         1053.0     1625.0   Sold
# 4             NaN          929.0     2292.0   Sold
# 5             NaN         1212.0     2138.0   Sold
# 6             NaN          820.0     1901.0   Sold
# 7             NaN         1148.0     1262.0   Sold
# 8             NaN          522.0     2494.0   Sold
# 9             NaN          675.0     1219.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
# 1  RX-11091056        N          Y  26.347042 -80.083200
# 2  RX-11076265        N          Y  26.781054 -80.039562
# 3  RX-11090640        N          Y  26.347042 -80.083200
# 4  RX-11030421        N          Y  26.350338 -80.082988
# 5  RX-11013110        N          Y  26.721061 -80.035205
# 6  RX-11053747        N          Y  26.795862 -80.032351
# 7  RX-11045437        N          Y  26.323476 -80.075019
# 8  RX-11069723        N          Y  26.389260 -80.067914
# 9  RX-11068508        N          Y  26.385217 -80.155402
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...        Christian Angle
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...          Thomas Murray
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...          Michael Wells
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Karen Lehrman Prayias
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...           Emmy Buckman
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...         Andrew Pietrak
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...            Lisa Nanfra
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...         Abigail Wapner
#
#                list_broker_name_1    list_agent_name_2  \
# 0     Christian Angle Real Estate                 None
# 1                 Douglas Elliman    Alejandro Salazar
# 2        Compass Florida LLC (PB)                 None
# 3                 Douglas Elliman    Alejandro Salazar
# 4   Premier Estate Properties Inc            Scot Karp
# 5    Sotheby's Intl. Realty, Inc.                 None
# 6  Illustrated Properties LLC (Co         Owen Buckman
# 7    Luxury Real Estate Group LLC                 None
# 8             Compass Florida LLC  Beth Aronson Fisher
# 9           Abigail Wapner Realty    Barbara Orenstein
#
#                list_broker_name_2       buy_agent_name_1  \
# 0                            None       Julien Taylor IV
# 1                 Douglas Elliman         Non Non-Member
# 2                            None          Thomas Murray
# 3                 Douglas Elliman              Non Agent
# 4   Premier Estate Properties Inc           Scott Eckert
# 5                            None  Karen Lehrman Prayias
# 6  Illustrated Properties LLC (Co        Meike MacGregor
# 7                            None         Robert Goodman
# 8             Compass Florida LLC           Sian Matthew
# 9           Abigail Wapner Realty            Ina Tuchman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0    William Raveis Real Estate             None              None     1
# 1     Non-Member Selling Office             None              None     2
# 2      Compass Florida LLC (PB)             None              None     3
# 3     Non-Member Selling Office             None              None     4
# 4                    RPE Realty             None              None     5
# 5  Sotheby's Intl. Realty, Inc.             None              None     6
# 6           Compass Florida LLC             None              None     7
# 7                      LoKation             None              None     8
# 8               Coldwell Banker             None              None     9
# 9          Boca West Realty LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Bristol Condo at 1100 S Flagler Dr #1502 in We...
# 1    blue  Alina Residences at 220 SE Mizner Blvd #303 in...
# 2    blue  Havn Yacht Club & Residences at 184 Lake Dr Un...
# 3    blue  Alina Residences at 220 SE Mizner Blvd #102 in...
# 4    blue  200 East Palmetto Park Condo at 200 E Palmetto...
# 5    blue  Ocean Towers North Condo at 170 N Ocean Blvd #...
# 6    blue  Martinique at 4000 N Ocean Dr #301 in Singer I...
# 7    blue  Ocean Towers Condo at 2800 S Ocean Blvd S Unit...
# 8    blue  Sea Ranch Club OF Boca I Condo at 4301 N Ocean...
# 9    blue  Village OF Peppertree Condo at 19980 Sawgrass ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Bristol Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,200,000 to $12,543,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, West Palm Beach, Palm Beach, Boca Raton, Singer Island, Palm Beach Shores, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 92 condo sales totaling $55,024,048 million from June 6 to June 14. The previous week, brokers closed 91 condo sales totaling $53,926,699.
#
# Last week’s units sold for an average of $598,087, higher than the $592,601 average price from the previous week. The average price per square foot rose to $353 from $341, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,200,000.0 million to $12,543,000.0 million.
#
# Bristol Condo at 1100 S Flagler Dr #1502 in West Palm Beach took the top spot with a $12,543,000.0 million closing. The sale closed at $3,288.0 per square foot.
#
# Christian Angle with Christian Angle Real Estate, and None with None had the listing.
# Julien Taylor IV with William Raveis Real Estate, and None with None represented the buyer.
#
# Alina Residences at 220 SE Mizner Blvd #303 in Boca Raton, closed for the second highest amount, $2,753,000.0, or $1,019.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Alejandro Salazar with Douglas Elliman had the listing.
# Non Non-Member with Non-Member Selling Office, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_06162025 " width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from June 6 to June 14:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 1  PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 2  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 3  PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 4  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 5  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 6  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 7  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 8  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 9  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0    West Palm Beach                FL             33401.0  12543000.0   3.0
# 1         Boca Raton                FL             33432.0   2753000.0   2.0
# 2  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 3         Boca Raton                FL             33432.0   2039000.0   2.0
# 4         Boca Raton                FL             33432.0   1875000.0   2.0
# 5         Palm Beach                FL             33480.0   1690800.0   2.0
# 6      Singer Island                FL             33404.0   1650000.0   2.0
# 7         Boca Raton                FL             33432.0   1635700.0   2.0
# 8         Boca Raton                FL             33431.0   1387500.0   3.0
# 9         Boca Raton                FL             33434.0   1200000.0   3.0
#
#    BATHS                        LOCATION  SQUARE FEET   LOT SIZE  YEAR BUILT  \
# 0    4.5                   Bristol Condo       3815.0        NaN      2019.0
# 1    3.0                Alina Residences       2701.0      180.0      2024.0
# 2    3.0    Havn Yacht Club & Residences       2662.0        NaN      2008.0
# 3    2.5                Alina Residences       1937.0      180.0      2024.0
# 4    2.5    200 East Palmetto Park Condo       2018.0     2018.0      2009.0
# 5    2.0        Ocean Towers North Condo       1395.0        NaN      1968.0
# 6    3.5                      Martinique       2011.0        NaN      1986.0
# 7    2.0              Ocean Towers Condo       1425.0        NaN      1973.0
# 8    3.0  Sea Ranch Club OF Boca I Condo       2660.0        NaN      1981.0
# 9    2.0     Village OF Peppertree Condo       1779.0  1519994.0      1979.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3288.0     8327.0   Sold
# 1             NaN         1019.0     2283.0   Sold
# 2             NaN          939.0     3993.0   Sold
# 3             NaN         1053.0     1625.0   Sold
# 4             NaN          929.0     2292.0   Sold
# 5             NaN         1212.0     2138.0   Sold
# 6             NaN          820.0     1901.0   Sold
# 7             NaN         1148.0     1262.0   Sold
# 8             NaN          522.0     2494.0   Sold
# 9             NaN          675.0     1219.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
# 1  RX-11091056        N          Y  26.347042 -80.083200
# 2  RX-11076265        N          Y  26.781054 -80.039562
# 3  RX-11090640        N          Y  26.347042 -80.083200
# 4  RX-11030421        N          Y  26.350338 -80.082988
# 5  RX-11013110        N          Y  26.721061 -80.035205
# 6  RX-11053747        N          Y  26.795862 -80.032351
# 7  RX-11045437        N          Y  26.323476 -80.075019
# 8  RX-11069723        N          Y  26.389260 -80.067914
# 9  RX-11068508        N          Y  26.385217 -80.155402
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...        Christian Angle
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...          Thomas Murray
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...          Michael Wells
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Karen Lehrman Prayias
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...           Emmy Buckman
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...         Andrew Pietrak
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...            Lisa Nanfra
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...         Abigail Wapner
#
#                list_broker_name_1    list_agent_name_2  \
# 0     Christian Angle Real Estate                 None
# 1                 Douglas Elliman    Alejandro Salazar
# 2        Compass Florida LLC (PB)                 None
# 3                 Douglas Elliman    Alejandro Salazar
# 4   Premier Estate Properties Inc            Scot Karp
# 5    Sotheby's Intl. Realty, Inc.                 None
# 6  Illustrated Properties LLC (Co         Owen Buckman
# 7    Luxury Real Estate Group LLC                 None
# 8             Compass Florida LLC  Beth Aronson Fisher
# 9           Abigail Wapner Realty    Barbara Orenstein
#
#                list_broker_name_2       buy_agent_name_1  \
# 0                            None       Julien Taylor IV
# 1                 Douglas Elliman         Non Non-Member
# 2                            None          Thomas Murray
# 3                 Douglas Elliman              Non Agent
# 4   Premier Estate Properties Inc           Scott Eckert
# 5                            None  Karen Lehrman Prayias
# 6  Illustrated Properties LLC (Co        Meike MacGregor
# 7                            None         Robert Goodman
# 8             Compass Florida LLC           Sian Matthew
# 9           Abigail Wapner Realty            Ina Tuchman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0    William Raveis Real Estate             None              None     1
# 1     Non-Member Selling Office             None              None     2
# 2      Compass Florida LLC (PB)             None              None     3
# 3     Non-Member Selling Office             None              None     4
# 4                    RPE Realty             None              None     5
# 5  Sotheby's Intl. Realty, Inc.             None              None     6
# 6           Compass Florida LLC             None              None     7
# 7                      LoKation             None              None     8
# 8               Coldwell Banker             None              None     9
# 9          Boca West Realty LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Bristol Condo at 1100 S Flagler Dr #1502 in We...
# 1    blue  Alina Residences at 220 SE Mizner Blvd #303 in...
# 2    blue  Havn Yacht Club & Residences at 184 Lake Dr Un...
# 3    blue  Alina Residences at 220 SE Mizner Blvd #102 in...
# 4    blue  200 East Palmetto Park Condo at 200 E Palmetto...
# 5    blue  Ocean Towers North Condo at 170 N Ocean Blvd #...
# 6    blue  Martinique at 4000 N Ocean Dr #301 in Singer I...
# 7    blue  Ocean Towers Condo at 2800 S Ocean Blvd S Unit...
# 8    blue  Sea Ranch Club OF Boca I Condo at 4301 N Ocean...
# 9    blue  Village OF Peppertree Condo at 19980 Sawgrass ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Bristol Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,200,000 to $12,543,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, West Palm Beach, Palm Beach, Boca Raton, Singer Island, Palm Beach Shores, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 92 condo sales totaling $55,024,048 million from June 6 to June 14. The previous week, brokers closed 91 condo sales totaling $53,926,699.
#
# Last week’s units sold for an average of $598,087, higher than the $592,601 average price from the previous week. The average price per square foot rose to $353 from $341, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,200,000.0 million to $12,543,000.0 million.
#
# Bristol Condo at 1100 S Flagler Dr #1502 in West Palm Beach took the top spot with a $12,543,000.0 million closing. The sale closed at $3,288.0 per square foot.
#
# Christian Angle with Christian Angle Real Estate, and None with None had the listing.
# Julien Taylor IV with William Raveis Real Estate, and None with None represented the buyer.
#
# Alina Residences at 220 SE Mizner Blvd #303 in Boca Raton, closed for the second highest amount, $2,753,000.0, or $1,019.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Alejandro Salazar with Douglas Elliman had the listing.
# Non Non-Member with Non-Member Selling Office, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_06162025 " width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from June 6 to June 14:
#
# Most Expensive
# Bristol Condo, 1100 S Flagler Dr #1502, in West Palm Beach | Price: $12,543,000 | $3,288 psf | Listing agents: Christian Angle with Christian Angle Real Estate and None with None | Buyer's agents: Julien Taylor IV with William Raveis Real Estate and None with None
#
# Least Expensive
# Village OF Peppertree Condo, 19980 Sawgrass Ln #5104, in Boca Raton | Price: $1,200,000 | $675 psf | Listing agents: Abigail Wapner with Abigail Wapner Realty and Barbara Orenstein with Abigail Wapner Realty | Buyer's agents: Ina Tuchman with Boca West Realty LLC and None with None
#
# Highest Price Per Square Foot
# Bristol Condo, 1100 S Flagler Dr #1502, in West Palm Beach | Price: $12,543,000 | $3,288 psf | Listing agents: Christian Angle with Christian Angle Real Estate and None with None | Buyer's agents: Julien Taylor IV with William Raveis Real Estate and None with None
#
# Lowest Price Per Square Foot
# Sea Ranch Club OF Boca I Condo, 4301 N Ocean Blvd #201, in Boca Raton | Price: $1,387,500 | $522 psf | Listing agents: Lisa Nanfra with Compass Florida LLC and Beth Aronson Fisher with Compass Florida LLC | Buyer's agents: Sian Matthew with Coldwell Banker and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/West-Palm-Beach/1100-S-Flagler-Dr-33401/unit-1502/home/168183440
# Second priciest sale:  https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-303/home/195825379
# Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/19980-Sawgrass-Ln-33434/unit-5104/home/42638716
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/4301-N-Ocean-Blvd-33431/unit-201/home/42320754
# Highest top ten psf:  https://www.redfin.com/FL/West-Palm-Beach/1100-S-Flagler-Dr-33401/unit-1502/home/168183440
# Lowest top ten psf:  https://www.redfin.com/FL/Boca-Raton/4301-N-Ocean-Blvd-33431/unit-201/home/42320754

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/West-Palm-Beach/1100-S-Flagler-Dr-33401/unit-1502/home/168183440

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-303/home/195825379

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/19980-Sawgrass-Ln-33434/unit-5104/home/42638716

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/4301-N-Ocean-Blvd-33431/unit-201/home/42320754

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/1100-S-Flagler-Dr-33401/unit-1502/home/168183440

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/4301-N-Ocean-Blvd-33431/unit-201/home/42320754

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-06-13   Condo/Co-op        1100 S Flagler Dr #1502
# 1  PAST SALE 2025-06-11   Condo/Co-op        220 SE Mizner Blvd #303
# 2  PAST SALE 2025-06-11   Condo/Co-op         184 Lake Dr Unit 1-201
# 3  PAST SALE 2025-06-13   Condo/Co-op        220 SE Mizner Blvd #102
# 4  PAST SALE 2025-06-13   Condo/Co-op    200 E Palmetto Park Rd #409
# 5  PAST SALE 2025-06-10   Condo/Co-op          170 N Ocean Blvd #307
# 6  PAST SALE 2025-06-09   Condo/Co-op           4000 N Ocean Dr #301
# 7  PAST SALE 2025-06-13   Condo/Co-op  2800 S Ocean Blvd S Unit 19 C
# 8  PAST SALE 2025-06-10   Condo/Co-op         4301 N Ocean Blvd #201
# 9  PAST SALE 2025-06-09   Condo/Co-op        19980 Sawgrass Ln #5104
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0    West Palm Beach                FL             33401.0  12543000.0   3.0
# 1         Boca Raton                FL             33432.0   2753000.0   2.0
# 2  Palm Beach Shores                FL             33404.0   2500000.0   2.0
# 3         Boca Raton                FL             33432.0   2039000.0   2.0
# 4         Boca Raton                FL             33432.0   1875000.0   2.0
# 5         Palm Beach                FL             33480.0   1690800.0   2.0
# 6      Singer Island                FL             33404.0   1650000.0   2.0
# 7         Boca Raton                FL             33432.0   1635700.0   2.0
# 8         Boca Raton                FL             33431.0   1387500.0   3.0
# 9         Boca Raton                FL             33434.0   1200000.0   3.0
#
#    BATHS                        LOCATION  SQUARE FEET   LOT SIZE  YEAR BUILT  \
# 0    4.5                   Bristol Condo       3815.0        NaN      2019.0
# 1    3.0                Alina Residences       2701.0      180.0      2024.0
# 2    3.0    Havn Yacht Club & Residences       2662.0        NaN      2008.0
# 3    2.5                Alina Residences       1937.0      180.0      2024.0
# 4    2.5    200 East Palmetto Park Condo       2018.0     2018.0      2009.0
# 5    2.0        Ocean Towers North Condo       1395.0        NaN      1968.0
# 6    3.5                      Martinique       2011.0        NaN      1986.0
# 7    2.0              Ocean Towers Condo       1425.0        NaN      1973.0
# 8    3.0  Sea Ranch Club OF Boca I Condo       2660.0        NaN      1981.0
# 9    2.0     Village OF Peppertree Condo       1779.0  1519994.0      1979.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3288.0     8327.0   Sold
# 1             NaN         1019.0     2283.0   Sold
# 2             NaN          939.0     3993.0   Sold
# 3             NaN         1053.0     1625.0   Sold
# 4             NaN          929.0     2292.0   Sold
# 5             NaN         1212.0     2138.0   Sold
# 6             NaN          820.0     1901.0   Sold
# 7             NaN         1148.0     1262.0   Sold
# 8             NaN          522.0     2494.0   Sold
# 9             NaN          675.0     1219.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11029308        N          Y  26.703917 -80.049385
# 1  RX-11091056        N          Y  26.347042 -80.083200
# 2  RX-11076265        N          Y  26.781054 -80.039562
# 3  RX-11090640        N          Y  26.347042 -80.083200
# 4  RX-11030421        N          Y  26.350338 -80.082988
# 5  RX-11013110        N          Y  26.721061 -80.035205
# 6  RX-11053747        N          Y  26.795862 -80.032351
# 7  RX-11045437        N          Y  26.323476 -80.075019
# 8  RX-11069723        N          Y  26.389260 -80.067914
# 9  RX-11068508        N          Y  26.385217 -80.155402
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/West-Palm-Beach/1100...        Christian Angle
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Palm-Beach-Shores/18...          Thomas Murray
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...    Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/200-E-Pal...          Michael Wells
# 5  https://www.redfin.com/FL/Palm-Beach/170-N-Oce...  Karen Lehrman Prayias
# 6  https://www.redfin.com/FL/Riviera-Beach/4000-N...           Emmy Buckman
# 7  https://www.redfin.com/FL/Boca-Raton/2800-S-Oc...         Andrew Pietrak
# 8  https://www.redfin.com/FL/Boca-Raton/4301-N-Oc...            Lisa Nanfra
# 9  https://www.redfin.com/FL/Boca-Raton/19980-Saw...         Abigail Wapner
#
#                list_broker_name_1    list_agent_name_2  \
# 0     Christian Angle Real Estate                 None
# 1                 Douglas Elliman    Alejandro Salazar
# 2        Compass Florida LLC (PB)                 None
# 3                 Douglas Elliman    Alejandro Salazar
# 4   Premier Estate Properties Inc            Scot Karp
# 5    Sotheby's Intl. Realty, Inc.                 None
# 6  Illustrated Properties LLC (Co         Owen Buckman
# 7    Luxury Real Estate Group LLC                 None
# 8             Compass Florida LLC  Beth Aronson Fisher
# 9           Abigail Wapner Realty    Barbara Orenstein
#
#                list_broker_name_2       buy_agent_name_1  \
# 0                            None       Julien Taylor IV
# 1                 Douglas Elliman         Non Non-Member
# 2                            None          Thomas Murray
# 3                 Douglas Elliman              Non Agent
# 4   Premier Estate Properties Inc           Scott Eckert
# 5                            None  Karen Lehrman Prayias
# 6  Illustrated Properties LLC (Co        Meike MacGregor
# 7                            None         Robert Goodman
# 8             Compass Florida LLC           Sian Matthew
# 9           Abigail Wapner Realty            Ina Tuchman
#
#               buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0    William Raveis Real Estate             None              None     1
# 1     Non-Member Selling Office             None              None     2
# 2      Compass Florida LLC (PB)             None              None     3
# 3     Non-Member Selling Office             None              None     4
# 4                    RPE Realty             None              None     5
# 5  Sotheby's Intl. Realty, Inc.             None              None     6
# 6           Compass Florida LLC             None              None     7
# 7                      LoKation             None              None     8
# 8               Coldwell Banker             None              None     9
# 9          Boca West Realty LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Bristol Condo at 1100 S Flagler Dr #1502 in We...
# 1    blue  Alina Residences at 220 SE Mizner Blvd #303 in...
# 2    blue  Havn Yacht Club & Residences at 184 Lake Dr Un...
# 3    blue  Alina Residences at 220 SE Mizner Blvd #102 in...
# 4    blue  200 East Palmetto Park Condo at 200 E Palmetto...
# 5    blue  Ocean Towers North Condo at 170 N Ocean Blvd #...
# 6    blue  Martinique at 4000 N Ocean Dr #301 in Singer I...
# 7    blue  Ocean Towers Condo at 2800 S Ocean Blvd S Unit...
# 8    blue  Sea Ranch Club OF Boca I Condo at 4301 N Ocean...
# 9    blue  Village OF Peppertree Condo at 19980 Sawgrass ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 5, 15) ## List (Earlier) date
date2 = datetime(2025, 6, 11) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 27

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING AGENTS'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING AGENTS'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "BEDS", 
    "BATHS",
    "SOURCE", 
    "MLS#"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df = chart_df.rename(columns={'$/SQUARE FEET':'PPSF'})

# %%
chart_df['PPSF'].astype(float)
# Out:
# 0    3288.0
# 1    1019.0
# 2     939.0
# 3    1053.0
# 4     929.0
# 5    1212.0
# 6     820.0
# 7    1148.0
# 8     522.0
# 9     675.0
# Name: PPSF, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['PPSF'] = chart_df['PPSF'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))

# %%
desired_order = [
    'SOLD DATE',
    'LOCATION',
    'ADDRESS',
    'PRICE',
    'SQUARE FEET',
    'PPSF',
    'YEAR BUILT',
    'LISTING AGENTS',
    'BUYING AGENTS'
]

chart_df = chart_df[desired_order]

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                      ADDRESS        PRICE  \
# 0 2025-06-13   1100 S Flagler Dr #1502 in West Palm Beach  $12,543,000
# 1 2025-06-11        220 SE Mizner Blvd #303 in Boca Raton   $2,753,000
# 2 2025-06-11  184 Lake Dr Unit 1-201 in Palm Beach Shores   $2,500,000
# 3 2025-06-13        220 SE Mizner Blvd #102 in Boca Raton   $2,039,000
# 4 2025-06-13    200 E Palmetto Park Rd #409 in Boca Raton   $1,875,000
# 5 2025-06-10          170 N Ocean Blvd #307 in Palm Beach   $1,690,800
# 6 2025-06-09        4000 N Ocean Dr #301 in Singer Island   $1,650,000
# 7 2025-06-13  2800 S Ocean Blvd S Unit 19 C in Boca Raton   $1,635,700
# 8 2025-06-10         4301 N Ocean Blvd #201 in Boca Raton   $1,387,500
# 9 2025-06-09        19980 Sawgrass Ln #5104 in Boca Raton   $1,200,000
#
#   SQUARE FEET    PPSF YEAR BUILT  \
# 0       3,815  $3,288       2019
# 1       2,701  $1,019       2024
# 2       2,662    $939       2008
# 3       1,937  $1,053       2024
# 4       2,018    $929       2009
# 5       1,395  $1,212       1968
# 6       2,011    $820       1986
# 7       1,425  $1,148       1973
# 8       2,660    $522       1981
# 9       1,779    $675       1979
#
#                                       LISTING AGENTS  \
# 0    Christian Angle Christian Angle Real Estate
# 1  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 2         Thomas Murray Compass Florida LLC (PB)
# 3  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 4  Michael Wells Premier Estate Properties Inc Sc...
# 5  Karen Lehrman Prayias Sotheby's Intl. Realty, ...
# 6  Emmy Buckman Illustrated Properties LLC (Co Ow...
# 7    Andrew Pietrak Luxury Real Estate Group LLC
# 8  Lisa Nanfra Compass Florida LLC Beth Aronson F...
# 9  Abigail Wapner Abigail Wapner Realty Barbara O...
#
#                                        BUYING AGENTS
# 0    Julien Taylor IV William Raveis Real Estate
# 1       Non Non-Member Non-Member Selling Office
# 2         Thomas Murray Compass Florida LLC (PB)
# 3            Non Agent Non-Member Selling Office
# 4                        Scott Eckert RPE Realty
# 5  Karen Lehrman Prayias Sotheby's Intl. Realty, ...
# 6            Meike MacGregor Compass Florida LLC
# 7                        Robert Goodman LoKation
# 8                   Sian Matthew Coldwell Banker
# 9               Ina Tuchman Boca West Realty LLC
