# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=2)

# Get the date one week ago
one_week_ago = today - timedelta(days=8)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 23rd May. 31st

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                     ADDRESS   CITY  \
# 1  PAST SALE  June-2-2025   Condo/Co-op  1300 Brickell Bay Dr #2404  Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33131.0  640000.0   1.0    1.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Miami/1300-Brickell-...  MARMLS  A11763087
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.760372 -80.190197
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-05-30    50
# 2025-05-28    29
# 2025-05-27    25
# 2025-05-29    24
# 2025-05-26     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 20   PAST SALE 2025-05-28   Condo/Co-op    9001 Collins Ave Unit S-903
# 104  PAST SALE 2025-05-30   Condo/Co-op  17901 Collins Ave Unit TS4205
# 113  PAST SALE 2025-05-28   Condo/Co-op    7872 Fisher Island Dr #7872
# 34   PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #2501
# 25   PAST SALE 2025-05-27   Condo/Co-op    9001 Collins Ave Unit S-606
# 126  PAST SALE 2025-05-27   Condo/Co-op       1000 Biscayne Blvd #3001
# 92   PAST SALE 2025-05-27   Condo/Co-op          100 S Pointe Dr #2107
# 66   PAST SALE 2025-05-29   Condo/Co-op              101 20th St #2208
# 118  PAST SALE 2025-05-28   Condo/Co-op             1470 16th St Ph -1
# 36   PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #1401
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  \
# 20            Surfside                FL             33154.0  19500000.0
# 104  Sunny Isles Beach                FL             33160.0  17875000.0
# 113        Miami Beach                FL             33109.0  12300000.0
# 34         Miami Beach                FL             33139.0   9000000.0
# 25            Surfside                FL             33154.0   6850000.0
# 126              Miami                FL             33132.0   5600000.0
# 92         Miami Beach                FL             33139.0   5250000.0
# 66         Miami Beach                FL             33139.0   4275000.0
# 118        Miami Beach                FL             33139.0   4000000.0
# 36         Miami Beach                FL             33139.0   3450000.0
#
#      BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 20    4.0    5.5  ...   Sold                         NaN
# 104   6.0    8.5  ...   Sold                         NaN
# 113   3.0    3.5  ...   Sold                         NaN
# 34    3.0    3.5  ...   Sold                         NaN
# 25    2.0    2.5  ...   Sold                         NaN
# 126   4.0    5.5  ...   Sold                         NaN
# 92    2.0    2.5  ...   Sold                         NaN
# 66    2.0    2.0  ...   Sold                         NaN
# 118   3.0    2.5  ...   Sold                         NaN
# 36    3.0    3.5  ...   Sold                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 20                        NaN
# 104                       NaN
# 113                       NaN
# 34                        NaN
# 25                        NaN
# 126                       NaN
# 92                        NaN
# 66                        NaN
# 118                       NaN
# 36                        NaN
#
#                                                    URL  SOURCE       MLS#  \
# 20   https://www.redfin.com/FL/Surfside/9001-Collin...  MARMLS  A11778858
# 104  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11676098
# 113  https://www.redfin.com/FL/Miami-Beach/7872-Fis...  MARMLS  A11615008
# 34   https://www.redfin.com/FL/Miami-Beach/500-Alto...  MARMLS  A11761445
# 25   https://www.redfin.com/FL/Surfside/9001-Collin...  MARMLS  A11759743
# 126  https://www.redfin.com/FL/Miami/1000-Biscayne-...  MARMLS  A11586563
# 92   https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11729072
# 66   https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11734833
# 118  https://www.redfin.com/FL/Miami-Beach/1470-16t...  MARMLS  A11495252
# 36   https://www.redfin.com/FL/Miami-Beach/500-Alto...  MARMLS  A11720287
#
#      FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 20          N          Y  25.876848 -80.121466
# 104         N          Y  25.941865 -80.120490
# 113         N          Y  25.759774 -80.137270
# 34          N          Y  25.775127 -80.141257
# 25          N          Y  25.876848 -80.121466
# 126         N          Y  25.784171 -80.190078
# 92          N          Y  25.767180 -80.132822
# 66          N          Y  25.795451 -80.128287
# 118         N          Y  25.788734 -80.144759
# 36          N          Y  25.775127 -80.141257
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-05-28   Condo/Co-op    9001 Collins Ave Unit S-903
# 1  PAST SALE 2025-05-30   Condo/Co-op  17901 Collins Ave Unit TS4205
# 2  PAST SALE 2025-05-28   Condo/Co-op    7872 Fisher Island Dr #7872
# 3  PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #2501
# 4  PAST SALE 2025-05-27   Condo/Co-op    9001 Collins Ave Unit S-606
# 5  PAST SALE 2025-05-27   Condo/Co-op       1000 Biscayne Blvd #3001
# 6  PAST SALE 2025-05-27   Condo/Co-op          100 S Pointe Dr #2107
# 7  PAST SALE 2025-05-29   Condo/Co-op              101 20th St #2208
# 8  PAST SALE 2025-05-28   Condo/Co-op             1470 16th St Ph -1
# 9  PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #1401
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0           Surfside                FL             33154.0  19500000.0   4.0
# 1  Sunny Isles Beach                FL             33160.0  17875000.0   6.0
# 2        Miami Beach                FL             33109.0  12300000.0   3.0
# 3        Miami Beach                FL             33139.0   9000000.0   3.0
# 4           Surfside                FL             33154.0   6850000.0   2.0
# 5              Miami                FL             33132.0   5600000.0   4.0
# 6        Miami Beach                FL             33139.0   5250000.0   2.0
# 7        Miami Beach                FL             33139.0   4275000.0   2.0
# 8        Miami Beach                FL             33139.0   4000000.0   3.0
# 9        Miami Beach                FL             33139.0   3450000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    5.5  ... -80.121466  https://www.redfin.com/FL/Surfside/9001-Collin...
# 1    8.5  ... -80.120490  https://www.redfin.com/FL/Sunny-Isles-Beach/17...
# 2    3.5  ... -80.137270  https://www.redfin.com/FL/Miami-Beach/7872-Fis...
# 3    3.5  ... -80.141257  https://www.redfin.com/FL/Miami-Beach/500-Alto...
# 4    2.5  ... -80.121466  https://www.redfin.com/FL/Surfside/9001-Collin...
# 5    5.5  ... -80.190078  https://www.redfin.com/FL/Miami/1000-Biscayne-...
# 6    2.5  ... -80.132822  https://www.redfin.com/FL/Miami-Beach/100-S-Po...
# 7    2.0  ... -80.128287  https://www.redfin.com/FL/Miami-Beach/101-20th...
# 8    2.5  ... -80.144759  https://www.redfin.com/FL/Miami-Beach/1470-16t...
# 9    3.5  ... -80.141257  https://www.redfin.com/FL/Miami-Beach/500-Alto...
#
#    list_agent_name_1          list_broker_name_1  list_agent_name_2  \
# 0     Ximena Penuela            Fort Realty, LLC               None
# 1       Ryan Mendell        Maxwell E Realty Inc               None
# 2      Denise Levine  Denise LeVine Realty, Inc.               None
# 3    Angelica Garcia             Douglas Elliman               None
# 4      Anthony Nucci             Douglas Elliman               None
# 5   Elena Sanilevich    Cervera Real Estate Inc.     Nickel Goeseke
# 6  Constantin Gorges       Compass Florida, LLC.               None
# 7     Michael Duchon          The Corcoran Group     Eloy Carmenate
# 8     Eloy Carmenate          The Corcoran Group     Sofia Joelsson
# 9    Angelica Garcia             Douglas Elliman               None
#
#          list_broker_name_2        buy_agent_name_1  \
# 0                      None          Ximena Penuela
# 1                      None             Yansy Checa
# 2                      None      Maria Oneide Gioia
# 3                      None        Stefania Riverin
# 4                      None              Marco Tine
# 5  Cervera Real Estate Inc.           Jonathan Mann
# 6                      None  Salesperson Non Member
# 7        The Corcoran Group           Benjamin Moss
# 8        The Corcoran Group           Zachary Akers
# 9                      None            Anca Mirescu
#
#                     buy_broker_name_1  buy_agent_name_2  buy_broker_name_2
# 0                    Fort Realty, LLC              None               None
# 1                     Douglas Elliman              None               None
# 2                Luxury Living Realty              None               None
# 3          One Sotheby's Int'l Realty              None               None
# 4                             Serhant              None               None
# 5              Coldwell Banker Realty              None               None
# 6                      Non-MLS Member              None               None
# 7               Compass Florida, LLC.              None               None
# 8  One Sotheby's International Realty              None               None
# 9                     Douglas Elliman              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 129

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $1,173,360

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $657

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $151,363,476

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input county name:
#  Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 86
# -----------
# Input Previous Week Condo Average Sales Price:
# 1023844
# -----------
# Input Previous Week Condo Average PSF:
# 542
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 88050620.0

# %%
last_week
# Out:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           86             1023844          542                     88050620.0

# %%
last_week['Last Week Total Dollar Volume'].iloc[0]
# Out:
# 88050620.0

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          129             1173360          657                    151363476.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS      CITY  \
# 0  PAST SALE 2025-05-28   Condo/Co-op  9001 Collins Ave Unit S-903  Surfside
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33154.0  19500000.0   4.0    5.5
#
#           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  SURF CLUB CONDO       3844.0       NaN      2017.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         5073.0    18320.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Surfside/9001-Collin...  MARMLS  A11778858
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.876848 -80.121466
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Surfside/9001-Collin...    Ximena Penuela
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0   Fort Realty, LLC              None               None   Ximena Penuela
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Fort Realty, LLC             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 0  PAST SALE 2025-05-28   Condo/Co-op    9001 Collins Ave Unit S-903
# 1  PAST SALE 2025-05-30   Condo/Co-op  17901 Collins Ave Unit TS4205
# 2  PAST SALE 2025-05-28   Condo/Co-op    7872 Fisher Island Dr #7872
# 3  PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #2501
# 4  PAST SALE 2025-05-27   Condo/Co-op    9001 Collins Ave Unit S-606
# 5  PAST SALE 2025-05-27   Condo/Co-op       1000 Biscayne Blvd #3001
# 6  PAST SALE 2025-05-27   Condo/Co-op          100 S Pointe Dr #2107
# 7  PAST SALE 2025-05-29   Condo/Co-op              101 20th St #2208
# 8  PAST SALE 2025-05-28   Condo/Co-op             1470 16th St Ph -1
# 9  PAST SALE 2025-05-28   Condo/Co-op             500 Alton Rd #1401
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0           Surfside                FL             33154.0  19500000.0   4.0
# 1  Sunny Isles Beach                FL             33160.0  17875000.0   6.0
# 2        Miami Beach                FL             33109.0  12300000.0   3.0
# 3        Miami Beach                FL             33139.0   9000000.0   3.0
# 4           Surfside                FL             33154.0   6850000.0   2.0
# 5              Miami                FL             33132.0   5600000.0   4.0
# 6        Miami Beach                FL             33139.0   5250000.0   2.0
# 7        Miami Beach                FL             33139.0   4275000.0   2.0
# 8        Miami Beach                FL             33139.0   4000000.0   3.0
# 9        Miami Beach                FL             33139.0   3450000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5            SURF CLUB CONDO       3844.0       NaN      2017.0
# 1    8.5       Estates at Acqualina       8139.0       NaN      2022.0
# 2    3.5  OCEANSIDE FISHER ISL COND       4590.0       NaN      1990.0
# 3    3.5                Miami Beach       3972.0       NaN      2024.0
# 4    2.5            SURF CLUB CONDO       1753.0       NaN      2017.0
# 5    5.5  ONE THOUSAND MUSEUM CONDO       4600.0       NaN      2019.0
# 6    2.5   CONTINUUM ON SOUTH BEACH       1870.0       NaN      2002.0
# 7    2.0  SETAI RESORT & RESIDENCES       1242.0       NaN      2005.0
# 8    2.5    CAPRI SOUTH BEACH CONDO       1974.0       NaN      2008.0
# 9    3.5                Miami Beach       2178.0       NaN      2024.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN
# 3        Stefania Riverin          One Sotheby's Int'l Realty
# 4              Marco Tine                             Serhant
# 5           Jonathan Mann              Coldwell Banker Realty
# 6  Salesperson Non Member                      Non-MLS Member
# 7           Benjamin Moss               Compass Florida, LLC.
# 8           Zachary Akers  One Sotheby's International Realty
# 9            Anca Mirescu                     Douglas Elliman
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2af5758898e44027f71ac931b2ec76f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 23rd — May. 31st&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2af5758898e44027f71ac931b2ec76f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2af5758898e44027f71ac931b2ec76f8 = L.map(
#                 &quot;map_2af5758898e44027f71ac931b2ec76f8&quot;,
#                 {
#                     center: [25.81428000606061, -80.20011912499999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_3f92259433bf6e08ca1527c7a5f7e618 = L.featureGroup(
#                 {}
#             ).addTo(map_2af5758898e44027f71ac931b2ec76f8);
#
#
#             var marker_fde8246d7da28461fbc3b4d0247c7a11 = L.marker(
#                 [25.8768475, -80.1214662],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_3f92259433bf6e08ca1527c7a5f7e618);
#
#
#             var icon_f0e514d345b423510117226cdcfd9c71 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fde8246d7da28461fbc3b4d0247c7a11.setIcon(icon_f0e514d345b423510117226cdcfd9c71);
#
#
#         var popup_5129afaef5316a3c83eadf3ba6b33495 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_55c126b652cc108a282271ff819f1079 = $(`&lt;div id=&quot;html_55c126b652cc108a282271ff819f1079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;9001 Collins Ave Unit S-903&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$19,500,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$5,073.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,844.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2017.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_5129afaef5316a3c83eadf3ba6b33495.setContent(html_55c126b652cc108a282271ff819f1079);
#
#
#
#         marker_fde8246d7da28461fbc3b4d0247c7a11.bindPopup(popup_5129afaef5316a3c83eadf3ba6b33495)
#         ;
#
#
#
#
#             var feature_group_7e1cdf17623879c5ab907e472588a520 = L.featureGroup(
#                 {}
#             ).addTo(map_2af5758898e44027f71ac931b2ec76f8);
#
#
#             var marker_2692289e8318009d585732525e2a7710 = L.marker(
#                 [25.9418648, -80.1204896],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e1cdf17623879c5ab907e472588a520);
#
#
#             var icon_b0472de7e6986bc0a3290aa8fe0811c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2692289e8318009d585732525e2a7710.setIcon(icon_b0472de7e6986bc0a3290aa8fe0811c8);
#
#
#         var popup_a443653f89e1aa02ae89b4d9e374cab8 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_450212829a1aeb52ca57db0f8696d52a = $(`&lt;div id=&quot;html_450212829a1aeb52ca57db0f8696d52a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;17901 Collins Ave Unit TS4205&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$17,875,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,196.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;8,139.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2022.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_a443653f89e1aa02ae89b4d9e374cab8.setContent(html_450212829a1aeb52ca57db0f8696d52a);
#
#
#
#         marker_2692289e8318009d585732525e2a7710.bindPopup(popup_a443653f89e1aa02ae89b4d9e374cab8)
#         ;
#
#
#
#
#             var marker_f8178c2436545fad4a1fe5d5fffe9dcb = L.marker(
#                 [25.7597737, -80.1372698],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e1cdf17623879c5ab907e472588a520);
#
#
#             var icon_e0bc4d3f5a39e99c45f7932ca6ef8d7f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8178c2436545fad4a1fe5d5fffe9dcb.setIcon(icon_e0bc4d3f5a39e99c45f7932ca6ef8d7f);
#
#
#         var popup_d2453295d8d1c93193e8f0b67a01bd20 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_456bd03887fe20574e36

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS      CITY  \
# 0  PAST SALE 2025-05-28   Condo/Co-op  9001 Collins Ave Unit S-903  Surfside
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33154.0  19500000.0   4.0    5.5
#
#           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  SURF CLUB CONDO       3844.0       NaN      2017.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         5073.0    18320.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Surfside/9001-Collin...  MARMLS  A11778858
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.876848 -80.121466
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Surfside/9001-Collin...    Ximena Penuela
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0   Fort Realty, LLC              None               None   Ximena Penuela
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Fort Realty, LLC             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06022025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'SURF CLUB CONDO at 9001 Collins Ave Unit S-903 in Surfside'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLO
# 5  https://www.redfin.com/FL/Miami/1000-Biscayne-...  MARMLS  A11586563
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11729072
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11734833
# 8  https://www.redfin.com/FL/Miami-Beach/1470-16t...  MARMLS  A11495252
# 9  https://www.redfin.com/FL/Miami-Beach/500-Alto...  MARMLS  A11720287
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.876848 -80.121466
# 1        N          Y  25.941865 -80.120490
# 2        N          Y  25.759774 -80.137270
# 3        N          Y  25.775127 -80.141257
# 4        N          Y  25.876848 -80.121466
# 5        N          Y  25.784171 -80.190078
# 6        N          Y  25.767180 -80.132822
# 7        N          Y  25.795451 -80.128287
# 8        N          Y  25.788734 -80.144759
# 9        N          Y  25.775127 -80.141257
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Surfside/9001-Collin...     Ximena Penuela
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       Ryan Mendell
# 2  https://www.redfin.com/FL/Miami-Beach/7872-Fis...      Denise Levine
# 3  https://www.redfin.com/FL/Miami-Beach/500-Alto...    Angelica Garcia
# 4  https://www.redfin.com/FL/Surfside/9001-Collin...      Anthony Nucci
# 5  https://www.redfin.com/FL/Miami/1000-Biscayne-...   Elena Sanilevich
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  Constantin Gorges
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...     Michael Duchon
# 8  https://www.redfin.com/FL/Miami-Beach/1470-16t...     Eloy Carmenate
# 9  https://www.redfin.com/FL/Miami-Beach/500-Alto...    Angelica Garcia
#
#            list_broker_name_1 list_agent_name_2        list_broker_name_2  \
# 0            Fort Realty, LLC              None                      None
# 1        Maxwell E Realty Inc              None                      None
# 2  Denise LeVine Realty, Inc.              None                      None
# 3             Douglas Elliman              None                      None
# 4             Douglas Elliman              None                      None
# 5    Cervera Real Estate Inc.    Nickel Goeseke  Cervera Real Estate Inc.
# 6       Compass Florida, LLC.              None                      None
# 7          The Corcoran Group    Eloy Carmenate        The Corcoran Group
# 8          The Corcoran Group    Sofia Joelsson        The Corcoran Group
# 9             Douglas Elliman              None                      None
#
#          buy_agent_name_1                   buy_broker_name_1  \
# 0          Ximena Penuela                    Fort Realty, LLC
# 1             Yansy Checa                     Douglas Elliman
# 2      Maria Oneide Gioia                Luxury Living Realty
# 3        Stefania Riverin          One Sotheby's Int'l Realty
# 4              Marco Tine                             Serhant
# 5           Jonathan Mann              Coldwell Banker Realty
# 6  Salesperson Non Member                      Non-MLS Member
# 7           Benjamin Moss               Compass Florida, LLC.
# 8           Zachary Akers  One Sotheby's International Realty
# 9            Anca Mirescu                     Douglas Elliman
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR  \
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue
#
#                                            FULL_NAME
# 0  SURF CLUB CONDO at 9001 Collins Ave Unit S-903...
# 1  Estates at Acqualina at 17901 Collins Ave Unit...
# 2  OCEANSIDE FISHER ISL COND at 7872 Fisher Islan...
# 3   Miami Beach at 500 Alton Rd #2501 in Miami Beach
# 4  SURF CLUB CONDO at 9001 Collins Ave Unit S-606...
# 5  ONE THOUSAND MUSEUM CONDO at 1000 Biscayne Blv...
# 6  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #2208...
# 8  CAPRI SOUTH BEACH CONDO at 1470 16th St Ph -1 ...
# 9   Miami Beach at 500 Alton Rd #1401 in Miami Beach

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: SURF CLUB CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $3,450,000 to $19,500,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Miami Beach, Sunny Isles Beach, Surfside, Miami, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 129 condo sales totaling $151,363,476 million from May. 23rd to May. 31st. The previous week, brokers closed 86 condo sales totaling $88,050,620.
#
# Last week’s units sold for an average of $1,173,360, higher than the $1,023,844 average price from the previous week. The average price per square foot rose to $657 from $542, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $3,450,000.0 million to $19,500,000.0 million.
#
# SURF CLUB CONDO at 9001 Collins Ave Unit S-903 in Surfside took the top spot with a $19,500,000.0 million closing. The sale closed at $5,073.0 per square foot.
#
# Ximena Penuela with Fort Realty, LLC, and None with None had the listing.
# Ximena Penuela with Fort Realty, LLC, and None with None represented the buyer.
#
# Estates at Acqualina at 17901 Collins Ave Unit TS4205 in Sunny Isles Beach, closed for the second highest amount, $17,875,000.0, or $2,196.0 per square foot.
#
# Ryan Mendell with Maxwell E Realty Inc, and None with None had the listing.
# Yansy Checa with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06022025 " width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 23rd to May. 31st:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLO
#
#                                            FULL_NAME
# 0  SURF CLUB CONDO at 9001 Collins Ave Unit S-903...
# 1  Estates at Acqualina at 17901 Collins Ave Unit...
# 2  OCEANSIDE FISHER ISL COND at 7872 Fisher Islan...
# 3   Miami Beach at 500 Alton Rd #2501 in Miami Beach
# 4  SURF CLUB CONDO at 9001 Collins Ave Unit S-606...
# 5  ONE THOUSAND MUSEUM CONDO at 1000 Biscayne Blv...
# 6  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #2208...
# 8  CAPRI SOUTH BEACH CONDO at 1470 16th St Ph -1 ...
# 9   Miami Beach at 500 Alton Rd #1401 in Miami Beach

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: SURF CLUB CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $3,450,000 to $19,500,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Miami Beach, Sunny Isles Beach, Surfside, Miami, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 129 condo sales totaling $151,363,476 million from May. 23rd to May. 31st. The previous week, brokers closed 86 condo sales totaling $88,050,620.
#
# Last week’s units sold for an average of $1,173,360, higher than the $1,023,844 average price from the previous week. The average price per square foot rose to $657 from $542, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $3,450,000.0 million to $19,500,000.0 million.
#
# SURF CLUB CONDO at 9001 Collins Ave Unit S-903 in Surfside took the top spot with a $19,500,000.0 million closing. The sale closed at $5,073.0 per square foot.
#
# Ximena Penuela with Fort Realty, LLC, and None with None had the listing.
# Ximena Penuela with Fort Realty, LLC, and None with None represented the buyer.
#
# Estates at Acqualina at 17901 Collins Ave Unit TS4205 in Sunny Isles Beach, closed for the second highest amount, $17,875,000.0, or $2,196.0 per square foot.
#
# Ryan Mendell with Maxwell E Realty Inc, and None with None had the listing.
# Yansy Checa with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_06022025 " width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 23rd to May. 31st:
#
# Most Expensive
# SURF CLUB CONDO, 9001 Collins Ave Unit S-903, in Surfside | Price: $19,500,000 | $5,073 psf | Listing agents: Ximena Penuela with Fort Realty, LLC and None with None | Buyer's agents: Ximena Penuela with Fort Realty, LLC and None with None
#
# Least Expensive
# Miami Beach, 500 Alton Rd #1401, in Miami Beach | Price: $3,450,000 | $1,584 psf | Listing agents: Angelica Garcia with Douglas Elliman and None with None | Buyer's agents: Anca Mirescu with Douglas Elliman and None with None
#
# Highest Price Per Square Foot
# SURF CLUB CONDO, 9001 Collins Ave Unit S-903, in Surfside | Price: $19,500,000 | $5,073 psf | Listing agents: Ximena Penuela with Fort Realty, LLC and None with None | Buyer's agents: Ximena Penuela with Fort Realty, LLC and None with None
#
# Lowest Price Per Square Foot
# ONE THOUSAND MUSEUM CONDO, 1000 Biscayne Blvd #3001, in Miami | Price: $5,600,000 | $1,217 psf | Listing agents: Elena Sanilevich with Cervera Real Estate Inc. and Nickel Goeseke with Cervera Real Estate Inc. | Buyer's agents: Jonathan Mann with Coldwell Banker Realty and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Surfside/9001-Collins-Ave-33154/unit-S903/home/79133349
# Second priciest sale:  https://www.redfin.com/FL/Sunny-Isles-Beach/17901-Collins-Ave-33160/unit-TS4205/home/183119605
# Cheapest top ten sale:  https://www.redfin.com/FL/Miami-Beach/500-Alton-Rd-33139/unit-1401/home/194157817
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Miami-Beach/1470-16th-St-33139/unit-1/home/42679115
# Highest top ten psf:  https://www.redfin.com/FL/Surfside/9001-Collins-Ave-33154/unit-S903/home/79133349
# Lowest top ten psf:  https://www.redfin.com/FL/Miami/1000-Biscayne-Blvd-33132/unit-3001/home/168724901

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Surfside/9001-Collins-Ave-33154/unit-S903/home/79133349

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/17901-Collins-Ave-33160/unit-TS4205/home/183119605

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Miami-Beach/500-Alton-Rd-33139/unit-1401/home/194157817

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Miami-Beach/1470-16th-St-33139/unit-1/home/42679115

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Surfside/9001-Collins-Ave-33154/unit-S903/home/79133349

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Miami/1000-Biscayne-Blvd-33132/unit-3001/home/168724901

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue
#
#                                            FULL_NAME
# 0  SURF CLUB CONDO at 9001 Collins Ave Unit S-903...
# 1  Estates at Acqualina at 17901 Collins Ave Unit...
# 2  OCEANSIDE FISHER ISL COND at 7872 Fisher Islan...
# 3   Miami Beach at 500 Alton Rd #2501 in Miami Beach
# 4  SURF CLUB CONDO at 9001 Collins Ave Unit S-606...
# 5  ONE THOUSAND MUSEUM CONDO at 1000 Biscayne Blv...
# 6  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #2208...
# 8  CAPRI SOUTH BEACH CONDO at 1470 16th St Ph -1 ...
# 9   Miami Beach at 500 Alton Rd #1401 in Miami Beach

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 5, 1) ## List (Earlier) date
date2 = datetime(2025, 5, 30) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 29

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    5073.0
# 1    2196.0
# 2    2680.0
# 3    2266.0
# 4    3908.0
# 5    1217.0
# 6    2807.0
# 7    3442.0
# 8    2026.0
# 9    1584.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS        PRICE  \
# 0 2025-05-28            9001 Collins Ave Unit S-903 in Surfside  $19,500,000
# 1 2025-05-30  17901 Collins Ave Unit TS4205 in Sunny Isles B...  $17,875,000
# 2 2025-05-28         7872 Fisher Island Dr #7872 in Miami Beach  $12,300,000
# 3 2025-05-28                  500 Alton Rd #2501 in Miami Beach   $9,000,000
# 4 2025-05-27            9001 Collins Ave Unit S-606 in Surfside   $6,850,000
# 5 2025-05-27                  1000 Biscayne Blvd #3001 in Miami   $5,600,000
# 6 2025-05-27               100 S Pointe Dr #2107 in Miami Beach   $5,250,000
# 7 2025-05-29                   101 20th St #2208 in Miami Beach   $4,275,000
# 8 2025-05-28                  1470 16th St Ph -1 in Miami Beach   $4,000,000
# 9 2025-05-28                  500 Alton Rd #1401 in Miami Beach   $3,450,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET  SOURCE       MLS#  \
# 0    4    5.5       3,844       2017        $5,073  MARMLS  A11778858
# 1    6    8.5       8,139       2022        $2,196  MARMLS  A11676098
# 2    3    3.5       4,590       1990        $2,680  MARMLS  A11615008
# 3    3    3.5       3,972       2024        $2,266  MARMLS  A11761445
# 4    2    2.5       1,753       2017        $3,908  MARMLS  A11759743
# 5    4    5.5       4,600       2019        $1,217  MARMLS  A11586563
# 6    2    2.5       1,870       2002        $2,807  MARMLS  A11729072
# 7    2    2.0       1,242       2005        $3,442  MARMLS  A11734833
# 8    3    2.5       1,974       2008        $2,026  MARMLS  A11495252
# 9    3    3.5       2,178       2024        $1,584  MARMLS  A11720287
#
#                                         LISTING INFO  \
# 0                Ximena Penuela Fort Realty, LLC
# 1              Ryan Mendell Maxwell E Realty Inc
# 2       Denise Levine Denise LeVine Realty, Inc.
# 3                Angelica Garcia Douglas Elliman
# 4                  Anthony Nucci Douglas Elliman
# 5  Elena Sanilevich Cervera Real Estate Inc. Nick...
# 6        Constantin Gorges Compass Florida, LLC.
# 7  Michael Duchon The Corcoran Group Eloy Carmena...
# 8  Eloy Carmenate The Corcoran Group Sofia Joelss...
# 9                Angelica Garcia Douglas Elliman
#
#                                          BUYING INFO
# 0                Ximena Penuela Fort Realty, LLC
# 1                    Yansy Checa Douglas Elliman
# 2        Maria Oneide Gioia Luxury Living Realty
# 3    Stefania Riverin One Sotheby's Int'l Realty
# 4                             Marco Tine Serhant
# 5           Jonathan Mann Coldwell Banker Realty
# 6          Salesperson Non Member Non-MLS Member
# 7            Benjamin Moss Compass Florida, LLC.
# 8  Zachary Akers One Sotheby's International Real...
# 9                   Anca Mirescu Douglas Elliman
