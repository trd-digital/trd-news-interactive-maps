# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from textwrap import shorten
import requests

from bs4 import BeautifulSoup

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
df = pd.read_csv('19 hotels Ashford REIT expects to transfer to lender - Sheet1.csv')

# %%
df['geo_address'] = df['full_address'] + ' in Miami Beach\'s North Beach'

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## Image URL Collector

# %%
# df['image_links'] = ''
# links = []
# for url in df['story_link']:
#     try:
#         page = requests.get(url)
#         soup = BeautifulSoup(page.content, 'html.parser')
#         images = soup.find('img',{'class':'MainArtImage_image__2YtGm'})
#         images = images['src']
#         links.append(images)
#     except:
#         links.append('no_image')

# df['image_links'] = links

# %%
# print(df['story_link'].iloc[0])

# %%
# df.at[20,'image_img']=('<img src="Aimco.jpg" width="256" height="156">')
# df['image_links'].iloc[1]
# Out:
# 'https://static.therealdeal.com/wp-content/uploads/2023/06/main_MIA_Ella-Miami-Beach-1400x875.jpg'

# %%
# df.at[4,'image_links']=('https://therealdeal.com/wp-content/uploads/2019/10/trd-logo-16x9.jpg')

# %%
# df["short_description"] = df["description"].apply(lambda s: shorten(s, width=20, placeholder=""))
# df['remaining_desc'] = df.apply(lambda row : row['description'].replace(str(row['short_description']), ''), axis=1)
# df['remaining_desc']

# df["description_link"] = '<a href="' + df["story_link"] + '" target="_blank" rel="noopener noreferrer">' + df["short_description"] + "</a>" + df["remaining_desc"]
# df['description_link']
# Out:
# 0    <a href="https://therealdeal.com/miami/2023/06...
# 1    <a href="https://therealdeal.com/miami/2023/06...
# 2    <a href="https://therealdeal.com/miami/2022/07...
# 3    <a href="https://therealdeal.com/miami/2021/04...
# 4                                                  NaN
# Name: description_link, dtype: object

# %%
df.columns
# Out:
# Index(['full_address', 'Name of hotel', 'description', 'story_link',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    i = row
    address = df['full_address'].iloc[i]
    hotel_name = df['Name of hotel'].iloc[i]
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Address: </strong>{}'''.format(address) + '''<br><br>
    <strong>Name: </strong>{}'''.format(hotel_name) + '''<br>
    </html>
    '''
    return html

# %%
import branca

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=4)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Hotels Ashford REIT expects to transfer to lender')

for i in range(0,len(df)):
    html = popup_html(i)
    iframe = branca.element.IFrame(html=html)
    popup = folium.Popup(folium.Html(html, script=True, width=250))
    folium.Marker([df['lat'].iloc[i],df['lon'].iloc[i]],
                 popup=popup).add_to(m)

m.get_root().html.add_child(folium.Element(title_html))
m.fit_bounds(bounds=df[['lat','lon']].mean().to_list(),max_zoom=15)
# m.add_to(f)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4efc8d7a38754fdbc99dc1e08382bc4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Hotels Ashford REIT expects to transfer to lender&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4efc8d7a38754fdbc99dc1e08382bc4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4efc8d7a38754fdbc99dc1e08382bc4c = L.map(
#                 &quot;map_4efc8d7a38754fdbc99dc1e08382bc4c&quot;,
#                 {
#                     center: [36.4480122, -101.03111598947369],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_893f8c82c79e1db1f58125c86cfd27e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4efc8d7a38754fdbc99dc1e08382bc4c);
#
#
#             var marker_1a00aab1f49c740734510d2f00834fdf = L.marker(
#                 [39.2014404, -85.9213796],
#                 {}
#             ).addTo(map_4efc8d7a38754fdbc99dc1e08382bc4c);
#
#
#         var popup_fdb35d6032ac404a6125d0a1519e6390 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab10d8675329befee94ef1710d215342 = $(`&lt;div id=&quot;html_ab10d8675329befee94ef1710d215342&quot; style=&quot;width: 250.0px; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;3888 Mimosa Dr, Columbus, IN 47201&lt;br&gt;&lt;br&gt;     &lt;strong&gt;Name: &lt;/strong&gt;Courtyard by Marriott Columbus Tipton Lakes&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_fdb35d6032ac404a6125d0a1519e6390.setContent(html_ab10d8675329befee94ef1710d215342);
#
#
#
#         marker_1a00aab1f49c740734510d2f00834fdf.bindPopup(popup_fdb35d6032ac404a6125d0a1519e6390)
#         ;
#
#
#
#
#             var marker_316c2e36d525e4020222321a09aaa51a = L.marker(
#                 [33.4948764, -111.9216734],
#                 {}
#             ).addTo(map_4efc8d7a38754fdbc99dc1e08382bc4c);
#
#
#         var popup_0c2d2c9427f9044aeb5da565d3328c40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_984e4840e598030e54a4ec07a30f754c = $(`&lt;div id=&quot;html_984e4840e598030e54a4ec07a30f754c&quot; style=&quot;width: 250.0px; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;3311 N Scottsdale Rd, Scottsdale, AZ 85251&lt;br&gt;&lt;br&gt;     &lt;strong&gt;Name: &lt;/strong&gt;Courtyard by Marriott Scottsdale Old Town&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_0c2d2c9427f9044aeb5da565d3328c40.setContent(html_984e4840e598030e54a4ec07a30f754c);
#
#
#
#         marker_316c2e36d525e4020222321a09aaa51a.bindPopup(popup_0c2d2c9427f9044aeb5da565d3328c40)
#         ;
#
#
#
#
#             var marker_53379b0faa49d348a63dc944fe38dae3 = L.marker(
#                 [36.1715735, -115.139121],
#                 {}
#             ).addTo(map_4efc8d7a38754fdbc99dc1e08382bc4c);
#
#
#         var popup_b5ac28f8e9f11fe859b1b1ab320ea5a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79b5aa0238e13a7976d0be382e67043d = $(`&lt;div id=&quot;html_79b5aa0238e13a7976d0be382e67043d&quot; style=&quot;width: 250.0px; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;370 Hughes Center Dr, Las Vegas, NV 89169&lt;br&gt;&lt;br&gt;     &lt;strong&gt;Name: &lt;/strong&gt;Residence Inn by Marriott Las Vegas Hughes Center&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_b5ac28f8e9f11fe859b1b1ab320ea5a2.setContent(html_79b5aa0238e13a7976d0be382e67043d);
#
#
#
#         marker_53379b0faa49d348a63dc944fe38dae3.bindPopup(popup_b5ac28f8e9f11fe859b1b1ab320ea5a2)
#         ;
#
#
#
#
#             var marker_f5f1ef207a7bc4bcaf674bb61d48797f = L.marker(
#                 [33.4483771, -112.0740373],
#                 {}
#             ).addTo(map_4efc8d7a38754fdbc99dc1e08382bc4c);
#
#
#         var popup_57d5df7da8ff30eddcf3f03006630b09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d0e776d47343313ea54d96e1fee6e8e = $(`&lt;div id=&quot;html_1d0e776d47343313ea54d96e1fee6e8e&quot; style=&quot;width: 250.0px; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;801 N 44th St, Phoenix, AZ 85008&lt;br&gt;&lt;br&gt;     &lt;strong&gt;Name: &lt;/strong&gt;Residence Inn by Marriott Phoenix Airport&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_57d5df7da8ff30eddcf3f03006630b09.setContent(html_1d0e776d47343313ea54d96e1fee6e8e);

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/hotels_Ashford_REIT_transfer_to_lender
