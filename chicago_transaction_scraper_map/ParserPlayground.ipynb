# %% [markdown]
# ## Import and Set Options

# %%
from geopy.geocoders import GoogleV3
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import urllib3
import re
from textwrap import shorten
import os
import geopandas as gpd

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 1600)
pd.set_option('display.max_colwidth', None) ### Default 50

# %%
df = pd.read_csv('Chicago_sample.csv')

# %% [markdown]
# ## Test Stuff

# %%
df.columns
# Out:
# Index(['URL', 'HED', 'DEK', 'PUB_DATE', 'LEDE', 'STORY_TEXT', 'ADDRESS'], dtype='object')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df['STORY_TEXT'] = df['STORY_TEXT'].astype(str)

# %%
df['ADDRESS'] = df['STORY_TEXT'].str.extract(r'(?P<ADDRESS>[1-9][0-9]* (?:\w+\W+){1,6}(?:Road|Rd|Avenue|Ave|Boulevard|Blvd|Street|St|Place|Drive|Dr|Huron|Parkway|Way|Center|Lane|Court))')

# %%
df['ADDRESS'].isna().value_counts()
# Out:
# False    715
# True     285
# Name: ADDRESS, dtype: int64

# %%
# df.STORY_TEXT.iloc[570]

# %%
df[['URL','ADDRESS']].iloc[300:400]
# Out:
#                                                                                                                                                         URL  \
# 300                                     https://therealdeal.com/chicago/2022/03/11/trump-tower-penthouse-sale-may-signal-chicago-luxury-condo-markets-peak/
# 301                          https://therealdeal.com/chicago/2021/12/06/kimpton-chicago-hotel-to-be-sold-for-20m-less-than-appraised-value-eight-years-ago/
# 302                                             https://therealdeal.com/chicago/2019/01/13/studio-gang-to-design-new-university-of-chicago-campus-in-paris/
# 303                                                             https://therealdeal.com/chicago/2022/05/09/brookfield-buys-chicago-reit-watermark-for-3-8b/
# 304                                                 https://therealdeal.com/chicago/2019/01/15/lake-forest-mansion-latest-pricey-chicago-area-resi-listing/
# 305                    https://therealdeal.com/chicago/2019/05/01/how-a-2b-redevelopment-site-in-chicago-landed-in-an-opportunity-zone-a-trd-investigation/
# 306                                         https://therealdeal.com/chicago/2020/12/01/marijuana-dispensaries-level-up-with-sleek-design-larger-footprints/
# 307                    https://therealdeal.com/chicago/2019/04/19/chicagos-first-building-code-overhaul-in-70-years-could-boost-housing-market-experts-say/
# 308                                                     https://therealdeal.com/chicago/2022/10/21/amcap-picks-up-suburban-chicago-shopping-center-for-19m/
# 309                                                            https://therealdeal.com/chicago/2018/10/06/what-will-the-next-iconic-chicago-home-look-like/
# 310                         https://therealdeal.com/chicago/2018/09/24/neighborhood-spotlight-hegewisch-and-east-side-are-banking-on-an-industrial-revival/
# 311                                           https://therealdeal.com/chicago/2022/04/28/empire-mansion-finally-has-a-buyer-after-nine-years-on-the-market/
# 312                                   https://therealdeal.com/chicago/2018/07/11/national-association-of-realtors-plans-45m-expansion-mag-mile-hq-overhaul/
# 313                                            https://therealdeal.com/chicago/2019/03/06/irvine-company-inks-firms-to-103k-sf-of-leases-at-1-north-wacker/
# 314                                                       https://therealdeal.com/chicago/2018/11/16/panattoni-developing-765k-sf-spec-warehouse-in-aurora/
# 315  https://therealdeal.com/chicago/2019/07/09/chicago-cheat-sheet-city-pulls-plug-on-windy-city-rehab-chicago-fire-reaches-deal-to-leave-bridgeview-more/
# 376                              300 block of North Green Street
# 377                                    400 North Aberdeen Street
# 378                           1300 block of North Kostner Avenue
# 379                                        317 South Park Avenue
# 380                                             45 Lakeview Lane
# 381                                           2064 Rockport Lane
# 382                                       5530 South Shore Drive
# 383                                            1622 Forest Place
# 384                                                          NaN
# 385                                        5460 North River Road
# 386                                          433 W. Van Buren St
# 387                                     225 West Randolph Street
# 388                                                          NaN
# 389                333 N. Green Street (Credit: Getty Images, St
# 390                                                          NaN
# 391                                                          NaN
# 392                                                          NaN
# 393                                    900 North Michigan Avenue
# 394                                            735 Sheridan Road
# 395                   540 North Lake Shore Drive (Credit: Street
# 396                                     1140 South Wabash Avenue
# 397                                                          NaN
# 398                                              859 Fletcher Rd
# 399                                         9 West Walton Street

# %% [markdown]
# ## Link Formatter

# %%
df.columns
# Out:
# Index(['URL', 'HED', 'DEK', 'PUB_DATE', 'LEDE', 'STORY_TEXT', 'ADDRESS'], dtype='object')

# %%
df["short_description"] = df["LEDE"].apply(lambda s: shorten(s, width=20, placeholder=""))
df['remaining_desc'] = df.apply(lambda row : row['LEDE'].replace(str(row['short_description']), ''), axis=1)
df['remaining_desc']

df["description_link"] = '<a href="' + df["URL"] + '" target="_blank" rel="noopener noreferrer">' + df["short_description"] + "</a>" + df["remaining_desc"]
# df['description_link']

# %%
df['PUB_YEAR'] = df['PUB_DATE'].str.extract(r'(\d{4})')

# %%
# df[['PUB_DATE','PUB_YEAR']]

# %% [markdown]
# ## Geocoder Setup

# %%
# %store -r google_maps_API_Key
geolocator = GoogleV3(api_key=google_maps_API_Key)

# %%
df['geo_address'] = df['ADDRESS'] + ' Chicago, IL'
df['loc'] = df['geo_address'].apply(geolocator.geocode, timeout=10)
df['point'] = df['loc'].apply(lambda loc: tuple(loc.point) if loc else None)
df[['lat','lon','altitude']] = pd.DataFrame(df['point'].to_list(),index=df.index)

# %%
df.columns
# Out:
# Index(['URL', 'HED', 'DEK', 'PUB_DATE', 'LEDE', 'STORY_TEXT', 'ADDRESS',
#        'short_description', 'remaining_desc', 'description_link',
#        'geo_address', 'loc', 'point', 'lat', 'lon', 'altitude', 'PUB_YEAR'],
#       dtype='object')

# %%
# def popup_html(row):
#     i = row
#     URL = df2['URL'].iloc[i]
#     HED = df2['HED'].iloc[i]
#     DEK = df2['DEK'].iloc[i]
#     PUB_YEAR = df2['PUB_YEAR'].iloc[i]
#     LEDE = df2['LEDE'].iloc[i]
    
#     html = '''<!DOCTYPE html>
#     <html>
#     Folio: <strong>{}'''.format(URL) + '''</strong><br>
#     Address: <strong>{}'''.format(HED) + '''</strong><br>
#     Year Built: <strong>{}'''.format(DEK) + '''</strong><br>
#     Building Area: <strong>{}'''.format(PUB_YEAR) + '''</strong><br>
#     Lot Size: <strong>{}'''.format(LEDE) + '''</strong><br>
#     </html>
#     '''
#     return html

# %%
# df2 = df.dropna(subset='lat')

# %%
# df2 = df.dropna(subset='lon')

# %%
df2 = pd.read_csv('sample_map_data.csv')

# %%
df2.to_csv('sample_map_data.csv')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'URL', 'HED', 'DEK', 'PUB_DATE', 'LEDE', 'STORY_TEXT',
#        'ADDRESS', 'short_description', 'remaining_desc', 'description_link',
#        'geo_address', 'loc', 'point', 'lat', 'lon', 'altitude', 'PUB_YEAR'],
#       dtype='object')

# %%
df3 = df2.head(200)

# %%
import folium
from folium import Map, FeatureGroup, Marker, LayerControl
import branca

chi_map = folium.Map(location=df3[["lat", "lon"]].mean().to_list(),zoom_start=9,tiles=None)

for grp_name, df_grp in df3.groupby('PUB_YEAR'):
    feature_group = folium.FeatureGroup(grp_name)
    for row in df_grp.itertuples():
        html = '''<!DOCTYPE html>
        <html>
        <strong>{}'''.format(row.HED) + '''</strong><br><br>
        <em>{}'''.format(row.DEK) + '''</em><br><br>
        {}'''.format(row.description_link) + '''<br><br>
        <u>Published: {}'''.format(row.PUB_YEAR) + '''</u><br>
        </html>
        '''
        iframe = branca.element.IFrame(html=html)
        popup = folium.Popup(folium.Html(html, script=True),min_width=200,max_width=200)
        folium.Marker(location=[row.lat,row.lon],popup=popup).add_to(feature_group)
        
    feature_group.add_to(chi_map)
    
folium.LayerControl().add_to(chi_map)
folium.TileLayer('OpenStreetMap',control=False).add_to(chi_map)
chi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab4bd960a94e965c627ca28a0dfa7e05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab4bd960a94e965c627ca28a0dfa7e05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ab4bd960a94e965c627ca28a0dfa7e05 = L.map(
#                 &quot;map_ab4bd960a94e965c627ca28a0dfa7e05&quot;,
#                 {
#                     center: [41.8994260235, -87.6123270965],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_7bf564cd66d96a4d00872f62fdf20262 = L.featureGroup(
#                 {}
#             ).addTo(map_ab4bd960a94e965c627ca28a0dfa7e05);
#
#
#             var marker_0025b444315dc729d7a086a0c15672ac = L.marker(
#                 [41.8815671, -87.63209619999999],
#                 {}
#             ).addTo(feature_group_7bf564cd66d96a4d00872f62fdf20262);
#
#
#         var popup_b6cbc094704627daabdc35f9f7bf1380 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_b792d0dfd479769b895092c1ba95a7c0 = $(`&lt;div id=&quot;html_b792d0dfd479769b895092c1ba95a7c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;         &lt;html&gt;         &lt;strong&gt;Paragon Real Estate buys retail condo in historic Loop tower&lt;/strong&gt;&lt;br&gt;&lt;br&gt;         &lt;em&gt;The $16M acquisition is the San Diego-based firm’s first in Chicago&lt;/em&gt;&lt;br&gt;&lt;br&gt;         &lt;a href=&quot;https://therealdeal.com/chicago/2018/07/13/paragon-real-estate-buys-retail-condo-in-historic-loop-tower/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;Paragon Real Estate&lt;/a&gt; Investments bought the retail portion of a Loop tower for $16.05 million.&lt;br&gt;&lt;br&gt;         &lt;u&gt;Published: 2018&lt;/u&gt;&lt;br&gt;         &lt;/html&gt;         &lt;/div&gt;`)[0];
#             popup_b6cbc094704627daabdc35f9f7bf1380.setContent(html_b792d0dfd479769b895092c1ba95a7c0);
#
#
#         marker_0025b444315dc729d7a086a0c15672ac.bindPopup(popup_b6cbc094704627daabdc35f9f7bf1380)
#         ;
#
#
#
#
#             var marker_94a2bf4c75be741bd6fce38e2992928d = L.marker(
#                 [41.884798, -87.62124589999999],
#                 {}
#             ).addTo(feature_group_7bf564cd66d96a4d00872f62fdf20262);
#
#
#         var popup_e236722786c09c3813f402787ad0bf7e = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_7996dd3f364f4733832fa5e42b12b129 = $(`&lt;div id=&quot;html_7996dd3f364f4733832fa5e42b12b129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;         &lt;html&gt;         &lt;strong&gt;601W Companies’ $185M Aon Center observation deck pitch earns blessing of key alderman&lt;/strong&gt;&lt;br&gt;&lt;br&gt;         &lt;em&gt;The New York-based developer has proposed building a pair of external elevator shafts on the 83-story tower&lt;/em&gt;&lt;br&gt;&lt;br&gt;         &lt;a href=&quot;https://therealdeal.com/chicago/2018/11/10/601w-companies-185m-aon-center-observation-deck-pitch-earns-blessing-of-key-alderman/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;An $185 million&lt;/a&gt; proposal by 601W Companies to retool the Aon Center with a carnival-like observation deck is set to be approved by Alderman Alderman Brendan Reilly (42nd), the City Council’s key gatekeeper for Downtown development.&lt;br&gt;&lt;br&gt;         &lt;u&gt;Published: 2018&lt;/u&gt;&lt;br&gt;         &lt;/html&gt;         &lt;/div&gt;`)[0];
#             popup_e236722786c09c3813f402787ad0bf7e.setContent(html_7996dd3f364f4733832fa5e42b12b129);
#
#
#         marker_94a2bf4c75be741bd6fce38e2992928d.bindPopup(popup_e236722786c09c3813f402787ad0bf7e)
#         ;
#
#
#
#
#             var marker_f633e82b563c789350e13a65df7aa3b0 = L.marker(
#                 [41.9032161, -87.63363629999999],
#                 {}
#             ).addTo(feature_group_7bf564cd66d96a4d00872f62fdf20262);
#
#
#         var popup_10b3a66e55e16b4fe2678f08a610e1b8 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_1985f697853238077d26f3ca4635c2be = $(`&lt;div id=&quot;html_1985f697853238077d26f3ca4635c2be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;         &lt;html&gt;         &lt;strong&gt;250-unit Gold Coast building is latest Downtown deconversion&lt;/strong&gt;&lt;br&gt;&lt;br&gt;         &lt;em&gt;The building has been a hotel, apartments and condos, and now would revert back to rentals&lt;/em&gt;&lt;br&gt;&lt;br&gt;         &lt;a href=&quot;https://therealdeal.com/chicago/2018/04/16/250-unit-gold-coast-building-is-latest-downtown-deconversion/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;A Gold Coast condo&lt;/a&gt; building with 250 units has hit the market as a deconversion.&lt;br&gt;&lt;br&gt;         &lt;u&gt;Published: 2018&lt;/u&gt;&lt;br&gt;         &lt;/html&gt;         &lt;/div&gt;`)[0];
#             popup_10b3a66e55e16b4fe2678f08a610e1b8.setContent(html_1985f697853238077d26f3ca4635c2be);
#
#
#         marker_f633e82b563c789350e13a65df7aa3b0.bindPopup(popup_10b3a66e55e16b4fe2678f08a610e1b8)
#         ;
#
#
#
#
#             var marker_ac0ba7e68cb0464f36a957c5ffdf5531 = L.marker(
#                 [41.8845457, -87.66265969999999],

# %%
chi_map.save('index.html')
