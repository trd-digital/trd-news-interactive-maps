# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 11th May. 18th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                ADDRESS   CITY  \
# 1  PAST SALE  May-15-2025   Condo/Co-op  9066 SW 73rd Ct #1502  Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33156.0  327500.0   1.0    1.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Miami/9066-SW-73rd-C...  MARMLS  A11757523
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.686531 -80.314424
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-05-12    31
# 2025-05-15    29
# 2025-05-16    26
# 2025-05-14    21
# 2025-05-13    20
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 75   PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 80   PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 7    PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 27   PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 127  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 55   PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 39   PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 17   PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 109  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 64   PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                    CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  \
# 75          Miami Beach                FL             33109.0  16200000.0
# 80                Miami                FL             33133.0  12500000.0
# 7         Fisher Island                FL             33109.0   5500000.0
# 27                Miami                FL             33133.0   4050000.0
# 127         Miami Beach                FL             33139.0   4000000.0
# 55          Bal Harbour                FL             33154.0   3750000.0
# 39          Miami Beach                FL             33139.0   3260902.0
# 17          Miami Beach                FL             33139.0   3099000.0
# 109         Miami Beach                FL             33154.0   2850000.0
# 64   Bay Harbor Islands                FL             33154.0   2450000.0
#
#      BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 75    4.0    4.5  ...   Sold                         NaN
# 80    4.0    5.5  ...   Sold                         NaN
# 7     2.0    2.5  ...   Sold                         NaN
# 27    3.0    3.5  ...   Sold                         NaN
# 127   3.0    3.5  ...   Sold                         NaN
# 55    2.0    2.0  ...   Sold                         NaN
# 39    1.0    1.5  ...   Sold                         NaN
# 17    3.0    3.5  ...   Sold                         NaN
# 109   2.0    2.5  ...   Sold                         NaN
# 64    4.0    3.5  ...   Sold                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 75                        NaN
# 80                        NaN
# 7                         NaN
# 27                        NaN
# 127                       NaN
# 55                        NaN
# 39                        NaN
# 17                        NaN
# 109                       NaN
# 64                        NaN
#
#                                                    URL  SOURCE       MLS#  \
# 75   https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
# 80   https://www.redfin.com/FL/Miami/2811-S-Bayshor...  MARMLS  A11710639
# 7    https://www.redfin.com/FL/Miami-Beach/7953-Fis...  MARMLS  A11776077
# 27   https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11776122
# 127  https://www.redfin.com/FL/Miami-Beach/1300-Mon...  MARMLS  A11661491
# 55   https://www.redfin.com/FL/Bal-Harbour/10201-Co...  MARMLS  A11754086
# 39   https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11711551
# 17   https://www.redfin.com/FL/Miami-Beach/300-Coll...  MARMLS  A11751817
# 109  https://www.redfin.com/FL/Surfside/8701-Collin...  MARMLS  A11664216
# 64   https://www.redfin.com/FL/Bay-Harbor-Islands/1...  MARMLS  A11742820
#
#      FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 75          N          Y  25.763482 -80.137699
# 80          N          Y  25.728751 -80.238013
# 7           N          Y  25.758915 -80.137511
# 27          N          Y  25.732272 -80.234921
# 127         N          Y  25.784161 -80.142633
# 55          N          Y  25.895168 -80.123150
# 39          N          Y  25.767180 -80.132822
# 17          N          Y  25.772642 -80.133687
# 109         N          Y  25.872197 -80.121210
# 64          N          Y  25.892681 -80.130898
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 1  PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 2  PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 3  PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 4  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 5  PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 6  PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 7  PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 8  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 9  PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0         Miami Beach                FL             33109.0  16200000.0   4.0
# 1               Miami                FL             33133.0  12500000.0   4.0
# 2       Fisher Island                FL             33109.0   5500000.0   2.0
# 3               Miami                FL             33133.0   4050000.0   3.0
# 4         Miami Beach                FL             33139.0   4000000.0   3.0
# 5         Bal Harbour                FL             33154.0   3750000.0   2.0
# 6         Miami Beach                FL             33139.0   3260902.0   1.0
# 7         Miami Beach                FL             33139.0   3099000.0   3.0
# 8         Miami Beach                FL             33154.0   2850000.0   2.0
# 9  Bay Harbor Islands                FL             33154.0   2450000.0   4.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    4.5  ... -80.137699  https://www.redfin.com/FL/Miami-Beach/7012-Fis...
# 1    5.5  ... -80.238013  https://www.redfin.com/FL/Miami/2811-S-Bayshor...
# 2    2.5  ... -80.137511  https://www.redfin.com/FL/Miami-Beach/7953-Fis...
# 3    3.5  ... -80.234921  https://www.redfin.com/FL/Miami/2627-S-Bayshor...
# 4    3.5  ... -80.142633  https://www.redfin.com/FL/Miami-Beach/1300-Mon...
# 5    2.0  ... -80.123150  https://www.redfin.com/FL/Bal-Harbour/10201-Co...
# 6    1.5  ... -80.132822  https://www.redfin.com/FL/Miami-Beach/100-S-Po...
# 7    3.5  ... -80.133687  https://www.redfin.com/FL/Miami-Beach/300-Coll...
# 8    2.5  ... -80.121210  https://www.redfin.com/FL/Surfside/8701-Collin...
# 9    3.5  ... -80.130898  https://www.redfin.com/FL/Bay-Harbor-Islands/1...
#
#     list_agent_name_1                  list_broker_name_1  list_agent_name_2  \
# 0           Dora Puig                  Luxe Living Realty               None
# 1       Jessica Adams                     Douglas Elliman               None
# 2      Lilian Carrion                Compass Florida, LLC               None
# 3         Ana Sanchez  One Sotheby's International Realty    Yedri Villafane
# 4      Todd Nordstrom               Compass Florida, LLC.   Julian Fernandez
# 5                None                                None               None
# 6        Luis Paredes                  Million Realty LLC               None
# 7          David Reid      One Sotheby's International Re               None
# 8  Miltiadis Kastanis               Compass Florida, LLC.               None
# 9   3009174 Romanello               Compass Florida, LLC.     Claudia Villar
#
#                    list_broker_name_2     buy_agent_name_1  \
# 0                                None       Fredrik Eklund
# 1                                None       NON-MLS MEMBER
# 2                                None        Nataly Stuart
# 3  One Sotheby's International Realty  Christina Fernandez
# 4               Compass Florida, LLC.         Juan Zuluaga
# 5                                None                 None
# 6                                None         Matthew Lill
# 7                                None        Anna Sherrill
# 8                                None       Mikhail MudrIk
# 9               Compass Florida, LLC.    3009174 Romanello
#
#                 buy_broker_name_1  buy_agent_name_2      buy_broker_name_2
# 0                 Douglas Elliman              None                   None
# 1              MAR NON MLS MEMBER              None                   None
# 2           Socialite Realty, LLC              None                   None
# 3                ACC Realty, Inc.              None                   None
# 4          Coldwell Banker Realty              None                   None
# 5                            None              None                   None
# 6              The Corcoran Group              None                   None
# 7  One Sotheby's International Re              None                   None
# 8          The Agency Florida LLC              None                   None
# 9           Compass Florida, LLC.    Claudia Villar  Compass Florida, LLC.
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 127

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $973,842

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $636

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $123,677,931

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input county name:
# Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 91
# -----------
# Input Previous Week Condo Average Sales Price:
# 1230121
# -----------
# Input Previous Week Condo Average PSF:
# 660
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 111940988.0

# %%
last_week
# Out:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           91             1230121          660                    111940988.0

# %%
last_week['Last Week Total Dollar Volume'].iloc[0]
# Out:
# 111940988.0

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          127              973842          636                    123677931.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0  Miami Beach                FL             33109.0  16200000.0   4.0    4.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...         Dora Puig
#
#    list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Luxe Living Realty              None               None   Fredrik Eklund
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 1  PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 2  PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 3  PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 4  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 5  PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 6  PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 7  PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 8  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 9  PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0         Miami Beach                FL             33109.0  16200000.0   4.0
# 1               Miami                FL             33133.0  12500000.0   4.0
# 2       Fisher Island                FL             33109.0   5500000.0   2.0
# 3               Miami                FL             33133.0   4050000.0   3.0
# 4         Miami Beach                FL             33139.0   4000000.0   3.0
# 5         Bal Harbour                FL             33154.0   3750000.0   2.0
# 6         Miami Beach                FL             33139.0   3260902.0   1.0
# 7         Miami Beach                FL             33139.0   3099000.0   3.0
# 8         Miami Beach                FL             33154.0   2850000.0   2.0
# 9  Bay Harbor Islands                FL             33154.0   2450000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
# 1    5.5         C.G.B. SUBDIVISION       3247.0       NaN      2020.0
# 2    2.5  OCEANSIDE @ FISHER ISL CO       2420.0       NaN      1989.0
# 3    3.5       GROVENOR HOUSE CONDO       2640.0       NaN      2005.0
# 4    3.5  ALTON BEACH REALTY CO SUB       2691.0       NaN      2021.0
# 5    2.0   OCEANA BAL HARBOUR CONDO       1805.0       NaN      2016.0
# 6    1.5   CONTINUUM ON SOUTH BEACH       1201.0       NaN      2002.0
# 7    3.5          300 COLLINS CONDO       1699.0       NaN      2018.0
# 8    2.5     8701 COLLINS AVE CONDO       1602.0       NaN      2019.0
# 9    3.5    SERENO RESIDENCES CONDO       1929.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
# 1             NaN         3850.0     7447.0   Sold
# 2             NaN         2273.0     7646.0   Sold
# 3             NaN         1534.0     4081.0   Sold
# 4             NaN         1486.0    13370.0   Sold
# 5             NaN         2078.0     3864.0   Sold
# 6             NaN         2715.0     3600.0   Sold
# 7             NaN         1824.0     8986.0   Sold
# 8             NaN         1779.0     5903.0   Sold
# 9             NaN         1270.0     3525.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...  MARMLS  A11710639
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...  MARMLS  A11776077
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11776122
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...  MARMLS  A11661491
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...  MARMLS  A11754086
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11711551
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...  MARMLS  A11751817
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  MARMLS  A11664216
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...  MARMLS  A11742820
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
# 1        N          Y  25.728751 -80.238013
# 2        N          Y  25.758915 -80.137511
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.784161 -80.142633
# 5        N          Y  25.895168 -80.123150
# 6        N          Y  25.767180 -80.132822
# 7        N          Y  25.772642 -80.133687
# 8        N          Y  25.872197 -80.121210
# 9        N          Y  25.892681 -80.130898
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...           Dora Puig
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...       Jessica Adams
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...      Lilian Carrion
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Ana Sanchez
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...      Todd Nordstrom
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...                None
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...        Luis Paredes
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...          David Reid
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  Miltiadis Kastanis
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...   3009174 Romanello
#
#                    list_broker_name_1 list_agent_name_2  \
# 0                  Luxe Living Realty              None
# 1                     Douglas Elliman              None
# 2                Compass Florida, LLC              None
# 3  One Sotheby's International Realty   Yedri Villafane
# 4               Compass Florida, LLC.  Julian Fernandez
# 5                                None              None
# 6                  Million Realty LLC              None
# 7      One Sotheby's International Re              None
# 8               Compass Florida, LLC.              None
# 9               Compass Florida, LLC.    Claudia Villar
#
#                    list_broker_name_2     buy_agent_name_1  \
# 0                                None       Fredrik Eklund
# 1                                None       NON-MLS MEMBER
# 2                                None        Nataly Stuart
# 3  One Sotheby's International Realty  Christina Fernandez
# 4               Compass Florida, LLC.         Juan Zuluaga
# 5                                None                 None
# 6                                None         Matthew Lill
# 7                                None        Anna Sherrill
# 8                                None       Mikhail MudrIk
# 9               Compass Florida, LLC.    3009174 Romanello
#
#                 buy_broker_name_1 buy_agent_name_2      buy_broker_name_2  \
# 0                 Douglas Elliman             None                   None
# 1              MAR NON MLS MEMBER             None                   None
# 2           Socialite Realty, LLC             None                   None
# 3                ACC Realty, Inc.             None                   None
# 4          Coldwell Banker Realty             None                   None
# 5                            None             None                   None
# 6              The Corcoran Group             None                   None
# 7  One Sotheby's International Re             None                   None
# 8          The Agency Florida LLC             None                   None
# 9           Compass Florida, LLC.   Claudia Villar  Compass Florida, LLC.
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54f8f3a2c7a7c0f352315731a785a978 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 11th — May. 18th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54f8f3a2c7a7c0f352315731a785a978&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_54f8f3a2c7a7c0f352315731a785a978 = L.map(
#                 &quot;map_54f8f3a2c7a7c0f352315731a785a978&quot;,
#                 {
#                     center: [25.813143290441175, -80.20210758088236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_65673ec3e2a987db631fdb5599157ef5 = L.featureGroup(
#                 {}
#             ).addTo(map_54f8f3a2c7a7c0f352315731a785a978);
#
#
#             var marker_8c275b2a37ddce2b2e6170150a0d70cb = L.marker(
#                 [25.763482, -80.137699],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_65673ec3e2a987db631fdb5599157ef5);
#
#
#             var icon_1344c5fa08f71cdc47748c55030cdecc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c275b2a37ddce2b2e6170150a0d70cb.setIcon(icon_1344c5fa08f71cdc47748c55030cdecc);
#
#
#         var popup_524a7e1a811f1c4c2e2712234d412b90 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_dd3432b174cb5bd6d7d8f889a62890dd = $(`&lt;div id=&quot;html_dd3432b174cb5bd6d7d8f889a62890dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;7012 Fisher Island Dr #7012&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$16,200,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3,448.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,698.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2016.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_524a7e1a811f1c4c2e2712234d412b90.setContent(html_dd3432b174cb5bd6d7d8f889a62890dd);
#
#
#
#         marker_8c275b2a37ddce2b2e6170150a0d70cb.bindPopup(popup_524a7e1a811f1c4c2e2712234d412b90)
#         ;
#
#
#
#
#             var feature_group_8eb666367a7dd2bfff403687dacac06f = L.featureGroup(
#                 {}
#             ).addTo(map_54f8f3a2c7a7c0f352315731a785a978);
#
#
#             var marker_319f7b46c228953b57770e212d45acbc = L.marker(
#                 [25.7287511, -80.2380127],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_8eb666367a7dd2bfff403687dacac06f);
#
#
#             var icon_84dc575c6d7e7d80cfd3d7c138aebb90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_319f7b46c228953b57770e212d45acbc.setIcon(icon_84dc575c6d7e7d80cfd3d7c138aebb90);
#
#
#         var popup_1e2d4216f32cb6908c743aded81b0df4 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_66017ee6fcbb284d949b829a650a318a = $(`&lt;div id=&quot;html_66017ee6fcbb284d949b829a650a318a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2811 S Bayshore Dr Unit 15A&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$12,500,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3,850.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,247.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2020.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_1e2d4216f32cb6908c743aded81b0df4.setContent(html_66017ee6fcbb284d949b829a650a318a);
#
#
#
#         marker_319f7b46c228953b57770e212d45acbc.bindPopup(popup_1e2d4216f32cb6908c743aded81b0df4)
#         ;
#
#
#
#
#             var marker_13a4ada3c1e25e99ea1f297e6bf718e6 = L.marker(
#                 [25.7589149, -80.137511],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_8eb666367a7dd2bfff403687dacac06f);
#
#
#             var icon_b88e8754ca9afbbd0b2ebd9b5638ec9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13a4ada3c1e25e99ea1f297e6bf718e6.setIcon(icon_b88e8754ca9afbbd0b2ebd9b5638ec9b);
#
#
#         var popup_71e9c28296ba0f3b079fb25d79952f68 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_e470be02c24189236ec16fe4

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0  Miami Beach                FL             33109.0  16200000.0   4.0    4.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...         Dora Puig
#
#    list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Luxe Living Realty              None               None   Fredrik Eklund
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_05192025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Island Dr #7012 in Miami Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 1  PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 2  PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 3  PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 4  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 5  PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 6  PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 7  PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 8  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 9  PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0         Miami Beach                FL             33109.0  16200000.0   4.0
# 1               Miami                FL             33133.0  12500000.0   4.0
# 2       Fisher Island                FL             33109.0   5500000.0   2.0
# 3               Miami                FL             33133.0   4050000.0   3.0
# 4         Miami Beach                FL             33139.0   4000000.0   3.0
# 5         Bal Harbour                FL             33154.0   3750000.0   2.0
# 6         Miami Beach                FL             33139.0   3260902.0   1.0
# 7         Miami Beach                FL             33139.0   3099000.0   3.0
# 8         Miami Beach                FL             33154.0   2850000.0   2.0
# 9  Bay Harbor Islands                FL             33154.0   2450000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
# 1    5.5         C.G.B. SUBDIVISION       3247.0       NaN      2020.0
# 2    2.5  OCEANSIDE @ FISHER ISL CO       2420.0       NaN      1989.0
# 3    3.5       GROVENOR HOUSE CONDO       2640.0       NaN      2005.0
# 4    3.5  ALTON BEACH REALTY CO SUB       2691.0       NaN      2021.0
# 5    2.0   OCEANA BAL HARBOUR CONDO       1805.0       NaN      2016.0
# 6    1.5   CONTINUUM ON SOUTH BEACH       1201.0       NaN      2002.0
# 7    3.5          300 COLLINS CONDO       1699.0       NaN      2018.0
# 8    2.5     8701 COLLINS AVE CONDO       1602.0       NaN      2019.0
# 9    3.5    SERENO RESIDENCES CONDO       1929.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
# 1             NaN         3850.0     7447.0   Sold
# 2             NaN         2273.0     7646.0   Sold
# 3             NaN         1534.0     4081.0   Sold
# 4             NaN         1486.0    13370.0   Sold
# 5             NaN         2078.0     3864.0   Sold
# 6             NaN         2715.0     3600.0   Sold
# 7             NaN         1824.0     8986.0   Sold
# 8             NaN         1779.0     5903.0   Sold
# 9             NaN         1270.0     3525.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...  MARMLS  A11710639
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...  MARMLS  A11776077
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11776122
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...  MARMLS  A11661491
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...  MARMLS  A11754086
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11711551
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...  MARMLS  A11751817
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  MARMLS  A11664216
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...  MARMLS  A11742820
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
# 1        N          Y  25.728751 -80.238013
# 2        N          Y  25.758915 -80.137511
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.784161 -80.142633
# 5        N          Y  25.895168 -80.123150
# 6        N          Y  25.767180 -80.132822
# 7        N          Y  25.772642 -80.133687
# 8        N          Y  25.872197 -80.121210
# 9        N          Y  25.892681 -80.130898
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...           Dora Puig
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...       Jessica Adams
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...      Lilian Carrion
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Ana Sanchez
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...      Todd Nordstrom
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...                None
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...        Luis Paredes
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...          David Reid
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  Miltiadis Kastanis
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...   3009174 Romanello
#
#                    list_broker_name_1 list_agent_name_2  \
# 0                  Luxe Living Realty              None
# 1                     Douglas Elliman              None
# 2                Compass Florida, LLC              None
# 3  One Sotheby's International Realty   Yedri Villafane
# 4               Compass Florida, LLC.  Julian Fernandez
# 5                                None              None
# 6                  Million Realty LLC              None
# 7      One Sotheby's International Re              None
# 8               Compass Florida, LLC.              None
# 9               Compass Florida, LLC.    Claudia Villar
#
#                    list_broker_name_2     buy_agent_name_1  \
# 0                                None       Fredrik Eklund
# 1                                None       NON-MLS MEMBER
# 2                                None        Nataly Stuart
# 3  One Sotheby's International Realty  Christina Fernandez
# 4               Compass Florida, LLC.         Juan Zuluaga
# 5                                None                 None
# 6                                None         Matthew Lill
# 7                                None        Anna Sherrill
# 8                                None       Mikhail MudrIk
# 9               Compass Florida, LLC.    3009174 Romanello
#
#                 buy_broker_name_1 buy_agent_name_2      buy_broker_name_2  \
# 0                 Douglas Elliman             None                   None
# 1              MAR NON MLS MEMBER             None                   None
# 2           Socialite Realty, LLC             None                   None
# 3                ACC Realty, Inc.             None                   None
# 4          Coldwell Banker Realty             None                   None
# 5                            None             None                   None
# 6              The Corcoran Group             None                   None
# 7  One Sotheby's International Re             None                   None
# 8          The Agency Florida LLC             None                   None
# 9           Compass Florida, LLC.   Claudia Villar  Compass Florida, LLC.
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Islan...
# 1     2    blue  C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit ...
# 2     3    blue  OCEANSIDE @ FISHER ISL CO at 7953 Fisher Islan...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #15...
# 4     5    blue  ALTON BEACH REALTY CO SUB at 1300 Monad Ter Un...
# 5     6    blue  OCEANA BAL HARBOUR CONDO at 10201 Collins Ave ...
# 6     7    blue  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #1...
# 7     8    blue  300 COLLINS CONDO at 300 Collins Ave Unit 4D i...
# 8     9    blue  8701 COLLINS AVE CONDO at 8701 Collins Ave #30...
# 9    10    blue  SERENO RESIDENCES CONDO at 10201 E Bay Harbor ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: PALAZZO DEL SOL/DELLA LUN closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,450,000 to $16,200,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Fisher Island, Miami Beach, Miami, Bal Harbour, Bay Harbor Islands, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $123,677,931 million from May. 11th to May. 18th. The previous week, brokers closed 91 condo sales totaling $111,940,988.
#
# Last week’s units sold for an average of $973,842, lower than the $1,230,121 average price from the previous week. The average price per square foot fell to $636 from $660, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,450,000.0 million to $16,200,000.0 million.
#
# PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Island Dr #7012 in Miami Beach took the top spot with a $16,200,000.0 million closing. The sale closed at $3,448.0 per square foot.
#
# Dora Puig with Luxe Living Realty, and None with None had the listing.
# Fredrik Eklund with Douglas Elliman, and None with None represented the buyer.
#
# C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit 15A in Miami, closed for the second highest amount, $12,500,000.0, or $3,850.0 per square foot.
#
# Jessica Adams with Douglas Elliman, and None with None had the listing.
# NON-MLS MEMBER with MAR NON MLS MEMBER, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_05192025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 11th to May. 18th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 1  PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 2  PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 3  PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 4  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 5  PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 6  PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 7  PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 8  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 9  PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0         Miami Beach                FL             33109.0  16200000.0   4.0
# 1               Miami                FL             33133.0  12500000.0   4.0
# 2       Fisher Island                FL             33109.0   5500000.0   2.0
# 3               Miami                FL             33133.0   4050000.0   3.0
# 4         Miami Beach                FL             33139.0   4000000.0   3.0
# 5         Bal Harbour                FL             33154.0   3750000.0   2.0
# 6         Miami Beach                FL             33139.0   3260902.0   1.0
# 7         Miami Beach                FL             33139.0   3099000.0   3.0
# 8         Miami Beach                FL             33154.0   2850000.0   2.0
# 9  Bay Harbor Islands                FL             33154.0   2450000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
# 1    5.5         C.G.B. SUBDIVISION       3247.0       NaN      2020.0
# 2    2.5  OCEANSIDE @ FISHER ISL CO       2420.0       NaN      1989.0
# 3    3.5       GROVENOR HOUSE CONDO       2640.0       NaN      2005.0
# 4    3.5  ALTON BEACH REALTY CO SUB       2691.0       NaN      2021.0
# 5    2.0   OCEANA BAL HARBOUR CONDO       1805.0       NaN      2016.0
# 6    1.5   CONTINUUM ON SOUTH BEACH       1201.0       NaN      2002.0
# 7    3.5          300 COLLINS CONDO       1699.0       NaN      2018.0
# 8    2.5     8701 COLLINS AVE CONDO       1602.0       NaN      2019.0
# 9    3.5    SERENO RESIDENCES CONDO       1929.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
# 1             NaN         3850.0     7447.0   Sold
# 2             NaN         2273.0     7646.0   Sold
# 3             NaN         1534.0     4081.0   Sold
# 4             NaN         1486.0    13370.0   Sold
# 5             NaN         2078.0     3864.0   Sold
# 6             NaN         2715.0     3600.0   Sold
# 7             NaN         1824.0     8986.0   Sold
# 8             NaN         1779.0     5903.0   Sold
# 9             NaN         1270.0     3525.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...  MARMLS  A11710639
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...  MARMLS  A11776077
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11776122
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...  MARMLS  A11661491
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...  MARMLS  A11754086
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11711551
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...  MARMLS  A11751817
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  MARMLS  A11664216
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...  MARMLS  A11742820
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
# 1        N          Y  25.728751 -80.238013
# 2        N          Y  25.758915 -80.137511
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.784161 -80.142633
# 5        N          Y  25.895168 -80.123150
# 6        N          Y  25.767180 -80.132822
# 7        N          Y  25.772642 -80.133687
# 8        N          Y  25.872197 -80.121210
# 9        N          Y  25.892681 -80.130898
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...           Dora Puig
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...       Jessica Adams
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...      Lilian Carrion
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Ana Sanchez
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...      Todd Nordstrom
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...                None
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...        Luis Paredes
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...          David Reid
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  Miltiadis Kastanis
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...   3009174 Romanello
#
#                    list_broker_name_1 list_agent_name_2  \
# 0                  Luxe Living Realty              None
# 1                     Douglas Elliman              None
# 2                Compass Florida, LLC              None
# 3  One Sotheby's International Realty   Yedri Villafane
# 4               Compass Florida, LLC.  Julian Fernandez
# 5                                None              None
# 6                  Million Realty LLC              None
# 7      One Sotheby's International Re              None
# 8               Compass Florida, LLC.              None
# 9               Compass Florida, LLC.    Claudia Villar
#
#                    list_broker_name_2     buy_agent_name_1  \
# 0                                None       Fredrik Eklund
# 1                                None       NON-MLS MEMBER
# 2                                None        Nataly Stuart
# 3  One Sotheby's International Realty  Christina Fernandez
# 4               Compass Florida, LLC.         Juan Zuluaga
# 5                                None                 None
# 6                                None         Matthew Lill
# 7                                None        Anna Sherrill
# 8                                None       Mikhail MudrIk
# 9               Compass Florida, LLC.    3009174 Romanello
#
#                 buy_broker_name_1 buy_agent_name_2      buy_broker_name_2  \
# 0                 Douglas Elliman             None                   None
# 1              MAR NON MLS MEMBER             None                   None
# 2           Socialite Realty, LLC             None                   None
# 3                ACC Realty, Inc.             None                   None
# 4          Coldwell Banker Realty             None                   None
# 5                            None             None                   None
# 6              The Corcoran Group             None                   None
# 7  One Sotheby's International Re             None                   None
# 8          The Agency Florida LLC             None                   None
# 9           Compass Florida, LLC.   Claudia Villar  Compass Florida, LLC.
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Islan...
# 1     2    blue  C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit ...
# 2     3    blue  OCEANSIDE @ FISHER ISL CO at 7953 Fisher Islan...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #15...
# 4     5    blue  ALTON BEACH REALTY CO SUB at 1300 Monad Ter Un...
# 5     6    blue  OCEANA BAL HARBOUR CONDO at 10201 Collins Ave ...
# 6     7    blue  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #1...
# 7     8    blue  300 COLLINS CONDO at 300 Collins Ave Unit 4D i...
# 8     9    blue  8701 COLLINS AVE CONDO at 8701 Collins Ave #30...
# 9    10    blue  SERENO RESIDENCES CONDO at 10201 E Bay Harbor ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: PALAZZO DEL SOL/DELLA LUN closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,450,000 to $16,200,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Fisher Island, Miami Beach, Miami, Bal Harbour, Bay Harbor Islands, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $123,677,931 million from May. 11th to May. 18th. The previous week, brokers closed 91 condo sales totaling $111,940,988.
#
# Last week’s units sold for an average of $973,842, lower than the $1,230,121 average price from the previous week. The average price per square foot fell to $636 from $660, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,450,000.0 million to $16,200,000.0 million.
#
# PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Island Dr #7012 in Miami Beach took the top spot with a $16,200,000.0 million closing. The sale closed at $3,448.0 per square foot.
#
# Dora Puig with Luxe Living Realty, and None with None had the listing.
# Fredrik Eklund with Douglas Elliman, and None with None represented the buyer.
#
# C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit 15A in Miami, closed for the second highest amount, $12,500,000.0, or $3,850.0 per square foot.
#
# Jessica Adams with Douglas Elliman, and None with None had the listing.
# NON-MLS MEMBER with MAR NON MLS MEMBER, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_05192025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 11th to May. 18th:
#
# Most Expensive
# PALAZZO DEL SOL/DELLA LUN, 7012 Fisher Island Dr #7012, in Miami Beach | Price: $16,200,000 | $3,448 psf | Listing agents: Dora Puig with Luxe Living Realty and None with None | Buyer's agents: Fredrik Eklund with Douglas Elliman and None with None
#
# Least Expensive
# SERENO RESIDENCES CONDO, 10201 E Bay Harbor Dr #501, in Bay Harbor Islands | Price: $2,450,000 | $1,270 psf | Listing agents: 3009174 Romanello with Compass Florida, LLC. and Claudia Villar with Compass Florida, LLC. | Buyer's agents: 3009174 Romanello with Compass Florida, LLC. and Claudia Villar with Compass Florida, LLC.
#
# Highest Price Per Square Foot
# C.G.B. SUBDIVISION, 2811 S Bayshore Dr Unit 15A, in Miami | Price: $12,500,000 | $3,850 psf | Listing agents: Jessica Adams with Douglas Elliman and None with None | Buyer's agents: NON-MLS MEMBER with MAR NON MLS MEMBER and None with None
#
# Lowest Price Per Square Foot
# SERENO RESIDENCES CONDO, 10201 E Bay Harbor Dr #501, in Bay Harbor Islands | Price: $2,450,000 | $1,270 psf | Listing agents: 3009174 Romanello with Compass Florida, LLC. and Claudia Villar with Compass Florida, LLC. | Buyer's agents: 3009174 Romanello with Compass Florida, LLC. and Claudia Villar with Compass Florida, LLC.
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Miami-Beach/7012-Fisher-Island-Dr-33109/unit-7012/home/110132741
# Second priciest sale:  https://www.redfin.com/FL/Miami/2811-S-Bayshore-Dr-33133/unit-15A/home/175175301
# Cheapest top ten sale:  https://www.redfin.com/FL/Bay-Harbor-Islands/10201-E-Bay-Harbor-Dr-33154/unit-501/home/112999887
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Surfside/8701-Collins-Ave-33154/unit-306/home/168665606
# Highest top ten psf:  https://www.redfin.com/FL/Miami/2811-S-Bayshore-Dr-33133/unit-15A/home/175175301
# Lowest top ten psf:  https://www.redfin.com/FL/Bay-Harbor-Islands/10201-E-Bay-Harbor-Dr-33154/unit-501/home/112999887

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Miami-Beach/7012-Fisher-Island-Dr-33109/unit-7012/home/110132741

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Miami/2811-S-Bayshore-Dr-33133/unit-15A/home/175175301

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Bay-Harbor-Islands/10201-E-Bay-Harbor-Dr-33154/unit-501/home/112999887

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Surfside/8701-Collins-Ave-33154/unit-306/home/168665606

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami/2811-S-Bayshore-Dr-33133/unit-15A/home/175175301

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Bay-Harbor-Islands/10201-E-Bay-Harbor-Dr-33154/unit-501/home/112999887

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-05-12   Condo/Co-op  7012 Fisher Island Dr #7012
# 1  PAST SALE 2025-05-15   Condo/Co-op  2811 S Bayshore Dr Unit 15A
# 2  PAST SALE 2025-05-16   Condo/Co-op  7953 Fisher Island Dr #7953
# 3  PAST SALE 2025-05-16   Condo/Co-op     2627 S Bayshore Dr #1504
# 4  PAST SALE 2025-05-16   Condo/Co-op       1300 Monad Ter Unit 9B
# 5  PAST SALE 2025-05-15   Condo/Co-op       10201 Collins Ave #511
# 6  PAST SALE 2025-05-15   Condo/Co-op        100 S Pointe Dr #1602
# 7  PAST SALE 2025-05-12   Condo/Co-op      300 Collins Ave Unit 4D
# 8  PAST SALE 2025-05-14   Condo/Co-op        8701 Collins Ave #306
# 9  PAST SALE 2025-05-15   Condo/Co-op   10201 E Bay Harbor Dr #501
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0         Miami Beach                FL             33109.0  16200000.0   4.0
# 1               Miami                FL             33133.0  12500000.0   4.0
# 2       Fisher Island                FL             33109.0   5500000.0   2.0
# 3               Miami                FL             33133.0   4050000.0   3.0
# 4         Miami Beach                FL             33139.0   4000000.0   3.0
# 5         Bal Harbour                FL             33154.0   3750000.0   2.0
# 6         Miami Beach                FL             33139.0   3260902.0   1.0
# 7         Miami Beach                FL             33139.0   3099000.0   3.0
# 8         Miami Beach                FL             33154.0   2850000.0   2.0
# 9  Bay Harbor Islands                FL             33154.0   2450000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5  PALAZZO DEL SOL/DELLA LUN       4698.0       NaN      2016.0
# 1    5.5         C.G.B. SUBDIVISION       3247.0       NaN      2020.0
# 2    2.5  OCEANSIDE @ FISHER ISL CO       2420.0       NaN      1989.0
# 3    3.5       GROVENOR HOUSE CONDO       2640.0       NaN      2005.0
# 4    3.5  ALTON BEACH REALTY CO SUB       2691.0       NaN      2021.0
# 5    2.0   OCEANA BAL HARBOUR CONDO       1805.0       NaN      2016.0
# 6    1.5   CONTINUUM ON SOUTH BEACH       1201.0       NaN      2002.0
# 7    3.5          300 COLLINS CONDO       1699.0       NaN      2018.0
# 8    2.5     8701 COLLINS AVE CONDO       1602.0       NaN      2019.0
# 9    3.5    SERENO RESIDENCES CONDO       1929.0       NaN      2016.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         3448.0    15489.0   Sold
# 1             NaN         3850.0     7447.0   Sold
# 2             NaN         2273.0     7646.0   Sold
# 3             NaN         1534.0     4081.0   Sold
# 4             NaN         1486.0    13370.0   Sold
# 5             NaN         2078.0     3864.0   Sold
# 6             NaN         2715.0     3600.0   Sold
# 7             NaN         1824.0     8986.0   Sold
# 8             NaN         1779.0     5903.0   Sold
# 9             NaN         1270.0     3525.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...  MARMLS  A11712235
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...  MARMLS  A11710639
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...  MARMLS  A11776077
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11776122
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...  MARMLS  A11661491
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...  MARMLS  A11754086
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11711551
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...  MARMLS  A11751817
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  MARMLS  A11664216
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...  MARMLS  A11742820
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.763482 -80.137699
# 1        N          Y  25.728751 -80.238013
# 2        N          Y  25.758915 -80.137511
# 3        N          Y  25.732272 -80.234921
# 4        N          Y  25.784161 -80.142633
# 5        N          Y  25.895168 -80.123150
# 6        N          Y  25.767180 -80.132822
# 7        N          Y  25.772642 -80.133687
# 8        N          Y  25.872197 -80.121210
# 9        N          Y  25.892681 -80.130898
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/7012-Fis...           Dora Puig
# 1  https://www.redfin.com/FL/Miami/2811-S-Bayshor...       Jessica Adams
# 2  https://www.redfin.com/FL/Miami-Beach/7953-Fis...      Lilian Carrion
# 3  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Ana Sanchez
# 4  https://www.redfin.com/FL/Miami-Beach/1300-Mon...      Todd Nordstrom
# 5  https://www.redfin.com/FL/Bal-Harbour/10201-Co...                None
# 6  https://www.redfin.com/FL/Miami-Beach/100-S-Po...        Luis Paredes
# 7  https://www.redfin.com/FL/Miami-Beach/300-Coll...          David Reid
# 8  https://www.redfin.com/FL/Surfside/8701-Collin...  Miltiadis Kastanis
# 9  https://www.redfin.com/FL/Bay-Harbor-Islands/1...   3009174 Romanello
#
#                    list_broker_name_1 list_agent_name_2  \
# 0                  Luxe Living Realty              None
# 1                     Douglas Elliman              None
# 2                Compass Florida, LLC              None
# 3  One Sotheby's International Realty   Yedri Villafane
# 4               Compass Florida, LLC.  Julian Fernandez
# 5                                None              None
# 6                  Million Realty LLC              None
# 7      One Sotheby's International Re              None
# 8               Compass Florida, LLC.              None
# 9               Compass Florida, LLC.    Claudia Villar
#
#                    list_broker_name_2     buy_agent_name_1  \
# 0                                None       Fredrik Eklund
# 1                                None       NON-MLS MEMBER
# 2                                None        Nataly Stuart
# 3  One Sotheby's International Realty  Christina Fernandez
# 4               Compass Florida, LLC.         Juan Zuluaga
# 5                                None                 None
# 6                                None         Matthew Lill
# 7                                None        Anna Sherrill
# 8                                None       Mikhail MudrIk
# 9               Compass Florida, LLC.    3009174 Romanello
#
#                 buy_broker_name_1 buy_agent_name_2      buy_broker_name_2  \
# 0                 Douglas Elliman             None                   None
# 1              MAR NON MLS MEMBER             None                   None
# 2           Socialite Realty, LLC             None                   None
# 3                ACC Realty, Inc.             None                   None
# 4          Coldwell Banker Realty             None                   None
# 5                            None             None                   None
# 6              The Corcoran Group             None                   None
# 7  One Sotheby's International Re             None                   None
# 8          The Agency Florida LLC             None                   None
# 9           Compass Florida, LLC.   Claudia Villar  Compass Florida, LLC.
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  PALAZZO DEL SOL/DELLA LUN at 7012 Fisher Islan...
# 1     2    blue  C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit ...
# 2     3    blue  OCEANSIDE @ FISHER ISL CO at 7953 Fisher Islan...
# 3     4    blue  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #15...
# 4     5    blue  ALTON BEACH REALTY CO SUB at 1300 Monad Ter Un...
# 5     6    blue  OCEANA BAL HARBOUR CONDO at 10201 Collins Ave ...
# 6     7    blue  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #1...
# 7     8    blue  300 COLLINS CONDO at 300 Collins Ave Unit 4D i...
# 8     9    blue  8701 COLLINS AVE CONDO at 8701 Collins Ave #30...
# 9    10    blue  SERENO RESIDENCES CONDO at 10201 E Bay Harbor ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 12, 23) ## List (Earlier) date
date2 = datetime(2025, 5, 15) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 143

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    3448.0
# 1    3850.0
# 2    2273.0
# 3    1534.0
# 4    1486.0
# 5    2078.0
# 6    2715.0
# 7    1824.0
# 8    1779.0
# 9    1270.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                           ADDRESS        PRICE  \
# 0 2025-05-12        7012 Fisher Island Dr #7012 in Miami Beach  $16,200,000
# 1 2025-05-15              2811 S Bayshore Dr Unit 15A in Miami  $12,500,000
# 2 2025-05-16      7953 Fisher Island Dr #7953 in Fisher Island   $5,500,000
# 3 2025-05-16                 2627 S Bayshore Dr #1504 in Miami   $4,050,000
# 4 2025-05-16             1300 Monad Ter Unit 9B in Miami Beach   $4,000,000
# 5 2025-05-15             10201 Collins Ave #511 in Bal Harbour   $3,750,000
# 6 2025-05-15              100 S Pointe Dr #1602 in Miami Beach   $3,260,902
# 7 2025-05-12            300 Collins Ave Unit 4D in Miami Beach   $3,099,000
# 8 2025-05-14              8701 Collins Ave #306 in Miami Beach   $2,850,000
# 9 2025-05-15  10201 E Bay Harbor Dr #501 in Bay Harbor Islands   $2,450,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET  SOURCE       MLS#  \
# 0    4    4.5       4,698       2016        $3,448  MARMLS  A11712235
# 1    4    5.5       3,247       2020        $3,850  MARMLS  A11710639
# 2    2    2.5       2,420       1989        $2,273  MARMLS  A11776077
# 3    3    3.5       2,640       2005        $1,534  MARMLS  A11776122
# 4    3    3.5       2,691       2021        $1,486  MARMLS  A11661491
# 5    2    2.0       1,805       2016        $2,078  MARMLS  A11754086
# 6    1    1.5       1,201       2002        $2,715  MARMLS  A11711551
# 7    3    3.5       1,699       2018        $1,824  MARMLS  A11751817
# 8    2    2.5       1,602       2019        $1,779  MARMLS  A11664216
# 9    4    3.5       1,929       2016        $1,270  MARMLS  A11742820
#
#                                         LISTING INFO  \
# 0                   Dora Puig Luxe Living Realty
# 1                  Jessica Adams Douglas Elliman
# 2            Lilian Carrion Compass Florida, LLC
# 3  Ana Sanchez One Sotheby's International Realty...
# 4  Todd Nordstrom Compass Florida, LLC. Julian Fe...
# 5
# 6                Luis Paredes Million Realty LLC
# 7      David Reid One Sotheby's International Re
# 8       Miltiadis Kastanis Compass Florida, LLC.
# 9  3009174 Romanello Compass Florida, LLC. Claudi...
#
#                                          BUYING INFO
# 0                 Fredrik Eklund Douglas Elliman
# 1              NON-MLS MEMBER MAR NON MLS MEMBER
# 2            Nataly Stuart Socialite Realty, LLC
# 3           Christina Fernandez ACC Realty, Inc.
# 4            Juan Zuluaga Coldwell Banker Realty
# 5
# 6                Matthew Lill The Corcoran Group
# 7   Anna Sherrill One Sotheby's International Re
# 8          Mikhail MudrIk The Agency Florida LLC
# 9  3009174 Romanello Compass Florida, LLC. Claudi...
