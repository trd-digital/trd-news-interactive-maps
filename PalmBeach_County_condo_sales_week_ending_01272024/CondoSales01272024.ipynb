# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Jan. 19th Jan. 26th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 1  PAST SALE  January-22-2025   Condo/Co-op  10302 Myrtlewood Cir W
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Palm Beach Gardens                FL             33418.0  340000.0   2.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Palm-Beach-Gardens/1...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11044786         N          Y  26.873428 -80.106892
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# df2 = df[(df['SOLD DATE'] > '2024-12-29') & (df['SOLD DATE'] < '2025-01-07')]

# %%
df2 = df

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-01-24    17
# 2025-01-22    16
# 2025-01-23    16
# 2025-01-21    12
# 2025-01-20     2
# 2025-01-27     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 38  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 5   PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 22  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 64  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 24  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 40  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 62  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 12  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 10  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 41  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 38     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 5   Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 22  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 64   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 24  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 40  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 62     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 12     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 10  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 41  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#     ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 38  ...   Sold                         NaN                       NaN
# 5   ...   Sold                         NaN                       NaN
# 22  ...   Sold                         NaN                       NaN
# 64  ...   Sold                         NaN                       NaN
# 24  ...   Sold                         NaN                       NaN
# 40  ...   Sold                         NaN                       NaN
# 62  ...   Sold                         NaN                       NaN
# 12  ...   Sold                         NaN                       NaN
# 10  ...   Sold                         NaN                       NaN
# 41  ...   Sold                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 38  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
# 5   https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 22  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 64  https://www.redfin.com/FL/Lantana/6-Little-Pon...  Beaches MLS
# 24  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...  Beaches MLS
# 40  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...  Beaches MLS
# 62  https://www.redfin.com/FL/Jupiter/242-Tresana-...  Beaches MLS
# 12  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...  Beaches MLS
# 10  https://www.redfin.com/FL/Boca-Raton/7233-Prom...       MARMLS
# 41  https://www.redfin.com/FL/Boca-Raton/5214-Lake...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 38  RX-11028563         N          Y  26.918407 -80.066545
# 5   RX-11050978         N          Y  26.348269 -80.076619
# 22  RX-11031947         N          Y  26.344431 -80.070692
# 64  RX-10948720         N          Y  26.570376 -80.043908
# 24  RX-11034043         N          Y  26.860900 -80.065793
# 40  RX-11024057         N          Y  26.321745 -80.075232
# 62  RX-10959380         N          Y  26.926899 -80.155641
# 12  RX-11044736         N          Y  26.924386 -80.092082
# 10    A11697582         N          Y  26.334070 -80.157913
# 41  RX-11014143         N          Y  26.414444 -80.126160
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 1  PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 2  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 3  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 4  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 5  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 6  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 7  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 8  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 9  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 1  Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 2  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 3   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 4  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 5  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 6     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 7     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 8  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 9  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#    ...  LONGITUDE                                                url  \
# 0  ... -80.066545  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...
# 1  ... -80.076619  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...
# 2  ... -80.070692  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...
# 3  ... -80.043908  https://www.redfin.com/FL/Lantana/6-Little-Pon...
# 4  ... -80.065793  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...
# 5  ... -80.075232  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...
# 6  ... -80.155641  https://www.redfin.com/FL/Jupiter/242-Tresana-...
# 7  ... -80.092082  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...
# 8  ... -80.157913  https://www.redfin.com/FL/Boca-Raton/7233-Prom...
# 9  ... -80.126160  https://www.redfin.com/FL/Boca-Raton/5214-Lake...
#
#    list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0   Michael Montalto     Jupiter Ocean Grande Realty               None
# 1   Marisela Cotilla  Pineapple Realty Advisores LLC               None
# 2        Ana Londono                  Lang Realty/BR               None
# 3    Michelle Newman              The Corcoran Group               None
# 4     Crystal Condit  Waterfront Properties & Club C               None
# 5       Gregory Lynn               Lynn Realty Group        Charli Lynn
# 6      Allison Moore          Coldwell Banker Realty               None
# 7      Paul Stockall             Compass Florida LLC   Diane Hutchinson
# 8          Edy Pyles             Casalina Realty Inc               None
# 9    Michael Ledwitz      Engel & Volkers Boca Raton      Wendy Ledwitz
#
#            list_broker_name_2      buy_agent_name_1  \
# 0                        None        Dianna Shpritz
# 1                        None  Rachelle Hirt-Beresh
# 2                        None           Ana Londono
# 3                        None       Michelle Newman
# 4                        None       Ashley Barbaree
# 5           Lynn Realty Group         Cavan Dettman
# 6                        None          Margot Matot
# 7         Compass Florida LLC         Paul Stockall
# 8                        None                  None
# 9  Engel & Volkers Boca Raton             Joy Wayne
#
#                   buy_broker_name_1  buy_agent_name_2    buy_broker_name_2
# 0  Leibowitz Realty Group, LLC./PBG              None                 None
# 1               Compass Florida LLC       Scott Gerow  Compass Florida LLC
# 2                    Lang Realty/BR              None                 None
# 3                The Corcoran Group              None                 None
# 4               Sutter & Nugent LLC              None                 None
# 5             Compass Florida, LLC.              None                 None
# 6     Platinum Properties/The Keyes              None                 None
# 7               Compass Florida LLC  Diane Hutchinson  Compass Florida LLC
# 8                              None              None                 None
# 9         Linda A. Gary Real Estate              None                 None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 64

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $403,182

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $299

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $25,803,620

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Palm Beach County
# Input Previous Week Condo Sales Total (number units sold):
# 81
# Input Previous Week Condo Average Sales Price:
# 65_700_000
# Input Previous Week Condo Average PSF:
# 397
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 61_300_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS     CITY  \
# 0  PAST SALE 2025-01-21   Condo/Co-op  230 Ocean Grande Blvd #801  Jupiter
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33477.0  1650000.0   3.0    3.5
#
#                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
#
#             list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Jupiter Ocean Grande Realty              None               None
#
#   buy_agent_name_1                 buy_broker_name_1 buy_agent_name_2  \
# 0   Dianna Shpritz  Leibowitz Realty Group, LLC./PBG             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 1  PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 2  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 3  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 4  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 5  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 6  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 7  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 8  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 9  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 1  Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 2  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 3   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 4  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 5  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 6     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 7     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 8  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 9  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0         Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
# 1                   Mizner Court Condo       1630.0       NaN      1988.0
# 2                      Chalfonte Condo       1448.0       NaN      1974.0
# 3    Little Pond Park Residences Condo       1500.0       NaN      1977.0
# 4                      Juno Bay Colony       1839.0       NaN      2014.0
# 5                 Three Thousand South       1382.0       NaN      1970.0
# 6       Jupiter Country Club Condo Iii       2293.0       NaN      2019.0
# 7  West Bay AT Jonathans Landing Condo       1839.0       NaN      1990.0
# 8             PROMENADE AT BOCA POINTE       3165.0       NaN      1986.0
# 9                 Catalina / Polo Club       1819.0       NaN      1989.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
# 1             NaN          926.0     2747.0   Sold
# 2             NaN         1001.0     1569.0   Sold
# 3             NaN          813.0     1358.0   Sold
# 4             NaN          653.0     1557.0   Sold
# 5             NaN          729.0     2211.0   Sold
# 6             NaN          386.0     1314.0   Sold
# 7             NaN          454.0     1458.0   Sold
# 8             NaN          235.0     1417.0   Sold
# 9             NaN          396.0      550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...  Beaches MLS
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...  Beaches MLS
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...       MARMLS
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
# 1  RX-11050978        N          Y  26.348269 -80.076619
# 2  RX-11031947        N          Y  26.344431 -80.070692
# 3  RX-10948720        N          Y  26.570376 -80.043908
# 4  RX-11034043        N          Y  26.860900 -80.065793
# 5  RX-11024057        N          Y  26.321745 -80.075232
# 6  RX-10959380        N          Y  26.926899 -80.155641
# 7  RX-11044736        N          Y  26.924386 -80.092082
# 8    A11697582        N          Y  26.334070 -80.157913
# 9  RX-11014143        N          Y  26.414444 -80.126160
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Marisela Cotilla
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...   Michelle Newman
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...    Crystal Condit
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...      Gregory Lynn
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...     Allison Moore
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...     Paul Stockall
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...         Edy Pyles
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...   Michael Ledwitz
#
#                list_broker_name_1 list_agent_name_2  \
# 0     Jupiter Ocean Grande Realty              None
# 1  Pineapple Realty Advisores LLC              None
# 2                  Lang Realty/BR              None
# 3              The Corcoran Group              None
# 4  Waterfront Properties & Club C              None
# 5               Lynn Realty Group       Charli Lynn
# 6          Coldwell Banker Realty              None
# 7             Compass Florida LLC  Diane Hutchinson
# 8             Casalina Realty Inc              None
# 9      Engel & Volkers Boca Raton     Wendy Ledwitz
#
#            list_broker_name_2      buy_agent_name_1  \
# 0                        None        Dianna Shpritz
# 1                        None  Rachelle Hirt-Beresh
# 2                        None           Ana Londono
# 3                        None       Michelle Newman
# 4                        None       Ashley Barbaree
# 5           Lynn Realty Group         Cavan Dettman
# 6                        None          Margot Matot
# 7         Compass Florida LLC         Paul Stockall
# 8                        None                  None
# 9  Engel & Volkers Boca Raton             Joy Wayne
#
#                   buy_broker_name_1  buy_agent_name_2    buy_broker_name_2  \
# 0  Leibowitz Realty Group, LLC./PBG              None                 None
# 1               Compass Florida LLC       Scott Gerow  Compass Florida LLC
# 2                    Lang Realty/BR              None                 None
# 3                The Corcoran Group              None                 None
# 4               Sutter & Nugent LLC              None                 None
# 5             Compass Florida, LLC.              None                 None
# 6     Platinum Properties/The Keyes              None                 None
# 7               Compass Florida LLC  Diane Hutchinson  Compass Florida LLC
# 8                              None              None                 None
# 9         Linda A. Gary Real Estate              None                 None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b78635a6290f791cca192eb415879c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Jan. 19th — Jan. 26th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b78635a6290f791cca192eb415879c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4b78635a6290f791cca192eb415879c2 = L.map(
#                 &quot;map_4b78635a6290f791cca192eb415879c2&quot;,
#                 {
#                     center: [26.5779130734375, -80.11037309375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_dc6b53b545f8bcc52afa27fa3f5565b2 = L.featureGroup(
#                 {}
#             ).addTo(map_4b78635a6290f791cca192eb415879c2);
#
#
#             var marker_fdb86ad8adbb349701d9561f702e1fa4 = L.marker(
#                 [26.9184071, -80.0665452],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_dc6b53b545f8bcc52afa27fa3f5565b2);
#
#
#             var icon_a9a0b1a5220875144acd7b299b72e121 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fdb86ad8adbb349701d9561f702e1fa4.setIcon(icon_a9a0b1a5220875144acd7b299b72e121);
#
#
#         var popup_ca13c1a84c8713327f4894dad711562d = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_7c691be462f65a90c7cfb74ae072ebc2 = $(`&lt;div id=&quot;html_7c691be462f65a90c7cfb74ae072ebc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;230 Ocean Grande Blvd #801&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,650,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$663.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,490.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2003.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ca13c1a84c8713327f4894dad711562d.setContent(html_7c691be462f65a90c7cfb74ae072ebc2);
#
#
#
#         marker_fdb86ad8adbb349701d9561f702e1fa4.bindPopup(popup_ca13c1a84c8713327f4894dad711562d)
#         ;
#
#
#
#
#             var feature_group_54ea35376e5141aa6cf0cfa1aa0788be = L.featureGroup(
#                 {}
#             ).addTo(map_4b78635a6290f791cca192eb415879c2);
#
#
#             var marker_b5409d77c4109610be9cf76390995b0c = L.marker(
#                 [26.3482689, -80.0766189],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_54ea35376e5141aa6cf0cfa1aa0788be);
#
#
#             var icon_eed7a3206550abca5859296bc1b092f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b5409d77c4109610be9cf76390995b0c.setIcon(icon_eed7a3206550abca5859296bc1b092f6);
#
#
#         var popup_3469e240f49d2841968ab2da6d05230b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0436626711ef0a7794dd17c6a19f0669 = $(`&lt;div id=&quot;html_0436626711ef0a7794dd17c6a19f0669&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;140 SE 5th Ave #250&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,510,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$926.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;1,630.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1988.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_3469e240f49d2841968ab2da6d05230b.setContent(html_0436626711ef0a7794dd17c6a19f0669);
#
#
#
#         marker_b5409d77c4109610be9cf76390995b0c.bindPopup(popup_3469e240f49d2841968ab2da6d05230b)
#         ;
#
#
#
#
#             var marker_7af0bea9c959ee6f5f45cbf9e5fd077d = L.marker(
#                 [26.3444311, -80.070692],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_54ea35376e5141aa6cf0cfa1aa0788be);
#
#
#             var icon_b0862ab77ee128c2093eef35a236dcc8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7af0bea9c959ee6f5f45cbf9e5fd077d.setIcon(icon_b0862ab77ee128c2093eef35a236dcc8);
#
#
#         var popup_5ee951b17687a81bfe3f77ab4906b9c8 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0222f2db514c7116241c17effdf62795 =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS     CITY  \
# 0  PAST SALE 2025-01-21   Condo/Co-op  230 Ocean Grande Blvd #801  Jupiter
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33477.0  1650000.0   3.0    3.5
#
#                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
#
#             list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Jupiter Ocean Grande Realty              None               None
#
#   buy_agent_name_1                 buy_broker_name_1 buy_agent_name_2  \
# 0   Dianna Shpritz  Leibowitz Realty Group, LLC./PBG             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01272024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Jupiter Ocean Grande 4 Condo at 230 Ocean Grande Blvd #801 in Jupiter'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 1  PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 2  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 3  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 4  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 5  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 6  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 7  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 8  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 9  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 1  Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 2  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 3   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 4  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 5  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 6     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 7     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 8  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 9  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0         Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
# 1                   Mizner Court Condo       1630.0       NaN      1988.0
# 2                      Chalfonte Condo       1448.0       NaN      1974.0
# 3    Little Pond Park Residences Condo       1500.0       NaN      1977.0
# 4                      Juno Bay Colony       1839.0       NaN      2014.0
# 5                 Three Thousand South       1382.0       NaN      1970.0
# 6       Jupiter Country Club Condo Iii       2293.0       NaN      2019.0
# 7  West Bay AT Jonathans Landing Condo       1839.0       NaN      1990.0
# 8             PROMENADE AT BOCA POINTE       3165.0       NaN      1986.0
# 9                 Catalina / Polo Club       1819.0       NaN      1989.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
# 1             NaN          926.0     2747.0   Sold
# 2             NaN         1001.0     1569.0   Sold
# 3             NaN          813.0     1358.0   Sold
# 4             NaN          653.0     1557.0   Sold
# 5             NaN          729.0     2211.0   Sold
# 6             NaN          386.0     1314.0   Sold
# 7             NaN          454.0     1458.0   Sold
# 8             NaN          235.0     1417.0   Sold
# 9             NaN          396.0      550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...  Beaches MLS
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...  Beaches MLS
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...       MARMLS
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
# 1  RX-11050978        N          Y  26.348269 -80.076619
# 2  RX-11031947        N          Y  26.344431 -80.070692
# 3  RX-10948720        N          Y  26.570376 -80.043908
# 4  RX-11034043        N          Y  26.860900 -80.065793
# 5  RX-11024057        N          Y  26.321745 -80.075232
# 6  RX-10959380        N          Y  26.926899 -80.155641
# 7  RX-11044736        N          Y  26.924386 -80.092082
# 8    A11697582        N          Y  26.334070 -80.157913
# 9  RX-11014143        N          Y  26.414444 -80.126160
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Marisela Cotilla
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...   Michelle Newman
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...    Crystal Condit
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...      Gregory Lynn
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...     Allison Moore
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...     Paul Stockall
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...         Edy Pyles
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...   Michael Ledwitz
#
#                list_broker_name_1 list_agent_name_2  \
# 0     Jupiter Ocean Grande Realty              None
# 1  Pineapple Realty Advisores LLC              None
# 2                  Lang Realty/BR              None
# 3              The Corcoran Group              None
# 4  Waterfront Properties & Club C              None
# 5               Lynn Realty Group       Charli Lynn
# 6          Coldwell Banker Realty              None
# 7             Compass Florida LLC  Diane Hutchinson
# 8             Casalina Realty Inc              None
# 9      Engel & Volkers Boca Raton     Wendy Ledwitz
#
#            list_broker_name_2      buy_agent_name_1  \
# 0                        None        Dianna Shpritz
# 1                        None  Rachelle Hirt-Beresh
# 2                        None           Ana Londono
# 3                        None       Michelle Newman
# 4                        None       Ashley Barbaree
# 5           Lynn Realty Group         Cavan Dettman
# 6                        None          Margot Matot
# 7         Compass Florida LLC         Paul Stockall
# 8                        None                  None
# 9  Engel & Volkers Boca Raton             Joy Wayne
#
#                   buy_broker_name_1  buy_agent_name_2    buy_broker_name_2  \
# 0  Leibowitz Realty Group, LLC./PBG              None                 None
# 1               Compass Florida LLC       Scott Gerow  Compass Florida LLC
# 2                    Lang Realty/BR              None                 None
# 3                The Corcoran Group              None                 None
# 4               Sutter & Nugent LLC              None                 None
# 5             Compass Florida, LLC.              None                 None
# 6     Platinum Properties/The Keyes              None                 None
# 7               Compass Florida LLC  Diane Hutchinson  Compass Florida LLC
# 8                              None              None                 None
# 9         Linda A. Gary Real Estate              None                 None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Jupiter Ocean Grande 4 Condo at 230 Ocean Gran...
# 1     2    blue  Mizner Court Condo at 140 SE 5th Ave #250 in B...
# 2     3    blue  Chalfonte Condo at 550 S Ocean Blvd #1006 in B...
# 3     4    blue  Little Pond Park Residences Condo at 6 Little ...
# 4     5    blue  Juno Bay Colony at 424 Bay Colony Dr N in Juno...
# 5     6    blue  Three Thousand South at 3000 S Ocean Blvd #405...
# 6     7    blue  Jupiter Country Club Condo Iii at 242 Tresana ...
# 7     8    blue  West Bay AT Jonathans Landing Condo at 3940 Ba...
# 8     9    blue  PROMENADE AT BOCA POINTE at 7233 Promenade Dr ...
# 9    10    blue  Catalina / Polo Club at 5214 Lake Catalina Dr ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Jupiter Ocean Grande 4 Condo closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $720,000 to $1,650,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Jupiter, Manalapan, Juno Beach, Boca Raton
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 64 condo sales totaling $25,803,620 million from Jan. 19th to Jan. 26th. The previous week, brokers closed 81 condo sales totaling $61,300,000.
#
# Last week’s units sold for an average of $403,182, lower than the $65,700,000 average price from the previous week. The average price per square foot fell to $299 from $397, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $720,000.0 million to $1,650,000.0 million.
#
# Jupiter Ocean Grande 4 Condo at 230 Ocean Grande Blvd #801 in Jupiter took the top spot with a $1,650,000.0 million closing. The sale closed at $663.0 per square foot.
#
# Michael Montalto with Jupiter Ocean Grande Realty, and None with None had the listing.
# Dianna Shpritz with Leibowitz Realty Group, LLC./PBG, and None with None represented the buyer.
#
# Mizner Court Condo at 140 SE 5th Ave #250 in Boca Raton, closed for the second highest amount, $1,510,000.0, or $926.0 per square foot.
#
# Marisela Cotilla with Pineapple Realty Advisores LLC, and None with None had the listing.
# Rachelle Hirt-Beresh with Compass Florida LLC, and Scott Gerow with Compass Florida LLC represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01272024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 19th to Jan. 26th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 1  PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 2  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 3  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 4  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 5  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 6  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 7  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 8  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 9  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 1  Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 2  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 3   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 4  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 5  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 6     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 7     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 8  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 9  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0         Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
# 1                   Mizner Court Condo       1630.0       NaN      1988.0
# 2                      Chalfonte Condo       1448.0       NaN      1974.0
# 3    Little Pond Park Residences Condo       1500.0       NaN      1977.0
# 4                      Juno Bay Colony       1839.0       NaN      2014.0
# 5                 Three Thousand South       1382.0       NaN      1970.0
# 6       Jupiter Country Club Condo Iii       2293.0       NaN      2019.0
# 7  West Bay AT Jonathans Landing Condo       1839.0       NaN      1990.0
# 8             PROMENADE AT BOCA POINTE       3165.0       NaN      1986.0
# 9                 Catalina / Polo Club       1819.0       NaN      1989.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
# 1             NaN          926.0     2747.0   Sold
# 2             NaN         1001.0     1569.0   Sold
# 3             NaN          813.0     1358.0   Sold
# 4             NaN          653.0     1557.0   Sold
# 5             NaN          729.0     2211.0   Sold
# 6             NaN          386.0     1314.0   Sold
# 7             NaN          454.0     1458.0   Sold
# 8             NaN          235.0     1417.0   Sold
# 9             NaN          396.0      550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...  Beaches MLS
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...  Beaches MLS
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...       MARMLS
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
# 1  RX-11050978        N          Y  26.348269 -80.076619
# 2  RX-11031947        N          Y  26.344431 -80.070692
# 3  RX-10948720        N          Y  26.570376 -80.043908
# 4  RX-11034043        N          Y  26.860900 -80.065793
# 5  RX-11024057        N          Y  26.321745 -80.075232
# 6  RX-10959380        N          Y  26.926899 -80.155641
# 7  RX-11044736        N          Y  26.924386 -80.092082
# 8    A11697582        N          Y  26.334070 -80.157913
# 9  RX-11014143        N          Y  26.414444 -80.126160
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Marisela Cotilla
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...   Michelle Newman
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...    Crystal Condit
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...      Gregory Lynn
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...     Allison Moore
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...     Paul Stockall
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...         Edy Pyles
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...   Michael Ledwitz
#
#                list_broker_name_1 list_agent_name_2  \
# 0     Jupiter Ocean Grande Realty              None
# 1  Pineapple Realty Advisores LLC              None
# 2                  Lang Realty/BR              None
# 3              The Corcoran Group              None
# 4  Waterfront Properties & Club C              None
# 5               Lynn Realty Group       Charli Lynn
# 6          Coldwell Banker Realty              None
# 7             Compass Florida LLC  Diane Hutchinson
# 8             Casalina Realty Inc              None
# 9      Engel & Volkers Boca Raton     Wendy Ledwitz
#
#            list_broker_name_2      buy_agent_name_1  \
# 0                        None        Dianna Shpritz
# 1                        None  Rachelle Hirt-Beresh
# 2                        None           Ana Londono
# 3                        None       Michelle Newman
# 4                        None       Ashley Barbaree
# 5           Lynn Realty Group         Cavan Dettman
# 6                        None          Margot Matot
# 7         Compass Florida LLC         Paul Stockall
# 8                        None                  None
# 9  Engel & Volkers Boca Raton             Joy Wayne
#
#                   buy_broker_name_1  buy_agent_name_2    buy_broker_name_2  \
# 0  Leibowitz Realty Group, LLC./PBG              None                 None
# 1               Compass Florida LLC       Scott Gerow  Compass Florida LLC
# 2                    Lang Realty/BR              None                 None
# 3                The Corcoran Group              None                 None
# 4               Sutter & Nugent LLC              None                 None
# 5             Compass Florida, LLC.              None                 None
# 6     Platinum Properties/The Keyes              None                 None
# 7               Compass Florida LLC  Diane Hutchinson  Compass Florida LLC
# 8                              None              None                 None
# 9         Linda A. Gary Real Estate              None                 None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Jupiter Ocean Grande 4 Condo at 230 Ocean Gran...
# 1     2    blue  Mizner Court Condo at 140 SE 5th Ave #250 in B...
# 2     3    blue  Chalfonte Condo at 550 S Ocean Blvd #1006 in B...
# 3     4    blue  Little Pond Park Residences Condo at 6 Little ...
# 4     5    blue  Juno Bay Colony at 424 Bay Colony Dr N in Juno...
# 5     6    blue  Three Thousand South at 3000 S Ocean Blvd #405...
# 6     7    blue  Jupiter Country Club Condo Iii at 242 Tresana ...
# 7     8    blue  West Bay AT Jonathans Landing Condo at 3940 Ba...
# 8     9    blue  PROMENADE AT BOCA POINTE at 7233 Promenade Dr ...
# 9    10    blue  Catalina / Polo Club at 5214 Lake Catalina Dr ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Jupiter Ocean Grande 4 Condo closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $720,000 to $1,650,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Jupiter, Manalapan, Juno Beach, Boca Raton
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 64 condo sales totaling $25,803,620 million from Jan. 19th to Jan. 26th. The previous week, brokers closed 81 condo sales totaling $61,300,000.
#
# Last week’s units sold for an average of $403,182, lower than the $65,700,000 average price from the previous week. The average price per square foot fell to $299 from $397, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $720,000.0 million to $1,650,000.0 million.
#
# Jupiter Ocean Grande 4 Condo at 230 Ocean Grande Blvd #801 in Jupiter took the top spot with a $1,650,000.0 million closing. The sale closed at $663.0 per square foot.
#
# Michael Montalto with Jupiter Ocean Grande Realty, and None with None had the listing.
# Dianna Shpritz with Leibowitz Realty Group, LLC./PBG, and None with None represented the buyer.
#
# Mizner Court Condo at 140 SE 5th Ave #250 in Boca Raton, closed for the second highest amount, $1,510,000.0, or $926.0 per square foot.
#
# Marisela Cotilla with Pineapple Realty Advisores LLC, and None with None had the listing.
# Rachelle Hirt-Beresh with Compass Florida LLC, and Scott Gerow with Compass Florida LLC represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_01272024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Jan. 19th to Jan. 26th:
#
# Most Expensive
# Jupiter Ocean Grande 4 Condo, 230 Ocean Grande Blvd #801, in Jupiter | Price: $1,650,000 | $663 psf | Listing agents: Michael Montalto with Jupiter Ocean Grande Realty and None with None | Buyer's agents: Dianna Shpritz with Leibowitz Realty Group, LLC./PBG and None with None
#
# Least Expensive
# Catalina / Polo Club, 5214 Lake Catalina Dr N Unit C, in Boca Raton | Price: $720,000 | $396 psf | Listing agents: Michael Ledwitz with Engel & Volkers Boca Raton and Wendy Ledwitz with Engel & Volkers Boca Raton | Buyer's agents: Joy Wayne with Linda A. Gary Real Estate and None with None
#
# Highest Price Per Square Foot
# Chalfonte Condo, 550 S Ocean Blvd #1006, in Boca Raton | Price: $1,450,000 | $1,001 psf | Listing agents: Ana Londono with Lang Realty/BR and None with None | Buyer's agents: Ana Londono with Lang Realty/BR and None with None
#
# Lowest Price Per Square Foot
# PROMENADE AT BOCA POINTE, 7233 Promenade Dr #701, in Boca Raton | Price: $745,000 | $235 psf | Listing agents: Edy Pyles with Casalina Realty Inc and None with None | Buyer's agents: None with None and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Jupiter/230-Ocean-Grande-Blvd-33477/unit-801/home/172815762
# Second priciest sale:  https://www.redfin.com/FL/Boca-Raton/140-SE-5th-Ave-33432/unit-250/home/42331175
# Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/5214-Lake-Catalina-Dr-N-33496/unit-C/home/42237730
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/7233-Promenade-Dr-33433/unit-701/home/42269547
# Highest top ten psf:  https://www.redfin.com/FL/Boca-Raton/550-S-Ocean-Blvd-33432/unit-1006/home/42326365
# Lowest top ten psf:  https://www.redfin.com/FL/Boca-Raton/7233-Promenade-Dr-33433/unit-701/home/42269547

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Jupiter/230-Ocean-Grande-Blvd-33477/unit-801/home/172815762

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/140-SE-5th-Ave-33432/unit-250/home/42331175

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/5214-Lake-Catalina-Dr-N-33496/unit-C/home/42237730

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/7233-Promenade-Dr-33433/unit-701/home/42269547

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/550-S-Ocean-Blvd-33432/unit-1006/home/42326365

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/7233-Promenade-Dr-33433/unit-701/home/42269547

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2025-01-21   Condo/Co-op      230 Ocean Grande Blvd #801
# 1  PAST SALE 2025-01-24   Condo/Co-op             140 SE 5th Ave #250
# 2  PAST SALE 2025-01-24   Condo/Co-op          550 S Ocean Blvd #1006
# 3  PAST SALE 2025-01-21   Condo/Co-op                6 Little Pond Rd
# 4  PAST SALE 2025-01-24   Condo/Co-op             424 Bay Colony Dr N
# 5  PAST SALE 2025-01-24   Condo/Co-op          3000 S Ocean Blvd #405
# 6  PAST SALE 2025-01-24   Condo/Co-op            242 Tresana Blvd #74
# 7  PAST SALE 2025-01-23   Condo/Co-op       3940 Back Bay 241 Dr #241
# 8  PAST SALE 2025-01-24   Condo/Co-op          7233 Promenade Dr #701
# 9  PAST SALE 2025-01-21   Condo/Co-op  5214 Lake Catalina Dr N Unit C
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0     Jupiter                FL             33477.0  1650000.0   3.0    3.5
# 1  Boca Raton                FL             33432.0  1510000.0   2.0    2.0
# 2  Boca Raton                FL             33432.0  1450000.0   2.0    2.0
# 3   Manalapan                FL             33462.0  1220000.0   2.0    2.0
# 4  Juno Beach                FL             33408.0  1200000.0   3.0    2.5
# 5  Boca Raton                FL             33432.0  1007500.0   2.0    2.0
# 6     Jupiter                FL             33478.0   885000.0   3.0    2.5
# 7     Jupiter                FL             33477.0   835000.0   3.0    2.0
# 8  Boca Raton                FL             33433.0   745000.0   3.0    2.5
# 9  Boca Raton                FL             33496.0   720000.0   3.0    2.0
#
#                               LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0         Jupiter Ocean Grande 4 Condo       2490.0       NaN      2003.0
# 1                   Mizner Court Condo       1630.0       NaN      1988.0
# 2                      Chalfonte Condo       1448.0       NaN      1974.0
# 3    Little Pond Park Residences Condo       1500.0       NaN      1977.0
# 4                      Juno Bay Colony       1839.0       NaN      2014.0
# 5                 Three Thousand South       1382.0       NaN      1970.0
# 6       Jupiter Country Club Condo Iii       2293.0       NaN      2019.0
# 7  West Bay AT Jonathans Landing Condo       1839.0       NaN      1990.0
# 8             PROMENADE AT BOCA POINTE       3165.0       NaN      1986.0
# 9                 Catalina / Polo Club       1819.0       NaN      1989.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          663.0     2033.0   Sold
# 1             NaN          926.0     2747.0   Sold
# 2             NaN         1001.0     1569.0   Sold
# 3             NaN          813.0     1358.0   Sold
# 4             NaN          653.0     1557.0   Sold
# 5             NaN          729.0     2211.0   Sold
# 6             NaN          386.0     1314.0   Sold
# 7             NaN          454.0     1458.0   Sold
# 8             NaN          235.0     1417.0   Sold
# 9             NaN          396.0      550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...  Beaches MLS
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...  Beaches MLS
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...       MARMLS
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11028563        N          Y  26.918407 -80.066545
# 1  RX-11050978        N          Y  26.348269 -80.076619
# 2  RX-11031947        N          Y  26.344431 -80.070692
# 3  RX-10948720        N          Y  26.570376 -80.043908
# 4  RX-11034043        N          Y  26.860900 -80.065793
# 5  RX-11024057        N          Y  26.321745 -80.075232
# 6  RX-10959380        N          Y  26.926899 -80.155641
# 7  RX-11044736        N          Y  26.924386 -80.092082
# 8    A11697582        N          Y  26.334070 -80.157913
# 9  RX-11014143        N          Y  26.414444 -80.126160
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Jupiter/230-Ocean-Gr...  Michael Montalto
# 1  https://www.redfin.com/FL/Boca-Raton/140-SE-5t...  Marisela Cotilla
# 2  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 3  https://www.redfin.com/FL/Lantana/6-Little-Pon...   Michelle Newman
# 4  https://www.redfin.com/FL/Juno-Beach/424-Bay-C...    Crystal Condit
# 5  https://www.redfin.com/FL/Boca-Raton/3000-S-Oc...      Gregory Lynn
# 6  https://www.redfin.com/FL/Jupiter/242-Tresana-...     Allison Moore
# 7  https://www.redfin.com/FL/Jupiter/3940-Back-Ba...     Paul Stockall
# 8  https://www.redfin.com/FL/Boca-Raton/7233-Prom...         Edy Pyles
# 9  https://www.redfin.com/FL/Boca-Raton/5214-Lake...   Michael Ledwitz
#
#                list_broker_name_1 list_agent_name_2  \
# 0     Jupiter Ocean Grande Realty              None
# 1  Pineapple Realty Advisores LLC              None
# 2                  Lang Realty/BR              None
# 3              The Corcoran Group              None
# 4  Waterfront Properties & Club C              None
# 5               Lynn Realty Group       Charli Lynn
# 6          Coldwell Banker Realty              None
# 7             Compass Florida LLC  Diane Hutchinson
# 8             Casalina Realty Inc              None
# 9      Engel & Volkers Boca Raton     Wendy Ledwitz
#
#            list_broker_name_2      buy_agent_name_1  \
# 0                        None        Dianna Shpritz
# 1                        None  Rachelle Hirt-Beresh
# 2                        None           Ana Londono
# 3                        None       Michelle Newman
# 4                        None       Ashley Barbaree
# 5           Lynn Realty Group         Cavan Dettman
# 6                        None          Margot Matot
# 7         Compass Florida LLC         Paul Stockall
# 8                        None                  None
# 9  Engel & Volkers Boca Raton             Joy Wayne
#
#                   buy_broker_name_1  buy_agent_name_2    buy_broker_name_2  \
# 0  Leibowitz Realty Group, LLC./PBG              None                 None
# 1               Compass Florida LLC       Scott Gerow  Compass Florida LLC
# 2                    Lang Realty/BR              None                 None
# 3                The Corcoran Group              None                 None
# 4               Sutter & Nugent LLC              None                 None
# 5             Compass Florida, LLC.              None                 None
# 6     Platinum Properties/The Keyes              None                 None
# 7               Compass Florida LLC  Diane Hutchinson  Compass Florida LLC
# 8                              None              None                 None
# 9         Linda A. Gary Real Estate              None                 None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Jupiter Ocean Grande 4 Condo at 230 Ocean Gran...
# 1     2    blue  Mizner Court Condo at 140 SE 5th Ave #250 in B...
# 2     3    blue  Chalfonte Condo at 550 S Ocean Blvd #1006 in B...
# 3     4    blue  Little Pond Park Residences Condo at 6 Little ...
# 4     5    blue  Juno Bay Colony at 424 Bay Colony Dr N in Juno...
# 5     6    blue  Three Thousand South at 3000 S Ocean Blvd #405...
# 6     7    blue  Jupiter Country Club Condo Iii at 242 Tresana ...
# 7     8    blue  West Bay AT Jonathans Landing Condo at 3940 Ba...
# 8     9    blue  PROMENADE AT BOCA POINTE at 7233 Promenade Dr ...
# 9    10    blue  Catalina / Polo Club at 5214 Lake Catalina Dr ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 10, 15) ## List (Earlier) date
date2 = datetime(2025, 1, 21) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 98

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0     663.0
# 1     926.0
# 2    1001.0
# 3     813.0
# 4     653.0
# 5     729.0
# 6     386.0
# 7     454.0
# 8     235.0
# 9     396.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                       ADDRESS       PRICE BEDS  \
# 0 2025-01-21         230 Ocean Grande Blvd #801 in Jupiter  $1,650,000    3
# 1 2025-01-24             140 SE 5th Ave #250 in Boca Raton  $1,510,000    2
# 2 2025-01-24          550 S Ocean Blvd #1006 in Boca Raton  $1,450,000    2
# 3 2025-01-21                 6 Little Pond Rd in Manalapan  $1,220,000    2
# 4 2025-01-24             424 Bay Colony Dr N in Juno Beach  $1,200,000    3
# 5 2025-01-24          3000 S Ocean Blvd #405 in Boca Raton  $1,007,500    2
# 6 2025-01-24               242 Tresana Blvd #74 in Jupiter    $885,000    3
# 7 2025-01-23          3940 Back Bay 241 Dr #241 in Jupiter    $835,000    3
# 8 2025-01-24          7233 Promenade Dr #701 in Boca Raton    $745,000    3
# 9 2025-01-21  5214 Lake Catalina Dr N Unit C in Boca Raton    $720,000    3
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3.5       2,490       2003          $663  Beaches MLS  RX-11028563
# 1    2.0       1,630       1988          $926  Beaches MLS  RX-11050978
# 2    2.0       1,448       1974        $1,001  Beaches MLS  RX-11031947
# 3    2.0       1,500       1977          $813  Beaches MLS  RX-10948720
# 4    2.5       1,839       2014          $653  Beaches MLS  RX-11034043
# 5    2.0       1,382       1970          $729  Beaches MLS  RX-11024057
# 6    2.5       2,293       2019          $386  Beaches MLS  RX-10959380
# 7    2.0       1,839       1990          $454  Beaches MLS  RX-11044736
# 8    2.5       3,165       1986          $235       MARMLS    A11697582
# 9    2.0       1,819       1989          $396  Beaches MLS  RX-11014143
#
#                                         LISTING INFO  \
# 0   Michael Montalto Jupiter Ocean Grande Realty
# 1  Marisela Cotilla Pineapple Realty Advisores LL...
# 2                     Ana Londono Lang Realty/BR
# 3             Michelle Newman The Corcoran Group
# 4  Crystal Condit Waterfront Properties & Club C
# 5  Gregory Lynn Lynn Realty Group Charli Lynn Lyn...
# 6           Allison Moore Coldwell Banker Realty
# 7  Paul Stockall Compass Florida LLC Diane Hutchi...
# 8                  Edy Pyles Casalina Realty Inc
# 9  Michael Ledwitz Engel & Volkers Boca Raton Wen...
#
#                                          BUYING INFO
# 0  Dianna Shpritz Leibowitz Realty Group, LLC./PB...
# 1  Rachelle Hirt-Beresh Compass Florida LLC Scott...
# 2                     Ana Londono Lang Realty/BR
# 3             Michelle Newman The Corcoran Group
# 4            Ashley Barbaree Sutter & Nugent LLC
# 5            Cavan Dettman Compass Florida, LLC.
# 6     Margot Matot Platinum Properties/The Keyes
# 7  Paul Stockall Compass Florida LLC Diane Hutchi...
# 8
# 9            Joy Wayne Linda A. Gary Real Estate
