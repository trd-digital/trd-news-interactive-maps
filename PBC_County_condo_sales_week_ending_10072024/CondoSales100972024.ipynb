# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Sep. 29th Oct. 6th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE          SOLD DATE PROPERTY TYPE  \
# 1  PAST SALE  September-30-2024   Condo/Co-op
#
#                            ADDRESS             CITY STATE OR PROVINCE  \
# 1  550 Okeechobee Blvd Unit Uph-02  West Palm Beach                FL
#
#    ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 1             33401.0  1976500.0   3.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-10994622         N          Y  26.705124 -80.056199
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 52   PAST SALE 2024-10-04   Condo/Co-op     201 S Narcissus Ave #1502
# 19   PAST SALE 2024-10-04   Condo/Co-op        2860 S Ocean Blvd #103
# 122  PAST SALE 2024-10-04   Condo/Co-op      12 Colonial Club Dr #105
# 63   PAST SALE 2024-10-04   Condo/Co-op    1291 NW 13th St Unit 450-D
# 55   PAST SALE 2024-10-04   Condo/Co-op        2309 S Federal Hwy #17
# ..         ...        ...           ...                           ...
# 59   PAST SALE 2024-09-30   Condo/Co-op              8862 Windtree St
# 54   PAST SALE 2024-09-30   Condo/Co-op       2868 Ashley Dr E Unit E
# 53   PAST SALE 2024-09-30   Condo/Co-op           9233 SW 8th St #122
# 49   PAST SALE 2024-09-30   Condo/Co-op  4704 Lucerne Lakes Blvd #105
# 123  PAST SALE 2024-09-30   Condo/Co-op     6875 Willow Wood Dr #2012
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 52   West Palm Beach                FL             33401.0  2980000.0   2.0
# 19        Palm Beach                FL             33480.0   583135.0   1.0
# 122    Boynton Beach                FL             33435.0   272000.0   2.0
# 63        Boca Raton                FL             33486.0   275000.0   2.0
# 55     Boynton Beach                FL             33435.0   143000.0   1.0
# ..               ...               ...                 ...        ...   ...
# 59        Boca Raton                FL             33496.0   267000.0   2.0
# 54   West Palm Beach                FL             33415.0   183000.0   2.0
# 53        Boca Raton                FL             33428.0   188000.0   2.0
# 49        Lake Worth                FL             33467.0   257500.0   2.0
# 123       Boca Raton                FL             33434.0   200000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 52     3.0  ...   Sold                         NaN                       NaN
# 19     1.5  ...   Sold                         NaN                       NaN
# 122    2.0  ...   Sold                         NaN                       NaN
# 63     2.0  ...   Sold                         NaN                       NaN
# 55     1.0  ...   Sold                         NaN                       NaN
# ..     ...  ...    ...                         ...                       ...
# 59     2.0  ...   Sold                         NaN                       NaN
# 54     2.0  ...   Sold                         NaN                       NaN
# 53     2.0  ...   Sold                         NaN                       NaN
# 49     2.0  ...   Sold                         NaN                       NaN
# 123    2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 52   https://www.redfin.com/FL/West-Palm-Beach/201-...  Beaches MLS
# 19   https://www.redfin.com/FL/Palm-Beach/2860-S-Oc...  Beaches MLS
# 122  https://www.redfin.com/FL/Boynton-Beach/12-Col...  Beaches MLS
# 63   https://www.redfin.com/FL/Boca-Raton/1291-NW-1...  Beaches MLS
# 55   https://www.redfin.com/FL/Boynton-Beach/2309-S...       MARMLS
# ..                                                 ...          ...
# 59   https://www.redfin.com/FL/Boca-Raton/8862-Wind...  Beaches MLS
# 54   https://www.redfin.com/FL/West-Palm-Beach/2868...  Beaches MLS
# 53   https://www.redfin.com/FL/Boca-Raton/9233-SW-8...  Beaches MLS
# 49   https://www.redfin.com/FL/Lake-Worth/4704-Luce...  Beaches MLS
# 123  https://www.redfin.com/FL/Boca-Raton/6875-Will...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 52   RX-10996022         N          Y  26.711982 -80.051026
# 19   RX-11020193         N          Y  26.616651 -80.039614
# 122  RX-10918007         N          Y  26.502392 -80.059506
# 63     F10449771         N          Y  26.362029 -80.112435
# 55     A11627445         N          Y  26.508272 -80.060151
# ..           ...       ...        ...        ...        ...
# 59   RX-11005190         N          Y  26.401138 -80.178858
# 54   RX-11008154         N          Y  26.635326 -80.117675
# 53   RX-10998614         N          Y  26.339363 -80.190776
# 49   RX-11002761         N          Y  26.604079 -80.156920
# 123  RX-10910416         N          Y  26.375667 -80.150429
#
# [123 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 123

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $444,746

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $291

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $54,703,750

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Palm Beach County
# Input Previous Week Condo Sales Total (number units sold):
# 93
# Input Previous Week Condo Average Sales Price:
# 497032
# Input Previous Week Condo Average PSF:
# 289
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 45_900_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  2720 Donald Ross Rd #507
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  Azure Condo       3282.0       NaN      2018.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1248.0     3330.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...   Cristine Tamasi
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Illustrated Properties LLC (Co              None               None
#
#   buy_agent_name_1    buy_broker_name_1  buy_agent_name_2  \
# 0       Dory Faxon  Compass Florida LLC  Geraldine Stanko
#
#      buy_broker_name_2  RANK   COLOR
# 0  Compass Florida LLC     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op          2720 Donald Ross Rd #507
# 1  PAST SALE 2024-09-30   Condo/Co-op         350 S Ocean Blvd Unit 11d
# 2  PAST SALE 2024-09-30   Condo/Co-op       3170 S Ocean Blvd Unit S405
# 3  PAST SALE 2024-10-04   Condo/Co-op         201 S Narcissus Ave #1502
# 4  PAST SALE 2024-10-01   Condo/Co-op  1177 George Bush Blvd Unit 308 A
# 5  PAST SALE 2024-09-30   Condo/Co-op   550 Okeechobee Blvd Unit Uph-02
# 6  PAST SALE 2024-09-30   Condo/Co-op               110 Gleason St #202
# 7  PAST SALE 2024-09-30   Condo/Co-op         750 Ocean Royale Way #302
# 8  PAST SALE 2024-10-01   Condo/Co-op         525 S Flagler Dr Unit 19C
# 9  PAST SALE 2024-10-01   Condo/Co-op       4161 S Us Highway 1 Unit M4
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
# 1          Boca Raton                FL             33432.0  3300000.0   3.0
# 2          Palm Beach                FL             33480.0  3200000.0   3.0
# 3     West Palm Beach                FL             33401.0  2980000.0   2.0
# 4        Delray Beach                FL             33483.0  2620000.0   3.0
# 5     West Palm Beach                FL             33401.0  1976500.0   3.0
# 6        Delray Beach                FL             33483.0  1837500.0   4.0
# 7          Juno Beach                FL             33408.0  1700000.0   3.0
# 8     West Palm Beach                FL             33401.0  1372500.0   2.0
# 9             Jupiter                FL             33477.0  1360000.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  Azure Condo       3282.0       NaN      2018.0
# 1    3.0               Beresford Cond       2523.0       NaN      1977.0
# 2    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 3    3.0       Esplanade Grande Condo       2434.0       NaN      2004.0
# 4    3.5                 1177 Moderne       1978.0       NaN      2024.0
# 5    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 6    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 7    3.0           Ocean Royale Condo       2643.0       NaN      2000.0
# 8    2.0    Plaza Of The Palm Beaches       1927.0       NaN      1986.0
# 9    2.0            Beachcomber Condo       1450.0       NaN      1984.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1248.0     3330.0   Sold
# 1             NaN         1308.0     4279.0   Sold
# 2             NaN         1085.0     3687.0   Sold
# 3             NaN         1224.0     2381.0   Sold
# 4             NaN         1325.0     2571.0   Sold
# 5             NaN         1231.0     1706.0   Sold
# 6             NaN          873.0     2229.0   Sold
# 7             NaN          643.0     2900.0   Sold
# 8             NaN          712.0     2694.0   Sold
# 9             NaN          938.0     1234.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...  Beaches MLS
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
# 1  RX-10986927        N          Y  26.347232 -80.070218
# 2  RX-10913354        N          Y  26.605363 -80.037760
# 3  RX-10996022        N          Y  26.711982 -80.051026
# 4  RX-11015041        N          Y  26.474566 -80.059896
# 5  RX-10994622        N          Y  26.705124 -80.056199
# 6  RX-11008404        N          Y  26.459182 -80.061011
# 7  RX-10975016        N          Y  26.891689 -80.058145
# 8    F10425335        N          Y  26.708413 -80.051135
# 9  RX-11014994        N          Y  26.894166 -80.058991
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...        Cristine Tamasi
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...           Erin Omiatek
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...           Leslie Judge
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Steffanie Ngo-Hatchie
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...    Julie Ann Giachetti
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...        Jonathan Huffer
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...          Judith Lukens
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...                   None
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...           Gayle Borden
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...          Gayle Krueger
#
#                    list_broker_name_1 list_agent_name_2  \
# 0      Illustrated Properties LLC (Co              None
# 1  One Sotheby's International Realty              None
# 2              Illustrated Properties              None
# 3             United Realty Group Inc              None
# 4  One Sotheby's International Realty              None
# 5                  Redfin Corporation       Elena Fleck
# 6      Premier Estate Properties, Inc         Kim Lekas
# 7                                None              None
# 8              Coldwell Banker Realty    Kenneth Borden
# 9                All Water Realty LLC       David Baker
#
#                list_broker_name_2      buy_agent_name_1  \
# 0                            None            Dory Faxon
# 1                            None          Senada Adzem
# 2                            None            Nina Grody
# 3                            None      Miguel Rodriguez
# 4                            None      Mary Beth Windle
# 5              Redfin Corporation      Andrew Leibowitz
# 6  Premier Estate Properties, Inc        Patricia Burke
# 7                            None                  None
# 8          Coldwell Banker Realty  Non-member Mls Agent
# 9            All Water Realty LLC  Christopher LoPresti
#
#                       buy_broker_name_1   buy_agent_name_2  \
# 0                   Compass Florida LLC   Geraldine Stanko
# 1                       Douglas Elliman               None
# 2          William Raveis South Florida               None
# 3              Compass Florida LLC (PB)               None
# 4                       Douglas Elliman     Caron Dockerty
# 5      Leibowitz Realty Group, LLC./PBG  Michael Leibowitz
# 6    One Sotheby's International Realty               None
# 7                                  None               None
# 8                        NON MEMBER MLS               None
# 9  Illustrated Properties LLC (Jupiter)               None
#
#                   buy_broker_name_2  RANK   COLOR
# 0               Compass Florida LLC     1  orange
# 1                              None     2    blue
# 2                              None     3    blue
# 3                              None     4    blue
# 4                   Douglas Elliman     5    blue
# 5  Leibowitz Realty Group, LLC./PBG     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db09ca5ed716063cb999f899b3514539 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Sep. 29th - Oct. 6th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db09ca5ed716063cb999f899b3514539&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_db09ca5ed716063cb999f899b3514539 = L.map(
#                 &quot;map_db09ca5ed716063cb999f899b3514539&quot;,
#                 {
#                     center: [26.580632210569107, -80.1161652195122],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_d54193a2acb7b7874c2d5288b1811a13 = L.featureGroup(
#                 {}
#             ).addTo(map_db09ca5ed716063cb999f899b3514539);
#
#
#             var marker_2808ce928572fc77616e0094bad8e1e0 = L.marker(
#                 [26.8810721, -80.0738652],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_d54193a2acb7b7874c2d5288b1811a13);
#
#
#             var icon_6840ecae212fc585b9fb5394c5829f3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2808ce928572fc77616e0094bad8e1e0.setIcon(icon_6840ecae212fc585b9fb5394c5829f3e);
#
#
#         var popup_4c7fac8a7ae5939dca027d4cef0abfb1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_783c178f4c7d3baf69db47e8f229610e = $(`&lt;div id=&quot;html_783c178f4c7d3baf69db47e8f229610e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2720 Donald Ross Rd #507&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,095,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,248.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,282.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_4c7fac8a7ae5939dca027d4cef0abfb1.setContent(html_783c178f4c7d3baf69db47e8f229610e);
#
#
#
#         marker_2808ce928572fc77616e0094bad8e1e0.bindPopup(popup_4c7fac8a7ae5939dca027d4cef0abfb1)
#         ;
#
#
#
#
#             var feature_group_c50bfb9bf594e293443dbdb3212a625d = L.featureGroup(
#                 {}
#             ).addTo(map_db09ca5ed716063cb999f899b3514539);
#
#
#             var marker_612a8c6587c5f9189693ed7bc6a37836 = L.marker(
#                 [26.347232, -80.0702184],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c50bfb9bf594e293443dbdb3212a625d);
#
#
#             var icon_f582ca067074d9e5e56c3337125e6e85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_612a8c6587c5f9189693ed7bc6a37836.setIcon(icon_f582ca067074d9e5e56c3337125e6e85);
#
#
#         var popup_2fcdd2bbbb3e3a7963a231228e1d2568 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_dc2dc9ed6c9d24510f4d46bec96a203c = $(`&lt;div id=&quot;html_dc2dc9ed6c9d24510f4d46bec96a203c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;350 S Ocean Blvd Unit 11d&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,300,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,308.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,523.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1977.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_2fcdd2bbbb3e3a7963a231228e1d2568.setContent(html_dc2dc9ed6c9d24510f4d46bec96a203c);
#
#
#
#         marker_612a8c6587c5f9189693ed7bc6a37836.bindPopup(popup_2fcdd2bbbb3e3a7963a231228e1d2568)
#         ;
#
#
#
#
#             var marker_aee98a9061fe66d9d2ad554b18bd21d9 = L.marker(
#                 [26.6053629, -80.0377601],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c50bfb9bf594e293443dbdb3212a625d);
#
#
#             var icon_3cf31cf40595c59c5955f86da926110f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aee98a9061fe66d9d2ad554b18bd21d9.setIcon(icon_3cf31cf40595c59c5955f86da926110f);
#
#
#         var popup_f9784e315cad7279c3acb008d9e563d9 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f10f694012f26e35eb14c1071db7d75c = $(`

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  2720 Donald Ross Rd #507
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  Azure Condo       3282.0       NaN      2018.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1248.0     3330.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...   Cristine Tamasi
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Illustrated Properties LLC (Co              None               None
#
#   buy_agent_name_1    buy_broker_name_1  buy_agent_name_2  \
# 0       Dory Faxon  Compass Florida LLC  Geraldine Stanko
#
#      buy_broker_name_2  RANK   COLOR
# 0  Compass Florida LLC     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_10072024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Azure Condo at 2720 Donald Ross Rd #507 in Palm Beach Gardens'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op          2720 Donald Ross Rd #507
# 1  PAST SALE 2024-09-30   Condo/Co-op         350 S Ocean Blvd Unit 11d
# 2  PAST SALE 2024-09-30   Condo/Co-op       3170 S Ocean Blvd Unit S405
# 3  PAST SALE 2024-10-04   Condo/Co-op         201 S Narcissus Ave #1502
# 4  PAST SALE 2024-10-01   Condo/Co-op  1177 George Bush Blvd Unit 308 A
# 5  PAST SALE 2024-09-30   Condo/Co-op   550 Okeechobee Blvd Unit Uph-02
# 6  PAST SALE 2024-09-30   Condo/Co-op               110 Gleason St #202
# 7  PAST SALE 2024-09-30   Condo/Co-op         750 Ocean Royale Way #302
# 8  PAST SALE 2024-10-01   Condo/Co-op         525 S Flagler Dr Unit 19C
# 9  PAST SALE 2024-10-01   Condo/Co-op       4161 S Us Highway 1 Unit M4
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
# 1          Boca Raton                FL             33432.0  3300000.0   3.0
# 2          Palm Beach                FL             33480.0  3200000.0   3.0
# 3     West Palm Beach                FL             33401.0  2980000.0   2.0
# 4        Delray Beach                FL             33483.0  2620000.0   3.0
# 5     West Palm Beach                FL             33401.0  1976500.0   3.0
# 6        Delray Beach                FL             33483.0  1837500.0   4.0
# 7          Juno Beach                FL             33408.0  1700000.0   3.0
# 8     West Palm Beach                FL             33401.0  1372500.0   2.0
# 9             Jupiter                FL             33477.0  1360000.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  Azure Condo       3282.0       NaN      2018.0
# 1    3.0               Beresford Cond       2523.0       NaN      1977.0
# 2    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 3    3.0       Esplanade Grande Condo       2434.0       NaN      2004.0
# 4    3.5                 1177 Moderne       1978.0       NaN      2024.0
# 5    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 6    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 7    3.0           Ocean Royale Condo       2643.0       NaN      2000.0
# 8    2.0    Plaza Of The Palm Beaches       1927.0       NaN      1986.0
# 9    2.0            Beachcomber Condo       1450.0       NaN      1984.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1248.0     3330.0   Sold
# 1             NaN         1308.0     4279.0   Sold
# 2             NaN         1085.0     3687.0   Sold
# 3             NaN         1224.0     2381.0   Sold
# 4             NaN         1325.0     2571.0   Sold
# 5             NaN         1231.0     1706.0   Sold
# 6             NaN          873.0     2229.0   Sold
# 7             NaN          643.0     2900.0   Sold
# 8             NaN          712.0     2694.0   Sold
# 9             NaN          938.0     1234.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...  Beaches MLS
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
# 1  RX-10986927        N          Y  26.347232 -80.070218
# 2  RX-10913354        N          Y  26.605363 -80.037760
# 3  RX-10996022        N          Y  26.711982 -80.051026
# 4  RX-11015041        N          Y  26.474566 -80.059896
# 5  RX-10994622        N          Y  26.705124 -80.056199
# 6  RX-11008404        N          Y  26.459182 -80.061011
# 7  RX-10975016        N          Y  26.891689 -80.058145
# 8    F10425335        N          Y  26.708413 -80.051135
# 9  RX-11014994        N          Y  26.894166 -80.058991
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...        Cristine Tamasi
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...           Erin Omiatek
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...           Leslie Judge
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Steffanie Ngo-Hatchie
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...    Julie Ann Giachetti
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...        Jonathan Huffer
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...          Judith Lukens
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...                   None
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...           Gayle Borden
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...          Gayle Krueger
#
#                    list_broker_name_1 list_agent_name_2  \
# 0      Illustrated Properties LLC (Co              None
# 1  One Sotheby's International Realty              None
# 2              Illustrated Properties              None
# 3             United Realty Group Inc              None
# 4  One Sotheby's International Realty              None
# 5                  Redfin Corporation       Elena Fleck
# 6      Premier Estate Properties, Inc         Kim Lekas
# 7                                None              None
# 8              Coldwell Banker Realty    Kenneth Borden
# 9                All Water Realty LLC       David Baker
#
#                list_broker_name_2      buy_agent_name_1  \
# 0                            None            Dory Faxon
# 1                            None          Senada Adzem
# 2                            None            Nina Grody
# 3                            None      Miguel Rodriguez
# 4                            None      Mary Beth Windle
# 5              Redfin Corporation      Andrew Leibowitz
# 6  Premier Estate Properties, Inc        Patricia Burke
# 7                            None                  None
# 8          Coldwell Banker Realty  Non-member Mls Agent
# 9            All Water Realty LLC  Christopher LoPresti
#
#                       buy_broker_name_1   buy_agent_name_2  \
# 0                   Compass Florida LLC   Geraldine Stanko
# 1                       Douglas Elliman               None
# 2          William Raveis South Florida               None
# 3              Compass Florida LLC (PB)               None
# 4                       Douglas Elliman     Caron Dockerty
# 5      Leibowitz Realty Group, LLC./PBG  Michael Leibowitz
# 6    One Sotheby's International Realty               None
# 7                                  None               None
# 8                        NON MEMBER MLS               None
# 9  Illustrated Properties LLC (Jupiter)               None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0               Compass Florida LLC     1  orange
# 1                              None     2    blue
# 2                              None     3    blue
# 3                              None     4    blue
# 4                   Douglas Elliman     5    blue
# 5  Leibowitz Realty Group, LLC./PBG     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  Azure Condo at 2720 Donald Ross Rd #507 in Pal...
# 1  Beresford Cond at 350 S Ocean Blvd Unit 11d in...
# 2  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 3  Esplanade Grande Condo at 201 S Narcissus Ave ...
# 4  1177 Moderne at 1177 George Bush Blvd Unit 308...
# 5  Cityplace South Tower Condo at 550 Okeechobee ...
# 6  Bella Vista Condo at 110 Gleason St #202 in De...
# 7  Ocean Royale Condo at 750 Ocean Royale Way #30...
# 8  Plaza Of The Palm Beaches at 525 S Flagler Dr ...
# 9  Beachcomber Condo at 4161 S Us Highway 1 Unit ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Azure Condo closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,360,000M to $4,095,000M
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Palm Beach, Juno Beach, West Palm Beach, Delray Beach, Palm Beach Gardens, Jupiter, Boca Raton
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 123 condo sales totaling $54,703,750 million from Sep. 29th to Oct. 6th. The previous week, brokers closed 93 condo sales totaling $45,900,000.
#
# Last week’s units sold for an average of $444,746, lower than the $497,032 average price from the previous week. The average price per square foot rose to $291 from $289, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,360,000.0 million to $4,095,000.0 million.
#
# Azure Condo at 2720 Donald Ross Rd #507 in Palm Beach Gardens took the top spot with a $4,095,000.0 million closing. The sale closed at $1,248.0 per square foot.
#
# Cristine Tamasi with Illustrated Properties LLC (Co, and None with None had the listing.
# Dory Faxon with Compass Florida LLC, and Geraldine Stanko with Compass Florida LLC represented the buyer.
#
# Beresford Cond at 350 S Ocean Blvd Unit 11d in Boca Raton, closed for the second highest amount, $3,300,000.0, or $1,308.0 per square foot.
#
# Erin Omiatek with One Sotheby's International Realty, and None with None had the listing.
# Senada Adzem with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_10072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 29th to Oct. 6th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op          2720 Donald Ross Rd #507
# 1  PAST SALE 2024-09-30   Condo/Co-op         350 S Ocean Blvd Unit 11d
# 2  PAST SALE 2024-09-30   Condo/Co-op       3170 S Ocean Blvd Unit S405
# 3  PAST SALE 2024-10-04   Condo/Co-op         201 S Narcissus Ave #1502
# 4  PAST SALE 2024-10-01   Condo/Co-op  1177 George Bush Blvd Unit 308 A
# 5  PAST SALE 2024-09-30   Condo/Co-op   550 Okeechobee Blvd Unit Uph-02
# 6  PAST SALE 2024-09-30   Condo/Co-op               110 Gleason St #202
# 7  PAST SALE 2024-09-30   Condo/Co-op         750 Ocean Royale Way #302
# 8  PAST SALE 2024-10-01   Condo/Co-op         525 S Flagler Dr Unit 19C
# 9  PAST SALE 2024-10-01   Condo/Co-op       4161 S Us Highway 1 Unit M4
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
# 1          Boca Raton                FL             33432.0  3300000.0   3.0
# 2          Palm Beach                FL             33480.0  3200000.0   3.0
# 3     West Palm Beach                FL             33401.0  2980000.0   2.0
# 4        Delray Beach                FL             33483.0  2620000.0   3.0
# 5     West Palm Beach                FL             33401.0  1976500.0   3.0
# 6        Delray Beach                FL             33483.0  1837500.0   4.0
# 7          Juno Beach                FL             33408.0  1700000.0   3.0
# 8     West Palm Beach                FL             33401.0  1372500.0   2.0
# 9             Jupiter                FL             33477.0  1360000.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  Azure Condo       3282.0       NaN      2018.0
# 1    3.0               Beresford Cond       2523.0       NaN      1977.0
# 2    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 3    3.0       Esplanade Grande Condo       2434.0       NaN      2004.0
# 4    3.5                 1177 Moderne       1978.0       NaN      2024.0
# 5    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 6    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 7    3.0           Ocean Royale Condo       2643.0       NaN      2000.0
# 8    2.0    Plaza Of The Palm Beaches       1927.0       NaN      1986.0
# 9    2.0            Beachcomber Condo       1450.0       NaN      1984.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1248.0     3330.0   Sold
# 1             NaN         1308.0     4279.0   Sold
# 2             NaN         1085.0     3687.0   Sold
# 3             NaN         1224.0     2381.0   Sold
# 4             NaN         1325.0     2571.0   Sold
# 5             NaN         1231.0     1706.0   Sold
# 6             NaN          873.0     2229.0   Sold
# 7             NaN          643.0     2900.0   Sold
# 8             NaN          712.0     2694.0   Sold
# 9             NaN          938.0     1234.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...  Beaches MLS
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
# 1  RX-10986927        N          Y  26.347232 -80.070218
# 2  RX-10913354        N          Y  26.605363 -80.037760
# 3  RX-10996022        N          Y  26.711982 -80.051026
# 4  RX-11015041        N          Y  26.474566 -80.059896
# 5  RX-10994622        N          Y  26.705124 -80.056199
# 6  RX-11008404        N          Y  26.459182 -80.061011
# 7  RX-10975016        N          Y  26.891689 -80.058145
# 8    F10425335        N          Y  26.708413 -80.051135
# 9  RX-11014994        N          Y  26.894166 -80.058991
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...        Cristine Tamasi
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...           Erin Omiatek
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...           Leslie Judge
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Steffanie Ngo-Hatchie
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...    Julie Ann Giachetti
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...        Jonathan Huffer
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...          Judith Lukens
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...                   None
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...           Gayle Borden
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...          Gayle Krueger
#
#                    list_broker_name_1 list_agent_name_2  \
# 0      Illustrated Properties LLC (Co              None
# 1  One Sotheby's International Realty              None
# 2              Illustrated Properties              None
# 3             United Realty Group Inc              None
# 4  One Sotheby's International Realty              None
# 5                  Redfin Corporation       Elena Fleck
# 6      Premier Estate Properties, Inc         Kim Lekas
# 7                                None              None
# 8              Coldwell Banker Realty    Kenneth Borden
# 9                All Water Realty LLC       David Baker
#
#                list_broker_name_2      buy_agent_name_1  \
# 0                            None            Dory Faxon
# 1                            None          Senada Adzem
# 2                            None            Nina Grody
# 3                            None      Miguel Rodriguez
# 4                            None      Mary Beth Windle
# 5              Redfin Corporation      Andrew Leibowitz
# 6  Premier Estate Properties, Inc        Patricia Burke
# 7                            None                  None
# 8          Coldwell Banker Realty  Non-member Mls Agent
# 9            All Water Realty LLC  Christopher LoPresti
#
#                       buy_broker_name_1   buy_agent_name_2  \
# 0                   Compass Florida LLC   Geraldine Stanko
# 1                       Douglas Elliman               None
# 2          William Raveis South Florida               None
# 3              Compass Florida LLC (PB)               None
# 4                       Douglas Elliman     Caron Dockerty
# 5      Leibowitz Realty Group, LLC./PBG  Michael Leibowitz
# 6    One Sotheby's International Realty               None
# 7                                  None               None
# 8                        NON MEMBER MLS               None
# 9  Illustrated Properties LLC (Jupiter)               None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0               Compass Florida LLC     1  orange
# 1                              None     2    blue
# 2                              None     3    blue
# 3                              None     4    blue
# 4                   Douglas Elliman     5    blue
# 5  Leibowitz Realty Group, LLC./PBG     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  Azure Condo at 2720 Donald Ross Rd #507 in Pal...
# 1  Beresford Cond at 350 S Ocean Blvd Unit 11d in...
# 2  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 3  Esplanade Grande Condo at 201 S Narcissus Ave ...
# 4  1177 Moderne at 1177 George Bush Blvd Unit 308...
# 5  Cityplace South Tower Condo at 550 Okeechobee ...
# 6  Bella Vista Condo at 110 Gleason St #202 in De...
# 7  Ocean Royale Condo at 750 Ocean Royale Way #30...
# 8  Plaza Of The Palm Beaches at 525 S Flagler Dr ...
# 9  Beachcomber Condo at 4161 S Us Highway 1 Unit ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: Azure Condo closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,360,000M to $4,095,000M
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Palm Beach, Juno Beach, West Palm Beach, Delray Beach, Palm Beach Gardens, Jupiter, Boca Raton
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 123 condo sales totaling $54,703,750 million from Sep. 29th to Oct. 6th. The previous week, brokers closed 93 condo sales totaling $45,900,000.
#
# Last week’s units sold for an average of $444,746, lower than the $497,032 average price from the previous week. The average price per square foot rose to $291 from $289, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,360,000.0 million to $4,095,000.0 million.
#
# Azure Condo at 2720 Donald Ross Rd #507 in Palm Beach Gardens took the top spot with a $4,095,000.0 million closing. The sale closed at $1,248.0 per square foot.
#
# Cristine Tamasi with Illustrated Properties LLC (Co, and None with None had the listing.
# Dory Faxon with Compass Florida LLC, and Geraldine Stanko with Compass Florida LLC represented the buyer.
#
# Beresford Cond at 350 S Ocean Blvd Unit 11d in Boca Raton, closed for the second highest amount, $3,300,000.0, or $1,308.0 per square foot.
#
# Erin Omiatek with One Sotheby's International Realty, and None with None had the listing.
# Senada Adzem with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PBC_County_condo_sales_week_ending_10072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 29th to Oct. 6th:
#
# Most Expensive
# Azure Condo, 2720 Donald Ross Rd #507, in Palm Beach Gardens | Price: $4,095,000 | $1,248 psf | Listing agents: Cristine Tamasi with Illustrated Properties LLC (Co and None with None | Buyer's agents: Dory Faxon with Compass Florida LLC and Geraldine Stanko with Compass Florida LLC
# Least Expensive
# Beachcomber Condo, 4161 S Us Highway 1 Unit M4, in Jupiter | Price: $1,360,000 | $938 psf | Listing agents: Gayle Krueger with All Water Realty LLC and David Baker with All Water Realty LLC | Buyer's agents: Christopher LoPresti with Illustrated Properties LLC (Jupiter) and None with None
# Highest Price Per Square Foot
# 1177 Moderne, 1177 George Bush Blvd Unit 308 A, in Delray Beach | Price: $2,620,000 | $1,325 psf | Listing agents: Julie Ann Giachetti with One Sotheby's International Realty and None with None | Buyer's agents: Mary Beth Windle with Douglas Elliman and Caron Dockerty with Douglas Elliman
# Lowest Price Per Square Foot
# Ocean Royale Condo, 750 Ocean Royale Way #302, in Juno Beach | Price: $1,700,000 | $643 psf | Listing agents: None with None and None with None | Buyer's agents: None with None and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Palm-Beach-Gardens/2720-Donald-Ross-Rd-33410/unit-507/home/171497898

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/350-S-Ocean-Blvd-33432/unit-11d/home/190764723

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Jupiter/4161-S-US-Highway-1-33477/unit-M4/home/42411559

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/525-S-Flagler-Dr-33401/unit-19C/home/42519200

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Delray-Beach/1177-George-Bush-Blvd-33483/unit-308-A/home/189018580

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Juno-Beach/750-Ocean-Royale-Way-33408/unit-302/home/42548233

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op          2720 Donald Ross Rd #507
# 1  PAST SALE 2024-09-30   Condo/Co-op         350 S Ocean Blvd Unit 11d
# 2  PAST SALE 2024-09-30   Condo/Co-op       3170 S Ocean Blvd Unit S405
# 3  PAST SALE 2024-10-04   Condo/Co-op         201 S Narcissus Ave #1502
# 4  PAST SALE 2024-10-01   Condo/Co-op  1177 George Bush Blvd Unit 308 A
# 5  PAST SALE 2024-09-30   Condo/Co-op   550 Okeechobee Blvd Unit Uph-02
# 6  PAST SALE 2024-09-30   Condo/Co-op               110 Gleason St #202
# 7  PAST SALE 2024-09-30   Condo/Co-op         750 Ocean Royale Way #302
# 8  PAST SALE 2024-10-01   Condo/Co-op         525 S Flagler Dr Unit 19C
# 9  PAST SALE 2024-10-01   Condo/Co-op       4161 S Us Highway 1 Unit M4
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Palm Beach Gardens                FL             33410.0  4095000.0   3.0
# 1          Boca Raton                FL             33432.0  3300000.0   3.0
# 2          Palm Beach                FL             33480.0  3200000.0   3.0
# 3     West Palm Beach                FL             33401.0  2980000.0   2.0
# 4        Delray Beach                FL             33483.0  2620000.0   3.0
# 5     West Palm Beach                FL             33401.0  1976500.0   3.0
# 6        Delray Beach                FL             33483.0  1837500.0   4.0
# 7          Juno Beach                FL             33408.0  1700000.0   3.0
# 8     West Palm Beach                FL             33401.0  1372500.0   2.0
# 9             Jupiter                FL             33477.0  1360000.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  Azure Condo       3282.0       NaN      2018.0
# 1    3.0               Beresford Cond       2523.0       NaN      1977.0
# 2    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 3    3.0       Esplanade Grande Condo       2434.0       NaN      2004.0
# 4    3.5                 1177 Moderne       1978.0       NaN      2024.0
# 5    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 6    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 7    3.0           Ocean Royale Condo       2643.0       NaN      2000.0
# 8    2.0    Plaza Of The Palm Beaches       1927.0       NaN      1986.0
# 9    2.0            Beachcomber Condo       1450.0       NaN      1984.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1248.0     3330.0   Sold
# 1             NaN         1308.0     4279.0   Sold
# 2             NaN         1085.0     3687.0   Sold
# 3             NaN         1224.0     2381.0   Sold
# 4             NaN         1325.0     2571.0   Sold
# 5             NaN         1231.0     1706.0   Sold
# 6             NaN          873.0     2229.0   Sold
# 7             NaN          643.0     2900.0   Sold
# 8             NaN          712.0     2694.0   Sold
# 9             NaN          938.0     1234.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...  Beaches MLS
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10981251        N          Y  26.881072 -80.073865
# 1  RX-10986927        N          Y  26.347232 -80.070218
# 2  RX-10913354        N          Y  26.605363 -80.037760
# 3  RX-10996022        N          Y  26.711982 -80.051026
# 4  RX-11015041        N          Y  26.474566 -80.059896
# 5  RX-10994622        N          Y  26.705124 -80.056199
# 6  RX-11008404        N          Y  26.459182 -80.061011
# 7  RX-10975016        N          Y  26.891689 -80.058145
# 8    F10425335        N          Y  26.708413 -80.051135
# 9  RX-11014994        N          Y  26.894166 -80.058991
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach-Gardens/2...        Cristine Tamasi
# 1  https://www.redfin.com/FL/Boca-Raton/350-S-Oce...           Erin Omiatek
# 2  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...           Leslie Judge
# 3  https://www.redfin.com/FL/West-Palm-Beach/201-...  Steffanie Ngo-Hatchie
# 4  https://www.redfin.com/FL/Delray-Beach/1177-Ge...    Julie Ann Giachetti
# 5  https://www.redfin.com/FL/West-Palm-Beach/550-...        Jonathan Huffer
# 6  https://www.redfin.com/FL/Delray-Beach/110-Gle...          Judith Lukens
# 7  https://www.redfin.com/FL/Juno-Beach/750-Ocean...                   None
# 8  https://www.redfin.com/FL/West-Palm-Beach/525-...           Gayle Borden
# 9  https://www.redfin.com/FL/Jupiter/4161-S-US-Hi...          Gayle Krueger
#
#                    list_broker_name_1 list_agent_name_2  \
# 0      Illustrated Properties LLC (Co              None
# 1  One Sotheby's International Realty              None
# 2              Illustrated Properties              None
# 3             United Realty Group Inc              None
# 4  One Sotheby's International Realty              None
# 5                  Redfin Corporation       Elena Fleck
# 6      Premier Estate Properties, Inc         Kim Lekas
# 7                                None              None
# 8              Coldwell Banker Realty    Kenneth Borden
# 9                All Water Realty LLC       David Baker
#
#                list_broker_name_2      buy_agent_name_1  \
# 0                            None            Dory Faxon
# 1                            None          Senada Adzem
# 2                            None            Nina Grody
# 3                            None      Miguel Rodriguez
# 4                            None      Mary Beth Windle
# 5              Redfin Corporation      Andrew Leibowitz
# 6  Premier Estate Properties, Inc        Patricia Burke
# 7                            None                  None
# 8          Coldwell Banker Realty  Non-member Mls Agent
# 9            All Water Realty LLC  Christopher LoPresti
#
#                       buy_broker_name_1   buy_agent_name_2  \
# 0                   Compass Florida LLC   Geraldine Stanko
# 1                       Douglas Elliman               None
# 2          William Raveis South Florida               None
# 3              Compass Florida LLC (PB)               None
# 4                       Douglas Elliman     Caron Dockerty
# 5      Leibowitz Realty Group, LLC./PBG  Michael Leibowitz
# 6    One Sotheby's International Realty               None
# 7                                  None               None
# 8                        NON MEMBER MLS               None
# 9  Illustrated Properties LLC (Jupiter)               None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0               Compass Florida LLC     1  orange
# 1                              None     2    blue
# 2                              None     3    blue
# 3                              None     4    blue
# 4                   Douglas Elliman     5    blue
# 5  Leibowitz Realty Group, LLC./PBG     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  Azure Condo at 2720 Donald Ross Rd #507 in Pal...
# 1  Beresford Cond at 350 S Ocean Blvd Unit 11d in...
# 2  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 3  Esplanade Grande Condo at 201 S Narcissus Ave ...
# 4  1177 Moderne at 1177 George Bush Blvd Unit 308...
# 5  Cityplace South Tower Condo at 550 Okeechobee ...
# 6  Bella Vista Condo at 110 Gleason St #202 in De...
# 7  Ocean Royale Condo at 750 Ocean Royale Way #30...
# 8  Plaza Of The Palm Beaches at 525 S Flagler Dr ...
# 9  Beachcomber Condo at 4161 S Us Highway 1 Unit ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 5, 24) ## List (Earlier) date
date2 = datetime(2024, 10, 1) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 130

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")
