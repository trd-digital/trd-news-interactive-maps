# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 20th Apr. 27th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 1  PAST SALE  April-22-2025   Condo/Co-op  555 N Riverside Dr #12
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 1  Pompano Beach                FL             33062.0  270000.0   1.0    1.0
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL  \
# 1  https://www.redfin.com/FL/Pompano-Beach/555-N-...
#
#                                    SOURCE      MLS#  FAVORITE INTERESTED  \
# 1  Stellar MLS as Distributed by MLS Grid  GC529440         N          Y
#
#     LATITUDE  LONGITUDE
# 1  26.240917 -80.091249
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-25    35
# 2025-04-21    31
# 2025-04-23    27
# 2025-04-22    25
# 2025-04-24    19
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 17   PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 30   PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 113  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 72   PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 8    PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 2    PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 54   PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 126  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 5    PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 106  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 17    Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 30      Pompano Beach                FL             33062.0  2600000.0   3.0
# 113   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 72    Deerfield Beach                FL             33441.0  1700000.0   4.0
# 8    Hallandale Beach                FL             33009.0  1695000.0   3.0
# 2     Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 54    Fort Lauderdale                FL             33316.0   825000.0   2.0
# 126   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 5     Fort Lauderdale                FL             33304.0   810000.0   2.0
# 106         Hollywood                FL             33019.0   785000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 17     4.0  ...   Sold                         NaN                       NaN
# 30     3.5  ...   Sold                         NaN                       NaN
# 113    2.5  ...   Sold                         NaN                       NaN
# 72     4.5  ...   Sold                         NaN                       NaN
# 8      3.5  ...   Sold                         NaN                       NaN
# 2      3.5  ...   Sold                         NaN                       NaN
# 54     2.0  ...   Sold                         NaN                       NaN
# 126    2.0  ...   Sold                         NaN                       NaN
# 5      2.0  ...   Sold                         NaN                       NaN
# 106    2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 17   https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS
# 30   https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...  Beaches MLS
# 113  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 72   https://www.redfin.com/FL/Deerfield-Beach/2051...  Beaches MLS
# 8    https://www.redfin.com/FL/Hallandale-Beach/185...  Beaches MLS
# 2    https://www.redfin.com/FL/Fort-Lauderdale/2100...  Beaches MLS
# 54   https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 126  https://www.redfin.com/FL/Fort-Lauderdale/2821...  Beaches MLS
# 5    https://www.redfin.com/FL/Fort-Lauderdale/609-...  Beaches MLS
# 106  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       MARMLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 17     F10495926         N          Y  26.168793 -80.098465
# 30   RX-11066286         N          Y  26.232119 -80.091722
# 113    F10471725         N          Y  26.168258 -80.099279
# 72   RX-11048992         N          Y  26.312557 -80.076756
# 8    RX-11062421         N          Y  25.984278 -80.118815
# 2      F10495495         N          Y  26.155455 -80.100849
# 54     F10487508         N          Y  26.118136 -80.107099
# 126    F10462721         N          Y  26.163462 -80.101526
# 5      F10493527         N          Y  26.131498 -80.109140
# 106    A11699311         N          Y  25.986806 -80.118650
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 1  PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 2  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 3  PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 4  PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 5  PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 6  PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 7  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 8  PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 9  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 1     Pompano Beach                FL             33062.0  2600000.0   3.0
# 2   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 3   Deerfield Beach                FL             33441.0  1700000.0   4.0
# 4  Hallandale Beach                FL             33009.0  1695000.0   3.0
# 5   Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 6   Fort Lauderdale                FL             33316.0   825000.0   2.0
# 7   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 8   Fort Lauderdale                FL             33304.0   810000.0   2.0
# 9         Hollywood                FL             33019.0   785000.0   2.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    4.0  ... -80.098465  https://www.redfin.com/FL/Fort-Lauderdale/3200...
# 1    3.5  ... -80.091722  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...
# 2    2.5  ... -80.099279  https://www.redfin.com/FL/Fort-Lauderdale/3100...
# 3    4.5  ... -80.076756  https://www.redfin.com/FL/Deerfield-Beach/2051...
# 4    3.5  ... -80.118815  https://www.redfin.com/FL/Hallandale-Beach/185...
# 5    3.5  ... -80.100849  https://www.redfin.com/FL/Fort-Lauderdale/2100...
# 6    2.0  ... -80.107099  https://www.redfin.com/FL/Fort-Lauderdale/1-La...
# 7    2.0  ... -80.101526  https://www.redfin.com/FL/Fort-Lauderdale/2821...
# 8    2.0  ... -80.109140  https://www.redfin.com/FL/Fort-Lauderdale/609-...
# 9    2.0  ... -80.118650  https://www.redfin.com/FL/Hollywood/4111-S-Oce...
#
#     list_agent_name_1             list_broker_name_1     list_agent_name_2  \
# 0       Patricia Post            Post and Post, Inc.                  None
# 1      Bonnie Heatzig            Compass Florida LLC                  None
# 2       Patricia Post            Post and Post, Inc.                  None
# 3       Michael Wells  Premier Estate Properties Inc             Scot Karp
# 4  Isabella Freedberg         Luxury Partners Realty                  None
# 5      Richard Salter           Compass Florida, LLC  Christopher MacInnis
# 6   Christian Duhaime    RE/MAX Consultants Realty 1                  None
# 7      Robert Lopardo         Coldwell Banker Realty                  None
# 8       Andrew Ziffer           Compass Florida, LLC    Michelle Akerstrom
# 9        Ryan Mendell           Maxwell E Realty Inc       Oren Cytrynbaum
#
#               list_broker_name_2    buy_agent_name_1  \
# 0                           None       Patricia Post
# 1                           None         Edward Cook
# 2                           None       Patricia Post
# 3  Premier Estate Properties Inc  Veronica Nagliatti
# 4                           None      Marie Bellitto
# 5           Compass Florida, LLC                None
# 6                           None        Ester Kadosh
# 7                           None       Linda Gentile
# 8           Compass Florida, LLC       Andrew Ziffer
# 9           Maxwell E Realty Inc   Graciela Kaminsky
#
#                               buy_broker_name_1    buy_agent_name_2  \
# 0                           Post and Post, Inc.                None
# 1                  Continental Properties, Inc.                None
# 2                           Post and Post, Inc.                None
# 3  Fortune Christie's International Real Estate                None
# 4                       Cervera Real Estate Inc                None
# 5                        Coldwell Banker Realty                None
# 6                        Coldwell Banker Realty                None
# 7                   Lauderdale Beach Properties     Romina Oliviero
# 8                          Compass Florida, LLC  Michelle Akerstrom
# 9                Aspen International Realty,Inc                None
#
#              buy_broker_name_2
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7  Lauderdale Beach Properties
# 8         Compass Florida, LLC
# 9                         None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 137

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $336,236

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $272

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $46,064,280

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          137              336236          272                     46064280.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 117
# -----------
# Input Previous Week Condo Average Sales Price:
# 436635
# -----------
# Input Previous Week Condo Average PSF:
# 316
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 51086250.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op  3200 N Ocean Blvd #609
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33308.0  3300000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.0  L'hermitage       2850.0       NaN      1998.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1158.0     3956.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS  F10495926
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.168793 -80.098465
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...     Patricia Post
#
#     list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Post and Post, Inc.              None               None    Patricia Post
#
#      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Post and Post, Inc.             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 1  PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 2  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 3  PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 4  PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 5  PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 6  PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 7  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 8  PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 9  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 1     Pompano Beach                FL             33062.0  2600000.0   3.0
# 2   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 3   Deerfield Beach                FL             33441.0  1700000.0   4.0
# 4  Hallandale Beach                FL             33009.0  1695000.0   3.0
# 5   Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 6   Fort Lauderdale                FL             33316.0   825000.0   2.0
# 7   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 8   Fort Lauderdale                FL             33304.0   810000.0   2.0
# 9         Hollywood                FL             33019.0   785000.0   2.0
#
#    BATHS                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.0                     L'hermitage       2850.0       NaN      1998.0
# 1    3.5              Plaza AT Oceanside       2726.0       NaN      2008.0
# 2    2.5                     L'hermitage       1977.0       NaN      1997.0
# 3    4.5  Ocean Plaza ON Deerfield Beach       3021.0       NaN      2003.0
# 4    3.5              Beach Club Tower 1       2078.0       NaN      2005.0
# 5    3.5                       The Palms       1941.0       NaN      1999.0
# 6    2.0            Venetian Condominium       1500.0       NaN      1970.0
# 7    2.0                        Sapphire       1274.0       NaN      2009.0
# 8    2.0                 609 Bayshore Dr       1100.0       NaN      1958.0
# 9    2.0       4111 SOUTH OCEAN DRIVE CO       1235.0       NaN      2017.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1158.0     3956.0   Sold
# 1             NaN          954.0     2186.0   Sold
# 2             NaN          885.0     2765.0   Sold
# 3             NaN          563.0     2091.0   Sold
# 4             NaN          816.0     2355.0   Sold
# 5             NaN          577.0     2831.0   Sold
# 6             NaN          550.0     1285.0   Sold
# 7             NaN          640.0     1397.0   Sold
# 8             NaN          736.0      600.0   Sold
# 9             NaN          636.0     1550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...  Beaches MLS
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...  Beaches MLS
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10495926        N          Y  26.168793 -80.098465
# 1  RX-11066286        N          Y  26.232119 -80.091722
# 2    F10471725        N          Y  26.168258 -80.099279
# 3  RX-11048992        N          Y  26.312557 -80.076756
# 4  RX-11062421        N          Y  25.984278 -80.118815
# 5    F10495495        N          Y  26.155455 -80.100849
# 6    F10487508        N          Y  26.118136 -80.107099
# 7    F10462721        N          Y  26.163462 -80.101526
# 8    F10493527        N          Y  26.131498 -80.109140
# 9    A11699311        N          Y  25.986806 -80.118650
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...       Patricia Post
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Bonnie Heatzig
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...       Patricia Post
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...       Michael Wells
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Isabella Freedberg
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...      Richard Salter
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...   Christian Duhaime
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...      Robert Lopardo
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...       Andrew Ziffer
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...        Ryan Mendell
#
#               list_broker_name_1     list_agent_name_2  \
# 0            Post and Post, Inc.                  None
# 1            Compass Florida LLC                  None
# 2            Post and Post, Inc.                  None
# 3  Premier Estate Properties Inc             Scot Karp
# 4         Luxury Partners Realty                  None
# 5           Compass Florida, LLC  Christopher MacInnis
# 6    RE/MAX Consultants Realty 1                  None
# 7         Coldwell Banker Realty                  None
# 8           Compass Florida, LLC    Michelle Akerstrom
# 9           Maxwell E Realty Inc       Oren Cytrynbaum
#
#               list_broker_name_2    buy_agent_name_1  \
# 0                           None       Patricia Post
# 1                           None         Edward Cook
# 2                           None       Patricia Post
# 3  Premier Estate Properties Inc  Veronica Nagliatti
# 4                           None      Marie Bellitto
# 5           Compass Florida, LLC                None
# 6                           None        Ester Kadosh
# 7                           None       Linda Gentile
# 8           Compass Florida, LLC       Andrew Ziffer
# 9           Maxwell E Realty Inc   Graciela Kaminsky
#
#                               buy_broker_name_1    buy_agent_name_2  \
# 0                           Post and Post, Inc.                None
# 1                  Continental Properties, Inc.                None
# 2                           Post and Post, Inc.                None
# 3  Fortune Christie's International Real Estate                None
# 4                       Cervera Real Estate Inc                None
# 5                        Coldwell Banker Realty                None
# 6                        Coldwell Banker Realty                None
# 7                   Lauderdale Beach Properties     Romina Oliviero
# 8                          Compass Florida, LLC  Michelle Akerstrom
# 9                Aspen International Realty,Inc                None
#
#              buy_broker_name_2  RANK   COLOR
# 0                         None     1  orange
# 1                         None     2    blue
# 2                         None     3    blue
# 3                         None     4    blue
# 4                         None     5    blue
# 5                         None     6    blue
# 6                         None     7    blue
# 7  Lauderdale Beach Properties     8    blue
# 8         Compass Florida, LLC     9    blue
# 9                         None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d6db0df278feea6ec22932dd34a3cba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 20th — Apr. 27th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d6db0df278feea6ec22932dd34a3cba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6d6db0df278feea6ec22932dd34a3cba = L.map(
#                 &quot;map_6d6db0df278feea6ec22932dd34a3cba&quot;,
#                 {
#                     center: [26.141096471014492, -80.17919494275363],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_ab0eaa1927ea9f4953707c28868eda0b = L.featureGroup(
#                 {}
#             ).addTo(map_6d6db0df278feea6ec22932dd34a3cba);
#
#
#             var marker_b066132410ca91b492c52d4930f36eff = L.marker(
#                 [26.1687932, -80.0984652],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_ab0eaa1927ea9f4953707c28868eda0b);
#
#
#             var icon_e30de0f0c41c5f282e21531ad1bc346d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b066132410ca91b492c52d4930f36eff.setIcon(icon_e30de0f0c41c5f282e21531ad1bc346d);
#
#
#         var popup_db756fb1086da11ca4483e738777fe5b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9f8f1cb46493509ebe5f3d78fe92d0a3 = $(`&lt;div id=&quot;html_9f8f1cb46493509ebe5f3d78fe92d0a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;3200 N Ocean Blvd #609&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,300,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,158.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,850.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1998.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_db756fb1086da11ca4483e738777fe5b.setContent(html_9f8f1cb46493509ebe5f3d78fe92d0a3);
#
#
#
#         marker_b066132410ca91b492c52d4930f36eff.bindPopup(popup_db756fb1086da11ca4483e738777fe5b)
#         ;
#
#
#
#
#             var feature_group_9ecc6265c397e80551b23baf5d820d0b = L.featureGroup(
#                 {}
#             ).addTo(map_6d6db0df278feea6ec22932dd34a3cba);
#
#
#             var marker_79f744b24e91d59053469ecc717c8989 = L.marker(
#                 [26.2321195, -80.0917218],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_9ecc6265c397e80551b23baf5d820d0b);
#
#
#             var icon_652d6e142e50ba56c47d6baa5f8c4a9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_79f744b24e91d59053469ecc717c8989.setIcon(icon_652d6e142e50ba56c47d6baa5f8c4a9b);
#
#
#         var popup_47f3733246a4f77ca5a77d7220af6f01 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0a26e44010215d5157d569a1cefc26b0 = $(`&lt;div id=&quot;html_0a26e44010215d5157d569a1cefc26b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1 N Ocean Blvd #1607&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,600,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$954.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,726.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2008.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_47f3733246a4f77ca5a77d7220af6f01.setContent(html_0a26e44010215d5157d569a1cefc26b0);
#
#
#
#         marker_79f744b24e91d59053469ecc717c8989.bindPopup(popup_47f3733246a4f77ca5a77d7220af6f01)
#         ;
#
#
#
#
#             var marker_2d1e77f48fa2afc095ddd712554f32e5 = L.marker(
#                 [26.1682582, -80.0992791],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_9ecc6265c397e80551b23baf5d820d0b);
#
#
#             var icon_1278507fbef6446f5113d3df508afe79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d1e77f48fa2afc095ddd712554f32e5.setIcon(icon_1278507fbef6446f5113d3df508afe79);
#
#
#         var popup_aba0a9eab293c7355ddfcadfb3e6887c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_c75be481199013d36d97269e60e4d794 = $(`&l

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op  3200 N Ocean Blvd #609
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33308.0  3300000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.0  L'hermitage       2850.0       NaN      1998.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1158.0     3956.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS  F10495926
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.168793 -80.098465
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...     Patricia Post
#
#     list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Post and Post, Inc.              None               None    Patricia Post
#
#      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Post and Post, Inc.             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04282025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# "L'hermitage at 3200 N Ocean Blvd #609 in Fort Lauderdale"

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 1  PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 2  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 3  PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 4  PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 5  PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 6  PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 7  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 8  PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 9  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 1     Pompano Beach                FL             33062.0  2600000.0   3.0
# 2   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 3   Deerfield Beach                FL             33441.0  1700000.0   4.0
# 4  Hallandale Beach                FL             33009.0  1695000.0   3.0
# 5   Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 6   Fort Lauderdale                FL             33316.0   825000.0   2.0
# 7   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 8   Fort Lauderdale                FL             33304.0   810000.0   2.0
# 9         Hollywood                FL             33019.0   785000.0   2.0
#
#    BATHS                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.0                     L'hermitage       2850.0       NaN      1998.0
# 1    3.5              Plaza AT Oceanside       2726.0       NaN      2008.0
# 2    2.5                     L'hermitage       1977.0       NaN      1997.0
# 3    4.5  Ocean Plaza ON Deerfield Beach       3021.0       NaN      2003.0
# 4    3.5              Beach Club Tower 1       2078.0       NaN      2005.0
# 5    3.5                       The Palms       1941.0       NaN      1999.0
# 6    2.0            Venetian Condominium       1500.0       NaN      1970.0
# 7    2.0                        Sapphire       1274.0       NaN      2009.0
# 8    2.0                 609 Bayshore Dr       1100.0       NaN      1958.0
# 9    2.0       4111 SOUTH OCEAN DRIVE CO       1235.0       NaN      2017.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1158.0     3956.0   Sold
# 1             NaN          954.0     2186.0   Sold
# 2             NaN          885.0     2765.0   Sold
# 3             NaN          563.0     2091.0   Sold
# 4             NaN          816.0     2355.0   Sold
# 5             NaN          577.0     2831.0   Sold
# 6             NaN          550.0     1285.0   Sold
# 7             NaN          640.0     1397.0   Sold
# 8             NaN          736.0      600.0   Sold
# 9             NaN          636.0     1550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...  Beaches MLS
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...  Beaches MLS
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10495926        N          Y  26.168793 -80.098465
# 1  RX-11066286        N          Y  26.232119 -80.091722
# 2    F10471725        N          Y  26.168258 -80.099279
# 3  RX-11048992        N          Y  26.312557 -80.076756
# 4  RX-11062421        N          Y  25.984278 -80.118815
# 5    F10495495        N          Y  26.155455 -80.100849
# 6    F10487508        N          Y  26.118136 -80.107099
# 7    F10462721        N          Y  26.163462 -80.101526
# 8    F10493527        N          Y  26.131498 -80.109140
# 9    A11699311        N          Y  25.986806 -80.118650
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...       Patricia Post
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Bonnie Heatzig
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...       Patricia Post
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...       Michael Wells
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Isabella Freedberg
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...      Richard Salter
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...   Christian Duhaime
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...      Robert Lopardo
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...       Andrew Ziffer
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...        Ryan Mendell
#
#               list_broker_name_1     list_agent_name_2  \
# 0            Post and Post, Inc.                  None
# 1            Compass Florida LLC                  None
# 2            Post and Post, Inc.                  None
# 3  Premier Estate Properties Inc             Scot Karp
# 4         Luxury Partners Realty                  None
# 5           Compass Florida, LLC  Christopher MacInnis
# 6    RE/MAX Consultants Realty 1                  None
# 7         Coldwell Banker Realty                  None
# 8           Compass Florida, LLC    Michelle Akerstrom
# 9           Maxwell E Realty Inc       Oren Cytrynbaum
#
#               list_broker_name_2    buy_agent_name_1  \
# 0                           None       Patricia Post
# 1                           None         Edward Cook
# 2                           None       Patricia Post
# 3  Premier Estate Properties Inc  Veronica Nagliatti
# 4                           None      Marie Bellitto
# 5           Compass Florida, LLC                None
# 6                           None        Ester Kadosh
# 7                           None       Linda Gentile
# 8           Compass Florida, LLC       Andrew Ziffer
# 9           Maxwell E Realty Inc   Graciela Kaminsky
#
#                               buy_broker_name_1    buy_agent_name_2  \
# 0                           Post and Post, Inc.                None
# 1                  Continental Properties, Inc.                None
# 2                           Post and Post, Inc.                None
# 3  Fortune Christie's International Real Estate                None
# 4                       Cervera Real Estate Inc                None
# 5                        Coldwell Banker Realty                None
# 6                        Coldwell Banker Realty                None
# 7                   Lauderdale Beach Properties     Romina Oliviero
# 8                          Compass Florida, LLC  Michelle Akerstrom
# 9                Aspen International Realty,Inc                None
#
#              buy_broker_name_2  RANK   COLOR  \
# 0                         None     1  orange
# 1                         None     2    blue
# 2                         None     3    blue
# 3                         None     4    blue
# 4                         None     5    blue
# 5                         None     6    blue
# 6                         None     7    blue
# 7  Lauderdale Beach Properties     8    blue
# 8         Compass Florida, LLC     9    blue
# 9                         None    10    blue
#
#                                            FULL_NAME
# 0  L'hermitage at 3200 N Ocean Blvd #609 in Fort ...
# 1  Plaza AT Oceanside at 1 N Ocean Blvd #1607 in ...
# 2  L'hermitage at 3100 N Ocean Blvd #1404 in Fort...
# 3  Ocean Plaza ON Deerfield Beach at 2051 SE 3rd ...
# 4  Beach Club Tower 1 at 1850 S Ocean Dr #2304 in...
# 5  The Palms at 2100 N Ocean Blvd Unit 8A in Fort...
# 6  Venetian Condominium at 1 Las Olas Cir #1210 i...
# 7  Sapphire at 2821 N Ocean Blvd Unit 506S in For...
# 8  609 Bayshore Dr at 609 Bayshore Dr #1 in Fort ...
# 9  4111 SOUTH OCEAN DRIVE CO at 4111 S Ocean Dr #...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: L'hermitage closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $785,000 to $3,300,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Deerfield Beach, Hallandale Beach, Hollywood, Pompano Beach, Fort Lauderdale, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 137 condo sales totaling $46,064,280 million from Apr. 20th to Apr. 27th. The previous week, brokers closed 117 condo sales totaling $51,086,250.
#
# Last week’s units sold for an average of $336,236, lower than the $436,635 average price from the previous week. The average price per square foot fell to $272 from $316, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $785,000.0 million to $3,300,000.0 million.
#
# L'hermitage at 3200 N Ocean Blvd #609 in Fort Lauderdale took the top spot with a $3,300,000.0 million closing. The sale closed at $1,158.0 per square foot.
#
# Patricia Post with Post and Post, Inc., and None with None had the listing.
# Patricia Post with Post and Post, Inc., and None with None represented the buyer.
#
# Plaza AT Oceanside at 1 N Ocean Blvd #1607 in Pompano Beach, closed for the second highest amount, $2,600,000.0, or $954.0 per square foot.
#
# Bonnie Heatzig with Compass Florida LLC, and None with None had the listing.
# Edward Cook with Continental Properties, Inc., and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04282025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 20th to Apr. 27th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 1  PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 2  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 3  PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 4  PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 5  PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 6  PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 7  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 8  PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 9  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 1     Pompano Beach                FL             33062.0  2600000.0   3.0
# 2   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 3   Deerfield Beach                FL             33441.0  1700000.0   4.0
# 4  Hallandale Beach                FL             33009.0  1695000.0   3.0
# 5   Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 6   Fort Lauderdale                FL             33316.0   825000.0   2.0
# 7   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 8   Fort Lauderdale                FL             33304.0   810000.0   2.0
# 9         Hollywood                FL             33019.0   785000.0   2.0
#
#    BATHS                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.0                     L'hermitage       2850.0       NaN      1998.0
# 1    3.5              Plaza AT Oceanside       2726.0       NaN      2008.0
# 2    2.5                     L'hermitage       1977.0       NaN      1997.0
# 3    4.5  Ocean Plaza ON Deerfield Beach       3021.0       NaN      2003.0
# 4    3.5              Beach Club Tower 1       2078.0       NaN      2005.0
# 5    3.5                       The Palms       1941.0       NaN      1999.0
# 6    2.0            Venetian Condominium       1500.0       NaN      1970.0
# 7    2.0                        Sapphire       1274.0       NaN      2009.0
# 8    2.0                 609 Bayshore Dr       1100.0       NaN      1958.0
# 9    2.0       4111 SOUTH OCEAN DRIVE CO       1235.0       NaN      2017.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1158.0     3956.0   Sold
# 1             NaN          954.0     2186.0   Sold
# 2             NaN          885.0     2765.0   Sold
# 3             NaN          563.0     2091.0   Sold
# 4             NaN          816.0     2355.0   Sold
# 5             NaN          577.0     2831.0   Sold
# 6             NaN          550.0     1285.0   Sold
# 7             NaN          640.0     1397.0   Sold
# 8             NaN          736.0      600.0   Sold
# 9             NaN          636.0     1550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...  Beaches MLS
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...  Beaches MLS
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10495926        N          Y  26.168793 -80.098465
# 1  RX-11066286        N          Y  26.232119 -80.091722
# 2    F10471725        N          Y  26.168258 -80.099279
# 3  RX-11048992        N          Y  26.312557 -80.076756
# 4  RX-11062421        N          Y  25.984278 -80.118815
# 5    F10495495        N          Y  26.155455 -80.100849
# 6    F10487508        N          Y  26.118136 -80.107099
# 7    F10462721        N          Y  26.163462 -80.101526
# 8    F10493527        N          Y  26.131498 -80.109140
# 9    A11699311        N          Y  25.986806 -80.118650
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...       Patricia Post
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Bonnie Heatzig
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...       Patricia Post
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...       Michael Wells
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Isabella Freedberg
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...      Richard Salter
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...   Christian Duhaime
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...      Robert Lopardo
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...       Andrew Ziffer
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...        Ryan Mendell
#
#               list_broker_name_1     list_agent_name_2  \
# 0            Post and Post, Inc.                  None
# 1            Compass Florida LLC                  None
# 2            Post and Post, Inc.                  None
# 3  Premier Estate Properties Inc             Scot Karp
# 4         Luxury Partners Realty                  None
# 5           Compass Florida, LLC  Christopher MacInnis
# 6    RE/MAX Consultants Realty 1                  None
# 7         Coldwell Banker Realty                  None
# 8           Compass Florida, LLC    Michelle Akerstrom
# 9           Maxwell E Realty Inc       Oren Cytrynbaum
#
#               list_broker_name_2    buy_agent_name_1  \
# 0                           None       Patricia Post
# 1                           None         Edward Cook
# 2                           None       Patricia Post
# 3  Premier Estate Properties Inc  Veronica Nagliatti
# 4                           None      Marie Bellitto
# 5           Compass Florida, LLC                None
# 6                           None        Ester Kadosh
# 7                           None       Linda Gentile
# 8           Compass Florida, LLC       Andrew Ziffer
# 9           Maxwell E Realty Inc   Graciela Kaminsky
#
#                               buy_broker_name_1    buy_agent_name_2  \
# 0                           Post and Post, Inc.                None
# 1                  Continental Properties, Inc.                None
# 2                           Post and Post, Inc.                None
# 3  Fortune Christie's International Real Estate                None
# 4                       Cervera Real Estate Inc                None
# 5                        Coldwell Banker Realty                None
# 6                        Coldwell Banker Realty                None
# 7                   Lauderdale Beach Properties     Romina Oliviero
# 8                          Compass Florida, LLC  Michelle Akerstrom
# 9                Aspen International Realty,Inc                None
#
#              buy_broker_name_2  RANK   COLOR  \
# 0                         None     1  orange
# 1                         None     2    blue
# 2                         None     3    blue
# 3                         None     4    blue
# 4                         None     5    blue
# 5                         None     6    blue
# 6                         None     7    blue
# 7  Lauderdale Beach Properties     8    blue
# 8         Compass Florida, LLC     9    blue
# 9                         None    10    blue
#
#                                            FULL_NAME
# 0  L'hermitage at 3200 N Ocean Blvd #609 in Fort ...
# 1  Plaza AT Oceanside at 1 N Ocean Blvd #1607 in ...
# 2  L'hermitage at 3100 N Ocean Blvd #1404 in Fort...
# 3  Ocean Plaza ON Deerfield Beach at 2051 SE 3rd ...
# 4  Beach Club Tower 1 at 1850 S Ocean Dr #2304 in...
# 5  The Palms at 2100 N Ocean Blvd Unit 8A in Fort...
# 6  Venetian Condominium at 1 Las Olas Cir #1210 i...
# 7  Sapphire at 2821 N Ocean Blvd Unit 506S in For...
# 8  609 Bayshore Dr at 609 Bayshore Dr #1 in Fort ...
# 9  4111 SOUTH OCEAN DRIVE CO at 4111 S Ocean Dr #...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: L'hermitage closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $785,000 to $3,300,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Deerfield Beach, Hallandale Beach, Hollywood, Pompano Beach, Fort Lauderdale, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 137 condo sales totaling $46,064,280 million from Apr. 20th to Apr. 27th. The previous week, brokers closed 117 condo sales totaling $51,086,250.
#
# Last week’s units sold for an average of $336,236, lower than the $436,635 average price from the previous week. The average price per square foot fell to $272 from $316, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $785,000.0 million to $3,300,000.0 million.
#
# L'hermitage at 3200 N Ocean Blvd #609 in Fort Lauderdale took the top spot with a $3,300,000.0 million closing. The sale closed at $1,158.0 per square foot.
#
# Patricia Post with Post and Post, Inc., and None with None had the listing.
# Patricia Post with Post and Post, Inc., and None with None represented the buyer.
#
# Plaza AT Oceanside at 1 N Ocean Blvd #1607 in Pompano Beach, closed for the second highest amount, $2,600,000.0, or $954.0 per square foot.
#
# Bonnie Heatzig with Compass Florida LLC, and None with None had the listing.
# Edward Cook with Continental Properties, Inc., and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04282025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 20th to Apr. 27th:
#
# Most Expensive
# L'hermitage, 3200 N Ocean Blvd #609, in Fort Lauderdale | Price: $3,300,000 | $1,158 psf | Listing agents: Patricia Post with Post and Post, Inc. and None with None | Buyer's agents: Patricia Post with Post and Post, Inc. and None with None
#
# Least Expensive
# 4111 SOUTH OCEAN DRIVE CO, 4111 S Ocean Dr #3503, in Hollywood | Price: $785,000 | $636 psf | Listing agents: Ryan Mendell with Maxwell E Realty Inc and Oren Cytrynbaum with Maxwell E Realty Inc | Buyer's agents: Graciela Kaminsky with Aspen International Realty,Inc and None with None
#
# Highest Price Per Square Foot
# L'hermitage, 3200 N Ocean Blvd #609, in Fort Lauderdale | Price: $3,300,000 | $1,158 psf | Listing agents: Patricia Post with Post and Post, Inc. and None with None | Buyer's agents: Patricia Post with Post and Post, Inc. and None with None
#
# Lowest Price Per Square Foot
# Venetian Condominium, 1 Las Olas Cir #1210, in Fort Lauderdale | Price: $825,000 | $550 psf | Listing agents: Christian Duhaime with RE/MAX Consultants Realty 1 and None with None | Buyer's agents: Ester Kadosh with Coldwell Banker Realty and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Fort-Lauderdale/3200-N-Ocean-Blvd-33308/unit-609/home/41972788
# Second priciest sale:  https://www.redfin.com/FL/Pompano-Beach/1-N-Ocean-Blvd-33062/unit-1607/home/42070652
# Cheapest top ten sale:  https://www.redfin.com/FL/Hollywood/4111-S-Ocean-Dr-33019/unit-3503/home/56678133
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/609-Bayshore-Dr-33304/unit-1/home/41978343
# Highest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/3200-N-Ocean-Blvd-33308/unit-609/home/41972788
# Lowest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/1-Las-Olas-Cir-33316/unit-1210/home/41801735

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Fort-Lauderdale/3200-N-Ocean-Blvd-33308/unit-609/home/41972788

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Pompano-Beach/1-N-Ocean-Blvd-33062/unit-1607/home/42070652

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Hollywood/4111-S-Ocean-Dr-33019/unit-3503/home/56678133

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/609-Bayshore-Dr-33304/unit-1/home/41978343

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/3200-N-Ocean-Blvd-33308/unit-609/home/41972788

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/1-Las-Olas-Cir-33316/unit-1210/home/41801735

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-24   Condo/Co-op       3200 N Ocean Blvd #609
# 1  PAST SALE 2025-04-25   Condo/Co-op         1 N Ocean Blvd #1607
# 2  PAST SALE 2025-04-21   Condo/Co-op      3100 N Ocean Blvd #1404
# 3  PAST SALE 2025-04-25   Condo/Co-op          2051 SE 3rd St Ph 3
# 4  PAST SALE 2025-04-21   Condo/Co-op        1850 S Ocean Dr #2304
# 5  PAST SALE 2025-04-25   Condo/Co-op    2100 N Ocean Blvd Unit 8A
# 6  PAST SALE 2025-04-21   Condo/Co-op         1 Las Olas Cir #1210
# 7  PAST SALE 2025-04-23   Condo/Co-op  2821 N Ocean Blvd Unit 506S
# 8  PAST SALE 2025-04-23   Condo/Co-op           609 Bayshore Dr #1
# 9  PAST SALE 2025-04-25   Condo/Co-op        4111 S Ocean Dr #3503
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33308.0  3300000.0   3.0
# 1     Pompano Beach                FL             33062.0  2600000.0   3.0
# 2   Fort Lauderdale                FL             33308.0  1750000.0   3.0
# 3   Deerfield Beach                FL             33441.0  1700000.0   4.0
# 4  Hallandale Beach                FL             33009.0  1695000.0   3.0
# 5   Fort Lauderdale                FL             33305.0  1120000.0   3.0
# 6   Fort Lauderdale                FL             33316.0   825000.0   2.0
# 7   Fort Lauderdale                FL             33308.0   815000.0   2.0
# 8   Fort Lauderdale                FL             33304.0   810000.0   2.0
# 9         Hollywood                FL             33019.0   785000.0   2.0
#
#    BATHS                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.0                     L'hermitage       2850.0       NaN      1998.0
# 1    3.5              Plaza AT Oceanside       2726.0       NaN      2008.0
# 2    2.5                     L'hermitage       1977.0       NaN      1997.0
# 3    4.5  Ocean Plaza ON Deerfield Beach       3021.0       NaN      2003.0
# 4    3.5              Beach Club Tower 1       2078.0       NaN      2005.0
# 5    3.5                       The Palms       1941.0       NaN      1999.0
# 6    2.0            Venetian Condominium       1500.0       NaN      1970.0
# 7    2.0                        Sapphire       1274.0       NaN      2009.0
# 8    2.0                 609 Bayshore Dr       1100.0       NaN      1958.0
# 9    2.0       4111 SOUTH OCEAN DRIVE CO       1235.0       NaN      2017.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1158.0     3956.0   Sold
# 1             NaN          954.0     2186.0   Sold
# 2             NaN          885.0     2765.0   Sold
# 3             NaN          563.0     2091.0   Sold
# 4             NaN          816.0     2355.0   Sold
# 5             NaN          577.0     2831.0   Sold
# 6             NaN          550.0     1285.0   Sold
# 7             NaN          640.0     1397.0   Sold
# 8             NaN          736.0      600.0   Sold
# 9             NaN          636.0     1550.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...  Beaches MLS
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...  Beaches MLS
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...  Beaches MLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...  Beaches MLS
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10495926        N          Y  26.168793 -80.098465
# 1  RX-11066286        N          Y  26.232119 -80.091722
# 2    F10471725        N          Y  26.168258 -80.099279
# 3  RX-11048992        N          Y  26.312557 -80.076756
# 4  RX-11062421        N          Y  25.984278 -80.118815
# 5    F10495495        N          Y  26.155455 -80.100849
# 6    F10487508        N          Y  26.118136 -80.107099
# 7    F10462721        N          Y  26.163462 -80.101526
# 8    F10493527        N          Y  26.131498 -80.109140
# 9    A11699311        N          Y  25.986806 -80.118650
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3200...       Patricia Post
# 1  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Bonnie Heatzig
# 2  https://www.redfin.com/FL/Fort-Lauderdale/3100...       Patricia Post
# 3  https://www.redfin.com/FL/Deerfield-Beach/2051...       Michael Wells
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...  Isabella Freedberg
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2100...      Richard Salter
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1-La...   Christian Duhaime
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2821...      Robert Lopardo
# 8  https://www.redfin.com/FL/Fort-Lauderdale/609-...       Andrew Ziffer
# 9  https://www.redfin.com/FL/Hollywood/4111-S-Oce...        Ryan Mendell
#
#               list_broker_name_1     list_agent_name_2  \
# 0            Post and Post, Inc.                  None
# 1            Compass Florida LLC                  None
# 2            Post and Post, Inc.                  None
# 3  Premier Estate Properties Inc             Scot Karp
# 4         Luxury Partners Realty                  None
# 5           Compass Florida, LLC  Christopher MacInnis
# 6    RE/MAX Consultants Realty 1                  None
# 7         Coldwell Banker Realty                  None
# 8           Compass Florida, LLC    Michelle Akerstrom
# 9           Maxwell E Realty Inc       Oren Cytrynbaum
#
#               list_broker_name_2    buy_agent_name_1  \
# 0                           None       Patricia Post
# 1                           None         Edward Cook
# 2                           None       Patricia Post
# 3  Premier Estate Properties Inc  Veronica Nagliatti
# 4                           None      Marie Bellitto
# 5           Compass Florida, LLC                None
# 6                           None        Ester Kadosh
# 7                           None       Linda Gentile
# 8           Compass Florida, LLC       Andrew Ziffer
# 9           Maxwell E Realty Inc   Graciela Kaminsky
#
#                               buy_broker_name_1    buy_agent_name_2  \
# 0                           Post and Post, Inc.                None
# 1                  Continental Properties, Inc.                None
# 2                           Post and Post, Inc.                None
# 3  Fortune Christie's International Real Estate                None
# 4                       Cervera Real Estate Inc                None
# 5                        Coldwell Banker Realty                None
# 6                        Coldwell Banker Realty                None
# 7                   Lauderdale Beach Properties     Romina Oliviero
# 8                          Compass Florida, LLC  Michelle Akerstrom
# 9                Aspen International Realty,Inc                None
#
#              buy_broker_name_2  RANK   COLOR  \
# 0                         None     1  orange
# 1                         None     2    blue
# 2                         None     3    blue
# 3                         None     4    blue
# 4                         None     5    blue
# 5                         None     6    blue
# 6                         None     7    blue
# 7  Lauderdale Beach Properties     8    blue
# 8         Compass Florida, LLC     9    blue
# 9                         None    10    blue
#
#                                            FULL_NAME
# 0  L'hermitage at 3200 N Ocean Blvd #609 in Fort ...
# 1  Plaza AT Oceanside at 1 N Ocean Blvd #1607 in ...
# 2  L'hermitage at 3100 N Ocean Blvd #1404 in Fort...
# 3  Ocean Plaza ON Deerfield Beach at 2051 SE 3rd ...
# 4  Beach Club Tower 1 at 1850 S Ocean Dr #2304 in...
# 5  The Palms at 2100 N Ocean Blvd Unit 8A in Fort...
# 6  Venetian Condominium at 1 Las Olas Cir #1210 i...
# 7  Sapphire at 2821 N Ocean Blvd Unit 506S in For...
# 8  609 Bayshore Dr at 609 Bayshore Dr #1 in Fort ...
# 9  4111 SOUTH OCEAN DRIVE CO at 4111 S Ocean Dr #...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 2, 27) ## List (Earlier) date
date2 = datetime(2025, 4, 25) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 57

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1158.0
# 1     954.0
# 2     885.0
# 3     563.0
# 4     816.0
# 5     577.0
# 6     550.0
# 7     640.0
# 8     736.0
# 9     636.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                         ADDRESS       PRICE BEDS  \
# 0 2025-04-24       3200 N Ocean Blvd #609 in Fort Lauderdale  $3,300,000    3
# 1 2025-04-25           1 N Ocean Blvd #1607 in Pompano Beach  $2,600,000    3
# 2 2025-04-21      3100 N Ocean Blvd #1404 in Fort Lauderdale  $1,750,000    3
# 3 2025-04-25          2051 SE 3rd St Ph 3 in Deerfield Beach  $1,700,000    4
# 4 2025-04-21       1850 S Ocean Dr #2304 in Hallandale Beach  $1,695,000    3
# 5 2025-04-25    2100 N Ocean Blvd Unit 8A in Fort Lauderdale  $1,120,000    3
# 6 2025-04-21         1 Las Olas Cir #1210 in Fort Lauderdale    $825,000    2
# 7 2025-04-23  2821 N Ocean Blvd Unit 506S in Fort Lauderdale    $815,000    2
# 8 2025-04-23           609 Bayshore Dr #1 in Fort Lauderdale    $810,000    2
# 9 2025-04-25              4111 S Ocean Dr #3503 in Hollywood    $785,000    2
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    4.0       2,850       1998        $1,158  Beaches MLS    F10495926
# 1    3.5       2,726       2008          $954  Beaches MLS  RX-11066286
# 2    2.5       1,977       1997          $885  Beaches MLS    F10471725
# 3    4.5       3,021       2003          $563  Beaches MLS  RX-11048992
# 4    3.5       2,078       2005          $816  Beaches MLS  RX-11062421
# 5    3.5       1,941       1999          $577  Beaches MLS    F10495495
# 6    2.0       1,500       1970          $550  Beaches MLS    F10487508
# 7    2.0       1,274       2009          $640  Beaches MLS    F10462721
# 8    2.0       1,100       1958          $736  Beaches MLS    F10493527
# 9    2.0       1,235       2017          $636       MARMLS    A11699311
#
#                                         LISTING INFO  \
# 0              Patricia Post Post and Post, Inc.
# 1             Bonnie Heatzig Compass Florida LLC
# 2              Patricia Post Post and Post, Inc.
# 3  Michael Wells Premier Estate Properties Inc Sc...
# 4      Isabella Freedberg Luxury Partners Realty
# 5  Richard Salter Compass Florida, LLC Christophe...
# 6  Christian Duhaime RE/MAX Consultants Realty 1
# 7          Robert Lopardo Coldwell Banker Realty
# 8  Andrew Ziffer Compass Florida, LLC Michelle Ak...
# 9  Ryan Mendell Maxwell E Realty Inc Oren Cytrynb...
#
#                                          BUYING INFO
# 0              Patricia Post Post and Post, Inc.
# 1       Edward Cook Continental Properties, Inc.
# 2              Patricia Post Post and Post, Inc.
# 3  Veronica Nagliatti Fortune Christie's Internat...
# 4         Marie Bellitto Cervera Real Estate Inc
# 5                         Coldwell Banker Realty
# 6            Ester Kadosh Coldwell Banker Realty
# 7  Linda Gentile Lauderdale Beach Properties Romi...
# 8  Andrew Ziffer Compass Florida, LLC Michelle Ak...
# 9  Graciela Kaminsky Aspen International Realty,I...
