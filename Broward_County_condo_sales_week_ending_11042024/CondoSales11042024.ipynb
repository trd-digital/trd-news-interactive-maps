# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Oct. 27th Nov. 3rd

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE              ADDRESS  \
# 1  PAST SALE  October-29-2024   Condo/Co-op  350 SE 2nd St #1470
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Fort Lauderdale                FL             33301.0  670000.0   3.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Fort-Lauderdale/350-...  Beaches MLS  F10468996
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  26.120405 -80.139762
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                        ADDRESS  \
# 105  PAST SALE 2024-11-04   Condo/Co-op          2871 Somerset Dr #205
# 58   PAST SALE 2024-11-01   Condo/Co-op  2749 S Oakland Forest Dr #204
# 68   PAST SALE 2024-11-01   Condo/Co-op      121 Royal Park Dr Unit 1G
# 22   PAST SALE 2024-11-01   Condo/Co-op             901 S Surf Rd #401
# 92   PAST SALE 2024-11-01   Condo/Co-op    3973 Carambola Cir N #29112
# ..         ...        ...           ...                            ...
# 117  PAST SALE 2024-10-28   Condo/Co-op     2796 S University Dr #2106
# 93   PAST SALE 2024-10-28   Condo/Co-op          2901 NW 46th Ave #209
# 98   PAST SALE 2024-10-28   Condo/Co-op          5920 W Sample Rd #205
# 101  PAST SALE 2024-10-28   Condo/Co-op          7554 Stirling Rd #102
# 44   PAST SALE 2024-10-28   Condo/Co-op             340 Sunset Dr #502
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 105  Lauderdale Lakes                FL             33311.0   90000.0   1.0
# 58       Oakland Park                FL             33309.0  255000.0   2.0
# 68    Fort Lauderdale                FL             33309.0  222222.0   2.0
# 22          Hollywood                FL             33019.0  380000.0   2.0
# 92      Coconut Creek                FL             33066.0  220000.0   2.0
# ..                ...               ...                 ...       ...   ...
# 117             Davie                FL             33328.0  204000.0   1.0
# 93   Lauderdale Lakes                FL             33313.0  117000.0   2.0
# 98      Coral Springs                FL             33067.0  220000.0   1.0
# 101             Davie                FL             33024.0  199000.0   2.0
# 44    Fort Lauderdale                FL             33301.0  378000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 105    1.0  ...   Sold                         NaN                       NaN
# 58     2.0  ...   Sold                         NaN                       NaN
# 68     2.0  ...   Sold                         NaN                       NaN
# 22     2.0  ...   Sold                         NaN                       NaN
# 92     2.0  ...   Sold                         NaN                       NaN
# ..     ...  ...    ...                         ...                       ...
# 117    1.0  ...   Sold                         NaN                       NaN
# 93     2.0  ...   Sold                         NaN                       NaN
# 98     1.0  ...   Sold                         NaN                       NaN
# 101    2.0  ...   Sold                         NaN                       NaN
# 44     2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 105  https://www.redfin.com/FL/Lauderdale-Lakes/287...  Beaches MLS
# 58   https://www.redfin.com/FL/Oakland-Park/2749-S-...  Beaches MLS
# 68   https://www.redfin.com/FL/Oakland-Park/121-Roy...  Beaches MLS
# 22   https://www.redfin.com/FL/Hollywood/901-S-Surf...  Beaches MLS
# 92   https://www.redfin.com/FL/Coconut-Creek/3973-C...  Beaches MLS
# ..                                                 ...          ...
# 117  https://www.redfin.com/FL/Davie/2796-S-Univers...  Beaches MLS
# 93   https://www.redfin.com/FL/Lauderdale-Lakes/290...  Beaches MLS
# 98   https://www.redfin.com/FL/Coral-Springs/5920-W...  Beaches MLS
# 101  https://www.redfin.com/FL/Hollywood/7554-Stirl...  Beaches MLS
# 44   https://www.redfin.com/FL/Fort-Lauderdale/340-...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 105    F10444482         N          Y  26.158620 -80.191430
# 58     F10457175         N          Y  26.169121 -80.182005
# 68     F10456110         N          Y  26.172878 -80.164108
# 22     F10452448         N          Y  26.006761 -80.116237
# 92   RX-11006208         N          Y  26.270978 -80.182925
# ..           ...       ...        ...        ...        ...
# 117    F10440748         N          Y  26.086042 -80.249501
# 93     F10441465         N          Y  26.161593 -80.210387
# 98     F10448756         N          Y  26.272885 -80.203238
# 101    F10448697         N          Y  26.044504 -80.239435
# 44     F10459283         N          Y  26.119224 -80.113355
#
# [149 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 149

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $328,285

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $263

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $48,914,535

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Broward
# Input Previous Week Condo Sales Total (number units sold):
# 98
# Input Previous Week Condo Average Sales Price:
# 303409
# Input Previous Week Condo Average PSF:
# 277
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 33_500_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op  2000 S Ocean Dr Unit 21A
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
#
#    BATHS    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  2000 Ocean       2913.0       NaN      2021.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1167.0     7670.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...  MARMLS  A11666798
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...      Leslie Clark
#
#              list_broker_name_1         list_agent_name_2  \
# 0  Fortune International Realty  Bianca Boscacci Balduzzi
#
#              list_broker_name_2 buy_agent_name_1      buy_broker_name_1  \
# 0  Fortune International Realty      Yael Sultan  Avanti Way Realty LLC
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op                2000 S Ocean Dr Unit 21A
# 1  PAST SALE 2024-11-01   Condo/Co-op                1180 N Federal Hwy #1006
# 2  PAST SALE 2024-10-30   Condo/Co-op               100 E Las Olas Blvd #3001
# 3  PAST SALE 2024-10-28   Condo/Co-op                 2895 NE 33rd Ct Unit 2B
# 4  PAST SALE 2024-10-28   Condo/Co-op                   1800 S Ocean Dr #3801
# 5  PAST SALE 2024-10-29   Condo/Co-op                  333 Las Olas Way #1507
# 6  PAST SALE 2024-10-29   Condo/Co-op                1228 Hillsboro Mile #101
# 7  PAST SALE 2024-10-31   Condo/Co-op                   3111 N Ocean Dr #1607
# 8  PAST SALE 2024-10-31   Condo/Co-op                     411 NW 1st Ave #502
# 9  PAST SALE 2024-10-29   Condo/Co-op  2600 E Hallandale Beach Blvd Unit T701
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
# 1   Fort Lauderdale                FL             33304.0  2100000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1975000.0   3.0
# 3   Fort Lauderdale                FL             33306.0  1850000.0   3.0
# 4  Hallandale Beach                FL             33009.0  1750000.0   3.0
# 5   Fort Lauderdale                FL             33301.0  1065000.0   2.0
# 6   Hillsboro Beach                FL             33062.0   950000.0   3.0
# 7         Hollywood                FL             33019.0   925000.0   3.0
# 8   Fort Lauderdale                FL             33301.0   800000.0   2.0
# 9  Hallandale Beach                FL             33009.0   795000.0   3.0
#
#    BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  2000 Ocean       2913.0       NaN      2021.0
# 1    3.5                        Riva       2400.0       NaN      2018.0
# 2    2.5    100 Las Olas Condominium       2395.0       NaN      2020.0
# 3    3.5  33INTRACOASTAL CONDOMINIUM       1878.0       NaN      2018.0
# 4    3.5            BEACH CLUB THREE       2078.0       NaN      2007.0
# 5    2.5   LAS OLAS RIVER HOUSE COND       1522.0       NaN      2004.0
# 6    2.5          Mediterranea Condo       2160.0       NaN      1999.0
# 7    2.5            Hollywood Towers       1650.0       NaN      1967.0
# 8    2.0               Foundry Lofts       1521.0       NaN      2007.0
# 9    3.0       BEACHWALK CONDOMINIUM       1853.0       NaN      2015.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1167.0     7670.0   Sold
# 1             NaN          875.0     2370.0   Sold
# 2             NaN          825.0     2794.0   Sold
# 3             NaN          985.0     2027.0   Sold
# 4             NaN          842.0     1674.0   Sold
# 5             NaN          700.0     1731.0   Sold
# 6             NaN          440.0     1973.0   Sold
# 7             NaN          561.0     1215.0   Sold
# 8             NaN          526.0     1300.0   Sold
# 9             NaN          429.0     2101.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11666798
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...  Beaches MLS  F10455424
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10458018
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...       MARMLS  A11656849
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...       MARMLS  A11593823
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11513221
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...  Beaches MLS  F10425148
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...  Beaches MLS  F10433465
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...  Beaches MLS  F10403208
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS  A11546247
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.139647 -80.118966
# 2        N          Y  26.118835 -80.141476
# 3        N          Y  26.169738 -80.104635
# 4        N          Y  25.985667 -80.118693
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.304202 -80.077943
# 7        N          Y  26.030688 -80.115514
# 8        N          Y  26.126606 -80.144908
# 9        N          Y  25.985942 -80.122707
#
#                                                  url        list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...             Leslie Clark
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...       Elizabeth Caldwell
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...        Elvira Santamaria
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...          Megan Kowalchuk
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...                     None
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Steven Yaroslawitz
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...              John Putzig
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...                Moe Mossa
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...           Timothy Singer
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...  Ricardo Schilkrut Cogan
#
#                    list_broker_name_1         list_agent_name_2  \
# 0        Fortune International Realty  Bianca Boscacci Balduzzi
# 1                Compass Florida, LLC                      None
# 2        Beckett Realty Advisors, LLC           Kenneth Beckett
# 3                     Douglas Elliman                      None
# 4                                None                      None
# 5       Charles Rutenberg Realty Fort                      None
# 6                        RE/MAX First              Susan Nelson
# 7                   Savvy Avenue, LLC                      None
# 8              Coldwell Banker Realty            Timothy Powers
# 9  One Sotheby's International Realty                      None
#
#              list_broker_name_2  buy_agent_name_1  \
# 0  Fortune International Realty       Yael Sultan
# 1                          None  James Cunningham
# 2  Beckett Realty Advisors, LLC      Catina Jones
# 3                          None  Richard Kallabat
# 4                          None              None
# 5                          None              None
# 6                  RE/MAX First       Dany Landry
# 7                          None      Beth Jenkins
# 8        Coldwell Banker Realty   Eirini Melaniti
# 9                          None   Benjamin Figgie
#
#                      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                Avanti Way Realty LLC             None              None
# 1           One Sotheby's Int'l Realty             None              None
# 2  Aston Rose Sports And Entertainment             None              None
# 3       Keller Williams Capital Realty             None              None
# 4                                 None             None              None
# 5                                 None             None              None
# 6           Royal International Realty             None              None
# 7                 Compass Florida, LLC             None              None
# 8               Coldwell Banker Realty             None              None
# 9              Miami Waterfront Realty             None              None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1cacf4ef462b144fa976e63fcf7ec22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Oct. 27th - Nov. 3rd&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1cacf4ef462b144fa976e63fcf7ec22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b1cacf4ef462b144fa976e63fcf7ec22 = L.map(
#                 &quot;map_b1cacf4ef462b144fa976e63fcf7ec22&quot;,
#                 {
#                     center: [26.14771492013423, -80.19127271342282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_8a769e2260422ac28aff82a56cb9ccef = L.featureGroup(
#                 {}
#             ).addTo(map_b1cacf4ef462b144fa976e63fcf7ec22);
#
#
#             var marker_3911f96e7fb2672d22a060b66ae5bf94 = L.marker(
#                 [25.9787316, -80.1187739],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_8a769e2260422ac28aff82a56cb9ccef);
#
#
#             var icon_a5dc1b062d4084863bb0133ba9c87647 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3911f96e7fb2672d22a060b66ae5bf94.setIcon(icon_a5dc1b062d4084863bb0133ba9c87647);
#
#
#         var popup_113da30bdc96bd6b64c042b5b652a09d = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_efaaa3f5c09c7937a7d800c3304f379c = $(`&lt;div id=&quot;html_efaaa3f5c09c7937a7d800c3304f379c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2000 S Ocean Dr Unit 21A&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,400,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,167.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,913.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2021.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_113da30bdc96bd6b64c042b5b652a09d.setContent(html_efaaa3f5c09c7937a7d800c3304f379c);
#
#
#
#         marker_3911f96e7fb2672d22a060b66ae5bf94.bindPopup(popup_113da30bdc96bd6b64c042b5b652a09d)
#         ;
#
#
#
#
#             var feature_group_0b52528d2700f3ed01cc3e96edd91523 = L.featureGroup(
#                 {}
#             ).addTo(map_b1cacf4ef462b144fa976e63fcf7ec22);
#
#
#             var marker_8e262df95f857d95e8ef39f88a91fe91 = L.marker(
#                 [26.1396472, -80.1189664],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_0b52528d2700f3ed01cc3e96edd91523);
#
#
#             var icon_01451e95fb6c7a4611b8f3af4a7ae8d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e262df95f857d95e8ef39f88a91fe91.setIcon(icon_01451e95fb6c7a4611b8f3af4a7ae8d5);
#
#
#         var popup_4ea93899d0c9a1600669e648f46a86c7 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_709b0bd04bab27d1eb1c577b2827ba69 = $(`&lt;div id=&quot;html_709b0bd04bab27d1eb1c577b2827ba69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1180 N Federal Hwy #1006&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,100,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$875.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,400.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_4ea93899d0c9a1600669e648f46a86c7.setContent(html_709b0bd04bab27d1eb1c577b2827ba69);
#
#
#
#         marker_8e262df95f857d95e8ef39f88a91fe91.bindPopup(popup_4ea93899d0c9a1600669e648f46a86c7)
#         ;
#
#
#
#
#             var marker_0df7af5acfcb4a401efc2e8de105bacc = L.marker(
#                 [26.1188355, -80.1414763],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_0b52528d2700f3ed01cc3e96edd91523);
#
#
#             var icon_7695d4438899497d198a7c2019186316 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0df7af5acfcb4a401efc2e8de105bacc.setIcon(icon_7695d4438899497d198a7c2019186316);
#
#
#         var popup_f538d85555e156fd8f286c6a4c46fa89 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_c101906a8d51f9054d16a37d83364998 = $(`&l

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op  2000 S Ocean Dr Unit 21A
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
#
#    BATHS    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  2000 Ocean       2913.0       NaN      2021.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1167.0     7670.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...  MARMLS  A11666798
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...      Leslie Clark
#
#              list_broker_name_1         list_agent_name_2  \
# 0  Fortune International Realty  Bianca Boscacci Balduzzi
#
#              list_broker_name_2 buy_agent_name_1      buy_broker_name_1  \
# 0  Fortune International Realty      Yael Sultan  Avanti Way Realty LLC
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_11042024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '2000 Ocean at 2000 S Ocean Dr Unit 21A in Hallandale Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op                2000 S Ocean Dr Unit 21A
# 1  PAST SALE 2024-11-01   Condo/Co-op                1180 N Federal Hwy #1006
# 2  PAST SALE 2024-10-30   Condo/Co-op               100 E Las Olas Blvd #3001
# 3  PAST SALE 2024-10-28   Condo/Co-op                 2895 NE 33rd Ct Unit 2B
# 4  PAST SALE 2024-10-28   Condo/Co-op                   1800 S Ocean Dr #3801
# 5  PAST SALE 2024-10-29   Condo/Co-op                  333 Las Olas Way #1507
# 6  PAST SALE 2024-10-29   Condo/Co-op                1228 Hillsboro Mile #101
# 7  PAST SALE 2024-10-31   Condo/Co-op                   3111 N Ocean Dr #1607
# 8  PAST SALE 2024-10-31   Condo/Co-op                     411 NW 1st Ave #502
# 9  PAST SALE 2024-10-29   Condo/Co-op  2600 E Hallandale Beach Blvd Unit T701
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
# 1   Fort Lauderdale                FL             33304.0  2100000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1975000.0   3.0
# 3   Fort Lauderdale                FL             33306.0  1850000.0   3.0
# 4  Hallandale Beach                FL             33009.0  1750000.0   3.0
# 5   Fort Lauderdale                FL             33301.0  1065000.0   2.0
# 6   Hillsboro Beach                FL             33062.0   950000.0   3.0
# 7         Hollywood                FL             33019.0   925000.0   3.0
# 8   Fort Lauderdale                FL             33301.0   800000.0   2.0
# 9  Hallandale Beach                FL             33009.0   795000.0   3.0
#
#    BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  2000 Ocean       2913.0       NaN      2021.0
# 1    3.5                        Riva       2400.0       NaN      2018.0
# 2    2.5    100 Las Olas Condominium       2395.0       NaN      2020.0
# 3    3.5  33INTRACOASTAL CONDOMINIUM       1878.0       NaN      2018.0
# 4    3.5            BEACH CLUB THREE       2078.0       NaN      2007.0
# 5    2.5   LAS OLAS RIVER HOUSE COND       1522.0       NaN      2004.0
# 6    2.5          Mediterranea Condo       2160.0       NaN      1999.0
# 7    2.5            Hollywood Towers       1650.0       NaN      1967.0
# 8    2.0               Foundry Lofts       1521.0       NaN      2007.0
# 9    3.0       BEACHWALK CONDOMINIUM       1853.0       NaN      2015.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1167.0     7670.0   Sold
# 1             NaN          875.0     2370.0   Sold
# 2             NaN          825.0     2794.0   Sold
# 3             NaN          985.0     2027.0   Sold
# 4             NaN          842.0     1674.0   Sold
# 5             NaN          700.0     1731.0   Sold
# 6             NaN          440.0     1973.0   Sold
# 7             NaN          561.0     1215.0   Sold
# 8             NaN          526.0     1300.0   Sold
# 9             NaN          429.0     2101.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11666798
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...  Beaches MLS  F10455424
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10458018
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...       MARMLS  A11656849
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...       MARMLS  A11593823
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11513221
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...  Beaches MLS  F10425148
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...  Beaches MLS  F10433465
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...  Beaches MLS  F10403208
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS  A11546247
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.139647 -80.118966
# 2        N          Y  26.118835 -80.141476
# 3        N          Y  26.169738 -80.104635
# 4        N          Y  25.985667 -80.118693
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.304202 -80.077943
# 7        N          Y  26.030688 -80.115514
# 8        N          Y  26.126606 -80.144908
# 9        N          Y  25.985942 -80.122707
#
#                                                  url        list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...             Leslie Clark
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...       Elizabeth Caldwell
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...        Elvira Santamaria
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...          Megan Kowalchuk
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...                     None
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Steven Yaroslawitz
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...              John Putzig
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...                Moe Mossa
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...           Timothy Singer
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...  Ricardo Schilkrut Cogan
#
#                    list_broker_name_1         list_agent_name_2  \
# 0        Fortune International Realty  Bianca Boscacci Balduzzi
# 1                Compass Florida, LLC                      None
# 2        Beckett Realty Advisors, LLC           Kenneth Beckett
# 3                     Douglas Elliman                      None
# 4                                None                      None
# 5       Charles Rutenberg Realty Fort                      None
# 6                        RE/MAX First              Susan Nelson
# 7                   Savvy Avenue, LLC                      None
# 8              Coldwell Banker Realty            Timothy Powers
# 9  One Sotheby's International Realty                      None
#
#              list_broker_name_2  buy_agent_name_1  \
# 0  Fortune International Realty       Yael Sultan
# 1                          None  James Cunningham
# 2  Beckett Realty Advisors, LLC      Catina Jones
# 3                          None  Richard Kallabat
# 4                          None              None
# 5                          None              None
# 6                  RE/MAX First       Dany Landry
# 7                          None      Beth Jenkins
# 8        Coldwell Banker Realty   Eirini Melaniti
# 9                          None   Benjamin Figgie
#
#                      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                Avanti Way Realty LLC             None              None
# 1           One Sotheby's Int'l Realty             None              None
# 2  Aston Rose Sports And Entertainment             None              None
# 3       Keller Williams Capital Realty             None              None
# 4                                 None             None              None
# 5                                 None             None              None
# 6           Royal International Realty             None              None
# 7                 Compass Florida, LLC             None              None
# 8               Coldwell Banker Realty             None              None
# 9              Miami Waterfront Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  2000 Ocean at 2000 S Ocean Dr Unit 21A in Hall...
# 1     2    blue  Riva at 1180 N Federal Hwy #1006 in Fort Laude...
# 2     3    blue  100 Las Olas Condominium at 100 E Las Olas Blv...
# 3     4    blue  33INTRACOASTAL CONDOMINIUM at 2895 NE 33rd Ct ...
# 4     5    blue  BEACH CLUB THREE at 1800 S Ocean Dr #3801 in H...
# 5     6    blue  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6     7    blue  Mediterranea Condo at 1228 Hillsboro Mile #101...
# 7     8    blue  Hollywood Towers at 3111 N Ocean Dr #1607 in H...
# 8     9    blue  Foundry Lofts at 411 NW 1st Ave #502 in Fort L...
# 9    10    blue  BEACHWALK CONDOMINIUM at 2600 E Hallandale Bea...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: 2000 Ocean closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $795,000M to $3,400,000M
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Broward condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hollywood, Hillsboro Beach, Fort Lauderdale, Hallandale Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 149 condo sales totaling $48,914,535 million from Oct. 27th to Nov. 3rd. The previous week, brokers closed 98 condo sales totaling $33,500,000.
#
# Last week’s units sold for an average of $328,285, higher than the $303,409 average price from the previous week. The average price per square foot fell to $263 from $277, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $795,000.0 million to $3,400,000.0 million.
#
# 2000 Ocean at 2000 S Ocean Dr Unit 21A in Hallandale Beach took the top spot with a $3,400,000.0 million closing. The sale closed at $1,167.0 per square foot.
#
# Leslie Clark with Fortune International Realty, and Bianca Boscacci Balduzzi with Fortune International Realty had the listing.
# Yael Sultan with Avanti Way Realty LLC, and None with None represented the buyer.
#
# Riva at 1180 N Federal Hwy #1006 in Fort Lauderdale, closed for the second highest amount, $2,100,000.0, or $875.0 per square foot.
#
# Elizabeth Caldwell with Compass Florida, LLC, and None with None had the listing.
# James Cunningham with One Sotheby's Int'l Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_11042024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Oct. 27th to Nov. 3rd:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op                2000 S Ocean Dr Unit 21A
# 1  PAST SALE 2024-11-01   Condo/Co-op                1180 N Federal Hwy #1006
# 2  PAST SALE 2024-10-30   Condo/Co-op               100 E Las Olas Blvd #3001
# 3  PAST SALE 2024-10-28   Condo/Co-op                 2895 NE 33rd Ct Unit 2B
# 4  PAST SALE 2024-10-28   Condo/Co-op                   1800 S Ocean Dr #3801
# 5  PAST SALE 2024-10-29   Condo/Co-op                  333 Las Olas Way #1507
# 6  PAST SALE 2024-10-29   Condo/Co-op                1228 Hillsboro Mile #101
# 7  PAST SALE 2024-10-31   Condo/Co-op                   3111 N Ocean Dr #1607
# 8  PAST SALE 2024-10-31   Condo/Co-op                     411 NW 1st Ave #502
# 9  PAST SALE 2024-10-29   Condo/Co-op  2600 E Hallandale Beach Blvd Unit T701
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
# 1   Fort Lauderdale                FL             33304.0  2100000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1975000.0   3.0
# 3   Fort Lauderdale                FL             33306.0  1850000.0   3.0
# 4  Hallandale Beach                FL             33009.0  1750000.0   3.0
# 5   Fort Lauderdale                FL             33301.0  1065000.0   2.0
# 6   Hillsboro Beach                FL             33062.0   950000.0   3.0
# 7         Hollywood                FL             33019.0   925000.0   3.0
# 8   Fort Lauderdale                FL             33301.0   800000.0   2.0
# 9  Hallandale Beach                FL             33009.0   795000.0   3.0
#
#    BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  2000 Ocean       2913.0       NaN      2021.0
# 1    3.5                        Riva       2400.0       NaN      2018.0
# 2    2.5    100 Las Olas Condominium       2395.0       NaN      2020.0
# 3    3.5  33INTRACOASTAL CONDOMINIUM       1878.0       NaN      2018.0
# 4    3.5            BEACH CLUB THREE       2078.0       NaN      2007.0
# 5    2.5   LAS OLAS RIVER HOUSE COND       1522.0       NaN      2004.0
# 6    2.5          Mediterranea Condo       2160.0       NaN      1999.0
# 7    2.5            Hollywood Towers       1650.0       NaN      1967.0
# 8    2.0               Foundry Lofts       1521.0       NaN      2007.0
# 9    3.0       BEACHWALK CONDOMINIUM       1853.0       NaN      2015.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1167.0     7670.0   Sold
# 1             NaN          875.0     2370.0   Sold
# 2             NaN          825.0     2794.0   Sold
# 3             NaN          985.0     2027.0   Sold
# 4             NaN          842.0     1674.0   Sold
# 5             NaN          700.0     1731.0   Sold
# 6             NaN          440.0     1973.0   Sold
# 7             NaN          561.0     1215.0   Sold
# 8             NaN          526.0     1300.0   Sold
# 9             NaN          429.0     2101.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11666798
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...  Beaches MLS  F10455424
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10458018
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...       MARMLS  A11656849
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...       MARMLS  A11593823
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11513221
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...  Beaches MLS  F10425148
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...  Beaches MLS  F10433465
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...  Beaches MLS  F10403208
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS  A11546247
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.139647 -80.118966
# 2        N          Y  26.118835 -80.141476
# 3        N          Y  26.169738 -80.104635
# 4        N          Y  25.985667 -80.118693
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.304202 -80.077943
# 7        N          Y  26.030688 -80.115514
# 8        N          Y  26.126606 -80.144908
# 9        N          Y  25.985942 -80.122707
#
#                                                  url        list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...             Leslie Clark
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...       Elizabeth Caldwell
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...        Elvira Santamaria
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...          Megan Kowalchuk
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...                     None
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Steven Yaroslawitz
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...              John Putzig
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...                Moe Mossa
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...           Timothy Singer
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...  Ricardo Schilkrut Cogan
#
#                    list_broker_name_1         list_agent_name_2  \
# 0        Fortune International Realty  Bianca Boscacci Balduzzi
# 1                Compass Florida, LLC                      None
# 2        Beckett Realty Advisors, LLC           Kenneth Beckett
# 3                     Douglas Elliman                      None
# 4                                None                      None
# 5       Charles Rutenberg Realty Fort                      None
# 6                        RE/MAX First              Susan Nelson
# 7                   Savvy Avenue, LLC                      None
# 8              Coldwell Banker Realty            Timothy Powers
# 9  One Sotheby's International Realty                      None
#
#              list_broker_name_2  buy_agent_name_1  \
# 0  Fortune International Realty       Yael Sultan
# 1                          None  James Cunningham
# 2  Beckett Realty Advisors, LLC      Catina Jones
# 3                          None  Richard Kallabat
# 4                          None              None
# 5                          None              None
# 6                  RE/MAX First       Dany Landry
# 7                          None      Beth Jenkins
# 8        Coldwell Banker Realty   Eirini Melaniti
# 9                          None   Benjamin Figgie
#
#                      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                Avanti Way Realty LLC             None              None
# 1           One Sotheby's Int'l Realty             None              None
# 2  Aston Rose Sports And Entertainment             None              None
# 3       Keller Williams Capital Realty             None              None
# 4                                 None             None              None
# 5                                 None             None              None
# 6           Royal International Realty             None              None
# 7                 Compass Florida, LLC             None              None
# 8               Coldwell Banker Realty             None              None
# 9              Miami Waterfront Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  2000 Ocean at 2000 S Ocean Dr Unit 21A in Hall...
# 1     2    blue  Riva at 1180 N Federal Hwy #1006 in Fort Laude...
# 2     3    blue  100 Las Olas Condominium at 100 E Las Olas Blv...
# 3     4    blue  33INTRACOASTAL CONDOMINIUM at 2895 NE 33rd Ct ...
# 4     5    blue  BEACH CLUB THREE at 1800 S Ocean Dr #3801 in H...
# 5     6    blue  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6     7    blue  Mediterranea Condo at 1228 Hillsboro Mile #101...
# 7     8    blue  Hollywood Towers at 3111 N Ocean Dr #1607 in H...
# 8     9    blue  Foundry Lofts at 411 NW 1st Ave #502 in Fort L...
# 9    10    blue  BEACHWALK CONDOMINIUM at 2600 E Hallandale Bea...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: 2000 Ocean closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $795,000M to $3,400,000M
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Broward condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hollywood, Hillsboro Beach, Fort Lauderdale, Hallandale Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 149 condo sales totaling $48,914,535 million from Oct. 27th to Nov. 3rd. The previous week, brokers closed 98 condo sales totaling $33,500,000.
#
# Last week’s units sold for an average of $328,285, higher than the $303,409 average price from the previous week. The average price per square foot fell to $263 from $277, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $795,000.0 million to $3,400,000.0 million.
#
# 2000 Ocean at 2000 S Ocean Dr Unit 21A in Hallandale Beach took the top spot with a $3,400,000.0 million closing. The sale closed at $1,167.0 per square foot.
#
# Leslie Clark with Fortune International Realty, and Bianca Boscacci Balduzzi with Fortune International Realty had the listing.
# Yael Sultan with Avanti Way Realty LLC, and None with None represented the buyer.
#
# Riva at 1180 N Federal Hwy #1006 in Fort Lauderdale, closed for the second highest amount, $2,100,000.0, or $875.0 per square foot.
#
# Elizabeth Caldwell with Compass Florida, LLC, and None with None had the listing.
# James Cunningham with One Sotheby's Int'l Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_11042024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Oct. 27th to Nov. 3rd:
#
# Most Expensive
# 2000 Ocean, 2000 S Ocean Dr Unit 21A, in Hallandale Beach | Price: $3,400,000 | $1,167 psf | Listing agents: Leslie Clark with Fortune International Realty and Bianca Boscacci Balduzzi with Fortune International Realty | Buyer's agents: Yael Sultan with Avanti Way Realty LLC and None with None
# Least Expensive
# BEACHWALK CONDOMINIUM, 2600 E Hallandale Beach Blvd Unit T701, in Hallandale Beach | Price: $795,000 | $429 psf | Listing agents: Ricardo Schilkrut Cogan with One Sotheby's International Realty and None with None | Buyer's agents: Benjamin Figgie with Miami Waterfront Realty and None with None
# Highest Price Per Square Foot
# 2000 Ocean, 2000 S Ocean Dr Unit 21A, in Hallandale Beach | Price: $3,400,000 | $1,167 psf | Listing agents: Leslie Clark with Fortune International Realty and Bianca Boscacci Balduzzi with Fortune International Realty | Buyer's agents: Yael Sultan with Avanti Way Realty LLC and None with None
# Lowest Price Per Square Foot
# BEACHWALK CONDOMINIUM, 2600 E Hallandale Beach Blvd Unit T701, in Hallandale Beach | Price: $795,000 | $429 psf | Listing agents: Ricardo Schilkrut Cogan with One Sotheby's International Realty and None with None | Buyer's agents: Benjamin Figgie with Miami Waterfront Realty and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/2000-S-Ocean-Dr-33009/unit-21A/home/172268446

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/1180-N-Federal-Hwy-33304/unit-1006/home/63058571

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/2600-E-Hallandale-Beach-Blvd-33009/unit-T701/home/55092510

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/411-NW-1st-Ave-33301/unit-502/home/42075355

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/2000-S-Ocean-Dr-33009/unit-21A/home/172268446

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/2600-E-Hallandale-Beach-Blvd-33009/unit-T701/home/55092510

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2024-10-30   Condo/Co-op                2000 S Ocean Dr Unit 21A
# 1  PAST SALE 2024-11-01   Condo/Co-op                1180 N Federal Hwy #1006
# 2  PAST SALE 2024-10-30   Condo/Co-op               100 E Las Olas Blvd #3001
# 3  PAST SALE 2024-10-28   Condo/Co-op                 2895 NE 33rd Ct Unit 2B
# 4  PAST SALE 2024-10-28   Condo/Co-op                   1800 S Ocean Dr #3801
# 5  PAST SALE 2024-10-29   Condo/Co-op                  333 Las Olas Way #1507
# 6  PAST SALE 2024-10-29   Condo/Co-op                1228 Hillsboro Mile #101
# 7  PAST SALE 2024-10-31   Condo/Co-op                   3111 N Ocean Dr #1607
# 8  PAST SALE 2024-10-31   Condo/Co-op                     411 NW 1st Ave #502
# 9  PAST SALE 2024-10-29   Condo/Co-op  2600 E Hallandale Beach Blvd Unit T701
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  3400000.0   3.0
# 1   Fort Lauderdale                FL             33304.0  2100000.0   3.0
# 2   Fort Lauderdale                FL             33301.0  1975000.0   3.0
# 3   Fort Lauderdale                FL             33306.0  1850000.0   3.0
# 4  Hallandale Beach                FL             33009.0  1750000.0   3.0
# 5   Fort Lauderdale                FL             33301.0  1065000.0   2.0
# 6   Hillsboro Beach                FL             33062.0   950000.0   3.0
# 7         Hollywood                FL             33019.0   925000.0   3.0
# 8   Fort Lauderdale                FL             33301.0   800000.0   2.0
# 9  Hallandale Beach                FL             33009.0   795000.0   3.0
#
#    BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5                  2000 Ocean       2913.0       NaN      2021.0
# 1    3.5                        Riva       2400.0       NaN      2018.0
# 2    2.5    100 Las Olas Condominium       2395.0       NaN      2020.0
# 3    3.5  33INTRACOASTAL CONDOMINIUM       1878.0       NaN      2018.0
# 4    3.5            BEACH CLUB THREE       2078.0       NaN      2007.0
# 5    2.5   LAS OLAS RIVER HOUSE COND       1522.0       NaN      2004.0
# 6    2.5          Mediterranea Condo       2160.0       NaN      1999.0
# 7    2.5            Hollywood Towers       1650.0       NaN      1967.0
# 8    2.0               Foundry Lofts       1521.0       NaN      2007.0
# 9    3.0       BEACHWALK CONDOMINIUM       1853.0       NaN      2015.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1167.0     7670.0   Sold
# 1             NaN          875.0     2370.0   Sold
# 2             NaN          825.0     2794.0   Sold
# 3             NaN          985.0     2027.0   Sold
# 4             NaN          842.0     1674.0   Sold
# 5             NaN          700.0     1731.0   Sold
# 6             NaN          440.0     1973.0   Sold
# 7             NaN          561.0     1215.0   Sold
# 8             NaN          526.0     1300.0   Sold
# 9             NaN          429.0     2101.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11666798
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...  Beaches MLS  F10455424
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10458018
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...       MARMLS  A11656849
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...       MARMLS  A11593823
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS  A11513221
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...  Beaches MLS  F10425148
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...  Beaches MLS  F10433465
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...  Beaches MLS  F10403208
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS  A11546247
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.139647 -80.118966
# 2        N          Y  26.118835 -80.141476
# 3        N          Y  26.169738 -80.104635
# 4        N          Y  25.985667 -80.118693
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.304202 -80.077943
# 7        N          Y  26.030688 -80.115514
# 8        N          Y  26.126606 -80.144908
# 9        N          Y  25.985942 -80.122707
#
#                                                  url        list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...             Leslie Clark
# 1  https://www.redfin.com/FL/Fort-Lauderdale/1180...       Elizabeth Caldwell
# 2  https://www.redfin.com/FL/Fort-Lauderdale/100-...        Elvira Santamaria
# 3  https://www.redfin.com/FL/Fort-Lauderdale/2895...          Megan Kowalchuk
# 4  https://www.redfin.com/FL/Hallandale-Beach/180...                     None
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Steven Yaroslawitz
# 6  https://www.redfin.com/FL/Hillsboro-Beach/1228...              John Putzig
# 7  https://www.redfin.com/FL/Hollywood/3111-N-Oce...                Moe Mossa
# 8  https://www.redfin.com/FL/Fort-Lauderdale/411-...           Timothy Singer
# 9  https://www.redfin.com/FL/Hallandale-Beach/260...  Ricardo Schilkrut Cogan
#
#                    list_broker_name_1         list_agent_name_2  \
# 0        Fortune International Realty  Bianca Boscacci Balduzzi
# 1                Compass Florida, LLC                      None
# 2        Beckett Realty Advisors, LLC           Kenneth Beckett
# 3                     Douglas Elliman                      None
# 4                                None                      None
# 5       Charles Rutenberg Realty Fort                      None
# 6                        RE/MAX First              Susan Nelson
# 7                   Savvy Avenue, LLC                      None
# 8              Coldwell Banker Realty            Timothy Powers
# 9  One Sotheby's International Realty                      None
#
#              list_broker_name_2  buy_agent_name_1  \
# 0  Fortune International Realty       Yael Sultan
# 1                          None  James Cunningham
# 2  Beckett Realty Advisors, LLC      Catina Jones
# 3                          None  Richard Kallabat
# 4                          None              None
# 5                          None              None
# 6                  RE/MAX First       Dany Landry
# 7                          None      Beth Jenkins
# 8        Coldwell Banker Realty   Eirini Melaniti
# 9                          None   Benjamin Figgie
#
#                      buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                Avanti Way Realty LLC             None              None
# 1           One Sotheby's Int'l Realty             None              None
# 2  Aston Rose Sports And Entertainment             None              None
# 3       Keller Williams Capital Realty             None              None
# 4                                 None             None              None
# 5                                 None             None              None
# 6           Royal International Realty             None              None
# 7                 Compass Florida, LLC             None              None
# 8               Coldwell Banker Realty             None              None
# 9              Miami Waterfront Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  2000 Ocean at 2000 S Ocean Dr Unit 21A in Hall...
# 1     2    blue  Riva at 1180 N Federal Hwy #1006 in Fort Laude...
# 2     3    blue  100 Las Olas Condominium at 100 E Las Olas Blv...
# 3     4    blue  33INTRACOASTAL CONDOMINIUM at 2895 NE 33rd Ct ...
# 4     5    blue  BEACH CLUB THREE at 1800 S Ocean Dr #3801 in H...
# 5     6    blue  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 6     7    blue  Mediterranea Condo at 1228 Hillsboro Mile #101...
# 7     8    blue  Hollywood Towers at 3111 N Ocean Dr #1607 in H...
# 8     9    blue  Foundry Lofts at 411 NW 1st Ave #502 in Fort L...
# 9    10    blue  BEACHWALK CONDOMINIUM at 2600 E Hallandale Bea...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 8, 11) ## List (Earlier) date
date2 = datetime(2024, 11, 1) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 82

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2024-10-30       2000 S Ocean Dr Unit 21A in Hallandale Beach  $3,400,000
# 1 2024-11-01        1180 N Federal Hwy #1006 in Fort Lauderdale  $2,100,000
# 2 2024-10-30       100 E Las Olas Blvd #3001 in Fort Lauderdale  $1,975,000
# 3 2024-10-28         2895 NE 33rd Ct Unit 2B in Fort Lauderdale  $1,850,000
# 4 2024-10-28          1800 S Ocean Dr #3801 in Hallandale Beach  $1,750,000
# 5 2024-10-29          333 Las Olas Way #1507 in Fort Lauderdale  $1,065,000
# 6 2024-10-29        1228 Hillsboro Mile #101 in Hillsboro Beach    $950,000
# 7 2024-10-31                 3111 N Ocean Dr #1607 in Hollywood    $925,000
# 8 2024-10-31             411 NW 1st Ave #502 in Fort Lauderdale    $800,000
# 9 2024-10-29  2600 E Hallandale Beach Blvd Unit T701 in Hall...    $795,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    3    3.5       2,913       2021        $1,167       MARMLS  A11666798
# 1    3    3.5       2,400       2018          $875  Beaches MLS  F10455424
# 2    3    2.5       2,395       2020          $825  Beaches MLS  F10458018
# 3    3    3.5       1,878       2018          $985       MARMLS  A11656849
# 4    3    3.5       2,078       2007          $842       MARMLS  A11593823
# 5    2    2.5       1,522       2004          $700       MARMLS  A11513221
# 6    3    2.5       2,160       1999          $440  Beaches MLS  F10425148
# 7    3    2.5       1,650       1967          $561  Beaches MLS  F10433465
# 8    2    2.0       1,521       2007          $526  Beaches MLS  F10403208
# 9    3    3.0       1,853       2015          $429       MARMLS  A11546247
#
#                                         LISTING INFO  \
# 0  Leslie Clark Fortune International Realty Bian...
# 1        Elizabeth Caldwell Compass Florida, LLC
# 2  Elvira Santamaria Beckett Realty Advisors, LLC...
# 3                Megan Kowalchuk Douglas Elliman
# 4
# 5  Steven Yaroslawitz Charles Rutenberg Realty Fo...
# 6  John Putzig RE/MAX First Susan Nelson RE/MAX F...
# 7                    Moe Mossa Savvy Avenue, LLC
# 8  Timothy Singer Coldwell Banker Realty Timothy ...
# 9  Ricardo Schilkrut Cogan One Sotheby's Internat...
#
#                                          BUYING INFO
# 0              Yael Sultan Avanti Way Realty LLC
# 1    James Cunningham One Sotheby's Int'l Realty
# 2  Catina Jones Aston Rose Sports And Entertainme...
# 3  Richard Kallabat Keller Williams Capital Realt...
# 4
# 5
# 6         Dany Landry Royal International Realty
# 7              Beth Jenkins Compass Florida, LLC
# 8         Eirini Melaniti Coldwell Banker Realty
# 9        Benjamin Figgie Miami Waterfront Realty
