# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 13th Apr. 20th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE               ADDRESS  \
# 1  PAST SALE  April-17-2025   Condo/Co-op  2829 NE 30th St #202
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Fort Lauderdale                FL             33306.0  215000.0   2.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2829...  Beaches MLS  F10490650
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  26.166166  -80.10766
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-15    32
# 2025-04-17    27
# 2025-04-14    23
# 2025-04-18    21
# 2025-04-16    14
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 100  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 46   PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 69   PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 106  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 76   PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 8    PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 26   PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 12   PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 25   PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 91   PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 100   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 46    Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 69    Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 106   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 76   Hallandale Beach                FL             33009.0  1435000.0   3.0
# 8    Hallandale Beach                FL             33009.0  1150000.0   3.0
# 26    Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 12    Fort Lauderdale                FL             33308.0   900000.0   3.0
# 25          Hollywood                FL             33019.0   860000.0   2.0
# 91    Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 100    6.5  ...   Sold                         NaN                       NaN
# 46     2.5  ...   Sold                         NaN                       NaN
# 69     3.0  ...   Sold                         NaN                       NaN
# 106    2.5  ...   Sold                         NaN                       NaN
# 76     3.0  ...   Sold                         NaN                       NaN
# 8      3.0  ...   Sold                         NaN                       NaN
# 26     3.0  ...   Sold                         NaN                       NaN
# 12     2.5  ...   Sold                         NaN                       NaN
# 25     2.0  ...   Sold                         NaN                       NaN
# 91     2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 100  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS
# 46   https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS
# 69   https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS
# 106  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 76   https://www.redfin.com/FL/Hallandale-Beach/185...       MARMLS
# 8    https://www.redfin.com/FL/Hallandale-Beach/194...       MARMLS
# 26   https://www.redfin.com/FL/Fort-Lauderdale/511-...  Beaches MLS
# 12   https://www.redfin.com/FL/Fort-Lauderdale/3410...       MARMLS
# 25   https://www.redfin.com/FL/Hollywood/4010-S-Oce...       MARMLS
# 91   https://www.redfin.com/FL/Fort-Lauderdale/3101...       MARMLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 100  F10464735         N          Y  26.130150 -80.104107
# 46   F10486037         N          Y  26.157113 -80.100624
# 69   F10474254         N          Y  26.121158 -80.120244
# 106  F10462714         N          Y  26.168258 -80.099279
# 76   A11708244         N          Y  25.984278 -80.118815
# 8    A11761546         N          Y  25.981318 -80.120771
# 26   F10479067         N          Y  26.129150 -80.108666
# 12   A11744890         N          Y  26.169850 -80.098531
# 25   A11757878         N          Y  25.987076 -80.120292
# 91   A11684913         N          Y  26.128581 -80.103951
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 1  PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 2  PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 3  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 4  PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 5  PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 6  PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 7  PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 8  PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 9  PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 1   Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 2   Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 4  Hallandale Beach                FL             33009.0  1435000.0   3.0
# 5  Hallandale Beach                FL             33009.0  1150000.0   3.0
# 6   Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   900000.0   3.0
# 8         Hollywood                FL             33019.0   860000.0   2.0
# 9   Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    6.5  ... -80.104107  https://www.redfin.com/FL/Fort-Lauderdale/525-...
# 1    2.5  ... -80.100624  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 2    3.0  ... -80.120244  https://www.redfin.com/FL/Fort-Lauderdale/20-I...
# 3    2.5  ... -80.099279  https://www.redfin.com/FL/Fort-Lauderdale/3100...
# 4    3.0  ... -80.118815  https://www.redfin.com/FL/Hallandale-Beach/185...
# 5    3.0  ... -80.120771  https://www.redfin.com/FL/Hallandale-Beach/194...
# 6    3.0  ... -80.108666  https://www.redfin.com/FL/Fort-Lauderdale/511-...
# 7    2.5  ... -80.098531  https://www.redfin.com/FL/Fort-Lauderdale/3410...
# 8    2.0  ... -80.120292  https://www.redfin.com/FL/Hollywood/4010-S-Oce...
# 9    2.0  ... -80.103951  https://www.redfin.com/FL/Fort-Lauderdale/3101...
#
#    list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0          Tim Elmes            Compass Florida, LLC               None
# 1      Heather Lefka    Florida Luxurious Properties               None
# 2   Samantha LaViola      DeBianchi Real Estate, LLC               None
# 3      Patricia Post             Post and Post, Inc.               None
# 4    Damira Liberman                        LoKation               None
# 5      Andre Lauzier          Coldwell Banker Realty               None
# 6       Rachel Buemi       D'Angelo Realty Group LLC               None
# 7       Juan Iarussi           Compass Florida, LLC.               None
# 8      Miriam Poggio  One Sotheby's International Re  Bautista Carugati
# 9      Michael Duris          Duris Real Estate, Inc               None
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None   Daniel Teixeira
# 1                            None              None
# 2                            None     Sherri Pfefer
# 3                            None     Patricia Post
# 4                            None         Leon Bell
# 5                            None   Franklin Gaitan
# 6                            None    Kyle Denlinger
# 7                            None              None
# 8  One Sotheby's International Re      Lesley Rojas
# 9                            None     Michael Duris
#
#                buy_broker_name_1  buy_agent_name_2       buy_broker_name_2
# 0                Douglas Elliman              None                    None
# 1          Million and Up Realty              None                    None
# 2         Coldwell Banker Realty      Megan Pfefer  Coldwell Banker Realty
# 3            Post and Post, Inc.              None                    None
# 4                   Sunny Realty              None                    None
# 5  Charles Rutenberg Realty Fort              None                    None
# 6                 EXP Realty LLC              None                    None
# 7                           None              None                    None
# 8              Elimar Realty Inc              None                    None
# 9         Duris Real Estate, Inc              None                    None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 117

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $436,635

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $316

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $51,086,250

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          117              436635          316                     51086250.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 138
# -----------
# Input Previous Week Condo Average Sales Price:
# 311070
# -----------
# Input Previous Week Condo Average PSF:
# 271
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 42927599.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33304.0  7800000.0   5.0
#
#    BATHS      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    6.5  Four Seasons       3892.0       NaN      2023.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2004.0     8373.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
#
#   FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0        N          Y  26.13015 -80.104107
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
#
#      list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Compass Florida, LLC              None               None  Daniel Teixeira
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 1  PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 2  PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 3  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 4  PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 5  PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 6  PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 7  PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 8  PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 9  PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 1   Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 2   Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 4  Hallandale Beach                FL             33009.0  1435000.0   3.0
# 5  Hallandale Beach                FL             33009.0  1150000.0   3.0
# 6   Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   900000.0   3.0
# 8         Hollywood                FL             33019.0   860000.0   2.0
# 9   Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5               Four Seasons       3892.0       NaN      2023.0
# 1    2.5                    Auberge       2119.0       NaN      2018.0
# 2    3.0                   Aqualuna       3134.0       NaN      2016.0
# 3    2.5                L'hermitage       2086.0       NaN      1997.0
# 4    3.0           BEACH CLUB CONDO       1841.0       NaN      2005.0
# 5    3.0  OCEAN MARINE YACHT CLUB C       1962.0       NaN      2007.0
# 6    3.0            Bayshore Towers       1640.0       NaN      1972.0
# 7    2.5           SOUTHPOINT CONDO       1859.0       NaN      1974.0
# 8    2.0     4010 SOUTH OCEAN CONDO       1075.0       NaN      2019.0
# 9    2.0  FORT LAUDERDALE RESIDENCE       1176.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2004.0     8373.0   Sold
# 1             NaN         1652.0     4356.0   Sold
# 2             NaN          622.0     2291.0   Sold
# 3             NaN          911.0     2918.0   Sold
# 4             NaN          779.0     1894.0   Sold
# 5             NaN          586.0     1622.0   Sold
# 6             NaN          610.0     1806.0   Sold
# 7             NaN          484.0     1442.0   Sold
# 8             NaN          800.0     1806.0   Sold
# 9             NaN          723.0     2150.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10486037
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10474254
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10462714
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...       MARMLS  A11708244
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...       MARMLS  A11761546
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...  Beaches MLS  F10479067
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...       MARMLS  A11744890
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...       MARMLS  A11757878
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...       MARMLS  A11684913
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.130150 -80.104107
# 1        N          Y  26.157113 -80.100624
# 2        N          Y  26.121158 -80.120244
# 3        N          Y  26.168258 -80.099279
# 4        N          Y  25.984278 -80.118815
# 5        N          Y  25.981318 -80.120771
# 6        N          Y  26.129150 -80.108666
# 7        N          Y  26.169850 -80.098531
# 8        N          Y  25.987076 -80.120292
# 9        N          Y  26.128581 -80.103951
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Heather Lefka
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Samantha LaViola
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...     Patricia Post
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...   Damira Liberman
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...     Andre Lauzier
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...      Rachel Buemi
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...      Juan Iarussi
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...     Miriam Poggio
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...     Michael Duris
#
#                list_broker_name_1  list_agent_name_2  \
# 0            Compass Florida, LLC               None
# 1    Florida Luxurious Properties               None
# 2      DeBianchi Real Estate, LLC               None
# 3             Post and Post, Inc.               None
# 4                        LoKation               None
# 5          Coldwell Banker Realty               None
# 6       D'Angelo Realty Group LLC               None
# 7           Compass Florida, LLC.               None
# 8  One Sotheby's International Re  Bautista Carugati
# 9          Duris Real Estate, Inc               None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None  Daniel Teixeira
# 1                            None             None
# 2                            None    Sherri Pfefer
# 3                            None    Patricia Post
# 4                            None        Leon Bell
# 5                            None  Franklin Gaitan
# 6                            None   Kyle Denlinger
# 7                            None             None
# 8  One Sotheby's International Re     Lesley Rojas
# 9                            None    Michael Duris
#
#                buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0                Douglas Elliman             None                    None
# 1          Million and Up Realty             None                    None
# 2         Coldwell Banker Realty     Megan Pfefer  Coldwell Banker Realty
# 3            Post and Post, Inc.             None                    None
# 4                   Sunny Realty             None                    None
# 5  Charles Rutenberg Realty Fort             None                    None
# 6                 EXP Realty LLC             None                    None
# 7                           None             None                    None
# 8              Elimar Realty Inc             None                    None
# 9         Duris Real Estate, Inc             None                    None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8181a4913e36c1927bd0b963147caa2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 13th — Apr. 20th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8181a4913e36c1927bd0b963147caa2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e8181a4913e36c1927bd0b963147caa2 = L.map(
#                 &quot;map_e8181a4913e36c1927bd0b963147caa2&quot;,
#                 {
#                     center: [26.14904795609756, -80.17102212195122],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_55001f1e072ff873210d24e8438b85b0 = L.featureGroup(
#                 {}
#             ).addTo(map_e8181a4913e36c1927bd0b963147caa2);
#
#
#             var marker_57c3b87928498715f7398886704dfaf4 = L.marker(
#                 [26.1301495, -80.1041065],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_55001f1e072ff873210d24e8438b85b0);
#
#
#             var icon_4b26db1dba49c8a79bd6cf7902dc0672 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57c3b87928498715f7398886704dfaf4.setIcon(icon_4b26db1dba49c8a79bd6cf7902dc0672);
#
#
#         var popup_ec34889550f994f4a8ed255de3dbf565 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_825ea0f63a572f698475400d40bb5202 = $(`&lt;div id=&quot;html_825ea0f63a572f698475400d40bb5202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;525 N Ft Lauderdale Beach Blvd #1901&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,800,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,004.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,892.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2023.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ec34889550f994f4a8ed255de3dbf565.setContent(html_825ea0f63a572f698475400d40bb5202);
#
#
#
#         marker_57c3b87928498715f7398886704dfaf4.bindPopup(popup_ec34889550f994f4a8ed255de3dbf565)
#         ;
#
#
#
#
#             var feature_group_efacf94a4aebfdc7c18e72ff4a137210 = L.featureGroup(
#                 {}
#             ).addTo(map_e8181a4913e36c1927bd0b963147caa2);
#
#
#             var marker_c8770496749c8c972106bff984643cea = L.marker(
#                 [26.1571129, -80.1006236],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_efacf94a4aebfdc7c18e72ff4a137210);
#
#
#             var icon_4fb3cd18f8b1f129df7908ef4b05d63f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8770496749c8c972106bff984643cea.setIcon(icon_4fb3cd18f8b1f129df7908ef4b05d63f);
#
#
#         var popup_75be06131d0a608c8547a3dc558c7f67 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_4b0abc380244215f6da8f310ed901613 = $(`&lt;div id=&quot;html_4b0abc380244215f6da8f310ed901613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2200 N Ocean Blvd Unit N903&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,500,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,652.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,119.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_75be06131d0a608c8547a3dc558c7f67.setContent(html_4b0abc380244215f6da8f310ed901613);
#
#
#
#         marker_c8770496749c8c972106bff984643cea.bindPopup(popup_75be06131d0a608c8547a3dc558c7f67)
#         ;
#
#
#
#
#             var marker_4200d6ba8dac7712a8554b256b12cfc0 = L.marker(
#                 [26.1211583, -80.1202441],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_efacf94a4aebfdc7c18e72ff4a137210);
#
#
#             var icon_69064aa42b552ad4a4a1a5d197c6cfa0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4200d6ba8dac7712a8554b256b12cfc0.setIcon(icon_69064aa42b552ad4a4a1a5d197c6cfa0);
#
#
#         var popup_b6156dd0f09af52deb98c2a3c56a92f3 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_546c6c4d523fb30036

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33304.0  7800000.0   5.0
#
#    BATHS      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    6.5  Four Seasons       3892.0       NaN      2023.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2004.0     8373.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
#
#   FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0        N          Y  26.13015 -80.104107
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
#
#      list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0  Compass Florida, LLC              None               None  Daniel Teixeira
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04212025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Four Seasons at 525 N Ft Lauderdale Beach Blvd #1901 in Fort Lauderdale'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 1  PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 2  PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 3  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 4  PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 5  PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 6  PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 7  PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 8  PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 9  PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 1   Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 2   Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 4  Hallandale Beach                FL             33009.0  1435000.0   3.0
# 5  Hallandale Beach                FL             33009.0  1150000.0   3.0
# 6   Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   900000.0   3.0
# 8         Hollywood                FL             33019.0   860000.0   2.0
# 9   Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5               Four Seasons       3892.0       NaN      2023.0
# 1    2.5                    Auberge       2119.0       NaN      2018.0
# 2    3.0                   Aqualuna       3134.0       NaN      2016.0
# 3    2.5                L'hermitage       2086.0       NaN      1997.0
# 4    3.0           BEACH CLUB CONDO       1841.0       NaN      2005.0
# 5    3.0  OCEAN MARINE YACHT CLUB C       1962.0       NaN      2007.0
# 6    3.0            Bayshore Towers       1640.0       NaN      1972.0
# 7    2.5           SOUTHPOINT CONDO       1859.0       NaN      1974.0
# 8    2.0     4010 SOUTH OCEAN CONDO       1075.0       NaN      2019.0
# 9    2.0  FORT LAUDERDALE RESIDENCE       1176.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2004.0     8373.0   Sold
# 1             NaN         1652.0     4356.0   Sold
# 2             NaN          622.0     2291.0   Sold
# 3             NaN          911.0     2918.0   Sold
# 4             NaN          779.0     1894.0   Sold
# 5             NaN          586.0     1622.0   Sold
# 6             NaN          610.0     1806.0   Sold
# 7             NaN          484.0     1442.0   Sold
# 8             NaN          800.0     1806.0   Sold
# 9             NaN          723.0     2150.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10486037
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10474254
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10462714
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...       MARMLS  A11708244
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...       MARMLS  A11761546
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...  Beaches MLS  F10479067
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...       MARMLS  A11744890
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...       MARMLS  A11757878
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...       MARMLS  A11684913
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.130150 -80.104107
# 1        N          Y  26.157113 -80.100624
# 2        N          Y  26.121158 -80.120244
# 3        N          Y  26.168258 -80.099279
# 4        N          Y  25.984278 -80.118815
# 5        N          Y  25.981318 -80.120771
# 6        N          Y  26.129150 -80.108666
# 7        N          Y  26.169850 -80.098531
# 8        N          Y  25.987076 -80.120292
# 9        N          Y  26.128581 -80.103951
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Heather Lefka
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Samantha LaViola
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...     Patricia Post
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...   Damira Liberman
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...     Andre Lauzier
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...      Rachel Buemi
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...      Juan Iarussi
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...     Miriam Poggio
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...     Michael Duris
#
#                list_broker_name_1  list_agent_name_2  \
# 0            Compass Florida, LLC               None
# 1    Florida Luxurious Properties               None
# 2      DeBianchi Real Estate, LLC               None
# 3             Post and Post, Inc.               None
# 4                        LoKation               None
# 5          Coldwell Banker Realty               None
# 6       D'Angelo Realty Group LLC               None
# 7           Compass Florida, LLC.               None
# 8  One Sotheby's International Re  Bautista Carugati
# 9          Duris Real Estate, Inc               None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None  Daniel Teixeira
# 1                            None             None
# 2                            None    Sherri Pfefer
# 3                            None    Patricia Post
# 4                            None        Leon Bell
# 5                            None  Franklin Gaitan
# 6                            None   Kyle Denlinger
# 7                            None             None
# 8  One Sotheby's International Re     Lesley Rojas
# 9                            None    Michael Duris
#
#                buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0                Douglas Elliman             None                    None
# 1          Million and Up Realty             None                    None
# 2         Coldwell Banker Realty     Megan Pfefer  Coldwell Banker Realty
# 3            Post and Post, Inc.             None                    None
# 4                   Sunny Realty             None                    None
# 5  Charles Rutenberg Realty Fort             None                    None
# 6                 EXP Realty LLC             None                    None
# 7                           None             None                    None
# 8              Elimar Realty Inc             None                    None
# 9         Duris Real Estate, Inc             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Four Seasons at 525 N Ft Lauderdale Beach Blvd...
# 1     2    blue  Auberge at 2200 N Ocean Blvd Unit N903 in Fort...
# 2     3    blue  Aqualuna at 20 Isle Of Venice Dr #201 in Fort ...
# 3     4    blue  L'hermitage at 3100 N Ocean Blvd #2507 in Fort...
# 4     5    blue  BEACH CLUB CONDO at 1850 S Ocean Dr #3502 in H...
# 5     6    blue  OCEAN MARINE YACHT CLUB C at 1945 S Ocean Dr #...
# 6     7    blue  Bayshore Towers at 511 Bayshore Dr #807 in For...
# 7     8    blue  SOUTHPOINT CONDO at 3410 Galt Ocean Dr Unit 11...
# 8     9    blue  4010 SOUTH OCEAN CONDO at 4010 S Ocean Dr Unit...
# 9    10    blue  FORT LAUDERDALE RESIDENCE at 3101 Bayshore Dr ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Four Seasons closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $850,000 to $7,800,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hallandale Beach, Fort Lauderdale, Hollywood, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 117 condo sales totaling $51,086,250 million from Apr. 13th to Apr. 20th. The previous week, brokers closed 138 condo sales totaling $42,927,599.
#
# Last week’s units sold for an average of $436,635, higher than the $311,070 average price from the previous week. The average price per square foot rose to $316 from $271, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $850,000.0 million to $7,800,000.0 million.
#
# Four Seasons at 525 N Ft Lauderdale Beach Blvd #1901 in Fort Lauderdale took the top spot with a $7,800,000.0 million closing. The sale closed at $2,004.0 per square foot.
#
# Tim Elmes with Compass Florida, LLC, and None with None had the listing.
# Daniel Teixeira with Douglas Elliman, and None with None represented the buyer.
#
# Auberge at 2200 N Ocean Blvd Unit N903 in Fort Lauderdale, closed for the second highest amount, $3,500,000.0, or $1,652.0 per square foot.
#
# Heather Lefka with Florida Luxurious Properties, and None with None had the listing.
# None with Million and Up Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04212025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 13th to Apr. 20th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 1  PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 2  PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 3  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 4  PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 5  PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 6  PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 7  PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 8  PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 9  PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 1   Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 2   Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 4  Hallandale Beach                FL             33009.0  1435000.0   3.0
# 5  Hallandale Beach                FL             33009.0  1150000.0   3.0
# 6   Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   900000.0   3.0
# 8         Hollywood                FL             33019.0   860000.0   2.0
# 9   Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5               Four Seasons       3892.0       NaN      2023.0
# 1    2.5                    Auberge       2119.0       NaN      2018.0
# 2    3.0                   Aqualuna       3134.0       NaN      2016.0
# 3    2.5                L'hermitage       2086.0       NaN      1997.0
# 4    3.0           BEACH CLUB CONDO       1841.0       NaN      2005.0
# 5    3.0  OCEAN MARINE YACHT CLUB C       1962.0       NaN      2007.0
# 6    3.0            Bayshore Towers       1640.0       NaN      1972.0
# 7    2.5           SOUTHPOINT CONDO       1859.0       NaN      1974.0
# 8    2.0     4010 SOUTH OCEAN CONDO       1075.0       NaN      2019.0
# 9    2.0  FORT LAUDERDALE RESIDENCE       1176.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2004.0     8373.0   Sold
# 1             NaN         1652.0     4356.0   Sold
# 2             NaN          622.0     2291.0   Sold
# 3             NaN          911.0     2918.0   Sold
# 4             NaN          779.0     1894.0   Sold
# 5             NaN          586.0     1622.0   Sold
# 6             NaN          610.0     1806.0   Sold
# 7             NaN          484.0     1442.0   Sold
# 8             NaN          800.0     1806.0   Sold
# 9             NaN          723.0     2150.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10486037
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10474254
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10462714
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...       MARMLS  A11708244
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...       MARMLS  A11761546
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...  Beaches MLS  F10479067
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...       MARMLS  A11744890
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...       MARMLS  A11757878
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...       MARMLS  A11684913
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.130150 -80.104107
# 1        N          Y  26.157113 -80.100624
# 2        N          Y  26.121158 -80.120244
# 3        N          Y  26.168258 -80.099279
# 4        N          Y  25.984278 -80.118815
# 5        N          Y  25.981318 -80.120771
# 6        N          Y  26.129150 -80.108666
# 7        N          Y  26.169850 -80.098531
# 8        N          Y  25.987076 -80.120292
# 9        N          Y  26.128581 -80.103951
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Heather Lefka
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Samantha LaViola
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...     Patricia Post
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...   Damira Liberman
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...     Andre Lauzier
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...      Rachel Buemi
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...      Juan Iarussi
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...     Miriam Poggio
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...     Michael Duris
#
#                list_broker_name_1  list_agent_name_2  \
# 0            Compass Florida, LLC               None
# 1    Florida Luxurious Properties               None
# 2      DeBianchi Real Estate, LLC               None
# 3             Post and Post, Inc.               None
# 4                        LoKation               None
# 5          Coldwell Banker Realty               None
# 6       D'Angelo Realty Group LLC               None
# 7           Compass Florida, LLC.               None
# 8  One Sotheby's International Re  Bautista Carugati
# 9          Duris Real Estate, Inc               None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None  Daniel Teixeira
# 1                            None             None
# 2                            None    Sherri Pfefer
# 3                            None    Patricia Post
# 4                            None        Leon Bell
# 5                            None  Franklin Gaitan
# 6                            None   Kyle Denlinger
# 7                            None             None
# 8  One Sotheby's International Re     Lesley Rojas
# 9                            None    Michael Duris
#
#                buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0                Douglas Elliman             None                    None
# 1          Million and Up Realty             None                    None
# 2         Coldwell Banker Realty     Megan Pfefer  Coldwell Banker Realty
# 3            Post and Post, Inc.             None                    None
# 4                   Sunny Realty             None                    None
# 5  Charles Rutenberg Realty Fort             None                    None
# 6                 EXP Realty LLC             None                    None
# 7                           None             None                    None
# 8              Elimar Realty Inc             None                    None
# 9         Duris Real Estate, Inc             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Four Seasons at 525 N Ft Lauderdale Beach Blvd...
# 1     2    blue  Auberge at 2200 N Ocean Blvd Unit N903 in Fort...
# 2     3    blue  Aqualuna at 20 Isle Of Venice Dr #201 in Fort ...
# 3     4    blue  L'hermitage at 3100 N Ocean Blvd #2507 in Fort...
# 4     5    blue  BEACH CLUB CONDO at 1850 S Ocean Dr #3502 in H...
# 5     6    blue  OCEAN MARINE YACHT CLUB C at 1945 S Ocean Dr #...
# 6     7    blue  Bayshore Towers at 511 Bayshore Dr #807 in For...
# 7     8    blue  SOUTHPOINT CONDO at 3410 Galt Ocean Dr Unit 11...
# 8     9    blue  4010 SOUTH OCEAN CONDO at 4010 S Ocean Dr Unit...
# 9    10    blue  FORT LAUDERDALE RESIDENCE at 3101 Bayshore Dr ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Four Seasons closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $850,000 to $7,800,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Hallandale Beach, Fort Lauderdale, Hollywood, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 117 condo sales totaling $51,086,250 million from Apr. 13th to Apr. 20th. The previous week, brokers closed 138 condo sales totaling $42,927,599.
#
# Last week’s units sold for an average of $436,635, higher than the $311,070 average price from the previous week. The average price per square foot rose to $316 from $271, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $850,000.0 million to $7,800,000.0 million.
#
# Four Seasons at 525 N Ft Lauderdale Beach Blvd #1901 in Fort Lauderdale took the top spot with a $7,800,000.0 million closing. The sale closed at $2,004.0 per square foot.
#
# Tim Elmes with Compass Florida, LLC, and None with None had the listing.
# Daniel Teixeira with Douglas Elliman, and None with None represented the buyer.
#
# Auberge at 2200 N Ocean Blvd Unit N903 in Fort Lauderdale, closed for the second highest amount, $3,500,000.0, or $1,652.0 per square foot.
#
# Heather Lefka with Florida Luxurious Properties, and None with None had the listing.
# None with Million and Up Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04212025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 13th to Apr. 20th:
#
# Most Expensive
# Four Seasons, 525 N Ft Lauderdale Beach Blvd #1901, in Fort Lauderdale | Price: $7,800,000 | $2,004 psf | Listing agents: Tim Elmes with Compass Florida, LLC and None with None | Buyer's agents: Daniel Teixeira with Douglas Elliman and None with None
#
# Least Expensive
# FORT LAUDERDALE RESIDENCE, 3101 Bayshore Dr #1804, in Fort Lauderdale | Price: $850,000 | $723 psf | Listing agents: Michael Duris with Duris Real Estate, Inc and None with None | Buyer's agents: Michael Duris with Duris Real Estate, Inc and None with None
#
# Highest Price Per Square Foot
# Four Seasons, 525 N Ft Lauderdale Beach Blvd #1901, in Fort Lauderdale | Price: $7,800,000 | $2,004 psf | Listing agents: Tim Elmes with Compass Florida, LLC and None with None | Buyer's agents: Daniel Teixeira with Douglas Elliman and None with None
#
# Lowest Price Per Square Foot
# SOUTHPOINT CONDO, 3410 Galt Ocean Dr Unit 1109N, in Fort Lauderdale | Price: $900,000 | $484 psf | Listing agents: Juan Iarussi with Compass Florida, LLC. and None with None | Buyer's agents: None with None and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Fort-Lauderdale/525-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1901/home/145299094
# Second priciest sale:  https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N903/home/148578655
# Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/3101-Bayshore-Dr-33304/unit-1804/home/42082358
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Hollywood/4010-S-Ocean-Dr-33019/unit-T3702/home/172066685
# Highest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/525-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1901/home/145299094
# Lowest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/3410-Galt-Ocean-Dr-33308/unit-1109N/home/41708717

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Fort-Lauderdale/525-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1901/home/145299094

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N903/home/148578655

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/3101-Bayshore-Dr-33304/unit-1804/home/42082358

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Hollywood/4010-S-Ocean-Dr-33019/unit-T3702/home/172066685

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/525-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1901/home/145299094

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/3410-Galt-Ocean-Dr-33308/unit-1109N/home/41708717

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                               ADDRESS  \
# 0  PAST SALE 2025-04-17   Condo/Co-op  525 N Ft Lauderdale Beach Blvd #1901
# 1  PAST SALE 2025-04-17   Condo/Co-op           2200 N Ocean Blvd Unit N903
# 2  PAST SALE 2025-04-16   Condo/Co-op             20 Isle Of Venice Dr #201
# 3  PAST SALE 2025-04-18   Condo/Co-op               3100 N Ocean Blvd #2507
# 4  PAST SALE 2025-04-17   Condo/Co-op                 1850 S Ocean Dr #3502
# 5  PAST SALE 2025-04-15   Condo/Co-op                 1945 S Ocean Dr #2706
# 6  PAST SALE 2025-04-15   Condo/Co-op                  511 Bayshore Dr #807
# 7  PAST SALE 2025-04-17   Condo/Co-op         3410 Galt Ocean Dr Unit 1109N
# 8  PAST SALE 2025-04-15   Condo/Co-op            4010 S Ocean Dr Unit T3702
# 9  PAST SALE 2025-04-15   Condo/Co-op                3101 Bayshore Dr #1804
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0   Fort Lauderdale                FL             33304.0  7800000.0   5.0
# 1   Fort Lauderdale                FL             33305.0  3500000.0   2.0
# 2   Fort Lauderdale                FL             33301.0  1950000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1900000.0   2.0
# 4  Hallandale Beach                FL             33009.0  1435000.0   3.0
# 5  Hallandale Beach                FL             33009.0  1150000.0   3.0
# 6   Fort Lauderdale                FL             33304.0  1000000.0   3.0
# 7   Fort Lauderdale                FL             33308.0   900000.0   3.0
# 8         Hollywood                FL             33019.0   860000.0   2.0
# 9   Fort Lauderdale                FL             33304.0   850000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    6.5               Four Seasons       3892.0       NaN      2023.0
# 1    2.5                    Auberge       2119.0       NaN      2018.0
# 2    3.0                   Aqualuna       3134.0       NaN      2016.0
# 3    2.5                L'hermitage       2086.0       NaN      1997.0
# 4    3.0           BEACH CLUB CONDO       1841.0       NaN      2005.0
# 5    3.0  OCEAN MARINE YACHT CLUB C       1962.0       NaN      2007.0
# 6    3.0            Bayshore Towers       1640.0       NaN      1972.0
# 7    2.5           SOUTHPOINT CONDO       1859.0       NaN      1974.0
# 8    2.0     4010 SOUTH OCEAN CONDO       1075.0       NaN      2019.0
# 9    2.0  FORT LAUDERDALE RESIDENCE       1176.0       NaN      2010.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2004.0     8373.0   Sold
# 1             NaN         1652.0     4356.0   Sold
# 2             NaN          622.0     2291.0   Sold
# 3             NaN          911.0     2918.0   Sold
# 4             NaN          779.0     1894.0   Sold
# 5             NaN          586.0     1622.0   Sold
# 6             NaN          610.0     1806.0   Sold
# 7             NaN          484.0     1442.0   Sold
# 8             NaN          800.0     1806.0   Sold
# 9             NaN          723.0     2150.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...  Beaches MLS  F10464735
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...  Beaches MLS  F10486037
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10474254
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS  F10462714
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...       MARMLS  A11708244
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...       MARMLS  A11761546
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...  Beaches MLS  F10479067
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...       MARMLS  A11744890
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...       MARMLS  A11757878
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...       MARMLS  A11684913
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.130150 -80.104107
# 1        N          Y  26.157113 -80.100624
# 2        N          Y  26.121158 -80.120244
# 3        N          Y  26.168258 -80.099279
# 4        N          Y  25.984278 -80.118815
# 5        N          Y  25.981318 -80.120771
# 6        N          Y  26.129150 -80.108666
# 7        N          Y  26.169850 -80.098531
# 8        N          Y  25.987076 -80.120292
# 9        N          Y  26.128581 -80.103951
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/525-...         Tim Elmes
# 1  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Heather Lefka
# 2  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Samantha LaViola
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3100...     Patricia Post
# 4  https://www.redfin.com/FL/Hallandale-Beach/185...   Damira Liberman
# 5  https://www.redfin.com/FL/Hallandale-Beach/194...     Andre Lauzier
# 6  https://www.redfin.com/FL/Fort-Lauderdale/511-...      Rachel Buemi
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3410...      Juan Iarussi
# 8  https://www.redfin.com/FL/Hollywood/4010-S-Oce...     Miriam Poggio
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3101...     Michael Duris
#
#                list_broker_name_1  list_agent_name_2  \
# 0            Compass Florida, LLC               None
# 1    Florida Luxurious Properties               None
# 2      DeBianchi Real Estate, LLC               None
# 3             Post and Post, Inc.               None
# 4                        LoKation               None
# 5          Coldwell Banker Realty               None
# 6       D'Angelo Realty Group LLC               None
# 7           Compass Florida, LLC.               None
# 8  One Sotheby's International Re  Bautista Carugati
# 9          Duris Real Estate, Inc               None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None  Daniel Teixeira
# 1                            None             None
# 2                            None    Sherri Pfefer
# 3                            None    Patricia Post
# 4                            None        Leon Bell
# 5                            None  Franklin Gaitan
# 6                            None   Kyle Denlinger
# 7                            None             None
# 8  One Sotheby's International Re     Lesley Rojas
# 9                            None    Michael Duris
#
#                buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0                Douglas Elliman             None                    None
# 1          Million and Up Realty             None                    None
# 2         Coldwell Banker Realty     Megan Pfefer  Coldwell Banker Realty
# 3            Post and Post, Inc.             None                    None
# 4                   Sunny Realty             None                    None
# 5  Charles Rutenberg Realty Fort             None                    None
# 6                 EXP Realty LLC             None                    None
# 7                           None             None                    None
# 8              Elimar Realty Inc             None                    None
# 9         Duris Real Estate, Inc             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Four Seasons at 525 N Ft Lauderdale Beach Blvd...
# 1     2    blue  Auberge at 2200 N Ocean Blvd Unit N903 in Fort...
# 2     3    blue  Aqualuna at 20 Isle Of Venice Dr #201 in Fort ...
# 3     4    blue  L'hermitage at 3100 N Ocean Blvd #2507 in Fort...
# 4     5    blue  BEACH CLUB CONDO at 1850 S Ocean Dr #3502 in H...
# 5     6    blue  OCEAN MARINE YACHT CLUB C at 1945 S Ocean Dr #...
# 6     7    blue  Bayshore Towers at 511 Bayshore Dr #807 in For...
# 7     8    blue  SOUTHPOINT CONDO at 3410 Galt Ocean Dr Unit 11...
# 8     9    blue  4010 SOUTH OCEAN CONDO at 4010 S Ocean Dr Unit...
# 9    10    blue  FORT LAUDERDALE RESIDENCE at 3101 Bayshore Dr ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 2, 10) ## List (Earlier) date
date2 = datetime(2025, 4, 17) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 66

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    2004.0
# 1    1652.0
# 2     622.0
# 3     911.0
# 4     779.0
# 5     586.0
# 6     610.0
# 7     484.0
# 8     800.0
# 9     723.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2025-04-17  525 N Ft Lauderdale Beach Blvd #1901 in Fort L...  $7,800,000
# 1 2025-04-17     2200 N Ocean Blvd Unit N903 in Fort Lauderdale  $3,500,000
# 2 2025-04-16       20 Isle Of Venice Dr #201 in Fort Lauderdale  $1,950,000
# 3 2025-04-18         3100 N Ocean Blvd #2507 in Fort Lauderdale  $1,900,000
# 4 2025-04-17          1850 S Ocean Dr #3502 in Hallandale Beach  $1,435,000
# 5 2025-04-15          1945 S Ocean Dr #2706 in Hallandale Beach  $1,150,000
# 6 2025-04-15            511 Bayshore Dr #807 in Fort Lauderdale  $1,000,000
# 7 2025-04-17   3410 Galt Ocean Dr Unit 1109N in Fort Lauderdale    $900,000
# 8 2025-04-15            4010 S Ocean Dr Unit T3702 in Hollywood    $860,000
# 9 2025-04-15          3101 Bayshore Dr #1804 in Fort Lauderdale    $850,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    5    6.5       3,892       2023        $2,004  Beaches MLS  F10464735
# 1    2    2.5       2,119       2018        $1,652  Beaches MLS  F10486037
# 2    3    3.0       3,134       2016          $622  Beaches MLS  F10474254
# 3    2    2.5       2,086       1997          $911  Beaches MLS  F10462714
# 4    3    3.0       1,841       2005          $779       MARMLS  A11708244
# 5    3    3.0       1,962       2007          $586       MARMLS  A11761546
# 6    3    3.0       1,640       1972          $610  Beaches MLS  F10479067
# 7    3    2.5       1,859       1974          $484       MARMLS  A11744890
# 8    2    2.0       1,075       2019          $800       MARMLS  A11757878
# 9    2    2.0       1,176       2010          $723       MARMLS  A11684913
#
#                                         LISTING INFO  \
# 0                 Tim Elmes Compass Florida, LLC
# 1     Heather Lefka Florida Luxurious Properties
# 2    Samantha LaViola DeBianchi Real Estate, LLC
# 3              Patricia Post Post and Post, Inc.
# 4                       Damira Liberman LoKation
# 5           Andre Lauzier Coldwell Banker Realty
# 6         Rachel Buemi D'Angelo Realty Group LLC
# 7             Juan Iarussi Compass Florida, LLC.
# 8  Miriam Poggio One Sotheby's International Re B...
# 9           Michael Duris Duris Real Estate, Inc
#
#                                          BUYING INFO
# 0                Daniel Teixeira Douglas Elliman
# 1                          Million and Up Realty
# 2  Sherri Pfefer Coldwell Banker Realty Megan Pfe...
# 3              Patricia Post Post and Post, Inc.
# 4                         Leon Bell Sunny Realty
# 5  Franklin Gaitan Charles Rutenberg Realty Fort
# 6                  Kyle Denlinger EXP Realty LLC
# 7
# 8                 Lesley Rojas Elimar Realty Inc
# 9           Michael Duris Duris Real Estate, Inc
