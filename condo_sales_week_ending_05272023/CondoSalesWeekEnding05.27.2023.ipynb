# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import tabula

# %% [markdown]
# ## Read-in

# %%
# Gotta figure out how to get rid of the java error.
# SO: https://stackoverflow.com/questions/54817211/java-command-is-not-found-from-this-python-process-please-ensure-java-is-inst

dsf = tabula.io.read_pdf('condo.pdf', pages='all',lattice=True)

# %% [markdown]
# ## Clean Data

# %%
df = dsf[0]
df.columns = df.iloc[0]
df = df.drop(df.index[0])
### This next line gets ride of the Nan ###
df = df.iloc[: , 1:]
df = df.replace(np.nan, 'Not Available', regex=True)
df = df.rename(columns={'Building / Address / City': 'building_address_city','Days on\rMarket':'days_on_market',\
                        'Price /\rSq. Ft.':'price_per_sqft'})
df['geo_address'] = df['building_address_city']
df['geo_address'] = df['geo_address'].map(lambda x: re.sub(r'\r', ' ', x))
df = df.replace('\n',' ',regex=True)
df2 = df['geo_address'].str.extract(r'(?P<building_name>\D*)(?P<address_only>\d.*)', expand=True)

# %% [markdown]
# Review this later (it's about how to properly merge DFs): https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## Geocode

# %%
result = pd.merge(df,df2,left_index=True, right_index=True)
df = result

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# Folium documentation link: https://python-visualization.github.io/folium/index.html
#
# Folium is the library that lets us use leaflet with Python, since it's meant to be used with JavaScript.
#
# For adding titles: https://stackoverflow.com/questions/61928013/adding-a-title-or-text-to-a-folium-map

# %% [markdown]
# ## Correction section

# %%
df
# Out:
#                                 building_address_city Close Date
# 1   Oceana Bal Harbour\r10201 Collins Ave 2803\rBa...  5/22/2023  \
# 2   Estates the Acqualina\r17975 Collins Ave 2701\...  5/23/2023
# 3   Jade Signature\r16901 Collins Ave 3401\rSunny ...  5/24/2023
# 4   Residence by Armani Casa\r18975 Collins Ave 25...  5/22/2023
# 5   Bayside Village\r2221 Fisher Island Dr 3201\rF...  5/22/2023
# 6   Muse Condo\r17141 Collins Ave 2502\rSunny Isle...  5/25/2023
# 7   Brickell Flatiron\r1000 Brickell Plaza PH-6007...  5/26/2023
# 8   Paramount Miami World Center\r851 NE 1st Ave 3...  5/25/2023
# 9   South Pointe Towers Condo\r400 S Pointe Dr 710...  5/25/2023
# 10  0Williams Island\r2600 Island Blvd 2501\rAventura  5/24/2023
#
#    days_on_market      Sale Price Sq. Ft. price_per_sqft
# 1              91  $22,000,000.00    5183      $4,244.65  \
# 2              61  $10,965,000.00    4780      $2,293.93
# 3             117   $5,750,000.00    3012      $1,909.03
# 4             193   $4,210,000.00    2682      $1,569.72
# 5             275   $3,600,000.00    2744      $1,311.95
# 6              49   $2,750,000.00    2042      $1,346.72
# 7               8   $2,525,000.00    1800      $1,402.78
# 8              91   $2,300,000.00    3450        $747.72
# 9             118   $2,194,000.00    1559      $1,407.31
# 10              8   $1,700,000.00    2580        $658.91
#
#                     Agent                  Listing Broker
# 1        Ruthie Assouline                 Douglas Elliman  \
# 2        Karina Batievsky                Acqualina Realty
# 3           Cassio Faccin             FACCIN Group Realty
# 4            Randal Longo       Keys Realty Redefined LLC
# 5        Svetlana Carroll      One Sotheby's Int'l Realty
# 6        Natalya Grinberg  Big International Realty, Inc.
# 7      Michael Wiesenfeld              The Corcoran Group
# 8   Christian Dreyfuss PA            Brown Harris Stevens
# 9          Jorge Martinez      One Sotheby's Int'l Realty
# 10             Joel Matus     Williams Island Realty, LLC
#
#             Buyer Agent                        Buyer Broker
# 1   T Kimberly Rodstein  Keller Williams Miami Beach Realty  \
# 2           Marla Cohen                    Acqualina Realty
# 3         Alfredo Ferro                    Envirotek Realty
# 4          Mariana Niro                             Serhant
# 5             Jill Eber              Coldwell Banker Realty
# 6          Marcio Sousa                   The Keyes Company
# 7    Ricardo Di Giorgio             Miami Residential Group
# 8       Zarko Draskovic                London Foster Realty
# 9        Marci Declaris                     Douglas Elliman
# 10         Nicole Shein         Williams Island Realty, LLC
#
#                                           geo_address
# 1   Oceana Bal Harbour 10201 Collins Ave 2803 Bal ...  \
# 2   Estates the Acqualina 17975 Collins Ave 2701 S...
# 3   Jade Signature 16901 Collins Ave 3401 Sunny Is...
# 4   Residence by Armani Casa 18975 Collins Ave 250...
# 5   Bayside Village 2221 Fisher Island Dr 3201 Fis...
# 6   Muse Condo 17141 Collins Ave 2502 Sunny Isles ...
# 7   Brickell Flatiron 1000 Brickell Plaza PH-6007 ...
# 8   Paramount Miami World Center 851 NE 1st Ave 38...
# 9   South Pointe Towers Condo 400 S Pointe Dr 710 ...
# 10    0Williams Island 2600 Island Blvd 2501 Aventura
#
#                     building_name
# 1             Oceana Bal Harbour   \
# 2          Estates the Acqualina
# 3                 Jade Signature
# 4       Residence by Armani Casa
# 5                Bayside Village
# 6                     Muse Condo
# 7              Brickell Flatiron
# 8   Paramount Miami World Center
# 9      South Pointe Towers Condo
# 10
#
#                                        address_only
# 1                10201 Collins Ave 2803 Bal Harbour  \
# 2          17975 Collins Ave 2701 Sunny Isles Beach
# 3          16901 Collins Ave 3401 Sunny Isles Beach
# 4          18975 Collins Ave 2502 Sunny Isles Beach
# 5          2221 Fisher Island Dr 3201 Fisher Island
# 6          17141 Collins Ave 2502 Sunny Isles Beach
# 7                 1000 Brickell Plaza PH-6007 Miami
# 8                         851 NE 1st Ave 3805 Miami
# 9                   400 S Pointe Dr 710 Miami Beach
# 10  0Williams Island 2600 Island Blvd 2501 Aventura
#
#                             geocoded        lat        lon
# 1          (25.8951514, -80.1230855)  25.895151 -80.123086
# 2   (25.9423323, -80.12016559999999)  25.942332 -80.120166
# 3          (25.9327557, -80.1210054)  25.932756 -80.121005
# 4            (25.9519943, -80.11997)  25.951994 -80.119970
# 5           (25.7589251, -80.143131)  25.758925 -80.143131
# 6   (25.9349392, -80.12091819999999)  25.934939 -80.120918
# 7          (25.7642427, -80.1927022)  25.764243 -80.192702
# 8          (25.7824272, -80.1918372)  25.782427 -80.191837
# 9          (25.7672946, -80.1341836)  25.767295 -80.134184
# 10         (25.9392382, -80.1337739)  25.939238 -80.133774

# %%
df.at[10,'building_name']=('Williams Island')
df.at[10,'address_only']=('2600 Island Blvd')

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df = df.replace('N/A', np.nan)

# %%
df['Sale Price']
# Out:
# 1     $22,000,000.00
# 2     $10,965,000.00
# 3      $5,750,000.00
# 4      $4,210,000.00
# 5      $3,600,000.00
# 6      $2,750,000.00
# 7      $2,525,000.00
# 8      $2,300,000.00
# 9      $2,194,000.00
# 10     $1,700,000.00
# Name: Sale Price, dtype: object

# %%
df['int_Sale_Price'] = df['Sale Price'].str.replace('$','',regex=False)

# %%
df['int_Sale_Price'] = df['int_Sale_Price'].str.replace(',','',regex=False)

# %%
df['int_Sale_Price'] = pd.to_numeric(df['int_Sale_Price'])

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.replace('$','',regex=False)
df['price_per_sqft'] = df['price_per_sqft'].str.replace(',','',regex=False)
df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'])

df['days_on_market'] = pd.to_numeric(df['days_on_market'])

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df['RANK'] = range(1, len(df) + 1)
# use numpy to assign values to the 'COLOR' column
df['COLOR'] = np.where(df['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['building_address_city', 'Close Date', 'days_on_market', 'Sale Price',
#        'Sq. Ft.', 'price_per_sqft', 'Agent', 'Listing Broker', 'Buyer Agent',
#        'Buyer Broker', 'geo_address', 'building_name', 'address_only',
#        'geocoded', 'lat', 'lon', 'int_Sale_Price', 'RANK', 'COLOR'],
#       dtype='object')

# %%
def popup_html(row):
    building_name = row['building_name']
    price = row['Sale Price']
    days_on_market = row['days_on_market']
    listing_agent = row['Agent']
    buyers_agent = row['Buyer Agent']
    psf = row['price_per_sqft']
    address = row['address_only']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>{}'''.format(price) + '''<br>
    <strong>Days on Market: </strong>{}'''.format(days_on_market) + '''<br>
    <strong>Listing Agent: </strong>{}'''.format(listing_agent) + '''<br>
    <strong>Buyer's Agent: </strong>{}'''.format(buyers_agent) + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(psf) + '''<br>
    <strong>Address: </strong>{}'''.format(address) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format('May 21st - May 27th')


### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e935bcd331b4f3847387dad1facca12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May 21st - May 27th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e935bcd331b4f3847387dad1facca12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0e935bcd331b4f3847387dad1facca12 = L.map(
#                 &quot;map_0e935bcd331b4f3847387dad1facca12&quot;,
#                 {
#                     center: [25.866930070000002, -80.14007726],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_079fc7a86c165ea776a693eb51639fea = L.featureGroup(
#                 {}
#             ).addTo(map_0e935bcd331b4f3847387dad1facca12);
#
#
#             var marker_3310190806693d7867e20aa280cd3d50 = L.marker(
#                 [25.8951514, -80.1230855],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_079fc7a86c165ea776a693eb51639fea);
#
#
#             var icon_5dce711afa755b59adcb65fcbfc99d37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3310190806693d7867e20aa280cd3d50.setIcon(icon_5dce711afa755b59adcb65fcbfc99d37);
#
#
#         var popup_0624b0916b57cc38b752188754b3e93f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3fb88329d063054ba1cadec6200ffb3e = $(`&lt;div id=&quot;html_3fb88329d063054ba1cadec6200ffb3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;Oceana Bal Harbour &lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$22,000,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;91&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Ruthie Assouline&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;T Kimberly Rodstein&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$4244.65&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;10201 Collins Ave 2803 Bal Harbour&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_0624b0916b57cc38b752188754b3e93f.setContent(html_3fb88329d063054ba1cadec6200ffb3e);
#
#
#
#         marker_3310190806693d7867e20aa280cd3d50.bindPopup(popup_0624b0916b57cc38b752188754b3e93f)
#         ;
#
#
#
#
#             var feature_group_9e2cf97f3f08792adad5eaff2d536d12 = L.featureGroup(
#                 {}
#             ).addTo(map_0e935bcd331b4f3847387dad1facca12);
#
#
#             var marker_69f8393c9807d40b52584a4273b7ed88 = L.marker(
#                 [25.9423323, -80.12016559999999],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_9e2cf97f3f08792adad5eaff2d536d12);
#
#
#             var icon_6d752a0f72bee760472c78b5b3e5b68c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69f8393c9807d40b52584a4273b7ed88.setIcon(icon_6d752a0f72bee760472c78b5b3e5b68c);
#
#
#         var popup_45613fa666ebe62360c67c8e87a35e1b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2a71429ceacb4a5cf1b45f4ee6ca7da4 = $(`&lt;div id=&quot;html_2a71429ceacb4a5cf1b45f4ee6ca7da4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;Estates the Acqualina &lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$10,965,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;61&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Karina Batievsky&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;Marla Cohen&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2293.93&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;17975 Collins Ave 2701 Sunny Isles Beach&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_45613fa666ebe62360c67c8e87a35e1b.setContent(html_2a71429ceacb4a5cf1b45f4ee6ca7da4);
#
#
#
#         marker_69f8393c9807d40b52584a4273b7ed88.bindPopup(popup_45613fa666ebe62360c67c8e87a35e1b)
#         ;
#
#
#
#
#             var marker_c1706adae4664acde0c0ac0cee5d8dbc = L.marker(
#                 [25.9327557, -80.1210054],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_9e2cf97f3f08792adad5eaff2d536d12);
#
#
#             var icon_5c409e9a2b939ba2b680a8720f2ed613 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot

# %%
df
# Out:
#                                 building_address_city Close Date
# 1   Oceana Bal Harbour\r10201 Collins Ave 2803\rBa...  5/22/2023  \
# 2   Estates the Acqualina\r17975 Collins Ave 2701\...  5/23/2023
# 3   Jade Signature\r16901 Collins Ave 3401\rSunny ...  5/24/2023
# 4   Residence by Armani Casa\r18975 Collins Ave 25...  5/22/2023
# 5   Bayside Village\r2221 Fisher Island Dr 3201\rF...  5/22/2023
# 6   Muse Condo\r17141 Collins Ave 2502\rSunny Isle...  5/25/2023
# 7   Brickell Flatiron\r1000 Brickell Plaza PH-6007...  5/26/2023
# 8   Paramount Miami World Center\r851 NE 1st Ave 3...  5/25/2023
# 9   South Pointe Towers Condo\r400 S Pointe Dr 710...  5/25/2023
# 10  0Williams Island\r2600 Island Blvd 2501\rAventura  5/24/2023
#
#     days_on_market      Sale Price Sq. Ft.  price_per_sqft
# 1               91  $22,000,000.00    5183         4244.65  \
# 2               61  $10,965,000.00    4780         2293.93
# 3              117   $5,750,000.00    3012         1909.03
# 4              193   $4,210,000.00    2682         1569.72
# 5              275   $3,600,000.00    2744         1311.95
# 6               49   $2,750,000.00    2042         1346.72
# 7                8   $2,525,000.00    1800         1402.78
# 8               91   $2,300,000.00    3450          747.72
# 9              118   $2,194,000.00    1559         1407.31
# 10               8   $1,700,000.00    2580          658.91
#
#                     Agent                  Listing Broker
# 1        Ruthie Assouline                 Douglas Elliman  \
# 2        Karina Batievsky                Acqualina Realty
# 3           Cassio Faccin             FACCIN Group Realty
# 4            Randal Longo       Keys Realty Redefined LLC
# 5        Svetlana Carroll      One Sotheby's Int'l Realty
# 6        Natalya Grinberg  Big International Realty, Inc.
# 7      Michael Wiesenfeld              The Corcoran Group
# 8   Christian Dreyfuss PA            Brown Harris Stevens
# 9          Jorge Martinez      One Sotheby's Int'l Realty
# 10             Joel Matus     Williams Island Realty, LLC
#
#             Buyer Agent                        Buyer Broker
# 1   T Kimberly Rodstein  Keller Williams Miami Beach Realty  \
# 2           Marla Cohen                    Acqualina Realty
# 3         Alfredo Ferro                    Envirotek Realty
# 4          Mariana Niro                             Serhant
# 5             Jill Eber              Coldwell Banker Realty
# 6          Marcio Sousa                   The Keyes Company
# 7    Ricardo Di Giorgio             Miami Residential Group
# 8       Zarko Draskovic                London Foster Realty
# 9        Marci Declaris                     Douglas Elliman
# 10         Nicole Shein         Williams Island Realty, LLC
#
#                                           geo_address
# 1   Oceana Bal Harbour 10201 Collins Ave 2803 Bal ...  \
# 2   Estates the Acqualina 17975 Collins Ave 2701 S...
# 3   Jade Signature 16901 Collins Ave 3401 Sunny Is...
# 4   Residence by Armani Casa 18975 Collins Ave 250...
# 5   Bayside Village 2221 Fisher Island Dr 3201 Fis...
# 6   Muse Condo 17141 Collins Ave 2502 Sunny Isles ...
# 7   Brickell Flatiron 1000 Brickell Plaza PH-6007 ...
# 8   Paramount Miami World Center 851 NE 1st Ave 38...
# 9   South Pointe Towers Condo 400 S Pointe Dr 710 ...
# 10    0Williams Island 2600 Island Blvd 2501 Aventura
#
#                     building_name                              address_only
# 1             Oceana Bal Harbour         10201 Collins Ave 2803 Bal Harbour  \
# 2          Estates the Acqualina   17975 Collins Ave 2701 Sunny Isles Beach
# 3                 Jade Signature   16901 Collins Ave 3401 Sunny Isles Beach
# 4       Residence by Armani Casa   18975 Collins Ave 2502 Sunny Isles Beach
# 5                Bayside Village   2221 Fisher Island Dr 3201 Fisher Island
# 6                     Muse Condo   17141 Collins Ave 2502 Sunny Isles Beach
# 7              Brickell Flatiron          1000 Brickell Plaza PH-6007 Miami
# 8   Paramount Miami World Center                  851 NE 1st Ave 3805 Miami
# 9      South Pointe Towers Condo            400 S Pointe Dr 710 Miami Beach
# 10                Williams Island                          2600 Island Blvd
#
#                             geocoded        lat        lon  int_Sale_Price
# 1          (25.8951514, -80.1230855)  25.895151 -80.123086      22000000.0  \
# 2   (25.9423323, -80.12016559999999)  25.942332 -80.120166      10965000.0
# 3          (25.9327557, -80.1210054)  25.932756 -80.121005       5750000.0
# 4            (25.9519943, -80.11997)  25.951994 -80.119970       4210000.0
# 5           (25.7589251, -80.143131)  25.758925 -80.143131       3600000.0
# 6   (25.9349392, -80.12091819999999)  25.934939 -80.120918       2750000.0
# 7          (25.7642427, -80.1927022)  25.764243 -80.192702       2525000.0
# 8          (25.7824272, -80.1918372)  25.782427 -80.191837       2300000.0
# 9          (25.7672946, -80.1341836)  25.767295 -80.134184       2194000.0
# 10         (25.9392382, -80.1337739)  25.939238 -80.133774       1700000.0
#
#     RANK   COLOR
# 1      1  orange
# 2      2    blue
# 3      3    blue
# 4      4    blue
# 5      5    blue
# 6      6    blue
# 7      7    blue
# 8      8    blue
# 9      9    blue
# 10    10    blue

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
### Highest and lowest sale price ###
print(f"{ME}{BR}{df.loc[df['int_Sale_Price'].idxmax()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmax()]['address_only']} | Price ${df.loc[df['int_Sale_Price'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmax()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmax()]['days_on_market']}")
print(f"{LE}{BR}{df.loc[df['int_Sale_Price'].idxmin()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmin()]['address_only']} | Price ${df.loc[df['int_Sale_Price'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmin()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmin()]['days_on_market']}")
### Highest and lowest psf ###
print(f"{MAX_PSF}{BR}{df.loc[df['price_per_sqft'].idxmax()]['building_name']}, {df.loc[df['price_per_sqft'].idxmax()]['address_only']} | Price ${df.loc[df['price_per_sqft'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmax()]['Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmax()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmax()]['days_on_market']}")
print(f"{MIN_PSF}{BR}{df.loc[df['price_per_sqft'].idxmin()]['building_name']}, {df.loc[df['price_per_sqft'].idxmin()]['address_only']} | Price ${df.loc[df['price_per_sqft'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmin()]['Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmin()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmin()]['days_on_market']}")
### Highest and lowest days on market ###
print(f"{DAYS_MAX}{BR}{df.loc[df['days_on_market'].idxmax()]['building_name']}, {df.loc[df['days_on_market'].idxmax()]['address_only']} | Price ${df.loc[df['days_on_market'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmax()]['Agent']} with {df.loc[df['days_on_market'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmax()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmax()]['days_on_market']}")
print(f"{DAYS_MIN}{BR}{df.loc[df['days_on_market'].idxmin()]['building_name']}, {df.loc[df['days_on_market'].idxmin()]['address_only']} | Price ${df.loc[df['days_on_market'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmin()]['Agent']} with {df.loc[df['days_on_market'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmin()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmin()]['days_on_market']}")
# Out:
# Most Expensive
# Oceana Bal Harbour , 10201 Collins Ave 2803 Bal Harbour | Price $22,000,000 | $4,245 psf | Listing agent: Ruthie Assouline with Douglas Elliman | Buyer's agent: T Kimberly Rodstein with Keller Williams Miami Beach Realty | Days on market: 91
# Least Expensive
# Williams Island, 2600 Island Blvd | Price $1,700,000 | $659 psf | Listing agent: Joel Matus with Williams Island Realty, LLC | Buyer's agent: Nicole Shein with Williams Island Realty, LLC | Days on market: 8
# Highest Price Per Square Foot
# Oceana Bal Harbour , 10201 Collins Ave 2803 Bal Harbour | Price $22,000,000 | $4,245 psf | Listing agent: Ruthie Assouline with Douglas Elliman | Buyer's agent: T Kimberly Rodstein with Keller Williams Miami Beach Realty | Days on market: 91
# Lowest Price Per Square Foot
# Williams Island, 2600 Island Blvd | Price $1,700,000 | $659 psf | Listing agent: Joel Matus with Williams Island Realty, LLC | Buyer's agent: Nicole Shein with Williams Island Realty, LLC | Days on market: 8
# Most Days on Market
# Bayside Village , 2221 Fisher Island Dr 3201 Fisher Island | Price $3,600,000 | $1,312 psf | Listing agent: Svetlana Carroll with One Sotheby's Int'l Realty | Buyer's agent: Jill Eber with Coldwell Banker Realty | Days on market: 275
# Fewest Days on Market
# Brickell Flatiron , 1000 Brickell Plaza PH-6007 Miami | Price $2,525,000 | $1,403 psf | Listing agent: Michael Wiesenfeld with The Corcoran Group | Buyer's agent: Ricardo Di Giorgio with Miami Residential Group | Days on market: 8

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_05272023
