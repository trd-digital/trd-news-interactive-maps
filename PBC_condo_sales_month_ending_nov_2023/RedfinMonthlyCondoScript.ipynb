# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import folium
import geopandas as gpd
import glob

# %% [markdown]
# ## PD Set Options

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Data Read-in

# %%
csv_file_list = glob.glob('*.csv')

df_list = []

for csv_file in csv_file_list:
    df = pd.read_csv(csv_file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df
# Out:
#                                              SALE TYPE        SOLD DATE
# 0    In accordance with local MLS rules, some MLS l...              NaN  \
# 1                                            PAST SALE              NaN
# 2                                            PAST SALE              NaN
# 3                                            PAST SALE  October-31-2023
# 4                                            PAST SALE  November-3-2023
# ..                                                 ...              ...
# 215                                          PAST SALE              NaN
# 216                                          PAST SALE              NaN
# 217                                          PAST SALE              NaN
# 218                                          PAST SALE              NaN
# 219                                          PAST SALE              NaN
#
#     PROPERTY TYPE                    ADDRESS             CITY
# 0             NaN                        NaN              NaN  \
# 1     Condo/Co-op         453 Fanshaw K #453       Boca Raton
# 2     Condo/Co-op        618 NW 13th St #110       Boca Raton
# 3     Condo/Co-op             230 Somerset L  West Palm Beach
# 4     Condo/Co-op     450 N Federal Hwy #603    Boynton Beach
# ..            ...                        ...              ...
# 215   Condo/Co-op           709 Lori Dr #314     Palm Springs
# 216   Condo/Co-op             29 Waterford B     Delray Beach
# 217   Condo/Co-op  1251 NW 13th St Unit 433C       Boca Raton
# 218   Condo/Co-op          417 Bennington Ln       Lake Worth
# 219   Condo/Co-op              251 Fanshaw F       Boca Raton
#
#     STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS
# 0                 NaN                 NaN       NaN   NaN    NaN  \
# 1                  FL             33434.0  275000.0   2.0    1.5
# 2                  FL             33486.0  300000.0   3.0    2.0
# 3                  FL             33417.0  300000.0   2.0    2.0
# 4                  FL             33435.0  283500.0   1.0    1.0
# ..                ...                 ...       ...   ...    ...
# 215                FL             33461.0  155000.0   1.0    1.0
# 216                FL             33446.0  150000.0   2.0    2.0
# 217                FL             33486.0  165000.0   1.0    1.0
# 218                FL             33467.0  175000.0   2.0    2.0
# 219                FL             33434.0  150000.0   2.0    1.5
#
#              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET
# 0                 NaN          NaN       NaN         NaN             NaN  \
# 1                 NaN        835.0       NaN      1980.0             NaN
# 2                 NaN       1286.0       NaN      1970.0             NaN
# 3     Century Village        874.0       NaN      1972.0             NaN
# 4    Casa Costa Condo        805.0       NaN      2010.0             NaN
# ..                ...          ...       ...         ...             ...
# 215               NaN        696.0       NaN      1979.0             NaN
# 216               NaN        883.0       NaN      1973.0             NaN
# 217               NaN        729.0       NaN      1973.0             NaN
# 218               NaN        941.0       NaN      1983.0             NaN
# 219               NaN        835.0       NaN      1980.0             NaN
#
#      $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME
# 0              NaN        NaN    NaN                         NaN  \
# 1            329.0        NaN    NaN                         NaN
# 2            233.0        NaN    NaN                         NaN
# 3            343.0      500.0   Sold                         NaN
# 4            352.0      573.0   Sold                         NaN
# ..             ...        ...    ...                         ...
# 215          223.0        NaN    NaN                         NaN
# 216          170.0        NaN    NaN                         NaN
# 217          226.0        NaN    NaN                         NaN
# 218          186.0        NaN    NaN                         NaN
# 219          180.0        NaN    NaN                         NaN
#
#      NEXT OPEN HOUSE END TIME
# 0                         NaN  \
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 215                       NaN
# 216                       NaN
# 217                       NaN
# 218                       NaN
# 219                       NaN
#
#     URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)
# 0                                                  NaN                                           \
# 1    https://www.redfin.com/FL/Boca-Raton/453-Fansh...
# 2    https://www.redfin.com/FL/Boca-Raton/618-NW-13...
# 3    https://www.redfin.com/FL/West-Palm-Beach/230-...
# 4    https://www.redfin.com/FL/Boynton-Beach/450-N-...
# ..                                                 ...
# 215  https://www.redfin.com/FL/Palm-Springs/709-Lor...
# 216  https://www.redfin.com/FL/Delray-Beach/29-Wate...
# 217  https://www.redfin.com/FL/Boca-Raton/1251-NW-1...
# 218  https://www.redfin.com/FL/Lake-Worth/417-Benni...
# 219  https://www.redfin.com/FL/Boca-Raton/251-Fansh...
#
#           SOURCE         MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0            NaN          NaN      NaN        NaN        NaN        NaN
# 1            NaN          NaN        N          Y  26.384826 -80.174459
# 2            NaN          NaN        N          Y  26.360975 -80.099405
# 3    Beaches MLS  RX-10921251        N          Y  26.713297 -80.130859
# 4    Beaches MLS  RX-10917527        N          Y  26.530064 -80.057953
# ..           ...          ...      ...        ...        ...        ...
# 215          NaN          NaN        N          Y  26.646112 -80.093287
# 216          NaN          NaN        N          Y  26.448901 -80.151942
# 217          NaN          NaN        N          Y  26.361855 -80.111931
# 218          NaN          NaN        N          Y  26.624736 -80.160075
# 219          NaN          NaN        N          Y  26.384599 -80.174740
#
# [2556 rows x 27 columns]

# %%
PBC_gf = gpd.read_file('Palm_Beach_County_Boundary.geojson')

# %% [markdown]
# ## Data Clean

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
df = df.dropna(subset=['SOLD DATE'])

# %%
# Define list of desired months (excluding current month)
desired_months = ['November']

# Filter DataFrame to include only entries from desired months
df_filtered = df[df['SOLD DATE'].str.split('-', expand=True)[0].isin(desired_months)]

# Reset the index
df_filtered = df_filtered.reset_index(drop=True)

# %%
# Data checks
print(df_filtered['PRICE'].isna().value_counts())
print('-------')
print(df_filtered['$/SQUARE FEET'].isna().value_counts())
print('-------')
print(df_filtered['YEAR BUILT'].isna().value_counts())
print('-------')
# Out:
# PRICE
# False    581
# Name: count, dtype: int64
# -------
# $/SQUARE FEET
# False    578
# True       3
# Name: count, dtype: int64
# -------
# YEAR BUILT
# False    581
# Name: count, dtype: int64
# -------

# %%
sorted_df = df_filtered.sort_values(by='$/SQUARE FEET', ascending=True)
second_newest_building = sorted_df.iloc[2]
print(second_newest_building['URL'])
# Out:
# https://www.redfin.com/FL/Lake-Worth/2566-Garden-Dr-S-33461/unit-205/home/42285967

# %%
df_filtered.loc[df_filtered['PRICE'] == '0']
# Out:
# Empty DataFrame
# Columns: [SALE TYPE, SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, STATUS, NEXT OPEN HOUSE START TIME, NEXT OPEN HOUSE END TIME, URL, SOURCE, MLS#, FAVORITE, INTERESTED, LATITUDE, LONGITUDE]
# Index: []

# %%
df_filtered['PRICE'] = pd.to_numeric(df_filtered['PRICE'])
df_filtered['$/SQUARE FEET'] = pd.to_numeric(df_filtered['$/SQUARE FEET'])
df_filtered['YEAR BUILT'] = pd.to_numeric(df_filtered['YEAR BUILT'])
df_filtered['LATITUDE'] = pd.to_numeric(df_filtered['LATITUDE'])
df_filtered['LONGITUDE'] = pd.to_numeric(df_filtered['LONGITUDE'])

# %%
df_filtered.sort_values(by='PRICE',ascending=True).head(20)
# Out:
#      SALE TYPE         SOLD DATE PROPERTY TYPE                    ADDRESS
# 382  PAST SALE  November-22-2023   Condo/Co-op      2811 Garden Dr S #105  \
# 392  PAST SALE   November-3-2023   Condo/Co-op            136 Sheffield F
# 404  PAST SALE  November-20-2023   Condo/Co-op  3360 Lake Osborne Dr #206
# 394  PAST SALE   November-2-2023   Condo/Co-op              280 Windsor M
# 398  PAST SALE   November-9-2023   Condo/Co-op       166 Salisbury G #166
# 391  PAST SALE  November-15-2023   Condo/Co-op  3500 Springdale Blvd #115
# 363  PAST SALE  November-24-2023   Condo/Co-op         1956 Bridgewood Dr
# 381  PAST SALE   November-9-2023   Condo/Co-op     158 Easthampton Unit G
# 393  PAST SALE  November-28-2023   Condo/Co-op      2566 S Garden Dr #205
# 401  PAST SALE   November-8-2023   Condo/Co-op         155 Andover F #155
# 374  PAST SALE  November-27-2023   Condo/Co-op              232 Andover I
# 385  PAST SALE  November-28-2023   Condo/Co-op      2647 N Garden Dr #104
# 400  PAST SALE  November-30-2023   Condo/Co-op            187 Salisbury H
# 405  PAST SALE   November-8-2023   Condo/Co-op       276 Andover K Unit K
# 373  PAST SALE  November-30-2023   Condo/Co-op          224 Southampton B
# 368  PAST SALE  November-20-2023   Condo/Co-op       73 Canterbury Unit C
# 366  PAST SALE  November-13-2023   Condo/Co-op  700 Village Green Ct #215
# 362  PAST SALE  November-28-2023   Condo/Co-op    2004 Lake Osborne Dr #4
# 359  PAST SALE   November-8-2023   Condo/Co-op    14721 Bonaire Blvd #208
# 389  PAST SALE  November-20-2023   Condo/Co-op     334 Southampton B #334
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS
# 382       Lake Worth                FL             33461.0  55000.0   1.0  \
# 392  West Palm Beach                FL             33417.0  68000.0   1.0
# 404       Lake Worth                FL             33461.0  70000.0   1.0
# 394  West Palm Beach                FL             33417.0  70000.0   1.0
# 398  West Palm Beach                FL             33417.0  72000.0   1.0
# 391     Palm Springs                FL             33461.0  72500.0   1.0
# 363       Boca Raton                FL             33434.0  75000.0   2.0
# 381  West Palm Beach                FL             33417.0  77000.0   1.0
# 393       Lake Worth                FL             33461.0  79000.0   2.0
# 401  West Palm Beach                FL             33417.0  80000.0   1.0
# 374  West Palm Beach                FL             33417.0  80000.0   1.0
# 385       Lake Worth                FL             33461.0  80000.0   2.0
# 400  West Palm Beach                FL             33417.0  85000.0   1.0
# 405  West Palm Beach                FL             33417.0  85000.0   1.0
# 373  West Palm Beach                FL             33417.0  87500.0   1.0
# 368  West Palm Beach                FL             33417.0  88000.0   2.0
# 366     Palm Springs                FL             33461.0  90000.0   1.0
# 362       Lake Worth                FL             33461.0  91500.0   1.0
# 359     Delray Beach                FL             33446.0  95000.0   2.0
# 389  West Palm Beach                FL             33417.0  95000.0   1.0
#
#      BATHS                             LOCATION  SQUARE FEET  LOT SIZE
# 382    1.5         Lake Clarke Gardens Condo 25        744.0       NaN  \
# 392    1.0                      Century Village        570.0       NaN
# 404    1.5           Murry Hills Apt Bldg Condo        734.0       NaN
# 394    1.0                      Century Village        585.0       NaN
# 398    1.0                     SALISBURY CONDOS        570.0       NaN
# 391    1.5             REGAL PALMS REGENT CONDO        779.0       NaN
# 363    2.0                   Bridgewood Midrise       1050.0       NaN
# 381    1.5                    EASTHAMPTON CONDO        702.0       NaN
# 393    1.0         Lake Clarke Gardens Condo 19        894.0       NaN
# 401    1.0                       ANDOVER CONDOS        532.0       NaN
# 374    1.0                       Andover Condos        532.0       NaN
# 385    1.0          Lake Clarke Gardens Condo 4        894.0       NaN
# 400    1.0    Century Village, Salisbury Condos        570.0       NaN
# 405    1.0                       ANDOVER CONDOS        532.0       NaN
# 373    1.5  Century Village - Southampton Condo        615.0       NaN
# 368    1.5                    CANTERBURY CONDOS        798.0       NaN
# 366    1.5          Village Green Hampton Condo        757.0       NaN
# 362    1.0                       Lakeside Point        638.0       NaN
# 359    2.0                   Villages OF Oriole       1024.0       NaN
# 389    1.5                      Century Village        615.0       NaN
#
#      YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS
# 382      1971.0             NaN           74.0      737.0   Sold  \
# 392      1971.0             NaN          119.0      409.0   Sold
# 404      1979.0             NaN           95.0      287.0   Sold
# 394      1972.0             NaN          120.0      410.0   Sold
# 398      1969.0             NaN          126.0      445.0   Sold
# 391      1980.0             NaN           93.0      350.0   Sold
# 363      1974.0             NaN           71.0      729.0   Sold
# 381      1969.0             NaN          110.0      445.0   Sold
# 393      1969.0             NaN           88.0      625.0   Sold
# 401      1971.0             NaN          150.0      450.0   Sold
# 374      1971.0             NaN          150.0      405.0   Sold
# 385      1968.0             NaN           89.0      684.0   Sold
# 400      1969.0             NaN          149.0      350.0   Sold
# 405      1971.0             NaN          160.0      468.0   Sold
# 373      1974.0             NaN          142.0      500.0   Sold
# 368      1973.0             NaN          110.0      519.0   Sold
# 366      1979.0             NaN          119.0      310.0   Sold
# 362      1967.0             NaN          143.0      224.0   Sold
# 359      1979.0             NaN           93.0      479.0   Sold
# 389      1974.0             NaN          154.0      515.0   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME
# 382                         NaN                       NaN  \
# 392                         NaN                       NaN
# 404                         NaN                       NaN
# 394                         NaN                       NaN
# 398                         NaN                       NaN
# 391                         NaN                       NaN
# 363                         NaN                       NaN
# 381                         NaN                       NaN
# 393                         NaN                       NaN
# 401                         NaN                       NaN
# 374                         NaN                       NaN
# 385                         NaN                       NaN
# 400                         NaN                       NaN
# 405                         NaN                       NaN
# 373                         NaN                       NaN
# 368                         NaN                       NaN
# 366                         NaN                       NaN
# 362                         NaN                       NaN
# 359                         NaN                       NaN
# 389                         NaN                       NaN
#
#                                                    URL       SOURCE
# 382  https://www.redfin.com/FL/Lake-Worth/2811-Gard...  Beaches MLS  \
# 392  https://www.redfin.com/FL/West-Palm-Beach/136-...  Beaches MLS
# 404  https://www.redfin.com/FL/Lake-Worth-Beach/336...  Beaches MLS
# 394  https://www.redfin.com/FL/West-Palm-Beach/280-...  Beaches MLS
# 398  https://www.redfin.com/FL/West-Palm-Beach/166-...       MARMLS
# 391  https://www.redfin.com/FL/Palm-Springs/3500-Sp...       MARMLS
# 363  https://www.redfin.com/FL/Boca-Raton/1956-Brid...  Beaches MLS
# 381  https://www.redfin.com/FL/West-Palm-Beach/158-...       MARMLS
# 393  https://www.redfin.com/FL/Lake-Worth/2566-Gard...  Beaches MLS
# 401  https://www.redfin.com/FL/West-Palm-Beach/155-...       MARMLS
# 374  https://www.redfin.com/FL/West-Palm-Beach/232-...  Beaches MLS
# 385  https://www.redfin.com/FL/Lake-Worth/2647-Gard...  Beaches MLS
# 400  https://www.redfin.com/FL/West-Palm-Beach/187-...  Beaches MLS
# 405  https://www.redfin.com/FL/West-Palm-Beach/276-...       MARMLS
# 373  https://www.redfin.com/FL/West-Palm-Beach/224-...  Beaches MLS
# 368  https://www.redfin.com/FL/West-Palm-Beach/73-C...       MARMLS
# 366  https://www.redfin.com/FL/Palm-Springs/700-Vil...  Beaches MLS
# 362  https://www.redfin.com/FL/Lake-Worth-Beach/200...  Beaches MLS
# 359  https://www.redfin.com/FL/Delray-Beach/14721-B...  Beaches MLS
# 389  https://www.redfin.com/FL/West-Palm-Beach/334-...  Beaches MLS
#
#             MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 382  RX-10914956        N          Y  26.633652 -80.085226
# 392  RX-10891556        N          Y  26.719117 -80.126059
# 404  RX-10858446        N          Y  26.603926 -80.073442
# 394  RX-10886223        N          Y  26.711138 -80.135877
# 398    A11353819        N          Y  26.716733 -80.121228
# 391    A11413329        N          Y  26.646890 -80.103729
# 363  RX-10926386        N          Y  26.373894 -80.164420
# 381    A11408474        N          Y  26.716714 -80.119845
# 393  RX-10887550        N          Y  26.632465 -80.081298
# 401    A11346109        N          Y  26.710947 -80.128411
# 374  RX-10927676        N          Y  26.709899 -80.128534
# 385  RX-10902613        N          Y  26.635292 -80.082608
# 400  RX-10875971        N          Y  26.718098 -80.120884
# 405    A11297531        N          Y  26.710841 -80.127653
# 373  RX-10925899        N          Y  26.707749 -80.123253
# 368    A11413735        N          Y  26.716863 -80.126109
# 366  RX-10920600        N          Y  26.641463 -80.105648
# 362  RX-10850959        N          Y  26.611705 -80.073597
# 359  RX-10927983        N          Y  26.461407 -80.148445
# 389  RX-10909433        N          Y  26.707749 -80.123253

# %%
print(df_filtered['URL'].iloc[392])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/136-Sheffield-F-33417/home/42145053

# %%
# # Correct the prices, if needed
# df_filtered.at[43,'$/SQUARE FEET']=(275000/705)

# %%
# Find problem psf by searching for a '0' value
df_filtered.loc[df_filtered['$/SQUARE FEET'] == '0'][['SOLD DATE','ADDRESS','CITY','$/SQUARE FEET','PRICE','SQUARE FEET']]
# Out:
# Empty DataFrame
# Columns: [SOLD DATE, ADDRESS, CITY, $/SQUARE FEET, PRICE, SQUARE FEET]
# Index: []

# %%
# # # Corrections, if needed
# df_filtered.at[245,'$/SQUARE FEET']=(210000/480)
# df_filtered.at[383,'$/SQUARE FEET']=(225000/460)
# df_filtered.at[673,'$/SQUARE FEET']=(550000/960)
# df_filtered.at[777,'$/SQUARE FEET']=(275000/697)

# %%
# Find problem psf by searching for low values
df_filtered.sort_values(by='$/SQUARE FEET',ascending=True).head(20)[['PRICE','ADDRESS','CITY','$/SQUARE FEET']]
# Out:
#         PRICE                    ADDRESS             CITY  $/SQUARE FEET
# 363   75000.0         1956 Bridgewood Dr       Boca Raton           71.0
# 382   55000.0      2811 Garden Dr S #105       Lake Worth           74.0
# 393   79000.0      2566 S Garden Dr #205       Lake Worth           88.0
# 385   80000.0      2647 N Garden Dr #104       Lake Worth           89.0
# 359   95000.0    14721 Bonaire Blvd #208     Delray Beach           93.0
# 391   72500.0  3500 Springdale Blvd #115     Palm Springs           93.0
# 404   70000.0  3360 Lake Osborne Dr #206       Lake Worth           95.0
# 368   88000.0       73 Canterbury Unit C  West Palm Beach          110.0
# 381   77000.0     158 Easthampton Unit G  West Palm Beach          110.0
# 576  155000.0     34 Southport Ln Unit E    Boynton Beach          112.0
# 251  220000.0      2 Stratford Dr Unit D    Boynton Beach          114.0
# 384   97000.0             114 Oxford 400  West Palm Beach          116.0
# 320  130000.0     130 Lake Meryl Dr #230  West Palm Beach          119.0
# 392   68000.0            136 Sheffield F  West Palm Beach          119.0
# 217  214500.0      66 Eastgate Dr Unit A    Boynton Beach          119.0
# 366   90000.0  700 Village Green Ct #215     Palm Springs          119.0
# 394   70000.0              280 Windsor M  West Palm Beach          120.0
# 396  108500.0      2812 S Garden Dr #312       Lake Worth          121.0
# 398   72000.0       166 Salisbury G #166  West Palm Beach          126.0
# 312  150000.0       1121 Cactus Ter #204     Delray Beach          129.0

# %%
print(df_filtered.URL.iloc[363])
# Out:
# https://www.redfin.com/FL/Boca-Raton/1956-Bridgewood-Dr-33434/home/187918847

# %%
# # Drop sales that aren't condos but labeled as such
# df_filtered = df_filtered.drop(1320)

# %% [markdown]
# ## Make Maps

# %%
### Create a price column formatted as currency ###
df_filtered['PRICE_AS_CURRENCY'] = df_filtered['PRICE'].apply(lambda x: "${:,.0f}".format(x))
### Set formatting for Beds, Baths ###
df_filtered['YEAR BUILT DISPLAY'] = df_filtered['YEAR BUILT'].apply(lambda x: '{:.0f}'.format(x))
df_filtered['PRICE_SQUARE_FEET_AS_CURRENCY'] = df_filtered['$/SQUARE FEET'].apply(lambda x: '${:,.0f}'.format(x))

# %%
df_filtered = df_filtered.sort_values(by=['PRICE'], ascending=False)
### Insert different colors for top 10 sales vs. the rest ###
df_filtered['COLOR'] = ''
### Create RANK column ###
df_filtered['RANK'] = 0
### Insert RANK values ###
df_filtered['RANK'] = range(1, len(df_filtered) + 1)
# use numpy to assign values to the 'COLOR' column
df_filtered['COLOR'] = np.where(df_filtered['RANK'] <= 10, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
### Define list of columns to drop from DF ###
columns_drop = ['SALE TYPE','PROPERTY TYPE','STATE OR PROVINCE','ZIP OR POSTAL CODE','HOA/MONTH','STATUS','NEXT OPEN HOUSE START TIME','NEXT OPEN HOUSE END TIME','SOURCE','MLS#','FAVORITE','INTERESTED','SQUARE FEET','LOT SIZE']

# %%
### Drop the columns ###
df_filtered = df_filtered.drop(columns=columns_drop)

# %%
def popup_html(row):
    Price = row['PRICE_AS_CURRENCY']
    Address = row['ADDRESS']
    City = row['CITY']
    sold_date = row['SOLD DATE']
    beds = row['BEDS']
    baths = row['BATHS']
    psf = row['PRICE_SQUARE_FEET_AS_CURRENCY']
    year_built = row['YEAR BUILT DISPLAY']
    rank = row['RANK']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Price: </strong>{}'''.format(Price) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>City: </strong>{}'''.format(City) + '''<br>
    <strong>Sold: </strong>{}'''.format(sold_date) + '''<br>
    <strong>Beds: </strong>{}'''.format(beds) + '''<br>
    <strong>Baths: </strong>{}'''.format(baths) + '''<br>
    <strong>Price per sf: </strong>{}'''.format(psf) + '''<br>
    <strong>Year Built: </strong>{}'''.format(year_built) + '''<br>
    <strong>Price Rank: </strong>{}'''.format(rank) + '''
    </html>
    '''
    return html

# %%
### Create map container ###
m = folium.Map(location=df_filtered[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=10,tiles=None)

### Create title ###
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f"November 2023 Condo Sales")

m.get_root().html.add_child(folium.Element(title_html))

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top 10 Sales')

folium.GeoJson(PBC_gf,tooltip='Palm Beach County',name='Palm Beach County').add_to(m)

for index, row in df_filtered.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c88c510f40abd5823a2368899f0c2fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;November 2023 Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c88c510f40abd5823a2368899f0c2fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7c88c510f40abd5823a2368899f0c2fe = L.map(
#                 &quot;map_7c88c510f40abd5823a2368899f0c2fe&quot;,
#                 {
#                     center: [26.568811693975906, -80.11153821549053],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#
#         function geo_json_a432e6201d9aa2c1ba539521ba6ff464_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a432e6201d9aa2c1ba539521ba6ff464 = L.geoJson(null, {
#                 onEachFeature: geo_json_a432e6201d9aa2c1ba539521ba6ff464_onEachFeature,
#
#         });
#
#         function geo_json_a432e6201d9aa2c1ba539521ba6ff464_add (data) {
#             geo_json_a432e6201d9aa2c1ba539521ba6ff464
#                 .addData(data)
#                 .addTo(map_7c88c510f40abd5823a2368899f0c2fe);
#         }
#             geo_json_a432e6201d9aa2c1ba539521ba6ff464_add({&quot;bbox&quot;: [-80.88609992322729, 26.320636346466905, -79.97430600056505, 26.97090204288687], &quot;features&quot;: [{&quot;bbox&quot;: [-80.08031856576163, 26.320969829601815, -79.97430600056505, 26.97045167842333], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-80.03288876158847, 26.70074981568316], [-80.03288919205531, 26.700749825321697], [-80.03306119703278, 26.694706306090694], [-80.03401714852984, 26.686003844110466], [-80.03539647651161, 26.675324743845756], [-80.03568686639512, 26.66910095218934], [-80.03592055460024, 26.66646839202047], [-80.03639570092619, 26.66371399186674], [-80.03669397755571, 26.64695477840359], [-80.03687134381703, 26.641471182298275], [-80.03630618751252, 26.610739694677815], [-80.03676052658105, 26.59438645955176], [-80.03745358229456, 26.585745385061074], [-80.03761691728879, 26.580552570959732], [-80.03864292633799, 26.57060485562758], [-80.0390146432161, 26.567880479322806], [-80.03957081936849, 26.565188118293136], [-80.04097523323341, 26.55840806025241], [-80.0415242334058, 26.552453218842274], [-80.04184220712284, 26.546299840080092], [-80.04201510432975, 26.545457892853108], [-80.04286663307963, 26.544866331623318], [-80.04676324895277, 26.52866646170171], [-80.04885256878174, 26.515228071171098], [-80.05212909599808, 26.497475084042584], [-80.0525387823489, 26.49421535099219], [-80.0528281434235, 26.492284420784664], [-80.05506923841442, 26.475777683198352], [-80.05703543995547, 26.462716184407462], [-80.05795014368917, 26.457846978786794], [-80.0581147083598, 26.454425543089556], [-80.0593962838377, 26.44439488368839], [-80.06205521602551, 26.427046603682633], [-80.06365326171095, 26.411963427461238], [-80.06565288336255, 26.391071860412467], [-80.06676748206591, 26.374803507416583], [-80.06735328989735, 26.36990739197701], [-80.06799822783066, 26.36444533146767], [-80.06870720424519, 26.357801785425785], [-80.06928212965641, 26.34741467996474], [-80.07024680669929, 26.336094418380036], [-80.070360984157, 26.335479587032662], [-80.07189000761996, 26.335563363945084], [-80.07304573829701, 26.327642261991514], [-80.0741075829009, 26.320969829601815], [-80.01524358538727, 26.32242153069109], [-80.0149400004264, 26.33614299946274], [-80.01493300170077, 26.33645600089736], [-80.01461199932952, 26.350982999704218], [-80.0143619991905, 26.362236000367936], [-80.01099999947722, 26.39112699937061], [-80.00688799913158, 26.426456999788147], [-80.00614899991163, 26.43280899872488], [-80.0025300006999, 26.454531000591192], [-79.99976200067432, 26.471141999167653], [-79.99836500016181, 26.476159999403492], [-79.99799799998866, 26.477478000998286], [-79.99692999894404, 26.48370799923478], [-79.99669399818382, 26.488490999811255], [-79.99651799962251, 26.492951000076893], [-79.99556700024922, 26.496064999405284], [-79.99420000054441, 26.500348999216012], [-79.99386099973063, 26.502945999802392], [-79.99360499959421, 26.504893000013602], [-79.99312899807343, 26.50853000182098], [-79.99294000095512, 26.510004997746385], [-79.99126899891097, 26.523026000106494], [-79.98854300209302, 26.527264002425746], [-79.9863100011398, 26.53703500133105], [-79.98526100140523, 26.544712000668593], [-79.98527499816399, 26.544972998158507], [-79.9855129990211, 26.54938400015844], [-79.98587499996702, 26.550886999810817], [-79.985109997757, 26.55378600077542], [-79.98411899995547, 26.56092599887499], [-79.98247599917225, 26.569246999706113], [-79.9820899994455, 26.57961000121073], [-79.98168100011026, 26.58402800015615], [-79.98138600060203, 26.587214000299504], [-79.98133999981481, 26.587715998398703], [-79.98072199960366, 26.594623999861437], [-79.98064800007934, 26.595447000961098], [-79.9806759981807, 26.604843998371045], [-79.98098699993173, 26.615426000591327], [-79.9810739998664, 26.618373998674667], [-79.9812970012281, 26.62534500117428], [-79.9811759991607, 26.63831000104791], [-79.9812719988484, 26.647361000211017], [-79.98130300140457, 26. ...

# %%
m.save('index.html')

# %% [markdown]
# ## Summary Info

# %%
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

Newest = '\033[1m' + 'Newest' + '\033[0m'
Oldest = '\033[1m' + 'Oldest' + '\033[0m'

# %%
df_filtered.columns
# Out:
# Index(['SOLD DATE', 'ADDRESS', 'CITY', 'PRICE', 'BEDS', 'BATHS', 'LOCATION',
#        'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'URL', 'LATITUDE',
#        'LONGITUDE', 'PRICE_AS_CURRENCY', 'YEAR BUILT DISPLAY',
#        'PRICE_SQUARE_FEET_AS_CURRENCY', 'COLOR', 'RANK'],
#       dtype='object')

# %%
df_filtered['FULL_ADDRESS'] = df_filtered['ADDRESS'] + ' ' + df_filtered['CITY']

# %%
print(df_filtered.loc[df_filtered['PRICE'].idxmin()]['URL'])
# Out:
# https://www.redfin.com/FL/Lake-Worth/2811-Garden-Dr-S-33461/unit-105/home/42287192

# %%
print(f"{ME}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{LE}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{MAX_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{MIN_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{Newest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{Oldest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['YEAR BUILT']:.0f}")
# Out:
# Most Expensive
# La Clara, 200 Arkona Ct West Palm Beach | Price $18,750,000 | $2,338 psf | Year built: 2023
# Least Expensive
# Lake Clarke Gardens Condo 25, 2811 Garden Dr S #105 Lake Worth | Price $55,000 | $74 psf | Year built: 1971
# Highest Price Per Square Foot
# Seaglass Condominium, 1500 Beach Rd #403 Tequesta | Price $12,500,000 | $2,399 psf | Year built: 2022
# Lowest Price Per Square Foot
# Bridgewood Midrise, 1956 Bridgewood Dr Boca Raton | Price $75,000 | $71 psf | Year built: 1974
# Newest
# La Clara, 200 Arkona Ct West Palm Beach | Price $18,750,000 | $2,338 psf | Year built: 2023
# Oldest
# Gulfstream Condo, 31 S Golfview Rd #13 Lake Worth Beach | Price $235,000 | $324 psf | Year built: 1948

# %%
df_filtered['YEAR BUILT'].sort_values()
# Out:
# 179    1948.0
# 492    1956.0
# 521    1963.0
# 288    1964.0
# 274    1964.0
#         ...
# 469    2023.0
# 467    2023.0
# 463    2023.0
# 461    2023.0
# 530    2023.0
# Name: YEAR BUILT, Length: 581, dtype: float64

# %% [markdown]
# ## Time on Market Calculator

# %%
print(df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['URL'])
# Out:
# https://www.redfin.com/FL/Lake-Worth/2855-Garden-Dr-S-33461/unit-312/home/42291183

# %%
from datetime import datetime, timedelta

date1 = datetime(2021, 10, 12) ## List (Earlier) date
date2 = datetime(2023, 11, 3) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 752

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PBC_condo_sales_month_ending_nov_2023

# %% [markdown]
# ## Get Summary Data

# %%
print('SALES INFO')
print(f'Number of sales: {len(df_filtered)}')
print('--------')
print(f'Total sale price: ${df_filtered["PRICE"].sum():,.0f}')
print('--------')
print(f'Median sale price: ${df_filtered["PRICE"].median():,.0f}')
print('--------')
print(f'Max sale price: ${df_filtered["PRICE"].max():,.0f}')
print('--------')
print(f'Min sale price: ${df_filtered["PRICE"].min():,.0f}')
print('------------------------------------------------')
print('PSF INFO')
print(f'Max price per square foot: ${df_filtered["$/SQUARE FEET"].max():,.0f}')
print('--------')
print(f'Min price per square foot: ${df_filtered["$/SQUARE FEET"].min():,.0f}')
print('--------')
print(f'Median price per square foot: ${df_filtered["$/SQUARE FEET"].median():,.0f}')
print('------------------------------------------------')
print('CONDO AGES')
print(f'Newest building: {df_filtered["YEAR BUILT"].max()}')
print('----------')
print(f'Oldest building: {df_filtered["YEAR BUILT"].min()}')
print('----------')
print(f'Average building age: {df_filtered["YEAR BUILT"].mean()}')
# Out:
# SALES INFO
# Number of sales: 581
# --------
# Total sale price: $299,104,047
# --------
# Median sale price: $260,000
# --------
# Max sale price: $18,750,000
# --------
# Min sale price: $55,000
# ------------------------------------------------
# PSF INFO
# Max price per square foot: $2,399
# --------
# Min price per square foot: $71
# --------
# Median price per square foot: $232
# ------------------------------------------------
# CONDO AGES
# Newest building: 2023.0
# ----------
# Oldest building: 1948.0
# ----------
# Average building age: 1983.5180722891566
