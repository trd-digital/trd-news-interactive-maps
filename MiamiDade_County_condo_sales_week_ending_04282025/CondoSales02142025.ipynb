# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 20th Apr. 27th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 1  PAST SALE  April-22-2025   Condo/Co-op  17301 E Biscayne Blvd #310
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 1  North Miami Beach                FL             33160.0  1375000.0   3.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    3.5  ...   Sold                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Aventura/17301-Bisca...  MARMLS  A11779348
#
#    FAVORITE INTERESTED  LATITUDE  LONGITUDE
# 1         N          Y  25.93586 -80.148937
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-21    27
# 2025-04-24    23
# 2025-04-25    23
# 2025-04-22    19
# 2025-04-23    17
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 91   PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 42   PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 96   PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 77   PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 66   PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 104  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 28   PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 22   PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 44   PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 93   PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  \
# 91               Miami                FL             33133.0  11250000.0
# 42        Key Biscayne                FL             33149.0   8000000.0
# 96               Miami                FL             33133.0   7515000.0
# 77         Miami Beach                FL             33139.0   7250000.0
# 66               Miami                FL             33131.0   5650000.0
# 104  Sunny Isles Beach                FL             33160.0   3200000.0
# 28        Coral Gables                FL             33158.0   2500000.0
# 22         Miami Beach                FL             33139.0   2450000.0
# 44               Miami                FL             33137.0   2400000.0
# 93            Aventura                FL             33180.0   1900000.0
#
#      BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 91    6.0    7.5  ...   Sold                         NaN
# 42    4.0    5.5  ...   Sold                         NaN
# 96    4.0    7.5  ...   Sold                         NaN
# 77    4.0    4.5  ...   Sold                         NaN
# 66    3.0    4.5  ...   Sold                         NaN
# 104   4.0    4.5  ...   Sold                         NaN
# 28    3.0    3.5  ...   Sold                         NaN
# 22    1.0    1.5  ...   Sold                         NaN
# 44    2.0    2.5  ...   Sold                         NaN
# 93    5.0    5.5  ...   Sold                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 91                        NaN
# 42                        NaN
# 96                        NaN
# 77                        NaN
# 66                        NaN
# 104                       NaN
# 28                        NaN
# 22                        NaN
# 44                        NaN
# 93                        NaN
#
#                                                    URL  SOURCE       MLS#  \
# 91   https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
# 42   https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11734228
# 96   https://www.redfin.com/FL/Miami/2669-S-Bayshor...  MARMLS  A11614365
# 77   https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11673326
# 66   https://www.redfin.com/FL/Miami/1425-Brickell-...  MARMLS  A11695932
# 104  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  MARMLS  A11618112
# 28   https://www.redfin.com/FL/Coral-Gables/13621-D...  MARMLS  A11737965
# 22   https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11751093
# 44   https://www.redfin.com/FL/Miami/3131-NE-7th-Av...  MARMLS  A11744133
# 93   https://www.redfin.com/FL/Aventura/21200-Point...  MARMLS  A11639494
#
#      FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 91          N          Y  25.732272 -80.234921
# 42          N          Y  25.694584 -80.157715
# 96          N          Y  25.730676 -80.237117
# 77          N          Y  25.768803 -80.133811
# 66          N          Y  25.759132 -80.191829
# 104         N          Y  25.929401 -80.126023
# 28          N          Y  25.637681 -80.290989
# 22          N          Y  25.795314 -80.128730
# 44          N          Y  25.807047 -80.185578
# 93          N          Y  25.973121 -80.125125
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 1  PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 2  PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 3  PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 4  PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 5  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 6  PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 7  PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 8  PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 9  PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0              Miami                FL             33133.0  11250000.0   6.0
# 1       Key Biscayne                FL             33149.0   8000000.0   4.0
# 2              Miami                FL             33133.0   7515000.0   4.0
# 3        Miami Beach                FL             33139.0   7250000.0   4.0
# 4              Miami                FL             33131.0   5650000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0   3200000.0   4.0
# 6       Coral Gables                FL             33158.0   2500000.0   3.0
# 7        Miami Beach                FL             33139.0   2450000.0   1.0
# 8              Miami                FL             33137.0   2400000.0   2.0
# 9           Aventura                FL             33180.0   1900000.0   5.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    7.5  ... -80.234921  https://www.redfin.com/FL/Miami/2627-S-Bayshor...
# 1    5.5  ... -80.157715  https://www.redfin.com/FL/Key-Biscayne/360-Oce...
# 2    7.5  ... -80.237117  https://www.redfin.com/FL/Miami/2669-S-Bayshor...
# 3    4.5  ... -80.133811  https://www.redfin.com/FL/Miami-Beach/1-Collin...
# 4    4.5  ... -80.191829  https://www.redfin.com/FL/Miami/1425-Brickell-...
# 5    4.5  ... -80.126023  https://www.redfin.com/FL/Sunny-Isles-Beach/33...
# 6    3.5  ... -80.290989  https://www.redfin.com/FL/Coral-Gables/13621-D...
# 7    1.5  ... -80.128730  https://www.redfin.com/FL/Miami-Beach/101-20th...
# 8    2.5  ... -80.185578  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...
# 9    5.5  ... -80.125125  https://www.redfin.com/FL/Aventura/21200-Point...
#
#        list_agent_name_1                  list_broker_name_1  \
# 0              Liz Hogan               Compass Florida, LLC.
# 1           Elena Chacon                     BHHS EWM Realty
# 2         Giorgio Vecchi                     Douglas Elliman
# 3             Marco Tine                             Serhant
# 4       Fabian Dominguez        Fortune Christie's Intl R.E.
# 5  Lucas Lempek Ferreira                            LoKation
# 6      Gustavo De Castro               RE/MAX Advance Realty
# 7            Jeff Miller      One Sotheby's International Re
# 8              Saar Mana           Sterling One Realty, Inc.
# 9         Patricia Genis  One Sotheby's International Realty
#
#    list_agent_name_2            list_broker_name_2   buy_agent_name_1  \
# 0               None                          None   Debra Flam Velez
# 1               None                          None     Carolina Trovo
# 2        Dario Stoka               Douglas Elliman        Dario Stoka
# 3               None                          None     Joseph Schafer
# 4    Peter Liakouras  Fortune Christie's Intl R.E.     Debora Caridad
# 5               None                          None       Chun Po Hung
# 6               None                          None     Brandi Kulberg
# 7               None                          None  Cecilia Solorzano
# 8               None                          None       Elle Berkman
# 9               None                          None     Jessica Sonino
#
#                               buy_broker_name_1  buy_agent_name_2  \
# 0                        Coldwell Banker Realty              None
# 1                          Blue One Realty, LLC              None
# 2                               Douglas Elliman              None
# 3                               Douglas Elliman    Raissa Enis PA
# 4  Fortune Christie's International Real Estate              None
# 5                                EXP Realty LLC              None
# 6                  Tenzer Realty and Associates              None
# 7                            Suma Luxury Realty              None
# 8                        Coldwell Banker Realty              None
# 9                                      LoKation              None
#
#    buy_broker_name_2
# 0               None
# 1               None
# 2               None
# 3    Douglas Elliman
# 4               None
# 5               None
# 6               None
# 7               None
# 8               None
# 9               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 109

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $972,843

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $589

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $106,039,925

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input county name:
# Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 141
# -----------
# Input Previous Week Condo Average Sales Price:
# 968147
# -----------
# Input Previous Week Condo Average PSF:
# 615
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 136508765.0

# %%
last_week
# Out:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          141              968147          615                    136508765.0

# %%
last_week['Last Week Total Dollar Volume'].iloc[0]
# Out:
# 136508765.0

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          109              972843          589                    106039925.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS   CITY  \
# 0  PAST SALE 2025-04-23   Condo/Co-op  2627 S Bayshore Dr #3001  Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33133.0  11250000.0   6.0    7.5
#
#                LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  GROVENOR HOUSE CONDO       6920.0       NaN      2006.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1626.0    10696.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Liz Hogan
#
#       list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Compass Florida, LLC.              None               None
#
#    buy_agent_name_1       buy_broker_name_1 buy_agent_name_2  \
# 0  Debra Flam Velez  Coldwell Banker Realty             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 1  PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 2  PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 3  PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 4  PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 5  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 6  PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 7  PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 8  PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 9  PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0              Miami                FL             33133.0  11250000.0   6.0
# 1       Key Biscayne                FL             33149.0   8000000.0   4.0
# 2              Miami                FL             33133.0   7515000.0   4.0
# 3        Miami Beach                FL             33139.0   7250000.0   4.0
# 4              Miami                FL             33131.0   5650000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0   3200000.0   4.0
# 6       Coral Gables                FL             33158.0   2500000.0   3.0
# 7        Miami Beach                FL             33139.0   2450000.0   1.0
# 8              Miami                FL             33137.0   2400000.0   2.0
# 9           Aventura                FL             33180.0   1900000.0   5.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    7.5       GROVENOR HOUSE CONDO       6920.0       NaN      2006.0
# 1    5.5  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 2    7.5                 DINNER KEY       3532.0       NaN      2016.0
# 3    4.5            ONE OCEAN CONDO       3337.0       NaN      2016.0
# 4    4.5    FOUR SEASONS RESIDENCES       3730.0       NaN      2003.0
# 5    4.5        PARQUE TOWERS CONDO       3084.0       NaN      2019.0
# 6    3.5  MILANO AT DEERING BAY CON       2972.0       NaN      2003.0
# 7    1.5  SETAI RESORT & RESIDENCES        821.0       NaN      2004.0
# 8    2.5          ONE PARAISO CONDO       1634.0       NaN      2018.0
# 9    5.5  ATLANTIC I AT THE POINT C       4171.0       NaN      2004.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1626.0    10696.0   Sold
# 1             NaN         2385.0     5464.0   Sold
# 2             NaN         2128.0     5366.0   Sold
# 3             NaN         2173.0     9539.0   Sold
# 4             NaN         1515.0     6058.0   Sold
# 5             NaN         1038.0     2400.0   Sold
# 6             NaN          841.0     3025.0   Sold
# 7             NaN         2984.0     3733.0   Sold
# 8             NaN         1469.0     2400.0   Sold
# 9             NaN          456.0     8034.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11734228
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...  MARMLS  A11614365
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11673326
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...  MARMLS  A11695932
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  MARMLS  A11618112
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...  MARMLS  A11737965
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11751093
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...  MARMLS  A11744133
# 9  https://www.redfin.com/FL/Aventura/21200-Point...  MARMLS  A11639494
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
# 1        N          Y  25.694584 -80.157715
# 2        N          Y  25.730676 -80.237117
# 3        N          Y  25.768803 -80.133811
# 4        N          Y  25.759132 -80.191829
# 5        N          Y  25.929401 -80.126023
# 6        N          Y  25.637681 -80.290989
# 7        N          Y  25.795314 -80.128730
# 8        N          Y  25.807047 -80.185578
# 9        N          Y  25.973121 -80.125125
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...              Liz Hogan
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...           Elena Chacon
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...         Giorgio Vecchi
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...             Marco Tine
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...       Fabian Dominguez
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  Lucas Lempek Ferreira
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...      Gustavo De Castro
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...            Jeff Miller
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...              Saar Mana
# 9  https://www.redfin.com/FL/Aventura/21200-Point...         Patricia Genis
#
#                    list_broker_name_1 list_agent_name_2  \
# 0               Compass Florida, LLC.              None
# 1                     BHHS EWM Realty              None
# 2                     Douglas Elliman       Dario Stoka
# 3                             Serhant              None
# 4        Fortune Christie's Intl R.E.   Peter Liakouras
# 5                            LoKation              None
# 6               RE/MAX Advance Realty              None
# 7      One Sotheby's International Re              None
# 8           Sterling One Realty, Inc.              None
# 9  One Sotheby's International Realty              None
#
#              list_broker_name_2   buy_agent_name_1  \
# 0                          None   Debra Flam Velez
# 1                          None     Carolina Trovo
# 2               Douglas Elliman        Dario Stoka
# 3                          None     Joseph Schafer
# 4  Fortune Christie's Intl R.E.     Debora Caridad
# 5                          None       Chun Po Hung
# 6                          None     Brandi Kulberg
# 7                          None  Cecilia Solorzano
# 8                          None       Elle Berkman
# 9                          None     Jessica Sonino
#
#                               buy_broker_name_1 buy_agent_name_2  \
# 0                        Coldwell Banker Realty             None
# 1                          Blue One Realty, LLC             None
# 2                               Douglas Elliman             None
# 3                               Douglas Elliman   Raissa Enis PA
# 4  Fortune Christie's International Real Estate             None
# 5                                EXP Realty LLC             None
# 6                  Tenzer Realty and Associates             None
# 7                            Suma Luxury Realty             None
# 8                        Coldwell Banker Realty             None
# 9                                      LoKation             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3   Douglas Elliman     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_960df79b74acd5a4a379ae418d0d4279 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 20th — Apr. 27th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_960df79b74acd5a4a379ae418d0d4279&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_960df79b74acd5a4a379ae418d0d4279 = L.map(
#                 &quot;map_960df79b74acd5a4a379ae418d0d4279&quot;,
#                 {
#                     center: [25.795833786238532, -80.21529921834862],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_ffe4d24474dd653a0067a62095b69a59 = L.featureGroup(
#                 {}
#             ).addTo(map_960df79b74acd5a4a379ae418d0d4279);
#
#
#             var marker_06809d512e0b2e945a70785db21d73a5 = L.marker(
#                 [25.7322719, -80.2349208],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_ffe4d24474dd653a0067a62095b69a59);
#
#
#             var icon_413b90f59a4c2f65c30a2819a9837e82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_06809d512e0b2e945a70785db21d73a5.setIcon(icon_413b90f59a4c2f65c30a2819a9837e82);
#
#
#         var popup_4b837de4dca8e821f5dbce819dca5a76 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_ae47e5fddb5111f60cb1b42d5b0e8748 = $(`&lt;div id=&quot;html_ae47e5fddb5111f60cb1b42d5b0e8748&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2627 S Bayshore Dr #3001&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$11,250,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,626.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;6,920.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2006.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_4b837de4dca8e821f5dbce819dca5a76.setContent(html_ae47e5fddb5111f60cb1b42d5b0e8748);
#
#
#
#         marker_06809d512e0b2e945a70785db21d73a5.bindPopup(popup_4b837de4dca8e821f5dbce819dca5a76)
#         ;
#
#
#
#
#             var feature_group_7ba51eda54ff33aad1b0000fd9738b7f = L.featureGroup(
#                 {}
#             ).addTo(map_960df79b74acd5a4a379ae418d0d4279);
#
#
#             var marker_efca9b1be62b5afe81560fcd859576f4 = L.marker(
#                 [25.694584, -80.157715],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7ba51eda54ff33aad1b0000fd9738b7f);
#
#
#             var icon_981ff9cc8fad078a077aa7bb819ce528 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_efca9b1be62b5afe81560fcd859576f4.setIcon(icon_981ff9cc8fad078a077aa7bb819ce528);
#
#
#         var popup_cec38c0e9f9c71ba62a994918113ffc8 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_60822abc3514b16bfd5132e8460aa675 = $(`&lt;div id=&quot;html_60822abc3514b16bfd5132e8460aa675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;360 Ocean Dr Unit 902S&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$8,000,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,385.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,354.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2014.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_cec38c0e9f9c71ba62a994918113ffc8.setContent(html_60822abc3514b16bfd5132e8460aa675);
#
#
#
#         marker_efca9b1be62b5afe81560fcd859576f4.bindPopup(popup_cec38c0e9f9c71ba62a994918113ffc8)
#         ;
#
#
#
#
#             var marker_855c7d9f1f7655b26ac5850feba445d1 = L.marker(
#                 [25.7306755, -80.2371172],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7ba51eda54ff33aad1b0000fd9738b7f);
#
#
#             var icon_1c6cbc6c4cda1b17452e3636ccc6e16a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_855c7d9f1f7655b26ac5850feba445d1.setIcon(icon_1c6cbc6c4cda1b17452e3636ccc6e16a);
#
#
#         var popup_c4faaa1b539baab1bc6f8cd9b202b7c0 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_ce38b2366af239c902540f4544a2a331

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS   CITY  \
# 0  PAST SALE 2025-04-23   Condo/Co-op  2627 S Bayshore Dr #3001  Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33133.0  11250000.0   6.0    7.5
#
#                LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  GROVENOR HOUSE CONDO       6920.0       NaN      2006.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1626.0    10696.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...         Liz Hogan
#
#       list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Compass Florida, LLC.              None               None
#
#    buy_agent_name_1       buy_broker_name_1 buy_agent_name_2  \
# 0  Debra Flam Velez  Coldwell Banker Realty             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_04282025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #3001 in Miami'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 1  PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 2  PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 3  PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 4  PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 5  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 6  PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 7  PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 8  PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 9  PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0              Miami                FL             33133.0  11250000.0   6.0
# 1       Key Biscayne                FL             33149.0   8000000.0   4.0
# 2              Miami                FL             33133.0   7515000.0   4.0
# 3        Miami Beach                FL             33139.0   7250000.0   4.0
# 4              Miami                FL             33131.0   5650000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0   3200000.0   4.0
# 6       Coral Gables                FL             33158.0   2500000.0   3.0
# 7        Miami Beach                FL             33139.0   2450000.0   1.0
# 8              Miami                FL             33137.0   2400000.0   2.0
# 9           Aventura                FL             33180.0   1900000.0   5.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    7.5       GROVENOR HOUSE CONDO       6920.0       NaN      2006.0
# 1    5.5  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 2    7.5                 DINNER KEY       3532.0       NaN      2016.0
# 3    4.5            ONE OCEAN CONDO       3337.0       NaN      2016.0
# 4    4.5    FOUR SEASONS RESIDENCES       3730.0       NaN      2003.0
# 5    4.5        PARQUE TOWERS CONDO       3084.0       NaN      2019.0
# 6    3.5  MILANO AT DEERING BAY CON       2972.0       NaN      2003.0
# 7    1.5  SETAI RESORT & RESIDENCES        821.0       NaN      2004.0
# 8    2.5          ONE PARAISO CONDO       1634.0       NaN      2018.0
# 9    5.5  ATLANTIC I AT THE POINT C       4171.0       NaN      2004.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1626.0    10696.0   Sold
# 1             NaN         2385.0     5464.0   Sold
# 2             NaN         2128.0     5366.0   Sold
# 3             NaN         2173.0     9539.0   Sold
# 4             NaN         1515.0     6058.0   Sold
# 5             NaN         1038.0     2400.0   Sold
# 6             NaN          841.0     3025.0   Sold
# 7             NaN         2984.0     3733.0   Sold
# 8             NaN         1469.0     2400.0   Sold
# 9             NaN          456.0     8034.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11734228
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...  MARMLS  A11614365
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11673326
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...  MARMLS  A11695932
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  MARMLS  A11618112
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...  MARMLS  A11737965
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11751093
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...  MARMLS  A11744133
# 9  https://www.redfin.com/FL/Aventura/21200-Point...  MARMLS  A11639494
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
# 1        N          Y  25.694584 -80.157715
# 2        N          Y  25.730676 -80.237117
# 3        N          Y  25.768803 -80.133811
# 4        N          Y  25.759132 -80.191829
# 5        N          Y  25.929401 -80.126023
# 6        N          Y  25.637681 -80.290989
# 7        N          Y  25.795314 -80.128730
# 8        N          Y  25.807047 -80.185578
# 9        N          Y  25.973121 -80.125125
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...              Liz Hogan
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...           Elena Chacon
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...         Giorgio Vecchi
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...             Marco Tine
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...       Fabian Dominguez
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  Lucas Lempek Ferreira
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...      Gustavo De Castro
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...            Jeff Miller
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...              Saar Mana
# 9  https://www.redfin.com/FL/Aventura/21200-Point...         Patricia Genis
#
#                    list_broker_name_1 list_agent_name_2  \
# 0               Compass Florida, LLC.              None
# 1                     BHHS EWM Realty              None
# 2                     Douglas Elliman       Dario Stoka
# 3                             Serhant              None
# 4        Fortune Christie's Intl R.E.   Peter Liakouras
# 5                            LoKation              None
# 6               RE/MAX Advance Realty              None
# 7      One Sotheby's International Re              None
# 8           Sterling One Realty, Inc.              None
# 9  One Sotheby's International Realty              None
#
#              list_broker_name_2   buy_agent_name_1  \
# 0                          None   Debra Flam Velez
# 1                          None     Carolina Trovo
# 2               Douglas Elliman        Dario Stoka
# 3                          None     Joseph Schafer
# 4  Fortune Christie's Intl R.E.     Debora Caridad
# 5                          None       Chun Po Hung
# 6                          None     Brandi Kulberg
# 7                          None  Cecilia Solorzano
# 8                          None       Elle Berkman
# 9                          None     Jessica Sonino
#
#                               buy_broker_name_1 buy_agent_name_2  \
# 0                        Coldwell Banker Realty             None
# 1                          Blue One Realty, LLC             None
# 2                               Douglas Elliman             None
# 3                               Douglas Elliman   Raissa Enis PA
# 4  Fortune Christie's International Real Estate             None
# 5                                EXP Realty LLC             None
# 6                  Tenzer Realty and Associates             None
# 7                            Suma Luxury Realty             None
# 8                        Coldwell Banker Realty             None
# 9                                      LoKation             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3   Douglas Elliman     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #30...
# 1  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 2  DINNER KEY at 2669 S Bayshore Dr Unit 1601N in...
# 3  ONE OCEAN CONDO at 1 Collins Ave #406 in Miami...
# 4  FOUR SEASONS RESIDENCES at 1425 Brickell Ave U...
# 5  PARQUE TOWERS CONDO at 330 Sunny Isles Blvd Un...
# 6  MILANO AT DEERING BAY CON at 13621 Deering Bay...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #3005...
# 8  ONE PARAISO CONDO at 3131 NE 7th Ave #4301 in ...
# 9  ATLANTIC I AT THE POINT C at 21200 Point Pl #6...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: GROVENOR HOUSE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,900,000 to $11,250,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Key Biscayne, Sunny Isles Beach, Miami, Miami Beach, Coral Gables, Aventura, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 109 condo sales totaling $106,039,925 million from Apr. 20th to Apr. 27th. The previous week, brokers closed 141 condo sales totaling $136,508,765.
#
# Last week’s units sold for an average of $972,843, higher than the $968,147 average price from the previous week. The average price per square foot fell to $589 from $615, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,900,000.0 million to $11,250,000.0 million.
#
# GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #3001 in Miami took the top spot with a $11,250,000.0 million closing. The sale closed at $1,626.0 per square foot.
#
# Liz Hogan with Compass Florida, LLC., and None with None had the listing.
# Debra Flam Velez with Coldwell Banker Realty, and None with None represented the buyer.
#
# OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit 902S in Key Biscayne, closed for the second highest amount, $8,000,000.0, or $2,385.0 per square foot.
#
# Elena Chacon with BHHS EWM Realty, and None with None had the listing.
# Carolina Trovo with Blue One Realty, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_04282025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 20th to Apr. 27th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 1  PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 2  PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 3  PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 4  PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 5  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 6  PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 7  PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 8  PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 9  PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0              Miami                FL             33133.0  11250000.0   6.0
# 1       Key Biscayne                FL             33149.0   8000000.0   4.0
# 2              Miami                FL             33133.0   7515000.0   4.0
# 3        Miami Beach                FL             33139.0   7250000.0   4.0
# 4              Miami                FL             33131.0   5650000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0   3200000.0   4.0
# 6       Coral Gables                FL             33158.0   2500000.0   3.0
# 7        Miami Beach                FL             33139.0   2450000.0   1.0
# 8              Miami                FL             33137.0   2400000.0   2.0
# 9           Aventura                FL             33180.0   1900000.0   5.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    7.5       GROVENOR HOUSE CONDO       6920.0       NaN      2006.0
# 1    5.5  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 2    7.5                 DINNER KEY       3532.0       NaN      2016.0
# 3    4.5            ONE OCEAN CONDO       3337.0       NaN      2016.0
# 4    4.5    FOUR SEASONS RESIDENCES       3730.0       NaN      2003.0
# 5    4.5        PARQUE TOWERS CONDO       3084.0       NaN      2019.0
# 6    3.5  MILANO AT DEERING BAY CON       2972.0       NaN      2003.0
# 7    1.5  SETAI RESORT & RESIDENCES        821.0       NaN      2004.0
# 8    2.5          ONE PARAISO CONDO       1634.0       NaN      2018.0
# 9    5.5  ATLANTIC I AT THE POINT C       4171.0       NaN      2004.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1626.0    10696.0   Sold
# 1             NaN         2385.0     5464.0   Sold
# 2             NaN         2128.0     5366.0   Sold
# 3             NaN         2173.0     9539.0   Sold
# 4             NaN         1515.0     6058.0   Sold
# 5             NaN         1038.0     2400.0   Sold
# 6             NaN          841.0     3025.0   Sold
# 7             NaN         2984.0     3733.0   Sold
# 8             NaN         1469.0     2400.0   Sold
# 9             NaN          456.0     8034.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11734228
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...  MARMLS  A11614365
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11673326
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...  MARMLS  A11695932
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  MARMLS  A11618112
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...  MARMLS  A11737965
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11751093
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...  MARMLS  A11744133
# 9  https://www.redfin.com/FL/Aventura/21200-Point...  MARMLS  A11639494
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
# 1        N          Y  25.694584 -80.157715
# 2        N          Y  25.730676 -80.237117
# 3        N          Y  25.768803 -80.133811
# 4        N          Y  25.759132 -80.191829
# 5        N          Y  25.929401 -80.126023
# 6        N          Y  25.637681 -80.290989
# 7        N          Y  25.795314 -80.128730
# 8        N          Y  25.807047 -80.185578
# 9        N          Y  25.973121 -80.125125
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...              Liz Hogan
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...           Elena Chacon
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...         Giorgio Vecchi
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...             Marco Tine
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...       Fabian Dominguez
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  Lucas Lempek Ferreira
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...      Gustavo De Castro
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...            Jeff Miller
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...              Saar Mana
# 9  https://www.redfin.com/FL/Aventura/21200-Point...         Patricia Genis
#
#                    list_broker_name_1 list_agent_name_2  \
# 0               Compass Florida, LLC.              None
# 1                     BHHS EWM Realty              None
# 2                     Douglas Elliman       Dario Stoka
# 3                             Serhant              None
# 4        Fortune Christie's Intl R.E.   Peter Liakouras
# 5                            LoKation              None
# 6               RE/MAX Advance Realty              None
# 7      One Sotheby's International Re              None
# 8           Sterling One Realty, Inc.              None
# 9  One Sotheby's International Realty              None
#
#              list_broker_name_2   buy_agent_name_1  \
# 0                          None   Debra Flam Velez
# 1                          None     Carolina Trovo
# 2               Douglas Elliman        Dario Stoka
# 3                          None     Joseph Schafer
# 4  Fortune Christie's Intl R.E.     Debora Caridad
# 5                          None       Chun Po Hung
# 6                          None     Brandi Kulberg
# 7                          None  Cecilia Solorzano
# 8                          None       Elle Berkman
# 9                          None     Jessica Sonino
#
#                               buy_broker_name_1 buy_agent_name_2  \
# 0                        Coldwell Banker Realty             None
# 1                          Blue One Realty, LLC             None
# 2                               Douglas Elliman             None
# 3                               Douglas Elliman   Raissa Enis PA
# 4  Fortune Christie's International Real Estate             None
# 5                                EXP Realty LLC             None
# 6                  Tenzer Realty and Associates             None
# 7                            Suma Luxury Realty             None
# 8                        Coldwell Banker Realty             None
# 9                                      LoKation             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3   Douglas Elliman     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #30...
# 1  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 2  DINNER KEY at 2669 S Bayshore Dr Unit 1601N in...
# 3  ONE OCEAN CONDO at 1 Collins Ave #406 in Miami...
# 4  FOUR SEASONS RESIDENCES at 1425 Brickell Ave U...
# 5  PARQUE TOWERS CONDO at 330 Sunny Isles Blvd Un...
# 6  MILANO AT DEERING BAY CON at 13621 Deering Bay...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #3005...
# 8  ONE PARAISO CONDO at 3131 NE 7th Ave #4301 in ...
# 9  ATLANTIC I AT THE POINT C at 21200 Point Pl #6...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: GROVENOR HOUSE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,900,000 to $11,250,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Key Biscayne, Sunny Isles Beach, Miami, Miami Beach, Coral Gables, Aventura, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 109 condo sales totaling $106,039,925 million from Apr. 20th to Apr. 27th. The previous week, brokers closed 141 condo sales totaling $136,508,765.
#
# Last week’s units sold for an average of $972,843, higher than the $968,147 average price from the previous week. The average price per square foot fell to $589 from $615, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,900,000.0 million to $11,250,000.0 million.
#
# GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #3001 in Miami took the top spot with a $11,250,000.0 million closing. The sale closed at $1,626.0 per square foot.
#
# Liz Hogan with Compass Florida, LLC., and None with None had the listing.
# Debra Flam Velez with Coldwell Banker Realty, and None with None represented the buyer.
#
# OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit 902S in Key Biscayne, closed for the second highest amount, $8,000,000.0, or $2,385.0 per square foot.
#
# Elena Chacon with BHHS EWM Realty, and None with None had the listing.
# Carolina Trovo with Blue One Realty, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_04282025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 20th to Apr. 27th:
#
# Most Expensive
# GROVENOR HOUSE CONDO, 2627 S Bayshore Dr #3001, in Miami | Price: $11,250,000 | $1,626 psf | Listing agents: Liz Hogan with Compass Florida, LLC. and None with None | Buyer's agents: Debra Flam Velez with Coldwell Banker Realty and None with None
#
# Least Expensive
# ATLANTIC I AT THE POINT C, 21200 Point Pl #605, in Aventura | Price: $1,900,000 | $456 psf | Listing agents: Patricia Genis with One Sotheby's International Realty and None with None | Buyer's agents: Jessica Sonino with LoKation and None with None
#
# Highest Price Per Square Foot
# SETAI RESORT & RESIDENCES, 101 20th St #3005, in Miami Beach | Price: $2,450,000 | $2,984 psf | Listing agents: Jeff Miller with One Sotheby's International Re and None with None | Buyer's agents: Cecilia Solorzano with Suma Luxury Realty and None with None
#
# Lowest Price Per Square Foot
# ATLANTIC I AT THE POINT C, 21200 Point Pl #605, in Aventura | Price: $1,900,000 | $456 psf | Listing agents: Patricia Genis with One Sotheby's International Realty and None with None | Buyer's agents: Jessica Sonino with LoKation and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Miami/2627-S-Bayshore-Dr-33133/unit-3001/home/43344989
# Second priciest sale:  https://www.redfin.com/FL/Key-Biscayne/360-Ocean-Dr-33149/unit-902S/home/79133320
# Cheapest top ten sale:  https://www.redfin.com/FL/Aventura/21200-Point-Pl-33180/unit-605/home/190088441
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Miami/3131-NE-7th-Ave-33137/unit-4301/home/79132377
# Highest top ten psf:  https://www.redfin.com/FL/Miami-Beach/101-20th-St-33139/unit-3005/home/43309724
# Lowest top ten psf:  https://www.redfin.com/FL/Aventura/21200-Point-Pl-33180/unit-605/home/190088441

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Miami/2627-S-Bayshore-Dr-33133/unit-3001/home/43344989

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Key-Biscayne/360-Ocean-Dr-33149/unit-902S/home/79133320

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Aventura/21200-Point-Pl-33180/unit-605/home/190088441

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Miami/3131-NE-7th-Ave-33137/unit-4301/home/79132377

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/101-20th-St-33139/unit-3005/home/43309724

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Aventura/21200-Point-Pl-33180/unit-605/home/190088441

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-04-23   Condo/Co-op          2627 S Bayshore Dr #3001
# 1  PAST SALE 2025-04-21   Condo/Co-op            360 Ocean Dr Unit 902S
# 2  PAST SALE 2025-04-24   Condo/Co-op     2669 S Bayshore Dr Unit 1601N
# 3  PAST SALE 2025-04-23   Condo/Co-op                1 Collins Ave #406
# 4  PAST SALE 2025-04-25   Condo/Co-op        1425 Brickell Ave Unit 53F
# 5  PAST SALE 2025-04-22   Condo/Co-op  330 Sunny Isles Blvd Unit 5-2404
# 6  PAST SALE 2025-04-22   Condo/Co-op         13621 Deering Bay Dr #803
# 7  PAST SALE 2025-04-25   Condo/Co-op                 101 20th St #3005
# 8  PAST SALE 2025-04-24   Condo/Co-op             3131 NE 7th Ave #4301
# 9  PAST SALE 2025-04-22   Condo/Co-op               21200 Point Pl #605
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0              Miami                FL             33133.0  11250000.0   6.0
# 1       Key Biscayne                FL             33149.0   8000000.0   4.0
# 2              Miami                FL             33133.0   7515000.0   4.0
# 3        Miami Beach                FL             33139.0   7250000.0   4.0
# 4              Miami                FL             33131.0   5650000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0   3200000.0   4.0
# 6       Coral Gables                FL             33158.0   2500000.0   3.0
# 7        Miami Beach                FL             33139.0   2450000.0   1.0
# 8              Miami                FL             33137.0   2400000.0   2.0
# 9           Aventura                FL             33180.0   1900000.0   5.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    7.5       GROVENOR HOUSE CONDO       6920.0       NaN      2006.0
# 1    5.5  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 2    7.5                 DINNER KEY       3532.0       NaN      2016.0
# 3    4.5            ONE OCEAN CONDO       3337.0       NaN      2016.0
# 4    4.5    FOUR SEASONS RESIDENCES       3730.0       NaN      2003.0
# 5    4.5        PARQUE TOWERS CONDO       3084.0       NaN      2019.0
# 6    3.5  MILANO AT DEERING BAY CON       2972.0       NaN      2003.0
# 7    1.5  SETAI RESORT & RESIDENCES        821.0       NaN      2004.0
# 8    2.5          ONE PARAISO CONDO       1634.0       NaN      2018.0
# 9    5.5  ATLANTIC I AT THE POINT C       4171.0       NaN      2004.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1626.0    10696.0   Sold
# 1             NaN         2385.0     5464.0   Sold
# 2             NaN         2128.0     5366.0   Sold
# 3             NaN         2173.0     9539.0   Sold
# 4             NaN         1515.0     6058.0   Sold
# 5             NaN         1038.0     2400.0   Sold
# 6             NaN          841.0     3025.0   Sold
# 7             NaN         2984.0     3733.0   Sold
# 8             NaN         1469.0     2400.0   Sold
# 9             NaN          456.0     8034.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...  MARMLS  A11642973
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11734228
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...  MARMLS  A11614365
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11673326
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...  MARMLS  A11695932
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  MARMLS  A11618112
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...  MARMLS  A11737965
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...  MARMLS  A11751093
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...  MARMLS  A11744133
# 9  https://www.redfin.com/FL/Aventura/21200-Point...  MARMLS  A11639494
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.732272 -80.234921
# 1        N          Y  25.694584 -80.157715
# 2        N          Y  25.730676 -80.237117
# 3        N          Y  25.768803 -80.133811
# 4        N          Y  25.759132 -80.191829
# 5        N          Y  25.929401 -80.126023
# 6        N          Y  25.637681 -80.290989
# 7        N          Y  25.795314 -80.128730
# 8        N          Y  25.807047 -80.185578
# 9        N          Y  25.973121 -80.125125
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami/2627-S-Bayshor...              Liz Hogan
# 1  https://www.redfin.com/FL/Key-Biscayne/360-Oce...           Elena Chacon
# 2  https://www.redfin.com/FL/Miami/2669-S-Bayshor...         Giorgio Vecchi
# 3  https://www.redfin.com/FL/Miami-Beach/1-Collin...             Marco Tine
# 4  https://www.redfin.com/FL/Miami/1425-Brickell-...       Fabian Dominguez
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/33...  Lucas Lempek Ferreira
# 6  https://www.redfin.com/FL/Coral-Gables/13621-D...      Gustavo De Castro
# 7  https://www.redfin.com/FL/Miami-Beach/101-20th...            Jeff Miller
# 8  https://www.redfin.com/FL/Miami/3131-NE-7th-Av...              Saar Mana
# 9  https://www.redfin.com/FL/Aventura/21200-Point...         Patricia Genis
#
#                    list_broker_name_1 list_agent_name_2  \
# 0               Compass Florida, LLC.              None
# 1                     BHHS EWM Realty              None
# 2                     Douglas Elliman       Dario Stoka
# 3                             Serhant              None
# 4        Fortune Christie's Intl R.E.   Peter Liakouras
# 5                            LoKation              None
# 6               RE/MAX Advance Realty              None
# 7      One Sotheby's International Re              None
# 8           Sterling One Realty, Inc.              None
# 9  One Sotheby's International Realty              None
#
#              list_broker_name_2   buy_agent_name_1  \
# 0                          None   Debra Flam Velez
# 1                          None     Carolina Trovo
# 2               Douglas Elliman        Dario Stoka
# 3                          None     Joseph Schafer
# 4  Fortune Christie's Intl R.E.     Debora Caridad
# 5                          None       Chun Po Hung
# 6                          None     Brandi Kulberg
# 7                          None  Cecilia Solorzano
# 8                          None       Elle Berkman
# 9                          None     Jessica Sonino
#
#                               buy_broker_name_1 buy_agent_name_2  \
# 0                        Coldwell Banker Realty             None
# 1                          Blue One Realty, LLC             None
# 2                               Douglas Elliman             None
# 3                               Douglas Elliman   Raissa Enis PA
# 4  Fortune Christie's International Real Estate             None
# 5                                EXP Realty LLC             None
# 6                  Tenzer Realty and Associates             None
# 7                            Suma Luxury Realty             None
# 8                        Coldwell Banker Realty             None
# 9                                      LoKation             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3   Douglas Elliman     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  GROVENOR HOUSE CONDO at 2627 S Bayshore Dr #30...
# 1  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 2  DINNER KEY at 2669 S Bayshore Dr Unit 1601N in...
# 3  ONE OCEAN CONDO at 1 Collins Ave #406 in Miami...
# 4  FOUR SEASONS RESIDENCES at 1425 Brickell Ave U...
# 5  PARQUE TOWERS CONDO at 330 Sunny Isles Blvd Un...
# 6  MILANO AT DEERING BAY CON at 13621 Deering Bay...
# 7  SETAI RESORT & RESIDENCES at 101 20th St #3005...
# 8  ONE PARAISO CONDO at 3131 NE 7th Ave #4301 in ...
# 9  ATLANTIC I AT THE POINT C at 21200 Point Pl #6...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 1, 29) ## List (Earlier) date
date2 = datetime(2025, 4, 21) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 82

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1626.0
# 1    2385.0
# 2    2128.0
# 3    2173.0
# 4    1515.0
# 5    1038.0
# 6     841.0
# 7    2984.0
# 8    1469.0
# 9     456.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS        PRICE  \
# 0 2025-04-23                  2627 S Bayshore Dr #3001 in Miami  $11,250,000
# 1 2025-04-21             360 Ocean Dr Unit 902S in Key Biscayne   $8,000,000
# 2 2025-04-24             2669 S Bayshore Dr Unit 1601N in Miami   $7,515,000
# 3 2025-04-23                  1 Collins Ave #406 in Miami Beach   $7,250,000
# 4 2025-04-25                1425 Brickell Ave Unit 53F in Miami   $5,650,000
# 5 2025-04-22  330 Sunny Isles Blvd Unit 5-2404 in Sunny Isle...   $3,200,000
# 6 2025-04-22          13621 Deering Bay Dr #803 in Coral Gables   $2,500,000
# 7 2025-04-25                   101 20th St #3005 in Miami Beach   $2,450,000
# 8 2025-04-24                     3131 NE 7th Ave #4301 in Miami   $2,400,000
# 9 2025-04-22                    21200 Point Pl #605 in Aventura   $1,900,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET  SOURCE       MLS#  \
# 0    6    7.5       6,920       2006        $1,626  MARMLS  A11642973
# 1    4    5.5       3,354       2014        $2,385  MARMLS  A11734228
# 2    4    7.5       3,532       2016        $2,128  MARMLS  A11614365
# 3    4    4.5       3,337       2016        $2,173  MARMLS  A11673326
# 4    3    4.5       3,730       2003        $1,515  MARMLS  A11695932
# 5    4    4.5       3,084       2019        $1,038  MARMLS  A11618112
# 6    3    3.5       2,972       2003          $841  MARMLS  A11737965
# 7    1    1.5         821       2004        $2,984  MARMLS  A11751093
# 8    2    2.5       1,634       2018        $1,469  MARMLS  A11744133
# 9    5    5.5       4,171       2004          $456  MARMLS  A11639494
#
#                                         LISTING INFO  \
# 0                Liz Hogan Compass Florida, LLC.
# 1                   Elena Chacon BHHS EWM Realty
# 2  Giorgio Vecchi Douglas Elliman Dario Stoka Dou...
# 3                             Marco Tine Serhant
# 4  Fabian Dominguez Fortune Christie's Intl R.E. ...
# 5                 Lucas Lempek Ferreira LoKation
# 6        Gustavo De Castro RE/MAX Advance Realty
# 7     Jeff Miller One Sotheby's International Re
# 8            Saar Mana Sterling One Realty, Inc.
# 9  Patricia Genis One Sotheby's International Rea...
#
#                                          BUYING INFO
# 0        Debra Flam Velez Coldwell Banker Realty
# 1            Carolina Trovo Blue One Realty, LLC
# 2                    Dario Stoka Douglas Elliman
# 3  Joseph Schafer Douglas Elliman Raissa Enis PA ...
# 4  Debora Caridad Fortune Christie's Internationa...
# 5                    Chun Po Hung EXP Realty LLC
# 6    Brandi Kulberg Tenzer Realty and Associates
# 7           Cecilia Solorzano Suma Luxury Realty
# 8            Elle Berkman Coldwell Banker Realty
# 9                        Jessica Sonino LoKation
