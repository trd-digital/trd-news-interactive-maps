# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import folium

# %% [markdown]
# ## Data Read-in

# %%
df = pd.read_csv('redfin_2023-08-07-09-19-29.csv')

# %% [markdown]
# ## Data Clean

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
df = df.dropna(subset=['SOLD DATE'])

# %%
# Define list of desired months (excluding current month)
desired_months = ['July']

# Filter DataFrame to include only entries from desired months
df_filtered = df[df['SOLD DATE'].str.split('-', expand=True)[0].isin(desired_months)]

# Reset the index
df_filtered = df_filtered.reset_index(drop=True)

# %%
# Data checks
print(df_filtered['PRICE'].isna().value_counts())
print('-------')
print(df_filtered['$/SQUARE FEET'].isna().value_counts())
print('-------')
print(df_filtered['YEAR BUILT'].isna().value_counts())
print('-------')
# Out:
# PRICE
# False    841
# Name: count, dtype: int64
# -------
# $/SQUARE FEET
# False    834
# True       7
# Name: count, dtype: int64
# -------
# YEAR BUILT
# False    841
# Name: count, dtype: int64
# -------

# %%
df_filtered.loc[df_filtered['PRICE'] == '0']
# Out:
# Empty DataFrame
# Columns: [SALE TYPE, SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, STATUS, NEXT OPEN HOUSE START TIME, NEXT OPEN HOUSE END TIME, URL, SOURCE, MLS#, FAVORITE, INTERESTED, LATITUDE, LONGITUDE]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_filtered['PRICE'] = pd.to_numeric(df_filtered['PRICE'])
df_filtered['$/SQUARE FEET'] = pd.to_numeric(df_filtered['$/SQUARE FEET'])
df_filtered['YEAR BUILT'] = pd.to_numeric(df_filtered['YEAR BUILT'])
df_filtered['LATITUDE'] = pd.to_numeric(df_filtered['LATITUDE'])
df_filtered['LONGITUDE'] = pd.to_numeric(df_filtered['LONGITUDE'])

# %%
df_filtered.sort_values(by='PRICE',ascending=True).head(20)
# Out:
#      SALE TYPE     SOLD DATE PROPERTY TYPE
# 185  PAST SALE  July-25-2023   Condo/Co-op  \
# 422  PAST SALE   July-5-2023   Condo/Co-op
# 631  PAST SALE  July-18-2023   Condo/Co-op
# 667  PAST SALE  July-21-2023   Condo/Co-op
# 809  PAST SALE  July-26-2023   Condo/Co-op
# 8    PAST SALE  July-25-2023   Condo/Co-op
# 394  PAST SALE  July-25-2023   Condo/Co-op
# 786  PAST SALE  July-18-2023   Condo/Co-op
# 557  PAST SALE  July-28-2023   Condo/Co-op
# 473  PAST SALE  July-14-2023   Condo/Co-op
# 107  PAST SALE  July-14-2023   Condo/Co-op
# 329  PAST SALE  July-10-2023   Condo/Co-op
# 246  PAST SALE   July-6-2023   Condo/Co-op
# 456  PAST SALE  July-14-2023   Condo/Co-op
# 607  PAST SALE  July-17-2023   Condo/Co-op
# 53   PAST SALE  July-18-2023   Condo/Co-op
# 203  PAST SALE  July-17-2023   Condo/Co-op
# 220  PAST SALE  July-19-2023   Condo/Co-op
# 155  PAST SALE  July-13-2023   Condo/Co-op
# 448  PAST SALE   July-7-2023   Condo/Co-op
#
#                                  ADDRESS               CITY STATE OR PROVINCE
# 185      9917 W Okeechobee Rd Unit 4-305    Hialeah Gardens                FL  \
# 422            14951 Royal Oaks Ln #2306        North Miami                FL
# 631                    290 174th St #308  Sunny Isles Beach                FL
# 667                13480 NE 6th Ave #107        North Miami                FL
# 809                13480 NE 6th Ave #216        North Miami                FL
# 8                  13480 NE 6th Ave #303        North Miami                FL
# 394                13480 NE 6th Ave #304        North Miami                FL
# 786                 18700 NE 3rd Ct #620              Miami                FL
# 557                   55 NW 204th St #15      Miami Gardens                FL
# 473  1351 NE Miami Gardens Dr Unit 1122E              Miami                FL
# 107                 301 NW 177th St #212              Miami                FL
# 329           15205 NE 6th Ave Unit D103              Miami                FL
# 246                 1160 NE 191st St #24              Miami                FL
# 456          1770 NE 191st St Unit 116-1              Miami                FL
# 607            9760 SW 184th St Unit 13D         Cutler Bay                FL
# 53    1301 NE Miami Gardens Dr Unit 522W              Miami                FL
# 203              453 SW 2nd St Unit 406D              Miami                FL
# 220               19201 Collins Ave #424  Sunny Isles Beach                FL
# 155                1850 NE 169th St #311  North Miami Beach                FL
# 448              496 NW 165 St Unit D514              Miami                FL
#
#      ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS
# 185             33016.0     250.0   3.0    2.0  ...   Sold  \
# 422             33181.0     400.0   3.0    3.0  ...   Sold
# 631             33160.0   44500.0   2.0    2.0  ...   Sold
# 667             33161.0   67000.0   1.0    1.0  ...   Sold
# 809             33161.0   69885.0   2.0    2.0  ...   Sold
# 8               33161.0   70000.0   2.0    2.0  ...   Sold
# 394             33161.0   75000.0   2.0    2.0  ...   Sold
# 786             33179.0   90537.0   1.0    1.0  ...   Sold
# 557             33169.0   93000.0   1.0    1.0  ...   Sold
# 473             33179.0  135000.0   1.0    2.0  ...   Sold
# 107             33169.0  135000.0   1.0    1.0  ...   Sold
# 329             33162.0  135000.0   1.0    1.5  ...   Sold
# 246             33179.0  135000.0   1.0    1.5  ...   Sold
# 456             33179.0  138500.0   2.0    2.0  ...   Sold
# 607             33157.0  142000.0   2.0    1.0  ...   Sold
# 53              33179.0  145000.0   1.0    2.0  ...   Sold
# 203             33130.0  145000.0   2.0    1.0  ...   Sold
# 220             33160.0  145000.0   0.0    1.0  ...   Sold
# 155             33162.0  145000.0   1.0    1.5  ...   Sold
# 448             33169.0  149000.0   1.0    1.0  ...   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME
# 185                         NaN                       NaN  \
# 422                         NaN                       NaN
# 631                         NaN                       NaN
# 667                         NaN                       NaN
# 809                         NaN                       NaN
# 8                           NaN                       NaN
# 394                         NaN                       NaN
# 786                         NaN                       NaN
# 557                         NaN                       NaN
# 473                         NaN                       NaN
# 107                         NaN                       NaN
# 329                         NaN                       NaN
# 246                         NaN                       NaN
# 456                         NaN                       NaN
# 607                         NaN                       NaN
# 53                          NaN                       NaN
# 203                         NaN                       NaN
# 220                         NaN                       NaN
# 155                         NaN                       NaN
# 448                         NaN                       NaN
#
#                                                    URL       SOURCE
# 185  https://www.redfin.com/FL/Hialeah/9917-W-Okeec...       MARMLS  \
# 422  https://www.redfin.com/FL/North-Miami/14951-Ro...       MARMLS
# 631  https://www.redfin.com/FL/Sunny-Isles-Beach/29...       MARMLS
# 667  https://www.redfin.com/FL/North-Miami/13480-NE...       MARMLS
# 809  https://www.redfin.com/FL/North-Miami/13480-NE...       MARMLS
# 8    https://www.redfin.com/FL/North-Miami/13480-NE...       MARMLS
# 394  https://www.redfin.com/FL/North-Miami/13480-NE...       MARMLS
# 786  https://www.redfin.com/FL/Miami/18700-NE-3rd-C...       MARMLS
# 557  https://www.redfin.com/FL/Miami/55-NW-204th-St...  Beaches MLS
# 473  https://www.redfin.com/FL/North-Miami-Beach/13...       MARMLS
# 107  https://www.redfin.com/FL/Miami/301-NW-177th-S...  Beaches MLS
# 329  https://www.redfin.com/FL/Miami/15205-NE-6th-A...  Beaches MLS
# 246  https://www.redfin.com/FL/Miami/1160-NE-191st-...       MARMLS
# 456  https://www.redfin.com/FL/Miami/1770-NE-191st-...       MARMLS
# 607  https://www.redfin.com/FL/Cutler-Bay/9760-SW-1...       MARMLS
# 53   https://www.redfin.com/FL/Miami/1301-NE-Miami-...       MARMLS
# 203  https://www.redfin.com/FL/Miami/453-SW-2nd-St-...       MARMLS
# 220  https://www.redfin.com/FL/Sunny-Isles-Beach/19...       MARMLS
# 155  https://www.redfin.com/FL/North-Miami-Beach/18...  Beaches MLS
# 448  https://www.redfin.com/FL/Miami/496-NW-165th-S...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 185  A11379050         N          Y  25.866333 -80.334622
# 422  A11365864         N          Y  25.913867 -80.151668
# 631  A11332103         N          Y  25.936045 -80.130062
# 667  A11332382         N          Y  25.898940 -80.187168
# 809  A11267636         N          Y  25.898940 -80.187168
# 8    A11405950         N          Y  25.898940 -80.187168
# 394  A11376319         N          Y  25.898940 -80.187168
# 786  A11296791         N          Y  25.947261 -80.194442
# 557  F10376247         N          Y  25.963215 -80.203585
# 473  A11358458         N          Y  25.945855 -80.174575
# 107  F10380090         N          Y  25.937848 -80.207617
# 329  F10379909         N          Y  25.915314 -80.186602
# 246  A11392868         N          Y  25.950791 -80.178555
# 456  A11346202         N          Y  25.951003 -80.166485
# 607  A11363749         N          Y  25.598210 -80.349457
# 53   A11405324         N          Y  25.946501 -80.175895
# 203  A11405652         N          Y  25.772698 -80.202051
# 220  A11399973         N          Y  25.954318 -80.119900
# 155  F10382521         N          Y  25.931157 -80.163328
# 448  F10377377         N          Y  25.922968 -80.207469
#
# [20 rows x 27 columns]

# %%
print(df_filtered['URL'].iloc[667])
# Out:
# https://www.redfin.com/FL/North-Miami/13480-NE-6th-Ave-33161/unit-107/home/42871136

# %%
# Correct the prices, if needed
df_filtered.at[185,'PRICE']=(250000)
df_filtered.at[422,'PRICE']=(400000)
df_filtered.at[631,'PRICE']=(445000)

# %%
# Find problem psf by searching for a '0' value
df_filtered.loc[df_filtered['$/SQUARE FEET'] == '0'][['SOLD DATE','ADDRESS','CITY','$/SQUARE FEET','PRICE','SQUARE FEET']]
# Out:
# Empty DataFrame
# Columns: [SOLD DATE, ADDRESS, CITY, $/SQUARE FEET, PRICE, SQUARE FEET]
# Index: []

# %%
# # Corrections, if needed
df_filtered.at[185,'$/SQUARE FEET']=(250000/1190)
df_filtered.at[422,'$/SQUARE FEET']=(400000/1730)
df_filtered.at[631,'$/SQUARE FEET']=(445000/1240)

# %%
# Find problem psf by searching for low values
df_filtered.sort_values(by='$/SQUARE FEET',ascending=True).head(20)[['PRICE','ADDRESS','CITY','$/SQUARE FEET']]
# Out:
#         PRICE                              ADDRESS           CITY
# 394   75000.0                13480 NE 6th Ave #304    North Miami  \
# 809   69885.0                13480 NE 6th Ave #216    North Miami
# 8     70000.0                13480 NE 6th Ave #303    North Miami
# 667   67000.0                13480 NE 6th Ave #107    North Miami
# 456  138500.0          1770 NE 191st St Unit 116-1          Miami
# 786   90537.0                 18700 NE 3rd Ct #620          Miami
# 752  180000.0          1750 NE 191st St Unit 426-4          Miami
# 688  172000.0        484 NW 165th St Rd Unit A-212          Miami
# 181  174000.0              488 NW 165 Th Unit B409          Miami
# 369  260000.0                 900 NE 195th St #310          Miami
# 473  135000.0  1351 NE Miami Gardens Dr Unit 1122E          Miami
# 489  245000.0    18021 NE Biscayne Blvd Unit 901-2       Aventura
# 624  162500.0                1700 NE 191st St #408          Miami
# 672  185000.0         492 NW 165th St Rd Unit C409          Miami
# 213  229900.0         601 Ives Dairy Rd Unit 102-8          Miami
# 17   323250.0                   1099 W 40th St #25        Hialeah
# 557   93000.0                   55 NW 204th St #15  Miami Gardens
# 246  135000.0                 1160 NE 191st St #24          Miami
# 53   145000.0   1301 NE Miami Gardens Dr Unit 522W          Miami
# 152  165000.0                1400 NE 191st St #204          Miami
#
#      $/SQUARE FEET
# 394           82.0
# 809           82.0
# 8             82.0
# 667           92.0
# 456          105.0
# 786          107.0
# 752          137.0
# 688          146.0
# 181          148.0
# 369          155.0
# 473          157.0
# 489          157.0
# 624          157.0
# 672          157.0
# 213          161.0
# 17           161.0
# 557          161.0
# 246          163.0
# 53           168.0
# 152          173.0

# %%
print(df_filtered.URL.iloc[8])
# Out:
# https://www.redfin.com/FL/North-Miami/13480-NE-6th-Ave-33161/unit-303/home/42879152

# %%
# # Drop sales that aren't condos but labeled as such
# df_filtered = df_filtered.drop(1320)

# %% [markdown]
# ## Make Maps

# %%
### Create a price column formatted as currency ###
df_filtered['PRICE_AS_CURRENCY'] = df_filtered['PRICE'].apply(lambda x: "${:,.0f}".format(x))
### Set formatting for Beds, Baths ###
df_filtered['YEAR BUILT DISPLAY'] = df_filtered['YEAR BUILT'].apply(lambda x: '{:.0f}'.format(x))
df_filtered['PRICE_SQUARE_FEET_AS_CURRENCY'] = df_filtered['$/SQUARE FEET'].apply(lambda x: '${:,.0f}'.format(x))

# %%
df_filtered = df_filtered.sort_values(by=['PRICE'], ascending=False)
### Insert different colors for top 10 sales vs. the rest ###
df_filtered['COLOR'] = ''
### Create RANK column ###
df_filtered['RANK'] = 0
### Insert RANK values ###
df_filtered['RANK'] = range(1, len(df_filtered) + 1)
# use numpy to assign values to the 'COLOR' column
df_filtered['COLOR'] = np.where(df_filtered['RANK'] <= 10, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
### Define list of columns to drop from DF ###
columns_drop = ['SALE TYPE','PROPERTY TYPE','STATE OR PROVINCE','ZIP OR POSTAL CODE','HOA/MONTH','STATUS','NEXT OPEN HOUSE START TIME','NEXT OPEN HOUSE END TIME','SOURCE','MLS#','FAVORITE','INTERESTED','SQUARE FEET','LOT SIZE']

# %%
### Drop the columns ###
df_filtered = df_filtered.drop(columns=columns_drop)

# %%
def popup_html(row):
    Price = row['PRICE_AS_CURRENCY']
    Address = row['ADDRESS']
    City = row['CITY']
    sold_date = row['SOLD DATE']
    beds = row['BEDS']
    baths = row['BATHS']
    psf = row['PRICE_SQUARE_FEET_AS_CURRENCY']
    year_built = row['YEAR BUILT DISPLAY']
    rank = row['RANK']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Price: </strong>{}'''.format(Price) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>City: </strong>{}'''.format(City) + '''<br>
    <strong>Sold: </strong>{}'''.format(sold_date) + '''<br>
    <strong>Beds: </strong>{}'''.format(beds) + '''<br>
    <strong>Baths: </strong>{}'''.format(baths) + '''<br>
    <strong>Price per sf: </strong>{}'''.format(psf) + '''<br>
    <strong>Year Built: </strong>{}'''.format(year_built) + '''<br>
    <strong>Price Rank: </strong>{}'''.format(rank) + '''
    </html>
    '''
    return html

# %%
### Create map container ###
m = folium.Map(location=df_filtered[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=10,tiles=None)

### Create title ###
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f"July 2023 Condo Sales")

m.get_root().html.add_child(folium.Element(title_html))

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top 10 Sales')

for index, row in df_filtered.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_190cdaf29bb3e22bb1c46c38754f6a2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;July 2023 Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_190cdaf29bb3e22bb1c46c38754f6a2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_190cdaf29bb3e22bb1c46c38754f6a2d = L.map(
#                 &quot;map_190cdaf29bb3e22bb1c46c38754f6a2d&quot;,
#                 {
#                     center: [25.813704658501784, -80.20857613210462],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_c4cdbd4b1b47e6f016f84f3c6c39846a = L.featureGroup(
#                 {}
#             ).addTo(map_190cdaf29bb3e22bb1c46c38754f6a2d);
#
#
#             var marker_bd7937a7f5a58f7b3053960d157375ea = L.marker(
#                 [25.7617, -80.135686],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c4cdbd4b1b47e6f016f84f3c6c39846a);
#
#
#             var icon_1db8a7714e2e03e2403566cdddd881ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bd7937a7f5a58f7b3053960d157375ea.setIcon(icon_1db8a7714e2e03e2403566cdddd881ce);
#
#
#         var popup_519d8d7d21fef649aba5a879d038aa47 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_22bf96cf2446adda5850d8e082af6b8a = $(`&lt;div id=&quot;html_22bf96cf2446adda5850d8e082af6b8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Price: &lt;/strong&gt;$24,175,000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;7463 Fisher Island Dr #7463&lt;br&gt;     &lt;strong&gt;City: &lt;/strong&gt;Miami Beach&lt;br&gt;     &lt;strong&gt;Sold: &lt;/strong&gt;July-6-2023&lt;br&gt;     &lt;strong&gt;Beds: &lt;/strong&gt;6.0&lt;br&gt;     &lt;strong&gt;Baths: &lt;/strong&gt;7.0&lt;br&gt;     &lt;strong&gt;Price per sf: &lt;/strong&gt;$3,177&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2002&lt;br&gt;     &lt;strong&gt;Price Rank: &lt;/strong&gt;1     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_519d8d7d21fef649aba5a879d038aa47.setContent(html_22bf96cf2446adda5850d8e082af6b8a);
#
#
#
#         marker_bd7937a7f5a58f7b3053960d157375ea.bindPopup(popup_519d8d7d21fef649aba5a879d038aa47)
#         ;
#
#
#
#
#             var marker_844c2bd28a40bc342b2fd390ab20d59b = L.marker(
#                 [25.7287205, -80.2380801],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c4cdbd4b1b47e6f016f84f3c6c39846a);
#
#
#             var icon_15f1d18a1fa00131b8d2242ec81c9091 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_844c2bd28a40bc342b2fd390ab20d59b.setIcon(icon_15f1d18a1fa00131b8d2242ec81c9091);
#
#
#         var popup_e4686fa67431db1c6a6220494a04b7cb = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2d5c7fabcb7573f9c8c093d19e915eee = $(`&lt;div id=&quot;html_2d5c7fabcb7573f9c8c093d19e915eee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Price: &lt;/strong&gt;$17,500,000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;2821 S Bayshore Dr Unit UPH-A&lt;br&gt;     &lt;strong&gt;City: &lt;/strong&gt;Miami&lt;br&gt;     &lt;strong&gt;Sold: &lt;/strong&gt;July-13-2023&lt;br&gt;     &lt;strong&gt;Beds: &lt;/strong&gt;5.0&lt;br&gt;     &lt;strong&gt;Baths: &lt;/strong&gt;7.0&lt;br&gt;     &lt;strong&gt;Price per sf: &lt;/strong&gt;$2,526&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018&lt;br&gt;     &lt;strong&gt;Price Rank: &lt;/strong&gt;2     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_e4686fa67431db1c6a6220494a04b7cb.setContent(html_2d5c7fabcb7573f9c8c093d19e915eee);
#
#
#
#         marker_844c2bd28a40bc342b2fd390ab20d59b.bindPopup(popup_e4686fa67431db1c6a6220494a04b7cb)
#         ;
#
#
#
#
#             var marker_1e163fbc7a6c1bb182451b067e6e9721 = L.marker(
#                 [25.729886, -80.2368583],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c4cdbd4b1b47e6f016f84f3c6c39846a);
#
#
#             var icon_cc12b8e1f4a3d709b8999c83353e41a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e163fbc7a6c1bb182451b067e6e9721.setIcon(icon_cc12b8e1f4a3d709b8999c83353e41a2);
#
#
#         var popup_a8ace1d676628fd1efe31b4adfebccba = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_da1e8bd87

# %%
m.save('index.html')

# %% [markdown]
# ## Summary Info

# %%
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

Newest = '\033[1m' + 'Newest' + '\033[0m'
Oldest = '\033[1m' + 'Oldest' + '\033[0m'

# %%
df_filtered.columns
# Out:
# Index(['SOLD DATE', 'ADDRESS', 'CITY', 'PRICE', 'BEDS', 'BATHS', 'LOCATION',
#        'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'URL', 'LATITUDE',
#        'LONGITUDE', 'PRICE_AS_CURRENCY', 'YEAR BUILT DISPLAY',
#        'PRICE_SQUARE_FEET_AS_CURRENCY', 'COLOR', 'RANK'],
#       dtype='object')

# %%
df_filtered['FULL_ADDRESS'] = df_filtered['ADDRESS'] + ' ' + df_filtered['CITY']

# %%
print(df_filtered.loc[df_filtered['PRICE'].idxmin()]['URL'])
# Out:
# https://www.redfin.com/FL/North-Miami/13480-NE-6th-Ave-33161/unit-107/home/42871136

# %%
print(f"{ME}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{LE}{BR}{df_filtered.loc[df_filtered['PRICE'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['PRICE'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['PRICE'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['PRICE'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{MAX_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{MIN_PSF}{BR}{df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['$/SQUARE FEET'].idxmin()]['YEAR BUILT']:.0f}")

print(f"{Newest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmax()]['YEAR BUILT']:.0f}")
print(f"{Oldest}{BR}{df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['LOCATION']}, {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['FULL_ADDRESS']} | Price ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['PRICE']:,.0f} | ${df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['$/SQUARE FEET']:,.0f} psf | Year built: {df_filtered.loc[df_filtered['YEAR BUILT'].idxmin()]['YEAR BUILT']:.0f}")
# Out:
# Most Expensive
# 7400 OCEANSIDE AT FISHER, 7463 Fisher Island Dr #7463 Miami Beach | Price $24,175,000 | $3,177 psf | Year built: 2002
# Least Expensive
# ZURICH CONDO, 13480 NE 6th Ave #107 North Miami | Price $67,000 | $92 psf | Year built: 1974
# Highest Price Per Square Foot
# 7400 OCEANSIDE AT FISHER, 7463 Fisher Island Dr #7463 Miami Beach | Price $24,175,000 | $3,177 psf | Year built: 2002
# Lowest Price Per Square Foot
# ZURICH CONDO, 13480 NE 6th Ave #304 North Miami | Price $75,000 | $82 psf | Year built: 1974
# Newest
# MISSONI BAIA, 700 NE 26th Ter #804 Miami | Price $680,000 | $nan psf | Year built: 2023
# Oldest
# PALM GARDEN CONDO, 760 Meridian Ave #1 Miami Beach | Price $735,000 | $721 psf | Year built: 1923

# %% [markdown]
# ## Time on Market Calculator

# %%
# print(df_Current.loc[df_Current['YEAR BUILT'].idxmin()])

# %%
from datetime import datetime, timedelta

date1 = datetime(2023, 1, 24) ## List (Earlier) date
date2 = datetime(2023, 7, 21) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 178

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MD_condo_sales_month_ending_july_2023_copy

# %% [markdown]
# ## Get Summary Data

# %%
print('SALES INFO')
print(f'Number of sales: {len(df_filtered)}')
print('--------')
print(f'Total sale price: ${df_filtered["PRICE"].sum():,.0f}')
print('--------')
print(f'Median sale price: ${df_filtered["PRICE"].median():,.0f}')
print('--------')
print(f'Max sale price: ${df_filtered["PRICE"].max():,.0f}')
print('--------')
print(f'Min sale price: ${df_filtered["PRICE"].min():,.0f}')
print('------------------------------------------------')
print('PSF INFO')
print(f'Max price per square foot: ${df_filtered["$/SQUARE FEET"].max():,.0f}')
print('--------')
print(f'Min price per square foot: ${df_filtered["$/SQUARE FEET"].min():,.0f}')
print('--------')
print(f'Median price per square foot: ${df_filtered["$/SQUARE FEET"].median():,.0f}')
print('------------------------------------------------')
print('CONDO AGES')
print(f'Newest building: {df_filtered["YEAR BUILT"].max()}')
print('----------')
print(f'Oldest building: {df_filtered["YEAR BUILT"].min()}')
print('----------')
print(f'Average building age: {df_filtered["YEAR BUILT"].mean()}')
# Out:
# SALES INFO
# Number of sales: 841
# --------
# Total sale price: $592,948,877
# --------
# Median sale price: $415,000
# --------
# Max sale price: $24,175,000
# --------
# Min sale price: $67,000
# ------------------------------------------------
# PSF INFO
# Max price per square foot: $3,177
# --------
# Min price per square foot: $82
# --------
# Median price per square foot: $435
# ------------------------------------------------
# CONDO AGES
# Newest building: 2023.0
# ----------
# Oldest building: 1923.0
# ----------
# Average building age: 1988.6052318668253
