# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_Oct_2023.csv')

# %%
# Make sure to update this
first_month = 10
current_month = 'October'

# %%
len(df)
# Out:
# 583

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'])

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Data Stuff

# %%
# # Count number of earliest month dates
# sep_dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

# print(f'Number of September dates: {sep_dates_count}')

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
# create new column and assign colors based on month
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'red' if x.month == first_month else 'red' if x.month == second_month else 'blue' if x.month == third_month else '')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_85427/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 356

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{current_month}')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_red = folium.FeatureGroup(name=f'{current_month}') ## 

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'red':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    else:
        continue

# Add the FeatureGroups to the map
fg_red.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dd991922d9e9192c0aeb255ab800079 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;October&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dd991922d9e9192c0aeb255ab800079&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0dd991922d9e9192c0aeb255ab800079 = L.map(
#                 &quot;map_0dd991922d9e9192c0aeb255ab800079&quot;,
#                 {
#                     center: [41.802294774760384, -87.73805836964856],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_00c92b39fccf2b82ec1b9f3b0858229e = L.featureGroup(
#                 {}
#             ).addTo(map_0dd991922d9e9192c0aeb255ab800079);
#
#
#             var circle_marker_d1e34d36ca463ceca00b4cb7a49b0f0a = L.circleMarker(
#                 [41.5037996, -87.6934923],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00c92b39fccf2b82ec1b9f3b0858229e);
#
#
#         var popup_b574fc44e5ddcf3d09529c6ce4cfab5c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_565bbce7624dddcec3d793d3dd8dc978 = $(`&lt;div id=&quot;html_565bbce7624dddcec3d793d3dd8dc978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;NEWREZ LLC&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;ASHFORD-THOMPSON SHERRY&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;31-24-325-005-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;414 HAMLIN ST, PARK FOREST&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$142,373.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_b574fc44e5ddcf3d09529c6ce4cfab5c.setContent(html_565bbce7624dddcec3d793d3dd8dc978);
#
#
#
#         circle_marker_d1e34d36ca463ceca00b4cb7a49b0f0a.bindPopup(popup_b574fc44e5ddcf3d09529c6ce4cfab5c)
#         ;
#
#
#
#
#             var circle_marker_3fb3bf685c2b2890a67e58a8c0c54470 = L.circleMarker(
#                 [41.83949490000001, -87.8572556],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00c92b39fccf2b82ec1b9f3b0858229e);
#
#
#         var popup_160144a4d14eb55c40d5388d00608290 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9974c2a827e7583b0c53ad31edec6eff = $(`&lt;div id=&quot;html_9974c2a827e7583b0c53ad31edec6eff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;ROCKET MTG LLC&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;LARSH ERIN&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;15-27-311-017-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;1430 HARRISON AVE, LA GRANGE PARK&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$136,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_160144a4d14eb55c40d5388d00608290.setContent(html_9974c2a827e7583b0c53ad31edec6eff);
#
#
#
#         circle_marker_3fb3bf685c2b2890a67e58a8c0c54470.bindPopup(popup_160144a4d14eb55c40d5388d00608290)
#         ;
#
#
#
#
#             var circle_marker_2dcd3a84b5340b30b074fa35932918d7 = L.circleMarker(
#                 [41.6703292, -87.6434259],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00c92b39fccf2b82ec1b9f3b0858229e);
#
#
#         var popup_e99dbcafd87d35bfff889d6871b5be32 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_cd6bc873fb9e24cbeda5eb9d47d53bf3 = $(`&lt;div id=&quot;html_cd6bc873fb9e24cbeda5eb9d47d53bf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;BPL MTG TRUST LLC&lt;br&gt;     &lt;

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_october_2023

# %% [markdown]
# ## Stats for story

# %%
df['mortgage_amount_int'] = df['mortgage_amount'].str.replace('$','')
df['mortgage_amount_int'] = df['mortgage_amount_int'].str.replace(',','')
df = df.loc[df['mortgage_amount_int'] != 'NA']
df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)

# %%
# Count number of first month dates
dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

print(f'Number of {current_month} dates: {dates_count}')
# Out:
# Number of October dates: 284

# %%
x = df.loc[df['Doc Recorded'].dt.month == first_month]

# %%
x.reset_index(inplace=True, drop=True)

# %%
# september.at[205,'mortgage_amount_int']=96900
# september.at[205,'mortgage_amount']='$96,900'

# %%
x.sort_values(by='mortgage_amount_int',ascending=False).head(1)
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type
# 195     View  2327846192   2023-10-05    10/4/2023  LIS PENDENS FORECLOSURE  \
#
#      Consi. Amt.       1st Grantor            1st Grantee   Assoc. Doc#
# 195          NaN  SOCIETE GENERALE  161 N CLARK OWNER LLC  1.830545e+09  \
#
#                                              deed_urls  PIN Address COLOR
# 195  https://crs.cookcountyclerkil.gov/Document/Det...  NaN     NaN   red  \
#
#                                          mortgage_urls  mortgage_amount
# 195  https://crs.cookcountyclerkil.gov/Document/Det...  $230,000,000.00  \
#
#     geo_address geocoded  lat  lon  mortgage_amount_int
# 195         NaN     None  NaN  NaN            230000000

# %%
# print(x['mortgage_urls'].iloc[16])

# %%
print(f'{current_month}: ${x.mortgage_amount_int.sum():,}')
# Out:
# October: $323,368,767

# %%
# October
29 + 9
# Out:
# 38

# %%
x['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# NEWREZ LLC                               29
# US BK TRUST NATL ASSN TR                 17
# WILMINGTON SAV FUND SOC FSB TR           12
# LOANDEPOTCOM LLC                         10
# ROCKET MTG LLC                            9
# WELLS FARGO BK NA                         8
# CARRINGTON MTG SERVICES LLC               8
# HUNTINGTON NATL BK                        7
# US BK NATL ASSN TR                        6
# F ST INVESTMENTS LLC                      5
# BMO BK NA                                 5
# US BANK TRUST NATIONAL ASSN TR            5
# FEDERAL HOME LOAN MTG CORP TR             5
# MORTGAGE ASSETS MGMT LLC                  4
# WILMINGTON SAV FUND SOCIETY FSB TR        4
# DATA MTG INC                              4
# METROPOLITAN LIFE INST CO                 4
# HUNTINGTON NATL BANK                      4
# JPMORGAN CHASE BK NATL ASSN               4
# FORETHOUGHT LIFE INST CO                  3
# OLD NATL BK                               3
# CITIBANK NA TR                            3
# BANK OF NEW YORK MELLON TR                3
# TOORAK CAP PARTNERS LLC                   2
# AMOS FIN LLC                              2
# WILMINGTON TRUST NATIONAL ASSN TR         2
# FLAGSTAR BK NA                            2
# BANKUNITED NA                             2
# ARVEST BK                                 2
# WELLS FARGO BK NATL ASSN TR               2
# ARCPE 1 LLC                               2
# BRIGHTHOUSE LIFE INST CO                  2
# NATIONSTAR MTG LLC                        2
# DEUTSCHE BK NATIONAL TRUST COMPANY TR     2
# DEUTSCHE BK NATL TRUST CO TR              2
# HSBC BK USA NA TR                         2
# HSBC BK USA NATL ASSN TR                  2
# US BK TRUST NATL ASSN                     2
# PNC BK NATL ASSN                          2
# WINTRUST MTG                              2
# MCLP ASSET CO INC                         2
# PHH MTG CORP                              2
# OTTINO CHRIS                              1
# FEDERAL HOME LOAN MTG CORP                1
# NORTHPOINTE BK                            1
# SOCIETE GENERALE                          1
# WILMINGTON TRUST NA TR                    1
# 21ST MTG CORP                             1
# CITIBANK NA                               1
# COMMUNITY LOAN SERVICING LLC              1
# SIGNATURE FED CU                          1
# BMO HARRIS BK NA                          1
# JRT CO LLC                                1
# CNRFS LLC                                 1
# HARVEST SMALL BUS FIN LLC                 1
# MORTGAGE RESEARCH CTR LLC                 1
# FINANCE AMER COMM LLC                     1
# HINSDALE BK AND TRUST NA                  1
# MORTGAGE ASSES MGMT LLC                   1
# DISCOVER BK                               1
# Name: count, dtype: int64

# %%
x['1st Grantee'].value_counts()
# Out:
# 1st Grantee
# CLEARPOINT PROP 3 LLC             2
# CHICAGO TITLE LAND TRUST CO TR    2
# SA ALLIANCE INC                   2
# KING CASSANDRA B                  2
# CIBROOK LTD                       2
#                                  ..
# KOSTENKO-BROWNE SABRINA           1
# HARRIS MARY VALENTINE             1
# MOTYKOWSKI JEAN S                 1
# DESIGNED BY DAVIS LLC             1
# CLEARPOINT PROP II LLC            1
# Name: count, Length: 278, dtype: int64

# %%
df.to_csv(f'{current_month}_2023_foreclosures.csv')

# %%
# apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
print(f"{current_month} median mortgage foreclosure amount: ${x['mortgage_amount_int'].median():,}")
# Out:
# October median mortgage foreclosure amount: $179,910.5

# %% [markdown]
# ## Boundary Analysis

# %%
boundaries = gpd.read_file('Boundaries - Neighborhoods.geojson')

# %%
# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(x['lon'], x['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_x = gpd.GeoDataFrame(x, geometry=geometry)

gdf_filings_x.crs = 'EPSG:4326'
gdf_filings_x = gdf_filings_x.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_x = gpd.sjoin(gdf_filings_x, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# %%
counts_x['count'].sum()
# Out:
# 107
