# %%
import pandas as pd
import json
import os
import re

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 1600)

# %%
with open('jo1.json','r') as openfile:
    jo1 = json.load(openfile)
    
with open('jo2.json','r') as openfile:
    jo2 = json.load(openfile)
    
with open('jo3.json','r') as openfile:
    jo3 = json.load(openfile)
    
with open('mo1.json','r') as openfile:
    mo1 = json.load(openfile)
    
with open('mo2.json','r') as openfile:
    mo2 = json.load(openfile)
    
with open('mo3.json','r') as openfile:
    mo3 = json.load(openfile)

# %%
df_jo1 = pd.json_normalize(jo1, record_path=['results'])
df_jo2 = pd.json_normalize(jo2, record_path=['results'])
df_jo3 = pd.json_normalize(jo3, record_path=['results'])

df_mo1 = pd.json_normalize(mo1, record_path=['results'])
df_mo2 = pd.json_normalize(mo2, record_path=['results'])
df_mo3 = pd.json_normalize(mo3, record_path=['results'])

# %%
mo1
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcYSjRiKVD1WCpwylU8gB-rwtqWV-qECMAmhkB9Aa7cSeQ4CylkqGkXZlJomFGI8PWTLR8EthWumrkmvoy89ukv7FKCYgrQTS6IkT9_gqkx0oDYanMC92q75vzyTJc0ee4axW5wrdHPvrP3uPqa5gD4epn3iUwg_AADTdO_hwGfhRia5OCyXE7CuUzgKw0gXPdiYsXHuNrYtoVaXvfMA_hpFSJYgPdSN5wJhBs3npbS9jdxGvw3vyYeAG-wZVJmL-MNWLFmSnpM-IvQ6Eedjb5J-2tPaDz_Mn7aFdr-p16Lej01NovSd1E8K0sOFvfTDO_w_Y3AYdmrhS4sgP-4yaT0Dasga0u6b5KEgJGN2QmAyhEntMfxGqVIldXhUey75gq9hk2XieZpWVwPp9klzEvtdBdyeDA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '2112 N Ashland Ave, Chicago, IL 60614, United States',
#    'geometry': {'location': {'lat': 41.9209232, 'lng': -87.6690914},
#     'viewport': {'northeast': {'lat': 41.92225667989273,
#       'lng': -87.66769962010729},
#      'southwest': {'lat': 41.91955702010728, 'lng': -87.67039927989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114375365861939110473">Josue Villarreal</a>'],
#      'photo_reference': 'AcYSjRg5CLHfnhpWM6_88XyasCl-4ecjQ4llYoMMhJnz3mnnzr__1TESMdj3wuio3WoNhjFERHHO5qAgzDAgokBdEu3z_Pz6duCXUHbtXaw4ih6G5C6w8vka5dtETNlF8x7IqQZshEovs6KUbjHnLM9fKsLD_Se3Gx1pEl4hD3xzcp8P8A5h',
#      'width': 5312}],
#    'place_id': 'ChIJYX-nu-jSD4gR0LYi-YU1le4',
#    'plus_code': {'compound_code': 'W8CJ+99 Chicago, Illinois',
#     'global_code': '86HJW8CJ+99'},
#    'rating': 4.2,
#    'reference': 'ChIJYX-nu-jSD4gR0LYi-YU1le4',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1004},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '333 E Benton Pl, Chicago, IL 60601, United States',
#    'geometry': {'location': {'lat': 41.8852691, 'lng': -87.6184837},
#     'viewport': {'northeast': {'lat': 41.88673092989272,
#       'lng': -87.61734497010727},
#      'southwest': {'lat': 41.88403127010728, 'lng': -87.62004462989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1393,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107776902774223037801">Neury Freitas</a>'],
#      'photo_reference': 'AcYSjRig38urpsGJRsOEk-t4rNENihcy9AVF0BXJ3pTcd_JxshKB-vHR4z_iUsjyHiW3dw9ignEdbOgeXc0qkUUJY5lhpWcXnJmPRR0Q0wNEQPYfS6OsjCpvVwSoM8ie8WZJl0wNsZGCWSmHXJfaOpJrqK3qkOJVXe0kyGg2EJpN9TaOcwtp',
#      'width': 2048}],
#    'place_id': 'ChIJo9X181crDogRaEqrf4G9v7I',
#    'plus_code': {'compound_code': 'V9PJ+4J Chicago, Illinois',
#     'global_code': '86HJV9PJ+4J'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJo9X181crDogRaEqrf4G9v7I',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 562},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1615 S Clark St, Chicago, IL 60616, United States',
#    'geometry': {'location': {'lat': 41.8593299, 'lng': -87.62962189999999},
#     'viewport': {'northeast': {'lat': 41.86085992989272,
#       'lng': -87.62805652010726},
#      'southwest': {'lat': 41.85816027010728, 'lng': -87.63075617989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115364171718794331056">Kenan Qin</a>'],
#      'photo_reference': 'AcYSjRi-Yphz1LPTIFUkBkIk4E4y7iKNz5EHeYPrV45HjMS7fqby6p4ZD84tcpcOO-Qbev_Ea9pIlUFjykncLUCb8rl8Syf6jHipvazvJsmbxok0pN1kl5r9A2yVtbukhiI9gdKj-BTFioV-m2A9wI5oysG37ymbTnPsBsaNEsVwnBbTNy9Z',
#      'width': 3264}],
#    'place_id': 'ChIJNaEnx4gsDogRSvMJjPSuO10',
#    'plus_code': {'compound_code': 'V95C+P5 Chicago, Illinois',
#     'global_code': '86HJV95C+P5'},
#    'rating': 4.3,
#    'reference': 'ChIJNaEnx4gsDogRSvMJjPSuO10',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1216},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2021 W Chicago Ave, Chicago, IL 60622, United States',
#    'geometry': {'location': {'lat': 41.895527, 'lng': -87.6784275},
#     'viewport': {'northeast': {'lat': 41.89705642989272,
#       'lng': -87.67703117010727},
#      'southwest': {'lat': 41.89435677010728, 'lng': -87.6797308298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110726792029025262012">Edward Cabral</a>'],
#      'photo_reference': 'AcYSjRgoM1CvdPAxY_9tDQf1hQLL86sVDQ-rtJwsoRa7bHYICydzT0-fMGZmbiPG8zh4wvvPOTaq3qiJKULb18iD4n7Con3CRF-p-SRhVDbLJxr-ueOvV8qJ08H0kCipw6Ku_CLLihQUqP5asBaYGTN9LSRYsCKtJVgqf4V2I4-Cg8YBEBnM',
#      'width': 5312}],
#    'place_id': 'ChIJYzCVr0otDogRvZsJTDwqXUI',
#    'plus_code': {'compound_code': 'V8WC+6J Chicago, Illinois',
#     'global_code': '86HJV8WC+6J'},
#    'rating': 3.9,
#    'reference': 'ChIJYzCVr0otDogRvZsJTDwqXUI',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1042},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3030 N Broadway Suite 100, Chicago, IL 60657, United States',
#    'geometry': {'location': {'lat': 41.9373349, 'lng': -87.6447764},
#     'viewport': {'northeast': {'lat': 41.93856162989271,
#       'lng': -87.6431917201073},
#      'southwest': {'lat': 41.93586197010727, 'lng': -87.64589137989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106274751186627026766">Javairia Shahid</a>'],
#      'photo_reference': 'AcYSjRgCaCSsFwO6P87aSnL_6o5lZ2XE2VShIn7VTxO21ZiRpxet4mt7oiJgMCiz_zENk4Dvi4zJ6za3-3PnlVySgTYGf7B8UD6yQ1zbhQu7CNtjhBEf24zQumroBfefvXrH90onmBfIaaHXgFubqWUTvHpdkJ20bsjz9qrlOKB0c8h9EtJl',
#      'width': 4032}],
#    'place_id': 'ChIJJx-TGKfTD4gRzlQFzvvCJ4s',
#    'plus_code': {'compound_code': 'W9P4+W3 Chicago, Illinois',
#     'global_code': '86HJW9P4+W3'},
#    'rating': 4.2,
#    'reference': 'ChIJJx-TGKfTD4gRzlQFzvvCJ4s',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1082},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '40 S Halsted St, Chicago, IL 60661, United States',
#    'geometry': {'location': {'lat': 41.8808742, 'lng': -87.64795389999999},
#     'viewport': {'northeast': {'lat': 41.88203082989271,
#       'lng': -87.64657717010728},
#      'southwest': {'lat': 41.87933117010727, 'lng': -87.64927682989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108899100436075675103">Abhilash</a>'],
#      'photo_reference': 'AcYSjRhVuzVb_rOvzunXzAjJWiaRPzj50XBqQmNJxmUkP7jpU2FNHbkHgrP1CFyXq6aGdFj9M7ZZAKdRwbmeLeVbZtPMPXTTs5rOv1-VTLsqEXzyJaJi-PFrddRYnzx80clbm9VzbLr5G1Thlj3n-NhaAlEgCoeZsSOZS6ZhDw-u9iWaPuo',
#      'width': 4032}],
#    'place_id': 'ChIJf56prsQsDogR1ZIKNBWokaA',
#    'plus_code': {'compound_code': 'V9J2+8R Chicago, Illinois',
#     'global_code': '86HJV9J2+8R'},
#    'rating': 4.4,
#    'reference': 'ChIJf56prsQsDogR1ZIKNBWokaA',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1641},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3857 S Martin Luther King Dr, Chicago, IL 60653, United States',
#    'geometry': {'location': {'lat': 41.8245943, 'lng': -87.6160697},
#     'viewport': {'northeast': {'lat': 41.82599157989272,
#       'lng': -87.61461597010727},
#      'southwest': {'lat': 41.82329192010728, 'lng': -87.61731562989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117585333447566421183">Coyote Prophet</a>'],
#      'photo_reference': 'AcYSjRgTRQV-M9-T8rHMH-Rk3ghisGEddP9YpT1tzQWZtEJT5jVmVOM2IeLqmbzQZLAV4-3diiHlAz7kW0CYIOw37xTbtaanEQEEErnfXfqHzKCX9Gh1MdY0C7zWt_eX902oj6eJ1TmS_jXiWClmVYnJg3l8MY43Xg992HGQOksmbLtZ5Xaf',
#      'width': 5312}],
#    'place_id': 'ChIJr16JMPgrDogRJn8yKYSvTjk',
#    'plus_code': {'compound_code': 'R9FM+RH Chicago, Illinois',
#     'global_code': '86HJR9FM+RH'},
#    'rating': 4.3,
#    'reference': 'ChIJr16JMPgrDogRJn8yKYSvTjk',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1750},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3145 S Ashland Ave, Chicago, IL 60608, United States',
#    'geometry': {'location': {'lat': 41.835986, 'lng': -87.66361599999999},
#     'viewport': {'northeast': {'lat': 41.83725282989272,
#       'lng': -87.66252707010727},
#      'southwest': {'lat': 41.83455317010727, 'lng': -87.66522672989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118159815552209307110">Isaias Benitez</a>'],
#      'photo_reference': 'AcYSjRgZa9nWD6oEIdDuiemB6gfDkm9IWObppEgqBTlxZOVWrkMoPEQNk1ZnJrcmjwyhSAEyROzx5yhJ2WVQ6hbu3GBLeVnabpd_1cJ9GIVco4MuZsUG7Y60ktQ57UDHEThWF9spksAURdTY5V9DOu4Bpj7WyBe-FcKLjahXU09oXYsOFmD1',
#      'width': 2988}],
#    'place_id': 'ChIJN5MvEbYtDogRum48zi8OXAw',
#    'plus_code': {'compound_code': 'R8PP+9H Chicago, Illinois',
#     'global_code': '86HJR8PP+9H'},
#    'rating': 4,
#    'reference': 'ChIJN5MvEbYtDogRum48zi8OXAw',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 617},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1500 N Clybourn Ave C104, Chicago, IL 60610, United States',
#    'geometry': {'location': {'lat': 41.9081984, 'lng': -87.6464058},
#     'viewport': {'northeast': {'lat': 41.90950672989272,
#       'lng': -87.64472102010727},
#      'southwest': {'lat': 41.90680707010728, 'lng': -87.64742067989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103399552228700573890">Jeremiah Taylor</a>'],
#      'photo_reference': 'AcYSjRiyNUDVNZjjpdgpXGcUzfcZ9xcKVZu4hhD-Nt2jwRt1mKzOlUQmwU8HAlIX6iAR6c-vWK8XjIhFoFl1-rcnsXuaZDjIIbmEEzl3FllTHiL44FGJuUxXu8k82jGSxrNNFUtkhPFljbgpPQGE-HuKgh6gpbUvwEa8XMP-iMEPIO9qNUaf',
#      'width': 5312}],
#    'place_id': 'ChIJJSiZHjvTD4gRmKQNVa-jbaQ',
#    'plus_code': {'compound_code': 'W953+7C Chicago, Illinois',
#     'global_code': '86HJW953+7C'},
#    'rating': 4.2,
#    'reference': 'ChIJJSiZHjvTD4gRmKQNVa-jbaQ',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 525},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '5201 N Sheridan Rd, Chicago, IL 60640, United States',
#    'geometry': {'location': {'lat': 41.9766202, 'lng': -87.6548425},
#     'viewport': {'northeast': {'lat': 41.97792187989272,
#       'lng': -87.65357047010728},
#      'southwest': {'lat': 41.97522222010728, 'lng': -87.65627012989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102865816747116287647">Patrick K Crowley</a>'],
#      'photo_reference': 'AcYSjRj7bRxnX1WaV7OqdXr_dwwEFCUDz6FdMVOktZAnDqdqtZrOTUUH7UR4yda_fNogYiuQhA1I9MgATjli_jsAUYKVgO6k6ZJle0uLUu_9_B9bzNGjzA50MPAzqOBluM3GDYz8Xhro-NzXXRBIG-9YEQBbTfPs8HM7RPrXsfvITvmkkcK5',
#      'width': 4032}],
#    'place_id': 'ChIJ1dstXX7RD4gRb-JwAp76ycI',
#    'plus_code': {'compound_code': 'X8GW+J3 Chicago, Illinois',
#     'global_code': '86HJX8GW+J3'},
#    'rating': 4,
#    'reference': 'ChIJ1dstXX7RD4gRb-JwAp76ycI',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1357},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '5353 N Elston Ave, Chicago, IL 60630, United States',
#    'geometry': {'location': {'lat': 41.9794753, 'lng': -87.7574483},
#     'viewport': {'northeast': {'lat': 41.98059307989271,
#       'lng': -87.75598782010726},
#      'southwest': {'lat': 41.97789342010727, 'lng': -87.75868747989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3006,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112490881099361717450">Matt Davidson</a>'],
#      'photo_reference': 'AcYSjRg_TGatBe_yx8Ol8fon6X24XYJ51DATvqsyxPXk1YBbQvfG6yekaOACDZuvWwM3TZ8zbPamuEMuhwjw6h9bviOUprCxc8iKMVjkIbQdI_5T6FOWcBuODtnYsMuHIRYcqIn1m6ORPhzzOzS5NA_hQw-tneT0hjLAv2lrvVFNK7NEhpAA',
#      'width': 5344}],
#    'place_id': 'ChIJ7cA4LKDOD4gRNxU08K5OG0U',
#    'plus_code': {'compound_code': 'X6HV+Q2 Chicago, Illinois',
#     'global_code': '86HJX6HV+Q2'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJ7cA4LKDOD4gRNxU08K5OG0U',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 605},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3350 N Western Ave, Chicago, IL 60618, United States',
#    'geometry': {'location': {'lat': 41.9424388, 'lng': -87.6899609},
#     'viewport': {'northeast': {'lat': 41.94383627989271,
#       'lng': -87.68836632010728},
#      'southwest': {'lat': 41.94113662010727, 'lng': -87.69106597989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104679973507019790228">Markus Azadeh</a>'],
#      'photo_reference': 'AcYSjRgg19wl-MLaAigccGFiLMkN3NWsIhTw08CeLU5CRCisnW7aiXzosu-NdpkpTwyLUsLCN2SvNants2TL93xXcxfAhfSBeiqj6_R69MrB62APvIgZx1J_h45dItdb4WRwp8Pr2eEzOr06jDJCwaIQGDcPna_wFOfxA_0uriG9IgS28hNR',
#      'width': 4160}],
#    'place_id': 'ChIJcbLNdHvSD4gRgIJK0vnJNAU',
#    'plus_code': {'compound_code': 'W8R6+X2 Chicago, Illinois',
#     'global_code': '86HJW8R6+X2'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJcbLNdHvSD4gRgIJK0vnJNAU',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 515},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1800 W Lawrence Ave, Chicago, IL 60640, United States',
#    'geometry': {'location': {'lat': 41.9694105, 'lng': -87.6750103},
#     'viewport': {'northeast': {'lat': 41.97049627989272,
#       'lng': -87.67350727010728},
#      'southwest': {'lat': 41.96779662010728, 'lng': -87.67620692989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111734690371003028183">Michael Foley</a>'],
#      'photo_reference': 'AcYSjRhVQj4U8JsDS39rvRXTY08W2KYV3aeUm4zo680f0eI9iXn0Ppm5SpLYOETXEUmK9aZVg0JwJGevpv5BptsseniFsAt1tVFMdwxU8R3VwjgFUY54pQMpCMHaRE8V14htQl0drwFRZSp4gDKoEHQBC-N5CMzOQkyBqnFqeD3jyFigd_K-',
#      'width': 1920}],
#    'place_id': 'ChIJr5x_ziPSD4gR6ggfC-zA0uo',
#    'plus_code': {'compound_code': 'X89F+QX Chicago, Illinois',
#     'global_code': '86HJX89F+QX'},
#    'rating': 4.4,
#    'reference': 'ChIJr5x_ziPSD4gR6ggfC-zA0uo',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1450},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '11000 S Cicero Ave, Oak Lawn, IL 60453, United States',
#    'geometry': {'location': {'lat': 41.6931601, 'lng': -87.7416793},
#     'viewport': {'northeast': {'lat': 41.69430437989272,
#       'lng': -87.74036797010729},
#      'southwest': {'lat': 41.69160472010728, 'lng': -87.74306762989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115281986832845483114">Celena Davis</a>'],
#      'photo_reference': 'AcYSjRiF2zfMAHAZ8l68_2pVd1U7Bn2A2q7EYQXJlwcLa06SQY5zhI7pllZ3HDA6aKQsPPfWYDmNIIjfn3_kbwslQCpbsYW77wwNKL14OFC5dPDLdVc_pGNtrN9ENML-gis0NeBMcGcHxpSN5PdO-KzJHgNYZJOqOGKznJ3U1nA25xtX1NCW',
#      'width': 3096}],
#    'place_id': 'ChIJr0kyTKk7DogR0r8_3N0eLA8',
#    'plus_code': {'compound_code': 'M7V5+78 Oak Lawn, Illinois',
#     'global_code': '86HJM7V5+78'},
#    'rating': 4.3,
#    'reference': 'ChIJr0kyTKk7DogR0r8_3N0eLA8',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1348},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '3358 W Touhy Ave, Skokie, IL 60076, United States',
#    'geometry': {'location': {'lat': 42.0126071, 'lng': -87.71417749999999},
#     'viewport': {'northeast': {'lat': 42.01409917989272,
#       'lng': -87.71253847010728},
#      'southwest': {'lat': 42.01139952010728, 'lng': -87.71523812989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100929063969790156059">David Wolkowitz</a>'],
#      'photo_reference': 'AcYSjRhku5i0iYTHxbpoOqPyScVj3rXQm-f9biNoSv3rSlGsKxeiXa9GpZItPNbV6bwGrsG0Q3PW_BQabDtlmG9sR_kISYos3b0SODDBp8si5PqUKWM744uUp8XFdlzLoZdglEeDlj0Cbe8q1ojRzNAFWSSDYa6XAX6uVAJP8Lbvw28GyzwQ',
#      'width': 1920}],
#    'place_id': 'ChIJ1ZOOETTOD4gR_VDlKWiyFI0',
#    'plus_code': {'compound_code': '277P+28 Skokie, Illinois',
#     'global_code': '86JJ277P+28'},
#    'rating': 4.3,
#    'reference': 'ChIJ1ZOOETTOD4gR_VDlKWiyFI0',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1194},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '2559 W 95th St, Evergreen Park, IL 60805, United States',
#    'geometry': {'location': {'lat': 41.7194475, 'lng': -87.6879781},
#     'viewport': {'northeast': {'lat': 41.72099467989273,
#       'lng': -87.68656562010727},
#      'southwest': {'lat': 41.71829502010728, 'lng': -87.68926527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112315367629663927569">Marco Zarate</a>'],
#      'photo_reference': 'AcYSjRhs6_A6WeY9m_pOcWJ1EbDtZZ46dDZhhQrvfED520eb30_uauEhOYY12kBmD-XlMgi3qm5vh_fk4mGmi1Obk1IBXJ69Qx7SJ5qo7V-hQDJYobkiorTq_eMpvPEzSZTPvaHoC-w_CVRbGIdO58plAOvvGGet3vOSOK2taMtS5nZs9G0B',
#      'width': 3024}],
#    'place_id': 'ChIJa6U2K0YlDogR9lVQgZ2NH20',
#    'plus_code': {'compound_code': 'P896+QR Evergreen Park, Illinois',
#     'global_code': '86HJP896+QR'},
#    'rating': 4.3,
#    'reference': 'ChIJa6U2K0YlDogR9lVQgZ2NH20',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1232},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '7401 W Lawrence Ave, Harwood Heights, IL 60706, United States',
#    'geometry': {'location': {'lat': 41.9655408, 'lng': -87.8128243},
#     'viewport': {'northeast': {'lat': 41.96707677989273,
#       'lng': -87.81085075000001},
#      'southwest': {'lat': 41.96437712010728, 'lng': -87.81575015}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106047699285371260698">Stefan Bialas</a>'],
#      'photo_reference': 'AcYSjRgYgvVvsoX5ItWAIdyzE40YQxPY4GykJOQ5w6x9VAJaQaGyqJawOdPlpimJ0oHK3ZRe7RnVlR80RcLYDWGGZYUUSnVLP8xDEztyGBrbFNJdzpEP7pi2HKRUZ587JMUnGD0eMO8AxqBMqcd6tbZkd8PHTTtP_uHrYavMld1gkqGmdLOb',
#      'width': 4032}],
#    'place_id': 'ChIJJ95-4czLD4gR3UGODTzIwC4',
#    'plus_code': {'compound_code': 'X58P+6V Harwood Heights, Illinois',
#     'global_code': '86HJX58P+6V'},
#    'rating': 4.2,
#    'reference': 'ChIJJ95-4czLD4gR3UGODTzIwC4',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 909},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '333 E Benton Pl, Chicago, IL 60601, United States',
#    'geometry': {'location': {'lat': 41.8852691, 'lng': -87.6184837},
#     'viewport': {'northeast': {'lat': 41.88673212989272,
#       'lng': -87.61713547010727},
#      'southwest': {'lat': 41.88403247010728, 'lng': -87.6198351298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': "Mariano's Bakery",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJGzn_yB8rDogR17Kzh-GLePI',
#    'plus_code': {'compound_code': 'V9PJ+4J Chicago, Illinois',
#     'global_code': '86HJV9PJ+4J'},
#    'rating': 0,
#    'reference': 'ChIJGzn_yB8rDogR17Kzh-GLePI',
#    'types': ['bakery', 'store', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 0},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '1900 S Cumberland Ave, Park Ridge, IL 60068, United States',
#    'geometry': {'location': {'lat': 41.98735569999999, 'lng': -87.8379008},
#     'viewport': {'northeast': {'lat': 41.98874672989272,
#       'lng': -87.83632232010727},
#      'southwest': {'lat': 41.98604707010728, 'lng': -87.83902197989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115852890524653789627">Fernando Cadenas</a>'],
#      'photo_reference': 'AcYSjRj6lP67CJ6VGPnrCOQTDJQbdfBfZXh_Tq66CNyFZYQcjlsMAR34eY937ihCat5TMT0BwdttVvTRo7DPTkR0t9h-WP_MUTwQz9O8-q8m505YORyOQNlcioMpCH9TZH0YFNn6OcvbF3FfGDDAj1MW0zO55DqQWAF1uC9gH9SheufxDz6o',
#      'width': 1920}],
#    'place_id': 'ChIJox4p9fLJD4gRCkPj0z3SbGw',
#    'plus_code': {'compound_code': 'X5P6+WR Park Ridge, Illinois',
#     'global_code': '86HJX5P6+WR'},
#    'rating': 4.3,
#    'reference': 'ChIJox4p9fLJD4gRCkPj0z3SbGw',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1222},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '25 Waukegan Rd, Glenview, IL 60025, United States',
#    'geometry': {'location': {'lat': 42.0560727, 'lng': -87.7974505},
#     'viewport': {'northeast': {'lat': 42.05753402989272,
#       'lng': -87.79636237010727},
#      'southwest': {'lat': 42.05483437010728, 'lng': -87.79906202989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'name': "Mariano's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106439836208009555087">jj park</a>'],
#      'photo_reference': 'AcYSjRhE-CDXAj95BLJxy9h_dmouDRI-GYj0oYXe7j6mEON4zepSKpmu_AVxqjtgsHtUAg2d7h6wlNVKLoQ3Ytfpa2w0Q2brp4O1kllM1AlrAdDn26SP1jyYLxqK0on-E8oLmoTaF8X8eOrSaZfSmRNDIWUQPhxEb7ZK94x_cS8pf5_8MNwx',
#      'width': 4032}],
#    'place_id': 'ChIJJYvEQJ7ID4gRp2Q5Lnxs9GY',
#    'plus_code': {'compound_code': '3643+C2 Glenview, Illinois',
#     'global_code': '86JJ3643+C2'},
#    'rating': 4,
#    'reference': 'ChIJJYvEQJ7ID4gRp2Q5Lnxs9GY',
#    'types': ['grocery_or_supermarket',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 428}],
#  'status': 'OK'}

# %%
jo_frames = [df_jo1,df_jo2,df_jo3]
df_jo = pd.concat(jo_frames,axis=0)

# %%
mo_frames = [df_mo1,df_mo2,df_mo3]
df_mo = pd.concat(mo_frames,axis=0)

# %%
df_jo.columns
# Out:
# Index(['business_status', 'formatted_address', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'price_level',
#        'rating', 'reference', 'types', 'user_ratings_total',
#        'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code'],
#       dtype='object')

# %%
import folium
from folium.plugins import MarkerCluster

# %%
data = {'color':['lightblue','darkpurple'],
       'store':['Jewel-Osco','Mariano\'s']}
df_color_lg = pd.DataFrame(data)

# %%
df_jo['short_address'] = df_jo['formatted_address'].str.extract(r'(?P<short_address>[^,]*)')
df_mo['short_address'] = df_mo['formatted_address'].str.extract(r'(?P<short_address>[^,]*)')

# %%
m = folium.Map(location=df_jo[["geometry.location.lat", "geometry.location.lng"]].mean().to_list(), zoom_start=9,tiles=None)
title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Jewel-Osco & Mariano\'s')

for i,r in df_jo.iterrows():
    location = (r["geometry.location.lat"], r["geometry.location.lng"])
    info = (r["name"], r["short_address"])
    info = list(info)
    new_line = '<br>'
    bold_start = '<strong>'
    bold_end = '</strong>'
    text = f'Name: {bold_start}{info[0]}{bold_end}{new_line} \
    Address: {bold_start}{info[1]}{bold_end}'
    folium.Marker(location=location,icon=folium.Icon(color='lightblue'),
                      tooltip=text)\
    .add_to(m)
    folium.Circle(location=location,radius=4800).add_to(m)

m.get_root().html.add_child(folium.Element(title_html))

for i,r in df_mo.iterrows():
    location = (r["geometry.location.lat"], r["geometry.location.lng"])
    info = (r["name"], r["short_address"])
    info = list(info)
    new_line = '<br>'
    bold_start = '<strong>'
    bold_end = '</strong>'
    text = f'Name: {bold_start}{info[0]}{bold_end}{new_line} \
    Address: {bold_start}{info[1]}{bold_end}'
    folium.Marker(location=location,icon=folium.Icon(color='darkpurple'),
                      tooltip=text)\
    .add_to(m)

lgd_txt = '<span style="color: {col};">{txt}</span>'
    
for i, r in df_color_lg.iterrows():
    fg = folium.FeatureGroup(name=lgd_txt.format(txt=r['store'] + ' ' + '= ' + r['color'],col=r['color']))
    m.add_child(fg)
    
folium.TileLayer('Open Street Map',control=False).add_to(m)
    
folium.map.LayerControl('topleft', collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a4e2b29eb34a95f5785d408d9f1fa09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Jewel-Osco &amp; Mariano&#x27;s&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a4e2b29eb34a95f5785d408d9f1fa09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1a4e2b29eb34a95f5785d408d9f1fa09 = L.map(
#                 &quot;map_1a4e2b29eb34a95f5785d408d9f1fa09&quot;,
#                 {
#                     center: [41.88607636333334, -87.682972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var marker_c965e9690d67ae7aec837f3250b6a6b3 = L.marker(
#                 [41.866463, -87.6262491],
#                 {}
#             ).addTo(map_1a4e2b29eb34a95f5785d408d9f1fa09);
#
#
#             var icon_f6f65af25971558f613a1e2fbae7eff5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c965e9690d67ae7aec837f3250b6a6b3.setIcon(icon_f6f65af25971558f613a1e2fbae7eff5);
#
#
#             marker_c965e9690d67ae7aec837f3250b6a6b3.bindTooltip(
#                 `&lt;div&gt;
#                      Name: &lt;strong&gt;Jewel-Osco&lt;/strong&gt;&lt;br&gt;     Address: &lt;strong&gt;1224 S Wabash Ave&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_7055db5c9e91f25d0ec7aaed9978931a = L.circle(
#                 [41.866463, -87.6262491],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4800, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a4e2b29eb34a95f5785d408d9f1fa09);
#
#
#             var marker_58af04dde007ed9278ad77175d3443e3 = L.marker(
#                 [41.9272358, -87.674309],
#                 {}
#             ).addTo(map_1a4e2b29eb34a95f5785d408d9f1fa09);
#
#
#             var icon_0b849c6b9995bc8bde82c035af4c0e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_58af04dde007ed9278ad77175d3443e3.setIcon(icon_0b849c6b9995bc8bde82c035af4c0e22);
#
#
#             marker_58af04dde007ed9278ad77175d3443e3.bindTooltip(
#                 `&lt;div&gt;
#                      Name: &lt;strong&gt;Jewel-Osco&lt;/strong&gt;&lt;br&gt;     Address: &lt;strong&gt;2550 N Clybourn Ave&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_4bd7070f954c5d9f0fea00ec42038cda = L.circle(
#                 [41.9272358, -87.674309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4800, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a4e2b29eb34a95f5785d408d9f1fa09);
#
#
#             var marker_7b84ae6b8c1b49e467e2e3d3c5d45313 = L.marker(
#                 [41.9613017, -87.65344329999999],
#                 {}
#             ).addTo(map_1a4e2b29eb34a95f5785d408d9f1fa09);
#
#
#             var icon_967af886f19dcd5413e149d5cbd86851 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7b84ae6b8c1b49e467e2e3d3c5d45313.setIcon(icon_967af886f19dcd5413e149d5cbd86851);
#
#
#             marker_7b84ae6b8c1b49e467e2e3d3c5d45313.bindTooltip(
#                 `&lt;div&gt;
#                      Name: &lt;strong&gt;Jewel-Osco&lt;/strong&gt;&lt;br&gt;     Address: &lt;strong&gt;4355 N Sheridan Rd&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_e5fb0c1ab53f2628937c7fbba2788380 = L.circle(
#                 [41.9613017, -87.65344329999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/grocery_store_merger_analysis
