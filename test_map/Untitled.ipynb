# %% [markdown]
# ## Important Stuff
#
# Link to data: https://docs.google.com/spreadsheets/d/1vBdD5fDEb8e4J3cmIwoqyLTgelAbumhq2q19hsziX1I/edit?gid=0#gid=0

# %%
import pandas as pd
import googlemaps
import folium
import os

# %%
df = pd.read_csv('test_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Sellers                         20 non-null     object
#  1   Buyers                          20 non-null     object
#  2   Sale Price                      20 non-null     int64
#  3   BBL                             20 non-null     int64
#  4   Building BBL                    18 non-null     float64
#  5   Use Code Description            20 non-null     object
#  6   Property Sq. Ft                 10 non-null     float64
#  7   Recorded Date of Previous Sale  9 non-null      object
#  8   Doc Date of Previous Sale       9 non-null      object
#  9   Previous Owner Name             6 non-null      object
#  10  Previous Sale Price             9 non-null      float64
#  11  Physical Address                20 non-null     object
#  12  Municipality                    20 non-null     object
#  13  County                          20 non-null     object
#  14  Neighborhood                    20 non-null     object
#  15  Geo-Coordinates                 20 non-null     object
#  16  PropAppraiserURL                20 non-null     object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 2.8+ KB

# %%
df.head(1)
# Out:
#           Sellers            Buyers  Sale Price         BBL  Building BBL  \
# 0  FORTUNA, FIONA  MC CROSSIN, SEAN      280000  1013360010  1.013360e+09
#
#   Use Code Description  Property Sq. Ft Recorded Date of Previous Sale  \
# 0    Residential Co-op              NaN     2007-02-14 00:00:00.000000
#
#     Doc Date of Previous Sale Previous Owner Name  Previous Sale Price  \
# 0  2007-02-07 00:00:00.000000                 NaN             190000.0
#
#                               Physical Address   Municipality  \
# 0  321 EAST 43RD STREET Unit 511, NEW YORK, NY  New York City
#
#             County Neighborhood                         Geo-Coordinates  \
# 0  New York County   Turtle Bay  (-73.97049890662383,40.75023918271339)
#
#                                   PropAppraiserURL
# 0  https://zola.planning.nyc.gov/l/lot/1/133/60010

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# --- 1) Parse Geo-Coordinates into lon/lat ---
# Your Geo-Coordinates look like: "(-73.97...,40.75...)"
coords = (
    df["Geo-Coordinates"]
      .astype(str)
      .str.strip("()")
      .str.split(",", expand=True)
)

df["lon"] = pd.to_numeric(coords[0], errors="coerce")
df["lat"] = pd.to_numeric(coords[1], errors="coerce")

# Drop rows missing coords
df_map = df.dropna(subset=["lat", "lon"]).copy()

# --- 2) Choose a starting center (mean of points) ---
center_lat = df_map["lat"].mean()
center_lon = df_map["lon"].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles="CartoDB positron")

# --- 3) Add markers (clustered) with a nice popup ---
cluster = MarkerCluster(name="Sales").add_to(m)

for _, r in df_map.iterrows():
    sale_price = r.get("Sale Price")
    address = r.get("Physical Address", "")
    sellers = r.get("Sellers", "")
    buyers = r.get("Buyers", "")
    neighborhood = r.get("Neighborhood", "")
    url = r.get("PropAppraiserURL", "")

    # Popup HTML (keep it compact but useful)
    popup_html = f"""
    <div style="font-size: 13px; line-height: 1.25;">
      <b>{address}</b><br>
      <b>Sale:</b> ${sale_price:,.0f}<br>
      <b>Sellers:</b> {sellers}<br>
      <b>Buyers:</b> {buyers}<br>
      <b>Neighborhood:</b> {neighborhood}<br>
      <a href="{url}" target="_blank" rel="noopener noreferrer">Open Zola / Lot</a>
    </div>
    """

    folium.CircleMarker(
        location=[r["lat"], r["lon"]],
        radius=6,
        popup=folium.Popup(popup_html, max_width=350),
        tooltip=f"{address} — ${sale_price:,.0f}",
        fill=True
    ).add_to(cluster)

folium.LayerControl().add_to(m)

# --- 4) Save / display ---
m.save("index.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2da1e4a12b88cedc0016f37b2176b52c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2da1e4a12b88cedc0016f37b2176b52c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2da1e4a12b88cedc0016f37b2176b52c = L.map(
#                 &quot;map_2da1e4a12b88cedc0016f37b2176b52c&quot;,
#                 {
#                     center: [40.75106098340756, -73.95256676894229],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f327fb0025bd34e1ecf9bd86998388f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f327fb0025bd34e1ecf9bd86998388f.addTo(map_2da1e4a12b88cedc0016f37b2176b52c);
#
#
#             var marker_cluster_b9247f72152496d5382a975d1d6deba7 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_041bcc0d60a793a08f593ee062ace482 = L.circleMarker(
#                 [40.75023918271339, -73.97049890662383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b9247f72152496d5382a975d1d6deba7);
#
#
#         var popup_0b1829ee71392deae0365484c6085d16 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_df0df8c32a5a92302940b30bfdc807ec = $(`&lt;div id=&quot;html_df0df8c32a5a92302940b30bfdc807ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size: 13px; line-height: 1.25;&quot;&gt;       &lt;b&gt;321 EAST 43RD STREET Unit 511, NEW YORK, NY&lt;/b&gt;&lt;br&gt;       &lt;b&gt;Sale:&lt;/b&gt; $280,000&lt;br&gt;       &lt;b&gt;Sellers:&lt;/b&gt; FORTUNA, FIONA&lt;br&gt;       &lt;b&gt;Buyers:&lt;/b&gt; MC CROSSIN, SEAN&lt;br&gt;       &lt;b&gt;Neighborhood:&lt;/b&gt; Turtle Bay&lt;br&gt;       &lt;a href=&quot;https://zola.planning.nyc.gov/l/lot/1/133/60010&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;Open Zola / Lot&lt;/a&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_0b1829ee71392deae0365484c6085d16.setContent(html_df0df8c32a5a92302940b30bfdc807ec);
#
#
#
#         circle_marker_041bcc0d60a793a08f593ee062ace482.bindPopup(popup_0b1829ee71392deae0365484c6085d16)
#         ;
#
#
#
#
#             circle_marker_041bcc0d60a793a08f593ee062ace482.bindTooltip(
#                 `&lt;div&gt;
#                      321 EAST 43RD STREET Unit 511, NEW YORK, NY — $280,000
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ba17336b5b3f12758d6a05136f48167d = L.circleMarker(
#                 [40.756064985230346, -73.96259555482251],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_b9247f72152496d5382a975d1d6deba7);
#
#
#         var popup_bb0b9183100bf1caff5f2f91855456d7 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_1610f5bddf05a337619c63a31cdefac1 = $(`&lt;div id=&quot;html_1610f5bddf05a337619c63a31cdefac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-size: 13px; line
