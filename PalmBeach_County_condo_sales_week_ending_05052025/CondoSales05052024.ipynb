# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 27th May. 4th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 1  PAST SALE  April-30-2025   Condo/Co-op  6805 Willow Wood Dr #5032
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 1  Boca Raton                FL             33434.0  145000.0   2.0    2.0
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Boca-Raton/6805-Will...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11086845         N          Y  26.375139 -80.148992
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Palm Beach

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-30    76
# 2025-05-01    38
# 2025-04-29    31
# 2025-04-28    26
# 2025-05-02    23
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 170  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 190  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 103  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 150  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 18   PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 90   PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 61   PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 17   PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 160  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 12   PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 170       Boca Raton                FL             33432.0  4775000.0   3.0
# 190   Highland Beach                FL             33487.0  4605000.0   4.0
# 103          Jupiter                FL             33469.0  3500000.0   3.0
# 150  West Palm Beach                FL             33401.0  2600000.0   3.0
# 18           Jupiter                FL             33477.0  2150000.0   4.0
# 90        Palm Beach                FL             33480.0  1947582.0   2.0
# 61    Highland Beach                FL             33487.0  1837500.0   2.0
# 17   West Palm Beach                FL             33401.0  1837500.0   2.0
# 160       Boca Raton                FL             33432.0  1725000.0   2.0
# 12        Palm Beach                FL             33480.0  1725000.0   1.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 170    4.5  ...   Sold                         NaN                       NaN
# 190    3.0  ...   Sold                         NaN                       NaN
# 103    4.5  ...   Sold                         NaN                       NaN
# 150    2.0  ...   Sold                         NaN                       NaN
# 18     4.5  ...   Sold                         NaN                       NaN
# 90     2.0  ...   Sold                         NaN                       NaN
# 61     2.5  ...   Sold                         NaN                       NaN
# 17     2.0  ...   Sold                         NaN                       NaN
# 160    2.0  ...   Sold                         NaN                       NaN
# 12     1.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 170  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
# 190  https://www.redfin.com/FL/Highland-Beach/2727-...  Beaches MLS
# 103  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Beaches MLS
# 150  https://www.redfin.com/FL/West-Palm-Beach/400-...  Beaches MLS
# 18   https://www.redfin.com/FL/Jupiter/306-Villa-Dr...  Beaches MLS
# 90   https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 61   https://www.redfin.com/FL/Highland-Beach/3740-...  Beaches MLS
# 17   https://www.redfin.com/FL/West-Palm-Beach/1200...  Beaches MLS
# 160  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 12   https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 170  RX-11026048         N          Y  26.344230 -80.076892
# 190  RX-10948375         N          Y  26.424944 -80.063184
# 103  RX-11058005         N          Y  26.970013 -80.080861
# 150  RX-11040176         N          Y  26.716414 -80.050223
# 18   RX-11067037         N          Y  26.890340 -80.084839
# 90   RX-11058499         N          Y  26.715065 -80.042094
# 61   RX-11063700         N          Y  26.407547 -80.065582
# 17   RX-11062948         N          Y  26.702722 -80.049673
# 160  RX-11014007         N          Y  26.344456 -80.070723
# 12   RX-11071687         N          Y  26.715065 -80.042094
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 1  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 2  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 3  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 4  PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 5  PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 6  PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 7  PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 8  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 9  PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  4775000.0   3.0
# 1   Highland Beach                FL             33487.0  4605000.0   4.0
# 2          Jupiter                FL             33469.0  3500000.0   3.0
# 3  West Palm Beach                FL             33401.0  2600000.0   3.0
# 4          Jupiter                FL             33477.0  2150000.0   4.0
# 5       Palm Beach                FL             33480.0  1947582.0   2.0
# 6   Highland Beach                FL             33487.0  1837500.0   2.0
# 7  West Palm Beach                FL             33401.0  1837500.0   2.0
# 8       Boca Raton                FL             33432.0  1725000.0   2.0
# 9       Palm Beach                FL             33480.0  1725000.0   1.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    4.5  ... -80.076892  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...
# 1    3.0  ... -80.063184  https://www.redfin.com/FL/Highland-Beach/2727-...
# 2    4.5  ... -80.080861  https://www.redfin.com/FL/Jupiter/19950-Beach-...
# 3    2.0  ... -80.050223  https://www.redfin.com/FL/West-Palm-Beach/400-...
# 4    4.5  ... -80.084839  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...
# 5    2.0  ... -80.042094  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...
# 6    2.5  ... -80.065582  https://www.redfin.com/FL/Highland-Beach/3740-...
# 7    2.0  ... -80.049673  https://www.redfin.com/FL/West-Palm-Beach/1200...
# 8    2.0  ... -80.070723  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...
# 9    1.0  ... -80.042094  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...
#
#    list_agent_name_1              list_broker_name_1    list_agent_name_2  \
# 0      Sergio Uliana        United Realty Group, Inc                 None
# 1     Theresa Berman      William Raveis Real Estate  Laura Mae Gallagher
# 2  Carla Christenson  One Sotheby's International Re       Richard Powers
# 3     Samantha Curry                 Douglas Elliman                 None
# 4      Matthew Dugow           Compass Florida, LLC.         Chad Carroll
# 5  Sabra Kirkpatrick      Brown Harris Stevens of PB         Sarah Koenig
# 6         Nancy Ghen              Coldwell Banker/BR        Judith Randon
# 7        John Cregan    Sotheby's Intl. Realty, Inc.          Lisa Cregan
# 8        Ana Londono                  Lang Realty/BR                 None
# 9          Kim Raich    Sotheby's Intl. Realty, Inc.                 None
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None       Jason Morss
# 1      William Raveis Real Estate      Shari Orland
# 2  One Sotheby's International Re       Dianne West
# 3                            None    Burton Minkoff
# 4            Compass Florida, LLC    Greta Huizenga
# 5      Brown Harris Stevens of PB    Michael Gazlay
# 6            Judith Randon Realty     Raquel Martin
# 7    Sotheby's Intl. Realty, Inc.        Lucy Bauer
# 8                            None         Jeff Daly
# 9                            None       Brie Segota
#
#                 buy_broker_name_1  buy_agent_name_2  \
# 0             Tangent Realty Corp              None
# 1  Champagne & Parisi Real Estate              None
# 2  Waterfront Properties & Club C              None
# 3                 Douglas Elliman              None
# 4       Douglas Elliman (Jupiter)    Donna Hutchins
# 5           K2 Realty, Inc. (NPB)              None
# 6        United Realty Group, Inc              None
# 7      Brown Harris Stevens of PB       Mary Wulsin
# 8        Realty Home Advisors Inc              None
# 9     Coffee Cake And Real Estate              None
#
#             buy_broker_name_2
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4   Douglas Elliman (Jupiter)
# 5                        None
# 6                        None
# 7  Brown Harris Stevens of PB
# 8                        None
# 9                        None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 194

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $494,991

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $333

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $96,028,333

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          194              494991          333                     96028333.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 105
# -----------
# Input Previous Week Condo Average Sales Price:
# 500588
# -----------
# Input Previous Week Condo Average PSF:
# 331
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 52561775.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS        CITY  \
# 0  PAST SALE 2025-05-01   Condo/Co-op  500 SE 5th Ave Unit 402s  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  4775000.0   3.0    4.5
#
#              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Mizner Grand Condo       4168.0       NaN      1999.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1146.0     4965.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.34423 -80.076892
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...     Sergio Uliana
#
#          list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  United Realty Group, Inc              None               None
#
#   buy_agent_name_1    buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0      Jason Morss  Tangent Realty Corp             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 1  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 2  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 3  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 4  PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 5  PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 6  PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 7  PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 8  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 9  PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  4775000.0   3.0
# 1   Highland Beach                FL             33487.0  4605000.0   4.0
# 2          Jupiter                FL             33469.0  3500000.0   3.0
# 3  West Palm Beach                FL             33401.0  2600000.0   3.0
# 4          Jupiter                FL             33477.0  2150000.0   4.0
# 5       Palm Beach                FL             33480.0  1947582.0   2.0
# 6   Highland Beach                FL             33487.0  1837500.0   2.0
# 7  West Palm Beach                FL             33401.0  1837500.0   2.0
# 8       Boca Raton                FL             33432.0  1725000.0   2.0
# 9       Palm Beach                FL             33480.0  1725000.0   1.0
#
#    BATHS                       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5             Mizner Grand Condo       4168.0       NaN      1999.0
# 1    3.0                    Villa Magna       4100.0       NaN      1982.0
# 2    4.5  Claridge Jupiter Island Condo       3500.0       NaN      1994.0
# 3    2.0         Waterview Towers Condo       2109.0       NaN      1981.0
# 4    4.5        Bears Club Villas Condo       3195.0       NaN      2006.0
# 5    2.0        Palm Beach Towers Condo       1614.0       NaN      1956.0
# 6    2.5                  Toscana South       2601.0       NaN      2004.0
# 7    2.0                  Trianon Condo       1323.0       NaN      1972.0
# 8    2.0                Chalfonte Condo       1446.0       NaN      1974.0
# 9    1.0        Palm Beach Towers Condo        900.0       NaN      1956.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1146.0     4965.0   Sold
# 1             NaN         1123.0     4526.0   Sold
# 2             NaN         1000.0     6266.0   Sold
# 3             NaN         1233.0     2157.0   Sold
# 4             NaN          673.0     7097.0   Sold
# 5             NaN         1207.0     2222.0   Sold
# 6             NaN          706.0     2644.0   Sold
# 7             NaN         1389.0     1477.0   Sold
# 8             NaN         1193.0     1525.0   Sold
# 9             NaN         1917.0     1245.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...  Beaches MLS
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...  Beaches MLS
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.344230 -80.076892
# 1  RX-10948375        N          Y  26.424944 -80.063184
# 2  RX-11058005        N          Y  26.970013 -80.080861
# 3  RX-11040176        N          Y  26.716414 -80.050223
# 4  RX-11067037        N          Y  26.890340 -80.084839
# 5  RX-11058499        N          Y  26.715065 -80.042094
# 6  RX-11063700        N          Y  26.407547 -80.065582
# 7  RX-11062948        N          Y  26.702722 -80.049673
# 8  RX-11014007        N          Y  26.344456 -80.070723
# 9  RX-11071687        N          Y  26.715065 -80.042094
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...      Sergio Uliana
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...     Theresa Berman
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Carla Christenson
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...     Samantha Curry
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...      Matthew Dugow
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Sabra Kirkpatrick
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...         Nancy Ghen
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...        John Cregan
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...        Ana Londono
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Kim Raich
#
#                list_broker_name_1    list_agent_name_2  \
# 0        United Realty Group, Inc                 None
# 1      William Raveis Real Estate  Laura Mae Gallagher
# 2  One Sotheby's International Re       Richard Powers
# 3                 Douglas Elliman                 None
# 4           Compass Florida, LLC.         Chad Carroll
# 5      Brown Harris Stevens of PB         Sarah Koenig
# 6              Coldwell Banker/BR        Judith Randon
# 7    Sotheby's Intl. Realty, Inc.          Lisa Cregan
# 8                  Lang Realty/BR                 None
# 9    Sotheby's Intl. Realty, Inc.                 None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None      Jason Morss
# 1      William Raveis Real Estate     Shari Orland
# 2  One Sotheby's International Re      Dianne West
# 3                            None   Burton Minkoff
# 4            Compass Florida, LLC   Greta Huizenga
# 5      Brown Harris Stevens of PB   Michael Gazlay
# 6            Judith Randon Realty    Raquel Martin
# 7    Sotheby's Intl. Realty, Inc.       Lucy Bauer
# 8                            None        Jeff Daly
# 9                            None      Brie Segota
#
#                 buy_broker_name_1 buy_agent_name_2  \
# 0             Tangent Realty Corp             None
# 1  Champagne & Parisi Real Estate             None
# 2  Waterfront Properties & Club C             None
# 3                 Douglas Elliman             None
# 4       Douglas Elliman (Jupiter)   Donna Hutchins
# 5           K2 Realty, Inc. (NPB)             None
# 6        United Realty Group, Inc             None
# 7      Brown Harris Stevens of PB      Mary Wulsin
# 8        Realty Home Advisors Inc             None
# 9     Coffee Cake And Real Estate             None
#
#             buy_broker_name_2  RANK   COLOR
# 0                        None     1  orange
# 1                        None     2    blue
# 2                        None     3    blue
# 3                        None     4    blue
# 4   Douglas Elliman (Jupiter)     5    blue
# 5                        None     6    blue
# 6                        None     7    blue
# 7  Brown Harris Stevens of PB     8    blue
# 8                        None     9    blue
# 9                        None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d51ef60998eb2237b837e28950aa09a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 27th — May. 4th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d51ef60998eb2237b837e28950aa09a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d51ef60998eb2237b837e28950aa09a6 = L.map(
#                 &quot;map_d51ef60998eb2237b837e28950aa09a6&quot;,
#                 {
#                     center: [26.569225364432988, -80.10418119226803],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_2bff01765a6bb465ea4f812bf58366e7 = L.featureGroup(
#                 {}
#             ).addTo(map_d51ef60998eb2237b837e28950aa09a6);
#
#
#             var marker_d287f5966d38a556bcab8b039733756b = L.marker(
#                 [26.3442296, -80.0768924],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_2bff01765a6bb465ea4f812bf58366e7);
#
#
#             var icon_70d089cebe54e858ab238c0a28b605c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d287f5966d38a556bcab8b039733756b.setIcon(icon_70d089cebe54e858ab238c0a28b605c4);
#
#
#         var popup_98046f182bf7f664fac8c231def10ea7 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_90e502bb703dfc2a639c0763fd00905b = $(`&lt;div id=&quot;html_90e502bb703dfc2a639c0763fd00905b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;500 SE 5th Ave Unit 402s&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,775,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,146.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,168.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1999.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_98046f182bf7f664fac8c231def10ea7.setContent(html_90e502bb703dfc2a639c0763fd00905b);
#
#
#
#         marker_d287f5966d38a556bcab8b039733756b.bindPopup(popup_98046f182bf7f664fac8c231def10ea7)
#         ;
#
#
#
#
#             var feature_group_48b31ccbf0fe12b02377356976aa10d7 = L.featureGroup(
#                 {}
#             ).addTo(map_d51ef60998eb2237b837e28950aa09a6);
#
#
#             var marker_fa2878f6931e24ad0402a722301f340c = L.marker(
#                 [26.4249437, -80.0631839],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_48b31ccbf0fe12b02377356976aa10d7);
#
#
#             var icon_ec0964a94a78d611dbedcf99b2a1cebf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa2878f6931e24ad0402a722301f340c.setIcon(icon_ec0964a94a78d611dbedcf99b2a1cebf);
#
#
#         var popup_26f91638bb857a180a64743c77a84429 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_00e7b1017b8a8262ca33208803c4d3f2 = $(`&lt;div id=&quot;html_00e7b1017b8a8262ca33208803c4d3f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2727 S Ocean Blvd Unit 801 &amp; 805&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,605,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,123.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,100.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1982.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_26f91638bb857a180a64743c77a84429.setContent(html_00e7b1017b8a8262ca33208803c4d3f2);
#
#
#
#         marker_fa2878f6931e24ad0402a722301f340c.bindPopup(popup_26f91638bb857a180a64743c77a84429)
#         ;
#
#
#
#
#             var marker_49b8a7ee6e7fee08f086a1b9e61c2e0c = L.marker(
#                 [26.9700126, -80.080861],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_48b31ccbf0fe12b02377356976aa10d7);
#
#
#             var icon_4458c4f5cf3e9050f8b96d429620ff85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49b8a7ee6e7fee08f086a1b9e61c2e0c.setIcon(icon_4458c4f5cf3e9050f8b96d429620ff85);
#
#
#         var popup_50b6a942df0b4cfedbabb6bac3d4d01e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_8533bdb9bf1dfdde639

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS        CITY  \
# 0  PAST SALE 2025-05-01   Condo/Co-op  500 SE 5th Ave Unit 402s  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  4775000.0   3.0    4.5
#
#              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Mizner Grand Condo       4168.0       NaN      1999.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1146.0     4965.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.34423 -80.076892
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...     Sergio Uliana
#
#          list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  United Realty Group, Inc              None               None
#
#   buy_agent_name_1    buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0      Jason Morss  Tangent Realty Corp             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05052025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Mizner Grand Condo at 500 SE 5th Ave Unit 402s in Boca Raton'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 1  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 2  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 3  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 4  PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 5  PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 6  PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 7  PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 8  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 9  PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  4775000.0   3.0
# 1   Highland Beach                FL             33487.0  4605000.0   4.0
# 2          Jupiter                FL             33469.0  3500000.0   3.0
# 3  West Palm Beach                FL             33401.0  2600000.0   3.0
# 4          Jupiter                FL             33477.0  2150000.0   4.0
# 5       Palm Beach                FL             33480.0  1947582.0   2.0
# 6   Highland Beach                FL             33487.0  1837500.0   2.0
# 7  West Palm Beach                FL             33401.0  1837500.0   2.0
# 8       Boca Raton                FL             33432.0  1725000.0   2.0
# 9       Palm Beach                FL             33480.0  1725000.0   1.0
#
#    BATHS                       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5             Mizner Grand Condo       4168.0       NaN      1999.0
# 1    3.0                    Villa Magna       4100.0       NaN      1982.0
# 2    4.5  Claridge Jupiter Island Condo       3500.0       NaN      1994.0
# 3    2.0         Waterview Towers Condo       2109.0       NaN      1981.0
# 4    4.5        Bears Club Villas Condo       3195.0       NaN      2006.0
# 5    2.0        Palm Beach Towers Condo       1614.0       NaN      1956.0
# 6    2.5                  Toscana South       2601.0       NaN      2004.0
# 7    2.0                  Trianon Condo       1323.0       NaN      1972.0
# 8    2.0                Chalfonte Condo       1446.0       NaN      1974.0
# 9    1.0        Palm Beach Towers Condo        900.0       NaN      1956.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1146.0     4965.0   Sold
# 1             NaN         1123.0     4526.0   Sold
# 2             NaN         1000.0     6266.0   Sold
# 3             NaN         1233.0     2157.0   Sold
# 4             NaN          673.0     7097.0   Sold
# 5             NaN         1207.0     2222.0   Sold
# 6             NaN          706.0     2644.0   Sold
# 7             NaN         1389.0     1477.0   Sold
# 8             NaN         1193.0     1525.0   Sold
# 9             NaN         1917.0     1245.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...  Beaches MLS
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...  Beaches MLS
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.344230 -80.076892
# 1  RX-10948375        N          Y  26.424944 -80.063184
# 2  RX-11058005        N          Y  26.970013 -80.080861
# 3  RX-11040176        N          Y  26.716414 -80.050223
# 4  RX-11067037        N          Y  26.890340 -80.084839
# 5  RX-11058499        N          Y  26.715065 -80.042094
# 6  RX-11063700        N          Y  26.407547 -80.065582
# 7  RX-11062948        N          Y  26.702722 -80.049673
# 8  RX-11014007        N          Y  26.344456 -80.070723
# 9  RX-11071687        N          Y  26.715065 -80.042094
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...      Sergio Uliana
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...     Theresa Berman
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Carla Christenson
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...     Samantha Curry
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...      Matthew Dugow
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Sabra Kirkpatrick
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...         Nancy Ghen
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...        John Cregan
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...        Ana Londono
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Kim Raich
#
#                list_broker_name_1    list_agent_name_2  \
# 0        United Realty Group, Inc                 None
# 1      William Raveis Real Estate  Laura Mae Gallagher
# 2  One Sotheby's International Re       Richard Powers
# 3                 Douglas Elliman                 None
# 4           Compass Florida, LLC.         Chad Carroll
# 5      Brown Harris Stevens of PB         Sarah Koenig
# 6              Coldwell Banker/BR        Judith Randon
# 7    Sotheby's Intl. Realty, Inc.          Lisa Cregan
# 8                  Lang Realty/BR                 None
# 9    Sotheby's Intl. Realty, Inc.                 None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None      Jason Morss
# 1      William Raveis Real Estate     Shari Orland
# 2  One Sotheby's International Re      Dianne West
# 3                            None   Burton Minkoff
# 4            Compass Florida, LLC   Greta Huizenga
# 5      Brown Harris Stevens of PB   Michael Gazlay
# 6            Judith Randon Realty    Raquel Martin
# 7    Sotheby's Intl. Realty, Inc.       Lucy Bauer
# 8                            None        Jeff Daly
# 9                            None      Brie Segota
#
#                 buy_broker_name_1 buy_agent_name_2  \
# 0             Tangent Realty Corp             None
# 1  Champagne & Parisi Real Estate             None
# 2  Waterfront Properties & Club C             None
# 3                 Douglas Elliman             None
# 4       Douglas Elliman (Jupiter)   Donna Hutchins
# 5           K2 Realty, Inc. (NPB)             None
# 6        United Realty Group, Inc             None
# 7      Brown Harris Stevens of PB      Mary Wulsin
# 8        Realty Home Advisors Inc             None
# 9     Coffee Cake And Real Estate             None
#
#             buy_broker_name_2  RANK   COLOR  \
# 0                        None     1  orange
# 1                        None     2    blue
# 2                        None     3    blue
# 3                        None     4    blue
# 4   Douglas Elliman (Jupiter)     5    blue
# 5                        None     6    blue
# 6                        None     7    blue
# 7  Brown Harris Stevens of PB     8    blue
# 8                        None     9    blue
# 9                        None    10    blue
#
#                                            FULL_NAME
# 0  Mizner Grand Condo at 500 SE 5th Ave Unit 402s...
# 1  Villa Magna at 2727 S Ocean Blvd Unit 801 & 80...
# 2  Claridge Jupiter Island Condo at 19950 Beach 6...
# 3  Waterview Towers Condo at 400 N Flagler Dr #17...
# 4  Bears Club Villas Condo at 306 Villa Dr in Jup...
# 5  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6  Toscana South at 3740 S Ocean Blvd #1206 in Hi...
# 7  Trianon Condo at 1200 S Flagler Dr Ph 2 in Wes...
# 8  Chalfonte Condo at 550 S Ocean Blvd #1204 in B...
# 9  Palm Beach Towers Condo at 44 Cocoanut Row Uni...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Mizner Grand Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,725,000 to $4,775,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, West Palm Beach, Boca Raton, Palm Beach, Jupiter, Highland Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 194 condo sales totaling $96,028,333 million from Apr. 27th to May. 4th. The previous week, brokers closed 105 condo sales totaling $52,561,775.
#
# Last week’s units sold for an average of $494,991, lower than the $500,588 average price from the previous week. The average price per square foot rose to $333 from $331, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,725,000.0 million to $4,775,000.0 million.
#
# Mizner Grand Condo at 500 SE 5th Ave Unit 402s in Boca Raton took the top spot with a $4,775,000.0 million closing. The sale closed at $1,146.0 per square foot.
#
# Sergio Uliana with United Realty Group, Inc, and None with None had the listing.
# Jason Morss with Tangent Realty Corp, and None with None represented the buyer.
#
# Villa Magna at 2727 S Ocean Blvd Unit 801 & 805 in Highland Beach, closed for the second highest amount, $4,605,000.0, or $1,123.0 per square foot.
#
# Theresa Berman with William Raveis Real Estate, and Laura Mae Gallagher with William Raveis Real Estate had the listing.
# Shari Orland with Champagne & Parisi Real Estate, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05052025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 27th to May. 4th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 1  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 2  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 3  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 4  PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 5  PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 6  PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 7  PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 8  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 9  PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  4775000.0   3.0
# 1   Highland Beach                FL             33487.0  4605000.0   4.0
# 2          Jupiter                FL             33469.0  3500000.0   3.0
# 3  West Palm Beach                FL             33401.0  2600000.0   3.0
# 4          Jupiter                FL             33477.0  2150000.0   4.0
# 5       Palm Beach                FL             33480.0  1947582.0   2.0
# 6   Highland Beach                FL             33487.0  1837500.0   2.0
# 7  West Palm Beach                FL             33401.0  1837500.0   2.0
# 8       Boca Raton                FL             33432.0  1725000.0   2.0
# 9       Palm Beach                FL             33480.0  1725000.0   1.0
#
#    BATHS                       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5             Mizner Grand Condo       4168.0       NaN      1999.0
# 1    3.0                    Villa Magna       4100.0       NaN      1982.0
# 2    4.5  Claridge Jupiter Island Condo       3500.0       NaN      1994.0
# 3    2.0         Waterview Towers Condo       2109.0       NaN      1981.0
# 4    4.5        Bears Club Villas Condo       3195.0       NaN      2006.0
# 5    2.0        Palm Beach Towers Condo       1614.0       NaN      1956.0
# 6    2.5                  Toscana South       2601.0       NaN      2004.0
# 7    2.0                  Trianon Condo       1323.0       NaN      1972.0
# 8    2.0                Chalfonte Condo       1446.0       NaN      1974.0
# 9    1.0        Palm Beach Towers Condo        900.0       NaN      1956.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1146.0     4965.0   Sold
# 1             NaN         1123.0     4526.0   Sold
# 2             NaN         1000.0     6266.0   Sold
# 3             NaN         1233.0     2157.0   Sold
# 4             NaN          673.0     7097.0   Sold
# 5             NaN         1207.0     2222.0   Sold
# 6             NaN          706.0     2644.0   Sold
# 7             NaN         1389.0     1477.0   Sold
# 8             NaN         1193.0     1525.0   Sold
# 9             NaN         1917.0     1245.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...  Beaches MLS
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...  Beaches MLS
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.344230 -80.076892
# 1  RX-10948375        N          Y  26.424944 -80.063184
# 2  RX-11058005        N          Y  26.970013 -80.080861
# 3  RX-11040176        N          Y  26.716414 -80.050223
# 4  RX-11067037        N          Y  26.890340 -80.084839
# 5  RX-11058499        N          Y  26.715065 -80.042094
# 6  RX-11063700        N          Y  26.407547 -80.065582
# 7  RX-11062948        N          Y  26.702722 -80.049673
# 8  RX-11014007        N          Y  26.344456 -80.070723
# 9  RX-11071687        N          Y  26.715065 -80.042094
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...      Sergio Uliana
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...     Theresa Berman
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Carla Christenson
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...     Samantha Curry
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...      Matthew Dugow
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Sabra Kirkpatrick
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...         Nancy Ghen
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...        John Cregan
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...        Ana Londono
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Kim Raich
#
#                list_broker_name_1    list_agent_name_2  \
# 0        United Realty Group, Inc                 None
# 1      William Raveis Real Estate  Laura Mae Gallagher
# 2  One Sotheby's International Re       Richard Powers
# 3                 Douglas Elliman                 None
# 4           Compass Florida, LLC.         Chad Carroll
# 5      Brown Harris Stevens of PB         Sarah Koenig
# 6              Coldwell Banker/BR        Judith Randon
# 7    Sotheby's Intl. Realty, Inc.          Lisa Cregan
# 8                  Lang Realty/BR                 None
# 9    Sotheby's Intl. Realty, Inc.                 None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None      Jason Morss
# 1      William Raveis Real Estate     Shari Orland
# 2  One Sotheby's International Re      Dianne West
# 3                            None   Burton Minkoff
# 4            Compass Florida, LLC   Greta Huizenga
# 5      Brown Harris Stevens of PB   Michael Gazlay
# 6            Judith Randon Realty    Raquel Martin
# 7    Sotheby's Intl. Realty, Inc.       Lucy Bauer
# 8                            None        Jeff Daly
# 9                            None      Brie Segota
#
#                 buy_broker_name_1 buy_agent_name_2  \
# 0             Tangent Realty Corp             None
# 1  Champagne & Parisi Real Estate             None
# 2  Waterfront Properties & Club C             None
# 3                 Douglas Elliman             None
# 4       Douglas Elliman (Jupiter)   Donna Hutchins
# 5           K2 Realty, Inc. (NPB)             None
# 6        United Realty Group, Inc             None
# 7      Brown Harris Stevens of PB      Mary Wulsin
# 8        Realty Home Advisors Inc             None
# 9     Coffee Cake And Real Estate             None
#
#             buy_broker_name_2  RANK   COLOR  \
# 0                        None     1  orange
# 1                        None     2    blue
# 2                        None     3    blue
# 3                        None     4    blue
# 4   Douglas Elliman (Jupiter)     5    blue
# 5                        None     6    blue
# 6                        None     7    blue
# 7  Brown Harris Stevens of PB     8    blue
# 8                        None     9    blue
# 9                        None    10    blue
#
#                                            FULL_NAME
# 0  Mizner Grand Condo at 500 SE 5th Ave Unit 402s...
# 1  Villa Magna at 2727 S Ocean Blvd Unit 801 & 80...
# 2  Claridge Jupiter Island Condo at 19950 Beach 6...
# 3  Waterview Towers Condo at 400 N Flagler Dr #17...
# 4  Bears Club Villas Condo at 306 Villa Dr in Jup...
# 5  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6  Toscana South at 3740 S Ocean Blvd #1206 in Hi...
# 7  Trianon Condo at 1200 S Flagler Dr Ph 2 in Wes...
# 8  Chalfonte Condo at 550 S Ocean Blvd #1204 in B...
# 9  Palm Beach Towers Condo at 44 Cocoanut Row Uni...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Mizner Grand Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $1,725,000 to $4,775,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, West Palm Beach, Boca Raton, Palm Beach, Jupiter, Highland Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 194 condo sales totaling $96,028,333 million from Apr. 27th to May. 4th. The previous week, brokers closed 105 condo sales totaling $52,561,775.
#
# Last week’s units sold for an average of $494,991, lower than the $500,588 average price from the previous week. The average price per square foot rose to $333 from $331, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,725,000.0 million to $4,775,000.0 million.
#
# Mizner Grand Condo at 500 SE 5th Ave Unit 402s in Boca Raton took the top spot with a $4,775,000.0 million closing. The sale closed at $1,146.0 per square foot.
#
# Sergio Uliana with United Realty Group, Inc, and None with None had the listing.
# Jason Morss with Tangent Realty Corp, and None with None represented the buyer.
#
# Villa Magna at 2727 S Ocean Blvd Unit 801 & 805 in Highland Beach, closed for the second highest amount, $4,605,000.0, or $1,123.0 per square foot.
#
# Theresa Berman with William Raveis Real Estate, and Laura Mae Gallagher with William Raveis Real Estate had the listing.
# Shari Orland with Champagne & Parisi Real Estate, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05052025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 27th to May. 4th:
#
# Most Expensive
# Mizner Grand Condo, 500 SE 5th Ave Unit 402s, in Boca Raton | Price: $4,775,000 | $1,146 psf | Listing agents: Sergio Uliana with United Realty Group, Inc and None with None | Buyer's agents: Jason Morss with Tangent Realty Corp and None with None
#
# Least Expensive
# Chalfonte Condo, 550 S Ocean Blvd #1204, in Boca Raton | Price: $1,725,000 | $1,193 psf | Listing agents: Ana Londono with Lang Realty/BR and None with None | Buyer's agents: Jeff Daly with Realty Home Advisors Inc and None with None
#
# Highest Price Per Square Foot
# Palm Beach Towers Condo, 44 Cocoanut Row Unit 506b, in Palm Beach | Price: $1,725,000 | $1,917 psf | Listing agents: Kim Raich with Sotheby's Intl. Realty, Inc. and None with None | Buyer's agents: Brie Segota with Coffee Cake And Real Estate and None with None
#
# Lowest Price Per Square Foot
# Bears Club Villas Condo, 306 Villa Dr, in Jupiter | Price: $2,150,000 | $673 psf | Listing agents: Matthew Dugow with Compass Florida, LLC. and Chad Carroll with Compass Florida, LLC | Buyer's agents: Greta Huizenga with Douglas Elliman (Jupiter) and Donna Hutchins with Douglas Elliman (Jupiter)
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Boca-Raton/500-SE-5th-Ave-33432/unit-402S/home/42649468
# Second priciest sale:  https://www.redfin.com/FL/Highland-Beach/2727-S-Ocean-Blvd-33487/unit-805/home/172902371
# Cheapest top ten sale:  https://www.redfin.com/FL/Palm-Beach/44-Cocoanut-Row-33480/unit-506B/home/42443785
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/550-S-Ocean-Blvd-33432/unit-1204/home/42328390
# Highest top ten psf:  https://www.redfin.com/FL/Palm-Beach/44-Cocoanut-Row-33480/unit-506B/home/42443785
# Lowest top ten psf:  https://www.redfin.com/FL/Jupiter/306-Villa-Dr-33477/home/42606156

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Boca-Raton/500-SE-5th-Ave-33432/unit-402S/home/42649468

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Highland-Beach/2727-S-Ocean-Blvd-33487/unit-805/home/172902371

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Palm-Beach/44-Cocoanut-Row-33480/unit-506B/home/42443785

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/550-S-Ocean-Blvd-33432/unit-1204/home/42328390

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Palm-Beach/44-Cocoanut-Row-33480/unit-506B/home/42443785

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Jupiter/306-Villa-Dr-33477/home/42606156

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 0  PAST SALE 2025-05-01   Condo/Co-op          500 SE 5th Ave Unit 402s
# 1  PAST SALE 2025-04-28   Condo/Co-op  2727 S Ocean Blvd Unit 801 & 805
# 2  PAST SALE 2025-04-30   Condo/Co-op         19950 Beach 6s Rd Unit 6s
# 3  PAST SALE 2025-04-29   Condo/Co-op            400 N Flagler Dr #1702
# 4  PAST SALE 2025-04-29   Condo/Co-op                      306 Villa Dr
# 5  PAST SALE 2025-04-30   Condo/Co-op         44 Cocoanut Row Unit 522a
# 6  PAST SALE 2025-04-29   Condo/Co-op           3740 S Ocean Blvd #1206
# 7  PAST SALE 2025-05-02   Condo/Co-op            1200 S Flagler Dr Ph 2
# 8  PAST SALE 2025-05-01   Condo/Co-op            550 S Ocean Blvd #1204
# 9  PAST SALE 2025-05-02   Condo/Co-op         44 Cocoanut Row Unit 506b
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  4775000.0   3.0
# 1   Highland Beach                FL             33487.0  4605000.0   4.0
# 2          Jupiter                FL             33469.0  3500000.0   3.0
# 3  West Palm Beach                FL             33401.0  2600000.0   3.0
# 4          Jupiter                FL             33477.0  2150000.0   4.0
# 5       Palm Beach                FL             33480.0  1947582.0   2.0
# 6   Highland Beach                FL             33487.0  1837500.0   2.0
# 7  West Palm Beach                FL             33401.0  1837500.0   2.0
# 8       Boca Raton                FL             33432.0  1725000.0   2.0
# 9       Palm Beach                FL             33480.0  1725000.0   1.0
#
#    BATHS                       LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    4.5             Mizner Grand Condo       4168.0       NaN      1999.0
# 1    3.0                    Villa Magna       4100.0       NaN      1982.0
# 2    4.5  Claridge Jupiter Island Condo       3500.0       NaN      1994.0
# 3    2.0         Waterview Towers Condo       2109.0       NaN      1981.0
# 4    4.5        Bears Club Villas Condo       3195.0       NaN      2006.0
# 5    2.0        Palm Beach Towers Condo       1614.0       NaN      1956.0
# 6    2.5                  Toscana South       2601.0       NaN      2004.0
# 7    2.0                  Trianon Condo       1323.0       NaN      1972.0
# 8    2.0                Chalfonte Condo       1446.0       NaN      1974.0
# 9    1.0        Palm Beach Towers Condo        900.0       NaN      1956.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1146.0     4965.0   Sold
# 1             NaN         1123.0     4526.0   Sold
# 2             NaN         1000.0     6266.0   Sold
# 3             NaN         1233.0     2157.0   Sold
# 4             NaN          673.0     7097.0   Sold
# 5             NaN         1207.0     2222.0   Sold
# 6             NaN          706.0     2644.0   Sold
# 7             NaN         1389.0     1477.0   Sold
# 8             NaN         1193.0     1525.0   Sold
# 9             NaN         1917.0     1245.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...  Beaches MLS
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...  Beaches MLS
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...  Beaches MLS
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11026048        N          Y  26.344230 -80.076892
# 1  RX-10948375        N          Y  26.424944 -80.063184
# 2  RX-11058005        N          Y  26.970013 -80.080861
# 3  RX-11040176        N          Y  26.716414 -80.050223
# 4  RX-11067037        N          Y  26.890340 -80.084839
# 5  RX-11058499        N          Y  26.715065 -80.042094
# 6  RX-11063700        N          Y  26.407547 -80.065582
# 7  RX-11062948        N          Y  26.702722 -80.049673
# 8  RX-11014007        N          Y  26.344456 -80.070723
# 9  RX-11071687        N          Y  26.715065 -80.042094
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/500-SE-5t...      Sergio Uliana
# 1  https://www.redfin.com/FL/Highland-Beach/2727-...     Theresa Berman
# 2  https://www.redfin.com/FL/Jupiter/19950-Beach-...  Carla Christenson
# 3  https://www.redfin.com/FL/West-Palm-Beach/400-...     Samantha Curry
# 4  https://www.redfin.com/FL/Jupiter/306-Villa-Dr...      Matthew Dugow
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Sabra Kirkpatrick
# 6  https://www.redfin.com/FL/Highland-Beach/3740-...         Nancy Ghen
# 7  https://www.redfin.com/FL/West-Palm-Beach/1200...        John Cregan
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...        Ana Londono
# 9  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Kim Raich
#
#                list_broker_name_1    list_agent_name_2  \
# 0        United Realty Group, Inc                 None
# 1      William Raveis Real Estate  Laura Mae Gallagher
# 2  One Sotheby's International Re       Richard Powers
# 3                 Douglas Elliman                 None
# 4           Compass Florida, LLC.         Chad Carroll
# 5      Brown Harris Stevens of PB         Sarah Koenig
# 6              Coldwell Banker/BR        Judith Randon
# 7    Sotheby's Intl. Realty, Inc.          Lisa Cregan
# 8                  Lang Realty/BR                 None
# 9    Sotheby's Intl. Realty, Inc.                 None
#
#                list_broker_name_2 buy_agent_name_1  \
# 0                            None      Jason Morss
# 1      William Raveis Real Estate     Shari Orland
# 2  One Sotheby's International Re      Dianne West
# 3                            None   Burton Minkoff
# 4            Compass Florida, LLC   Greta Huizenga
# 5      Brown Harris Stevens of PB   Michael Gazlay
# 6            Judith Randon Realty    Raquel Martin
# 7    Sotheby's Intl. Realty, Inc.       Lucy Bauer
# 8                            None        Jeff Daly
# 9                            None      Brie Segota
#
#                 buy_broker_name_1 buy_agent_name_2  \
# 0             Tangent Realty Corp             None
# 1  Champagne & Parisi Real Estate             None
# 2  Waterfront Properties & Club C             None
# 3                 Douglas Elliman             None
# 4       Douglas Elliman (Jupiter)   Donna Hutchins
# 5           K2 Realty, Inc. (NPB)             None
# 6        United Realty Group, Inc             None
# 7      Brown Harris Stevens of PB      Mary Wulsin
# 8        Realty Home Advisors Inc             None
# 9     Coffee Cake And Real Estate             None
#
#             buy_broker_name_2  RANK   COLOR  \
# 0                        None     1  orange
# 1                        None     2    blue
# 2                        None     3    blue
# 3                        None     4    blue
# 4   Douglas Elliman (Jupiter)     5    blue
# 5                        None     6    blue
# 6                        None     7    blue
# 7  Brown Harris Stevens of PB     8    blue
# 8                        None     9    blue
# 9                        None    10    blue
#
#                                            FULL_NAME
# 0  Mizner Grand Condo at 500 SE 5th Ave Unit 402s...
# 1  Villa Magna at 2727 S Ocean Blvd Unit 801 & 80...
# 2  Claridge Jupiter Island Condo at 19950 Beach 6...
# 3  Waterview Towers Condo at 400 N Flagler Dr #17...
# 4  Bears Club Villas Condo at 306 Villa Dr in Jup...
# 5  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6  Toscana South at 3740 S Ocean Blvd #1206 in Hi...
# 7  Trianon Condo at 1200 S Flagler Dr Ph 2 in Wes...
# 8  Chalfonte Condo at 550 S Ocean Blvd #1204 in B...
# 9  Palm Beach Towers Condo at 44 Cocoanut Row Uni...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 1, 8) ## List (Earlier) date
date2 = datetime(2025, 4, 28) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 476

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1146.0
# 1    1123.0
# 2    1000.0
# 3    1233.0
# 4     673.0
# 5    1207.0
# 6     706.0
# 7    1389.0
# 8    1193.0
# 9    1917.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2025-05-01             500 SE 5th Ave Unit 402s in Boca Raton  $4,775,000
# 1 2025-04-28  2727 S Ocean Blvd Unit 801 & 805 in Highland B...  $4,605,000
# 2 2025-04-30               19950 Beach 6s Rd Unit 6s in Jupiter  $3,500,000
# 3 2025-04-29          400 N Flagler Dr #1702 in West Palm Beach  $2,600,000
# 4 2025-04-29                            306 Villa Dr in Jupiter  $2,150,000
# 5 2025-04-30            44 Cocoanut Row Unit 522a in Palm Beach  $1,947,582
# 6 2025-04-29          3740 S Ocean Blvd #1206 in Highland Beach  $1,837,500
# 7 2025-05-02          1200 S Flagler Dr Ph 2 in West Palm Beach  $1,837,500
# 8 2025-05-01               550 S Ocean Blvd #1204 in Boca Raton  $1,725,000
# 9 2025-05-02            44 Cocoanut Row Unit 506b in Palm Beach  $1,725,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3    4.5       4,168       1999        $1,146  Beaches MLS  RX-11026048
# 1    4    3.0       4,100       1982        $1,123  Beaches MLS  RX-10948375
# 2    3    4.5       3,500       1994        $1,000  Beaches MLS  RX-11058005
# 3    3    2.0       2,109       1981        $1,233  Beaches MLS  RX-11040176
# 4    4    4.5       3,195       2006          $673  Beaches MLS  RX-11067037
# 5    2    2.0       1,614       1956        $1,207  Beaches MLS  RX-11058499
# 6    2    2.5       2,601       2004          $706  Beaches MLS  RX-11063700
# 7    2    2.0       1,323       1972        $1,389  Beaches MLS  RX-11062948
# 8    2    2.0       1,446       1974        $1,193  Beaches MLS  RX-11014007
# 9    1    1.0         900       1956        $1,917  Beaches MLS  RX-11071687
#
#                                         LISTING INFO  \
# 0         Sergio Uliana United Realty Group, Inc
# 1  Theresa Berman William Raveis Real Estate Laur...
# 2  Carla Christenson One Sotheby's International ...
# 3                 Samantha Curry Douglas Elliman
# 4  Matthew Dugow Compass Florida, LLC. Chad Carro...
# 5  Sabra Kirkpatrick Brown Harris Stevens of PB S...
# 6  Nancy Ghen Coldwell Banker/BR Judith Randon Ju...
# 7  John Cregan Sotheby's Intl. Realty, Inc. Lisa ...
# 8                     Ana Londono Lang Realty/BR
# 9         Kim Raich Sotheby's Intl. Realty, Inc.
#
#                                          BUYING INFO
# 0                Jason Morss Tangent Realty Corp
# 1    Shari Orland Champagne & Parisi Real Estate
# 2     Dianne West Waterfront Properties & Club C
# 3                 Burton Minkoff Douglas Elliman
# 4  Greta Huizenga Douglas Elliman (Jupiter) Donna...
# 5           Michael Gazlay K2 Realty, Inc. (NPB)
# 6         Raquel Martin United Realty Group, Inc
# 7  Lucy Bauer Brown Harris Stevens of PB Mary Wul...
# 8             Jeff Daly Realty Home Advisors Inc
# 9        Brie Segota Coffee Cake And Real Estate
