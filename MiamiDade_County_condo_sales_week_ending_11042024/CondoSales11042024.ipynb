# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Oct. 27th Nov. 3rd

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE        SOLD DATE PROPERTY TYPE            ADDRESS          CITY  \
# 1  PAST SALE  October-30-2024   Condo/Co-op  230 Sunrise Dr #8  Key Biscayne
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33149.0  538500.0   1.0    1.5  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Key-Biscayne/230-Sun...  MARMLS  A11640817
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.689827 -80.161426
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 13   PAST SALE 2024-11-04   Condo/Co-op         201 Crandon Blvd #900
# 40   PAST SALE 2024-11-04   Condo/Co-op        951 Brickell Ave #3302
# 115  PAST SALE 2024-11-04   Condo/Co-op            230 174th St #2001
# 12   PAST SALE 2024-11-01   Condo/Co-op           301 Altara Ave #731
# 81   PAST SALE 2024-11-01   Condo/Co-op       10765 SW 108th Ave #207
# ..         ...        ...           ...                           ...
# 56   PAST SALE 2024-10-28   Condo/Co-op          1331 Lincoln Rd #803
# 58   PAST SALE 2024-10-28   Condo/Co-op        2600 Island Blvd #1804
# 60   PAST SALE 2024-10-28   Condo/Co-op         13390 NE 7th Ave #314
# 2    PAST SALE 2024-10-28   Condo/Co-op           11447 NW 95th Ct #4
# 92   PAST SALE 2024-10-28   Condo/Co-op  8550 SW 109th Ave Unit 5-218
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 13        Key Biscayne                FL             33149.0  2550000.0   3.0
# 40               Miami                FL             33131.0   570000.0   1.0
# 115  Sunny Isles Beach                FL             33160.0   450000.0   2.0
# 12        Coral Gables                FL             33146.0   870000.0   2.0
# 81               Miami                FL             33176.0   299000.0   2.0
# ..                 ...               ...                 ...        ...   ...
# 56         Miami Beach                FL             33139.0   425000.0   2.0
# 58            Aventura                FL             33160.0  1910000.0   3.0
# 60         North Miami                FL             33161.0   195000.0   2.0
# 2      Hialeah Gardens                FL             33018.0   440000.0   3.0
# 92               Miami                FL             33173.0   220000.0   1.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 13     3.0  ...   Sold                         NaN                       NaN
# 40     1.0  ...   Sold                         NaN                       NaN
# 115    2.0  ...   Sold                         NaN                       NaN
# 12     2.0  ...   Sold                         NaN                       NaN
# 81     2.0  ...   Sold                         NaN                       NaN
# ..     ...  ...    ...                         ...                       ...
# 56     2.0  ...   Sold                         NaN                       NaN
# 58     3.0  ...   Sold                         NaN                       NaN
# 60     2.0  ...   Sold                         NaN                       NaN
# 2      2.0  ...   Sold                         NaN                       NaN
# 92     1.5  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 13   https://www.redfin.com/FL/Key-Biscayne/201-Cra...       MARMLS
# 40   https://www.redfin.com/FL/Miami/951-Brickell-A...       MARMLS
# 115  https://www.redfin.com/FL/Sunny-Isles-Beach/23...       MARMLS
# 12   https://www.redfin.com/FL/Coral-Gables/301-Alt...       MARMLS
# 81   https://www.redfin.com/FL/Miami/10765-SW-108th...       MARMLS
# ..                                                 ...          ...
# 56   https://www.redfin.com/FL/Miami-Beach/1331-Lin...       MARMLS
# 58   https://www.redfin.com/FL/Aventura/2600-Island...       MARMLS
# 60   https://www.redfin.com/FL/North-Miami/13390-NE...  Beaches MLS
# 2    https://www.redfin.com/FL/Hialeah/11447-NW-95t...       MARMLS
# 92   https://www.redfin.com/FL/Miami/8550-SW-109th-...       MARMLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 13   A11653306         N          Y  25.696814 -80.158094
# 40   A11633680         N          Y  25.764430 -80.190781
# 115  A11523186         N          Y  25.936714 -80.124549
# 12   A11670201         N          Y  25.733644 -80.261796
# 81   A11632049         N          Y  25.669168 -80.370098
# ..         ...       ...        ...        ...        ...
# 56   A11620184         N          Y  25.790648 -80.142640
# 58   A11538506         N          Y  25.939020 -80.133755
# 60   F10458662         N          Y  25.898298 -80.185466
# 2    A11664031         N          Y  25.877574 -80.352415
# 92   A11611322         N          Y  25.689153 -80.370756
#
# [120 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 120

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $770,797

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $543

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $92,495,640

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 112
# Input Previous Week Condo Average Sales Price:
# 782730
# Input Previous Week Condo Average PSF:
# 478
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 87_700_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op  16901 Collins Ave #901
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
#
#    BATHS              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5  JADE SIGNATURE CONDO       2980.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  Marcelo Violland
#
#                    list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Prime International Associates Inc              None               None
#
#      buy_agent_name_1   buy_broker_name_1   buy_agent_name_2  \
# 0  Jose Augusto Nunes  Algebra Realty.com  Yorghi Abad Mitre
#
#     buy_broker_name_2  RANK   COLOR
# 0  Algebra Realty.com     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op      16901 Collins Ave #901
# 1  PAST SALE 2024-10-30   Condo/Co-op          400 Alton Rd #2804
# 2  PAST SALE 2024-10-30   Condo/Co-op      6000 Island Blvd #2103
# 3  PAST SALE 2024-11-01   Condo/Co-op  9705 Collins Ave Unit 805N
# 4  PAST SALE 2024-10-29   Condo/Co-op     17875 Collins Ave #3305
# 5  PAST SALE 2024-10-31   Condo/Co-op          1 Collins Ave #204
# 6  PAST SALE 2024-11-04   Condo/Co-op       201 Crandon Blvd #900
# 7  PAST SALE 2024-11-01   Condo/Co-op      17121 Collins Ave #901
# 8  PAST SALE 2024-11-01   Condo/Co-op     18975 Collins Ave #5205
# 9  PAST SALE 2024-10-30   Condo/Co-op   808 Brickell Key Dr #1904
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
# 1        Miami Beach                FL             33139.0  4375000.0   3.0
# 2           Aventura                FL             33160.0  3695000.0   4.0
# 3        Bal Harbour                FL             33154.0  3125000.0   2.0
# 4  Sunny Isles Beach                FL             33160.0  2900000.0   3.0
# 5        Miami Beach                FL             33139.0  2900000.0   3.0
# 6       Key Biscayne                FL             33149.0  2550000.0   3.0
# 7  Sunny Isles Beach                FL             33160.0  2390000.0   3.0
# 8  Sunny Isles Beach                FL             33160.0  2385000.0   2.0
# 9              Miami                FL             33131.0  2300000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5       JADE SIGNATURE CONDO       2980.0       NaN      2018.0
# 1    3.5  MURANO GRANDE AT PORTOFIN       2974.0       NaN      2003.0
# 2    3.5  BELLAMARE @ WILLIAMS ISLA       3224.0       NaN      2005.0
# 3    2.5  BAL HARBOUR NORTH SOUTH C       1599.0       NaN      2011.0
# 4    3.0  ACQUALINA OCEAN RESIDENCE       2214.0       NaN      2006.0
# 5    2.5            ONE OCEAN CONDO       2505.0       NaN      2016.0
# 6    3.0            KEY COLONY NO 1       2169.0       NaN      1978.0
# 7    3.5           JADE OCEAN CONDO       1956.0       NaN      2009.0
# 8    2.0        18975 COLLINS CONDO       1296.0       NaN      2020.0
# 9    3.5   TWO TEQUESTA POINT CONDO       2520.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
# 1             NaN         1471.0     4144.0   Sold
# 2             NaN         1146.0     4033.0   Sold
# 3             NaN         1954.0     3205.0   Sold
# 4             NaN         1310.0     4123.0   Sold
# 5             NaN         1158.0     6100.0   Sold
# 6             NaN         1176.0     2323.0   Sold
# 7             NaN         1222.0     2918.0   Sold
# 8             NaN         1840.0     2130.0   Sold
# 9             NaN          913.0     2194.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...  MARMLS  A11640687
# 2  https://www.redfin.com/FL/Aventura/6000-Island...  MARMLS  A11637287
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...  MARMLS  A11521311
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11649633
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11348761
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...  MARMLS  A11653306
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11659012
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  MARMLS  A11663453
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...  MARMLS  A11663478
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
# 1        N          Y  25.772744 -80.140607
# 2        N          Y  25.942761 -80.135433
# 3        N          Y  25.889270 -80.122909
# 4        N          Y  25.941257 -80.120772
# 5        N          Y  25.769375 -80.133358
# 6        N          Y  25.696814 -80.158094
# 7        N          Y  25.934401 -80.121005
# 8        N          Y  25.951740 -80.119755
# 9        N          Y  25.768790 -80.183330
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...     Marcelo Violland
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...           Dean Bloch
# 2  https://www.redfin.com/FL/Aventura/6000-Island...      Richard Goihman
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...         Mariana Niro
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...                 None
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...         Kathrin Rein
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...        Carla Datorre
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...          Luz Spriggs
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Stephanie Penaranda
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...       Jenny Gonzalez
#
#                       list_broker_name_1 list_agent_name_2  \
# 0     Prime International Associates Inc              None
# 1                        Douglas Elliman              None
# 2                        Douglas Elliman              None
# 3                                Serhant              None
# 4                                   None              None
# 5     Keller Williams Miami Beach Realty              None
# 6                   Datorre Realty Group              None
# 7           Keller Williams Eagle Realty              None
# 8  All in One International Realty, LLC.              None
# 9                  Engel & Völkers Miami      Rocio Useche
#
#       list_broker_name_2    buy_agent_name_1            buy_broker_name_1  \
# 0                   None  Jose Augusto Nunes           Algebra Realty.com
# 1                   None       David Vazquez              Douglas Elliman
# 2                   None          Joel Matus  Williams Island Realty, LLC
# 3                   None        Mariana Niro                      Serhant
# 4                   None                None                         None
# 5                   None        Julian Cohen              Douglas Elliman
# 6                   None       Birgit Lahaye       Coldwell Banker Realty
# 7                   None        Nei Andreani  Miami Realty Solution Group
# 8                   None     Ludmila Bogatov               Bogatov Realty
# 9  Engel & Völkers Miami   Gisela Cacciamani              BHHS EWM Realty
#
#     buy_agent_name_2     buy_broker_name_2  RANK   COLOR
# 0  Yorghi Abad Mitre    Algebra Realty.com     1  orange
# 1               None                  None     2    blue
# 2               None                  None     3    blue
# 3      Victor Harary  Compass Florida, LLC     4    blue
# 4               None                  None     5    blue
# 5               None                  None     6    blue
# 6               None                  None     7    blue
# 7               None                  None     8    blue
# 8               None                  None     9    blue
# 9               None                  None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06b0658e704da510db18063629f13644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Oct. 27th - Nov. 3rd&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06b0658e704da510db18063629f13644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_06b0658e704da510db18063629f13644 = L.map(
#                 &quot;map_06b0658e704da510db18063629f13644&quot;,
#                 {
#                     center: [25.82846234, -80.21349182083333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_69cc35978fcb78fe31e3d2ce8c70f036 = L.featureGroup(
#                 {}
#             ).addTo(map_06b0658e704da510db18063629f13644);
#
#
#             var marker_76c91fedb33f732f6df89f4aef540008 = L.marker(
#                 [25.9327637, -80.1210362],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_69cc35978fcb78fe31e3d2ce8c70f036);
#
#
#             var icon_55d3b0ed0068636e0be79107e52d2754 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_76c91fedb33f732f6df89f4aef540008.setIcon(icon_55d3b0ed0068636e0be79107e52d2754);
#
#
#         var popup_8578e5bb3b43d402a33dc4b42ff11166 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_7ab0aef551ea72633f205bf672e08c93 = $(`&lt;div id=&quot;html_7ab0aef551ea72633f205bf672e08c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;16901 Collins Ave #901&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,975,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,669.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,980.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_8578e5bb3b43d402a33dc4b42ff11166.setContent(html_7ab0aef551ea72633f205bf672e08c93);
#
#
#
#         marker_76c91fedb33f732f6df89f4aef540008.bindPopup(popup_8578e5bb3b43d402a33dc4b42ff11166)
#         ;
#
#
#
#
#             var feature_group_c0676a8ddb35500f3cc623b40f2d0a5e = L.featureGroup(
#                 {}
#             ).addTo(map_06b0658e704da510db18063629f13644);
#
#
#             var marker_0f053540eb980646d2c0268aaff65dfe = L.marker(
#                 [25.7727436, -80.1406065],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c0676a8ddb35500f3cc623b40f2d0a5e);
#
#
#             var icon_edba4bd856ff20b0ca0a8b9b4b940d98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0f053540eb980646d2c0268aaff65dfe.setIcon(icon_edba4bd856ff20b0ca0a8b9b4b940d98);
#
#
#         var popup_e4900ebdfb1ef9cac9840704779de467 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_8cc2d6174ed3e5246c3011c25e652dfc = $(`&lt;div id=&quot;html_8cc2d6174ed3e5246c3011c25e652dfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;400 Alton Rd #2804&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,375,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,471.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,974.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2003.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_e4900ebdfb1ef9cac9840704779de467.setContent(html_8cc2d6174ed3e5246c3011c25e652dfc);
#
#
#
#         marker_0f053540eb980646d2c0268aaff65dfe.bindPopup(popup_e4900ebdfb1ef9cac9840704779de467)
#         ;
#
#
#
#
#             var marker_45736f9ecb3a131804a512c5bb420c26 = L.marker(
#                 [25.942761, -80.1354328],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_c0676a8ddb35500f3cc623b40f2d0a5e);
#
#
#             var icon_e4fb44c8be8578dc7d8c3795699e5bbe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45736f9ecb3a131804a512c5bb420c26.setIcon(icon_e4fb44c8be8578dc7d8c3795699e5bbe);
#
#
#         var popup_aff68981cbe743c514b846fe08fa9479 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_ce8ec0242c4db946760656bc0ed0cbf3 = $(`&lt;div id=&quo

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op  16901 Collins Ave #901
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
#
#    BATHS              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5  JADE SIGNATURE CONDO       2980.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  Marcelo Violland
#
#                    list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Prime International Associates Inc              None               None
#
#      buy_agent_name_1   buy_broker_name_1   buy_agent_name_2  \
# 0  Jose Augusto Nunes  Algebra Realty.com  Yorghi Abad Mitre
#
#     buy_broker_name_2  RANK   COLOR
# 0  Algebra Realty.com     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_11042024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'JADE SIGNATURE CONDO at 16901 Collins Ave #901 in Sunny Isles Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op      16901 Collins Ave #901
# 1  PAST SALE 2024-10-30   Condo/Co-op          400 Alton Rd #2804
# 2  PAST SALE 2024-10-30   Condo/Co-op      6000 Island Blvd #2103
# 3  PAST SALE 2024-11-01   Condo/Co-op  9705 Collins Ave Unit 805N
# 4  PAST SALE 2024-10-29   Condo/Co-op     17875 Collins Ave #3305
# 5  PAST SALE 2024-10-31   Condo/Co-op          1 Collins Ave #204
# 6  PAST SALE 2024-11-04   Condo/Co-op       201 Crandon Blvd #900
# 7  PAST SALE 2024-11-01   Condo/Co-op      17121 Collins Ave #901
# 8  PAST SALE 2024-11-01   Condo/Co-op     18975 Collins Ave #5205
# 9  PAST SALE 2024-10-30   Condo/Co-op   808 Brickell Key Dr #1904
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
# 1        Miami Beach                FL             33139.0  4375000.0   3.0
# 2           Aventura                FL             33160.0  3695000.0   4.0
# 3        Bal Harbour                FL             33154.0  3125000.0   2.0
# 4  Sunny Isles Beach                FL             33160.0  2900000.0   3.0
# 5        Miami Beach                FL             33139.0  2900000.0   3.0
# 6       Key Biscayne                FL             33149.0  2550000.0   3.0
# 7  Sunny Isles Beach                FL             33160.0  2390000.0   3.0
# 8  Sunny Isles Beach                FL             33160.0  2385000.0   2.0
# 9              Miami                FL             33131.0  2300000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5       JADE SIGNATURE CONDO       2980.0       NaN      2018.0
# 1    3.5  MURANO GRANDE AT PORTOFIN       2974.0       NaN      2003.0
# 2    3.5  BELLAMARE @ WILLIAMS ISLA       3224.0       NaN      2005.0
# 3    2.5  BAL HARBOUR NORTH SOUTH C       1599.0       NaN      2011.0
# 4    3.0  ACQUALINA OCEAN RESIDENCE       2214.0       NaN      2006.0
# 5    2.5            ONE OCEAN CONDO       2505.0       NaN      2016.0
# 6    3.0            KEY COLONY NO 1       2169.0       NaN      1978.0
# 7    3.5           JADE OCEAN CONDO       1956.0       NaN      2009.0
# 8    2.0        18975 COLLINS CONDO       1296.0       NaN      2020.0
# 9    3.5   TWO TEQUESTA POINT CONDO       2520.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
# 1             NaN         1471.0     4144.0   Sold
# 2             NaN         1146.0     4033.0   Sold
# 3             NaN         1954.0     3205.0   Sold
# 4             NaN         1310.0     4123.0   Sold
# 5             NaN         1158.0     6100.0   Sold
# 6             NaN         1176.0     2323.0   Sold
# 7             NaN         1222.0     2918.0   Sold
# 8             NaN         1840.0     2130.0   Sold
# 9             NaN          913.0     2194.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...  MARMLS  A11640687
# 2  https://www.redfin.com/FL/Aventura/6000-Island...  MARMLS  A11637287
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...  MARMLS  A11521311
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11649633
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11348761
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...  MARMLS  A11653306
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11659012
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  MARMLS  A11663453
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...  MARMLS  A11663478
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
# 1        N          Y  25.772744 -80.140607
# 2        N          Y  25.942761 -80.135433
# 3        N          Y  25.889270 -80.122909
# 4        N          Y  25.941257 -80.120772
# 5        N          Y  25.769375 -80.133358
# 6        N          Y  25.696814 -80.158094
# 7        N          Y  25.934401 -80.121005
# 8        N          Y  25.951740 -80.119755
# 9        N          Y  25.768790 -80.183330
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...     Marcelo Violland
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...           Dean Bloch
# 2  https://www.redfin.com/FL/Aventura/6000-Island...      Richard Goihman
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...         Mariana Niro
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...                 None
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...         Kathrin Rein
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...        Carla Datorre
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...          Luz Spriggs
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Stephanie Penaranda
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...       Jenny Gonzalez
#
#                       list_broker_name_1 list_agent_name_2  \
# 0     Prime International Associates Inc              None
# 1                        Douglas Elliman              None
# 2                        Douglas Elliman              None
# 3                                Serhant              None
# 4                                   None              None
# 5     Keller Williams Miami Beach Realty              None
# 6                   Datorre Realty Group              None
# 7           Keller Williams Eagle Realty              None
# 8  All in One International Realty, LLC.              None
# 9                  Engel & Völkers Miami      Rocio Useche
#
#       list_broker_name_2    buy_agent_name_1            buy_broker_name_1  \
# 0                   None  Jose Augusto Nunes           Algebra Realty.com
# 1                   None       David Vazquez              Douglas Elliman
# 2                   None          Joel Matus  Williams Island Realty, LLC
# 3                   None        Mariana Niro                      Serhant
# 4                   None                None                         None
# 5                   None        Julian Cohen              Douglas Elliman
# 6                   None       Birgit Lahaye       Coldwell Banker Realty
# 7                   None        Nei Andreani  Miami Realty Solution Group
# 8                   None     Ludmila Bogatov               Bogatov Realty
# 9  Engel & Völkers Miami   Gisela Cacciamani              BHHS EWM Realty
#
#     buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0  Yorghi Abad Mitre    Algebra Realty.com     1  orange
# 1               None                  None     2    blue
# 2               None                  None     3    blue
# 3      Victor Harary  Compass Florida, LLC     4    blue
# 4               None                  None     5    blue
# 5               None                  None     6    blue
# 6               None                  None     7    blue
# 7               None                  None     8    blue
# 8               None                  None     9    blue
# 9               None                  None    10    blue
#
#                                            FULL_NAME
# 0  JADE SIGNATURE CONDO at 16901 Collins Ave #901...
# 1  MURANO GRANDE AT PORTOFIN at 400 Alton Rd #280...
# 2  BELLAMARE @ WILLIAMS ISLA at 6000 Island Blvd ...
# 3  BAL HARBOUR NORTH SOUTH C at 9705 Collins Ave ...
# 4  ACQUALINA OCEAN RESIDENCE at 17875 Collins Ave...
# 5  ONE OCEAN CONDO at 1 Collins Ave #204 in Miami...
# 6  KEY COLONY NO 1 at 201 Crandon Blvd #900 in Ke...
# 7  JADE OCEAN CONDO at 17121 Collins Ave #901 in ...
# 8  18975 COLLINS CONDO at 18975 Collins Ave #5205...
# 9  TWO TEQUESTA POINT CONDO at 808 Brickell Key D...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: JADE SIGNATURE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,300,000M to $4,975,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Bal Harbour, Key Biscayne, Aventura, Miami, Miami Beach, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 120 condo sales totaling $92,495,640 million from Oct. 27th to Nov. 3rd. The previous week, brokers closed 112 condo sales totaling $87,700,000.
#
# Last week’s units sold for an average of $770,797, lower than the $782,730 average price from the previous week. The average price per square foot rose to $543 from $478, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,300,000.0 million to $4,975,000.0 million.
#
# JADE SIGNATURE CONDO at 16901 Collins Ave #901 in Sunny Isles Beach took the top spot with a $4,975,000.0 million closing. The sale closed at $1,669.0 per square foot.
#
# Marcelo Violland with Prime International Associates Inc, and None with None had the listing.
# Jose Augusto Nunes with Algebra Realty.com, and Yorghi Abad Mitre with Algebra Realty.com represented the buyer.
#
# MURANO GRANDE AT PORTOFIN at 400 Alton Rd #2804 in Miami Beach, closed for the second highest amount, $4,375,000.0, or $1,471.0 per square foot.
#
# Dean Bloch with Douglas Elliman, and None with None had the listing.
# David Vazquez with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_11042024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Oct. 27th to Nov. 3rd:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op      16901 Collins Ave #901
# 1  PAST SALE 2024-10-30   Condo/Co-op          400 Alton Rd #2804
# 2  PAST SALE 2024-10-30   Condo/Co-op      6000 Island Blvd #2103
# 3  PAST SALE 2024-11-01   Condo/Co-op  9705 Collins Ave Unit 805N
# 4  PAST SALE 2024-10-29   Condo/Co-op     17875 Collins Ave #3305
# 5  PAST SALE 2024-10-31   Condo/Co-op          1 Collins Ave #204
# 6  PAST SALE 2024-11-04   Condo/Co-op       201 Crandon Blvd #900
# 7  PAST SALE 2024-11-01   Condo/Co-op      17121 Collins Ave #901
# 8  PAST SALE 2024-11-01   Condo/Co-op     18975 Collins Ave #5205
# 9  PAST SALE 2024-10-30   Condo/Co-op   808 Brickell Key Dr #1904
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
# 1        Miami Beach                FL             33139.0  4375000.0   3.0
# 2           Aventura                FL             33160.0  3695000.0   4.0
# 3        Bal Harbour                FL             33154.0  3125000.0   2.0
# 4  Sunny Isles Beach                FL             33160.0  2900000.0   3.0
# 5        Miami Beach                FL             33139.0  2900000.0   3.0
# 6       Key Biscayne                FL             33149.0  2550000.0   3.0
# 7  Sunny Isles Beach                FL             33160.0  2390000.0   3.0
# 8  Sunny Isles Beach                FL             33160.0  2385000.0   2.0
# 9              Miami                FL             33131.0  2300000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5       JADE SIGNATURE CONDO       2980.0       NaN      2018.0
# 1    3.5  MURANO GRANDE AT PORTOFIN       2974.0       NaN      2003.0
# 2    3.5  BELLAMARE @ WILLIAMS ISLA       3224.0       NaN      2005.0
# 3    2.5  BAL HARBOUR NORTH SOUTH C       1599.0       NaN      2011.0
# 4    3.0  ACQUALINA OCEAN RESIDENCE       2214.0       NaN      2006.0
# 5    2.5            ONE OCEAN CONDO       2505.0       NaN      2016.0
# 6    3.0            KEY COLONY NO 1       2169.0       NaN      1978.0
# 7    3.5           JADE OCEAN CONDO       1956.0       NaN      2009.0
# 8    2.0        18975 COLLINS CONDO       1296.0       NaN      2020.0
# 9    3.5   TWO TEQUESTA POINT CONDO       2520.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
# 1             NaN         1471.0     4144.0   Sold
# 2             NaN         1146.0     4033.0   Sold
# 3             NaN         1954.0     3205.0   Sold
# 4             NaN         1310.0     4123.0   Sold
# 5             NaN         1158.0     6100.0   Sold
# 6             NaN         1176.0     2323.0   Sold
# 7             NaN         1222.0     2918.0   Sold
# 8             NaN         1840.0     2130.0   Sold
# 9             NaN          913.0     2194.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...  MARMLS  A11640687
# 2  https://www.redfin.com/FL/Aventura/6000-Island...  MARMLS  A11637287
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...  MARMLS  A11521311
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11649633
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11348761
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...  MARMLS  A11653306
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11659012
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  MARMLS  A11663453
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...  MARMLS  A11663478
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
# 1        N          Y  25.772744 -80.140607
# 2        N          Y  25.942761 -80.135433
# 3        N          Y  25.889270 -80.122909
# 4        N          Y  25.941257 -80.120772
# 5        N          Y  25.769375 -80.133358
# 6        N          Y  25.696814 -80.158094
# 7        N          Y  25.934401 -80.121005
# 8        N          Y  25.951740 -80.119755
# 9        N          Y  25.768790 -80.183330
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...     Marcelo Violland
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...           Dean Bloch
# 2  https://www.redfin.com/FL/Aventura/6000-Island...      Richard Goihman
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...         Mariana Niro
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...                 None
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...         Kathrin Rein
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...        Carla Datorre
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...          Luz Spriggs
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Stephanie Penaranda
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...       Jenny Gonzalez
#
#                       list_broker_name_1 list_agent_name_2  \
# 0     Prime International Associates Inc              None
# 1                        Douglas Elliman              None
# 2                        Douglas Elliman              None
# 3                                Serhant              None
# 4                                   None              None
# 5     Keller Williams Miami Beach Realty              None
# 6                   Datorre Realty Group              None
# 7           Keller Williams Eagle Realty              None
# 8  All in One International Realty, LLC.              None
# 9                  Engel & Völkers Miami      Rocio Useche
#
#       list_broker_name_2    buy_agent_name_1            buy_broker_name_1  \
# 0                   None  Jose Augusto Nunes           Algebra Realty.com
# 1                   None       David Vazquez              Douglas Elliman
# 2                   None          Joel Matus  Williams Island Realty, LLC
# 3                   None        Mariana Niro                      Serhant
# 4                   None                None                         None
# 5                   None        Julian Cohen              Douglas Elliman
# 6                   None       Birgit Lahaye       Coldwell Banker Realty
# 7                   None        Nei Andreani  Miami Realty Solution Group
# 8                   None     Ludmila Bogatov               Bogatov Realty
# 9  Engel & Völkers Miami   Gisela Cacciamani              BHHS EWM Realty
#
#     buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0  Yorghi Abad Mitre    Algebra Realty.com     1  orange
# 1               None                  None     2    blue
# 2               None                  None     3    blue
# 3      Victor Harary  Compass Florida, LLC     4    blue
# 4               None                  None     5    blue
# 5               None                  None     6    blue
# 6               None                  None     7    blue
# 7               None                  None     8    blue
# 8               None                  None     9    blue
# 9               None                  None    10    blue
#
#                                            FULL_NAME
# 0  JADE SIGNATURE CONDO at 16901 Collins Ave #901...
# 1  MURANO GRANDE AT PORTOFIN at 400 Alton Rd #280...
# 2  BELLAMARE @ WILLIAMS ISLA at 6000 Island Blvd ...
# 3  BAL HARBOUR NORTH SOUTH C at 9705 Collins Ave ...
# 4  ACQUALINA OCEAN RESIDENCE at 17875 Collins Ave...
# 5  ONE OCEAN CONDO at 1 Collins Ave #204 in Miami...
# 6  KEY COLONY NO 1 at 201 Crandon Blvd #900 in Ke...
# 7  JADE OCEAN CONDO at 17121 Collins Ave #901 in ...
# 8  18975 COLLINS CONDO at 18975 Collins Ave #5205...
# 9  TWO TEQUESTA POINT CONDO at 808 Brickell Key D...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: JADE SIGNATURE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,300,000M to $4,975,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Bal Harbour, Key Biscayne, Aventura, Miami, Miami Beach, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 120 condo sales totaling $92,495,640 million from Oct. 27th to Nov. 3rd. The previous week, brokers closed 112 condo sales totaling $87,700,000.
#
# Last week’s units sold for an average of $770,797, lower than the $782,730 average price from the previous week. The average price per square foot rose to $543 from $478, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,300,000.0 million to $4,975,000.0 million.
#
# JADE SIGNATURE CONDO at 16901 Collins Ave #901 in Sunny Isles Beach took the top spot with a $4,975,000.0 million closing. The sale closed at $1,669.0 per square foot.
#
# Marcelo Violland with Prime International Associates Inc, and None with None had the listing.
# Jose Augusto Nunes with Algebra Realty.com, and Yorghi Abad Mitre with Algebra Realty.com represented the buyer.
#
# MURANO GRANDE AT PORTOFIN at 400 Alton Rd #2804 in Miami Beach, closed for the second highest amount, $4,375,000.0, or $1,471.0 per square foot.
#
# Dean Bloch with Douglas Elliman, and None with None had the listing.
# David Vazquez with Douglas Elliman, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_11042024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Oct. 27th to Nov. 3rd:
#
# Most Expensive
# JADE SIGNATURE CONDO, 16901 Collins Ave #901, in Sunny Isles Beach | Price: $4,975,000 | $1,669 psf | Listing agents: Marcelo Violland with Prime International Associates Inc and None with None | Buyer's agents: Jose Augusto Nunes with Algebra Realty.com and Yorghi Abad Mitre with Algebra Realty.com
# Least Expensive
# TWO TEQUESTA POINT CONDO, 808 Brickell Key Dr #1904, in Miami | Price: $2,300,000 | $913 psf | Listing agents: Jenny Gonzalez with Engel & Völkers Miami and Rocio Useche with Engel & Völkers Miami | Buyer's agents: Gisela Cacciamani with BHHS EWM Realty and None with None
# Highest Price Per Square Foot
# BAL HARBOUR NORTH SOUTH C, 9705 Collins Ave Unit 805N, in Bal Harbour | Price: $3,125,000 | $1,954 psf | Listing agents: Mariana Niro with Serhant and None with None | Buyer's agents: Mariana Niro with Serhant and Victor Harary with Compass Florida, LLC
# Lowest Price Per Square Foot
# TWO TEQUESTA POINT CONDO, 808 Brickell Key Dr #1904, in Miami | Price: $2,300,000 | $913 psf | Listing agents: Jenny Gonzalez with Engel & Völkers Miami and Rocio Useche with Engel & Völkers Miami | Buyer's agents: Gisela Cacciamani with BHHS EWM Realty and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/16901-Collins-Ave-33160/unit-901/home/56742099

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Miami-Beach/400-Alton-Rd-33139/unit-2804/home/43304044

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Miami/808-Brickell-Key-Dr-33131/unit-1904/home/42766612

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/18975-Collins-Ave-33160/unit-5205/home/171996189

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Bal-Harbour/9705-Collins-Ave-33154/unit-805N/home/50121175

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Miami/808-Brickell-Key-Dr-33131/unit-1904/home/42766612

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2024-10-31   Condo/Co-op      16901 Collins Ave #901
# 1  PAST SALE 2024-10-30   Condo/Co-op          400 Alton Rd #2804
# 2  PAST SALE 2024-10-30   Condo/Co-op      6000 Island Blvd #2103
# 3  PAST SALE 2024-11-01   Condo/Co-op  9705 Collins Ave Unit 805N
# 4  PAST SALE 2024-10-29   Condo/Co-op     17875 Collins Ave #3305
# 5  PAST SALE 2024-10-31   Condo/Co-op          1 Collins Ave #204
# 6  PAST SALE 2024-11-04   Condo/Co-op       201 Crandon Blvd #900
# 7  PAST SALE 2024-11-01   Condo/Co-op      17121 Collins Ave #901
# 8  PAST SALE 2024-11-01   Condo/Co-op     18975 Collins Ave #5205
# 9  PAST SALE 2024-10-30   Condo/Co-op   808 Brickell Key Dr #1904
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  4975000.0   4.0
# 1        Miami Beach                FL             33139.0  4375000.0   3.0
# 2           Aventura                FL             33160.0  3695000.0   4.0
# 3        Bal Harbour                FL             33154.0  3125000.0   2.0
# 4  Sunny Isles Beach                FL             33160.0  2900000.0   3.0
# 5        Miami Beach                FL             33139.0  2900000.0   3.0
# 6       Key Biscayne                FL             33149.0  2550000.0   3.0
# 7  Sunny Isles Beach                FL             33160.0  2390000.0   3.0
# 8  Sunny Isles Beach                FL             33160.0  2385000.0   2.0
# 9              Miami                FL             33131.0  2300000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5       JADE SIGNATURE CONDO       2980.0       NaN      2018.0
# 1    3.5  MURANO GRANDE AT PORTOFIN       2974.0       NaN      2003.0
# 2    3.5  BELLAMARE @ WILLIAMS ISLA       3224.0       NaN      2005.0
# 3    2.5  BAL HARBOUR NORTH SOUTH C       1599.0       NaN      2011.0
# 4    3.0  ACQUALINA OCEAN RESIDENCE       2214.0       NaN      2006.0
# 5    2.5            ONE OCEAN CONDO       2505.0       NaN      2016.0
# 6    3.0            KEY COLONY NO 1       2169.0       NaN      1978.0
# 7    3.5           JADE OCEAN CONDO       1956.0       NaN      2009.0
# 8    2.0        18975 COLLINS CONDO       1296.0       NaN      2020.0
# 9    3.5   TWO TEQUESTA POINT CONDO       2520.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1669.0     5630.0   Sold
# 1             NaN         1471.0     4144.0   Sold
# 2             NaN         1146.0     4033.0   Sold
# 3             NaN         1954.0     3205.0   Sold
# 4             NaN         1310.0     4123.0   Sold
# 5             NaN         1158.0     6100.0   Sold
# 6             NaN         1176.0     2323.0   Sold
# 7             NaN         1222.0     2918.0   Sold
# 8             NaN         1840.0     2130.0   Sold
# 9             NaN          913.0     2194.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11561742
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...  MARMLS  A11640687
# 2  https://www.redfin.com/FL/Aventura/6000-Island...  MARMLS  A11637287
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...  MARMLS  A11521311
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11649633
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...  MARMLS  A11348761
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...  MARMLS  A11653306
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...  MARMLS  A11659012
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  MARMLS  A11663453
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...  MARMLS  A11663478
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.932764 -80.121036
# 1        N          Y  25.772744 -80.140607
# 2        N          Y  25.942761 -80.135433
# 3        N          Y  25.889270 -80.122909
# 4        N          Y  25.941257 -80.120772
# 5        N          Y  25.769375 -80.133358
# 6        N          Y  25.696814 -80.158094
# 7        N          Y  25.934401 -80.121005
# 8        N          Y  25.951740 -80.119755
# 9        N          Y  25.768790 -80.183330
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Sunny-Isles-Beach/16...     Marcelo Violland
# 1  https://www.redfin.com/FL/Miami-Beach/400-Alto...           Dean Bloch
# 2  https://www.redfin.com/FL/Aventura/6000-Island...      Richard Goihman
# 3  https://www.redfin.com/FL/Bal-Harbour/9705-Col...         Mariana Niro
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/17...                 None
# 5  https://www.redfin.com/FL/Miami-Beach/1-Collin...         Kathrin Rein
# 6  https://www.redfin.com/FL/Key-Biscayne/201-Cra...        Carla Datorre
# 7  https://www.redfin.com/FL/Sunny-Isles-Beach/17...          Luz Spriggs
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Stephanie Penaranda
# 9  https://www.redfin.com/FL/Miami/808-Brickell-K...       Jenny Gonzalez
#
#                       list_broker_name_1 list_agent_name_2  \
# 0     Prime International Associates Inc              None
# 1                        Douglas Elliman              None
# 2                        Douglas Elliman              None
# 3                                Serhant              None
# 4                                   None              None
# 5     Keller Williams Miami Beach Realty              None
# 6                   Datorre Realty Group              None
# 7           Keller Williams Eagle Realty              None
# 8  All in One International Realty, LLC.              None
# 9                  Engel & Völkers Miami      Rocio Useche
#
#       list_broker_name_2    buy_agent_name_1            buy_broker_name_1  \
# 0                   None  Jose Augusto Nunes           Algebra Realty.com
# 1                   None       David Vazquez              Douglas Elliman
# 2                   None          Joel Matus  Williams Island Realty, LLC
# 3                   None        Mariana Niro                      Serhant
# 4                   None                None                         None
# 5                   None        Julian Cohen              Douglas Elliman
# 6                   None       Birgit Lahaye       Coldwell Banker Realty
# 7                   None        Nei Andreani  Miami Realty Solution Group
# 8                   None     Ludmila Bogatov               Bogatov Realty
# 9  Engel & Völkers Miami   Gisela Cacciamani              BHHS EWM Realty
#
#     buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0  Yorghi Abad Mitre    Algebra Realty.com     1  orange
# 1               None                  None     2    blue
# 2               None                  None     3    blue
# 3      Victor Harary  Compass Florida, LLC     4    blue
# 4               None                  None     5    blue
# 5               None                  None     6    blue
# 6               None                  None     7    blue
# 7               None                  None     8    blue
# 8               None                  None     9    blue
# 9               None                  None    10    blue
#
#                                            FULL_NAME
# 0  JADE SIGNATURE CONDO at 16901 Collins Ave #901...
# 1  MURANO GRANDE AT PORTOFIN at 400 Alton Rd #280...
# 2  BELLAMARE @ WILLIAMS ISLA at 6000 Island Blvd ...
# 3  BAL HARBOUR NORTH SOUTH C at 9705 Collins Ave ...
# 4  ACQUALINA OCEAN RESIDENCE at 17875 Collins Ave...
# 5  ONE OCEAN CONDO at 1 Collins Ave #204 in Miami...
# 6  KEY COLONY NO 1 at 201 Crandon Blvd #900 in Ke...
# 7  JADE OCEAN CONDO at 17121 Collins Ave #901 in ...
# 8  18975 COLLINS CONDO at 18975 Collins Ave #5205...
# 9  TWO TEQUESTA POINT CONDO at 808 Brickell Key D...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 8, 13) ## List (Earlier) date
date2 = datetime(2024, 10, 30) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 78

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")

# %%
chart_df
# Out:
#    SOLD DATE                                       ADDRESS       PRICE BEDS  \
# 0 2024-10-31   16901 Collins Ave #901 in Sunny Isles Beach  $4,975,000    4
# 1 2024-10-30             400 Alton Rd #2804 in Miami Beach  $4,375,000    3
# 2 2024-10-30            6000 Island Blvd #2103 in Aventura  $3,695,000    4
# 3 2024-11-01     9705 Collins Ave Unit 805N in Bal Harbour  $3,125,000    2
# 4 2024-10-29  17875 Collins Ave #3305 in Sunny Isles Beach  $2,900,000    3
# 5 2024-10-31             1 Collins Ave #204 in Miami Beach  $2,900,000    3
# 6 2024-11-04         201 Crandon Blvd #900 in Key Biscayne  $2,550,000    3
# 7 2024-11-01   17121 Collins Ave #901 in Sunny Isles Beach  $2,390,000    3
# 8 2024-11-01  18975 Collins Ave #5205 in Sunny Isles Beach  $2,385,000    2
# 9 2024-10-30            808 Brickell Key Dr #1904 in Miami  $2,300,000    3
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET  SOURCE       MLS#  \
# 0    5.5       2,980       2018        $1,669  MARMLS  A11561742
# 1    3.5       2,974       2003        $1,471  MARMLS  A11640687
# 2    3.5       3,224       2005        $1,146  MARMLS  A11637287
# 3    2.5       1,599       2011        $1,954  MARMLS  A11521311
# 4    3.0       2,214       2006        $1,310  MARMLS  A11649633
# 5    2.5       2,505       2016        $1,158  MARMLS  A11348761
# 6    3.0       2,169       1978        $1,176  MARMLS  A11653306
# 7    3.5       1,956       2009        $1,222  MARMLS  A11659012
# 8    2.0       1,296       2020        $1,840  MARMLS  A11663453
# 9    3.5       2,520       1998          $913  MARMLS  A11663478
#
#                                         LISTING INFO  \
# 0  Marcelo Violland Prime International Associate...
# 1                     Dean Bloch Douglas Elliman
# 2                Richard Goihman Douglas Elliman
# 3                           Mariana Niro Serhant
# 4
# 5  Kathrin Rein Keller Williams Miami Beach Realt...
# 6             Carla Datorre Datorre Realty Group
# 7       Luz Spriggs Keller Williams Eagle Realty
# 8  Stephanie Penaranda All in One International R...
# 9  Jenny Gonzalez Engel & Völkers Miami Rocio Use...
#
#                                          BUYING INFO
# 0  Jose Augusto Nunes Algebra Realty.com Yorghi A...
# 1                  David Vazquez Douglas Elliman
# 2         Joel Matus Williams Island Realty, LLC
# 3  Mariana Niro Serhant Victor Harary Compass Flo...
# 4
# 5                   Julian Cohen Douglas Elliman
# 6           Birgit Lahaye Coldwell Banker Realty
# 7       Nei Andreani Miami Realty Solution Group
# 8                 Ludmila Bogatov Bogatov Realty
# 9              Gisela Cacciamani BHHS EWM Realty
