# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_Sep_2023.csv')

# %%
len(df)
# Out:
# 518

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'])

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Data Stuff

# %%
first_month = 9

# %%
# # Count number of earliest month dates
# sep_dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

# print(f'Number of September dates: {sep_dates_count}')

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
# create new column and assign colors based on month
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'red' if x.month == first_month else 'red' if x.month == second_month else 'blue' if x.month == third_month else '')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_27257/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 297

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format('August')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_red = folium.FeatureGroup(name='August') ## 

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'red':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    else:
        continue

# Add the FeatureGroups to the map
fg_red.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2d85e935b9281d882b512b7e823f60e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;August&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2d85e935b9281d882b512b7e823f60e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f2d85e935b9281d882b512b7e823f60e = L.map(
#                 &quot;map_f2d85e935b9281d882b512b7e823f60e&quot;,
#                 {
#                     center: [41.812905752901024, -87.73613009488055],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_662b4541149cf4f9137a17c374b088d6 = L.featureGroup(
#                 {}
#             ).addTo(map_f2d85e935b9281d882b512b7e823f60e);
#
#
#             var circle_marker_5b149fbf41359ba356d1772aa99e9a2e = L.circleMarker(
#                 [42.087905, -88.14407],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_662b4541149cf4f9137a17c374b088d6);
#
#
#         var popup_65c8ffa5e2fe1c1bd9a52fc145050728 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_80f21c7e22a7994dacfd38670ec18b0e = $(`&lt;div id=&quot;html_80f21c7e22a7994dacfd38670ec18b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;LAXMI PROP LLC TERRA VITA BARRINGTON LOT&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;ERANKI VIJAY&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;01-26-406-014-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;17 TERRA VITA CT, SOUTH BARRINGTON&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$265,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_65c8ffa5e2fe1c1bd9a52fc145050728.setContent(html_80f21c7e22a7994dacfd38670ec18b0e);
#
#
#
#         circle_marker_5b149fbf41359ba356d1772aa99e9a2e.bindPopup(popup_65c8ffa5e2fe1c1bd9a52fc145050728)
#         ;
#
#
#
#
#             var circle_marker_c5c43db4e2ec6d6bf6f43b359b7ccc60 = L.circleMarker(
#                 [42.0116691, -87.6730899],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_662b4541149cf4f9137a17c374b088d6);
#
#
#         var popup_bb11c11108e476229f80da372e595481 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b1a812793b1d4c820d7bd3bc32324b39 = $(`&lt;div id=&quot;html_b1a812793b1d4c820d7bd3bc32324b39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;GOLBERT CHARLES P GDN&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;DAVIS PHILLIP EST&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;11-31-202-030-1002&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;1716 W ESTES AVE, CHICAGO&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;NA&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_bb11c11108e476229f80da372e595481.setContent(html_b1a812793b1d4c820d7bd3bc32324b39);
#
#
#
#         circle_marker_c5c43db4e2ec6d6bf6f43b359b7ccc60.bindPopup(popup_bb11c11108e476229f80da372e595481)
#         ;
#
#
#
#
#             var circle_marker_ea115ab980680eb8ec2ed5d162174606 = L.circleMarker(
#                 [41.741597, -87.8209018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_662b4541149cf4f9137a17c374b088d6);
#
#
#         var popup_24e7823394a276f356b7a96e6ea6eb05 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3d66dccb1afff9e584e35feec201ffa0 = $(`&lt;div id=&quot;html_3d66dccb1afff9e584e35feec201ffa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;WILMINGTON SAV FUND SOC

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_september_2023

# %% [markdown]
# ## Stats for story

# %%
df['mortgage_amount_int'] = df['mortgage_amount'].str.replace('$','')
df['mortgage_amount_int'] = df['mortgage_amount_int'].str.replace(',','')
df = df.loc[df['mortgage_amount_int'] != 'NA']
df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)

# %%
# Count number of first month dates
sep_dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

print(f'Number of September dates: {sep_dates_count}')
# Out:
# Number of September dates: 251

# %%
september = df.loc[df['Doc Recorded'].dt.month == first_month]

# %%
september.reset_index(inplace=True, drop=True)

# %%
september.at[205,'mortgage_amount_int']=96900
september.at[205,'mortgage_amount']='$96,900'

# %%
september.sort_values(by='mortgage_amount_int',ascending=False).head(1)
# Out:
#    View Doc    Doc Number Doc Recorded Doc Executed                 Doc Type
# 16     View  2.327215e+09   2023-09-29    9/28/2023  LIS PENDENS FORECLOSURE  \
#
#     Consi. Amt.                   1st Grantor        1st Grantee
# 16          NaN  ELIZON DB TRANSFER AGENT LLC  1419 PARTNERS LLC  \
#
#      Assoc. Doc#                                          deed_urls  ...
# 16  2.202719e+09  https://crs.cookcountyclerkil.gov/Document/Det...  ...  \
#
#                      Address COLOR
# 16  1419 N WELLS ST, CHICAGO   red  \
#
#                                         mortgage_urls mortgage_amount
# 16  https://crs.cookcountyclerkil.gov/Document/Det...  $10,400,000.00  \
#
#                                  geo_address
# 16  1419 N WELLS ST, CHICAGO Cook County, IL  \
#
#                             geocoded       lat        lon
# 16  (41.9083501, -87.63424549999999)  41.90835 -87.634245  \
#
#     mortgage_amount_int  205
# 16           10400000.0  NaN
#
# [1 rows x 21 columns]

# %%
print(september['mortgage_urls'].iloc[16])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=MzE2MTY1NTI1&hId=ZDRkMDAzODc1NjBkZWE3NTYwNDc4MjU1OGU1ZmFiZGE0MzViOTAyM2NlNWJlYmU5ODQ1MTEyMmRiNzgwZTAzZA2

# %%
print(f'September: ${september.mortgage_amount_int.sum():,}')
# Out:
# September: $80,026,582.0

# %%
# August
29 + 9
# Out:
# 38

# %%
september['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# US BK TRUST NATL ASSN TR                    29
# NEWREZ LLC                                  19
# WILMINGTON SAV FUND SOC FSB TR              11
# US BK NATL ASSN TR                           9
# WELLS FARGO BK NA                            9
# LOANDEPOTCOM LLC                             8
# GITSIT SOLUTIONS LLC                         8
# JPMORGAN CHASE BK NATL ASSN                  7
# BMO BK NA                                    7
# CARRINGTON MTG SERVICES LLC                  6
# MORTGAGE ASSETS MGMT LLC                     5
# HUNTINGTON NATL BK                           5
# ROCKET MTG LLC                               4
# LAKEVIEW LOAN SERVICING LLC                  4
# MCLP ASSET CO INC                            4
# BMO HARRIS BK NA                             4
# US BK NATL ASSN                              4
# CITIBANK NA TR                               3
# ARVEST BK                                    3
# OLD NATL BK                                  3
# F ST INVESTMENTS LLC                         2
# SLEEP AGAIN I TRUST                          2
# LIMA ONE CAP LLC                             2
# METROPOLITAN LIFE INST CO                    2
# CROSSCOUNTRY MTG LLC                         2
# WILMINGTON TRUST NATL ASSN TR                2
# COMMUNITY LOAN SERVICING LLC                 2
# BANK OF NEW YORK MELLON TR                   2
# LONGBRIDGE FIN LLC                           2
# SELENE FIN LP                                2
# TOORAK CAP PARTNERS LLC                      2
# MATRIX FIN SERVICES CORP                     2
# CITIMORTGAGE INC                             2
# CIVIC REAL ESTATE HOLDINGS III LLC           2
# GROUNDFLOOR PROP GA LLC                      2
# FIRST AMER BK                                2
# U S BK NATL ASSN TR                          1
# FINANCE OF AMER REVERSE LLC                  1
# FEDERAL HOME LOAN MTG CORP TR                1
# U S BK TRUST NATL ASSN TR                    1
# TVC MTG TRUST 2020-RTL1                      1
# SPECIALIZED LOAN SERVICING LLC               1
# JP MORGAN MTG ACQ CORP                       1
# LOANCARE LLC                                 1
# CONSUMERS CU                                 1
# FREEDOM MTG CORP                             1
# CALIBER HOME LOANS INC                       1
# LAXMI PROP LLC TERRA VITA BARRINGTON LOT     1
# ALIGNED STREETS LLC                          1
# CREDIT UNION 1                               1
# COMMUNITY LOAN SERVICING                     1
# LOAN FUNDER LLC SERIES 22789                 1
# LARISA RAPPAPORT TRUST                       1
# FLAGSTAR BK NA                               1
# NUMARK CU                                    1
# WATERMAN BK                                  1
# SHELLPOINT MTG SERVICING                     1
# FTF LENDG LLC                                1
# HHI LL JV I TRUST                            1
# ANCHOR STONE FUND 2 LLC                      1
# Name: count, dtype: int64

# %%
september['1st Grantee'].value_counts()
# Out:
# 1st Grantee
# BLACK SQ REAL ESTATE INC                          3
# DORETHA WARD ENTERPRISES LLC                      2
# UNKNOWN                                           2
# CHICAGO TITLE LAND TRUST CO TR                    2
# DEVOIL SOLUTIONS LLC                              2
#                                                  ..
# PROFESSIONALLY AFFORDABLE HOMES LLC - SERIES 1    1
# ABRON ALONZO                                      1
# TEENY TURNER LLC                                  1
# MCCUAN MARIBETH                                   1
# DEMIRDJIAN ROUPEN STEVEN                          1
# Name: count, Length: 244, dtype: int64

# %%
df.to_csv('september_2023_foreclosures.csv')

# %%
# apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
print(f"September median mortgage foreclosure amount: ${september['mortgage_amount_int'].median():,}")
# Out:
# September median mortgage foreclosure amount: $171,845.0

# %% [markdown]
# ## Boundary Analysis

# %%
boundaries = gpd.read_file('Boundaries - Neighborhoods.geojson')

# %%
# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(september['lon'], august['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_august = gpd.GeoDataFrame(august, geometry=geometry)

gdf_filings_august.crs = 'EPSG:4326'
gdf_filings_august = gdf_filings_august.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_august = gpd.sjoin(gdf_filings_august, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# %%
counts_august['count'].sum()
