# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Mar. 23rd Mar. 30th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 1  PAST SALE  March-28-2025   Condo/Co-op  525 S Flagler Dr Unit Gph3
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    4.5  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11076071         N          Y  26.708413 -80.051135
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Palm Beach County

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-03-28    32
# 2025-03-27    26
# 2025-03-24    23
# 2025-03-25    22
# 2025-03-26    16
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 115  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1    PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 10   PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 4    PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 42   PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 69   PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 91   PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 38   PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 37   PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9    PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 115       Palm Beach                FL             33480.0  7405000.0   3.0
# 1    West Palm Beach                FL             33401.0  7240000.0   3.0
# 10        Palm Beach                FL             33480.0  4300000.0   2.0
# 4            Jupiter                FL             33477.0  3150000.0   3.0
# 42        Palm Beach                FL             33480.0  2620000.0   3.0
# 69        Palm Beach                FL             33480.0  2025000.0   2.0
# 91     Riviera Beach                FL             33404.0  1625000.0   2.0
# 38   West Palm Beach                FL             33405.0  1500000.0   2.0
# 37   West Palm Beach                FL             33405.0  1500000.0   2.0
# 9         Boca Raton                FL             33434.0  1400000.0   3.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 115    3.5  ...   Sold                         NaN                       NaN
# 1      4.5  ...   Sold                         NaN                       NaN
# 10     3.0  ...   Sold                         NaN                       NaN
# 4      2.5  ...   Sold                         NaN                       NaN
# 42     2.5  ...   Sold                         NaN                       NaN
# 69     2.0  ...   Sold                         NaN                       NaN
# 91     2.5  ...   Sold                         NaN                       NaN
# 38     2.0  ...   Sold                         NaN                       NaN
# 37     2.0  ...   Sold                         NaN                       NaN
# 9      3.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 115  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
# 1    https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 10   https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 4    https://www.redfin.com/FL/Jupiter/382-Spyglass...  Beaches MLS
# 42   https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...  Beaches MLS
# 69   https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 91   https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 38   https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 37   https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 9    https://www.redfin.com/FL/Boca-Raton/19710-Saw...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 115  RX-10979308         N          Y  26.719588 -80.036274
# 1    RX-11076071         N          Y  26.708413 -80.051135
# 10   RX-11052747         N          Y  26.720485 -80.041578
# 4    RX-11066007         N          Y  26.911561 -80.088739
# 42   RX-11040354         N          Y  26.601768 -80.037184
# 69   RX-11034978         N          Y  26.715571 -80.042932
# 91   RX-10999043         N          Y  26.785118 -80.033251
# 38   RX-11045888         N          Y  26.676376 -80.049253
# 37   RX-11045891         N          Y  26.676376 -80.049253
# 9    RX-11060085         N          Y  26.387868 -80.157099
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1  PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 2  PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 3  PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 4  PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 5  PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 6  PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 7  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 8  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9  PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Palm Beach                FL             33480.0  7405000.0   3.0
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
# 2       Palm Beach                FL             33480.0  4300000.0   2.0
# 3          Jupiter                FL             33477.0  3150000.0   3.0
# 4       Palm Beach                FL             33480.0  2620000.0   3.0
# 5       Palm Beach                FL             33480.0  2025000.0   2.0
# 6    Riviera Beach                FL             33404.0  1625000.0   2.0
# 7  West Palm Beach                FL             33405.0  1500000.0   2.0
# 8  West Palm Beach                FL             33405.0  1500000.0   2.0
# 9       Boca Raton                FL             33434.0  1400000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    3.5  ... -80.036274  https://www.redfin.com/FL/Palm-Beach/130-Sunri...
# 1    4.5  ... -80.051135  https://www.redfin.com/FL/West-Palm-Beach/525-...
# 2    3.0  ... -80.041578  https://www.redfin.com/FL/Palm-Beach/150-Bradl...
# 3    2.5  ... -80.088739  https://www.redfin.com/FL/Jupiter/382-Spyglass...
# 4    2.5  ... -80.037184  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...
# 5    2.0  ... -80.042932  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...
# 6    2.5  ... -80.033251  https://www.redfin.com/FL/Riviera-Beach/2700-N...
# 7    2.0  ... -80.049253  https://www.redfin.com/FL/West-Palm-Beach/3901...
# 8    2.0  ... -80.049253  https://www.redfin.com/FL/West-Palm-Beach/3901...
# 9    3.0  ... -80.157099  https://www.redfin.com/FL/Boca-Raton/19710-Saw...
#
#        list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0  Jennifer Stepan Beqaj           Linda R. Olsson, Inc.       Linda Olsson
# 1           Linda Olsson           Linda R. Olsson, Inc.               None
# 2        Christian Angle     Christian Angle Real Estate               None
# 3         Thomas Frankel     Admirals Cove Realty Co Inc     Allan Meyerson
# 4         Donald Gorbach                  Gorbach Realty               None
# 5          Liza Pulitzer      Brown Harris Stevens of PB      Austin McGurk
# 6        Vincent Marotta  Illustrated Properties LLC (Co               None
# 7            Jason Shinn         Triple Crown Properties        Ethan Shinn
# 8            Jason Shinn         Triple Crown Properties        Ethan Shinn
# 9           Janice Gates            Boca West Realty LLC      Jeffrie Stern
#
#             list_broker_name_2   buy_agent_name_1  \
# 0        Linda R. Olsson, Inc.   Spencer Schlager
# 1                         None      Lori Cronican
# 2                         None    Christian Angle
# 3  Admirals Cove Realty Co Inc     Thomas Frankel
# 4                         None       Daniel Calvo
# 5   Brown Harris Stevens of PB  Michele Vasilescu
# 6                         None      Dermot OBrien
# 7      Triple Crown Properties     Jessica Julian
# 8      Triple Crown Properties     Jessica Julian
# 9         Boca West Realty LLC        Ellen Klein
#
#               buy_broker_name_1      buy_agent_name_2  buy_broker_name_2
# 0               Douglas Elliman                  None               None
# 1               Douglas Elliman  Christopher Cronican    Douglas Elliman
# 2   Christian Angle Real Estate                  None               None
# 3   Admirals Cove Realty Co Inc                  None               None
# 4                    CGI Realty                  None               None
# 5    Illustrated Properties LLC                  None               None
# 6  Sotheby's Intl. Realty, Inc.                  None               None
# 7               Douglas Elliman                  None               None
# 8               Douglas Elliman                  None               None
# 9           Compass Florida LLC                  None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 119

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $595,957

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $390

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $70,918,909

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          119              595957          390                     70918909.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 118
# -----------
# Input Previous Week Condo Average Sales Price:
# 527811
# -----------
# Input Previous Week Condo Average PSF:
# 304
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 62281725.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS        CITY  \
# 0  PAST SALE 2025-03-27   Condo/Co-op  130 Sunrise Ave Ph - 5  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33480.0  7405000.0   3.0    3.5
#
#                                      LOCATION  SQUARE FEET  LOT SIZE  \
# 0  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
#
#       list_broker_name_1 list_agent_name_2     list_broker_name_2  \
# 0  Linda R. Olsson, Inc.      Linda Olsson  Linda R. Olsson, Inc.
#
#    buy_agent_name_1 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0  Spencer Schlager   Douglas Elliman             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1  PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 2  PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 3  PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 4  PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 5  PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 6  PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 7  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 8  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9  PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Palm Beach                FL             33480.0  7405000.0   3.0
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
# 2       Palm Beach                FL             33480.0  4300000.0   2.0
# 3          Jupiter                FL             33477.0  3150000.0   3.0
# 4       Palm Beach                FL             33480.0  2620000.0   3.0
# 5       Palm Beach                FL             33480.0  2025000.0   2.0
# 6    Riviera Beach                FL             33404.0  1625000.0   2.0
# 7  West Palm Beach                FL             33405.0  1500000.0   2.0
# 8  West Palm Beach                FL             33405.0  1500000.0   2.0
# 9       Boca Raton                FL             33434.0  1400000.0   3.0
#
#    BATHS                                    LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
# 1    4.5             Plaza OF The Palm Beaches Condo       3841.0       NaN
# 2    3.0                   Palm Beach Biltmore Condo       1508.0       NaN
# 3    2.5                               Admirals Cove       2440.0       NaN
# 4    2.5                Meridian OF Palm Beach Condo       2550.0       NaN
# 5    2.0                     Palm Beach Towers Condo       1272.0       NaN
# 6    2.5                      2700 North Ocean Condo       1725.0       NaN
# 7    2.0                Harbor Towers & Marina Condo       1178.0       NaN
# 8    2.0                Harbor Towers & Marina Condo       1178.0     150.0
# 9    3.0                                  Peppertree       2080.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
# 1      1986.0             NaN         1885.0     5589.0   Sold
# 2      1926.0             NaN         2851.0     3559.0   Sold
# 3      1988.0             NaN         1291.0     2353.0   Sold
# 4      1981.0             NaN         1027.0     3225.0   Sold
# 5      1956.0             NaN         1592.0     2208.0   Sold
# 6      2008.0             NaN          942.0     1737.0   Sold
# 7      1986.0             NaN         1273.0     1544.0   Sold
# 8      1986.0             NaN         1273.0     1544.0   Sold
# 9      1980.0             NaN          673.0     1232.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...  Beaches MLS
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
# 1  RX-11076071        N          Y  26.708413 -80.051135
# 2  RX-11052747        N          Y  26.720485 -80.041578
# 3  RX-11066007        N          Y  26.911561 -80.088739
# 4  RX-11040354        N          Y  26.601768 -80.037184
# 5  RX-11034978        N          Y  26.715571 -80.042932
# 6  RX-10999043        N          Y  26.785118 -80.033251
# 7  RX-11045888        N          Y  26.676376 -80.049253
# 8  RX-11045891        N          Y  26.676376 -80.049253
# 9  RX-11060085        N          Y  26.387868 -80.157099
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...           Linda Olsson
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...        Christian Angle
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...         Thomas Frankel
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...         Donald Gorbach
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Liza Pulitzer
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...        Vincent Marotta
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...           Janice Gates
#
#                list_broker_name_1 list_agent_name_2  \
# 0           Linda R. Olsson, Inc.      Linda Olsson
# 1           Linda R. Olsson, Inc.              None
# 2     Christian Angle Real Estate              None
# 3     Admirals Cove Realty Co Inc    Allan Meyerson
# 4                  Gorbach Realty              None
# 5      Brown Harris Stevens of PB     Austin McGurk
# 6  Illustrated Properties LLC (Co              None
# 7         Triple Crown Properties       Ethan Shinn
# 8         Triple Crown Properties       Ethan Shinn
# 9            Boca West Realty LLC     Jeffrie Stern
#
#             list_broker_name_2   buy_agent_name_1  \
# 0        Linda R. Olsson, Inc.   Spencer Schlager
# 1                         None      Lori Cronican
# 2                         None    Christian Angle
# 3  Admirals Cove Realty Co Inc     Thomas Frankel
# 4                         None       Daniel Calvo
# 5   Brown Harris Stevens of PB  Michele Vasilescu
# 6                         None      Dermot OBrien
# 7      Triple Crown Properties     Jessica Julian
# 8      Triple Crown Properties     Jessica Julian
# 9         Boca West Realty LLC        Ellen Klein
#
#               buy_broker_name_1      buy_agent_name_2 buy_broker_name_2  RANK  \
# 0               Douglas Elliman                  None              None     1
# 1               Douglas Elliman  Christopher Cronican   Douglas Elliman     2
# 2   Christian Angle Real Estate                  None              None     3
# 3   Admirals Cove Realty Co Inc                  None              None     4
# 4                    CGI Realty                  None              None     5
# 5    Illustrated Properties LLC                  None              None     6
# 6  Sotheby's Intl. Realty, Inc.                  None              None     7
# 7               Douglas Elliman                  None              None     8
# 8               Douglas Elliman                  None              None     9
# 9           Compass Florida LLC                  None              None    10
#
#     COLOR
# 0  orange
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# 5    blue
# 6    blue
# 7    blue
# 8    blue
# 9    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d12f322c53480044b693ab86d7eb094 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Mar. 23rd — Mar. 30th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d12f322c53480044b693ab86d7eb094&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2d12f322c53480044b693ab86d7eb094 = L.map(
#                 &quot;map_2d12f322c53480044b693ab86d7eb094&quot;,
#                 {
#                     center: [26.569846853333335, -80.09972398333335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_bd079cc0c46760de30c302f727f82686 = L.featureGroup(
#                 {}
#             ).addTo(map_2d12f322c53480044b693ab86d7eb094);
#
#
#             var marker_11825b734cd2bcb5ea5621fa47146d0a = L.marker(
#                 [26.7195877, -80.0362736],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_bd079cc0c46760de30c302f727f82686);
#
#
#             var icon_ecedbed4125f7bac56f0ad08219f4793 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_11825b734cd2bcb5ea5621fa47146d0a.setIcon(icon_ecedbed4125f7bac56f0ad08219f4793);
#
#
#         var popup_7f44a4c7fec1d94902bb4276959d7313 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_916725abd2e49f73cac135bae07d9409 = $(`&lt;div id=&quot;html_916725abd2e49f73cac135bae07d9409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;130 Sunrise Ave Ph - 5&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,405,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,968.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,495.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1977.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_7f44a4c7fec1d94902bb4276959d7313.setContent(html_916725abd2e49f73cac135bae07d9409);
#
#
#
#         marker_11825b734cd2bcb5ea5621fa47146d0a.bindPopup(popup_7f44a4c7fec1d94902bb4276959d7313)
#         ;
#
#
#
#
#             var feature_group_95dc5a51931f20371e8433369dbd1fe2 = L.featureGroup(
#                 {}
#             ).addTo(map_2d12f322c53480044b693ab86d7eb094);
#
#
#             var marker_c15c5a6e51769dfef8fbd88cb0833f1d = L.marker(
#                 [26.708413, -80.0511347],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_95dc5a51931f20371e8433369dbd1fe2);
#
#
#             var icon_6a2c137c3a7cc9a1a4f393311e724086 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c15c5a6e51769dfef8fbd88cb0833f1d.setIcon(icon_6a2c137c3a7cc9a1a4f393311e724086);
#
#
#         var popup_78d10610ca604ac395779902cad94aee = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_e4b446f08a478a3f5bfa5135bc0922a9 = $(`&lt;div id=&quot;html_e4b446f08a478a3f5bfa5135bc0922a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;525 S Flagler Dr Unit Gph3&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,240,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,885.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,841.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1986.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_78d10610ca604ac395779902cad94aee.setContent(html_e4b446f08a478a3f5bfa5135bc0922a9);
#
#
#
#         marker_c15c5a6e51769dfef8fbd88cb0833f1d.bindPopup(popup_78d10610ca604ac395779902cad94aee)
#         ;
#
#
#
#
#             var marker_ea89196bf0a8894f9cc0258d1f008ad4 = L.marker(
#                 [26.7204848, -80.0415784],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_95dc5a51931f20371e8433369dbd1fe2);
#
#
#             var icon_3e11ae1aa418aefc37cf857193994d32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea89196bf0a8894f9cc0258d1f008ad4.setIcon(icon_3e11ae1aa418aefc37cf857193994d32);
#
#
#         var popup_4f2b7a46b91adb2dfdf431a181babea0 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_c3062aa7a1d29885356254a

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS        CITY  \
# 0  PAST SALE 2025-03-27   Condo/Co-op  130 Sunrise Ave Ph - 5  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33480.0  7405000.0   3.0    3.5
#
#                                      LOCATION  SQUARE FEET  LOT SIZE  \
# 0  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
#
#       list_broker_name_1 list_agent_name_2     list_broker_name_2  \
# 0  Linda R. Olsson, Inc.      Linda Olsson  Linda R. Olsson, Inc.
#
#    buy_agent_name_1 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0  Spencer Schlager   Douglas Elliman             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_03312024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Sun And Surf One Hundred And Thirty Condos at 130 Sunrise Ave Ph - 5 in Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1  PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 2  PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 3  PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 4  PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 5  PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 6  PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 7  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 8  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9  PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Palm Beach                FL             33480.0  7405000.0   3.0
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
# 2       Palm Beach                FL             33480.0  4300000.0   2.0
# 3          Jupiter                FL             33477.0  3150000.0   3.0
# 4       Palm Beach                FL             33480.0  2620000.0   3.0
# 5       Palm Beach                FL             33480.0  2025000.0   2.0
# 6    Riviera Beach                FL             33404.0  1625000.0   2.0
# 7  West Palm Beach                FL             33405.0  1500000.0   2.0
# 8  West Palm Beach                FL             33405.0  1500000.0   2.0
# 9       Boca Raton                FL             33434.0  1400000.0   3.0
#
#    BATHS                                    LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
# 1    4.5             Plaza OF The Palm Beaches Condo       3841.0       NaN
# 2    3.0                   Palm Beach Biltmore Condo       1508.0       NaN
# 3    2.5                               Admirals Cove       2440.0       NaN
# 4    2.5                Meridian OF Palm Beach Condo       2550.0       NaN
# 5    2.0                     Palm Beach Towers Condo       1272.0       NaN
# 6    2.5                      2700 North Ocean Condo       1725.0       NaN
# 7    2.0                Harbor Towers & Marina Condo       1178.0       NaN
# 8    2.0                Harbor Towers & Marina Condo       1178.0     150.0
# 9    3.0                                  Peppertree       2080.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
# 1      1986.0             NaN         1885.0     5589.0   Sold
# 2      1926.0             NaN         2851.0     3559.0   Sold
# 3      1988.0             NaN         1291.0     2353.0   Sold
# 4      1981.0             NaN         1027.0     3225.0   Sold
# 5      1956.0             NaN         1592.0     2208.0   Sold
# 6      2008.0             NaN          942.0     1737.0   Sold
# 7      1986.0             NaN         1273.0     1544.0   Sold
# 8      1986.0             NaN         1273.0     1544.0   Sold
# 9      1980.0             NaN          673.0     1232.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...  Beaches MLS
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
# 1  RX-11076071        N          Y  26.708413 -80.051135
# 2  RX-11052747        N          Y  26.720485 -80.041578
# 3  RX-11066007        N          Y  26.911561 -80.088739
# 4  RX-11040354        N          Y  26.601768 -80.037184
# 5  RX-11034978        N          Y  26.715571 -80.042932
# 6  RX-10999043        N          Y  26.785118 -80.033251
# 7  RX-11045888        N          Y  26.676376 -80.049253
# 8  RX-11045891        N          Y  26.676376 -80.049253
# 9  RX-11060085        N          Y  26.387868 -80.157099
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...           Linda Olsson
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...        Christian Angle
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...         Thomas Frankel
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...         Donald Gorbach
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Liza Pulitzer
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...        Vincent Marotta
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...           Janice Gates
#
#                list_broker_name_1 list_agent_name_2  \
# 0           Linda R. Olsson, Inc.      Linda Olsson
# 1           Linda R. Olsson, Inc.              None
# 2     Christian Angle Real Estate              None
# 3     Admirals Cove Realty Co Inc    Allan Meyerson
# 4                  Gorbach Realty              None
# 5      Brown Harris Stevens of PB     Austin McGurk
# 6  Illustrated Properties LLC (Co              None
# 7         Triple Crown Properties       Ethan Shinn
# 8         Triple Crown Properties       Ethan Shinn
# 9            Boca West Realty LLC     Jeffrie Stern
#
#             list_broker_name_2   buy_agent_name_1  \
# 0        Linda R. Olsson, Inc.   Spencer Schlager
# 1                         None      Lori Cronican
# 2                         None    Christian Angle
# 3  Admirals Cove Realty Co Inc     Thomas Frankel
# 4                         None       Daniel Calvo
# 5   Brown Harris Stevens of PB  Michele Vasilescu
# 6                         None      Dermot OBrien
# 7      Triple Crown Properties     Jessica Julian
# 8      Triple Crown Properties     Jessica Julian
# 9         Boca West Realty LLC        Ellen Klein
#
#               buy_broker_name_1      buy_agent_name_2 buy_broker_name_2  RANK  \
# 0               Douglas Elliman                  None              None     1
# 1               Douglas Elliman  Christopher Cronican   Douglas Elliman     2
# 2   Christian Angle Real Estate                  None              None     3
# 3   Admirals Cove Realty Co Inc                  None              None     4
# 4                    CGI Realty                  None              None     5
# 5    Illustrated Properties LLC                  None              None     6
# 6  Sotheby's Intl. Realty, Inc.                  None              None     7
# 7               Douglas Elliman                  None              None     8
# 8               Douglas Elliman                  None              None     9
# 9           Compass Florida LLC                  None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Sun And Surf One Hundred And Thirty Condos at ...
# 1    blue  Plaza OF The Palm Beaches Condo at 525 S Flagl...
# 2    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #4...
# 3    blue       Admirals Cove at 382 Spyglass Way in Jupiter
# 4    blue  Meridian OF Palm Beach Condo at 3300 S Ocean B...
# 5    blue  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 7    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 8    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 9    blue  Peppertree at 19710 Sawgrass Dr #3301 in Boca ...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Sun And Surf One Hundred And Thirty Condos closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,400,000 to $7,405,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Riviera Beach, Boca Raton, Jupiter, Palm Beach, West Palm Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 119 condo sales totaling $70,918,909 million from Mar. 23rd to Mar. 30th. The previous week, brokers closed 118 condo sales totaling $62,281,725.
#
# Last week’s units sold for an average of $595,957, higher than the $527,811 average price from the previous week. The average price per square foot rose to $390 from $304, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,400,000.0 million to $7,405,000.0 million.
#
# Sun And Surf One Hundred And Thirty Condos at 130 Sunrise Ave Ph - 5 in Palm Beach took the top spot with a $7,405,000.0 million closing. The sale closed at $2,968.0 per square foot.
#
# Jennifer Stepan Beqaj with Linda R. Olsson, Inc., and Linda Olsson with Linda R. Olsson, Inc. had the listing.
# Spencer Schlager with Douglas Elliman, and None with None represented the buyer.
#
# Plaza OF The Palm Beaches Condo at 525 S Flagler Dr Unit Gph3 in West Palm Beach, closed for the second highest amount, $7,240,000.0, or $1,885.0 per square foot.
#
# Linda Olsson with Linda R. Olsson, Inc., and None with None had the listing.
# Lori Cronican with Douglas Elliman, and Christopher Cronican with Douglas Elliman represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_03312024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 23rd to Mar. 30th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1  PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 2  PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 3  PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 4  PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 5  PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 6  PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 7  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 8  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9  PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Palm Beach                FL             33480.0  7405000.0   3.0
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
# 2       Palm Beach                FL             33480.0  4300000.0   2.0
# 3          Jupiter                FL             33477.0  3150000.0   3.0
# 4       Palm Beach                FL             33480.0  2620000.0   3.0
# 5       Palm Beach                FL             33480.0  2025000.0   2.0
# 6    Riviera Beach                FL             33404.0  1625000.0   2.0
# 7  West Palm Beach                FL             33405.0  1500000.0   2.0
# 8  West Palm Beach                FL             33405.0  1500000.0   2.0
# 9       Boca Raton                FL             33434.0  1400000.0   3.0
#
#    BATHS                                    LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
# 1    4.5             Plaza OF The Palm Beaches Condo       3841.0       NaN
# 2    3.0                   Palm Beach Biltmore Condo       1508.0       NaN
# 3    2.5                               Admirals Cove       2440.0       NaN
# 4    2.5                Meridian OF Palm Beach Condo       2550.0       NaN
# 5    2.0                     Palm Beach Towers Condo       1272.0       NaN
# 6    2.5                      2700 North Ocean Condo       1725.0       NaN
# 7    2.0                Harbor Towers & Marina Condo       1178.0       NaN
# 8    2.0                Harbor Towers & Marina Condo       1178.0     150.0
# 9    3.0                                  Peppertree       2080.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
# 1      1986.0             NaN         1885.0     5589.0   Sold
# 2      1926.0             NaN         2851.0     3559.0   Sold
# 3      1988.0             NaN         1291.0     2353.0   Sold
# 4      1981.0             NaN         1027.0     3225.0   Sold
# 5      1956.0             NaN         1592.0     2208.0   Sold
# 6      2008.0             NaN          942.0     1737.0   Sold
# 7      1986.0             NaN         1273.0     1544.0   Sold
# 8      1986.0             NaN         1273.0     1544.0   Sold
# 9      1980.0             NaN          673.0     1232.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...  Beaches MLS
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
# 1  RX-11076071        N          Y  26.708413 -80.051135
# 2  RX-11052747        N          Y  26.720485 -80.041578
# 3  RX-11066007        N          Y  26.911561 -80.088739
# 4  RX-11040354        N          Y  26.601768 -80.037184
# 5  RX-11034978        N          Y  26.715571 -80.042932
# 6  RX-10999043        N          Y  26.785118 -80.033251
# 7  RX-11045888        N          Y  26.676376 -80.049253
# 8  RX-11045891        N          Y  26.676376 -80.049253
# 9  RX-11060085        N          Y  26.387868 -80.157099
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...           Linda Olsson
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...        Christian Angle
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...         Thomas Frankel
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...         Donald Gorbach
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Liza Pulitzer
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...        Vincent Marotta
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...           Janice Gates
#
#                list_broker_name_1 list_agent_name_2  \
# 0           Linda R. Olsson, Inc.      Linda Olsson
# 1           Linda R. Olsson, Inc.              None
# 2     Christian Angle Real Estate              None
# 3     Admirals Cove Realty Co Inc    Allan Meyerson
# 4                  Gorbach Realty              None
# 5      Brown Harris Stevens of PB     Austin McGurk
# 6  Illustrated Properties LLC (Co              None
# 7         Triple Crown Properties       Ethan Shinn
# 8         Triple Crown Properties       Ethan Shinn
# 9            Boca West Realty LLC     Jeffrie Stern
#
#             list_broker_name_2   buy_agent_name_1  \
# 0        Linda R. Olsson, Inc.   Spencer Schlager
# 1                         None      Lori Cronican
# 2                         None    Christian Angle
# 3  Admirals Cove Realty Co Inc     Thomas Frankel
# 4                         None       Daniel Calvo
# 5   Brown Harris Stevens of PB  Michele Vasilescu
# 6                         None      Dermot OBrien
# 7      Triple Crown Properties     Jessica Julian
# 8      Triple Crown Properties     Jessica Julian
# 9         Boca West Realty LLC        Ellen Klein
#
#               buy_broker_name_1      buy_agent_name_2 buy_broker_name_2  RANK  \
# 0               Douglas Elliman                  None              None     1
# 1               Douglas Elliman  Christopher Cronican   Douglas Elliman     2
# 2   Christian Angle Real Estate                  None              None     3
# 3   Admirals Cove Realty Co Inc                  None              None     4
# 4                    CGI Realty                  None              None     5
# 5    Illustrated Properties LLC                  None              None     6
# 6  Sotheby's Intl. Realty, Inc.                  None              None     7
# 7               Douglas Elliman                  None              None     8
# 8               Douglas Elliman                  None              None     9
# 9           Compass Florida LLC                  None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Sun And Surf One Hundred And Thirty Condos at ...
# 1    blue  Plaza OF The Palm Beaches Condo at 525 S Flagl...
# 2    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #4...
# 3    blue       Admirals Cove at 382 Spyglass Way in Jupiter
# 4    blue  Meridian OF Palm Beach Condo at 3300 S Ocean B...
# 5    blue  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 7    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 8    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 9    blue  Peppertree at 19710 Sawgrass Dr #3301 in Boca ...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Sun And Surf One Hundred And Thirty Condos closing tops Palm Beach County weekly condo sales
# DEK: Top 10 sales ranged from $1,400,000 to $7,405,000
# FEATURED HED:
# SEO HED: Palm Beach County County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach County, weekly condo sales, Riviera Beach, Boca Raton, Jupiter, Palm Beach, West Palm Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County County’s NEWS PEG HERE.
#
# Brokers closed 119 condo sales totaling $70,918,909 million from Mar. 23rd to Mar. 30th. The previous week, brokers closed 118 condo sales totaling $62,281,725.
#
# Last week’s units sold for an average of $595,957, higher than the $527,811 average price from the previous week. The average price per square foot rose to $390 from $304, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,400,000.0 million to $7,405,000.0 million.
#
# Sun And Surf One Hundred And Thirty Condos at 130 Sunrise Ave Ph - 5 in Palm Beach took the top spot with a $7,405,000.0 million closing. The sale closed at $2,968.0 per square foot.
#
# Jennifer Stepan Beqaj with Linda R. Olsson, Inc., and Linda Olsson with Linda R. Olsson, Inc. had the listing.
# Spencer Schlager with Douglas Elliman, and None with None represented the buyer.
#
# Plaza OF The Palm Beaches Condo at 525 S Flagler Dr Unit Gph3 in West Palm Beach, closed for the second highest amount, $7,240,000.0, or $1,885.0 per square foot.
#
# Linda Olsson with Linda R. Olsson, Inc., and None with None had the listing.
# Lori Cronican with Douglas Elliman, and Christopher Cronican with Douglas Elliman represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_03312024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 23rd to Mar. 30th:
#
# Most Expensive
# Sun And Surf One Hundred And Thirty Condos, 130 Sunrise Ave Ph - 5, in Palm Beach | Price: $7,405,000 | $2,968 psf | Listing agents: Jennifer Stepan Beqaj with Linda R. Olsson, Inc. and Linda Olsson with Linda R. Olsson, Inc. | Buyer's agents: Spencer Schlager with Douglas Elliman and None with None
#
# Least Expensive
# Peppertree, 19710 Sawgrass Dr #3301, in Boca Raton | Price: $1,400,000 | $673 psf | Listing agents: Janice Gates with Boca West Realty LLC and Jeffrie Stern with Boca West Realty LLC | Buyer's agents: Ellen Klein with Compass Florida LLC and None with None
#
# Highest Price Per Square Foot
# Sun And Surf One Hundred And Thirty Condos, 130 Sunrise Ave Ph - 5, in Palm Beach | Price: $7,405,000 | $2,968 psf | Listing agents: Jennifer Stepan Beqaj with Linda R. Olsson, Inc. and Linda Olsson with Linda R. Olsson, Inc. | Buyer's agents: Spencer Schlager with Douglas Elliman and None with None
#
# Lowest Price Per Square Foot
# Peppertree, 19710 Sawgrass Dr #3301, in Boca Raton | Price: $1,400,000 | $673 psf | Listing agents: Janice Gates with Boca West Realty LLC and Jeffrie Stern with Boca West Realty LLC | Buyer's agents: Ellen Klein with Compass Florida LLC and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Palm-Beach/130-Sunrise-Ave-33480/unit-5/home/42437720
# Second priciest sale:  https://www.redfin.com/FL/West-Palm-Beach/525-S-Flagler-Dr-33401/unit-Gph3/home/195194603
# Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/19710-Sawgrass-Dr-33434/unit-3301/home/42246006
# Second Cheapest top ten sale:  https://www.redfin.com/FL/West-Palm-Beach/3901-S-Flagler-Dr-33405/unit-903/home/42521858
# Highest top ten psf:  https://www.redfin.com/FL/Palm-Beach/130-Sunrise-Ave-33480/unit-5/home/42437720
# Lowest top ten psf:  https://www.redfin.com/FL/Boca-Raton/19710-Sawgrass-Dr-33434/unit-3301/home/42246006

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Palm-Beach/130-Sunrise-Ave-33480/unit-5/home/42437720

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/525-S-Flagler-Dr-33401/unit-Gph3/home/195194603

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/19710-Sawgrass-Dr-33434/unit-3301/home/42246006

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/West-Palm-Beach/3901-S-Flagler-Dr-33405/unit-903/home/42521858

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Palm-Beach/130-Sunrise-Ave-33480/unit-5/home/42437720

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/19710-Sawgrass-Dr-33434/unit-3301/home/42246006

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-03-27   Condo/Co-op       130 Sunrise Ave Ph - 5
# 1  PAST SALE 2025-03-28   Condo/Co-op   525 S Flagler Dr Unit Gph3
# 2  PAST SALE 2025-03-25   Condo/Co-op          150 Bradley Pl #408
# 3  PAST SALE 2025-03-27   Condo/Co-op             382 Spyglass Way
# 4  PAST SALE 2025-03-25   Condo/Co-op  3300 S Ocean Blvd Unit 508s
# 5  PAST SALE 2025-03-24   Condo/Co-op    44 Cocoanut Row Unit 221b
# 6  PAST SALE 2025-03-25   Condo/Co-op  2700 N Ocean Dr Unit 1506 B
# 7  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #503
# 8  PAST SALE 2025-03-25   Condo/Co-op       3901 S Flagler Dr #903
# 9  PAST SALE 2025-03-28   Condo/Co-op      19710 Sawgrass Dr #3301
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Palm Beach                FL             33480.0  7405000.0   3.0
# 1  West Palm Beach                FL             33401.0  7240000.0   3.0
# 2       Palm Beach                FL             33480.0  4300000.0   2.0
# 3          Jupiter                FL             33477.0  3150000.0   3.0
# 4       Palm Beach                FL             33480.0  2620000.0   3.0
# 5       Palm Beach                FL             33480.0  2025000.0   2.0
# 6    Riviera Beach                FL             33404.0  1625000.0   2.0
# 7  West Palm Beach                FL             33405.0  1500000.0   2.0
# 8  West Palm Beach                FL             33405.0  1500000.0   2.0
# 9       Boca Raton                FL             33434.0  1400000.0   3.0
#
#    BATHS                                    LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5  Sun And Surf One Hundred And Thirty Condos       2495.0       NaN
# 1    4.5             Plaza OF The Palm Beaches Condo       3841.0       NaN
# 2    3.0                   Palm Beach Biltmore Condo       1508.0       NaN
# 3    2.5                               Admirals Cove       2440.0       NaN
# 4    2.5                Meridian OF Palm Beach Condo       2550.0       NaN
# 5    2.0                     Palm Beach Towers Condo       1272.0       NaN
# 6    2.5                      2700 North Ocean Condo       1725.0       NaN
# 7    2.0                Harbor Towers & Marina Condo       1178.0       NaN
# 8    2.0                Harbor Towers & Marina Condo       1178.0     150.0
# 9    3.0                                  Peppertree       2080.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1977.0             NaN         2968.0     4513.0   Sold
# 1      1986.0             NaN         1885.0     5589.0   Sold
# 2      1926.0             NaN         2851.0     3559.0   Sold
# 3      1988.0             NaN         1291.0     2353.0   Sold
# 4      1981.0             NaN         1027.0     3225.0   Sold
# 5      1956.0             NaN         1592.0     2208.0   Sold
# 6      2008.0             NaN          942.0     1737.0   Sold
# 7      1986.0             NaN         1273.0     1544.0   Sold
# 8      1986.0             NaN         1273.0     1544.0   Sold
# 9      1980.0             NaN          673.0     1232.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Beaches MLS
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...  Beaches MLS
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...  Beaches MLS
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10979308        N          Y  26.719588 -80.036274
# 1  RX-11076071        N          Y  26.708413 -80.051135
# 2  RX-11052747        N          Y  26.720485 -80.041578
# 3  RX-11066007        N          Y  26.911561 -80.088739
# 4  RX-11040354        N          Y  26.601768 -80.037184
# 5  RX-11034978        N          Y  26.715571 -80.042932
# 6  RX-10999043        N          Y  26.785118 -80.033251
# 7  RX-11045888        N          Y  26.676376 -80.049253
# 8  RX-11045891        N          Y  26.676376 -80.049253
# 9  RX-11060085        N          Y  26.387868 -80.157099
#
#                                                  url      list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/130-Sunri...  Jennifer Stepan Beqaj
# 1  https://www.redfin.com/FL/West-Palm-Beach/525-...           Linda Olsson
# 2  https://www.redfin.com/FL/Palm-Beach/150-Bradl...        Christian Angle
# 3  https://www.redfin.com/FL/Jupiter/382-Spyglass...         Thomas Frankel
# 4  https://www.redfin.com/FL/Palm-Beach/3300-S-Oc...         Donald Gorbach
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...          Liza Pulitzer
# 6  https://www.redfin.com/FL/Riviera-Beach/2700-N...        Vincent Marotta
# 7  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 8  https://www.redfin.com/FL/West-Palm-Beach/3901...            Jason Shinn
# 9  https://www.redfin.com/FL/Boca-Raton/19710-Saw...           Janice Gates
#
#                list_broker_name_1 list_agent_name_2  \
# 0           Linda R. Olsson, Inc.      Linda Olsson
# 1           Linda R. Olsson, Inc.              None
# 2     Christian Angle Real Estate              None
# 3     Admirals Cove Realty Co Inc    Allan Meyerson
# 4                  Gorbach Realty              None
# 5      Brown Harris Stevens of PB     Austin McGurk
# 6  Illustrated Properties LLC (Co              None
# 7         Triple Crown Properties       Ethan Shinn
# 8         Triple Crown Properties       Ethan Shinn
# 9            Boca West Realty LLC     Jeffrie Stern
#
#             list_broker_name_2   buy_agent_name_1  \
# 0        Linda R. Olsson, Inc.   Spencer Schlager
# 1                         None      Lori Cronican
# 2                         None    Christian Angle
# 3  Admirals Cove Realty Co Inc     Thomas Frankel
# 4                         None       Daniel Calvo
# 5   Brown Harris Stevens of PB  Michele Vasilescu
# 6                         None      Dermot OBrien
# 7      Triple Crown Properties     Jessica Julian
# 8      Triple Crown Properties     Jessica Julian
# 9         Boca West Realty LLC        Ellen Klein
#
#               buy_broker_name_1      buy_agent_name_2 buy_broker_name_2  RANK  \
# 0               Douglas Elliman                  None              None     1
# 1               Douglas Elliman  Christopher Cronican   Douglas Elliman     2
# 2   Christian Angle Real Estate                  None              None     3
# 3   Admirals Cove Realty Co Inc                  None              None     4
# 4                    CGI Realty                  None              None     5
# 5    Illustrated Properties LLC                  None              None     6
# 6  Sotheby's Intl. Realty, Inc.                  None              None     7
# 7               Douglas Elliman                  None              None     8
# 8               Douglas Elliman                  None              None     9
# 9           Compass Florida LLC                  None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  Sun And Surf One Hundred And Thirty Condos at ...
# 1    blue  Plaza OF The Palm Beaches Condo at 525 S Flagl...
# 2    blue  Palm Beach Biltmore Condo at 150 Bradley Pl #4...
# 3    blue       Admirals Cove at 382 Spyglass Way in Jupiter
# 4    blue  Meridian OF Palm Beach Condo at 3300 S Ocean B...
# 5    blue  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 6    blue  2700 North Ocean Condo at 2700 N Ocean Dr Unit...
# 7    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 8    blue  Harbor Towers & Marina Condo at 3901 S Flagler...
# 9    blue  Peppertree at 19710 Sawgrass Dr #3301 in Boca ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 4, 18) ## List (Earlier) date
date2 = datetime(2025, 3, 27) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 343

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    2968.0
# 1    1885.0
# 2    2851.0
# 3    1291.0
# 4    1027.0
# 5    1592.0
# 6     942.0
# 7    1273.0
# 8    1273.0
# 9     673.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                        ADDRESS       PRICE BEDS  \
# 0 2025-03-27           130 Sunrise Ave Ph - 5 in Palm Beach  $7,405,000    3
# 1 2025-03-28  525 S Flagler Dr Unit Gph3 in West Palm Beach  $7,240,000    3
# 2 2025-03-25              150 Bradley Pl #408 in Palm Beach  $4,300,000    2
# 3 2025-03-27                    382 Spyglass Way in Jupiter  $3,150,000    3
# 4 2025-03-25      3300 S Ocean Blvd Unit 508s in Palm Beach  $2,620,000    3
# 5 2025-03-24        44 Cocoanut Row Unit 221b in Palm Beach  $2,025,000    2
# 6 2025-03-25   2700 N Ocean Dr Unit 1506 B in Riviera Beach  $1,625,000    2
# 7 2025-03-25      3901 S Flagler Dr #503 in West Palm Beach  $1,500,000    2
# 8 2025-03-25      3901 S Flagler Dr #903 in West Palm Beach  $1,500,000    2
# 9 2025-03-28          19710 Sawgrass Dr #3301 in Boca Raton  $1,400,000    3
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3.5       2,495       1977        $2,968  Beaches MLS  RX-10979308
# 1    4.5       3,841       1986        $1,885  Beaches MLS  RX-11076071
# 2    3.0       1,508       1926        $2,851  Beaches MLS  RX-11052747
# 3    2.5       2,440       1988        $1,291  Beaches MLS  RX-11066007
# 4    2.5       2,550       1981        $1,027  Beaches MLS  RX-11040354
# 5    2.0       1,272       1956        $1,592  Beaches MLS  RX-11034978
# 6    2.5       1,725       2008          $942  Beaches MLS  RX-10999043
# 7    2.0       1,178       1986        $1,273  Beaches MLS  RX-11045888
# 8    2.0       1,178       1986        $1,273  Beaches MLS  RX-11045891
# 9    3.0       2,080       1980          $673  Beaches MLS  RX-11060085
#
#                                         LISTING INFO  \
# 0  Jennifer Stepan Beqaj Linda R. Olsson, Inc. Li...
# 1             Linda Olsson Linda R. Olsson, Inc.
# 2    Christian Angle Christian Angle Real Estate
# 3  Thomas Frankel Admirals Cove Realty Co Inc All...
# 4                  Donald Gorbach Gorbach Realty
# 5  Liza Pulitzer Brown Harris Stevens of PB Austi...
# 6  Vincent Marotta Illustrated Properties LLC (Co...
# 7  Jason Shinn Triple Crown Properties Ethan Shin...
# 8  Jason Shinn Triple Crown Properties Ethan Shin...
# 9  Janice Gates Boca West Realty LLC Jeffrie Ster...
#
#                                          BUYING INFO
# 0               Spencer Schlager Douglas Elliman
# 1  Lori Cronican Douglas Elliman Christopher Cron...
# 2    Christian Angle Christian Angle Real Estate
# 3     Thomas Frankel Admirals Cove Realty Co Inc
# 4                        Daniel Calvo CGI Realty
# 5   Michele Vasilescu Illustrated Properties LLC
# 6     Dermot OBrien Sotheby's Intl. Realty, Inc.
# 7                 Jessica Julian Douglas Elliman
# 8                 Jessica Julian Douglas Elliman
# 9                Ellen Klein Compass Florida LLC
