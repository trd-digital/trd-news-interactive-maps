# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 27th Jun. 3rd

# %%
filename = glob.glob('redfin*.csv')
filename = filename[0]

# %%
df = pd.read_csv(filename)
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]
df = df.sort_values(by='PRICE',ascending=False)
df_top_ten = df.head(10)

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 152

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $830,170

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $582

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $126,185,900

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# # Define the date range
# start_date = '2024-05-20'
# end_date = '2024-05-26'

# # Filter rows where 'SOLD DATE' is within the specified range
# second_week_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
print(len(second_week_df))
# Out:
# 63

# %%
second_week_df['PRICE'].mean()
# Out:
# 225502.50793650793

# %%
second_week_df['$/SQUARE FEET'].mean()
# Out:
# 292.1166666666667

# %%
pd.set_option('display.max_rows',None)

# %%
second_week_df.sort_values(by='PRICE',ascending=False)
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                           ADDRESS  \
# 21   PAST SALE 2024-05-24   Condo/Co-op             6746 SW 115th Ct #205
# 96   PAST SALE 2024-05-24   Condo/Co-op       9857 SW 138th Ave Unit EC1L
# 113  PAST SALE 2024-05-24   Condo/Co-op          4560 NW 79th Ave Unit 1E
# 194  PAST SALE 2024-05-21   Condo/Co-op       6215 Kendale Lakes Cir #267
# 236  PAST SALE 2024-05-20   Condo/Co-op       3301 N Country Club Dr #702
# 120  PAST SALE 2024-05-23   Condo/Co-op                 250 181st Dr #304
# 231  PAST SALE 2024-05-24   Condo/Co-op      8205 SW 152nd Ave Unit F-110
# 90   PAST SALE 2024-05-24   Condo/Co-op           7145 Miami Lks Unit R19
# 166  PAST SALE 2024-05-24   Condo/Co-op        10395 N Kendall Dr Unit V8
# 182  PAST SALE 2024-05-22   Condo/Co-op               8075 NW 7th St #111
# 214  PAST SALE 2024-05-22   Condo/Co-op            18001 Collins Ave #508
# 217  PAST SALE 2024-05-24   Condo/Co-op              7705 Abbott Ave #305
# 92   PAST SALE 2024-05-21   Condo/Co-op         1950 W 56th St Unit 2304B
# 188  PAST SALE 2024-05-23   Condo/Co-op       210 Fontainebleau Blvd #411
# 186  PAST SALE 2024-05-24   Condo/Co-op           10875 SW 112th Ave #114
# 195  PAST SALE 2024-05-24   Condo/Co-op               2620 W 76th St #201
# 13   PAST SALE 2024-05-21   Condo/Co-op                501 SW 1st St #412
# 213  PAST SALE 2024-05-23   Condo/Co-op            10985 SW 107th St #115
# 110  PAST SALE 2024-05-22   Condo/Co-op      11111 Biscayne Blvd Unit 10B
# 213             NaN          344.0      398.0   Sold
# 110             NaN          138.0     2230.0   Sold
# 135             NaN          315.0      151.0   Sold
# 227             NaN          190.0      595.0   Sold
# 118             NaN          258.0      362.0   Sold
# 228             NaN          226.0      361.0   Sold
# 164             NaN          232.0      527.0   Sold
# 97              NaN          585.0      502.0   Sold
# 193             NaN          184.0     2070.0   Sold
# 100             NaN          276.0      275.0   Sold
# 101             NaN          541.0      382.0   Sold
# 67              NaN          376.0      264.0   Sold
# 58              NaN          230.0      305.0   Sold
# 62              NaN          317.0      369.0   Sold
# 105             NaN          297.0      366.0   Sold
# 89              NaN          196.0      697.0   Sold
# 126             NaN          388.0      408.0   Sold
# 157             NaN          235.0      381.0   Sold
# 158             NaN          232.0      380.0   Sold
# 23              NaN          555.0      511.0   Sold
# 225             NaN          289.0      541.0   Sold
# 136             NaN          310.0      439.0   Sold
# 168             NaN          478.0     1260.0   Sold
# 52              NaN          230.0      775.0   Sold
# 210             NaN          196.0      681.0   Sold
# 162             NaN          228.0      523.0   Sold
# 14              NaN          176.0      504.0   Sold
# 72              NaN          461.0      432.0   Sold
# 59              NaN          281.0      338.0   Sold
# 125             NaN          334.0      199.0   Sold
# 39              NaN          279.0      530.0   Sold
# 16              NaN            NaN      460.0   Sold
# 81              NaN          181.0      448.0   Sold
# 57              NaN          238.0      335.0   Sold
# 60              NaN          262.0      137.0   Sold
# 145             NaN          416.0      379.0   Sold
# 86              NaN            NaN      200.0   Sold
# 56              NaN          638.0     1746.0   Sold
# 191             NaN          133.0      753.0   Sold
# 192             NaN          239.0      251.0   Sold
# 132             NaN          311.0      308.0   Sold
# 220             NaN          224.0      200.0   Sold
# 54              NaN          189.0      600.0   Sold
# 159             NaN           79.0     2575.0   Sold
# 63              NaN          169.0      445.0   Sold
# 18              NaN           88.0      397.0   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 21                          NaN                       NaN
# 96                          NaN                       NaN
# 113                         NaN                       NaN
# 194                         NaN                       NaN
# 236                         NaN                       NaN
# 120                         NaN                       NaN
# 231                         NaN                       NaN
# 90                          NaN                       NaN
# 166                         NaN                       NaN
# 182                         NaN                       NaN
# 214                         NaN                       NaN
# 217                         NaN                       NaN
# 92                          NaN                       NaN
# 188                         NaN                       NaN
# 186                         NaN                       NaN
# 195                         NaN                       NaN
# 13                          NaN                       NaN
# 213                         NaN                       NaN
# 110                         NaN                       NaN
# 135                         NaN                       NaN
# 227                         NaN                       NaN
# 118                         NaN                       NaN
# 228                         NaN                       NaN
# 164                         NaN                       NaN
# 97                          NaN                       NaN
# 193                         NaN                       NaN
# 100                         NaN                       NaN
# 101                         NaN                       NaN
# 67                          NaN                       NaN
# 58                          NaN                       NaN
# 62                          NaN                       NaN
# 105                         NaN                       NaN
# 89                          NaN                       NaN
# 126                         NaN                       NaN
# 157                         NaN                       NaN
# 158                         NaN                       NaN
# 23                          NaN                       NaN
# 225                         NaN                       NaN
# 136                         NaN                       NaN
# 168                         NaN                       NaN
# 52                          NaN                       NaN
# 210                         NaN                       NaN
# 162                         NaN                       NaN
# 14                          NaN                       NaN
# 72                          NaN                       NaN
# 59                          NaN                       NaN
# 125                         NaN                       NaN
# 39                          NaN                       NaN
# 16                          NaN                       NaN
# 81                          NaN                       NaN
# 57                          NaN                       NaN
# 60                          NaN                       NaN
# 145                         NaN                       NaN
# 86                          NaN                       NaN
# 56                          NaN                       NaN
# 191                         NaN                       NaN
# 192                         NaN                       NaN
# 132                         NaN                       NaN
# 220                         NaN                       NaN
# 54                          NaN                       NaN
# 159                         NaN                       NaN
# 63                          NaN                       NaN
# 18                          NaN                       NaN
#
#                                                    URL       SOURCE  \
# 21   https://www.redfin.com/FL/Miami/6746-SW-115th-...       MARMLS
# 96   https://www.redfin.com/FL/Miami/9857-SW-138th-...       MARMLS
# 113  https://www.redfin.com/FL/Doral/4560-NW-79th-A...       MARMLS
# 194  https://www.redfin.com/FL/Miami/6215-SW-Kendal...       MARMLS
# 236  https://www.redfin.com/FL/Miami/3301-N-Country...       MARMLS
# 120  https://www.redfin.com/FL/Sunny-Isles-Beach/25...       MARMLS
# 231  https://www.redfin.com/FL/Miami/8205-SW-152nd-...       MARMLS
# 90   https://www.redfin.com/FL/Miami-Lakes/7145-Mia...       MARMLS
# 166  https://www.redfin.com/FL/Miami/10395-N-Kendal...       MARMLS
# 182  https://www.redfin.com/FL/Miami/8075-NW-7th-St...       MARMLS
# 214  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 217  https://www.redfin.com/FL/Miami-Beach/7705-Abb...       MARMLS
# 92   https://www.redfin.com/FL/Hialeah/1950-W-56th-...       MARMLS
# 188  https://www.redfin.com/FL/Miami/210-Fontainebl...       MARMLS
# 186  https://www.redfin.com/FL/Miami/10875-SW-112th...       MARMLS
# 195  https://www.redfin.com/FL/Hialeah/2620-W-76th-...       MARMLS
# 13   https://www.redfin.com/FL/Miami/501-SW-1st-St-...       MARMLS
# 213  https://www.redfin.com/FL/Miami/10985-SW-107th...       MARMLS
# 110  https://www.redfin.com/FL/Miami/11111-Biscayne...       MARMLS
# 135  https://www.redfin.com/FL/Miami/546-SW-1st-St-...       MARMLS
# 227  https://www.redfin.com/FL/Miami/601-Ives-Dairy...       MARMLS
# 118  https://www.redfin.com/FL/Hialeah/7420-W-20th-...       MARMLS
# 228  https://www.redfin.com/FL/Hialeah/1350-W-53rd-...       MARMLS
# 164  https://www.redfin.com/FL/Hialeah/6930-Miami-G...       MARMLS
# 97   https://www.redfin.com/FL/Miami-Beach/1005-Mer...       MARMLS
# 193  https://www.redfin.com/FL/North-Miami/2150-San...       MARMLS
# 100  https://www.redfin.com/FL/Homestead/910-Consti...       MARMLS
# 101  https://www.redfin.com/FL/Miami-Beach/1751-Jam...       MARMLS
# 67   https://www.redfin.com/FL/Miami/310-Fontainebl...       MARMLS
# 58   https://www.redfin.com/FL/Hialeah/1890-W-56th-...       MARMLS
# 62   https://www.redfin.com/FL/Miami-Lakes/13920-La...       MARMLS
# 105  https://www.redfin.com/FL/Miami/11195-SW-1st-S...       MARMLS
# 186  A11510571        N          Y  25.667994 -80.370242
# 195  A11504181        N          Y  25.890906 -80.336218
# 13   A11527033        N          Y  25.773107 -80.202987
# 213  A11495102        N          Y  25.669972 -80.373830
# 110  A11518434        N          Y  25.879253 -80.165007
# 135  A11547679        N          Y  25.772670 -80.203720
# 227  A11454538        N          Y  25.959291 -80.190950
# 118  A11537152        N          Y  25.890340 -80.325694
# 228  A11432320        N          Y  25.869902 -80.310265
# 164  A11535927        N          Y  25.941488 -80.315485
# 97   A11565869        N          Y  25.780827 -80.135916
# 193  A11521337        N          Y  25.888402 -80.157471
# 100  A11549128        N          Y  25.460354 -80.464172
# 101  A11563662        N          Y  25.793340 -80.130477
# 67   A11564767        N          Y  25.771622 -80.339718
# 58   A11577606        N          Y  25.872767 -80.320576
# 62   A11550859        N          Y  25.900045 -80.306770
# 105  A11528226        N          Y  25.767685 -80.375943
# 89   A11564132        N          Y  25.865785 -80.125809
# 126  A11526597        N          Y  25.783827 -80.208687
# 157  A11541147        N          Y  25.967545 -80.185692
# 158  A11540715        N          Y  25.966204 -80.187330
# 23   A11561079        N          Y  25.777647 -80.133685
# 225  A11461923        N          Y  25.932790 -80.124335
# 136  A11550435        N          Y  25.687171 -80.412419
# 168  A11536321        N          Y  25.790125 -80.185688
# 52   A11580074        N          Y  25.964125 -80.137952
# 210  A11496603        N          Y  25.452080 -80.438109
# 162  A11529802        N          Y  25.872929 -80.318670
# 14   A11576728        N          Y  25.958554 -80.184130
# 72   A11572247        N          Y  25.780094 -80.135458
# 59   A11562666        N          Y  25.864731 -80.319801
# 125  A11547733        N          Y  25.882162 -80.290742
# 39   A11563964        N          Y  25.862840 -80.319157
# 16   A11569715        N          Y  25.824983 -80.272549
# 81   A11545744        N          Y  25.598210 -80.349457
# 57   A11554283        N          Y  25.582241 -80.376041
# 60   A11563262        N          Y  25.889739 -80.192009
# 145  A11526858        N          Y  25.778233 -80.134716
# 86   F10434500        N          Y  25.824983 -80.272549
# 56   A11556603        N          Y  25.778169 -80.133774
# 191  F10415179        N          Y  25.949923 -80.166133
# 192  A11508436        N          Y  25.937727 -80.207622
# 132  A11535567        N          Y  25.770743 -80.279616
# 220  A11473388        N          Y  25.775799 -80.212393
# 54   A11566713        N          Y  25.923168 -80.206694
# 159  A11521619        N          Y  25.880804 -80.163005
# 63   A11562430        N          Y  25.949213 -80.167412
# 18   A11478679        N          Y  25.898940 -80.187168

# %% [markdown]
# ## Previous Week's Values

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 63
# Input Previous Week Condo Average Sales Price:
# 225503
# Input Previous Week Condo Average PSF:
# 292
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 14206658

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#     SALE TYPE    SOLD DATE PROPERTY TYPE                ADDRESS         CITY  \
# 30  PAST SALE  May-31-2024   Condo/Co-op  800 S Pointe Dr #1104  Miami Beach
#
#    STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 30                FL             33139.0  14400000.0   4.0    3.5
#
#         LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 30  APOGEE CONDO       4154.0       NaN      2008.0             NaN
#
#     $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 30         3467.0     7723.0   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 30                       NaN
#
#                                                   URL  SOURCE       MLS#  \
# 30  https://www.redfin.com/FL/Miami-Beach/800-S-Po...  MARMLS  A11505183
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 30        N          Y  25.768065 -80.136299     1  orange

# %%
def popup_html(row):
    building_name = row['LOCATION']
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff351ea5732078abdb46cc2cf3986bd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 27th - Jun. 3rd&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff351ea5732078abdb46cc2cf3986bd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ff351ea5732078abdb46cc2cf3986bd0 = L.map(
#                 &quot;map_ff351ea5732078abdb46cc2cf3986bd0&quot;,
#                 {
#                     center: [25.81411859934211, -80.21079719539473],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_d8bc99cf76d6a9204d9d0207cae13c12 = L.featureGroup(
#                 {}
#             ).addTo(map_ff351ea5732078abdb46cc2cf3986bd0);
#
#
#             var marker_6f63e0e884e49adaf118d99cf1d4c3f0 = L.marker(
#                 [25.7680651, -80.1362994],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_d8bc99cf76d6a9204d9d0207cae13c12);
#
#
#             var icon_44d1f60fe2a69cb0748eec2effe9d447 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6f63e0e884e49adaf118d99cf1d4c3f0.setIcon(icon_44d1f60fe2a69cb0748eec2effe9d447);
#
#
#         var popup_334c459dc81e6d6f83549df601740a70 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_173bb555d939ada901c5cc3a1c4461c3 = $(`&lt;div id=&quot;html_173bb555d939ada901c5cc3a1c4461c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;APOGEE CONDO&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$14,400,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3,467.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,154.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2008.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_334c459dc81e6d6f83549df601740a70.setContent(html_173bb555d939ada901c5cc3a1c4461c3);
#
#
#
#         marker_6f63e0e884e49adaf118d99cf1d4c3f0.bindPopup(popup_334c459dc81e6d6f83549df601740a70)
#         ;
#
#
#
#
#             var feature_group_e8aa5eddfa2c55314712004cdb5ceab3 = L.featureGroup(
#                 {}
#             ).addTo(map_ff351ea5732078abdb46cc2cf3986bd0);
#
#
#             var marker_c984e02ee60d92cac14fa2235da1a19a = L.marker(
#                 [25.767177, -80.1328155],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_e8aa5eddfa2c55314712004cdb5ceab3);
#
#
#             var icon_6e2002210593cf4de54e35bd0e2027fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c984e02ee60d92cac14fa2235da1a19a.setIcon(icon_6e2002210593cf4de54e35bd0e2027fb);
#
#
#         var popup_a8d57e99a1cecb80d755cb3cfe167a06 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0e10e8a705c3a397e51a0dccc9205415 = $(`&lt;div id=&quot;html_0e10e8a705c3a397e51a0dccc9205415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;CONTINUUM ON SOUTH BEACH&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,750,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,691.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,508.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2002.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_a8d57e99a1cecb80d755cb3cfe167a06.setContent(html_0e10e8a705c3a397e51a0dccc9205415);
#
#
#
#         marker_c984e02ee60d92cac14fa2235da1a19a.bindPopup(popup_a8d57e99a1cecb80d755cb3cfe167a06)
#         ;
#
#
#
#
#             var marker_c0da45571c3a029fc700a7d572f24787 = L.marker(
#                 [25.9400648, -80.1202638],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_e8aa5eddfa2c55314712004cdb5ceab3);
#
#
#             var icon_a1f399cef5b6c6a4b3b569c9ed2c0315 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0da45571c3a029fc700a7d572f24787.setIcon(icon_a1f399cef5b6c6a4b3b569c9ed2c0315);
#
#
#         var popup_76e99151368a7093844c1ba85e7242e3 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_06a28184c29050f3fa46811f5c3a2adb = $(`&lt;div id=&

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#     SALE TYPE    SOLD DATE PROPERTY TYPE                ADDRESS         CITY  \
# 30  PAST SALE  May-31-2024   Condo/Co-op  800 S Pointe Dr #1104  Miami Beach
#
#    STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 30                FL             33139.0  14400000.0   4.0    3.5
#
#         LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 30  APOGEE CONDO       4154.0       NaN      2008.0             NaN
#
#     $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 30         3467.0     7723.0   Sold                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 30                       NaN
#
#                                                   URL  SOURCE       MLS#  \
# 30  https://www.redfin.com/FL/Miami-Beach/800-S-Po...  MARMLS  A11505183
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 30        N          Y  25.768065 -80.136299     1  orange

# %%
# , {df_top_ten[df_top_ten['PRICE'].idxmax()]['ADDRESS']} | Price ${df_top_ten[df_top_ten['PRICE'].idxmax()]['PRICE']:,.0f}

# %%
df_top_ten['PRICE'].iloc[0]
# Out:
# 14400000.0

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_06032024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'APOGEE CONDO at 800 S Pointe Dr #1104 in Miami Beach'

# %%
# previous_week_condo_sales_total = 130_000_000

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
# df_top_ten

# %% [markdown]
# ## RESUME HERE

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops Miami-Dade weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m Miami-Dade County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m Miami-Dade County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #MiamiDade condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, Miami-Dade County, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

Miami-Dade County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} sales average from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: APOGEE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,070,000M to $14,400,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, North Miami Beach, Miami Beach, Sunny Isles Beach, Coconut Grove
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 152 condo sales totaling $126,185,900 million from May. 27th to Jun. 3rd. The previous week, brokers closed 63 condo sales totaling $14,206,658.
#
# Last week’s units sold for an average of $830,170, higher than the $225,503 sales average from the previous week. The average price per square foot rose to $582 from $292, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,070,000.0 million to $14,400,000.0 million.
#
# APOGEE CONDO at 800 S Pointe Dr #1104 in Miami Beach took the top spot with a $14,400,000.0 million closing. The sale closed at $3,467.0 per square foot.
#
# CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #506 in Miami Beach, closed for the second highest amount, $6,750,000.0, or $2,691.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_06032024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 27th to Jun. 3rd:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf")

print(story_checklist)
# Out:
# HED: APOGEE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,070,000M to $14,400,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, North Miami Beach, Miami Beach, Sunny Isles Beach, Coconut Grove
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 152 condo sales totaling $126,185,900 million from May. 27th to Jun. 3rd. The previous week, brokers closed 63 condo sales totaling $14,206,658.
#
# Last week’s units sold for an average of $830,170, higher than the $225,503 sales average from the previous week. The average price per square foot rose to $582 from $292, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,070,000.0 million to $14,400,000.0 million.
#
# APOGEE CONDO at 800 S Pointe Dr #1104 in Miami Beach took the top spot with a $14,400,000.0 million closing. The sale closed at $3,467.0 per square foot.
#
# CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #506 in Miami Beach, closed for the second highest amount, $6,750,000.0, or $2,691.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_06032024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 27th to Jun. 3rd:
#
# Most Expensive
# APOGEE CONDO, 800 S Pointe Dr #1104 in Miami Beach | Price: $14,400,000 | $3,467 psf
# Least Expensive
# MARINA PALMS RESIDENCES S, 17111 Biscayne Blvd #1710 in North Miami Beach | Price: $2,070,000 | $868 psf
# Highest Price Per Square Foot
# APOGEE CONDO, 800 S Pointe Dr #1104 in Miami Beach | Price: $14,400,000 | $3,467 psf
# Lowest Price Per Square Foot
# MARINA PALMS RESIDENCES S, 17111 Biscayne Blvd #1710 in North Miami Beach | Price: $2,070,000 | $868 psf
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Miami-Beach/800-S-Pointe-Dr-33139/unit-1104/home/43398584

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Aventura/17111-Biscayne-Blvd-33160/unit-1710/home/79133394

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/17875-Collins-Ave-33160/unit-3706/home/43362748

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/5775-Collins-Ave-33140/unit-1702/home/178632955

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Bal-Harbour/10295-Collins-Ave-33154/unit-403/home/43449070

# %%
df_top_ten
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE  May-15-2024   Condo/Co-op         50 S Pointe Dr #2201
# 1  PAST SALE  May-15-2024   Condo/Co-op     4701 N Meridian Ave #512
# 2  PAST SALE  May-14-2024   Condo/Co-op      17901 Collins Ave #2403
# 3  PAST SALE  May-17-2024   Condo/Co-op  2811 S Bayshore Dr Unit 15D
# 4  PAST SALE  May-17-2024   Condo/Co-op       5775 Collins Ave #1702
# 5  PAST SALE  May-16-2024   Condo/Co-op      15701 Collins Ave #2601
# 6  PAST SALE  May-10-2024   Condo/Co-op      2901 Collins Ave # 1205
# 7  PAST SALE  May-20-2024   Condo/Co-op      16901 Collins Ave #4305
# 8  PAST SALE  May-15-2024   Condo/Co-op      17875 Collins Ave #3706
# 9  PAST SALE  May-15-2024   Condo/Co-op       10295 Collins Ave #403
#
#                 CITY STATE OR PROVINCE ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL            33139.0  10000000.0   3.0
# 1        Miami Beach                FL            33140.0   8500000.0   4.0
# 2  Sunny Isles Beach                FL            33160.0   7600000.0   4.0
# 3              Miami                FL            33133.0   7200000.0   3.0
# 4        Miami Beach                FL            33140.0   6000000.0   2.0
# 5  Sunny Isles Beach                FL            33160.0   5000000.0   3.0
# 6        Miami Beach                FL              33140   4995000.0   2.0
# 7  Sunny Isles Beach                FL            33160.0   4500000.0   3.0
# 8  Sunny Isles Beach                FL            33160.0   3800000.0   4.0
# 9        Bal Harbour                FL            33154.0   3700000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET LOT SIZE  YEAR BUILT  \
# 0    4.5   CONTINUUM ON SOUTH BEACH       2872.0      NaN      2008.0
# 1    4.5  4701 NORTH MERIDIAN CONDO       4204.0      NaN      2019.0
# 2    5.0       Estates at Acqualina       3287.0      NaN      2022.0
# 3    3.5         C.G.B. SUBDIVISION       2546.0      NaN      2020.0
# 4    3.0  AMD PL OF 2ND OCEAN FRONT       1612.0      NaN      2021.0
# 5    4.5        15701 COLLINS CONDO       3080.0      NaN      2020.0
# 6    2.5                The Edition       1450.0     None      2014.0
# 7    4.5       JADE SIGNATURE CONDO       2639.0      NaN      2018.0
# 8    4.0  ACQUALINA OCEAN RESIDENCE       2736.0      NaN      2006.0
# 9    3.5  10295 COLLINS AVE RESDNTA       3105.0      NaN      2007.0
#
#   DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS NEXT OPEN HOUSE START TIME  \
# 0            NaN         3482.0     4668.0   Sold                        NaN
# 1            NaN         2022.0     9350.0   Sold                        NaN
# 2            NaN         2312.0     6125.0   Sold                        NaN
# 3            NaN         2828.0     5565.0   Sold                        NaN
# 4            NaN         3722.0     4431.0   Sold                        NaN
# 5            NaN         1623.0     4100.0   Sold                        NaN
# 6           None         3445.0        NaN   Sold                         NA
# 7            NaN         1705.0     4616.0   Sold                        NaN
# 8            NaN         1389.0     5190.0   Sold                        NaN
# 9            NaN         1192.0     5101.0   Sold                        NaN
#
#   NEXT OPEN HOUSE END TIME                                                URL  \
# 0                      NaN  https://www.redfin.com/FL/Miami-Beach/50-S-Poi...
# 1                      NaN  https://www.redfin.com/FL/Miami-Beach/4701-N-M...
# 2                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/17...
# 3                      NaN  https://www.redfin.com/FL/Miami/2811-S-Bayshor...
# 4                      NaN  https://www.redfin.com/FL/Miami-Beach/5775-Col...
# 5                      NaN  https://www.redfin.com/FL/North-Miami-Beach/15...
# 6                       NA  https://www.redfin.com/FL/Miami-Beach/2901-Col...
# 7                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/16...
# 8                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/17...
# 9                      NaN  https://www.redfin.com/FL/Bal-Harbour/10295-Co...
#
#          SOURCE       MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK  \
# 0        MARMLS  A11513210        N          Y  25.767875 -80.132756     1
# 1        MARMLS  A11545111        N          Y  25.822813 -80.130733     2
# 2        MARMLS  A11539419        N          Y  25.941881 -80.120417     3
# 3        MARMLS  A11525122        N          Y  25.728751 -80.238013     4
# 4        MARMLS  A11587566        N          Y  25.839257 -80.120395     5
# 5        MARMLS  A11549055        N          Y  25.921979 -80.121703     6
# 6  Manual Entry  A11456329       NA         NA  25.805127 -80.124117     7
# 7        MARMLS  A11431905        N          Y  25.932756 -80.121005     8
# 8        MARMLS  A11527429        N          Y  25.941240 -80.120744     9
# 9        MARMLS  A11530469        N          Y  25.898952 -80.123405    10
#
#     COLOR                                          FULL_NAME
# 0  orange  CONTINUUM ON SOUTH BEACH at 50 S Pointe Dr #22...
# 1    blue  4701 NORTH MERIDIAN CONDO at 4701 N Meridian A...
# 2    blue  Estates at Acqualina at 17901 Collins Ave #240...
# 3    blue  C.G.B. SUBDIVISION at 2811 S Bayshore Dr Unit ...
# 4    blue  AMD PL OF 2ND OCEAN FRONT at 5775 Collins Ave ...
# 5    blue  15701 COLLINS CONDO at 15701 Collins Ave #2601...
# 6    blue  The Edition at 2901 Collins Ave # 1205 in Miam...
# 7    blue  JADE SIGNATURE CONDO at 16901 Collins Ave #430...
# 8    blue  ACQUALINA OCEAN RESIDENCE at 17875 Collins Ave...
# 9    blue  10295 COLLINS AVE RESDNTA at 10295 Collins Ave...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2023, 12, 25) ## List (Earlier) date
date2 = datetime(2024, 5, 31) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 158
