# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Sep. 22nd Sep. 29th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE          SOLD DATE PROPERTY TYPE  \
# 1  PAST SALE  September-30-2024   Condo/Co-op
#
#                            ADDRESS             CITY STATE OR PROVINCE  \
# 1  550 Okeechobee Blvd Unit Uph-02  West Palm Beach                FL
#
#    ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 1             33401.0  1976500.0   3.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-10994622         N          Y  26.705124 -80.056199
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                          ADDRESS  \
# 1   PAST SALE 2024-09-30   Condo/Co-op  550 Okeechobee Blvd Unit Uph-02
# 7   PAST SALE 2024-09-30   Condo/Co-op        4467 Oak Terrace Dr #4467
# 24  PAST SALE 2024-09-30   Condo/Co-op          7738 Lakeside Blvd #346
# 18  PAST SALE 2024-09-30   Condo/Co-op               1611 Bridgewood Dr
# 13  PAST SALE 2024-09-30   Condo/Co-op              110 Gleason St #202
# ..        ...        ...           ...                              ...
# 29  PAST SALE 2024-09-23   Condo/Co-op        550 Okeechobee Blvd #1602
# 21  PAST SALE 2024-09-23   Condo/Co-op         618 Sea Pine Way Unit B1
# 10  PAST SALE 2024-09-23   Condo/Co-op         19663 Boca West Dr #4231
# 9   PAST SALE 2024-09-23   Condo/Co-op        2025 Lavers Cir Unit D101
# 47  PAST SALE 2024-09-23   Condo/Co-op               400 Wilma Cir #301
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 1   West Palm Beach                FL             33401.0  1976500.0   3.0
# 7        Greenacres                FL             33463.0   181875.0   2.0
# 24       Boca Raton                FL             33434.0   287500.0   2.0
# 18       Boca Raton                FL             33434.0   250000.0   2.0
# 13     Delray Beach                FL             33483.0  1837500.0   4.0
# ..              ...               ...                 ...        ...   ...
# 29  West Palm Beach                FL             33401.0  1360000.0   3.0
# 21       Greenacres                FL             33415.0   241000.0   2.0
# 10       Boca Raton                FL             33434.0   430000.0   2.0
# 9      Delray Beach                FL             33444.0   249900.0   1.0
# 47    Riviera Beach                FL             33404.0   210000.0   2.0
#
#     BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1     2.0  ...   Sold                         NaN                       NaN
# 7     2.0  ...   Sold                         NaN                       NaN
# 24    2.0  ...   Sold                         NaN                       NaN
# 18    2.0  ...   Sold                         NaN                       NaN
# 13    3.5  ...   Sold                         NaN                       NaN
# ..    ...  ...    ...                         ...                       ...
# 29    2.0  ...   Sold                         NaN                       NaN
# 21    2.0  ...   Sold                         NaN                       NaN
# 10    2.0  ...   Sold                         NaN                       NaN
# 9     1.0  ...   Sold                         NaN                       NaN
# 47    2.0  ...   Sold                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 1   https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 7   https://www.redfin.com/FL/Greenacres/4467-Oak-...  Beaches MLS
# 24  https://www.redfin.com/FL/Boca-Raton/7738-Lake...  Beaches MLS
# 18  https://www.redfin.com/FL/Boca-Raton/1611-Brid...  Beaches MLS
# 13  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# ..                                                ...          ...
# 29  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 21  https://www.redfin.com/FL/Greenacres/618-Sea-P...  Beaches MLS
# 10  https://www.redfin.com/FL/Boca-Raton/19663-W-B...  Beaches MLS
# 9   https://www.redfin.com/FL/Delray-Beach/2025-La...  Beaches MLS
# 47  https://www.redfin.com/FL/Riviera-Beach/400-Wi...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1   RX-10994622         N          Y  26.705124 -80.056199
# 7   RX-11010790         N          Y  26.609916 -80.139350
# 24  RX-11008830         N          Y  26.379651 -80.165867
# 18  RX-11007123         N          Y  26.373894 -80.164420
# 13  RX-11008404         N          Y  26.459182 -80.061011
# ..          ...       ...        ...        ...        ...
# 29  RX-11008446         N          Y  26.705124 -80.056199
# 21  RX-11015438         N          Y  26.639263 -80.139526
# 10  RX-10999954         N          Y  26.383262 -80.163871
# 9     F10456652         N          Y  26.436711 -80.083163
# 47  RX-10998096         N          Y  26.786439 -80.049871
#
# [93 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 93

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $497,032

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $289

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $46,224,011

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')
# Out:
# Comparison week filtered sales: 54
# -----------
# Comparison week average sales price: $257,589.35
# -----------
# Comparison week average psf: $260.44
# -----------
# Comparison week sales total: $13,909,825.00
# -----------

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input county name:
# Palm Beach
# Input Previous Week Condo Sales Total (number units sold):
# 67
# Input Previous Week Condo Average Sales Price:
# 593041
# Input Previous Week Condo Average PSF:
# 343
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 45_900_000

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS        CITY  \
# 0  PAST SALE 2024-09-27   Condo/Co-op  1000 S Ocean Blvd #505  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  9400000.0   3.0    3.5
#
#              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  One Thousand Ocean       4520.0       NaN      2010.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2080.0     8587.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
#
#                  list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Signature One Luxury Estates LLC              None               None
#
#    buy_agent_name_1 buy_broker_name_1    buy_agent_name_2 buy_broker_name_2  \
# 0  Michael O'Connor   Douglas Elliman  Nicholas Malinosky   Douglas Elliman
#
#    RANK   COLOR
# 0     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                          ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op           1000 S Ocean Blvd #505
# 1  PAST SALE 2024-09-30   Condo/Co-op      3170 S Ocean Blvd Unit S405
# 2  PAST SALE 2024-09-27   Condo/Co-op        44 Cocoanut Row Unit 418b
# 3  PAST SALE 2024-09-30   Condo/Co-op  550 Okeechobee Blvd Unit Uph-02
# 4  PAST SALE 2024-09-30   Condo/Co-op              110 Gleason St #202
# 5  PAST SALE 2024-09-27   Condo/Co-op              1 N Ocean Blvd #303
# 6  PAST SALE 2024-09-24   Condo/Co-op           3450 S Ocean Blvd Ph 3
# 7  PAST SALE 2024-09-23   Condo/Co-op        550 Okeechobee Blvd #1602
# 8  PAST SALE 2024-09-25   Condo/Co-op            550 S Ocean Blvd #509
# 9  PAST SALE 2024-09-27   Condo/Co-op              120 SE 5th Ave #226
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  9400000.0   3.0
# 1       Palm Beach                FL             33480.0  3200000.0   3.0
# 2       Palm Beach                FL             33480.0  2797500.0   2.0
# 3  West Palm Beach                FL             33401.0  1976500.0   3.0
# 4     Delray Beach                FL             33483.0  1837500.0   4.0
# 5       Boca Raton                FL             33432.0  1725000.0   4.0
# 6   Highland Beach                FL             33487.0  1700000.0   3.0
# 7  West Palm Beach                FL             33401.0  1360000.0   3.0
# 8       Boca Raton                FL             33432.0   900000.0   2.0
# 9       Boca Raton                FL             33432.0   812500.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           One Thousand Ocean       4520.0       NaN      2010.0
# 1    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 2    2.0      Palm Beach Towers Condo          NaN       NaN      1956.0
# 3    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 4    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 5    3.5                     Meridian       3129.0       NaN      2007.0
# 6    2.0              Casuarina Condo       2066.0       NaN      1986.0
# 7    2.0  Cityplace South Tower Condo       1709.0       NaN      2008.0
# 8    2.0              Chalfonte Condo       1351.0       NaN      1974.0
# 9    2.0           Mizner Court Condo       1706.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2080.0     8587.0   Sold
# 1             NaN         1085.0     3687.0   Sold
# 2             NaN            NaN        NaN   Sold
# 3             NaN         1231.0     1706.0   Sold
# 4             NaN          873.0     2229.0   Sold
# 5             NaN          551.0     3640.0   Sold
# 6             NaN          823.0     2572.0   Sold
# 7             NaN          796.0     1695.0   Sold
# 8             NaN          666.0     1569.0   Sold
# 9             NaN          476.0     2957.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
# 1  RX-10913354        N          Y  26.605363 -80.037760
# 2  RX-10982741        N          Y  26.716272 -80.043612
# 3  RX-10994622        N          Y  26.705124 -80.056199
# 4  RX-11008404        N          Y  26.459182 -80.061011
# 5  RX-10949933        N          Y  26.350986 -80.070943
# 6  RX-10971118        N          Y  26.413344 -80.065466
# 7  RX-11008446        N          Y  26.705124 -80.056199
# 8  RX-11001697        N          Y  26.344431 -80.070692
# 9  RX-10973151        N          Y  26.348269 -80.076619
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...      Leslie Judge
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Dana Landry
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...   Jonathan Huffer
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...     Judith Lukens
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...     Elliot Koolik
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...         Amy Blake
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...      Jean Cassett
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...        David Hall
#
#                  list_broker_name_1 list_agent_name_2  \
# 0  Signature One Luxury Estates LLC              None
# 1            Illustrated Properties              None
# 2                    Dana E. Landry              None
# 3                Redfin Corporation       Elena Fleck
# 4    Premier Estate Properties, Inc         Kim Lekas
# 5               Compass Florida LLC     Paul Ruthberg
# 6               John P. O'Grady LLC  Kathya Seckinger
# 7               RE/MAX Select Group              None
# 8                    Lang Realty/BR              None
# 9               Compass Florida LLC        Sonia Hall
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None  Michael O'Connor
# 1                            None        Nina Grody
# 2                            None     Austin McGurk
# 3              Redfin Corporation  Andrew Leibowitz
# 4  Premier Estate Properties, Inc    Patricia Burke
# 5             Compass Florida LLC       Robyn Rosen
# 6             John P. O'Grady LLC      Ken Benedict
# 7                            None      Jill Merrell
# 8                            None       Ana Londono
# 9             Compass Florida LLC       John Scalia
#
#                     buy_broker_name_1    buy_agent_name_2  \
# 0                     Douglas Elliman  Nicholas Malinosky
# 1        William Raveis South Florida                None
# 2          Brown Harris Stevens of PB       Liza Pulitzer
# 3    Leibowitz Realty Group, LLC./PBG   Michael Leibowitz
# 4  One Sotheby's International Realty                None
# 5                 Compass Florida LLC                None
# 6      Waterfront Properties & Club C                None
# 7                  The Corcoran Group                None
# 8                      Lang Realty/BR                None
# 9                    EXP Realty, LLC.                None
#
#                   buy_broker_name_2  RANK   COLOR
# 0                   Douglas Elliman     1  orange
# 1                              None     2    blue
# 2        Brown Harris Stevens of PB     3    blue
# 3  Leibowitz Realty Group, LLC./PBG     4    blue
# 4                              None     5    blue
# 5                              None     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1480aca03fe291493aac61a39e269294 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Sep. 22nd - Sep. 29th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1480aca03fe291493aac61a39e269294&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1480aca03fe291493aac61a39e269294 = L.map(
#                 &quot;map_1480aca03fe291493aac61a39e269294&quot;,
#                 {
#                     center: [26.522863888172044, -80.12340390860217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_76b16c2b60f411d50a8c45dc32fef9b6 = L.featureGroup(
#                 {}
#             ).addTo(map_1480aca03fe291493aac61a39e269294);
#
#
#             var marker_e65cb48041d77cf1e2219ca459afc858 = L.marker(
#                 [26.3367207, -80.0714449],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_76b16c2b60f411d50a8c45dc32fef9b6);
#
#
#             var icon_b2da5bdc5b08e2b4df76403a5d884380 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e65cb48041d77cf1e2219ca459afc858.setIcon(icon_b2da5bdc5b08e2b4df76403a5d884380);
#
#
#         var popup_c6e3e147fa6efed2e0230c4afa3b9082 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f265de92189d95e69b9d184d3fba6b2e = $(`&lt;div id=&quot;html_f265de92189d95e69b9d184d3fba6b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1000 S Ocean Blvd #505&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$9,400,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,080.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,520.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2010.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_c6e3e147fa6efed2e0230c4afa3b9082.setContent(html_f265de92189d95e69b9d184d3fba6b2e);
#
#
#
#         marker_e65cb48041d77cf1e2219ca459afc858.bindPopup(popup_c6e3e147fa6efed2e0230c4afa3b9082)
#         ;
#
#
#
#
#             var feature_group_688478e66b1040e8c4e29329657740e2 = L.featureGroup(
#                 {}
#             ).addTo(map_1480aca03fe291493aac61a39e269294);
#
#
#             var marker_38b662b44f278c6f13162aa2c3f1a05c = L.marker(
#                 [26.6053629, -80.0377601],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_688478e66b1040e8c4e29329657740e2);
#
#
#             var icon_d0c65cffd96c6d18967c0d9b01a6fd5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38b662b44f278c6f13162aa2c3f1a05c.setIcon(icon_d0c65cffd96c6d18967c0d9b01a6fd5c);
#
#
#         var popup_976921f0f2b421b336de68c71fb62570 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_4ae08a252af6995fdaa6d18293ab1561 = $(`&lt;div id=&quot;html_4ae08a252af6995fdaa6d18293ab1561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;3170 S Ocean Blvd Unit S405&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,200,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,085.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,950.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1985.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_976921f0f2b421b336de68c71fb62570.setContent(html_4ae08a252af6995fdaa6d18293ab1561);
#
#
#
#         marker_38b662b44f278c6f13162aa2c3f1a05c.bindPopup(popup_976921f0f2b421b336de68c71fb62570)
#         ;
#
#
#
#
#             var marker_1ca557bd34d6d89687640aefd7f41ca2 = L.marker(
#                 [26.7162722, -80.0436118],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_688478e66b1040e8c4e29329657740e2);
#
#
#             var icon_3b3c707e22cffcd01beddf73328c2610 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ca557bd34d6d89687640aefd7f41ca2.setIcon(icon_3b3c707e22cffcd01beddf73328c2610);
#
#
#         var popup_438306ebbc34645686916f18400c7062 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_5ce176fcaffd3ebf91b8cad1d68ef81d =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                 ADDRESS        CITY  \
# 0  PAST SALE 2024-09-27   Condo/Co-op  1000 S Ocean Blvd #505  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  9400000.0   3.0    3.5
#
#              LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  One Thousand Ocean       4520.0       NaN      2010.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2080.0     8587.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
#
#                  list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Signature One Luxury Estates LLC              None               None
#
#    buy_agent_name_1 buy_broker_name_1    buy_agent_name_2 buy_broker_name_2  \
# 0  Michael O'Connor   Douglas Elliman  Nicholas Malinosky   Douglas Elliman
#
#    RANK   COLOR
# 0     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PB_County_condo_sales_week_ending_09302024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'One Thousand Ocean at 1000 S Ocean Blvd #505 in Boca Raton'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                          ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op           1000 S Ocean Blvd #505
# 1  PAST SALE 2024-09-30   Condo/Co-op      3170 S Ocean Blvd Unit S405
# 2  PAST SALE 2024-09-27   Condo/Co-op        44 Cocoanut Row Unit 418b
# 3  PAST SALE 2024-09-30   Condo/Co-op  550 Okeechobee Blvd Unit Uph-02
# 4  PAST SALE 2024-09-30   Condo/Co-op              110 Gleason St #202
# 5  PAST SALE 2024-09-27   Condo/Co-op              1 N Ocean Blvd #303
# 6  PAST SALE 2024-09-24   Condo/Co-op           3450 S Ocean Blvd Ph 3
# 7  PAST SALE 2024-09-23   Condo/Co-op        550 Okeechobee Blvd #1602
# 8  PAST SALE 2024-09-25   Condo/Co-op            550 S Ocean Blvd #509
# 9  PAST SALE 2024-09-27   Condo/Co-op              120 SE 5th Ave #226
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  9400000.0   3.0
# 1       Palm Beach                FL             33480.0  3200000.0   3.0
# 2       Palm Beach                FL             33480.0  2797500.0   2.0
# 3  West Palm Beach                FL             33401.0  1976500.0   3.0
# 4     Delray Beach                FL             33483.0  1837500.0   4.0
# 5       Boca Raton                FL             33432.0  1725000.0   4.0
# 6   Highland Beach                FL             33487.0  1700000.0   3.0
# 7  West Palm Beach                FL             33401.0  1360000.0   3.0
# 8       Boca Raton                FL             33432.0   900000.0   2.0
# 9       Boca Raton                FL             33432.0   812500.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           One Thousand Ocean       4520.0       NaN      2010.0
# 1    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 2    2.0      Palm Beach Towers Condo          NaN       NaN      1956.0
# 3    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 4    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 5    3.5                     Meridian       3129.0       NaN      2007.0
# 6    2.0              Casuarina Condo       2066.0       NaN      1986.0
# 7    2.0  Cityplace South Tower Condo       1709.0       NaN      2008.0
# 8    2.0              Chalfonte Condo       1351.0       NaN      1974.0
# 9    2.0           Mizner Court Condo       1706.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2080.0     8587.0   Sold
# 1             NaN         1085.0     3687.0   Sold
# 2             NaN            NaN        NaN   Sold
# 3             NaN         1231.0     1706.0   Sold
# 4             NaN          873.0     2229.0   Sold
# 5             NaN          551.0     3640.0   Sold
# 6             NaN          823.0     2572.0   Sold
# 7             NaN          796.0     1695.0   Sold
# 8             NaN          666.0     1569.0   Sold
# 9             NaN          476.0     2957.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
# 1  RX-10913354        N          Y  26.605363 -80.037760
# 2  RX-10982741        N          Y  26.716272 -80.043612
# 3  RX-10994622        N          Y  26.705124 -80.056199
# 4  RX-11008404        N          Y  26.459182 -80.061011
# 5  RX-10949933        N          Y  26.350986 -80.070943
# 6  RX-10971118        N          Y  26.413344 -80.065466
# 7  RX-11008446        N          Y  26.705124 -80.056199
# 8  RX-11001697        N          Y  26.344431 -80.070692
# 9  RX-10973151        N          Y  26.348269 -80.076619
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...      Leslie Judge
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Dana Landry
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...   Jonathan Huffer
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...     Judith Lukens
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...     Elliot Koolik
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...         Amy Blake
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...      Jean Cassett
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...        David Hall
#
#                  list_broker_name_1 list_agent_name_2  \
# 0  Signature One Luxury Estates LLC              None
# 1            Illustrated Properties              None
# 2                    Dana E. Landry              None
# 3                Redfin Corporation       Elena Fleck
# 4    Premier Estate Properties, Inc         Kim Lekas
# 5               Compass Florida LLC     Paul Ruthberg
# 6               John P. O'Grady LLC  Kathya Seckinger
# 7               RE/MAX Select Group              None
# 8                    Lang Realty/BR              None
# 9               Compass Florida LLC        Sonia Hall
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None  Michael O'Connor
# 1                            None        Nina Grody
# 2                            None     Austin McGurk
# 3              Redfin Corporation  Andrew Leibowitz
# 4  Premier Estate Properties, Inc    Patricia Burke
# 5             Compass Florida LLC       Robyn Rosen
# 6             John P. O'Grady LLC      Ken Benedict
# 7                            None      Jill Merrell
# 8                            None       Ana Londono
# 9             Compass Florida LLC       John Scalia
#
#                     buy_broker_name_1    buy_agent_name_2  \
# 0                     Douglas Elliman  Nicholas Malinosky
# 1        William Raveis South Florida                None
# 2          Brown Harris Stevens of PB       Liza Pulitzer
# 3    Leibowitz Realty Group, LLC./PBG   Michael Leibowitz
# 4  One Sotheby's International Realty                None
# 5                 Compass Florida LLC                None
# 6      Waterfront Properties & Club C                None
# 7                  The Corcoran Group                None
# 8                      Lang Realty/BR                None
# 9                    EXP Realty, LLC.                None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0                   Douglas Elliman     1  orange
# 1                              None     2    blue
# 2        Brown Harris Stevens of PB     3    blue
# 3  Leibowitz Realty Group, LLC./PBG     4    blue
# 4                              None     5    blue
# 5                              None     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  One Thousand Ocean at 1000 S Ocean Blvd #505 i...
# 1  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 2  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 3  Cityplace South Tower Condo at 550 Okeechobee ...
# 4  Bella Vista Condo at 110 Gleason St #202 in De...
# 5      Meridian at 1 N Ocean Blvd #303 in Boca Raton
# 6  Casuarina Condo at 3450 S Ocean Blvd Ph 3 in H...
# 7  Cityplace South Tower Condo at 550 Okeechobee ...
# 8  Chalfonte Condo at 550 S Ocean Blvd #509 in Bo...
# 9  Mizner Court Condo at 120 SE 5th Ave #226 in B...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: One Thousand Ocean closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $812,500M to $9,400,000M
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Highland Beach, Boca Raton, Palm Beach, West Palm Beach, Delray Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 93 condo sales totaling $46,224,011 million from Sep. 22nd to Sep. 29th. The previous week, brokers closed 67 condo sales totaling $45,900,000.
#
# Last week’s units sold for an average of $497,032, lower than the $593,041 average price from the previous week. The average price per square foot fell to $289 from $343, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $812,500.0 million to $9,400,000.0 million.
#
# One Thousand Ocean at 1000 S Ocean Blvd #505 in Boca Raton took the top spot with a $9,400,000.0 million closing. The sale closed at $2,080.0 per square foot.
#
# Marcy Javor with Signature One Luxury Estates LLC, and None with None had the listing.
# Michael O'Connor with Douglas Elliman, and Nicholas Malinosky with Douglas Elliman represented the buyer.
#
# Enclave OF Palm Beach Condo at 3170 S Ocean Blvd Unit S405 in Palm Beach, closed for the second highest amount, $3,200,000.0, or $1,085.0 per square foot.
#
# Leslie Judge with Illustrated Properties, and None with None had the listing.
# Nina Grody with William Raveis South Florida, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PB_County_condo_sales_week_ending_09302024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 22nd to Sep. 29th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                          ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op           1000 S Ocean Blvd #505
# 1  PAST SALE 2024-09-30   Condo/Co-op      3170 S Ocean Blvd Unit S405
# 2  PAST SALE 2024-09-27   Condo/Co-op        44 Cocoanut Row Unit 418b
# 3  PAST SALE 2024-09-30   Condo/Co-op  550 Okeechobee Blvd Unit Uph-02
# 4  PAST SALE 2024-09-30   Condo/Co-op              110 Gleason St #202
# 5  PAST SALE 2024-09-27   Condo/Co-op              1 N Ocean Blvd #303
# 6  PAST SALE 2024-09-24   Condo/Co-op           3450 S Ocean Blvd Ph 3
# 7  PAST SALE 2024-09-23   Condo/Co-op        550 Okeechobee Blvd #1602
# 8  PAST SALE 2024-09-25   Condo/Co-op            550 S Ocean Blvd #509
# 9  PAST SALE 2024-09-27   Condo/Co-op              120 SE 5th Ave #226
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  9400000.0   3.0
# 1       Palm Beach                FL             33480.0  3200000.0   3.0
# 2       Palm Beach                FL             33480.0  2797500.0   2.0
# 3  West Palm Beach                FL             33401.0  1976500.0   3.0
# 4     Delray Beach                FL             33483.0  1837500.0   4.0
# 5       Boca Raton                FL             33432.0  1725000.0   4.0
# 6   Highland Beach                FL             33487.0  1700000.0   3.0
# 7  West Palm Beach                FL             33401.0  1360000.0   3.0
# 8       Boca Raton                FL             33432.0   900000.0   2.0
# 9       Boca Raton                FL             33432.0   812500.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           One Thousand Ocean       4520.0       NaN      2010.0
# 1    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 2    2.0      Palm Beach Towers Condo          NaN       NaN      1956.0
# 3    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 4    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 5    3.5                     Meridian       3129.0       NaN      2007.0
# 6    2.0              Casuarina Condo       2066.0       NaN      1986.0
# 7    2.0  Cityplace South Tower Condo       1709.0       NaN      2008.0
# 8    2.0              Chalfonte Condo       1351.0       NaN      1974.0
# 9    2.0           Mizner Court Condo       1706.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2080.0     8587.0   Sold
# 1             NaN         1085.0     3687.0   Sold
# 2             NaN            NaN        NaN   Sold
# 3             NaN         1231.0     1706.0   Sold
# 4             NaN          873.0     2229.0   Sold
# 5             NaN          551.0     3640.0   Sold
# 6             NaN          823.0     2572.0   Sold
# 7             NaN          796.0     1695.0   Sold
# 8             NaN          666.0     1569.0   Sold
# 9             NaN          476.0     2957.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
# 1  RX-10913354        N          Y  26.605363 -80.037760
# 2  RX-10982741        N          Y  26.716272 -80.043612
# 3  RX-10994622        N          Y  26.705124 -80.056199
# 4  RX-11008404        N          Y  26.459182 -80.061011
# 5  RX-10949933        N          Y  26.350986 -80.070943
# 6  RX-10971118        N          Y  26.413344 -80.065466
# 7  RX-11008446        N          Y  26.705124 -80.056199
# 8  RX-11001697        N          Y  26.344431 -80.070692
# 9  RX-10973151        N          Y  26.348269 -80.076619
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...      Leslie Judge
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Dana Landry
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...   Jonathan Huffer
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...     Judith Lukens
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...     Elliot Koolik
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...         Amy Blake
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...      Jean Cassett
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...        David Hall
#
#                  list_broker_name_1 list_agent_name_2  \
# 0  Signature One Luxury Estates LLC              None
# 1            Illustrated Properties              None
# 2                    Dana E. Landry              None
# 3                Redfin Corporation       Elena Fleck
# 4    Premier Estate Properties, Inc         Kim Lekas
# 5               Compass Florida LLC     Paul Ruthberg
# 6               John P. O'Grady LLC  Kathya Seckinger
# 7               RE/MAX Select Group              None
# 8                    Lang Realty/BR              None
# 9               Compass Florida LLC        Sonia Hall
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None  Michael O'Connor
# 1                            None        Nina Grody
# 2                            None     Austin McGurk
# 3              Redfin Corporation  Andrew Leibowitz
# 4  Premier Estate Properties, Inc    Patricia Burke
# 5             Compass Florida LLC       Robyn Rosen
# 6             John P. O'Grady LLC      Ken Benedict
# 7                            None      Jill Merrell
# 8                            None       Ana Londono
# 9             Compass Florida LLC       John Scalia
#
#                     buy_broker_name_1    buy_agent_name_2  \
# 0                     Douglas Elliman  Nicholas Malinosky
# 1        William Raveis South Florida                None
# 2          Brown Harris Stevens of PB       Liza Pulitzer
# 3    Leibowitz Realty Group, LLC./PBG   Michael Leibowitz
# 4  One Sotheby's International Realty                None
# 5                 Compass Florida LLC                None
# 6      Waterfront Properties & Club C                None
# 7                  The Corcoran Group                None
# 8                      Lang Realty/BR                None
# 9                    EXP Realty, LLC.                None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0                   Douglas Elliman     1  orange
# 1                              None     2    blue
# 2        Brown Harris Stevens of PB     3    blue
# 3  Leibowitz Realty Group, LLC./PBG     4    blue
# 4                              None     5    blue
# 5                              None     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  One Thousand Ocean at 1000 S Ocean Blvd #505 i...
# 1  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 2  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 3  Cityplace South Tower Condo at 550 Okeechobee ...
# 4  Bella Vista Condo at 110 Gleason St #202 in De...
# 5      Meridian at 1 N Ocean Blvd #303 in Boca Raton
# 6  Casuarina Condo at 3450 S Ocean Blvd Ph 3 in H...
# 7  Cityplace South Tower Condo at 550 Okeechobee ...
# 8  Chalfonte Condo at 550 S Ocean Blvd #509 in Bo...
# 9  Mizner Court Condo at 120 SE 5th Ave #226 in B...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: One Thousand Ocean closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $812,500M to $9,400,000M
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Highland Beach, Boca Raton, Palm Beach, West Palm Beach, Delray Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 93 condo sales totaling $46,224,011 million from Sep. 22nd to Sep. 29th. The previous week, brokers closed 67 condo sales totaling $45,900,000.
#
# Last week’s units sold for an average of $497,032, lower than the $593,041 average price from the previous week. The average price per square foot fell to $289 from $343, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $812,500.0 million to $9,400,000.0 million.
#
# One Thousand Ocean at 1000 S Ocean Blvd #505 in Boca Raton took the top spot with a $9,400,000.0 million closing. The sale closed at $2,080.0 per square foot.
#
# Marcy Javor with Signature One Luxury Estates LLC, and None with None had the listing.
# Michael O'Connor with Douglas Elliman, and Nicholas Malinosky with Douglas Elliman represented the buyer.
#
# Enclave OF Palm Beach Condo at 3170 S Ocean Blvd Unit S405 in Palm Beach, closed for the second highest amount, $3,200,000.0, or $1,085.0 per square foot.
#
# Leslie Judge with Illustrated Properties, and None with None had the listing.
# Nina Grody with William Raveis South Florida, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PB_County_condo_sales_week_ending_09302024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 22nd to Sep. 29th:
#
# Most Expensive
# One Thousand Ocean, 1000 S Ocean Blvd #505 in Boca Raton | Price: $9,400,000 | $2,080 psf | Listing agents: Marcy Javor with Signature One Luxury Estates LLC and None with None | Buyer's agents: Michael O'Connor with Douglas Elliman and Nicholas Malinosky with Douglas Elliman
# Least Expensive
# Mizner Court Condo, 120 SE 5th Ave #226 in Boca Raton | Price: $812,500 | $476 psf | Listing agents: David Hall with Compass Florida LLC and Sonia Hall with Compass Florida LLC | Buyer's agents: John Scalia with EXP Realty, LLC. and None with None
# Highest Price Per Square Foot
# One Thousand Ocean, 1000 S Ocean Blvd #505 in Boca Raton | Price: $9,400,000 | $2,080 psf | Listing agents: Marcy Javor with Signature One Luxury Estates LLC and None with None | Buyer's agents: Michael O'Connor with Douglas Elliman and Nicholas Malinosky with Douglas Elliman
# Lowest Price Per Square Foot
# Mizner Court Condo, 120 SE 5th Ave #226 in Boca Raton | Price: $812,500 | $476 psf | Listing agents: David Hall with Compass Florida LLC and Sonia Hall with Compass Florida LLC | Buyer's agents: John Scalia with EXP Realty, LLC. and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Boca-Raton/1000-S-Ocean-Blvd-33432/unit-505/home/42663635

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Palm-Beach/3170-S-Ocean-Blvd-33480/unit-S405/home/42439852

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/120-SE-5th-Ave-33432/unit-226/home/42328697

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/550-S-Ocean-Blvd-33432/unit-509/home/42326970

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/1000-S-Ocean-Blvd-33432/unit-505/home/42663635

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/120-SE-5th-Ave-33432/unit-226/home/42328697

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                          ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op           1000 S Ocean Blvd #505
# 1  PAST SALE 2024-09-30   Condo/Co-op      3170 S Ocean Blvd Unit S405
# 2  PAST SALE 2024-09-27   Condo/Co-op        44 Cocoanut Row Unit 418b
# 3  PAST SALE 2024-09-30   Condo/Co-op  550 Okeechobee Blvd Unit Uph-02
# 4  PAST SALE 2024-09-30   Condo/Co-op              110 Gleason St #202
# 5  PAST SALE 2024-09-27   Condo/Co-op              1 N Ocean Blvd #303
# 6  PAST SALE 2024-09-24   Condo/Co-op           3450 S Ocean Blvd Ph 3
# 7  PAST SALE 2024-09-23   Condo/Co-op        550 Okeechobee Blvd #1602
# 8  PAST SALE 2024-09-25   Condo/Co-op            550 S Ocean Blvd #509
# 9  PAST SALE 2024-09-27   Condo/Co-op              120 SE 5th Ave #226
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Boca Raton                FL             33432.0  9400000.0   3.0
# 1       Palm Beach                FL             33480.0  3200000.0   3.0
# 2       Palm Beach                FL             33480.0  2797500.0   2.0
# 3  West Palm Beach                FL             33401.0  1976500.0   3.0
# 4     Delray Beach                FL             33483.0  1837500.0   4.0
# 5       Boca Raton                FL             33432.0  1725000.0   4.0
# 6   Highland Beach                FL             33487.0  1700000.0   3.0
# 7  West Palm Beach                FL             33401.0  1360000.0   3.0
# 8       Boca Raton                FL             33432.0   900000.0   2.0
# 9       Boca Raton                FL             33432.0   812500.0   2.0
#
#    BATHS                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           One Thousand Ocean       4520.0       NaN      2010.0
# 1    3.0  Enclave OF Palm Beach Condo       2950.0       NaN      1985.0
# 2    2.0      Palm Beach Towers Condo          NaN       NaN      1956.0
# 3    2.0  Cityplace South Tower Condo       1606.0       NaN      2008.0
# 4    3.5            Bella Vista Condo       2105.0       NaN      2006.0
# 5    3.5                     Meridian       3129.0       NaN      2007.0
# 6    2.0              Casuarina Condo       2066.0       NaN      1986.0
# 7    2.0  Cityplace South Tower Condo       1709.0       NaN      2008.0
# 8    2.0              Chalfonte Condo       1351.0       NaN      1974.0
# 9    2.0           Mizner Court Condo       1706.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2080.0     8587.0   Sold
# 1             NaN         1085.0     3687.0   Sold
# 2             NaN            NaN        NaN   Sold
# 3             NaN         1231.0     1706.0   Sold
# 4             NaN          873.0     2229.0   Sold
# 5             NaN          551.0     3640.0   Sold
# 6             NaN          823.0     2572.0   Sold
# 7             NaN          796.0     1695.0   Sold
# 8             NaN          666.0     1569.0   Sold
# 9             NaN          476.0     2957.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...  Beaches MLS
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...  Beaches MLS
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...  Beaches MLS
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10943338        N          Y  26.336721 -80.071445
# 1  RX-10913354        N          Y  26.605363 -80.037760
# 2  RX-10982741        N          Y  26.716272 -80.043612
# 3  RX-10994622        N          Y  26.705124 -80.056199
# 4  RX-11008404        N          Y  26.459182 -80.061011
# 5  RX-10949933        N          Y  26.350986 -80.070943
# 6  RX-10971118        N          Y  26.413344 -80.065466
# 7  RX-11008446        N          Y  26.705124 -80.056199
# 8  RX-11001697        N          Y  26.344431 -80.070692
# 9  RX-10973151        N          Y  26.348269 -80.076619
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/1000-S-Oc...       Marcy Javor
# 1  https://www.redfin.com/FL/Palm-Beach/3170-S-Oc...      Leslie Judge
# 2  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Dana Landry
# 3  https://www.redfin.com/FL/West-Palm-Beach/550-...   Jonathan Huffer
# 4  https://www.redfin.com/FL/Delray-Beach/110-Gle...     Judith Lukens
# 5  https://www.redfin.com/FL/Boca-Raton/1-N-Ocean...     Elliot Koolik
# 6  https://www.redfin.com/FL/Highland-Beach/3450-...         Amy Blake
# 7  https://www.redfin.com/FL/West-Palm-Beach/550-...      Jean Cassett
# 8  https://www.redfin.com/FL/Boca-Raton/550-S-Oce...       Ana Londono
# 9  https://www.redfin.com/FL/Boca-Raton/120-SE-5t...        David Hall
#
#                  list_broker_name_1 list_agent_name_2  \
# 0  Signature One Luxury Estates LLC              None
# 1            Illustrated Properties              None
# 2                    Dana E. Landry              None
# 3                Redfin Corporation       Elena Fleck
# 4    Premier Estate Properties, Inc         Kim Lekas
# 5               Compass Florida LLC     Paul Ruthberg
# 6               John P. O'Grady LLC  Kathya Seckinger
# 7               RE/MAX Select Group              None
# 8                    Lang Realty/BR              None
# 9               Compass Florida LLC        Sonia Hall
#
#                list_broker_name_2  buy_agent_name_1  \
# 0                            None  Michael O'Connor
# 1                            None        Nina Grody
# 2                            None     Austin McGurk
# 3              Redfin Corporation  Andrew Leibowitz
# 4  Premier Estate Properties, Inc    Patricia Burke
# 5             Compass Florida LLC       Robyn Rosen
# 6             John P. O'Grady LLC      Ken Benedict
# 7                            None      Jill Merrell
# 8                            None       Ana Londono
# 9             Compass Florida LLC       John Scalia
#
#                     buy_broker_name_1    buy_agent_name_2  \
# 0                     Douglas Elliman  Nicholas Malinosky
# 1        William Raveis South Florida                None
# 2          Brown Harris Stevens of PB       Liza Pulitzer
# 3    Leibowitz Realty Group, LLC./PBG   Michael Leibowitz
# 4  One Sotheby's International Realty                None
# 5                 Compass Florida LLC                None
# 6      Waterfront Properties & Club C                None
# 7                  The Corcoran Group                None
# 8                      Lang Realty/BR                None
# 9                    EXP Realty, LLC.                None
#
#                   buy_broker_name_2  RANK   COLOR  \
# 0                   Douglas Elliman     1  orange
# 1                              None     2    blue
# 2        Brown Harris Stevens of PB     3    blue
# 3  Leibowitz Realty Group, LLC./PBG     4    blue
# 4                              None     5    blue
# 5                              None     6    blue
# 6                              None     7    blue
# 7                              None     8    blue
# 8                              None     9    blue
# 9                              None    10    blue
#
#                                            FULL_NAME
# 0  One Thousand Ocean at 1000 S Ocean Blvd #505 i...
# 1  Enclave OF Palm Beach Condo at 3170 S Ocean Bl...
# 2  Palm Beach Towers Condo at 44 Cocoanut Row Uni...
# 3  Cityplace South Tower Condo at 550 Okeechobee ...
# 4  Bella Vista Condo at 110 Gleason St #202 in De...
# 5      Meridian at 1 N Ocean Blvd #303 in Boca Raton
# 6  Casuarina Condo at 3450 S Ocean Blvd Ph 3 in H...
# 7  Cityplace South Tower Condo at 550 Okeechobee ...
# 8  Chalfonte Condo at 550 S Ocean Blvd #509 in Bo...
# 9  Mizner Court Condo at 120 SE 5th Ave #226 in B...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2023, 8, 21) ## List (Earlier) date
date2 = datetime(2024, 9, 30) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 406

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 2
#       1 chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
# ----> 2 chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
#       3 chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
#       4 chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4897, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
# -> 4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
#    4904     ).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[89], line 2, in <lambda>(x)
#       1 chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
# ----> 2 chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
#       3 chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
#       4 chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")
