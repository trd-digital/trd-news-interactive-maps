# %% [markdown]
# ## Notes
#
# - The goal is to get building permit data for our markets (and across the country) from the U.S. Census Bureau
# - I downloaded the master file from the bureau (link below)
# - A column with "REP" means the data contained is from a reported source only. A column without "REP", like "BLDGS_1_UNIT", contains estimated data
#
# Data link: https://www2.census.gov/econ/bps/Master%20Data%20Set/

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## PD Set Options

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Data Read-in

# %%
pd.read_csv?

# %%
df = pd.read_csv("BPS_Compiled_File_202412.csv",dtype='str', encoding_errors='ignore')

# %%
df
# Out:
#          BLDGS_1_UNIT BLDGS_1_UNIT_REP BLDGS_2_UNITS BLDGS_2_UNITS_REP  \
# 0                   0              NaN             0               NaN
# 1                   1              NaN             0               NaN
# 2                   1              NaN             0               NaN
# 3                   1              NaN             0               NaN
# 4                   2                0             0                 0
# ...               ...              ...           ...               ...
# 10859892            2                0             0                 0
# 10859893            3                0             0                 0
# 10859894            3                0             0                 0
# 10859895            0                0             0                 0
# 10859896           15               15             0                 0
#
#          BLDGS_3_4_UNITS BLDGS_3_4_UNITS_REP BLDGS_5_UNITS BLDGS_5_UNITS_REP  \
# 0                      0                 NaN             0               NaN
# 1                      0                 NaN             0               NaN
# 2                      0                 NaN             0               NaN
# 3                      0                 NaN             0               NaN
# 4                      0                   0             0                 0
# ...                  ...                 ...           ...               ...
# 10859892               0                   0             0                 0
# 10859893               0                   0             0                 0
# 10859894               0                   0             0                 0
# 10859895               0                   0             0                 0
# 10859896               0                   0             0                 0
#
#          CBSA_CODE CBSA_NAME CENSUS_PLACE_CODE CENTRAL_CITY COUNTY_CODE  \
# 0            99999       NaN              1140          NaN         045
# 1            99999       NaN              1140          NaN         045
# 2            99999       NaN              1330          NaN         045
# 3            99999       NaN              1330          NaN         045
# 4            99999       NaN               NaN          NaN         047
# ...            ...       ...               ...          ...         ...
# 10859892     99999       NaN               796          NaN         079
# 10859893     99999       NaN               NaN          NaN         079
# 10859894     44460       NaN               255          NaN         081
# 10859895     44460       NaN               332          NaN         081
# 10859896     44460       NaN               NaN          NaN         081
#
#              COUNTY_NAME CSA_CODE DIVISION_CODE                DIVISION_NAME  \
# 0            Dale County      999             6  East South Central Division
# 1            Dale County      999             6  East South Central Division
# 2            Dale County      999             6  East South Central Division
# 3            Dale County      999             6  East South Central Division
# 4          Dallas County      999             6  East South Central Division
# ...                  ...      ...           ...                          ...
# 10859892  Mineral County      999             8            Mountain Division
# 10859893  Mineral County      999             8            Mountain Division
# 10859894   Moffat County      999             8            Mountain Division
# 10859895   Moffat County      999             8            Mountain Division
# 10859896   Moffat County      999             8            Mountain Division
#
#             FILE_NAME FIPS_COUNTY_5_DIGITS FIPS_MCD_CODE FIPS_PLACE_CODE  \
# 0         so2101c.txt                01045         00000           48400
# 1         so2102c.txt                01045         00000           48400
# 2         so2101c.txt                01045         00000           57648
# 3         so2102c.txt                01045         00000           57648
# 4         so2102y.txt                01047         00000           99990
# ...               ...                  ...           ...             ...
# 10859892  we2412y.txt                08079         00000           14765
# 10859893  we2412y.txt                08079         00000           99990
# 10859894  we2412y.txt                08081         00000           17760
# 10859895  we2412y.txt                08081         00000           20495
# 10859896  we2412y.txt                08081         00000           99990
#
#          FOOTNOTE_CODE ID_6_DIGIT LOCATION_TYPE MONCOV MONTH  \
# 0                  NaN     329000         Place    NaN     1
# 1                  NaN     329000         Place    NaN     2
# 2                  NaN     385000         Place    NaN     1
# 3                  NaN     385000         Place    NaN     2
# 4                    2     129000         Place    NaN     2
# ...                ...        ...           ...    ...   ...
# 10859892           NaN     147000         Place    NaN    12
# 10859893           NaN     429000         Place    NaN    12
# 10859894           NaN     143000         Place    NaN    12
# 10859895           NaN     177000         Place    NaN    12
# 10859896           NaN     433000         Place    NaN    12
#
#          NUMBER_OF_MONTHS_REP        PERIOD  \
# 0                         NaN       Monthly
# 1                         NaN       Monthly
# 2                         NaN       Monthly
# 3                         NaN       Monthly
# 4                           0  Year-to-date
# ...                       ...           ...
# 10859892                    0  Year-to-date
# 10859893                    0  Year-to-date
# 10859894                    0  Year-to-date
# 10859895                    0  Year-to-date
# 10859896                   12  Year-to-date
#
#                                   PLACE_NAME UNIQUE_PLACE_ID    POP  \
# 0                          Midland City town        01329000   2344
# 1                          Midland City town        01329000   2344
# 2                                      Ozark        01385000  14907
# 3                                      Ozark        01385000  14907
# 4          Dallas County Unincorporated Area        01129000  18840
# ...                                      ...             ...    ...
# 10859892                 City of Creede town        08147000    315
# 10859893  Mineral County Unincorporated Area        08429000    458
# 10859894                               Craig        08143000   8953
# 10859895                       Dinosaur town        08177000    334
# 10859896   Moffat County Unincorporated Area        08433000   3857
#
#          REGION_CODE   REGION_NAME SOURCE_CODE STATE_CODE STATE_NAME  \
# 0                  3  South Region           3         01    Alabama
# 1                  3  South Region           3         01    Alabama
# 2                  3  South Region           5         01    Alabama
# 3                  3  South Region           5         01    Alabama
# 4                  3  South Region         NaN         01    Alabama
# ...              ...           ...         ...        ...        ...
# 10859892           4   West Region         NaN         08   Colorado
# 10859893           4   West Region         NaN         08   Colorado
# 10859894           4   West Region         NaN         08   Colorado
# 10859895           4   West Region         NaN         08   Colorado
# 10859896           4   West Region         NaN         08   Colorado
#
#          SURVEY_DATE TOTAL_BLDGS TOTAL_BLDGS_REP TOTAL_UNITS TOTAL_UNITS_REP  \
# 0             202101           0             NaN           0             NaN
# 1             202102           1             NaN           1             NaN
# 2             202101           1             NaN           1             NaN
# 3             202102           1             NaN           1             NaN
# 4             202102           2               0           2               0
# ...              ...         ...             ...         ...             ...
# 10859892      202412           2               0           2               0
# 10859893      202412           3               0           3               0
# 10859894      202412           3               0           3               0
# 10859895      202412           0               0           0               0
# 10859896      202412          15              15          15              15
#
#          TOTAL_VALUE TOTAL_VALUE_REP UNITS_1_UNIT UNITS_1_UNIT_REP  \
# 0                  0             NaN            0              NaN
# 1             135000             NaN            1              NaN
# 2             105692             NaN            1              NaN
# 3             105692             NaN            1              NaN
# 4             298830               0            2                0
# ...              ...             ...          ...              ...
# 10859892     1441534               0            2                0
# 10859893     1243990               0            3                0
# 10859894      717000               0            3                0
# 10859895           0               0            0                0
# 10859896     4278280         4278280           15               15
#
#          UNITS_2_UNITS UNITS_2_UNITS_REP UNITS_3_4_UNITS UNITS_3_4_UNITS_REP  \
# 0                    0               NaN               0                 NaN
# 1                    0               NaN               0                 NaN
# 2                    0               NaN               0                 NaN
# 3                    0               NaN               0                 NaN
# 4                    0                 0               0                   0
# ...                ...               ...             ...                 ...
# 10859892             0                 0               0                   0
# 10859893             0                 0               0                   0
# 10859894             0                 0               0                   0
# 10859895             0                 0               0                   0
# 10859896             0                 0               0                   0
#
#          UNITS_5_UNITS UNITS_5_UNITS_REP VALUE_1_UNIT VALUE_1_UNIT_REP  \
# 0                    0               NaN            0              NaN
# 1                    0               NaN       135000              NaN
# 2                    0               NaN       105692              NaN
# 3                    0               NaN       105692              NaN
# 4                    0                 0       298830                0
# ...                ...               ...          ...              ...
# 10859892             0                 0      1441534                0
# 10859893             0                 0      1243990                0
# 10859894             0                 0       717000                0
# 10859895             0                 0            0                0
# 10859896             0                 0      4278280          4278280
#
#          VALUE_2_UNITS VALUE_2_UNITS_REP VALUE_3_4_UNITS VALUE_3_4_UNITS_REP  \
# 0                    0               NaN               0                 NaN
# 1                    0               NaN               0                 NaN
# 2                    0               NaN               0                 NaN
# 3                    0               NaN               0                 NaN
# 4                    0                 0               0                   0
# ...                ...               ...             ...                 ...
# 10859892             0                 0               0                   0
# 10859893             0                 0               0                   0
# 10859894             0                 0               0                   0
# 10859895             0                 0               0                   0
# 10859896             0                 0               0                   0
#
#          VALUE_5_UNITS VALUE_5_UNITS_REP  YEAR   ZIP_CODE  \
# 0                    0               NaN  2021      36350
# 1                    0               NaN  2021      36350
# 2                    0               NaN  2021      36361
# 3                    0               NaN  2021      36361
# 4                    0                 0  2021  367020987
# ...                ...               ...   ...        ...
# 10859892             0                 0  2024      81130
# 10859893             0                 0  2024      81130
# 10859894             0                 0  2024      81625
# 10859895             0                 0  2024  816100238
# 10859896             0                 0  2024      81625
#
#                                LOCATION_NAME
# 0                          Midland City town
# 1                          Midland City town
# 2                                      Ozark
# 3                                      Ozark
# 4          Dallas County Unincorporated Area
# ...                                      ...
# 10859892                 City of Creede town
# 10859893  Mineral County Unincorporated Area
# 10859894                               Craig
# 10859895                       Dinosaur town
# 10859896   Moffat County Unincorporated Area
#
# [10859897 rows x 62 columns]

# %% [markdown]
# ## Data work

# %%
df_monthly = df[df['PERIOD'] == 'Monthly']

# %%
df_monthly_county = df_monthly[df_monthly['LOCATION_TYPE'] == 'County']

# %%
df_monthly_county_year = df_monthly_county[df_monthly_county['YEAR'] == '2024']

# %%
keep_columns = ['BLDGS_1_UNIT', 'BLDGS_2_UNITS','BLDGS_3_4_UNITS',
       'BLDGS_5_UNITS','COUNTY_NAME','DIVISION_NAME','MONTH','PERIOD','REGION_NAME',
       'STATE_NAME', 'SURVEY_DATE', 'TOTAL_BLDGS','TOTAL_UNITS','TOTAL_VALUE',
       'UNITS_1_UNIT', 'UNITS_2_UNITS','UNITS_3_4_UNITS',
       'UNITS_5_UNITS', 'VALUE_1_UNIT', 'VALUE_2_UNITS',
       'VALUE_3_4_UNITS', 'VALUE_5_UNITS','YEAR', 'ZIP_CODE', 'LOCATION_NAME']

# %%
final_df = df_monthly_county_year[keep_columns]

# %%
final_df['COUNTY_STATE_NAME'] = final_df['COUNTY_NAME'] + ', ' + final_df['STATE_NAME']
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_76291/128574475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['COUNTY_STATE_NAME'] = final_df['COUNTY_NAME'] + ', ' + final_df['STATE_NAME']

# %%
import calendar
final_df['MONTH_NAME'] = final_df['MONTH'].astype(int).apply(lambda x: calendar.month_name[x])
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_76291/477860774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['MONTH_NAME'] = final_df['MONTH'].astype(int).apply(lambda x: calendar.month_name[x])

# %%
final_df['MONTH_NAME_YEAR'] = final_df["MONTH_NAME"] + " " + final_df["YEAR"]
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_76291/3739681526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['MONTH_NAME_YEAR'] = final_df["MONTH_NAME"] + " " + final_df["YEAR"]

# %%
final_df.to_csv("2024_CB_BuildingPermit_data.csv")

# %%
final_df.head(1)
# Out:
#         BLDGS_1_UNIT BLDGS_2_UNITS BLDGS_3_4_UNITS BLDGS_5_UNITS  \
# 3208622            4             0               0             0
#
#           COUNTY_NAME            DIVISION_NAME MONTH   PERIOD   REGION_NAME  \
# 3208622  Swain County  South Atlantic Division     2  Monthly  South Region
#
#              STATE_NAME SURVEY_DATE TOTAL_BLDGS TOTAL_UNITS TOTAL_VALUE  \
# 3208622  North Carolina      202402           4           4     1615000
#
#         UNITS_1_UNIT UNITS_2_UNITS UNITS_3_4_UNITS UNITS_5_UNITS VALUE_1_UNIT  \
# 3208622            4             0               0             0      1615000
#
#         VALUE_2_UNITS VALUE_3_4_UNITS VALUE_5_UNITS  YEAR ZIP_CODE  \
# 3208622             0               0             0  2024      NaN
#
#         LOCATION_NAME             COUNTY_STATE_NAME MONTH_NAME MONTH_NAME_YEAR
# 3208622  Swain County  Swain County, North Carolina   February   February 2024

# %%
final_df.columns
# Out:
# Index(['BLDGS_1_UNIT', 'BLDGS_2_UNITS', 'BLDGS_3_4_UNITS', 'BLDGS_5_UNITS',
#        'COUNTY_NAME', 'DIVISION_NAME', 'MONTH', 'PERIOD', 'REGION_NAME',
#        'STATE_NAME', 'SURVEY_DATE', 'TOTAL_BLDGS', 'TOTAL_UNITS',
#        'TOTAL_VALUE', 'UNITS_1_UNIT', 'UNITS_2_UNITS', 'UNITS_3_4_UNITS',
#        'UNITS_5_UNITS', 'VALUE_1_UNIT', 'VALUE_2_UNITS', 'VALUE_3_4_UNITS',
#        'VALUE_5_UNITS', 'YEAR', 'ZIP_CODE', 'LOCATION_NAME',
#        'COUNTY_STATE_NAME', 'MONTH_NAME', 'MONTH_NAME_YEAR'],
#       dtype='object')
