# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data read-in

# %%
df = pd.read_csv('Building_Permits_Since_2014.csv')

# %% [markdown]
# ## Clean & Filter Data

# %%
## Filter 'ScopeofWork' to:  REMODELING/REPARIS, NEW CONSTRUCTION, ADDITION AND REMODELING
df_filtered = df[(df['ScopeofWork'] == 'REMODELING/REPAIRS') | (df['ScopeofWork'] == 'NEW CONSTRUCTION') | (df['ScopeofWork'] == 'ADDITION AND REMODELING')]

# %%
## Remove expired permits 
df_filtered = df_filtered[df_filtered['BuildingPermitStatusDescription'] != 'Expired']

# %%
df_filtered
# Out:
#                 X          Y      ID  AdditionSQFT ApplicationNumber
# 1      -80.221208  25.809518       2           0.0        BD12000085  \
# 6      -80.186212  25.823628       7           0.0        BD12000216
# 8      -80.250444  25.721209       9           0.0        BD12000288
# 13     -80.271987  25.769186      14           0.0        BD12000375
# 14     -80.271987  25.769186      15           0.0        BD12000375
# ...           ...        ...     ...           ...               ...
# 132855 -80.185015  25.767911  132087           0.0        BD23009707
# 132856 -80.185015  25.767911  132088           0.0        BD23009707
# 132857 -80.185015  25.767911  132089           0.0        BD23009707
# 132858 -80.235832  25.778414  132090           0.0        BD23009714
# 132874 -80.245554  25.769429  132106           0.0        BD23009750
#
#        BuildingFinalLastInspDate  BuildingFinalLastInspResult
# 1         2019/04/05 10:01:00+00                          NaN  \
# 6         2012/07/12 07:58:00+00                          NaN
# 8         2022/07/21 11:29:00+00                          NaN
# 13        2012/10/23 13:42:00+00                          NaN
# 14                           NaN                          NaN
# ...                          ...                          ...
# 132855                       NaN                          NaN
# 132856                       NaN                          NaN
# 132857                       NaN                          NaN
# 132858                       NaN                          NaN
# 132874                       NaN                          NaN
#
#        BuildingPermitStatusDescription
# 1                                Final  \
# 6                                Final
# 8                                Final
# 13                               Final
# 14                               Final
# ...                                ...
# 132855                          Active
# 132856                          Active
# 132857                          Active
# 132858                           Final
# 132874                          Active
#
#                  BuildingPermitStatusReasonDescr Certificatecode  ... RemSQFT
# 1                 All Inspections are finalized.             NaN  ...     0.0  \
# 6                 All Inspections are finalized.             NaN  ...     0.0
# 8                 All Inspections are finalized.             NaN  ...     0.0
# 13                All Inspections are finalized.              CC  ...   900.0
# 14                All Inspections are finalized.             NaN  ...   900.0
# ...                                          ...             ...  ...     ...
# 132855  Permit is Active. Ready for Inspections.             NaN  ...    84.0
# 132856  Permit is Active. Ready for Inspections.             NaN  ...    84.0
# 132857  Permit is Active. Ready for Inspections.             NaN  ...    84.0
# 132858            All Inspections are finalized.             NaN  ...     0.0
# 132874  Permit is Active. Ready for Inspections.             NaN  ...   176.0
#
#        RequiredCertificate         ScopeofWork              Statusdate
# 1                           REMODELING/REPAIRS  2019/04/05 10:01:00+00  \
# 6                           REMODELING/REPAIRS  2021/08/16 13:07:00+00
# 8                             NEW CONSTRUCTION  2022/07/21 11:29:00+00
# 13                      CC  REMODELING/REPAIRS  2022/05/13 10:30:00+00
# 14                      CC  REMODELING/REPAIRS  2022/04/29 14:03:00+00
# ...                    ...                 ...                     ...
# 132855                  CC  REMODELING/REPAIRS  2023/05/19 10:05:00+00
# 132856                  CC  REMODELING/REPAIRS  2023/06/06 15:09:00+00
# 132857                  CC  REMODELING/REPAIRS  2023/06/06 15:07:00+00
# 132858                      REMODELING/REPAIRS  2023/06/20 14:23:00+00
# 132874                  CC  REMODELING/REPAIRS  2023/06/21 12:46:00+00
#
#         TotalCost               TotalDaysInPlanReview
# 1         10000.0    1 Day(s) 0 Hour(s) 35 Minute(s)   \
# 6          1000.0  24 Day(s) 23 Hour(s) 58 Minute(s)
# 8          3500.0    23 Day(s) 3 Hour(s) 9 Minute(s)
# 13        40500.0   48 Day(s) 3 Hour(s) 55 Minute(s)
# 14         3500.0   83 Day(s) 0 Hour(s) 45 Minute(s)
# ...           ...                                 ...
# 132855     8500.0  20 Day(s) 16 Hour(s) 32 Minute(s)
# 132856     1700.0  38 Day(s) 21 Hour(s) 36 Minute(s)
# 132857     3000.0  38 Day(s) 21 Hour(s) 34 Minute(s)
# 132858     7000.0   22 Day(s) 1 Hour(s) 22 Minute(s)
# 132874    20896.0  34 Day(s) 14 Hour(s) 43 Minute(s)
#
#         TotalDaysInPlanReviewNumeric TotalSQFT
# 1                                1.0       0.0  \
# 6                               24.0       0.0
# 8                               23.0       0.0
# 13                              48.0     900.0
# 14                              83.0     900.0
# ...                              ...       ...
# 132855                          20.0      84.0
# 132856                          38.0      84.0
# 132857                          38.0      84.0
# 132858                          22.0       0.0
# 132874                          34.0     176.0
#
#                                                 WorkItems  ObjectId
# 1       STORE FRONTS / FIXED GLASS / INTERIOR GLASS SY...         2
# 6                  GARAGE OR ROLL-UP DOOR (NO ELECTRICAL)         7
# 8                                                    SHED         9
# 13                                SINGLE FAMILY RESIDENCE        14
# 14      CLOTHES WASHERS|DRYERS|GARBAGE DISPOSAL|LIGHT ...        15
# ...                                                   ...       ...
# 132855                               MULTI-FAMILY (CONDO)    132856
# 132856   LIGHT SOCKET|ROUGH WIRING OUTLETS|SERVICE REPAIR    132857
# 132857  SETTING FIXTURE: DISHWASHER|SETTING FIXTURE: D...    132858
# 132858                         WINDOWS / DOORS / SKYLIGHT    132859
# 132874  SINGLE FAMILY RESIDENCE|WINDOWS / DOORS / SKYL...    132875
#
# [84818 rows x 43 columns]

# %% [markdown]
# ## Analysis
