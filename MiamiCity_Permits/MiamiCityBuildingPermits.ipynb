# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Notes:
#
# Data link: https://datahub-miamigis.opendata.arcgis.com/datasets/MiamiGIS::building-permits-since-2014/explore?location=25.782311%2C-80.231660%2C13.00
#
# Date Data pulled: 6.26.23

# %% [markdown]
# ## PD Set Options

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Data read-in

# %%
df = pd.read_csv('Building_Permits_Since_2014.csv')

# %% [markdown]
# ## Clean & Filter Data

# %%
## Filter 'ScopeofWork' to:  REMODELING/REPARIS, NEW CONSTRUCTION, ADDITION AND REMODELING
df_filtered = df[(df['ScopeofWork'] == 'REMODELING/REPAIRS') | (df['ScopeofWork'] == 'NEW CONSTRUCTION') | (df['ScopeofWork'] == 'ADDITION AND REMODELING')]

# %%
## Remove expired permits 
df_filtered = df_filtered[df_filtered['BuildingPermitStatusDescription'] != 'Expired']

# %% [markdown]
# ## Create 3, 5, 10, and all-time reports

# %%
# Convert "PlanAcceptedDate"
df_filtered['PlanAcceptedDate'] = pd.to_datetime(df_filtered['PlanAcceptedDate'])

# %% [markdown]
# ### Create reports

# %%
df_three_years = df_filtered[df_filtered['PlanAcceptedDate'] > '2020-06-26']
df_five_years = df_filtered[df_filtered['PlanAcceptedDate'] > '2018-06-26']
df_ten_years = df_filtered[df_filtered['PlanAcceptedDate'] > '2013-06-26']

# %%
df_three_years = df_three_years[df_three_years['BuildingPermitStatusDescription'] != 'Revoked']
df_five_years = df_five_years[df_five_years['BuildingPermitStatusDescription'] != 'Revoked']
df_ten_years = df_ten_years[df_ten_years['BuildingPermitStatusDescription'] != 'Revoked']
df_filtered = df_filtered[df_filtered['BuildingPermitStatusDescription'] != 'Revoked']

# %% [markdown]
# ## Analysis

# %%
# pd.set_option('display.max_columns',None)
# df_filtered[df_filtered['CompanyName'] == 'STILES MCHUGH LLC']

# %%
three_years_grouped = df_three_years.groupby('CompanyName')['TotalCost'].sum().sort_values(ascending=False)
five_years_grouped = df_five_years.groupby('CompanyName')['TotalCost'].sum().sort_values(ascending=False)
ten_years_grouped = df_ten_years.groupby('CompanyName')['TotalCost'].sum().sort_values(ascending=False)
all_years_grouped = df_filtered.groupby('CompanyName')['TotalCost'].sum().sort_values(ascending=False)

# %%
three_years_grouped.to_csv('MiamiCityPermits_three_years.csv')
five_years_grouped.to_csv('MiamiCityPermits_five_years.csv')
ten_years_grouped.to_csv('MiamiCityPermits_ten_years.csv')
all_years_grouped.to_csv('MiamiCityPermits_all_years.csv')

# %% [markdown]
# ## Create CSV files

# %%
five_years_grouped = five_years_grouped.to_frame()
five_years_grouped = five_years_grouped.reset_index()
five_years_grouped = five_years_grouped.head(30)
top_25_list = five_years_grouped['CompanyName']

# %%
# for company in top_25_list:
#     x = df_five_years[df_five_years['CompanyName'] == company]
#     x.to_csv(f'{company}.csv')

# %%
# df_five_years[df_five_years['CompanyName'] == 'CMC CONSTRUCTION COMPANY']
# Out:
#                X          Y     ID  AdditionSQFT ApplicationNumber
# 30024 -80.220255  25.735420  30025      440027.0        BD18013439  \
# 45875 -80.189480  25.790587  45683           0.0        BD19007217
# 45885 -80.189480  25.790587  45685           0.0        BD19007217
# 66824 -80.220255  25.735420  66475           0.0        BD20002889
# 97994 -80.235838  25.729706  97399           0.0        BD21015241
#
#       BuildingFinalLastInspDate  BuildingFinalLastInspResult
# 30024                       NaN                          NaN  \
# 45875    2020/08/20 13:21:00+00                          NaN
# 45885                       NaN                          NaN
# 66824                       NaN                          NaN
# 97994    2022/07/13 12:41:00+00                          NaN
#
#       BuildingPermitStatusDescription
# 30024                          Active  \
# 45875                           Final
# 45885                           Final
# 66824                          Active
# 97994                           Final
#
#                 BuildingPermitStatusReasonDescr Certificatecode
# 30024  Permit is Active. Ready for Inspections.             NaN  \
# 45875            All Inspections are finalized.             NaN
# 45885            All Inspections are finalized.             NaN
# 66824  Permit is Active. Ready for Inspections.             NaN
# 97994            All Inspections are finalized.              CO
#
#            Certificatedate              CompanyAddress CompanyCity
# 30024                  NaN  701 BRICKELL AV SUITE 2410       MIAMI  \
# 45875                  NaN  701 BRICKELL AV SUITE 2410       MIAMI
# 45885                  NaN  701 BRICKELL AV SUITE 2410       MIAMI
# 66824                  NaN  701 BRICKELL AV SUITE 2410       MIAMI
# 97994  2022/07/15 14:53:00  701 BRICKELL AV SUITE 2410       MIAMI
#
#                     CompanyName  CompanyZip
# 30024  CMC CONSTRUCTION COMPANY     33131.0  \
# 45875  CMC CONSTRUCTION COMPANY     33131.0
# 45885  CMC CONSTRUCTION COMPANY     33131.0
# 66824  CMC CONSTRUCTION COMPANY     33131.0
# 97994  CMC CONSTRUCTION COMPANY     33131.0
#
#                                DaysInCity  DaysInCityNumeric
# 30024  260 Day(s) 1 Hour(s) 36 Minute(s)               260.0  \
# 45875                                 NaN                NaN
# 45885                                 NaN                NaN
# 66824                                 NaN                NaN
# 97994                                 NaN                NaN
#
#             DeliveryAddress     FirstSubmissionDate   FolioNumber
# 30024       4 GROVE ISLE DR  2018/08/31 18:06:00+00  141140020010  \
# 45875          265 NE 16 ST                     NaN  132310060050
# 45885          265 NE 16 ST                     NaN  132310060050
# 66824       4 GROVE ISLE DR                     NaN  141140020010
# 97994  3357 PAN AMERICAN DR                     NaN  141220460001
#
#       IsPermitFinal  IsPrivateProvider              IssuedDate   Latitude
# 30024            NO               True  2020/02/24 10:47:00+00  25.735420  \
# 45875           YES              False  2019/10/11 10:12:00+00  25.790587
# 45885           YES              False  2020/08/11 12:01:00+00  25.790587
# 66824            NO              False  2020/03/06 09:52:00+00  25.735420
# 97994           YES               True  2021/12/30 17:54:00+00  25.729706
#
#        Longitude Miami21Zone  NewAdditionCost       PermitNumber
# 30024 -80.220255        T5-R       96701169.0  BD18013439001B001  \
# 45875 -80.189480    T6-36B-O         139000.0  BD19007217001B001
# 45885 -80.189480    T6-36B-O              NaN  BD19007217001L001
# 66824 -80.220255        T5-R              NaN  BD20002889001B001
# 97994 -80.235838          CS              NaN  BD21015241001B001
#
#                PlanAcceptedDate         PlanCreatedDate  ProcessNumber
# 30024 2018-08-31 18:05:00+00:00  2018/08/27 10:02:00+00  BD18013439001  \
# 45875 2019-05-17 19:11:00+00:00  2019/04/18 11:23:00+00  BD19007217001
# 45885 2019-05-17 19:11:00+00:00  2019/04/18 11:23:00+00  BD19007217001
# 66824 2020-02-20 15:19:00+00:00  2020/02/11 15:28:00+00  BD20002889001
# 97994 2021-10-01 11:51:00+00:00  2021/07/08 16:57:00+00  BD21015241001
#
#       PropertyType  RemodelingCost  RemSQFT RequiredCertificate
# 30024   Commercial             0.0      0.0                  CO  \
# 45875   Commercial             NaN      0.0                  CC
# 45885   Commercial             NaN      0.0                  CC
# 66824   Commercial         70000.0      0.0
# 97994   Commercial        250000.0   2177.0                  CO
#
#               ScopeofWork              Statusdate   TotalCost
# 30024    NEW CONSTRUCTION  2022/12/12 08:44:00+00  96701169.0  \
# 45875    NEW CONSTRUCTION  2020/08/20 13:21:00+00    139000.0
# 45885    NEW CONSTRUCTION  2020/08/12 11:41:00+00         NaN
# 66824  REMODELING/REPAIRS  2023/01/06 16:02:00+00     70000.0
# 97994  REMODELING/REPAIRS  2022/07/15 14:44:00+00    250000.0
#
#                      TotalDaysInPlanReview  TotalDaysInPlanReviewNumeric
# 30024  541 Day(s) 16 Hour(s) 42 Minute(s)                          541.0  \
# 45875   146 Day(s) 15 Hour(s) 1 Minute(s)                          146.0
# 45885  451 Day(s) 16 Hour(s) 50 Minute(s)                          451.0
# 66824   14 Day(s) 18 Hour(s) 33 Minute(s)                           14.0
# 97994     90 Day(s) 6 Hour(s) 3 Minute(s)                           90.0
#
#        TotalSQFT                                          WorkItems  ObjectId
# 30024   440027.0                               MULTI-FAMILY (CONDO)     30025
# 45875        0.0                                SURFACE PARKING LOT     45876
# 45885        0.0                                       TREE REMOVAL     45886
# 66824        0.0                                   TEMPORARY FENCE      66825
# 97994     2177.0  PROFESSIONAL OFFICE / BANK / FINANCIAL INSTITU...     97995
