# %% [markdown]
# ## Imports

# %%
from geopy.geocoders import GoogleV3
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import urllib3
import re
from textwrap import shorten
import os

# %%
df = pd.read_csv('map_NorthMiamiBeach_popup_pin - Sheet1.csv')

# %% [markdown]
# ## Image URL collector

# %%
# Drop last n rows of a df. In case there are sums that need clipped
# df.drop(df.tail(n).index, inplace=True)

# %%
df['image_links'] = ''
links = []
for url in df['story_link']:
    try:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        images = soup.find_all('img')
        counter = 0
        for image in images:
            counter += 1
            if 'jpg' in image['src']:
                links.append(image['src'])
                if counter == len(images):
                    links.append('no image found')
                break
    except:
        links.append('no_image')

df['image_links'] = links

# %%
len(links)
# Out:
# 9

# %% [markdown]
# ## Article link formatter

# %%
df["short_description"] = df["description"].apply(lambda s: shorten(s, width=20, placeholder=""))
df['remaining_desc'] = df.apply(lambda row : row['description'].replace(str(row['short_description']), ''), axis=1)
df['remaining_desc']

df["description_link"] = '<a href="' + df["story_link"] + '" target="_blank" rel="noopener noreferrer">' + df["short_description"] + "</a>" + df["remaining_desc"]
df['description_link']
# Out:
# 0    <a href="https://therealdeal.com/miami/2022/08...
# 1    <a href="https://therealdeal.com/miami/2022/08...
# 2    <a href="https://therealdeal.com/miami/2020/12...
# 3    <a href="https://therealdeal.com/miami/2022/08...
# 4    <a href="https://therealdeal.com/miami/2022/08...
# 5    <a href="https://therealdeal.com/miami/2022/07...
# 6    <a href="https://therealdeal.com/miami/2022/03...
# 7    <a href="https://therealdeal.com/miami/2022/03...
# 8    <a href="https://therealdeal.com/miami/2022/04...
# Name: description_link, dtype: object

# %% [markdown]
# ## Google Maps API Geolocater Setup

# %%
# %store -r google_maps_API_Key
geolocator = GoogleV3(api_key=google_maps_API_Key)

# %%
df['geo_address'] = df['full_address'] + ' North Miami Beach, FL'
df['loc'] = df['geo_address'].apply(geolocator.geocode, timeout=10)
df['point'] = df['loc'].apply(lambda loc: tuple(loc.point) if loc else None)
df[['lat','lon','altitude']] = pd.DataFrame(df['point'].to_list(),index=df.index)

# %% [markdown]
# ## Correction Section

# %%
df.columns
# Out:
# Index(['full_address', 'developers', 'description', 'story_link',
#        'story_link_2', 'image_links', 'short_description', 'remaining_desc',
#        'description_link', 'geo_address', 'loc', 'point', 'lat', 'lon',
#        'altitude'],
#       dtype='object')

# %%
df
# Out:
#                                         full_address  \
# 0                     16955-17071 West Dixie Highway
# 1                           16375 Biscayne Boulevard
# 2                           16395 Biscayne Boulevard
# 3                        2261 Northeast 164th Street
# 4                          4098 Northeast 167 Street
# 5   1750 and 1775 Northeast 167th Street (This is...
# 6  Southeast corner of Northeast 159th Street and...
# 7                        2050 Northeast 164th Street
# 8                           13899 Biscayne Boulevard
#
#                                           developers  \
# 0                          Trinsic Residential Group
# 1                                  Estate Companies
# 2                                  Estate Companies
# 3                                          BH Group
# 4                                  Macken Companies
# 5  Ari Pearl’s PPG Development. Matt Press of Equ...
# 6                                    AHS Residential
# 7                        Carpe Real Estate Partners
# 8          Fortune International Group and Blue Road
#
#                                          description  \
# 0  This will be the nine-story, 373-unit Aura Nor...
# 1  This will be a 28-story, 363-unit Soleste on t...
# 2  This will be the 23-story, 367-unit Soleste No...
# 3  This will be a 30-story, 400-unit apartment to...
# 4  This is the Koya Bay project, a collection of ...
# 5  This is a plan for an apartment complex with s...
# 6  We don't know what is AHS' plan. If you have t...
# 7  This is the 26-story, 440-unit Venus apartment...
# 8  This will be the Nexo, a 16-story, 254-unit pr...
#
#                                           story_link  \
# 0  https://therealdeal.com/miami/2022/08/16/trins...
# 1  https://therealdeal.com/miami/2022/08/15/estat...
# 2  https://therealdeal.com/miami/2020/12/14/estat...
# 3  https://therealdeal.com/miami/2022/08/16/bh-pl...
# 4  https://therealdeal.com/miami/2022/08/01/macke...
# 5  https://therealdeal.com/miami/2022/07/20/ari-p...
# 6  https://therealdeal.com/miami/2022/03/28/ahs-r...
# 7  https://therealdeal.com/miami/2022/03/16/carpe...
# 8  https://therealdeal.com/miami/2022/04/19/blue-...
#
#                                         story_link_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://therealdeal.com/miami/2020/10/26/macke...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
#
#                                          image_links     short_description  \
# 0  https://s14.therealdeal.com/trd/m/up/2022/08/T...      This will be the
# 1  https://s11.therealdeal.com/trd/m/up/2022/08/m...        This will be a
# 2  https://s11.therealdeal.com/trd/m/up/2020/12/1...      This will be the
# 3  https://therealdeal.com/miami/wp-content/uploa...        This will be a
# 4  https://s13.therealdeal.com/trd/m/up/2022/08/M...  This is the Koya Bay
# 5  https://s11.therealdeal.com/trd/m/up/2022/07/m...    This is a plan for
# 6  https://s14.therealdeal.com/trd/m/up/2022/03/A...    We don't know what
# 7  https://s13.therealdeal.com/trd/m/up/2022/03/M...           This is the
# 8  https://s12.therealdeal.com/trd/m/up/2022/04/m...      This will be the
#
#                                       remaining_desc  \
# 0   nine-story, 373-unit Aura North Miami Beach w...
# 1   28-story, 363-unit Soleste on the Bay tower w...
# 2   23-story, 367-unit Soleste NoMi apartment tow...
# 3               30-story, 400-unit apartment tower.
# 4   project, a collection of 10 four-story townho...
# 5   an apartment complex with several buildings r...
# 6   is AHS' plan. If you have time, maybe reach o...
# 7   26-story, 440-unit Venus apartment tower. I k...
# 8   Nexo, a 16-story, 254-unit project, which wil...
#
#                                     description_link  \
# 0  <a href="https://therealdeal.com/miami/2022/08...
# 1  <a href="https://therealdeal.com/miami/2022/08...
# 2  <a href="https://therealdeal.com/miami/2020/12...
# 3  <a href="https://therealdeal.com/miami/2022/08...
# 4  <a href="https://therealdeal.com/miami/2022/08...
# 5  <a href="https://therealdeal.com/miami/2022/07...
# 6  <a href="https://therealdeal.com/miami/2022/03...
# 7  <a href="https://therealdeal.com/miami/2022/03...
# 8  <a href="https://therealdeal.com/miami/2022/04...
#
#                                          geo_address  \
# 0  16955-17071 West Dixie Highway North Miami Bea...
# 1     16375 Biscayne Boulevard North Miami Beach, FL
# 2     16395 Biscayne Boulevard North Miami Beach, FL
# 3  2261 Northeast 164th Street North Miami Beach, FL
# 4    4098 Northeast 167 Street North Miami Beach, FL
# 5   1750 and 1775 Northeast 167th Street (This is...
# 6  Southeast corner of Northeast 159th Street and...
# 7  2050 Northeast 164th Street North Miami Beach, FL
# 8     13899 Biscayne Boulevard North Miami Beach, FL
#
#                                                  loc  \
# 0  (16955 W Dixie Hwy, North Miami Beach, FL 3316...
# 1  (16375 Biscayne Blvd, Aventura, FL 33160, USA,...
# 2  (16395 Biscayne Blvd, North Miami Beach, FL 33...
# 3  (2261 NE 164th St, North Miami Beach, FL 33160...
# 4  (4098 NE 167th St, North Miami Beach, FL 33160...
# 5  (1775 NE 167th St, North Miami Beach, FL 33162...
# 6  (15540 W Dixie Hwy, North Miami Beach, FL 3316...
# 7  (2050 NE 164th St, North Miami Beach, FL 33162...
# 8  (13899 Biscayne Blvd, North Miami Beach, FL 33...
#
#                                    point        lat        lon  altitude
# 0           (25.932546, -80.152974, 0.0)  25.932546 -80.152974       0.0
# 1         (25.9280335, -80.1522347, 0.0)  25.928034 -80.152235       0.0
# 2           (25.9285698, -80.15203, 0.0)  25.928570 -80.152030       0.0
# 3         (25.9274746, -80.1547639, 0.0)  25.927475 -80.154764       0.0
# 4         (25.9336827, -80.1316907, 0.0)  25.933683 -80.131691       0.0
# 5         (25.9298195, -80.1652049, 0.0)  25.929820 -80.165205       0.0
# 6   (25.919162, -80.15936800000001, 0.0)  25.919162 -80.159368       0.0
# 7          (25.9269576, -80.158881, 0.0)  25.926958 -80.158881       0.0
# 8  (25.9038948, -80.15829599999999, 0.0)  25.903895 -80.158296       0.0

# %% [markdown]
# ## Correction section

# %%
# df.at[0,'Net decline in footprint, in sf']=('Almost 200K sf')
# df.at[1,'Address(es) of space company vacated or plans to vacate, in sf']=('690 East Middlefield Road, Mountain View. Synopsys is subletting the entire building to Waymo.')

### Change value to percent value
### df['percent_change'] = pd.Series(['{0:.2f}%'.format(val) for val in df['percent_change']], index = df.index)

# %% [markdown]
# ## HTML popup formatter

# %%
df.columns
# Out:
# Index(['full_address', 'developers', 'description', 'story_link',
#        'story_link_2', 'image_links', 'short_description', 'remaining_desc',
#        'description_link', 'geo_address', 'loc', 'point', 'lat', 'lon',
#        'altitude'],
#       dtype='object')

# %%
def popup_html(row):
    i = row
    address = df['full_address'].iloc[i]
    developer = df['developers'].iloc[i]
    image = df['image_links'].iloc[i]
    description = df['description_link'].iloc[i]
    
    html = '''<!DOCTYPE html>
    <html>
    <img src={} width="256" height="156">'''.format(image) + '''<br>______________________________________<br>
    Address: <strong>{}'''.format(address) + '''</strong><br>
    Developer: <strong>{}'''.format(developer) + '''</strong><br>
    <strong>{}'''.format(description) + '''</strong><br>
    </html>
    '''
    return html

# %% [markdown]
# ### HTML reservoir

# %%
#     Developer(s): <strong><em>{}'''.format(developer) + '''</strong></em><br><br>

# %% [markdown]
# ## Map Maker

# %%
df.description_link[0]
# Out:
# '<a href="https://therealdeal.com/miami/2022/08/16/trinsic-nabs-99m-loan-to-build-north-miami-beach-rentals/" target="_blank" rel="noopener noreferrer">This will be the</a> nine-story, 373-unit Aura North Miami Beach with 17,000 square feet of retail. '

# %%
import folium
import branca

f = folium.Figure(width=750, height=750)
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=15)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Bay Harbor Islands Resi Projects')

for i in range(0,len(df)):
    html = popup_html(i)
    iframe = branca.element.IFrame(html=html)
    popup = folium.Popup(folium.Html(html, script=True))
    folium.Marker([df['lat'].iloc[i],df['lon'].iloc[i]],
                 popup=popup).add_to(m)

m.get_root().html.add_child(folium.Element(title_html))
m.fit_bounds(bounds=df[['lat','lon']].mean().to_list(),max_zoom=15)
# m.add_to(f)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2fd6649aa1dd6e9b8907ebe0a138b8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Bay Harbor Islands Resi Projects&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2fd6649aa1dd6e9b8907ebe0a138b8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d2fd6649aa1dd6e9b8907ebe0a138b8a = L.map(
#                 &quot;map_d2fd6649aa1dd6e9b8907ebe0a138b8a&quot;,
#                 {
#                     center: [25.925571166666668, -80.15393813333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dee4277191bac698b00fdaf61f9cca0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2fd6649aa1dd6e9b8907ebe0a138b8a);
#
#
#             var marker_648d9e0eecd1467e35e14b968c28758a = L.marker(
#                 [25.932546, -80.152974],
#                 {}
#             ).addTo(map_d2fd6649aa1dd6e9b8907ebe0a138b8a);
#
#
#         var popup_27da788576c631110a178e99fcb84251 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a27f288805a4e41e23c2a6af25de26d2 = $(`&lt;div id=&quot;html_a27f288805a4e41e23c2a6af25de26d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s14.therealdeal.com/trd/m/up/2022/08/Trinsic-starts-on-North-Miami-Beach-rentals-with-99M-loan-705x466.jpg width=&quot;256&quot; height=&quot;156&quot;&gt;&lt;br&gt;______________________________________&lt;br&gt;     Address: &lt;strong&gt;16955-17071 West Dixie Highway&lt;/strong&gt;&lt;br&gt;     Developer: &lt;strong&gt;Trinsic Residential Group&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;&lt;a href=&quot;https://therealdeal.com/miami/2022/08/16/trinsic-nabs-99m-loan-to-build-north-miami-beach-rentals/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;This will be the&lt;/a&gt; nine-story, 373-unit Aura North Miami Beach with 17,000 square feet of retail. &lt;/strong&gt;&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#             popup_27da788576c631110a178e99fcb84251.setContent(html_a27f288805a4e41e23c2a6af25de26d2);
#
#
#         marker_648d9e0eecd1467e35e14b968c28758a.bindPopup(popup_27da788576c631110a178e99fcb84251)
#         ;
#
#
#
#
#             var marker_3449c39e3e6e45ff311e72d5a6fe1f41 = L.marker(
#                 [25.9280335, -80.1522347],
#                 {}
#             ).addTo(map_d2fd6649aa1dd6e9b8907ebe0a138b8a);
#
#
#         var popup_09d60b5dc6a96defdd90fd0dee5791b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d8cbfa42cfdfe0037a2d42962df2287 = $(`&lt;div id=&quot;html_1d8cbfa42cfdfe0037a2d42962df2287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s11.therealdeal.com/trd/m/up/2022/08/main_MIA_North-Miami-Beach-Tower.jpg width=&quot;256&quot; height=&quot;156&quot;&gt;&lt;br&gt;______________________________________&lt;br&gt;     Address: &lt;strong&gt; 16375 Biscayne Boulevard&lt;/strong&gt;&lt;br&gt;     Developer: &lt;strong&gt;Estate Companies &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;&lt;a href=&quot;https://therealdeal.com/miami/2022/08/15/estate-proposes-360-unit-north-miami-beach-rental-tower/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;This will be a&lt;/a&gt; 28-story, 363-unit Soleste on the Bay tower with 14,000 square feet of retail. It will rise on the lot immediarely south of Estate&#x27;s other North Miami Beach apartment tower, which is under construction and I have provided info on next. &lt;/strong&gt;&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#             popup_09d60b5dc6a96defdd90fd0dee5791b5.setContent(html_1d8cbfa42cfdfe0037a2d42962df2287);
#
#
#         marker_3449c39e3e6e45ff311e72d5a6fe1f41.bindPopup(popup_09d60b5dc6a96defdd90fd0dee5791b5)
#         ;
#
#
#
#
#             var marker_a10c245a2d4010577bd5837fcf130c62 = L.marker(
#                 [25.9285698, -80.15203],
#                 {}
#             ).addTo(map_d2fd6649aa1dd6e9b8907ebe0a138b8a);
#
#
#         var popup_d9fe42a3c681adccfc81e29cbc2d7a0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_94273e88123b5de1bfea035b971f3f86 = $(`&lt;div id=&quot;html_94273e88123b5de1bfea035b971f3f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s11.therealdeal.com/trd/m/up/2020/12/1200-Estate-Companies-pay-13M-for-North-Miami-Beach-apartments-dev-site-650x405.jpg width=&quot;256&quot; height=&quot;156&quot;&gt;&lt;br&gt;______________________________________&lt;br&gt;     Address: &lt;strong&gt; 16395 Biscayne Boulevard&lt;/

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Bay_Harbor_Resi_pipeline
