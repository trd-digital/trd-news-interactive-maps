# %% [markdown]
# ## Imports

# %%
from geopy.geocoders import GoogleV3
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import urllib3
import re
from textwrap import shorten
import os

# %%
df = pd.read_csv('map_NorthMiamiBeach_popup_pin - Sheet1.csv')

# %% [markdown]
# ## Image URL collector

# %%
# Drop last n rows of a df. In case there are sums that need clipped
# df.drop(df.tail(n).index, inplace=True)

# %%
df['image_links'] = ''
links = []
for url in df['story_link']:
    try:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        images = soup.find_all('img')
        counter = 0
        for image in images:
            counter += 1
            if 'jpg' in image['src']:
                links.append(image['src'])
                if counter == len(images):
                    links.append('no image found')
                break
    except:
        links.append('no_image')

df['image_links'] = links

# %%
len(links)
# Out:
# 9

# %% [markdown]
# ## Article link formatter

# %%
df["short_description"] = df["description"].apply(lambda s: shorten(s, width=20, placeholder=""))
df['remaining_desc'] = df.apply(lambda row : row['description'].replace(str(row['short_description']), ''), axis=1)
df['remaining_desc']

df["description_link"] = '<a href="' + df["story_link"] + '" target="_blank" rel="noopener noreferrer">' + df["short_description"] + "</a>" + df["remaining_desc"]
df['description_link']
# Out:
# 0    <a href="https://therealdeal.com/miami/2022/08...
# 1    <a href="https://therealdeal.com/miami/2022/08...
# 2    <a href="https://therealdeal.com/miami/2020/12...
# 3    <a href="https://therealdeal.com/miami/2022/08...
# 4    <a href="https://therealdeal.com/miami/2022/08...
# 5    <a href="https://therealdeal.com/miami/2022/07...
# 6    <a href="https://therealdeal.com/miami/2022/03...
# 7    <a href="https://therealdeal.com/miami/2022/03...
# 8    <a href="https://therealdeal.com/miami/2022/04...
# Name: description_link, dtype: object

# %% [markdown]
# ## Google Maps API Geolocater Setup

# %%
# %store -r google_maps_API_Key
geolocator = GoogleV3(api_key=google_maps_API_Key)

# %%
df['geo_address'] = df['full_address'] + ' North Miami Beach, FL'
df['loc'] = df['geo_address'].apply(geolocator.geocode, timeout=10)
df['point'] = df['loc'].apply(lambda loc: tuple(loc.point) if loc else None)
df[['lat','lon','altitude']] = pd.DataFrame(df['point'].to_list(),index=df.index)

# %% [markdown]
# ## Correction Section

# %%
df.columns
# Out:
# Index(['full_address', 'developers', 'units', 'apts_condos', 'land_sale',
#        'loan_amount', 'description', 'story_link', 'story_link_2',
#        'image_links', 'short_description', 'remaining_desc',
#        'description_link', 'geo_address', 'loc', 'point', 'lat', 'lon',
#        'altitude'],
#       dtype='object')

# %%
df
# Out:
#                                         full_address  \
# 0                     16955-17071 West Dixie Highway
# 1                           16375 Biscayne Boulevard
# 2                           16395 Biscayne Boulevard
# 3                        2261 Northeast 164th Street
# 4                          4098 Northeast 167 Street
# 5   1750 and 1775 Northeast 167th Street (This is...
# 6  Southeast corner of Northeast 159th Street and...
# 7                        2050 Northeast 164th Street
# 8                           13899 Biscayne Boulevard
#
#                                           developers  units apts_condos  \
# 0                          Trinsic Residential Group  373.0  apartments
# 2  <a href="https://therealdeal.com/miami/2020/12...
# 3  <a href="https://therealdeal.com/miami/2022/08...
# 4  <a href="https://therealdeal.com/miami/2022/08...
# 5  <a href="https://therealdeal.com/miami/2022/07...
# 6  <a href="https://therealdeal.com/miami/2022/03...
# 7  <a href="https://therealdeal.com/miami/2022/03...
# 8  <a href="https://therealdeal.com/miami/2022/04...
#
#                                          geo_address  \
# 0  16955-17071 West Dixie Highway North Miami Bea...
# 1     16375 Biscayne Boulevard North Miami Beach, FL
# 2     16395 Biscayne Boulevard North Miami Beach, FL
# 3  2261 Northeast 164th Street North Miami Beach, FL
# 4    4098 Northeast 167 Street North Miami Beach, FL
# 5   1750 and 1775 Northeast 167th Street (This is...
# 6  Southeast corner of Northeast 159th Street and...
# 7  2050 Northeast 164th Street North Miami Beach, FL
# 8     13899 Biscayne Boulevard North Miami Beach, FL
#
#                                                  loc  \
# 0  (16955 W Dixie Hwy, North Miami Beach, FL 3316...
# 1  (16375 Biscayne Blvd, Aventura, FL 33160, USA,...
# 2  (16395 Biscayne Blvd, North Miami Beach, FL 33...
# 3  (2261 NE 164th St, North Miami Beach, FL 33160...
# 4  (4098 NE 167th St, North Miami Beach, FL 33160...
# 5  (1775 NE 167th St, North Miami Beach, FL 33162...
# 6  (15540 W Dixie Hwy, North Miami Beach, FL 3316...
# 7  (2050 NE 164th St, North Miami Beach, FL 33162...
# 8  (13899 Biscayne Blvd, North Miami Beach, FL 33...
#
#                                    point        lat        lon  altitude
# 0           (25.932546, -80.152974, 0.0)  25.932546 -80.152974       0.0
# 1         (25.9280335, -80.1522347, 0.0)  25.928034 -80.152235       0.0
# 2           (25.9285698, -80.15203, 0.0)  25.928570 -80.152030       0.0
# 3         (25.9274746, -80.1547639, 0.0)  25.927475 -80.154764       0.0
# 4         (25.9336827, -80.1316907, 0.0)  25.933683 -80.131691       0.0
# 5         (25.9298195, -80.1652049, 0.0)  25.929820 -80.165205       0.0
# 6   (25.919162, -80.15936800000001, 0.0)  25.919162 -80.159368       0.0
# 7          (25.9269576, -80.158881, 0.0)  25.926958 -80.158881       0.0
# 8  (25.9038948, -80.15829599999999, 0.0)  25.903895 -80.158296       0.0

# %% [markdown]
# ## Correction section

# %%
# df.at[0,'Net decline in footprint, in sf']=('Almost 200K sf')
# df.at[1,'Address(es) of space company vacated or plans to vacate, in sf']=('690 East Middlefield Road, Mountain View. Synopsys is subletting the entire building to Waymo.')

### Change value to percent value
### df['percent_change'] = pd.Series(['{0:.2f}%'.format(val) for val in df['percent_change']], index = df.index)

# %% [markdown]
# ## HTML popup formatter

# %%
df.columns
# Out:
# Index(['full_address', 'developers', 'units', 'apts_condos', 'land_sale',
#        'loan_amount', 'description', 'story_link', 'story_link_2',
#        'image_links', 'short_description', 'remaining_desc',
#        'description_link', 'geo_address', 'loc', 'point', 'lat', 'lon',
#        'altitude'],
#       dtype='object')

# %%
def popup_html(row):
    i = row
    address = df['full_address'].iloc[i]
    developer = df['developers'].iloc[i]
    image = df['image_links'].iloc[i]
    description = df['description_link'].iloc[i]
    
    html = '''<!DOCTYPE html>
    <html>
    <img src={} width="256" height="156">'''.format(image) + '''<br>______________________________________<br>
    Address: <strong>{}'''.format(address) + '''</strong><br>
    Developer: <strong>{}'''.format(developer) + '''</strong><br>
    <strong>{}'''.format(description) + '''</strong><br>
    </html>
    '''
    return html

# %% [markdown]
# ### HTML reservoir

# %%
#     Developer(s): <strong><em>{}'''.format(developer) + '''</strong></em><br><br>

# %% [markdown]
# ## Map Maker

# %%
df.description_link[0]
# Out:
# '<a href="https://therealdeal.com/miami/2022/08/16/trinsic-nabs-99m-loan-to-build-north-miami-beach-rentals/" target="_blank" rel="noopener noreferrer">Trinsic Residential</a> paid roughly $18 million for a five-lot assemblage in March, with plans to build a 373-unit apartment complex and 17,000 square feet of retail. This month, the developers scored a $99 million construction loan from TD Bank for the project.'

# %%
import folium
import branca

f = folium.Figure(width=750, height=750)
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=13)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'North Miami Beach Resi Projects')

for i in range(0,len(df)):
    html = popup_html(i)
    iframe = branca.element.IFrame(html=html)
    popup = folium.Popup(folium.Html(html, script=True))
    folium.Marker([df['lat'].iloc[i],df['lon'].iloc[i]],
                 popup=popup).add_to(m)

m.get_root().html.add_child(folium.Element(title_html))
m.fit_bounds(bounds=df[['lat','lon']].mean().to_list(),max_zoom=15)
# m.add_to(f)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_668fa2b24ffcef3a0fbb0c67e2479905 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;North Miami Beach Resi Projects&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_668fa2b24ffcef3a0fbb0c67e2479905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_668fa2b24ffcef3a0fbb0c67e2479905 = L.map(
#                 &quot;map_668fa2b24ffcef3a0fbb0c67e2479905&quot;,
#                 {
#                     center: [25.925571166666668, -80.15393813333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c16d2d73d327bde19df303f3c2e79a49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_668fa2b24ffcef3a0fbb0c67e2479905);
#
#
#             var marker_a80f62ba1eec7e0ba19d06e8cc805753 = L.marker(
#                 [25.932546, -80.152974],
#                 {}
#             ).addTo(map_668fa2b24ffcef3a0fbb0c67e2479905);
#
#
#         var popup_f5250ee1ce2c4a7f4e025d64819a932c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2e25f99c5a983dd1e93fbcb8146e94d7 = $(`&lt;div id=&quot;html_2e25f99c5a983dd1e93fbcb8146e94d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s14.therealdeal.com/trd/m/up/2022/08/Trinsic-starts-on-North-Miami-Beach-rentals-with-99M-loan-705x466.jpg width=&quot;256&quot; height=&quot;156&quot;&gt;&lt;br&gt;______________________________________&lt;br&gt;     Address: &lt;strong&gt;16955-17071 West Dixie Highway&lt;/strong&gt;&lt;br&gt;     Developer: &lt;strong&gt;Trinsic Residential Group&lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;&lt;a href=&quot;https://therealdeal.com/miami/2022/08/16/trinsic-nabs-99m-loan-to-build-north-miami-beach-rentals/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;Trinsic Residential&lt;/a&gt; paid roughly $18 million for a five-lot assemblage in March, with plans to build a 373-unit apartment complex and 17,000 square feet of retail. This month, the developers scored a $99 million construction loan from TD Bank for the project.&lt;/strong&gt;&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#             popup_f5250ee1ce2c4a7f4e025d64819a932c.setContent(html_2e25f99c5a983dd1e93fbcb8146e94d7);
#
#
#         marker_a80f62ba1eec7e0ba19d06e8cc805753.bindPopup(popup_f5250ee1ce2c4a7f4e025d64819a932c)
#         ;
#
#
#
#
#             var marker_24f25a0c4abc6d924cd52842eae96a5a = L.marker(
#                 [25.9280335, -80.1522347],
#                 {}
#             ).addTo(map_668fa2b24ffcef3a0fbb0c67e2479905);
#
#
#         var popup_af965a5c1f095bd6cbf9ae3ea152eae9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b4eb3515bcb8f366284c6cbf74e979aa = $(`&lt;div id=&quot;html_b4eb3515bcb8f366284c6cbf74e979aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s11.therealdeal.com/trd/m/up/2022/08/main_MIA_North-Miami-Beach-Tower.jpg width=&quot;256&quot; height=&quot;156&quot;&gt;&lt;br&gt;______________________________________&lt;br&gt;     Address: &lt;strong&gt; 16375 Biscayne Boulevard&lt;/strong&gt;&lt;br&gt;     Developer: &lt;strong&gt;Estate Companies &lt;/strong&gt;&lt;br&gt;     &lt;strong&gt;&lt;a href=&quot;https://therealdeal.com/miami/2022/08/15/estate-proposes-360-unit-north-miami-beach-rental-tower/&quot; target=&quot;_blank&quot; rel=&quot;noopener noreferrer&quot;&gt;The Estate Companies&lt;/a&gt; is planning a 28-story, 363-unit rental tower named Soleste on the Bay. Plans call for 14,000 square feet of ground-floor retail and 645 parking spaces, according to the developer’s application to the city. Form Group is the architect. This project is immediately south of the Soleste NoMi project the company is developing.&lt;/strong&gt;&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#             popup_af965a5c1f095bd6cbf9ae3ea152eae9.setContent(html_b4eb3515bcb8f366284c6cbf74e979aa);
#
#
#         marker_24f25a0c4abc6d924cd52842eae96a5a.bindPopup(popup_af965a5c1f095bd6cbf9ae3ea152eae9)
#         ;
#
#
#
#
#             var marker_58774b5c4277a137300e07f06fb918b1 = L.marker(
#                 [25.9285698, -80.15203],
#                 {}
#             ).addTo(map_668fa2b24ffcef3a0fbb0c67e2479905);
#
#
#         var popup_a9611323d9058500d888ac1d05ba3504 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fcd937e45b6538591fdf51d79c65291e = $(`&lt;div id=&quot;html_fcd937e45b6538591fdf51d79c65291e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;img src=https://s11.therealdeal.com/trd/m/up/2020/

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/north_miami_beach
