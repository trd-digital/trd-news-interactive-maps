# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_March_April.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'View Doc', 'Doc Number',
#        'Doc Recorded', 'Doc Executed', 'Doc Type', 'Consi. Amt.',
#        '1st Grantor', '1st Grantee', 'Assoc. Doc#', '1st PIN', 'deed_urls'],
#       dtype='object')

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'])

# %% [markdown]
# ## Data Stuff

# %%
old_month = 3
new_month = 4

# %%
# Count number of new month dates
mar_dates_count = len(df.loc[df['Doc Recorded'].dt.month == old_month])

print(f'Number of March dates: {mar_dates_count}')
# Out:
# Number of March dates: 1210

# %%
# Count number of old month dates
apr_dates_count = len(df.loc[df['Doc Recorded'].dt.month == new_month])

print(f'Number of April dates: {apr_dates_count}')
# Out:
# Number of April dates: 567

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
# create new column and assign colors based on month
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'orange' if x.month == old_month else 'red' if x.month == new_month else '')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 1394

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
df
# Out:
#      View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type
# 0        View  2307445306   2023-03-15          NaN  LIS PENDENS FORECLOSURE  \
# 1        View  2307445303   2023-03-15          NaN  LIS PENDENS FORECLOSURE
# 2        View  2307445176   2023-03-15          NaN  LIS PENDENS FORECLOSURE
# 3        View  2307445023   2023-03-15    3/10/2023  LIS PENDENS FORECLOSURE
# 4        View  2307445012   2023-03-15     3/9/2023  LIS PENDENS FORECLOSURE
# ...       ...         ...          ...          ...                      ...
# 1772     View  2306715004   2023-03-08          NaN  LIS PENDENS FORECLOSURE
# 1773     View  2306710209   2023-03-08     3/2/2023  LIS PENDENS FORECLOSURE
# 1774     View  2306710207   2023-03-08     3/2/2023  LIS PENDENS FORECLOSURE
# 1775     View  2306710206   2023-03-08     3/2/2023  LIS PENDENS FORECLOSURE
# 1776     View  2306710205   2023-03-08     3/2/2023  LIS PENDENS FORECLOSURE
# 1774  https://crs.cookcountyclerkil.gov/Document/Det...      $95,144.00
# 1775  https://crs.cookcountyclerkil.gov/Document/Det...      $68,000.00
# 1776  https://crs.cookcountyclerkil.gov/Document/Det...     $126,000.00
#
#                                          geo_address
# 0      8635 W CAREY AVE, RIVER GROVE Cook County, IL  \
# 1          9652 S UNION AVE, CHICAGO Cook County, IL
# 2       8001 S PHILLIPS AVE, CHICAGO Cook County, IL
# 3     151 N KENILWORTH AVE, OAK PARK Cook County, IL
# 4       7215 S LAWNDALE AVE, CHICAGO Cook County, IL
# ...                                              ...
# 1772      611 W RANDOLPH ST, CHICAGO Cook County, IL
# 1773        3045 E 138TH PL, BURNHAM Cook County, IL
# 1774  1285 BURNHAM AVE, CALUMET CITY Cook County, IL
# 1775   15804 LARAMIE AVE, OAK FOREST Cook County, IL
# 1776     3234 GRAND BLVD, BROOKFIELD Cook County, IL
#
#                               geocoded        lat        lon
# 0     (41.9284093, -87.84204489999999)  41.928409 -87.842045
# 1            (41.7181068, -87.6410203)  41.718107 -87.641020
# 2     (41.7497311, -87.56471479999999)  41.749731 -87.564715
# 3     (41.8890712, -87.79792750000001)  41.889071 -87.797928
# 4            (41.7619202, -87.7147024)  41.761920 -87.714702
# ...                                ...        ...        ...
# 1772         (41.8842265, -87.6433624)  41.884226 -87.643362
# 1773         (41.6442757, -87.5432361)  41.644276 -87.543236
# 1774         (41.5978364, -87.5391798)  41.597836 -87.539180
# 1775         (41.6045738, -87.7468263)  41.604574 -87.746826
# 1776         (41.8316507, -87.8577186)  41.831651 -87.857719
#
# [1394 rows x 19 columns]

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format('March & April')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_orange = folium.FeatureGroup(name='April') ## new month
fg_red = folium.FeatureGroup(name='March') ## old month

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'orange':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=10,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)
    elif pd.notnull(lat) and pd.notnull(lon):
        marker = folium.CircleMarker(
            location=[lat,lon],
            raidus=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    else:
        continue

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_red.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4daf10b90f0128aba5b8d897a17411da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;March &amp; April&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4daf10b90f0128aba5b8d897a17411da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4daf10b90f0128aba5b8d897a17411da = L.map(
#                 &quot;map_4daf10b90f0128aba5b8d897a17411da&quot;,
#                 {
#                     center: [41.78937487038102, -87.7273877163192],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_4ff044fe17393fcfb9d2b0dff35f1811 = L.featureGroup(
#                 {}
#             ).addTo(map_4daf10b90f0128aba5b8d897a17411da);
#
#
#             var circle_marker_090263948919d31872f62a56bddf278b = L.circleMarker(
#                 [41.9284093, -87.84204489999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_4ff044fe17393fcfb9d2b0dff35f1811);
#
#
#         var popup_72fede1d47d8365f2143940f88581ed1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_d713b43af68633e9090c97ecd4951a4f = $(`&lt;div id=&quot;html_d713b43af68633e9090c97ecd4951a4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;FEDERAL HOME LOAN MTG CORP TR&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;WETER DALE R&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;12-26-308-027-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;8635 W CAREY AVE, RIVER GROVE&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$143,400.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_72fede1d47d8365f2143940f88581ed1.setContent(html_d713b43af68633e9090c97ecd4951a4f);
#
#
#
#         circle_marker_090263948919d31872f62a56bddf278b.bindPopup(popup_72fede1d47d8365f2143940f88581ed1)
#         ;
#
#
#
#
#             var circle_marker_a906a5e40087495b69c1be7b56ecb079 = L.circleMarker(
#                 [41.7181068, -87.6410203],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_4ff044fe17393fcfb9d2b0dff35f1811);
#
#
#         var popup_ca59aae2c25a952e733e8ba3fc0b1923 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_e952b851e79a9c8a5c4110e49c34679f = $(`&lt;div id=&quot;html_e952b851e79a9c8a5c4110e49c34679f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;SPECIALIZED LOAN SERVICING LLC&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;DALY JOHN&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;25-09-109-101-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;9652 S UNION AVE, CHICAGO&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$141,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ca59aae2c25a952e733e8ba3fc0b1923.setContent(html_e952b851e79a9c8a5c4110e49c34679f);
#
#
#
#         circle_marker_a906a5e40087495b69c1be7b56ecb079.bindPopup(popup_ca59aae2c25a952e733e8ba3fc0b1923)
#         ;
#
#
#
#
#             var circle_marker_946d6ce8024b3b4666606634ecacc41d = L.circleMarker(
#                 [41.7497311, -87.56471479999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_4ff044fe17393fcfb9d2b0dff35f1811);
#
#
#         var popup_ef8dfd7b852ea938338b5cb46cca6c71 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f45fe1419ab2e0fa914c98c36fbbe4ae = $(`&lt;div id=&quot;html_f45fe1419ab2e0fa914c98c36fbbe4ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lende

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_mar_apr

# %% [markdown]
# ## Stats for story

# %%
# Count number of old month dates
mar_dates_count = len(df.loc[df['Doc Recorded'].dt.month == old_month])

print(f'Number of March dates: {mar_dates_count}')

# Count number of new month dates
apr_dates_count = len(df.loc[df['Doc Recorded'].dt.month == new_month])

print(f'Number of April dates: {apr_dates_count}')
# Out:
# Number of March dates: 912
# Number of April dates: 482

# %%
mar = df.loc[df['Doc Recorded'].dt.month == old_month]
apr = df.loc[df['Doc Recorded'].dt.month == new_month]

# %%
print(f'March: ${mar.mortgage_amount_int.sum():,}')
print('-------')
print(f'April: ${apr.mortgage_amount_int.sum():,}')
print('-------')
print(f'Total: ${mar.mortgage_amount_int.sum() + apr.mortgage_amount_int.sum():,}')
# Out:
# March: $182,659,953
# -------
# April: $103,713,597
# -------
# Total: $286,373,550

# %%
70 + 49 + 46
# Out:
# 165

# %%
mar['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# US BK NATL ASSN                           69
# LAKEVIEW LOAN SERVICING LLC               50
# US BK NATL ASSN TR                        49
# US BK TRUST NATL ASSN TR                  45
# NATIONSTAR MTG LLC                        44
# NEWREZ LLC                                38
# FREEDOM MTG CORP                          33
# WILMINGTON SAV FUND SOC FSB TR            32
# WELLS FARGO BK NA                         25
# FIFTH THIRD BK NATL ASSN                  22
# PENNYMAC LOAN SERVICES LLC                21
# CARRINGTON MTG SERVICES LLC               19
# LOANDEPOTCOM LLC                          18
# FEDERAL HOME LOAN MTG CORP TR             16
# JPMORGAN CHASE BK NATL ASSN               14
# DEUTSCHE BK NATL TRUST CO TR              14
# BANK OF AMER NA                           12
# THE BK OF NEW YORK MELLON TR              12
# ROCKET MTG LLC                            10
# CITIZENS BK NA                             8
# METROPOLITAN LIFE INST CO                  8
# PNC BK NATL ASSN                           8
# CROSSCOUNTRY MTG LLC                       7
# MORTGAGE ASSETS MGMT LLC                   6
# BMO HARRIS BK NA                           6
# PLANET HOME LENDG LLC                      6
# M&T BK                                     6
# SPECIALIZED LOAN SERVICING LLC             6
# WELLS FARGO BK NA TR                       5
# MIDFIRST BK                                5
# CITIMORTGAGE INC                           5
# BANK OF NEW YORK MELLON TRUST CO NA TR     5
# LIMA ONE CAP LLC                           5
# HSBC BK USA NATL ASSN TR                   5
# GN BK                                      5
# PHH MTG CORP                               4
# FIFTH THIRD BK NA                          4
# RUSHMORE LOAN MGMT SERVICES LLC            4
# CIVIC REAL ESTATE HOLDINGS III LLC         4
# LOANCARE LLC                               4
# WELLS FARGO BK NATL ASSN TR                4
# MCLP ASSET CO INC                          4
# CONSUMERS CU                               4
# HSBC BK USA NA TR                          4
# SELECT PORTFOLIO SERVICING INC             3
# AMERIHOME MTG CO LLC                       3
# HIBERNIAN GRP LLC                          3
#                                  ..
# ZAMBRANO ANTONIO                  1
# OSZAKEWSKI CHRISTOPHER            1
# MERINO PATRICIA                   1
# REED DAMIEN J                     1
# DAVIS RICHARD A                   1
# Name: count, Length: 351, dtype: int64

# %%
df.to_csv('mar_apr_foreclosures.csv')

# %%
apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
apr['mortgage_amount_int'] = apr['mortgage_amount'].str.replace('$','')
apr['mortgage_amount_int'] = apr['mortgage_amount_int'].str.replace(',','')
apr = apr.loc[apr['mortgage_amount_int'] != 'NA']
apr['mortgage_amount_int'] = apr['mortgage_amount_int'].astype(float).fillna(0).astype(int)
apr['mortgage_amount_int'].median()
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/2478360253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apr['mortgage_amount_int'] = apr['mortgage_amount'].str.replace('$','')
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/2478360253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apr['mortgage_amount_int'] = apr['mortgage_amount_int'].str.replace(',','')
# 174510.0

# %%
mar['mortgage_amount_int'] = mar['mortgage_amount'].str.replace('$','')
mar['mortgage_amount_int'] = mar['mortgage_amount_int'].str.replace(',','')
mar = mar.loc[mar['mortgage_amount_int'] != 'NA']
mar['mortgage_amount_int'] = mar['mortgage_amount_int'].astype(float).fillna(0).astype(int)
mar['mortgage_amount_int'].median()
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/1868218194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar['mortgage_amount_int'] = mar['mortgage_amount'].str.replace('$','')
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/1868218194.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar['mortgage_amount_int'] = mar['mortgage_amount_int'].str.replace(',','')
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_21743/1868218194.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar['mortgage_amount_int'] = mar['mortgage_amount_int'].astype(float).fillna(0).astype(int)
# 166920.0

# %% [markdown]
# ## Boundary Analysis

# %%
boundaries = gpd.read_file('Boundaries - Neighborhoods.geojson')

# %%
# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(apr['lon'], apr['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_apr = gpd.GeoDataFrame(apr, geometry=geometry)

gdf_filings_apr.crs = 'EPSG:4326'
gdf_filings_apr = gdf_filings_apr.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_apr = gpd.sjoin(gdf_filings_apr, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(mar['lon'], mar['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_mar = gpd.GeoDataFrame(mar, geometry=geometry)

gdf_filings_mar.crs = 'EPSG:4326'
gdf_filings_mar = gdf_filings_mar.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_mar = gpd.sjoin(gdf_filings_feb, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# %%
counts_mar

# %%
counts_apr
