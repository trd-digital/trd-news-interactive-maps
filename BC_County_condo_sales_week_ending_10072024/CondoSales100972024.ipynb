# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Sep. 29th Oct. 6th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE SOLD DATE PROPERTY TYPE                     ADDRESS        CITY  \
# 1  PAST SALE       NaN   Condo/Co-op  1085 NW 85th Ter Unit C113  Plantation
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33322.0  123000.0   1.0    2.0  ...    NaN
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE  MLS#  FAVORITE  \
# 1  https://www.redfin.com/FL/Plantation/1085-NW-8...     NaN   NaN         N
#
#   INTERESTED  LATITUDE  LONGITUDE
# 1          Y  26.13746 -80.263517
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 3    PAST SALE 2024-10-04   Condo/Co-op           1000 SE 4th St #315
# 77   PAST SALE 2024-10-04   Condo/Co-op  8300 Sunrise Lakes Blvd #310
# 33   PAST SALE 2024-10-04   Condo/Co-op       5100 Washington St #104
# 40   PAST SALE 2024-10-04   Condo/Co-op          1100 NE 9th Ave #107
# 47   PAST SALE 2024-10-04   Condo/Co-op        4143 N Ocean Blvd #101
# ..         ...        ...           ...                           ...
# 138  PAST SALE        NaT   Condo/Co-op      3901 S Ocean Dr Unit 12P
# 139  PAST SALE        NaT   Condo/Co-op                  621 Durham W
# 140  PAST SALE        NaT   Condo/Co-op           9134 Whistable Walk
# 141  PAST SALE        NaT   Condo/Co-op     510 N Ocean Blvd Unit R40
# 142  PAST SALE        NaT   Condo/Co-op          5881 NW 16th Pl #316
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 3    Fort Lauderdale                FL             33301.0  290000.0   1.0
# 77           Sunrise                FL             33322.0  130000.0   2.0
# 33         Hollywood                FL             33021.0  240000.0   2.0
# 40   Fort Lauderdale                FL             33304.0  125000.0   1.0
# 47   Fort Lauderdale                FL             33308.0  250000.0   2.0
# ..               ...               ...                 ...       ...   ...
# 138        Hollywood                FL             33019.0  615000.0   2.0
# 139  Deerfield Beach                FL             33442.0  175000.0   2.0
# 140          Tamarac                FL             33321.0  329000.0   2.0
# 141    Pompano Beach                FL             33062.0  725000.0   2.0
# 142          Sunrise                FL             33313.0  150000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 3      1.0  ...   Sold                         NaN                       NaN
# 77     2.0  ...   Sold                         NaN                       NaN
# 33     2.0  ...   Sold                         NaN                       NaN
# 40     1.0  ...   Sold                         NaN                       NaN
# 47     2.0  ...   Sold                         NaN                       NaN
# ..     ...  ...    ...                         ...                       ...
# 138    2.0  ...    NaN                         NaN                       NaN
# 139    2.0  ...    NaN                         NaN                       NaN
# 140    2.0  ...    NaN                         NaN                       NaN
# 141    2.0  ...    NaN                         NaN                       NaN
# 142    2.0  ...    NaN                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 3    https://www.redfin.com/FL/Fort-Lauderdale/1000...       MARMLS
# 77   https://www.redfin.com/FL/Sunrise/8300-Sunrise...  Beaches MLS
# 33   https://www.redfin.com/FL/Hollywood/5100-Washi...  Beaches MLS
# 40   https://www.redfin.com/FL/Fort-Lauderdale/1100...  Beaches MLS
# 47   https://www.redfin.com/FL/Fort-Lauderdale/4143...  Beaches MLS
# ..                                                 ...          ...
# 138  https://www.redfin.com/FL/Hollywood/3901-S-Oce...          NaN
# 139  https://www.redfin.com/FL/Deerfield-Beach/621-...          NaN
# 140  https://www.redfin.com/FL/Tamarac/9134-Whistab...          NaN
# 141  https://www.redfin.com/FL/Pompano-Beach/510-N-...          NaN
# 142  https://www.redfin.com/FL/Sunrise/5881-NW-16th...          NaN
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 3    A11669663         N          Y  26.117776 -80.133195
# 77   F10444819         N          Y  26.163347 -80.263033
# 33   F10454437         N          Y  26.002413 -80.194594
# 40   F10457679         N          Y  26.139207 -80.134176
# 47   F10455430         N          Y  26.180302 -80.098396
# ..         ...       ...        ...        ...        ...
# 138        NaN         N          Y  25.988153 -80.118301
# 139        NaN         N          Y  26.315473 -80.138519
# 140        NaN         N          Y  26.196196 -80.272993
# 141        NaN         N          Y  26.240377 -80.087999
# 142        NaN         N          Y  26.146316 -80.228689
#
# [142 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 142

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $388,150

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $305

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $55,117,348

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()

## Clean Data
# Out:
# Input county name:
# Broward County
# Input Previous Week Condo Sales Total (number units sold):
# 126
# Input Previous Week Condo Average Sales Price:
# 343326
# Input Previous Week Condo Average PSF:
# 275
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 43_300_000

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33301.0  3450000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.5  Casa Murano       3108.0       NaN      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1110.0     2521.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...     Richard Chong
#
#              list_broker_name_1 list_agent_name_2  \
# 0  Charles Rutenberg Realty FTL   Stephen Carfray
#
#              list_broker_name_2  buy_agent_name_1     buy_broker_name_1  \
# 0  Charles Rutenberg Realty FTL  Patrick Barnicle  Compass Florida, LLC
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
# 1  PAST SALE 2024-10-03   Condo/Co-op           3535 S Ocean Dr #1506
# 2  PAST SALE 2024-10-02   Condo/Co-op         5000 N Ocean Blvd #1711
# 3  PAST SALE 2024-09-30   Condo/Co-op           3101 S Ocean Dr #3205
# 4  PAST SALE 2024-10-02   Condo/Co-op  2200 S Ocean Ln Unit 401 & 402
# 5  PAST SALE 2024-09-30   Condo/Co-op          5000 N Ocean Blvd #912
# 6  PAST SALE 2024-10-02   Condo/Co-op           3101 S Ocean Dr #2605
# 7  PAST SALE 2024-09-30   Condo/Co-op         410 Hendricks Isle #204
# 8  PAST SALE 2024-10-03   Condo/Co-op            2200 S Ocean Ln #205
# 9  PAST SALE 2024-09-30   Condo/Co-op        3900 Galt Ocean Dr #1101
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33301.0  3450000.0
# 1              Hollywood                FL             33019.0  2180000.0
# 2  Lauderdale By The Sea                FL             33308.0  2025000.0
# 3              Hollywood                FL             33019.0  1860000.0
# 4        Fort Lauderdale                FL             33316.0  1750000.0
# 5  Lauderdale By The Sea                FL             33308.0  1750000.0
# 6              Hollywood                FL             33019.0  1450000.0
# 7        Fort Lauderdale                FL             33301.0  1400000.0
# 8        Fort Lauderdale                FL             33316.0  1370000.0
# 9        Fort Lauderdale                FL             33308.0  1250000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    4.5                Casa Murano       3108.0       NaN      2024.0
# 1   3.0    3.5  Diplomat Oceanfront Resid       3030.0       NaN      2007.0
# 2   3.0    2.5           Sea Ranch Club B       2300.0       NaN      1979.0
# 3   3.0    3.0          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   4.0    3.5  POINT OF AMERICAS PHASE I       3621.0       NaN      1971.0
# 5   3.0    2.5          Sea Ranch Club B.       2260.0       NaN      1979.0
# 6   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 7   3.0    3.5       Landings At Las Olas       2687.0       NaN      2005.0
# 8   2.0    2.5  POINT OF AMERICAS PHASE 2       2170.0       NaN      1971.0
# 9   3.0    2.5        PLAYA DEL MAR CONDO       2140.0       NaN      1975.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1110.0     2521.0   Sold
# 1             NaN          719.0     3853.0   Sold
# 2             NaN          880.0     2677.0   Sold
# 3             NaN          879.0     2161.0   Sold
# 4             NaN          483.0     3871.0   Sold
# 5             NaN          774.0     2213.0   Sold
# 6             NaN          686.0     2190.0   Sold
# 7             NaN          521.0     1988.0   Sold
# 8             NaN          631.0     2088.0   Sold
# 9             NaN          584.0     1464.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...  Beaches MLS  F10449275
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10412790
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11618958
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11562880
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10420799
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11554717
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...  Beaches MLS  F10446051
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11604053
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...       MARMLS  A11634288
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
# 1        N          Y  25.992497 -80.117826
# 2        N          Y  26.198972 -80.094812
# 3        N          Y  25.993975 -80.117768
# 4        N          Y  26.095913 -80.106280
# 5        N          Y  26.198972 -80.094812
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.126760 -80.121763
# 8        N          Y  26.095913 -80.106280
# 9        N          Y  26.175849 -80.097707
#
#                                                  url  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...
#
#            list_agent_name_1            list_broker_name_1  \
# 0              Richard Chong  Charles Rutenberg Realty FTL
# 1  Mariolga Lesseur de Parra      Related ISG Realty, LLC.
# 2          Bridget O'Donnell          Compass Florida, LLC
# 3           Stuart Scherline           Marina Realty Group
# 4             Laurie Spector          Compass Florida, LLC
# 5             Shirley Patino                EXP Realty LLC
# 6           Lourdes Maestres          Compass Florida, LLC
# 7              Patricia Huff      Intercoastal Realty  Inc
# 8               Jorge Brandt       United Realty Group Inc
# 9            Mauro Rodriguez       Partnership Realty Inc.
#
#      list_agent_name_2            list_broker_name_2      buy_agent_name_1  \
# 0      Stephen Carfray  Charles Rutenberg Realty FTL      Patrick Barnicle
# 1  Valentina Tischenko      Related ISG Realty, LLC.       Michael Bremser
# 2         David Marder          Compass Florida, LLC          Freda Lisnow
# 3            Alan Pate           Marina Realty Group        Russell Miller
# 4                 None                          None    Nicole Murray Chen
# 5                 None                          None  Elisabeth Van Kleeff
# 6                 None                          None           Marc Kijner
# 7         Richard Huff      Intercoastal Realty  Inc     Bridget O'Donnell
# 8       Mariela Brandt       United Realty Group Inc                  None
# 9                 None                          None                  None
#
#                 buy_broker_name_1 buy_agent_name_2     buy_broker_name_2  \
# 0            Compass Florida, LLC             None                  None
# 1                        LoKation             None                  None
# 2  Better Homes & Gdns RE Fla 1st             None                  None
# 3          Coldwell Banker Realty             None                  None
# 4   Galleria International Realty             None                  None
# 5                        LoKation             None                  None
# 6            Compass Florida, LLC             None                  None
# 7            Compass Florida, LLC     David Marder  Compass Florida, LLC
# 8                            None             None                  None
# 9                            None             None                  None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26971998065e6e801d3a68666dfdf4d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Sep. 29th - Oct. 6th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26971998065e6e801d3a68666dfdf4d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26971998065e6e801d3a68666dfdf4d0 = L.map(
#                 &quot;map_26971998065e6e801d3a68666dfdf4d0&quot;,
#                 {
#                     center: [26.153844616901406, -80.17483444788733],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_7943bf4d1dcc62c3e4f875885b8c2132 = L.featureGroup(
#                 {}
#             ).addTo(map_26971998065e6e801d3a68666dfdf4d0);
#
#
#             var marker_23d0dca4077f1b4e97c1598bb144ecb3 = L.marker(
#                 [26.1256721, -80.1208917],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7943bf4d1dcc62c3e4f875885b8c2132);
#
#
#             var icon_4365e9990c4b163493722abfd063fcd7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_23d0dca4077f1b4e97c1598bb144ecb3.setIcon(icon_4365e9990c4b163493722abfd063fcd7);
#
#
#         var popup_d073cd1069afaf09e3876975ef6b514c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_929c1eb7308b82cbd131269ada096a38 = $(`&lt;div id=&quot;html_929c1eb7308b82cbd131269ada096a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;141 Isle Of Venice Dr Unit 3-S&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,450,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,110.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,108.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2024.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_d073cd1069afaf09e3876975ef6b514c.setContent(html_929c1eb7308b82cbd131269ada096a38);
#
#
#
#         marker_23d0dca4077f1b4e97c1598bb144ecb3.bindPopup(popup_d073cd1069afaf09e3876975ef6b514c)
#         ;
#
#
#
#
#             var feature_group_f3f3dae7606a81b2cc4e19930e67a3c7 = L.featureGroup(
#                 {}
#             ).addTo(map_26971998065e6e801d3a68666dfdf4d0);
#
#
#             var marker_34fc0d7d92f74e83fde8f77776d0ee97 = L.marker(
#                 [25.9924975, -80.117826],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_f3f3dae7606a81b2cc4e19930e67a3c7);
#
#
#             var icon_c2db06961da991893db316142d45a388 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34fc0d7d92f74e83fde8f77776d0ee97.setIcon(icon_c2db06961da991893db316142d45a388);
#
#
#         var popup_0a27c7e5838264570abe808943123333 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_f48b98d4cde124e260f3b20e6030ef3c = $(`&lt;div id=&quot;html_f48b98d4cde124e260f3b20e6030ef3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;3535 S Ocean Dr #1506&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,180,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$719.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,030.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2007.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_0a27c7e5838264570abe808943123333.setContent(html_f48b98d4cde124e260f3b20e6030ef3c);
#
#
#
#         marker_34fc0d7d92f74e83fde8f77776d0ee97.bindPopup(popup_0a27c7e5838264570abe808943123333)
#         ;
#
#
#
#
#             var marker_0b7f8af5b538c98b8012cac56038be65 = L.marker(
#                 [26.1989718, -80.0948123],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_f3f3dae7606a81b2cc4e19930e67a3c7);
#
#
#             var icon_2fcc038942406d222629366e8505e546 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0b7f8af5b538c98b8012cac56038be65.setIcon(icon_2fcc038942406d222629366e8505e546);
#
#
#         var popup_192767d0f810279b8782ef7994e4f7e5 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2e74731feceac58d34381d4dd36b5390 = $(

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33301.0  3450000.0   3.0
#
#    BATHS     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    4.5  Casa Murano       3108.0       NaN      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1110.0     2521.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...     Richard Chong
#
#              list_broker_name_1 list_agent_name_2  \
# 0  Charles Rutenberg Realty FTL   Stephen Carfray
#
#              list_broker_name_2  buy_agent_name_1     buy_broker_name_1  \
# 0  Charles Rutenberg Realty FTL  Patrick Barnicle  Compass Florida, LLC
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/BC_County_condo_sales_week_ending_10072024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Casa Murano at 141 Isle Of Venice Dr Unit 3-S in Fort Lauderdale'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
# 1  PAST SALE 2024-10-03   Condo/Co-op           3535 S Ocean Dr #1506
# 2  PAST SALE 2024-10-02   Condo/Co-op         5000 N Ocean Blvd #1711
# 3  PAST SALE 2024-09-30   Condo/Co-op           3101 S Ocean Dr #3205
# 4  PAST SALE 2024-10-02   Condo/Co-op  2200 S Ocean Ln Unit 401 & 402
# 5  PAST SALE 2024-09-30   Condo/Co-op          5000 N Ocean Blvd #912
# 6  PAST SALE 2024-10-02   Condo/Co-op           3101 S Ocean Dr #2605
# 7  PAST SALE 2024-09-30   Condo/Co-op         410 Hendricks Isle #204
# 8  PAST SALE 2024-10-03   Condo/Co-op            2200 S Ocean Ln #205
# 9  PAST SALE 2024-09-30   Condo/Co-op        3900 Galt Ocean Dr #1101
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33301.0  3450000.0
# 1              Hollywood                FL             33019.0  2180000.0
# 2  Lauderdale By The Sea                FL             33308.0  2025000.0
# 3              Hollywood                FL             33019.0  1860000.0
# 4        Fort Lauderdale                FL             33316.0  1750000.0
# 5  Lauderdale By The Sea                FL             33308.0  1750000.0
# 6              Hollywood                FL             33019.0  1450000.0
# 7        Fort Lauderdale                FL             33301.0  1400000.0
# 8        Fort Lauderdale                FL             33316.0  1370000.0
# 9        Fort Lauderdale                FL             33308.0  1250000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    4.5                Casa Murano       3108.0       NaN      2024.0
# 1   3.0    3.5  Diplomat Oceanfront Resid       3030.0       NaN      2007.0
# 2   3.0    2.5           Sea Ranch Club B       2300.0       NaN      1979.0
# 3   3.0    3.0          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   4.0    3.5  POINT OF AMERICAS PHASE I       3621.0       NaN      1971.0
# 5   3.0    2.5          Sea Ranch Club B.       2260.0       NaN      1979.0
# 6   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 7   3.0    3.5       Landings At Las Olas       2687.0       NaN      2005.0
# 8   2.0    2.5  POINT OF AMERICAS PHASE 2       2170.0       NaN      1971.0
# 9   3.0    2.5        PLAYA DEL MAR CONDO       2140.0       NaN      1975.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1110.0     2521.0   Sold
# 1             NaN          719.0     3853.0   Sold
# 2             NaN          880.0     2677.0   Sold
# 3             NaN          879.0     2161.0   Sold
# 4             NaN          483.0     3871.0   Sold
# 5             NaN          774.0     2213.0   Sold
# 6             NaN          686.0     2190.0   Sold
# 7             NaN          521.0     1988.0   Sold
# 8             NaN          631.0     2088.0   Sold
# 9             NaN          584.0     1464.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...  Beaches MLS  F10449275
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10412790
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11618958
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11562880
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10420799
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11554717
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...  Beaches MLS  F10446051
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11604053
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...       MARMLS  A11634288
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
# 1        N          Y  25.992497 -80.117826
# 2        N          Y  26.198972 -80.094812
# 3        N          Y  25.993975 -80.117768
# 4        N          Y  26.095913 -80.106280
# 5        N          Y  26.198972 -80.094812
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.126760 -80.121763
# 8        N          Y  26.095913 -80.106280
# 9        N          Y  26.175849 -80.097707
#
#                                                  url  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...
#
#            list_agent_name_1            list_broker_name_1  \
# 0              Richard Chong  Charles Rutenberg Realty FTL
# 1  Mariolga Lesseur de Parra      Related ISG Realty, LLC.
# 2          Bridget O'Donnell          Compass Florida, LLC
# 3           Stuart Scherline           Marina Realty Group
# 4             Laurie Spector          Compass Florida, LLC
# 5             Shirley Patino                EXP Realty LLC
# 6           Lourdes Maestres          Compass Florida, LLC
# 7              Patricia Huff      Intercoastal Realty  Inc
# 8               Jorge Brandt       United Realty Group Inc
# 9            Mauro Rodriguez       Partnership Realty Inc.
#
#      list_agent_name_2            list_broker_name_2      buy_agent_name_1  \
# 0      Stephen Carfray  Charles Rutenberg Realty FTL      Patrick Barnicle
# 1  Valentina Tischenko      Related ISG Realty, LLC.       Michael Bremser
# 2         David Marder          Compass Florida, LLC          Freda Lisnow
# 3            Alan Pate           Marina Realty Group        Russell Miller
# 4                 None                          None    Nicole Murray Chen
# 5                 None                          None  Elisabeth Van Kleeff
# 6                 None                          None           Marc Kijner
# 7         Richard Huff      Intercoastal Realty  Inc     Bridget O'Donnell
# 8       Mariela Brandt       United Realty Group Inc                  None
# 9                 None                          None                  None
#
#                 buy_broker_name_1 buy_agent_name_2     buy_broker_name_2  \
# 0            Compass Florida, LLC             None                  None
# 1                        LoKation             None                  None
# 2  Better Homes & Gdns RE Fla 1st             None                  None
# 3          Coldwell Banker Realty             None                  None
# 4   Galleria International Realty             None                  None
# 5                        LoKation             None                  None
# 6            Compass Florida, LLC             None                  None
# 7            Compass Florida, LLC     David Marder  Compass Florida, LLC
# 8                            None             None                  None
# 9                            None             None                  None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Casa Murano at 141 Isle Of Venice Dr Unit 3-S ...
# 1     2    blue  Diplomat Oceanfront Resid at 3535 S Ocean Dr #...
# 2     3    blue  Sea Ranch Club B at 5000 N Ocean Blvd #1711 in...
# 3     4    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #3205 in ...
# 4     5    blue  POINT OF AMERICAS PHASE I at 2200 S Ocean Ln U...
# 5     6    blue  Sea Ranch Club B. at 5000 N Ocean Blvd #912 in...
# 6     7    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #2605 in ...
# 7     8    blue  Landings At Las Olas at 410 Hendricks Isle #20...
# 8     9    blue  POINT OF AMERICAS PHASE 2 at 2200 S Ocean Ln #...
# 9    10    blue  PLAYA DEL MAR CONDO at 3900 Galt Ocean Dr #110...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Casa Murano closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $1,250,000M to $3,450,000M
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Broward County condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Lauderdale By The Sea, Fort Lauderdale, Hollywood
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 142 condo sales totaling $55,117,348 million from Sep. 29th to Oct. 6th. The previous week, brokers closed 126 condo sales totaling $43,300,000.
#
# Last week’s units sold for an average of $388,150, higher than the $343,326 average price from the previous week. The average price per square foot rose to $305 from $275, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,250,000.0 million to $3,450,000.0 million.
#
# Casa Murano at 141 Isle Of Venice Dr Unit 3-S in Fort Lauderdale took the top spot with a $3,450,000.0 million closing. The sale closed at $1,110.0 per square foot.
#
# Richard Chong with Charles Rutenberg Realty FTL, and Stephen Carfray with Charles Rutenberg Realty FTL had the listing.
# Patrick Barnicle with Compass Florida, LLC, and None with None represented the buyer.
#
# Diplomat Oceanfront Resid at 3535 S Ocean Dr #1506 in Hollywood, closed for the second highest amount, $2,180,000.0, or $719.0 per square foot.
#
# Mariolga Lesseur de Parra with Related ISG Realty, LLC., and Valentina Tischenko with Related ISG Realty, LLC. had the listing.
# Michael Bremser with LoKation, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/BC_County_condo_sales_week_ending_10072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 29th to Oct. 6th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
# 1  PAST SALE 2024-10-03   Condo/Co-op           3535 S Ocean Dr #1506
# 2  PAST SALE 2024-10-02   Condo/Co-op         5000 N Ocean Blvd #1711
# 3  PAST SALE 2024-09-30   Condo/Co-op           3101 S Ocean Dr #3205
# 4  PAST SALE 2024-10-02   Condo/Co-op  2200 S Ocean Ln Unit 401 & 402
# 5  PAST SALE 2024-09-30   Condo/Co-op          5000 N Ocean Blvd #912
# 6  PAST SALE 2024-10-02   Condo/Co-op           3101 S Ocean Dr #2605
# 7  PAST SALE 2024-09-30   Condo/Co-op         410 Hendricks Isle #204
# 8  PAST SALE 2024-10-03   Condo/Co-op            2200 S Ocean Ln #205
# 9  PAST SALE 2024-09-30   Condo/Co-op        3900 Galt Ocean Dr #1101
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33301.0  3450000.0
# 1              Hollywood                FL             33019.0  2180000.0
# 2  Lauderdale By The Sea                FL             33308.0  2025000.0
# 3              Hollywood                FL             33019.0  1860000.0
# 4        Fort Lauderdale                FL             33316.0  1750000.0
# 5  Lauderdale By The Sea                FL             33308.0  1750000.0
# 6              Hollywood                FL             33019.0  1450000.0
# 7        Fort Lauderdale                FL             33301.0  1400000.0
# 8        Fort Lauderdale                FL             33316.0  1370000.0
# 9        Fort Lauderdale                FL             33308.0  1250000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    4.5                Casa Murano       3108.0       NaN      2024.0
# 1   3.0    3.5  Diplomat Oceanfront Resid       3030.0       NaN      2007.0
# 2   3.0    2.5           Sea Ranch Club B       2300.0       NaN      1979.0
# 3   3.0    3.0          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   4.0    3.5  POINT OF AMERICAS PHASE I       3621.0       NaN      1971.0
# 5   3.0    2.5          Sea Ranch Club B.       2260.0       NaN      1979.0
# 6   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 7   3.0    3.5       Landings At Las Olas       2687.0       NaN      2005.0
# 8   2.0    2.5  POINT OF AMERICAS PHASE 2       2170.0       NaN      1971.0
# 9   3.0    2.5        PLAYA DEL MAR CONDO       2140.0       NaN      1975.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1110.0     2521.0   Sold
# 1             NaN          719.0     3853.0   Sold
# 2             NaN          880.0     2677.0   Sold
# 3             NaN          879.0     2161.0   Sold
# 4             NaN          483.0     3871.0   Sold
# 5             NaN          774.0     2213.0   Sold
# 6             NaN          686.0     2190.0   Sold
# 7             NaN          521.0     1988.0   Sold
# 8             NaN          631.0     2088.0   Sold
# 9             NaN          584.0     1464.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...  Beaches MLS  F10449275
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10412790
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11618958
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11562880
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10420799
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11554717
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...  Beaches MLS  F10446051
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11604053
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...       MARMLS  A11634288
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
# 1        N          Y  25.992497 -80.117826
# 2        N          Y  26.198972 -80.094812
# 3        N          Y  25.993975 -80.117768
# 4        N          Y  26.095913 -80.106280
# 5        N          Y  26.198972 -80.094812
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.126760 -80.121763
# 8        N          Y  26.095913 -80.106280
# 9        N          Y  26.175849 -80.097707
#
#                                                  url  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...
#
#            list_agent_name_1            list_broker_name_1  \
# 0              Richard Chong  Charles Rutenberg Realty FTL
# 1  Mariolga Lesseur de Parra      Related ISG Realty, LLC.
# 2          Bridget O'Donnell          Compass Florida, LLC
# 3           Stuart Scherline           Marina Realty Group
# 4             Laurie Spector          Compass Florida, LLC
# 5             Shirley Patino                EXP Realty LLC
# 6           Lourdes Maestres          Compass Florida, LLC
# 7              Patricia Huff      Intercoastal Realty  Inc
# 8               Jorge Brandt       United Realty Group Inc
# 9            Mauro Rodriguez       Partnership Realty Inc.
#
#      list_agent_name_2            list_broker_name_2      buy_agent_name_1  \
# 0      Stephen Carfray  Charles Rutenberg Realty FTL      Patrick Barnicle
# 1  Valentina Tischenko      Related ISG Realty, LLC.       Michael Bremser
# 2         David Marder          Compass Florida, LLC          Freda Lisnow
# 3            Alan Pate           Marina Realty Group        Russell Miller
# 4                 None                          None    Nicole Murray Chen
# 5                 None                          None  Elisabeth Van Kleeff
# 6                 None                          None           Marc Kijner
# 7         Richard Huff      Intercoastal Realty  Inc     Bridget O'Donnell
# 8       Mariela Brandt       United Realty Group Inc                  None
# 9                 None                          None                  None
#
#                 buy_broker_name_1 buy_agent_name_2     buy_broker_name_2  \
# 0            Compass Florida, LLC             None                  None
# 1                        LoKation             None                  None
# 2  Better Homes & Gdns RE Fla 1st             None                  None
# 3          Coldwell Banker Realty             None                  None
# 4   Galleria International Realty             None                  None
# 5                        LoKation             None                  None
# 6            Compass Florida, LLC             None                  None
# 7            Compass Florida, LLC     David Marder  Compass Florida, LLC
# 8                            None             None                  None
# 9                            None             None                  None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Casa Murano at 141 Isle Of Venice Dr Unit 3-S ...
# 1     2    blue  Diplomat Oceanfront Resid at 3535 S Ocean Dr #...
# 2     3    blue  Sea Ranch Club B at 5000 N Ocean Blvd #1711 in...
# 3     4    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #3205 in ...
# 4     5    blue  POINT OF AMERICAS PHASE I at 2200 S Ocean Ln U...
# 5     6    blue  Sea Ranch Club B. at 5000 N Ocean Blvd #912 in...
# 6     7    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #2605 in ...
# 7     8    blue  Landings At Las Olas at 410 Hendricks Isle #20...
# 8     9    blue  POINT OF AMERICAS PHASE 2 at 2200 S Ocean Ln #...
# 9    10    blue  PLAYA DEL MAR CONDO at 3900 Galt Ocean Dr #110...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: Casa Murano closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $1,250,000M to $3,450,000M
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Broward County condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Lauderdale By The Sea, Fort Lauderdale, Hollywood
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 142 condo sales totaling $55,117,348 million from Sep. 29th to Oct. 6th. The previous week, brokers closed 126 condo sales totaling $43,300,000.
#
# Last week’s units sold for an average of $388,150, higher than the $343,326 average price from the previous week. The average price per square foot rose to $305 from $275, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,250,000.0 million to $3,450,000.0 million.
#
# Casa Murano at 141 Isle Of Venice Dr Unit 3-S in Fort Lauderdale took the top spot with a $3,450,000.0 million closing. The sale closed at $1,110.0 per square foot.
#
# Richard Chong with Charles Rutenberg Realty FTL, and Stephen Carfray with Charles Rutenberg Realty FTL had the listing.
# Patrick Barnicle with Compass Florida, LLC, and None with None represented the buyer.
#
# Diplomat Oceanfront Resid at 3535 S Ocean Dr #1506 in Hollywood, closed for the second highest amount, $2,180,000.0, or $719.0 per square foot.
#
# Mariolga Lesseur de Parra with Related ISG Realty, LLC., and Valentina Tischenko with Related ISG Realty, LLC. had the listing.
# Michael Bremser with LoKation, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/BC_County_condo_sales_week_ending_10072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 29th to Oct. 6th:
#
# Most Expensive
# Casa Murano, 141 Isle Of Venice Dr Unit 3-S, in Fort Lauderdale | Price: $3,450,000 | $1,110 psf | Listing agents: Richard Chong with Charles Rutenberg Realty FTL and Stephen Carfray with Charles Rutenberg Realty FTL | Buyer's agents: Patrick Barnicle with Compass Florida, LLC and None with None
# Least Expensive
# PLAYA DEL MAR CONDO, 3900 Galt Ocean Dr #1101, in Fort Lauderdale | Price: $1,250,000 | $584 psf | Listing agents: Mauro Rodriguez with Partnership Realty Inc. and None with None | Buyer's agents: None with None and None with None
# Highest Price Per Square Foot
# Casa Murano, 141 Isle Of Venice Dr Unit 3-S, in Fort Lauderdale | Price: $3,450,000 | $1,110 psf | Listing agents: Richard Chong with Charles Rutenberg Realty FTL and Stephen Carfray with Charles Rutenberg Realty FTL | Buyer's agents: Patrick Barnicle with Compass Florida, LLC and None with None
# Lowest Price Per Square Foot
# POINT OF AMERICAS PHASE I, 2200 S Ocean Ln Unit 401 & 402, in Fort Lauderdale | Price: $1,750,000 | $483 psf | Listing agents: Laurie Spector with Compass Florida, LLC and None with None | Buyer's agents: Nicole Murray Chen with Galleria International Realty and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/141-Isle-of-Venice-Dr-33301/unit-3S/home/190870657

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Hollywood/3535-S-Ocean-Dr-33019/unit-1506/home/42071311

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/3900-Galt-Ocean-Dr-33308/unit-1101/home/41708454

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2200-S-Ocean-Ln-33316/unit-205/home/41805700

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/141-Isle-of-Venice-Dr-33301/unit-3S/home/190870657

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2200-S-Ocean-Ln-33316/unit-402/home/41807220

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE 2024-10-01   Condo/Co-op  141 Isle Of Venice Dr Unit 3-S
# 1  PAST SALE 2024-10-03   Condo/Co-op           3535 S Ocean Dr #1506
# 2  PAST SALE 2024-10-02   Condo/Co-op         5000 N Ocean Blvd #1711
# 3  PAST SALE 2024-09-30   Condo/Co-op           3101 S Ocean Dr #3205
# 4  PAST SALE 2024-10-02   Condo/Co-op  2200 S Ocean Ln Unit 401 & 402
# 5  PAST SALE 2024-09-30   Condo/Co-op          5000 N Ocean Blvd #912
# 6  PAST SALE 2024-10-02   Condo/Co-op           3101 S Ocean Dr #2605
# 7  PAST SALE 2024-09-30   Condo/Co-op         410 Hendricks Isle #204
# 8  PAST SALE 2024-10-03   Condo/Co-op            2200 S Ocean Ln #205
# 9  PAST SALE 2024-09-30   Condo/Co-op        3900 Galt Ocean Dr #1101
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33301.0  3450000.0
# 1              Hollywood                FL             33019.0  2180000.0
# 2  Lauderdale By The Sea                FL             33308.0  2025000.0
# 3              Hollywood                FL             33019.0  1860000.0
# 4        Fort Lauderdale                FL             33316.0  1750000.0
# 5  Lauderdale By The Sea                FL             33308.0  1750000.0
# 6              Hollywood                FL             33019.0  1450000.0
# 7        Fort Lauderdale                FL             33301.0  1400000.0
# 8        Fort Lauderdale                FL             33316.0  1370000.0
# 9        Fort Lauderdale                FL             33308.0  1250000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    4.5                Casa Murano       3108.0       NaN      2024.0
# 1   3.0    3.5  Diplomat Oceanfront Resid       3030.0       NaN      2007.0
# 2   3.0    2.5           Sea Ranch Club B       2300.0       NaN      1979.0
# 3   3.0    3.0          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 4   4.0    3.5  POINT OF AMERICAS PHASE I       3621.0       NaN      1971.0
# 5   3.0    2.5          Sea Ranch Club B.       2260.0       NaN      1979.0
# 6   3.0    3.5          OCEAN PALMS CONDO       2115.0       NaN      2005.0
# 7   3.0    3.5       Landings At Las Olas       2687.0       NaN      2005.0
# 8   2.0    2.5  POINT OF AMERICAS PHASE 2       2170.0       NaN      1971.0
# 9   3.0    2.5        PLAYA DEL MAR CONDO       2140.0       NaN      1975.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1110.0     2521.0   Sold
# 1             NaN          719.0     3853.0   Sold
# 2             NaN          880.0     2677.0   Sold
# 3             NaN          879.0     2161.0   Sold
# 4             NaN          483.0     3871.0   Sold
# 5             NaN          774.0     2213.0   Sold
# 6             NaN          686.0     2190.0   Sold
# 7             NaN          521.0     1988.0   Sold
# 8             NaN          631.0     2088.0   Sold
# 9             NaN          584.0     1464.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10441760
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...  Beaches MLS  F10449275
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10412790
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11618958
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11562880
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS  F10420799
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11554717
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...  Beaches MLS  F10446051
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11604053
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...       MARMLS  A11634288
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.125672 -80.120892
# 1        N          Y  25.992497 -80.117826
# 2        N          Y  26.198972 -80.094812
# 3        N          Y  25.993975 -80.117768
# 4        N          Y  26.095913 -80.106280
# 5        N          Y  26.198972 -80.094812
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.126760 -80.121763
# 8        N          Y  26.095913 -80.106280
# 9        N          Y  26.175849 -80.097707
#
#                                                  url  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/141-...
# 1  https://www.redfin.com/FL/Hollywood/3535-S-Oce...
# 2  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 3  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 4  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 5  https://www.redfin.com/FL/Lauderdale-by-the-Se...
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 7  https://www.redfin.com/FL/Fort-Lauderdale/410-...
# 8  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 9  https://www.redfin.com/FL/Fort-Lauderdale/3900...
#
#            list_agent_name_1            list_broker_name_1  \
# 0              Richard Chong  Charles Rutenberg Realty FTL
# 1  Mariolga Lesseur de Parra      Related ISG Realty, LLC.
# 2          Bridget O'Donnell          Compass Florida, LLC
# 3           Stuart Scherline           Marina Realty Group
# 4             Laurie Spector          Compass Florida, LLC
# 5             Shirley Patino                EXP Realty LLC
# 6           Lourdes Maestres          Compass Florida, LLC
# 7              Patricia Huff      Intercoastal Realty  Inc
# 8               Jorge Brandt       United Realty Group Inc
# 9            Mauro Rodriguez       Partnership Realty Inc.
#
#      list_agent_name_2            list_broker_name_2      buy_agent_name_1  \
# 0      Stephen Carfray  Charles Rutenberg Realty FTL      Patrick Barnicle
# 1  Valentina Tischenko      Related ISG Realty, LLC.       Michael Bremser
# 2         David Marder          Compass Florida, LLC          Freda Lisnow
# 3            Alan Pate           Marina Realty Group        Russell Miller
# 4                 None                          None    Nicole Murray Chen
# 5                 None                          None  Elisabeth Van Kleeff
# 6                 None                          None           Marc Kijner
# 7         Richard Huff      Intercoastal Realty  Inc     Bridget O'Donnell
# 8       Mariela Brandt       United Realty Group Inc                  None
# 9                 None                          None                  None
#
#                 buy_broker_name_1 buy_agent_name_2     buy_broker_name_2  \
# 0            Compass Florida, LLC             None                  None
# 1                        LoKation             None                  None
# 2  Better Homes & Gdns RE Fla 1st             None                  None
# 3          Coldwell Banker Realty             None                  None
# 4   Galleria International Realty             None                  None
# 5                        LoKation             None                  None
# 6            Compass Florida, LLC             None                  None
# 7            Compass Florida, LLC     David Marder  Compass Florida, LLC
# 8                            None             None                  None
# 9                            None             None                  None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Casa Murano at 141 Isle Of Venice Dr Unit 3-S ...
# 1     2    blue  Diplomat Oceanfront Resid at 3535 S Ocean Dr #...
# 2     3    blue  Sea Ranch Club B at 5000 N Ocean Blvd #1711 in...
# 3     4    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #3205 in ...
# 4     5    blue  POINT OF AMERICAS PHASE I at 2200 S Ocean Ln U...
# 5     6    blue  Sea Ranch Club B. at 5000 N Ocean Blvd #912 in...
# 6     7    blue  OCEAN PALMS CONDO at 3101 S Ocean Dr #2605 in ...
# 7     8    blue  Landings At Las Olas at 410 Hendricks Isle #20...
# 8     9    blue  POINT OF AMERICAS PHASE 2 at 2200 S Ocean Ln #...
# 9    10    blue  PLAYA DEL MAR CONDO at 3900 Galt Ocean Dr #110...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 7, 3) ## List (Earlier) date
date2 = datetime(2024, 10, 3) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 92

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")
