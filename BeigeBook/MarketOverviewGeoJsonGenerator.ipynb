# %% [markdown]
# ## Imports

# %%
import os
import re
import pandas as pd
import geopandas as gpd
import requests
import googlemaps
import gspread
import bleach
from bs4 import BeautifulSoup
from googleapiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials# Define the scope of the application
from googleapiclient.discovery import build
from bs4 import BeautifulSoup
from shapely.geometry import Point
from dotenv import load_dotenv

# %% [markdown]
# ## CONFIGURATION

# %%
# Load environment variables from .env file if present
load_dotenv()

# Try to get the API key from environment variables
GOOGLE_MAPS_API_KEY = os.environ.get("GOOGLE_MAPS_API_KEY")
if not GOOGLE_MAPS_API_KEY:
  raise RuntimeError("GOOGLE_MAPS_API_KEY not found in environment or .env file.")

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# Add credentials to the account
creds = ServiceAccountCredentials.from_json_keyfile_name('autoscraper-380600-0d0c84856d6b.json', scope)

# Authorize the clientsheet 
client = gspread.authorize(creds)

sheet = client.open_by_key('11UHXwJ_A9-kJZANhI3JvqKBGhIlGilmaAuX7NVL7YA4')

# Drive client
drivesvc = build("drive", "v3", credentials=creds)

range_name = 'A1:AO200'

# %%
def fetch_data(sheet, worksheet_name, range_name, df_name=None):
    print('Fetching data from Google Sheets...')
    worksheet = sheet.worksheet(worksheet_name)
    data = worksheet.get(range_name)
    df = pd.DataFrame(data)
    df.columns = df.iloc[0]  # Set first row as column headers
    df = df.drop(0).reset_index(drop=True)  # Drop the header row from the dataframe and reset index

    df.drop_duplicates(inplace=True)  # Drop duplicate rows
    print(f'Number of rows in {worksheet_name} worksheet: {len(df)}')
    return df

# ────────────────────────────────────────────────────────────────
# HELPERS
# ────────────────────────────────────────────────────────────────
def extract_doc_id(url: str) -> str:
    """Extract the Doc ID from a Google Docs URL."""
    m = re.search(r"/d/([a-zA-Z0-9_-]+)", url)
    if not m:
        raise ValueError(f"Unable to parse document ID from URL: {url}")
    return m.group(1)

def export_doc_html(doc_id: str) -> str:
    """
    Export a Google Doc as HTML via Drive API and return
    just the <body> contents (preserves paragraphs, bold, links, etc).
    """
    html_bytes = drivesvc.files().export(
        fileId=doc_id,
        mimeType="text/html"
    ).execute()
    soup = BeautifulSoup(html_bytes, "html.parser")
    # Grab only the inner <body> so we don’t pull in full <head>, styles, etc.
    return "".join(str(el) for el in soup.body.contents).strip()

def geocode(address: str, api_key: str) -> tuple:
    """Return (lat, lon) for a given address using Google Maps Geocoding API."""
    endpoint = "https://maps.googleapis.com/maps/api/geocode/json"
    resp = requests.get(endpoint, params={"address": address, "key": api_key})
    resp.raise_for_status()
    data = resp.json()
    if data.get("status") != "OK" or not data.get("results"):
        raise ValueError(f"Geocoding failed for '{address}': {data.get('status')}")
    loc = data["results"][0]["geometry"]["location"]
    return loc["lat"], loc["lng"]

def set_target_blank(attrs, new=False):
    # attrs is a dict of existing a-tag attrs; we override/add target.
    attrs["target"] = "_blank"
    return attrs

# %%
df = fetch_data(sheet, 'Sheet1', range_name, 'df')
# Out:
# Fetching data from Google Sheets...
# Number of rows in Sheet1 worksheet: 18

# %%
df
# Out:
# 0                                          Metro  \
# 0                                       New York
# 1                                  South Florida
# 2                                    Los Angeles
# 3                                        Chicago
# 4    San Francisco (and San Jose/Silicon Valley)
# 5   Texas (Dallas, Houston, Austin, San Antonio)
# 6                                         Boston
# 7                               Washington, D.C.
# 8                                   Philadelphia
# 9                                        Atlanta
# 10                                         Tampa
# 11                                       Orlando
# 12                                     Charlotte
# 13                                     Nashville
# 14                                       Phoenix
# 15                                       Seattle
# 16                                        Denver
# 17                                     Las Vegas
#
# 0                                      Landing Page  \
# 0                 https://therealdeal.com/new-york/
# 1                    https://therealdeal.com/miami/
# 2                       https://therealdeal.com/la/
# 3                  https://therealdeal.com/chicago/
# 4            https://therealdeal.com/san-francisco/
# 5                    https://therealdeal.com/texas/
# 6          https://therealdeal.com/national/boston/
# 7   https://therealdeal.com/national/washington-dc/
# 8    https://therealdeal.com/national/philadelphia/
# 9         https://therealdeal.com/national/atlanta/
# 10          https://therealdeal.com/national/tampa/
# 11        https://therealdeal.com/national/orlando/
# 12      https://therealdeal.com/national/charlotte/
# 13      https://therealdeal.com/national/nashville/
# 14        https://therealdeal.com/national/phoenix/
# 15        https://therealdeal.com/national/seattle/
# 16         https://therealdeal.com/national/denver/
# 17      https://therealdeal.com/national/las-vegas/
#
# 0                                  Overview Draft Doc      Last Updated  \
# 0   https://docs.google.com/document/d/1V_9byGw5Af...  October 14, 2025
# 1   https://docs.google.com/document/d/11BBpyeLXZj...  October 15, 2025
# 2   https://docs.google.com/document/d/1D7MgwzuE3H...  October 15, 2025
# 3   https://docs.google.com/document/d/18nhSNkDeo-...  October 15, 2025
# 4   https://docs.google.com/document/d/19AxLoIrrJm...  October 17, 2025
# 5   https://docs.google.com/document/d/1YnJCsS-yuD...  October 17, 2025
# 6   https://docs.google.com/document/d/1w_cSk1I22h...  October 20, 2025
# 7   https://docs.google.com/document/d/16JBncASAOo...  October 17, 2025
# 8   https://docs.google.com/document/d/1nV6VB0fEEV...  October 20, 2025
# 9   https://docs.google.com/document/d/1SGcedyLLjg...  October 20, 2025
# 10  https://docs.google.com/document/d/1TJINO169Hw...  October 21, 2025
# 11  https://docs.google.com/document/d/1aO0Iu8jaV3...  October 21, 2025
# 12  https://docs.google.com/document/d/10BXb8eSxEC...  October 21, 2025
# 13  https://docs.google.com/document/d/1Z1_avmR7qr...  October 23, 2025
# 14  https://docs.google.com/document/d/1Z561LDlCrC...  October 23, 2025
# 15  https://docs.google.com/document/d/1L5lc_nzb-a...  October 24, 2025
# 16  https://docs.google.com/document/d/1bSWxpplJBO...  October 24, 2025
# 17  https://docs.google.com/document/d/1PGl13lSmPc...  October 14, 2025
#
# 0  Last Updated By                          geocoded
# 0      Mary Diduch         (40.7127753, -74.0059728)
# 1      Mary Diduch          (26.522474, -81.1637245)
# 2      Mary Diduch         (34.0549076, -118.242643)
# 3      Mary Diduch           (41.88325, -87.6323879)
# 4      Mary Diduch          (37.33874, -121.8852525)
# 5      Mary Diduch  (29.7600771, -95.37011079999999)
# 6      Mary Diduch         (42.3555076, -71.0565364)
# 7      Mary Diduch         (38.9072873, -77.0369274)
# 8      Mary Diduch         (39.9525839, -75.1652215)
# 9      Mary Diduch         (33.7501275, -84.3885209)
# 10     Mary Diduch  (27.9516896, -82.45875269999999)
# 11     Mary Diduch         (28.5383832, -81.3789269)
# 12     Mary Diduch  (35.2270768, -80.84089329999999)
# 13     Mary Diduch         (36.1626638, -86.7816016)
# 14     Mary Diduch        (33.4482948, -112.0725488)
# 15     Mary Diduch        (47.6061389, -122.3328481)
# 16     Mary Diduch         (39.7392358, -104.990251)
# 17     Mary Diduch         (36.171563, -115.1391009)

# %%
# geocode each Metro once, via googlemaps.Client:
gmaps = googlemaps.Client(key=GOOGLE_MAPS_API_KEY)
df['geocoded'] = df['Metro'].apply(lambda m: gmaps.geocode(m)[0]['geometry']['location'].values())

# %%
# ────────────────────────────────────────────────────────────────
#  CONFIG: what to keep
# ────────────────────────────────────────────────────────────────
ALLOWED_TAGS = ["b", "strong", "i", "em", "br", "p", "a"]
ALLOWED_ATTRS = { "a": ["href", "title", "target"] }

records = []
for _, row in df.iterrows():
    metro    = row["Metro"]
    doc_url  = row["Overview Draft Doc"]
    lat, lon = row["geocoded"]
    print(f"Processing: {metro}")

    # 1) pull raw HTML
    doc_id = extract_doc_id(doc_url)
    raw    = export_doc_html(doc_id)

    # 2) strip out everything except bold, italics, p, br, a[href]
    clean = bleach.clean(
        raw,
        tags=ALLOWED_TAGS,
        attributes=ALLOWED_ATTRS,
        strip=True
    )

    # 3) parse & force all <a> to open in a new tab
    soup = BeautifulSoup(clean, "html.parser")
    for a in soup.find_all("a"):
        a["target"] = "_blank"
    clean = str(soup)

    # 4) append your record
    records.append({
        "Metro":           metro,
        "Landing Page":    row["Landing Page"],
        "summary":         clean,
        "Last Updated":    row["Last Updated"],
        "Last Updated By": row["Last Updated By"],
        "geometry":        Point(lon, lat)
    })

if not records:
    raise RuntimeError("No records!")

# build GeoDataFrame straight from records
gdf = gpd.GeoDataFrame(records, crs="EPSG:4326")
gdf.to_file("market_overviews.geojson", driver="GeoJSON")
print(f"Wrote {len(gdf)} features")
# Out:
# Processing: New York
# Processing: South Florida
# Processing: Los Angeles
# Processing: Chicago
# Processing: San Francisco (and San Jose/Silicon Valley)
# Processing: Texas (Dallas, Houston, Austin, San Antonio)
# Processing: Boston
# Processing: Washington, D.C.
# Processing: Philadelphia
# Processing: Atlanta
# Processing: Tampa
# Processing: Orlando
# Processing: Charlotte
# Processing: Nashville
# Processing: Phoenix
# Processing: Seattle
# Processing: Denver
# Processing: Las Vegas
# Wrote 18 features
