# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Mar. 23rd Mar. 30th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE               ADDRESS         CITY  \
# 1  PAST SALE  March-24-2025   Condo/Co-op  6001 SW 70th St #305  South Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33143.0  375000.0   2.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/South-Miami/6001-SW-...  MARMLS  A11760834
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.706558 -80.291032
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-03-28    31
# 2025-03-24    29
# 2025-03-25    29
# 2025-03-27    20
# 2025-03-26    17
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 74   PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 118  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 126  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 112  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 52   PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 63   PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 122  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 120  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 41   PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 117  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  \
# 74         Miami Beach                FL             33139.0  11250000.0
# 118  Sunny Isles Beach                FL             33160.0   6100000.0
# 126  Sunny Isles Beach                FL             33160.0   4950000.0
# 112  Sunny Isles Beach                FL             33160.0   3800000.0
# 52   Sunny Isles Beach                FL             33160.0   3775000.0
# 63         Miami Beach                FL             33139.0   3600000.0
# 122              Miami                FL             33133.0   3500000.0
# 120        Miami Beach                FL             33139.0   2837500.0
# 41   Sunny Isles Beach                FL             33160.0   2600000.0
# 117       Key Biscayne                FL             33149.0   2575000.0
#
#      BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 74    5.0    5.5  ...   Sold                         NaN
# 118   4.0    6.5  ...   Sold                         NaN
# 126   3.0    3.5  ...   Sold                         NaN
# 112   3.0    3.5  ...   Sold                         NaN
# 52    3.0    3.5  ...   Sold                         NaN
# 63    3.0    2.5  ...   Sold                         NaN
# 122   3.0    3.5  ...   Sold                         NaN
# 120   4.0    3.5  ...   Sold                         NaN
# 41    2.0    2.5  ...   Sold                         NaN
# 117   4.0    3.0  ...   Sold                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 74                        NaN
# 118                       NaN
# 126                       NaN
# 112                       NaN
# 52                        NaN
# 63                        NaN
# 122                       NaN
# 120                       NaN
# 41                        NaN
# 117                       NaN
#
#                                                    URL       SOURCE  \
# 74   https://www.redfin.com/FL/Miami-Beach/321-Ocea...       MARMLS
# 118  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 126  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 112  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Beaches MLS
# 52   https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 63   https://www.redfin.com/FL/Miami-Beach/300-S-Po...       MARMLS
# 122  https://www.redfin.com/FL/Miami/2669-S-Bayshor...       MARMLS
# 120  https://www.redfin.com/FL/Miami-Beach/1800-Sun...       MARMLS
# 41   https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 117  https://www.redfin.com/FL/Key-Biscayne/749-Cra...       MARMLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 74     A11695945         N          Y  25.772296 -80.131901
# 118    A11611470         N          Y  25.940065 -80.120264
# 126    A11490517         N          Y  25.934939 -80.120918
# 112  RX-11004551         N          Y  25.951740 -80.119755
# 52     A11712041         N          Y  25.951740 -80.119755
# 63     A11710839         N          Y  25.767706 -80.134877
# 122    A11582132         N          Y  25.730676 -80.237117
# 120    A11606692         N          Y  25.794488 -80.144801
# 41     A11720744         N          Y  25.951740 -80.119755
# 117    A11618404         N          Y  25.687221 -80.161390
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 0  PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 1  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 2  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 3  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 4  PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 5  PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 6  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 7  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 8  PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 9  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL             33139.0  11250000.0   5.0
# 1  Sunny Isles Beach                FL             33160.0   6100000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0   4950000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0   3800000.0   3.0
# 4  Sunny Isles Beach                FL             33160.0   3775000.0   3.0
# 5        Miami Beach                FL             33139.0   3600000.0   3.0
# 6              Miami                FL             33133.0   3500000.0   3.0
# 7        Miami Beach                FL             33139.0   2837500.0   4.0
# 8  Sunny Isles Beach                FL             33160.0   2600000.0   2.0
# 9       Key Biscayne                FL             33149.0   2575000.0   4.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    5.5  ... -80.131901  https://www.redfin.com/FL/Miami-Beach/321-Ocea...
# 1    6.5  ... -80.120264  https://www.redfin.com/FL/Sunny-Isles-Beach/17...
# 2    3.5  ... -80.120918  https://www.redfin.com/FL/Sunny-Isles-Beach/17...
# 3    3.5  ... -80.119755  https://www.redfin.com/FL/Sunny-Isles-Beach/18...
# 4    3.5  ... -80.119755  https://www.redfin.com/FL/Sunny-Isles-Beach/18...
# 5    2.5  ... -80.134877  https://www.redfin.com/FL/Miami-Beach/300-S-Po...
# 6    3.5  ... -80.237117  https://www.redfin.com/FL/Miami/2669-S-Bayshor...
# 7    3.5  ... -80.144801  https://www.redfin.com/FL/Miami-Beach/1800-Sun...
# 8    2.5  ... -80.119755  https://www.redfin.com/FL/Sunny-Isles-Beach/18...
# 9    3.0  ... -80.161390  https://www.redfin.com/FL/Key-Biscayne/749-Cra...
#
#    list_agent_name_1                            list_broker_name_1  \
# 0     Michael Duchon                            The Corcoran Group
# 1         Adi Amuial                   Miles Goldstein Real Estate
# 2       Roberta Poli                      Related ISG Realty, LLC.
# 3  Karine Frangulyan              Signature One Luxury Estates LLC
# 4        Roger Silva                 The Florida Lounge Realty LLC
# 5               None                                          None
# 6        Ivan Madera  Fortune Christie's International Real Estate
# 7    Paul Sasseville                         Compass Florida, LLC.
# 8    Luciene Cofresi                  Fortune International Realty
# 9      Gloria Ibarra                           Realty Progress LLC
#
#    list_agent_name_2  list_broker_name_2          buy_agent_name_1  \
# 0     Eloy Carmenate  The Corcoran Group              Darin Tansey
# 1               None                None  Adriana Vargas Hernandez
# 2               None                None     Viktoriya Donisova Ho
# 3               None                None               Wendy Cohen
# 4               None                None           Romina Grinberg
# 5               None                None                      None
# 6               None                None          Lindsey Lamchick
# 7               None                None              Cory Waldman
# 8               None                None           Claudio Minones
# 9               None                None           Natalia Salgado
#
#                     buy_broker_name_1  buy_agent_name_2  buy_broker_name_2
# 0                     Douglas Elliman              None               None
# 1                    Acqualina Realty              None               None
# 2               Compass Florida, LLC.              None               None
# 3  One Sotheby's International Realty              None               None
# 4                Compass Florida, LLC              None               None
# 5                                None              None               None
# 6                            The Edit              None               None
# 7              Coldwell Banker Realty              None               None
# 8  One Sotheby's International Realty              None               None
# 9            DLS International Realty              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 126

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $843,850

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $547

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $106,325,153

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input county name:
# Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 116
# -----------
# Input Previous Week Condo Average Sales Price:
# 682803
# -----------
# Input Previous Week Condo Average PSF:
# 536
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 79205150.0

# %%
last_week
# Out:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          116              682803          536                     79205150.0

# %%
last_week['Last Week Total Dollar Volume'].iloc[0]
# Out:
# 79205150.0

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          126              843850          547                    106325153.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE            ADDRESS         CITY  \
# 0  PAST SALE 2025-03-24   Condo/Co-op  321 Ocean Dr #201  Miami Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33139.0  11250000.0   5.0    5.5
#
#           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  321 OCEAN CONDO       4400.0       NaN      2015.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2557.0    28702.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...  MARMLS  A11695945
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.772296 -80.131901
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...    Michael Duchon
#
#    list_broker_name_1 list_agent_name_2  list_broker_name_2 buy_agent_name_1  \
# 0  The Corcoran Group    Eloy Carmenate  The Corcoran Group     Darin Tansey
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 0  PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 1  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 2  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 3  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 4  PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 5  PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 6  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 7  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 8  PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 9  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL             33139.0  11250000.0   5.0
# 1  Sunny Isles Beach                FL             33160.0   6100000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0   4950000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0   3800000.0   3.0
# 4  Sunny Isles Beach                FL             33160.0   3775000.0   3.0
# 5        Miami Beach                FL             33139.0   3600000.0   3.0
# 6              Miami                FL             33133.0   3500000.0   3.0
# 7        Miami Beach                FL             33139.0   2837500.0   4.0
# 8  Sunny Isles Beach                FL             33160.0   2600000.0   2.0
# 9       Key Biscayne                FL             33149.0   2575000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5            321 OCEAN CONDO       4400.0       NaN      2015.0
# 1    6.5  17749 COLLINS AVENUE COND       4609.0       NaN      2015.0
# 2    3.5                 MUSE CONDO       3195.0       NaN      2018.0
# 3    3.5        18975 Collins Condo       2271.0       NaN      2019.0
# 4    3.5        18975 COLLINS CONDO       2271.0       NaN      2019.0
# 5    2.5      PORTOFINO TOWER CONDO       2340.0       NaN      1996.0
# 6    3.5     THE GROVE AT GRAND BAY       1829.0       NaN      2016.0
# 7    3.5  SUNSET HARBOUR SOUTH COND       2246.0       NaN      1998.0
# 8    2.5        18975 COLLINS CONDO       1521.0       NaN      2019.0
# 9    3.0     LAKE VILLA THREE CONDO       2650.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2557.0    28702.0   Sold
# 1             NaN         1323.0    10288.0   Sold
# 2             NaN         1549.0     9176.0   Sold
# 3             NaN         1673.0     3734.0   Sold
# 4             NaN         1662.0     8904.0   Sold
# 5             NaN         1538.0     4016.0   Sold
# 6             NaN         1914.0     3083.0   Sold
# 7             NaN         1263.0     3317.0   Sold
# 8             NaN         1709.0     2983.0   Sold
# 9             NaN          972.0     3605.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...       MARMLS
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Beaches MLS
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...       MARMLS
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...       MARMLS
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...       MARMLS
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11695945        N          Y  25.772296 -80.131901
# 1    A11611470        N          Y  25.940065 -80.120264
# 2    A11490517        N          Y  25.934939 -80.120918
# 3  RX-11004551        N          Y  25.951740 -80.119755
# 4    A11712041        N          Y  25.951740 -80.119755
# 5    A11710839        N          Y  25.767706 -80.134877
# 6    A11582132        N          Y  25.730676 -80.237117
# 7    A11606692        N          Y  25.794488 -80.144801
# 8    A11720744        N          Y  25.951740 -80.119755
# 9    A11618404        N          Y  25.687221 -80.161390
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...     Michael Duchon
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...         Adi Amuial
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       Roberta Poli
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Karine Frangulyan
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...        Roger Silva
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...               None
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...        Ivan Madera
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...    Paul Sasseville
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...    Luciene Cofresi
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...      Gloria Ibarra
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                            The Corcoran Group    Eloy Carmenate
# 1                   Miles Goldstein Real Estate              None
# 2                      Related ISG Realty, LLC.              None
# 3              Signature One Luxury Estates LLC              None
# 4                 The Florida Lounge Realty LLC              None
# 5                                          None              None
# 6  Fortune Christie's International Real Estate              None
# 7                         Compass Florida, LLC.              None
# 8                  Fortune International Realty              None
# 9                           Realty Progress LLC              None
#
#    list_broker_name_2          buy_agent_name_1  \
# 0  The Corcoran Group              Darin Tansey
# 1                None  Adriana Vargas Hernandez
# 2                None     Viktoriya Donisova Ho
# 3                None               Wendy Cohen
# 4                None           Romina Grinberg
# 5                None                      None
# 6                None          Lindsey Lamchick
# 7                None              Cory Waldman
# 8                None           Claudio Minones
# 9                None           Natalia Salgado
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                     Douglas Elliman             None              None
# 1                    Acqualina Realty             None              None
# 2               Compass Florida, LLC.             None              None
# 3  One Sotheby's International Realty             None              None
# 4                Compass Florida, LLC             None              None
# 5                                None             None              None
# 6                            The Edit             None              None
# 7              Coldwell Banker Realty             None              None
# 8  One Sotheby's International Realty             None              None
# 9            DLS International Realty             None              None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0d6729cf7f26cdb4bc4ba6061943cb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Mar. 23rd — Mar. 30th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0d6729cf7f26cdb4bc4ba6061943cb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d0d6729cf7f26cdb4bc4ba6061943cb0 = L.map(
#                 &quot;map_d0d6729cf7f26cdb4bc4ba6061943cb0&quot;,
#                 {
#                     center: [25.811376959523805, -80.22482310714285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_5da51162f2f891494508c733adb8f588 = L.featureGroup(
#                 {}
#             ).addTo(map_d0d6729cf7f26cdb4bc4ba6061943cb0);
#
#
#             var marker_0eb8ee951ac23b4161b6c5c2f73fb821 = L.marker(
#                 [25.7722958, -80.1319008],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_5da51162f2f891494508c733adb8f588);
#
#
#             var icon_fb42f744662a369b7d4898a2c17cd0b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0eb8ee951ac23b4161b6c5c2f73fb821.setIcon(icon_fb42f744662a369b7d4898a2c17cd0b4);
#
#
#         var popup_acba671d4b46ba4fc080b4804aa8083b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_838abc58b552ebbaa74af1763cd3e081 = $(`&lt;div id=&quot;html_838abc58b552ebbaa74af1763cd3e081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;321 Ocean Dr #201&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$11,250,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,557.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,400.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2015.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_acba671d4b46ba4fc080b4804aa8083b.setContent(html_838abc58b552ebbaa74af1763cd3e081);
#
#
#
#         marker_0eb8ee951ac23b4161b6c5c2f73fb821.bindPopup(popup_acba671d4b46ba4fc080b4804aa8083b)
#         ;
#
#
#
#
#             var feature_group_fb499961fdc410f8f449f954f7bb7016 = L.featureGroup(
#                 {}
#             ).addTo(map_d0d6729cf7f26cdb4bc4ba6061943cb0);
#
#
#             var marker_7d5cadc37a5a1129206cfb12d83b2508 = L.marker(
#                 [25.9400648, -80.1202638],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_fb499961fdc410f8f449f954f7bb7016);
#
#
#             var icon_49123a7b551ac51dc4945ee91d4e499c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d5cadc37a5a1129206cfb12d83b2508.setIcon(icon_49123a7b551ac51dc4945ee91d4e499c);
#
#
#         var popup_e1bc6058986ab2b62708b842fca79e73 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_8ef47d01b552d084acf7182d4f5ac92f = $(`&lt;div id=&quot;html_8ef47d01b552d084acf7182d4f5ac92f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;17749 Collins Ave #802&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,100,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,323.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,609.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2015.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_e1bc6058986ab2b62708b842fca79e73.setContent(html_8ef47d01b552d084acf7182d4f5ac92f);
#
#
#
#         marker_7d5cadc37a5a1129206cfb12d83b2508.bindPopup(popup_e1bc6058986ab2b62708b842fca79e73)
#         ;
#
#
#
#
#             var marker_4e771012dd9248ba7c931d78bd7b7407 = L.marker(
#                 [25.9349392, -80.1209182],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_fb499961fdc410f8f449f954f7bb7016);
#
#
#             var icon_736c0370cc2c696f82603726f0f0fa27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4e771012dd9248ba7c931d78bd7b7407.setIcon(icon_736c0370cc2c696f82603726f0f0fa27);
#
#
#         var popup_ad92db4eb7cc2401fe35b00a167a49d6 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_d474d36e3ec1a47de46931f14a620f5d = $(

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE            ADDRESS         CITY  \
# 0  PAST SALE 2025-03-24   Condo/Co-op  321 Ocean Dr #201  Miami Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 0                FL             33139.0  11250000.0   5.0    5.5
#
#           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  321 OCEAN CONDO       4400.0       NaN      2015.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         2557.0    28702.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...  MARMLS  A11695945
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.772296 -80.131901
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...    Michael Duchon
#
#    list_broker_name_1 list_agent_name_2  list_broker_name_2 buy_agent_name_1  \
# 0  The Corcoran Group    Eloy Carmenate  The Corcoran Group     Darin Tansey
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   Douglas Elliman             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_03312024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '321 OCEAN CONDO at 321 Ocean Dr #201 in Miami Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 0  PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 1  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 2  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 3  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 4  PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 5  PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 6  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 7  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 8  PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 9  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL             33139.0  11250000.0   5.0
# 1  Sunny Isles Beach                FL             33160.0   6100000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0   4950000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0   3800000.0   3.0
# 4  Sunny Isles Beach                FL             33160.0   3775000.0   3.0
# 5        Miami Beach                FL             33139.0   3600000.0   3.0
# 6              Miami                FL             33133.0   3500000.0   3.0
# 7        Miami Beach                FL             33139.0   2837500.0   4.0
# 8  Sunny Isles Beach                FL             33160.0   2600000.0   2.0
# 9       Key Biscayne                FL             33149.0   2575000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5            321 OCEAN CONDO       4400.0       NaN      2015.0
# 1    6.5  17749 COLLINS AVENUE COND       4609.0       NaN      2015.0
# 2    3.5                 MUSE CONDO       3195.0       NaN      2018.0
# 3    3.5        18975 Collins Condo       2271.0       NaN      2019.0
# 4    3.5        18975 COLLINS CONDO       2271.0       NaN      2019.0
# 5    2.5      PORTOFINO TOWER CONDO       2340.0       NaN      1996.0
# 6    3.5     THE GROVE AT GRAND BAY       1829.0       NaN      2016.0
# 7    3.5  SUNSET HARBOUR SOUTH COND       2246.0       NaN      1998.0
# 8    2.5        18975 COLLINS CONDO       1521.0       NaN      2019.0
# 9    3.0     LAKE VILLA THREE CONDO       2650.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2557.0    28702.0   Sold
# 1             NaN         1323.0    10288.0   Sold
# 2             NaN         1549.0     9176.0   Sold
# 3             NaN         1673.0     3734.0   Sold
# 4             NaN         1662.0     8904.0   Sold
# 5             NaN         1538.0     4016.0   Sold
# 6             NaN         1914.0     3083.0   Sold
# 7             NaN         1263.0     3317.0   Sold
# 8             NaN         1709.0     2983.0   Sold
# 9             NaN          972.0     3605.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...       MARMLS
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Beaches MLS
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...       MARMLS
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...       MARMLS
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...       MARMLS
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11695945        N          Y  25.772296 -80.131901
# 1    A11611470        N          Y  25.940065 -80.120264
# 2    A11490517        N          Y  25.934939 -80.120918
# 3  RX-11004551        N          Y  25.951740 -80.119755
# 4    A11712041        N          Y  25.951740 -80.119755
# 5    A11710839        N          Y  25.767706 -80.134877
# 6    A11582132        N          Y  25.730676 -80.237117
# 7    A11606692        N          Y  25.794488 -80.144801
# 8    A11720744        N          Y  25.951740 -80.119755
# 9    A11618404        N          Y  25.687221 -80.161390
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...     Michael Duchon
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...         Adi Amuial
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       Roberta Poli
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Karine Frangulyan
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...        Roger Silva
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...               None
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...        Ivan Madera
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...    Paul Sasseville
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...    Luciene Cofresi
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...      Gloria Ibarra
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                            The Corcoran Group    Eloy Carmenate
# 1                   Miles Goldstein Real Estate              None
# 2                      Related ISG Realty, LLC.              None
# 3              Signature One Luxury Estates LLC              None
# 4                 The Florida Lounge Realty LLC              None
# 5                                          None              None
# 6  Fortune Christie's International Real Estate              None
# 7                         Compass Florida, LLC.              None
# 8                  Fortune International Realty              None
# 9                           Realty Progress LLC              None
#
#    list_broker_name_2          buy_agent_name_1  \
# 0  The Corcoran Group              Darin Tansey
# 1                None  Adriana Vargas Hernandez
# 2                None     Viktoriya Donisova Ho
# 3                None               Wendy Cohen
# 4                None           Romina Grinberg
# 5                None                      None
# 6                None          Lindsey Lamchick
# 7                None              Cory Waldman
# 8                None           Claudio Minones
# 9                None           Natalia Salgado
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                     Douglas Elliman             None              None
# 1                    Acqualina Realty             None              None
# 2               Compass Florida, LLC.             None              None
# 3  One Sotheby's International Realty             None              None
# 4                Compass Florida, LLC             None              None
# 5                                None             None              None
# 6                            The Edit             None              None
# 7              Coldwell Banker Realty             None              None
# 8  One Sotheby's International Realty             None              None
# 9            DLS International Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  321 OCEAN CONDO at 321 Ocean Dr #201 in Miami ...
# 1     2    blue  17749 COLLINS AVENUE COND at 17749 Collins Ave...
# 2     3    blue  MUSE CONDO at 17141 Collins Ave #1501 in Sunny...
# 3     4    blue  18975 Collins Condo at 18975 Collins Ave #2303...
# 4     5    blue  18975 COLLINS CONDO at 18975 Collins Ave #903 ...
# 5     6    blue  PORTOFINO TOWER CONDO at 300 S Pointe Dr #1105...
# 6     7    blue  THE GROVE AT GRAND BAY at 2669 S Bayshore Dr U...
# 7     8    blue  SUNSET HARBOUR SOUTH COND at 1800 Sunset Harbo...
# 8     9    blue  18975 COLLINS CONDO at 18975 Collins Ave #604 ...
# 9    10    blue  LAKE VILLA THREE CONDO at 749 Crandon Blvd #21...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: 321 OCEAN CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,575,000 to $11,250,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Key Biscayne, Miami Beach, Miami, Sunny Isles Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 126 condo sales totaling $106,325,153 million from Mar. 23rd to Mar. 30th. The previous week, brokers closed 116 condo sales totaling $79,205,150.
#
# Last week’s units sold for an average of $843,850, higher than the $682,803 average price from the previous week. The average price per square foot rose to $547 from $536, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,575,000.0 million to $11,250,000.0 million.
#
# 321 OCEAN CONDO at 321 Ocean Dr #201 in Miami Beach took the top spot with a $11,250,000.0 million closing. The sale closed at $2,557.0 per square foot.
#
# Michael Duchon with The Corcoran Group, and Eloy Carmenate with The Corcoran Group had the listing.
# Darin Tansey with Douglas Elliman, and None with None represented the buyer.
#
# 17749 COLLINS AVENUE COND at 17749 Collins Ave #802 in Sunny Isles Beach, closed for the second highest amount, $6,100,000.0, or $1,323.0 per square foot.
#
# Adi Amuial with Miles Goldstein Real Estate, and None with None had the listing.
# Adriana Vargas Hernandez with Acqualina Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_03312024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 23rd to Mar. 30th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 0  PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 1  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 2  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 3  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 4  PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 5  PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 6  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 7  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 8  PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 9  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL             33139.0  11250000.0   5.0
# 1  Sunny Isles Beach                FL             33160.0   6100000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0   4950000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0   3800000.0   3.0
# 4  Sunny Isles Beach                FL             33160.0   3775000.0   3.0
# 5        Miami Beach                FL             33139.0   3600000.0   3.0
# 6              Miami                FL             33133.0   3500000.0   3.0
# 7        Miami Beach                FL             33139.0   2837500.0   4.0
# 8  Sunny Isles Beach                FL             33160.0   2600000.0   2.0
# 9       Key Biscayne                FL             33149.0   2575000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5            321 OCEAN CONDO       4400.0       NaN      2015.0
# 1    6.5  17749 COLLINS AVENUE COND       4609.0       NaN      2015.0
# 2    3.5                 MUSE CONDO       3195.0       NaN      2018.0
# 3    3.5        18975 Collins Condo       2271.0       NaN      2019.0
# 4    3.5        18975 COLLINS CONDO       2271.0       NaN      2019.0
# 5    2.5      PORTOFINO TOWER CONDO       2340.0       NaN      1996.0
# 6    3.5     THE GROVE AT GRAND BAY       1829.0       NaN      2016.0
# 7    3.5  SUNSET HARBOUR SOUTH COND       2246.0       NaN      1998.0
# 8    2.5        18975 COLLINS CONDO       1521.0       NaN      2019.0
# 9    3.0     LAKE VILLA THREE CONDO       2650.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2557.0    28702.0   Sold
# 1             NaN         1323.0    10288.0   Sold
# 2             NaN         1549.0     9176.0   Sold
# 3             NaN         1673.0     3734.0   Sold
# 4             NaN         1662.0     8904.0   Sold
# 5             NaN         1538.0     4016.0   Sold
# 6             NaN         1914.0     3083.0   Sold
# 7             NaN         1263.0     3317.0   Sold
# 8             NaN         1709.0     2983.0   Sold
# 9             NaN          972.0     3605.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...       MARMLS
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Beaches MLS
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...       MARMLS
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...       MARMLS
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...       MARMLS
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11695945        N          Y  25.772296 -80.131901
# 1    A11611470        N          Y  25.940065 -80.120264
# 2    A11490517        N          Y  25.934939 -80.120918
# 3  RX-11004551        N          Y  25.951740 -80.119755
# 4    A11712041        N          Y  25.951740 -80.119755
# 5    A11710839        N          Y  25.767706 -80.134877
# 6    A11582132        N          Y  25.730676 -80.237117
# 7    A11606692        N          Y  25.794488 -80.144801
# 8    A11720744        N          Y  25.951740 -80.119755
# 9    A11618404        N          Y  25.687221 -80.161390
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...     Michael Duchon
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...         Adi Amuial
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       Roberta Poli
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Karine Frangulyan
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...        Roger Silva
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...               None
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...        Ivan Madera
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...    Paul Sasseville
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...    Luciene Cofresi
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...      Gloria Ibarra
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                            The Corcoran Group    Eloy Carmenate
# 1                   Miles Goldstein Real Estate              None
# 2                      Related ISG Realty, LLC.              None
# 3              Signature One Luxury Estates LLC              None
# 4                 The Florida Lounge Realty LLC              None
# 5                                          None              None
# 6  Fortune Christie's International Real Estate              None
# 7                         Compass Florida, LLC.              None
# 8                  Fortune International Realty              None
# 9                           Realty Progress LLC              None
#
#    list_broker_name_2          buy_agent_name_1  \
# 0  The Corcoran Group              Darin Tansey
# 1                None  Adriana Vargas Hernandez
# 2                None     Viktoriya Donisova Ho
# 3                None               Wendy Cohen
# 4                None           Romina Grinberg
# 5                None                      None
# 6                None          Lindsey Lamchick
# 7                None              Cory Waldman
# 8                None           Claudio Minones
# 9                None           Natalia Salgado
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                     Douglas Elliman             None              None
# 1                    Acqualina Realty             None              None
# 2               Compass Florida, LLC.             None              None
# 3  One Sotheby's International Realty             None              None
# 4                Compass Florida, LLC             None              None
# 5                                None             None              None
# 6                            The Edit             None              None
# 7              Coldwell Banker Realty             None              None
# 8  One Sotheby's International Realty             None              None
# 9            DLS International Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  321 OCEAN CONDO at 321 Ocean Dr #201 in Miami ...
# 1     2    blue  17749 COLLINS AVENUE COND at 17749 Collins Ave...
# 2     3    blue  MUSE CONDO at 17141 Collins Ave #1501 in Sunny...
# 3     4    blue  18975 Collins Condo at 18975 Collins Ave #2303...
# 4     5    blue  18975 COLLINS CONDO at 18975 Collins Ave #903 ...
# 5     6    blue  PORTOFINO TOWER CONDO at 300 S Pointe Dr #1105...
# 6     7    blue  THE GROVE AT GRAND BAY at 2669 S Bayshore Dr U...
# 7     8    blue  SUNSET HARBOUR SOUTH COND at 1800 Sunset Harbo...
# 8     9    blue  18975 COLLINS CONDO at 18975 Collins Ave #604 ...
# 9    10    blue  LAKE VILLA THREE CONDO at 749 Crandon Blvd #21...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: 321 OCEAN CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,575,000 to $11,250,000
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Key Biscayne, Miami Beach, Miami, Sunny Isles Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 126 condo sales totaling $106,325,153 million from Mar. 23rd to Mar. 30th. The previous week, brokers closed 116 condo sales totaling $79,205,150.
#
# Last week’s units sold for an average of $843,850, higher than the $682,803 average price from the previous week. The average price per square foot rose to $547 from $536, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,575,000.0 million to $11,250,000.0 million.
#
# 321 OCEAN CONDO at 321 Ocean Dr #201 in Miami Beach took the top spot with a $11,250,000.0 million closing. The sale closed at $2,557.0 per square foot.
#
# Michael Duchon with The Corcoran Group, and Eloy Carmenate with The Corcoran Group had the listing.
# Darin Tansey with Douglas Elliman, and None with None represented the buyer.
#
# 17749 COLLINS AVENUE COND at 17749 Collins Ave #802 in Sunny Isles Beach, closed for the second highest amount, $6,100,000.0, or $1,323.0 per square foot.
#
# Adi Amuial with Miles Goldstein Real Estate, and None with None had the listing.
# Adriana Vargas Hernandez with Acqualina Realty, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_03312024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 23rd to Mar. 30th:
#
# Most Expensive
# 321 OCEAN CONDO, 321 Ocean Dr #201, in Miami Beach | Price: $11,250,000 | $2,557 psf | Listing agents: Michael Duchon with The Corcoran Group and Eloy Carmenate with The Corcoran Group | Buyer's agents: Darin Tansey with Douglas Elliman and None with None
#
# Least Expensive
# LAKE VILLA THREE CONDO, 749 Crandon Blvd #212, in Key Biscayne | Price: $2,575,000 | $972 psf | Listing agents: Gloria Ibarra with Realty Progress LLC and None with None | Buyer's agents: Natalia Salgado with DLS International Realty and None with None
#
# Highest Price Per Square Foot
# 321 OCEAN CONDO, 321 Ocean Dr #201, in Miami Beach | Price: $11,250,000 | $2,557 psf | Listing agents: Michael Duchon with The Corcoran Group and Eloy Carmenate with The Corcoran Group | Buyer's agents: Darin Tansey with Douglas Elliman and None with None
#
# Lowest Price Per Square Foot
# LAKE VILLA THREE CONDO, 749 Crandon Blvd #212, in Key Biscayne | Price: $2,575,000 | $972 psf | Listing agents: Gloria Ibarra with Realty Progress LLC and None with None | Buyer's agents: Natalia Salgado with DLS International Realty and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Miami-Beach/321-Ocean-Dr-33139/unit-201/home/45471133
# Second priciest sale:  https://www.redfin.com/FL/Sunny-Isles-Beach/17749-Collins-Ave-33160/unit-802/home/110130747
# Cheapest top ten sale:  https://www.redfin.com/FL/Key-Biscayne/749-Crandon-Blvd-33149/unit-212/home/42923730
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Sunny-Isles-Beach/18975-Collins-Ave-33160/unit-604/home/171050928
# Highest top ten psf:  https://www.redfin.com/FL/Miami-Beach/321-Ocean-Dr-33139/unit-201/home/45471133
# Lowest top ten psf:  https://www.redfin.com/FL/Key-Biscayne/749-Crandon-Blvd-33149/unit-212/home/42923730

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Miami-Beach/321-Ocean-Dr-33139/unit-201/home/45471133

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/17749-Collins-Ave-33160/unit-802/home/110130747

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Key-Biscayne/749-Crandon-Blvd-33149/unit-212/home/42923730

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/18975-Collins-Ave-33160/unit-604/home/171050928

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/321-Ocean-Dr-33139/unit-201/home/45471133

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Key-Biscayne/749-Crandon-Blvd-33149/unit-212/home/42923730

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                              ADDRESS  \
# 0  PAST SALE 2025-03-24   Condo/Co-op                    321 Ocean Dr #201
# 1  PAST SALE 2025-03-28   Condo/Co-op               17749 Collins Ave #802
# 2  PAST SALE 2025-03-28   Condo/Co-op              17141 Collins Ave #1501
# 3  PAST SALE 2025-03-24   Condo/Co-op              18975 Collins Ave #2303
# 4  PAST SALE 2025-03-26   Condo/Co-op               18975 Collins Ave #903
# 5  PAST SALE 2025-03-27   Condo/Co-op                300 S Pointe Dr #1105
# 6  PAST SALE 2025-03-24   Condo/Co-op        2669 S Bayshore Dr Unit 1602N
# 7  PAST SALE 2025-03-28   Condo/Co-op  1800 Sunset Harbour Dr Unit 1102/04
# 8  PAST SALE 2025-03-24   Condo/Co-op               18975 Collins Ave #604
# 9  PAST SALE 2025-03-25   Condo/Co-op                749 Crandon Blvd #212
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL             33139.0  11250000.0   5.0
# 1  Sunny Isles Beach                FL             33160.0   6100000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0   4950000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0   3800000.0   3.0
# 4  Sunny Isles Beach                FL             33160.0   3775000.0   3.0
# 5        Miami Beach                FL             33139.0   3600000.0   3.0
# 6              Miami                FL             33133.0   3500000.0   3.0
# 7        Miami Beach                FL             33139.0   2837500.0   4.0
# 8  Sunny Isles Beach                FL             33160.0   2600000.0   2.0
# 9       Key Biscayne                FL             33149.0   2575000.0   4.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5            321 OCEAN CONDO       4400.0       NaN      2015.0
# 1    6.5  17749 COLLINS AVENUE COND       4609.0       NaN      2015.0
# 2    3.5                 MUSE CONDO       3195.0       NaN      2018.0
# 3    3.5        18975 Collins Condo       2271.0       NaN      2019.0
# 4    3.5        18975 COLLINS CONDO       2271.0       NaN      2019.0
# 5    2.5      PORTOFINO TOWER CONDO       2340.0       NaN      1996.0
# 6    3.5     THE GROVE AT GRAND BAY       1829.0       NaN      2016.0
# 7    3.5  SUNSET HARBOUR SOUTH COND       2246.0       NaN      1998.0
# 8    2.5        18975 COLLINS CONDO       1521.0       NaN      2019.0
# 9    3.0     LAKE VILLA THREE CONDO       2650.0       NaN      1998.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2557.0    28702.0   Sold
# 1             NaN         1323.0    10288.0   Sold
# 2             NaN         1549.0     9176.0   Sold
# 3             NaN         1673.0     3734.0   Sold
# 4             NaN         1662.0     8904.0   Sold
# 5             NaN         1538.0     4016.0   Sold
# 6             NaN         1914.0     3083.0   Sold
# 7             NaN         1263.0     3317.0   Sold
# 8             NaN         1709.0     2983.0   Sold
# 9             NaN          972.0     3605.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...       MARMLS
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       MARMLS
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Beaches MLS
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...       MARMLS
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...       MARMLS
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...       MARMLS
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...       MARMLS
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...       MARMLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11695945        N          Y  25.772296 -80.131901
# 1    A11611470        N          Y  25.940065 -80.120264
# 2    A11490517        N          Y  25.934939 -80.120918
# 3  RX-11004551        N          Y  25.951740 -80.119755
# 4    A11712041        N          Y  25.951740 -80.119755
# 5    A11710839        N          Y  25.767706 -80.134877
# 6    A11582132        N          Y  25.730676 -80.237117
# 7    A11606692        N          Y  25.794488 -80.144801
# 8    A11720744        N          Y  25.951740 -80.119755
# 9    A11618404        N          Y  25.687221 -80.161390
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Miami-Beach/321-Ocea...     Michael Duchon
# 1  https://www.redfin.com/FL/Sunny-Isles-Beach/17...         Adi Amuial
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/17...       Roberta Poli
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  Karine Frangulyan
# 4  https://www.redfin.com/FL/Sunny-Isles-Beach/18...        Roger Silva
# 5  https://www.redfin.com/FL/Miami-Beach/300-S-Po...               None
# 6  https://www.redfin.com/FL/Miami/2669-S-Bayshor...        Ivan Madera
# 7  https://www.redfin.com/FL/Miami-Beach/1800-Sun...    Paul Sasseville
# 8  https://www.redfin.com/FL/Sunny-Isles-Beach/18...    Luciene Cofresi
# 9  https://www.redfin.com/FL/Key-Biscayne/749-Cra...      Gloria Ibarra
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                            The Corcoran Group    Eloy Carmenate
# 1                   Miles Goldstein Real Estate              None
# 2                      Related ISG Realty, LLC.              None
# 3              Signature One Luxury Estates LLC              None
# 4                 The Florida Lounge Realty LLC              None
# 5                                          None              None
# 6  Fortune Christie's International Real Estate              None
# 7                         Compass Florida, LLC.              None
# 8                  Fortune International Realty              None
# 9                           Realty Progress LLC              None
#
#    list_broker_name_2          buy_agent_name_1  \
# 0  The Corcoran Group              Darin Tansey
# 1                None  Adriana Vargas Hernandez
# 2                None     Viktoriya Donisova Ho
# 3                None               Wendy Cohen
# 4                None           Romina Grinberg
# 5                None                      None
# 6                None          Lindsey Lamchick
# 7                None              Cory Waldman
# 8                None           Claudio Minones
# 9                None           Natalia Salgado
#
#                     buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0                     Douglas Elliman             None              None
# 1                    Acqualina Realty             None              None
# 2               Compass Florida, LLC.             None              None
# 3  One Sotheby's International Realty             None              None
# 4                Compass Florida, LLC             None              None
# 5                                None             None              None
# 6                            The Edit             None              None
# 7              Coldwell Banker Realty             None              None
# 8  One Sotheby's International Realty             None              None
# 9            DLS International Realty             None              None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  321 OCEAN CONDO at 321 Ocean Dr #201 in Miami ...
# 1     2    blue  17749 COLLINS AVENUE COND at 17749 Collins Ave...
# 2     3    blue  MUSE CONDO at 17141 Collins Ave #1501 in Sunny...
# 3     4    blue  18975 Collins Condo at 18975 Collins Ave #2303...
# 4     5    blue  18975 COLLINS CONDO at 18975 Collins Ave #903 ...
# 5     6    blue  PORTOFINO TOWER CONDO at 300 S Pointe Dr #1105...
# 6     7    blue  THE GROVE AT GRAND BAY at 2669 S Bayshore Dr U...
# 7     8    blue  SUNSET HARBOUR SOUTH COND at 1800 Sunset Harbo...
# 8     9    blue  18975 COLLINS CONDO at 18975 Collins Ave #604 ...
# 9    10    blue  LAKE VILLA THREE CONDO at 749 Crandon Blvd #21...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 6, 22) ## List (Earlier) date
date2 = datetime(2025, 3, 28) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 279

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    2557.0
# 1    1323.0
# 2    1549.0
# 3    1673.0
# 4    1662.0
# 5    1538.0
# 6    1914.0
# 7    1263.0
# 8    1709.0
# 9     972.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS        PRICE  \
# 0 2025-03-24                   321 Ocean Dr #201 in Miami Beach  $11,250,000
# 1 2025-03-28        17749 Collins Ave #802 in Sunny Isles Beach   $6,100,000
# 2 2025-03-28       17141 Collins Ave #1501 in Sunny Isles Beach   $4,950,000
# 3 2025-03-24       18975 Collins Ave #2303 in Sunny Isles Beach   $3,800,000
# 4 2025-03-26        18975 Collins Ave #903 in Sunny Isles Beach   $3,775,000
# 5 2025-03-27               300 S Pointe Dr #1105 in Miami Beach   $3,600,000
# 6 2025-03-24             2669 S Bayshore Dr Unit 1602N in Miami   $3,500,000
# 7 2025-03-28  1800 Sunset Harbour Dr Unit 1102/04 in Miami B...   $2,837,500
# 8 2025-03-24        18975 Collins Ave #604 in Sunny Isles Beach   $2,600,000
# 9 2025-03-25              749 Crandon Blvd #212 in Key Biscayne   $2,575,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    5    5.5       4,400       2015        $2,557       MARMLS    A11695945
# 1    4    6.5       4,609       2015        $1,323       MARMLS    A11611470
# 2    3    3.5       3,195       2018        $1,549       MARMLS    A11490517
# 3    3    3.5       2,271       2019        $1,673  Beaches MLS  RX-11004551
# 4    3    3.5       2,271       2019        $1,662       MARMLS    A11712041
# 5    3    2.5       2,340       1996        $1,538       MARMLS    A11710839
# 6    3    3.5       1,829       2016        $1,914       MARMLS    A11582132
# 7    4    3.5       2,246       1998        $1,263       MARMLS    A11606692
# 8    2    2.5       1,521       2019        $1,709       MARMLS    A11720744
# 9    4    3.0       2,650       1998          $972       MARMLS    A11618404
#
#                                         LISTING INFO  \
# 0  Michael Duchon The Corcoran Group Eloy Carmena...
# 1         Adi Amuial Miles Goldstein Real Estate
# 2          Roberta Poli Related ISG Realty, LLC.
# 3  Karine Frangulyan Signature One Luxury Estates...
# 4      Roger Silva The Florida Lounge Realty LLC
# 5
# 6  Ivan Madera Fortune Christie's International R...
# 7          Paul Sasseville Compass Florida, LLC.
# 8   Luciene Cofresi Fortune International Realty
# 9              Gloria Ibarra Realty Progress LLC
#
#                                          BUYING INFO
# 0                   Darin Tansey Douglas Elliman
# 1      Adriana Vargas Hernandez Acqualina Realty
# 2    Viktoriya Donisova Ho Compass Florida, LLC.
# 3  Wendy Cohen One Sotheby's International Realty...
# 4           Romina Grinberg Compass Florida, LLC
# 5
# 6                      Lindsey Lamchick The Edit
# 7            Cory Waldman Coldwell Banker Realty
# 8  Claudio Minones One Sotheby's International Re...
# 9       Natalia Salgado DLS International Realty
