# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import tabula

# %% [markdown]
# ## Read-in

# %%
# Gotta figure out how to get rid of the java error.
# SO: https://stackoverflow.com/questions/54817211/java-command-is-not-found-from-this-python-process-please-ensure-java-is-inst

dsf = tabula.read_pdf('condo.pdf', pages='all')

# %% [markdown]
# ## Clean Data

# %%
df = dsf[0]
df.columns = df.iloc[0]
df = df[1:]
df = df.drop(columns=df.columns[0])
df = df.replace(np.nan, 'Not Available', regex=True)
df = df.rename(columns={'Building / Address / City': 'building_address_city','Days on\rMarket':'days_on_market',\
                        'Price /\rSq. Ft.':'price_per_sqft'})
df['building_address_city'] = df['building_address_city'].str.replace('^0', '', regex=True)
df['geo_address'] = df['building_address_city']
df['geo_address'] = df['geo_address'].map(lambda x: re.sub(r'\r', ' ', x))
df = df.replace('\n',' ',regex=True)
pattern = r'^(?P<building_name>[\d\s]*[A-Za-z\s]+)\s(?P<address>.+)\s(?P<city>[A-Za-z\s]+)$'
df2[['building_name', 'address', 'city']] = df['geo_address'].str.extract(pattern, expand=True)

# %% [markdown]
# Review this later (it's about how to properly merge DFs): https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## Geocode

# %%
result = pd.merge(df,df2,left_index=True, right_index=True)
df = result
df = df.drop(columns=['address','city'])

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# Folium documentation link: https://python-visualization.github.io/folium/index.html
#
# Folium is the library that lets us use leaflet with Python, since it's meant to be used with JavaScript.
#
# For adding titles: https://stackoverflow.com/questions/61928013/adding-a-title-or-text-to-a-folium-map

# %% [markdown]
# ## Correction section

# %%
## Sample Format ##
# df.at[10,'building_name']=('1500 Ocean Drive')

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df = df.replace('N/A', np.nan)

# %%
df['int_Sale_Price'] = df['Sale Price'].str.replace('$','',regex=False)

# %%
df['int_Sale_Price'] = df['int_Sale_Price'].str.replace(',','',regex=False)

# %%
df['int_Sale_Price'] = pd.to_numeric(df['int_Sale_Price'])

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.replace('$','',regex=False)
df['price_per_sqft'] = df['price_per_sqft'].str.replace(',','',regex=False)
df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'])

df['days_on_market'] = pd.to_numeric(df['days_on_market'])

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df['RANK'] = range(1, len(df) + 1)
# use numpy to assign values to the 'COLOR' column
df['COLOR'] = np.where(df['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['building_address_city', 'Close Date', 'days_on_market', 'Sale Price',
#        'Sq. Ft.', 'price_per_sqft', 'Agent', 'Listing Broker', 'Buyer Agent',
#        'Buyer Broker', 'geo_address', 'building_name', 'address_only',
#        'geocoded', 'lat', 'lon', 'int_Sale_Price', 'RANK', 'COLOR'],
#       dtype='object')

# %%
def popup_html(row):
    building_name = row['building_name']
    price = row['Sale Price']
    days_on_market = row['days_on_market']
    listing_agent = row['Agent']
    buyers_agent = row['Buyer Agent']
    psf = row['price_per_sqft']
    address = row['address_only']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>{}'''.format(price) + '''<br>
    <strong>Days on Market: </strong>{}'''.format(days_on_market) + '''<br>
    <strong>Listing Agent: </strong>{}'''.format(listing_agent) + '''<br>
    <strong>Buyer's Agent: </strong>{}'''.format(buyers_agent) + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(psf) + '''<br>
    <strong>Address: </strong>{}'''.format(address) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format('June 4th - June 10th')


### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b239b286891945729b7ee31d1a4340a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;June 4th - June 10th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b239b286891945729b7ee31d1a4340a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b239b286891945729b7ee31d1a4340a7 = L.map(
#                 &quot;map_b239b286891945729b7ee31d1a4340a7&quot;,
#                 {
#                     center: [25.807322570000004, -80.16471788999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_baffb7dc4d0f84005e47d6f27c4521a6 = L.featureGroup(
#                 {}
#             ).addTo(map_b239b286891945729b7ee31d1a4340a7);
#
#
#             var marker_c5571045c8dc21f0c0eba0601e8ff6d3 = L.marker(
#                 [25.7322298, -80.2348919],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_baffb7dc4d0f84005e47d6f27c4521a6);
#
#
#             var icon_bec0542e49a41d2d2b307760f6d27d43 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c5571045c8dc21f0c0eba0601e8ff6d3.setIcon(icon_bec0542e49a41d2d2b307760f6d27d43);
#
#
#         var popup_0b70e89479c3f34aa1cc49281e87048a = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_fb818372f3280375167931e70ea6a291 = $(`&lt;div id=&quot;html_fb818372f3280375167931e70ea6a291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;Grovenor House Condo&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$12,550,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;56&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Roberta Ingletto&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;Daniel Hertzberg&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1813.58&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;2627 S Bayshore Dr LPH 3101 Miami&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_0b70e89479c3f34aa1cc49281e87048a.setContent(html_fb818372f3280375167931e70ea6a291);
#
#
#
#         marker_c5571045c8dc21f0c0eba0601e8ff6d3.bindPopup(popup_0b70e89479c3f34aa1cc49281e87048a)
#         ;
#
#
#
#
#             var feature_group_7e0a6bd60317baa35931c242688286d2 = L.featureGroup(
#                 {}
#             ).addTo(map_b239b286891945729b7ee31d1a4340a7);
#
#
#             var marker_08f8b269f9128e441de49e3f08b072c6 = L.marker(
#                 [25.6875627, -80.1581203],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e0a6bd60317baa35931c242688286d2);
#
#
#             var icon_543698446db837ea5f3e2c826dfe1c40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_08f8b269f9128e441de49e3f08b072c6.setIcon(icon_543698446db837ea5f3e2c826dfe1c40);
#
#
#         var popup_a2c1fb130f35fd7d3943113ef359c017 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3d41fb2ae0f466d5330ec27862535ca5 = $(`&lt;div id=&quot;html_3d41fb2ae0f466d5330ec27862535ca5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;The Ocean Club&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$5,250,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;64&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Douglas Kinsley&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;Mairym Casal&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1316.12&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;791 Crandon Blvd 206 Key Biscayne&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_a2c1fb130f35fd7d3943113ef359c017.setContent(html_3d41fb2ae0f466d5330ec27862535ca5);
#
#
#
#         marker_08f8b269f9128e441de49e3f08b072c6.bindPopup(popup_a2c1fb130f35fd7d3943113ef359c017)
#         ;
#
#
#
#
#             var marker_4bf7d06053af79bf70e3629ec2a7fe4c = L.marker(
#                 [25.7672315, -80.1327611],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e0a6bd60317baa35931c242688286d2);
#
#
#             var icon_362a9f8c457a96f7b14d488603374baa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quo

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df
# Out:
#                                 building_address_city Close Date
# 1   Grovenor House Condo\r2627 S Bayshore Dr LPH 3...  6/15/2023  \
# 2   The Ocean Club\r791 Crandon Blvd 206\rKey Bisc...  6/15/2023
# 3         Continuum\r50 S Pointe Dr 2004\rMiami Beach  6/12/2023
# 4   Jade Signature\r16901 Collins Ave 3203\rSunny ...  6/14/2023
# 5   Residences Ritz Carlton\r3400 SW 27th Ave 1002...  6/12/2023
# 6    Icon South Beach\r450 Alton Rd 3202\rMiami Beach  6/12/2023
# 7          Four Seasons\r1425 Brickell Ave 45B\rMiami  6/16/2023
# 8   900 Biscayne Bay\r900 Biscayne Blvd PH-6109\rM...  6/16/2023
# 9   Ocean Two\r19111 Collins Ave 1004\rSunny Isles...  6/14/2023
# 10  Ocean Two\r19111 Collins Ave 2005\rSunny Isles...  6/12/2023
#
#     days_on_market      Sale Price Sq. Ft.  price_per_sqft
# 1               56  $12,550,000.00    6920         1813.58  \
# 2               64   $5,250,000.00    3989         1316.12
# 3              220   $4,400,000.00    1443         3049.20
# 4              240   $3,850,000.00    2511         1533.25
# 5                6   $3,000,000.00    2110         1421.80
# 6               35   $2,800,000.00    1933         1448.53
# 7              414   $2,425,000.00    2114         1147.11
# 8               42   $1,875,000.00    2577          727.59
# 9              167   $1,825,000.00    2440          747.95
# 10              69   $1,800,000.00    2440          737.70
#
#                    Agent                        Listing Broker
# 1       Roberta Ingletto                            RGI Realty  \
# 2        Douglas Kinsley  Fortune Christie's Int'l Real Estate
# 3             Lisa Blake                        Villazzo, LLC.
# 4   Gustavo Strallnikoff             Dezer Platinum Realty LLC
# 5            Glen Janney              Cervera Real Estate Inc.
# 6            Sean Murray                       Douglas Elliman
# 7        Magin Hernandez                Magin New World Realty
# 8          Benjamin Moss                  Compass Florida, LLC
# 9   Jocelyn Alter Furman                      BMore Group, LLC
# 10           Wendy Cohen    One Sotheby's International Realty
#
#             Buyer Agent                        Buyer Broker
# 1      Daniel Hertzberg              Coldwell Banker Realty  \
# 2          Mairym Casal                Brown Harris Stevens
# 3        Kayce Driscoll                     Douglas Elliman
# 4   Viacheslav Kutsenko           Florida Best Realty, Inc.
# 5           Glen Janney            Cervera Real Estate Inc.
# 6          Judith Zeder              Coldwell Banker Realty
# 7      Vanessa Frank PA  One Sotheby's International Realty
# 8       Andrea Da Silva            Related ISG Realty, LLC.
# 9        Joanna Jimenez                Compass Florida, LLC
# 10         Daniel Cohen  One Sotheby's International Realty
#
#                                           geo_address
# 1   Grovenor House Condo 2627 S Bayshore Dr LPH 31...  \
# 2    The Ocean Club 791 Crandon Blvd 206 Key Biscayne
# 3           Continuum 50 S Pointe Dr 2004 Miami Beach
# 4   Jade Signature 16901 Collins Ave 3203 Sunny Is...
# 5   Residences Ritz Carlton 3400 SW 27th Ave 1002 ...
# 6      Icon South Beach 450 Alton Rd 3202 Miami Beach
# 7            Four Seasons 1425 Brickell Ave 45B Miami
# 8    900 Biscayne Bay 900 Biscayne Blvd PH-6109 Miami
# 9   Ocean Two 19111 Collins Ave 1004 Sunny Isles B...
# 10  Ocean Two 19111 Collins Ave 2005 Sunny Isles B...
#
#               building_name                                      address_only
# 1      Grovenor House Condo                 2627 S Bayshore Dr LPH 3101 Miami  \
# 2            The Ocean Club                 791 Crandon Blvd 206 Key Biscayne
# 3                 Continuum                   50 S Pointe Dr 2004 Miami Beach
# 4            Jade Signature          16901 Collins Ave 3203 Sunny Isles Beach
# 5   Residences Ritz Carlton               3400 SW 27th Ave 1002 Coconut Grive
# 6          Icon South Beach                     450 Alton Rd 3202 Miami Beach
# 7              Four Seasons                       1425 Brickell Ave 45B Miami
# 8          900 Biscayne Bay  900 Biscayne Bay 900 Biscayne Blvd PH-6109 Miami
# 9                 Ocean Two          19111 Collins Ave 1004 Sunny Isles Beach
# 10                Ocean Two          19111 Collins Ave 2005 Sunny Isles Beach
#
#                             geocoded        lat        lon  int_Sale_Price
# 1          (25.7322298, -80.2348919)  25.732230 -80.234892      12550000.0  \
# 2          (25.6875627, -80.1581203)  25.687563 -80.158120       5250000.0
# 3          (25.7672315, -80.1327611)  25.767232 -80.132761       4400000.0
# 4          (25.9327557, -80.1210054)  25.932756 -80.121005       3850000.0
# 5          (25.7297273, -80.2378425)  25.729727 -80.237842       3000000.0
# 6          (25.7736596, -80.1411255)  25.773660 -80.141126       2800000.0
# 7          (25.7591323, -80.1918295)  25.759132 -80.191829       2425000.0
# 8   (25.7834936, -80.19020909999999)  25.783494 -80.190209       1875000.0
# 9          (25.9537166, -80.1196968)  25.953717 -80.119697       1825000.0
# 10         (25.9537166, -80.1196968)  25.953717 -80.119697       1800000.0
#
#     RANK   COLOR
# 1      1  orange
# 2      2    blue
# 3      3    blue
# 4      4    blue
# 5      5    blue
# 6      6    blue
# 7      7    blue
# 8      8    blue
# 9      9    blue
# 10    10    blue

# %%
### Highest and lowest sale price ###
print(f"{ME}{BR}{df.loc[df['int_Sale_Price'].idxmax()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmax()]['address_only']} | Price ${df.loc[df['int_Sale_Price'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmax()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmax()]['days_on_market']}")
print(f"{LE}{BR}{df.loc[df['int_Sale_Price'].idxmin()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmin()]['address_only']} | Price ${df.loc[df['int_Sale_Price'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmin()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmin()]['days_on_market']}")
### Highest and lowest psf ###
print(f"{MAX_PSF}{BR}{df.loc[df['price_per_sqft'].idxmax()]['building_name']}, {df.loc[df['price_per_sqft'].idxmax()]['address_only']} | Price ${df.loc[df['price_per_sqft'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmax()]['Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmax()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmax()]['days_on_market']}")
print(f"{MIN_PSF}{BR}{df.loc[df['price_per_sqft'].idxmin()]['building_name']}, {df.loc[df['price_per_sqft'].idxmin()]['address_only']} | Price ${df.loc[df['price_per_sqft'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmin()]['Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmin()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmin()]['days_on_market']}")
### Highest and lowest days on market ###
print(f"{DAYS_MAX}{BR}{df.loc[df['days_on_market'].idxmax()]['building_name']}, {df.loc[df['days_on_market'].idxmax()]['address_only']} | Price ${df.loc[df['days_on_market'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmax()]['Agent']} with {df.loc[df['days_on_market'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmax()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmax()]['days_on_market']}")
print(f"{DAYS_MIN}{BR}{df.loc[df['days_on_market'].idxmin()]['building_name']}, {df.loc[df['days_on_market'].idxmin()]['address_only']} | Price ${df.loc[df['days_on_market'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmin()]['Agent']} with {df.loc[df['days_on_market'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmin()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmin()]['days_on_market']}")
# Out:
# Most Expensive
# Grovenor House Condo, 2627 S Bayshore Dr LPH 3101 Miami | Price $12,550,000 | $1,814 psf | Listing agent: Roberta Ingletto with RGI Realty | Buyer's agent: Daniel Hertzberg with Coldwell Banker Realty | Days on market: 56
# Least Expensive
# Ocean Two, 19111 Collins Ave 2005 Sunny Isles Beach | Price $1,800,000 | $738 psf | Listing agent: Wendy Cohen with One Sotheby's International Realty | Buyer's agent: Daniel Cohen with One Sotheby's International Realty | Days on market: 69
# Highest Price Per Square Foot
# Continuum, 50 S Pointe Dr 2004 Miami Beach | Price $4,400,000 | $3,049 psf | Listing agent: Lisa Blake with Villazzo, LLC. | Buyer's agent: Kayce Driscoll with Douglas Elliman | Days on market: 220
# Lowest Price Per Square Foot
# 900 Biscayne Bay, 900 Biscayne Bay 900 Biscayne Blvd PH-6109 Miami | Price $1,875,000 | $728 psf | Listing agent: Benjamin Moss with Compass Florida, LLC | Buyer's agent: Andrea Da Silva with Related ISG Realty, LLC. | Days on market: 42
# Most Days on Market
# Four Seasons, 1425 Brickell Ave 45B Miami | Price $2,425,000 | $1,147 psf | Listing agent: Magin Hernandez with Magin New World Realty | Buyer's agent: Vanessa Frank PA with One Sotheby's International Realty | Days on market: 414
# Fewest Days on Market
# Residences Ritz Carlton, 3400 SW 27th Ave 1002 Coconut Grive | Price $3,000,000 | $1,422 psf | Listing agent: Glen Janney with Cervera Real Estate Inc. | Buyer's agent: Glen Janney with Cervera Real Estate Inc. | Days on market: 6

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_06202023
