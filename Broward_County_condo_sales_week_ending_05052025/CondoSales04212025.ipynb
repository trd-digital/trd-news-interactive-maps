# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Apr. 27th May. 4th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE               ADDRESS  \
# 1  PAST SALE  April-30-2025   Condo/Co-op  377 Tilford R Unit R
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  \
# 1  Deerfield Beach                FL             33442.0  78500.0   1.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    1.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Deerfield-Beach/377-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11083581         N          Y  26.311022 -80.150841
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-04-30    64
# 2025-04-28    39
# 2025-05-01    34
# 2025-04-29    34
# 2025-05-02    17
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 44   PAST SALE 2025-04-30   Condo/Co-op
# 108  PAST SALE 2025-05-01   Condo/Co-op
# 132  PAST SALE 2025-04-30   Condo/Co-op
# 11   PAST SALE 2025-04-30   Condo/Co-op
# 133  PAST SALE 2025-04-30   Condo/Co-op
# 122  PAST SALE 2025-04-28   Condo/Co-op
# 110  PAST SALE 2025-04-29   Condo/Co-op
# 125  PAST SALE 2025-05-02   Condo/Co-op
# 161  PAST SALE 2025-05-02   Condo/Co-op
# 91   PAST SALE 2025-04-30   Condo/Co-op
#
#                                         ADDRESS                   CITY  \
# 44                  2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 108                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 132                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 11                   20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 133                      333 Las Olas Way #3802        Fort Lauderdale
# 122                      333 Las Olas Way #2910        Fort Lauderdale
# 110                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 125                       2100 S Ocean Ln #2102        Fort Lauderdale
# 161                        100 S Birch Rd #2501        Fort Lauderdale
# 91   551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#     STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 44                 FL             33305.0  3862500.0   3.0    3.5  ...   Sold
# 108                FL             33301.0  3850000.0   4.0    4.5  ...   Sold
# 132                FL             33062.0  3650000.0   3.0    4.0  ...   Sold
# 11                 FL             33301.0  2885000.0   3.0    3.0  ...   Sold
# 133                FL             33301.0  2250000.0   3.0    3.5  ...   Sold
# 122                FL             33301.0  1900000.0   3.0    3.5  ...   Sold
# 110                FL             33062.0  1505000.0   3.0    2.5  ...   Sold
# 125                FL             33316.0  1455000.0   2.0    2.0  ...   Sold
# 161                FL             33316.0  1450000.0   3.0    2.5  ...   Sold
# 91                 FL             33304.0   980000.0   2.0    2.5  ...   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 44                          NaN                       NaN
# 108                         NaN                       NaN
# 132                         NaN                       NaN
# 11                          NaN                       NaN
# 133                         NaN                       NaN
# 122                         NaN                       NaN
# 110                         NaN                       NaN
# 125                         NaN                       NaN
# 161                         NaN                       NaN
# 91                          NaN                       NaN
#
#                                                    URL       SOURCE  \
# 44   https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS
# 108  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS
# 132  https://www.redfin.com/FL/Pompano-Beach/730-N-...  Beaches MLS
# 11   https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS
# 133  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS
# 122  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS
# 110  https://www.redfin.com/FL/Pompano-Beach/1800-S...       MARMLS
# 125  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS
# 161  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS
# 91   https://www.redfin.com/FL/Fort-Lauderdale/551-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 44   A11744571         N          Y  26.157113 -80.100624
# 108  F10484254         N          Y  26.125672 -80.120892
# 132  F10479015         N          Y  26.243932 -80.087321
# 11   F10495970         N          Y  26.121158 -80.120244
# 133  F10461930         N          Y  26.118354 -80.141518
# 122  F10473160         N          Y  26.118354 -80.141518
# 110  A11719958         N          Y  26.207626 -80.093562
# 125  A11711209         N          Y  26.096516 -80.106815
# 161  F10467363         N          Y  26.121167 -80.106486
# 91   F10483825         N          Y  26.130917 -80.104597
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-04-30   Condo/Co-op
# 1  PAST SALE 2025-05-01   Condo/Co-op
# 2  PAST SALE 2025-04-30   Condo/Co-op
# 3  PAST SALE 2025-04-30   Condo/Co-op
# 4  PAST SALE 2025-04-30   Condo/Co-op
# 5  PAST SALE 2025-04-28   Condo/Co-op
# 6  PAST SALE 2025-04-29   Condo/Co-op
# 7  PAST SALE 2025-05-02   Condo/Co-op
# 8  PAST SALE 2025-05-02   Condo/Co-op
# 9  PAST SALE 2025-04-30   Condo/Co-op
#
#                                       ADDRESS                   CITY  \
# 0                 2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 1                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 2                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 3                  20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 4                      333 Las Olas Way #3802        Fort Lauderdale
# 5                      333 Las Olas Way #2910        Fort Lauderdale
# 6                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 7                       2100 S Ocean Ln #2102        Fort Lauderdale
# 8                        100 S Birch Rd #2501        Fort Lauderdale
# 9  551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ...  \
# 0                FL             33305.0  3862500.0   3.0    3.5  ...
# 1                FL             33301.0  3850000.0   4.0    4.5  ...
# 2                FL             33062.0  3650000.0   3.0    4.0  ...
# 3                FL             33301.0  2885000.0   3.0    3.0  ...
# 4                FL             33301.0  2250000.0   3.0    3.5  ...
# 5                FL             33301.0  1900000.0   3.0    3.5  ...
# 6                FL             33062.0  1505000.0   3.0    2.5  ...
# 7                FL             33316.0  1455000.0   2.0    2.0  ...
# 8                FL             33316.0  1450000.0   3.0    2.5  ...
# 9                FL             33304.0   980000.0   2.0    2.5  ...
#
#    LONGITUDE                                                url  \
# 0 -80.100624  https://www.redfin.com/FL/Fort-Lauderdale/2200...
# 1 -80.120892  https://www.redfin.com/FL/Fort-Lauderdale/141-...
# 2 -80.087321  https://www.redfin.com/FL/Pompano-Beach/730-N-...
# 3 -80.120244  https://www.redfin.com/FL/Fort-Lauderdale/20-I...
# 4 -80.141518  https://www.redfin.com/FL/Fort-Lauderdale/333-...
# 5 -80.141518  https://www.redfin.com/FL/Fort-Lauderdale/333-...
# 6 -80.093562  https://www.redfin.com/FL/Pompano-Beach/1800-S...
# 7 -80.106815  https://www.redfin.com/FL/Fort-Lauderdale/2100...
# 8 -80.106486  https://www.redfin.com/FL/Fort-Lauderdale/100-...
# 9 -80.104597  https://www.redfin.com/FL/Fort-Lauderdale/551-...
#
#    list_agent_name_1            list_broker_name_1   list_agent_name_2  \
# 0     Michelle Nunez  Fortune International Realty        Megan Probst
# 1       David Marder          Compass Florida, LLC       Maria Scarola
# 2         Tara Hoyer       Sabbia Beach Realty Inc                None
# 3      Andrew Ziffer          Compass Florida, LLC  Michelle Akerstrom
# 4   Samantha LaViola    DeBianchi Real Estate, LLC                None
# 5         David Diaz          Compass Florida, LLC        Peter Barkin
# 6     Marni Schapson                    LPT Realty                None
# 7         Brian Hero    One Sotheby's Int'l Realty                None
# 8    Jolanta Johnson          Compass Florida, LLC       Marzena Annis
# 9  Tika Van Den Hurk               Douglas Elliman                None
#
#          list_broker_name_2      buy_agent_name_1        buy_broker_name_1  \
# 0      Compass Florida, LLC       Sharon Srebnick   Coldwell Banker Realty
# 1  Related ISG Realty, LLC.          David Marder     Compass Florida, LLC
# 2                      None            Tara Hoyer  Sabbia Beach Realty Inc
# 3      Compass Florida, LLC      Lourdes Maestres     Compass Florida, LLC
# 4                      None  Non-member Mls Agent           NON MEMBER MLS
# 5      Compass Florida, LLC  Non-member Mls Agent           NON MEMBER MLS
# 6                      None                  None                     None
# 7                      None                  None                     None
# 8      Compass Florida, LLC    Christopher Maxner     Compass Florida, LLC
# 9                      None                  None    Engel & Völkers Miami
#
#    buy_agent_name_2  buy_broker_name_2
# 0              None               None
# 1              None               None
# 2              None               None
# 3              None               None
# 4              None               None
# 5              None               None
# 6              None               None
# 7              None               None
# 8              None               None
# 9              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 188

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $391,807

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $300

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $73,659,705

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          188              391807          300                     73659705.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 137
# -----------
# Input Previous Week Condo Average Sales Price:
# 336236
# -----------
# Input Previous Week Condo Average PSF:
# 272
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 46064280.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-30   Condo/Co-op  2200 N Ocean Blvd Unit N302
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33305.0  3862500.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  MARMLS  A11744571
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Michelle Nunez
#
#              list_broker_name_1 list_agent_name_2    list_broker_name_2  \
# 0  Fortune International Realty      Megan Probst  Compass Florida, LLC
#
#   buy_agent_name_1       buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0  Sharon Srebnick  Coldwell Banker Realty             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-04-30   Condo/Co-op
# 1  PAST SALE 2025-05-01   Condo/Co-op
# 2  PAST SALE 2025-04-30   Condo/Co-op
# 3  PAST SALE 2025-04-30   Condo/Co-op
# 4  PAST SALE 2025-04-30   Condo/Co-op
# 5  PAST SALE 2025-04-28   Condo/Co-op
# 6  PAST SALE 2025-04-29   Condo/Co-op
# 7  PAST SALE 2025-05-02   Condo/Co-op
# 8  PAST SALE 2025-05-02   Condo/Co-op
# 9  PAST SALE 2025-04-30   Condo/Co-op
#
#                                       ADDRESS                   CITY  \
# 0                 2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 1                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 2                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 3                  20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 4                      333 Las Olas Way #3802        Fort Lauderdale
# 5                      333 Las Olas Way #2910        Fort Lauderdale
# 6                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 7                       2100 S Ocean Ln #2102        Fort Lauderdale
# 8                        100 S Birch Rd #2501        Fort Lauderdale
# 9  551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33305.0  3862500.0   3.0    3.5
# 1                FL             33301.0  3850000.0   4.0    4.5
# 2                FL             33062.0  3650000.0   3.0    4.0
# 3                FL             33301.0  2885000.0   3.0    3.0
# 4                FL             33301.0  2250000.0   3.0    3.5
# 5                FL             33301.0  1900000.0   3.0    3.5
# 6                FL             33062.0  1505000.0   3.0    2.5
# 7                FL             33316.0  1455000.0   2.0    2.0
# 8                FL             33316.0  1450000.0   3.0    2.5
# 9                FL             33304.0   980000.0   2.0    2.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
# 1                Casa Murano       3131.0       NaN      2024.0
# 2               Sabbia Beach       2956.0       NaN      2019.0
# 3          Aqualuna Las Olas       3134.0       NaN      2017.0
# 4       Las Olas River House       2726.0       NaN      2004.0
# 5       Las Olas River House       3239.0       NaN      2004.0
# 6   HAMPTON BEACH CLUB CONDO       2300.0       NaN      1980.0
# 7    POINT OF AMERICAS CONDO       1879.0       NaN      1969.0
# 8     Jackson Tower Las Olas       1998.0       NaN      2001.0
# 9     Ocean Resort Residence       1060.0       NaN      2009.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
# 1             NaN         1230.0     2521.0   Sold
# 2             NaN         1235.0     4939.0   Sold
# 3             NaN          921.0     2291.0   Sold
# 4             NaN          825.0     3529.0   Sold
# 5             NaN          587.0        NaN   Sold
# 6             NaN          654.0     1915.0   Sold
# 7             NaN          774.0     2171.0   Sold
# 8             NaN          726.0     2846.0   Sold
# 9             NaN          925.0        7.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11744571
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10484254
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...  Beaches MLS  F10479015
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10495970
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10461930
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10473160
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...       MARMLS  A11719958
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11711209
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10467363
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Beaches MLS  F10483825
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
# 1        N          Y  26.125672 -80.120892
# 2        N          Y  26.243932 -80.087321
# 3        N          Y  26.121158 -80.120244
# 4        N          Y  26.118354 -80.141518
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.207626 -80.093562
# 7        N          Y  26.096516 -80.106815
# 8        N          Y  26.121167 -80.106486
# 9        N          Y  26.130917 -80.104597
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Michelle Nunez
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...       David Marder
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...         Tara Hoyer
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...      Andrew Ziffer
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...   Samantha LaViola
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...         David Diaz
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...     Marni Schapson
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...         Brian Hero
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...    Jolanta Johnson
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Tika Van Den Hurk
#
#              list_broker_name_1   list_agent_name_2        list_broker_name_2  \
# 0  Fortune International Realty        Megan Probst      Compass Florida, LLC
# 1          Compass Florida, LLC       Maria Scarola  Related ISG Realty, LLC.
# 2       Sabbia Beach Realty Inc                None                      None
# 3          Compass Florida, LLC  Michelle Akerstrom      Compass Florida, LLC
# 4    DeBianchi Real Estate, LLC                None                      None
# 5          Compass Florida, LLC        Peter Barkin      Compass Florida, LLC
# 6                    LPT Realty                None                      None
# 7    One Sotheby's Int'l Realty                None                      None
# 8          Compass Florida, LLC       Marzena Annis      Compass Florida, LLC
# 9               Douglas Elliman                None                      None
#
#        buy_agent_name_1        buy_broker_name_1 buy_agent_name_2  \
# 0       Sharon Srebnick   Coldwell Banker Realty             None
# 1          David Marder     Compass Florida, LLC             None
# 2            Tara Hoyer  Sabbia Beach Realty Inc             None
# 3      Lourdes Maestres     Compass Florida, LLC             None
# 4  Non-member Mls Agent           NON MEMBER MLS             None
# 5  Non-member Mls Agent           NON MEMBER MLS             None
# 6                  None                     None             None
# 7                  None                     None             None
# 8    Christopher Maxner     Compass Florida, LLC             None
# 9                  None    Engel & Völkers Miami             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4afe7edc45732b7625e6582c1e2dafba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Apr. 27th — May. 4th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4afe7edc45732b7625e6582c1e2dafba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4afe7edc45732b7625e6582c1e2dafba = L.map(
#                 &quot;map_4afe7edc45732b7625e6582c1e2dafba&quot;,
#                 {
#                     center: [26.150725623232322, -80.17627655656565],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_540f8de9a240fe4ca79190c49707879d = L.featureGroup(
#                 {}
#             ).addTo(map_4afe7edc45732b7625e6582c1e2dafba);
#
#
#             var marker_c397820995653dda9fee3f6cd54acd34 = L.marker(
#                 [26.1571129, -80.1006236],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_540f8de9a240fe4ca79190c49707879d);
#
#
#             var icon_511b85301f9b65121230d2066bcf4c9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c397820995653dda9fee3f6cd54acd34.setIcon(icon_511b85301f9b65121230d2066bcf4c9f);
#
#
#         var popup_f6e9374e65224d010ef981937d70c81b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_82acaba1309731b573b4c00642ed9c2a = $(`&lt;div id=&quot;html_82acaba1309731b573b4c00642ed9c2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2200 N Ocean Blvd Unit N302&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,862,500.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,449.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,666.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2018.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_f6e9374e65224d010ef981937d70c81b.setContent(html_82acaba1309731b573b4c00642ed9c2a);
#
#
#
#         marker_c397820995653dda9fee3f6cd54acd34.bindPopup(popup_f6e9374e65224d010ef981937d70c81b)
#         ;
#
#
#
#
#             var feature_group_7a4c279a261ed4a5d779081e71f1d94f = L.featureGroup(
#                 {}
#             ).addTo(map_4afe7edc45732b7625e6582c1e2dafba);
#
#
#             var marker_d72a34d43f619bfd0fe09e78a9fa4b21 = L.marker(
#                 [26.1256721, -80.1208917],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7a4c279a261ed4a5d779081e71f1d94f);
#
#
#             var icon_83e4101c7dd7834fa8aeb4324f9e9a29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d72a34d43f619bfd0fe09e78a9fa4b21.setIcon(icon_83e4101c7dd7834fa8aeb4324f9e9a29);
#
#
#         var popup_c568b341bf7b57c802cd62558795d198 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_7db5d2e7fdcbd964d0978332d0ac566e = $(`&lt;div id=&quot;html_7db5d2e7fdcbd964d0978332d0ac566e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;141 Isle Of Venice Dr Ph -N&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$3,850,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,230.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,131.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2024.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_c568b341bf7b57c802cd62558795d198.setContent(html_7db5d2e7fdcbd964d0978332d0ac566e);
#
#
#
#         marker_d72a34d43f619bfd0fe09e78a9fa4b21.bindPopup(popup_c568b341bf7b57c802cd62558795d198)
#         ;
#
#
#
#
#             var marker_755361dcb065d67fa7672a0888f02f51 = L.marker(
#                 [26.2439316, -80.0873209],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7a4c279a261ed4a5d779081e71f1d94f);
#
#
#             var icon_4f51863ab665eadc686810b4b1c06141 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_755361dcb065d67fa7672a0888f02f51.setIcon(icon_4f51863ab665eadc686810b4b1c06141);
#
#
#         var popup_d660298c4c301a13efca53fa4618856a = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_c0bcda5f5296c143422e7629f45

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                      ADDRESS  \
# 0  PAST SALE 2025-04-30   Condo/Co-op  2200 N Ocean Blvd Unit N302
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Fort Lauderdale                FL             33305.0  3862500.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...  MARMLS  A11744571
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...    Michelle Nunez
#
#              list_broker_name_1 list_agent_name_2    list_broker_name_2  \
# 0  Fortune International Realty      Megan Probst  Compass Florida, LLC
#
#   buy_agent_name_1       buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  \
# 0  Sharon Srebnick  Coldwell Banker Realty             None              None
#
#    RANK   COLOR
# 0     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_05052025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd Unit N302 in Fort Lauderdale'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-04-30   Condo/Co-op
# 1  PAST SALE 2025-05-01   Condo/Co-op
# 2  PAST SALE 2025-04-30   Condo/Co-op
# 3  PAST SALE 2025-04-30   Condo/Co-op
# 4  PAST SALE 2025-04-30   Condo/Co-op
# 5  PAST SALE 2025-04-28   Condo/Co-op
# 6  PAST SALE 2025-04-29   Condo/Co-op
# 7  PAST SALE 2025-05-02   Condo/Co-op
# 8  PAST SALE 2025-05-02   Condo/Co-op
# 9  PAST SALE 2025-04-30   Condo/Co-op
#
#                                       ADDRESS                   CITY  \
# 0                 2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 1                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 2                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 3                  20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 4                      333 Las Olas Way #3802        Fort Lauderdale
# 5                      333 Las Olas Way #2910        Fort Lauderdale
# 6                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 7                       2100 S Ocean Ln #2102        Fort Lauderdale
# 8                        100 S Birch Rd #2501        Fort Lauderdale
# 9  551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33305.0  3862500.0   3.0    3.5
# 1                FL             33301.0  3850000.0   4.0    4.5
# 2                FL             33062.0  3650000.0   3.0    4.0
# 3                FL             33301.0  2885000.0   3.0    3.0
# 4                FL             33301.0  2250000.0   3.0    3.5
# 5                FL             33301.0  1900000.0   3.0    3.5
# 6                FL             33062.0  1505000.0   3.0    2.5
# 7                FL             33316.0  1455000.0   2.0    2.0
# 8                FL             33316.0  1450000.0   3.0    2.5
# 9                FL             33304.0   980000.0   2.0    2.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
# 1                Casa Murano       3131.0       NaN      2024.0
# 2               Sabbia Beach       2956.0       NaN      2019.0
# 3          Aqualuna Las Olas       3134.0       NaN      2017.0
# 4       Las Olas River House       2726.0       NaN      2004.0
# 5       Las Olas River House       3239.0       NaN      2004.0
# 6   HAMPTON BEACH CLUB CONDO       2300.0       NaN      1980.0
# 7    POINT OF AMERICAS CONDO       1879.0       NaN      1969.0
# 8     Jackson Tower Las Olas       1998.0       NaN      2001.0
# 9     Ocean Resort Residence       1060.0       NaN      2009.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
# 1             NaN         1230.0     2521.0   Sold
# 2             NaN         1235.0     4939.0   Sold
# 3             NaN          921.0     2291.0   Sold
# 4             NaN          825.0     3529.0   Sold
# 5             NaN          587.0        NaN   Sold
# 6             NaN          654.0     1915.0   Sold
# 7             NaN          774.0     2171.0   Sold
# 8             NaN          726.0     2846.0   Sold
# 9             NaN          925.0        7.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11744571
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10484254
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...  Beaches MLS  F10479015
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10495970
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10461930
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10473160
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...       MARMLS  A11719958
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11711209
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10467363
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Beaches MLS  F10483825
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
# 1        N          Y  26.125672 -80.120892
# 2        N          Y  26.243932 -80.087321
# 3        N          Y  26.121158 -80.120244
# 4        N          Y  26.118354 -80.141518
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.207626 -80.093562
# 7        N          Y  26.096516 -80.106815
# 8        N          Y  26.121167 -80.106486
# 9        N          Y  26.130917 -80.104597
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Michelle Nunez
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...       David Marder
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...         Tara Hoyer
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...      Andrew Ziffer
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...   Samantha LaViola
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...         David Diaz
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...     Marni Schapson
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...         Brian Hero
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...    Jolanta Johnson
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Tika Van Den Hurk
#
#              list_broker_name_1   list_agent_name_2        list_broker_name_2  \
# 0  Fortune International Realty        Megan Probst      Compass Florida, LLC
# 1          Compass Florida, LLC       Maria Scarola  Related ISG Realty, LLC.
# 2       Sabbia Beach Realty Inc                None                      None
# 3          Compass Florida, LLC  Michelle Akerstrom      Compass Florida, LLC
# 4    DeBianchi Real Estate, LLC                None                      None
# 5          Compass Florida, LLC        Peter Barkin      Compass Florida, LLC
# 6                    LPT Realty                None                      None
# 7    One Sotheby's Int'l Realty                None                      None
# 8          Compass Florida, LLC       Marzena Annis      Compass Florida, LLC
# 9               Douglas Elliman                None                      None
#
#        buy_agent_name_1        buy_broker_name_1 buy_agent_name_2  \
# 0       Sharon Srebnick   Coldwell Banker Realty             None
# 1          David Marder     Compass Florida, LLC             None
# 2            Tara Hoyer  Sabbia Beach Realty Inc             None
# 3      Lourdes Maestres     Compass Florida, LLC             None
# 4  Non-member Mls Agent           NON MEMBER MLS             None
# 5  Non-member Mls Agent           NON MEMBER MLS             None
# 6                  None                     None             None
# 7                  None                     None             None
# 8    Christopher Maxner     Compass Florida, LLC             None
# 9                  None    Engel & Völkers Miami             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd...
# 1  Casa Murano at 141 Isle Of Venice Dr Ph -N in ...
# 2  Sabbia Beach at 730 N Ocean Blvd Unit LPH B in...
# 3  Aqualuna Las Olas at 20 Isle Of Venice Dr Ph -...
# 4  Las Olas River House at 333 Las Olas Way #3802...
# 5  Las Olas River House at 333 Las Olas Way #2910...
# 6  HAMPTON BEACH CLUB CONDO at 1800 S Ocean Blvd ...
# 7  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #21...
# 8  Jackson Tower Las Olas at 100 S Birch Rd #2501...
# 9  Ocean Resort Residence at 551 N Fort Lauderdal...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: 2200 FORT LAUDERDALE BEAC closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $980,000 to $3,862,500
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Pompano Beach, Lauderdale By The Sea, Fort Lauderdale, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 188 condo sales totaling $73,659,705 million from Apr. 27th to May. 4th. The previous week, brokers closed 137 condo sales totaling $46,064,280.
#
# Last week’s units sold for an average of $391,807, higher than the $336,236 average price from the previous week. The average price per square foot rose to $300 from $272, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $980,000.0 million to $3,862,500.0 million.
#
# 2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd Unit N302 in Fort Lauderdale took the top spot with a $3,862,500.0 million closing. The sale closed at $1,449.0 per square foot.
#
# Michelle Nunez with Fortune International Realty, and Megan Probst with Compass Florida, LLC had the listing.
# Sharon Srebnick with Coldwell Banker Realty, and None with None represented the buyer.
#
# Casa Murano at 141 Isle Of Venice Dr Ph -N in Fort Lauderdale, closed for the second highest amount, $3,850,000.0, or $1,230.0 per square foot.
#
# David Marder with Compass Florida, LLC, and Maria Scarola with Related ISG Realty, LLC. had the listing.
# David Marder with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_05052025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 27th to May. 4th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-04-30   Condo/Co-op
# 1  PAST SALE 2025-05-01   Condo/Co-op
# 2  PAST SALE 2025-04-30   Condo/Co-op
# 3  PAST SALE 2025-04-30   Condo/Co-op
# 4  PAST SALE 2025-04-30   Condo/Co-op
# 5  PAST SALE 2025-04-28   Condo/Co-op
# 6  PAST SALE 2025-04-29   Condo/Co-op
# 7  PAST SALE 2025-05-02   Condo/Co-op
# 8  PAST SALE 2025-05-02   Condo/Co-op
# 9  PAST SALE 2025-04-30   Condo/Co-op
#
#                                       ADDRESS                   CITY  \
# 0                 2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 1                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 2                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 3                  20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 4                      333 Las Olas Way #3802        Fort Lauderdale
# 5                      333 Las Olas Way #2910        Fort Lauderdale
# 6                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 7                       2100 S Ocean Ln #2102        Fort Lauderdale
# 8                        100 S Birch Rd #2501        Fort Lauderdale
# 9  551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33305.0  3862500.0   3.0    3.5
# 1                FL             33301.0  3850000.0   4.0    4.5
# 2                FL             33062.0  3650000.0   3.0    4.0
# 3                FL             33301.0  2885000.0   3.0    3.0
# 4                FL             33301.0  2250000.0   3.0    3.5
# 5                FL             33301.0  1900000.0   3.0    3.5
# 6                FL             33062.0  1505000.0   3.0    2.5
# 7                FL             33316.0  1455000.0   2.0    2.0
# 8                FL             33316.0  1450000.0   3.0    2.5
# 9                FL             33304.0   980000.0   2.0    2.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
# 1                Casa Murano       3131.0       NaN      2024.0
# 2               Sabbia Beach       2956.0       NaN      2019.0
# 3          Aqualuna Las Olas       3134.0       NaN      2017.0
# 4       Las Olas River House       2726.0       NaN      2004.0
# 5       Las Olas River House       3239.0       NaN      2004.0
# 6   HAMPTON BEACH CLUB CONDO       2300.0       NaN      1980.0
# 7    POINT OF AMERICAS CONDO       1879.0       NaN      1969.0
# 8     Jackson Tower Las Olas       1998.0       NaN      2001.0
# 9     Ocean Resort Residence       1060.0       NaN      2009.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
# 1             NaN         1230.0     2521.0   Sold
# 2             NaN         1235.0     4939.0   Sold
# 3             NaN          921.0     2291.0   Sold
# 4             NaN          825.0     3529.0   Sold
# 5             NaN          587.0        NaN   Sold
# 6             NaN          654.0     1915.0   Sold
# 7             NaN          774.0     2171.0   Sold
# 8             NaN          726.0     2846.0   Sold
# 9             NaN          925.0        7.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11744571
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10484254
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...  Beaches MLS  F10479015
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10495970
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10461930
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10473160
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...       MARMLS  A11719958
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11711209
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10467363
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Beaches MLS  F10483825
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
# 1        N          Y  26.125672 -80.120892
# 2        N          Y  26.243932 -80.087321
# 3        N          Y  26.121158 -80.120244
# 4        N          Y  26.118354 -80.141518
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.207626 -80.093562
# 7        N          Y  26.096516 -80.106815
# 8        N          Y  26.121167 -80.106486
# 9        N          Y  26.130917 -80.104597
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Michelle Nunez
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...       David Marder
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...         Tara Hoyer
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...      Andrew Ziffer
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...   Samantha LaViola
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...         David Diaz
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...     Marni Schapson
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...         Brian Hero
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...    Jolanta Johnson
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Tika Van Den Hurk
#
#              list_broker_name_1   list_agent_name_2        list_broker_name_2  \
# 0  Fortune International Realty        Megan Probst      Compass Florida, LLC
# 1          Compass Florida, LLC       Maria Scarola  Related ISG Realty, LLC.
# 2       Sabbia Beach Realty Inc                None                      None
# 3          Compass Florida, LLC  Michelle Akerstrom      Compass Florida, LLC
# 4    DeBianchi Real Estate, LLC                None                      None
# 5          Compass Florida, LLC        Peter Barkin      Compass Florida, LLC
# 6                    LPT Realty                None                      None
# 7    One Sotheby's Int'l Realty                None                      None
# 8          Compass Florida, LLC       Marzena Annis      Compass Florida, LLC
# 9               Douglas Elliman                None                      None
#
#        buy_agent_name_1        buy_broker_name_1 buy_agent_name_2  \
# 0       Sharon Srebnick   Coldwell Banker Realty             None
# 1          David Marder     Compass Florida, LLC             None
# 2            Tara Hoyer  Sabbia Beach Realty Inc             None
# 3      Lourdes Maestres     Compass Florida, LLC             None
# 4  Non-member Mls Agent           NON MEMBER MLS             None
# 5  Non-member Mls Agent           NON MEMBER MLS             None
# 6                  None                     None             None
# 7                  None                     None             None
# 8    Christopher Maxner     Compass Florida, LLC             None
# 9                  None    Engel & Völkers Miami             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd...
# 1  Casa Murano at 141 Isle Of Venice Dr Ph -N in ...
# 2  Sabbia Beach at 730 N Ocean Blvd Unit LPH B in...
# 3  Aqualuna Las Olas at 20 Isle Of Venice Dr Ph -...
# 4  Las Olas River House at 333 Las Olas Way #3802...
# 5  Las Olas River House at 333 Las Olas Way #2910...
# 6  HAMPTON BEACH CLUB CONDO at 1800 S Ocean Blvd ...
# 7  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #21...
# 8  Jackson Tower Las Olas at 100 S Birch Rd #2501...
# 9  Ocean Resort Residence at 551 N Fort Lauderdal...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: 2200 FORT LAUDERDALE BEAC closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $980,000 to $3,862,500
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Pompano Beach, Lauderdale By The Sea, Fort Lauderdale, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 188 condo sales totaling $73,659,705 million from Apr. 27th to May. 4th. The previous week, brokers closed 137 condo sales totaling $46,064,280.
#
# Last week’s units sold for an average of $391,807, higher than the $336,236 average price from the previous week. The average price per square foot rose to $300 from $272, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $980,000.0 million to $3,862,500.0 million.
#
# 2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd Unit N302 in Fort Lauderdale took the top spot with a $3,862,500.0 million closing. The sale closed at $1,449.0 per square foot.
#
# Michelle Nunez with Fortune International Realty, and Megan Probst with Compass Florida, LLC had the listing.
# Sharon Srebnick with Coldwell Banker Realty, and None with None represented the buyer.
#
# Casa Murano at 141 Isle Of Venice Dr Ph -N in Fort Lauderdale, closed for the second highest amount, $3,850,000.0, or $1,230.0 per square foot.
#
# David Marder with Compass Florida, LLC, and Maria Scarola with Related ISG Realty, LLC. had the listing.
# David Marder with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_05052025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Apr. 27th to May. 4th:
#
# Most Expensive
# 2200 FORT LAUDERDALE BEAC, 2200 N Ocean Blvd Unit N302, in Fort Lauderdale | Price: $3,862,500 | $1,449 psf | Listing agents: Michelle Nunez with Fortune International Realty and Megan Probst with Compass Florida, LLC | Buyer's agents: Sharon Srebnick with Coldwell Banker Realty and None with None
#
# Least Expensive
# Ocean Resort Residence, 551 N Fort Lauderdale Beach Blvd Unit R304, in Fort Lauderdale | Price: $980,000 | $925 psf | Listing agents: Tika Van Den Hurk with Douglas Elliman and None with None | Buyer's agents: None with Engel & Völkers Miami and None with None
#
# Highest Price Per Square Foot
# 2200 FORT LAUDERDALE BEAC, 2200 N Ocean Blvd Unit N302, in Fort Lauderdale | Price: $3,862,500 | $1,449 psf | Listing agents: Michelle Nunez with Fortune International Realty and Megan Probst with Compass Florida, LLC | Buyer's agents: Sharon Srebnick with Coldwell Banker Realty and None with None
#
# Lowest Price Per Square Foot
# Las Olas River House, 333 Las Olas Way #2910, in Fort Lauderdale | Price: $1,900,000 | $587 psf | Listing agents: David Diaz with Compass Florida, LLC and Peter Barkin with Compass Florida, LLC | Buyer's agents: Non-member Mls Agent with NON MEMBER MLS and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N302/home/148713373
# Second priciest sale:  https://www.redfin.com/FL/Fort-Lauderdale/141-Isle-of-Venice-Dr-33301/home/194279304
# Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/551-N-Beach-Blvd-33304/unit-R304/home/82729152
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/100-S-Birch-Rd-33316/unit-2501/home/106119160
# Highest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N302/home/148713373
# Lowest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/333-Las-Olas-Way-33301/unit-2910/home/42027561

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N302/home/148713373

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/141-Isle-of-Venice-Dr-33301/home/194279304

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/551-N-Beach-Blvd-33304/unit-R304/home/82729152

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/100-S-Birch-Rd-33316/unit-2501/home/106119160

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2200-N-Ocean-Blvd-33305/unit-N302/home/148713373

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/333-Las-Olas-Way-33301/unit-2910/home/42027561

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-04-30   Condo/Co-op
# 1  PAST SALE 2025-05-01   Condo/Co-op
# 2  PAST SALE 2025-04-30   Condo/Co-op
# 3  PAST SALE 2025-04-30   Condo/Co-op
# 4  PAST SALE 2025-04-30   Condo/Co-op
# 5  PAST SALE 2025-04-28   Condo/Co-op
# 6  PAST SALE 2025-04-29   Condo/Co-op
# 7  PAST SALE 2025-05-02   Condo/Co-op
# 8  PAST SALE 2025-05-02   Condo/Co-op
# 9  PAST SALE 2025-04-30   Condo/Co-op
#
#                                       ADDRESS                   CITY  \
# 0                 2200 N Ocean Blvd Unit N302        Fort Lauderdale
# 1                 141 Isle Of Venice Dr Ph -N        Fort Lauderdale
# 2                 730 N Ocean Blvd Unit LPH B          Pompano Beach
# 3                  20 Isle Of Venice Dr Ph -1        Fort Lauderdale
# 4                      333 Las Olas Way #3802        Fort Lauderdale
# 5                      333 Las Olas Way #2910        Fort Lauderdale
# 6                     1800 S Ocean Blvd #1405  Lauderdale By The Sea
# 7                       2100 S Ocean Ln #2102        Fort Lauderdale
# 8                        100 S Birch Rd #2501        Fort Lauderdale
# 9  551 N Fort Lauderdale Beach Blvd Unit R304        Fort Lauderdale
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33305.0  3862500.0   3.0    3.5
# 1                FL             33301.0  3850000.0   4.0    4.5
# 2                FL             33062.0  3650000.0   3.0    4.0
# 3                FL             33301.0  2885000.0   3.0    3.0
# 4                FL             33301.0  2250000.0   3.0    3.5
# 5                FL             33301.0  1900000.0   3.0    3.5
# 6                FL             33062.0  1505000.0   3.0    2.5
# 7                FL             33316.0  1455000.0   2.0    2.0
# 8                FL             33316.0  1450000.0   3.0    2.5
# 9                FL             33304.0   980000.0   2.0    2.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  2200 FORT LAUDERDALE BEAC       2666.0       NaN      2018.0
# 1                Casa Murano       3131.0       NaN      2024.0
# 2               Sabbia Beach       2956.0       NaN      2019.0
# 3          Aqualuna Las Olas       3134.0       NaN      2017.0
# 4       Las Olas River House       2726.0       NaN      2004.0
# 5       Las Olas River House       3239.0       NaN      2004.0
# 6   HAMPTON BEACH CLUB CONDO       2300.0       NaN      1980.0
# 7    POINT OF AMERICAS CONDO       1879.0       NaN      1969.0
# 8     Jackson Tower Las Olas       1998.0       NaN      2001.0
# 9     Ocean Resort Residence       1060.0       NaN      2009.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1449.0     5762.0   Sold
# 1             NaN         1230.0     2521.0   Sold
# 2             NaN         1235.0     4939.0   Sold
# 3             NaN          921.0     2291.0   Sold
# 4             NaN          825.0     3529.0   Sold
# 5             NaN          587.0        NaN   Sold
# 6             NaN          654.0     1915.0   Sold
# 7             NaN          774.0     2171.0   Sold
# 8             NaN          726.0     2846.0   Sold
# 9             NaN          925.0        7.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...       MARMLS  A11744571
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...  Beaches MLS  F10484254
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...  Beaches MLS  F10479015
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...  Beaches MLS  F10495970
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10461930
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...  Beaches MLS  F10473160
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...       MARMLS  A11719958
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...       MARMLS  A11711209
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...  Beaches MLS  F10467363
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Beaches MLS  F10483825
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.157113 -80.100624
# 1        N          Y  26.125672 -80.120892
# 2        N          Y  26.243932 -80.087321
# 3        N          Y  26.121158 -80.120244
# 4        N          Y  26.118354 -80.141518
# 5        N          Y  26.118354 -80.141518
# 6        N          Y  26.207626 -80.093562
# 7        N          Y  26.096516 -80.106815
# 8        N          Y  26.121167 -80.106486
# 9        N          Y  26.130917 -80.104597
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/2200...     Michelle Nunez
# 1  https://www.redfin.com/FL/Fort-Lauderdale/141-...       David Marder
# 2  https://www.redfin.com/FL/Pompano-Beach/730-N-...         Tara Hoyer
# 3  https://www.redfin.com/FL/Fort-Lauderdale/20-I...      Andrew Ziffer
# 4  https://www.redfin.com/FL/Fort-Lauderdale/333-...   Samantha LaViola
# 5  https://www.redfin.com/FL/Fort-Lauderdale/333-...         David Diaz
# 6  https://www.redfin.com/FL/Pompano-Beach/1800-S...     Marni Schapson
# 7  https://www.redfin.com/FL/Fort-Lauderdale/2100...         Brian Hero
# 8  https://www.redfin.com/FL/Fort-Lauderdale/100-...    Jolanta Johnson
# 9  https://www.redfin.com/FL/Fort-Lauderdale/551-...  Tika Van Den Hurk
#
#              list_broker_name_1   list_agent_name_2        list_broker_name_2  \
# 0  Fortune International Realty        Megan Probst      Compass Florida, LLC
# 1          Compass Florida, LLC       Maria Scarola  Related ISG Realty, LLC.
# 2       Sabbia Beach Realty Inc                None                      None
# 3          Compass Florida, LLC  Michelle Akerstrom      Compass Florida, LLC
# 4    DeBianchi Real Estate, LLC                None                      None
# 5          Compass Florida, LLC        Peter Barkin      Compass Florida, LLC
# 6                    LPT Realty                None                      None
# 7    One Sotheby's Int'l Realty                None                      None
# 8          Compass Florida, LLC       Marzena Annis      Compass Florida, LLC
# 9               Douglas Elliman                None                      None
#
#        buy_agent_name_1        buy_broker_name_1 buy_agent_name_2  \
# 0       Sharon Srebnick   Coldwell Banker Realty             None
# 1          David Marder     Compass Florida, LLC             None
# 2            Tara Hoyer  Sabbia Beach Realty Inc             None
# 3      Lourdes Maestres     Compass Florida, LLC             None
# 4  Non-member Mls Agent           NON MEMBER MLS             None
# 5  Non-member Mls Agent           NON MEMBER MLS             None
# 6                  None                     None             None
# 7                  None                     None             None
# 8    Christopher Maxner     Compass Florida, LLC             None
# 9                  None    Engel & Völkers Miami             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  2200 FORT LAUDERDALE BEAC at 2200 N Ocean Blvd...
# 1  Casa Murano at 141 Isle Of Venice Dr Ph -N in ...
# 2  Sabbia Beach at 730 N Ocean Blvd Unit LPH B in...
# 3  Aqualuna Las Olas at 20 Isle Of Venice Dr Ph -...
# 4  Las Olas River House at 333 Las Olas Way #3802...
# 5  Las Olas River House at 333 Las Olas Way #2910...
# 6  HAMPTON BEACH CLUB CONDO at 1800 S Ocean Blvd ...
# 7  POINT OF AMERICAS CONDO at 2100 S Ocean Ln #21...
# 8  Jackson Tower Las Olas at 100 S Birch Rd #2501...
# 9  Ocean Resort Residence at 551 N Fort Lauderdal...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 2, 3) ## List (Earlier) date
date2 = datetime(2025, 5, 1) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 87

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1449.0
# 1    1230.0
# 2    1235.0
# 3     921.0
# 4     825.0
# 5     587.0
# 6     654.0
# 7     774.0
# 8     726.0
# 9     925.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2025-04-30     2200 N Ocean Blvd Unit N302 in Fort Lauderdale  $3,862,500
# 1 2025-05-01     141 Isle Of Venice Dr Ph -N in Fort Lauderdale  $3,850,000
# 2 2025-04-30       730 N Ocean Blvd Unit LPH B in Pompano Beach  $3,650,000
# 3 2025-04-30      20 Isle Of Venice Dr Ph -1 in Fort Lauderdale  $2,885,000
# 4 2025-04-30          333 Las Olas Way #3802 in Fort Lauderdale  $2,250,000
# 5 2025-04-28          333 Las Olas Way #2910 in Fort Lauderdale  $1,900,000
# 6 2025-04-29   1800 S Ocean Blvd #1405 in Lauderdale By The Sea  $1,505,000
# 7 2025-05-02           2100 S Ocean Ln #2102 in Fort Lauderdale  $1,455,000
# 8 2025-05-02            100 S Birch Rd #2501 in Fort Lauderdale  $1,450,000
# 9 2025-04-30  551 N Fort Lauderdale Beach Blvd Unit R304 in ...    $980,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    3    3.5       2,666       2018        $1,449       MARMLS  A11744571
# 1    4    4.5       3,131       2024        $1,230  Beaches MLS  F10484254
# 2    3    4.0       2,956       2019        $1,235  Beaches MLS  F10479015
# 3    3    3.0       3,134       2017          $921  Beaches MLS  F10495970
# 4    3    3.5       2,726       2004          $825  Beaches MLS  F10461930
# 5    3    3.5       3,239       2004          $587  Beaches MLS  F10473160
# 6    3    2.5       2,300       1980          $654       MARMLS  A11719958
# 7    2    2.0       1,879       1969          $774       MARMLS  A11711209
# 8    3    2.5       1,998       2001          $726  Beaches MLS  F10467363
# 9    2    2.5       1,060       2009          $925  Beaches MLS  F10483825
#
#                                         LISTING INFO  \
# 0  Michelle Nunez Fortune International Realty Me...
# 1  David Marder Compass Florida, LLC Maria Scarol...
# 2             Tara Hoyer Sabbia Beach Realty Inc
# 3  Andrew Ziffer Compass Florida, LLC Michelle Ak...
# 4    Samantha LaViola DeBianchi Real Estate, LLC
# 5  David Diaz Compass Florida, LLC Peter Barkin C...
# 6                      Marni Schapson LPT Realty
# 7          Brian Hero One Sotheby's Int'l Realty
# 8  Jolanta Johnson Compass Florida, LLC Marzena A...
# 9              Tika Van Den Hurk Douglas Elliman
#
#                                    BUYING INFO
# 0   Sharon Srebnick Coldwell Banker Realty
# 1        David Marder Compass Florida, LLC
# 2       Tara Hoyer Sabbia Beach Realty Inc
# 3    Lourdes Maestres Compass Florida, LLC
# 4      Non-member Mls Agent NON MEMBER MLS
# 5      Non-member Mls Agent NON MEMBER MLS
# 6
# 7
# 8  Christopher Maxner Compass Florida, LLC
# 9                    Engel & Völkers Miami
