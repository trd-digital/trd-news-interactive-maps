# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 11th May. 18th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                ADDRESS        CITY  \
# 1  PAST SALE  May-16-2025   Condo/Co-op  6161 NW 2nd Ave #5220  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33487.0  195000.0   2.0    2.0  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Boca-Raton/6161-NW-2...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11068735         N          Y  26.404699 -80.083122
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Palm Beach

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-05-15    48
# 2025-05-16    27
# 2025-05-12    21
# 2025-05-14    18
# 2025-05-13    12
# 2025-05-17     1
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 5   PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 17  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 7   PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 22  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 18  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 20  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 24  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 8   PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 11  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 15  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#    STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 5                 FL             33432.0  6170000.0   4.0    4.5  ...   Sold
# 17                FL             33432.0  4330000.0   3.0    4.0  ...   Sold
# 7                 FL             33432.0  4150000.0   2.0    3.5  ...   Sold
# 22                FL             33432.0  4009000.0   2.0    3.0  ...   Sold
# 18                FL             33432.0  3349000.0   3.0    3.5  ...   Sold
# 20                FL             33432.0  3082860.0   2.0    3.0  ...   Sold
# 24                FL             33432.0  3071000.0   2.0    3.0  ...   Sold
# 8                 FL             33432.0  2988000.0   3.0    3.5  ...   Sold
# 11                FL             33432.0  2774000.0   2.0    3.0  ...   Sold
# 15                FL             33432.0  2664000.0   2.0    3.0  ...   Sold
#
#     NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 5                          NaN                       NaN
# 17                         NaN                       NaN
# 7                          NaN                       NaN
# 22                         NaN                       NaN
# 18                         NaN                       NaN
# 20                         NaN                       NaN
# 24                         NaN                       NaN
# 8                          NaN                       NaN
# 11                         NaN                       NaN
# 15                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 5   https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
# 17  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 7   https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 22  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 18  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 20  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 24  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 8   https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 11  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 15  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 5   RX-11077147         N          Y  26.347136 -80.083209
# 17  RX-11090587         N          Y  26.347042 -80.083200
# 7   RX-11090966         N          Y  26.347042 -80.083200
# 22  RX-11090968         N          Y  26.347042 -80.083200
# 18  RX-11090678         N          Y  26.347042 -80.083200
# 20  RX-11090681         N          Y  26.347042 -80.083200
# 24  RX-11091034         N          Y  26.347042 -80.083200
# 8   RX-11091043         N          Y  26.347042 -80.083200
# 11  RX-11091038         N          Y  26.347042 -80.083200
# 15  RX-11089856         N          Y  26.347042 -80.083200
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 1  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 2  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 3  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 4  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 5  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 6  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 7  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 8  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 9  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ...  \
# 0                FL             33432.0  6170000.0   4.0    4.5  ...
# 1                FL             33432.0  4330000.0   3.0    4.0  ...
# 2                FL             33432.0  4150000.0   2.0    3.5  ...
# 3                FL             33432.0  4009000.0   2.0    3.0  ...
# 4                FL             33432.0  3349000.0   3.0    3.5  ...
# 5                FL             33432.0  3082860.0   2.0    3.0  ...
# 6                FL             33432.0  3071000.0   2.0    3.0  ...
# 7                FL             33432.0  2988000.0   3.0    3.5  ...
# 8                FL             33432.0  2774000.0   2.0    3.0  ...
# 9                FL             33432.0  2664000.0   2.0    3.0  ...
#
#    LONGITUDE                                                url  \
# 0 -80.083209  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...
# 1 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 2 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...
# 3 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...
# 4 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...
# 5 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...
# 6 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 7 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 8 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 9 -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
#
#      list_agent_name_1  list_broker_name_1   list_agent_name_2  \
# 0  Rochelle LeCavalier     Douglas Elliman  Kathy Koch Pitlake
# 1  Rochelle LeCavalier     Douglas Elliman   Alejandro Salazar
# 2  Rochelle LeCavalier     Douglas Elliman  Kathy Koch Pitlake
# 3  Rochelle LeCavalier     Douglas Elliman  Kathy Koch Pitlake
# 4  Rochelle LeCavalier     Douglas Elliman   Alejandro Salazar
# 5  Rochelle LeCavalier     Douglas Elliman   Alejandro Salazar
# 6  Rochelle LeCavalier     Douglas Elliman   Alejandro Salazar
# 7  Rochelle LeCavalier     Douglas Elliman                None
# 8  Rochelle LeCavalier     Douglas Elliman  Kathy Koch Pitlake
# 9  Rochelle LeCavalier     Douglas Elliman  Kathy Koch Pitlake
#
#    list_broker_name_2   buy_agent_name_1                   buy_broker_name_1  \
# 0     Douglas Elliman       Lauren Pines                      Lang Realty/BR
# 1     Douglas Elliman    Charles Luciano                 Compass Florida LLC
# 2     Douglas Elliman  Alejandro Salazar                     Douglas Elliman
# 3     Douglas Elliman    Rebecca Spooner          Siemens Group Realty Corp.
# 4     Douglas Elliman     Cynthia Nossel  Keller Williams Miami Beach Realty
# 5     Douglas Elliman       Blake Morris                     Lang Realty/ BR
# 6     Douglas Elliman        Scott Gerow                 Compass Florida LLC
# 7                None   Marisela Cotilla      Pineapple Realty Advisores LLC
# 8     Douglas Elliman     Simon Reynolds           Nest Seekers Florida, LLC
# 9     Douglas Elliman     Edward Pitlake                     Douglas Elliman
#
#        buy_agent_name_2    buy_broker_name_2
# 0                  None                 None
# 1                  None                 None
# 2                  None                 None
# 3                  None                 None
# 4                  None                 None
# 5                  None                 None
# 6  Rachelle Hirt-Beresh  Compass Florida LLC
# 7                  None                 None
# 8                  None                 None
# 9                  None                 None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 127

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $810,516

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $416

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $102,935,560

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          127              810516          416                    102935560.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 97
# -----------
# Input Previous Week Condo Average Sales Price:
# 717106
# -----------
# Input Previous Week Condo Average PSF:
# 391
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 69559250.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman     Lauren Pines
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0    Lang Realty/BR             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 1  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 2  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 3  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 4  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 5  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 6  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 7  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 8  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 9  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
# 1                FL             33432.0  4330000.0   3.0    4.0
# 2                FL             33432.0  4150000.0   2.0    3.5
# 3                FL             33432.0  4009000.0   2.0    3.0
# 4                FL             33432.0  3349000.0   3.0    3.5
# 5                FL             33432.0  3082860.0   2.0    3.0
# 6                FL             33432.0  3071000.0   2.0    3.0
# 7                FL             33432.0  2988000.0   3.0    3.5
# 8                FL             33432.0  2774000.0   2.0    3.0
# 9                FL             33432.0  2664000.0   2.0    3.0
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
# 1        Alina Residences       3800.0     180.0      2024.0             NaN
# 2        Alina Residences       3791.0     180.0      2024.0             NaN
# 3        Alina Residences       3483.0     180.0      2024.0             NaN
# 4        Alina Residences       3304.0     180.0      2024.0             NaN
# 5        Alina Residences       2701.0     180.0      2024.0             NaN
# 6        Alina Residences       2728.0     180.0      2024.0             NaN
# 7        Alina Residences       3304.0     180.0      2024.0             NaN
# 8        Alina Residences       2725.0     180.0      2024.0             NaN
# 9        Alina Residences       2717.0     180.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
# 1         1139.0     3241.0   Sold                         NaN
# 2         1095.0     3216.0   Sold                         NaN
# 3         1151.0     2974.0   Sold                         NaN
# 4         1014.0        NaN   Sold                         NaN
# 5         1141.0     2284.0   Sold                         NaN
# 6         1126.0     2317.0   Sold                         NaN
# 7          904.0     2826.0   Sold                         NaN
# 8         1018.0     2307.0   Sold                         NaN
# 9          980.0     2341.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
# 1  RX-11090587        N          Y  26.347042 -80.083200
# 2  RX-11090966        N          Y  26.347042 -80.083200
# 3  RX-11090968        N          Y  26.347042 -80.083200
# 4  RX-11090678        N          Y  26.347042 -80.083200
# 5  RX-11090681        N          Y  26.347042 -80.083200
# 6  RX-11091034        N          Y  26.347042 -80.083200
# 7  RX-11091043        N          Y  26.347042 -80.083200
# 8  RX-11091038        N          Y  26.347042 -80.083200
# 9  RX-11089856        N          Y  26.347042 -80.083200
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 1    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 2    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 3    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 4    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 5    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 6    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 7    Douglas Elliman                None               None
# 8    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 9    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
#
#     buy_agent_name_1                   buy_broker_name_1  \
# 0       Lauren Pines                      Lang Realty/BR
# 1    Charles Luciano                 Compass Florida LLC
# 2  Alejandro Salazar                     Douglas Elliman
# 3    Rebecca Spooner          Siemens Group Realty Corp.
# 4     Cynthia Nossel  Keller Williams Miami Beach Realty
# 5       Blake Morris                     Lang Realty/ BR
# 6        Scott Gerow                 Compass Florida LLC
# 7   Marisela Cotilla      Pineapple Realty Advisores LLC
# 8     Simon Reynolds           Nest Seekers Florida, LLC
# 9     Edward Pitlake                     Douglas Elliman
#
#        buy_agent_name_2    buy_broker_name_2  RANK   COLOR
# 0                  None                 None     1  orange
# 1                  None                 None     2    blue
# 2                  None                 None     3    blue
# 3                  None                 None     4    blue
# 4                  None                 None     5    blue
# 5                  None                 None     6    blue
# 6  Rachelle Hirt-Beresh  Compass Florida LLC     7    blue
# 7                  None                 None     8    blue
# 8                  None                 None     9    blue
# 9                  None                 None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fe5aa218ae88739861f4f6e894b5b72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 11th — May. 18th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fe5aa218ae88739861f4f6e894b5b72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1fe5aa218ae88739861f4f6e894b5b72 = L.map(
#                 &quot;map_1fe5aa218ae88739861f4f6e894b5b72&quot;,
#                 {
#                     center: [26.539123729496403, -80.10229571582734],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_e4372532f7f6de54da4033151e62b55e = L.featureGroup(
#                 {}
#             ).addTo(map_1fe5aa218ae88739861f4f6e894b5b72);
#
#
#             var marker_cf8e31acb523e56702a8366ad17cd8e8 = L.marker(
#                 [26.3471364, -80.0832086],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_e4372532f7f6de54da4033151e62b55e);
#
#
#             var icon_5113def6fc7eee0729059e9a85730253 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf8e31acb523e56702a8366ad17cd8e8.setIcon(icon_5113def6fc7eee0729059e9a85730253);
#
#
#         var popup_1e3fd154207f0634a82282db58776395 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a41d26ab94db331f82c19a5edc8cd3db = $(`&lt;div id=&quot;html_a41d26ab94db331f82c19a5edc8cd3db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;210 SE Mizner Blvd #302&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,170,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,500.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,113.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2024.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_1e3fd154207f0634a82282db58776395.setContent(html_a41d26ab94db331f82c19a5edc8cd3db);
#
#
#
#         marker_cf8e31acb523e56702a8366ad17cd8e8.bindPopup(popup_1e3fd154207f0634a82282db58776395)
#         ;
#
#
#
#
#             var feature_group_7e33ebfaaab27bf3bf2cfbedb62524ba = L.featureGroup(
#                 {}
#             ).addTo(map_1fe5aa218ae88739861f4f6e894b5b72);
#
#
#             var marker_cae3da4e4d79fe44b71aea135d4ad307 = L.marker(
#                 [26.3470419, -80.0832],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e33ebfaaab27bf3bf2cfbedb62524ba);
#
#
#             var icon_27c4c71685edf9849572abfd3fc42596 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cae3da4e4d79fe44b71aea135d4ad307.setIcon(icon_27c4c71685edf9849572abfd3fc42596);
#
#
#         var popup_8b1f41531f42f0985f0a9c15a52cc607 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2f5adbe2c4a51b6f10e6fd02ce17ca41 = $(`&lt;div id=&quot;html_2f5adbe2c4a51b6f10e6fd02ce17ca41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;220 SE Mizner Blvd #307&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,330,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,139.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,800.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2024.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_8b1f41531f42f0985f0a9c15a52cc607.setContent(html_2f5adbe2c4a51b6f10e6fd02ce17ca41);
#
#
#
#         marker_cae3da4e4d79fe44b71aea135d4ad307.bindPopup(popup_8b1f41531f42f0985f0a9c15a52cc607)
#         ;
#
#
#
#
#             var marker_5412fce29cffc73a203be5ee314b90cb = L.marker(
#                 [26.3470419, -80.0832],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_7e33ebfaaab27bf3bf2cfbedb62524ba);
#
#
#             var icon_b97073755c544405c6b055a4b82c9479 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5412fce29cffc73a203be5ee314b90cb.setIcon(icon_b97073755c544405c6b055a4b82c9479);
#
#
#         var popup_9a7b1c945fa96a353c9d79678dae7c81 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_45426c44f11ecb6c2acedaa7dc711c26 = $(

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman     Lauren Pines
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0    Lang Realty/BR             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05192025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Alina Boca Raton Condo at 210 SE Mizner Blvd #302 in Boca Raton'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 1  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 2  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 3  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 4  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 5  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 6  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 7  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 8  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 9  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
# 1                FL             33432.0  4330000.0   3.0    4.0
# 2                FL             33432.0  4150000.0   2.0    3.5
# 3                FL             33432.0  4009000.0   2.0    3.0
# 4                FL             33432.0  3349000.0   3.0    3.5
# 5                FL             33432.0  3082860.0   2.0    3.0
# 6                FL             33432.0  3071000.0   2.0    3.0
# 7                FL             33432.0  2988000.0   3.0    3.5
# 8                FL             33432.0  2774000.0   2.0    3.0
# 9                FL             33432.0  2664000.0   2.0    3.0
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
# 1        Alina Residences       3800.0     180.0      2024.0             NaN
# 2        Alina Residences       3791.0     180.0      2024.0             NaN
# 3        Alina Residences       3483.0     180.0      2024.0             NaN
# 4        Alina Residences       3304.0     180.0      2024.0             NaN
# 5        Alina Residences       2701.0     180.0      2024.0             NaN
# 6        Alina Residences       2728.0     180.0      2024.0             NaN
# 7        Alina Residences       3304.0     180.0      2024.0             NaN
# 8        Alina Residences       2725.0     180.0      2024.0             NaN
# 9        Alina Residences       2717.0     180.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
# 1         1139.0     3241.0   Sold                         NaN
# 2         1095.0     3216.0   Sold                         NaN
# 3         1151.0     2974.0   Sold                         NaN
# 4         1014.0        NaN   Sold                         NaN
# 5         1141.0     2284.0   Sold                         NaN
# 6         1126.0     2317.0   Sold                         NaN
# 7          904.0     2826.0   Sold                         NaN
# 8         1018.0     2307.0   Sold                         NaN
# 9          980.0     2341.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
# 1  RX-11090587        N          Y  26.347042 -80.083200
# 2  RX-11090966        N          Y  26.347042 -80.083200
# 3  RX-11090968        N          Y  26.347042 -80.083200
# 4  RX-11090678        N          Y  26.347042 -80.083200
# 5  RX-11090681        N          Y  26.347042 -80.083200
# 6  RX-11091034        N          Y  26.347042 -80.083200
# 7  RX-11091043        N          Y  26.347042 -80.083200
# 8  RX-11091038        N          Y  26.347042 -80.083200
# 9  RX-11089856        N          Y  26.347042 -80.083200
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 1    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 2    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 3    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 4    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 5    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 6    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 7    Douglas Elliman                None               None
# 8    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 9    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
#
#     buy_agent_name_1                   buy_broker_name_1  \
# 0       Lauren Pines                      Lang Realty/BR
# 1    Charles Luciano                 Compass Florida LLC
# 2  Alejandro Salazar                     Douglas Elliman
# 3    Rebecca Spooner          Siemens Group Realty Corp.
# 4     Cynthia Nossel  Keller Williams Miami Beach Realty
# 5       Blake Morris                     Lang Realty/ BR
# 6        Scott Gerow                 Compass Florida LLC
# 7   Marisela Cotilla      Pineapple Realty Advisores LLC
# 8     Simon Reynolds           Nest Seekers Florida, LLC
# 9     Edward Pitlake                     Douglas Elliman
#
#        buy_agent_name_2    buy_broker_name_2  RANK   COLOR  \
# 0                  None                 None     1  orange
# 1                  None                 None     2    blue
# 2                  None                 None     3    blue
# 3                  None                 None     4    blue
# 4                  None                 None     5    blue
# 5                  None                 None     6    blue
# 6  Rachelle Hirt-Beresh  Compass Florida LLC     7    blue
# 7                  None                 None     8    blue
# 8                  None                 None     9    blue
# 9                  None                 None    10    blue
#
#                                            FULL_NAME
# 0  Alina Boca Raton Condo at 210 SE Mizner Blvd #...
# 1  Alina Residences at 220 SE Mizner Blvd #307 in...
# 2  Alina Residences at 220 SE Mizner Blvd #205 in...
# 3  Alina Residences at 220 SE Mizner Blvd #207 in...
# 4  Alina Residences at 220 SE Mizner Blvd #201 in...
# 5  Alina Residences at 220 SE Mizner Blvd #203 in...
# 6  Alina Residences at 220 SE Mizner Blvd #219 in...
# 7  Alina Residences at 220 SE Mizner Blvd #301 in...
# 8  Alina Residences at 220 SE Mizner Blvd #220 in...
# 9  Alina Residences at 220 SE Mizner Blvd #221 in...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Alina Boca Raton Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $2,664,000 to $6,170,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Boca Raton, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $102,935,560 million from May. 11th to May. 18th. The previous week, brokers closed 97 condo sales totaling $69,559,250.
#
# Last week’s units sold for an average of $810,516, higher than the $717,106 average price from the previous week. The average price per square foot rose to $416 from $391, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,664,000.0 million to $6,170,000.0 million.
#
# Alina Boca Raton Condo at 210 SE Mizner Blvd #302 in Boca Raton took the top spot with a $6,170,000.0 million closing. The sale closed at $1,500.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Kathy Koch Pitlake with Douglas Elliman had the listing.
# Lauren Pines with Lang Realty/BR, and None with None represented the buyer.
#
# Alina Residences at 220 SE Mizner Blvd #307 in Boca Raton, closed for the second highest amount, $4,330,000.0, or $1,139.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Alejandro Salazar with Douglas Elliman had the listing.
# Charles Luciano with Compass Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05192025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 11th to May. 18th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 1  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 2  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 3  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 4  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 5  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 6  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 7  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 8  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 9  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
# 1                FL             33432.0  4330000.0   3.0    4.0
# 2                FL             33432.0  4150000.0   2.0    3.5
# 3                FL             33432.0  4009000.0   2.0    3.0
# 4                FL             33432.0  3349000.0   3.0    3.5
# 5                FL             33432.0  3082860.0   2.0    3.0
# 6                FL             33432.0  3071000.0   2.0    3.0
# 7                FL             33432.0  2988000.0   3.0    3.5
# 8                FL             33432.0  2774000.0   2.0    3.0
# 9                FL             33432.0  2664000.0   2.0    3.0
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
# 1        Alina Residences       3800.0     180.0      2024.0             NaN
# 2        Alina Residences       3791.0     180.0      2024.0             NaN
# 3        Alina Residences       3483.0     180.0      2024.0             NaN
# 4        Alina Residences       3304.0     180.0      2024.0             NaN
# 5        Alina Residences       2701.0     180.0      2024.0             NaN
# 6        Alina Residences       2728.0     180.0      2024.0             NaN
# 7        Alina Residences       3304.0     180.0      2024.0             NaN
# 8        Alina Residences       2725.0     180.0      2024.0             NaN
# 9        Alina Residences       2717.0     180.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
# 1         1139.0     3241.0   Sold                         NaN
# 2         1095.0     3216.0   Sold                         NaN
# 3         1151.0     2974.0   Sold                         NaN
# 4         1014.0        NaN   Sold                         NaN
# 5         1141.0     2284.0   Sold                         NaN
# 6         1126.0     2317.0   Sold                         NaN
# 7          904.0     2826.0   Sold                         NaN
# 8         1018.0     2307.0   Sold                         NaN
# 9          980.0     2341.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
# 1  RX-11090587        N          Y  26.347042 -80.083200
# 2  RX-11090966        N          Y  26.347042 -80.083200
# 3  RX-11090968        N          Y  26.347042 -80.083200
# 4  RX-11090678        N          Y  26.347042 -80.083200
# 5  RX-11090681        N          Y  26.347042 -80.083200
# 6  RX-11091034        N          Y  26.347042 -80.083200
# 7  RX-11091043        N          Y  26.347042 -80.083200
# 8  RX-11091038        N          Y  26.347042 -80.083200
# 9  RX-11089856        N          Y  26.347042 -80.083200
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 1    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 2    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 3    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 4    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 5    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 6    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 7    Douglas Elliman                None               None
# 8    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 9    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
#
#     buy_agent_name_1                   buy_broker_name_1  \
# 0       Lauren Pines                      Lang Realty/BR
# 1    Charles Luciano                 Compass Florida LLC
# 2  Alejandro Salazar                     Douglas Elliman
# 3    Rebecca Spooner          Siemens Group Realty Corp.
# 4     Cynthia Nossel  Keller Williams Miami Beach Realty
# 5       Blake Morris                     Lang Realty/ BR
# 6        Scott Gerow                 Compass Florida LLC
# 7   Marisela Cotilla      Pineapple Realty Advisores LLC
# 8     Simon Reynolds           Nest Seekers Florida, LLC
# 9     Edward Pitlake                     Douglas Elliman
#
#        buy_agent_name_2    buy_broker_name_2  RANK   COLOR  \
# 0                  None                 None     1  orange
# 1                  None                 None     2    blue
# 2                  None                 None     3    blue
# 3                  None                 None     4    blue
# 4                  None                 None     5    blue
# 5                  None                 None     6    blue
# 6  Rachelle Hirt-Beresh  Compass Florida LLC     7    blue
# 7                  None                 None     8    blue
# 8                  None                 None     9    blue
# 9                  None                 None    10    blue
#
#                                            FULL_NAME
# 0  Alina Boca Raton Condo at 210 SE Mizner Blvd #...
# 1  Alina Residences at 220 SE Mizner Blvd #307 in...
# 2  Alina Residences at 220 SE Mizner Blvd #205 in...
# 3  Alina Residences at 220 SE Mizner Blvd #207 in...
# 4  Alina Residences at 220 SE Mizner Blvd #201 in...
# 5  Alina Residences at 220 SE Mizner Blvd #203 in...
# 6  Alina Residences at 220 SE Mizner Blvd #219 in...
# 7  Alina Residences at 220 SE Mizner Blvd #301 in...
# 8  Alina Residences at 220 SE Mizner Blvd #220 in...
# 9  Alina Residences at 220 SE Mizner Blvd #221 in...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Alina Boca Raton Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $2,664,000 to $6,170,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, Boca Raton, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $102,935,560 million from May. 11th to May. 18th. The previous week, brokers closed 97 condo sales totaling $69,559,250.
#
# Last week’s units sold for an average of $810,516, higher than the $717,106 average price from the previous week. The average price per square foot rose to $416 from $391, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,664,000.0 million to $6,170,000.0 million.
#
# Alina Boca Raton Condo at 210 SE Mizner Blvd #302 in Boca Raton took the top spot with a $6,170,000.0 million closing. The sale closed at $1,500.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Kathy Koch Pitlake with Douglas Elliman had the listing.
# Lauren Pines with Lang Realty/BR, and None with None represented the buyer.
#
# Alina Residences at 220 SE Mizner Blvd #307 in Boca Raton, closed for the second highest amount, $4,330,000.0, or $1,139.0 per square foot.
#
# Rochelle LeCavalier with Douglas Elliman, and Alejandro Salazar with Douglas Elliman had the listing.
# Charles Luciano with Compass Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05192025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 11th to May. 18th:
#
# Most Expensive
# Alina Boca Raton Condo, 210 SE Mizner Blvd #302, in Boca Raton | Price: $6,170,000 | $1,500 psf | Listing agents: Rochelle LeCavalier with Douglas Elliman and Kathy Koch Pitlake with Douglas Elliman | Buyer's agents: Lauren Pines with Lang Realty/BR and None with None
#
# Least Expensive
# Alina Residences, 220 SE Mizner Blvd #221, in Boca Raton | Price: $2,664,000 | $980 psf | Listing agents: Rochelle LeCavalier with Douglas Elliman and Kathy Koch Pitlake with Douglas Elliman | Buyer's agents: Edward Pitlake with Douglas Elliman and None with None
#
# Highest Price Per Square Foot
# Alina Boca Raton Condo, 210 SE Mizner Blvd #302, in Boca Raton | Price: $6,170,000 | $1,500 psf | Listing agents: Rochelle LeCavalier with Douglas Elliman and Kathy Koch Pitlake with Douglas Elliman | Buyer's agents: Lauren Pines with Lang Realty/BR and None with None
#
# Lowest Price Per Square Foot
# Alina Residences, 220 SE Mizner Blvd #301, in Boca Raton | Price: $2,988,000 | $904 psf | Listing agents: Rochelle LeCavalier with Douglas Elliman and None with None | Buyer's agents: Marisela Cotilla with Pineapple Realty Advisores LLC and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Boca-Raton/210-SE-Mizner-Blvd-33432/unit-302/home/195227043
# Second priciest sale:  https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-307/home/195808230
# Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-221/home/195781238
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-220/home/195825151
# Highest top ten psf:  https://www.redfin.com/FL/Boca-Raton/210-SE-Mizner-Blvd-33432/unit-302/home/195227043
# Lowest top ten psf:  https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-301/home/195825205

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Boca-Raton/210-SE-Mizner-Blvd-33432/unit-302/home/195227043

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-307/home/195808230

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-221/home/195781238

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-220/home/195825151

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/210-SE-Mizner-Blvd-33432/unit-302/home/195227043

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Boca-Raton/220-SE-Mizner-Blvd-33432/unit-301/home/195825205

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS        CITY  \
# 0  PAST SALE 2025-05-16   Condo/Co-op  210 SE Mizner Blvd #302  Boca Raton
# 1  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #307  Boca Raton
# 2  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #205  Boca Raton
# 3  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #207  Boca Raton
# 4  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #201  Boca Raton
# 5  PAST SALE 2025-05-14   Condo/Co-op  220 SE Mizner Blvd #203  Boca Raton
# 6  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #219  Boca Raton
# 7  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #301  Boca Raton
# 8  PAST SALE 2025-05-15   Condo/Co-op  220 SE Mizner Blvd #220  Boca Raton
# 9  PAST SALE 2025-05-12   Condo/Co-op  220 SE Mizner Blvd #221  Boca Raton
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33432.0  6170000.0   4.0    4.5
# 1                FL             33432.0  4330000.0   3.0    4.0
# 2                FL             33432.0  4150000.0   2.0    3.5
# 3                FL             33432.0  4009000.0   2.0    3.0
# 4                FL             33432.0  3349000.0   3.0    3.5
# 5                FL             33432.0  3082860.0   2.0    3.0
# 6                FL             33432.0  3071000.0   2.0    3.0
# 7                FL             33432.0  2988000.0   3.0    3.5
# 8                FL             33432.0  2774000.0   2.0    3.0
# 9                FL             33432.0  2664000.0   2.0    3.0
#
#                  LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  Alina Boca Raton Condo       4113.0  392000.0      2024.0             NaN
# 1        Alina Residences       3800.0     180.0      2024.0             NaN
# 2        Alina Residences       3791.0     180.0      2024.0             NaN
# 3        Alina Residences       3483.0     180.0      2024.0             NaN
# 4        Alina Residences       3304.0     180.0      2024.0             NaN
# 5        Alina Residences       2701.0     180.0      2024.0             NaN
# 6        Alina Residences       2728.0     180.0      2024.0             NaN
# 7        Alina Residences       3304.0     180.0      2024.0             NaN
# 8        Alina Residences       2725.0     180.0      2024.0             NaN
# 9        Alina Residences       2717.0     180.0      2024.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0         1500.0     5524.0   Sold                         NaN
# 1         1139.0     3241.0   Sold                         NaN
# 2         1095.0     3216.0   Sold                         NaN
# 3         1151.0     2974.0   Sold                         NaN
# 4         1014.0        NaN   Sold                         NaN
# 5         1141.0     2284.0   Sold                         NaN
# 6         1126.0     2317.0   Sold                         NaN
# 7          904.0     2826.0   Sold                         NaN
# 8         1018.0     2307.0   Sold                         NaN
# 9          980.0     2341.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Beaches MLS
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Beaches MLS
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-11077147        N          Y  26.347136 -80.083209
# 1  RX-11090587        N          Y  26.347042 -80.083200
# 2  RX-11090966        N          Y  26.347042 -80.083200
# 3  RX-11090968        N          Y  26.347042 -80.083200
# 4  RX-11090678        N          Y  26.347042 -80.083200
# 5  RX-11090681        N          Y  26.347042 -80.083200
# 6  RX-11091034        N          Y  26.347042 -80.083200
# 7  RX-11091043        N          Y  26.347042 -80.083200
# 8  RX-11091038        N          Y  26.347042 -80.083200
# 9  RX-11089856        N          Y  26.347042 -80.083200
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Boca-Raton/210-SE-Mi...  Rochelle LeCavalier
# 1  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 2  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 3  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Boca-Raton/220-Se-Mi...  Rochelle LeCavalier
# 6  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 7  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 8  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 9  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
#
#   list_broker_name_1   list_agent_name_2 list_broker_name_2  \
# 0    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 1    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 2    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 3    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 4    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 5    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 6    Douglas Elliman   Alejandro Salazar    Douglas Elliman
# 7    Douglas Elliman                None               None
# 8    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
# 9    Douglas Elliman  Kathy Koch Pitlake    Douglas Elliman
#
#     buy_agent_name_1                   buy_broker_name_1  \
# 0       Lauren Pines                      Lang Realty/BR
# 1    Charles Luciano                 Compass Florida LLC
# 2  Alejandro Salazar                     Douglas Elliman
# 3    Rebecca Spooner          Siemens Group Realty Corp.
# 4     Cynthia Nossel  Keller Williams Miami Beach Realty
# 5       Blake Morris                     Lang Realty/ BR
# 6        Scott Gerow                 Compass Florida LLC
# 7   Marisela Cotilla      Pineapple Realty Advisores LLC
# 8     Simon Reynolds           Nest Seekers Florida, LLC
# 9     Edward Pitlake                     Douglas Elliman
#
#        buy_agent_name_2    buy_broker_name_2  RANK   COLOR  \
# 0                  None                 None     1  orange
# 1                  None                 None     2    blue
# 2                  None                 None     3    blue
# 3                  None                 None     4    blue
# 4                  None                 None     5    blue
# 5                  None                 None     6    blue
# 6  Rachelle Hirt-Beresh  Compass Florida LLC     7    blue
# 7                  None                 None     8    blue
# 8                  None                 None     9    blue
# 9                  None                 None    10    blue
#
#                                            FULL_NAME
# 0  Alina Boca Raton Condo at 210 SE Mizner Blvd #...
# 1  Alina Residences at 220 SE Mizner Blvd #307 in...
# 2  Alina Residences at 220 SE Mizner Blvd #205 in...
# 3  Alina Residences at 220 SE Mizner Blvd #207 in...
# 4  Alina Residences at 220 SE Mizner Blvd #201 in...
# 5  Alina Residences at 220 SE Mizner Blvd #203 in...
# 6  Alina Residences at 220 SE Mizner Blvd #219 in...
# 7  Alina Residences at 220 SE Mizner Blvd #301 in...
# 8  Alina Residences at 220 SE Mizner Blvd #220 in...
# 9  Alina Residences at 220 SE Mizner Blvd #221 in...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 4, 1) ## List (Earlier) date
date2 = datetime(2025, 5, 16) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 45

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1500.0
# 1    1139.0
# 2    1095.0
# 3    1151.0
# 4    1014.0
# 5    1141.0
# 6    1126.0
# 7     904.0
# 8    1018.0
# 9     980.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                ADDRESS       PRICE BEDS  BATHS  \
# 0 2025-05-16  210 SE Mizner Blvd #302 in Boca Raton  $6,170,000    4    4.5
# 1 2025-05-14  220 SE Mizner Blvd #307 in Boca Raton  $4,330,000    3    4.0
# 2 2025-05-15  220 SE Mizner Blvd #205 in Boca Raton  $4,150,000    2    3.5
# 3 2025-05-15  220 SE Mizner Blvd #207 in Boca Raton  $4,009,000    2    3.0
# 4 2025-05-14  220 SE Mizner Blvd #201 in Boca Raton  $3,349,000    3    3.5
# 5 2025-05-14  220 SE Mizner Blvd #203 in Boca Raton  $3,082,860    2    3.0
# 6 2025-05-15  220 SE Mizner Blvd #219 in Boca Raton  $3,071,000    2    3.0
# 7 2025-05-15  220 SE Mizner Blvd #301 in Boca Raton  $2,988,000    3    3.5
# 8 2025-05-15  220 SE Mizner Blvd #220 in Boca Raton  $2,774,000    2    3.0
# 9 2025-05-12  220 SE Mizner Blvd #221 in Boca Raton  $2,664,000    2    3.0
#
#   SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0       4,113       2024        $1,500  Beaches MLS  RX-11077147
# 1       3,800       2024        $1,139  Beaches MLS  RX-11090587
# 2       3,791       2024        $1,095  Beaches MLS  RX-11090966
# 3       3,483       2024        $1,151  Beaches MLS  RX-11090968
# 4       3,304       2024        $1,014  Beaches MLS  RX-11090678
# 5       2,701       2024        $1,141  Beaches MLS  RX-11090681
# 6       2,728       2024        $1,126  Beaches MLS  RX-11091034
# 7       3,304       2024          $904  Beaches MLS  RX-11091043
# 8       2,725       2024        $1,018  Beaches MLS  RX-11091038
# 9       2,717       2024          $980  Beaches MLS  RX-11089856
#
#                                         LISTING INFO  \
# 0  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 1  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 2  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 3  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 4  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 5  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 6  Rochelle LeCavalier Douglas Elliman Alejandro ...
# 7            Rochelle LeCavalier Douglas Elliman
# 8  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 9  Rochelle LeCavalier Douglas Elliman Kathy Koch...
#
#                                          BUYING INFO
# 0                    Lauren Pines Lang Realty/BR
# 1            Charles Luciano Compass Florida LLC
# 2              Alejandro Salazar Douglas Elliman
# 3     Rebecca Spooner Siemens Group Realty Corp.
# 4  Cynthia Nossel Keller Williams Miami Beach Rea...
# 5                   Blake Morris Lang Realty/ BR
# 6  Scott Gerow Compass Florida LLC Rachelle Hirt-...
# 7  Marisela Cotilla Pineapple Realty Advisores LL...
# 8       Simon Reynolds Nest Seekers Florida, LLC
# 9                 Edward Pitlake Douglas Elliman

# %%
df2 = df2.sort_values(by='PRICE',ascending=False).head(20)

# %%
df2.to_csv("PBC_last_week_sales.csv")
