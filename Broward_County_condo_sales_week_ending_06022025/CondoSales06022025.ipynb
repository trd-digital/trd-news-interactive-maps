# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=2)

# Get the date one week ago
one_week_ago = today - timedelta(days=8)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 23rd May. 31st

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE               ADDRESS  \
# 1  PAST SALE  May-28-2025   Condo/Co-op  3300 NE 36th St #416
#
#               CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 1  Fort Lauderdale                FL             33308.0  450000.0   2.0
#
#    BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1    2.0  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Fort-Lauderdale/3300...  Beaches MLS  F10490614
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  26.172116 -80.100718
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
#  Broward

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-05-30    43
# 2025-05-29    30
# 2025-05-27    29
# 2025-05-28    23
# 2025-05-26     2
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 62   PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 60   PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 107  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 82   PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 127  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 124  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 34   PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 35   PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 90   PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 92   PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 62          Hollywood                FL             33019.0  2500000.0   4.0
# 60    Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 107  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 82    Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 127   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 124   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 34    Fort Lauderdale                FL             33304.0   900000.0   3.0
# 35      Pompano Beach                FL             33062.0   900000.0   3.0
# 90    Fort Lauderdale                FL             33316.0   889000.0   2.0
# 92    Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 62     3.5  ...   Sold                         NaN                       NaN
# 60     3.5  ...   Sold                         NaN                       NaN
# 107    3.0  ...   Sold                         NaN                       NaN
# 82     2.5  ...   Sold                         NaN                       NaN
# 127    2.5  ...   Sold                         NaN                       NaN
# 124    4.5  ...   Sold                         NaN                       NaN
# 34     3.5  ...   Sold                         NaN                       NaN
# 35     3.0  ...   Sold                         NaN                       NaN
# 90     2.0  ...   Sold                         NaN                       NaN
# 92     2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL       SOURCE  \
# 62   https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 60   https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 107  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 82   https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
# 127  https://www.redfin.com/FL/Hillsboro-Beach/1155...  Beaches MLS
# 124  https://www.redfin.com/FL/Fort-Lauderdale/2845...  Beaches MLS
# 34   https://www.redfin.com/FL/Fort-Lauderdale/920-...       MARMLS
# 35   https://www.redfin.com/FL/Pompano-Beach/525-N-...  Beaches MLS
# 90   https://www.redfin.com/FL/Fort-Lauderdale/1490...  Beaches MLS
# 92   https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
#
#             MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 62     A11735368         N          Y  25.993834 -80.117821
# 60     A11729858         N          Y  26.118354 -80.141518
# 107    A11681350         N          Y  25.984911 -80.118344
# 82     F10482684         N          Y  26.181938 -80.096840
# 127  RX-10926283         N          Y  26.293859 -80.078549
# 124    F10446082         N          Y  26.136658 -80.107327
# 34     A11757633         N          Y  26.136230 -80.126510
# 35   RX-11074180         N          Y  26.240511 -80.088927
# 90     F10478653         N          Y  26.102908 -80.128525
# 92     F10477857         N          Y  26.181938 -80.096840
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 1  PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 2  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 3  PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 4  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 5  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 6  PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 7  PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 8  PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 9  PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2500000.0   4.0
# 1   Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 2  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 4   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 5   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 6   Fort Lauderdale                FL             33304.0   900000.0   3.0
# 7     Pompano Beach                FL             33062.0   900000.0   3.0
# 8   Fort Lauderdale                FL             33316.0   889000.0   2.0
# 9   Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    3.5  ... -80.117821  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 1    3.5  ... -80.141518  https://www.redfin.com/FL/Fort-Lauderdale/333-...
# 2    3.0  ... -80.118344  https://www.redfin.com/FL/Hallandale-Beach/183...
# 3    2.5  ... -80.096840  https://www.redfin.com/FL/Fort-Lauderdale/4300...
# 4    2.5  ... -80.078549  https://www.redfin.com/FL/Hillsboro-Beach/1155...
# 5    4.5  ... -80.107327  https://www.redfin.com/FL/Fort-Lauderdale/2845...
# 6    3.5  ... -80.126510  https://www.redfin.com/FL/Fort-Lauderdale/920-...
# 7    3.0  ... -80.088927  https://www.redfin.com/FL/Pompano-Beach/525-N-...
# 8    2.0  ... -80.128525  https://www.redfin.com/FL/Fort-Lauderdale/1490...
# 9    2.0  ... -80.096840  https://www.redfin.com/FL/Fort-Lauderdale/4300...
#
#     list_agent_name_1                             list_broker_name_1  \
# 0          Joel Lusky  The Brokerage South Florida Real Estate, LLC.
# 1         Bobbi Ocean                  Galleria International Realty
# 2    Mariana Martynov                                Golden Keys Inc
# 3      Marisa DiLenge                                     Realty 100
# 4        Robert Meyer                Keller Williams Realty Services
# 5        Gayle Borden                         Coldwell Banker Realty
# 6  Michelle Mattingly                               Oakstrand Realty
# 7     Colleen Newland                                Douglas Elliman
# 8     Robert Russotto                 Better Homes & Gdns RE Fla 1st
# 9      Ellen Taracido                           Compass Florida, LLC
#
#    list_agent_name_2                             list_broker_name_2  \
# 0      Zalmy Shapira  The Brokerage South Florida Real Estate, LLC.
# 1               None                                           None
# 2               None                                           None
# 3    Michael DiLenge                                     Realty 100
# 4               None                                           None
# 5      Jane Wheatley                         Coldwell Banker Realty
# 6               None                                           None
# 7               None                                           None
# 8   Patricia Echarte                 Better Homes & Gdns RE Fla 1st
# 9               None                                           None
#
#    buy_agent_name_1               buy_broker_name_1  buy_agent_name_2  \
# 0     Eva Bouhadana           Beachfront Realty Inc              None
# 1      Jessie Stier            Compass Florida, LLC              None
# 2    Monica Benitez                Xcellence Realty              None
# 3     Ryan Hanrahan     RE/MAX Consultants Realty 1              None
# 4    Burton Wilkins  One Sotheby's International Re              None
# 5      Daniel Bozza      Atlantic Realty Group, LLC              None
# 6              None                            None              None
# 7    Non Non-Member       Non-Member Selling Office              None
# 8   Robert Russotto  Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9    Rosa Levy-harf      Level Realty Partners, LLC       Ilana Gross
#
#                 buy_broker_name_2
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# 5                            None
# 6                            None
# 7                            None
# 8  Better Homes & Gdns RE Fla 1st
# 9      Level Realty Partners, LLC
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 127

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $341,962

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $266

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $43,429,130

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          127              341962          266                     43429130.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 89
# -----------
# Input Previous Week Condo Average Sales Price:
# 287503
# -----------
# Input Previous Week Condo Average PSF:
# 250
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 25587800.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                ADDRESS       CITY  \
# 0  PAST SALE 2025-05-29   Condo/Co-op  3101 S Ocean Dr #2703  Hollywood
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33019.0  2500000.0   4.0    3.5
#
#             LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  OCEAN PALMS CONDO       3466.0       NaN      2005.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          721.0     3621.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...  MARMLS  A11735368
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.993834 -80.117821
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...        Joel Lusky
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
#
#        buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Beachfront Realty Inc             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 1  PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 2  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 3  PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 4  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 5  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 6  PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 7  PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 8  PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 9  PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2500000.0   4.0
# 1   Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 2  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 4   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 5   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 6   Fort Lauderdale                FL             33304.0   900000.0   3.0
# 7     Pompano Beach                FL             33062.0   900000.0   3.0
# 8   Fort Lauderdale                FL             33316.0   889000.0   2.0
# 9   Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#    BATHS                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5             OCEAN PALMS CONDO       3466.0       NaN      2005.0
# 1    3.5     LAS OLAS RIVER HOUSE COND       2726.0       NaN      2004.0
# 2    3.0          BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3    2.5                    Plaza East       2030.0       NaN      1967.0
# 4    2.5    Hillsboro Ocean Club Condo       2100.0       NaN      1984.0
# 5    4.5         Le Club International       2630.0       NaN      2002.0
# 6    3.5     LA TERRACE AT VICTORIA PA       2212.0       NaN      2005.0
# 7    3.0  Silver Thatch Atlantic Plaza       2465.0       NaN      1980.0
# 8    2.0                Dockside Lofts       1459.0       NaN      2005.0
# 9    2.0                    Plaza East       1450.0       NaN      1967.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          721.0     3621.0   Sold
# 1             NaN          807.0     3529.0   Sold
# 2             NaN          969.0     2188.0   Sold
# 3             NaN          662.0     2216.0   Sold
# 4             NaN          548.0     1500.0   Sold
# 5             NaN          418.0     3014.0   Sold
# 6             NaN          407.0      590.0   Sold
# 7             NaN          365.0     2499.0   Sold
# 8             NaN          609.0      650.0   Sold
# 9             NaN          552.0     1683.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...       MARMLS
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...  Beaches MLS
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11735368        N          Y  25.993834 -80.117821
# 1    A11729858        N          Y  26.118354 -80.141518
# 2    A11681350        N          Y  25.984911 -80.118344
# 3    F10482684        N          Y  26.181938 -80.096840
# 4  RX-10926283        N          Y  26.293859 -80.078549
# 5    F10446082        N          Y  26.136658 -80.107327
# 6    A11757633        N          Y  26.136230 -80.126510
# 7  RX-11074180        N          Y  26.240511 -80.088927
# 8    F10478653        N          Y  26.102908 -80.128525
# 9    F10477857        N          Y  26.181938 -80.096840
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...          Joel Lusky
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...         Bobbi Ocean
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...    Mariana Martynov
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Marisa DiLenge
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...        Robert Meyer
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...        Gayle Borden
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Michelle Mattingly
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...     Colleen Newland
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...     Robert Russotto
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Ellen Taracido
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
# 1                  Galleria International Realty              None
# 2                                Golden Keys Inc              None
# 3                                     Realty 100   Michael DiLenge
# 4                Keller Williams Realty Services              None
# 5                         Coldwell Banker Realty     Jane Wheatley
# 6                               Oakstrand Realty              None
# 7                                Douglas Elliman              None
# 8                 Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9                           Compass Florida, LLC              None
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
# 1                                           None     Jessie Stier
# 2                                           None   Monica Benitez
# 3                                     Realty 100    Ryan Hanrahan
# 4                                           None   Burton Wilkins
# 5                         Coldwell Banker Realty     Daniel Bozza
# 6                                           None             None
# 7                                           None   Non Non-Member
# 8                 Better Homes & Gdns RE Fla 1st  Robert Russotto
# 9                                           None   Rosa Levy-harf
#
#                 buy_broker_name_1  buy_agent_name_2  \
# 0           Beachfront Realty Inc              None
# 1            Compass Florida, LLC              None
# 2                Xcellence Realty              None
# 3     RE/MAX Consultants Realty 1              None
# 4  One Sotheby's International Re              None
# 5      Atlantic Realty Group, LLC              None
# 6                            None              None
# 7       Non-Member Selling Office              None
# 8  Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9      Level Realty Partners, LLC       Ilana Gross
#
#                 buy_broker_name_2  RANK   COLOR
# 0                            None     1  orange
# 1                            None     2    blue
# 2                            None     3    blue
# 3                            None     4    blue
# 4                            None     5    blue
# 5                            None     6    blue
# 6                            None     7    blue
# 7                            None     8    blue
# 8  Better Homes & Gdns RE Fla 1st     9    blue
# 9      Level Realty Partners, LLC    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74c5076e1550204a38c648e6baaf9f7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 23rd — May. 31st&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74c5076e1550204a38c648e6baaf9f7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74c5076e1550204a38c648e6baaf9f7d = L.map(
#                 &quot;map_74c5076e1550204a38c648e6baaf9f7d&quot;,
#                 {
#                     center: [26.164341162204728, -80.17438687165355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_4c9fb5c89b24e5d5a351cb0c8a5082f7 = L.featureGroup(
#                 {}
#             ).addTo(map_74c5076e1550204a38c648e6baaf9f7d);
#
#
#             var marker_9bc3c275c26251a82bdfcf503a4f85da = L.marker(
#                 [25.9938336, -80.1178208],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_4c9fb5c89b24e5d5a351cb0c8a5082f7);
#
#
#             var icon_1020a55af15a2c75a25c41336a5f774e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9bc3c275c26251a82bdfcf503a4f85da.setIcon(icon_1020a55af15a2c75a25c41336a5f774e);
#
#
#         var popup_eaf75c91aa8b1c780607601062a1de2c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6fdb0e4f7586cdd55df6694f8d363361 = $(`&lt;div id=&quot;html_6fdb0e4f7586cdd55df6694f8d363361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;3101 S Ocean Dr #2703&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,500,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$721.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,466.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2005.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_eaf75c91aa8b1c780607601062a1de2c.setContent(html_6fdb0e4f7586cdd55df6694f8d363361);
#
#
#
#         marker_9bc3c275c26251a82bdfcf503a4f85da.bindPopup(popup_eaf75c91aa8b1c780607601062a1de2c)
#         ;
#
#
#
#
#             var feature_group_a63a4591d3df802bae1756250d0911dc = L.featureGroup(
#                 {}
#             ).addTo(map_74c5076e1550204a38c648e6baaf9f7d);
#
#
#             var marker_d49b301a862c8a206f403897913a7d08 = L.marker(
#                 [26.1183542, -80.1415179],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_a63a4591d3df802bae1756250d0911dc);
#
#
#             var icon_815efab17634c13827a4cc3427750095 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d49b301a862c8a206f403897913a7d08.setIcon(icon_815efab17634c13827a4cc3427750095);
#
#
#         var popup_2a6190ad3e265d1694e8cd21a7247eeb = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_bde6ab6a66d3c3a8746a12257f2f71c5 = $(`&lt;div id=&quot;html_bde6ab6a66d3c3a8746a12257f2f71c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;333 Las Olas Way #3302&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,200,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$807.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,726.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2004.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_2a6190ad3e265d1694e8cd21a7247eeb.setContent(html_bde6ab6a66d3c3a8746a12257f2f71c5);
#
#
#
#         marker_d49b301a862c8a206f403897913a7d08.bindPopup(popup_2a6190ad3e265d1694e8cd21a7247eeb)
#         ;
#
#
#
#
#             var marker_5d5ca4efcfca8983eb35d5ff57628d28 = L.marker(
#                 [25.9849114, -80.1183443],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_a63a4591d3df802bae1756250d0911dc);
#
#
#             var icon_c5e717c6ad46078d526cdd07d45b22e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d5ca4efcfca8983eb35d5ff57628d28.setIcon(icon_c5e717c6ad46078d526cdd07d45b22e3);
#
#
#         var popup_34a09ef93ee56fdc2ae41fea735192ad = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6b3d7cc062cbec2a39f6062141375c8a = $(`&lt

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                ADDRESS       CITY  \
# 0  PAST SALE 2025-05-29   Condo/Co-op  3101 S Ocean Dr #2703  Hollywood
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33019.0  2500000.0   4.0    3.5
#
#             LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0  OCEAN PALMS CONDO       3466.0       NaN      2005.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          721.0     3621.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...  MARMLS  A11735368
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.993834 -80.117821
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...        Joel Lusky
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
#
#        buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Beachfront Realty Inc             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_06022025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in Hollywood'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 1  PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 2  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 3  PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 4  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 5  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 6  PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 7  PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 8  PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 9  PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2500000.0   4.0
# 1   Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 2  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 4   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 5   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 6   Fort Lauderdale                FL             33304.0   900000.0   3.0
# 7     Pompano Beach                FL             33062.0   900000.0   3.0
# 8   Fort Lauderdale                FL             33316.0   889000.0   2.0
# 9   Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#    BATHS                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5             OCEAN PALMS CONDO       3466.0       NaN      2005.0
# 1    3.5     LAS OLAS RIVER HOUSE COND       2726.0       NaN      2004.0
# 2    3.0          BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3    2.5                    Plaza East       2030.0       NaN      1967.0
# 4    2.5    Hillsboro Ocean Club Condo       2100.0       NaN      1984.0
# 5    4.5         Le Club International       2630.0       NaN      2002.0
# 6    3.5     LA TERRACE AT VICTORIA PA       2212.0       NaN      2005.0
# 7    3.0  Silver Thatch Atlantic Plaza       2465.0       NaN      1980.0
# 8    2.0                Dockside Lofts       1459.0       NaN      2005.0
# 9    2.0                    Plaza East       1450.0       NaN      1967.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          721.0     3621.0   Sold
# 1             NaN          807.0     3529.0   Sold
# 2             NaN          969.0     2188.0   Sold
# 3             NaN          662.0     2216.0   Sold
# 4             NaN          548.0     1500.0   Sold
# 5             NaN          418.0     3014.0   Sold
# 6             NaN          407.0      590.0   Sold
# 7             NaN          365.0     2499.0   Sold
# 8             NaN          609.0      650.0   Sold
# 9             NaN          552.0     1683.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...       MARMLS
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...  Beaches MLS
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11735368        N          Y  25.993834 -80.117821
# 1    A11729858        N          Y  26.118354 -80.141518
# 2    A11681350        N          Y  25.984911 -80.118344
# 3    F10482684        N          Y  26.181938 -80.096840
# 4  RX-10926283        N          Y  26.293859 -80.078549
# 5    F10446082        N          Y  26.136658 -80.107327
# 6    A11757633        N          Y  26.136230 -80.126510
# 7  RX-11074180        N          Y  26.240511 -80.088927
# 8    F10478653        N          Y  26.102908 -80.128525
# 9    F10477857        N          Y  26.181938 -80.096840
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...          Joel Lusky
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...         Bobbi Ocean
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...    Mariana Martynov
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Marisa DiLenge
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...        Robert Meyer
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...        Gayle Borden
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Michelle Mattingly
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...     Colleen Newland
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...     Robert Russotto
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Ellen Taracido
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
# 1                  Galleria International Realty              None
# 2                                Golden Keys Inc              None
# 3                                     Realty 100   Michael DiLenge
# 4                Keller Williams Realty Services              None
# 5                         Coldwell Banker Realty     Jane Wheatley
# 6                               Oakstrand Realty              None
# 7                                Douglas Elliman              None
# 8                 Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9                           Compass Florida, LLC              None
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
# 1                                           None     Jessie Stier
# 2                                           None   Monica Benitez
# 3                                     Realty 100    Ryan Hanrahan
# 4                                           None   Burton Wilkins
# 5                         Coldwell Banker Realty     Daniel Bozza
# 6                                           None             None
# 7                                           None   Non Non-Member
# 8                 Better Homes & Gdns RE Fla 1st  Robert Russotto
# 9                                           None   Rosa Levy-harf
#
#                 buy_broker_name_1  buy_agent_name_2  \
# 0           Beachfront Realty Inc              None
# 1            Compass Florida, LLC              None
# 2                Xcellence Realty              None
# 3     RE/MAX Consultants Realty 1              None
# 4  One Sotheby's International Re              None
# 5      Atlantic Realty Group, LLC              None
# 6                            None              None
# 7       Non-Member Selling Office              None
# 8  Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9      Level Realty Partners, LLC       Ilana Gross
#
#                 buy_broker_name_2  RANK   COLOR  \
# 0                            None     1  orange
# 1                            None     2    blue
# 2                            None     3    blue
# 3                            None     4    blue
# 4                            None     5    blue
# 5                            None     6    blue
# 6                            None     7    blue
# 7                            None     8    blue
# 8  Better Homes & Gdns RE Fla 1st     9    blue
# 9      Level Realty Partners, LLC    10    blue
#
#                                            FULL_NAME
# 0  OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in ...
# 1  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2202 ...
# 3  Plaza East at 4300 N Ocean Blvd Unit 5A in For...
# 4  Hillsboro Ocean Club Condo at 1155 Hillsboro M...
# 5  Le Club International at 2845 NE 9th St #804 i...
# 6  LA TERRACE AT VICTORIA PA at 920 NE 16th Ter #...
# 7  Silver Thatch Atlantic Plaza at 525 N Ocean Bl...
# 8  Dockside Lofts at 1490 SE 15th St #101 in Fort...
# 9  Plaza East at 4300 N Ocean Blvd Unit 14N in Fo...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: OCEAN PALMS CONDO closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $800,000 to $2,500,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Pompano Beach, Hollywood, Fort Lauderdale, Hallandale Beach, Hillsboro Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $43,429,130 million from May. 23rd to May. 31st. The previous week, brokers closed 89 condo sales totaling $25,587,800.
#
# Last week’s units sold for an average of $341,962, higher than the $287,503 average price from the previous week. The average price per square foot rose to $266 from $250, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $800,000.0 million to $2,500,000.0 million.
#
# OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in Hollywood took the top spot with a $2,500,000.0 million closing. The sale closed at $721.0 per square foot.
#
# Joel Lusky with The Brokerage South Florida Real Estate, LLC., and Zalmy Shapira with The Brokerage South Florida Real Estate, LLC. had the listing.
# Eva Bouhadana with Beachfront Realty Inc, and None with None represented the buyer.
#
# LAS OLAS RIVER HOUSE COND at 333 Las Olas Way #3302 in Fort Lauderdale, closed for the second highest amount, $2,200,000.0, or $807.0 per square foot.
#
# Bobbi Ocean with Galleria International Realty, and None with None had the listing.
# Jessie Stier with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_06022025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 23rd to May. 31st:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 1  PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 2  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 3  PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 4  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 5  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 6  PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 7  PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 8  PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 9  PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2500000.0   4.0
# 1   Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 2  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 4   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 5   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 6   Fort Lauderdale                FL             33304.0   900000.0   3.0
# 7     Pompano Beach                FL             33062.0   900000.0   3.0
# 8   Fort Lauderdale                FL             33316.0   889000.0   2.0
# 9   Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#    BATHS                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5             OCEAN PALMS CONDO       3466.0       NaN      2005.0
# 1    3.5     LAS OLAS RIVER HOUSE COND       2726.0       NaN      2004.0
# 2    3.0          BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3    2.5                    Plaza East       2030.0       NaN      1967.0
# 4    2.5    Hillsboro Ocean Club Condo       2100.0       NaN      1984.0
# 5    4.5         Le Club International       2630.0       NaN      2002.0
# 6    3.5     LA TERRACE AT VICTORIA PA       2212.0       NaN      2005.0
# 7    3.0  Silver Thatch Atlantic Plaza       2465.0       NaN      1980.0
# 8    2.0                Dockside Lofts       1459.0       NaN      2005.0
# 9    2.0                    Plaza East       1450.0       NaN      1967.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          721.0     3621.0   Sold
# 1             NaN          807.0     3529.0   Sold
# 2             NaN          969.0     2188.0   Sold
# 3             NaN          662.0     2216.0   Sold
# 4             NaN          548.0     1500.0   Sold
# 5             NaN          418.0     3014.0   Sold
# 6             NaN          407.0      590.0   Sold
# 7             NaN          365.0     2499.0   Sold
# 8             NaN          609.0      650.0   Sold
# 9             NaN          552.0     1683.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...       MARMLS
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...  Beaches MLS
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11735368        N          Y  25.993834 -80.117821
# 1    A11729858        N          Y  26.118354 -80.141518
# 2    A11681350        N          Y  25.984911 -80.118344
# 3    F10482684        N          Y  26.181938 -80.096840
# 4  RX-10926283        N          Y  26.293859 -80.078549
# 5    F10446082        N          Y  26.136658 -80.107327
# 6    A11757633        N          Y  26.136230 -80.126510
# 7  RX-11074180        N          Y  26.240511 -80.088927
# 8    F10478653        N          Y  26.102908 -80.128525
# 9    F10477857        N          Y  26.181938 -80.096840
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...          Joel Lusky
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...         Bobbi Ocean
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...    Mariana Martynov
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Marisa DiLenge
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...        Robert Meyer
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...        Gayle Borden
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Michelle Mattingly
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...     Colleen Newland
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...     Robert Russotto
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Ellen Taracido
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
# 1                  Galleria International Realty              None
# 2                                Golden Keys Inc              None
# 3                                     Realty 100   Michael DiLenge
# 4                Keller Williams Realty Services              None
# 5                         Coldwell Banker Realty     Jane Wheatley
# 6                               Oakstrand Realty              None
# 7                                Douglas Elliman              None
# 8                 Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9                           Compass Florida, LLC              None
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
# 1                                           None     Jessie Stier
# 2                                           None   Monica Benitez
# 3                                     Realty 100    Ryan Hanrahan
# 4                                           None   Burton Wilkins
# 5                         Coldwell Banker Realty     Daniel Bozza
# 6                                           None             None
# 7                                           None   Non Non-Member
# 8                 Better Homes & Gdns RE Fla 1st  Robert Russotto
# 9                                           None   Rosa Levy-harf
#
#                 buy_broker_name_1  buy_agent_name_2  \
# 0           Beachfront Realty Inc              None
# 1            Compass Florida, LLC              None
# 2                Xcellence Realty              None
# 3     RE/MAX Consultants Realty 1              None
# 4  One Sotheby's International Re              None
# 5      Atlantic Realty Group, LLC              None
# 6                            None              None
# 7       Non-Member Selling Office              None
# 8  Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9      Level Realty Partners, LLC       Ilana Gross
#
#                 buy_broker_name_2  RANK   COLOR  \
# 0                            None     1  orange
# 1                            None     2    blue
# 2                            None     3    blue
# 3                            None     4    blue
# 4                            None     5    blue
# 5                            None     6    blue
# 6                            None     7    blue
# 7                            None     8    blue
# 8  Better Homes & Gdns RE Fla 1st     9    blue
# 9      Level Realty Partners, LLC    10    blue
#
#                                            FULL_NAME
# 0  OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in ...
# 1  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2202 ...
# 3  Plaza East at 4300 N Ocean Blvd Unit 5A in For...
# 4  Hillsboro Ocean Club Condo at 1155 Hillsboro M...
# 5  Le Club International at 2845 NE 9th St #804 i...
# 6  LA TERRACE AT VICTORIA PA at 920 NE 16th Ter #...
# 7  Silver Thatch Atlantic Plaza at 525 N Ocean Bl...
# 8  Dockside Lofts at 1490 SE 15th St #101 in Fort...
# 9  Plaza East at 4300 N Ocean Blvd Unit 14N in Fo...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: OCEAN PALMS CONDO closing tops Broward weekly condo sales
# DEK: Top 10 sales ranged from $800,000 to $2,500,000
# FEATURED HED:
# SEO HED: Broward County Weekly Condo Report
# SEO DESCRIPTION: Broward County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward, weekly condo sales, Pompano Beach, Hollywood, Fort Lauderdale, Hallandale Beach, Hillsboro Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County’s NEWS PEG HERE.
#
# Brokers closed 127 condo sales totaling $43,429,130 million from May. 23rd to May. 31st. The previous week, brokers closed 89 condo sales totaling $25,587,800.
#
# Last week’s units sold for an average of $341,962, higher than the $287,503 average price from the previous week. The average price per square foot rose to $266 from $250, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $800,000.0 million to $2,500,000.0 million.
#
# OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in Hollywood took the top spot with a $2,500,000.0 million closing. The sale closed at $721.0 per square foot.
#
# Joel Lusky with The Brokerage South Florida Real Estate, LLC., and Zalmy Shapira with The Brokerage South Florida Real Estate, LLC. had the listing.
# Eva Bouhadana with Beachfront Realty Inc, and None with None represented the buyer.
#
# LAS OLAS RIVER HOUSE COND at 333 Las Olas Way #3302 in Fort Lauderdale, closed for the second highest amount, $2,200,000.0, or $807.0 per square foot.
#
# Bobbi Ocean with Galleria International Realty, and None with None had the listing.
# Jessie Stier with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_06022025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 23rd to May. 31st:
#
# Most Expensive
# OCEAN PALMS CONDO, 3101 S Ocean Dr #2703, in Hollywood | Price: $2,500,000 | $721 psf | Listing agents: Joel Lusky with The Brokerage South Florida Real Estate, LLC. and Zalmy Shapira with The Brokerage South Florida Real Estate, LLC. | Buyer's agents: Eva Bouhadana with Beachfront Realty Inc and None with None
#
# Least Expensive
# Plaza East, 4300 N Ocean Blvd Unit 14N, in Fort Lauderdale | Price: $800,000 | $552 psf | Listing agents: Ellen Taracido with Compass Florida, LLC and None with None | Buyer's agents: Rosa Levy-harf with Level Realty Partners, LLC and Ilana Gross with Level Realty Partners, LLC
#
# Highest Price Per Square Foot
# BEACH CLUB TWO CONDO, 1830 S Ocean Dr #2202, in Hallandale Beach | Price: $2,000,000 | $969 psf | Listing agents: Mariana Martynov with Golden Keys Inc and None with None | Buyer's agents: Monica Benitez with Xcellence Realty and None with None
#
# Lowest Price Per Square Foot
# Silver Thatch Atlantic Plaza, 525 N Ocean Blvd #1824, in Pompano Beach | Price: $900,000 | $365 psf | Listing agents: Colleen Newland with Douglas Elliman and None with None | Buyer's agents: Non Non-Member with Non-Member Selling Office and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Hollywood/3101-S-Ocean-Dr-33019/unit-2703/home/42066767
# Second priciest sale:  https://www.redfin.com/FL/Fort-Lauderdale/333-Las-Olas-Way-33301/unit-3302/home/42020124
# Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/4300-N-Ocean-Blvd-33308/unit-14N/home/41710996
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/1490-SE-15th-St-33316/unit-101/home/42057000
# Highest top ten psf:  https://www.redfin.com/FL/Hallandale-Beach/1830-S-Ocean-Dr-33009/unit-2202/home/42051881
# Lowest top ten psf:  https://www.redfin.com/FL/Pompano-Beach/525-N-Ocean-Blvd-33062/unit-1824/home/41528960

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Hollywood/3101-S-Ocean-Dr-33019/unit-2703/home/42066767

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/333-Las-Olas-Way-33301/unit-3302/home/42020124

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/4300-N-Ocean-Blvd-33308/unit-14N/home/41710996

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/1490-SE-15th-St-33316/unit-101/home/42057000

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/1830-S-Ocean-Dr-33009/unit-2202/home/42051881

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Pompano-Beach/525-N-Ocean-Blvd-33062/unit-1824/home/41528960

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-29   Condo/Co-op       3101 S Ocean Dr #2703
# 1  PAST SALE 2025-05-28   Condo/Co-op      333 Las Olas Way #3302
# 2  PAST SALE 2025-05-26   Condo/Co-op       1830 S Ocean Dr #2202
# 3  PAST SALE 2025-05-29   Condo/Co-op   4300 N Ocean Blvd Unit 5A
# 4  PAST SALE 2025-05-30   Condo/Co-op    1155 Hillsboro Mile #307
# 5  PAST SALE 2025-05-30   Condo/Co-op         2845 NE 9th St #804
# 6  PAST SALE 2025-05-30   Condo/Co-op          920 NE 16th Ter #3
# 7  PAST SALE 2025-05-30   Condo/Co-op      525 N Ocean Blvd #1824
# 8  PAST SALE 2025-05-28   Condo/Co-op        1490 SE 15th St #101
# 9  PAST SALE 2025-05-30   Condo/Co-op  4300 N Ocean Blvd Unit 14N
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0         Hollywood                FL             33019.0  2500000.0   4.0
# 1   Fort Lauderdale                FL             33301.0  2200000.0   3.0
# 2  Hallandale Beach                FL             33009.0  2000000.0   3.0
# 3   Fort Lauderdale                FL             33308.0  1343500.0   3.0
# 4   Hillsboro Beach                FL             33062.0  1150000.0   2.0
# 5   Fort Lauderdale                FL             33304.0  1100000.0   3.0
# 6   Fort Lauderdale                FL             33304.0   900000.0   3.0
# 7     Pompano Beach                FL             33062.0   900000.0   3.0
# 8   Fort Lauderdale                FL             33316.0   889000.0   2.0
# 9   Fort Lauderdale                FL             33308.0   800000.0   2.0
#
#    BATHS                      LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5             OCEAN PALMS CONDO       3466.0       NaN      2005.0
# 1    3.5     LAS OLAS RIVER HOUSE COND       2726.0       NaN      2004.0
# 2    3.0          BEACH CLUB TWO CONDO       2065.0       NaN      2006.0
# 3    2.5                    Plaza East       2030.0       NaN      1967.0
# 4    2.5    Hillsboro Ocean Club Condo       2100.0       NaN      1984.0
# 5    4.5         Le Club International       2630.0       NaN      2002.0
# 6    3.5     LA TERRACE AT VICTORIA PA       2212.0       NaN      2005.0
# 7    3.0  Silver Thatch Atlantic Plaza       2465.0       NaN      1980.0
# 8    2.0                Dockside Lofts       1459.0       NaN      2005.0
# 9    2.0                    Plaza East       1450.0       NaN      1967.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          721.0     3621.0   Sold
# 1             NaN          807.0     3529.0   Sold
# 2             NaN          969.0     2188.0   Sold
# 3             NaN          662.0     2216.0   Sold
# 4             NaN          548.0     1500.0   Sold
# 5             NaN          418.0     3014.0   Sold
# 6             NaN          407.0      590.0   Sold
# 7             NaN          365.0     2499.0   Sold
# 8             NaN          609.0      650.0   Sold
# 9             NaN          552.0     1683.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...  Beaches MLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...       MARMLS
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...  Beaches MLS
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...  Beaches MLS
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    A11735368        N          Y  25.993834 -80.117821
# 1    A11729858        N          Y  26.118354 -80.141518
# 2    A11681350        N          Y  25.984911 -80.118344
# 3    F10482684        N          Y  26.181938 -80.096840
# 4  RX-10926283        N          Y  26.293859 -80.078549
# 5    F10446082        N          Y  26.136658 -80.107327
# 6    A11757633        N          Y  26.136230 -80.126510
# 7  RX-11074180        N          Y  26.240511 -80.088927
# 8    F10478653        N          Y  26.102908 -80.128525
# 9    F10477857        N          Y  26.181938 -80.096840
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hollywood/3101-S-Oce...          Joel Lusky
# 1  https://www.redfin.com/FL/Fort-Lauderdale/333-...         Bobbi Ocean
# 2  https://www.redfin.com/FL/Hallandale-Beach/183...    Mariana Martynov
# 3  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Marisa DiLenge
# 4  https://www.redfin.com/FL/Hillsboro-Beach/1155...        Robert Meyer
# 5  https://www.redfin.com/FL/Fort-Lauderdale/2845...        Gayle Borden
# 6  https://www.redfin.com/FL/Fort-Lauderdale/920-...  Michelle Mattingly
# 7  https://www.redfin.com/FL/Pompano-Beach/525-N-...     Colleen Newland
# 8  https://www.redfin.com/FL/Fort-Lauderdale/1490...     Robert Russotto
# 9  https://www.redfin.com/FL/Fort-Lauderdale/4300...      Ellen Taracido
#
#                               list_broker_name_1 list_agent_name_2  \
# 0  The Brokerage South Florida Real Estate, LLC.     Zalmy Shapira
# 1                  Galleria International Realty              None
# 2                                Golden Keys Inc              None
# 3                                     Realty 100   Michael DiLenge
# 4                Keller Williams Realty Services              None
# 5                         Coldwell Banker Realty     Jane Wheatley
# 6                               Oakstrand Realty              None
# 7                                Douglas Elliman              None
# 8                 Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9                           Compass Florida, LLC              None
#
#                               list_broker_name_2 buy_agent_name_1  \
# 0  The Brokerage South Florida Real Estate, LLC.    Eva Bouhadana
# 1                                           None     Jessie Stier
# 2                                           None   Monica Benitez
# 3                                     Realty 100    Ryan Hanrahan
# 4                                           None   Burton Wilkins
# 5                         Coldwell Banker Realty     Daniel Bozza
# 6                                           None             None
# 7                                           None   Non Non-Member
# 8                 Better Homes & Gdns RE Fla 1st  Robert Russotto
# 9                                           None   Rosa Levy-harf
#
#                 buy_broker_name_1  buy_agent_name_2  \
# 0           Beachfront Realty Inc              None
# 1            Compass Florida, LLC              None
# 2                Xcellence Realty              None
# 3     RE/MAX Consultants Realty 1              None
# 4  One Sotheby's International Re              None
# 5      Atlantic Realty Group, LLC              None
# 6                            None              None
# 7       Non-Member Selling Office              None
# 8  Better Homes & Gdns RE Fla 1st  Patricia Echarte
# 9      Level Realty Partners, LLC       Ilana Gross
#
#                 buy_broker_name_2  RANK   COLOR  \
# 0                            None     1  orange
# 1                            None     2    blue
# 2                            None     3    blue
# 3                            None     4    blue
# 4                            None     5    blue
# 5                            None     6    blue
# 6                            None     7    blue
# 7                            None     8    blue
# 8  Better Homes & Gdns RE Fla 1st     9    blue
# 9      Level Realty Partners, LLC    10    blue
#
#                                            FULL_NAME
# 0  OCEAN PALMS CONDO at 3101 S Ocean Dr #2703 in ...
# 1  LAS OLAS RIVER HOUSE COND at 333 Las Olas Way ...
# 2  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2202 ...
# 3  Plaza East at 4300 N Ocean Blvd Unit 5A in For...
# 4  Hillsboro Ocean Club Condo at 1155 Hillsboro M...
# 5  Le Club International at 2845 NE 9th St #804 i...
# 6  LA TERRACE AT VICTORIA PA at 920 NE 16th Ter #...
# 7  Silver Thatch Atlantic Plaza at 525 N Ocean Bl...
# 8  Dockside Lofts at 1490 SE 15th St #101 in Fort...
# 9  Plaza East at 4300 N Ocean Blvd Unit 14N in Fo...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 1, 21) ## List (Earlier) date
date2 = datetime(2025, 5, 28) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 127

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
# Coerce non-numeric to NaN, then you’ll have a float column
chart_df['$/SQUARE FEET'] = pd.to_numeric(chart_df['$/SQUARE FEET'], errors='coerce')

# %%
chart_df['SQUARE FEET'] = pd.to_numeric(chart_df['SQUARE FEET'], errors='coerce')

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    721.0
# 1    807.0
# 2    969.0
# 3    662.0
# 4    548.0
# 5    418.0
# 6    407.0
# 7    365.0
# 8    609.0
# 9    552.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                        ADDRESS       PRICE BEDS  \
# 0 2025-05-29             3101 S Ocean Dr #2703 in Hollywood  $2,500,000    4
# 1 2025-05-28      333 Las Olas Way #3302 in Fort Lauderdale  $2,200,000    3
# 2 2025-05-26      1830 S Ocean Dr #2202 in Hallandale Beach  $2,000,000    3
# 3 2025-05-29   4300 N Ocean Blvd Unit 5A in Fort Lauderdale  $1,343,500    3
# 4 2025-05-30    1155 Hillsboro Mile #307 in Hillsboro Beach  $1,150,000    2
# 5 2025-05-30         2845 NE 9th St #804 in Fort Lauderdale  $1,100,000    3
# 6 2025-05-30          920 NE 16th Ter #3 in Fort Lauderdale    $900,000    3
# 7 2025-05-30        525 N Ocean Blvd #1824 in Pompano Beach    $900,000    3
# 8 2025-05-28        1490 SE 15th St #101 in Fort Lauderdale    $889,000    2
# 9 2025-05-30  4300 N Ocean Blvd Unit 14N in Fort Lauderdale    $800,000    2
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3.5       3,466       2005          $721       MARMLS    A11735368
# 1    3.5       2,726       2004          $807       MARMLS    A11729858
# 2    3.0       2,065       2006          $969       MARMLS    A11681350
# 3    2.5       2,030       1967          $662  Beaches MLS    F10482684
# 4    2.5       2,100       1984          $548  Beaches MLS  RX-10926283
# 5    4.5       2,630       2002          $418  Beaches MLS    F10446082
# 6    3.5       2,212       2005          $407       MARMLS    A11757633
# 7    3.0       2,465       1980          $365  Beaches MLS  RX-11074180
# 8    2.0       1,459       2005          $609  Beaches MLS    F10478653
# 9    2.0       1,450       1967          $552  Beaches MLS    F10477857
#
#                                         LISTING INFO  \
# 0  Joel Lusky The Brokerage South Florida Real Es...
# 1      Bobbi Ocean Galleria International Realty
# 2               Mariana Martynov Golden Keys Inc
# 3  Marisa DiLenge Realty 100 Michael DiLenge Real...
# 4   Robert Meyer Keller Williams Realty Services
# 5  Gayle Borden Coldwell Banker Realty Jane Wheat...
# 6            Michelle Mattingly Oakstrand Realty
# 7                Colleen Newland Douglas Elliman
# 8  Robert Russotto Better Homes & Gdns RE Fla 1st...
# 9            Ellen Taracido Compass Florida, LLC
#
#                                          BUYING INFO
# 0            Eva Bouhadana Beachfront Realty Inc
# 1              Jessie Stier Compass Florida, LLC
# 2                Monica Benitez Xcellence Realty
# 3      Ryan Hanrahan RE/MAX Consultants Realty 1
# 4  Burton Wilkins One Sotheby's International Re
# 5        Daniel Bozza Atlantic Realty Group, LLC
# 6
# 7       Non Non-Member Non-Member Selling Office
# 8  Robert Russotto Better Homes & Gdns RE Fla 1st...
# 9  Rosa Levy-harf Level Realty Partners, LLC Ilan...
