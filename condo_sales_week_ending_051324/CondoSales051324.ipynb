# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 6th May. 13th

# %%
filename = glob.glob('redfin*.csv')
filename = filename[0]

# %%
df = pd.read_csv(filename)
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
new_row = {'SALE TYPE':'PAST SALE', 
           'SOLD DATE':'May-10-2024',
           'PROPERTY TYPE':'Condo/Co-op', 
           'ADDRESS':'2901 Collins Ave # 1205', 
           'CITY':'Miami Beach',
           'STATE OR PROVINCE':'FL', 
           'ZIP OR POSTAL CODE':'33140', 
           'PRICE':4995000,
           'BEDS':2, 
           'BATHS':2.5,
           'LOCATION':'The Edition', 
           'SQUARE FEET':1450, 
           'LOT SIZE':None,
           'YEAR BUILT':2014, 
           'DAYS ON MARKET':None,
           '$/SQUARE FEET':3445, 
           'HOA/MONTH':None, 
           'STATUS':'Sold', 
           'NEXT OPEN HOUSE START TIME':'NA',
           'NEXT OPEN HOUSE END TIME':'NA', 
           'URL':'https://www.redfin.com/FL/Miami-Beach/2901-Collins-Ave-33140/unit-1205/home/45457156', 
           'SOURCE':'Manual Entry', 
           'MLS#':'A11456329', 
           'FAVORITE':'NA',
           'INTERESTED':'NA', 
           'LATITUDE':25.805127277324562, 
           'LONGITUDE': -80.12411666847869}

# %%
# Convert the new row to a DataFrame
new_row_df = pd.DataFrame([new_row])

# Concatenate the new row to the original DataFrame
df = pd.concat([df, new_row_df], ignore_index=True)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_62435/3499859834.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row_df], ignore_index=True)

# %%
df
# Out:
#                                              SALE TYPE    SOLD DATE  \
# 0    In accordance with local MLS rules, some MLS l...          NaN
# 1                                            PAST SALE   May-6-2024
# 2                                            PAST SALE  May-10-2024
# 3                                            PAST SALE   May-8-2024
# 4                                            PAST SALE  May-10-2024
# ..                                                 ...          ...
# 161                                          PAST SALE   May-8-2024
# 162                                          PAST SALE   May-8-2024
# 163                                          PAST SALE  May-10-2024
# 164                                          PAST SALE   May-7-2024
# 165                                          PAST SALE  May-10-2024
#
#     PROPERTY TYPE                     ADDRESS          CITY STATE OR PROVINCE  \
# 0             NaN                         NaN           NaN               NaN
# 1     Condo/Co-op  8810 SW 123rd Ct Unit M207         Miami                FL
# 2     Condo/Co-op       600 Biltmore Way #512  Coral Gables                FL
# 3     Condo/Co-op         3590 Coral Way #510         Miami                FL
# 4     Condo/Co-op   950 Brickell Bay Dr #2002         Miami                FL
# ..            ...                         ...           ...               ...
# 161   Condo/Co-op          3845 W 9th Ave #37       Hialeah                FL
# 162   Condo/Co-op      424 NE 82nd St Unit 4C         Miami                FL
# 163   Condo/Co-op      7845 NE Bayshore Ct #9         Miami                FL
# 164   Condo/Co-op      720 NE 69th St Unit 5W         Miami                FL
# 165   Condo/Co-op     2901 Collins Ave # 1205   Miami Beach                FL
#
#     ZIP OR POSTAL CODE      PRICE  BEDS  BATHS                  LOCATION  \
# 0                  NaN        NaN   NaN    NaN                       NaN
# 1              33186.0   350000.0   2.0    2.0  KENLAND BEND NORTH CONDO
# 2              33134.0   590000.0   2.0    2.0         BILTMORE II CONDO
# 3              33145.0   515000.0   2.0    2.0     KEYSTONE VILLAS CONDO
# 4              33131.0   520000.0   1.0    1.0    THE PLAZA 851 BRICKELL
# ..                 ...        ...   ...    ...                       ...
# 161            33012.0   325000.0   2.0    1.5                MANGO HILL
# 162            33138.0   190000.0   2.0    1.0      COLONIAL PLAZA CONDO
# 163            33138.0   215000.0   1.0    1.0         TUDOR HOUSE CONDO
# 164            33138.0   465000.0   2.0    2.5     PALM BAY TOWERS CONDO
# 165              33140  4995000.0   2.0    2.5               The Edition
#
#      SQUARE FEET LOT SIZE  YEAR BUILT DAYS ON MARKET  $/SQUARE FEET  \
# 0            NaN      NaN         NaN            NaN            NaN
# 1         1200.0      NaN      1988.0            NaN          292.0
# 2         1129.0      NaN      1973.0            NaN          523.0
# 3         1023.0      NaN      2005.0            NaN          503.0
# 4          688.0      NaN      2008.0            NaN          756.0
# ..           ...      ...         ...            ...            ...
# 161       1208.0      NaN      1980.0            NaN          269.0
# 162        855.0      NaN      1945.0            NaN          222.0
# 163        631.0      NaN      1958.0            NaN          341.0
# 164       1763.0      NaN      1972.0            NaN          264.0
# 165       1450.0     None      2014.0           None         3445.0
#
#      HOA/MONTH STATUS NEXT OPEN HOUSE START TIME NEXT OPEN HOUSE END TIME  \
# 0          NaN    NaN                        NaN                      NaN
# 1        404.0   Sold                        NaN                      NaN
# 2       1286.0   Sold                        NaN                      NaN
# 3        614.0   Sold                        NaN                      NaN
# 4        662.0   Sold                        NaN                      NaN
# ..         ...    ...                        ...                      ...
# 161       85.0   Sold                        NaN                      NaN
# 162      393.0   Sold                        NaN                      NaN
# 163      590.0   Sold                        NaN                      NaN
# 164     3254.0   Sold                        NaN                      NaN
# 165        NaN   Sold                         NA                       NA
#
#                                                    URL        SOURCE  \
# 0                                                  NaN           NaN
# 1    https://www.redfin.com/FL/Miami/8810-SW-123rd-...        MARMLS
# 2    https://www.redfin.com/FL/Coral-Gables/600-Bil...        MARMLS
# 3    https://www.redfin.com/FL/Miami/3590-Coral-Way...        MARMLS
# 4    https://www.redfin.com/FL/Miami/950-Brickell-B...        MARMLS
# ..                                                 ...           ...
# 161  https://www.redfin.com/FL/Hialeah/3845-W-9th-A...        MARMLS
# 162  https://www.redfin.com/FL/Miami/424-NE-82nd-St...        MARMLS
# 163  https://www.redfin.com/FL/Miami/7845-NE-Baysho...        MARMLS
# 164  https://www.redfin.com/FL/Miami/720-NE-69th-St...        MARMLS
# 165  https://www.redfin.com/FL/Miami-Beach/2901-Col...  Manual Entry
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0          NaN      NaN        NaN        NaN        NaN
# 1    A11547071        N          Y  25.685338 -80.397613
# 2    A11570340        N          Y  25.747593 -80.267728
# 3    A11564495        N          Y  25.749431 -80.251885
# 4    A11514564        N          Y  25.764962 -80.190116
# ..         ...      ...        ...        ...        ...
# 161  A11441005        N          Y  25.856336 -80.301124
# 162  A11527843        N          Y  25.849638 -80.187223
# 163  A11551197        N          Y  25.847132 -80.173029
# 164  A11523775        N          Y  25.837195 -80.179769
# 165  A11456329       NA         NA  25.805127 -80.124117
#
# [166 rows x 27 columns]

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]
df = df.sort_values(by='PRICE',ascending=False)
df_top_ten = df.head(10)

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 165

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $850,114

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $560

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $140,268,882

# %% [markdown]
# ## Previous Week's Values

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 179
# Input Previous Week Condo Average Sales Price:
# 635738
# Input Previous Week Condo Average PSF:
# 529
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 114000000

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#     SALE TYPE   SOLD DATE PROPERTY TYPE                ADDRESS         CITY  \
# 54  PAST SALE  May-9-2024   Condo/Co-op  100 S Pointe Dr #2203  Miami Beach
#
#    STATE OR PROVINCE ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 54                FL            33139.0  17800000.0   3.0    3.5
#
#                     LOCATION  SQUARE FEET LOT SIZE  YEAR BUILT DAYS ON MARKET  \
# 54  CONTINUUM ON SOUTH BEACH       4776.0      NaN      2002.0            NaN
#
#     $/SQUARE FEET  HOA/MONTH STATUS NEXT OPEN HOUSE START TIME  \
# 54         3727.0     7051.0   Sold                        NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 54                      NaN
#
#                                                   URL  SOURCE       MLS#  \
# 54  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11551257
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 54        N          Y  25.767177 -80.132816     1  orange

# %%
def popup_html(row):
    building_name = row['LOCATION']
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_044ab3af9e0147a90bc88e80bccd9953 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 6th - May. 13th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_044ab3af9e0147a90bc88e80bccd9953&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_044ab3af9e0147a90bc88e80bccd9953 = L.map(
#                 &quot;map_044ab3af9e0147a90bc88e80bccd9953&quot;,
#                 {
#                     center: [25.80601157258985, -80.22047374344532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_21ff44a6e94778b8544d1a78dc6a38ef = L.featureGroup(
#                 {}
#             ).addTo(map_044ab3af9e0147a90bc88e80bccd9953);
#
#
#             var marker_562e3e8230b427f89b5332a127e735fa = L.marker(
#                 [25.767177, -80.1328155],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_21ff44a6e94778b8544d1a78dc6a38ef);
#
#
#             var icon_173b4fd10086bb3c26388ab7eebe26fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_562e3e8230b427f89b5332a127e735fa.setIcon(icon_173b4fd10086bb3c26388ab7eebe26fc);
#
#
#         var popup_b6f07f5091bb3de768a3fe60557d2451 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_bafc59711eb15f1feab781e7b466eecf = $(`&lt;div id=&quot;html_bafc59711eb15f1feab781e7b466eecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;CONTINUUM ON SOUTH BEACH&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$17,800,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3,727.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;4,776.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2002.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_b6f07f5091bb3de768a3fe60557d2451.setContent(html_bafc59711eb15f1feab781e7b466eecf);
#
#
#
#         marker_562e3e8230b427f89b5332a127e735fa.bindPopup(popup_b6f07f5091bb3de768a3fe60557d2451)
#         ;
#
#
#
#
#             var feature_group_2213d39ef18d1ad96e7e76bc8a7a9d08 = L.featureGroup(
#                 {}
#             ).addTo(map_044ab3af9e0147a90bc88e80bccd9953);
#
#
#             var marker_5da7d279945472b1f8cd95d6e333ed50 = L.marker(
#                 [25.7554036, -80.195048],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_2213d39ef18d1ad96e7e76bc8a7a9d08);
#
#
#             var icon_b84742e9887d11cd351ae313d01f59a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5da7d279945472b1f8cd95d6e333ed50.setIcon(icon_b84742e9887d11cd351ae313d01f59a6);
#
#
#         var popup_aa9d7e7af967c35cffa19030190fb7fa = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_ec87d8b92a598f9c78d3bb93b584994d = $(`&lt;div id=&quot;html_ec87d8b92a598f9c78d3bb93b584994d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;SANTA MARIA CONDO&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,700,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,169.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;5,730.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1997.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_aa9d7e7af967c35cffa19030190fb7fa.setContent(html_ec87d8b92a598f9c78d3bb93b584994d);
#
#
#
#         marker_5da7d279945472b1f8cd95d6e333ed50.bindPopup(popup_aa9d7e7af967c35cffa19030190fb7fa)
#         ;
#
#
#
#
#             var marker_1982d3a71a234b8d8c04541c37c622df = L.marker(
#                 [25.7899933, -80.1740861],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_2213d39ef18d1ad96e7e76bc8a7a9d08);
#
#
#             var icon_aef88d8d4bd6da36eb6dde8f5e8ead3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1982d3a71a234b8d8c04541c37c622df.setIcon(icon_aef88d8d4bd6da36eb6dde8f5e8ead3e);
#
#
#         var popup_dda0e142a9ad057362c28ab2b475372a = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_29f939ba3bc10427250f5366c2416fce = $(`&lt;div

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#     SALE TYPE   SOLD DATE PROPERTY TYPE                ADDRESS         CITY  \
# 54  PAST SALE  May-9-2024   Condo/Co-op  100 S Pointe Dr #2203  Miami Beach
#
#    STATE OR PROVINCE ZIP OR POSTAL CODE       PRICE  BEDS  BATHS  \
# 54                FL            33139.0  17800000.0   3.0    3.5
#
#                     LOCATION  SQUARE FEET LOT SIZE  YEAR BUILT DAYS ON MARKET  \
# 54  CONTINUUM ON SOUTH BEACH       4776.0      NaN      2002.0            NaN
#
#     $/SQUARE FEET  HOA/MONTH STATUS NEXT OPEN HOUSE START TIME  \
# 54         3727.0     7051.0   Sold                        NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 54                      NaN
#
#                                                   URL  SOURCE       MLS#  \
# 54  https://www.redfin.com/FL/Miami-Beach/100-S-Po...  MARMLS  A11551257
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK   COLOR
# 54        N          Y  25.767177 -80.132816     1  orange

# %%
# , {df_top_ten[df_top_ten['PRICE'].idxmax()]['ADDRESS']} | Price ${df_top_ten[df_top_ten['PRICE'].idxmax()]['PRICE']:,.0f}

# %%
df_top_ten['PRICE'].iloc[0]
# Out:
# 17800000.0

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_051324

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2203 in Miami Beach'

# %%
# previous_week_condo_sales_total = 130_000_000

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
# df_top_ten

# %% [markdown]
# ## RESUME HERE

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops Miami-Dade weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m Miami-Dade County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m Miami-Dade County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #MiamiDade condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, Miami-Dade County, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

Miami-Dade County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} sales average from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: CONTINUUM ON SOUTH BEACH closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,240,000M to $17,800,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, Miami Beach, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 165 condo sales totaling $140,268,882 million from May. 6th to May. 13th. The previous week, brokers closed 179 condo sales totaling $114,000,000.
#
# Last week’s units sold for an average of $850,114, higher than the $635,738 sales average from the previous week. The average price per square foot rose to $560 from $529, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,240,000.0 million to $17,800,000.0 million.
#
# CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2203 in Miami Beach took the top spot with a $17,800,000.0 million closing. The sale closed at $3,727.0 per square foot.
#
# SANTA MARIA CONDO at 1643 Brickell Ave #3902 in Miami, closed for the second highest amount, $6,700,000.0, or $1,169.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_051324" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 6th to May. 13th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf")

print(story_checklist)
# Out:
# HED: CONTINUUM ON SOUTH BEACH closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,240,000M to $17,800,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, Miami Beach, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 165 condo sales totaling $140,268,882 million from May. 6th to May. 13th. The previous week, brokers closed 179 condo sales totaling $114,000,000.
#
# Last week’s units sold for an average of $850,114, higher than the $635,738 sales average from the previous week. The average price per square foot rose to $560 from $529, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,240,000.0 million to $17,800,000.0 million.
#
# CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2203 in Miami Beach took the top spot with a $17,800,000.0 million closing. The sale closed at $3,727.0 per square foot.
#
# SANTA MARIA CONDO at 1643 Brickell Ave #3902 in Miami, closed for the second highest amount, $6,700,000.0, or $1,169.0 per square foot.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_051324" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 6th to May. 13th:
#
# Most Expensive
# CONTINUUM ON SOUTH BEACH, 100 S Pointe Dr #2203 in Miami Beach | Price: $17,800,000 | $3,727 psf
# Least Expensive
# SOUTH POINTE TOWERS CONDO, 400 S Pointe Dr #2104 in Miami Beach | Price: $2,240,000 | $1,243 psf
# Highest Price Per Square Foot
# CONTINUUM ON SOUTH BEACH, 100 S Pointe Dr #2203 in Miami Beach | Price: $17,800,000 | $3,727 psf
# Lowest Price Per Square Foot
# OCEAN ONE CONDO, 19333 Collins Ave Ph -6 in Sunny Isles Beach | Price: $2,600,000 | $996 psf
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
df_top_ten
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE   May-9-2024   Condo/Co-op           100 S Pointe Dr #2203
# 1  PAST SALE   May-9-2024   Condo/Co-op         1643 Brickell Ave #3902
# 2  PAST SALE   May-8-2024   Condo/Co-op       1000 Venetian Way Ph 2202
# 3  PAST SALE  May-10-2024   Condo/Co-op         2901 Collins Ave # 1205
# 4  PAST SALE  May-10-2024   Condo/Co-op         18555 Collins Ave #1005
# 5  PAST SALE   May-6-2024   Condo/Co-op      1331 Brickell Bay Dr #4011
# 6  PAST SALE   May-8-2024   Condo/Co-op  4701 N Meridian Ave Unit LPH16
# 7  PAST SALE  May-10-2024   Condo/Co-op           700 NE 26th Ter #5302
# 8  PAST SALE   May-7-2024   Condo/Co-op         19333 Collins Ave Ph -6
# 9  PAST SALE  May-10-2024   Condo/Co-op           400 S Pointe Dr #2104
#
#                 CITY STATE OR PROVINCE ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL            33139.0  17800000.0   3.0
# 1              Miami                FL            33129.0   6700000.0   4.0
# 2        Miami Beach                FL            33139.0   6000000.0   4.0
# 3        Miami Beach                FL              33140   4995000.0   2.0
# 4  Sunny Isles Beach                FL            33160.0   3710000.0   3.0
# 5              Miami                FL            33131.0   3665000.0   4.0
# 6        Miami Beach                FL            33140.0   3000000.0   2.0
# 7              Miami                FL            33137.0   2700000.0   2.0
# 8  Sunny Isles Beach                FL            33160.0   2600000.0   3.0
# 9        Miami Beach                FL            33139.0   2240000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET LOT SIZE  YEAR BUILT  \
# 0    3.5   CONTINUUM ON SOUTH BEACH       4776.0      NaN      2002.0
# 1    5.5          SANTA MARIA CONDO       5730.0      NaN      1997.0
# 2    4.5  ONE THOUSAND VENETIAN WAY       4252.0      NaN      1983.0
# 3    2.5                The Edition       1450.0     None      2014.0
# 4    4.5       Porsche Design Condo       3529.0      NaN      2016.0
# 5    4.5  JADE RESIDENCES AT BRICKE       3415.0      NaN      2004.0
# 6    2.5  4701 NORTH MERIDIAN CONDO       2020.0      NaN      2019.0
# 7    3.5               Missoni Baia       2464.0      NaN      2023.0
# 8    3.5            OCEAN ONE CONDO       2610.0      NaN      1999.0
# 9    3.0  SOUTH POINTE TOWERS CONDO       1802.0      NaN      1987.0
#
#   DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS NEXT OPEN HOUSE START TIME  \
# 0            NaN         3727.0     7051.0   Sold                        NaN
# 1            NaN         1169.0     6516.0   Sold                        NaN
# 2            NaN         1411.0     4829.0   Sold                        NaN
# 3           None         3445.0        NaN   Sold                         NA
# 4            NaN         1051.0     6957.0   Sold                        NaN
# 5            NaN         1073.0     4345.0   Sold                        NaN
# 6            NaN         1485.0     4092.0   Sold                        NaN
# 7            NaN         1096.0     3080.0   Sold                        NaN
# 8            NaN          996.0     2746.0   Sold                        NaN
# 9            NaN         1243.0     6056.0   Sold                        NaN
#
#   NEXT OPEN HOUSE END TIME                                                URL  \
# 0                      NaN  https://www.redfin.com/FL/Miami-Beach/100-S-Po...
# 1                      NaN  https://www.redfin.com/FL/Miami/1643-Brickell-...
# 2                      NaN  https://www.redfin.com/FL/Miami-Beach/1000-Ven...
# 3                       NA  https://www.redfin.com/FL/Miami-Beach/2901-Col...
# 4                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/18...
# 5                      NaN  https://www.redfin.com/FL/Miami/1331-Brickell-...
# 6                      NaN  https://www.redfin.com/FL/Miami-Beach/4701-Mer...
# 7                      NaN  https://www.redfin.com/FL/Miami/700-NE-26th-Te...
# 8                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/19...
# 9                      NaN  https://www.redfin.com/FL/Miami-Beach/400-S-Po...
#
#          SOURCE       MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK  \
# 0        MARMLS  A11551257        N          Y  25.767177 -80.132816     1
# 1        MARMLS  A11530099        N          Y  25.755404 -80.195048     2
# 2        MARMLS  A11514539        N          Y  25.789993 -80.174086     3
# 3  Manual Entry  A11456329       NA         NA  25.805127 -80.124117     4
# 4   Beaches MLS  F10427226        N          Y  25.948195 -80.120410     5
# 5        MARMLS  A11473986        N          Y  25.760000 -80.189163     6
# 6        MARMLS  A11530654        N          Y  25.822813 -80.130733     7
# 7        MARMLS  A11504430        N          Y  25.802198 -80.185790     8
# 8        MARMLS  A11511811        N          Y  25.955742 -80.119566     9
# 9        MARMLS  A11500974        N          Y  25.767827 -80.134241    10
#
#     COLOR                                          FULL_NAME
# 0  orange  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2...
# 1    blue  SANTA MARIA CONDO at 1643 Brickell Ave #3902 i...
# 2    blue  ONE THOUSAND VENETIAN WAY at 1000 Venetian Way...
# 3    blue  The Edition at 2901 Collins Ave # 1205 in Miam...
# 4    blue  Porsche Design Condo at 18555 Collins Ave #100...
# 5    blue  JADE RESIDENCES AT BRICKE at 1331 Brickell Bay...
# 6    blue  4701 NORTH MERIDIAN CONDO at 4701 N Meridian A...
# 7    blue     Missoni Baia at 700 NE 26th Ter #5302 in Miami
# 8    blue  OCEAN ONE CONDO at 19333 Collins Ave Ph -6 in ...
# 9    blue  SOUTH POINTE TOWERS CONDO at 400 S Pointe Dr #...

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Miami-Beach/100-S-Pointe-Dr-33139/unit-2203/home/43284562

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Miami-Beach/400-S-Pointe-Dr-33139/unit-2104/home/42804179

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/19333-Collins-Ave-33160/unit-06/home/184430182

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami-Beach/100-S-Pointe-Dr-33139/unit-2203/home/43284562

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/19333-Collins-Ave-33160/unit-06/home/184430182

# %%
df_top_ten
# Out:
#    SALE TYPE    SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 0  PAST SALE   May-9-2024   Condo/Co-op           100 S Pointe Dr #2203
# 1  PAST SALE   May-9-2024   Condo/Co-op         1643 Brickell Ave #3902
# 2  PAST SALE   May-8-2024   Condo/Co-op       1000 Venetian Way Ph 2202
# 3  PAST SALE  May-10-2024   Condo/Co-op         2901 Collins Ave # 1205
# 4  PAST SALE  May-10-2024   Condo/Co-op         18555 Collins Ave #1005
# 5  PAST SALE   May-6-2024   Condo/Co-op      1331 Brickell Bay Dr #4011
# 6  PAST SALE   May-8-2024   Condo/Co-op  4701 N Meridian Ave Unit LPH16
# 7  PAST SALE  May-10-2024   Condo/Co-op           700 NE 26th Ter #5302
# 8  PAST SALE   May-7-2024   Condo/Co-op         19333 Collins Ave Ph -6
# 9  PAST SALE  May-10-2024   Condo/Co-op           400 S Pointe Dr #2104
#
#                 CITY STATE OR PROVINCE ZIP OR POSTAL CODE       PRICE  BEDS  \
# 0        Miami Beach                FL            33139.0  17800000.0   3.0
# 1              Miami                FL            33129.0   6700000.0   4.0
# 2        Miami Beach                FL            33139.0   6000000.0   4.0
# 3        Miami Beach                FL              33140   4995000.0   2.0
# 4  Sunny Isles Beach                FL            33160.0   3710000.0   3.0
# 5              Miami                FL            33131.0   3665000.0   4.0
# 6        Miami Beach                FL            33140.0   3000000.0   2.0
# 7              Miami                FL            33137.0   2700000.0   2.0
# 8  Sunny Isles Beach                FL            33160.0   2600000.0   3.0
# 9        Miami Beach                FL            33139.0   2240000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET LOT SIZE  YEAR BUILT  \
# 0    3.5   CONTINUUM ON SOUTH BEACH       4776.0      NaN      2002.0
# 1    5.5          SANTA MARIA CONDO       5730.0      NaN      1997.0
# 2    4.5  ONE THOUSAND VENETIAN WAY       4252.0      NaN      1983.0
# 3    2.5                The Edition       1450.0     None      2014.0
# 4    4.5       Porsche Design Condo       3529.0      NaN      2016.0
# 5    4.5  JADE RESIDENCES AT BRICKE       3415.0      NaN      2004.0
# 6    2.5  4701 NORTH MERIDIAN CONDO       2020.0      NaN      2019.0
# 7    3.5               Missoni Baia       2464.0      NaN      2023.0
# 8    3.5            OCEAN ONE CONDO       2610.0      NaN      1999.0
# 9    3.0  SOUTH POINTE TOWERS CONDO       1802.0      NaN      1987.0
#
#   DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS NEXT OPEN HOUSE START TIME  \
# 0            NaN         3727.0     7051.0   Sold                        NaN
# 1            NaN         1169.0     6516.0   Sold                        NaN
# 2            NaN         1411.0     4829.0   Sold                        NaN
# 3           None         3445.0        NaN   Sold                         NA
# 4            NaN         1051.0     6957.0   Sold                        NaN
# 5            NaN         1073.0     4345.0   Sold                        NaN
# 6            NaN         1485.0     4092.0   Sold                        NaN
# 7            NaN         1096.0     3080.0   Sold                        NaN
# 8            NaN          996.0     2746.0   Sold                        NaN
# 9            NaN         1243.0     6056.0   Sold                        NaN
#
#   NEXT OPEN HOUSE END TIME                                                URL  \
# 0                      NaN  https://www.redfin.com/FL/Miami-Beach/100-S-Po...
# 1                      NaN  https://www.redfin.com/FL/Miami/1643-Brickell-...
# 2                      NaN  https://www.redfin.com/FL/Miami-Beach/1000-Ven...
# 3                       NA  https://www.redfin.com/FL/Miami-Beach/2901-Col...
# 4                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/18...
# 5                      NaN  https://www.redfin.com/FL/Miami/1331-Brickell-...
# 6                      NaN  https://www.redfin.com/FL/Miami-Beach/4701-Mer...
# 7                      NaN  https://www.redfin.com/FL/Miami/700-NE-26th-Te...
# 8                      NaN  https://www.redfin.com/FL/Sunny-Isles-Beach/19...
# 9                      NaN  https://www.redfin.com/FL/Miami-Beach/400-S-Po...
#
#          SOURCE       MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  RANK  \
# 0        MARMLS  A11551257        N          Y  25.767177 -80.132816     1
# 1        MARMLS  A11530099        N          Y  25.755404 -80.195048     2
# 2        MARMLS  A11514539        N          Y  25.789993 -80.174086     3
# 3  Manual Entry  A11456329       NA         NA  25.805127 -80.124117     4
# 4   Beaches MLS  F10427226        N          Y  25.948195 -80.120410     5
# 5        MARMLS  A11473986        N          Y  25.760000 -80.189163     6
# 6        MARMLS  A11530654        N          Y  25.822813 -80.130733     7
# 7        MARMLS  A11504430        N          Y  25.802198 -80.185790     8
# 8        MARMLS  A11511811        N          Y  25.955742 -80.119566     9
# 9        MARMLS  A11500974        N          Y  25.767827 -80.134241    10
#
#     COLOR                                          FULL_NAME
# 0  orange  CONTINUUM ON SOUTH BEACH at 100 S Pointe Dr #2...
# 1    blue  SANTA MARIA CONDO at 1643 Brickell Ave #3902 i...
# 2    blue  ONE THOUSAND VENETIAN WAY at 1000 Venetian Way...
# 3    blue  The Edition at 2901 Collins Ave # 1205 in Miam...
# 4    blue  Porsche Design Condo at 18555 Collins Ave #100...
# 5    blue  JADE RESIDENCES AT BRICKE at 1331 Brickell Bay...
# 6    blue  4701 NORTH MERIDIAN CONDO at 4701 N Meridian A...
# 7    blue     Missoni Baia at 700 NE 26th Ter #5302 in Miami
# 8    blue  OCEAN ONE CONDO at 19333 Collins Ave Ph -6 in ...
# 9    blue  SOUTH POINTE TOWERS CONDO at 400 S Pointe Dr #...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2023, 8, 22) ## List (Earlier) date
date2 = datetime(2024, 5, 1) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 253
