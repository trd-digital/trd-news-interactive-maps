# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# May. 4th May. 11th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE   SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 1  PAST SALE  May-9-2025   Condo/Co-op  10662 Ocean Palm Way #101
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 1  Boynton Beach                FL             33437.0  269000.0   3.0    2.0
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Boynton-Beach/10662-...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11069132         N          Y  26.518344 -80.128832
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Palm Beach

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-05-09    27
# 2025-05-05    22
# 2025-05-08    16
# 2025-05-07    16
# 2025-05-06    16
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 97  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 54  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 64  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 6   PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 3   PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 30  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 51  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 60  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 61  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 62  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 97          Palm Beach                FL             33480.0  6000000.0   3.0
# 54            Tequesta                FL             33469.0  4100000.0   3.0
# 64  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 6           Boca Raton                FL             33432.0  3211000.0   2.0
# 3           Boca Raton                FL             33432.0  2900000.0   2.0
# 30          Palm Beach                FL             33480.0  2500000.0   2.0
# 51             Jupiter                FL             33477.0  2350000.0   3.0
# 60    North Palm Beach                FL             33408.0  2200000.0   3.0
# 61    North Palm Beach                FL             33408.0  2200000.0   3.0
# 62    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#     BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 97    3.5  ...   Sold                         NaN                       NaN
# 54    3.5  ...   Sold                         NaN                       NaN
# 64    3.5  ...   Sold                         NaN                       NaN
# 6     3.0  ...   Sold                         NaN                       NaN
# 3     2.5  ...   Sold                         NaN                       NaN
# 30    2.0  ...   Sold                         NaN                       NaN
# 51    2.0  ...   Sold                         NaN                       NaN
# 60    2.0  ...   Sold                         NaN                       NaN
# 61    2.0  ...   Sold                         NaN                       NaN
# 62    2.0  ...   Sold                         NaN                       NaN
#
#                                                   URL       SOURCE  \
# 97  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
# 54  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...  Beaches MLS
# 64  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 6   https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 3   https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 30  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 51  https://www.redfin.com/FL/Jupiter/604-Captains...  Beaches MLS
# 60  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 61  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 62  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
#
#            MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 97  RX-10879239         N          Y  26.717140 -80.034673
# 54  RX-11056254         N          Y  26.955362 -80.077420
# 64  RX-11049233         N          Y  26.880648 -80.071850
# 6   RX-11089230         N          Y  26.347042 -80.083200
# 3   RX-11089244         N          Y  26.347042 -80.083200
# 30  RX-11071642         N          Y  26.715065 -80.042094
# 51  RX-11049155         N          Y  26.909631 -80.085249
# 60  RX-11048862         N          Y  26.876802 -80.065047
# 61  RX-11048869         N          Y  26.876802 -80.065047
# 62  RX-11048850         N          Y  26.876802 -80.065047
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 1  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 2  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 3  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 4  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 5  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 6  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 7  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 8  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 9  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  6000000.0   3.0
# 1            Tequesta                FL             33469.0  4100000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 3          Boca Raton                FL             33432.0  3211000.0   2.0
# 4          Boca Raton                FL             33432.0  2900000.0   2.0
# 5          Palm Beach                FL             33480.0  2500000.0   2.0
# 6             Jupiter                FL             33477.0  2350000.0   3.0
# 7    North Palm Beach                FL             33408.0  2200000.0   3.0
# 8    North Palm Beach                FL             33408.0  2200000.0   3.0
# 9    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    3.5  ... -80.034673  https://www.redfin.com/FL/Palm-Beach/2-N-Break...
# 1    3.5  ... -80.077420  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...
# 2    3.5  ... -80.071850  https://www.redfin.com/FL/Palm-Beach-Gardens/2...
# 3    3.0  ... -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 4    2.5  ... -80.083200  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...
# 5    2.0  ... -80.042094  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...
# 6    2.0  ... -80.085249  https://www.redfin.com/FL/Jupiter/604-Captains...
# 7    2.0  ... -80.065047  https://www.redfin.com/FL/North-Palm-Beach/136...
# 8    2.0  ... -80.065047  https://www.redfin.com/FL/North-Palm-Beach/136...
# 9    2.0  ... -80.065047  https://www.redfin.com/FL/North-Palm-Beach/136...
#
#      list_agent_name_1             list_broker_name_1   list_agent_name_2  \
# 0         Laura Semler     Brown Harris Stevens of PB                None
# 1         John Holland  Holland Group Real Estate LLC      Emily Sullivan
# 2         Bradley Ball        Frankel Ball Realty LLC        Shannon Ball
# 3  Rochelle LeCavalier                Douglas Elliman  Kathy Koch Pitlake
# 4  Rochelle LeCavalier                Douglas Elliman  Kathy Koch Pitlake
# 5       Mark Whitehead    Coffee Cake And Real Estate         Brie Segota
# 6      Stephen Rockoff             The Corcoran Group                None
# 7        James Edwards   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 8        James Edwards   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 9        James Edwards   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
#
#               list_broker_name_2     buy_agent_name_1  \
# 0                           None      Christian Angle
# 1  Holland Group Real Estate LLC        Traci Chivers
# 2        Frankel Ball Realty LLC        Ken Meierling
# 3                Douglas Elliman        Pamela Levine
# 4                Douglas Elliman  Rochelle LeCavalier
# 5    Coffee Cake And Real Estate            Non Agent
# 6                           None       Crystal Condit
# 7   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 8   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 9   Sotheby's Intl. Realty, Inc.        Patrick Kelly
#
#                 buy_broker_name_1  buy_agent_name_2       buy_broker_name_2
# 0     Christian Angle Real Estate              None                    None
# 1  Premier Properties of South Fl              None                    None
# 2     Engel & Voelkers Jupiter RE              None                    None
# 3          Luxury Partners Realty       Jeff Levine  Luxury Partners Realty
# 4                 Douglas Elliman              None                    None
# 5       Non-Member Selling Office              None                    None
# 6  Waterfront Properties & Club C              None                    None
# 7  Coastal Realty Group Sales & M              None                    None
# 8  Coastal Realty Group Sales & M              None                    None
# 9  Coastal Realty Group Sales & M              None                    None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 97

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $717,106

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $391

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $69,559,250

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           97              717106          391                     69559250.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 194
# -----------
# Input Previous Week Condo Average Sales Price:
# 494991
# -----------
# Input Previous Week Condo Average PSF:
# 333
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 96028333.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS        CITY  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33480.0  6000000.0   3.0    3.5
#
#                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Two North Breakers Row Condo       3243.0       NaN      1986.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1850.0    13078.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.71714 -80.034673
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...      Laura Semler
#
#            list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Brown Harris Stevens of PB              None               None
#
#   buy_agent_name_1            buy_broker_name_1 buy_agent_name_2  \
# 0  Christian Angle  Christian Angle Real Estate             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 1  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 2  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 3  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 4  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 5  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 6  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 7  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 8  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 9  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  6000000.0   3.0
# 1            Tequesta                FL             33469.0  4100000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 3          Boca Raton                FL             33432.0  3211000.0   2.0
# 4          Boca Raton                FL             33432.0  2900000.0   2.0
# 5          Palm Beach                FL             33480.0  2500000.0   2.0
# 6             Jupiter                FL             33477.0  2350000.0   3.0
# 7    North Palm Beach                FL             33408.0  2200000.0   3.0
# 8    North Palm Beach                FL             33408.0  2200000.0   3.0
# 9    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#    BATHS                                   LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Two North Breakers Row Condo       3243.0       NaN
# 1    3.5                    Cliveden Jupiter Island       2750.0       NaN
# 2    3.5                                      Azure       3466.0       NaN
# 3    3.0                           Alina Residences       2683.0     180.0
# 4    2.5                           Alina Residences       2429.0     180.0
# 5    2.0                          Palm Beach Towers       1621.0       NaN
# 6    2.0                              Admirals Cove       2160.0       NaN
# 7    2.0  Carriage Homes AT Frenchmans Harbor Condo       2493.0       NaN
# 8    2.0  Carriage Homes AT Frenchmans Harbor Condo       2367.0       NaN
# 9    2.0  Carriage Homes AT Frenchmans Harbor Condo       1920.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1986.0             NaN         1850.0    13078.0   Sold
# 1      1996.0             NaN         1491.0     2378.0   Sold
# 2      2016.0             NaN         1125.0     3635.0   Sold
# 3      2024.0             NaN         1197.0     2291.0   Sold
# 4      2024.0             NaN         1194.0     2050.0   Sold
# 5      1956.0             NaN         1542.0     2193.0   Sold
# 6      1988.0             NaN         1088.0     2357.0   Sold
# 7      2012.0             NaN          882.0     2397.0   Sold
# 8      2012.0             NaN          929.0     2397.0   Sold
# 9      2012.0             NaN         1146.0     2200.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.717140 -80.034673
# 1  RX-11056254        N          Y  26.955362 -80.077420
# 2  RX-11049233        N          Y  26.880648 -80.071850
# 3  RX-11089230        N          Y  26.347042 -80.083200
# 4  RX-11089244        N          Y  26.347042 -80.083200
# 5  RX-11071642        N          Y  26.715065 -80.042094
# 6  RX-11049155        N          Y  26.909631 -80.085249
# 7  RX-11048862        N          Y  26.876802 -80.065047
# 8  RX-11048869        N          Y  26.876802 -80.065047
# 9  RX-11048850        N          Y  26.876802 -80.065047
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...         Laura Semler
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...         John Holland
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...         Bradley Ball
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Mark Whitehead
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...      Stephen Rockoff
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
#
#               list_broker_name_1   list_agent_name_2  \
# 0     Brown Harris Stevens of PB                None
# 1  Holland Group Real Estate LLC      Emily Sullivan
# 2        Frankel Ball Realty LLC        Shannon Ball
# 3                Douglas Elliman  Kathy Koch Pitlake
# 4                Douglas Elliman  Kathy Koch Pitlake
# 5    Coffee Cake And Real Estate         Brie Segota
# 6             The Corcoran Group                None
# 7   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 8   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 9   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
#
#               list_broker_name_2     buy_agent_name_1  \
# 0                           None      Christian Angle
# 1  Holland Group Real Estate LLC        Traci Chivers
# 2        Frankel Ball Realty LLC        Ken Meierling
# 3                Douglas Elliman        Pamela Levine
# 4                Douglas Elliman  Rochelle LeCavalier
# 5    Coffee Cake And Real Estate            Non Agent
# 6                           None       Crystal Condit
# 7   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 8   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 9   Sotheby's Intl. Realty, Inc.        Patrick Kelly
#
#                 buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0     Christian Angle Real Estate             None                    None
# 1  Premier Properties of South Fl             None                    None
# 2     Engel & Voelkers Jupiter RE             None                    None
# 3          Luxury Partners Realty      Jeff Levine  Luxury Partners Realty
# 4                 Douglas Elliman             None                    None
# 5       Non-Member Selling Office             None                    None
# 6  Waterfront Properties & Club C             None                    None
# 7  Coastal Realty Group Sales & M             None                    None
# 8  Coastal Realty Group Sales & M             None                    None
# 9  Coastal Realty Group Sales & M             None                    None
#
#    RANK   COLOR
# 0     1  orange
# 1     2    blue
# 2     3    blue
# 3     4    blue
# 4     5    blue
# 5     6    blue
# 6     7    blue
# 7     8    blue
# 8     9    blue
# 9    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_685ed57391b6c991ee0399f0f4c95e9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Palm Beach County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May. 4th — May. 11th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_685ed57391b6c991ee0399f0f4c95e9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_685ed57391b6c991ee0399f0f4c95e9c = L.map(
#                 &quot;map_685ed57391b6c991ee0399f0f4c95e9c&quot;,
#                 {
#                     center: [26.563266888659797, -80.10674757010311],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_749d9f01a2f9cb402b33021290a7dc8f = L.featureGroup(
#                 {}
#             ).addTo(map_685ed57391b6c991ee0399f0f4c95e9c);
#
#
#             var marker_7460549fbe5b3291f01d41198b8e84b3 = L.marker(
#                 [26.7171396, -80.0346735],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_749d9f01a2f9cb402b33021290a7dc8f);
#
#
#             var icon_533b771f3c8594fa56f25955e79cf13f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7460549fbe5b3291f01d41198b8e84b3.setIcon(icon_533b771f3c8594fa56f25955e79cf13f);
#
#
#         var popup_9b4ea7d19e3e4a80a837ea8b0f29b8c7 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_34a83d79ceb6076f4b3262ee9a4210ae = $(`&lt;div id=&quot;html_34a83d79ceb6076f4b3262ee9a4210ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2 N Breakers Row Unit S-T1&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,000,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,850.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,243.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1986.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_9b4ea7d19e3e4a80a837ea8b0f29b8c7.setContent(html_34a83d79ceb6076f4b3262ee9a4210ae);
#
#
#
#         marker_7460549fbe5b3291f01d41198b8e84b3.bindPopup(popup_9b4ea7d19e3e4a80a837ea8b0f29b8c7)
#         ;
#
#
#
#
#             var feature_group_5ca53c8ace74bd989499af876b3291d2 = L.featureGroup(
#                 {}
#             ).addTo(map_685ed57391b6c991ee0399f0f4c95e9c);
#
#
#             var marker_bf5503ed1ef68e3c81edd254a3ad8a97 = L.marker(
#                 [26.9553616, -80.0774202],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_5ca53c8ace74bd989499af876b3291d2);
#
#
#             var icon_ec3202faedeff52d20d186bfe94814d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf5503ed1ef68e3c81edd254a3ad8a97.setIcon(icon_ec3202faedeff52d20d186bfe94814d5);
#
#
#         var popup_859ac8e84010a3ae63d3becfb6364b71 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6088fc0f4f978c95d7799035fa43fd9b = $(`&lt;div id=&quot;html_6088fc0f4f978c95d7799035fa43fd9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;425 Beach Rd Ph -O&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,100,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,491.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,750.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;1996.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_859ac8e84010a3ae63d3becfb6364b71.setContent(html_6088fc0f4f978c95d7799035fa43fd9b);
#
#
#
#         marker_bf5503ed1ef68e3c81edd254a3ad8a97.bindPopup(popup_859ac8e84010a3ae63d3becfb6364b71)
#         ;
#
#
#
#
#             var marker_f6f558341e229a16f6a0f225ea10d6ac = L.marker(
#                 [26.880648, -80.0718505],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_5ca53c8ace74bd989499af876b3291d2);
#
#
#             var icon_a6f8211c65f2b4ff062ffdfefa4b6de9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f6f558341e229a16f6a0f225ea10d6ac.setIcon(icon_a6f8211c65f2b4ff062ffdfefa4b6de9);
#
#
#         var popup_2073014fe1de3132e4ff0eb30a8c3a9e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_943058eb8404464df50e8f65c94e5243 =

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS        CITY  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1  Palm Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33480.0  6000000.0   3.0    3.5
#
#                        LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  Two North Breakers Row Condo       3243.0       NaN      1986.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         1850.0    13078.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED  LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.71714 -80.034673
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...      Laura Semler
#
#            list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0  Brown Harris Stevens of PB              None               None
#
#   buy_agent_name_1            buy_broker_name_1 buy_agent_name_2  \
# 0  Christian Angle  Christian Angle Real Estate             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05122025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Two North Breakers Row Condo at 2 N Breakers Row Unit S-T1 in Palm Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 1  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 2  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 3  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 4  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 5  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 6  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 7  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 8  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 9  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  6000000.0   3.0
# 1            Tequesta                FL             33469.0  4100000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 3          Boca Raton                FL             33432.0  3211000.0   2.0
# 4          Boca Raton                FL             33432.0  2900000.0   2.0
# 5          Palm Beach                FL             33480.0  2500000.0   2.0
# 6             Jupiter                FL             33477.0  2350000.0   3.0
# 7    North Palm Beach                FL             33408.0  2200000.0   3.0
# 8    North Palm Beach                FL             33408.0  2200000.0   3.0
# 9    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#    BATHS                                   LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Two North Breakers Row Condo       3243.0       NaN
# 1    3.5                    Cliveden Jupiter Island       2750.0       NaN
# 2    3.5                                      Azure       3466.0       NaN
# 3    3.0                           Alina Residences       2683.0     180.0
# 4    2.5                           Alina Residences       2429.0     180.0
# 5    2.0                          Palm Beach Towers       1621.0       NaN
# 6    2.0                              Admirals Cove       2160.0       NaN
# 7    2.0  Carriage Homes AT Frenchmans Harbor Condo       2493.0       NaN
# 8    2.0  Carriage Homes AT Frenchmans Harbor Condo       2367.0       NaN
# 9    2.0  Carriage Homes AT Frenchmans Harbor Condo       1920.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1986.0             NaN         1850.0    13078.0   Sold
# 1      1996.0             NaN         1491.0     2378.0   Sold
# 2      2016.0             NaN         1125.0     3635.0   Sold
# 3      2024.0             NaN         1197.0     2291.0   Sold
# 4      2024.0             NaN         1194.0     2050.0   Sold
# 5      1956.0             NaN         1542.0     2193.0   Sold
# 6      1988.0             NaN         1088.0     2357.0   Sold
# 7      2012.0             NaN          882.0     2397.0   Sold
# 8      2012.0             NaN          929.0     2397.0   Sold
# 9      2012.0             NaN         1146.0     2200.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.717140 -80.034673
# 1  RX-11056254        N          Y  26.955362 -80.077420
# 2  RX-11049233        N          Y  26.880648 -80.071850
# 3  RX-11089230        N          Y  26.347042 -80.083200
# 4  RX-11089244        N          Y  26.347042 -80.083200
# 5  RX-11071642        N          Y  26.715065 -80.042094
# 6  RX-11049155        N          Y  26.909631 -80.085249
# 7  RX-11048862        N          Y  26.876802 -80.065047
# 8  RX-11048869        N          Y  26.876802 -80.065047
# 9  RX-11048850        N          Y  26.876802 -80.065047
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...         Laura Semler
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...         John Holland
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...         Bradley Ball
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Mark Whitehead
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...      Stephen Rockoff
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
#
#               list_broker_name_1   list_agent_name_2  \
# 0     Brown Harris Stevens of PB                None
# 1  Holland Group Real Estate LLC      Emily Sullivan
# 2        Frankel Ball Realty LLC        Shannon Ball
# 3                Douglas Elliman  Kathy Koch Pitlake
# 4                Douglas Elliman  Kathy Koch Pitlake
# 5    Coffee Cake And Real Estate         Brie Segota
# 6             The Corcoran Group                None
# 7   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 8   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 9   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
#
#               list_broker_name_2     buy_agent_name_1  \
# 0                           None      Christian Angle
# 1  Holland Group Real Estate LLC        Traci Chivers
# 2        Frankel Ball Realty LLC        Ken Meierling
# 3                Douglas Elliman        Pamela Levine
# 4                Douglas Elliman  Rochelle LeCavalier
# 5    Coffee Cake And Real Estate            Non Agent
# 6                           None       Crystal Condit
# 7   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 8   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 9   Sotheby's Intl. Realty, Inc.        Patrick Kelly
#
#                 buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0     Christian Angle Real Estate             None                    None
# 1  Premier Properties of South Fl             None                    None
# 2     Engel & Voelkers Jupiter RE             None                    None
# 3          Luxury Partners Realty      Jeff Levine  Luxury Partners Realty
# 4                 Douglas Elliman             None                    None
# 5       Non-Member Selling Office             None                    None
# 6  Waterfront Properties & Club C             None                    None
# 7  Coastal Realty Group Sales & M             None                    None
# 8  Coastal Realty Group Sales & M             None                    None
# 9  Coastal Realty Group Sales & M             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Two North Breakers Row Condo at 2 N Breakers R...
# 1     2    blue  Cliveden Jupiter Island at 425 Beach Rd Ph -O ...
# 2     3    blue  Azure at 2700 Donald Ross Rd #412 in Palm Beac...
# 3     4    blue  Alina Residences at 220 SE Mizner Blvd #215 in...
# 4     5    blue  Alina Residences at 220 SE Mizner Blvd #217 in...
# 5     6    blue  Palm Beach Towers at 44 Cocoanut Row Unit 321a...
# 6     7    blue       Admirals Cove at 604 Captains Way in Jupiter
# 7     8    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 8     9    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 9    10    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: Two North Breakers Row Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $2,200,000 to $6,000,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, North Palm Beach, Boca Raton, Tequesta, Jupiter, Palm Beach Gardens, Palm Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 97 condo sales totaling $69,559,250 million from May. 4th to May. 11th. The previous week, brokers closed 194 condo sales totaling $96,028,333.
#
# Last week’s units sold for an average of $717,106, higher than the $494,991 average price from the previous week. The average price per square foot rose to $391 from $333, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,200,000.0 million to $6,000,000.0 million.
#
# Two North Breakers Row Condo at 2 N Breakers Row Unit S-T1 in Palm Beach took the top spot with a $6,000,000.0 million closing. The sale closed at $1,850.0 per square foot.
#
# Laura Semler with Brown Harris Stevens of PB, and None with None had the listing.
# Christian Angle with Christian Angle Real Estate, and None with None represented the buyer.
#
# Cliveden Jupiter Island at 425 Beach Rd Ph -O in Tequesta, closed for the second highest amount, $4,100,000.0, or $1,491.0 per square foot.
#
# John Holland with Holland Group Real Estate LLC, and Emily Sullivan with Holland Group Real Estate LLC had the listing.
# Traci Chivers with Premier Properties of South Fl, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05122025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 4th to May. 11th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 1  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 2  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 3  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 4  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 5  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 6  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 7  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 8  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 9  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  6000000.0   3.0
# 1            Tequesta                FL             33469.0  4100000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 3          Boca Raton                FL             33432.0  3211000.0   2.0
# 4          Boca Raton                FL             33432.0  2900000.0   2.0
# 5          Palm Beach                FL             33480.0  2500000.0   2.0
# 6             Jupiter                FL             33477.0  2350000.0   3.0
# 7    North Palm Beach                FL             33408.0  2200000.0   3.0
# 8    North Palm Beach                FL             33408.0  2200000.0   3.0
# 9    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#    BATHS                                   LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Two North Breakers Row Condo       3243.0       NaN
# 1    3.5                    Cliveden Jupiter Island       2750.0       NaN
# 2    3.5                                      Azure       3466.0       NaN
# 3    3.0                           Alina Residences       2683.0     180.0
# 4    2.5                           Alina Residences       2429.0     180.0
# 5    2.0                          Palm Beach Towers       1621.0       NaN
# 6    2.0                              Admirals Cove       2160.0       NaN
# 7    2.0  Carriage Homes AT Frenchmans Harbor Condo       2493.0       NaN
# 8    2.0  Carriage Homes AT Frenchmans Harbor Condo       2367.0       NaN
# 9    2.0  Carriage Homes AT Frenchmans Harbor Condo       1920.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1986.0             NaN         1850.0    13078.0   Sold
# 1      1996.0             NaN         1491.0     2378.0   Sold
# 2      2016.0             NaN         1125.0     3635.0   Sold
# 3      2024.0             NaN         1197.0     2291.0   Sold
# 4      2024.0             NaN         1194.0     2050.0   Sold
# 5      1956.0             NaN         1542.0     2193.0   Sold
# 6      1988.0             NaN         1088.0     2357.0   Sold
# 7      2012.0             NaN          882.0     2397.0   Sold
# 8      2012.0             NaN          929.0     2397.0   Sold
# 9      2012.0             NaN         1146.0     2200.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.717140 -80.034673
# 1  RX-11056254        N          Y  26.955362 -80.077420
# 2  RX-11049233        N          Y  26.880648 -80.071850
# 3  RX-11089230        N          Y  26.347042 -80.083200
# 4  RX-11089244        N          Y  26.347042 -80.083200
# 5  RX-11071642        N          Y  26.715065 -80.042094
# 6  RX-11049155        N          Y  26.909631 -80.085249
# 7  RX-11048862        N          Y  26.876802 -80.065047
# 8  RX-11048869        N          Y  26.876802 -80.065047
# 9  RX-11048850        N          Y  26.876802 -80.065047
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...         Laura Semler
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...         John Holland
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...         Bradley Ball
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Mark Whitehead
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...      Stephen Rockoff
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
#
#               list_broker_name_1   list_agent_name_2  \
# 0     Brown Harris Stevens of PB                None
# 1  Holland Group Real Estate LLC      Emily Sullivan
# 2        Frankel Ball Realty LLC        Shannon Ball
# 3                Douglas Elliman  Kathy Koch Pitlake
# 4                Douglas Elliman  Kathy Koch Pitlake
# 5    Coffee Cake And Real Estate         Brie Segota
# 6             The Corcoran Group                None
# 7   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 8   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 9   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
#
#               list_broker_name_2     buy_agent_name_1  \
# 0                           None      Christian Angle
# 1  Holland Group Real Estate LLC        Traci Chivers
# 2        Frankel Ball Realty LLC        Ken Meierling
# 3                Douglas Elliman        Pamela Levine
# 4                Douglas Elliman  Rochelle LeCavalier
# 5    Coffee Cake And Real Estate            Non Agent
# 6                           None       Crystal Condit
# 7   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 8   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 9   Sotheby's Intl. Realty, Inc.        Patrick Kelly
#
#                 buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0     Christian Angle Real Estate             None                    None
# 1  Premier Properties of South Fl             None                    None
# 2     Engel & Voelkers Jupiter RE             None                    None
# 3          Luxury Partners Realty      Jeff Levine  Luxury Partners Realty
# 4                 Douglas Elliman             None                    None
# 5       Non-Member Selling Office             None                    None
# 6  Waterfront Properties & Club C             None                    None
# 7  Coastal Realty Group Sales & M             None                    None
# 8  Coastal Realty Group Sales & M             None                    None
# 9  Coastal Realty Group Sales & M             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Two North Breakers Row Condo at 2 N Breakers R...
# 1     2    blue  Cliveden Jupiter Island at 425 Beach Rd Ph -O ...
# 2     3    blue  Azure at 2700 Donald Ross Rd #412 in Palm Beac...
# 3     4    blue  Alina Residences at 220 SE Mizner Blvd #215 in...
# 4     5    blue  Alina Residences at 220 SE Mizner Blvd #217 in...
# 5     6    blue  Palm Beach Towers at 44 Cocoanut Row Unit 321a...
# 6     7    blue       Admirals Cove at 604 Captains Way in Jupiter
# 7     8    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 8     9    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 9    10    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: Two North Breakers Row Condo closing tops Palm Beach weekly condo sales
# DEK: Top 10 sales ranged from $2,200,000 to $6,000,000
# FEATURED HED:
# SEO HED: Palm Beach County Weekly Condo Report
# SEO DESCRIPTION: Palm Beach County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Palm Beach condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Palm Beach, weekly condo sales, North Palm Beach, Boca Raton, Tequesta, Jupiter, Palm Beach Gardens, Palm Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Palm Beach County’s NEWS PEG HERE.
#
# Brokers closed 97 condo sales totaling $69,559,250 million from May. 4th to May. 11th. The previous week, brokers closed 194 condo sales totaling $96,028,333.
#
# Last week’s units sold for an average of $717,106, higher than the $494,991 average price from the previous week. The average price per square foot rose to $391 from $333, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,200,000.0 million to $6,000,000.0 million.
#
# Two North Breakers Row Condo at 2 N Breakers Row Unit S-T1 in Palm Beach took the top spot with a $6,000,000.0 million closing. The sale closed at $1,850.0 per square foot.
#
# Laura Semler with Brown Harris Stevens of PB, and None with None had the listing.
# Christian Angle with Christian Angle Real Estate, and None with None represented the buyer.
#
# Cliveden Jupiter Island at 425 Beach Rd Ph -O in Tequesta, closed for the second highest amount, $4,100,000.0, or $1,491.0 per square foot.
#
# John Holland with Holland Group Real Estate LLC, and Emily Sullivan with Holland Group Real Estate LLC had the listing.
# Traci Chivers with Premier Properties of South Fl, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/PalmBeach_County_condo_sales_week_ending_05122025" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from May. 4th to May. 11th:
#
# Most Expensive
# Two North Breakers Row Condo, 2 N Breakers Row Unit S-T1, in Palm Beach | Price: $6,000,000 | $1,850 psf | Listing agents: Laura Semler with Brown Harris Stevens of PB and None with None | Buyer's agents: Christian Angle with Christian Angle Real Estate and None with None
#
# Least Expensive
# Carriage Homes AT Frenchmans Harbor Condo, 13633 Treasure Cove Cir, in North Palm Beach | Price: $2,200,000 | $882 psf | Listing agents: James Edwards with Sotheby's Intl. Realty, Inc. and Patricia Mahaney with Sotheby's Intl. Realty, Inc. | Buyer's agents: Patrick Kelly with Coastal Realty Group Sales & M and None with None
#
# Highest Price Per Square Foot
# Two North Breakers Row Condo, 2 N Breakers Row Unit S-T1, in Palm Beach | Price: $6,000,000 | $1,850 psf | Listing agents: Laura Semler with Brown Harris Stevens of PB and None with None | Buyer's agents: Christian Angle with Christian Angle Real Estate and None with None
#
# Lowest Price Per Square Foot
# Carriage Homes AT Frenchmans Harbor Condo, 13633 Treasure Cove Cir, in North Palm Beach | Price: $2,200,000 | $882 psf | Listing agents: James Edwards with Sotheby's Intl. Realty, Inc. and Patricia Mahaney with Sotheby's Intl. Realty, Inc. | Buyer's agents: Patrick Kelly with Coastal Realty Group Sales & M and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Palm-Beach/2-N-Breakers-Row-33480/unit-S-T1/home/190483993
# Second priciest sale:  https://www.redfin.com/FL/Jupiter/425-Beach-Rd-33469/unit-O/home/42469663
# Cheapest top ten sale:  https://www.redfin.com/FL/North-Palm-Beach/13629-Treasure-Cove-Cir-33408/home/52844986
# Second Cheapest top ten sale:  https://www.redfin.com/FL/North-Palm-Beach/13631-Treasure-Cove-Cir-33408/home/52844984
# Highest top ten psf:  https://www.redfin.com/FL/Palm-Beach/2-N-Breakers-Row-33480/unit-S-T1/home/190483993
# Lowest top ten psf:  https://www.redfin.com/FL/North-Palm-Beach/13633-Treasure-Cove-Cir-33408/home/52844985

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Palm-Beach/2-N-Breakers-Row-33480/unit-S-T1/home/190483993

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Jupiter/425-Beach-Rd-33469/unit-O/home/42469663

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/North-Palm-Beach/13629-Treasure-Cove-Cir-33408/home/52844986

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/North-Palm-Beach/13631-Treasure-Cove-Cir-33408/home/52844984

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Palm-Beach/2-N-Breakers-Row-33480/unit-S-T1/home/190483993

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/North-Palm-Beach/13633-Treasure-Cove-Cir-33408/home/52844985

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 0  PAST SALE 2025-05-06   Condo/Co-op  2 N Breakers Row Unit S-T1
# 1  PAST SALE 2025-05-09   Condo/Co-op          425 Beach Rd Ph -O
# 2  PAST SALE 2025-05-07   Condo/Co-op    2700 Donald Ross Rd #412
# 3  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #215
# 4  PAST SALE 2025-05-09   Condo/Co-op     220 SE Mizner Blvd #217
# 5  PAST SALE 2025-05-06   Condo/Co-op   44 Cocoanut Row Unit 321a
# 6  PAST SALE 2025-05-06   Condo/Co-op            604 Captains Way
# 7  PAST SALE 2025-05-05   Condo/Co-op     13633 Treasure Cove Cir
# 8  PAST SALE 2025-05-05   Condo/Co-op     13631 Treasure Cove Cir
# 9  PAST SALE 2025-05-05   Condo/Co-op     13629 Treasure Cove Cir
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0          Palm Beach                FL             33480.0  6000000.0   3.0
# 1            Tequesta                FL             33469.0  4100000.0   3.0
# 2  Palm Beach Gardens                FL             33410.0  3900000.0   4.0
# 3          Boca Raton                FL             33432.0  3211000.0   2.0
# 4          Boca Raton                FL             33432.0  2900000.0   2.0
# 5          Palm Beach                FL             33480.0  2500000.0   2.0
# 6             Jupiter                FL             33477.0  2350000.0   3.0
# 7    North Palm Beach                FL             33408.0  2200000.0   3.0
# 8    North Palm Beach                FL             33408.0  2200000.0   3.0
# 9    North Palm Beach                FL             33408.0  2200000.0   3.0
#
#    BATHS                                   LOCATION  SQUARE FEET  LOT SIZE  \
# 0    3.5               Two North Breakers Row Condo       3243.0       NaN
# 1    3.5                    Cliveden Jupiter Island       2750.0       NaN
# 2    3.5                                      Azure       3466.0       NaN
# 3    3.0                           Alina Residences       2683.0     180.0
# 4    2.5                           Alina Residences       2429.0     180.0
# 5    2.0                          Palm Beach Towers       1621.0       NaN
# 6    2.0                              Admirals Cove       2160.0       NaN
# 7    2.0  Carriage Homes AT Frenchmans Harbor Condo       2493.0       NaN
# 8    2.0  Carriage Homes AT Frenchmans Harbor Condo       2367.0       NaN
# 9    2.0  Carriage Homes AT Frenchmans Harbor Condo       1920.0       NaN
#
#    YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0      1986.0             NaN         1850.0    13078.0   Sold
# 1      1996.0             NaN         1491.0     2378.0   Sold
# 2      2016.0             NaN         1125.0     3635.0   Sold
# 3      2024.0             NaN         1197.0     2291.0   Sold
# 4      2024.0             NaN         1194.0     2050.0   Sold
# 5      1956.0             NaN         1542.0     2193.0   Sold
# 6      1988.0             NaN         1088.0     2357.0   Sold
# 7      2012.0             NaN          882.0     2397.0   Sold
# 8      2012.0             NaN          929.0     2397.0   Sold
# 9      2012.0             NaN         1146.0     2200.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...  Beaches MLS
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...  Beaches MLS
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...  Beaches MLS
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Beaches MLS
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...  Beaches MLS
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...  Beaches MLS
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0  RX-10879239        N          Y  26.717140 -80.034673
# 1  RX-11056254        N          Y  26.955362 -80.077420
# 2  RX-11049233        N          Y  26.880648 -80.071850
# 3  RX-11089230        N          Y  26.347042 -80.083200
# 4  RX-11089244        N          Y  26.347042 -80.083200
# 5  RX-11071642        N          Y  26.715065 -80.042094
# 6  RX-11049155        N          Y  26.909631 -80.085249
# 7  RX-11048862        N          Y  26.876802 -80.065047
# 8  RX-11048869        N          Y  26.876802 -80.065047
# 9  RX-11048850        N          Y  26.876802 -80.065047
#
#                                                  url    list_agent_name_1  \
# 0  https://www.redfin.com/FL/Palm-Beach/2-N-Break...         Laura Semler
# 1  https://www.redfin.com/FL/Jupiter/425-Beach-Rd...         John Holland
# 2  https://www.redfin.com/FL/Palm-Beach-Gardens/2...         Bradley Ball
# 3  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 4  https://www.redfin.com/FL/Boca-Raton/220-SE-Mi...  Rochelle LeCavalier
# 5  https://www.redfin.com/FL/Palm-Beach/44-Cocoan...       Mark Whitehead
# 6  https://www.redfin.com/FL/Jupiter/604-Captains...      Stephen Rockoff
# 7  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 8  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
# 9  https://www.redfin.com/FL/North-Palm-Beach/136...        James Edwards
#
#               list_broker_name_1   list_agent_name_2  \
# 0     Brown Harris Stevens of PB                None
# 1  Holland Group Real Estate LLC      Emily Sullivan
# 2        Frankel Ball Realty LLC        Shannon Ball
# 3                Douglas Elliman  Kathy Koch Pitlake
# 4                Douglas Elliman  Kathy Koch Pitlake
# 5    Coffee Cake And Real Estate         Brie Segota
# 6             The Corcoran Group                None
# 7   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 8   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
# 9   Sotheby's Intl. Realty, Inc.    Patricia Mahaney
#
#               list_broker_name_2     buy_agent_name_1  \
# 0                           None      Christian Angle
# 1  Holland Group Real Estate LLC        Traci Chivers
# 2        Frankel Ball Realty LLC        Ken Meierling
# 3                Douglas Elliman        Pamela Levine
# 4                Douglas Elliman  Rochelle LeCavalier
# 5    Coffee Cake And Real Estate            Non Agent
# 6                           None       Crystal Condit
# 7   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 8   Sotheby's Intl. Realty, Inc.        Patrick Kelly
# 9   Sotheby's Intl. Realty, Inc.        Patrick Kelly
#
#                 buy_broker_name_1 buy_agent_name_2       buy_broker_name_2  \
# 0     Christian Angle Real Estate             None                    None
# 1  Premier Properties of South Fl             None                    None
# 2     Engel & Voelkers Jupiter RE             None                    None
# 3          Luxury Partners Realty      Jeff Levine  Luxury Partners Realty
# 4                 Douglas Elliman             None                    None
# 5       Non-Member Selling Office             None                    None
# 6  Waterfront Properties & Club C             None                    None
# 7  Coastal Realty Group Sales & M             None                    None
# 8  Coastal Realty Group Sales & M             None                    None
# 9  Coastal Realty Group Sales & M             None                    None
#
#    RANK   COLOR                                          FULL_NAME
# 0     1  orange  Two North Breakers Row Condo at 2 N Breakers R...
# 1     2    blue  Cliveden Jupiter Island at 425 Beach Rd Ph -O ...
# 2     3    blue  Azure at 2700 Donald Ross Rd #412 in Palm Beac...
# 3     4    blue  Alina Residences at 220 SE Mizner Blvd #215 in...
# 4     5    blue  Alina Residences at 220 SE Mizner Blvd #217 in...
# 5     6    blue  Palm Beach Towers at 44 Cocoanut Row Unit 321a...
# 6     7    blue       Admirals Cove at 604 Captains Way in Jupiter
# 7     8    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 8     9    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...
# 9    10    blue  Carriage Homes AT Frenchmans Harbor Condo at 1...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 1, 27) ## List (Earlier) date
date2 = datetime(2025, 5, 9) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 102

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0    1850.0
# 1    1491.0
# 2    1125.0
# 3    1197.0
# 4    1194.0
# 5    1542.0
# 6    1088.0
# 7     882.0
# 8     929.0
# 9    1146.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                         ADDRESS       PRICE BEDS  \
# 0 2025-05-06        2 N Breakers Row Unit S-T1 in Palm Beach  $6,000,000    3
# 1 2025-05-09                  425 Beach Rd Ph -O in Tequesta  $4,100,000    3
# 2 2025-05-07  2700 Donald Ross Rd #412 in Palm Beach Gardens  $3,900,000    4
# 3 2025-05-09           220 SE Mizner Blvd #215 in Boca Raton  $3,211,000    2
# 4 2025-05-09           220 SE Mizner Blvd #217 in Boca Raton  $2,900,000    2
# 5 2025-05-06         44 Cocoanut Row Unit 321a in Palm Beach  $2,500,000    2
# 6 2025-05-06                     604 Captains Way in Jupiter  $2,350,000    3
# 7 2025-05-05     13633 Treasure Cove Cir in North Palm Beach  $2,200,000    3
# 8 2025-05-05     13631 Treasure Cove Cir in North Palm Beach  $2,200,000    3
# 9 2025-05-05     13629 Treasure Cove Cir in North Palm Beach  $2,200,000    3
#
#    BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE         MLS#  \
# 0    3.5       3,243       1986        $1,850  Beaches MLS  RX-10879239
# 1    3.5       2,750       1996        $1,491  Beaches MLS  RX-11056254
# 2    3.5       3,466       2016        $1,125  Beaches MLS  RX-11049233
# 3    3.0       2,683       2024        $1,197  Beaches MLS  RX-11089230
# 4    2.5       2,429       2024        $1,194  Beaches MLS  RX-11089244
# 5    2.0       1,621       1956        $1,542  Beaches MLS  RX-11071642
# 6    2.0       2,160       1988        $1,088  Beaches MLS  RX-11049155
# 7    2.0       2,493       2012          $882  Beaches MLS  RX-11048862
# 8    2.0       2,367       2012          $929  Beaches MLS  RX-11048869
# 9    2.0       1,920       2012        $1,146  Beaches MLS  RX-11048850
#
#                                         LISTING INFO  \
# 0        Laura Semler Brown Harris Stevens of PB
# 1  John Holland Holland Group Real Estate LLC Emi...
# 2  Bradley Ball Frankel Ball Realty LLC Shannon B...
# 3  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 4  Rochelle LeCavalier Douglas Elliman Kathy Koch...
# 5  Mark Whitehead Coffee Cake And Real Estate Bri...
# 6             Stephen Rockoff The Corcoran Group
# 7  James Edwards Sotheby's Intl. Realty, Inc. Pat...
# 8  James Edwards Sotheby's Intl. Realty, Inc. Pat...
# 9  James Edwards Sotheby's Intl. Realty, Inc. Pat...
#
#                                          BUYING INFO
# 0    Christian Angle Christian Angle Real Estate
# 1   Traci Chivers Premier Properties of South Fl
# 2      Ken Meierling Engel & Voelkers Jupiter RE
# 3  Pamela Levine Luxury Partners Realty Jeff Levi...
# 4            Rochelle LeCavalier Douglas Elliman
# 5            Non Agent Non-Member Selling Office
# 6  Crystal Condit Waterfront Properties & Club C
# 7   Patrick Kelly Coastal Realty Group Sales & M
# 8   Patrick Kelly Coastal Realty Group Sales & M
# 9   Patrick Kelly Coastal Realty Group Sales & M
