# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now() - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=6)

def format_date(date):
    day = date.day
    # Months 3-7 (March–July) should be full; all others abbreviated with a period
    if date.month in (3, 4, 5, 6, 7):
        month_str = date.strftime("%B")      # e.g. "March", "April", ...
    else:
        month_str = date.strftime("%b") + "."  # e.g. "Jan.", "Feb.", "Aug.", ...

    return f"{month_str} {day}"


# Format both dates
week_ending = format_date(today)
week_starting = format_date(one_week_ago)

print(week_starting, week_ending)
# Out:
# June 23 June 29

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE     SOLD DATE PROPERTY TYPE                     ADDRESS  \
# 1  PAST SALE  June-24-2025   Condo/Co-op  2000 S Ocean Blvd Unit 14b
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 1  Pompano Beach                FL             33062.0  520000.0   2.0    2.0
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Pompano-Beach/2000-S...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11078315         N          Y  26.205295 -80.094233
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
#  Broward

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] >= one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-06-27    26
# 2025-06-26    17
# 2025-06-24    13
# 2025-06-25     9
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"
        querystring = {"url": url}
        
        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }
        response = requests.get(base_url, headers=headers, params=querystring)
        response.raise_for_status()
        data = response.json()

        # Safely drill down, falling back to {} if any level is None or missing
        info = data.get('data') or {}
        panel = info.get('mainHouseInfoPanelInfo') or {}
        house = panel.get('mainHouseInfo') or {}

        # Extract listing agents
        listing_agents = house.get('listingAgents') or []
        list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName') if len(listing_agents) > 0 else None
        list_broker_name_1 = listing_agents[0].get('brokerName')           if len(listing_agents) > 0 else None
        list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName') if len(listing_agents) > 1 else None
        list_broker_name_2 = listing_agents[1].get('brokerName')           if len(listing_agents) > 1 else None

        # Extract buying agents
        buying_agents = house.get('buyingAgents') or []
        buy_agent_name_1  = buying_agents[0].get('agentInfo', {}).get('agentName') if len(buying_agents) > 0 else None
        buy_broker_name_1 = buying_agents[0].get('brokerName')             if len(buying_agents) > 0 else None
        buy_agent_name_2  = buying_agents[1].get('agentInfo', {}).get('agentName') if len(buying_agents) > 1 else None
        buy_broker_name_2 = buying_agents[1].get('brokerName')             if len(buying_agents) > 1 else None

        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return { key: None for key in [
            'url', 'list_agent_name_1','list_broker_name_1',
            'list_agent_name_2','list_broker_name_2',
            'buy_agent_name_1','buy_broker_name_1',
            'buy_agent_name_2','buy_broker_name_2'
        ] }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-06-26   Condo/Co-op
# 1  PAST SALE 2025-06-24   Condo/Co-op
# 2  PAST SALE 2025-06-27   Condo/Co-op
# 3  PAST SALE 2025-06-25   Condo/Co-op
# 4  PAST SALE 2025-06-25   Condo/Co-op
# 5  PAST SALE 2025-06-25   Condo/Co-op
# 6  PAST SALE 2025-06-26   Condo/Co-op
# 7  PAST SALE 2025-06-25   Condo/Co-op
# 8  PAST SALE 2025-06-26   Condo/Co-op
# 9  PAST SALE 2025-06-24   Condo/Co-op
#
#                                    ADDRESS                   CITY  \
# 0                  1460 S Ocean Blvd #1003  Lauderdale By The Sea
# 1                     715 Bayshore Dr #504        Fort Lauderdale
# 2                   333 Las Olas Way #2301        Fort Lauderdale
# 3                  3900 Galt Ocean Dr #412        Fort Lauderdale
# 4                   3020 NE 32nd Ave #1012        Fort Lauderdale
# 5  2600 E Hallandale Beach Blvd Unit T1401       Hallandale Beach
# 6               1880 S Ocean Dr Unit TS401       Hallandale Beach
# 7              3200 Port Royale Dr N #2008        Fort Lauderdale
# 8                     3725 S Ocean Dr #910              Hollywood
# 9               2000 S Ocean Blvd Unit 14b          Pompano Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ...  \
# 0                FL             33062.0  2200000.0   3.0    3.5  ...
# 1                FL             33304.0  1100000.0   3.0    3.5  ...
# 2                FL             33301.0   815000.0   2.0    2.0  ...
# 3                FL             33308.0   800000.0   2.0    2.5  ...
# 4                FL             33308.0   775000.0   2.0    2.0  ...
# 5                FL             33009.0   760000.0   3.0    3.0  ...
# 6                FL             33009.0   630000.0   3.0    3.0  ...
# 7                FL             33308.0   600000.0   2.0    2.0  ...
# 8                FL             33019.0   548000.0   2.0    2.0  ...
# 9                FL             33062.0   520000.0   2.0    2.0  ...
#
#    LONGITUDE                                                url  \
# 0 -80.091956  https://www.redfin.com/FL/Pompano-Beach/1460-S...
# 1 -80.108524  https://www.redfin.com/FL/Fort-Lauderdale/715-...
# 2 -80.141518  https://www.redfin.com/FL/Fort-Lauderdale/333-...
# 3 -80.097707  https://www.redfin.com/FL/Fort-Lauderdale/3900...
# 4 -80.103219  https://www.redfin.com/FL/Fort-Lauderdale/3020...
# 5 -80.122748  https://www.redfin.com/FL/Hallandale-Beach/260...
# 6 -80.119329  https://www.redfin.com/FL/Hallandale-Beach/188...
# 7 -80.101623  https://www.redfin.com/FL/Fort-Lauderdale/3200...
# 8 -80.118043  https://www.redfin.com/FL/Hollywood/3725-S-Oce...
# 9 -80.094233  https://www.redfin.com/FL/Pompano-Beach/2000-S...
#
#    list_agent_name_1              list_broker_name_1  list_agent_name_2  \
# 0        Marc Brandt                 Douglas Elliman    Jeffery Kotwica
# 1     Alicia Levitan  Keller Williams Realty Profess               None
# 2        Bobbi Ocean   Galleria International Realty               None
# 3   Roderick Perkins    Luxury Real Estate Group LLC               None
# 4        Eric Miller                  EXP Realty LLC               None
# 5         Riad Fayad  Sigma Real Estate & Investment               None
# 6         Vera Aster           Beachfront Realty Inc               None
# 7       Danny Shears          Coldwell Banker Realty               None
# 8       Leo Meyerkov        Related ISG Realty, LLC.               None
# 9          Nick Wulf              REDFIN CORPORATION               None
#
#    list_broker_name_2      buy_agent_name_1             buy_broker_name_1  \
# 0     Douglas Elliman           Gilles Rais        Coldwell Banker Realty
# 1                None       Martine Dreyfus                EXP Realty LLC
# 2                None         Tatiana Silva  Optimar International Realty
# 3                None          Megan Romine               Douglas Elliman
# 4                None  Lori Novello Cortese                EXP Realty LLC
# 5                None     Debora Pludwinski                EXP Realty LLC
# 6                None            Vera Aster         Beachfront Realty Inc
# 7                None           Eric Miller                EXP Realty LLC
# 8                None          Raul Alvarez         My Realty Group, LLC.
# 9                None           Randy Lloyd                      LoKation
#
#    buy_agent_name_2  buy_broker_name_2
# 0              None               None
# 1              None               None
# 2              None               None
# 3              None               None
# 4              None               None
# 5              None               None
# 6              None               None
# 7              None               None
# 8              None               None
# 9              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 65

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $326,772

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $264

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $21,240,150

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0           65              326772          264                     21240150.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 120
# -----------
# Input Previous Week Condo Average Sales Price:
# 293057
# -----------
# Input Previous Week Condo Average PSF:
# 252
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 35166873.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2025-06-26   Condo/Co-op  1460 S Ocean Blvd #1003
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0  Lauderdale By The Sea                FL             33062.0  2200000.0
#
#    BEDS  BATHS           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5  Europa By The Sea       3523.0       NaN      2006.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          624.0     3859.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...  Beaches MLS  F10476660
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.213195 -80.091956
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...       Marc Brandt
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman   Jeffery Kotwica    Douglas Elliman      Gilles Rais
#
#         buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Coldwell Banker Realty             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...       Marc Brandt
# 1  https://www.redfin.com/FL/Fort-Lauderdale/715-...    Alicia Levitan
# 2  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Bobbi Ocean
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3900...  Roderick Perkins
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3020...       Eric Miller
# 5  https://www.redfin.com/FL/Hallandale-Beach/260...        Riad Fayad
# 6  https://www.redfin.com/FL/Hallandale-Beach/188...        Vera Aster
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3200...      Danny Shears
# 8  https://www.redfin.com/FL/Hollywood/3725-S-Oce...      Leo Meyerkov
# 9  https://www.redfin.com/FL/Pompano-Beach/2000-S...         Nick Wulf
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 0                 Douglas Elliman   Jeffery Kotwica    Douglas Elliman
# 1  Keller Williams Realty Profess              None               None
# 2   Galleria International Realty              None               None
# 3    Luxury Real Estate Group LLC              None               None
# 4                  EXP Realty LLC              None               None
# 5  Sigma Real Estate & Investment              None               None
# 6           Beachfront Realty Inc              None               None
# 7          Coldwell Banker Realty              None               None
# 8        Related ISG Realty, LLC.              None               None
# 9              REDFIN CORPORATION              None               None
#
#        buy_agent_name_1             buy_broker_name_1 buy_agent_name_2  \
# 0           Gilles Rais        Coldwell Banker Realty             None
# 1       Martine Dreyfus                EXP Realty LLC             None
# 2         Tatiana Silva  Optimar International Realty             None
# 3          Megan Romine               Douglas Elliman             None
# 4  Lori Novello Cortese                EXP Realty LLC             None
# 5     Debora Pludwinski                EXP Realty LLC             None
# 6            Vera Aster         Beachfront Realty Inc             None
# 7           Eric Miller                EXP Realty LLC             None
# 8          Raul Alvarez         My Realty Group, LLC.             None
# 9           Randy Lloyd                      LoKation             None
#
#   buy_broker_name_2  RANK   COLOR
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue

# %%
# %store -r map_box_api_key

# %%
map_box_api_key
# Out:
# 'pk.eyJ1IjoidHJkZGF0YSIsImEiOiJjamc2bTc2YmUxY2F3MnZxZGh2amR2MTY5In0.QlOWqB-yQNrNlXD0KQ9IvQ'

# %%
import folium
from branca.element import Template, MacroElement

# ——— Your title & caption HTML ———
title_html = f'''
  <h3 align="center" style="font-size:16px"><b>Recent {county} County Condo Sales</b></h3>
'''
caption_html = f'''
  <p align="center" style="font-size:13px"><i>{week_starting} — {week_ending}</i></p>
'''

# ——— Base map ———
m = folium.Map(
    location=df[['LATITUDE','LONGITUDE']].mean().to_list(),
    zoom_start=9,
    tiles=None
)

# ——— Tile layers ———
folium.TileLayer('OpenStreetMap', name='OSM', control=False).add_to(m)
folium.TileLayer(
    tiles=(
        "https://api.mapbox.com/styles/v1/"
        "mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x"
        f"?access_token={map_box_api_key}"
    ),
    attr="Mapbox", name="Streets", control=False
).add_to(m)

# ——— Add your markers ———
for _, row in df_top_ten.iterrows():
    lat, lon = row['LATITUDE'], row['LONGITUDE']
    popup = folium.Popup(popup_html(row), max_width=400)

    if row['COLOR'] == 'blue':
        # Regular sale: blue circle
        folium.CircleMarker(
            location=(lat, lon),
            radius=7,
            fill=True,
            fill_color='blue',
            fill_opacity=0.5,
            color=None,
            popup=popup
        ).add_to(m)
    else:
        # Top sale: gold star
        folium.Marker(
            location=(lat, lon),
            popup=popup,
            icon=folium.DivIcon(
                html="""
                <div style="font-size:24px; line-height:24px; color:gold;">
                  &#9733;
                </div>
                """
            )
        ).add_to(m)

# ——— Layer control, title & caption ———
folium.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))

# ——— Optional legend via branca ———
legend_html = """
{% macro html(this, kwargs) %}
  <div style="
      position: fixed;
      bottom: 50px; left: 50px;
      background: white; padding: 8px;
      border: 2px solid grey;
      font-size: 12px;
      z-index: 9999;
  ">
    <div style="display:inline-block; font-size:18px; color:gold; margin-right:6px;">&#9733;</div> Top Sale<br>
    <i style="background: blue; width: 10px; height: 10px;
       display: inline-block; margin-right: 6px;"></i> All other sales
  </div>
{% endmacro %}
"""
legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)

# ——— Display ———
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4704ec7704efbb864bc5e603252a64f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County Condo Sales&lt;/b&gt;&lt;/h3&gt;
#
#   &lt;p align=&quot;center&quot; style=&quot;font-size:13px&quot;&gt;&lt;i&gt;June 23 — June 29&lt;/i&gt;&lt;/p&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4704ec7704efbb864bc5e603252a64f4&quot; &gt;&lt;/div&gt;
#
#
#   &lt;div style=&quot;
#       position: fixed;
#       bottom: 50px; left: 50px;
#       background: white; padding: 8px;
#       border: 2px solid grey;
#       font-size: 12px;
#       z-index: 9999;
#   &quot;&gt;
#     &lt;div style=&quot;display:inline-block; font-size:18px; color:gold; margin-right:6px;&quot;&gt;&amp;#9733;&lt;/div&gt; Top Sale&lt;br&gt;
#     &lt;i style=&quot;background: blue; width: 10px; height: 10px;
#        display: inline-block; margin-right: 6px;&quot;&gt;&lt;/i&gt; All other sales
#   &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4704ec7704efbb864bc5e603252a64f4 = L.map(
#                 &quot;map_4704ec7704efbb864bc5e603252a64f4&quot;,
#                 {
#                     center: [26.146430668292684, -80.18526895000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_075cdd21f4504ded8594cc6bbaec2b4b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4704ec7704efbb864bc5e603252a64f4);
#
#
#             var tile_layer_0afdf3527f3c48c94df74b2819d6a8c6 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoidHJkZGF0YSIsImEiOiJjamc2bTc2YmUxY2F3MnZxZGh2amR2MTY5In0.QlOWqB-yQNrNlXD0KQ9IvQ&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4704ec7704efbb864bc5e603252a64f4);
#
#
#             var marker_51f3d25b9d8fb10f86483389fc80d3f1 = L.marker(
#                 [26.2131946, -80.0919556],
#                 {}
#             ).addTo(map_4704ec7704efbb864bc5e603252a64f4);
#
#
#             var div_icon_0a185f86d2e5825b8b682f2b36429e1d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;font-size:24px; line-height:24px; color:gold;\&quot;\u003e\n                  \u0026#9733;\n                \u003c/div\u003e\n                &quot;});
#             marker_51f3d25b9d8fb10f86483389fc80d3f1.setIcon(div_icon_0a185f86d2e5825b8b682f2b36429e1d);
#
#
#         var popup_d2ee0b4e41293fa76b969fb20f119cad = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_5291b352c719c58bd1cd137fb533f450 = $(`&lt;div id=&quot;html_5291b352c719c58bd1cd137fb533f450&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;1460 S Ocean Blvd #1003&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,200,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$624.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,523.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2006.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_d2ee0b4e41293fa76b969fb20f119cad.setContent(html_5291b352c719c58bd1cd137fb533f450);
#
#
#
#         marker_51f3d25b9d8fb10f86483389fc80d3f1.bindPopup(popup_d2ee0b4e41293fa76b969fb20f119cad)
#         ;
#
#
#
#
#             var circle_marker_03ed9485aab158f98bec9df35bd9e624 = L.circleMarker(
#                 [26.1331576, -80.1085237],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4704ec7704efbb864bc5e603252a64f4);
#
#
#         var popup_bc201f80308889219a09e0f2b4db2917 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_62bb42c05505f27062f5164042cdad74 = $(`&lt;div id=&quot;html_62bb42c05505f27062f5164042cdad74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;715 Bayshore Dr #504&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$1,100,000.0&lt;br&gt;     &lt;strong&gt;Price sq

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2025-06-26   Condo/Co-op  1460 S Ocean Blvd #1003
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0  Lauderdale By The Sea                FL             33062.0  2200000.0
#
#    BEDS  BATHS           LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.5  Europa By The Sea       3523.0       NaN      2006.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          624.0     3859.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...  Beaches MLS  F10476660
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  26.213195 -80.091956
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...       Marc Brandt
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman   Jeffery Kotwica    Douglas Elliman      Gilles Rais
#
#         buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Coldwell Banker Realty             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_06302025

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'Europa By The Sea at 1460 S Ocean Blvd #1003 in Lauderdale By The Sea'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 0  PAST SALE 2025-06-26   Condo/Co-op
# 1  PAST SALE 2025-06-24   Condo/Co-op
# 2  PAST SALE 2025-06-27   Condo/Co-op
# 3  PAST SALE 2025-06-25   Condo/Co-op
# 4  PAST SALE 2025-06-25   Condo/Co-op
# 5  PAST SALE 2025-06-25   Condo/Co-op
# 6  PAST SALE 2025-06-26   Condo/Co-op
# 7  PAST SALE 2025-06-25   Condo/Co-op
# 8  PAST SALE 2025-06-26   Condo/Co-op
# 9  PAST SALE 2025-06-24   Condo/Co-op
#
#                                    ADDRESS                   CITY  \
# 0                  1460 S Ocean Blvd #1003  Lauderdale By The Sea
# 1                     715 Bayshore Dr #504        Fort Lauderdale
# 2                   333 Las Olas Way #2301        Fort Lauderdale
# 3                  3900 Galt Ocean Dr #412        Fort Lauderdale
# 4                   3020 NE 32nd Ave #1012        Fort Lauderdale
# 5  2600 E Hallandale Beach Blvd Unit T1401       Hallandale Beach
# 6               1880 S Ocean Dr Unit TS401       Hallandale Beach
# 7              3200 Port Royale Dr N #2008        Fort Lauderdale
# 8                     3725 S Ocean Dr #910              Hollywood
# 9               2000 S Ocean Blvd Unit 14b          Pompano Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33062.0  2200000.0   3.0    3.5
# 1                FL             33304.0  1100000.0   3.0    3.5
# 2                FL             33301.0   815000.0   2.0    2.0
# 3                FL             33308.0   800000.0   2.0    2.5
# 4                FL             33308.0   775000.0   2.0    2.0
# 5                FL             33009.0   760000.0   3.0    3.0
# 6                FL             33009.0   630000.0   3.0    3.0
# 7                FL             33308.0   600000.0   2.0    2.0
# 8                FL             33019.0   548000.0   2.0    2.0
# 9                FL             33062.0   520000.0   2.0    2.0
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0          Europa By The Sea       3523.0       NaN      2006.0
# 1                    La Rive       2680.0       NaN      2004.0
# 2  LAS OLAS RIVER HOUSE COND       1161.0       NaN      2004.0
# 3              Playa Del Mar       1649.0       NaN      1975.0
# 4     Tides At Bridgeside Sq       1600.0       NaN      2002.0
# 5      BEACHWALK CONDOMINIUM       1737.0       NaN      2015.0
# 6  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
# 7   TOWER PORTSMOUTH AT PORT       1365.0       NaN      1981.0
# 8       SEA AIR TOWERS CONDO       1431.0       NaN      1971.0
# 9          Royal Coast Condo       1350.0       NaN      1971.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          624.0     3859.0   Sold
# 1             NaN          410.0     2791.0   Sold
# 2             NaN          702.0     1503.0   Sold
# 3             NaN          485.0     1109.0   Sold
# 4             NaN          484.0     1892.0   Sold
# 5             NaN          438.0     2100.0   Sold
# 6             NaN          325.0     1731.0   Sold
# 7             NaN          440.0     1278.0   Sold
# 8             NaN          383.0      995.0   Sold
# 9             NaN          385.0     1481.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...  Beaches MLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/715-...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3900...  Beaches MLS
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3020...  Beaches MLS
# 5  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS
# 6  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3200...       MARMLS
# 8  https://www.redfin.com/FL/Hollywood/3725-S-Oce...       MARMLS
# 9  https://www.redfin.com/FL/Pompano-Beach/2000-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10476660        N          Y  26.213195 -80.091956
# 1    F10498085        N          Y  26.133158 -80.108524
# 2    A11679228        N          Y  26.118354 -80.141518
# 3    F10485618        N          Y  26.175849 -80.097707
# 4    F10483468        N          Y  26.166161 -80.103219
# 5    A11592428        N          Y  25.985939 -80.122748
# 6    A11782835        N          Y  25.982872 -80.119329
# 7    A11757014        N          Y  26.210739 -80.101623
# 8    A11782912        N          Y  25.989969 -80.118043
# 9  RX-11078315        N          Y  26.205295 -80.094233
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...       Marc Brandt
# 1  https://www.redfin.com/FL/Fort-Lauderdale/715-...    Alicia Levitan
# 2  https://www.redfin.com/FL/Fort-Lauderdale/333-...       Bobbi Ocean
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3900...  Roderick Perkins
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3020...       Eric Miller
# 5  https://www.redfin.com/FL/Hallandale-Beach/260...        Riad Fayad
# 6  https://www.redfin.com/FL/Hallandale-Beach/188...        Vera Aster
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3200...      Danny Shears
# 8  https://www.redfin.com/FL/Hollywood/3725-S-Oce...      Leo Meyerkov
# 9  https://www.redfin.com/FL/Pompano-Beach/2000-S...         Nick Wulf
#
#                list_broker_name_1 list_agent_name_2 list_broker_name_2  \
# 
#
#                                    ADDRESS                   CITY  \
# 0                  1460 S Ocean Blvd #1003  Lauderdale By The Sea
# 1                     715 Bayshore Dr #504        Fort Lauderdale
# 2                   333 Las Olas Way #2301        Fort Lauderdale
# 3                  3900 Galt Ocean Dr #412        Fort Lauderdale
# 4                   3020 NE 32nd Ave #1012        Fort Lauderdale
# 5  2600 E Hallandale Beach Blvd Unit T1401       Hallandale Beach
# 6               1880 S Ocean Dr Unit TS401       Hallandale Beach
# 7              3200 Port Royale Dr N #2008        Fort Lauderdale
# 8                     3725 S Ocean Dr #910              Hollywood
# 9               2000 S Ocean Blvd Unit 14b          Pompano Beach
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33062.0  2200000.0   3.0    3.5
# 1                FL             33304.0  1100000.0   3.0    3.5
# 2                FL             33301.0   815000.0   2.0    2.0
# 3                FL             33308.0   800000.0   2.0    2.5
# 4                FL             33308.0   775000.0   2.0    2.0
# 5                FL             33009.0   760000.0   3.0    3.0
# 6                FL             33009.0   630000.0   3.0    3.0
# 7                FL             33308.0   600000.0   2.0    2.0
# 8                FL             33019.0   548000.0   2.0    2.0
# 9                FL             33062.0   520000.0   2.0    2.0
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0          Europa By The Sea       3523.0       NaN      2006.0
# 1                    La Rive       2680.0       NaN      2004.0
# 2  LAS OLAS RIVER HOUSE COND       1161.0       NaN      2004.0
# 3              Playa Del Mar       1649.0       NaN      1975.0
# 4     Tides At Bridgeside Sq       1600.0       NaN      2002.0
# 5      BEACHWALK CONDOMINIUM       1737.0       NaN      2015.0
# 6  LA MER ESTATES WEST CONDO       1940.0       NaN      1974.0
# 7   TOWER PORTSMOUTH AT PORT       1365.0       NaN      1981.0
# 8       SEA AIR TOWERS CONDO       1431.0       NaN      1971.0
# 9          Royal Coast Condo       1350.0       NaN      1971.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          624.0     3859.0   Sold
# 1             NaN          410.0     2791.0   Sold
# 2             NaN          702.0     1503.0   Sold
# 3             NaN          485.0     1109.0   Sold
# 4             NaN          484.0     1892.0   Sold
# 5             NaN          438.0     2100.0   Sold
# 6             NaN          325.0     1731.0   Sold
# 7             NaN          440.0     1278.0   Sold
# 8             NaN          383.0      995.0   Sold
# 9             NaN          385.0     1481.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Pompano-Beach/1460-S...  Beaches MLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/715-...  Beaches MLS
# 2  https://www.redfin.com/FL/Fort-Lauderdale/333-...       MARMLS
# 3  https://www.redfin.com/FL/Fort-Lauderdale/3900...  Beaches MLS
# 4  https://www.redfin.com/FL/Fort-Lauderdale/3020...  Beaches MLS
# 5  https://www.redfin.com/FL/Hallandale-Beach/260...       MARMLS
# 6  https://www.redfin.com/FL/Hallandale-Beach/188...       MARMLS
# 7  https://www.redfin.com/FL/Fort-Lauderdale/3200...       MARMLS
# 8  https://www.redfin.com/FL/Hollywood/3725-S-Oce...       MARMLS
# 9  https://www.redfin.com/FL/Pompano-Beach/2000-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10476660        N          Y  26.213195 -80.091956
# 1    F10498085        N          Y  26.133158 -80.108524
# 2    A11679228        N          Y  26.118354 -80.141518
# 3    F10485618        N          Y  26.175849 -80.097707
# 4    F10483468        N          Y  26.166161 -80.103219
# 5    A11592428        N          Y  25.985939 -80.122748
# 6    A11782835        N          Y  25.982872 -80.119329
# 7    A11757014        N          Y  26.210739 -80.101623
# 8    A11782912        N          Y  25.989969 -80.118043
# 9  RX-11078315        N          Y  26.205295 -80.094233
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Pompano-Beach
#
#                     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  \
# 0        Fort Lauderdale                FL             33308.0  1700000.0
# 1        Fort Lauderdale                FL             33316.0  1600000.0
# 2              Hollywood                FL             33019.0  1600000.0
# 3  Lauderdale By The Sea                FL             33308.0   900000.0
# 4              Hollywood                FL             33019.0   890000.0
# 5        Fort Lauderdale                FL             33301.0   790000.0
# 6        Fort Lauderdale                FL             33305.0   725000.0
# 7        Fort Lauderdale                FL             33308.0   650000.0
# 8          Pompano Beach                FL             33062.0   645000.0
# 9  Lauderdale By The Sea                FL             33062.0   615000.0
#
#    BEDS  BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   3.0    3.0                L'hermitage       2318.0       NaN      1997.0
# 1   3.0    3.5            Harborage Place       3368.0       NaN      1998.0
# 2   3.0    3.0  SEASIDE VILLAGE WEST COND       2180.0       NaN      2018.0
# 3   2.0    2.5             Sea Ranch Club       1780.0       NaN      1979.0
# 4   2.0    2.0  Lyfe Resort And Residence       1136.0       NaN      2017.0
# 5   3.0    2.0   350 LAS OLAS PLACE CONDO       1650.0       NaN      2005.0
# 6   2.0    2.0     Shore Club Condominium       1500.0       NaN      1976.0
# 7   1.0    2.0              Southern Seas        820.0       NaN      1957.0
# 8   2.0    2.0              Emerald Tower       1426.0       NaN      1972.0
# 9   2.0    2.0   Hampton Beach Club Condo       1372.0       NaN      1980.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          733.0     3119.0   Sold
# 1             NaN          475.0     5188.0   Sold
# 2             NaN          734.0     1938.0   Sold
# 3             NaN          506.0      681.0   Sold
# 4             NaN          783.0     1580.0   Sold
# 5             NaN          479.0     1750.0   Sold
# 6             NaN          483.0     1797.0   Sold
# 7             NaN          793.0     1526.0   Sold
# 8             NaN          452.0     1158.0   Sold
# 9             NaN          448.0     1338.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3100...  Beaches MLS
# 1  https://www.redfin.com/FL/Fort-Lauderdale/3055...  Beaches MLS
# 2  https://www.redfin.com/FL/Hollywood/6100-N-Oce...       MARMLS
# 3  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
# 4  https://www.redfin.com/FL/Hollywood/4111-S-Oce...  Beaches MLS
# 5  https://www.redfin.com/FL/Fort-Lauderdale/350-...       MARMLS
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1905...  Beaches MLS
# 7  https://www.redfin.com/FL/Lauderdale-by-the-Se...  Beaches MLS
# 8  https://www.redfin.com/FL/Pompano-Beach/1401-S...  Beaches MLS
# 9  https://www.redfin.com/FL/Pompano-Beach/1800-S...  Beaches MLS
#
#           MLS# FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0    F10495199        N          Y  26.168258 -80.099279
# 1    F10475427        N          Y  26.109135 -80.108540
# 2    A11735935        N          Y  26.052075 -80.114644
# 3    F10449724        N          Y  26.198972 -80.094812
# 4    F10496568        N          Y  25.986806 -80.118650
# 5    A11733963        N          Y  26.120405 -80.139762
# 6    F10431446        N          Y  26.153396 -80.101460
# 7    F10480424        N          Y  26.193553 -80.095086
# 8    F10496152        N          Y  26.215922 -80.092949
# 9  RX-11052021        N          Y  26.207626 -80.093562
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/Fort-Lauderdale/3100...       Patricia Post
# 1  https://www.redfin.com/FL/Fort-Lauderdale/3055...  Elizabeth Caldwell
# 2  https://www.redfin.com/FL/Hollywood/6100-N-Oce...                None
# 3  https://www.redfin.com/FL/Lauderdale-by-the-Se...       Angelica Pooz
# 4  https://www.redfin.com/FL/Hollywood/4111-S-Oce...       Jaime Delgado
# 5  https://www.redfin.com/FL/Fort-Lauderdale/350-...        Patty Sierra
# 6  https://www.redfin.com/FL/Fort-Lauderdale/1905...     Romina Oliviero
# 7  https://www.redfin.com/FL/Lauderdale-by-the-Se...      Timothy Singer
# 8  https://www.redfin.com/FL/Pompano-Beach/1401-S...       Ruthie Brooks
# 9  https://www.redfin.com/FL/Pompano-Beach/1800-S...        Barry Frette
#
#             list_broker_name_1 list_agent_name_2      list_broker_name_2  \
# 0          Post and Post, Inc.              None                    None
# 1         Compass Florida, LLC  Rebecca Baughman    Compass Florida, LLC
# 2                         None              None                    None
# 3        Xcellence Realty Inc.              None                    None
# 4           Al dia Real Estate              None                    None
# 5                Sierra Realty              None                    None
# 6  Lauderdale Beach Properties              None                    None
# 7       Coldwell Banker Realty         Ryan Love  Coldwell Banker Realty
# 8   Balistreri Real Estate Inc              None                    None
# 9   William Raveis Real Estate              None                    None
#
#        buy_agent_name_1           buy_broker_name_1 buy_agent_name_2  \
# 0         Patricia Post         Post and Post, Inc.             None
# 1         Susan Rindley  One Sotheby's Int'l Realty             None
# 2                  None                        None             None
# 3         Angelica Pooz       Xcellence Realty Inc.             None
# 4        Antonio Pineda  Expert Team One Realty LLC             None
# 5          Patty Sierra               Sierra Realty             None
# 6        Roni Sterin PA           The Keyes Company             None
# 7  Non-member Mls Agent              NON MEMBER MLS             None
# 8         Ruthie Brooks  Balistreri Real Estate Inc             None
# 9         David Saindon           RE/MAX Experience             None
#
#   buy_broker_name_2  RANK   COLOR  \
# 0              None     1  orange
# 1              None     2    blue
# 2              None     3    blue
# 3              None     4    blue
# 4              None     5    blue
# 5              None     6    blue
# 6              None     7    blue
# 7              None     8    blue
# 8              None     9    blue
# 9              None    10    blue
#
#                                            FULL_NAME
# 0  L'hermitage at 3100 N Ocean Blvd #2201 in Fort...
# 1  Harborage Place at 3055 Harbor Dr #603 in Fort...
# 2  SEASIDE VILLAGE WEST COND at 6100 N Ocean Dr U...
# 3  Sea Ranch Club at 5000 N Ocean Blvd #1402 in L...
# 4  Lyfe Resort And Residence at 4111 S Ocean Dr U...
# 5  350 LAS OLAS PLACE CONDO at 350 SE 2nd St #970...
# 6  Shore Club Condominium at 1905 N Ocean Blvd Un...
# 7  Southern Seas at 4520 El Mar Dr #1 in Fort Lau...
# 8  Emerald Tower at 1401 S Ocean Blvd #1008 in Po...
# 9  Hampton Beach Club Condo at 1800 S Ocean Blvd ...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2025, 4, 14) ## List (Earlier) date
date2 = datetime(2025, 6, 24) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 71

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING AGENTS'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING AGENTS'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "BEDS", 
    "BATHS",
    "SOURCE", 
    "MLS#"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
desired_order = [
    'SOLD DATE',
    'LOCATION',
    'ADDRESS',
    'PRICE',
    'SQUARE FEET',
    '$/SQUARE FEET',
    'YEAR BUILT',
    'LISTING AGENTS',
    'BUYING AGENTS'
]

chart_df = chart_df[desired_order]

# %%
chart_df = chart_df.rename(columns={'$/SQUARE FEET':'PPSF'})

# %%
# Coerce non-numeric to NaN, then you’ll have a float column
chart_df['PPSF'] = pd.to_numeric(chart_df['PPSF'], errors='coerce')

# %%
chart_df['SQUARE FEET'] = pd.to_numeric(chart_df['SQUARE FEET'], errors='coerce')

# %%
chart_df['PPSF'].astype(float)
# Out:
# 0    624.0
# 1    410.0
# 2    702.0
# 3    485.0
# 4    484.0
# 5    438.0
# 6    325.0
# 7    440.0
# 8    383.0
# 9    385.0
# Name: PPSF, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['PPSF'] = chart_df['PPSF'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                   LOCATION  \
# 0 2025-06-26          Europa By The Sea
# 1 2025-06-24                    La Rive
# 2 2025-06-27  LAS OLAS RIVER HOUSE COND
# 3 2025-06-25              Playa Del Mar
# 4 2025-06-25     Tides At Bridgeside Sq
# 5 2025-06-25      BEACHWALK CONDOMINIUM
# 6 2025-06-26  LA MER ESTATES WEST CONDO
# 7 2025-06-25   TOWER PORTSMOUTH AT PORT
# 8 2025-06-26       SEA AIR TOWERS CONDO
# 9 2025-06-24          Royal Coast Condo
#
#                                              ADDRESS       PRICE SQUARE FEET  \
# 0   1460 S Ocean Blvd #1003 in Lauderdale By The Sea  $2,200,000       3,523
# 1            715 Bayshore Dr #504 in Fort Lauderdale  $1,100,000       2,680
# 2          333 Las Olas Way #2301 in Fort Lauderdale    $815,000       1,161
# 3         3900 Galt Ocean Dr #412 in Fort Lauderdale    $800,000       1,649
# 4          3020 NE 32nd Ave #1012 in Fort Lauderdale    $775,000       1,600
# 5  2600 E Hallandale Beach Blvd Unit T1401 in Hal...    $760,000       1,737
# 6     1880 S Ocean Dr Unit TS401 in Hallandale Beach    $630,000       1,940
# 7     3200 Port Royale Dr N #2008 in Fort Lauderdale    $600,000       1,365
# 8                  3725 S Ocean Dr #910 in Hollywood    $548,000       1,431
# 9        2000 S Ocean Blvd Unit 14b in Pompano Beach    $520,000       1,350
#
#    PPSF YEAR BUILT                                     LISTING AGENTS  \
# 0  $624       2006  Marc Brandt Douglas Elliman Jeffery Kotwica Do...
# 1  $410       2004  Alicia Levitan Keller Williams Realty Profess
# 2  $702       2004      Bobbi Ocean Galleria International Realty
# 3  $485       1975  Roderick Perkins Luxury Real Estate Group LLC
# 4  $484       2002                     Eric Miller EXP Realty LLC
# 5  $438       2015      Riad Fayad Sigma Real Estate & Investment
# 6  $325       1974               Vera Aster Beachfront Realty Inc
# 7  $440       1981            Danny Shears Coldwell Banker Realty
# 8  $383       1971          Leo Meyerkov Related ISG Realty, LLC.
# 9  $385       1971                   Nick Wulf REDFIN CORPORATION
#
#                                     BUYING AGENTS
# 0          Gilles Rais Coldwell Banker Realty
# 1              Martine Dreyfus EXP Realty LLC
# 2  Tatiana Silva Optimar International Realty
# 3                Megan Romine Douglas Elliman
# 4         Lori Novello Cortese EXP Realty LLC
# 5            Debora Pludwinski EXP Realty LLC
# 6            Vera Aster Beachfront Realty Inc
# 7                  Eric Miller EXP Realty LLC
# 8          Raul Alvarez My Realty Group, LLC.
# 9                        Randy Lloyd LoKation
