# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Sep. 8th Sep. 15th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE          SOLD DATE PROPERTY TYPE          ADDRESS   CITY  \
# 1  PAST SALE  September-11-2024   Condo/Co-op  3778 SW 27th Ln  Miami
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 1                FL             33134.0  1175000.0   3.0    2.5  ...   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Miami/3778-SW-27th-L...  MARMLS  A11654960
#
#    FAVORITE INTERESTED  LATITUDE  LONGITUDE
# 1         N          Y  25.73969 -80.255813
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
# # Filter dates between. If only using data looking back one week, this shouldn't change the df
# df = df[(df['SOLD DATE'] >= '2024-08-26') & (df['SOLD DATE'] <= '2024-09-02')]

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#     SALE TYPE  SOLD DATE PROPERTY TYPE                         ADDRESS  \
# 85  PAST SALE 2024-09-16   Condo/Co-op        3201 NE 183rd St Ph 2907
# 68  PAST SALE 2024-09-13   Condo/Co-op             780 NE 69th St #807
# 80  PAST SALE 2024-09-13   Condo/Co-op  10233 NW 9th St Cir Unit 106-1
# 21  PAST SALE 2024-09-13   Condo/Co-op       8540 SW 133rd Ave Rd #414
# 72  PAST SALE 2024-09-13   Condo/Co-op         16445 Collins Ave #1625
# ..        ...        ...           ...                             ...
# 33  PAST SALE 2024-09-09   Condo/Co-op             2740 SW 28 Ter #303
# 35  PAST SALE 2024-09-09   Condo/Co-op         18555 Collins Ave #4803
# 73  PAST SALE 2024-09-09   Condo/Co-op          4000 Island Blvd #2301
# 62  PAST SALE 2024-09-09   Condo/Co-op    8600 SW 109th Ave Unit 4-222
# 2   PAST SALE 2024-09-09   Condo/Co-op             234 NE 3rd St #2202
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 85           Aventura                FL             33160.0  1850000.0   3.0
# 68              Miami                FL             33138.0   360000.0   2.0
# 80              Miami                FL             33172.0   330000.0   2.0
# 21              Miami                FL             33183.0   325000.0   3.0
# 72  Sunny Isles Beach                FL             33160.0   950000.0   2.0
# ..                ...               ...                 ...        ...   ...
# 33              Miami                FL             33133.0   250000.0   0.0
# 35  Sunny Isles Beach                FL             33160.0  4200000.0   3.0
# 73           Aventura                FL             33160.0   825000.0   3.0
# 62              Miami                FL             33173.0   212000.0   1.0
# 2               Miami                FL             33132.0   480000.0   2.0
#
#     BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 85    3.0  ...   Sold                         NaN                       NaN
# 68    2.0  ...   Sold                         NaN                       NaN
# 80    2.0  ...   Sold                         NaN                       NaN
# 21    2.0  ...   Sold                         NaN                       NaN
# 72    2.0  ...   Sold                         NaN                       NaN
# ..    ...  ...    ...                         ...                       ...
# 33    1.0  ...   Sold                         NaN                       NaN
# 35    4.5  ...   Sold                         NaN                       NaN
# 73    3.5  ...   Sold                         NaN                       NaN
# 62    1.5  ...   Sold                         NaN                       NaN
# 2     2.0  ...   Sold                         NaN                       NaN
#
#                                                   URL  SOURCE       MLS#  \
# 85  https://www.redfin.com/FL/Aventura/3201-NE-183...  MARMLS  A11566970
# 68  https://www.redfin.com/FL/Miami/780-NE-69th-St...  MARMLS  A11536629
# 80  https://www.redfin.com/FL/Miami/10233-NW-9th-S...  MARMLS  A11560999
# 21  https://www.redfin.com/FL/Miami/8540-SW-133rd-...  MARMLS  A11624328
# 72  https://www.redfin.com/FL/Sunny-Isles-Beach/16...  MARMLS  A11540949
# ..                                                ...     ...        ...
# 33  https://www.redfin.com/FL/Miami/2740-SW-28th-T...  MARMLS  A11622359
# 35  https://www.redfin.com/FL/Sunny-Isles-Beach/18...  MARMLS  A11621758
# 73  https://www.redfin.com/FL/Aventura/4000-Island...  MARMLS  A11581446
# 62  https://www.redfin.com/FL/Miami/8600-SW-109th-...  MARMLS  A11570161
# 2   https://www.redfin.com/FL/Miami/234-NE-3rd-St-...  MARMLS  A11655571
#
#     FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 85         N          Y  25.945719 -80.135657
# 68         N          Y  25.838979 -80.179894
# 80         N          Y  25.778643 -80.362825
# 21         N          Y  25.687171 -80.412419
# 72         N          Y  25.928446 -80.121485
# ..       ...        ...        ...        ...
# 33         N          Y  25.738466 -80.238763
# 35         N          Y  25.948195 -80.120410
# 73         N          Y  25.941569 -80.134850
# 62         N          Y  25.688546 -80.370705
# 2          N          Y  25.776895 -80.189708
#
# [107 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 107

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $876,980

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $574

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $93,836,900

# %%
# # Define the date range
# start_date = '2024-05-20'
# end_date = '2024-05-26'

# # Filter rows where 'SOLD DATE' is within the specified range
# second_week_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %% [markdown]
# ## Previous Week's Values

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 90
# Input Previous Week Condo Average Sales Price:
# 592142
# Input Previous Week Condo Average PSF:
# 475
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 53_300_000

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2024-09-12   Condo/Co-op  15701 Collins Ave #2205
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  7100000.0   4.0
#
#    BATHS             LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5  15701 COLLINS CONDO       3204.0       NaN      2020.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2216.0     5457.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/North-Miami-Beach/15...  MARMLS  A11596165
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.921944 -80.121716
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/North-Miami-Beach/15...  Catherine Kalifeh
#
#       list_broker_name_1 list_agent_name_2     list_broker_name_2  \
# 0  Compass Florida, LLC.      Frank Lustig  Compass Florida, LLC.
#
#   buy_agent_name_1 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0             None              None             None              None     1
#
#     COLOR
# 0  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2024-09-12   Condo/Co-op       15701 Collins Ave #2205
# 1  PAST SALE 2024-09-12   Condo/Co-op       2655 S Bayshore Dr #801
# 2  PAST SALE 2024-09-09   Condo/Co-op       18555 Collins Ave #4803
# 3  PAST SALE 2024-09-10   Condo/Co-op       16051 Collins Ave #3103
# 4  PAST SALE 2024-09-10   Condo/Co-op  2669 S Bayshore Dr Unit 802N
# 5  PAST SALE 2024-09-11   Condo/Co-op       16051 Collins Ave #2001
# 6  PAST SALE 2024-09-12   Condo/Co-op       18975 Collins Ave #4004
# 7  PAST SALE 2024-09-09   Condo/Co-op     848 Brickell Key Dr #1901
# 8  PAST SALE 2024-09-10   Condo/Co-op     848 Brickell Key Dr #1601
# 9  PAST SALE 2024-09-11   Condo/Co-op       17001 Collins Ave #3607
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  7100000.0   4.0
# 1              Miami                FL             33133.0  6554000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0  4200000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0  3900000.0   4.0
# 4              Miami                FL             33133.0  3400000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0  3380000.0   3.0
# 6  Sunny Isles Beach                FL             33160.0  3250000.0   2.0
# 7              Miami                FL             33131.0  2260000.0   3.0
# 8              Miami                FL             33131.0  2250000.0   3.0
# 9  Sunny Isles Beach                FL             33160.0  2100000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5        15701 COLLINS CONDO       3204.0       NaN      2020.0
# 1    3.5           Mr. C Residences       2715.0       NaN      2024.0
# 2    4.5  18555 COLLINS AVENUE COND       3130.0       NaN      2016.0
# 3    5.5     TURNBERRY OCEAN COLONY       3480.0       NaN      2006.0
# 4    3.5                 DINNER KEY       1833.0       NaN      2016.0
# 5    4.5  TURNBERRY OCEAN COLONY NO       2775.0       NaN      2006.0
# 6    2.5        18975 COLLINS CONDO       1688.0       NaN      2019.0
# 7    2.5  THREE TEQUESTA POINT COND       2353.0       NaN      2001.0
# 8    2.5  THREE TEQUESTA POINT COND       2353.0       NaN      2001.0
# 9    3.0                 JADE BEACH       1479.0       NaN      2008.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN
# 3                          None              Alisa Gitman
# 4  AG Real Estate Advisors, LLC            Tarlan Mamedov
# 5     Miami Matrix Realty, LLC.            Uri Sefchovich
# 6                          None          geanemiami Brito
# 7                          None              Natalia Diaz
# 8                          None  Jenny Gutierrez Sandberg
# 9                          None              Maria Bottas
#
#                 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0                            None             None              None     1
# 1            Compass Florida, LLC             None              None     2
# 2          Current Capital Realty             None              None     3
# 3       Miami Matrix Realty, LLC.             None              None     4
# 4              ONE Commercial LLC             None              None     5
# 5               The Keyes Company             None              None     6
# 6           Compass Florida, LLC.             None              None     7
# 7               The Keyes Company             None              None     8
# 8  Keller Williams Capital Realty             None              None     9
# 9    AG Real Estate Advisors, LLC             None              None    10
#
#     COLOR
# 0  orange
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# 5    blue
# 6    blue
# 7    blue
# 8    blue
# 9    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80a748b178f41df1f7c02de586ebb390 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Sep. 8th - Sep. 15th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80a748b178f41df1f7c02de586ebb390&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_80a748b178f41df1f7c02de586ebb390 = L.map(
#                 &quot;map_80a748b178f41df1f7c02de586ebb390&quot;,
#                 {
#                     center: [25.806272021495325, -80.2183593457944],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_4a0b4f98a78bff26b1ad259fe54582d3 = L.featureGroup(
#                 {}
#             ).addTo(map_80a748b178f41df1f7c02de586ebb390);
#
#
#             var marker_9a6385dc3bfc60d8f476dc6bdab797ae = L.marker(
#                 [25.9219435, -80.1217161],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_4a0b4f98a78bff26b1ad259fe54582d3);
#
#
#             var icon_d399a3488245ae5228a8629fb58dce2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a6385dc3bfc60d8f476dc6bdab797ae.setIcon(icon_d399a3488245ae5228a8629fb58dce2e);
#
#
#         var popup_330248a640876c8e51f7d315708a8bd6 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_829c09b492785145ee97019397cf4e3e = $(`&lt;div id=&quot;html_829c09b492785145ee97019397cf4e3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;15701 Collins Ave #2205&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,100,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,216.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,204.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2020.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_330248a640876c8e51f7d315708a8bd6.setContent(html_829c09b492785145ee97019397cf4e3e);
#
#
#
#         marker_9a6385dc3bfc60d8f476dc6bdab797ae.bindPopup(popup_330248a640876c8e51f7d315708a8bd6)
#         ;
#
#
#
#
#             var feature_group_57653b7d37d5b407414ab105aa70adba = L.featureGroup(
#                 {}
#             ).addTo(map_80a748b178f41df1f7c02de586ebb390);
#
#
#             var marker_7c7428ba5eebac7589b7de2148d19a03 = L.marker(
#                 [25.7311964, -80.2362702],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_57653b7d37d5b407414ab105aa70adba);
#
#
#             var icon_85acb985754b027ed97de3f3b3f6ff1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c7428ba5eebac7589b7de2148d19a03.setIcon(icon_85acb985754b027ed97de3f3b3f6ff1d);
#
#
#         var popup_075013949507463890580498cb7f9e9b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2cd8a7f95c54bea6362f259d5bdf105e = $(`&lt;div id=&quot;html_2cd8a7f95c54bea6362f259d5bdf105e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2655 S Bayshore Dr #801&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$6,554,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,414.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,715.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2024.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_075013949507463890580498cb7f9e9b.setContent(html_2cd8a7f95c54bea6362f259d5bdf105e);
#
#
#
#         marker_7c7428ba5eebac7589b7de2148d19a03.bindPopup(popup_075013949507463890580498cb7f9e9b)
#         ;
#
#
#
#
#             var marker_7ced75368b32a1417c1feaedf7017db0 = L.marker(
#                 [25.948195, -80.1204099],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_57653b7d37d5b407414ab105aa70adba);
#
#
#             var icon_a2fd4f15d137dc29c4c0d1dbe4d6db4b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ced75368b32a1417c1feaedf7017db0.setIcon(icon_a2fd4f15d137dc29c4c0d1dbe4d6db4b);
#
#
#         var popup_52aab9b5618ca3d60b89fff22cfefb23 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_681c3c6097aa300aaef2fcc372858bd7 = $(`&lt

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS  \
# 0  PAST SALE 2024-09-12   Condo/Co-op  15701 Collins Ave #2205
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  7100000.0   4.0
#
#    BATHS             LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5  15701 COLLINS CONDO       3204.0       NaN      2020.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2216.0     5457.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/North-Miami-Beach/15...  MARMLS  A11596165
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.921944 -80.121716
#
#                                                  url  list_agent_name_1  \
# 0  https://www.redfin.com/FL/North-Miami-Beach/15...  Catherine Kalifeh
#
#       list_broker_name_1 list_agent_name_2     list_broker_name_2  \
# 0  Compass Florida, LLC.      Frank Lustig  Compass Florida, LLC.
#
#   buy_agent_name_1 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0             None              None             None              None     1
#
#     COLOR
# 0  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_09162024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '15701 COLLINS CONDO at 15701 Collins Ave #2205 in Sunny Isles Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLO
# 1            Compass Florida, LLC             None              None     2
# 2          Current Capital Realty             None              None     3
# 3       Miami Matrix Realty, LLC.             None              None     4
# 4              ONE Commercial LLC             None              None     5
# 5               The Keyes Company             None              None     6
# 6           Compass Florida, LLC.             None              None     7
# 7               The Keyes Company             None              None     8
# 8  Keller Williams Capital Realty             None              None     9
# 9    AG Real Estate Advisors, LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  15701 COLLINS CONDO at 15701 Collins Ave #2205...
# 1    blue  Mr. C Residences at 2655 S Bayshore Dr #801 in...
# 2    blue  18555 COLLINS AVENUE COND at 18555 Collins Ave...
# 3    blue  TURNBERRY OCEAN COLONY at 16051 Collins Ave #3...
# 4    blue  DINNER KEY at 2669 S Bayshore Dr Unit 802N in ...
# 5    blue  TURNBERRY OCEAN COLONY NO at 16051 Collins Ave...
# 6    blue  18975 COLLINS CONDO at 18975 Collins Ave #4004...
# 7    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 8    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 9    blue  JADE BEACH at 17001 Collins Ave #3607 in Sunny...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops Miami-Dade weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m Miami-Dade County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m Miami-Dade County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #MiamiDade condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, Miami-Dade County, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

Miami-Dade County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: 15701 COLLINS CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,100,000M to $7,100,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 107 condo sales totaling $93,836,900 million from Sep. 8th to Sep. 15th. The previous week, brokers closed 90 condo sales totaling $53,300,000.
#
# Last week’s units sold for an average of $876,980, higher than the $592,142 average price from the previous week. The average price per square foot rose to $574 from $475, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,100,000.0 million to $7,100,000.0 million.
#
# 15701 COLLINS CONDO at 15701 Collins Ave #2205 in Sunny Isles Beach took the top spot with a $7,100,000.0 million closing. The sale closed at $2,216.0 per square foot.
#
# Catherine Kalifeh with Compass Florida, LLC., and Frank Lustig with Compass Florida, LLC. had the listing.
# None with None, and None with None represented the buyer.
#
# Mr. C Residences at 2655 S Bayshore Dr #801 in Miami, closed for the second highest amount, $6,554,000.0, or $2,414.0 per square foot.
#
# Sari Shapiro with Douglas Elliman, and None with None had the listing.
# Mayan Van Der Miller with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_09162024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 8th to Sep. 15th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 0  PAST SALE 2024-09-12   Condo/Co-op       15701 Collins Ave #2205
# 1  PAST SALE 2024-09-12   Condo/Co-op       2655 S Bayshore Dr #801
# 2  PAST SALE 2024-09-09   Condo/Co-op       18555 Collins Ave #4803
# 3  PAST SALE 2024-09-10   Condo/Co-op       16051 Collins Ave #3103
# 4  PAST SALE 2024-09-10   Condo/Co-op  2669 S Bayshore Dr Unit 802N
# 5  PAST SALE 2024-09-11   Condo/Co-op       16051 Collins Ave #2001
# 6  PAST SALE 2024-09-12   Condo/Co-op       18975 Collins Ave #4004
# 7  PAST SALE 2024-09-09   Condo/Co-op     848 Brickell Key Dr #1901
# 8  PAST SALE 2024-09-10   Condo/Co-op     848 Brickell Key Dr #1601
# 9  PAST SALE 2024-09-11   Condo/Co-op       17001 Collins Ave #3607
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Sunny Isles Beach                FL             33160.0  7100000.0   4.0
# 1              Miami                FL             33133.0  6554000.0   4.0
# 2  Sunny Isles Beach                FL             33160.0  4200000.0   3.0
# 3  Sunny Isles Beach                FL             33160.0  3900000.0   4.0
# 4              Miami                FL             33133.0  3400000.0   3.0
# 5  Sunny Isles Beach                FL             33160.0  3380000.0   3.0
# 6  Sunny Isles Beach                FL             33160.0  3250000.0   2.0
# 7              Miami                FL             33131.0  2260000.0   3.0
# 8              Miami                FL             33131.0  2250000.0   3.0
# 9  Sunny Isles Beach                FL             33160.0  2100000.0   2.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    5.5        15701 COLLINS CONDO       3204.0       NaN      2020.0
# 1    3.5           Mr. C Residences       2715.0       NaN      2024.0
# 2    4.5  18555 COLLINS AVENUE COND       3130.0       NaN      2016.0
# 3    5.5     TURNBERRY OCEAN COLONY       3480.0       NaN      2006.0
# 4    3.5                 DINNER KEY       1833.0       NaN      2016.0
# 5    4.5  TURNBERRY OCEAN COLONY NO       2775.0       NaN      2006.0
# 6    2.5        18975 COLLINS CONDO       1688.0       NaN      2019.0
# 7    2.5  THREE TEQUESTA POINT COND       2353.0       NaN      2001.0
# 8    2.5  THREE TEQUESTA POINT COND       2353.0       NaN      2001.0
# 9    3.0                 JADE BEACH       1479.0       NaN      2008.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN
# 5     Miami Matrix Realty, LLC.            Uri Sefchovich
# 6                          None          geanemiami Brito
# 7                          None              Natalia Diaz
# 8                          None  Jenny Gutierrez Sandberg
# 9                          None              Maria Bottas
#
#                 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0                            None             None              None     1
# 1            Compass Florida, LLC             None              None     2
# 2          Current Capital Realty             None              None     3
# 3       Miami Matrix Realty, LLC.             None              None     4
# 4              ONE Commercial LLC             None              None     5
# 5               The Keyes Company             None              None     6
# 6           Compass Florida, LLC.             None              None     7
# 7               The Keyes Company             None              None     8
# 8  Keller Williams Capital Realty             None              None     9
# 9    AG Real Estate Advisors, LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  15701 COLLINS CONDO at 15701 Collins Ave #2205...
# 1    blue  Mr. C Residences at 2655 S Bayshore Dr #801 in...
# 2    blue  18555 COLLINS AVENUE COND at 18555 Collins Ave...
# 3    blue  TURNBERRY OCEAN COLONY at 16051 Collins Ave #3...
# 4    blue  DINNER KEY at 2669 S Bayshore Dr Unit 802N in ...
# 5    blue  TURNBERRY OCEAN COLONY NO at 16051 Collins Ave...
# 6    blue  18975 COLLINS CONDO at 18975 Collins Ave #4004...
# 7    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 8    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 9    blue  JADE BEACH at 17001 Collins Ave #3607 in Sunny...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: 15701 COLLINS CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $2,100,000M to $7,100,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #MiamiDade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade County, weekly condo sales, Miami, Sunny Isles Beach
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 107 condo sales totaling $93,836,900 million from Sep. 8th to Sep. 15th. The previous week, brokers closed 90 condo sales totaling $53,300,000.
#
# Last week’s units sold for an average of $876,980, higher than the $592,142 average price from the previous week. The average price per square foot rose to $574 from $475, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $2,100,000.0 million to $7,100,000.0 million.
#
# 15701 COLLINS CONDO at 15701 Collins Ave #2205 in Sunny Isles Beach took the top spot with a $7,100,000.0 million closing. The sale closed at $2,216.0 per square foot.
#
# Catherine Kalifeh with Compass Florida, LLC., and Frank Lustig with Compass Florida, LLC. had the listing.
# None with None, and None with None represented the buyer.
#
# Mr. C Residences at 2655 S Bayshore Dr #801 in Miami, closed for the second highest amount, $6,554,000.0, or $2,414.0 per square foot.
#
# Sari Shapiro with Douglas Elliman, and None with None had the listing.
# Mayan Van Der Miller with Compass Florida, LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_09162024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 8th to Sep. 15th:
#
# Most Expensive
# 15701 COLLINS CONDO, 15701 Collins Ave #2205 in Sunny Isles Beach | Price: $7,100,000 | $2,216 psf | Listing agents: Catherine Kalifeh with Compass Florida, LLC. and Frank Lustig with Compass Florida, LLC. | Buyer's agents: None with None and None with None
# Least Expensive
# JADE BEACH, 17001 Collins Ave #3607 in Sunny Isles Beach | Price: $2,100,000 | $1,420 psf | Listing agents: Ellen Manas with One Sotheby's International Realty and None with None | Buyer's agents: Maria Bottas with AG Real Estate Advisors, LLC and None with None
# Highest Price Per Square Foot
# Mr. C Residences, 2655 S Bayshore Dr #801 in Miami | Price: $6,554,000 | $2,414 psf | Listing agents: Sari Shapiro with Douglas Elliman and None with None | Buyer's agents: Mayan Van Der Miller with Compass Florida, LLC and None with None
# Lowest Price Per Square Foot
# THREE TEQUESTA POINT COND, 848 Brickell Key Dr #1601 in Miami | Price: $2,250,000 | $956 psf | Listing agents: Maria Laviosa with Concept International Realty Inc and None with None | Buyer's agents: Jenny Gutierrez Sandberg with Keller Williams Capital Realty and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/North-Miami-Beach/15701-Collins-Ave-33160/unit-2205/home/171036268

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Miami/2655-S-Bayshore-Dr-33133/unit-801/home/191479727

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Sunny-Isles-Beach/17001-Collins-Ave-33160/unit-3607/home/43407074

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Miami/848-Brickell-Key-Dr-33131/unit-1601/home/43264911

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Miami/2655-S-Bayshore-Dr-33133/unit-801/home/191479727

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Miami/848-Brickell-Key-Dr-33131/unit-1601/home/43264911

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.921944 -80.121716
# 1        N          Y  25.731196 -80.236270
# 2        N          Y  25.948195 -80.120410
# 3        N          Y  25.926219 -80.121522
# 4        N          Y  25.730676 -80.237117
# 5        N          Y  25.926219 -80.121522
# 6        N          Y  25.951740 -80.119755
# 7        N          Y  25.769284 -80.183714
# 8        N          Y  25.769433 -80.183317
# 9        N          Y  25.933531 -80.120941
#
#                                                  url   list_agent_name_1  \
# 0  https://www.redfin.com/FL/North-Miami-Beach/15...   Catherine Kalifeh
# 1  https://www.redfin.com/FL/Miami/2655-S-Bayshor...        Sari Shapiro
# 2  https://www.redfin.com/FL/Sunny-Isles-Beach/18...    Melissa Barragan
# 3  https://www.redfin.com/FL/Sunny-Isles-Beach/16...     Jackson Keddell
# 4  https://www.redfin.com/FL/Miami/2669-S-Bayshor...   Marcello Agostini
# 5  https://www.redfin.com/FL/Sunny-Isles-Beach/16...        Alisa Gitman
# 6  https://www.redfin.com/FL/Sunny-Isles-Beach/18...         Jorge Llano
# 7  https://www.redfin.com/FL/Miami/848-Brickell-K...  Giovanna Fernandez
# 8  https://www.redfin.com/FL/Miami/848-Brickell-K...       Maria Laviosa
# 9  https://www.redfin.com/FL/Sunny-Isles-Beach/17...         Ellen Manas
#
#                    list_broker_name_1 list_agent_name_2  \
# 0               Compass Florida, LLC.      Frank Lustig
# 1                     Douglas Elliman              None
# 2           Dezer Platinum Realty LLC              None
# 3                     Douglas Elliman              None
# 4        AG Real Estate Advisors, LLC    Fernanda Souza
# 5           Miami Matrix Realty, LLC.   Oksana Ivanenko
# 6           Dezer Platinum Realty LLC              None
# 7                     BHHS EWM Realty              None
# 8    Concept International Realty Inc              None
# 9  One Sotheby's International Realty              None
#
#              list_broker_name_2          buy_agent_name_1  \
# 0         Compass Florida, LLC.                      None
# 1                          None      Mayan Van Der Miller
# 2                          None               Todd Nepola
# 3                          None              Alisa Gitman
# 4  AG Real Estate Advisors, LLC            Tarlan Mamedov
# 5     Miami Matrix Realty, LLC.            Uri Sefchovich
# 6                          None          geanemiami Brito
# 7                          None              Natalia Diaz
# 8                          None  Jenny Gutierrez Sandberg
# 9                          None              Maria Bottas
#
#                 buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK  \
# 0                            None             None              None     1
# 1            Compass Florida, LLC             None              None     2
# 2          Current Capital Realty             None              None     3
# 3       Miami Matrix Realty, LLC.             None              None     4
# 4              ONE Commercial LLC             None              None     5
# 5               The Keyes Company             None              None     6
# 6           Compass Florida, LLC.             None              None     7
# 7               The Keyes Company             None              None     8
# 8  Keller Williams Capital Realty             None              None     9
# 9    AG Real Estate Advisors, LLC             None              None    10
#
#     COLOR                                          FULL_NAME
# 0  orange  15701 COLLINS CONDO at 15701 Collins Ave #2205...
# 1    blue  Mr. C Residences at 2655 S Bayshore Dr #801 in...
# 2    blue  18555 COLLINS AVENUE COND at 18555 Collins Ave...
# 3    blue  TURNBERRY OCEAN COLONY at 16051 Collins Ave #3...
# 4    blue  DINNER KEY at 2669 S Bayshore Dr Unit 802N in ...
# 5    blue  TURNBERRY OCEAN COLONY NO at 16051 Collins Ave...
# 6    blue  18975 COLLINS CONDO at 18975 Collins Ave #4004...
# 7    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 8    blue  THREE TEQUESTA POINT COND at 848 Brickell Key ...
# 9    blue  JADE BEACH at 17001 Collins Ave #3607 in Sunny...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 7, 3) ## List (Earlier) date
date2 = datetime(2024, 9, 12) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 71

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")
