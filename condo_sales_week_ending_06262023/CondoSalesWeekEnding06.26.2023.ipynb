# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import tabula

# %% [markdown]
# ## Read-in

# %%
# Gotta figure out how to get rid of the java error.
# SO: https://stackoverflow.com/questions/54817211/java-command-is-not-found-from-this-python-process-please-ensure-java-is-inst

dsf = tabula.read_pdf('condo.pdf', pages='all')

# %% [markdown]
# ## Clean Data

# %%
df = dsf[0]
df.columns = df.iloc[0]
df = df[1:]
df = df.drop(columns=df.columns[0])
df = df.replace(np.nan, 'Not Available', regex=True)
df = df.rename(columns={'Building / Address / City': 'building_address_city','Days on\rMarket':'days_on_market',\
                        'Price /\rSq. Ft.':'price_per_sqft'})
df['building_address_city'] = df['building_address_city'].str.replace('^0', '', regex=True)
df['geo_address'] = df['building_address_city']
df['geo_address'] = df['geo_address'].map(lambda x: re.sub(r'\r', ' ', x))
df = df.replace('\n',' ',regex=True)
pattern = r'^(?P<building_name>[\d\s]*[A-Za-z\s]+)\s(?P<address>.+)\s(?P<city>[A-Za-z\s]+)$'
df2 = df['geo_address']
df2 = df2.to_frame()
df2[['building_name', 'address', 'city']] = df2['geo_address'].str.extract(pattern, expand=True)

# %% [markdown]
# Review this later (it's about how to properly merge DFs): https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## Geocode

# %%
result = pd.merge(df,df2,left_index=True, right_index=True)
df = result
df = df.drop(columns='city')

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['geo_address_x'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# Folium documentation link: https://python-visualization.github.io/folium/index.html
#
# Folium is the library that lets us use leaflet with Python, since it's meant to be used with JavaScript.
#
# For adding titles: https://stackoverflow.com/questions/61928013/adding-a-title-or-text-to-a-folium-map

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df = df.replace('N/A', np.nan)

# %%
df['int_Sale_Price'] = df['Sale Price'].str.replace('$','',regex=False)

# %%
df['int_Sale_Price'] = df['int_Sale_Price'].str.replace(',','',regex=False)

# %%
df['int_Sale_Price'] = pd.to_numeric(df['int_Sale_Price'])

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.replace('$','',regex=False)
df['price_per_sqft'] = df['price_per_sqft'].str.replace(',','',regex=False)
df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'])

df['days_on_market'] = pd.to_numeric(df['days_on_market'])

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df['RANK'] = range(1, len(df) + 1)
# use numpy to assign values to the 'COLOR' column
df['COLOR'] = np.where(df['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['building_address_city', 'Close Date', 'days_on_market', 'Sale Price',
#        'Sq. Ft.', 'price_per_sqft', 'Agent', 'Listing Broker', 'Buyer Agent',
#        'Buyer Broker', 'geo_address_x', 'geo_address_y', 'building_name',
#        'address', 'geocoded', 'lat', 'lon', 'int_Sale_Price', 'RANK', 'COLOR'],
#       dtype='object')

# %%
def popup_html(row):
    building_name = row['building_name']
    price = row['Sale Price']
    days_on_market = row['days_on_market']
    listing_agent = row['Agent']
    buyers_agent = row['Buyer Agent']
    psf = row['price_per_sqft']
    address = row['address']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(building_name) + '''<br>
    <strong>Sale Price: </strong>{}'''.format(price) + '''<br>
    <strong>Days on Market: </strong>{}'''.format(days_on_market) + '''<br>
    <strong>Listing Agent: </strong>{}'''.format(listing_agent) + '''<br>
    <strong>Buyer's Agent: </strong>{}'''.format(buyers_agent) + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(psf) + '''<br>
    <strong>Address: </strong>{}'''.format(address) + '''<br>
    </html>
    '''
    return html

# %%
df
# Out:
#                                 building_address_city Close Date
# 1       Fendi Chateau\r9349 Collins Ave 406\rSurfside  6/21/2023  \
# 2   Oceana Bal Harbour\r10201 Collins Ave 806\rBal...  6/22/2023
# 3         Porto Vita\r19955 NE 38th Ct 2804\rAventura  6/20/2023
# 4    Lake Villa 2\r733 Crandon Blvd PH6\rKey Biscayne  6/21/2023
# 5   Anastasia Coral Gables\r521 Anastasia Ave 521\...  6/20/2023
# 6            The Point\r21200 Point Pl 2504\rAventura  6/23/2023
# 7          Bellamare\r6000 Island Blvd 2304\rAventura  6/22/2023
# 8         Aria on the Bay\r488 NE 18th St 1515\rMiami  6/23/2023
# 9      Millenium Tower\r1435 Brickell Ave 3207\rMiami  6/23/2023
# 10  Trump Tower\r16001 Collins Ave 3104\rSunny Isl...  6/21/2023
#
#     days_on_market      Sale Price Sq. Ft.  price_per_sqft
# 1               67  $19,750,000.00    5720         3452.80  \
# 2               15   $7,875,000.00    3070         3000.00
# 3               29   $3,000,000.00    3950          759.49
# 4              459   $2,752,000.00    2470         1114.17
# 5                7   $2,100,000.00    2976          705.65
# 6               91   $2,080,000.00    3173          655.53
# 7               18   $1,900,000.00    2030          935.96
# 8              192   $1,800,000.00    2018          891.97
# 9              104   $1,785,000.00    1801          991.12
# 10              15   $1,750,000.00    2327          752.04
#
#                        Agent                      Listing Broker
# 1             Ximena Penuela                       Clarte Realty  \
# 2            Jeremy Milgroom                      Grafeno Realty
# 3            Diane Lieberman  One Sotheby's International Realty
# 4   Lucrecia Arana Lindemann                             Destaca
# 5               Elena Kemper                     BHHS EWM Realty
# 6     Sharon Weissman Harari  One Sotheby's International Realty
# 7            Johanna Bassols           Oceanica Real Estate, LLC
# 8            Serena De Marta                  Canvas Real Estate
# 9    Monique Pennen-Wills PA                     BHHS EWM Realty
# 10              Michael Shir        GMT International Realty Inc
#
#              Buyer Agent                   Buyer Broker
# 1        Michele Redlich         Coldwell Banker Realty  \
# 2          Toni Schrager           Brown Harris Stevens
# 3             Beata Hill   Optimar International Realty
# 4         Yunayka Martin                Luxe Properties
# 5          Ashley Cusack                BHHS EWM Realty
# 6        Richard Goihman                Douglas Elliman
# 7   Coromoto Mora Ortega          Beachfront Realty Inc
# 8          Nicole Pellon           Blokhaus Real Estate
# 9          Jason Samuels         Coldwell Banker Realty
# 10        Jaine Gitelman  Trust Invest Real Estate Corp
#
#                                         geo_address_x
# 1         Fendi Chateau 9349 Collins Ave 406 Surfside  \
# 2   Oceana Bal Harbour 10201 Collins Ave 806 Bal H...
# 3           Porto Vita 19955 NE 38th Ct 2804 Aventura
# 4      Lake Villa 2 733 Crandon Blvd PH6 Key Biscayne
# 5   Anastasia Coral Gables 521 Anastasia Ave 521 C...
# 6              The Point 21200 Point Pl 2504 Aventura
# 7            Bellamare 6000 Island Blvd 2304 Aventura
# 8           Aria on the Bay 488 NE 18th St 1515 Miami
# 9        Millenium Tower 1435 Brickell Ave 3207 Miami
# 10  Trump Tower 16001 Collins Ave 3104 Sunny Isles...
#
#                                         geo_address_y           building_name
# 1         Fendi Chateau 9349 Collins Ave 406 Surfside           Fendi Chateau  \
# 2   Oceana Bal Harbour 10201 Collins Ave 806 Bal H...      Oceana Bal Harbour
# 3           Porto Vita 19955 NE 38th Ct 2804 Aventura              Porto Vita
# 4      Lake Villa 2 733 Crandon Blvd PH6 Key Biscayne              Lake Villa
# 5   Anastasia Coral Gables 521 Anastasia Ave 521 C...  Anastasia Coral Gables
# 6              The Point 21200 Point Pl 2504 Aventura               The Point
# 7            Bellamare 6000 Island Blvd 2304 Aventura               Bellamare
# 8           Aria on the Bay 488 NE 18th St 1515 Miami         Aria on the Bay
# 9        Millenium Tower 1435 Brickell Ave 3207 Miami         Millenium Tower
# 10  Trump Tower 16001 Collins Ave 3104 Sunny Isles...             Trump Tower
#
#                                address                          geocoded
# 1                 9349 Collins Ave 406      (25.883, -80.12183999999999)  \
# 2            10201 Collins Ave 806 Bal         (25.8951514, -80.1230855)
# 3                19955 NE 38th Ct 2804  (25.9614457, -80.12616750000001)
# 4           2 733 Crandon Blvd PH6 Key          (25.693713, -80.1628248)
# 5          521 Anastasia Ave 521 Coral         (25.7420923, -80.2651236)
# 6                  21200 Point Pl 2504         (25.9731214, -80.1251248)
# 7                6000 Island Blvd 2304         (25.9426083, -80.1357173)
# 8                  488 NE 18th St 1515         (25.7935581, -80.1870727)
# 9               1435 Brickell Ave 3207         (25.7588046, -80.1922639)
# 10  16001 Collins Ave 3104 Sunny Isles         (25.9244562, -80.1216846)
#
#           lat        lon  int_Sale_Price  RANK   COLOR
# 1   25.883000 -80.121840      19750000.0     1  orange
# 2   25.895151 -80.123086       7875000.0     2    blue
# 3   25.961446 -80.126168       3000000.0     3    blue
# 4   25.693713 -80.162825       2752000.0     4    blue
# 5   25.742092 -80.265124       2100000.0     5    blue
# 6   25.973121 -80.125125       2080000.0     6    blue
# 7   25.942608 -80.135717       1900000.0     7    blue
# 8   25.793558 -80.187073       1800000.0     8    blue
# 9   25.758805 -80.192264       1785000.0     9    blue
# 10  25.924456 -80.121685       1750000.0    10    blue

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format('June 18th - June 24th')


### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['lat'], row['lon']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ad68b7ab2e3d444e47c6158caacda8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;June 18th - June 24th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ad68b7ab2e3d444e47c6158caacda8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5ad68b7ab2e3d444e47c6158caacda8c = L.map(
#                 &quot;map_5ad68b7ab2e3d444e47c6158caacda8c&quot;,
#                 {
#                     center: [25.8567951, -80.15609047000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_bb68e8f50735f9cacc011c56b0a4672c = L.featureGroup(
#                 {}
#             ).addTo(map_5ad68b7ab2e3d444e47c6158caacda8c);
#
#
#             var marker_28b6a52bc3750ad2a6c62b459ed51811 = L.marker(
#                 [25.883, -80.12183999999999],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_bb68e8f50735f9cacc011c56b0a4672c);
#
#
#             var icon_aa7c0ec7e7b75bc6bc358107b9db64af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28b6a52bc3750ad2a6c62b459ed51811.setIcon(icon_aa7c0ec7e7b75bc6bc358107b9db64af);
#
#
#         var popup_ba27dafdbca5f07a18d90e14a72cd816 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9279eda981ed5b29482e6e9a83f08fea = $(`&lt;div id=&quot;html_9279eda981ed5b29482e6e9a83f08fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;Fendi Chateau&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$19,750,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;67&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Ximena Penuela&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;Michele Redlich&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3452.8&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;9349 Collins Ave 406&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ba27dafdbca5f07a18d90e14a72cd816.setContent(html_9279eda981ed5b29482e6e9a83f08fea);
#
#
#
#         marker_28b6a52bc3750ad2a6c62b459ed51811.bindPopup(popup_ba27dafdbca5f07a18d90e14a72cd816)
#         ;
#
#
#
#
#             var feature_group_af859ca19d3af152c3fa01977c78972c = L.featureGroup(
#                 {}
#             ).addTo(map_5ad68b7ab2e3d444e47c6158caacda8c);
#
#
#             var marker_53a28054b04eb50ae697c47a0456dd98 = L.marker(
#                 [25.8951514, -80.1230855],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_af859ca19d3af152c3fa01977c78972c);
#
#
#             var icon_412535a12732a050f280249df496e1c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_53a28054b04eb50ae697c47a0456dd98.setIcon(icon_412535a12732a050f280249df496e1c7);
#
#
#         var popup_ad1fd7ecc4b514ac405c0f218745f86d = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_64b8489c2f8ff211cf769f2a2e0d6d01 = $(`&lt;div id=&quot;html_64b8489c2f8ff211cf769f2a2e0d6d01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;Oceana Bal Harbour&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$7,875,000.00&lt;br&gt;     &lt;strong&gt;Days on Market: &lt;/strong&gt;15&lt;br&gt;     &lt;strong&gt;Listing Agent: &lt;/strong&gt;Jeremy Milgroom&lt;br&gt;     &lt;strong&gt;Buyer&#x27;s Agent: &lt;/strong&gt;Toni Schrager&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$3000.0&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;10201 Collins Ave 806 Bal&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_ad1fd7ecc4b514ac405c0f218745f86d.setContent(html_64b8489c2f8ff211cf769f2a2e0d6d01);
#
#
#
#         marker_53a28054b04eb50ae697c47a0456dd98.bindPopup(popup_ad1fd7ecc4b514ac405c0f218745f86d)
#         ;
#
#
#
#
#             var marker_71cb19ba40de19b97d1b03e8afc4bb41 = L.marker(
#                 [25.9614457, -80.12616750000001],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_af859ca19d3af152c3fa01977c78972c);
#
#
#             var icon_bf3f8d23a5d0df29ba1e12ec711efd44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
### Highest and lowest sale price ###
print(f"{ME}{BR}{df.loc[df['int_Sale_Price'].idxmax()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmax()]['address']} | Price ${df.loc[df['int_Sale_Price'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmax()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmax()]['days_on_market']}")
print(f"{LE}{BR}{df.loc[df['int_Sale_Price'].idxmin()]['building_name']}, {df.loc[df['int_Sale_Price'].idxmin()]['address']} | Price ${df.loc[df['int_Sale_Price'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['int_Sale_Price'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['int_Sale_Price'].idxmin()]['Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Agent']} with {df.loc[df['int_Sale_Price'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['int_Sale_Price'].idxmin()]['days_on_market']}")
### Highest and lowest psf ###
print(f"{MAX_PSF}{BR}{df.loc[df['price_per_sqft'].idxmax()]['building_name']}, {df.loc[df['price_per_sqft'].idxmax()]['address']} | Price ${df.loc[df['price_per_sqft'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmax()]['Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmax()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmax()]['days_on_market']}")
print(f"{MIN_PSF}{BR}{df.loc[df['price_per_sqft'].idxmin()]['building_name']}, {df.loc[df['price_per_sqft'].idxmin()]['address']} | Price ${df.loc[df['price_per_sqft'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['price_per_sqft'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['price_per_sqft'].idxmin()]['Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['price_per_sqft'].idxmin()]['Buyer Agent']} with {df.loc[df['price_per_sqft'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['price_per_sqft'].idxmin()]['days_on_market']}")
### Highest and lowest days on market ###
print(f"{DAYS_MAX}{BR}{df.loc[df['days_on_market'].idxmax()]['building_name']}, {df.loc[df['days_on_market'].idxmax()]['address']} | Price ${df.loc[df['days_on_market'].idxmax()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmax()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmax()]['Agent']} with {df.loc[df['days_on_market'].idxmax()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmax()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmax()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmax()]['days_on_market']}")
print(f"{DAYS_MIN}{BR}{df.loc[df['days_on_market'].idxmin()]['building_name']}, {df.loc[df['days_on_market'].idxmin()]['address']} | Price ${df.loc[df['days_on_market'].idxmin()]['int_Sale_Price']:,.0f} | ${df.loc[df['days_on_market'].idxmin()]['price_per_sqft']:,.0f} psf | Listing agent: {df.loc[df['days_on_market'].idxmin()]['Agent']} with {df.loc[df['days_on_market'].idxmin()]['Listing Broker']} | Buyer's agent: {df.loc[df['days_on_market'].idxmin()]['Buyer Agent']} with {df.loc[df['days_on_market'].idxmin()]['Buyer Broker']} | Days on market: {df.loc[df['days_on_market'].idxmin()]['days_on_market']}")
# Out:
# Most Expensive
# Fendi Chateau, 9349 Collins Ave 406 | Price $19,750,000 | $3,453 psf | Listing agent: Ximena Penuela with Clarte Realty | Buyer's agent: Michele Redlich with Coldwell Banker Realty | Days on market: 67
# Least Expensive
# Trump Tower, 16001 Collins Ave 3104 Sunny Isles | Price $1,750,000 | $752 psf | Listing agent: Michael Shir with GMT International Realty Inc | Buyer's agent: Jaine Gitelman with Trust Invest Real Estate Corp | Days on market: 15
# Highest Price Per Square Foot
# Fendi Chateau, 9349 Collins Ave 406 | Price $19,750,000 | $3,453 psf | Listing agent: Ximena Penuela with Clarte Realty | Buyer's agent: Michele Redlich with Coldwell Banker Realty | Days on market: 67
# Lowest Price Per Square Foot
# The Point, 21200 Point Pl 2504 | Price $2,080,000 | $656 psf | Listing agent: Sharon Weissman Harari with One Sotheby's International Realty | Buyer's agent: Richard Goihman with Douglas Elliman | Days on market: 91
# Most Days on Market
# Lake Villa, 2 733 Crandon Blvd PH6 Key | Price $2,752,000 | $1,114 psf | Listing agent: Lucrecia Arana Lindemann with Destaca | Buyer's agent: Yunayka Martin with Luxe Properties | Days on market: 459
# Fewest Days on Market
# Anastasia Coral Gables, 521 Anastasia Ave 521 Coral | Price $2,100,000 | $706 psf | Listing agent: Elena Kemper with BHHS EWM Realty | Buyer's agent: Ashley Cusack with BHHS EWM Realty | Days on market: 7

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/condo_sales_week_ending_06262023
