# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_May_June_2024.csv',dtype='str')

# %%
df['Doc Recorded'].isna().value_counts()
# Out:
# Doc Recorded
# False    2476
# Name: count, dtype: int64

# %%
len(df[df['Doc Recorded'].str.startswith('6')])
# Out:
# 1002

# %%
# Make sure to update this
print('Enter report month as numeric. Example: January is 1, February is 2, etc...')
first_month = int(input())
print('Enter report month as named string. Example: January...February...')
current_month = input()
# Out:
# Enter report month as numeric. Example: January is 1, February is 2, etc...
# 5
# Enter report month as named string. Example: January...February...
# May

# %%
print(first_month)
print('---------')
print(current_month)
# Out:
# 5
# ---------
# May

# %%
len(df)
# Out:
# 2476

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'], format='mixed')

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 1876

# %% [markdown]
# ## Data Stuff

# %%
# # Count number of earliest month dates
# sep_dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

# print(f'Number of September dates: {sep_dates_count}')

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
# create new column and assign colors based on month
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'red' if x.month == first_month else '')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_23504/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
len(df)
# Out:
# 1611

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 1611

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
df['COLOR'].value_counts()
# Out:
# COLOR
# red    913
#        698
# Name: count, dtype: int64

# %%
# df.to_csv("backup_copy.csv")

# %%
df['COLOR'] = df['COLOR'].replace('', 'yellow')

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'May and June')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_red = folium.FeatureGroup(name=f'May') ## 
fg_yellow = folium.FeatureGroup(name='June')

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'red':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    elif pd.notnull(lat) and pd.notnull(lon) and color == 'yellow':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_yellow)
    else:
        continue

# Add the FeatureGroups to the map
fg_red.add_to(m)
fg_yellow.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bafbe3555cc26eb66bfeaa0e3147e7ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;May and June&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bafbe3555cc26eb66bfeaa0e3147e7ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bafbe3555cc26eb66bfeaa0e3147e7ce = L.map(
#                 &quot;map_bafbe3555cc26eb66bfeaa0e3147e7ce&quot;,
#                 {
#                     center: [41.7912782094763, -87.7283273447631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_0a527e03a97c64b68ce8b8afca979004 = L.featureGroup(
#                 {}
#             ).addTo(map_bafbe3555cc26eb66bfeaa0e3147e7ce);
#
#
#             var circle_marker_630e89b49ecb0b8417b5805a4dd08a1a = L.circleMarker(
#                 [41.5189688, -87.72793589999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0a527e03a97c64b68ce8b8afca979004);
#
#
#         var popup_dac6bdfd4dc06805046451f9ca61faa4 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_02da1f339e2ed607426489a96419937f = $(`&lt;div id=&quot;html_02da1f339e2ed607426489a96419937f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;WILMINGTON SAV FUND SOCIETY FSB TR&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;FREEMAN CAROLYN&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;31-15-317-013-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;329 HOMELAND RD, MATTESON&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$326,400.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_dac6bdfd4dc06805046451f9ca61faa4.setContent(html_02da1f339e2ed607426489a96419937f);
#
#
#
#         circle_marker_630e89b49ecb0b8417b5805a4dd08a1a.bindPopup(popup_dac6bdfd4dc06805046451f9ca61faa4)
#         ;
#
#
#
#
#             var circle_marker_36a92a350321f02e249a48108ff355fa = L.circleMarker(
#                 [41.90917, -87.8112938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0a527e03a97c64b68ce8b8afca979004);
#
#
#         var popup_6ce168c637ac2d18866b20a34087088e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_81f4b3d49c7353c12e37e34b72755849 = $(`&lt;div id=&quot;html_81f4b3d49c7353c12e37e34b72755849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;JPMORGAN CHASE BK NATIONAL ASSOCIATION&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;CHICAGO TITLE LAND TRUST TR&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;12-36-427-043-1003&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;7410 W NORTH AVE, ELMWOOD PARK&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$109,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_6ce168c637ac2d18866b20a34087088e.setContent(html_81f4b3d49c7353c12e37e34b72755849);
#
#
#
#         circle_marker_36a92a350321f02e249a48108ff355fa.bindPopup(popup_6ce168c637ac2d18866b20a34087088e)
#         ;
#
#
#
#
#             var circle_marker_83c273248f7d0b43f761917098ca5dbb = L.circleMarker(
#                 [41.85656230000001, -87.6234583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0a527e03a97c64b68ce8b8afca979004);
#
#
#         var popup_0ba6068fcad4735ee270325ec48d778c = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0b353e617a7305bf8a0f36c564181128 = $(`&lt;div id=&quot;html_0b353e617a7305bf8a0f36c564181128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_may_june_2024

# %% [markdown]
# ## Stats for story

# %%
df['mortgage_amount_int'] = df['mortgage_amount'].str.replace('$','')
df['mortgage_amount_int'] = df['mortgage_amount_int'].str.replace(',','')
df = df.loc[df['mortgage_amount_int'] != 'NA']
df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)

# %%
# Count number of first month dates
dates_count = len(df.loc[df['Doc Recorded'].dt.month == first_month])

print(f'Number of {current_month} dates: {dates_count}')
# Out:
# Number of May dates: 845

# %%
df['Doc Recorded'].dt.month.value_counts()
# Out:
# Doc Recorded
# 5    845
# 6    632
# Name: count, dtype: int64

# %%
# Filter for March
df_may = df[df['Doc Recorded'].dt.month == 5]

# Filter for April
df_june = df[df['Doc Recorded'].dt.month == 6]

# %%
df_may.reset_index(inplace=True, drop=True)
df_june.reset_index(inplace=True, drop=True)

# %%
# x.at[123,'mortgage_amount_int']=33130000
# x.at[123,'mortgage_amount']='$33,130,000'

# x.at[16,'mortgage_amount_int']=173600
# x.at[16,'mortgage_amount']='$173,600'

# %%
print(f'May foreclosures: {len(df_march)}')
print('----------')
print(f'June foreclosures: {len(df_april)}')
# Out:
# May foreclosures: 845
# ----------
# June foreclosures: 632

# %%
df_may.sort_values(by='mortgage_amount_int',ascending=False).head(2)
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 8       View  2412308062   2024-05-02    4/30/2024  LIS PENDENS FORECLOSURE
# 624     View  2415009013   2024-05-29          NaN  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.                           1st Grantor      1st Grantee  \
# 8           NaN                       BANK OF AMER NA  3 FNP OWNER LLC
# 624         NaN  CGCMT 2016-P5 SOUTH MICHIGAN AVE LLC     332 PROP LLC
#
#       Assoc. Doc#                                          deed_urls  \
# 8    1823534065.0  https://crs.cookcountyclerkil.gov/Document/Det...
# 624  1627255096.0  https://crs.cookcountyclerkil.gov/Document/Det...
#
#                     PIN                      Address COLOR  \
# 8    17-09-462-015-0000     70 W MADISON ST, CHICAGO   red
# 624  17-15-107-018-0000  330 S MICHIGAN AVE, CHICAGO   red
#
#                                          mortgage_urls  mortgage_amount  \
# 8    https://crs.cookcountyclerkil.gov/Document/Det...  $305,000,000.00
# 624  https://crs.cookcountyclerkil.gov/Document/Det...   $32,500,000.00
#
#                                      geo_address                   geocoded  \
# 8       70 W MADISON ST, CHICAGO Cook County, IL  (41.8821962, -87.6300878)
# 624  330 S MICHIGAN AVE, CHICAGO Cook County, IL   (41.877479, -87.6245598)
#
#            lat        lon  mortgage_amount_int
# 8    41.882196 -87.630088            305000000
# 624  41.877479 -87.624560             32500000

# %%
print(df_may.iloc[624]['mortgage_urls'])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=NDIyODY2MzI1&hId=ZGUxNDU1ZjFkYWFkMWNlZTkzYmZmNTRmNzhmMzg2OWMzMWQ0ZTYxMzk5ZmJmNGFiZmE4MjQ2MzE0NTY5NmI2ZA2

# %%
df_june.sort_values(by='mortgage_amount_int',ascending=False).iloc[0:1]
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 621     View  2416424550   2024-06-12          NaN  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.           1st Grantor                             1st Grantee  \
# 621         NaN  VMC FIN 2021-FL4 LLC  SCRE II SHAFER CRT LIMITED PARTNERSHIP
#
#       Assoc. Doc#                                          deed_urls  \
# 621  1934506145.0  https://crs.cookcountyclerkil.gov/Document/Det...
#
#                     PIN                   Address   COLOR  \
# 621  12-03-100-015-0000  6400 SHAFER CT, ROSEMONT  yellow
#
#                                          mortgage_urls mortgage_amount  \
# 621  https://crs.cookcountyclerkil.gov/Document/Det...  $17,900,000.00
#
#                                   geo_address                   geocoded  \
# 621  6400 SHAFER CT, ROSEMONT Cook County, IL  (41.9945895, -87.8642756)
#
#            lat        lon  mortgage_amount_int
# 621  41.994589 -87.864276             17900000

# %%
print(df_june['mortgage_urls'].iloc[621])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=MjYwOTk4MjE1&hId=YzIwZjJkYmEyZDNhZWE0YTU4OTc1YjQ5OTQ0YmYwMmJkNDVmNGY3NjM5NjQ1NmYxNTM5MjYwZThiZDBiYWU0MQ2

# %%
print(f'{current_month}: ${df_may.mortgage_amount_int.sum():,}')
# Out:
# May: $552,713,746

# %%
print(f'June: ${df_june.mortgage_amount_int.sum():,}')
# Out:
# June: $161,296,165

# %%
252_713_746 + 161_296_165
# Out:
# 414009911

# %%
52 + 39 + 24 + 13
# Out:
# 128

# %%
df_may['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# MIDFIRST BANK                             65
# US BANK TRUST NATIONAL ASSN TR            52
# LAKEVIEW LOAN SERVICING LLC               43
# NATIONSTAR MTG LLC                        42
# US BK NATIONAL ASSOCIATION                39
# JPMORGAN CHASE BK NATIONAL ASSOCIATION    31
# WILMINGTON SAV FUND SOCIETY FSB TR        30
# DEUTSCHE BK NATIONAL TRUST COMPANY TR     29
# NEWREZ LLC                                29
# US BANK NATIONAL ASSN TR                  24
# FIFTH THIRD BK NATIONAL ASSOCIATION       21
# PENNYMAC LOAN SERVICES LLC                20
# WELLS FARGO BK NA                         19
# FREEDOM MTG CORPORATION                   18
# HUNTINGTON NATL BANK                      13
# CARRINGTON MTG SERVICES LLC               13
# US BANK TRUST COMPANY NATIONAL ASSN TR    13
# ROCKET MTG LLC                            13
# FEDERAL HOME LOAN MORTGAGE CORP TR        12
# GREENSPRING CAP MANAGEMENT LLC            12
# PNC BK NATIONAL ASSOCIATION               11
# CROSSCOUNTRY MTG LLC                      10
# BANK OF AMER NA                           10
# BANK OF NEW YORK MELLON TR                 9
# SERVBANK SB                                9
# LOANDEPOTCOM LLC                           9
# SELECT PORTFOLIO SERVICING INC             7
# FIFTH THIRD BK NA                          7
# SPECIALIZED LOAN SERVICING LLC             7
# PHH MTG CORPORATION                        6
# MORTGAGE ASSETS MGMT LLC                   5
# MATRIX FIN SERVICES CORPORATION            5
# MCLP ASSET CO INC                          5
# WINTRUST MORTGAGE                          5
# HSBC BK USA NA TR                          5
# WELLS FARGO BK NA TR                       4
# ATHENE ANNUITY AND LIFE COMPANY            4
# HSBC BANK USA NATIONAL ASSN TR             4
# ABL RPC RESIDENTIAL CREDIT ACQ LLC         4
# TOORAK CAP PARTNERS LLC                    4
# WILMINGTON TRUST NATIONAL ASSN TR          4
# BMO BK NA                                  4
# WILMINGTON SAV FUND SOCIETY FSB            3
# M&T BANK                                   3
# COASTAL COMM BANK                          3
# FEDERAL HOME LOAN MTG CORPORATION          3
# FEDERAL SAV BANK                           3
# CITIZENS BK NA                             3
# GREENSPRING CAP MANAGEMENT LLC TR          3
# SERVIS ONE INC                             3
# JP MORGAN MORTGAGE ACQ CORP                2
# ONSLOW BAY FIN LLC                         2
# WELLS FARGO BANK NATIONAL ASSN TR          2
# FLAGSTAR BK NA                             2
# FEDERAL NATIONAL MTG ASSOCIATION           2
# F ST INVESTMENTS LLC                       2
# WILMINGTON TRUST NA TR                     2
# US BK NA TR                                2
# MOVEMENT MTG LLC                           2
# COMMUNITY LOAN SERVICING LLC               2
# Name: count, dtype: int64

# %%
32 + 27 + 20 + 9
# Out:
# 88

# %%
df_june['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# NEWREZ LLC                                  36
# US BK NATIONAL ASSOCIATION                  32
# NATIONSTAR MTG LLC                          32
# US BANK TRUST NATIONAL ASSN TR              27
# LAKEVIEW LOAN SERVICING LLC                 26
# FEDERAL HOME LOAN MORTGAGE CORP TR          23
# DEUTSCHE BK NATIONAL TRUST COMPANY TR       23
# FREEDOM MTG CORPORATION                     20
# US BANK NATIONAL ASSN TR                    20
# WILMINGTON SAV FUND SOCIETY FSB TR          19
# MIDFIRST BANK                               17
# WELLS FARGO BK NA                           15
# PENNYMAC LOAN SERVICES LLC                  14
# PNC BK NATIONAL ASSOCIATION                 13
# CARRINGTON MTG SERVICES LLC                 12
# JPMORGAN CHASE BK NATIONAL ASSOCIATION      12
# PHH MTG CORPORATION                         12
# FIFTH THIRD BK NATIONAL ASSOCIATION         11
# LOANDEPOTCOM LLC                            10
# BANK OF NEW YORK MELLON TR                   9
# FIFTH THIRD BK NA                            9
# US BANK TRUST COMPANY NATIONAL ASSN TR       9
# ROCKET MTG LLC                               8
# HSBC BANK USA NATIONAL ASSN TR               7
# CITIMORTGAGE INC                             7
# MORTGAGE ASSETS MGMT LLC                     6
# QUICKEN LOANS LLC                            6
# HSBC BK USA NA TR                            5
# ATHENE ANNUITY AND LIFE COMPANY              5
# BANK OF AMER NA                              5
# HUNTINGTON NATL BANK                         4
# ASSOCIATED BK NA                             4
# INTERSTATE INTRINSIC VALUE FUND A LLC        4
# PLANET HOME LENDG LLC                        4
# WELLS FARGO BANK NATIONAL ASSN TR            4
# WILMINGTON SAV FUND SOCIETY FSB              4
# LAND HOME FIN SERVICES INC                   3
# JP MORGAN MORTGAGE ACQ CORP                  3
# BANK OF NEW YORK MELLON TRUST CO NA TR       3
# CROSSCOUNTRY MTG LLC                         3
# SHARESTATES INVESTMENTS LLC                  3
# SELECT PORTFOLIO SERVICING INC               3
# METROPOLITAN TOWER LIFE INST COMPANY         3
# US BK TRUST COMPANY NATIONAL ASSOCIATION     3
# BMO BK NA                                    3
# SERVIS ONE INC                               3
# STAR 212 LLC                                 2
# BANK UNITED NA                               2
# OLD NATL BANK                                2
# QUICKEN LOANS INC                            2
# HSBC BK USA NATIONAL ASSOCIATION             2
# CITIBANK NA                                  2
# FEDERAL NATIONAL MTG ASSOCIATION             2
# F ST INVESTMENTS LLC                         2
# BYLINE BANK                                  2
# WEST COAST SERVICING INC                     2
# CITIZENS BK NA                               2
# MATRIX FIN SERVICES CORPORATION              2
# M&T BANK                                     2
# BUDMAN BUILDING LLC                          2
# Name: count, dtype: int64

# %%
df_march['1st Grantee'].value_counts()
# Out:
# 1st Grantee
# CHICAGO TITLE LAND TRUST CO TR    4
# HUSSAIN ALI                       2
# PORTER JASON                      2
# OLSHANSKY EDWARD                  2
# ILLINOIS HOUSING DEV AUTHORITY    2
#                                  ..
# SLAY JAMAAR                       1
# FERNANDEZ IRENE A                 1
# PARKER EFEREM                     1
# DIXON TAMIRRA                     1
# RAZZAQ ALI                        1
# Name: count, Length: 1020, dtype: int64

# %%
df_april['1st Grantee'].value_counts()
# Out:
# 1st Grantee
# ALJ INVESTMENTS INC               5
# JACKSON ANDRE L                   5
# LV HALSTED LLC                    4
# JACKSON ANDRE                     4
# US BANK TRUST NATIONAL ASSN TR    2
#                                  ..
# FLETCHER DOUGLAS G JR             1
# HAMLET DEQUINCY L                 1
# RELIFORD BILLY G JR               1
# MEDINA ROCIO                      1
# RUPERT CURTIS                     1
# Name: count, Length: 886, dtype: int64

# %%
df.to_csv(f'{current_month}_June_2024_foreclosures.csv')

# %%
# apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
print(f"{current_month} median mortgage foreclosure amount: ${df_may['mortgage_amount_int'].median():,}")
# Out:
# May median mortgage foreclosure amount: $171,400.0

# %%
print(f"April median mortgage foreclosure amount: ${df_june['mortgage_amount_int'].median():,}")
# Out:
# April median mortgage foreclosure amount: $161,025.0

# %% [markdown]
# ## Boundary Analysis

# %%
boundaries = gpd.read_file('Boundaries - Neighborhoods.geojson')

# %%
# create Point objects from lat/lon columns in df
geometry = gpd.points_from_xy(x['lon'], x['lat'])

# create geodataframe from df with Point objects as geometry
gdf_filings_x = gpd.GeoDataFrame(x, geometry=geometry)

gdf_filings_x.crs = 'EPSG:4326'
gdf_filings_x = gdf_filings_x.to_crs(boundaries.crs)

# use contains method to get count of points within each neighborhood
counts_x = gpd.sjoin(gdf_filings_x, boundaries, predicate='within').groupby('pri_neigh').size().reset_index(name='count')

# %%
counts_x['count'].sum()
# Out:
# 517
