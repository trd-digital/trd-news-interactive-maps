# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Mar. 30th Apr. 6th

# %%
filename = glob.glob('*redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE      SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 1  PAST SALE  March-31-2025   Condo/Co-op  800 Cypress Grove Dr #110
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 1  Pompano Beach                FL             33069.0  300000.0   3.0    2.5
#
#    ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1  ...   Sold                         NaN                       NaN
#
#                                                  URL       SOURCE  \
# 1  https://www.redfin.com/FL/Pompano-Beach/800-Cy...  Beaches MLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1  RX-11047780         N          Y  26.216553 -80.184541
#
# [1 rows x 27 columns]

# %%
print('Input county name:')
county = input()
# Out:
# Input county name:
# Broward County

# %%
def load_last_week_data_df(filename='last_week_data.csv'):
    try:
        return pd.read_csv(filename)
    except FileNotFoundError:
        return None
    
last_week = load_last_week_data_df()

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df2 = df[(df['SOLD DATE'] > one_week_ago) & (df['SOLD DATE'] < today)]

# %%
df2['SOLD DATE'].value_counts()
# Out:
# SOLD DATE
# 2025-03-31    82
# 2025-04-01    46
# 2025-04-04    30
# 2025-04-02    22
# 2025-04-03    21
# Name: count, dtype: int64

# %%
df2 = df2.sort_values(by='PRICE',ascending=False)

# %%
# df2 = df2.drop(index=64)

# %%
df_top_ten = df2.head(10)

# %%
df_top_ten
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE  \
# 17   PAST SALE 2025-04-04   Condo/Co-op
# 8    PAST SALE 2025-03-31   Condo/Co-op
# 76   PAST SALE 2025-03-31   Condo/Co-op
# 125  PAST SALE 2025-03-31   Condo/Co-op
# 7    PAST SALE 2025-04-01   Condo/Co-op
# 103  PAST SALE 2025-04-04   Condo/Co-op
# 187  PAST SALE 2025-04-02   Condo/Co-op
# 148  PAST SALE 2025-04-02   Condo/Co-op
# 89   PAST SALE 2025-04-03   Condo/Co-op
# 90   PAST SALE 2025-03-31   Condo/Co-op
#
#                                     ADDRESS              CITY  \
# 17                 2000 S Ocean Dr Unit 10B  Hallandale Beach
# 8     701 N Fort Lauderdale Beach Blvd #505   Fort Lauderdale
# 76   701 N Fort Lauderdale Beach Blvd #1703   Fort Lauderdale
# 125                      1 Ocean Blvd #1501     Pompano Beach
# 7                411 N New River Dr E #2806   Fort Lauderdale
# 103                    665 SE 21st Ave #309   Deerfield Beach
# 187                    3101 S Ocean Dr #603         Hollywood
# 148                    401 N Birch Rd #1115   Fort Lauderdale
# 89                    1830 S Ocean Dr #2911  Hallandale Beach
# 90                   2011 N Ocean Blvd #705   Fort Lauderdale
#
#     STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 17                 FL             33009.0  2750000.0   4.0    3.5  ...   Sold
# 8                  FL             33304.0  2450000.0   3.0    3.5  ...   Sold
# 76                 FL             33304.0  2295000.0   2.0    2.5  ...   Sold
# 125                FL             33062.0  2150000.0   3.0    3.0  ...   Sold
# 7                  FL             33301.0  1850000.0   3.0    3.5  ...   Sold
# 103                FL             33441.0  1280000.0   2.0    2.0  ...   Sold
# 187                FL             33019.0  1215000.0   2.0    2.5  ...   Sold
# 148                FL             33304.0  1215000.0   2.0    2.5  ...   Sold
# 89                 FL             33009.0  1150000.0   2.0    2.0  ...   Sold
# 90                 FL             33305.0  1100000.0   3.0    3.0  ...   Sold
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 17                          NaN                       NaN
# 8                           NaN                       NaN
# 76                          NaN                       NaN
# 125                         NaN                       NaN
# 7                           NaN                       NaN
# 103                         NaN                       NaN
# 187                         NaN                       NaN
# 148                         NaN                       NaN
# 89                          NaN                       NaN
# 90                          NaN                       NaN
#
#                                                    URL       SOURCE  \
# 17   https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS
# 8    https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS
# 76   https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS
# 125  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...       MARMLS
# 7    https://www.redfin.com/FL/Fort-Lauderdale/411-...       MARMLS
# 103  https://www.redfin.com/FL/Deerfield-Beach/665-...  Beaches MLS
# 187  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS
# 148  https://www.redfin.com/FL/Fort-Lauderdale/401-...       MARMLS
# 89   https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS
# 90   https://www.redfin.com/FL/Fort-Lauderdale/2011...       MARMLS
#
#           MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 17   A11742484         N          Y  25.978732 -80.118774
# 8    F10477583         N          Y  26.132895 -80.104208
# 76   F10476475         N          Y  26.132895 -80.104208
# 125  A11691976         N          Y  26.232119 -80.091722
# 7    A11722286         N          Y  26.118085 -80.138584
# 103  F10480329         N          Y  26.308781 -80.076681
# 187  A11655277         N          Y  25.993975 -80.117768
# 148  A11693234         N          Y  26.128355 -80.106535
# 89   A11717120         N          Y  25.984911 -80.118344
# 90   A11712607         N          Y  26.154538 -80.101733
#
# [10 rows x 27 columns]

# %%
# df_top_ten = df2.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op                2000 S Ocean Dr Unit 10B
# 1  PAST SALE 2025-03-31   Condo/Co-op   701 N Fort Lauderdale Beach Blvd #505
# 2  PAST SALE 2025-03-31   Condo/Co-op  701 N Fort Lauderdale Beach Blvd #1703
# 3  PAST SALE 2025-03-31   Condo/Co-op                      1 Ocean Blvd #1501
# 4  PAST SALE 2025-04-01   Condo/Co-op              411 N New River Dr E #2806
# 5  PAST SALE 2025-04-04   Condo/Co-op                    665 SE 21st Ave #309
# 6  PAST SALE 2025-04-02   Condo/Co-op                    3101 S Ocean Dr #603
# 7  PAST SALE 2025-04-02   Condo/Co-op                    401 N Birch Rd #1115
# 8  PAST SALE 2025-04-03   Condo/Co-op                   1830 S Ocean Dr #2911
# 9  PAST SALE 2025-03-31   Condo/Co-op                  2011 N Ocean Blvd #705
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
# 1   Fort Lauderdale                FL             33304.0  2450000.0   3.0
# 2   Fort Lauderdale                FL             33304.0  2295000.0   2.0
# 3     Pompano Beach                FL             33062.0  2150000.0   3.0
# 4   Fort Lauderdale                FL             33301.0  1850000.0   3.0
# 5   Deerfield Beach                FL             33441.0  1280000.0   2.0
# 6         Hollywood                FL             33019.0  1215000.0   2.0
# 7   Fort Lauderdale                FL             33304.0  1215000.0   2.0
# 8  Hallandale Beach                FL             33009.0  1150000.0   2.0
# 9   Fort Lauderdale                FL             33305.0  1100000.0   3.0
#
#    BATHS  ...  LONGITUDE                                                url  \
# 0    3.5  ... -80.118774  https://www.redfin.com/FL/Hallandale-Beach/200...
# 1    3.5  ... -80.104208  https://www.redfin.com/FL/Fort-Lauderdale/701-...
# 2    2.5  ... -80.104208  https://www.redfin.com/FL/Fort-Lauderdale/701-...
# 3    3.0  ... -80.091722  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...
# 4    3.5  ... -80.138584  https://www.redfin.com/FL/Fort-Lauderdale/411-...
# 5    2.0  ... -80.076681  https://www.redfin.com/FL/Deerfield-Beach/665-...
# 6    2.5  ... -80.117768  https://www.redfin.com/FL/Hollywood/3101-S-Oce...
# 7    2.5  ... -80.106535  https://www.redfin.com/FL/Fort-Lauderdale/401-...
# 8    2.0  ... -80.118344  https://www.redfin.com/FL/Hallandale-Beach/183...
# 9    3.0  ... -80.101733  https://www.redfin.com/FL/Fort-Lauderdale/2011...
#
#    list_agent_name_1             list_broker_name_1  list_agent_name_2  \
# 0          Devin Kay                Douglas Elliman               None
# 1      Joshua Dotoli           Compass Florida, LLC               None
# 2      Joshua Dotoli           Compass Florida, LLC               None
# 3       Guy Clarizio              The Keyes Company               None
# 4       Susan Fredel     Property Sales & Inv. Inc.               None
# 5      Denise Perron            Perron Realty Corp.               None
# 6    Sandra Pariente  Charles Rutenberg Realty Fort               None
# 7      Maria Salgado     One Sotheby's Int'l Realty               None
# 8      Rosy Pallozzi    Miami Properties Int'l Corp   Letizia Pallozzi
# 9       Juan Iarussi          Compass Florida, LLC.        Lucas Gomez
#
#             list_broker_name_2  buy_agent_name_1            buy_broker_name_1  \
# 0                         None     Elinor Kadosh      Haute Real Estate, Inc.
# 1                         None     James Branham            The Keyes Company
# 2                         None     Joshua Dotoli         Compass Florida, LLC
# 3                         None      Guy Clarizio            The Keyes Company
# 4                         None              None                         None
# 5                         None              None               EXP Realty LLC
# 6                         None       Analia Olas           The Corcoran Group
# 7                         None  Agostina Mittone         Compass Florida, LLC
# 8  Miami Properties Int'l Corp     Rosy Pallozzi  Miami Properties Int'l Corp
# 9        Compass Florida, LLC.              None                         None
#
#    buy_agent_name_2  buy_broker_name_2
# 0              None               None
# 1              None               None
# 2              None               None
# 3              None               None
# 4              None               None
# 5              None               None
# 6              None               None
# 7              None               None
# 8              None               None
# 9              None               None
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df2)
print(len(df2))
# Out:
# 201

# %%
# Average sale price
average_sale_price = round(df2['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $368,669

# %%
# Average PSF
average_price_psf = round(df2['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $303

# %%
# Total sales dollar volume
current_week_condo_sales_total = df2['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $74,102,478

# %%
def save_current_week_data_df(df, filename='last_week_data.csv'):
    df.to_csv(filename, index=False)

# Create a dictionary of your current week data.
current_week_data = {
    "Condo Sales": current_week_condo_sales,
    "Average Sale Price": average_sale_price,
    "Average PSF": average_price_psf,
    "Last Week Total Dollar Volume": current_week_condo_sales_total
}

# Convert the dictionary into a DataFrame.
current_week_summary_df = pd.DataFrame([current_week_data])

# Save the DataFrame to a CSV file.
save_current_week_data_df(current_week_summary_df)

# Next week, load last week's data automatically.
last_week_df = load_last_week_data_df()
if last_week_df is not None:
    print("Last week's data:")
    print(last_week_df)
else:
    print("No previous data found.")
# Out:
# Last week's data:
#    Condo Sales  Average Sale Price  Average PSF  Last Week Total Dollar Volume
# 0          201              368669          303                     74102478.0

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# # Define the date range
# start_date = '2024-12-23'
# end_date = '2024-12-29'

# # Filter the DataFrame between two dates (inclusive)
# old_week = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input Previous Week Condo Sales Total (number units sold):')
# previous_week_condo_sales = input()
previous_week_condo_sales = last_week['Condo Sales'].iloc[0]
print(previous_week_condo_sales)
print('-----------')

print('Input Previous Week Condo Average Sales Price:')
# previous_week_average_sales_price = input()
previous_week_average_sales_price = last_week['Average Sale Price'].iloc[0]
print(previous_week_average_sales_price)
print('-----------')

print('Input Previous Week Condo Average PSF:')
# previous_week_average_psf = input()
previous_week_average_psf = last_week['Average PSF'].iloc[0]
print(previous_week_average_psf)
print('-----------')

print('Input Previous Week Condo Sales total (ex: 198_000_000)')
# previous_week_condo_sales_total = input()
previous_week_condo_sales_total = last_week['Last Week Total Dollar Volume'].iloc[0]
print(previous_week_condo_sales_total)


## Clean Data
# Out:
# Input Previous Week Condo Sales Total (number units sold):
# 152
# -----------
# Input Previous Week Condo Average Sales Price:
# 322334
# -----------
# Input Previous Week Condo Average PSF:
# 270
# -----------
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 48994700.0

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op  2000 S Ocean Dr Unit 10B
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
#
#    BATHS          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  2000 OCEAN CONDO       2913.0       NaN      2022.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          944.0     4734.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...  MARMLS  A11742484
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None    Elinor Kadosh
#
#          buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Haute Real Estate, Inc.             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op                2000 S Ocean Dr Unit 10B
# 1  PAST SALE 2025-03-31   Condo/Co-op   701 N Fort Lauderdale Beach Blvd #505
# 2  PAST SALE 2025-03-31   Condo/Co-op  701 N Fort Lauderdale Beach Blvd #1703
# 3  PAST SALE 2025-03-31   Condo/Co-op                      1 Ocean Blvd #1501
# 4  PAST SALE 2025-04-01   Condo/Co-op              411 N New River Dr E #2806
# 5  PAST SALE 2025-04-04   Condo/Co-op                    665 SE 21st Ave #309
# 6  PAST SALE 2025-04-02   Condo/Co-op                    3101 S Ocean Dr #603
# 7  PAST SALE 2025-04-02   Condo/Co-op                    401 N Birch Rd #1115
# 8  PAST SALE 2025-04-03   Condo/Co-op                   1830 S Ocean Dr #2911
# 9  PAST SALE 2025-03-31   Condo/Co-op                  2011 N Ocean Blvd #705
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
# 1   Fort Lauderdale                FL             33304.0  2450000.0   3.0
# 2   Fort Lauderdale                FL             33304.0  2295000.0   2.0
# 3     Pompano Beach                FL             33062.0  2150000.0   3.0
# 4   Fort Lauderdale                FL             33301.0  1850000.0   3.0
# 5   Deerfield Beach                FL             33441.0  1280000.0   2.0
# 6         Hollywood                FL             33019.0  1215000.0   2.0
# 7   Fort Lauderdale                FL             33304.0  1215000.0   2.0
# 8  Hallandale Beach                FL             33009.0  1150000.0   2.0
# 9   Fort Lauderdale                FL             33305.0  1100000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           2000 OCEAN CONDO       2913.0       NaN      2022.0
# 1    3.5  Paramount Fort Lauderdale       2419.0       NaN      2017.0
# 2    2.5       Paramount Residences       1750.0       NaN      2018.0
# 3    3.0   PLAZA AT OCEANSIDE (THE)       2027.0       NaN      2008.0
# 4    3.5       LAS OLAS GRAND CONDO       2635.0       NaN      2005.0
# 5    2.0         Island Point Condo       1610.0       NaN      1981.0
# 6    2.5          OCEAN PALMS CONDO       1733.0       NaN      2005.0
# 7    2.5        TIFFANY HOUSE CONDO       1293.0       NaN      2018.0
# 8    2.0       BEACH CLUB TWO CONDO       1554.0       NaN      2006.0
# 9    3.0                    The VUE       1685.0       NaN      2005.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          944.0     4734.0   Sold
# 1             NaN         1013.0     4257.0   Sold
# 2             NaN         1311.0     3082.0   Sold
# 3             NaN         1061.0     1731.0   Sold
# 4             NaN          702.0     3440.0   Sold
# 5             NaN          795.0     1000.0   Sold
# 6             NaN          701.0     1855.0   Sold
# 7             NaN          940.0     1777.0   Sold
# 8             NaN          740.0     3721.0   Sold
# 9             NaN          653.0     2003.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11742484
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10477583
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10476475
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...       MARMLS  A11691976
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...       MARMLS  A11722286
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...  Beaches MLS  F10480329
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11655277
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...       MARMLS  A11693234
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS  A11717120
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...       MARMLS  A11712607
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.132895 -80.104208
# 2        N          Y  26.132895 -80.104208
# 3        N          Y  26.232119 -80.091722
# 4        N          Y  26.118085 -80.138584
# 5        N          Y  26.308781 -80.076681
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.128355 -80.106535
# 8        N          Y  25.984911 -80.118344
# 9        N          Y  26.154538 -80.101733
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Guy Clarizio
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...      Susan Fredel
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...     Denise Perron
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...   Sandra Pariente
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...     Maria Salgado
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...     Rosy Pallozzi
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...      Juan Iarussi
#
#               list_broker_name_1 list_agent_name_2  \
# 0                Douglas Elliman              None
# 1           Compass Florida, LLC              None
# 2           Compass Florida, LLC              None
# 3              The Keyes Company              None
# 4     Property Sales & Inv. Inc.              None
# 5            Perron Realty Corp.              None
# 6  Charles Rutenberg Realty Fort              None
# 7     One Sotheby's Int'l Realty              None
# 8    Miami Properties Int'l Corp  Letizia Pallozzi
# 9          Compass Florida, LLC.       Lucas Gomez
#
#             list_broker_name_2  buy_agent_name_1            buy_broker_name_1  \
# 0                         None     Elinor Kadosh      Haute Real Estate, Inc.
# 1                         None     James Branham            The Keyes Company
# 2                         None     Joshua Dotoli         Compass Florida, LLC
# 3                         None      Guy Clarizio            The Keyes Company
# 4                         None              None                         None
# 5                         None              None               EXP Realty LLC
# 6                         None       Analia Olas           The Corcoran Group
# 7                         None  Agostina Mittone         Compass Florida, LLC
# 8  Miami Properties Int'l Corp     Rosy Pallozzi  Miami Properties Int'l Corp
# 9        Compass Florida, LLC.              None                         None
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent {county} County Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} — {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b6f2765b63a5f168ac09c8bc9a77468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Broward County County Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Mar. 30th — Apr. 6th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b6f2765b63a5f168ac09c8bc9a77468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4b6f2765b63a5f168ac09c8bc9a77468 = L.map(
#                 &quot;map_4b6f2765b63a5f168ac09c8bc9a77468&quot;,
#                 {
#                     center: [26.162316205584148, -80.16863417728268],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_1837006cff5251d580bb768290296150 = L.featureGroup(
#                 {}
#             ).addTo(map_4b6f2765b63a5f168ac09c8bc9a77468);
#
#
#             var marker_f01e756c8520212b32f4e9b3d32c93c9 = L.marker(
#                 [25.9787316, -80.1187739],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_1837006cff5251d580bb768290296150);
#
#
#             var icon_560022078b9eefc8796a4af6652d0717 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f01e756c8520212b32f4e9b3d32c93c9.setIcon(icon_560022078b9eefc8796a4af6652d0717);
#
#
#         var popup_263022675ba2d2901d96adba3a205ff2 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_18389393a9f475f905cec08f563ae808 = $(`&lt;div id=&quot;html_18389393a9f475f905cec08f563ae808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;2000 S Ocean Dr Unit 10B&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,750,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$944.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,913.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2022.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_263022675ba2d2901d96adba3a205ff2.setContent(html_18389393a9f475f905cec08f563ae808);
#
#
#
#         marker_f01e756c8520212b32f4e9b3d32c93c9.bindPopup(popup_263022675ba2d2901d96adba3a205ff2)
#         ;
#
#
#
#
#             var feature_group_50d53f61e8bd6be2eadfc284bf68c753 = L.featureGroup(
#                 {}
#             ).addTo(map_4b6f2765b63a5f168ac09c8bc9a77468);
#
#
#             var marker_8ffceae17897f39dae26b5e16f7bd0b0 = L.marker(
#                 [26.1328946, -80.1042085],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_50d53f61e8bd6be2eadfc284bf68c753);
#
#
#             var icon_c6b8fd7ab29f31ef2050ba77af4e384a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ffceae17897f39dae26b5e16f7bd0b0.setIcon(icon_c6b8fd7ab29f31ef2050ba77af4e384a);
#
#
#         var popup_f4970dfe36397ca5f5a617051e2eaa01 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_19ed0bd46f21488a7864f0a399a6ef6d = $(`&lt;div id=&quot;html_19ed0bd46f21488a7864f0a399a6ef6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;701 N Fort Lauderdale Beach Blvd #505&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$2,450,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,013.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;2,419.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2017.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_f4970dfe36397ca5f5a617051e2eaa01.setContent(html_19ed0bd46f21488a7864f0a399a6ef6d);
#
#
#
#         marker_8ffceae17897f39dae26b5e16f7bd0b0.bindPopup(popup_f4970dfe36397ca5f5a617051e2eaa01)
#         ;
#
#
#
#
#             var marker_f29a58841edf553150668629bb269b0f = L.marker(
#                 [26.1328946, -80.1042085],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_50d53f61e8bd6be2eadfc284bf68c753);
#
#
#             var icon_37315a18c88af5eb701ed338f86f6068 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f29a58841edf553150668629bb269b0f.setIcon(icon_37315a18c88af5eb701ed338f86f6068);
#
#
#         var popup_777856c6180deb4831db8421967ab34b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_900b0dbc1ce5e4d

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op  2000 S Ocean Dr Unit 10B
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
#
#    BATHS          LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0    3.5  2000 OCEAN CONDO       2913.0       NaN      2022.0             NaN
#
#    $/SQUARE FEET  HOA/MONTH STATUS  NEXT OPEN HOUSE START TIME  \
# 0          944.0     4734.0   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...  MARMLS  A11742484
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    Douglas Elliman              None               None    Elinor Kadosh
#
#          buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0  Haute Real Estate, Inc.             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04072024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# '2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B in Hallandale Beach'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op                2000 S Ocean Dr Unit 10B
# 1  PAST SALE 2025-03-31   Condo/Co-op   701 N Fort Lauderdale Beach Blvd #505
# 2  PAST SALE 2025-03-31   Condo/Co-op  701 N Fort Lauderdale Beach Blvd #1703
# 3  PAST SALE 2025-03-31   Condo/Co-op                      1 Ocean Blvd #1501
# 4  PAST SALE 2025-04-01   Condo/Co-op              411 N New River Dr E #2806
# 5  PAST SALE 2025-04-04   Condo/Co-op                    665 SE 21st Ave #309
# 6  PAST SALE 2025-04-02   Condo/Co-op                    3101 S Ocean Dr #603
# 7  PAST SALE 2025-04-02   Condo/Co-op                    401 N Birch Rd #1115
# 8  PAST SALE 2025-04-03   Condo/Co-op                   1830 S Ocean Dr #2911
# 9  PAST SALE 2025-03-31   Condo/Co-op                  2011 N Ocean Blvd #705
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
# 1   Fort Lauderdale                FL             33304.0  2450000.0   3.0
# 2   Fort Lauderdale                FL             33304.0  2295000.0   2.0
# 3     Pompano Beach                FL             33062.0  2150000.0   3.0
# 4   Fort Lauderdale                FL             33301.0  1850000.0   3.0
# 5   Deerfield Beach                FL             33441.0  1280000.0   2.0
# 6         Hollywood                FL             33019.0  1215000.0   2.0
# 7   Fort Lauderdale                FL             33304.0  1215000.0   2.0
# 8  Hallandale Beach                FL             33009.0  1150000.0   2.0
# 9   Fort Lauderdale                FL             33305.0  1100000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           2000 OCEAN CONDO       2913.0       NaN      2022.0
# 1    3.5  Paramount Fort Lauderdale       2419.0       NaN      2017.0
# 2    2.5       Paramount Residences       1750.0       NaN      2018.0
# 3    3.0   PLAZA AT OCEANSIDE (THE)       2027.0       NaN      2008.0
# 4    3.5       LAS OLAS GRAND CONDO       2635.0       NaN      2005.0
# 5    2.0         Island Point Condo       1610.0       NaN      1981.0
# 6    2.5          OCEAN PALMS CONDO       1733.0       NaN      2005.0
# 7    2.5        TIFFANY HOUSE CONDO       1293.0       NaN      2018.0
# 8    2.0       BEACH CLUB TWO CONDO       1554.0       NaN      2006.0
# 9    3.0                    The VUE       1685.0       NaN      2005.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          944.0     4734.0   Sold
# 1             NaN         1013.0     4257.0   Sold
# 2             NaN         1311.0     3082.0   Sold
# 3             NaN         1061.0     1731.0   Sold
# 4             NaN          702.0     3440.0   Sold
# 5             NaN          795.0     1000.0   Sold
# 6             NaN          701.0     1855.0   Sold
# 7             NaN          940.0     1777.0   Sold
# 8             NaN          740.0     3721.0   Sold
# 9             NaN          653.0     2003.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11742484
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10477583
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10476475
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...       MARMLS  A11691976
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...       MARMLS  A11722286
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...  Beaches MLS  F10480329
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11655277
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...       MARMLS  A11693234
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS  A11717120
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...       MARMLS  A11712607
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.132895 -80.104208
# 2        N          Y  26.132895 -80.104208
# 3        N          Y  26.232119 -80.091722
# 4        N          Y  26.118085 -80.138584
# 5        N          Y  26.308781 -80.076681
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.128355 -80.106535
# 8        N          Y  25.984911 -80.118344
# 9        N          Y  26.154538 -80.101733
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Guy Clarizio
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...      Susan Fredel
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...     Denise Perron
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...   Sandra Pariente
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...     Maria Salgado
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...     Rosy Pallozzi
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...      Juan Iarussi
#
#               list_broker_name_1 list_agent_name_2  \
# 0                Douglas Elliman              None
# 1           Compass Florida, LLC              None
# 2           Compass Florida, LLC              None
# 3              The Keyes Company              None
# 4     Property Sales & Inv. Inc.              None
# 5            Perron Realty Corp.              None
# 6  Charles Rutenberg Realty Fort              None
# 7     One Sotheby's Int'l Realty              None
# 8    Miami Properties Int'l Corp  Letizia Pallozzi
# 9          Compass Florida, LLC.       Lucas Gomez
#
#             list_broker_name_2  buy_agent_name_1            buy_broker_name_1  \
# 0                         None     Elinor Kadosh      Haute Real Estate, Inc.
# 1                         None     James Branham            The Keyes Company
# 2                         None     Joshua Dotoli         Compass Florida, LLC
# 3                         None      Guy Clarizio            The Keyes Company
# 4                         None              None                         None
# 5                         None              None               EXP Realty LLC
# 6                         None       Analia Olas           The Corcoran Group
# 7                         None  Agostina Mittone         Compass Florida, LLC
# 8  Miami Properties Int'l Corp     Rosy Pallozzi  Miami Properties Int'l Corp
# 9        Compass Florida, LLC.              None                         None
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR  \
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue
#
#                                            FULL_NAME
# 0  2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B i...
# 1  Paramount Fort Lauderdale at 701 N Fort Lauder...
# 2  Paramount Residences at 701 N Fort Lauderdale ...
# 3  PLAZA AT OCEANSIDE (THE) at 1 Ocean Blvd #1501...
# 4  LAS OLAS GRAND CONDO at 411 N New River Dr E #...
# 5  Island Point Condo at 665 SE 21st Ave #309 in ...
# 6  OCEAN PALMS CONDO at 3101 S Ocean Dr #603 in H...
# 7  TIFFANY HOUSE CONDO at 401 N Birch Rd #1115 in...
# 8  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2911 ...
# 9  The VUE at 2011 N Ocean Blvd #705 in Fort Laud...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f} to ${df_top_ten.at[0,'PRICE']:,.0f}
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Kate Hinsche
\033[1mRESEARCH:\033[0m Adam Farence
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Image of the top sale

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}, condos, condo market

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: 2000 OCEAN CONDO closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $1,100,000 to $2,750,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Hollywood, Fort Lauderdale, Deerfield Beach, Hallandale Beach, Pompano Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 201 condo sales totaling $74,102,478 million from Mar. 30th to Apr. 6th. The previous week, brokers closed 152 condo sales totaling $48,994,700.
#
# Last week’s units sold for an average of $368,669, higher than the $322,334 average price from the previous week. The average price per square foot rose to $303 from $270, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,100,000.0 million to $2,750,000.0 million.
#
# 2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B in Hallandale Beach took the top spot with a $2,750,000.0 million closing. The sale closed at $944.0 per square foot.
#
# Devin Kay with Douglas Elliman, and None with None had the listing.
# Elinor Kadosh with Haute Real Estate, Inc., and None with None represented the buyer.
#
# Paramount Fort Lauderdale at 701 N Fort Lauderdale Beach Blvd #505 in Fort Lauderdale, closed for the second highest amount, $2,450,000.0, or $1,013.0 per square foot.
#
# Joshua Dotoli with Compass Florida, LLC, and None with None had the listing.
# James Branham with The Keyes Company, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 30th to Apr. 6th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op                2000 S Ocean Dr Unit 10B
# 1  PAST SALE 2025-03-31   Condo/Co-op   701 N Fort Lauderdale Beach Blvd #505
# 2  PAST SALE 2025-03-31   Condo/Co-op  701 N Fort Lauderdale Beach Blvd #1703
# 3  PAST SALE 2025-03-31   Condo/Co-op                      1 Ocean Blvd #1501
# 4  PAST SALE 2025-04-01   Condo/Co-op              411 N New River Dr E #2806
# 5  PAST SALE 2025-04-04   Condo/Co-op                    665 SE 21st Ave #309
# 6  PAST SALE 2025-04-02   Condo/Co-op                    3101 S Ocean Dr #603
# 7  PAST SALE 2025-04-02   Condo/Co-op                    401 N Birch Rd #1115
# 8  PAST SALE 2025-04-03   Condo/Co-op                   1830 S Ocean Dr #2911
# 9  PAST SALE 2025-03-31   Condo/Co-op                  2011 N Ocean Blvd #705
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
# 1   Fort Lauderdale                FL             33304.0  2450000.0   3.0
# 2   Fort Lauderdale                FL             33304.0  2295000.0   2.0
# 3     Pompano Beach                FL             33062.0  2150000.0   3.0
# 4   Fort Lauderdale                FL             33301.0  1850000.0   3.0
# 5   Deerfield Beach                FL             33441.0  1280000.0   2.0
# 6         Hollywood                FL             33019.0  1215000.0   2.0
# 7   Fort Lauderdale                FL             33304.0  1215000.0   2.0
# 8  Hallandale Beach                FL             33009.0  1150000.0   2.0
# 9   Fort Lauderdale                FL             33305.0  1100000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           2000 OCEAN CONDO       2913.0       NaN      2022.0
# 1    3.5  Paramount Fort Lauderdale       2419.0       NaN      2017.0
# 2    2.5       Paramount Residences       1750.0       NaN      2018.0
# 3    3.0   PLAZA AT OCEANSIDE (THE)       2027.0       NaN      2008.0
# 4    3.5       LAS OLAS GRAND CONDO       2635.0       NaN      2005.0
# 5    2.0         Island Point Condo       1610.0       NaN      1981.0
# 6    2.5          OCEAN PALMS CONDO       1733.0       NaN      2005.0
# 7    2.5        TIFFANY HOUSE CONDO       1293.0       NaN      2018.0
# 8    2.0       BEACH CLUB TWO CONDO       1554.0       NaN      2006.0
# 9    3.0                    The VUE       1685.0       NaN      2005.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          944.0     4734.0   Sold
# 1             NaN         1013.0     4257.0   Sold
# 2             NaN         1311.0     3082.0   Sold
# 3             NaN         1061.0     1731.0   Sold
# 4             NaN          702.0     3440.0   Sold
# 5             NaN          795.0     1000.0   Sold
# 6             NaN          701.0     1855.0   Sold
# 7             NaN          940.0     1777.0   Sold
# 8             NaN          740.0     3721.0   Sold
# 9             NaN          653.0     2003.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11742484
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10477583
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10476475
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...       MARMLS  A11691976
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...       MARMLS  A11722286
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...  Beaches MLS  F10480329
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11655277
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...       MARMLS  A11693234
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS  A11717120
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...       MARMLS  A11712607
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.132895 -80.104208
# 2        N          Y  26.132895 -80.104208
# 3        N          Y  26.232119 -80.091722
# 4        N          Y  26.118085 -80.138584
# 5        N          Y  26.308781 -80.076681
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.128355 -80.106535
# 8        N          Y  25.984911 -80.118344
# 9        N          Y  26.154538 -80.101733
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Guy Clarizio
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...      Susan Fredel
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...     Denise Perron
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...   Sandra Pariente
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...     Maria Salgado
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...     Rosy Pallozzi
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...      Juan Iarussi
#
#               list_broker_name_1 list_agent_name_2  \
# 0                Douglas Elliman              None
# 1           Compass Florida, LLC              None
# 2           Compass Florida, LLC              None
# 3              The Keyes Company              None
# 4     Property Sales & Inv. Inc.              None
# 5            Perron Realty Corp.              None
# 6  Charles Rutenberg Realty Fort              None
# 7     One Sotheby's Int'l Realty              None
# 8    Miami Properties Int'l Corp  Letizia Pallozzi
# 9          Compass Florida, LLC.       Lucas Gomez
#
#             list_broker_name_2  buy_agent_name_1            buy_broker_name_1  \
# 0                         None     Elinor Kadosh      Haute Real Estate, Inc.
# 1                         None     James Branham            The Keyes Company
# 2                         None     Joshua Dotoli         Compass Florida, LLC
# 3                         None      Guy Clarizio            The Keyes Company
# 4                         None              None                         None
# 5                         None              None               EXP Realty LLC
# 6                         None       Analia Olas           The Corcoran Group
# 7                         None  Agostina Mittone         Compass Florida, LLC
# 8  Miami Properties Int'l Corp     Rosy Pallozzi  Miami Properties Int'l Corp
# 9        Compass Florida, LLC.              None                         None
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR  \
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue
#
#                                            FULL_NAME
# 0  2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B i...
# 1  Paramount Fort Lauderdale at 701 N Fort Lauder...
# 2  Paramount Residences at 701 N Fort Lauderdale ...
# 3  PLAZA AT OCEANSIDE (THE) at 1 Ocean Blvd #1501...
# 4  LAS OLAS GRAND CONDO at 411 N New River Dr E #...
# 5  Island Point Condo at 665 SE 21st Ave #309 in ...
# 6  OCEAN PALMS CONDO at 3101 S Ocean Dr #603 in H...
# 7  TIFFANY HOUSE CONDO at 401 N Birch Rd #1115 in...
# 8  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2911 ...
# 9  The VUE at 2011 N Ocean Blvd #705 in Fort Laud...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}\n")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}\n")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}\n")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']}, in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}\n")


print("\n--------SALE LINKS FOR REFERENCE ONLY--------\n")
print('Top sale: ',df_top_ten['URL'].iloc[0])
print('Second priciest sale: ', df_top_ten['URL'].iloc[1])
print('Cheapest top ten sale: ',df_top_ten['URL'].iloc[-1])
print('Second Cheapest top ten sale: ',df_top_ten['URL'].iloc[-2])
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print('Highest top ten psf: ',max_url)

# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print('Lowest top ten psf: ', min_url)
# Out:
# HED: 2000 OCEAN CONDO closing tops Broward County weekly condo sales
# DEK: Top 10 sales ranged from $1,100,000 to $2,750,000
# FEATURED HED:
# SEO HED: Broward County County Weekly Condo Report
# SEO DESCRIPTION: Broward County County’s condo sales XXXXXXX
# AUTHOR: Kate Hinsche
# RESEARCH: Adam Farence
# Social: #Broward County condo sales XXXXX
# ART:
#
# Image of the top sale
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Broward County, weekly condo sales, Hollywood, Fort Lauderdale, Deerfield Beach, Hallandale Beach, Pompano Beach, condos, condo market
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Broward County County’s NEWS PEG HERE.
#
# Brokers closed 201 condo sales totaling $74,102,478 million from Mar. 30th to Apr. 6th. The previous week, brokers closed 152 condo sales totaling $48,994,700.
#
# Last week’s units sold for an average of $368,669, higher than the $322,334 average price from the previous week. The average price per square foot rose to $303 from $270, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,100,000.0 million to $2,750,000.0 million.
#
# 2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B in Hallandale Beach took the top spot with a $2,750,000.0 million closing. The sale closed at $944.0 per square foot.
#
# Devin Kay with Douglas Elliman, and None with None had the listing.
# Elinor Kadosh with Haute Real Estate, Inc., and None with None represented the buyer.
#
# Paramount Fort Lauderdale at 701 N Fort Lauderdale Beach Blvd #505 in Fort Lauderdale, closed for the second highest amount, $2,450,000.0, or $1,013.0 per square foot.
#
# Joshua Dotoli with Compass Florida, LLC, and None with None had the listing.
# James Branham with The Keyes Company, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/Broward_County_condo_sales_week_ending_04072024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Mar. 30th to Apr. 6th:
#
# Most Expensive
# 2000 OCEAN CONDO, 2000 S Ocean Dr Unit 10B, in Hallandale Beach | Price: $2,750,000 | $944 psf | Listing agents: Devin Kay with Douglas Elliman and None with None | Buyer's agents: Elinor Kadosh with Haute Real Estate, Inc. and None with None
#
# Least Expensive
# The VUE, 2011 N Ocean Blvd #705, in Fort Lauderdale | Price: $1,100,000 | $653 psf | Listing agents: Juan Iarussi with Compass Florida, LLC. and Lucas Gomez with Compass Florida, LLC. | Buyer's agents: None with None and None with None
#
# Highest Price Per Square Foot
# Paramount Residences, 701 N Fort Lauderdale Beach Blvd #1703, in Fort Lauderdale | Price: $2,295,000 | $1,311 psf | Listing agents: Joshua Dotoli with Compass Florida, LLC and None with None | Buyer's agents: Joshua Dotoli with Compass Florida, LLC and None with None
#
# Lowest Price Per Square Foot
# The VUE, 2011 N Ocean Blvd #705, in Fort Lauderdale | Price: $1,100,000 | $653 psf | Listing agents: Juan Iarussi with Compass Florida, LLC. and Lucas Gomez with Compass Florida, LLC. | Buyer's agents: None with None and None with None
#
#
# --------SALE LINKS FOR REFERENCE ONLY--------
#
# Top sale:  https://www.redfin.com/FL/Hallandale-Beach/2000-S-Ocean-Dr-33009/unit-10B/home/145873023
# Second priciest sale:  https://www.redfin.com/FL/Fort-Lauderdale/701-N-Fort-Lauderdale-Beach-Blvd-33304/unit-505/home/144029374
# Cheapest top ten sale:  https://www.redfin.com/FL/Fort-Lauderdale/2011-N-Ocean-Blvd-33305/unit-705/home/42036495
# Second Cheapest top ten sale:  https://www.redfin.com/FL/Hallandale-Beach/1830-S-Ocean-Dr-33009/unit-2911/home/42071543
# Highest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/701-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1703/home/144335639
# Lowest top ten psf:  https://www.redfin.com/FL/Fort-Lauderdale/2011-N-Ocean-Blvd-33305/unit-705/home/42036495

# %%
print('Top sale:', df_top_ten['URL'].iloc[0])
# Out:
# Top sale: https://www.redfin.com/FL/Hallandale-Beach/2000-S-Ocean-Dr-33009/unit-10B/home/145873023

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/701-N-Fort-Lauderdale-Beach-Blvd-33304/unit-505/home/144029374

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2011-N-Ocean-Blvd-33305/unit-705/home/42036495

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Hallandale-Beach/1830-S-Ocean-Dr-33009/unit-2911/home/42071543

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/701-N-Fort-Lauderdale-Beach-Blvd-33304/unit-1703/home/144335639

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Fort-Lauderdale/2011-N-Ocean-Blvd-33305/unit-705/home/42036495

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                                 ADDRESS  \
# 0  PAST SALE 2025-04-04   Condo/Co-op                2000 S Ocean Dr Unit 10B
# 1  PAST SALE 2025-03-31   Condo/Co-op   701 N Fort Lauderdale Beach Blvd #505
# 2  PAST SALE 2025-03-31   Condo/Co-op  701 N Fort Lauderdale Beach Blvd #1703
# 3  PAST SALE 2025-03-31   Condo/Co-op                      1 Ocean Blvd #1501
# 4  PAST SALE 2025-04-01   Condo/Co-op              411 N New River Dr E #2806
# 5  PAST SALE 2025-04-04   Condo/Co-op                    665 SE 21st Ave #309
# 6  PAST SALE 2025-04-02   Condo/Co-op                    3101 S Ocean Dr #603
# 7  PAST SALE 2025-04-02   Condo/Co-op                    401 N Birch Rd #1115
# 8  PAST SALE 2025-04-03   Condo/Co-op                   1830 S Ocean Dr #2911
# 9  PAST SALE 2025-03-31   Condo/Co-op                  2011 N Ocean Blvd #705
#
#                CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0  Hallandale Beach                FL             33009.0  2750000.0   4.0
# 1   Fort Lauderdale                FL             33304.0  2450000.0   3.0
# 2   Fort Lauderdale                FL             33304.0  2295000.0   2.0
# 3     Pompano Beach                FL             33062.0  2150000.0   3.0
# 4   Fort Lauderdale                FL             33301.0  1850000.0   3.0
# 5   Deerfield Beach                FL             33441.0  1280000.0   2.0
# 6         Hollywood                FL             33019.0  1215000.0   2.0
# 7   Fort Lauderdale                FL             33304.0  1215000.0   2.0
# 8  Hallandale Beach                FL             33009.0  1150000.0   2.0
# 9   Fort Lauderdale                FL             33305.0  1100000.0   3.0
#
#    BATHS                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0    3.5           2000 OCEAN CONDO       2913.0       NaN      2022.0
# 1    3.5  Paramount Fort Lauderdale       2419.0       NaN      2017.0
# 2    2.5       Paramount Residences       1750.0       NaN      2018.0
# 3    3.0   PLAZA AT OCEANSIDE (THE)       2027.0       NaN      2008.0
# 4    3.5       LAS OLAS GRAND CONDO       2635.0       NaN      2005.0
# 5    2.0         Island Point Condo       1610.0       NaN      1981.0
# 6    2.5          OCEAN PALMS CONDO       1733.0       NaN      2005.0
# 7    2.5        TIFFANY HOUSE CONDO       1293.0       NaN      2018.0
# 8    2.0       BEACH CLUB TWO CONDO       1554.0       NaN      2006.0
# 9    3.0                    The VUE       1685.0       NaN      2005.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN          944.0     4734.0   Sold
# 1             NaN         1013.0     4257.0   Sold
# 2             NaN         1311.0     3082.0   Sold
# 3             NaN         1061.0     1731.0   Sold
# 4             NaN          702.0     3440.0   Sold
# 5             NaN          795.0     1000.0   Sold
# 6             NaN          701.0     1855.0   Sold
# 7             NaN          940.0     1777.0   Sold
# 8             NaN          740.0     3721.0   Sold
# 9             NaN          653.0     2003.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...       MARMLS  A11742484
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10477583
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...  Beaches MLS  F10476475
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...       MARMLS  A11691976
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...       MARMLS  A11722286
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...  Beaches MLS  F10480329
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...       MARMLS  A11655277
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...       MARMLS  A11693234
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...       MARMLS  A11717120
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...       MARMLS  A11712607
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.978732 -80.118774
# 1        N          Y  26.132895 -80.104208
# 2        N          Y  26.132895 -80.104208
# 3        N          Y  26.232119 -80.091722
# 4        N          Y  26.118085 -80.138584
# 5        N          Y  26.308781 -80.076681
# 6        N          Y  25.993975 -80.117768
# 7        N          Y  26.128355 -80.106535
# 8        N          Y  25.984911 -80.118344
# 9        N          Y  26.154538 -80.101733
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Hallandale-Beach/200...         Devin Kay
# 1  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 2  https://www.redfin.com/FL/Fort-Lauderdale/701-...     Joshua Dotoli
# 3  https://www.redfin.com/FL/Pompano-Beach/1-N-Oc...      Guy Clarizio
# 4  https://www.redfin.com/FL/Fort-Lauderdale/411-...      Susan Fredel
# 5  https://www.redfin.com/FL/Deerfield-Beach/665-...     Denise Perron
# 6  https://www.redfin.com/FL/Hollywood/3101-S-Oce...   Sandra Pariente
# 7  https://www.redfin.com/FL/Fort-Lauderdale/401-...     Maria Salgado
# 8  https://www.redfin.com/FL/Hallandale-Beach/183...     Rosy Pallozzi
# 9  https://www.redfin.com/FL/Fort-Lauderdale/2011...      Juan Iarussi
#
#               list_broker_name_1 list_agent_name_2  \
# 0                Douglas Elliman              None
# 1           Compass Florida, LLC              None
# 2           Compass Florida, LLC              None
# 3              The Keyes Company              None
# 4     Property Sales & Inv. Inc.              None
# 5            Perron Realty Corp.              None
# 6  Charles Rutenberg Realty Fort              None
# 7     One Sotheby's Int'l Realty              None
# 8    Miami Properties Int'l Corp  Letizia Pallozzi
# 9          Compass Florida, LLC.       Lucas Gomez
#
#             list_broker_name_2  buy_agent_name_1            buy_broker_name_1  \
# 0                         None     Elinor Kadosh      Haute Real Estate, Inc.
# 1                         None     James Branham            The Keyes Company
# 2                         None     Joshua Dotoli         Compass Florida, LLC
# 3                         None      Guy Clarizio            The Keyes Company
# 4                         None              None                         None
# 5                         None              None               EXP Realty LLC
# 6                         None       Analia Olas           The Corcoran Group
# 7                         None  Agostina Mittone         Compass Florida, LLC
# 8  Miami Properties Int'l Corp     Rosy Pallozzi  Miami Properties Int'l Corp
# 9        Compass Florida, LLC.              None                         None
#
#   buy_agent_name_2 buy_broker_name_2  RANK   COLOR  \
# 0             None              None     1  orange
# 1             None              None     2    blue
# 2             None              None     3    blue
# 3             None              None     4    blue
# 4             None              None     5    blue
# 5             None              None     6    blue
# 6             None              None     7    blue
# 7             None              None     8    blue
# 8             None              None     9    blue
# 9             None              None    10    blue
#
#                                            FULL_NAME
# 0  2000 OCEAN CONDO at 2000 S Ocean Dr Unit 10B i...
# 1  Paramount Fort Lauderdale at 701 N Fort Lauder...
# 2  Paramount Residences at 701 N Fort Lauderdale ...
# 3  PLAZA AT OCEANSIDE (THE) at 1 Ocean Blvd #1501...
# 4  LAS OLAS GRAND CONDO at 411 N New River Dr E #...
# 5  Island Point Condo at 665 SE 21st Ave #309 in ...
# 6  OCEAN PALMS CONDO at 3101 S Ocean Dr #603 in H...
# 7  TIFFANY HOUSE CONDO at 401 N Birch Rd #1115 in...
# 8  BEACH CLUB TWO CONDO at 1830 S Ocean Dr #2911 ...
# 9  The VUE at 2011 N Ocean Blvd #705 in Fort Laud...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 11, 15) ## List (Earlier) date
date2 = datetime(2025, 4, 4) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 140

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['$/SQUARE FEET'].astype(float)
# Out:
# 0     944.0
# 1    1013.0
# 2    1311.0
# 3    1061.0
# 4     702.0
# 5     795.0
# 6     701.0
# 7     940.0
# 8     740.0
# 9     653.0
# Name: $/SQUARE FEET, dtype: float64

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x) if pd.notnull(x) else x)
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv",index=False)

# %%
chart_df
# Out:
#    SOLD DATE                                            ADDRESS       PRICE  \
# 0 2025-04-04       2000 S Ocean Dr Unit 10B in Hallandale Beach  $2,750,000
# 1 2025-03-31  701 N Fort Lauderdale Beach Blvd #505 in Fort ...  $2,450,000
# 2 2025-03-31  701 N Fort Lauderdale Beach Blvd #1703 in Fort...  $2,295,000
# 3 2025-03-31                1 Ocean Blvd #1501 in Pompano Beach  $2,150,000
# 4 2025-04-01      411 N New River Dr E #2806 in Fort Lauderdale  $1,850,000
# 5 2025-04-04            665 SE 21st Ave #309 in Deerfield Beach  $1,280,000
# 6 2025-04-02                  3101 S Ocean Dr #603 in Hollywood  $1,215,000
# 7 2025-04-02            401 N Birch Rd #1115 in Fort Lauderdale  $1,215,000
# 8 2025-04-03          1830 S Ocean Dr #2911 in Hallandale Beach  $1,150,000
# 9 2025-03-31          2011 N Ocean Blvd #705 in Fort Lauderdale  $1,100,000
#
#   BEDS  BATHS SQUARE FEET YEAR BUILT $/SQUARE FEET       SOURCE       MLS#  \
# 0    4    3.5       2,913       2022          $944       MARMLS  A11742484
# 1    3    3.5       2,419       2017        $1,013  Beaches MLS  F10477583
# 2    2    2.5       1,750       2018        $1,311  Beaches MLS  F10476475
# 3    3    3.0       2,027       2008        $1,061       MARMLS  A11691976
# 4    3    3.5       2,635       2005          $702       MARMLS  A11722286
# 5    2    2.0       1,610       1981          $795  Beaches MLS  F10480329
# 6    2    2.5       1,733       2005          $701       MARMLS  A11655277
# 7    2    2.5       1,293       2018          $940       MARMLS  A11693234
# 8    2    2.0       1,554       2006          $740       MARMLS  A11717120
# 9    3    3.0       1,685       2005          $653       MARMLS  A11712607
#
#                                         LISTING INFO  \
# 0                      Devin Kay Douglas Elliman
# 1             Joshua Dotoli Compass Florida, LLC
# 2             Joshua Dotoli Compass Florida, LLC
# 3                 Guy Clarizio The Keyes Company
# 4        Susan Fredel Property Sales & Inv. Inc.
# 5              Denise Perron Perron Realty Corp.
# 6  Sandra Pariente Charles Rutenberg Realty Fort
# 7       Maria Salgado One Sotheby's Int'l Realty
# 8  Rosy Pallozzi Miami Properties Int'l Corp Leti...
# 9  Juan Iarussi Compass Florida, LLC. Lucas Gomez...
#
#                                      BUYING INFO
# 0      Elinor Kadosh Haute Real Estate, Inc.
# 1            James Branham The Keyes Company
# 2         Joshua Dotoli Compass Florida, LLC
# 3             Guy Clarizio The Keyes Company
# 4
# 5                             EXP Realty LLC
# 6             Analia Olas The Corcoran Group
# 7      Agostina Mittone Compass Florida, LLC
# 8  Rosy Pallozzi Miami Properties Int'l Corp
# 9
