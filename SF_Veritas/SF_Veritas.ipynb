# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import tabula

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('SF_Veritas_Addresses - Sheet1.csv')
df['address_geocode'] = df['address'] + ' San Francisco'

# %% [markdown]
# ## Geocode

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['address_geocode'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# Folium documentation link: https://python-visualization.github.io/folium/index.html
#
# Folium is the library that lets us use leaflet with Python, since it's meant to be used with JavaScript.
#
# For adding titles: https://stackoverflow.com/questions/61928013/adding-a-title-or-text-to-a-folium-map

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
# ### Insert NaNs if needed ###
# df = df.replace('N/A', np.nan)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['address', 'address_geocode', 'geocoded', 'lat', 'lon'], dtype='object')

# %%
def popup_html(row):
    address = row['address']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Address: </strong>{}'''.format(address) + '''<br>
    </html>
    '''
    return html

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Veritas Investments Sales to Prado Group ')


### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(),zoom_start=11.5,tiles=None)

for index, row in df.iterrows():
    marker = folium.Marker(
        location=[row['lat'], row['lon']],
        radius=5,
        fill=True,
        popup=folium.Popup(popup_html(row), max_width=400))
    marker.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ccbd766a8927d5f5621ed9c2a04191b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Veritas Investments Sales to Prado Group &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ccbd766a8927d5f5621ed9c2a04191b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8ccbd766a8927d5f5621ed9c2a04191b = L.map(
#                 &quot;map_8ccbd766a8927d5f5621ed9c2a04191b&quot;,
#                 {
#                     center: [37.78135583809524, -122.41989524761905],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var marker_bf51b7316b6abbd57ac22b06513856af = L.marker(
#                 [37.8029728, -122.4150038],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_8ccbd766a8927d5f5621ed9c2a04191b);
#
#
#         var popup_3c54cb8d5792f5675f9e799e668d53b5 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_882f99cbab35ad7d8a59a25689c83885 = $(`&lt;div id=&quot;html_882f99cbab35ad7d8a59a25689c83885&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;2227 Taylor St.&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_3c54cb8d5792f5675f9e799e668d53b5.setContent(html_882f99cbab35ad7d8a59a25689c83885);
#
#
#
#         marker_bf51b7316b6abbd57ac22b06513856af.bindPopup(popup_3c54cb8d5792f5675f9e799e668d53b5)
#         ;
#
#
#
#
#             var marker_2c80a0f9f31fc9e128d50a5b409f9fac = L.marker(
#                 [37.801428, -122.4230924],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_8ccbd766a8927d5f5621ed9c2a04191b);
#
#
#         var popup_3b6b534187fa0780bc0ebb5f8cf3620e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_6c2412f3e950ad36dc33f5e922fe78c7 = $(`&lt;div id=&quot;html_6c2412f3e950ad36dc33f5e922fe78c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;1305 Lombard St.&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_3b6b534187fa0780bc0ebb5f8cf3620e.setContent(html_6c2412f3e950ad36dc33f5e922fe78c7);
#
#
#
#         marker_2c80a0f9f31fc9e128d50a5b409f9fac.bindPopup(popup_3b6b534187fa0780bc0ebb5f8cf3620e)
#         ;
#
#
#
#
#             var marker_35d83fdebb8376dc69bac57002e931b0 = L.marker(
#                 [37.7983864, -122.4059884],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_8ccbd766a8927d5f5621ed9c2a04191b);
#
#
#         var popup_b401df7dc0004891c28141354404d40a = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_d4fa96f4c7d0d79075f35f710a2ea242 = $(`&lt;div id=&quot;html_d4fa96f4c7d0d79075f35f710a2ea242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;1127-1133 Kearny St.&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_b401df7dc0004891c28141354404d40a.setContent(html_d4fa96f4c7d0d79075f35f710a2ea242);
#
#
#
#         marker_35d83fdebb8376dc69bac57002e931b0.bindPopup(popup_b401df7dc0004891c28141354404d40a)
#         ;
#
#
#
#
#             var marker_af75340bcb24979c272d5582066f5b97 = L.marker(
#                 [37.7839119, -122.4162747],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_8ccbd766a8927d5f5621ed9c2a04191b);
#
#
#         var popup_fd51d55f2eef7acac6cb4d69e8dca638 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_bc652b646b633ea888cbfa75c99da095 = $(`&lt;div id=&quot;html_bc652b646b633ea888cbfa75c99da095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;333-335 Hyde St.&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_fd51d55f2eef7acac6cb4d69e8dca638.setContent(html_bc652b646b633ea888cbfa75c99da095);
#
#
#
#         marker_af75340bcb24979c272d5582066f5b97.bindPopup(popup_fd51d55f2eef7acac6cb4d69e8dca638)
#         ;
#
#
#
#
#             var marker_9a9c1f585bb6c15931b7b0fedaa6cba7 = L.marker(
#                 [37.775869, -122.429757],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(map_8ccbd766a8927d5f5621ed9c2a04191b);
#
#
#         var popup_d63b8155b5cef1f311d29842f4f51ee1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_2208d381fc61ef02bbbe9090b8b26880 = $(`&lt;div id=&quot;html_2208d381fc61ef02bbbe9090b8b26880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Address: &lt;/strong&gt;561-563 Webster St.&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_d63b8155b5cef1f311d29842f4f51ee1.setContent(html_2208d381fc61ef02bbbe9090b8b26880);
#
#
#
#         marker_9a9c1f585bb6c15931b7b0fedaa6cba7.bindPopup(popup_d63b8155b5cef1f311d29842f4f51ee1)
#         ;
#
#
#
#
#             var

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

# %%
cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/SF_Veritas
