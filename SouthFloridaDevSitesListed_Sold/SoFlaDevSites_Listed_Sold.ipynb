# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import os
import folium
import glob

# %% [markdown]
# ## Read-in

# %%
df_listed = pd.read_csv('Dev sites for sale _ recently sold - MAP - Listings.csv')
df_sold = pd.read_csv('Dev sites for sale _ recently sold - MAP - Recent sales.csv')

# %% [markdown]
# ## Data prep

# %%
df_concat = pd.concat([df_listed,df_sold])
df_concat.reset_index(drop=True,inplace=True)

# %%
df_concat
# Out:
#                                  full_address  status  \
# 0                  29 NW 28th Street in Miami  listed
# 1            2214 North Miami Avenue in Miami  listed
# 2                  201 SW 8th Street in Miami  listed
# 3         1501 Northwest 37th Street in Miami  listed
# 4            3302 & 3312 NW 2nd Avenue, Miami  listed
# 5     2200 NW 2ND AVE.\nMIAMI, FLORIDA\n33127  listed
# 6             SW 216 Street and SW 119 Avenue  listed
# 7        459 NE 25th Street, Edgewater, Miami  listed
# 8            523 & 545 NE 125 St, North Miami  listed
# 9    3728 NW 19th Avenue, Allapattah, Florida  listed
# 10  2214 North Miami Avenue, Wynwood, Florida  listed
# 11   SW 127 street & SW 248 street, Princeton  listed
# 12            5300 NW 2nd Ave, Miami, Florida  listed
# 13                      540 NW 79th St, Miami  listed
# 14                2180 Brickell Avenue, Miami  listed
# 15             50 NE 23rd St, Miami, FL 33137  listed
# 16        Old Dixie Highway & SW 220th Street  listed
# 17                          119 NW 24 Street     sold
# 18                         300 NW 29th Street    sold
# 19      7136 Harding Avenue and 600 72 Street    sold
#
#                                          Owner/seller  \
# 0   29 NW 28 STREET LLC, led by Lance Burstyn and ...
# 1   2214 N MIAMI AVE DEVELOPMENT LLC/ 7G REALTY MA...
# 2     Two entities managed by Simon and Antoine Karam
# 3              Josa Property 15, led by Jorge Salazar
# 4                                                 NaN
# 5            Brooklyn-based ABINGDON SQUARE PARTNERS
# 6                                                 NaN
# 7   \nHABITUS EDGEWATER HF1 B, affiliate of Miami-...
# 8           Homestead-based STEMBRIDGE REAL ESTATE CO
# 9   TROPIC PLACE VENTURES managed by Gerard Fernan...
# 10                    New York-based JK Realty Group
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17   113 NW 24 ST led by Elias Mitrani in Miami Beach
# 18   Miami Beach-based Red Group and Matteo Soltadani
# 19    Donald Kahn, Joel Pitrokowski, and Marcia Green
#
#                                           Description  \
# 0   The 0.2-acre site is zoned for 24 residential ...
# 1   The 0.4-acre lot is zoned T6-8-O, which allows...
# 2   The properties have recently realized Rapid Tr...
# 3   The 1.5-acre assemblage is zoned T6-8-O, which...
# 4   Colliers, as the exclusive listing broker, is ...
# 5   The offering presents one of the last\nopportu...
# 6   Colliers is pleased to present Goulds 255, a r...
# 7   The Porosoff Group of Compass Commercial is pr...
# 8   Gridline Properties is pleased to bring to mar...
# 9   Truly shovel ready\nAll impact fees paid ($115...
# 10  Metro 1 Commercial QOZB LLC is proud to presen...
# 11  Subject property located in Homestead with pot...
# 12                                                NaN
# 13  DWNTWN Realty Advisors has been retained exclu...
# 14                                                NaN
# 15  Re: Blanca CRE Poised to Sell the Potentially ...
# 16  • Approved for 132-Units, Surface-Parked Apart...
# 17  A 14,500 SF parcel zoned T5-O within Wynwood’s...
# 18  7,000 sf lot Can develop up to± 13,893 SF on 3...
# 19                                                NaN
#
#                  Neighborhood Asking price Previous sale price  \
# 0                     Wynwood          $5M       $1.1M in 2018
# 1                     Wynwood       $18.8M      $10.8M in 2022
# 2                    Brickell          NaN              $19.5M
# 3                  Allapattah      $11.5M                  NaN
# 4                     Wynwood          NaN                 NaN
# 5                     Wynwood         $31M               $5.1M
# 6   Unincorporated Miami-Dade        $4.5M                 NaN
# 7                   Edgewater        $5.1M               $1.9M
# 8                North Miami           $6M                 NaN
# 9                  Allapattah        $1.3M               $440K
# 10                   Wynwood        $18.8M             $10.8M
# 11                  Princeton        $5.5M                 NaN
# 12                        NaN          NaN                 NaN
# 13                        NaN          NaN                 NaN
# 14                        NaN          NaN                 NaN
# 15                  Edgewater          NaN                 NaN
# 16                        NaN          NaN                 NaN
# 17                    Wynwood          NaN                 NaN
# 18                    Wynwood          NaN                 NaN
# 19                        NaN          NaN                 NaN
#
#                                            story_link  \
# 0                                                 NaN
# 1   https://therealdeal.com/miami/2022/03/31/east-...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                            extra info  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.crexi.com/properties/1281366/flori...
# 4   https://www.crexi.com/properties/1403922/flori...
# 5   https://docs.google.com/spreadsheets/d/1OWoUw_...
# 6   https://www.crexi.com/properties/1416324/flori...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  https://drive.google.com/file/d/1KfsbCDb_f0FrP...
# 13  https://www.loopnet.com/Listing/540-NW-79th-St...
# 14  https://www.crexi.com/properties/1182459/flori...
# 15  https://www.dropbox.com/scl/fo/qrnvlk0khdluqsr...
# 16  https://gokatalyst.sharepoint.com/sites/Kataly...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                       other_addresses Sale price  Sale date
# 0   60 NE 23rd St, Miami, FL 33137 68 NE 23rd St, ...        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                   720 SW 2nd Avenue        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                                 NaN        NaN        NaN
# 5                   2230 NW 2ND AVE. 224 NW 22ND TER.        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                       544 NE 126 St        NaN        NaN
# 9                                                 NaN        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                                NaN        NaN        NaN
# 12     5310 NW 2nd Ave 5318 NW 2nd Ave 225 NW 53rd St        NaN        NaN
# 13                                                NaN        NaN        NaN
# 14                                                NaN        NaN        NaN
# 15                                                NaN        NaN        NaN
# 16                                                NaN        NaN        NaN
# 17                                                NaN      $7.8M    1/25/24
# 18                                                NaN        $5M  1/16/2024
# 19                                                NaN     $12.5M  1/16/2024

# %% [markdown]
# ## Geocode

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df_concat['geocoded'] = df_concat['full_address'].apply(geocode)

# %%
df = df_concat

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].str.strip('()').str.split(', ', expand=True)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# Folium documentation link: https://python-visualization.github.io/folium/index.html
#
# Folium is the library that lets us use leaflet with Python, since it's meant to be used with JavaScript.
#
# For adding titles: https://stackoverflow.com/questions/61928013/adding-a-title-or-text-to-a-folium-map

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df = df.replace('N/A', np.nan)

# %% [markdown]
# ## Prepare Data

# %%
df['status'].unique()
# Out:
# array(['listed', 'sold'], dtype=object)

# %%
df['color'] = ''

df.loc[df['status'] == 'listed', 'color'] = 'red'
df.loc[df['status'] == 'sold', 'color'] = 'blue'

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['full_address', 'status', 'Owner/seller', 'Description', 'Neighborhood',
#        'Asking price', 'Previous sale price', 'story_link', 'extra info',
#        'other_addresses', 'Sale price', 'Sale date', 'geocoded', 'lat', 'lon',
#        'color'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                  full_address  status  \
# 0  29 NW 28th Street in Miami  listed
#
#                                         Owner/seller  \
# 0  29 NW 28 STREET LLC, led by Lance Burstyn and ...
#
#                                          Description Neighborhood  \
# 0  The 0.2-acre site is zoned for 24 residential ...      Wynwood
#
#   Asking price Previous sale price story_link extra info  \
# 0          $5M       $1.1M in 2018        NaN        NaN
#
#                                      other_addresses Sale price Sale date  \
# 0  60 NE 23rd St, Miami, FL 33137 68 NE 23rd St, ...        NaN       NaN
#
#                     geocoded       lat        lon color
# 0  (25.8032799, -80.1956357)  25.80328 -80.195636   red

# %%
def popup_html(row):
    html_parts = []
    html_parts.append('<!DOCTYPE html><html><head><style>.popup-content {max-width: 256px; word-wrap: break-word;}</style></head><body><div class="popup-content">')

    # List of tuples containing the label and value
    info = [
        ('Address', row['full_address']),
        ('Status', row['status']),
        ('Neighborhood', row['Neighborhood']),
        ('Asking Price', row['Asking price']),
        ('Previous Sale Price', row['Previous sale price']),
        ('Sale Price', row['Sale price']),
        ('Sale Date', row['Sale date'])
    ]

    for label, value in info:
        if pd.notna(value):  # Check if the value is not NaN
            html_parts.append(f"<strong>{label}: </strong>{value}<br>")

    html_parts.append('</div></body></html>')
    
    return ''.join(html_parts)

df['legend_text'] = df['status'] + ' (' + df['color'] + ')'

# %%
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format('South Florida Development Sites Listed and Sold.')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Initialize a dictionary to hold the FeatureGroups for each status
status_groups = {}

for index, row in df.iterrows():
    status = row['legend_text']
    icon_color = row['color']  # Assuming you still want to use color for marker icons
    
    # Check if the FeatureGroup for this status already exists; if not, create it
    if status not in status_groups:
        status_groups[status] = folium.FeatureGroup(name=status).add_to(m)
    
    # Create a Marker for each row
    marker = folium.Marker(
        location=[row['lat'], row['lon']],
        popup=folium.Popup(popup_html(row), max_width=400),
        icon=folium.Icon(color=icon_color)  # Use the 'color' value for the icon
    )
    
    # Add the marker to the corresponding status group
    marker.add_to(status_groups[status])

# Add a LayerControl to allow users to toggle status groups
folium.LayerControl(collapsed=False).add_to(m)
folium.TileLayer('OpenStreetMap',control=False).add_to(m)

m.get_root().html.add_child(folium.Element(title_html))

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22106535c8e239d9f2a9c5654b4b3782 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;South Florida Development Sites Listed and Sold.&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22106535c8e239d9f2a9c5654b4b3782&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_22106535c8e239d9f2a9c5654b4b3782 = L.map(
#                 &quot;map_22106535c8e239d9f2a9c5654b4b3782&quot;,
#                 {
#                     center: [25.771728200000002, -80.22476540999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_fc1627302ed27756ce414e693b0a61b2 = L.featureGroup(
#                 {}
#             ).addTo(map_22106535c8e239d9f2a9c5654b4b3782);
#
#
#             var marker_7676f66f41276154b349ad04ad69f20b = L.marker(
#                 [25.8032799, -80.1956357],
#                 {}
#             ).addTo(feature_group_fc1627302ed27756ce414e693b0a61b2);
#
#
#             var icon_1da3b6e50f26cf01891c963e29c19b3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7676f66f41276154b349ad04ad69f20b.setIcon(icon_1da3b6e50f26cf01891c963e29c19b3a);
#
#
#         var popup_f9a9c3f647a77b6b9706b3a977fbe619 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_9b47b3d0ebe5087f369501b9fcbc7d56 = $(`&lt;div id=&quot;html_9b47b3d0ebe5087f369501b9fcbc7d56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;style&gt;.popup-content {max-width: 256px; word-wrap: break-word;}&lt;/style&gt;&lt;/head&gt;&lt;body&gt;&lt;div class=&quot;popup-content&quot;&gt;&lt;strong&gt;Address: &lt;/strong&gt;29 NW 28th Street in Miami&lt;br&gt;&lt;strong&gt;Status: &lt;/strong&gt;listed&lt;br&gt;&lt;strong&gt;Neighborhood: &lt;/strong&gt;Wynwood&lt;br&gt;&lt;strong&gt;Asking Price: &lt;/strong&gt;$5M&lt;br&gt;&lt;strong&gt;Previous Sale Price: &lt;/strong&gt;$1.1M in 2018&lt;br&gt;&lt;/div&gt;&lt;/body&gt;&lt;/html&gt;&lt;/div&gt;`)[0];
#                 popup_f9a9c3f647a77b6b9706b3a977fbe619.setContent(html_9b47b3d0ebe5087f369501b9fcbc7d56);
#
#
#
#         marker_7676f66f41276154b349ad04ad69f20b.bindPopup(popup_f9a9c3f647a77b6b9706b3a977fbe619)
#         ;
#
#
#
#
#             var marker_99aa11292fc6cc3327b8450618df695c = L.marker(
#                 [25.7983285, -80.1951345],
#                 {}
#             ).addTo(feature_group_fc1627302ed27756ce414e693b0a61b2);
#
#
#             var icon_ba862209690da00c6ae639634b4006c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_99aa11292fc6cc3327b8450618df695c.setIcon(icon_ba862209690da00c6ae639634b4006c8);
#
#
#         var popup_a5a0cb61e19f04708bc74824ce83104e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_7153ef6a8bd26189ea596c0fc9378c46 = $(`&lt;div id=&quot;html_7153ef6a8bd26189ea596c0fc9378c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;style&gt;.popup-content {max-width: 256px; word-wrap: break-word;}&lt;/style&gt;&lt;/head&gt;&lt;body&gt;&lt;div class=&quot;popup-content&quot;&gt;&lt;strong&gt;Address: &lt;/strong&gt;2214 North Miami Avenue in Miami&lt;br&gt;&lt;strong&gt;Status: &lt;/strong&gt;listed&lt;br&gt;&lt;strong&gt;Neighborhood: &lt;/strong&gt;Wynwood&lt;br&gt;&lt;strong&gt;Asking Price: &lt;/strong&gt;$18.8M&lt;br&gt;&lt;strong&gt;Previous Sale Price: &lt;/strong&gt;$10.8M in 2022&lt;br&gt;&lt;/div&gt;&lt;/body&gt;&lt;/html&gt;&lt;/div&gt;`)[0];
#                 popup_a5a0cb61e19f04708bc74824ce83104e.setContent(html_7153ef6a8bd26189ea596c0fc9378c46);
#
#
#
#         marker_99aa11292fc6cc3327b8450618df695c.bindPopup(popup_a5a0cb61e19f04708bc74824ce83104e)
#         ;
#
#
#
#
#             var marker_47fd5460e1f22f6b9a816e40061d7e5f = L.marker(
#                 [25.766593, -80.19828299999999],
#                 {}
#             ).addTo(feature_group_fc1627302ed27756ce414e693b0a61b2);
#
#
#             var icon_7864be77d246c5c6ae42e8848122c855 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47fd5460e1f22f6b9a816e40061d7e5f.setIcon(icon_7864be77d246c5c6ae42e8848122c855);
#
#
#         var popup_f3ba5980f7939e460dd116138a0e7981 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_3b2a9191728b5c01a10ee391456c4480 = $(`&lt;div id=&quot;html_3b2a9191728b5c01a10ee391456c4480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;&lt;html&gt;&lt;head&gt;&lt;style&

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/SouthFloridaDevSitesListed_Sold
