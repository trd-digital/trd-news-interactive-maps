# %% [markdown]
# # Imports

# %%
import pandas as pd
import geopandas as gpd
import googlemaps
from shapely.geometry import Point
import os
import numpy as np
import re
from textwrap import shorten
from bs4 import BeautifulSoup
import gspread

# %% [markdown]
# ## Data read-in

# %%
df = pd.read_csv('Mayweather_Map - Sheet1.csv')

# %%
# # Drop the 'URL' column if you no longer need it
# df = df.drop(columns=['URL'])

# %%
# df['Description'].iloc[0]

# %% [markdown]
# ## Article Link Formatter

# %%
# Assuming df is your dataframe
df["short_description"] = df["description"].apply(lambda s: shorten(s, width=20, placeholder=""))
df['remaining_desc'] = df.apply(lambda row: row['description'].replace(str(row['short_description']), ''), axis=1)

# Update 'description_link' with a conditional
df["description_link"] = df.apply(
    lambda row: (
        f'<a href="{row["story_link"]}" target="_blank" rel="noopener noreferrer">{row["short_description"]}</a>'
        + row["remaining_desc"]
        if pd.notna(row["story_link"]) else row["description"]
    ), 
    axis=1
)

df['description_link']
# Out:
# 0    <a href="https://therealdeal.com/new-york/2024...
# 1    <a href="https://therealdeal.com/new-york/2024...
# 2    <a href="https://therealdeal.com/chicago/2024/...
# 3    <a href="https://therealdeal.com/chicago/2024/...
# 4    <a href="https://therealdeal.com/new-york/tris...
# 5    <a href="https://therealdeal.com/miami/2024/11...
# 6        Mayweather is an investor in GO UES portfolio
# 7        Mayweather is an investor in GO UES portfolio
# 8        Mayweather is an investor in GO UES portfolio
# 9        Mayweather is an investor in GO UES portfolio
# Name: description_link, dtype: object

# %% [markdown]
# ## Geocode

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['full_address'].apply(geocode)

# %%
df
# Out:
#                              full_address  \
# 0           Upper Manhattan, New York, NY
# 1           410 10th Avenue, New York, NY
# 2   200 East Randolph Street, Chicago, IL
# 3  433 West Van Buren Street, Chicago, IL
# 4  185 Hudson St, Jersey City, New Jersey
# 5       1116 Ocean Drive, Miami Beach, FL
# 6        600 Grant Street, Pittsburgh, PA
# 7          525 East 72nd St, New York, NY
# 8          419 East 60th St, New York, NY
# 9          1113 York Avenue, New York, NY
#
#                                          description  \
# 0  The retired boxer has gone into contract to pa...
# 1  Mayweather invested in office landlord 601W Co...
# 2  Mayweather is an investor in office landlord 6...
# 3  Mayweather is an investor in office landlord 6...
# 4  Mayweather is an investor in office landlord 6...
# 5  The retired boxer turned real estate investor ...
# 6      Mayweather is an investor in GO UES portfolio
# 7      Mayweather is an investor in GO UES portfolio
# 8      Mayweather is an investor in GO UES portfolio
# 9      Mayweather is an investor in GO UES portfolio
#
#                                           story_link  \
# 0  https://therealdeal.com/new-york/2024/10/16/fl...
# 1  https://therealdeal.com/new-york/2024/11/18/fl...
# 2  https://therealdeal.com/chicago/2024/07/13/urb...
# 3  https://therealdeal.com/chicago/2024/11/11/viz...
# 4  https://therealdeal.com/new-york/tristate/2024...
# 5  https://therealdeal.com/miami/2024/11/21/floyd...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                

# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                             alt_link    short_description  \
# 0                                                NaN    The retired boxer
# 1  https://therealdeal.com/new-york/2021/03/02/he...  Mayweather invested
# 2                                                NaN     Mayweather is an
# 3                                                NaN     Mayweather is an
# 4                                                NaN     Mayweather is an
# 5                                                NaN    The retired boxer
# 6                                                NaN     Mayweather is an
# 7                                                NaN     Mayweather is an
# 8                                                NaN     Mayweather is an
# 9                                                NaN     Mayweather is an
#
#                                       remaining_desc  \
# 0   has gone into contract to pay $402 million fo...
# 1   in office landlord 601W Companies’ largest po...
# 2        investor in office landlord 601W Companies.
# 3        investor in office landlord 601W Companies.
# 4        investor in office landlord 601W Companies.
# 5   turned real estate investor is partnering wit...
# 6                       investor in GO UES portfolio
# 7                       investor in GO UES portfolio
# 8                       investor in GO UES portfolio
# 9                       investor in GO UES portfolio
#
#                                     description_link  \
# 0  <a href="https://therealdeal.com/new-york/2024...
# 1  <a href="https://therealdeal.com/new-york/2024...
# 2  <a href="https://therealdeal.com/chicago/2024/...
# 3  <a href="https://therealdeal.com/chicago/2024/...
# 4  <a href="https://therealdeal.com/new-york/tris...
# 5  <a href="https://therealdeal.com/miami/2024/11...
# 6      Mayweather is an investor in GO UES portfolio
# 7      Mayweather is an investor in GO UES portfolio
# 8      Mayweather is an investor in GO UES portfolio
# 9      Mayweather is an investor in GO UES portfolio
#
#                            geocoded                    geometry
# 0         (40.8240478, -73.9447643)  POINT (-73.94476 40.82405)
# 1         (40.7538202, -73.9990883)  POINT (-73.99909 40.75382)
# 2         (41.8853579, -87.6213768)  POINT (-87.62138 41.88536)
# 3         (41.8766444, -87.6386958)  POINT (-87.63870 41.87664)
# 4          (40.718789, -74.0347299)  POINT (-74.03473 40.71879)
# 5         (25.7818954, -80.1307774)  POINT (-80.13078 25.78190)
# 6  (40.4417487, -79.99478669999999)  POINT (-79.99479 40.44175)
# 7          (40.7664894, -73.951456)  POINT (-73.95146 40.76649)
# 8         (40.7598492, -73.9600368)  POINT (-73.96004 40.75985)
# 9         (40.7599844, -73.9593805)  POINT (-73.95938 40.75998)

# %%
# Strip whitespace from all string columns
gdf.columns = gdf.columns.str.strip()  # Trim whitespace from column names
gdf = gdf.applymap(lambda x: x.strip() if isinstance(x, str) else x)  # Trim whitespace from string values
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_44538/2323350875.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   gdf = gdf.applymap(lambda x: x.strip() if isinstance(x, str) else x)  # Trim whitespace from string values

# %%
# Convert all data to strings if possible, or remove complex structures
for col in gdf.columns:
    if gdf[col].dtype == object:
        try:
            gdf[col] = gdf[col].astype(str)
        except Exception as e:
            print(f"Could not convert column {col}: {e}")
            gdf.drop(columns=[col], inplace=True)

# %%
gdf.to_file('map_data.geojson', driver='GeoJSON')

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MayweatherMap

# %%
gdf.columns
# Out:
# Index(['full_address', 'description', 'story_link', 'alt_link',
#        'short_description', 'remaining_desc', 'description_link', 'geocoded',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# <a href="https://therealdeal.com/chicago/2024/04/03/david-gassman-sells-chicago-apartment-portfolio-for-72m/"> 6954 North Sheridan Road, Chicago</a>
