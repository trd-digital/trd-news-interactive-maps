# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
from datetime import datetime, timedelta
import glob
from tqdm.notebook import tqdm
import requests
import time

# %% [markdown]
# ## Read-in

# %%
# Get today's date
today = datetime.now()

today = today - timedelta(days=1)

# Get the date one week ago
one_week_ago = today - timedelta(days=7)

# Function to format the date with the correct ordinal suffix
def format_date_with_ordinal(date):
    day = date.day
    if 4 <= day <= 20 or 24 <= day <= 30:
        suffix = "th"
    else:
        suffix = ["st", "nd", "rd"][day % 10 - 1]
    return date.strftime(f"%b. {day}{suffix}")

# Format both dates
week_ending = format_date_with_ordinal(today)
week_starting = format_date_with_ordinal(one_week_ago)

print(week_starting, week_ending)
# Out:
# Sep. 22nd Sep. 29th

# %%
filename = glob.glob('redfin*.csv')
df_list = []
for file in filename:
    df = pd.read_csv(file)
    df_list.append(df)
    
df = pd.concat(df_list)

# %%
df = df.rename(columns={'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)':'URL'})

# %%
remove_string = 'In accordance with local MLS rules, some MLS listings are not included in the download'
df = df[~df['SALE TYPE'].str.contains(remove_string)]

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    SALE TYPE          SOLD DATE PROPERTY TYPE                       ADDRESS  \
# 1  PAST SALE  September-26-2024   Condo/Co-op  9727 Hammocks Blvd Unit 201D
#
#     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ...  \
# 1  Miami                FL             33196.0  290000.0   2.0    2.0  ...
#
#   STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1   Sold                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 1  https://www.redfin.com/FL/Miami/9727-Hammocks-...  MARMLS  A11645151
#
#    FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1         N          Y  25.674392 -80.438318
#
# [1 rows x 27 columns]

# %%
# new_row = {'SALE TYPE':'PAST SALE','SOLD DATE':'PLACEHOLDER',
#           'PROPERTY TYPE':'Condo/Co-op',
#           'ADDRESS':'PLACEHOLDER',
#           'CITY':'PLACEHOLDER',
#           'STATE OR PROVINCE':'FL',
#           'ZIP OR POSTAL CODE':'PLACEHOLDER',
#           'PRICE':99999999999,
#           'BEDS':9999999999,
#           'BATHS':999999999,
#           'LOCATION':'PLACEHOLDER',
#           'SQUARE FEET':9999999999,
#           'LOT SIZE':None,
#           'YEAR BUILT':'PLACEHOLDER',
#           'DAYS ON MARKET':None,
#           '$/SQUARE FEET':9999999999,
#           'HOA/MONTH':999999999,
#           'STATUS':'Sold',
#           'NEXT OPEN HOUSE START TIME':'PLACEHOLDER',
#           'NEXT OPEN HOUSE END TIME':'PLACEHOLDER',
#           'URL':'Manual Entry',
#           'SOURCE':'Manual Entry',
#           'MLS#':'Manual Entry',
#           'FAVORITE':'N',
#           'INTERESTED':'Y',
#           'LATITUDE':99.999999999,
#           'LONGITUDE':99.999999999}

# %%
df['SOLD DATE'] = pd.to_datetime(df['SOLD DATE'])

# %%
df.sort_values(ascending=False, by='SOLD DATE')
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                            ADDRESS  \
# 106  PAST SALE 2024-09-30   Condo/Co-op             9410 W Flagler St #206
# 97   PAST SALE 2024-09-30   Condo/Co-op  13953 Kendale Lakes Cir Unit 208B
# 61   PAST SALE 2024-09-27   Condo/Co-op  9375 Fontainebleau Blvd Unit L201
# 100  PAST SALE 2024-09-27   Condo/Co-op         10383 N Kendall Dr Unit N6
# 42   PAST SALE 2024-09-27   Condo/Co-op             2765 Coconut Ave #2765
# ..         ...        ...           ...                                ...
# 90   PAST SALE 2024-09-23   Condo/Co-op        1111 SW 1st Ave Unit 2522-N
# 91   PAST SALE 2024-09-23   Condo/Co-op         1331 Brickell Bay Dr #1604
# 21   PAST SALE 2024-09-23   Condo/Co-op         10839 NW 7th St Unit 12-21
# 95   PAST SALE 2024-09-23   Condo/Co-op          79 SW 12th St Unit 1412-S
# 82   PAST SALE 2024-09-23   Condo/Co-op                1330 West Ave #1806
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 106        Miami                FL             33174.0   305000.0   2.0
# 97         Miami                FL             33183.0   390000.0   3.0
# 61         Miami                FL             33172.0   250000.0   2.0
# 100        Miami                FL             33176.0   215000.0   2.0
# 42         Miami                FL             33133.0  1100000.0   2.0
# ..           ...               ...                 ...        ...   ...
# 90         Miami                FL             33130.0   625000.0   2.0
# 91         Miami                FL             33131.0   735000.0   1.0
# 21         Miami                FL             33172.0   299250.0   3.0
# 95         Miami                FL             33130.0   660000.0   2.0
# 82   Miami Beach                FL             33139.0   850000.0   2.0
#
#      BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 106    2.0  ...   Sold                         NaN                       NaN
# 97     2.5  ...   Sold                         NaN                       NaN
# 61     2.0  ...   Sold                         NaN                       NaN
# 100    1.0  ...   Sold                         NaN                       NaN
# 42     2.5  ...   Sold                         NaN                       NaN
# ..     ...  ...    ...                         ...                       ...
# 90     2.0  ...   Sold                         NaN                       NaN
# 91     1.0  ...   Sold                         NaN                       NaN
# 21     2.0  ...   Sold                         NaN                       NaN
# 95     2.0  ...   Sold                         NaN                       NaN
# 82     2.0  ...   Sold                         NaN                       NaN
#
#                                                    URL  SOURCE       MLS#  \
# 106  https://www.redfin.com/FL/Miami/9410-W-Flagler...  MARMLS  A11521989
# 97   https://www.redfin.com/FL/Miami/13953-Kendale-...  MARMLS  A11587306
# 61   https://www.redfin.com/FL/Miami/9375-Fontaineb...  MARMLS  A11628586
# 100  https://www.redfin.com/FL/Miami/10383-N-Kendal...  MARMLS  A11560869
# 42   https://www.redfin.com/FL/Miami/2765-Coconut-A...  MARMLS  A11642674
# ..                                                 ...     ...        ...
# 90   https://www.redfin.com/FL/Miami/1111-SW-1st-Av...  MARMLS  A11598318
# 91   https://www.redfin.com/FL/Miami/1331-Brickell-...  MARMLS  A11586663
# 21   https://www.redfin.com/FL/Miami/10839-NW-7th-S...  MARMLS  A11618022
# 95   https://www.redfin.com/FL/Miami/79-SW-12th-St-...  MARMLS  A11589380
# 82   https://www.redfin.com/FL/Miami-Beach/1330-Wes...  MARMLS  A11606508
#
#      FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 106         N          Y  25.768424 -80.350482
# 97          N          Y  25.706342 -80.421354
# 61          N          Y  25.777793 -80.345176
# 100         N          Y  25.689023 -80.361368
# 42          N          Y  25.738089 -80.239088
# ..        ...        ...        ...        ...
# 90          N          Y  25.762842 -80.194655
# 91          N          Y  25.760000 -80.189163
# 21          N          Y  25.778064 -80.372267
# 95          N          Y  25.762650 -80.194765
# 82          N          Y  25.784783 -80.143443
#
# [120 rows x 27 columns]

# %%
df = df.sort_values(by='PRICE',ascending=False)

# %%
# df = df.drop(index=64)

# %%
df_top_ten = df.head(10)

# %% [markdown]
# ## Collect Agent Information

# %%
def process_response(url):
    try:
        
        base_url = "https://redfin-com-data.p.rapidapi.com/properties/detail-by-url"

        querystring = {"url":url}

        headers = {
            "x-rapidapi-key": "00191da588msh8450293d26e3515p1bbd40jsn56510b513b61",
            "x-rapidapi-host": "redfin-com-data.p.rapidapi.com"
        }

        response = requests.get(base_url, headers=headers, params=querystring)

#         print(response.status_code)
#         print(url)
        time.sleep(0.2)

        response.raise_for_status()
        data = response.json()

        # Initialize default values for listing and buyer agents data
        list_agent_name_1 = None
        list_broker_name_1 = None
        list_agent_name_2 = None
        list_broker_name_2 = None
        
        buy_agent_name_1 = None
        buy_broker_name_1 = None
        buy_agent_name_2 = None
        buy_broker_name_2 = None
        
        # Extract listing agents data if it exists
        listing_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('listingAgents', [])
        if len(listing_agents) > 0:
            list_agent_name_1 = listing_agents[0].get('agentInfo', {}).get('agentName')
            list_broker_name_1 = listing_agents[0].get('brokerName')
        if len(listing_agents) > 1:
            list_agent_name_2 = listing_agents[1].get('agentInfo', {}).get('agentName')
            list_broker_name_2 = listing_agents[1].get('brokerName')
            
        # Extract listing agents data if it exists
        buying_agents = data.get('data', {}).get('mainHouseInfoPanelInfo', {}).get('mainHouseInfo', {}).get('buyingAgents', [])
        if len(buying_agents) > 0:
            buy_agent_name_1 = buying_agents[0].get('agentInfo', {}).get('agentName')
            buy_broker_name_1 = buying_agents[0].get('brokerName')
        if len(buying_agents) > 1:
            buy_agent_name_2 = buying_agents[1].get('agentInfo', {}).get('agentName')
            buy_broker_name_2 = buying_agents[1].get('brokerName')


        return {
            'url': url,
            'list_agent_name_1': list_agent_name_1,
            'list_broker_name_1': list_broker_name_1,
            'list_agent_name_2': list_agent_name_2,
            'list_broker_name_2': list_broker_name_2,
            'buy_agent_name_1': buy_agent_name_1,
            'buy_broker_name_1': buy_broker_name_1,
            'buy_agent_name_2': buy_agent_name_2,
            'buy_broker_name_2': buy_broker_name_2,
        }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return {
            'url': url,
            'list_agent_name_1': None,
            'list_broker_name_1': None,
            'list_agent_name_2': None,
            'list_broker_name_2': None,
            'buy_agent_name_1': None,
            'buy_broker_name_1': None,
            'buy_agent_name_2': None,
            'buy_broker_name_2': None,
        }

# %%
response_list = []

for index, row in df_top_ten.iterrows():
    response_list.append(process_response(row['URL']))

# %%
response_df = pd.DataFrame(response_list)

# %%
merged_df = pd.merge(left=df_top_ten,left_on='URL',right=response_df, right_on='url')

# %%
df_top_ten = merged_df

# %% [markdown]
# ## Current Week's Values

# %%
# Number of condos sold
current_week_condo_sales = len(df)
print(len(df))
# Out:
# 120

# %%
# Average sale price
average_sale_price = round(df['PRICE'].mean())
print(f'${average_sale_price:,.0f}')
# Out:
# $656,812

# %%
# Average PSF
average_price_psf = round(df['$/SQUARE FEET'].mean())
print(f'${average_price_psf:,.0f}')
# Out:
# $475

# %%
# Total sales dollar volume
current_week_condo_sales_total = df['PRICE'].sum()
print(f'${current_week_condo_sales_total:,.0f}')
# Out:
# $78,817,493

# %% [markdown]
# ## Previous Week's Values
#
# ### The below 2 cells are only used if we need to back fill from an earlier week than just last week.
#
# For example, if we start in a new locale and comparison information can't get pulled from an existing story

# %%
# Define the date range
# start_date = '2024-09-08'
# end_date = '2024-09-15'

# Filter the DataFrame between two dates (inclusive)
# filtered_df = df[(df['SOLD DATE'] >= start_date) & (df['SOLD DATE'] <= end_date)]

# %%
# # comparison week total sales
# print(f'Comparison week filtered sales: {(len(old_week))}')
# print('-----------')
# print(f'Comparison week average sales price: ${old_week["PRICE"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week average psf: ${old_week["$/SQUARE FEET"].mean():,.02f}')
# print('-----------')
# print(f'Comparison week sales total: ${old_week["PRICE"].sum():,.02f}')
# print('-----------')

# %%
print('Input county name:')
county = input()
print('Input Previous Week Condo Sales Total (number units sold):')
previous_week_condo_sales = input()
print('Input Previous Week Condo Average Sales Price:')
previous_week_average_sales_price = input()
print('Input Previous Week Condo Average PSF:')
previous_week_average_psf = input()
print('Input Previous Week Condo Sales total (ex: 198_000_000)')
previous_week_condo_sales_total = input()
# Out:
# Input county name:
# Miami-Dade
# Input Previous Week Condo Sales Total (number units sold):
# 134
# Input Previous Week Condo Average Sales Price:
# 684642
# Input Previous Week Condo Average PSF:
# 503
# Input Previous Week Condo Sales total (ex: 198_000_000)
# 93_800_000

# %% [markdown]
# ## Clean Data

# %%
# df_top_ten

# %% [markdown]
# ## Correction section

# %%
# df.at[index#,'col_name']

# %% [markdown]
# ## Format Data

# %%
### Insert NaNs if needed ###
df_top_ten = df_top_ten.replace('N/A', np.nan)

# %% [markdown]
# ## Color-code top sale

# %%
### Insert RANK values ###
df_top_ten['RANK'] = range(1, len(df_top_ten) + 1)
# use numpy to assign values to the 'COLOR' column
df_top_ten['COLOR'] = np.where(df_top_ten['RANK'] <= 1, 'orange', 'blue')

# %% [markdown]
# ## HTML Popup Formatter

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS          CITY  \
# 0  PAST SALE 2024-09-27   Condo/Co-op  360 Ocean Dr Unit 1002S  Key Biscayne
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33149.0  8400000.0   4.0    5.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11388372
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    BHHS EWM Realty      Ximena Ulloa    BHHS EWM Realty  Giulietta Ulloa
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   BHHS EWM Realty             None              None     1  orange

# %%
def popup_html(row):
    address = row['ADDRESS']  
    price = row['PRICE']
    psf = row['$/SQUARE FEET']
    sf = row['SQUARE FEET']
    year_built = row['YEAR BUILT']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Building Name: </strong>{}'''.format(address) + '''<br>
    <strong>Sale Price: </strong>${}'''.format(f'{price:,}') + '''<br>
    <strong>Price sq ft: </strong>${}'''.format(f'{psf:,}') + '''<br>
    <strong>Square Footage: </strong>{}'''.format(f'{sf:,}') + '''<br>
    <strong>Year Built: </strong>{}'''.format(f'{str(year_built)}') + '''<br>
    </html>
    '''
    return html

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op    360 Ocean Dr Unit 1002S
# 1  PAST SALE 2024-09-26   Condo/Co-op      480 NE 31st Unit UPH3
# 2  PAST SALE 2024-09-23   Condo/Co-op     2600 Island Blvd #2006
# 3  PAST SALE 2024-09-26   Condo/Co-op   1425 Brickell Ave Ph 69C
# 4  PAST SALE 2024-09-24   Condo/Co-op      3400 SW 27th Ave #802
# 5  PAST SALE 2024-09-26   Condo/Co-op     4775 Collins Ave #2302
# 6  PAST SALE 2024-09-26   Condo/Co-op         626 Coral Way #701
# 7  PAST SALE 2024-09-24   Condo/Co-op  13637 Deering Bay Dr #222
# 8  PAST SALE 2024-09-27   Condo/Co-op      251 Crandon Blvd #334
# 9  PAST SALE 2024-09-26   Condo/Co-op     3000 Island Blvd #1605
#
#            CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Key Biscayne                FL             33149.0  8400000.0   4.0    5.5
# 1         Miami                FL             33137.0  4500000.0   5.0    5.5
# 2      Aventura                FL             33160.0  4250000.0   5.0    4.5
# 3         Miami                FL             33131.0  2850000.0   2.0    2.5
# 4         Miami                FL             33133.0  2400000.0   2.0    2.5
# 5   Miami Beach                FL             33140.0  1800000.0   2.0    2.0
# 6  Coral Gables                FL             33134.0  1800000.0   3.0    3.0
# 7  Coral Gables                FL             33158.0  1725000.0   3.0    4.0
# 8  Key Biscayne                FL             33149.0  1630000.0   2.0    2.5
# 9      Aventura                FL             33160.0  1600000.0   4.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 1         GRAN PARAISO CONDO       3455.0       NaN      2019.0
# 2            Williams Island       4740.0       NaN      1997.0
# 3    FOUR SEASONS RESIDENCES       2139.0       NaN      2008.0
# 4  THE TOWER RESIDENCES COND       2110.0       NaN      2001.0
# 5        GREEN DIAMOND CONDO       1530.0       NaN      2000.0
# 6  GABLES ON THE GREEN CONDO       2100.0       NaN      2002.0
# 7       DEERING BAY CONDO II       3190.0       NaN      1995.0
# 8      KEY COLONY NO 2 CONDO       1560.0       NaN      1979.0
# 9            Williams Island       4308.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
# 1             NaN         1302.0     3771.0   Sold
# 2             NaN          897.0     5725.0   Sold
# 3             NaN         1332.0     3010.0   Sold
# 4             NaN         1137.0     3787.0   Sold
# 5             NaN         1176.0     2200.0   Sold
# 6             NaN          857.0     2306.0   Sold
# 7             NaN          541.0     3200.0   Sold
# 8             NaN         1045.0     1635.0   Sold
# 9             NaN          371.0     5220.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...       MARMLS  A11388372
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...       MARMLS  A11550306
# 2  https://www.redfin.com/FL/Aventura/2600-Island...       MARMLS  A11655519
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...       MARMLS  A11569532
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       MARMLS  A11640135
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...       MARMLS  A11575480
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...       MARMLS  A11648817
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...       MARMLS  A11587025
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...       MARMLS  A11583668
# 9  https://www.redfin.com/FL/Aventura/3000-Island...  Beaches MLS  F10414175
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
# 1        N          Y  25.806186 -80.187176
# 2        N          Y  25.939020 -80.133755
# 3        N          Y  25.759132 -80.191829
# 4        N          Y  25.729664 -80.237811
# 5        N          Y  25.822419 -80.121616
# 6        N          Y  25.748839 -80.267975
# 7        N          Y  25.635816 -80.290971
# 8        N          Y  25.697697 -80.158296
# 9        N          Y  25.940603 -80.134445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...      Adam Redolfi
# 2  https://www.redfin.com/FL/Aventura/2600-Island...        Joel Matus
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...  Fabian Dominguez
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       Nancy Muniz
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...      Flavia Glass
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...    Bethea Goldman
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...      Jose Nicolas
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...    Kim Ellen Haug
# 9  https://www.redfin.com/FL/Aventura/3000-Island...     Mark Ascolese
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                               BHHS EWM Realty      Ximena Ulloa
# 1                                 Alure Capital              None
# 2                   Williams Island Realty, LLC              None
# 3                  Fortune Christie's Intl R.E.   Peter Liakouras
# 4                        Coldwell Banker Realty              None
# 5                           Compass Florida LLC    Micael Machado
# 6                         Compass Florida, LLC.              None
# 7                         Compass Florida, LLC.              None
# 8  Fortune Christie's International Real Estate              None
# 9                   RE/MAX Consultants Realty 1              None
#
#              list_broker_name_2 buy_agent_name_1          buy_broker_name_1  \
# 0               BHHS EWM Realty  Giulietta Ulloa            BHHS EWM Realty
# 1                          None   Mikhail MudrIk     The Agency Florida LLC
# 2                          None             None                       None
# 3  Fortune Christie's Intl R.E.  Scott Shuffield            BHHS EWM Realty
# 4                          None      Nancy Muniz     Coldwell Banker Realty
# 5          Compass Florida, LLC     Flavia Glass        Compass Florida LLC
# 6                          None       Jorge Besu     Coldwell Banker Realty
# 7                          None     Jose Nicolas      Compass Florida, LLC.
# 8                          None   Luciana Lualdi        Avanti Way Brickell
# 9                          None             None  Dezer Platinum Realty LLC
#
#   buy_agent_name_2     buy_broker_name_2  RANK   COLOR
# 0             None                  None     1  orange
# 1             None                  None     2    blue
# 2             None                  None     3    blue
# 3             None                  None     4    blue
# 4             None                  None     5    blue
# 5   Micael Machado  Compass Florida, LLC     6    blue
# 6             None                  None     7    blue
# 7             None                  None     8    blue
# 8             None                  None     9    blue
# 9             None                  None    10    blue

# %%
from folium.plugins import MarkerCluster

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Recent Miami-Dade Condo Sales ')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'{week_starting} - {week_ending}')


### Create map container ###
m = folium.Map(location=df[["LATITUDE", "LONGITUDE"]].mean().to_list(),zoom_start=9.5,tiles=None)

# Create two FeatureGroups for different color pins
fg_blue = folium.FeatureGroup(name='All other sales')
fg_orange = folium.FeatureGroup(name='Top Sale')

for index, row in df_top_ten.iterrows():
    # Add the markers to the appropriate FeatureGroup based on the color
    if row['COLOR'] == 'blue':
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_blue)
    else:
        marker = folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            fill=True,
            icon=folium.Icon(color=row['COLOR']),
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_orange)

# Add the FeatureGroups to the map
fg_orange.add_to(m)
fg_blue.add_to(m)

folium.TileLayer('OpenStreetMap',control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5eb046260098bb1890581c1f06179d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Recent Miami-Dade Condo Sales &lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;Sep. 22nd - Sep. 29th&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5eb046260098bb1890581c1f06179d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c5eb046260098bb1890581c1f06179d1 = L.map(
#                 &quot;map_c5eb046260098bb1890581c1f06179d1&quot;,
#                 {
#                     center: [25.776085866666666, -80.24736414083333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_4194d29bec364ec88ee2daa5957f75bf = L.featureGroup(
#                 {}
#             ).addTo(map_c5eb046260098bb1890581c1f06179d1);
#
#
#             var marker_e7f530a4ba35a19fae884aacb2676cf6 = L.marker(
#                 [25.694584, -80.157715],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_4194d29bec364ec88ee2daa5957f75bf);
#
#
#             var icon_cfd0856aa8bc7a32237cdd02d55e252c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e7f530a4ba35a19fae884aacb2676cf6.setIcon(icon_cfd0856aa8bc7a32237cdd02d55e252c);
#
#
#         var popup_42593c06f9a4e7abc5e755ea80064173 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_53e5b2818c28ed4f2a5edfc0f1320796 = $(`&lt;div id=&quot;html_53e5b2818c28ed4f2a5edfc0f1320796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;360 Ocean Dr Unit 1002S&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$8,400,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$2,504.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,354.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2014.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_42593c06f9a4e7abc5e755ea80064173.setContent(html_53e5b2818c28ed4f2a5edfc0f1320796);
#
#
#
#         marker_e7f530a4ba35a19fae884aacb2676cf6.bindPopup(popup_42593c06f9a4e7abc5e755ea80064173)
#         ;
#
#
#
#
#             var feature_group_eb6266172097b8a523775343b2c384b4 = L.featureGroup(
#                 {}
#             ).addTo(map_c5eb046260098bb1890581c1f06179d1);
#
#
#             var marker_a02c646ca5ac4d01049a9e25e577c734 = L.marker(
#                 [25.8061865, -80.1871761],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_eb6266172097b8a523775343b2c384b4);
#
#
#             var icon_3082818a802f733e2e77a8eee5395258 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a02c646ca5ac4d01049a9e25e577c734.setIcon(icon_3082818a802f733e2e77a8eee5395258);
#
#
#         var popup_a36074a625883181deebdca3c1eae34d = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_c96fb03aa9c61eb63d738f95172ab719 = $(`&lt;div id=&quot;html_c96fb03aa9c61eb63d738f95172ab719&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Building Name: &lt;/strong&gt;480 NE 31st Unit UPH3&lt;br&gt;     &lt;strong&gt;Sale Price: &lt;/strong&gt;$4,500,000.0&lt;br&gt;     &lt;strong&gt;Price sq ft: &lt;/strong&gt;$1,302.0&lt;br&gt;     &lt;strong&gt;Square Footage: &lt;/strong&gt;3,455.0&lt;br&gt;     &lt;strong&gt;Year Built: &lt;/strong&gt;2019.0&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_a36074a625883181deebdca3c1eae34d.setContent(html_c96fb03aa9c61eb63d738f95172ab719);
#
#
#
#         marker_a02c646ca5ac4d01049a9e25e577c734.bindPopup(popup_a36074a625883181deebdca3c1eae34d)
#         ;
#
#
#
#
#             var marker_58dc0faa6cd75997469c67035bff9e4d = L.marker(
#                 [25.9390201, -80.1337546],
#                 {&quot;fill&quot;: true, &quot;radius&quot;: 5}
#             ).addTo(feature_group_eb6266172097b8a523775343b2c384b4);
#
#
#             var icon_f480a31f62de6f139460c63bececa33f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_58dc0faa6cd75997469c67035bff9e4d.setIcon(icon_f480a31f62de6f139460c63bececa33f);
#
#
#         var popup_0dfabd43a6fe969c1639e4dfa9509748 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_b128aa1e2b1621b7caf7eeba936bac0b = $(`&lt;

# %%
m.save('index.html')

# %% [markdown]
# ## Data snagger

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

DAYS_MAX = '\033[1m' + 'Most Days on Market' + '\033[0m'
DAYS_MIN = '\033[1m' + 'Fewest Days on Market' + '\033[0m'

# %%
df_top_ten.head(1)
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                  ADDRESS          CITY  \
# 0  PAST SALE 2024-09-27   Condo/Co-op  360 Ocean Dr Unit 1002S  Key Biscayne
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0                FL             33149.0  8400000.0   4.0    5.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
#
#                                                  URL  SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...  MARMLS  A11388372
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
#
#   list_broker_name_1 list_agent_name_2 list_broker_name_2 buy_agent_name_1  \
# 0    BHHS EWM Realty      Ximena Ulloa    BHHS EWM Realty  Giulietta Ulloa
#
#   buy_broker_name_1 buy_agent_name_2 buy_broker_name_2  RANK   COLOR
# 0   BHHS EWM Realty             None              None     1  orange

# %%
# # Highest and lowest sale price
# highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
# lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

# print(f"Highest Sale Price: {df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_sale_price_idx]['DAYS ON MARKET']}")
# print(f"Lowest Sale Price: {df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_sale_price_idx]['DAYS ON MARKET']}")

# # Highest and lowest psf
# highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
# lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

# print(f"Highest PSF: {df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[highest_psf_idx]['DAYS ON MARKET']}")
# print(f"Lowest PSF: {df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Days on market: {df_top_ten.loc[lowest_psf_idx]['DAYS ON MARKET']}")

# %% [markdown]
# ## Map URL snagger

# %% [markdown]
# Map template URL: `https://trd-digital.github.io/trd-news-interactive-maps/{map-folder-name}`

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_09302024

# %% [markdown]
# # CREATE TEMPLATE

# %%
muni_set = set(df_top_ten['CITY'])

# %%
df_top_ten['FULL_NAME'] = df_top_ten['LOCATION'] + ' at ' + df_top_ten['ADDRESS'] + ' in ' + df_top_ten['CITY']

# %%
df_top_ten.reset_index(inplace=True,drop=True)

# %%
top_sale = df_top_ten.at[0,'FULL_NAME']
second_top_sale = df_top_ten.at[1,'FULL_NAME']

# %%
top_sale
# Out:
# 'OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit 1002S in Key Biscayne'

# %%
### Average Sales Price ###
if float(average_sale_price) > float(previous_week_average_sales_price):
    change = 'higher'
    difference = float(average_sale_price) - float(previous_week_average_sales_price)
else:
    change = 'lower'
    difference = float(previous_week_average_sales_price) - float(average_sale_price)
    
### Total condo dollar volume ###
if float(current_week_condo_sales_total) > float(previous_week_condo_sales_total):
    seo_head = 'Rises'
elif float(previous_week_condo_sales_total) < float(current_week_condo_sales_total):
    seo_head = 'Falls'
else:
    seo_head = 'Unchanged'
    
### Average PSF ###    
if float(average_price_psf) > float(previous_week_average_psf):
    psf_rf = 'rose'
elif float(average_price_psf) < float(previous_week_average_psf):
    psf_rf ='fell'
else:
    psf_rf = 'equaled'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op    360 Ocean Dr Unit 1002S
# 1  PAST SALE 2024-09-26   Condo/Co-op      480 NE 31st Unit UPH3
# 2  PAST SALE 2024-09-23   Condo/Co-op     2600 Island Blvd #2006
# 3  PAST SALE 2024-09-26   Condo/Co-op   1425 Brickell Ave Ph 69C
# 4  PAST SALE 2024-09-24   Condo/Co-op      3400 SW 27th Ave #802
# 5  PAST SALE 2024-09-26   Condo/Co-op     4775 Collins Ave #2302
# 6  PAST SALE 2024-09-26   Condo/Co-op         626 Coral Way #701
# 7  PAST SALE 2024-09-24   Condo/Co-op  13637 Deering Bay Dr #222
# 8  PAST SALE 2024-09-27   Condo/Co-op      251 Crandon Blvd #334
# 9  PAST SALE 2024-09-26   Condo/Co-op     3000 Island Blvd #1605
#
#            CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Key Biscayne                FL             33149.0  8400000.0   4.0    5.5
# 1         Miami                FL             33137.0  4500000.0   5.0    5.5
# 2      Aventura                FL             33160.0  4250000.0   5.0    4.5
# 3         Miami                FL             33131.0  2850000.0   2.0    2.5
# 4         Miami                FL             33133.0  2400000.0   2.0    2.5
# 5   Miami Beach                FL             33140.0  1800000.0   2.0    2.0
# 6  Coral Gables                FL             33134.0  1800000.0   3.0    3.0
# 7  Coral Gables                FL             33158.0  1725000.0   3.0    4.0
# 8  Key Biscayne                FL             33149.0  1630000.0   2.0    2.5
# 9      Aventura                FL             33160.0  1600000.0   4.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 1         GRAN PARAISO CONDO       3455.0       NaN      2019.0
# 2            Williams Island       4740.0       NaN      1997.0
# 3    FOUR SEASONS RESIDENCES       2139.0       NaN      2008.0
# 4  THE TOWER RESIDENCES COND       2110.0       NaN      2001.0
# 5        GREEN DIAMOND CONDO       1530.0       NaN      2000.0
# 6  GABLES ON THE GREEN CONDO       2100.0       NaN      2002.0
# 7       DEERING BAY CONDO II       3190.0       NaN      1995.0
# 8      KEY COLONY NO 2 CONDO       1560.0       NaN      1979.0
# 9            Williams Island       4308.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
# 1             NaN         1302.0     3771.0   Sold
# 2             NaN          897.0     5725.0   Sold
# 3             NaN         1332.0     3010.0   Sold
# 4             NaN         1137.0     3787.0   Sold
# 5             NaN         1176.0     2200.0   Sold
# 6             NaN          857.0     2306.0   Sold
# 7             NaN          541.0     3200.0   Sold
# 8             NaN         1045.0     1635.0   Sold
# 9             NaN          371.0     5220.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...       MARMLS  A11388372
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...       MARMLS  A11550306
# 2  https://www.redfin.com/FL/Aventura/2600-Island...       MARMLS  A11655519
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...       MARMLS  A11569532
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       MARMLS  A11640135
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...       MARMLS  A11575480
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...       MARMLS  A11648817
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...       MARMLS  A11587025
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...       MARMLS  A11583668
# 9  https://www.redfin.com/FL/Aventura/3000-Island...  Beaches MLS  F10414175
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
# 1        N          Y  25.806186 -80.187176
# 2        N          Y  25.939020 -80.133755
# 3        N          Y  25.759132 -80.191829
# 4        N          Y  25.729664 -80.237811
# 5        N          Y  25.822419 -80.121616
# 6        N          Y  25.748839 -80.267975
# 7        N          Y  25.635816 -80.290971
# 8        N          Y  25.697697 -80.158296
# 9        N          Y  25.940603 -80.134445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...      Adam Redolfi
# 2  https://www.redfin.com/FL/Aventura/2600-Island...        Joel Matus
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...  Fabian Dominguez
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       Nancy Muniz
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...      Flavia Glass
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...    Bethea Goldman
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...      Jose Nicolas
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...    Kim Ellen Haug
# 9  https://www.redfin.com/FL/Aventura/3000-Island...     Mark Ascolese
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                               BHHS EWM Realty      Ximena Ulloa
# 1                                 Alure Capital              None
# 2                   Williams Island Realty, LLC              None
# 3                  Fortune Christie's Intl R.E.   Peter Liakouras
# 4                        Coldwell Banker Realty              None
# 5                           Compass Florida LLC    Micael Machado
# 6                         Compass Florida, LLC.              None
# 7                         Compass Florida, LLC.              None
# 8  Fortune Christie's International Real Estate              None
# 9                   RE/MAX Consultants Realty 1              None
#
#              list_broker_name_2 buy_agent_name_1          buy_broker_name_1  \
# 0               BHHS EWM Realty  Giulietta Ulloa            BHHS EWM Realty
# 1                          None   Mikhail MudrIk     The Agency Florida LLC
# 2                          None             None                       None
# 3  Fortune Christie's Intl R.E.  Scott Shuffield            BHHS EWM Realty
# 4                          None      Nancy Muniz     Coldwell Banker Realty
# 5          Compass Florida, LLC     Flavia Glass        Compass Florida LLC
# 6                          None       Jorge Besu     Coldwell Banker Realty
# 7                          None     Jose Nicolas      Compass Florida, LLC.
# 8                          None   Luciana Lualdi        Avanti Way Brickell
# 9                          None             None  Dezer Platinum Realty LLC
#
#   buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0             None                  None     1  orange
# 1             None                  None     2    blue
# 2             None                  None     3    blue
# 3             None                  None     4    blue
# 4             None                  None     5    blue
# 5   Micael Machado  Compass Florida, LLC     6    blue
# 6             None                  None     7    blue
# 7             None                  None     8    blue
# 8             None                  None     9    blue
# 9             None                  None    10    blue
#
#                                            FULL_NAME
# 0  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 1  GRAN PARAISO CONDO at 480 NE 31st Unit UPH3 in...
# 2  Williams Island at 2600 Island Blvd #2006 in A...
# 3  FOUR SEASONS RESIDENCES at 1425 Brickell Ave P...
# 4  THE TOWER RESIDENCES COND at 3400 SW 27th Ave ...
# 5  GREEN DIAMOND CONDO at 4775 Collins Ave #2302 ...
# 6  GABLES ON THE GREEN CONDO at 626 Coral Way #70...
# 7  DEERING BAY CONDO II at 13637 Deering Bay Dr #...
# 8  KEY COLONY NO 2 CONDO at 251 Crandon Blvd #334...
# 9  Williams Island at 3000 Island Blvd #1605 in A...

# %%
story_string = f'''
\033[1mHED:\033[0m {df_top_ten.loc[df_top_ten['PRICE'].idxmax()]['LOCATION']} closing tops {county} weekly condo sales 
\033[1mDEK:\033[0m Top 10 sales ranged from ${df_top_ten.at[9,'PRICE']:,.0f}M to ${df_top_ten.at[0,'PRICE']:,.0f}M
\033[1mFEATURED HED:\033[0m
\033[1mSEO HED:\033[0m {county} County Weekly Condo Report 
\033[1mSEO DESCRIPTION:\033[0m {county} County’s condo sales XXXXXXX
\033[1mAUTHOR:\033[0m Adam Farence
\033[1mRESEARCH:\033[0m 
\033[1mSocial:\033[0m #{county} condo sales XXXXX
\033[1mART:\033[0m

Interactive map

*Please provide credits for any images that you share
\033[1mSTORY TYPE:\033[0m Report
\033[1mSECTOR\033[0m (formerly CATEGORY): Residential Real Estate
\033[1mTAGS:\033[0m condo sales, {county}, weekly condo sales, {', '.join(str(x) for x in muni_set)}

\033[1mNeighborhood:\033[0m 
\033[1mProperty:\033[0m
\033[1mProperty Type:\033[0m
\033[1mCompanies:\033[0m 
\033[1mPeople:\033[0m
\033[1mIssues:\033[0m
\033[1mRegion:\033[0m
\033[1m[]Show in Yahoo Feed\033[0m

{county} County’s NEWS PEG HERE.

Brokers closed {int(current_week_condo_sales):,.0f} condo sales totaling ${float(current_week_condo_sales_total):,.0f} million from {week_starting} to {week_ending}. The previous week, brokers closed {previous_week_condo_sales} condo sales totaling ${int(previous_week_condo_sales_total):,.0f}.

Last week’s units sold for an average of ${float(average_sale_price):,.0f}, {change} than the ${float(previous_week_average_sales_price):,.0f} average price from the previous week. The average price per square foot {psf_rf} to ${average_price_psf} from ${previous_week_average_psf}, according to data from Redfin.

For the top 10 sales, prices ranged from ${df_top_ten.at[9,'PRICE']:,} million to ${df_top_ten.at[0,'PRICE']:,} million. 

{top_sale} took the top spot with a ${df_top_ten.at[0,'PRICE']:,} million closing. The sale closed at ${df_top_ten.at[0,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[0,'list_agent_name_1']} with {df_top_ten.at[0,'list_broker_name_1']}, and {df_top_ten.at[0,'list_agent_name_2']} with {df_top_ten.at[0,'list_broker_name_2']} had the listing.
{df_top_ten.at[0,'buy_agent_name_1']} with {df_top_ten.at[0,'buy_broker_name_1']}, and {df_top_ten.at[0,'buy_agent_name_2']} with {df_top_ten.at[0,'buy_broker_name_2']} represented the buyer.

{second_top_sale}, closed for the second highest amount, ${df_top_ten.at[1,'PRICE']:,}, or ${df_top_ten.at[1,'$/SQUARE FEET']:,} per square foot.

{df_top_ten.at[1,'list_agent_name_1']} with {df_top_ten.at[1,'list_broker_name_1']}, and {df_top_ten.at[1,'list_agent_name_2']} with {df_top_ten.at[1,'list_broker_name_2']} had the listing.
{df_top_ten.at[1,'buy_agent_name_1']} with {df_top_ten.at[1,'buy_broker_name_1']}, and {df_top_ten.at[1,'buy_agent_name_2']} with {df_top_ten.at[1,'buy_broker_name_2']} represented the buyer.

<figure>
 <div class="container">
   <div class="iframe-wrap">
   <iframe src="{final_name}" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
  </div>
</div>
  <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
</figure>

Here’s a breakdown of the top 10 sales from {week_starting} to {week_ending}:
'''

print(story_string)
# Out:
# HED: OCEANA KEY BISCAYNE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,600,000M to $8,400,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Aventura, Coral Gables, Miami Beach, Miami, Key Biscayne
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 120 condo sales totaling $78,817,493 million from Sep. 22nd to Sep. 29th. The previous week, brokers closed 134 condo sales totaling $93,800,000.
#
# Last week’s units sold for an average of $656,812, lower than the $684,642 average price from the previous week. The average price per square foot fell to $475 from $503, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,600,000.0 million to $8,400,000.0 million.
#
# OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit 1002S in Key Biscayne took the top spot with a $8,400,000.0 million closing. The sale closed at $2,504.0 per square foot.
#
# Giulietta Ulloa with BHHS EWM Realty, and Ximena Ulloa with BHHS EWM Realty had the listing.
# Giulietta Ulloa with BHHS EWM Realty, and None with None represented the buyer.
#
# GRAN PARAISO CONDO at 480 NE 31st Unit UPH3 in Miami, closed for the second highest amount, $4,500,000.0, or $1,302.0 per square foot.
#
# Adam Redolfi with Alure Capital, and None with None had the listing.
# Mikhail MudrIk with The Agency Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_09302024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 22nd to Sep. 29th:

# %%
story_checklist = '''
\033[1mRemember to...:\033[0m

1. Double check all names. Sometimes names differ between the hed and the body of the story.
    For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
    in the body.
    
2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
    a story. If there is, add in some extra details and link back to it.
'''

# %%
### Set up formatting ###
BR = '\n'

ME = '\033[1m' + 'Most Expensive' + '\033[0m'
LE = '\033[1m' + 'Least Expensive' + '\033[0m'

MAX_PSF = '\033[1m' + 'Highest Price Per Square Foot' + '\033[0m'
MIN_PSF = '\033[1m' + 'Lowest Price Per Square Foot' + '\033[0m'

# %%
df_top_ten.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME', 'URL', 'SOURCE', 'MLS#', 'FAVORITE',
#        'INTERESTED', 'LATITUDE', 'LONGITUDE', 'url', 'list_agent_name_1',
#        'list_broker_name_1', 'list_agent_name_2', 'list_broker_name_2',
#        'buy_agent_name_1', 'buy_broker_name_1', 'buy_agent_name_2',
#        'buy_broker_name_2', 'RANK', 'COLOR', 'FULL_NAME'],
#       dtype='object')

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op    360 Ocean Dr Unit 1002S
# 1  PAST SALE 2024-09-26   Condo/Co-op      480 NE 31st Unit UPH3
# 2  PAST SALE 2024-09-23   Condo/Co-op     2600 Island Blvd #2006
# 3  PAST SALE 2024-09-26   Condo/Co-op   1425 Brickell Ave Ph 69C
# 4  PAST SALE 2024-09-24   Condo/Co-op      3400 SW 27th Ave #802
# 5  PAST SALE 2024-09-26   Condo/Co-op     4775 Collins Ave #2302
# 6  PAST SALE 2024-09-26   Condo/Co-op         626 Coral Way #701
# 7  PAST SALE 2024-09-24   Condo/Co-op  13637 Deering Bay Dr #222
# 8  PAST SALE 2024-09-27   Condo/Co-op      251 Crandon Blvd #334
# 9  PAST SALE 2024-09-26   Condo/Co-op     3000 Island Blvd #1605
#
#            CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Key Biscayne                FL             33149.0  8400000.0   4.0    5.5
# 1         Miami                FL             33137.0  4500000.0   5.0    5.5
# 2      Aventura                FL             33160.0  4250000.0   5.0    4.5
# 3         Miami                FL             33131.0  2850000.0   2.0    2.5
# 4         Miami                FL             33133.0  2400000.0   2.0    2.5
# 5   Miami Beach                FL             33140.0  1800000.0   2.0    2.0
# 6  Coral Gables                FL             33134.0  1800000.0   3.0    3.0
# 7  Coral Gables                FL             33158.0  1725000.0   3.0    4.0
# 8  Key Biscayne                FL             33149.0  1630000.0   2.0    2.5
# 9      Aventura                FL             33160.0  1600000.0   4.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 1         GRAN PARAISO CONDO       3455.0       NaN      2019.0
# 2            Williams Island       4740.0       NaN      1997.0
# 3    FOUR SEASONS RESIDENCES       2139.0       NaN      2008.0
# 4  THE TOWER RESIDENCES COND       2110.0       NaN      2001.0
# 5        GREEN DIAMOND CONDO       1530.0       NaN      2000.0
# 6  GABLES ON THE GREEN CONDO       2100.0       NaN      2002.0
# 7       DEERING BAY CONDO II       3190.0       NaN      1995.0
# 8      KEY COLONY NO 2 CONDO       1560.0       NaN      1979.0
# 9            Williams Island       4308.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
# 1             NaN         1302.0     3771.0   Sold
# 2             NaN          897.0     5725.0   Sold
# 3             NaN         1332.0     3010.0   Sold
# 4             NaN         1137.0     3787.0   Sold
# 5             NaN         1176.0     2200.0   Sold
# 6             NaN          857.0     2306.0   Sold
# 7             NaN          541.0     3200.0   Sold
# 8             NaN         1045.0     1635.0   Sold
# 9             NaN          371.0     5220.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...       MARMLS  A11388372
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...       MARMLS  A11550306
# 2  https://www.redfin.com/FL/Aventura/2600-Island...       MARMLS  A11655519
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...       MARMLS  A11569532
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       MARMLS  A11640135
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...       MARMLS  A11575480
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...       MARMLS  A11648817
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...       MARMLS  A11587025
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...       MARMLS  A11583668
# 9  https://www.redfin.com/FL/Aventura/3000-Island...  Beaches MLS  F10414175
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
# 1        N          Y  25.806186 -80.187176
# 2        N          Y  25.939020 -80.133755
# 3        N          Y  25.759132 -80.191829
# 4        N          Y  25.729664 -80.237811
# 5        N          Y  25.822419 -80.121616
# 6        N          Y  25.748839 -80.267975
# 7        N          Y  25.635816 -80.290971
# 8        N          Y  25.697697 -80.158296
# 9        N          Y  25.940603 -80.134445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...      Adam Redolfi
# 2  https://www.redfin.com/FL/Aventura/2600-Island...        Joel Matus
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...  Fabian Dominguez
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       Nancy Muniz
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...      Flavia Glass
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...    Bethea Goldman
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...      Jose Nicolas
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...    Kim Ellen Haug
# 9  https://www.redfin.com/FL/Aventura/3000-Island...     Mark Ascolese
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                               BHHS EWM Realty      Ximena Ulloa
# 1                                 Alure Capital              None
# 2                   Williams Island Realty, LLC              None
# 3                  Fortune Christie's Intl R.E.   Peter Liakouras
# 4                        Coldwell Banker Realty              None
# 5                           Compass Florida LLC    Micael Machado
# 6                         Compass Florida, LLC.              None
# 7                         Compass Florida, LLC.              None
# 8  Fortune Christie's International Real Estate              None
# 9                   RE/MAX Consultants Realty 1              None
#
#              list_broker_name_2 buy_agent_name_1          buy_broker_name_1  \
# 0               BHHS EWM Realty  Giulietta Ulloa            BHHS EWM Realty
# 1                          None   Mikhail MudrIk     The Agency Florida LLC
# 2                          None             None                       None
# 3  Fortune Christie's Intl R.E.  Scott Shuffield            BHHS EWM Realty
# 4                          None      Nancy Muniz     Coldwell Banker Realty
# 5          Compass Florida, LLC     Flavia Glass        Compass Florida LLC
# 6                          None       Jorge Besu     Coldwell Banker Realty
# 7                          None     Jose Nicolas      Compass Florida, LLC.
# 8                          None   Luciana Lualdi        Avanti Way Brickell
# 9                          None             None  Dezer Platinum Realty LLC
#
#   buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0             None                  None     1  orange
# 1             None                  None     2    blue
# 2             None                  None     3    blue
# 3             None                  None     4    blue
# 4             None                  None     5    blue
# 5   Micael Machado  Compass Florida, LLC     6    blue
# 6             None                  None     7    blue
# 7             None                  None     8    blue
# 8             None                  None     9    blue
# 9             None                  None    10    blue
#
#                                            FULL_NAME
# 0  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 1  GRAN PARAISO CONDO at 480 NE 31st Unit UPH3 in...
# 2  Williams Island at 2600 Island Blvd #2006 in A...
# 3  FOUR SEASONS RESIDENCES at 1425 Brickell Ave P...
# 4  THE TOWER RESIDENCES COND at 3400 SW 27th Ave ...
# 5  GREEN DIAMOND CONDO at 4775 Collins Ave #2302 ...
# 6  GABLES ON THE GREEN CONDO at 626 Coral Way #70...
# 7  DEERING BAY CONDO II at 13637 Deering Bay Dr #...
# 8  KEY COLONY NO 2 CONDO at 251 Crandon Blvd #334...
# 9  Williams Island at 3000 Island Blvd #1605 in A...

# %%
print(story_string)

# Highest and lowest sale price
highest_sale_price_idx = df_top_ten['PRICE'].idxmax()
lowest_sale_price_idx = df_top_ten['PRICE'].idxmin()

print(f"{ME}{BR}{df_top_ten.loc[highest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[highest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[highest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[highest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_sale_price_idx]['buy_broker_name_2']}")
print(f"{LE}{BR}{df_top_ten.loc[lowest_sale_price_idx]['LOCATION']}, {df_top_ten.loc[lowest_sale_price_idx]['ADDRESS']} in {df_top_ten.loc[lowest_sale_price_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_sale_price_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_sale_price_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_sale_price_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_sale_price_idx]['buy_broker_name_2']}")

# Highest and lowest psf
highest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmax()
lowest_psf_idx = df_top_ten['$/SQUARE FEET'].idxmin()

print(f"{MAX_PSF}{BR}{df_top_ten.loc[highest_psf_idx]['LOCATION']}, {df_top_ten.loc[highest_psf_idx]['ADDRESS']} in {df_top_ten.loc[highest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[highest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[highest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[highest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[highest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[highest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[highest_psf_idx]['buy_broker_name_2']}")
print(f"{MIN_PSF}{BR}{df_top_ten.loc[lowest_psf_idx]['LOCATION']}, {df_top_ten.loc[lowest_psf_idx]['ADDRESS']} in {df_top_ten.loc[lowest_psf_idx]['CITY']} | Price: ${df_top_ten.loc[lowest_psf_idx]['PRICE']:,.0f} | ${df_top_ten.loc[lowest_psf_idx]['$/SQUARE FEET']:,.0f} psf | Listing agents: {df_top_ten.loc[lowest_psf_idx]['list_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['list_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['list_broker_name_2']} | Buyer's agents: {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_1']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_1']} and {df_top_ten.loc[lowest_psf_idx]['buy_agent_name_2']} with {df_top_ten.loc[lowest_psf_idx]['buy_broker_name_2']}")

print(story_checklist)
# Out:
# HED: OCEANA KEY BISCAYNE CONDO closing tops Miami-Dade weekly condo sales
# DEK: Top 10 sales ranged from $1,600,000M to $8,400,000M
# FEATURED HED:
# SEO HED: Miami-Dade County Weekly Condo Report
# SEO DESCRIPTION: Miami-Dade County’s condo sales XXXXXXX
# AUTHOR: Adam Farence
# RESEARCH:
# Social: #Miami-Dade condo sales XXXXX
# ART:
#
# Interactive map
#
# *Please provide credits for any images that you share
# STORY TYPE: Report
# SECTOR (formerly CATEGORY): Residential Real Estate
# TAGS: condo sales, Miami-Dade, weekly condo sales, Aventura, Coral Gables, Miami Beach, Miami, Key Biscayne
#
# Neighborhood:
# Property:
# Property Type:
# Companies:
# People:
# Issues:
# Region:
# []Show in Yahoo Feed
#
# Miami-Dade County’s NEWS PEG HERE.
#
# Brokers closed 120 condo sales totaling $78,817,493 million from Sep. 22nd to Sep. 29th. The previous week, brokers closed 134 condo sales totaling $93,800,000.
#
# Last week’s units sold for an average of $656,812, lower than the $684,642 average price from the previous week. The average price per square foot fell to $475 from $503, according to data from Redfin.
#
# For the top 10 sales, prices ranged from $1,600,000.0 million to $8,400,000.0 million.
#
# OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit 1002S in Key Biscayne took the top spot with a $8,400,000.0 million closing. The sale closed at $2,504.0 per square foot.
#
# Giulietta Ulloa with BHHS EWM Realty, and Ximena Ulloa with BHHS EWM Realty had the listing.
# Giulietta Ulloa with BHHS EWM Realty, and None with None represented the buyer.
#
# GRAN PARAISO CONDO at 480 NE 31st Unit UPH3 in Miami, closed for the second highest amount, $4,500,000.0, or $1,302.0 per square foot.
#
# Adam Redolfi with Alure Capital, and None with None had the listing.
# Mikhail MudrIk with The Agency Florida LLC, and None with None represented the buyer.
#
# <figure>
#  <div class="container">
#    <div class="iframe-wrap">
#    <iframe src="https://trd-digital.github.io/trd-news-interactive-maps/MiamiDade_County_condo_sales_week_ending_09302024" width="100%" height="600" frameBorder="0" scrolling="no"></iframe>
#   </div>
# </div>
#   <figcaption align="right"><a href="https://leafletjs.com/">Leaflet</a> map created by Adam Farence | Data by © <a href="https://www.openstreetmap.org/#map=4/38.01/-95.84"> OpenStreetMap</a>, under <a href="https://www.openstreetmap.org/copyright">ODbl.</a></figcaption>
# </figure>
#
# Here’s a breakdown of the top 10 sales from Sep. 22nd to Sep. 29th:
#
# Most Expensive
# OCEANA KEY BISCAYNE CONDO, 360 Ocean Dr Unit 1002S in Key Biscayne | Price: $8,400,000 | $2,504 psf | Listing agents: Giulietta Ulloa with BHHS EWM Realty and Ximena Ulloa with BHHS EWM Realty | Buyer's agents: Giulietta Ulloa with BHHS EWM Realty and None with None
# Least Expensive
# Williams Island, 3000 Island Blvd #1605 in Aventura | Price: $1,600,000 | $371 psf | Listing agents: Mark Ascolese with RE/MAX Consultants Realty 1 and None with None | Buyer's agents: None with Dezer Platinum Realty LLC and None with None
# Highest Price Per Square Foot
# OCEANA KEY BISCAYNE CONDO, 360 Ocean Dr Unit 1002S in Key Biscayne | Price: $8,400,000 | $2,504 psf | Listing agents: Giulietta Ulloa with BHHS EWM Realty and Ximena Ulloa with BHHS EWM Realty | Buyer's agents: Giulietta Ulloa with BHHS EWM Realty and None with None
# Lowest Price Per Square Foot
# Williams Island, 3000 Island Blvd #1605 in Aventura | Price: $1,600,000 | $371 psf | Listing agents: Mark Ascolese with RE/MAX Consultants Realty 1 and None with None | Buyer's agents: None with Dezer Platinum Realty LLC and None with None
#
# Remember to...:
#
# 1. Double check all names. Sometimes names differ between the hed and the body of the story.
#     For example, "Surf Club Four Seasons" in the HED and "Four Seasons Residences at the Surfclub"
#     in the body.
#
# 2. Add in context, if available. When there's a high-priced condo sale, check and see if there's
#     a story. If there is, add in some extra details and link back to it.

# %%
print(df_top_ten['URL'].iloc[0])
# Out:
# https://www.redfin.com/FL/Key-Biscayne/360-Ocean-Dr-33149/unit-1002S/home/79133323

# %%
print(df_top_ten['URL'].iloc[1])
# Out:
# https://www.redfin.com/FL/Miami/480-NE-31st-St-33137/unit-UPH3/home/189938164

# %%
print(df_top_ten['URL'].iloc[-1])
# Out:
# https://www.redfin.com/FL/Aventura/3000-Island-Blvd-33160/unit-1605/home/42946393

# %%
print(df_top_ten['URL'].iloc[-2])
# Out:
# https://www.redfin.com/FL/Key-Biscayne/251-Crandon-Blvd-33149/unit-334/home/42910761

# %%
# Find the index of the row with the maximum '$/SQUARE FEET' value
max_index = df_top_ten['$/SQUARE FEET'].idxmax()

# Use the index to access the 'URL' of that row
max_url = df_top_ten.loc[max_index, 'URL']

print(max_url)
# Out:
# https://www.redfin.com/FL/Key-Biscayne/360-Ocean-Dr-33149/unit-1002S/home/79133323

# %%
# Find the index of the row with the minimum '$/SQUARE FEET' value
min_index = df_top_ten['$/SQUARE FEET'].idxmin()

# Use the index to access the 'URL' of that row
min_url = df_top_ten.loc[min_index, 'URL']

print(min_url)
# Out:
# https://www.redfin.com/FL/Aventura/3000-Island-Blvd-33160/unit-1605/home/42946393

# %%
df_top_ten
# Out:
#    SALE TYPE  SOLD DATE PROPERTY TYPE                    ADDRESS  \
# 0  PAST SALE 2024-09-27   Condo/Co-op    360 Ocean Dr Unit 1002S
# 1  PAST SALE 2024-09-26   Condo/Co-op      480 NE 31st Unit UPH3
# 2  PAST SALE 2024-09-23   Condo/Co-op     2600 Island Blvd #2006
# 3  PAST SALE 2024-09-26   Condo/Co-op   1425 Brickell Ave Ph 69C
# 4  PAST SALE 2024-09-24   Condo/Co-op      3400 SW 27th Ave #802
# 5  PAST SALE 2024-09-26   Condo/Co-op     4775 Collins Ave #2302
# 6  PAST SALE 2024-09-26   Condo/Co-op         626 Coral Way #701
# 7  PAST SALE 2024-09-24   Condo/Co-op  13637 Deering Bay Dr #222
# 8  PAST SALE 2024-09-27   Condo/Co-op      251 Crandon Blvd #334
# 9  PAST SALE 2024-09-26   Condo/Co-op     3000 Island Blvd #1605
#
#            CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  \
# 0  Key Biscayne                FL             33149.0  8400000.0   4.0    5.5
# 1         Miami                FL             33137.0  4500000.0   5.0    5.5
# 2      Aventura                FL             33160.0  4250000.0   5.0    4.5
# 3         Miami                FL             33131.0  2850000.0   2.0    2.5
# 4         Miami                FL             33133.0  2400000.0   2.0    2.5
# 5   Miami Beach                FL             33140.0  1800000.0   2.0    2.0
# 6  Coral Gables                FL             33134.0  1800000.0   3.0    3.0
# 7  Coral Gables                FL             33158.0  1725000.0   3.0    4.0
# 8  Key Biscayne                FL             33149.0  1630000.0   2.0    2.5
# 9      Aventura                FL             33160.0  1600000.0   4.0    3.5
#
#                     LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  OCEANA KEY BISCAYNE CONDO       3354.0       NaN      2014.0
# 1         GRAN PARAISO CONDO       3455.0       NaN      2019.0
# 2            Williams Island       4740.0       NaN      1997.0
# 3    FOUR SEASONS RESIDENCES       2139.0       NaN      2008.0
# 4  THE TOWER RESIDENCES COND       2110.0       NaN      2001.0
# 5        GREEN DIAMOND CONDO       1530.0       NaN      2000.0
# 6  GABLES ON THE GREEN CONDO       2100.0       NaN      2002.0
# 7       DEERING BAY CONDO II       3190.0       NaN      1995.0
# 8      KEY COLONY NO 2 CONDO       1560.0       NaN      1979.0
# 9            Williams Island       4308.0       NaN      1988.0
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH STATUS  \
# 0             NaN         2504.0     4212.0   Sold
# 1             NaN         1302.0     3771.0   Sold
# 2             NaN          897.0     5725.0   Sold
# 3             NaN         1332.0     3010.0   Sold
# 4             NaN         1137.0     3787.0   Sold
# 5             NaN         1176.0     2200.0   Sold
# 6             NaN          857.0     2306.0   Sold
# 7             NaN          541.0     3200.0   Sold
# 8             NaN         1045.0     1635.0   Sold
# 9             NaN          371.0     5220.0   Sold
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
#
#                                                  URL       SOURCE       MLS#  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...       MARMLS  A11388372
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...       MARMLS  A11550306
# 2  https://www.redfin.com/FL/Aventura/2600-Island...       MARMLS  A11655519
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...       MARMLS  A11569532
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       MARMLS  A11640135
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...       MARMLS  A11575480
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...       MARMLS  A11648817
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...       MARMLS  A11587025
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...       MARMLS  A11583668
# 9  https://www.redfin.com/FL/Aventura/3000-Island...  Beaches MLS  F10414175
#
#   FAVORITE INTERESTED   LATITUDE  LONGITUDE  \
# 0        N          Y  25.694584 -80.157715
# 1        N          Y  25.806186 -80.187176
# 2        N          Y  25.939020 -80.133755
# 3        N          Y  25.759132 -80.191829
# 4        N          Y  25.729664 -80.237811
# 5        N          Y  25.822419 -80.121616
# 6        N          Y  25.748839 -80.267975
# 7        N          Y  25.635816 -80.290971
# 8        N          Y  25.697697 -80.158296
# 9        N          Y  25.940603 -80.134445
#
#                                                  url list_agent_name_1  \
# 0  https://www.redfin.com/FL/Key-Biscayne/360-Oce...   Giulietta Ulloa
# 1  https://www.redfin.com/FL/Miami/480-NE-31st-St...      Adam Redolfi
# 2  https://www.redfin.com/FL/Aventura/2600-Island...        Joel Matus
# 3  https://www.redfin.com/FL/Miami/1425-Brickell-...  Fabian Dominguez
# 4  https://www.redfin.com/FL/Miami/3400-SW-27th-A...       Nancy Muniz
# 5  https://www.redfin.com/FL/Miami-Beach/4775-Col...      Flavia Glass
# 6  https://www.redfin.com/FL/Coral-Gables/626-Cor...    Bethea Goldman
# 7  https://www.redfin.com/FL/Coral-Gables/13637-D...      Jose Nicolas
# 8  https://www.redfin.com/FL/Key-Biscayne/251-Cra...    Kim Ellen Haug
# 9  https://www.redfin.com/FL/Aventura/3000-Island...     Mark Ascolese
#
#                              list_broker_name_1 list_agent_name_2  \
# 0                               BHHS EWM Realty      Ximena Ulloa
# 1                                 Alure Capital              None
# 2                   Williams Island Realty, LLC              None
# 3                  Fortune Christie's Intl R.E.   Peter Liakouras
# 4                        Coldwell Banker Realty              None
# 5                           Compass Florida LLC    Micael Machado
# 6                         Compass Florida, LLC.              None
# 7                         Compass Florida, LLC.              None
# 8  Fortune Christie's International Real Estate              None
# 9                   RE/MAX Consultants Realty 1              None
#
#              list_broker_name_2 buy_agent_name_1          buy_broker_name_1  \
# 0               BHHS EWM Realty  Giulietta Ulloa            BHHS EWM Realty
# 1                          None   Mikhail MudrIk     The Agency Florida LLC
# 2                          None             None                       None
# 3  Fortune Christie's Intl R.E.  Scott Shuffield            BHHS EWM Realty
# 4                          None      Nancy Muniz     Coldwell Banker Realty
# 5          Compass Florida, LLC     Flavia Glass        Compass Florida LLC
# 6                          None       Jorge Besu     Coldwell Banker Realty
# 7                          None     Jose Nicolas      Compass Florida, LLC.
# 8                          None   Luciana Lualdi        Avanti Way Brickell
# 9                          None             None  Dezer Platinum Realty LLC
#
#   buy_agent_name_2     buy_broker_name_2  RANK   COLOR  \
# 0             None                  None     1  orange
# 1             None                  None     2    blue
# 2             None                  None     3    blue
# 3             None                  None     4    blue
# 4             None                  None     5    blue
# 5   Micael Machado  Compass Florida, LLC     6    blue
# 6             None                  None     7    blue
# 7             None                  None     8    blue
# 8             None                  None     9    blue
# 9             None                  None    10    blue
#
#                                            FULL_NAME
# 0  OCEANA KEY BISCAYNE CONDO at 360 Ocean Dr Unit...
# 1  GRAN PARAISO CONDO at 480 NE 31st Unit UPH3 in...
# 2  Williams Island at 2600 Island Blvd #2006 in A...
# 3  FOUR SEASONS RESIDENCES at 1425 Brickell Ave P...
# 4  THE TOWER RESIDENCES COND at 3400 SW 27th Ave ...
# 5  GREEN DIAMOND CONDO at 4775 Collins Ave #2302 ...
# 6  GABLES ON THE GREEN CONDO at 626 Coral Way #70...
# 7  DEERING BAY CONDO II at 13637 Deering Bay Dr #...
# 8  KEY COLONY NO 2 CONDO at 251 Crandon Blvd #334...
# 9  Williams Island at 3000 Island Blvd #1605 in A...

# %% [markdown]
# ## Time on Market Calculator

# %%
################ YEAR, MONTH, DAY #######################

date1 = datetime(2024, 3, 14) ## List (Earlier) date
date2 = datetime(2024, 9, 26) ## Close (Later) date

delta = date2 - date1
num_days = delta.days

print(num_days)
# Out:
# 196

# %% [markdown]
# ## Clean CSV for Datawrapper Chart

# %%
chart_df = df_top_ten

# %%
chart_df = chart_df.fillna(" ")

# %%
chart_df['LISTING INFO'] = chart_df['list_agent_name_1'] + ' ' + chart_df['list_broker_name_1'] + ' ' + chart_df['list_agent_name_2'] + ' ' + chart_df['list_broker_name_2'] 
chart_df['BUYING INFO'] = chart_df['buy_agent_name_1'] + ' ' + chart_df['buy_broker_name_1'] + ' ' + chart_df['buy_agent_name_2'] + ' ' + chart_df['buy_broker_name_2']

# %%
chart_df['ADDRESS'] = chart_df['ADDRESS'] + ' in ' + chart_df['CITY']

# %%
columns_to_drop = [
    "SALE TYPE",
    "PROPERTY TYPE",
    "STATE OR PROVINCE",
    "ZIP OR POSTAL CODE",
    "LOT SIZE",
    "DAYS ON MARKET",
    "HOA/MONTH",
    "STATUS",
    "NEXT OPEN HOUSE START TIME",
    "NEXT OPEN HOUSE END TIME",
    "URL",
    "FAVORITE",
    "INTERESTED",
    "LATITUDE",
    "LONGITUDE",
    "url",
    "RANK",
    "COLOR",
    "FULL_NAME",
    "list_agent_name_1",
    "list_broker_name_1",
    "list_agent_name_2",
    "list_broker_name_2",
    "buy_agent_name_1",
    "buy_broker_name_1",
    "buy_agent_name_2",
    "buy_broker_name_2",
    "CITY",
    "LOCATION"
]

# %%
chart_df = chart_df.drop(columns=columns_to_drop)

# %%
chart_df['PRICE'] = chart_df['PRICE'].apply(lambda x: "${:,.0f}".format(x))
chart_df['$/SQUARE FEET'] = chart_df['$/SQUARE FEET'].apply(lambda x: "${:,.0f}".format(x))
chart_df['SQUARE FEET'] = chart_df['SQUARE FEET'].apply(lambda x: "{:,.0f}".format(x))
chart_df['YEAR BUILT'] = chart_df['YEAR BUILT'].apply(lambda x: "{:.0f}".format(x))
chart_df['BEDS'] = chart_df['BEDS'].apply(lambda x: "{:.0f}".format(x))

# %%
csv_date_string = today.strftime("%m_%d_%Y")

# %%
chart_df.to_csv(f"WCS_Chart_{csv_date_string}.csv")
