# %% [markdown]
# ## Imports

# %%
import googlemaps
import pandas as pd
import numpy as np
import re
import os
import geopandas as gpd
import folium
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Point

# %% [markdown]
# ## Read-in

# %%
df = pd.read_csv('LISF_July_August_2024.csv',dtype='str')

# %%
df['Doc Recorded'].isna().value_counts()
# Out:
# Doc Recorded
# False    2388
# Name: count, dtype: int64

# %%
# Define the regex pattern to split the text
pattern = r'(\d+-\d+-\d+-\d+-\d+)\s(.*)'

# Apply regex and split the text into two columns
df[['PIN', 'Address']] = df['1st PIN'].str.extract(pattern)

# Remove leading/trailing whitespace from the address column
df['Address'] = df['Address'].str.strip()

# %%
df = df.drop(columns=['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','1st PIN'])

# %% [markdown]
# ## Clean, drop, and convert

# %%
df['Doc Recorded'] = pd.to_datetime(df['Doc Recorded'], format='mixed')

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 1888

# %% [markdown]
# ## Data Stuff

# %%
df['1st Grantor'] = df['1st Grantor'].fillna('NA')
df['1st Grantee'] = df['1st Grantee'].fillna('NA')

# %%
municipal_authority = ['city', 'town', 'municipality', 'village','transit auth','department of transp']  # list of municipal authority keywords
df = df[~df['1st Grantor'].str.contains('|'.join(municipal_authority), case=False) & 
        ~df['1st Grantee'].str.contains('|'.join(municipal_authority), case=False)]

# %%
df['COLOR'] = df['Doc Recorded'].apply(lambda x: 'red' if x.month == 7 else 'yellow')

# %% [markdown]
# ## Get mortgage amounts

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'TE': 'Trailers'
}

# %%
def mortgage_url_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    for link in soup.find_all('a', href=True):
        if link['href'].startswith('/Document/Detail'):
            mortgage_url = 'https://crs.cookcountyclerkil.gov' + link['href']
            return mortgage_url

# %%
def mortgage_consi_snagger(URL, headers):
    response = requests.get(URL, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all tr tags
    trs = soup.find_all('tr')

    # Loop through each tr tag and look for the td tag containing 'Consideration Amount' label
    for tr in trs:
        td = tr.find('th', text='Consideration Amount:')
        if td:
            # If the td tag is found, get the next td tag containing the amount
            amount_td = td.find_next_sibling('td')
            if amount_td:
                # Print the amount
                amount = amount_td.text.strip()
                return amount
            else:
                return 'not found'

# %%
df['mortgage_urls'] = df['deed_urls'].apply(lambda x: mortgage_url_snagger(x, headers))

# %%
df['mortgage_amount'] = df['mortgage_urls'].apply(lambda x: mortgage_consi_snagger(x, headers) if x is not None else None)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_24835/2390556658.py:9: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   td = tr.find('th', text='Consideration Amount:')

# %%
df[['mortgage_urls','mortgage_amount']] = df[['mortgage_urls','mortgage_amount']].fillna('NA')

# %% [markdown]
# ## Geocode

# %%
len(df)
# Out:
# 1494

# %%
df['geo_address'] = df['Address'] + ' Cook County, IL'

# %%
len(df)
# Out:
# 1494

# %%
# %store -r google_maps_API_Key
gmaps_key = googlemaps.Client(key=google_maps_API_Key)

# %%
# Define the geocode function
def geocode(add):
    g = gmaps_key.geocode(add)
    if g:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lat, lng)
    else:
        return None

# Apply geocoding to the 'geo_address' column and store the results in 'geocoded' column
df['geocoded'] = df['geo_address'].apply(geocode)

# %%
df['geocoded'] = df['geocoded'].astype(str)
df[['lat', 'lon']] = df['geocoded'].apply(lambda x: (None, None) if x == 'None' else x.strip('()').split(', ', 1)).apply(pd.Series)
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)

# %% [markdown]
# ## HTML Popup Formatter

# %%
df.columns
# Out:
# Index(['View Doc', 'Doc Number', 'Doc Recorded', 'Doc Executed', 'Doc Type',
#        'Consi. Amt.', '1st Grantor', '1st Grantee', 'Assoc. Doc#', 'deed_urls',
#        'PIN', 'Address', 'COLOR', 'mortgage_urls', 'mortgage_amount',
#        'geo_address', 'geocoded', 'lat', 'lon'],
#       dtype='object')

# %%
def popup_html(row):
    grantor = row['1st Grantor']
    grantee = row['1st Grantee']
    PIN = row['PIN']
    Address = row['Address']
    mortgage_amount = row['mortgage_amount']
    
    html = '''<!DOCTYPE html>
    <html>
    <strong>Lender: </strong>{}'''.format(grantor) + '''<br>
    <strong>Borrower: </strong>{}'''.format(grantee) + '''<br>
    <strong>PIN: </strong>{}'''.format(PIN) + '''<br>
    <strong>Address: </strong>{}'''.format(Address) + '''<br>
    <strong>Mortgage Amount: </strong>{}'''.format(mortgage_amount) + '''<br>
    </html>
    '''
    return html

# %%
df['COLOR'].value_counts()
# Out:
# COLOR
# red       795
# yellow    699
# Name: count, dtype: int64

# %%
# df.to_csv("backup_copy.csv")

# %%
# df['COLOR'] = df['COLOR'].replace('', 'yellow')

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np

m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=10)

title_html = '''
              <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(f'Cook County Pending Foreclosures')

caption_html = '''
                <p align="center" style="vertical-align: bottom; font-size:13px"><i>{}</i></p>
                '''.format(f'July and August')

### Create map container ###
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=9.5, tiles=None)

# Create two FeatureGroups for different color pins
fg_red = folium.FeatureGroup(name=f'May') ## 
fg_yellow = folium.FeatureGroup(name='June')

for index, row in df.iterrows():
    lat = row['lat']
    lon = row['lon']
    color = row['COLOR']
    if pd.notnull(lat) and pd.notnull(lon) and color == 'red':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_red)
    elif pd.notnull(lat) and pd.notnull(lon) and color == 'yellow':
        marker = folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            fill=True,
            color=color,
            popup=folium.Popup(popup_html(row), max_width=400))
        marker.add_to(fg_yellow)
    else:
        continue

# Add the FeatureGroups to the map
fg_red.add_to(m)
fg_yellow.add_to(m)

folium.TileLayer('OpenStreetMap', control=False).add_to(m)

# Add LayerControl to the map
folium.map.LayerControl(collapsed=False).add_to(m)
m.get_root().html.add_child(folium.Element(title_html))
m.get_root().html.add_child(folium.Element(caption_html))
folium.TileLayer('CartoDBpositron', control=False).add_to(m) 
            
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34ec55dffb53029c185e2b5ab576009c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#               &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Cook County Pending Foreclosures&lt;/b&gt;&lt;/h3&gt;
#
#
#                 &lt;p align=&quot;center&quot; style=&quot;vertical-align: bottom; font-size:13px&quot;&gt;&lt;i&gt;July and August&lt;/i&gt;&lt;/p&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34ec55dffb53029c185e2b5ab576009c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_34ec55dffb53029c185e2b5ab576009c = L.map(
#                 &quot;map_34ec55dffb53029c185e2b5ab576009c&quot;,
#                 {
#                     center: [41.78648085185685, -87.72286353950034],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var feature_group_0463e5ffb791d1f6b30335bc3553f8bb = L.featureGroup(
#                 {}
#             ).addTo(map_34ec55dffb53029c185e2b5ab576009c);
#
#
#             var circle_marker_97eb474cab9e7a449521ebe22d479a39 = L.circleMarker(
#                 [42.0920592, -87.71911519999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0463e5ffb791d1f6b30335bc3553f8bb);
#
#
#         var popup_91cd743f4923242d14400722c5bf7809 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_0d0fc72345b4841475bc7aadf5e24806 = $(`&lt;div id=&quot;html_0d0fc72345b4841475bc7aadf5e24806&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;JPMORGAN CHASE BK NATIONAL ASSOCIATION&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;KIM DAVID J&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;05-28-204-001-0000&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;32 WARWICK RD, WINNETKA&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$1,200,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_91cd743f4923242d14400722c5bf7809.setContent(html_0d0fc72345b4841475bc7aadf5e24806);
#
#
#
#         circle_marker_97eb474cab9e7a449521ebe22d479a39.bindPopup(popup_91cd743f4923242d14400722c5bf7809)
#         ;
#
#
#
#
#             var circle_marker_95ecfe1e9050ded3ce9768b624f0802f = L.circleMarker(
#                 [41.873522, -87.662037],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0463e5ffb791d1f6b30335bc3553f8bb);
#
#
#         var popup_1e084a7cd7ce3a1fcf4923159d688e80 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_bf5f5498305938ee16aa5b664302d21a = $(`&lt;div id=&quot;html_bf5f5498305938ee16aa5b664302d21a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt;TOWER REAL ESTATE FUND I LLC&lt;br&gt;     &lt;strong&gt;Borrower: &lt;/strong&gt;KAP MGMT LLC&lt;br&gt;     &lt;strong&gt;PIN: &lt;/strong&gt;17-17-302-090-1005&lt;br&gt;     &lt;strong&gt;Address: &lt;/strong&gt;1404 W FLOURNOY ST, CHICAGO&lt;br&gt;     &lt;strong&gt;Mortgage Amount: &lt;/strong&gt;$880,000.00&lt;br&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_1e084a7cd7ce3a1fcf4923159d688e80.setContent(html_bf5f5498305938ee16aa5b664302d21a);
#
#
#
#         circle_marker_95ecfe1e9050ded3ce9768b624f0802f.bindPopup(popup_1e084a7cd7ce3a1fcf4923159d688e80)
#         ;
#
#
#
#
#             var circle_marker_aae21ebfd9509858a161d477d76c5518 = L.circleMarker(
#                 [41.88138730000001, -87.7598775],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_0463e5ffb791d1f6b30335bc3553f8bb);
#
#
#         var popup_0cc08a1995a8394bddf55a6f2100fa7b = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_43642f6339f27e0109f540cfa7b06f51 = $(`&lt;div id=&quot;html_43642f6339f27e0109f540cfa7b06f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt;     &lt;html&gt;     &lt;strong&gt;Lender: &lt;/strong&gt

# %%
m.save('index.html')

# %% [markdown]
# ## Map URL Snagger

# %%
base_name = 'https://trd-digital.github.io/trd-news-interactive-maps/'

cwd = os.getcwd()

cwd = cwd.split('/')

final_name = base_name + cwd[-1]
print(final_name)
# Out:
# https://trd-digital.github.io/trd-news-interactive-maps/lis_pendens_scraper_july_august_2024

# %% [markdown]
# ## Stats for story

# %%
df['mortgage_amount_int'] = df['mortgage_amount'].str.replace('$','')
df['mortgage_amount_int'] = df['mortgage_amount_int'].str.replace(',','')
df = df.loc[df['mortgage_amount_int'] != 'NA']
df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)
# Out:
# /var/folders/rq/0_j_rksd7psgdycg9c1qwf6m0000gp/T/ipykernel_24835/159485817.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mortgage_amount_int'] = df['mortgage_amount_int'].astype(float).fillna(0).astype(int)

# %%
# Count number of first month dates
dates_count = len(df.loc[df['Doc Recorded'].dt.month == 7])

print(f'Number of July dates: {dates_count}')
# Out:
# Number of July dates: 731

# %%
# Count number of first month dates
dates_count_august = len(df.loc[df['Doc Recorded'].dt.month == 8])

print(f'Number of August dates: {dates_count_august}')
# Out:
# Number of August dates: 645

# %%
df['Doc Recorded'].dt.month.value_counts()
# Out:
# Doc Recorded
# 7    731
# 8    645
# Name: count, dtype: int64

# %%
# Filter for March
df_july = df[df['Doc Recorded'].dt.month == 7]

# Filter for April
df_august = df[df['Doc Recorded'].dt.month == 8]

# %%
df_july.reset_index(inplace=True, drop=True)
df_august.reset_index(inplace=True, drop=True)

# %%
# x.at[123,'mortgage_amount_int']=33130000
# x.at[123,'mortgage_amount']='$33,130,000'

# x.at[16,'mortgage_amount_int']=173600
# x.at[16,'mortgage_amount']='$173,600'

# %%
print(f'July foreclosures: {len(df_july)}')
print('----------')
print(f'August foreclosures: {len(df_august)}')
# Out:
# July foreclosures: 731
# ----------
# August foreclosures: 645

# %%
df_july.sort_values(by='mortgage_amount_int',ascending=False).head(2)
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 152     View  2420618107   2024-07-24    7/18/2024  LIS PENDENS FORECLOSURE
# 7       View  2421311021   2024-07-31    7/30/2024  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.                                 1st Grantor  \
# 152         NaN  WELLS FARGO TRUST COMPANY NATIONAL ASSN TR
# 7           NaN                      REPUBLIC BK OF CHICAGO
#
#                       1st Grantee   Assoc. Doc#  \
# 152  TERRA FUNDINGBURNHAM CTR LLC  1307722130.0
# 7             1454 S MICHIGAN LLC  2236422010.0
#
#                                              deed_urls                 PIN  \
# 152  https://crs.cookcountyclerkil.gov/Document/Det...  17-09-459-002-0000
# 7    https://crs.cookcountyclerkil.gov/Document/Det...  17-22-107-066-0000
#
#                           Address COLOR  \
# 152  111 W WASHINGTON ST, CHICAGO   red
# 7    1464 S MICHIGAN AVE, CHICAGO   red
#
#                                          mortgage_urls mortgage_amount  \
# 152  https://crs.cookcountyclerkil.gov/Document/Det...  $42,000,000.00
# 7    https://crs.cookcountyclerkil.gov/Document/Det...  $11,850,000.00
#
#                                       geo_address  \
# 152  111 W WASHINGTON ST, CHICAGO Cook County, IL
# 7    1464 S MICHIGAN AVE, CHICAGO Cook County, IL
#
#                                     geocoded        lat        lon  \
# 152                (41.8830402, -87.6314065)  41.883040 -87.631406
# 7    (41.86225779999999, -87.62428899999999)  41.862258 -87.624289
#
#      mortgage_amount_int
# 152             42000000
# 7               11850000

# %%
df_august.sort_values(by='mortgage_amount_int',ascending=False).head(2)
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 282     View  2421924711   2024-08-06     8/6/2024  LIS PENDENS FORECLOSURE
# 222     View  2423609047   2024-08-23          NaN  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.        1st Grantor              1st Grantee   Assoc. Doc#  \
# 282         NaN   FIRST EAGLE BANK  MERCHANTS BK OF INDIANA  1935141009.0
# 222         NaN  CNB BK & TRUST NA        ALEXI CORPORATION  2222328282.0
#
#                                              deed_urls                 PIN  \
# 282  https://crs.cookcountyclerkil.gov/Document/Det...  14-33-422-016-0000
# 222  https://crs.cookcountyclerkil.gov/Document/Det...  31-20-302-037-0000
#
#                             Address   COLOR  \
# 282  1639 N NORTH PARK AVE, CHICAGO  yellow
# 222      7155 LINCOLN HWY, MATTESON  yellow
#
#                                          mortgage_urls mortgage_amount  \
# 282  https://crs.cookcountyclerkil.gov/Document/Det...   $3,000,000.00
# 222  https://crs.cookcountyclerkil.gov/Document/Det...   $2,800,000.00
#
#                                         geo_address  \
# 282  1639 N NORTH PARK AVE, CHICAGO Cook County, IL
# 222      7155 LINCOLN HWY, MATTESON Cook County, IL
#
#                       geocoded        lat        lon  mortgage_amount_int
# 282  (41.9121939, -87.6363868)  41.912194 -87.636387              3000000
# 222  (41.5061598, -87.7897861)  41.506160 -87.789786              2800000

# %%
print(df_july.iloc[152]['mortgage_urls'])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=MzI0NDQzMDg1&hId=ZWU3YjZlNDAzMmZlYjM4MjkwZmRlZWFiOWM4YzI1NTg4MjY1NmNjMDUxOWE1MTM2ZDVlMjVkNzA1YzkyYzM5Nw2

# %%
print(df_august.iloc[282]['mortgage_urls'])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=Mzc2ODA3ODg1&hId=MDIxOTAyNzU5Njk2Mjk3ODkyOWU1YjcyNTczNDVkODE5YmIyZDFjNjlhYTg0Y2RjMmQxNDMyZDk2NDY2MjQ4Yg2

# %%
df_august.sort_values(by='mortgage_amount_int',ascending=False).iloc[0:1]
# Out:
#     View Doc  Doc Number Doc Recorded Doc Executed                 Doc Type  \
# 282     View  2421924711   2024-08-06     8/6/2024  LIS PENDENS FORECLOSURE
#
#     Consi. Amt.       1st Grantor              1st Grantee   Assoc. Doc#  \
# 282         NaN  FIRST EAGLE BANK  MERCHANTS BK OF INDIANA  1935141009.0
#
#                                              deed_urls                 PIN  \
# 282  https://crs.cookcountyclerkil.gov/Document/Det...  14-33-422-016-0000
#
#                             Address   COLOR  \
# 282  1639 N NORTH PARK AVE, CHICAGO  yellow
#
#                                          mortgage_urls mortgage_amount  \
# 282  https://crs.cookcountyclerkil.gov/Document/Det...   $3,000,000.00
#
#                                         geo_address  \
# 282  1639 N NORTH PARK AVE, CHICAGO Cook County, IL
#
#                       geocoded        lat        lon  mortgage_amount_int
# 282  (41.9121939, -87.6363868)  41.912194 -87.636387              3000000

# %%
print(df_june['mortgage_urls'].iloc[621])
# Out:
# https://crs.cookcountyclerkil.gov/Document/Detail?dId=MjYwOTk4MjE1&hId=YzIwZjJkYmEyZDNhZWE0YTU4OTc1YjQ5OTQ0YmYwMmJkNDVmNGY3NjM5NjQ1NmYxNTM5MjYwZThiZDBiYWU0MQ2

# %%
print(f'July: ${df_july.mortgage_amount_int.sum():,}')
print('----------')
print(f'August: ${df_august.mortgage_amount_int.sum():,}')
print('----------')
print(f'Total: ${df_july.mortgage_amount_int.sum() + df_august.mortgage_amount_int.sum():,}')
# Out:
# July: $217,098,578
# ----------
# August: $156,032,501
# ----------
# Total: $373,131,079

# %%
## US BANK july 2024
40+29+23
# Out:
# 92

# %%
## US BANK August 2024
35 + 29 + 22 + 8
# Out:
# 94

# %%
df_august['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# NEWREZ LLC                                36
# US BK NATIONAL ASSOCIATION                35
# NATIONSTAR MTG LLC                        30
# US BANK TRUST NATIONAL ASSN TR            29
# LAKEVIEW LOAN SERVICING LLC               28
# MIDFIRST BANK                             25
# PENNYMAC LOAN SERVICES LLC                25
# FREEDOM MTG CORPORATION                   22
# US BANK NATIONAL ASSN TR                  22
# WELLS FARGO BK NA                         20
# JPMORGAN CHASE BK NATIONAL ASSOCIATION    19
# WILMINGTON SAV FUND SOCIETY FSB TR        16
# FEDERAL HOME LOAN MORTGAGE CORP TR        16
# DEUTSCHE BK NATIONAL TRUST COMPANY TR     14
# CARRINGTON MTG SERVICES LLC               13
# FIFTH THIRD BK NATIONAL ASSOCIATION       12
# PHH MTG CORPORATION                        9
# WINTRUST MORTGAGE                          9
# US BANK TRUST COMPANY NATIONAL ASSN TR     8
# HUNTINGTON NATL BANK                       7
# CITIMORTGAGE INC                           7
# WELLS FARGO BK NA TR                       6
# WELLS FARGO BANK NATIONAL ASSN TR          6
# BANK OF NEW YORK MELLON TR                 6
# CITIZENS BK NA                             6
# PLANET HOME LENDG LLC                      6
# UNITED WHOLESALE MTG LLC                   5
# PNC BK NATIONAL ASSOCIATION                5
# AMERIHOME MORTGAGE CO LLC                  5
# CITIBANK NA TR                             5
# BMO BK NA                                  5
# DATA MTG INC                               5
# SERVBANK SB                                4
# GUARANTEED RATE INC                        4
# CAG NATL FUND IV LLC                       4
# MARQUETTE BANK                             4
# PARK TREE MGMT LLC                         4
# FEDERAL SAV BANK                           4
# MORTGAGE ASSETS MGMT LLC                   4
# ROCKET MTG LLC                             4
# LOANDEPOTCOM LLC                           4
# M&T BANK                                   4
# FIFTH THIRD BK NA                          3
# BANK OF AMER NA                            3
# CROSSCOUNTRY MTG LLC                       3
# NATIONS DIRECT MTG LLC                     3
# CITIBANK NA                                3
# BSI FIN SERVICES                           3
# ONSLOW BAY FIN LLC                         3
# HSBC BK USA NA TR                          3
# SELECT PORTFOLIO SERVICING INC             3
# GROUNDFLOOR PROP GA LLC                    3
# MOVEMENT MTG LLC                           2
# TRUIST BANK                                2
# YORKE PROP ILLINOIS LLC                    2
# BARCLAYS BK PLC                            2
# BANK OF NEW YORK TR                        2
# QUICKEN LOANS INC                          2
# TH MSR HOLDINGS LLC                        2
# BANK FIN NATIONAL ASSOCIATION              2
# Name: count, dtype: int64

# %%
df_august['1st Grantor'].value_counts().head(60)
# Out:
# 1st Grantor
# NEWREZ LLC                                36
# US BK NATIONAL ASSOCIATION                35
# NATIONSTAR MTG LLC                        30
# US BANK TRUST NATIONAL ASSN TR            29
# LAKEVIEW LOAN SERVICING LLC               28
# MIDFIRST BANK                             25
# PENNYMAC LOAN SERVICES LLC                25
# FREEDOM MTG CORPORATION                   22
# US BANK NATIONAL ASSN TR                  22
# WELLS FARGO BK NA                         20
# JPMORGAN CHASE BK NATIONAL ASSOCIATION    19
# WILMINGTON SAV FUND SOCIETY FSB TR        16
# FEDERAL HOME LOAN MORTGAGE CORP TR        16
# DEUTSCHE BK NATIONAL TRUST COMPANY TR     14
# CARRINGTON MTG SERVICES LLC               13
# FIFTH THIRD BK NATIONAL ASSOCIATION       12
# PHH MTG CORPORATION                        9
# WINTRUST MORTGAGE                          9
# US BANK TRUST COMPANY NATIONAL ASSN TR     8
# HUNTINGTON NATL BANK                       7
# CITIMORTGAGE INC                           7
# WELLS FARGO BK NA TR                       6
# WELLS FARGO BANK NATIONAL ASSN TR          6
# BANK OF NEW YORK MELLON TR                 6
# CITIZENS BK NA                             6
# PLANET HOME LENDG LLC                      6
# UNITED WHOLESALE MTG LLC                   5
# PNC BK NATIONAL ASSOCIATION                5
# AMERIHOME MORTGAGE CO LLC                  5
# CITIBANK NA TR                             5
# BMO BK NA                                  5
# DATA MTG INC                               5
# SERVBANK SB                                4
# GUARANTEED RATE INC                        4
# CAG NATL FUND IV LLC                       4
# MARQUETTE BANK                             4
# PARK TREE MGMT LLC                         4
# FEDERAL SAV BANK                           4
# MORTGAGE ASSETS MGMT LLC                   4
# ROCKET MTG LLC                             4
# LOANDEPOTCOM LLC                           4
# M&T BANK                                   4
# FIFTH THIRD BK NA                          3
# BANK OF AMER NA                            3
# CROSSCOUNTRY MTG LLC                       3
# NATIONS DIRECT MTG LLC                     3
# CITIBANK NA                                3
# BSI FIN SERVICES                           3
# ONSLOW BAY FIN LLC                         3
# HSBC BK USA NA TR                          3
# SELECT PORTFOLIO SERVICING INC             3
# GROUNDFLOOR PROP GA LLC                    3
# MOVEMENT MTG LLC                           2
# TRUIST BANK                                2
# YORKE PROP ILLINOIS LLC                    2
# BARCLAYS BK PLC                            2
# BANK OF NEW YORK TR                        2
# QUICKEN LOANS INC                          2
# TH MSR HOLDINGS LLC                        2
# BANK FIN NATIONAL ASSOCIATION              2
# Name: count, dtype: int64

# %%
df.to_csv(f'{current_month}_JulyAugust_2024_foreclosures.csv')

# %%
# apr.sort_values(by='mortgage_amount_int',ascending=False)

# %%
print(f"July median mortgage foreclosure amount: ${df_july['mortgage_amount_int'].median():,}")
# Out:
# July median mortgage foreclosure amount: $178,703.0

# %%
print(f"August median mortgage foreclosure amount: ${df_august['mortgage_amount_int'].median():,}")
# Out:
# August median mortgage foreclosure amount: $171,830.0
